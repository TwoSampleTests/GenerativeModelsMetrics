# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [2]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/20D_mixture/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-03 10:39:35.584633: Importing os...
# 2024-05-03 10:39:35.584740: Importing sys...
# Visible devices: [2]
# 2024-05-03 10:39:35.584974: Importing timer from timeit...
# 2024-05-03 10:39:35.585042: Setting env variables for tf import (only device(s) [2] will be available)...
# 2024-05-03 10:39:35.585170: Importing numpy...
# 2024-05-03 10:39:35.705920: Importing matplotlib...
# 2024-05-03 10:39:36.054921: Importing h5py...
# 2024-05-03 10:39:36.078132: Importing importlib.util...
# 2024-05-03 10:39:36.078234: Importing json...
# 2024-05-03 10:39:36.078298: Importing pandas...
# 2024-05-03 10:39:36.515980: Importing random...
# 2024-05-03 10:39:36.516124: Importing scipy utils...
# 2024-05-03 10:39:36.926153: Importing subprocess...
# 2024-05-03 10:39:36.926285: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-03 10:39:40.219757: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-03 10:39:41.400806: Importing timeit...
# 2024-05-03 10:39:41.400897: Importing tqdm...
# 2024-05-03 10:39:41.408682: Importing typing...
# 2024-05-03 10:39:41.408790: Setting tf configs...
# 2024-05-03 10:39:41.519535: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-03 10:39:46.168783: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #2, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-03 10:39:46.198432: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 10_000
dist_1 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
dist_2 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture.Mixture'> <class 'tensorflow_probability.python.distributions.mixture.Mixture'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)

# %% [markdown]
# # Fixed $n=50000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 50_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 500000000
# batch_size 50000
# niter 10000
# niter * batch_size 500000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            50000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...       20           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True       20           0  float64    20  500000000         False
#
#    ncomp
# 0      5
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/20D_mixture/20D_50K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 2,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/20D_mixture/20D_50K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 5000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/20D_mixture/20D_50K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/20D_mixture/20D_50K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/20D_mixture/20D_50K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/20D_mixture/20D_50K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fgd from results/20D_mixture/20D_50K/null_hypothesis/FGD.json
# Loading mmd from results/20D_mixture/20D_50K/null_hypothesis/MMD.json
# Loading ks from results/20D_mixture/20D_50K/null_hypothesis/KS.json
# Loading sks from results/20D_mixture/20D_50K/null_hypothesis/SKS.json
# Loading swd from results/20D_mixture/20D_50K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0012892875189689634], [0.95, [9500, 500], 0.012067958327521663], [0.99, [9900, 100], 0.023100897113778766]]
# Computing time for metric fgd: 4649.197955087991
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.010694377652782805], [0.95, [9500, 500], 0.24792677700024512], [0.99, [9900, 100], 0.4836074616096937]]
# Computing time for metric mmd: 13945.813867144054
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9142148210839266], [0.95, [9500, 500], 1.1562866557849483], [0.99, [9900, 100], 1.3287896487324844]]
# Computing time for metric ks: 180.6616022149101
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9124127729458597], [0.95, [9500, 500], 1.1215342776024302], [0.99, [9900, 100], 1.2842966596432495]]
# Computing time for metric sks: 533.7931425748393
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.6262794249557475], [0.95, [9500, 500], 0.8748483060915908], [0.99, [9900, 100], 1.0811092781908553]]
# Computing time for metric swd: 358.46774154901505
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f7a04088cc0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f7a04088e00>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f7a04088ea0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f7a04088f40>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f7a04088fe0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f7a04089080>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_mixture/20D_50K/null_hypothesis/FG...
# 1  $d_{\mathrm{MMD}}$  results/20D_mixture/20D_50K/null_hypothesis/MM...
# 2      $\overline{D}$  results/20D_mixture/20D_50K/null_hypothesis/KS...
# 3     $\widetilde{D}$  results/20D_mixture/20D_50K/null_hypothesis/SK...
# 4     $\widetilde{W}$  results/20D_mixture/20D_50K/null_hypothesis/SW...
# 5           $t_{\mu}$  results/20D_mixture/20D_50K/null_hypothesis/LR...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0012892875189689634], ...
# 1  [[0.68, [6800, 3199], 0.010694377652782805], [...
# 2  [[0.68, [6800, 3199], 0.9142148210839266], [0....
# 3  [[0.68, [6800, 3199], 0.9124127729458597], [0....
# 4  [[0.68, [6800, 3199], 0.6262794249557475], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10)$"
        dist_null = dist_null * 10
    #elif "MMD" in latex:
    #    latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-2})$"
    #    dist_null = dist_null / 100
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 10
        #elif "MMD" in latex:
        #    threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 10
        #elif "MMD" in latex:
        #    threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.023636393138266685 +/- 2.2877971942636097e-05
# sigma = 0.04783092299196839 +/- 0.0009561209246062055
# 68%CL = 0.012892875189689634, 95%CL = 0.12067958327521663, 99%CL = 0.23100897113778768
# mu = 0.023636393138266685 +/- 2.2877971942636097e-05
# sigma = 0.04783092299196839 +/- 0.0009561209246062055
# /tmp/ipykernel_1589936/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1589936/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1589936/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.4746834728866816 seconds.
# mu = -0.0008498668148910781 +/- 0.0001596884188025692
# sigma = 0.1263678831042798 +/- 0.0020411065975618104
# 68%CL = 0.010694377652782805, 95%CL = 0.24792677700024512, 99%CL = 0.4836074616096937
# mu = -0.0008498668148910781 +/- 0.0001596884188025692
# sigma = 0.1263678831042798 +/- 0.0020411065975618104
# /tmp/ipykernel_1589936/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1589936/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1589936/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1589936/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.8794675900135189 seconds.
# mu = 0.8672499136500023 +/- 0.00023096925332212896
# sigma = 0.15197672628469433 +/- 0.0013913160796868078
# 68%CL = 0.9142148210839266, 95%CL = 1.1562866557849483, 99%CL = 1.3287896487324844
# mu = 0.8672499136500023 +/- 0.00023096925332212896
# sigma = 0.15197672628469433 +/- 0.0013913160796868078
# /tmp/ipykernel_1589936/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1589936/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1589936/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1589936/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2716702399775386 seconds.
# mu = 0.8677795525910104 +/- 0.00018419771236073836
# sigma = 0.13571945783885903 +/- 0.0012259324788883024
# 68%CL = 0.9124127729458597, 95%CL = 1.1215342776024302, 99%CL = 1.2842966596432495
# mu = 0.8677795525910104 +/- 0.00018419771236073836
# sigma = 0.13571945783885903 +/- 0.0012259324788883024
# /tmp/ipykernel_1589936/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1589936/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1589936/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1589936/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2344562949147075 seconds.
# mu = 0.5751541919262889 +/- 0.0002645039021051419
# sigma = 0.16263575932283217 +/- 0.0014871058289628305
# 68%CL = 0.6262794249557475, 95%CL = 0.8748483060915908, 99%CL = 1.0811092781908553
# mu = 0.5751541919262889 +/- 0.0002645039021051419
# sigma = 0.16263575932283217 +/- 0.0014871058289628305
# /tmp/ipykernel_1589936/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1589936/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1589936/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1589936/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.8924820788670331 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f7a04088cc0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f7a04088e00>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f7a04088ea0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f7a04088f40>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f7a04088fe0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f7a04089080>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_mixture/20D_50K/null_hypothesis/FG...
# 1  $d_{\mathrm{MMD}}$  results/20D_mixture/20D_50K/null_hypothesis/MM...
# 2      $\overline{D}$  results/20D_mixture/20D_50K/null_hypothesis/KS...
# 3     $\widetilde{D}$  results/20D_mixture/20D_50K/null_hypothesis/SK...
# 4     $\widetilde{W}$  results/20D_mixture/20D_50K/null_hypothesis/SW...
# 5           $t_{\mu}$  results/20D_mixture/20D_50K/null_hypothesis/LR...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0012892875189689634], ...
# 1  [[0.68, [6800, 3199], 0.010694377652782805], [...
# 2  [[0.68, [6800, 3199], 0.9142148210839266], [0....
# 3  [[0.68, [6800, 3199], 0.9124127729458597], [0....
# 4  [[0.68, [6800, 3199], 0.6262794249557475], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/20D_mixture/20D_50K/null_hypothesis/FG...
# 1  results/20D_mixture/20D_50K/null_hypothesis/MM...
# 2  results/20D_mixture/20D_50K/null_hypothesis/KS...
# 3  results/20D_mixture/20D_50K/null_hypothesis/SK...
# 4  results/20D_mixture/20D_50K/null_hypothesis/SW...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 1.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for fgd with mean deformation already loaded.
# Exclusion limits for fgd with cov_diag deformation already loaded.
# Exclusion limits for fgd with cov_off_diag deformation already loaded.
# Exclusion limits for fgd with power_abs_up deformation already loaded.
# Exclusion limits for fgd with power_abs_down deformation already loaded.
# Exclusion limits for fgd with random_normal deformation already loaded.
# Exclusion limits for fgd with random_uniform deformation already loaded.
# Exclusion limits for mmd with mean deformation already loaded.
# Exclusion limits for mmd with cov_diag deformation already loaded.
# Exclusion limits for mmd with cov_off_diag deformation already loaded.
# Exclusion limits for mmd with power_abs_up deformation already loaded.
# Exclusion limits for mmd with power_abs_down deformation already loaded.
# Exclusion limits for mmd with random_normal deformation already loaded.
# Exclusion limits for mmd with random_uniform deformation already loaded.
# Exclusion limits for ks with mean deformation already loaded.
# Computing exclusion limits for ks with cov_diag deformation.
#
# ======================================================
# =============== ks - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = cov_diag
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714725597.416883 1589936 service.cc:145] XLA service 0xc1de5240 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714725597.416933 1589936 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1714725597.514424 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1714725597.520464 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1714725597.524359 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1714725597.524719 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1714725597.525716 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1714725597.525791 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1714725597.525861 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1714725597.525938 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1714725597.526010 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1714725597.526080 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1714725597.526151 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1714725597.526223 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1714725597.526292 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_25/Assert/Assert
# W0000 00:00:1714725597.526363 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_27/Assert/Assert
# W0000 00:00:1714725597.526433 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_29/Assert/Assert
# W0000 00:00:1714725597.526504 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_31/Assert/Assert
# W0000 00:00:1714725597.526575 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_33/Assert/Assert
# W0000 00:00:1714725597.526644 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_35/Assert/Assert
# W0000 00:00:1714725597.526713 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_37/Assert/Assert
# W0000 00:00:1714725597.526782 1589936 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_39/Assert/Assert
# I0000 00:00:1714725638.713593 1589936 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# statistic = 34.4683519647386 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8701700058656816
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = cov_diag
# statistic = 27.337289635017495 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8376775671844054
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = cov_diag
# WARNING:tensorflow:5 out of the last 5 calls to <function generate_and_clean_data_simple_1 at 0x7f7af6514f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function generate_and_clean_data_simple_1 at 0x7f7af6514f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 20.224078243127327 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7836731671789614
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = cov_diag
# statistic = 13.565950509415089 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6858394161674988
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = cov_diag
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f782c66d760> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 8.356730353937516 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5138086457311268
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = cov_diag
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f781c4be520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 5.0338565627835345 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2528207410022747
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = cov_diag
# statistic = 2.884440989445459 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8553678868707665
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.00390625 - deformation = cov_diag
# statistic = 1.7216236732752608 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.39288021713652566
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.001953125 - deformation = cov_diag
# statistic = 1.1829458416383778 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.022793104903249012
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0009765625 - deformation = cov_diag
# statistic = 0.9723064056410331 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.17286559228062467
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00146484375 - deformation = cov_diag
# statistic = 1.0701946689032666 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.07733456905930933
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.001708984375 - deformation = cov_diag
# statistic = 1.1251707140279466 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.027277250207444006
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0018310546875 - deformation = cov_diag
# statistic = 1.1536789694951777 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.00225777064492409
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00189208984375 - deformation = cov_diag
# statistic = 1.1684309370295036 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.010447962610247821
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.001861572265625 - deformation = cov_diag
# statistic = 1.1610783933177942 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.01652892561983471
# relative_error_metric = 0.004135505137355207
# =======> statistic within required accuracy at 0.95 CL in 1317.2041364049073 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0018463134765625 - deformation = cov_diag
# statistic = 1.1576001058478997 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.992628356458565
# relative_error_metric = 0.13770129366823705
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5009231567382812 - deformation = cov_diag
# statistic = 34.4927805373089 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.985310854489446
# relative_error_metric = 1.851621283843077
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.2513847351074219 - deformation = cov_diag
# statistic = 27.39391045401949 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9708359067833632
# relative_error_metric = 1.8149492012966886
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.1266155242919922 - deformation = cov_diag
# statistic = 20.350806710032476 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9425101334798296
# relative_error_metric = 1.7548312935825927
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.06423091888427734 - deformation = cov_diag
# statistic = 13.81365148271033 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.8882330018618212
# relative_error_metric = 1.6489893175880885
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.03303861618041992 - deformation = cov_diag
# statistic = 8.692169274867284 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.7882967235746798
# relative_error_metric = 1.4695958105952793
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.01744246482849121 - deformation = cov_diag
# statistic = 5.474330378090547 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.6171217383780576
# relative_error_metric = 1.2187175040314484
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.009644389152526855 - deformation = cov_diag
# statistic = 3.4247473792359067 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.3572843937712027
# relative_error_metric = 0.881851858172739
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.005745351314544678 - deformation = cov_diag
# statistic = 2.265756673470468 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.0271891463251863
# relative_error_metric = 0.5213269997109145
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.003795832395553589 - deformation = cov_diag
# statistic = 1.6900011977806597 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.6910558369735738
# relative_error_metric = 0.2393087612978507
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0028210729360580444 - deformation = cov_diag
# statistic = 1.411072348290972 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.4176896332644793
# relative_error_metric = 0.06006338979691547
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.002333693206310272 - deformation = cov_diag
# statistic = 1.2779561761823433 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.18909867733547633
# relative_error_metric = 0.039001479978817706
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0025773830711841583 - deformation = cov_diag
# statistic = 1.3428465195199808 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.09924092036225249
# relative_error_metric = 0.010523042736534812
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0024555381387472153 - deformation = cov_diag
# statistic = 1.3096263092944027 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.0484191694463679
# relative_error_metric = 0.014526397461917107
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.002516460604965687 - deformation = cov_diag
# statistic = 1.3260071118217471 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.023920037634338812
# relative_error_metric = 0.0020962334684756557
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.0025469218380749226 - deformation = cov_diag
# statistic = 1.3344503381891335 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.012031970111640828
# relative_error_metric = 0.004250979622149766
# =======> statistic within required accuracy at 0.99 CL in 1402.976242031902 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2720.1804127518553 seconds.
# Saving results in the file results/20D_mixture/20D_50K/exclusion_limits.json
# Computing exclusion limits for ks with cov_off_diag deformation.
#
# ======================================================
# =============== ks - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = cov_off_diag
# statistic = 25.565323219520018 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8269136236655348
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = cov_off_diag
# statistic = 23.733289575319255 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8141733479029745
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = cov_off_diag
# statistic = 20.85737185418453 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7898965035255192
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = cov_off_diag
# statistic = 16.928811026614113 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7442564754493353
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = cov_off_diag
# statistic = 13.411567922165535 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6825101048070392
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = cov_off_diag
# statistic = 10.291032427018612 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5959624616310557
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = cov_off_diag
# statistic = 7.324753471761859 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4546486570536197
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.00390625 - deformation = cov_off_diag
# statistic = 4.870777953513884 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2326037759734805
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.001953125 - deformation = cov_off_diag
# statistic = 3.0990647047517923 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.913098771106786
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0009765625 - deformation = cov_off_diag
# statistic = 1.9655937254284312 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5184741058713659
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00048828125 - deformation = cov_off_diag
# statistic = 1.3334229869761596 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.14229477056189227
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.000244140625 - deformation = cov_off_diag
# statistic = 1.0148390179854443 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.13029889472391987
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0003662109375 - deformation = cov_off_diag
# statistic = 1.1744231917987629 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.015563100685927997
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00030517578125 - deformation = cov_off_diag
# statistic = 1.0941646775340952 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.05520846181484266
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.000335693359375 - deformation = cov_off_diag
# statistic = 1.1348952476306404 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.018672815215953407
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0003509521484375 - deformation = cov_off_diag
# statistic = 1.1545169743021688 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.0425531914893617
# relative_error_metric = 0.0015316589083882767
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00035858154296875 - deformation = cov_off_diag
# statistic = 1.164509700543362 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.021505376344086023
# relative_error_metric = 0.007086399231876822
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.000354766845703125 - deformation = cov_off_diag
# statistic = 1.1599243615488113 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.010810810810810811
# relative_error_metric = 0.003141083205838872
# =======> statistic within required accuracy at 0.95 CL in 914.9306399500929 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0003528594970703125 - deformation = cov_off_diag
# statistic = 1.1574263272435417 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9985890598753415
# relative_error_metric = 0.13785071220264347
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5001764297485352 - deformation = cov_off_diag
# statistic = 25.5659398057758 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9971801090992924
# relative_error_metric = 1.8023717396406465
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.25026464462280273 - deformation = cov_off_diag
# statistic = 23.736625867710163 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9943681587874798
# relative_error_metric = 1.7879485145002583
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.12530875205993652 - deformation = cov_off_diag
# statistic = 20.870637576715136 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9887679461468553
# relative_error_metric = 1.760572264277293
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.06283080577850342 - deformation = cov_off_diag
# statistic = 16.957651029990192 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9776613467717439
# relative_error_metric = 1.7093388107443768
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.031591832637786865 - deformation = cov_off_diag
# statistic = 13.459761695182683 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9558161968716823
# relative_error_metric = 1.6405896377999938
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.01597234606742859 - deformation = cov_off_diag
# statistic = 10.392525893914796 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.913542406390852
# relative_error_metric = 1.5465390744246186
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.00816260278224945 - deformation = cov_off_diag
# statistic = 7.499041943711644 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.834249986438317
# relative_error_metric = 1.3979089270937994
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.004257731139659882 - deformation = cov_off_diag
# statistic = 5.134986395166977 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.693870460535565
# relative_error_metric = 1.1777006878283778
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.002305295318365097 - deformation = cov_off_diag
# statistic = 3.460655129208168 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.469015882714847
# relative_error_metric = 0.8902349141991088
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0013290774077177048 - deformation = cov_off_diag
# statistic = 2.397133693008848 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.1608258405750718
# relative_error_metric = 0.5734653916830541
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0008409684523940086 - deformation = cov_off_diag
# statistic = 1.7941189377730349 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.8177207704723516
# relative_error_metric = 0.298010188995795
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0005969139747321606 - deformation = cov_off_diag
# statistic = 1.4743021555730325 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.5139214452867025
# relative_error_metric = 0.10382286203901173
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.00047488673590123653 - deformation = cov_off_diag
# statistic = 1.3156819720789792 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.22770509035921457
# relative_error_metric = 0.009913267021170057
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0005359003553166986 - deformation = cov_off_diag
# statistic = 1.3962732061356813 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.12072496759321379
# relative_error_metric = 0.049528074027827614
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.0005053935456089675 - deformation = cov_off_diag
# statistic = 1.3556851906872287 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.06224099430161485
# relative_error_metric = 0.020037842456037437
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.000490140140755102 - deformation = cov_off_diag
# statistic = 1.3359526928929815 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.03161239385729043
# relative_error_metric = 0.005376162677047179
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.0004825134383281693 - deformation = cov_off_diag
# statistic = 1.3258491248466564 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.01568225849561144
# relative_error_metric = 0.0022153853210419338
# =======> statistic within required accuracy at 0.99 CL in 927.3404287318699 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1842.271103853127 seconds.
# Saving results in the file results/20D_mixture/20D_50K/exclusion_limits.json
# Computing exclusion limits for ks with power_abs_up deformation.
#
# ======================================================
# =============== ks - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = power_abs_up
# statistic = 46.904119437505145 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.90376388800873
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = power_abs_up
# statistic = 37.04424842661981 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.878924559219849
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = power_abs_up
# statistic = 28.358499930435425 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8432939160976638
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = power_abs_up
# statistic = 21.213997922873325 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7932459639984961
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = power_abs_up
# statistic = 15.319638860618202 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7192784940345185
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = power_abs_up
# statistic = 10.186772176554651 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5922487318893843
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = power_abs_up
# statistic = 6.557062260611598 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.400371139271562
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.00390625 - deformation = power_abs_up
# statistic = 4.291227262191415 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1509619446997323
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.001953125 - deformation = power_abs_up
# statistic = 2.6817071399256585 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7949051329085214
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0009765625 - deformation = power_abs_up
# statistic = 1.7002787270275788 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.380871430085752
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00048828125 - deformation = power_abs_up
# statistic = 1.2093822659747338 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.044888453917964796
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.000244140625 - deformation = power_abs_up
# statistic = 0.9923707868187521 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.15257515294533516
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0003662109375 - deformation = power_abs_up
# statistic = 1.0973271441990378 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.052324414756716044
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00042724609375 - deformation = power_abs_up
# statistic = 1.151844919894294 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.0038487718269243
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.000457763671875 - deformation = power_abs_up
# statistic = 1.180352604012014 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.020598770756900593
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0004425048828125 - deformation = power_abs_up
# statistic = 1.1658854866050232 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.03508771929824561
# relative_error_metric = 0.008267113918777677
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00043487548828125 - deformation = power_abs_up
# statistic = 1.1589757210937277 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.017699115044247787
# relative_error_metric = 0.002322903300838589
# =======> statistic within required accuracy at 0.95 CL in 1489.0568844249938 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.000431060791015625 - deformation = power_abs_up
# statistic = 1.155323484203642 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9982764997693103
# relative_error_metric = 0.1396604383503356
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5002155303955078 - deformation = power_abs_up
# statistic = 46.911028937957376 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9965559674340814
# relative_error_metric = 1.8898180227320245
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.2503232955932617 - deformation = power_abs_up
# statistic = 37.05983850498475 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9931237758381348
# relative_error_metric = 1.8615434088020348
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.12537717819213867 - deformation = power_abs_up
# statistic = 28.393743383522644 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9862946721295942
# relative_error_metric = 1.821174104200275
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.06290411949157715 - deformation = power_abs_up
# statistic = 21.27344851230903 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.972775901854717
# relative_error_metric = 1.764839280204938
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.03166759014129639 - deformation = power_abs_up
# statistic = 15.426223126757378 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9462830021206032
# relative_error_metric = 1.6827720356796598
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.016049325466156006 - deformation = power_abs_up
# statistic = 10.35990680227679 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.8953760465831209
# relative_error_metric = 1.545273622494406
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.008240193128585815 - deformation = power_abs_up
# statistic = 6.778184590663857 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.8011541144972316
# relative_error_metric = 1.3443720877882408
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.00433562695980072 - deformation = power_abs_up
# statistic = 4.5830580377184384 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.6382722648935406
# relative_error_metric = 1.1009310664225178
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.0023833438754081726 - deformation = power_abs_up
# statistic = 3.0814662710086105 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.3873506590459652
# relative_error_metric = 0.7948185566424079
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0014072023332118988 - deformation = power_abs_up
# statistic = 2.1397876478694484 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.06202591928342
# relative_error_metric = 0.46762573227442605
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0009191315621137619 - deformation = power_abs_up
# statistic = 1.642171986982928 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.7229647982628825
# relative_error_metric = 0.21096357117716916
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0006750961765646935 - deformation = power_abs_up
# statistic = 1.3940120227086226 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.4412310236274834
# relative_error_metric = 0.04790828113574478
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0005530784837901592 - deformation = power_abs_up
# statistic = 1.2724534913713885 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.19869762292486973
# relative_error_metric = 0.04331479552414794
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0006140873301774263 - deformation = power_abs_up
# statistic = 1.3339444288128552 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.10454186655772192
# relative_error_metric = 0.003871794877183393
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.0005835829069837928 - deformation = power_abs_up
# statistic = 1.3032387042243427 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.050939602984435416
# relative_error_metric = 0.019415402177896498
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0005988351185806096 - deformation = power_abs_up
# statistic = 1.318227946731362 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.025149524790202674
# relative_error_metric = 0.007980076913143164
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.000606461224379018 - deformation = power_abs_up
# statistic = 1.3259758584144758 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 0.0124961940595305
# relative_error_metric = 0.0021198032823866904
# =======> statistic within required accuracy at 0.99 CL in 1574.612791521009 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 3063.6697112801485 seconds.
# Saving results in the file results/20D_mixture/20D_50K/exclusion_limits.json
# Computing exclusion limits for ks with power_abs_down deformation.
#
# ======================================================
# =============== ks - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = power_abs_down
# statistic = 55.91550414626701 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9189591467493694
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = power_abs_down
# statistic = 40.64299958082339 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8893486698084088
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = power_abs_down
# statistic = 29.887745640783624 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8510133419861492
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = power_abs_down
# statistic = 21.789990691206434 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7984358615910208
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = power_abs_down
# statistic = 15.561268914035358 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7233359504131436
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = power_abs_down
# statistic = 10.269861056163348 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5952138253644939
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = power_abs_down
# statistic = 6.59255871256346 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4031179610278377
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.00390625 - deformation = power_abs_down
# statistic = 4.311513377046109 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1541119654397756
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.001953125 - deformation = power_abs_down
# statistic = 2.6808689407420294 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7946418885577565
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0009765625 - deformation = power_abs_down
# statistic = 1.6933376757129055 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.37692759287022654
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00048828125 - deformation = power_abs_down
# statistic = 1.204781206033329 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.04107848912994363
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.000244140625 - deformation = power_abs_down
# statistic = 0.9923552425779323 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.15259072564108575
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0003662109375 - deformation = power_abs_down
# statistic = 1.094670863749827 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.05474629485487217
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00042724609375 - deformation = power_abs_down
# statistic = 1.1492359848818807 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.0061163319576235204
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.000457763671875 - deformation = power_abs_down
# statistic = 1.1767318149058374 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.017526787188131904
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0004425048828125 - deformation = power_abs_down
# statistic = 1.162912707977729 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.03508771929824561
# relative_error_metric = 0.005714085900774529
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00043487548828125 - deformation = power_abs_down
# statistic = 1.1560032546470946 - next threshold = 1.1562866557849483 at 0.95 CL
# relative_error_eps = 0.017391304347826087
# relative_error_metric = 0.00024512595637342155
# =======> statistic within required accuracy at 0.95 CL in 1502.7937277650926 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.000438690185546875 - deformation = power_abs_down
# statistic = 1.1594975399032965 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.998246008716574
# relative_error_metric = 0.13607119757105154
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5002193450927734 - deformation = power_abs_down
# statistic = 55.92513318792875 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9964950912228703
# relative_error_metric = 1.907165162986413
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.25032901763916016 - deformation = power_abs_down
# statistic = 40.66815593486668 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9930024453411117
# relative_error_metric = 1.8734394008642947
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.12538385391235352 - deformation = power_abs_down
# statistic = 29.929377017011763 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9860536857304192
# relative_error_metric = 1.8299593622438897
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.0629112720489502 - deformation = power_abs_down
# statistic = 21.854627950271503 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.9723005242577407
# relative_error_metric = 1.7707344668993803
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.031674981117248535 - deformation = power_abs_down
# statistic = 15.674715086328977 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.945357828270642
# relative_error_metric = 1.6874080562950056
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.016056835651397705 - deformation = power_abs_down
# statistic = 10.452244976389261 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.8936220185077453
# relative_error_metric = 1.5488377070383992
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.00824776291847229 - deformation = power_abs_down
# statistic = 6.8176179028603965 - next threshold = 1.3287896487324844 at 0.99 CL
# relative_error_eps = 1.797988808415303
# relative_error_metric = 1.3475457051138258
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.0043432265520095825 - deformation = power_abs_down

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.005 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714505976.477947 1021083 service.cc:145] XLA service 0xc07f2dc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714505976.477992 1021083 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1714505976.574331 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1714505976.579118 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1714505976.582510 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1714505976.582817 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1714505976.583673 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1714505976.583739 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1714505976.583801 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1714505976.583868 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1714505976.583930 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1714505976.583991 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1714505976.584054 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1714505976.584117 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1714505976.584177 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_25/Assert/Assert
# W0000 00:00:1714505976.584240 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_27/Assert/Assert
# W0000 00:00:1714505976.584299 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_29/Assert/Assert
# W0000 00:00:1714505976.584362 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_31/Assert/Assert
# W0000 00:00:1714505976.584422 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_33/Assert/Assert
# W0000 00:00:1714505976.584482 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_35/Assert/Assert
# W0000 00:00:1714505976.584544 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_37/Assert/Assert
# W0000 00:00:1714505976.584604 1021083 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_39/Assert/Assert
# I0000 00:00:1714506017.519430 1021083 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 70.4706845729379 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -936.10684023082], [0.99, [9900, 100], -899.5262878783011]]
# Null distribution computed in 70.8152595689753 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# WARNING:tensorflow:5 out of the last 104 calls to <function generate_and_clean_data_simple_1 at 0x7fd17d9b8e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# LR metric calculation completed in 81.83409151504748 seconds.
# statistic = 1031.4756204818061 - next threshold = -936.10684023082 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 41.2626114234544
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.0025 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# WARNING:tensorflow:6 out of the last 105 calls to <function generate_and_clean_data_simple_1 at 0x7fd17d9b8e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 67.43888233695179 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -211.2180990821565], [0.99, [9900, 100], -193.13735863663038]]
# Null distribution computed in 67.79115978791378 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 82.37392156699207 seconds.
# statistic = 259.13852452336 - next threshold = -211.2180990821565 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 19.63073655022641
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.00125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 67.63834649010096 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.001250.json
# ThresholdS: [[0.95, [9500, 500], -41.45266981615341], [0.99, [9900, 100], -32.26743553047582]]
# Null distribution computed in 67.98672621999867 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 81.37158855691087 seconds.
# statistic = 65.41944083230044 - next threshold = -41.45266981615341 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 8.918357051640488
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.000625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 67.25979094603099 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.000625.json
# ThresholdS: [[0.95, [9500, 500], -4.688891698276738], [0.99, [9900, 100], -0.03775805947378156]]
# Null distribution computed in 67.61108016595244 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 81.78089414304122 seconds.
# statistic = 16.67226505881356 - next threshold = -4.688891698276738 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 3.5651324738718437
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.0003125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 67.22797021002043 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.000313.json
# ThresholdS: [[0.95, [9500, 500], 1.6617811880636177], [0.99, [9900, 100], 3.9893984528799216]]
# Null distribution computed in 67.57394683093298 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 82.93986351101194 seconds.
# statistic = 4.326768690128181 - next threshold = 1.6617811880636177 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8900276548649998
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.00015625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 68.62574752198998 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.000156.json
# ThresholdS: [[0.95, [9500, 500], 1.8347341912008062], [0.99, [9900, 100], 2.9955524859385916]]
# Null distribution computed in 68.96901959402021 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 82.57444858900271 seconds.
# statistic = 1.1610433852341506 - next threshold = 1.8347341912008062 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.44976023004242044
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.000234375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 67.81259937910363 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.000234.json
# ThresholdS: [[0.95, [9500, 500], 1.9993445263008305], [0.99, [9900, 100], 3.742753235005935]]
# Null distribution computed in 68.15743603289593 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 80.79976921097841 seconds.
# statistic = 2.49332079774426 - next threshold = 1.9993445263008305 at 0.95 CL
# relative_error_eps = 0.3999999999999999
# relative_error_metric = 0.21990343629632533
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.0001953125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 66.35944585199468 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.000195.json
# ThresholdS: [[0.95, [9500, 500], 1.9797690887925166], [0.99, [9900, 100], 3.432497446273786]]
# Null distribution computed in 66.70376680791378 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 83.87955065909773 seconds.
# statistic = 1.764535781469994 - next threshold = 1.9797690887925166 at 0.95 CL
# relative_error_eps = 0.18181818181818174
# relative_error_metric = 0.11496569578610873
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.00021484375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 67.65269322204404 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.000215.json
# ThresholdS: [[0.95, [9500, 500], 2.005239240015939], [0.99, [9900, 100], 3.6037739756994815]]
# Null distribution computed in 68.00187271100003 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 80.97247402195353 seconds.
# statistic = 2.113266712089976 - next threshold = 2.005239240015939 at 0.95 CL
# relative_error_eps = 0.09523809523809518
# relative_error_metric = 0.05245954398526456
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.00020507812500000002 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 67.736762151937 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.000205.json
# ThresholdS: [[0.95, [9500, 500], 1.9964247724186466], [0.99, [9900, 100], 3.522237238711143]]
# Null distribution computed in 68.09157385700382 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 81.89994881802704 seconds.
# statistic = 1.9349858524377408 - next threshold = 1.9964247724186466 at 0.95 CL
# relative_error_eps = 0.04651162790697665
# relative_error_metric = 0.03125540720292992
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00020996093750000002 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 68.28079923300538 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_mean_0.000210.json
# ThresholdS: [[0.95, [9500, 500], 2.0018121582620565], [0.99, [9900, 100], 3.5641167504204767]]
# Null distribution computed in 68.63587596791331 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 81.77288424398284 seconds.
# statistic = 2.023147433643312 - next threshold = 2.0018121582620565 at 0.95 CL
# relative_error_eps = 0.0235294117647059
# relative_error_metric = 0.010601485502693365
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.00020751953125000002 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# ...
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 70.55981566698756 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_power_abs_down_0.000023.json
# ThresholdS: [[0.95, [9500, 500], 1.6052159887818414], [0.99, [9900, 100], 3.862243425739477]]
# Null distribution computed in 70.868391878088 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 83.43265814892948 seconds.
# statistic = 3.7196201324428784 - next threshold = 3.862243425739477 at 0.99 CL
# relative_error_eps = 0.05130149382762639
# relative_error_metric = 0.03762222630415956
#
# ------------ 15 - 0.99 CL ------------
# eps = 2.3754115682095295e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 70.25053276796825 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_power_abs_down_0.000024.json
# ThresholdS: [[0.95, [9500, 500], 1.5334547062263335], [0.99, [9900, 100], 3.8539031567799555]]
# Null distribution computed in 70.54721483099274 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 82.8155919999117 seconds.
# statistic = 3.941893031774084 - next threshold = 3.8539031567799555 at 0.99 CL
# relative_error_eps = 0.025984001436136443
# relative_error_metric = 0.02257367249372611
#
# ------------ 16 - 0.99 CL ------------
# eps = 2.344946027733386e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 69.79410946799908 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_power_abs_down_0.000023.json
# ThresholdS: [[0.95, [9500, 500], 1.5733988600060107], [0.99, [9900, 100], 3.8592579053221865]]
# Null distribution computed in 70.09509648196399 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 83.77820502605755 seconds.
# statistic = 3.8198548003174477 - next threshold = 3.8592579053221865 at 0.99 CL
# relative_error_eps = 0.012908149375093148
# relative_error_metric = 0.010262410910000224
#
# ------------ 17 - 0.99 CL ------------
# eps = 2.360178797971458e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 70.44950096693356 seconds.
# Saving lr to results/20D_mixture/20D_50K/null_hypothesis/LR_power_abs_down_0.000024.json
# ThresholdS: [[0.95, [9500, 500], 1.5536672745155002], [0.99, [9900, 100], 3.856822184946092]]
# Null distribution computed in 70.75565683702007 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 82.83903355698567 seconds.
# statistic = 3.8806343758728206 - next threshold = 3.856822184946092 at 0.99 CL
# relative_error_eps = 0.006474969656427737
# relative_error_metric = 0.0061550435183854195
# =======> statistic within required accuracy at 0.99 CL in 3989.6335224689683 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 7985.901080787997 seconds.
# Saving results in the file results/20D_mixture/20D_50K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-04-29T17:25:11.267659', 'fgd_cov_diag_2024-04-29T18:05:24.362087', 'fgd_cov_off_diag_2024-04-29T18:54:12.507034', 'fgd_power_abs_up_2024-04-29T19:34:40.713058', 'fgd_power_abs_down_2024-04-30T10:53:35.682437', 'fgd_random_normal_2024-04-29T22:49:38.700371', 'fgd_random_uniform_2024-04-29T23:28:06.125597', 'mmd_mean_2024-04-28T16:32:59.112581', 'mmd_cov_diag_2024-04-28T17:19:48.456283', 'mmd_cov_off_diag_2024-04-30T00:02:11.939926', 'mmd_power_abs_up_2024-04-30T00:49:24.489148', 'mmd_power_abs_down_2024-04-30T01:46:27.966063', 'mmd_random_normal_2024-04-30T02:43:38.122374', 'mmd_random_uniform_2024-04-30T03:26:01.159215', 'ks_mean_2024-04-30T04:00:01.678918', 'ks_cov_diag_2024-04-30T04:48:20.498505', 'ks_cov_off_diag_2024-04-30T05:42:58.473489', 'ks_power_abs_up_2024-04-30T06:26:05.850997', 'ks_power_abs_down_2024-04-30T07:25:01.084938', 'ks_random_normal_2024-04-30T08:24:13.904045', 'ks_random_uniform_2024-04-30T09:11:02.321433', 'sks_mean_2024-04-30T09:57:25.071072', 'sks_cov_diag_2024-04-30T11:32:56.187458', 'sks_cov_off_diag_2024-04-30T12:11:50.125511', 'sks_power_abs_up_2024-04-30T12:43:07.403971', 'sks_power_abs_down_2024-04-30T13:24:21.938231', 'sks_random_normal_2024-04-30T14:07:08.437498', 'sks_random_uniform_2024-04-30T14:33:55.384630', 'swd_mean_2024-04-30T14:57:47.363827', 'swd_cov_diag_2024-04-30T15:52:26.410792', 'swd_cov_off_diag_2024-04-30T16:28:37.974318', 'swd_power_abs_up_2024-04-30T16:57:26.911113', 'swd_power_abs_down_2024-04-30T17:36:26.485917', 'swd_random_normal_2024-04-30T18:14:36.618068', 'swd_random_uniform_2024-04-30T18:38:32.731533', 'lr_mean_2024-04-30T21:39:35.251192', 'lr_cov_diag_2024-04-30T23:23:13.378414', 'lr_cov_off_diag_2024-05-01T01:19:14.546951', 'lr_power_abs_up_2024-05-01T03:17:28.509186', 'lr_power_abs_down_2024-05-01T05:30:27.182644'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean   20  10000                50000
# 14        ks        mean   20  10000                50000
# 21       sks        mean   20  10000                50000
# 7        mmd        mean   20  10000                50000
# 28       swd        mean   20  10000                50000
# 0        fgd        mean   20  10000                50000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.00021                             0.00030
# 14                             0.00484                             0.00664
# 21                             0.03510                             0.04813
# 7                              0.04547                             0.06210
# 28                             0.04932                             0.06928
# 0                              0.05890                             0.08031
#
#     $t^{\mu}$ (s)
# 35           6218
# 14           2898
# 21           2516
# 7            2809
# 28           1830
# 0            2413
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.00021
# 14        ks                             0.00484
# 21       sks                             0.03510
# 7        mmd                             0.04547
# 28       swd                             0.04932
# 0        fgd                             0.05890
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.00030           6218
# 14                             0.00664           2898
# 21                             0.04813           2516
# 7                              0.06210           2809
# 28                             0.06928           1830
# 0                              0.08031           2413

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag   20  10000                50000
# 15        ks    cov_diag   20  10000                50000
# 22       sks    cov_diag   20  10000                50000
# 8        mmd    cov_diag   20  10000                50000
# 29       swd    cov_diag   20  10000                50000
# 1        fgd    cov_diag   20  10000                50000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00005
# 15                                     0.00129
# 22                                     0.01056
# 8                                      0.01183
# 29                                     0.01550
# 1                                      0.01656
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00007                   6961
# 15                                     0.00174                   3277
# 22                                     0.01382                   2333
# 8                                      0.01540                   3256
# 29                                     0.02115                   2171
# 1                                      0.02249                   2928
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00005
# 15        ks                                     0.00129
# 22       sks                                     0.01056
# 8        mmd                                     0.01183
# 29       swd                                     0.01550
# 1        fgd                                     0.01656
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00007                   6961
# 15                                     0.00174                   3277
# 22                                     0.01382                   2333
# 8                                      0.01540                   3256
# 29                                     0.02115                   2171
# 1                                      0.02249                   2928

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag   20  10000                50000
# 16        ks  cov_off_diag   20  10000                50000
# 23       sks  cov_off_diag   20  10000                50000
# 9        mmd  cov_off_diag   20  10000                50000
# 2        fgd  cov_off_diag   20  10000                50000
# 30       swd  cov_off_diag   20  10000                50000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00000
# 16                                          0.00002
# 23                                          0.00030
# 9                                           0.00035
# 2                                           0.00043
# 30                                          0.00045
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00000
# 16                                          0.00004
# 23                                          0.00039
# 9                                           0.00047
# 2                                           0.00058
# 30                                          0.00062
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        7093
# 16                        2587
# 23                        1877
# 9                         2832
# 2                         2428
# 30                        1728
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00000
# 16        ks                                          0.00002
# 23       sks                                          0.00030
# 9        mmd                                          0.00035
# 2        fgd                                          0.00043
# 30       swd                                          0.00045
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00000
# 16                                          0.00004
# 23                                          0.00039
# 9                                           0.00047
# 2                                           0.00058
# 30                                          0.00062
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        7093
# 16                        2587
# 23                        1877
# 9                         2832
# 2                         2428
# 30                        1728

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up   20  10000                50000
# 17        ks  power_abs_up   20  10000                50000
# 10       mmd  power_abs_up   20  10000                50000
# 24       sks  power_abs_up   20  10000                50000
# 31       swd  power_abs_up   20  10000                50000
# 3        fgd  power_abs_up   20  10000                50000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00002
# 17                                      0.00043
# 10                                      0.00414
# 24                                      0.00473
# 31                                      0.00653
# 3                                       0.00751
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00002                    7978
# 17                                      0.00061                    3535
# 10                                      0.00540                    3423
# 24                                      0.00613                    2474
# 31                                      0.00902                    2339
# 3                                       0.01018                    2828
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00002
# 17        ks                                      0.00043
# 10       mmd                                      0.00414
# 24       sks                                      0.00473
# 31       swd                                      0.00653
# 3        fgd                                      0.00751
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00002                    7978
# 17                                      0.00061                    3535
# 10                                      0.00540                    3423
# 24                                      0.00613                    2474
# 31                                      0.00902                    2339
# 3                                       0.01018                    2828

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down   20  10000                50000
# 18        ks  power_abs_down   20  10000                50000
# 11       mmd  power_abs_down   20  10000                50000
# 25       sks  power_abs_down   20  10000                50000
# 32       swd  power_abs_down   20  10000                50000
# 4        fgd  power_abs_down   20  10000                50000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00002
# 18                                      0.00044
# 11                                      0.00349
# 25                                      0.00461
# 32                                      0.00641
# 4                                       0.00751
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00002                    7985
# 18                                      0.00062                    3552
# 11                                      0.00482                    3430
# 25                                      0.00604                    2566
# 32                                      0.00890                    2290
# 4                                       0.01023                    2360
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00002
# 18        ks                                      0.00044
# 11       mmd                                      0.00349
# 25       sks                                      0.00461
# 32       swd                                      0.00641
# 4        fgd                                      0.00751
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00002                    7985
# 18                                      0.00062                    3552
# 11                                      0.00482                    3430
# 25                                      0.00604                    2566
# 32                                      0.00890                    2290
# 4                                       0.01023                    2360

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 19        ks  random_normal   20  10000                50000
# 26       sks  random_normal   20  10000                50000
# 5        fgd  random_normal   20  10000                50000
# 33       swd  random_normal   20  10000                50000
# 12       mmd  random_normal   20  10000                50000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 19                                     0.00786
# 26                                     0.16504
# 5                                      0.18494
# 33                                     0.20117
# 12                                     0.46829
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 19                                     0.01022                   2808
# 26                                     0.19276                   1606
# 5                                      0.21697                   2307
# 33                                     0.23706                   1436
# 12                                     0.54131                   2543
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 19        ks                                     0.00786
# 26       sks                                     0.16504
# 5        fgd                                     0.18494
# 33       swd                                     0.20117
# 12       mmd                                     0.46829
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 19                                     0.01022                   2808
# 26                                     0.19276                   1606
# 5                                      0.21697                   2307
# 33                                     0.23706                   1436
# 12                                     0.54131                   2543

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 20        ks  random_uniform   20  10000                50000
# 27       sks  random_uniform   20  10000                50000
# 6        fgd  random_uniform   20  10000                50000
# 34       swd  random_uniform   20  10000                50000
# 13       mmd  random_uniform   20  10000                50000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 20                                     0.01259
# 27                                     0.28320
# 6                                      0.32104
# 34                                     0.34570
# 13                                     0.81299
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 20                                     0.01639                   2782
# 27                                     0.33080                   1431
# 6                                      0.37702                   2045
# 34                                     0.40960                   1341
# 13                                     0.93974                   2040
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 20        ks                                     0.01259
# 27       sks                                     0.28320
# 6        fgd                                     0.32104
# 34       swd                                     0.34570
# 13       mmd                                     0.81299
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 20                                     0.01639                   2782
# 27                                     0.33080                   1431
# 6                                      0.37702                   2045
# 34                                     0.40960                   1341
# 13                                     0.93974                   2040

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.059 & 0.08 & 2413 & cov_diag & 20 & 10000 & 50000 & 0.017 & 0.022 & 2928 & cov_off_diag & 20 & 10000 & 50000 & 0.00043 & 0.00058 & 2428 & 0.0075 & 0.01 & 2828 \\
# $\overline{D}$ & 0.0048 & 0.0066 & 2898 & cov_diag & 20 & 10000 & 50000 & 0.0013 & 0.0017 & 3277 & cov_off_diag & 20 & 10000 & 50000 & 2e-05 & 4e-05 & 2587 & 0.00043 & 0.00061 & 3535 \\
# $t_{\mathrm{LLR}}$ & 0.00021 & 0.0003 & 6218 & cov_diag & 20 & 10000 & 50000 & 5e-05 & 7e-05 & 6961 & cov_off_diag & 20 & 10000 & 50000 & 0 & 0 & 7093 & 2e-05 & 2e-05 & 7978 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.045 & 0.062 & 2809 & cov_diag & 20 & 10000 & 50000 & 0.012 & 0.015 & 3256 & cov_off_diag & 20 & 10000 & 50000 & 0.00035 & 0.00047 & 2832 & 0.0041 & 0.0054 & 3423 \\
# $\widetilde{D}$ & 0.035 & 0.048 & 2516 & cov_diag & 20 & 10000 & 50000 & 0.011 & 0.014 & 2333 & cov_off_diag & 20 & 10000 & 50000 & 0.0003 & 0.00039 & 1877 & 0.0047 & 0.0061 & 2474 \\
# $\widetilde{W}$ & 0.049 & 0.069 & 1830 & cov_diag & 20 & 10000 & 50000 & 0.015 & 0.021 & 2171 & cov_off_diag & 20 & 10000 & 50000 & 0.00045 & 0.00062 & 1728 & 0.0065 & 0.009 & 2339 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.0075 & 0.01 & 2360 & 0.18 & 0.22 & 2.3e+03 & 0.32 & 0.38 & 2e+03 & 3246 \\
# $\overline{D}$ & 0.00044 & 0.00062 & 3552 & 0.0079 & 0.01 & 2.8e+03 & 0.013 & 0.016 & 2.8e+03 & 182 \\
# $t_{\mathrm{LLR}}$ & 2e-05 & 2e-05 & 7985 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.0035 & 0.0048 & 3430 & 0.47 & 0.54 & 2.5e+03 & 0.81 & 0.94 & 2e+03 & 13873 \\
# $\widetilde{D}$ & 0.0046 & 0.006 & 2566 & 0.17 & 0.19 & 1.6e+03 & 0.28 & 0.33 & 1.4e+03 & 536 \\
# $\widetilde{W}$ & 0.0064 & 0.0089 & 2290 & 0.2 & 0.24 & 1.4e+03 & 0.35 & 0.41 & 1.3e+03 & 356 \\
# \bottomrule
# \end{tabular}
