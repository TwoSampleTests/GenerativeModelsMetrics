# %% [markdown]
# # Initialize

# %%
visible_devices = [0]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

sys.path.insert(0,'../utils_func/')
import MixtureDistributions # type: ignore

sys.path.insert(0,'../')
import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std, compute_exclusion_bisection, compute_exclusion_LR_bisection, save_update_metrics_config # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "../results_leonardo/"
if not os.path.exists(results_dir):
    print("WARNING: Results directory does not exist")
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-11 17:01:23.166573: Importing os...
# 2024-04-11 17:01:23.166876: Importing sys...
# Visible devices: [0]
# 2024-04-11 17:01:23.167115: Importing timer from timeit...
# 2024-04-11 17:01:23.167183: Setting env variables for tf import (only device(s) [0] will be available)...
# 2024-04-11 17:01:23.167308: Importing numpy...
# 2024-04-11 17:01:23.266603: Importing matplotlib...
# 2024-04-11 17:01:23.610197: Importing h5py...
# 2024-04-11 17:01:23.633105: Importing importlib.util...
# 2024-04-11 17:01:23.633203: Importing json...
# 2024-04-11 17:01:23.633265: Importing pandas...
# 2024-04-11 17:01:24.058344: Importing random...
# 2024-04-11 17:01:24.058477: Importing scipy utils...
# 2024-04-11 17:01:24.422925: Importing subprocess...
# 2024-04-11 17:01:24.423057: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-11 17:01:27.776640: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-11 17:01:28.920309: Importing timeit...
# 2024-04-11 17:01:28.920404: Importing tqdm...
# 2024-04-11 17:01:28.928277: Importing typing...
# 2024-04-11 17:01:28.928389: Setting tf configs...
# 2024-04-11 17:01:29.033020: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-11 17:01:33.634733: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #0, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-04-11 17:01:33.667503: All done.

# %% [markdown]
# # Fixed $n=100000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
batch_size_test = 100_000
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MixtureGaussian(ncomp, ndims, 0., 0., seed)
dist_2 = MixtureDistributions.MixtureGaussian(ncomp, ndims, eps_loc, eps_scale, seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture.Mixture'> <class 'tensorflow_probability.python.distributions.mixture.Mixture'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 1000000000
# batch_size 100000
# niter 10000
# niter * batch_size 1000000000
# small_sample False

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               #min_samples_input = 20_000,
                               #max_samples_input = 50_000,
                               num_batches = 20)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4,
                               block_size = 5_000,
                               num_batches = 1,
                               batch_size = 100_000)
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000           100000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims    nsamples  small_sample  \
# 0       True        5           0  float64     5  1000000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fn": {"name": "fn", # type: ignore
                                      "object_name": "FNMetric",
                                      "class_name": "GMetrics.FNMetric",
                                      "kwargs": {},
                                      "result_key": "metric_list", 
                                      "scale_func": lambda ns, ndims: np.sqrt(ns)/ndims,
                                      "scale_func_string": "lambda ns, ndims: np.sqrt(ns)/ndims",
                                      "test_config": test_config_null,
                                      "max_vectorize": 500, # optimized for 5D
                                      "latex": "$\overline{\|\cdot\|}_{F}$",
                                      "null_file": null_hypotheses_dir+"FN.json"},
                               "fpd": {"name": "fpd",
                                       "object_name": "FPDMetric",
                                       "class_name": "GMetrics.FPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100, # optimized for 5D
                                       "latex": "$d_{\mathrm{FPD}}$",
                                       "null_file": null_hypotheses_dir+"FPD.json"},
                               "kpd": {"name": "kpd",
                                       "object_name": "KPDMetric" ,
                                       "class_name": "GMetrics.KPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1, # optimized for 5D
                                       "latex": "$d_{\mathrm{KPD}}$",
                                       "null_file": null_hypotheses_dir+"KPD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fn': {'name': 'fn',
#   'object_name': 'FNMetric',
#   'class_name': 'GMetrics.FNMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)/ndims',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\overline{\\|\\cdot\\|}_{F}$',
#   'null_file': '../results_leonardo/5D_100K/null_hypothesis/FN.json'},
#  'fpd': {'name': 'fpd',
#   'object_name': 'FPDMetric',
#   'class_name': 'GMetrics.FPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 100,
#   'latex': '$d_{\\mathrm{FPD}}$',
#   'null_file': '../results_leonardo/5D_100K/null_hypothesis/FPD.json'},
#  'kpd': {'name': 'kpd',
#   'object_name': 'KPDMetric',
#   'class_name': 'GMetrics.KPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{KPD}}$',
#   'null_file': '../results_leonardo/5D_100K/null_hypothesis/KPD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$\\overline{D}$',
#   'null_file': '../results_leonardo/5D_100K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 50,
#   'latex': '$\\widetilde{D}$',
#   'null_file': '../results_leonardo/5D_100K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 50,
#   'latex': '$\\widetilde{W}$',
#   'null_file': '../results_leonardo/5D_100K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 200,
#   'latex': '$t_{\\mu}$',
#   'null_file': '../results_leonardo/5D_100K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fn from ../results_leonardo/5D_100K/null_hypothesis/FN.json
# Loading fpd from ../results_leonardo/5D_100K/null_hypothesis/FPD.json
# Computing and savng kpd with max_vectorize = 1
#
# ------------------------------------------
# Starting KPD metric calculation...
# Running TF KPD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10000
# Iterating from 0 to 1 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712847697.641243  370086 service.cc:145] XLA service 0xb8de6970 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1712847697.641286  370086 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1712847697.701114  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1712847697.704893  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1712847697.705807  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1712847697.706116  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1712847697.707024  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1712847697.707095  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1712847697.707163  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1712847697.707227  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1712847697.707293  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1712847697.707356  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1712847697.707422  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1712847697.707491  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1712847700.882614  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1712847700.883044  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1712847700.883140  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1712847700.883179  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1712847700.883272  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1712847700.883282  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1712847700.883289  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1712847700.883296  370086 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# I0000 00:00:1712847707.942005  370086 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# Iterating from 1 to 2 out of 10000 .
# Iterating from 2 to 3 out of 10000 .
# Iterating from 3 to 4 out of 10000 .
# Iterating from 4 to 5 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f8760236d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 5 to 6 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f87b40d25c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 6 to 7 out of 10000 .
# Iterating from 7 to 8 out of 10000 .
# Iterating from 8 to 9 out of 10000 .
# Iterating from 9 to 10 out of 10000 .
# Iterating from 10 to 11 out of 10000 .
# Iterating from 11 to 12 out of 10000 .
# Iterating from 12 to 13 out of 10000 .
# Iterating from 13 to 14 out of 10000 .
# Iterating from 14 to 15 out of 10000 .
# Iterating from 15 to 16 out of 10000 .
# Iterating from 16 to 17 out of 10000 .
# Iterating from 17 to 18 out of 10000 .
# Iterating from 18 to 19 out of 10000 .
# Iterating from 19 to 20 out of 10000 .
# Iterating from 20 to 21 out of 10000 .
# Iterating from 21 to 22 out of 10000 .
# Iterating from 22 to 23 out of 10000 .
# Iterating from 23 to 24 out of 10000 .
# Iterating from 24 to 25 out of 10000 .
# Iterating from 25 to 26 out of 10000 .
# Iterating from 26 to 27 out of 10000 .
# Iterating from 27 to 28 out of 10000 .
# Iterating from 28 to 29 out of 10000 .
# Iterating from 29 to 30 out of 10000 .
# Iterating from 30 to 31 out of 10000 .
# Iterating from 31 to 32 out of 10000 .
# Iterating from 32 to 33 out of 10000 .
# Iterating from 33 to 34 out of 10000 .
# Iterating from 34 to 35 out of 10000 .
# Iterating from 35 to 36 out of 10000 .
# Iterating from 36 to 37 out of 10000 .
# Iterating from 37 to 38 out of 10000 .
# Iterating from 38 to 39 out of 10000 .
# Iterating from 39 to 40 out of 10000 .
# Iterating from 40 to 41 out of 10000 .
# Iterating from 41 to 42 out of 10000 .
# Iterating from 42 to 43 out of 10000 .
# Iterating from 43 to 44 out of 10000 .
# Iterating from 44 to 45 out of 10000 .
# Iterating from 45 to 46 out of 10000 .
# Iterating from 46 to 47 out of 10000 .
# Iterating from 47 to 48 out of 10000 .
# Iterating from 48 to 49 out of 10000 .
# Iterating from 49 to 50 out of 10000 .
# Iterating from 50 to 51 out of 10000 .
# Iterating from 51 to 52 out of 10000 .
# Iterating from 52 to 53 out of 10000 .
# Iterating from 53 to 54 out of 10000 .
# Iterating from 54 to 55 out of 10000 .
# Iterating from 55 to 56 out of 10000 .
# Iterating from 56 to 57 out of 10000 .
# Iterating from 57 to 58 out of 10000 .
# Iterating from 58 to 59 out of 10000 .
# Iterating from 59 to 60 out of 10000 .
# Iterating from 60 to 61 out of 10000 .
# Iterating from 61 to 62 out of 10000 .
# Iterating from 62 to 63 out of 10000 .
# Iterating from 63 to 64 out of 10000 .
# Iterating from 64 to 65 out of 10000 .
# Iterating from 65 to 66 out of 10000 .
# Iterating from 66 to 67 out of 10000 .
# Iterating from 67 to 68 out of 10000 .
# Iterating from 68 to 69 out of 10000 .
# Iterating from 69 to 70 out of 10000 .
# Iterating from 70 to 71 out of 10000 .
# Iterating from 71 to 72 out of 10000 .
# Iterating from 72 to 73 out of 10000 .
# Iterating from 73 to 74 out of 10000 .
# Iterating from 74 to 75 out of 10000 .
# Iterating from 75 to 76 out of 10000 .
# Iterating from 76 to 77 out of 10000 .
# Iterating from 77 to 78 out of 10000 .
# Iterating from 78 to 79 out of 10000 .
# Iterating from 79 to 80 out of 10000 .
# Iterating from 80 to 81 out of 10000 .
# Iterating from 81 to 82 out of 10000 .
# Iterating from 82 to 83 out of 10000 .
# Iterating from 83 to 84 out of 10000 .
# Iterating from 84 to 85 out of 10000 .
# Iterating from 85 to 86 out of 10000 .
# Iterating from 86 to 87 out of 10000 .
# Iterating from 87 to 88 out of 10000 .
# Iterating from 88 to 89 out of 10000 .
# Iterating from 89 to 90 out of 10000 .
# Iterating from 90 to 91 out of 10000 .
# Iterating from 91 to 92 out of 10000 .
# Iterating from 92 to 93 out of 10000 .
# Iterating from 93 to 94 out of 10000 .
# Iterating from 94 to 95 out of 10000 .
# Iterating from 95 to 96 out of 10000 .
# Iterating from 96 to 97 out of 10000 .
# Iterating from 97 to 98 out of 10000 .
# Iterating from 98 to 99 out of 10000 .
# Iterating from 99 to 100 out of 10000 .
# Iterating from 100 to 101 out of 10000 .
# Iterating from 101 to 102 out of 10000 .
# Iterating from 102 to 103 out of 10000 .
# Iterating from 103 to 104 out of 10000 .
# Iterating from 104 to 105 out of 10000 .
# Iterating from 105 to 106 out of 10000 .
# Iterating from 106 to 107 out of 10000 .
# Iterating from 107 to 108 out of 10000 .
# Iterating from 108 to 109 out of 10000 .
# Iterating from 109 to 110 out of 10000 .
# Iterating from 110 to 111 out of 10000 .
# Iterating from 111 to 112 out of 10000 .
# Iterating from 112 to 113 out of 10000 .
# Iterating from 113 to 114 out of 10000 .
# Iterating from 114 to 115 out of 10000 .
# Iterating from 115 to 116 out of 10000 .
# Iterating from 116 to 117 out of 10000 .
# Iterating from 117 to 118 out of 10000 .
# Iterating from 118 to 119 out of 10000 .
# Iterating from 119 to 120 out of 10000 .
# Iterating from 120 to 121 out of 10000 .
# Iterating from 121 to 122 out of 10000 .
# Iterating from 122 to 123 out of 10000 .
# Iterating from 123 to 124 out of 10000 .
# Iterating from 124 to 125 out of 10000 .
# Iterating from 125 to 126 out of 10000 .
# Iterating from 126 to 127 out of 10000 .
# Iterating from 127 to 128 out of 10000 .
# Iterating from 128 to 129 out of 10000 .
# Iterating from 129 to 130 out of 10000 .
# Iterating from 130 to 131 out of 10000 .
# Iterating from 131 to 132 out of 10000 .
# Iterating from 132 to 133 out of 10000 .
# Iterating from 133 to 134 out of 10000 .
# Iterating from 134 to 135 out of 10000 .
# Iterating from 135 to 136 out of 10000 .
# Iterating from 136 to 137 out of 10000 .
# Iterating from 137 to 138 out of 10000 .
# Iterating from 138 to 139 out of 10000 .
# Iterating from 139 to 140 out of 10000 .
# Iterating from 140 to 141 out of 10000 .
# Iterating from 141 to 142 out of 10000 .
# Iterating from 142 to 143 out of 10000 .
# Iterating from 143 to 144 out of 10000 .
# Iterating from 144 to 145 out of 10000 .
# Iterating from 145 to 146 out of 10000 .
# Iterating from 146 to 147 out of 10000 .
# Iterating from 147 to 148 out of 10000 .
# Iterating from 148 to 149 out of 10000 .
# Iterating from 149 to 150 out of 10000 .
# Iterating from 150 to 151 out of 10000 .
# Iterating from 151 to 152 out of 10000 .
# Iterating from 152 to 153 out of 10000 .
# Iterating from 153 to 154 out of 10000 .
# Iterating from 154 to 155 out of 10000 .
# Iterating from 155 to 156 out of 10000 .
# Iterating from 156 to 157 out of 10000 .
# Iterating from 157 to 158 out of 10000 .
# Iterating from 158 to 159 out of 10000 .
# Iterating from 159 to 160 out of 10000 .
# Iterating from 160 to 161 out of 10000 .
# Iterating from 161 to 162 out of 10000 .
# Iterating from 162 to 163 out of 10000 .
# Iterating from 163 to 164 out of 10000 .
# Iterating from 164 to 165 out of 10000 .
# Iterating from 165 to 166 out of 10000 .
# Iterating from 166 to 167 out of 10000 .
# Iterating from 167 to 168 out of 10000 .
# Iterating from 168 to 169 out of 10000 .
# Iterating from 169 to 170 out of 10000 .
# Iterating from 170 to 171 out of 10000 .
# Iterating from 171 to 172 out of 10000 .
# Iterating from 172 to 173 out of 10000 .
# Iterating from 173 to 174 out of 10000 .
# Iterating from 174 to 175 out of 10000 .
# Iterating from 175 to 176 out of 10000 .
# Iterating from 176 to 177 out of 10000 .
# Iterating from 177 to 178 out of 10000 .
# Iterating from 178 to 179 out of 10000 .
# Iterating from 179 to 180 out of 10000 .
# Iterating from 180 to 181 out of 10000 .
# Iterating from 181 to 182 out of 10000 .
# Iterating from 182 to 183 out of 10000 .
# Iterating from 183 to 184 out of 10000 .
# Iterating from 184 to 185 out of 10000 .
# Iterating from 185 to 186 out of 10000 .
# Iterating from 186 to 187 out of 10000 .
# Iterating from 187 to 188 out of 10000 .
# Iterating from 188 to 189 out of 10000 .
# Iterating from 189 to 190 out of 10000 .
# Iterating from 190 to 191 out of 10000 .
# Iterating from 191 to 192 out of 10000 .
# Iterating from 192 to 193 out of 10000 .
# Iterating from 193 to 194 out of 10000 .
# Iterating from 194 to 195 out of 10000 .
# Iterating from 195 to 196 out of 10000 .
# Iterating from 196 to 197 out of 10000 .
# Iterating from 197 to 198 out of 10000 .
# Iterating from 198 to 199 out of 10000 .
# Iterating from 199 to 200 out of 10000 .
# Iterating from 200 to 201 out of 10000 .
# Iterating from 201 to 202 out of 10000 .
# Iterating from 202 to 203 out of 10000 .
# Iterating from 203 to 204 out of 10000 .
# Iterating from 204 to 205 out of 10000 .
# Iterating from 205 to 206 out of 10000 .
# Iterating from 206 to 207 out of 10000 .
# Iterating from 207 to 208 out of 10000 .
# Iterating from 208 to 209 out of 10000 .
# Iterating from 209 to 210 out of 10000 .
# Iterating from 210 to 211 out of 10000 .
# Iterating from 211 to 212 out of 10000 .
# Iterating from 212 to 213 out of 10000 .
# Iterating from 213 to 214 out of 10000 .
# Iterating from 214 to 215 out of 10000 .
# Iterating from 215 to 216 out of 10000 .
# Iterating from 216 to 217 out of 10000 .
# Iterating from 217 to 218 out of 10000 .
# Iterating from 218 to 219 out of 10000 .
# Iterating from 219 to 220 out of 10000 .
# Iterating from 220 to 221 out of 10000 .
# Iterating from 221 to 222 out of 10000 .
# Iterating from 222 to 223 out of 10000 .
# Iterating from 223 to 224 out of 10000 .
# Iterating from 224 to 225 out of 10000 .
# Iterating from 225 to 226 out of 10000 .
# Iterating from 226 to 227 out of 10000 .
# Iterating from 227 to 228 out of 10000 .
# Iterating from 228 to 229 out of 10000 .
# Iterating from 229 to 230 out of 10000 .
# Iterating from 230 to 231 out of 10000 .
# Iterating from 231 to 232 out of 10000 .
# Iterating from 232 to 233 out of 10000 .
# Iterating from 233 to 234 out of 10000 .
# Iterating from 234 to 235 out of 10000 .
# Iterating from 235 to 236 out of 10000 .
# Iterating from 236 to 237 out of 10000 .
# Iterating from 237 to 238 out of 10000 .
# Iterating from 238 to 239 out of 10000 .
# Iterating from 239 to 240 out of 10000 .
# Iterating from 240 to 241 out of 10000 .
# Iterating from 241 to 242 out of 10000 .
# Iterating from 242 to 243 out of 10000 .
# Iterating from 243 to 244 out of 10000 .
# Iterating from 244 to 245 out of 10000 .
# Iterating from 245 to 246 out of 10000 .
# Iterating from 246 to 247 out of 10000 .
# Iterating from 247 to 248 out of 10000 .
# Iterating from 248 to 249 out of 10000 .
# Iterating from 249 to 250 out of 10000 .
# Iterating from 250 to 251 out of 10000 .
# Iterating from 251 to 252 out of 10000 .
# Iterating from 252 to 253 out of 10000 .
# Iterating from 253 to 254 out of 10000 .
# Iterating from 254 to 255 out of 10000 .
# Iterating from 255 to 256 out of 10000 .
# Iterating from 256 to 257 out of 10000 .
# Iterating from 257 to 258 out of 10000 .
# Iterating from 258 to 259 out of 10000 .
# Iterating from 259 to 260 out of 10000 .
# Iterating from 260 to 261 out of 10000 .
# Iterating from 261 to 262 out of 10000 .
# Iterating from 262 to 263 out of 10000 .
# Iterating from 263 to 264 out of 10000 .
# Iterating from 264 to 265 out of 10000 .
# Iterating from 265 to 266 out of 10000 .
# Iterating from 266 to 267 out of 10000 .
# Iterating from 267 to 268 out of 10000 .
# Iterating from 268 to 269 out of 10000 .
# Iterating from 269 to 270 out of 10000 .
# Iterating from 270 to 271 out of 10000 .
# Iterating from 271 to 272 out of 10000 .
# Iterating from 272 to 273 out of 10000 .
# Iterating from 273 to 274 out of 10000 .
# Iterating from 274 to 275 out of 10000 .
# Iterating from 275 to 276 out of 10000 .
# Iterating from 276 to 277 out of 10000 .
# Iterating from 277 to 278 out of 10000 .
# Iterating from 278 to 279 out of 10000 .
# Iterating from 279 to 280 out of 10000 .
# Iterating from 280 to 281 out of 10000 .
# Iterating from 281 to 282 out of 10000 .
# Iterating from 282 to 283 out of 10000 .
# Iterating from 283 to 284 out of 10000 .
# Iterating from 284 to 285 out of 10000 .
# Iterating from 285 to 286 out of 10000 .
# Iterating from 286 to 287 out of 10000 .
# Iterating from 287 to 288 out of 10000 .
# Iterating from 288 to 289 out of 10000 .
# Iterating from 289 to 290 out of 10000 .
# Iterating from 290 to 291 out of 10000 .
# Iterating from 291 to 292 out of 10000 .
# Iterating from 292 to 293 out of 10000 .
# Iterating from 293 to 294 out of 10000 .
# Iterating from 294 to 295 out of 10000 .
# Iterating from 295 to 296 out of 10000 .
# Iterating from 296 to 297 out of 10000 .
# Iterating from 297 to 298 out of 10000 .
# Iterating from 298 to 299 out of 10000 .
# Iterating from 299 to 300 out of 10000 .
# Iterating from 300 to 301 out of 10000 .
# Iterating from 301 to 302 out of 10000 .
# Iterating from 302 to 303 out of 10000 .
# Iterating from 303 to 304 out of 10000 .
# Iterating from 304 to 305 out of 10000 .
# Iterating from 305 to 306 out of 10000 .
# Iterating from 306 to 307 out of 10000 .
# Iterating from 307 to 308 out of 10000 .
# Iterating from 308 to 309 out of 10000 .
# Iterating from 309 to 310 out of 10000 .
# Iterating from 310 to 311 out of 10000 .
# Iterating from 311 to 312 out of 10000 .
# Iterating from 312 to 313 out of 10000 .
# Iterating from 313 to 314 out of 10000 .
# Iterating from 314 to 315 out of 10000 .
# Iterating from 315 to 316 out of 10000 .
# Iterating from 316 to 317 out of 10000 .
# Iterating from 317 to 318 out of 10000 .
# Iterating from 318 to 319 out of 10000 .
# Iterating from 319 to 320 out of 10000 .
# Iterating from 320 to 321 out of 10000 .
# Iterating from 321 to 322 out of 10000 .
# Iterating from 322 to 323 out of 10000 .
# Iterating from 323 to 324 out of 10000 .
# Iterating from 324 to 325 out of 10000 .
# Iterating from 325 to 326 out of 10000 .
# Iterating from 326 to 327 out of 10000 .
# Iterating from 327 to 328 out of 10000 .
# Iterating from 328 to 329 out of 10000 .
# Iterating from 329 to 330 out of 10000 .
# Iterating from 330 to 331 out of 10000 .
# Iterating from 331 to 332 out of 10000 .
# Iterating from 332 to 333 out of 10000 .
# Iterating from 333 to 334 out of 10000 .
# Iterating from 334 to 335 out of 10000 .
# Iterating from 335 to 336 out of 10000 .
# Iterating from 336 to 337 out of 10000 .
# Iterating from 337 to 338 out of 10000 .
# Iterating from 338 to 339 out of 10000 .
# Iterating from 339 to 340 out of 10000 .
# Iterating from 340 to 341 out of 10000 .
# Iterating from 341 to 342 out of 10000 .
# Iterating from 342 to 343 out of 10000 .
# Iterating from 343 to 344 out of 10000 .
# Iterating from 344 to 345 out of 10000 .
# Iterating from 345 to 346 out of 10000 .
# Iterating from 346 to 347 out of 10000 .
# Iterating from 347 to 348 out of 10000 .
# Iterating from 348 to 349 out of 10000 .
# Iterating from 349 to 350 out of 10000 .
# Iterating from 350 to 351 out of 10000 .
# Iterating from 351 to 352 out of 10000 .
# Iterating from 352 to 353 out of 10000 .
# Iterating from 353 to 354 out of 10000 .
# Iterating from 354 to 355 out of 10000 .
# Iterating from 355 to 356 out of 10000 .
# Iterating from 356 to 357 out of 10000 .
# Iterating from 357 to 358 out of 10000 .
# Iterating from 358 to 359 out of 10000 .
# Iterating from 359 to 360 out of 10000 .
# Iterating from 360 to 361 out of 10000 .
# Iterating from 361 to 362 out of 10000 .
# Iterating from 362 to 363 out of 10000 .
# Iterating from 363 to 364 out of 10000 .
# Iterating from 364 to 365 out of 10000 .
# Iterating from 365 to 366 out of 10000 .
# Iterating from 366 to 367 out of 10000 .
# Iterating from 367 to 368 out of 10000 .
# Iterating from 368 to 369 out of 10000 .
# Iterating from 369 to 370 out of 10000 .
# Iterating from 370 to 371 out of 10000 .
# Iterating from 371 to 372 out of 10000 .
# Iterating from 372 to 373 out of 10000 .
# Iterating from 373 to 374 out of 10000 .
# Iterating from 374 to 375 out of 10000 .
# Iterating from 375 to 376 out of 10000 .
# Iterating from 376 to 377 out of 10000 .
# Iterating from 377 to 378 out of 10000 .
# Iterating from 378 to 379 out of 10000 .
# Iterating from 379 to 380 out of 10000 .
# Iterating from 380 to 381 out of 10000 .
# Iterating from 381 to 382 out of 10000 .
# Iterating from 382 to 383 out of 10000 .
# Iterating from 383 to 384 out of 10000 .
# Iterating from 384 to 385 out of 10000 .
# Iterating from 385 to 386 out of 10000 .
# Iterating from 386 to 387 out of 10000 .
# Iterating from 387 to 388 out of 10000 .
# Iterating from 388 to 389 out of 10000 .
# Iterating from 389 to 390 out of 10000 .
# Iterating from 390 to 391 out of 10000 .
# Iterating from 391 to 392 out of 10000 .
# Iterating from 392 to 393 out of 10000 .
# Iterating from 393 to 394 out of 10000 .
# Iterating from 394 to 395 out of 10000 .
# Iterating from 395 to 396 out of 10000 .
# Iterating from 396 to 397 out of 10000 .
# Iterating from 397 to 398 out of 10000 .
# Iterating from 398 to 399 out of 10000 .
# Iterating from 399 to 400 out of 10000 .
# Iterating from 400 to 401 out of 10000 .
# Iterating from 401 to 402 out of 10000 .
# Iterating from 402 to 403 out of 10000 .
# Iterating from 403 to 404 out of 10000 .
# Iterating from 404 to 405 out of 10000 .
# Iterating from 405 to 406 out of 10000 .
# Iterating from 406 to 407 out of 10000 .
# Iterating from 407 to 408 out of 10000 .
# Iterating from 408 to 409 out of 10000 .
# Iterating from 409 to 410 out of 10000 .
# Iterating from 410 to 411 out of 10000 .
# Iterating from 411 to 412 out of 10000 .
# Iterating from 412 to 413 out of 10000 .
# Iterating from 413 to 414 out of 10000 .
# Iterating from 414 to 415 out of 10000 .
# Iterating from 415 to 416 out of 10000 .
# Iterating from 416 to 417 out of 10000 .
# Iterating from 417 to 418 out of 10000 .
# Iterating from 418 to 419 out of 10000 .
# Iterating from 419 to 420 out of 10000 .
# Iterating from 420 to 421 out of 10000 .
# Iterating from 421 to 422 out of 10000 .
# Iterating from 422 to 423 out of 10000 .
# Iterating from 423 to 424 out of 10000 .
# Iterating from 424 to 425 out of 10000 .
# Iterating from 425 to 426 out of 10000 .
# Iterating from 426 to 427 out of 10000 .
# Iterating from 427 to 428 out of 10000 .
# Iterating from 428 to 429 out of 10000 .
# Iterating from 429 to 430 out of 10000 .
# Iterating from 430 to 431 out of 10000 .
# Iterating from 431 to 432 out of 10000 .
# Iterating from 432 to 433 out of 10000 .
# Iterating from 433 to 434 out of 10000 .
# Iterating from 434 to 435 out of 10000 .
# Iterating from 435 to 436 out of 10000 .
# Iterating from 436 to 437 out of 10000 .
# Iterating from 437 to 438 out of 10000 .
# Iterating from 438 to 439 out of 10000 .
# Iterating from 439 to 440 out of 10000 .
# Iterating from 440 to 441 out of 10000 .
# Iterating from 441 to 442 out of 10000 .
# Iterating from 442 to 443 out of 10000 .
# Iterating from 443 to 444 out of 10000 .
# Iterating from 444 to 445 out of 10000 .
# Iterating from 445 to 446 out of 10000 .
# Iterating from 446 to 447 out of 10000 .
# Iterating from 447 to 448 out of 10000 .
# Iterating from 448 to 449 out of 10000 .
# Iterating from 449 to 450 out of 10000 .
# Iterating from 450 to 451 out of 10000 .
# Iterating from 451 to 452 out of 10000 .
# Iterating from 452 to 453 out of 10000 .
# Iterating from 453 to 454 out of 10000 .
# Iterating from 454 to 455 out of 10000 .
# Iterating from 455 to 456 out of 10000 .
# Iterating from 456 to 457 out of 10000 .
# Iterating from 457 to 458 out of 10000 .
# Iterating from 458 to 459 out of 10000 .
# Iterating from 459 to 460 out of 10000 .
# Iterating from 460 to 461 out of 10000 .
# Iterating from 461 to 462 out of 10000 .
# Iterating from 462 to 463 out of 10000 .
# Iterating from 463 to 464 out of 10000 .
# Iterating from 464 to 465 out of 10000 .
# Iterating from 465 to 466 out of 10000 .
# Iterating from 466 to 467 out of 10000 .
# Iterating from 467 to 468 out of 10000 .
# Iterating from 468 to 469 out of 10000 .
# Iterating from 469 to 470 out of 10000 .
# Iterating from 470 to 471 out of 10000 .
# Iterating from 471 to 472 out of 10000 .
# Iterating from 472 to 473 out of 10000 .
# Iterating from 473 to 474 out of 10000 .
# Iterating from 474 to 475 out of 10000 .
# Iterating from 475 to 476 out of 10000 .
# Iterating from 476 to 477 out of 10000 .
# Iterating from 477 to 478 out of 10000 .
# Iterating from 478 to 479 out of 10000 .
# Iterating from 479 to 480 out of 10000 .
# Iterating from 480 to 481 out of 10000 .
# Iterating from 481 to 482 out of 10000 .
# Iterating from 482 to 483 out of 10000 .
# Iterating from 483 to 484 out of 10000 .
# Iterating from 484 to 485 out of 10000 .
# Iterating from 485 to 486 out of 10000 .
# Iterating from 486 to 487 out of 10000 .
# Iterating from 487 to 488 out of 10000 .
# Iterating from 488 to 489 out of 10000 .
# Iterating from 489 to 490 out of 10000 .
# Iterating from 490 to 491 out of 10000 .
# Iterating from 491 to 492 out of 10000 .
# Iterating from 492 to 493 out of 10000 .
# Iterating from 493 to 494 out of 10000 .
# Iterating from 494 to 495 out of 10000 .
# Iterating from 495 to 496 out of 10000 .
# Iterating from 496 to 497 out of 10000 .
# Iterating from 497 to 498 out of 10000 .
# Iterating from 498 to 499 out of 10000 .
# Iterating from 499 to 500 out of 10000 .
# Iterating from 500 to 501 out of 10000 .
# Iterating from 501 to 502 out of 10000 .
# Iterating from 502 to 503 out of 10000 .
# Iterating from 503 to 504 out of 10000 .
# Iterating from 504 to 505 out of 10000 .
# Iterating from 505 to 506 out of 10000 .
# Iterating from 506 to 507 out of 10000 .
# Iterating from 507 to 508 out of 10000 .
# Iterating from 508 to 509 out of 10000 .
# Iterating from 509 to 510 out of 10000 .
# Iterating from 510 to 511 out of 10000 .
# Iterating from 511 to 512 out of 10000 .
# Iterating from 512 to 513 out of 10000 .
# Iterating from 513 to 514 out of 10000 .
# Iterating from 514 to 515 out of 10000 .
# Iterating from 515 to 516 out of 10000 .
# Iterating from 516 to 517 out of 10000 .
# Iterating from 517 to 518 out of 10000 .
# Iterating from 518 to 519 out of 10000 .
# Iterating from 519 to 520 out of 10000 .
# Iterating from 520 to 521 out of 10000 .
# Iterating from 521 to 522 out of 10000 .
# Iterating from 522 to 523 out of 10000 .
# Iterating from 523 to 524 out of 10000 .
# Iterating from 524 to 525 out of 10000 .
# Iterating from 525 to 526 out of 10000 .
# Iterating from 526 to 527 out of 10000 .
# Iterating from 527 to 528 out of 10000 .
# Iterating from 528 to 529 out of 10000 .
# Iterating from 529 to 530 out of 10000 .
# Iterating from 530 to 531 out of 10000 .
# Iterating from 531 to 532 out of 10000 .
# Iterating from 532 to 533 out of 10000 .
# Iterating from 533 to 534 out of 10000 .
# Iterating from 534 to 535 out of 10000 .
# Iterating from 535 to 536 out of 10000 .
# Iterating from 536 to 537 out of 10000 .
# Iterating from 537 to 538 out of 10000 .
# Iterating from 538 to 539 out of 10000 .
# Iterating from 539 to 540 out of 10000 .
# Iterating from 540 to 541 out of 10000 .
# Iterating from 541 to 542 out of 10000 .
# Iterating from 542 to 543 out of 10000 .
# Iterating from 543 to 544 out of 10000 .
# Iterating from 544 to 545 out of 10000 .
# Iterating from 545 to 546 out of 10000 .
# Iterating from 546 to 547 out of 10000 .
# Iterating from 547 to 548 out of 10000 .
# Iterating from 548 to 549 out of 10000 .
# Iterating from 549 to 550 out of 10000 .
# Iterating from 550 to 551 out of 10000 .
# Iterating from 551 to 552 out of 10000 .
# Iterating from 552 to 553 out of 10000 .
# Iterating from 553 to 554 out of 10000 .
# Iterating from 554 to 555 out of 10000 .
# Iterating from 555 to 556 out of 10000 .
# Iterating from 556 to 557 out of 10000 .
# Iterating from 557 to 558 out of 10000 .
# Iterating from 558 to 559 out of 10000 .
# Iterating from 559 to 560 out of 10000 .
# Iterating from 560 to 561 out of 10000 .
# Iterating from 561 to 562 out of 10000 .
# Iterating from 562 to 563 out of 10000 .
# Iterating from 563 to 564 out of 10000 .
# Iterating from 564 to 565 out of 10000 .
# Iterating from 565 to 566 out of 10000 .
# Iterating from 566 to 567 out of 10000 .
# Iterating from 567 to 568 out of 10000 .
# Iterating from 568 to 569 out of 10000 .
# Iterating from 569 to 570 out of 10000 .
# Iterating from 570 to 571 out of 10000 .
# Iterating from 571 to 572 out of 10000 .
# Iterating from 572 to 573 out of 10000 .
# Iterating from 573 to 574 out of 10000 .
# Iterating from 574 to 575 out of 10000 .
# Iterating from 575 to 576 out of 10000 .
# Iterating from 576 to 577 out of 10000 .
# Iterating from 577 to 578 out of 10000 .
# Iterating from 578 to 579 out of 10000 .
# Iterating from 579 to 580 out of 10000 .
# Iterating from 580 to 581 out of 10000 .
# Iterating from 581 to 582 out of 10000 .
# Iterating from 582 to 583 out of 10000 .
# Iterating from 583 to 584 out of 10000 .
# Iterating from 584 to 585 out of 10000 .
# Iterating from 585 to 586 out of 10000 .
# Iterating from 586 to 587 out of 10000 .
# Iterating from 587 to 588 out of 10000 .
# Iterating from 588 to 589 out of 10000 .
# Iterating from 589 to 590 out of 10000 .
# Iterating from 590 to 591 out of 10000 .
# Iterating from 591 to 592 out of 10000 .
# Iterating from 592 to 593 out of 10000 .
# Iterating from 593 to 594 out of 10000 .
# Iterating from 594 to 595 out of 10000 .
# Iterating from 595 to 596 out of 10000 .
# Iterating from 596 to 597 out of 10000 .
# Iterating from 597 to 598 out of 10000 .
# Iterating from 598 to 599 out of 10000 .
# Iterating from 599 to 600 out of 10000 .
# Iterating from 600 to 601 out of 10000 .
# Iterating from 601 to 602 out of 10000 .
# Iterating from 602 to 603 out of 10000 .
# Iterating from 603 to 604 out of 10000 .
# Iterating from 604 to 605 out of 10000 .
# Iterating from 605 to 606 out of 10000 .
# Iterating from 606 to 607 out of 10000 .
# Iterating from 607 to 608 out of 10000 .
# Iterating from 608 to 609 out of 10000 .
# Iterating from 609 to 610 out of 10000 .
# Iterating from 610 to 611 out of 10000 .
# Iterating from 611 to 612 out of 10000 .
# Iterating from 612 to 613 out of 10000 .
# Iterating from 613 to 614 out of 10000 .
# Iterating from 614 to 615 out of 10000 .
# Iterating from 615 to 616 out of 10000 .
# Iterating from 616 to 617 out of 10000 .
# Iterating from 617 to 618 out of 10000 .
# Iterating from 618 to 619 out of 10000 .
# Iterating from 619 to 620 out of 10000 .
# Iterating from 620 to 621 out of 10000 .
# Iterating from 621 to 622 out of 10000 .
# Iterating from 622 to 623 out of 10000 .
# Iterating from 623 to 624 out of 10000 .
# Iterating from 624 to 625 out of 10000 .
# Iterating from 625 to 626 out of 10000 .
# Iterating from 626 to 627 out of 10000 .
# Iterating from 627 to 628 out of 10000 .
# Iterating from 628 to 629 out of 10000 .
# Iterating from 629 to 630 out of 10000 .
# Iterating from 630 to 631 out of 10000 .
# Iterating from 631 to 632 out of 10000 .
# Iterating from 632 to 633 out of 10000 .
# Iterating from 633 to 634 out of 10000 .
# Iterating from 634 to 635 out of 10000 .
# Iterating from 635 to 636 out of 10000 .
# Iterating from 636 to 637 out of 10000 .
# Iterating from 637 to 638 out of 10000 .
# Iterating from 638 to 639 out of 10000 .
# Iterating from 639 to 640 out of 10000 .
# Iterating from 640 to 641 out of 10000 .
# Iterating from 641 to 642 out of 10000 .
# Iterating from 642 to 643 out of 10000 .
# Iterating from 643 to 644 out of 10000 .
# Iterating from 644 to 645 out of 10000 .
# Iterating from 645 to 646 out of 10000 .
# Iterating from 646 to 647 out of 10000 .
# Iterating from 647 to 648 out of 10000 .
# Iterating from 648 to 649 out of 10000 .
# Iterating from 649 to 650 out of 10000 .
# Iterating from 650 to 651 out of 10000 .
# Iterating from 651 to 652 out of 10000 .
# Iterating from 652 to 653 out of 10000 .
# Iterating from 653 to 654 out of 10000 .
# Iterating from 654 to 655 out of 10000 .
# Iterating from 655 to 656 out of 10000 .
# Iterating from 656 to 657 out of 10000 .
# Iterating from 657 to 658 out of 10000 .
# Iterating from 658 to 659 out of 10000 .
# Iterating from 659 to 660 out of 10000 .
# Iterating from 660 to 661 out of 10000 .
# Iterating from 661 to 662 out of 10000 .
# Iterating from 662 to 663 out of 10000 .
# Iterating from 663 to 664 out of 10000 .
# Iterating from 664 to 665 out of 10000 .
# Iterating from 665 to 666 out of 10000 .
# Iterating from 666 to 667 out of 10000 .
# Iterating from 667 to 668 out of 10000 .
# Iterating from 668 to 669 out of 10000 .
# Iterating from 669 to 670 out of 10000 .
# Iterating from 670 to 671 out of 10000 .
# Iterating from 671 to 672 out of 10000 .
# Iterating from 672 to 673 out of 10000 .
# Iterating from 673 to 674 out of 10000 .
# Iterating from 674 to 675 out of 10000 .
# Iterating from 675 to 676 out of 10000 .
# Iterating from 676 to 677 out of 10000 .
# Iterating from 677 to 678 out of 10000 .
# Iterating from 678 to 679 out of 10000 .
# Iterating from 679 to 680 out of 10000 .
# Iterating from 680 to 681 out of 10000 .
# Iterating from 681 to 682 out of 10000 .
# Iterating from 682 to 683 out of 10000 .
# Iterating from 683 to 684 out of 10000 .
# Iterating from 684 to 685 out of 10000 .
# Iterating from 685 to 686 out of 10000 .
# Iterating from 686 to 687 out of 10000 .
# Iterating from 687 to 688 out of 10000 .
# Iterating from 688 to 689 out of 10000 .
# Iterating from 689 to 690 out of 10000 .
# Iterating from 690 to 691 out of 10000 .
# Iterating from 691 to 692 out of 10000 .
# Iterating from 692 to 693 out of 10000 .
# Iterating from 693 to 694 out of 10000 .
# Iterating from 694 to 695 out of 10000 .
# Iterating from 695 to 696 out of 10000 .
# Iterating from 696 to 697 out of 10000 .
# Iterating from 697 to 698 out of 10000 .
# Iterating from 698 to 699 out of 10000 .
# Iterating from 699 to 700 out of 10000 .
# Iterating from 700 to 701 out of 10000 .
# Iterating from 701 to 702 out of 10000 .
# Iterating from 702 to 703 out of 10000 .
# Iterating from 703 to 704 out of 10000 .
# Iterating from 704 to 705 out of 10000 .
# Iterating from 705 to 706 out of 10000 .
# Iterating from 706 to 707 out of 10000 .
# Iterating from 707 to 708 out of 10000 .
# Iterating from 708 to 709 out of 10000 .
# Iterating from 709 to 710 out of 10000 .
# Iterating from 710 to 711 out of 10000 .
# Iterating from 711 to 712 out of 10000 .
# Iterating from 712 to 713 out of 10000 .
# Iterating from 713 to 714 out of 10000 .
# Iterating from 714 to 715 out of 10000 .
# Iterating from 715 to 716 out of 10000 .
# Iterating from 716 to 717 out of 10000 .
# Iterating from 717 to 718 out of 10000 .
# Iterating from 718 to 719 out of 10000 .
# Iterating from 719 to 720 out of 10000 .
# Iterating from 720 to 721 out of 10000 .
# Iterating from 721 to 722 out of 10000 .
# Iterating from 722 to 723 out of 10000 .
# Iterating from 723 to 724 out of 10000 .
# Iterating from 724 to 725 out of 10000 .
# Iterating from 725 to 726 out of 10000 .
# Iterating from 726 to 727 out of 10000 .
# Iterating from 727 to 728 out of 10000 .
# Iterating from 728 to 729 out of 10000 .
# Iterating from 729 to 730 out of 10000 .
# Iterating from 730 to 731 out of 10000 .
# Iterating from 731 to 732 out of 10000 .
# Iterating from 732 to 733 out of 10000 .
# Iterating from 733 to 734 out of 10000 .
# Iterating from 734 to 735 out of 10000 .
# Iterating from 735 to 736 out of 10000 .
# Iterating from 736 to 737 out of 10000 .
# Iterating from 737 to 738 out of 10000 .
# Iterating from 738 to 739 out of 10000 .
# Iterating from 739 to 740 out of 10000 .
# Iterating from 740 to 741 out of 10000 .
# Iterating from 741 to 742 out of 10000 .
# Iterating from 742 to 743 out of 10000 .
# Iterating from 743 to 744 out of 10000 .
# Iterating from 744 to 745 out of 10000 .
# Iterating from 745 to 746 out of 10000 .
# Iterating from 746 to 747 out of 10000 .
# Iterating from 747 to 748 out of 10000 .
# Iterating from 748 to 749 out of 10000 .
# Iterating from 749 to 750 out of 10000 .
# Iterating from 750 to 751 out of 10000 .
# Iterating from 751 to 752 out of 10000 .
# Iterating from 752 to 753 out of 10000 .
# Iterating from 753 to 754 out of 10000 .
# Iterating from 754 to 755 out of 10000 .
# Iterating from 755 to 756 out of 10000 .
# Iterating from 756 to 757 out of 10000 .
# Iterating from 757 to 758 out of 10000 .
# Iterating from 758 to 759 out of 10000 .
# Iterating from 759 to 760 out of 10000 .
# Iterating from 760 to 761 out of 10000 .
# Iterating from 761 to 762 out of 10000 .
# Iterating from 762 to 763 out of 10000 .
# Iterating from 763 to 764 out of 10000 .
# Iterating from 764 to 765 out of 10000 .
# Iterating from 765 to 766 out of 10000 .
# Iterating from 766 to 767 out of 10000 .
# Iterating from 767 to 768 out of 10000 .
# Iterating from 768 to 769 out of 10000 .
# Iterating from 769 to 770 out of 10000 .
# Iterating from 770 to 771 out of 10000 .
# Iterating from 771 to 772 out of 10000 .
# Iterating from 772 to 773 out of 10000 .
# Iterating from 773 to 774 out of 10000 .
# Iterating from 774 to 775 out of 10000 .
# Iterating from 775 to 776 out of 10000 .
# Iterating from 776 to 777 out of 10000 .
# Iterating from 777 to 778 out of 10000 .
# Iterating from 778 to 779 out of 10000 .
# Iterating from 779 to 780 out of 10000 .
# Iterating from 780 to 781 out of 10000 .
# Iterating from 781 to 782 out of 10000 .
# Iterating from 782 to 783 out of 10000 .
# Iterating from 783 to 784 out of 10000 .
# Iterating from 784 to 785 out of 10000 .
# Iterating from 785 to 786 out of 10000 .
# Iterating from 786 to 787 out of 10000 .
# Iterating from 787 to 788 out of 10000 .
# Iterating from 788 to 789 out of 10000 .
# Iterating from 789 to 790 out of 10000 .
# Iterating from 790 to 791 out of 10000 .
# Iterating from 791 to 792 out of 10000 .
# Iterating from 792 to 793 out of 10000 .
# Iterating from 793 to 794 out of 10000 .
# Iterating from 794 to 795 out of 10000 .
# Iterating from 795 to 796 out of 10000 .
# Iterating from 796 to 797 out of 10000 .
# Iterating from 797 to 798 out of 10000 .
# Iterating from 798 to 799 out of 10000 .
# Iterating from 799 to 800 out of 10000 .
# Iterating from 800 to 801 out of 10000 .
# Iterating from 801 to 802 out of 10000 .
# Iterating from 802 to 803 out of 10000 .
# Iterating from 803 to 804 out of 10000 .
# Iterating from 804 to 805 out of 10000 .
# Iterating from 805 to 806 out of 10000 .
# Iterating from 806 to 807 out of 10000 .
# Iterating from 807 to 808 out of 10000 .
# Iterating from 808 to 809 out of 10000 .
# Iterating from 809 to 810 out of 10000 .
# Iterating from 810 to 811 out of 10000 .
# Iterating from 811 to 812 out of 10000 .
# Iterating from 812 to 813 out of 10000 .
# Iterating from 813 to 814 out of 10000 .
# Iterating from 814 to 815 out of 10000 .
# Iterating from 815 to 816 out of 10000 .
# Iterating from 816 to 817 out of 10000 .
# Iterating from 817 to 818 out of 10000 .
# Iterating from 818 to 819 out of 10000 .
# Iterating from 819 to 820 out of 10000 .
# Iterating from 820 to 821 out of 10000 .
# Iterating from 821 to 822 out of 10000 .
# Iterating from 822 to 823 out of 10000 .
# Iterating from 823 to 824 out of 10000 .
# Iterating from 824 to 825 out of 10000 .
# Iterating from 825 to 826 out of 10000 .
# Iterating from 826 to 827 out of 10000 .
# Iterating from 827 to 828 out of 10000 .
# Iterating from 828 to 829 out of 10000 .
# Iterating from 829 to 830 out of 10000 .
# Iterating from 830 to 831 out of 10000 .
# Iterating from 831 to 832 out of 10000 .
# Iterating from 832 to 833 out of 10000 .
# Iterating from 833 to 834 out of 10000 .
# Iterating from 834 to 835 out of 10000 .
# Iterating from 835 to 836 out of 10000 .
# Iterating from 836 to 837 out of 10000 .
# Iterating from 837 to 838 out of 10000 .
# Iterating from 838 to 839 out of 10000 .
# Iterating from 839 to 840 out of 10000 .
# Iterating from 840 to 841 out of 10000 .
# Iterating from 841 to 842 out of 10000 .
# Iterating from 842 to 843 out of 10000 .
# Iterating from 843 to 844 out of 10000 .
# Iterating from 844 to 845 out of 10000 .
# Iterating from 845 to 846 out of 10000 .
# Iterating from 846 to 847 out of 10000 .
# Iterating from 847 to 848 out of 10000 .
# Iterating from 848 to 849 out of 10000 .
# Iterating from 849 to 850 out of 10000 .
# Iterating from 850 to 851 out of 10000 .
# Iterating from 851 to 852 out of 10000 .
# Iterating from 852 to 853 out of 10000 .
# Iterating from 853 to 854 out of 10000 .
# Iterating from 854 to 855 out of 10000 .
# Iterating from 855 to 856 out of 10000 .
# Iterating from 856 to 857 out of 10000 .
# Iterating from 857 to 858 out of 10000 .
# Iterating from 858 to 859 out of 10000 .
# Iterating from 859 to 860 out of 10000 .
# Iterating from 860 to 861 out of 10000 .
# Iterating from 861 to 862 out of 10000 .
# Iterating from 862 to 863 out of 10000 .
# Iterating from 863 to 864 out of 10000 .
# Iterating from 864 to 865 out of 10000 .
# Iterating from 865 to 866 out of 10000 .
# Iterating from 866 to 867 out of 10000 .
# Iterating from 867 to 868 out of 10000 .
# Iterating from 868 to 869 out of 10000 .
# Iterating from 869 to 870 out of 10000 .
# Iterating from 870 to 871 out of 10000 .
# Iterating from 871 to 872 out of 10000 .
# Iterating from 872 to 873 out of 10000 .
# Iterating from 873 to 874 out of 10000 .
# Iterating from 874 to 875 out of 10000 .
# Iterating from 875 to 876 out of 10000 .
# Iterating from 876 to 877 out of 10000 .
# Iterating from 877 to 878 out of 10000 .
# Iterating from 878 to 879 out of 10000 .
# Iterating from 879 to 880 out of 10000 .
# Iterating from 880 to 881 out of 10000 .
# Iterating from 881 to 882 out of 10000 .
# Iterating from 882 to 883 out of 10000 .
# Iterating from 883 to 884 out of 10000 .
# Iterating from 884 to 885 out of 10000 .
# Iterating from 885 to 886 out of 10000 .
# Iterating from 886 to 887 out of 10000 .
# Iterating from 887 to 888 out of 10000 .
# Iterating from 888 to 889 out of 10000 .
# Iterating from 889 to 890 out of 10000 .
# Iterating from 890 to 891 out of 10000 .
# Iterating from 891 to 892 out of 10000 .
# Iterating from 892 to 893 out of 10000 .
# Iterating from 893 to 894 out of 10000 .
# Iterating from 894 to 895 out of 10000 .
# Iterating from 895 to 896 out of 10000 .
# Iterating from 896 to 897 out of 10000 .
# Iterating from 897 to 898 out of 10000 .
# Iterating from 898 to 899 out of 10000 .
# Iterating from 899 to 900 out of 10000 .
# Iterating from 900 to 901 out of 10000 .
# Iterating from 901 to 902 out of 10000 .
# Iterating from 902 to 903 out of 10000 .
# Iterating from 903 to 904 out of 10000 .
# Iterating from 904 to 905 out of 10000 .
# Iterating from 905 to 906 out of 10000 .
# Iterating from 906 to 907 out of 10000 .
# Iterating from 907 to 908 out of 10000 .
# Iterating from 908 to 909 out of 10000 .
# Iterating from 909 to 910 out of 10000 .
# Iterating from 910 to 911 out of 10000 .
# Iterating from 911 to 912 out of 10000 .
# Iterating from 912 to 913 out of 10000 .
# Iterating from 913 to 914 out of 10000 .
# Iterating from 914 to 915 out of 10000 .
# Iterating from 915 to 916 out of 10000 .
# Iterating from 916 to 917 out of 10000 .
# Iterating from 917 to 918 out of 10000 .
# Iterating from 918 to 919 out of 10000 .
# Iterating from 919 to 920 out of 10000 .
# Iterating from 920 to 921 out of 10000 .
# Iterating from 921 to 922 out of 10000 .
# Iterating from 922 to 923 out of 10000 .
# Iterating from 923 to 924 out of 10000 .
# Iterating from 924 to 925 out of 10000 .
# Iterating from 925 to 926 out of 10000 .
# Iterating from 926 to 927 out of 10000 .
# Iterating from 927 to 928 out of 10000 .
# Iterating from 928 to 929 out of 10000 .
# Iterating from 929 to 930 out of 10000 .
# Iterating from 930 to 931 out of 10000 .
# Iterating from 931 to 932 out of 10000 .
# Iterating from 932 to 933 out of 10000 .
# Iterating from 933 to 934 out of 10000 .
# Iterating from 934 to 935 out of 10000 .
# Iterating from 935 to 936 out of 10000 .
# Iterating from 936 to 937 out of 10000 .
# Iterating from 937 to 938 out of 10000 .
# Iterating from 938 to 939 out of 10000 .
# Iterating from 939 to 940 out of 10000 .
# Iterating from 940 to 941 out of 10000 .
# Iterating from 941 to 942 out of 10000 .
# Iterating from 942 to 943 out of 10000 .
# Iterating from 943 to 944 out of 10000 .
# Iterating from 944 to 945 out of 10000 .
# Iterating from 945 to 946 out of 10000 .
# Iterating from 946 to 947 out of 10000 .
# Iterating from 947 to 948 out of 10000 .
# Iterating from 948 to 949 out of 10000 .
# Iterating from 949 to 950 out of 10000 .
# Iterating from 950 to 951 out of 10000 .
# Iterating from 951 to 952 out of 10000 .
# Iterating from 952 to 953 out of 10000 .
# Iterating from 953 to 954 out of 10000 .
# Iterating from 954 to 955 out of 10000 .
# Iterating from 955 to 956 out of 10000 .
# Iterating from 956 to 957 out of 10000 .
# Iterating from 957 to 958 out of 10000 .
# Iterating from 958 to 959 out of 10000 .
# Iterating from 959 to 960 out of 10000 .
# Iterating from 960 to 961 out of 10000 .
# Iterating from 961 to 962 out of 10000 .
# Iterating from 962 to 963 out of 10000 .
# Iterating from 963 to 964 out of 10000 .
# Iterating from 964 to 965 out of 10000 .
# Iterating from 965 to 966 out of 10000 .
# Iterating from 966 to 967 out of 10000 .
# Iterating from 967 to 968 out of 10000 .
# Iterating from 968 to 969 out of 10000 .
# Iterating from 969 to 970 out of 10000 .
# Iterating from 970 to 971 out of 10000 .
# Iterating from 971 to 972 out of 10000 .
# Iterating from 972 to 973 out of 10000 .
# Iterating from 973 to 974 out of 10000 .
# Iterating from 974 to 975 out of 10000 .
# Iterating from 975 to 976 out of 10000 .
# Iterating from 976 to 977 out of 10000 .
# Iterating from 977 to 978 out of 10000 .
# Iterating from 978 to 979 out of 10000 .
# Iterating from 979 to 980 out of 10000 .
# Iterating from 980 to 981 out of 10000 .
# Iterating from 981 to 982 out of 10000 .
# Iterating from 982 to 983 out of 10000 .
# Iterating from 983 to 984 out of 10000 .
# Iterating from 984 to 985 out of 10000 .
# Iterating from 985 to 986 out of 10000 .
# Iterating from 986 to 987 out of 10000 .
# Iterating from 987 to 988 out of 10000 .
# Iterating from 988 to 989 out of 10000 .
# Iterating from 989 to 990 out of 10000 .
# Iterating from 990 to 991 out of 10000 .
# Iterating from 991 to 992 out of 10000 .
# Iterating from 992 to 993 out of 10000 .
# Iterating from 993 to 994 out of 10000 .
# Iterating from 994 to 995 out of 10000 .
# Iterating from 995 to 996 out of 10000 .
# Iterating from 996 to 997 out of 10000 .
# Iterating from 997 to 998 out of 10000 .
# Iterating from 998 to 999 out of 10000 .
# Iterating from 999 to 1000 out of 10000 .
# Iterating from 1000 to 1001 out of 10000 .
# Iterating from 1001 to 1002 out of 10000 .
# Iterating from 1002 to 1003 out of 10000 .
# Iterating from 1003 to 1004 out of 10000 .
# Iterating from 1004 to 1005 out of 10000 .
# Iterating from 1005 to 1006 out of 10000 .
# Iterating from 1006 to 1007 out of 10000 .
# Iterating from 1007 to 1008 out of 10000 .
# Iterating from 1008 to 1009 out of 10000 .
# Iterating from 1009 to 1010 out of 10000 .
# Iterating from 1010 to 1011 out of 10000 .
# Iterating from 1011 to 1012 out of 10000 .
# Iterating from 1012 to 1013 out of 10000 .
# Iterating from 1013 to 1014 out of 10000 .
# Iterating from 1014 to 1015 out of 10000 .
# Iterating from 1015 to 1016 out of 10000 .
# Iterating from 1016 to 1017 out of 10000 .
# Iterating from 1017 to 1018 out of 10000 .
# Iterating from 1018 to 1019 out of 10000 .
# Iterating from 1019 to 1020 out of 10000 .
# Iterating from 1020 to 1021 out of 10000 .
# Iterating from 1021 to 1022 out of 10000 .
# Iterating from 1022 to 1023 out of 10000 .
# Iterating from 1023 to 1024 out of 10000 .
# Iterating from 1024 to 1025 out of 10000 .
# Iterating from 1025 to 1026 out of 10000 .
# Iterating from 1026 to 1027 out of 10000 .
# Iterating from 1027 to 1028 out of 10000 .
# Iterating from 1028 to 1029 out of 10000 .
# Iterating from 1029 to 1030 out of 10000 .
# Iterating from 1030 to 1031 out of 10000 .
# Iterating from 1031 to 1032 out of 10000 .
# Iterating from 1032 to 1033 out of 10000 .
# Iterating from 1033 to 1034 out of 10000 .
# Iterating from 1034 to 1035 out of 10000 .
# Iterating from 1035 to 1036 out of 10000 .
# Iterating from 1036 to 1037 out of 10000 .
# ...
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# SKS metric calculation completed in 786.8675609461498 seconds.
# Saving sks to ../results_leonardo/5D_100K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 50
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# SWD metric calculation completed in 353.91842192504555 seconds.
# Saving swd to ../results_leonardo/5D_100K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fn: [[0.68, [6800, 3199], 0.7311931613101769], [0.95, [9500, 500], 1.2152135086781035], [0.99, [9900, 100], 1.5590543375150292]]
# Computing time for metric fn: 33.18956989585422
# ThresholdS for metric fpd: [[0.68, [6800, 3199], 0.3721655670741698], [0.95, [9500, 500], 0.4101249406132395], [0.99, [9900, 100], 0.4512487853491462]]
# Computing time for metric fpd: 270.10692294710316
# ThresholdS for metric kpd: [[0.68, [6800, 3199], -0.07877539754373998], [0.95, [9500, 500], -0.011921334883213675], [0.99, [9900, 100], 0.028590647968884664]]
# Computing time for metric kpd: 30466.033751571085
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9199168115783043], [0.95, [9500, 500], 1.1323405345344149], [0.99, [9900, 100], 1.284396397308672]]
# Computing time for metric ks: 102.95067132893018
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9117351041017392], [0.95, [9500, 500], 1.1124223535563071], [0.99, [9900, 100], 1.265660243663076]]
# Computing time for metric sks: 786.8675609461498
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.6889382599299374], [0.95, [9500, 500], 0.9896122829526833], [0.99, [9900, 100], 1.1974942238152133]]
# Computing time for metric swd: 353.91842192504555
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f87e7259800>
# 1          metric_list  <function <lambda> at 0x7f87e72598a0>
# 2          metric_list  <function <lambda> at 0x7f87e725aca0>
# 3      statistic_means  <function <lambda> at 0x7f87e725afc0>
# 4         metric_means  <function <lambda> at 0x7f87e725b060>
# 5         metric_means  <function <lambda> at 0x7f87e725b100>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f87e725b1a0>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1              lambda ns, ndims: 10000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            500
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...           1000
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
# 6  {'niter': 10000, 'batch_size_test': 100000, 'b...            200
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  ../results_leonardo/5D_100K/null_hypothesis/FN...
# 1  ../results_leonardo/5D_100K/null_hypothesis/FP...
# 2  ../results_leonardo/5D_100K/null_hypothesis/KP...
# 3  ../results_leonardo/5D_100K/null_hypothesis/KS...
# 4  ../results_leonardo/5D_100K/null_hypothesis/SK...
# 5  ../results_leonardo/5D_100K/null_hypothesis/SW...
# 6  ../results_leonardo/5D_100K/null_hypothesis/LR...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.7311931613101769], [0....
# 1  [[0.68, [6800, 3199], 0.3721655670741698], [0....
# 2  [[0.68, [6800, 3199], -0.07877539754373998], [...
# 3  [[0.68, [6800, 3199], 0.9199168115783043], [0....
# 4  [[0.68, [6800, 3199], 0.9117351041017392], [0....
# 5  [[0.68, [6800, 3199], 0.6889382599299374], [0....
# 6                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.6516939997710277 +/- 0.0008453544464860177
# sigma = 0.2907497973320046 +/- 0.0027147626221840793
# /tmp/ipykernel_370086/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_370086/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_370086/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_370086/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.5198449280578643 seconds.
# mu = 0.37037236579175314 +/- 4.298580003632062e-06
# sigma = 0.020733017155329953 +/- 0.000367371551416249
# /tmp/ipykernel_370086/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_370086/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_370086/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_370086/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9528770609758794 seconds.
# mu = -0.10200337186971595 +/- 2.866492800349496e-05
# sigma = 0.05353963765612815 +/- 0.0003878556341894495
# /tmp/ipykernel_370086/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_370086/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_370086/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_370086/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.0227291870396584 seconds.
# mu = 0.8693149240841894 +/- 0.00020805869243534366
# sigma = 0.14424239752421744 +/- 0.0012550704659856392
# /tmp/ipykernel_370086/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_370086/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_370086/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_370086/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.35298205120489 seconds.
# mu = 0.8689293527700909 +/- 0.00017416942795426158
# sigma = 0.1319732654571605 +/- 0.001199891859395542
# /tmp/ipykernel_370086/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_370086/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_370086/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_370086/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3584744611289352 seconds.
# mu = 0.6350235360487639 +/- 0.00034087011831206317
# sigma = 0.18462668233818838 +/- 0.0017387793214599034
# /tmp/ipykernel_370086/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_370086/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_370086/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_370086/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 4.226057433988899 seconds.
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f87e7259800>
# 1          metric_list  <function <lambda> at 0x7f87e72598a0>
# 2          metric_list  <function <lambda> at 0x7f87e725aca0>
# 3      statistic_means  <function <lambda> at 0x7f87e725afc0>
# 4         metric_means  <function <lambda> at 0x7f87e725b060>
# 5         metric_means  <function <lambda> at 0x7f87e725b100>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f87e725b1a0>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1              lambda ns, ndims: 10000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            500
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...           1000
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
# 6  {'niter': 10000, 'batch_size_test': 100000, 'b...            200
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  ../results_leonardo/5D_100K/null_hypothesis/FN...
# 1  ../results_leonardo/5D_100K/null_hypothesis/FP...
# 2  ../results_leonardo/5D_100K/null_hypothesis/KP...
# 3  ../results_leonardo/5D_100K/null_hypothesis/KS...
# 4  ../results_leonardo/5D_100K/null_hypothesis/SK...
# 5  ../results_leonardo/5D_100K/null_hypothesis/SW...
# 6  ../results_leonardo/5D_100K/null_hypothesis/LR...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.7311931613101769], [0....
# 1  [[0.68, [6800, 3199], 0.3721655670741698], [0....
# 2  [[0.68, [6800, 3199], -0.07877539754373998], [...
# 3  [[0.68, [6800, 3199], 0.9199168115783043], [0....
# 4  [[0.68, [6800, 3199], 0.9117351041017392], [0....
# 5  [[0.68, [6800, 3199], 0.6889382599299374], [0....
# 6                                                 []
#
#                                          null_figure
# 0  ../results_leonardo/5D_100K/null_hypothesis/FN...
# 1  ../results_leonardo/5D_100K/null_hypothesis/FP...
# 2  ../results_leonardo/5D_100K/null_hypothesis/KP...
# 3  ../results_leonardo/5D_100K/null_hypothesis/KS...
# 4  ../results_leonardo/5D_100K/null_hypothesis/SK...
# 5  ../results_leonardo/5D_100K/null_hypothesis/SW...
# 6                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "std", "both"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.01,
                                                 fn_tol = 0.01,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fn with mean deformation.
#
# ======================================================
# =============== fn - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 80.70564401110042 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.94066402401197
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 49.56604599226681 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9042785846100967
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 28.617883664147243 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8370650554130157
#
# ------------ 4 ------------
# eps = 0.3125
# WARNING:tensorflow:5 out of the last 407 calls to <function generate_and_clean_data_simple_1 at 0x7f88bd7a7600> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 15.14663933683161 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7029154289181616
#
# ------------ 5 ------------
# eps = 0.15625
# WARNING:tensorflow:6 out of the last 409 calls to <function generate_and_clean_data_simple_1 at 0x7f88bd7a7600> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f7ea37b44a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 7.623744797718514 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4500648304682364
#
# ------------ 6 ------------
# eps = 0.078125
# WARNING:tensorflow:6 out of the last 6 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f8760236ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 3.686303440877734 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0082959857656124
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.7178255600408538 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.3427244162705767
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.8911328198031061 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.30771833149459066
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 1.2621811505000669 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.037916963813544334
#
# ------------ 10 ------------
# eps = 0.0244140625
# statistic = 1.0598609737342601 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.13656918588363412
#
# ------------ 11 ------------
# eps = 0.02685546875
# statistic = 1.157776243094153 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.048409198177997874
#
# ------------ 12 ------------
# eps = 0.028076171875
# statistic = 1.2092754973166673 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.0425531914893617
# relative_error_metric = 0.004898361136514919
#
# ------------ 13 ------------
# eps = 0.0286865234375
# statistic = 1.2355648451518253 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.021505376344086023
# relative_error_metric = 0.016608059592103007
#
# ------------ 14 ------------
# eps = 0.02838134765625
# statistic = 1.222377817358102 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.010810810810810811
# relative_error_metric = 0.0058781868834825255
#
# ------------ 15 ------------
# eps = 0.028228759765625
# statistic = 1.2158158784099036 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.005420054200542005
# relative_error_metric = 0.0004955676266189454
# =======> statistic within required accuracy at 0.95 CL in 178.75964273908176 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0281524658203125
# statistic = 1.21254296901683 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.9776041271527198
# relative_error_metric = 0.2500445268016183
#
# ------------ 2 ------------
# eps = 2.5140762329101562
# statistic = 81.02455931026397 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.9557042750176312
# relative_error_metric = 1.9244860199911116
#
# ------------ 3 ------------
# eps = 1.2711143493652344
# statistic = 50.16275208017778 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.913328146332154
# relative_error_metric = 1.879427696324101
#
# ------------ 4 ------------
# eps = 0.6496334075927734
# statistic = 29.58893380640282 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.83385628456051
# relative_error_metric = 1.7997874751574336
#
# ------------ 5 ------------
# eps = 0.33889293670654297
# statistic = 16.366646669372322 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.6931990906138357
# relative_error_metric = 1.652107476987145
#
# ------------ 6 ------------
# eps = 0.18352270126342773
# statistic = 8.97285388706896 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.4680062624601558
# relative_error_metric = 1.4078739372696683
#
# ------------ 7 ------------
# eps = 0.10583758354187012
# statistic = 5.0934572091444394 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.1595654765611794
# relative_error_metric = 1.062576997225716
#
# ------------ 8 ------------
# eps = 0.06699502468109131
# statistic = 3.1200090799963807 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.8164704850561608
# relative_error_metric = 0.6672082009572571
#
# ------------ 9 ------------
# eps = 0.047573745250701904
# statistic = 2.1381282793061738 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.512934138806352
# relative_error_metric = 0.313251468378387
#
# ------------ 10 ------------
# eps = 0.0378631055355072
# statistic = 1.6597736902380142 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.29419240084600573
# relative_error_metric = 0.06258138170450434
#
# ------------ 11 ------------
# eps = 0.03300778567790985
# statistic = 1.4298233789535846 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.13701873292312028
# relative_error_metric = 0.08647457060513815
#
# ------------ 12 ------------
# eps = 0.03543544560670853
# statistic = 1.543638290656221 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.06624032510788562
# relative_error_metric = 0.00993720532858235
#
# ------------ 13 ------------
# eps = 0.036649275571107864
# statistic = 1.6014557675194183 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.0336778708321587
# relative_error_metric = 0.026832016728468567
#
# ------------ 14 ------------
# eps = 0.036042360588908195
# statistic = 1.5724799735589712 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.016981914093409517
# relative_error_metric = 0.008574478010006208
#
# ------------ 15 ------------
# eps = 0.03573890309780836
# statistic = 1.5580417666954662 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.008455061265687654
# relative_error_metric = 0.0006496885471033172
# =======> statistic within required accuracy at 0.99 CL in 169.93066459009424 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 348.69034184794873 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# Computing exclusion limits for fn with std deformation.
#
# ======================================================
# =============== fn - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 37.35205475820937 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8739642641766832
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 8.689592150844899 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.50924286636165
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 6.91035118609496 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4017826185250535
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 5.024552000752706 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.22098770741213
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 2.909423635972717 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.821507477084043
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.6327606361637121 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.2932239593831006
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.0306940091712296 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1643162045101204
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.3189468908973923 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.08186804768685156
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 1.1700803100267827 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.03784288400648792
#
# ------------ 10 ------------
# eps = 0.0537109375
# statistic = 1.243564714792272 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.02306121458498431
#
# ------------ 11 ------------
# eps = 0.05126953125
# statistic = 1.206559026619716 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.007147229504213781
#
# ------------ 12 ------------
# eps = 0.052490234375
# statistic = 1.2249994650712 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.023529411764705882
# relative_error_metric = 0.008020575661525677
#
# ------------ 13 ------------
# eps = 0.0518798828125
# statistic = 1.215763223222444 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.011834319526627219
# relative_error_metric = 0.00045225817024643173
#
# ------------ 14 ------------
# eps = 0.05157470703125
# statistic = 1.2111570655846382 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.0058997050147492625
# relative_error_metric = 0.003343630306510679
# =======> statistic within required accuracy at 0.95 CL in 156.73286049091257 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.051727294921875
# statistic = 1.213459136325881 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.9590418944634065
# relative_error_metric = 0.24930100751530465
#
# ------------ 2 ------------
# eps = 2.5258636474609375
# statistic = 37.95626700548668 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.919727689803167
# relative_error_metric = 1.8421822944085822
#
# ------------ 3 ------------
# eps = 1.2887954711914062
# statistic = 9.23461902593675 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.8456503798981247
# relative_error_metric = 1.4222340124561825
#
# ------------ 4 ------------
# eps = 0.6702613830566406
# statistic = 6.951955710134629 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.713417694766597
# relative_error_metric = 1.2672764671706307
#
# ------------ 5 ------------
# eps = 0.3609943389892578
# statistic = 5.523206872762165 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.4986713496776578
# relative_error_metric = 1.1194595673750876
#
# ------------ 6 ------------
# eps = 0.2063608169555664
# statistic = 3.6668270741135474 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.1983002309468822
# relative_error_metric = 0.8066668837560393
#
# ------------ 7 ------------
# eps = 0.1290440559387207
# statistic = 2.4730061546284112 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.8554094512074492
# relative_error_metric = 0.453342314131565
#
# ------------ 8 ------------
# eps = 0.09038567543029785
# statistic = 1.8349919047244505 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.5440514037898552
# relative_error_metric = 0.16260094737386405
#
# ------------ 9 ------------
# eps = 0.07105648517608643
# statistic = 1.517518020436008 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.23945653578482953
# relative_error_metric = 0.027001683852275134
#
# ------------ 10 ------------
# eps = 0.08072108030319214
# statistic = 1.6753906914604633 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.12735209049620935
# relative_error_metric = 0.07193589806179733
#
# ------------ 11 ------------
# eps = 0.07588878273963928
# statistic = 1.5961571969877093 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.06577003304828051
# relative_error_metric = 0.023518460849267602
#
# ------------ 12 ------------
# eps = 0.07347263395786285
# statistic = 1.556751687349758 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.032353051212279174
# relative_error_metric = 0.0014780446195273842
#
# ------------ 13 ------------
# eps = 0.07468070834875107
# statistic = 1.5764344906817214 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.01630843249405765
# relative_error_metric = 0.011086088402163219
#
# ------------ 14 ------------
# eps = 0.07407667115330696
# statistic = 1.5665879149579311 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.008187597969221206
# relative_error_metric = 0.00482049885071876
# =======> statistic within required accuracy at 0.99 CL in 157.001119047869 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 313.73401498398744 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# Computing exclusion limits for fn with both deformation.
#
# ======================================================
# =============== fn - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 73.57519191617789 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.935006983755473
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 47.53927578711056 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9002993548917702
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 28.75893934251695 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8378318126672721
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 15.89781862479686 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.715956003775389
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 8.178285344151035 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4825299804823608
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 3.994053631343605 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0668833246489722
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.8591529526819486 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4189087098738231
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.9226910121529791 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2736534711207871
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 1.3517733914006562 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.10639702346619906
#
# ------------ 10 ------------
# eps = 0.0244140625
# statistic = 1.1206635761875912 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.08095454431494511
#
# ------------ 11 ------------
# eps = 0.02685546875
# statistic = 1.233196314673265 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.014689375792935425
#
# ------------ 12 ------------
# eps = 0.025634765625
# statistic = 1.1760513742578786 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.032754325712458766
#
# ------------ 13 ------------
# eps = 0.0262451171875
# statistic = 1.2044207741546928 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.022988505747126436
# relative_error_metric = 0.008920963469549651
#
# ------------ 14 ------------
# eps = 0.02655029296875
# statistic = 1.2187597445579614 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.011560693641618497
# relative_error_metric = 0.0029139481094486597
#
# ------------ 15 ------------
# eps = 0.026397705078125
# statistic = 1.2115778181224721 - next threshold = 1.2152135086781035 at 0.95 CL
# relative_error_eps = 0.005763688760806916
# relative_error_metric = 0.0029962943376961935
# =======> statistic within required accuracy at 0.95 CL in 167.29857019498013 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0264739990234375
# statistic = 1.2151657014847093 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.9789323497715647
# relative_error_metric = 0.24791734699913065
#
# ------------ 2 ------------
# eps = 2.5132369995117188
# statistic = 73.81305955885796 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.9583039187707467
# relative_error_metric = 1.9172609466860098
#
# ------------ 3 ------------
# eps = 1.2698554992675781
# statistic = 48.0411357380389 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.9183108953137644
# relative_error_metric = 1.8742702933081357
#
# ------------ 4 ------------
# eps = 0.6481647491455078
# statistic = 29.592826339927495 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.8430330360045801
# relative_error_metric = 1.7998124923938914
#
# ------------ 5 ------------
# eps = 0.33731937408447266
# statistic = 17.04114127920047 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.7089116956994743
# relative_error_metric = 1.6647230234258508
#
# ------------ 6 ------------
# eps = 0.18189668655395508
# statistic = 9.5068094678458 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.491790336052725
# relative_error_metric = 1.4364454994431617
#
# ------------ 7 ------------
# eps = 0.10418534278869629
# statistic = 5.4109580364674725 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 1.1895260252725697
# relative_error_metric = 1.105278869613127
#
# ------------ 8 ------------
# eps = 0.0653296709060669
# statistic = 3.2928318981622002 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.8464949584796878
# relative_error_metric = 0.7146818686300749
#
# ------------ 9 ------------
# eps = 0.0459018349647522
# statistic = 2.228628439316384 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.5368597464309686
# relative_error_metric = 0.3535534210504752
#
# ------------ 10 ------------
# eps = 0.03618791699409485
# statistic = 1.706263508402482 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.31004216238582505
# relative_error_metric = 0.09016529344700834
#
# ------------ 11 ------------
# eps = 0.031330958008766174
# statistic = 1.4539653689847496 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.14386966563417614
# relative_error_metric = 0.06975657563976662
#
# ------------ 12 ------------
# eps = 0.03375943750143051
# statistic = 1.5789326718667858 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.0746186737268759
# relative_error_metric = 0.012669481608639678
#
# ------------ 13 ------------
# eps = 0.03254519775509834
# statistic = 1.5161032347756478 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.036626089311383565
# relative_error_metric = 0.02793424514333894
#
# ------------ 14 ------------
# eps = 0.03315231762826443
# statistic = 1.547438477741509 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.01814688232252479
# relative_error_metric = 0.007478439812558095
#
# ------------ 15 ------------
# eps = 0.03345587756484747
# statistic = 1.5631665136378867 - next threshold = 1.5590543375150292 at 0.99 CL
# relative_error_eps = 0.009114792427657128
# relative_error_metric = 0.0026341353279599406
# =======> statistic within required accuracy at 0.99 CL in 165.50474762590602 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 332.80335171194747 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# Computing exclusion limits for fpd with mean deformation.
#
# ======================================================
# =============== fpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 865.6397787253803 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9981057676289682
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 221.85428516201296 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9926191522894041
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 56.39731727016663 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9711217456972276
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 14.357603427842479 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8889131949395064
#
# ------------ 5 ------------
# eps = 0.15625
# WARNING:tensorflow:5 out of the last 5 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f850d55ec00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 3.749720304690091 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6056344249091568
#
# ------------ 6 ------------
# eps = 0.078125
# WARNING:tensorflow:6 out of the last 6 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f7e3570d580> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.0901875530703875 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9065612868255616
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.5275492064191736 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.2504585759937242
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.41204569077856645 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.004672388168561595
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 0.38377734502525757 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.06637490800720355
#
# ------------ 10 ------------
# eps = 0.0146484375
# statistic = 0.39573467826340175 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.035714067345619355
#
# ------------ 11 ------------
# eps = 0.01708984375
# statistic = 0.4033293972142667 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.0167078668905293
#
# ------------ 12 ------------
# eps = 0.018310546875
# statistic = 0.40754503941658105 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.00631037279016743
#
# ------------ 13 ------------
# eps = 0.0189208984375
# statistic = 0.40975943619568894 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.031746031746031744
# relative_error_metric = 0.0008915999082044854
#
# ------------ 14 ------------
# eps = 0.01922607421875
# statistic = 0.41089354248879767 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.016
# relative_error_metric = 0.0018723132094521644
#
# ------------ 15 ------------
# eps = 0.019073486328125
# statistic = 0.41032423894121783 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.008032128514056224
# relative_error_metric = 0.0004858273563916634
# =======> statistic within required accuracy at 0.95 CL in 204.43175021396019 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0189971923828125
# statistic = 0.41004127560579207 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.9848597704643915
# relative_error_metric = 0.09568787940654075
#
# ------------ 2 ------------
# eps = 2.5094985961914062
# statistic = 872.128077628608 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.969947045245387
# relative_error_metric = 1.9979314257320142
#
# ------------ 3 ------------
# eps = 1.2642478942871094
# statistic = 226.86604902886694 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.9407838998796059
# relative_error_metric = 1.992059578576938
#
# ------------ 4 ------------
# eps = 0.6416225433349609
# statistic = 59.40379156864081 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.884973509838172
# relative_error_metric = 1.9698438906611437
#
# ------------ 5 ------------
# eps = 0.3303098678588867
# statistic = 16.00981678755009 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.7824585352535662
# relative_error_metric = 1.890347612467552
#
# ------------ 6 ------------
# eps = 0.1746535301208496
# statistic = 4.631448741687019 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.607598832842914
# relative_error_metric = 1.6448745706791807
#
# ------------ 7 ------------
# eps = 0.09682536125183105
# statistic = 1.5490781293908957 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.3439207896334873
# relative_error_metric = 1.0976499250717937
#
# ------------ 8 ------------
# eps = 0.05791127681732178
# statistic = 0.7351191783966217 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.0119583665940743
# relative_error_metric = 0.47855370630744265
#
# ------------ 9 ------------
# eps = 0.03845423460006714
# statistic = 0.5225753469615448 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.6773388665542731
# relative_error_metric = 0.14648756227298432
#
# ------------ 10 ------------
# eps = 0.02872571349143982
# statistic = 0.45564834425047224 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.40770866444141224
# relative_error_metric = 0.009702443105688028
#
# ------------ 11 ------------
# eps = 0.02386145293712616
# statistic = 0.43038562384152307 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.18499800938775568
# relative_error_metric = 0.0473283739612098
#
# ------------ 12 ------------
# eps = 0.02629358321428299
# statistic = 0.44237836811677966 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.08841008238129125
# relative_error_metric = 0.019852613470758337
#
# ------------ 13 ------------
# eps = 0.027509648352861404
# statistic = 0.44885053940020053 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.043249126481850794
# relative_error_metric = 0.005328847346071528
#
# ------------ 14 ------------
# eps = 0.028117680922150612
# statistic = 0.4522083315712135 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.02186092977008471
# relative_error_metric = 0.002124165506245874
#
# ------------ 15 ------------
# eps = 0.027813664637506008
# statistic = 0.4505192092615083 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.0108710520586471
# relative_error_metric = 0.0016181015338715958
#
# ------------ 16 ------------
# eps = 0.02796567277982831
# statistic = 0.4513612073614291 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.005450338758418558
# relative_error_metric = 0.00024910429352834854
# =======> statistic within required accuracy at 0.99 CL in 220.95435447292402 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 425.3861392720137 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# Computing exclusion limits for fpd with std deformation.
#
# ======================================================
# =============== fpd - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 108.19475790561339 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.984894788158137
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 9.983894930805306 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8421688833822605
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 6.876297324335107 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7748552440688685
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 2.934300049359202 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.509482267543254
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 0.9909273600267698 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8290945586374131
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 0.5060472188396598 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.209397932990457
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.4024415231382446 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.018911480642510997
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 0.44428765462264813 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.07996772098139991
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 0.4210045613702631 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.026180326245330524
#
# ------------ 10 ------------
# eps = 0.0439453125
# statistic = 0.4111472522484985 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.002489580541371421
#
# ------------ 11 ------------
# eps = 0.04150390625
# statistic = 0.40665205872930127 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.05714285714285714
# relative_error_metric = 0.008503867975551986
#
# ------------ 12 ------------
# eps = 0.042724609375
# statistic = 0.4088638786149959 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.028169014084507043
# relative_error_metric = 0.0030795585205472126
#
# ------------ 13 ------------
# eps = 0.0433349609375
# statistic = 0.40999659620543505 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.013986013986013986
# relative_error_metric = 0.00031298875116075815
#
# ------------ 14 ------------
# eps = 0.04364013671875
# statistic = 0.41056967868468264 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.007017543859649123
# relative_error_metric = 0.0010838089125613823
# =======> statistic within required accuracy at 0.95 CL in 193.65679462300614 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.043487548828125
# statistic = 0.41028257645161575 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.965509938583487
# relative_error_metric = 0.09510091150228911
#
# ------------ 2 ------------
# eps = 2.5217437744140625
# statistic = 111.91262099199264 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.9321892751985248
# relative_error_metric = 1.9839361607519095
#
# ------------ 3 ------------
# eps = 1.2826156616210938
# statistic = 10.369577364984501 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.8688260506860743
# relative_error_metric = 1.8331924830581512
#
# ------------ 4 ------------
# eps = 0.6630516052246094
# statistic = 7.154409058803414 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.7537996382582404
# relative_error_metric = 1.762677314917037
#
# ------------ 5 ------------
# eps = 0.3532695770263672
# statistic = 3.509882958449411 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.5615700790808356
# relative_error_metric = 1.5443233757063402
#
# ------------ 6 ------------
# eps = 0.1983785629272461
# statistic = 1.4139201998652782 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.280799637245431
# relative_error_metric = 1.0322618724066557
#
# ------------ 7 ------------
# eps = 0.12093305587768555
# statistic = 0.7217027824929586 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.9420413845105347
# relative_error_metric = 0.4611511754767
#
# ------------ 8 ------------
# eps = 0.08221030235290527
# statistic = 0.5216902070939555 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.6161243515453847
# relative_error_metric = 0.14480131291259518
#
# ------------ 9 ------------
# eps = 0.06284892559051514
# statistic = 0.4559719106144012 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.3641530691748457
# relative_error_metric = 0.010412296117734856
#
# ------------ 10 ------------
# eps = 0.05316823720932007
# statistic = 0.4307553643053909 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.16688372905476395
# relative_error_metric = 0.04647012386910456
#
# ------------ 11 ------------
# eps = 0.0580085813999176
# statistic = 0.4427551440387161 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.0801000171380451
# relative_error_metric = 0.019001351182529685
#
# ------------ 12 ------------
# eps = 0.06042875349521637
# statistic = 0.4492093560563859 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.039263751771570855
# relative_error_metric = 0.004529759239173375
#
# ------------ 13 ------------
# eps = 0.06163883954286575
# statistic = 0.4525518290976886 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.019826491495934816
# relative_error_metric = 0.002883476128946688
#
# ------------ 14 ------------
# eps = 0.06103379651904106
# statistic = 0.4508709245650706 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.00986435187582268
# relative_error_metric = 0.0008377176109177814
# =======> statistic within required accuracy at 0.99 CL in 195.95664739701897 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 389.6134775420651 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# Computing exclusion limits for fpd with both deformation.
#
# ======================================================
# =============== fpd - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 951.3680696871598 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9982763843806122
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 220.24200603349365 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.992565221304636
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 59.7944076424636 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9727512249980645
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 16.239467528082514 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9014690740606777
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 4.335679415753945 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.654326297658691
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.2357555994053186 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.003269239434315
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.5539574524030031 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.2983821981019009
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.4168372937971061 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.016233759909611224
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 0.38443487456521525 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.0646649013888385
#
# ------------ 10 ------------
# eps = 0.0146484375
# statistic = 0.3979952496451665 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.030019522131217554
#
# ------------ 11 ------------
# eps = 0.01708984375
# statistic = 0.40673414991259255 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.008302021095129706
#
# ------------ 12 ------------
# eps = 0.018310546875
# statistic = 0.41161212210218046 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.003619604266178708
#
# ------------ 13 ------------
# eps = 0.0177001953125
# statistic = 0.40913013407953264 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.0024285636169661382
#
# ------------ 14 ------------
# eps = 0.01800537109375
# statistic = 0.4103603287426067 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.017094017094017096
# relative_error_metric = 0.0005737778316288049
#
# ------------ 15 ------------
# eps = 0.017852783203125
# statistic = 0.4097425377289196 - next threshold = 0.4101249406132395 at 0.95 CL
# relative_error_eps = 0.00851063829787234
# relative_error_metric = 0.0009328407198030339
# =======> statistic within required accuracy at 0.95 CL in 209.19859360391274 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0179290771484375
# statistic = 0.41005075896931126 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.9857079868026941
# relative_error_metric = 0.09566480477459154
#
# ------------ 2 ------------
# eps = 2.5089645385742188
# statistic = 959.128935425133 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.9716187859482797
# relative_error_metric = 1.9981189741398406
#
# ------------ 3 ------------
# eps = 1.2634468078613281
# statistic = 224.92477963262257 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.9440317947038597
# relative_error_metric = 1.991991184004498
#
# ------------ 4 ------------
# eps = 0.6406879425048828
# statistic = 62.60654461884223 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.8911107571567165
# relative_error_metric = 1.9713755422771169
#
# ------------ 5 ------------
# eps = 0.32930850982666016
# statistic = 17.91455727923938 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.7934661704728032
# relative_error_metric = 1.901719797375143
#
# ------------ 6 ------------
# eps = 0.17361879348754883
# statistic = 5.292188486885722 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.6255958974869618
# relative_error_metric = 1.685729110314766
#
# ------------ 7 ------------
# eps = 0.09577393531799316
# statistic = 1.7488688503104766 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.3692664157431773
# relative_error_metric = 1.1795915308612919
#
# ------------ 8 ------------
# eps = 0.05685150623321533
# statistic = 0.787696760223659 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 1.040976877276604
# relative_error_metric = 0.5431198749239005
#
# ------------ 9 ------------
# eps = 0.037390291690826416
# statistic = 0.5378175066098244 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.7035949596220256
# relative_error_metric = 0.17505140345894904
#
# ------------ 10 ------------
# eps = 0.027659684419631958
# statistic = 0.46100373944675566 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.4268862296978829
# relative_error_metric = 0.021386521456417854
#
# ------------ 11 ------------
# eps = 0.02279438078403473
# statistic = 0.4325610508477413 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.19286071859453058
# relative_error_metric = 0.04228903942010842
#
# ------------ 12 ------------
# eps = 0.025227032601833344
# statistic = 0.4460100547866275 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.09199481286808808
# relative_error_metric = 0.01167718907450607
#
# ------------ 13 ------------
# eps = 0.02644335851073265
# statistic = 0.4533097120655149 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.04708018974539957
# relative_error_metric = 0.004556757185431535
#
# ------------ 14 ------------
# eps = 0.025835195556282997
# statistic = 0.4496111099782461 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.0232662500064578
# relative_error_metric = 0.0036358048113684233
#
# ------------ 15 ------------
# eps = 0.026139277033507824
# statistic = 0.45144815287053314 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.011701185681085932
# relative_error_metric = 0.00044171529324146575
#
# ------------ 16 ------------
# eps = 0.02598723629489541
# statistic = 0.45052657506685145 - next threshold = 0.4512487853491462 at 0.99 CL
# relative_error_eps = 0.005833528041844605
# relative_error_metric = 0.0016017520859332006
# =======> statistic within required accuracy at 0.99 CL in 228.0074096249882 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 437.20603803615086 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# Computing exclusion limits for kpd with mean deformation.
#
# ======================================================
# =============== kpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# statistic = 47.39502197711109 - next threshold = -0.011921334883213675 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.0010063786220513
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 11.19927150045541 - next threshold = -0.011921334883213675 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.004262433804888
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 2.4445188490864744 - next threshold = -0.011921334883213675 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.0196026425474964
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 0.23178044579497126 - next threshold = -0.011921334883213675 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.216890441042462
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = -0.3484921225807014 - next threshold = -0.011921334883213675 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = -1.867692677547622
#
# ------------ 6 ------------
# eps = 0.234375
# statistic = -0.1018271432409179 - next threshold = -0.011921334883213675 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = -1.5807826151237243
#
# ------------ 7 ------------
# eps = 0.2734375
# statistic = 0.05408306654652861 - next threshold = -0.011921334883213675 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 3.1310099858717586
#
# ------------ 8 ------------
# eps = 0.25390625
# statistic = -0.026592145761394903 - next threshold = -0.011921334883213675 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = -0.7618532852722033
#
# ------------ 9 ------------
# eps = 0.263671875
# statistic = 0.013065026760017417 - next threshold = -0.011921334883213675 at 0.95 CL
# relative_error_eps = 0.03773584905660377
# ...
# eps = 0.01840994693338871
# statistic = 1.2302790307329063 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.06840560359970566
# relative_error_metric = 0.02700812924458652
#
# ------------ 14 ------------
# eps = 0.017801099456846714
# statistic = 1.205574609869228 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.034797894544939194
# relative_error_metric = 0.006725055845883186
#
# ------------ 15 ------------
# eps = 0.017496675718575716
# statistic = 1.1932666324066656 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.017248890999961148
# relative_error_metric = 0.0035366075176824973
#
# ------------ 16 ------------
# eps = 0.017648887587711215
# statistic = 1.1994168454123484 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.008661797098484459
# relative_error_metric = 0.0016042494206968377
# =======> statistic within required accuracy at 0.99 CL in 210.21688168495893 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 425.18789905007 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# Computing exclusion limits for swd with std deformation.
#
# ======================================================
# =============== swd - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 28.387537659848316 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8652541468618273
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 13.391410632816763 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7247449534712784
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 11.214979189120305 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6756590221910659
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 6.5117842593668875 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4723050422039536
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 3.466817536583434 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.111744312799976
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.8731190852127995 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6172474386419929
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.1121700016305425 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.11662265837601898
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.7851989994039968 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2303493172268509
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 0.9393543583208975 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.052108650877034875
#
# ------------ 10 ------------
# eps = 0.0341796875
# statistic = 1.0241498104545605 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.034301497296972586
#
# ------------ 11 ------------
# eps = 0.03173828125
# statistic = 0.9812782920249878 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.008457081314917656
#
# ------------ 12 ------------
# eps = 0.032958984375
# statistic = 1.002604798804541 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.03773584905660377
# relative_error_metric = 0.013043273216388346
#
# ------------ 13 ------------
# eps = 0.0323486328125
# statistic = 0.9919127944433264 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.01904761904761905
# relative_error_metric = 0.002321960511008231
#
# ------------ 14 ------------
# eps = 0.03204345703125
# statistic = 0.9865882469351572 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.009478672985781991
# relative_error_metric = 0.0030604546166149733
# =======> statistic within required accuracy at 0.95 CL in 191.92664845613763 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.032196044921875
# statistic = 0.9892487016516214 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.9744079565784287
# relative_error_metric = 0.19046182314195426
#
# ------------ 2 ------------
# eps = 2.5160980224609375
# statistic = 28.78594408273245 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.949462590940391
# relative_error_metric = 1.8402459102158797
#
# ------------ 3 ------------
# eps = 1.2741470336914062
# statistic = 13.381981205610533 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.9014162651481967
# relative_error_metric = 1.6714575281910868
#
# ------------ 4 ------------
# eps = 0.6531715393066406
# statistic = 11.516187634673598 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.8120947318620766
# relative_error_metric = 1.6232423503611086
#
# ------------ 5 ------------
# eps = 0.3426837921142578
# statistic = 7.058983832410676 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.6564654404843675
# relative_error_metric = 1.4198522829417661
#
# ------------ 6 ------------
# eps = 0.1874399185180664
# statistic = 4.097416619901932 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.4136471201233147
# relative_error_metric = 1.095362124757103
#
# ------------ 7 ------------
# eps = 0.1098179817199707
# statistic = 2.518022100639335 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.093158734155964
# relative_error_metric = 0.7108179652624619
#
# ------------ 8 ------------
# eps = 0.07100701332092285
# statistic = 1.7301829497032746 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.75212826169822
# relative_error_metric = 0.36389854093637997
#
# ------------ 9 ------------
# eps = 0.051601529121398926
# statistic = 1.3482982481446795 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.46315145566153826
# relative_error_metric = 0.11847314813793036
#
# ------------ 10 ------------
# eps = 0.04189878702163696
# statistic = 1.1644731643053372 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.20754458380480342
# relative_error_metric = 0.027960639656546153
#
# ------------ 11 ------------
# eps = 0.046750158071517944
# statistic = 1.2555485172083274 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.10945129792087246
# relative_error_metric = 0.047332476048819856
#
# ------------ 12 ------------
# eps = 0.044324472546577454
# statistic = 1.209776800544793 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.056265224420597115
# relative_error_metric = 0.010204564924587338
#
# ------------ 13 ------------
# eps = 0.04311162978410721
# statistic = 1.1870641256101797 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.02774237940944018
# relative_error_metric = 0.008748033536312452
#
# ------------ 14 ------------
# eps = 0.04371805116534233
# statistic = 1.198405652107751 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.013968066555217882
# relative_error_metric = 0.0007608233563488601
#
# ------------ 15 ------------
# eps = 0.04341484047472477
# statistic = 1.1927312350455803 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.006959729785396752
# relative_error_metric = 0.003985388702121081
# =======> statistic within required accuracy at 0.99 CL in 203.94261751300655 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 395.8693003170192 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# Computing exclusion limits for swd with both deformation.
#
# ======================================================
# =============== swd - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 112.99842713229462 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9652731185471972
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 56.78199164352634 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9314810588113787
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 30.87363434399606 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.875767551933555
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 16.018403938832034 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.767259797956886
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 8.194060859620375 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5689688569750573
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 4.244813903047988 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.243766366904266
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 2.2918314352499523 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7936867209232777
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 1.3513968234473783 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.3090842658455414
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 0.9216889529616069 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.07107548377488974
#
# ------------ 10 ------------
# eps = 0.0146484375
# statistic = 1.1295511755524215 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.1320699373501405
#
# ------------ 11 ------------
# eps = 0.01220703125
# statistic = 1.0232141004176456 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.033387695772050155
#
# ------------ 12 ------------
# eps = 0.010986328125
# statistic = 0.9717475722783968 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.018216657822010707
#
# ------------ 13 ------------
# eps = 0.0115966796875
# statistic = 0.9973180180461344 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.007756422144830592
#
# ------------ 14 ------------
# eps = 0.01129150390625
# statistic = 0.9844908837527974 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.02666666666666667
# relative_error_metric = 0.005188583136141675
#
# ------------ 15 ------------
# eps = 0.011444091796875
# statistic = 0.9908942096429488 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.013422818791946308
# relative_error_metric = 0.0012945442946621394
#
# ------------ 16 ------------
# eps = 0.0113677978515625
# statistic = 0.9876899767884948 - next threshold = 0.9896122829526833 at 0.95 CL
# relative_error_eps = 0.006688963210702341
# relative_error_metric = 0.0019443725962667532
# =======> statistic within required accuracy at 0.95 CL in 214.8679955599364 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.01140594482421875
# statistic = 0.9892914468605365 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.9908960120574557
# relative_error_metric = 0.1904190060751029
#
# ------------ 2 ------------
# eps = 2.5057029724121094
# statistic = 113.28278481671089 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.9818745311398889
# relative_error_metric = 1.9581589341377723
#
# ------------ 3 ------------
# eps = 1.258554458618164
# statistic = 57.1271888104482 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.964074644238351
# relative_error_metric = 1.9178739318232225
#
# ------------ 4 ------------
# eps = 0.6349802017211914
# statistic = 31.324023405386587 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.9294171455550064
# relative_error_metric = 1.8527136110351803
#
# ------------ 5 ------------
# eps = 0.3231930732727051
# statistic = 16.546839554470388 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.8636464041156897
# relative_error_metric = 1.7300559741993513
#
# ------------ 6 ------------
# eps = 0.16729950904846191
# statistic = 8.752121095931779 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.7446984503932386
# relative_error_metric = 1.518576674441454
#
# ------------ 7 ------------
# eps = 0.08935272693634033
# statistic = 4.811421509040887 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.5471974917921263
# relative_error_metric = 1.202855039375943
#
# ------------ 8 ------------
# eps = 0.05037933588027954
# statistic = 2.852671331573902 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 1.2615752687912714
# relative_error_metric = 0.817338000199189
#
# ------------ 9 ------------
# eps = 0.030892640352249146
# statistic = 1.8922598823400532 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.9213875805411804
# relative_error_metric = 0.4497222980565085
#
# ------------ 10 ------------
# eps = 0.021149292588233948
# statistic = 1.4267571702338644 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.5985732888735299
# relative_error_metric = 0.17472635963043978
#
# ------------ 11 ------------
# eps = 0.01627761870622635
# statistic = 1.2024493778000906 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.3519542472666106
# relative_error_metric = 0.0041293920253311165
#
# ------------ 12 ------------
# eps = 0.01384178176522255
# statistic = 1.093987798979339 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.16174538024505528
# relative_error_metric = 0.09034015873242086
#
# ------------ 13 ------------
# eps = 0.01505970023572445
# statistic = 1.147824053467582 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.0777295896153701
# relative_error_metric = 0.04235686970825755
#
# ------------ 14 ------------
# eps = 0.0156686594709754
# statistic = 1.17504614987268 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.038123954964214245
# relative_error_metric = 0.0189232387288228
#
# ------------ 15 ------------
# eps = 0.015973139088600874
# statistic = 1.1887263813478195 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.018882013226635633
# relative_error_metric = 0.007348727480118942
#
# ------------ 16 ------------
# eps = 0.01612537889741361
# statistic = 1.19558264544786 - next threshold = 1.1974942238152133 at 0.99 CL
# relative_error_eps = 0.00939664969734996
# relative_error_metric = 0.0015975904425853172
# =======> statistic within required accuracy at 0.99 CL in 214.77903376682661 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 429.6470639500767 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# dict_keys(['2024-04-12T01:50:21.783624', '2024-04-12T01:56:10.477491', '2024-04-12T02:01:24.214402', '2024-04-12T02:06:57.021336', '2024-04-12T02:14:02.410413', '2024-04-12T02:20:32.027183', '2024-04-12T02:27:49.242242', '2024-04-12T02:39:59.765353', '2024-04-12T02:49:47.440310', '2024-04-12T03:03:02.353916', '2024-04-12T03:11:32.426683', '2024-04-12T03:19:13.003140', '2024-04-12T03:28:03.782726', '2024-04-12T03:37:53.998312', '2024-04-12T03:47:04.913596', '2024-04-12T03:57:16.139974', '2024-04-12T04:04:21.334570', '2024-04-12T04:10:57.209526'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "std", "both"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 0.005
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.61147753405385 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -423.25506360013344], [0.99, [9900, 100], -398.269544133443]]
# Null distribution computed in 38.87554239598103 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.557367200031877 seconds.
# statistic = 499.5296979177197 - next threshold = -423.25506360013344 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 24.19637327071632
#
# ------------ 2 ------------
# eps = 0.0025
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.46348165301606 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -90.96009208548976], [0.99, [9900, 100], -78.55539477450905]]
# Null distribution computed in 38.731169065926224 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 19.077346839010715 seconds.
# statistic = 129.54835236642296 - next threshold = -90.96009208548976 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 11.428783927886373
#
# ------------ 3 ------------
# eps = 0.00125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.90323860920034 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.001250.json
# ThresholdS: [[0.95, [9500, 500], -15.298490585156769], [0.99, [9900, 100], -9.130110476346205]]
# Null distribution computed in 39.19478437304497 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.834946576040238 seconds.
# statistic = 34.72004245935473 - next threshold = -15.298490585156769 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 5.15082763401234
#
# ------------ 4 ------------
# eps = 0.000625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.46887732995674 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.000625.json
# ThresholdS: [[0.95, [9500, 500], -0.07669160673560532], [0.99, [9900, 100], 3.01598335382962]]
# Null distribution computed in 38.74301385390572 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.896312693832442 seconds.
# statistic = 9.846486726767356 - next threshold = -0.07669160673560532 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.0313994739064114
#
# ------------ 5 ------------
# eps = 0.0003125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.75123699987307 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.000313.json
# ThresholdS: [[0.95, [9500, 500], 1.8494656482750973], [0.99, [9900, 100], 3.394855304627479]]
# Null distribution computed in 39.01849790196866 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.475267432862893 seconds.
# statistic = 3.044859610847257 - next threshold = 1.8494656482750973 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.48848161872532214
#
# ------------ 6 ------------
# eps = 0.00015625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.907869757153094 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.000156.json
# ThresholdS: [[0.95, [9500, 500], 1.39652816719439], [0.99, [9900, 100], 2.168472680709778]]
# Null distribution computed in 39.17995302705094 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.31209089094773 seconds.
# statistic = 1.0528338518631177 - next threshold = 1.39652816719439 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.28063986675479097
#
# ------------ 7 ------------
# eps = 0.000234375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.34878330701031 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.000234.json
# ThresholdS: [[0.95, [9500, 500], 1.7409478610693991], [0.99, [9900, 100], 2.8994252498705353]]
# Null distribution computed in 38.62871614401229 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.487361314939335 seconds.
# statistic = 1.9314477448542593 - next threshold = 1.7409478610693991 at 0.95 CL
# relative_error_eps = 0.3999999999999999
# relative_error_metric = 0.10374692937633379
#
# ------------ 8 ------------
# eps = 0.0001953125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.61116712982766 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.000195.json
# ThresholdS: [[0.95, [9500, 500], 1.5983829247108392], [0.99, [9900, 100], 2.563389279508315]]
# Null distribution computed in 38.88174769608304 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.491065653972328 seconds.
# statistic = 1.4627910515111981 - next threshold = 1.5983829247108392 at 0.95 CL
# relative_error_eps = 0.18181818181818174
# relative_error_metric = 0.08858815229246292
#
# ------------ 9 ------------
# eps = 0.00021484375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.28016072092578 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.000215.json
# ThresholdS: [[0.95, [9500, 500], 1.6772187107114962], [0.99, [9900, 100], 2.738767343161647]]
# Null distribution computed in 38.543748297030106 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.642396220006049 seconds.
# statistic = 1.6897819614585083 - next threshold = 1.6772187107114962 at 0.95 CL
# relative_error_eps = 0.09523809523809518
# relative_error_metric = 0.007462576916514384
#
# ------------ 10 ------------
# eps = 0.00020507812500000002
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.40545661607757 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.000205.json
# ThresholdS: [[0.95, [9500, 500], 1.639641783739999], [0.99, [9900, 100], 2.6529183311176725]]
# Null distribution computed in 38.676411177031696 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.343543314142153 seconds.
# statistic = 1.5744521473531887 - next threshold = 1.639641783739999 at 0.95 CL
# relative_error_eps = 0.04651162790697665
# relative_error_metric = 0.04056486075665984
#
# ------------ 11 ------------
# eps = 0.00020996093750000002
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.19658212619834 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.000210.json
# ThresholdS: [[0.95, [9500, 500], 1.658890488835853], [0.99, [9900, 100], 2.6963028420853323]]
# Null distribution computed in 38.46331534697674 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.547770770965144 seconds.
# statistic = 1.6316584646393961 - next threshold = 1.658890488835853 at 0.95 CL
# relative_error_eps = 0.022988505747126325
# relative_error_metric = 0.016551660274007722
#
# ------------ 12 ------------
# eps = 0.00021240234375000003
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.25240202900022 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_mean_0.000212.json
# ThresholdS: [[0.95, [9500, 500], 1.6681696601762008], [0.99, [9900, 100], 2.717650093921647]]
# Null distribution computed in 38.519481615163386 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.296376079088077 seconds.
# statistic = 1.6606055656361505 - next threshold = 1.6681696601762008 at 0.95 CL
# relative_error_eps = 0.011428571428571312
# relative_error_metric = 0.004544671254097323
#
# ------------ 13 ------------
# eps = 0.000213623046875
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# ...
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.802096873987466 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_both_0.000257.json
# ThresholdS: [[0.95, [9500, 500], 1.8992707857787603], [0.99, [9900, 100], 3.2225332521602086]]
# Null distribution computed in 39.06399129703641 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.80763964401558 seconds.
# statistic = 3.1454066756657864 - next threshold = 3.2225332521602086 at 0.99 CL
# relative_error_eps = 0.07218740694469634
# relative_error_metric = 0.024223399519647516
#
# ------------ 11 ------------
# eps = 0.0002662199735641479
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.91849246900529 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_both_0.000266.json
# ThresholdS: [[0.95, [9500, 500], 1.906232808998765], [0.99, [9900, 100], 3.279074306566144]]
# Null distribution computed in 39.18722201301716 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.86453097499907 seconds.
# statistic = 3.327415954863916 - next threshold = 3.279074306566144 at 0.99 CL
# relative_error_eps = 0.03675705254997636
# relative_error_metric = 0.014634593069787686
#
# ------------ 12 ------------
# eps = 0.0002614155411720275
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 39.12532466114499 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_both_0.000261.json
# ThresholdS: [[0.95, [9500, 500], 1.9033347525117579], [0.99, [9900, 100], 3.2513864744434087]]
# Null distribution computed in 39.40047671296634 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.645062600960955 seconds.
# statistic = 3.235831600291965 - next threshold = 3.2513864744434087 at 0.99 CL
# relative_error_eps = 0.018211178959485576
# relative_error_metric = 0.004795545323818341
#
# ------------ 13 ------------
# eps = 0.0002638177573680877
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 38.89603575388901 seconds.
# Saving lr to ../results_leonardo/5D_100K/null_hypothesis/LR_both_0.000264.json
# ThresholdS: [[0.95, [9500, 500], 1.9049295476064698], [0.99, [9900, 100], 3.2653760923247153]]
# Null distribution computed in 39.166768931783736 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 13.945227392017841 seconds.
# statistic = 3.281478847831467 - next threshold = 3.2653760923247153 at 0.99 CL
# relative_error_eps = 0.009147234962966447
# relative_error_metric = 0.004919233938721648
# =======> statistic within required accuracy at 0.99 CL in 850.9336748570204 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1703.1444739431608 seconds.
# Saving results in the file ../results_leonardo/5D_100K/exclusion_limits.json
# dict_keys(['2024-04-12T01:50:21.783624', '2024-04-12T01:56:10.477491', '2024-04-12T02:01:24.214402', '2024-04-12T02:06:57.021336', '2024-04-12T02:14:02.410413', '2024-04-12T02:20:32.027183', '2024-04-12T02:27:49.242242', '2024-04-12T02:39:59.765353', '2024-04-12T02:49:47.440310', '2024-04-12T03:03:02.353916', '2024-04-12T03:11:32.426683', '2024-04-12T03:19:13.003140', '2024-04-12T03:28:03.782726', '2024-04-12T03:37:53.998312', '2024-04-12T03:47:04.913596', '2024-04-12T03:57:16.139974', '2024-04-12T04:04:21.334570', '2024-04-12T04:10:57.209526', '2024-04-12T04:18:06.885095', '2024-04-12T04:46:07.493341', '2024-04-12T05:12:01.329347'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_std = results_df[results_df["Deformation"] == "std"]
results_df_both = results_df[results_df["Deformation"] == "both"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 18        lr        mean    5  10000               100000
# 9         ks        mean    5  10000               100000
# 12       sks        mean    5  10000               100000
# 15       swd        mean    5  10000               100000
# 3        fpd        mean    5  10000               100000
# 0         fn        mean    5  10000               100000
# 6        kpd        mean    5  10000               100000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 18                             0.00021                             0.00034
# 9                              0.00274                             0.00372
# 12                             0.00654                             0.00955
# 15                             0.01232                             0.01757
# 3                              0.01900                             0.02789
# 0                              0.02815                             0.03589
# 6                              0.25757                             0.26712
#
#     $t^{\mu}$ (s)
# 18           1680
# 9             510
# 12            590
# 15            425
# 3             425
# 0             348
# 6             730
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 18        lr                             0.00021
# 9         ks                             0.00274
# 12       sks                             0.00654
# 15       swd                             0.01232
# 3        fpd                             0.01900
# 0         fn                             0.02815
# 6        kpd                             0.25757
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 18                             0.00034           1680
# 9                              0.00372            510
# 12                             0.00955            590
# 15                             0.01757            425
# 3                              0.02789            425
# 0                              0.03589            348
# 6                              0.26712            730

# %%
sorted_df_std = results_df_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma}$ (s)"}, inplace=True)
display(sorted_df_std)
sorted_df_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 19        lr         std    5  10000               100000
# 10        ks         std    5  10000               100000
# 13       sks         std    5  10000               100000
# 16       swd         std    5  10000               100000
# 4        fpd         std    5  10000               100000
# 1         fn         std    5  10000               100000
# 7        kpd         std    5  10000               100000
#
#     $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 19                                0.00041
# 10                                0.00889
# 13                                0.01915
# 16                                0.03220
# 4                                 0.04349
# 1                                 0.05173
# 7                                 3.40820
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 19                                0.00065              1553
# 10                                0.01152               460
# 13                                0.02652               550
# 16                                0.04357               395
# 4                                 0.06134               389
# 1                                 0.07377               313
# 7                                 3.45600               587
#    Statistic  $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 19        lr                                0.00041
# 10        ks                                0.00889
# 13       sks                                0.01915
# 16       swd                                0.03220
# 4        fpd                                0.04349
# 1         fn                                0.05173
# 7        kpd                                3.40820
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 19                                0.00065              1553
# 10                                0.01152               460
# 13                                0.02652               550
# 16                                0.04357               395
# 4                                 0.06134               389
# 1                                 0.07377               313
# 7                                 3.45600               587

# %%
sorted_df_both = results_df_both.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_both.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\sigma}$ (s)"}, inplace=True)
display(sorted_df_both)
sorted_df_both.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_both)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 20        lr        both    5  10000               100000
# 11        ks        both    5  10000               100000
# 14       sks        both    5  10000               100000
# 17       swd        both    5  10000               100000
# 5        fpd        both    5  10000               100000
# 2         fn        both    5  10000               100000
# 8        kpd        both    5  10000               100000
#
#     $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 20                                    0.00016
# 11                                    0.00251
# 14                                    0.00593
# 17                                    0.01141
# 5                                     0.01793
# 2                                     0.02647
# 8                                     0.26001
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 20                                    0.00026                  1703
# 11                                    0.00339                   530
# 14                                    0.00856                   611
# 17                                    0.01620                   429
# 5                                     0.02606                   437
# 2                                     0.03330                   332
# 8                                     0.27021                   794
#    Statistic  $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 20        lr                                    0.00016
# 11        ks                                    0.00251
# 14       sks                                    0.00593
# 17       swd                                    0.01141
# 5        fpd                                    0.01793
# 2         fn                                    0.02647
# 8        kpd                                    0.26001
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 20                                    0.00026                  1703
# 11                                    0.00339                   530
# 14                                    0.00856                   611
# 17                                    0.01620                   429
# 5                                     0.02606                   437
# 2                                     0.03330                   332
# 8                                     0.27021                   794

# %%
result_table = sorted_df_mean.merge(sorted_df_std, on='Statistic', how='outer').merge(sorted_df_both, on='Statistic', how='outer').merge(times_df, on='Statistic', how='outer')
result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fpd","$d_{\\mathrm{FPD}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("kpd","$d_{\\mathrm{KPD}}$")
display(result_table)
print(result_table.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g"))
# Out:
#                     Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 0  $\overline{\|\cdot\|}_{F}$                             0.02815
# 1          $d_{\mathrm{FPD}}$                             0.01900
# 2          $d_{\mathrm{KPD}}$                             0.25757
# 3              $\overline{D}$                             0.00274
# 4          $t_{\mathrm{LLR}}$                             0.00021
# 5             $\widetilde{D}$                             0.00654
# 6             $\widetilde{W}$                             0.01232
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)  \
# 0                             0.03589            348
# 1                             0.02789            425
# 2                             0.26712            730
# 3                             0.00372            510
# 4                             0.00034           1680
# 5                             0.00955            590
# 6                             0.01757            425
#
#    $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 0                                0.05173
# 1                                0.04349
# 2                                3.40820
# 3                                0.00889
# 4                                0.00041
# 5                                0.01915
# 6                                0.03220
#
#    $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)  \
# 0                                0.07377               313
# 1                                0.06134               389
# 2                                3.45600               587
# 3                                0.01152               460
# 4                                0.00065              1553
# 5                                0.02652               550
# 6                                0.04357               395
#
#    $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 0                                    0.02647
# 1                                    0.01793
# 2                                    0.26001
# 3                                    0.00251
# 4                                    0.00016
# 5                                    0.00593
# 6                                    0.01141
#
#    $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)  \
# 0                                    0.03330                   332
# 1                                    0.02606                   437
# 2                                    0.27021                   794
# 3                                    0.00339                   530
# 4                                    0.00026                  1703
# 5                                    0.00856                   611
# 6                                    0.01620                   429
#
#   $t^{\mathrm{null}}$ (s)
# 0                      33
# 1                     270
# 2                   30466
# 3                     102
# 4                       -
# 5                     786
# 6                     353
# \begin{tabular}{l|llr|llr|llr|r}
# \toprule
# Statistic & $\epsilon^{\mu}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu}_{99\%\mathrm{CL}}$ & $t^{\mu}$ (s) & $\epsilon^{\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\sigma}_{99\%\mathrm{CL}}$ & $t^{\sigma}$ (s) & $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$ & $t^{\mu-\sigma}$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $\overline{\|\cdot\|}_{F}$ & 0.028 & 0.036 & 348 & 0.052 & 0.074 & 313 & 0.026 & 0.033 & 332 & 33 \\
# $d_{\mathrm{FPD}}$ & 0.019 & 0.028 & 425 & 0.043 & 0.061 & 389 & 0.018 & 0.026 & 437 & 270 \\
# $d_{\mathrm{KPD}}$ & 0.26 & 0.27 & 730 & 3.4 & 3.5 & 587 & 0.26 & 0.27 & 794 & 30466 \\
# $\overline{D}$ & 0.0027 & 0.0037 & 510 & 0.0089 & 0.012 & 460 & 0.0025 & 0.0034 & 530 & 102 \\
# $t_{\mathrm{LLR}}$ & 0.00021 & 0.00034 & 1680 & 0.00041 & 0.00065 & 1553 & 0.00016 & 0.00026 & 1703 & - \\
# $\widetilde{D}$ & 0.0065 & 0.0095 & 590 & 0.019 & 0.027 & 550 & 0.0059 & 0.0086 & 611 & 786 \\
# $\widetilde{W}$ & 0.012 & 0.018 & 425 & 0.032 & 0.044 & 395 & 0.011 & 0.016 & 429 & 353 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Fixed $\epsilon$

# %%
fpd_results = {5: {10_000: [[0.68, 0.00010175550386551708], 
                            [0.95, 0.00015583746551772079], 
                            [0.99, 0.00022347410983350775]],
                   50_000: [[0.68, 4.5226688115357585e-05], 
                            [0.95, 5.398123973119404e-05], 
                            [0.99, 6.354077850007809e-05]],
                   100_000 : [[0.68, 3.725127064668703e-05], 
                              [0.95, 4.0825583153507725e-05], 
                              [0.99, 4.465564257168013e-05]],
                   200_000 : [[0.68, 3.3691504288769034e-05], 
                              [0.95, 3.5351867696872585e-05], 
                              [0.99, 3.68684570537516e-05]]},
               20: {10_000: [[0.68, 0.0006669445748113884], 
                             [0.95, 0.0013217846893085318], 
                             [0.99, 0.0019605548728214763]],
                    50_000: [[0.68, 0.00031117601754665936], 
                             [0.95, 0.00040269921440860503], 
                             [0.99, 0.000502723348035641]],
                    100_000 : [[0.68, 0.00015735387007512796], 
                               [0.95, 0.0001991294338873111], 
                               [0.99, 0.00028358152805583374]]},
               100: {10_000: [[0.68, 0.0060367495598200515], 
                              [0.95, 0.009021833572706342], 
                              [0.99, 0.011125954730711617]],
                     50_000: [[0.68, 0.0012229712948642107], 
                              [0.95, 0.001787009273603958], 
                              [0.99, 0.0022351123346437667]],
                    100_000 : [[0.68, 0.000817842570244682], 
                               [0.95, 0.0011978135448655475], 
                               [0.99, 0.001414743609381014]]}}
fpd_results
# Out:
# {5: {10000: [[0.68, 0.00010175550386551708],
#    [0.95, 0.00015583746551772079],
#    [0.99, 0.00022347410983350775]],
#   50000: [[0.68, 4.5226688115357585e-05],
#    [0.95, 5.398123973119404e-05],
#    [0.99, 6.354077850007809e-05]],
#   100000: [[0.68, 3.725127064668703e-05],
#    [0.95, 4.0825583153507725e-05],
#    [0.99, 4.465564257168013e-05]],
#   200000: [[0.68, 3.3691504288769034e-05],
#    [0.95, 3.5351867696872585e-05],
#    [0.99, 3.68684570537516e-05]]},
#  20: {10000: [[0.68, 0.0006669445748113884],
#    [0.95, 0.0013217846893085318],
#    [0.99, 0.0019605548728214763]],
#   50000: [[0.68, 0.00031117601754665936],
#    [0.95, 0.00040269921440860503],
#    [0.99, 0.000502723348035641]],
#   100000: [[0.68, 0.00015735387007512796],
#    [0.95, 0.0001991294338873111],
#    [0.99, 0.00028358152805583374]]},
#  100: {10000: [[0.68, 0.0060367495598200515],
#    [0.95, 0.009021833572706342],
#    [0.99, 0.011125954730711617]],
#   50000: [[0.68, 0.0012229712948642107],
#    [0.95, 0.001787009273603958],
#    [0.99, 0.0022351123346437667]],
#   100000: [[0.68, 0.000817842570244682],
#    [0.95, 0.0011978135448655475],
#    [0.99, 0.001414743609381014]]}}

# %%
def define_norm_df(dic,x,y):
    # Flatten the dictionary to a list of rows
    rows = []
    for N, n_dict in dic.items():
        for n, values in n_dict.items():
            row = {'N': N, 'n': n}
            for confidence, value in values:
                row[confidence] = value*(N**x)*(n**y)
            rows.append(row)

    # Convert the list of rows to a DataFrame
    df = pd.DataFrame(rows)

    # Optionally, rename the columns for clarity
    df.rename(columns={0.68: '0.68', 0.95: '0.95', 0.99: '0.99'}, inplace=True)
    return df

df = define_norm_df(fpd_results,0.,0.)
# Show the DataFrame
display(df)
# Out:
#      N       n      0.68      0.95      0.99
# 0    5   10000  0.000102  0.000156  0.000223
# 1    5   50000  0.000045  0.000054  0.000064
# 2    5  100000  0.000037  0.000041  0.000045
# 3    5  200000  0.000034  0.000035  0.000037
# 4   20   10000  0.000667  0.001322  0.001961
# 5   20   50000  0.000311  0.000403  0.000503
# 6   20  100000  0.000157  0.000199  0.000284
# 7  100   10000  0.006037  0.009022  0.011126
# 8  100   50000  0.001223  0.001787  0.002235
# 9  100  100000  0.000818  0.001198  0.001415
