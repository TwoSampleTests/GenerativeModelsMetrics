# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [0]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/5D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-02 19:08:49.624707: Importing os...
# 2024-05-02 19:08:49.624833: Importing sys...
# Visible devices: [0]
# 2024-05-02 19:08:49.625066: Importing timer from timeit...
# 2024-05-02 19:08:49.625134: Setting env variables for tf import (only device(s) [0] will be available)...
# 2024-05-02 19:08:49.625261: Importing numpy...
# 2024-05-02 19:08:49.916146: Importing matplotlib...
# 2024-05-02 19:08:50.356032: Importing h5py...
# 2024-05-02 19:08:50.598037: Importing importlib.util...
# 2024-05-02 19:08:50.598171: Importing json...
# 2024-05-02 19:08:50.598235: Importing pandas...
# 2024-05-02 19:08:51.578903: Importing random...
# 2024-05-02 19:08:51.579041: Importing scipy utils...
# 2024-05-02 19:08:52.425086: Importing subprocess...
# 2024-05-02 19:08:52.425217: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-02 19:09:01.478599: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-02 19:09:02.961771: Importing timeit...
# 2024-05-02 19:09:02.961863: Importing tqdm...
# 2024-05-02 19:09:02.972735: Importing typing...
# 2024-05-02 19:09:02.972842: Setting tf configs...
# 2024-05-02 19:09:04.134827: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-02 19:09:12.663077: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #0, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory was created
# 2024-05-02 19:09:12.694015: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)
# sample from dist_1:  tf.Tensor(
# [[ 1.1610332  -2.23691168 -2.20072828  5.13732308  1.32224517]
#  [-2.52914258 -0.85839971 -1.86610514  1.33679732 -0.66477288]], shape=(2, 5), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[ 1.1610332  -2.23691168 -2.20072828  5.13732308  1.32224517]
#  [-2.52914258 -0.85839971 -1.86610514  1.33679732 -0.66477288]], shape=(2, 5), dtype=float64)

# %%
cornerplotter(dist_1 = dist_1, 
              dist_2 = dist_2, 
              path_to_plots = results_dir, 
              figure_name = "corner_plot.png",
              max_points = 50_000,
              max_dim = 32,
              n_bins = 50,
              show = True,
              save = True)

# %%
plot_corr_matrix(dist = dist_1,
                 path_to_plots = results_dir,
                 figure_name = "corre_matrix_plot.pdf",
                 max_points = 1_000_000,
                 show_labels = True,
                 show = True,
                 save = True)

# %% [markdown]
# # Fixed $n=10000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 10_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory was created
# Null hypothesis directory was created

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 100000000
# batch_size 10000
# niter 10000
# niter * batch_size 100000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 10_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            10000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True        5           0  float64     5  100000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 10_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2000,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/5D_unimodal/5D_10K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 10000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 20,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/5D_unimodal/5D_10K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 10000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/5D_unimodal/5D_10K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/5D_unimodal/5D_10K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/5D_unimodal/5D_10K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 2000,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/5D_unimodal/5D_10K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 1000
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714669764.633962  163778 service.cc:145] XLA service 0x113ca94a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714669764.634247  163778 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1714669767.555611  163778 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# FGD metric calculation completed in 381.01109528698726 seconds.
# Saving fgd to results/5D_unimodal/5D_10K/null_hypothesis/FGD.json
# Computing and savng mmd with max_vectorize = 20
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 500
# Iterating from 0 to 20 out of 10000 .
# Iterating from 20 to 40 out of 10000 .
# Iterating from 40 to 60 out of 10000 .
# Iterating from 60 to 80 out of 10000 .
# Iterating from 80 to 100 out of 10000 .
# Iterating from 100 to 120 out of 10000 .
# Iterating from 120 to 140 out of 10000 .
# Iterating from 140 to 160 out of 10000 .
# Iterating from 160 to 180 out of 10000 .
# Iterating from 180 to 200 out of 10000 .
# Iterating from 200 to 220 out of 10000 .
# Iterating from 220 to 240 out of 10000 .
# Iterating from 240 to 260 out of 10000 .
# Iterating from 260 to 280 out of 10000 .
# Iterating from 280 to 300 out of 10000 .
# Iterating from 300 to 320 out of 10000 .
# Iterating from 320 to 340 out of 10000 .
# Iterating from 340 to 360 out of 10000 .
# Iterating from 360 to 380 out of 10000 .
# Iterating from 380 to 400 out of 10000 .
# Iterating from 400 to 420 out of 10000 .
# Iterating from 420 to 440 out of 10000 .
# Iterating from 440 to 460 out of 10000 .
# Iterating from 460 to 480 out of 10000 .
# Iterating from 480 to 500 out of 10000 .
# Iterating from 500 to 520 out of 10000 .
# Iterating from 520 to 540 out of 10000 .
# Iterating from 540 to 560 out of 10000 .
# Iterating from 560 to 580 out of 10000 .
# Iterating from 580 to 600 out of 10000 .
# Iterating from 600 to 620 out of 10000 .
# Iterating from 620 to 640 out of 10000 .
# Iterating from 640 to 660 out of 10000 .
# Iterating from 660 to 680 out of 10000 .
# Iterating from 680 to 700 out of 10000 .
# Iterating from 700 to 720 out of 10000 .
# Iterating from 720 to 740 out of 10000 .
# Iterating from 740 to 760 out of 10000 .
# Iterating from 760 to 780 out of 10000 .
# Iterating from 780 to 800 out of 10000 .
# Iterating from 800 to 820 out of 10000 .
# Iterating from 820 to 840 out of 10000 .
# Iterating from 840 to 860 out of 10000 .
# Iterating from 860 to 880 out of 10000 .
# Iterating from 880 to 900 out of 10000 .
# Iterating from 900 to 920 out of 10000 .
# Iterating from 920 to 940 out of 10000 .
# Iterating from 940 to 960 out of 10000 .
# Iterating from 960 to 980 out of 10000 .
# Iterating from 980 to 1000 out of 10000 .
# Iterating from 1000 to 1020 out of 10000 .
# Iterating from 1020 to 1040 out of 10000 .
# Iterating from 1040 to 1060 out of 10000 .
# Iterating from 1060 to 1080 out of 10000 .
# Iterating from 1080 to 1100 out of 10000 .
# Iterating from 1100 to 1120 out of 10000 .
# Iterating from 1120 to 1140 out of 10000 .
# Iterating from 1140 to 1160 out of 10000 .
# Iterating from 1160 to 1180 out of 10000 .
# Iterating from 1180 to 1200 out of 10000 .
# Iterating from 1200 to 1220 out of 10000 .
# Iterating from 1220 to 1240 out of 10000 .
# Iterating from 1240 to 1260 out of 10000 .
# Iterating from 1260 to 1280 out of 10000 .
# Iterating from 1280 to 1300 out of 10000 .
# Iterating from 1300 to 1320 out of 10000 .
# Iterating from 1320 to 1340 out of 10000 .
# Iterating from 1340 to 1360 out of 10000 .
# Iterating from 1360 to 1380 out of 10000 .
# Iterating from 1380 to 1400 out of 10000 .
# Iterating from 1400 to 1420 out of 10000 .
# Iterating from 1420 to 1440 out of 10000 .
# Iterating from 1440 to 1460 out of 10000 .
# Iterating from 1460 to 1480 out of 10000 .
# Iterating from 1480 to 1500 out of 10000 .
# Iterating from 1500 to 1520 out of 10000 .
# Iterating from 1520 to 1540 out of 10000 .
# Iterating from 1540 to 1560 out of 10000 .
# Iterating from 1560 to 1580 out of 10000 .
# Iterating from 1580 to 1600 out of 10000 .
# Iterating from 1600 to 1620 out of 10000 .
# Iterating from 1620 to 1640 out of 10000 .
# Iterating from 1640 to 1660 out of 10000 .
# Iterating from 1660 to 1680 out of 10000 .
# Iterating from 1680 to 1700 out of 10000 .
# Iterating from 1700 to 1720 out of 10000 .
# Iterating from 1720 to 1740 out of 10000 .
# Iterating from 1740 to 1760 out of 10000 .
# Iterating from 1760 to 1780 out of 10000 .
# Iterating from 1780 to 1800 out of 10000 .
# Iterating from 1800 to 1820 out of 10000 .
# Iterating from 1820 to 1840 out of 10000 .
# Iterating from 1840 to 1860 out of 10000 .
# Iterating from 1860 to 1880 out of 10000 .
# Iterating from 1880 to 1900 out of 10000 .
# Iterating from 1900 to 1920 out of 10000 .
# Iterating from 1920 to 1940 out of 10000 .
# Iterating from 1940 to 1960 out of 10000 .
# Iterating from 1960 to 1980 out of 10000 .
# Iterating from 1980 to 2000 out of 10000 .
# Iterating from 2000 to 2020 out of 10000 .
# Iterating from 2020 to 2040 out of 10000 .
# Iterating from 2040 to 2060 out of 10000 .
# Iterating from 2060 to 2080 out of 10000 .
# Iterating from 2080 to 2100 out of 10000 .
# Iterating from 2100 to 2120 out of 10000 .
# Iterating from 2120 to 2140 out of 10000 .
# Iterating from 2140 to 2160 out of 10000 .
# Iterating from 2160 to 2180 out of 10000 .
# Iterating from 2180 to 2200 out of 10000 .
# Iterating from 2200 to 2220 out of 10000 .
# Iterating from 2220 to 2240 out of 10000 .
# Iterating from 2240 to 2260 out of 10000 .
# Iterating from 2260 to 2280 out of 10000 .
# Iterating from 2280 to 2300 out of 10000 .
# Iterating from 2300 to 2320 out of 10000 .
# Iterating from 2320 to 2340 out of 10000 .
# Iterating from 2340 to 2360 out of 10000 .
# Iterating from 2360 to 2380 out of 10000 .
# Iterating from 2380 to 2400 out of 10000 .
# Iterating from 2400 to 2420 out of 10000 .
# Iterating from 2420 to 2440 out of 10000 .
# Iterating from 2440 to 2460 out of 10000 .
# Iterating from 2460 to 2480 out of 10000 .
# Iterating from 2480 to 2500 out of 10000 .
# Iterating from 2500 to 2520 out of 10000 .
# Iterating from 2520 to 2540 out of 10000 .
# Iterating from 2540 to 2560 out of 10000 .
# Iterating from 2560 to 2580 out of 10000 .
# Iterating from 2580 to 2600 out of 10000 .
# Iterating from 2600 to 2620 out of 10000 .
# Iterating from 2620 to 2640 out of 10000 .
# Iterating from 2640 to 2660 out of 10000 .
# Iterating from 2660 to 2680 out of 10000 .
# Iterating from 2680 to 2700 out of 10000 .
# Iterating from 2700 to 2720 out of 10000 .
# Iterating from 2720 to 2740 out of 10000 .
# Iterating from 2740 to 2760 out of 10000 .
# Iterating from 2760 to 2780 out of 10000 .
# Iterating from 2780 to 2800 out of 10000 .
# Iterating from 2800 to 2820 out of 10000 .
# Iterating from 2820 to 2840 out of 10000 .
# Iterating from 2840 to 2860 out of 10000 .
# Iterating from 2860 to 2880 out of 10000 .
# Iterating from 2880 to 2900 out of 10000 .
# Iterating from 2900 to 2920 out of 10000 .
# Iterating from 2920 to 2940 out of 10000 .
# Iterating from 2940 to 2960 out of 10000 .
# Iterating from 2960 to 2980 out of 10000 .
# Iterating from 2980 to 3000 out of 10000 .
# Iterating from 3000 to 3020 out of 10000 .
# Iterating from 3020 to 3040 out of 10000 .
# Iterating from 3040 to 3060 out of 10000 .
# Iterating from 3060 to 3080 out of 10000 .
# Iterating from 3080 to 3100 out of 10000 .
# Iterating from 3100 to 3120 out of 10000 .
# Iterating from 3120 to 3140 out of 10000 .
# Iterating from 3140 to 3160 out of 10000 .
# Iterating from 3160 to 3180 out of 10000 .
# Iterating from 3180 to 3200 out of 10000 .
# Iterating from 3200 to 3220 out of 10000 .
# Iterating from 3220 to 3240 out of 10000 .
# Iterating from 3240 to 3260 out of 10000 .
# Iterating from 3260 to 3280 out of 10000 .
# Iterating from 3280 to 3300 out of 10000 .
# Iterating from 3300 to 3320 out of 10000 .
# Iterating from 3320 to 3340 out of 10000 .
# Iterating from 3340 to 3360 out of 10000 .
# Iterating from 3360 to 3380 out of 10000 .
# Iterating from 3380 to 3400 out of 10000 .
# Iterating from 3400 to 3420 out of 10000 .
# Iterating from 3420 to 3440 out of 10000 .
# Iterating from 3440 to 3460 out of 10000 .
# Iterating from 3460 to 3480 out of 10000 .
# Iterating from 3480 to 3500 out of 10000 .
# Iterating from 3500 to 3520 out of 10000 .
# Iterating from 3520 to 3540 out of 10000 .
# Iterating from 3540 to 3560 out of 10000 .
# Iterating from 3560 to 3580 out of 10000 .
# Iterating from 3580 to 3600 out of 10000 .
# Iterating from 3600 to 3620 out of 10000 .
# Iterating from 3620 to 3640 out of 10000 .
# Iterating from 3640 to 3660 out of 10000 .
# Iterating from 3660 to 3680 out of 10000 .
# Iterating from 3680 to 3700 out of 10000 .
# Iterating from 3700 to 3720 out of 10000 .
# Iterating from 3720 to 3740 out of 10000 .
# Iterating from 3740 to 3760 out of 10000 .
# Iterating from 3760 to 3780 out of 10000 .
# Iterating from 3780 to 3800 out of 10000 .
# Iterating from 3800 to 3820 out of 10000 .
# Iterating from 3820 to 3840 out of 10000 .
# Iterating from 3840 to 3860 out of 10000 .
# Iterating from 3860 to 3880 out of 10000 .
# Iterating from 3880 to 3900 out of 10000 .
# Iterating from 3900 to 3920 out of 10000 .
# Iterating from 3920 to 3940 out of 10000 .
# Iterating from 3940 to 3960 out of 10000 .
# Iterating from 3960 to 3980 out of 10000 .
# Iterating from 3980 to 4000 out of 10000 .
# Iterating from 4000 to 4020 out of 10000 .
# Iterating from 4020 to 4040 out of 10000 .
# Iterating from 4040 to 4060 out of 10000 .
# Iterating from 4060 to 4080 out of 10000 .
# Iterating from 4080 to 4100 out of 10000 .
# Iterating from 4100 to 4120 out of 10000 .
# Iterating from 4120 to 4140 out of 10000 .
# Iterating from 4140 to 4160 out of 10000 .
# Iterating from 4160 to 4180 out of 10000 .
# Iterating from 4180 to 4200 out of 10000 .
# Iterating from 4200 to 4220 out of 10000 .
# Iterating from 4220 to 4240 out of 10000 .
# Iterating from 4240 to 4260 out of 10000 .
# Iterating from 4260 to 4280 out of 10000 .
# Iterating from 4280 to 4300 out of 10000 .
# Iterating from 4300 to 4320 out of 10000 .
# Iterating from 4320 to 4340 out of 10000 .
# Iterating from 4340 to 4360 out of 10000 .
# Iterating from 4360 to 4380 out of 10000 .
# Iterating from 4380 to 4400 out of 10000 .
# Iterating from 4400 to 4420 out of 10000 .
# Iterating from 4420 to 4440 out of 10000 .
# Iterating from 4440 to 4460 out of 10000 .
# Iterating from 4460 to 4480 out of 10000 .
# Iterating from 4480 to 4500 out of 10000 .
# Iterating from 4500 to 4520 out of 10000 .
# Iterating from 4520 to 4540 out of 10000 .
# Iterating from 4540 to 4560 out of 10000 .
# Iterating from 4560 to 4580 out of 10000 .
# Iterating from 4580 to 4600 out of 10000 .
# Iterating from 4600 to 4620 out of 10000 .
# Iterating from 4620 to 4640 out of 10000 .
# Iterating from 4640 to 4660 out of 10000 .
# Iterating from 4660 to 4680 out of 10000 .
# Iterating from 4680 to 4700 out of 10000 .
# Iterating from 4700 to 4720 out of 10000 .
# Iterating from 4720 to 4740 out of 10000 .
# Iterating from 4740 to 4760 out of 10000 .
# Iterating from 4760 to 4780 out of 10000 .
# Iterating from 4780 to 4800 out of 10000 .
# Iterating from 4800 to 4820 out of 10000 .
# Iterating from 4820 to 4840 out of 10000 .
# Iterating from 4840 to 4860 out of 10000 .
# Iterating from 4860 to 4880 out of 10000 .
# Iterating from 4880 to 4900 out of 10000 .
# Iterating from 4900 to 4920 out of 10000 .
# Iterating from 4920 to 4940 out of 10000 .
# Iterating from 4940 to 4960 out of 10000 .
# Iterating from 4960 to 4980 out of 10000 .
# Iterating from 4980 to 5000 out of 10000 .
# Iterating from 5000 to 5020 out of 10000 .
# Iterating from 5020 to 5040 out of 10000 .
# Iterating from 5040 to 5060 out of 10000 .
# Iterating from 5060 to 5080 out of 10000 .
# Iterating from 5080 to 5100 out of 10000 .
# Iterating from 5100 to 5120 out of 10000 .
# Iterating from 5120 to 5140 out of 10000 .
# Iterating from 5140 to 5160 out of 10000 .
# Iterating from 5160 to 5180 out of 10000 .
# Iterating from 5180 to 5200 out of 10000 .
# Iterating from 5200 to 5220 out of 10000 .
# Iterating from 5220 to 5240 out of 10000 .
# Iterating from 5240 to 5260 out of 10000 .
# Iterating from 5260 to 5280 out of 10000 .
# Iterating from 5280 to 5300 out of 10000 .
# Iterating from 5300 to 5320 out of 10000 .
# Iterating from 5320 to 5340 out of 10000 .
# Iterating from 5340 to 5360 out of 10000 .
# Iterating from 5360 to 5380 out of 10000 .
# Iterating from 5380 to 5400 out of 10000 .
# Iterating from 5400 to 5420 out of 10000 .
# Iterating from 5420 to 5440 out of 10000 .
# Iterating from 5440 to 5460 out of 10000 .
# Iterating from 5460 to 5480 out of 10000 .
# Iterating from 5480 to 5500 out of 10000 .
# Iterating from 5500 to 5520 out of 10000 .
# Iterating from 5520 to 5540 out of 10000 .
# Iterating from 5540 to 5560 out of 10000 .
# Iterating from 5560 to 5580 out of 10000 .
# Iterating from 5580 to 5600 out of 10000 .
# Iterating from 5600 to 5620 out of 10000 .
# Iterating from 5620 to 5640 out of 10000 .
# Iterating from 5640 to 5660 out of 10000 .
# Iterating from 5660 to 5680 out of 10000 .
# Iterating from 5680 to 5700 out of 10000 .
# Iterating from 5700 to 5720 out of 10000 .
# Iterating from 5720 to 5740 out of 10000 .
# Iterating from 5740 to 5760 out of 10000 .
# Iterating from 5760 to 5780 out of 10000 .
# Iterating from 5780 to 5800 out of 10000 .
# Iterating from 5800 to 5820 out of 10000 .
# Iterating from 5820 to 5840 out of 10000 .
# Iterating from 5840 to 5860 out of 10000 .
# Iterating from 5860 to 5880 out of 10000 .
# Iterating from 5880 to 5900 out of 10000 .
# Iterating from 5900 to 5920 out of 10000 .
# Iterating from 5920 to 5940 out of 10000 .
# Iterating from 5940 to 5960 out of 10000 .
# Iterating from 5960 to 5980 out of 10000 .
# Iterating from 5980 to 6000 out of 10000 .
# Iterating from 6000 to 6020 out of 10000 .
# Iterating from 6020 to 6040 out of 10000 .
# Iterating from 6040 to 6060 out of 10000 .
# Iterating from 6060 to 6080 out of 10000 .
# Iterating from 6080 to 6100 out of 10000 .
# Iterating from 6100 to 6120 out of 10000 .
# Iterating from 6120 to 6140 out of 10000 .
# Iterating from 6140 to 6160 out of 10000 .
# Iterating from 6160 to 6180 out of 10000 .
# Iterating from 6180 to 6200 out of 10000 .
# Iterating from 6200 to 6220 out of 10000 .
# Iterating from 6220 to 6240 out of 10000 .
# Iterating from 6240 to 6260 out of 10000 .
# Iterating from 6260 to 6280 out of 10000 .
# Iterating from 6280 to 6300 out of 10000 .
# Iterating from 6300 to 6320 out of 10000 .
# Iterating from 6320 to 6340 out of 10000 .
# Iterating from 6340 to 6360 out of 10000 .
# Iterating from 6360 to 6380 out of 10000 .
# Iterating from 6380 to 6400 out of 10000 .
# Iterating from 6400 to 6420 out of 10000 .
# Iterating from 6420 to 6440 out of 10000 .
# Iterating from 6440 to 6460 out of 10000 .
# Iterating from 6460 to 6480 out of 10000 .
# Iterating from 6480 to 6500 out of 10000 .
# Iterating from 6500 to 6520 out of 10000 .
# Iterating from 6520 to 6540 out of 10000 .
# Iterating from 6540 to 6560 out of 10000 .
# Iterating from 6560 to 6580 out of 10000 .
# Iterating from 6580 to 6600 out of 10000 .
# Iterating from 6600 to 6620 out of 10000 .
# Iterating from 6620 to 6640 out of 10000 .
# Iterating from 6640 to 6660 out of 10000 .
# Iterating from 6660 to 6680 out of 10000 .
# Iterating from 6680 to 6700 out of 10000 .
# Iterating from 6700 to 6720 out of 10000 .
# Iterating from 6720 to 6740 out of 10000 .
# Iterating from 6740 to 6760 out of 10000 .
# Iterating from 6760 to 6780 out of 10000 .
# Iterating from 6780 to 6800 out of 10000 .
# Iterating from 6800 to 6820 out of 10000 .
# Iterating from 6820 to 6840 out of 10000 .
# Iterating from 6840 to 6860 out of 10000 .
# Iterating from 6860 to 6880 out of 10000 .
# Iterating from 6880 to 6900 out of 10000 .
# Iterating from 6900 to 6920 out of 10000 .
# Iterating from 6920 to 6940 out of 10000 .
# Iterating from 6940 to 6960 out of 10000 .
# Iterating from 6960 to 6980 out of 10000 .
# Iterating from 6980 to 7000 out of 10000 .
# Iterating from 7000 to 7020 out of 10000 .
# Iterating from 7020 to 7040 out of 10000 .
# Iterating from 7040 to 7060 out of 10000 .
# Iterating from 7060 to 7080 out of 10000 .
# Iterating from 7080 to 7100 out of 10000 .
# Iterating from 7100 to 7120 out of 10000 .
# Iterating from 7120 to 7140 out of 10000 .
# Iterating from 7140 to 7160 out of 10000 .
# Iterating from 7160 to 7180 out of 10000 .
# Iterating from 7180 to 7200 out of 10000 .
# Iterating from 7200 to 7220 out of 10000 .
# Iterating from 7220 to 7240 out of 10000 .
# Iterating from 7240 to 7260 out of 10000 .
# Iterating from 7260 to 7280 out of 10000 .
# Iterating from 7280 to 7300 out of 10000 .
# Iterating from 7300 to 7320 out of 10000 .
# Iterating from 7320 to 7340 out of 10000 .
# Iterating from 7340 to 7360 out of 10000 .
# Iterating from 7360 to 7380 out of 10000 .
# Iterating from 7380 to 7400 out of 10000 .
# Iterating from 7400 to 7420 out of 10000 .
# Iterating from 7420 to 7440 out of 10000 .
# Iterating from 7440 to 7460 out of 10000 .
# Iterating from 7460 to 7480 out of 10000 .
# Iterating from 7480 to 7500 out of 10000 .
# Iterating from 7500 to 7520 out of 10000 .
# Iterating from 7520 to 7540 out of 10000 .
# Iterating from 7540 to 7560 out of 10000 .
# Iterating from 7560 to 7580 out of 10000 .
# Iterating from 7580 to 7600 out of 10000 .
# Iterating from 7600 to 7620 out of 10000 .
# Iterating from 7620 to 7640 out of 10000 .
# Iterating from 7640 to 7660 out of 10000 .
# Iterating from 7660 to 7680 out of 10000 .
# Iterating from 7680 to 7700 out of 10000 .
# Iterating from 7700 to 7720 out of 10000 .
# Iterating from 7720 to 7740 out of 10000 .
# Iterating from 7740 to 7760 out of 10000 .
# Iterating from 7760 to 7780 out of 10000 .
# Iterating from 7780 to 7800 out of 10000 .
# Iterating from 7800 to 7820 out of 10000 .
# Iterating from 7820 to 7840 out of 10000 .
# Iterating from 7840 to 7860 out of 10000 .
# Iterating from 7860 to 7880 out of 10000 .
# Iterating from 7880 to 7900 out of 10000 .
# Iterating from 7900 to 7920 out of 10000 .
# Iterating from 7920 to 7940 out of 10000 .
# Iterating from 7940 to 7960 out of 10000 .
# Iterating from 7960 to 7980 out of 10000 .
# Iterating from 7980 to 8000 out of 10000 .
# Iterating from 8000 to 8020 out of 10000 .
# Iterating from 8020 to 8040 out of 10000 .
# Iterating from 8040 to 8060 out of 10000 .
# Iterating from 8060 to 8080 out of 10000 .
# Iterating from 8080 to 8100 out of 10000 .
# Iterating from 8100 to 8120 out of 10000 .
# Iterating from 8120 to 8140 out of 10000 .
# Iterating from 8140 to 8160 out of 10000 .
# Iterating from 8160 to 8180 out of 10000 .
# Iterating from 8180 to 8200 out of 10000 .
# Iterating from 8200 to 8220 out of 10000 .
# Iterating from 8220 to 8240 out of 10000 .
# Iterating from 8240 to 8260 out of 10000 .
# Iterating from 8260 to 8280 out of 10000 .
# Iterating from 8280 to 8300 out of 10000 .
# Iterating from 8300 to 8320 out of 10000 .
# Iterating from 8320 to 8340 out of 10000 .
# Iterating from 8340 to 8360 out of 10000 .
# Iterating from 8360 to 8380 out of 10000 .
# Iterating from 8380 to 8400 out of 10000 .
# Iterating from 8400 to 8420 out of 10000 .
# Iterating from 8420 to 8440 out of 10000 .
# Iterating from 8440 to 8460 out of 10000 .
# Iterating from 8460 to 8480 out of 10000 .
# Iterating from 8480 to 8500 out of 10000 .
# Iterating from 8500 to 8520 out of 10000 .
# Iterating from 8520 to 8540 out of 10000 .
# Iterating from 8540 to 8560 out of 10000 .
# Iterating from 8560 to 8580 out of 10000 .
# Iterating from 8580 to 8600 out of 10000 .
# Iterating from 8600 to 8620 out of 10000 .
# Iterating from 8620 to 8640 out of 10000 .
# Iterating from 8640 to 8660 out of 10000 .
# Iterating from 8660 to 8680 out of 10000 .
# Iterating from 8680 to 8700 out of 10000 .
# Iterating from 8700 to 8720 out of 10000 .
# Iterating from 8720 to 8740 out of 10000 .
# Iterating from 8740 to 8760 out of 10000 .
# Iterating from 8760 to 8780 out of 10000 .
# Iterating from 8780 to 8800 out of 10000 .
# Iterating from 8800 to 8820 out of 10000 .
# Iterating from 8820 to 8840 out of 10000 .
# Iterating from 8840 to 8860 out of 10000 .
# Iterating from 8860 to 8880 out of 10000 .
# Iterating from 8880 to 8900 out of 10000 .
# Iterating from 8900 to 8920 out of 10000 .
# Iterating from 8920 to 8940 out of 10000 .
# Iterating from 8940 to 8960 out of 10000 .
# Iterating from 8960 to 8980 out of 10000 .
# Iterating from 8980 to 9000 out of 10000 .
# Iterating from 9000 to 9020 out of 10000 .
# Iterating from 9020 to 9040 out of 10000 .
# Iterating from 9040 to 9060 out of 10000 .
# Iterating from 9060 to 9080 out of 10000 .
# Iterating from 9080 to 9100 out of 10000 .
# Iterating from 9100 to 9120 out of 10000 .
# Iterating from 9120 to 9140 out of 10000 .
# Iterating from 9140 to 9160 out of 10000 .
# Iterating from 9160 to 9180 out of 10000 .
# Iterating from 9180 to 9200 out of 10000 .
# Iterating from 9200 to 9220 out of 10000 .
# Iterating from 9220 to 9240 out of 10000 .
# Iterating from 9240 to 9260 out of 10000 .
# Iterating from 9260 to 9280 out of 10000 .
# Iterating from 9280 to 9300 out of 10000 .
# Iterating from 9300 to 9320 out of 10000 .
# Iterating from 9320 to 9340 out of 10000 .
# Iterating from 9340 to 9360 out of 10000 .
# Iterating from 9360 to 9380 out of 10000 .
# Iterating from 9380 to 9400 out of 10000 .
# Iterating from 9400 to 9420 out of 10000 .
# Iterating from 9420 to 9440 out of 10000 .
# Iterating from 9440 to 9460 out of 10000 .
# Iterating from 9460 to 9480 out of 10000 .
# Iterating from 9480 to 9500 out of 10000 .
# Iterating from 9500 to 9520 out of 10000 .
# Iterating from 9520 to 9540 out of 10000 .
# Iterating from 9540 to 9560 out of 10000 .
# Iterating from 9560 to 9580 out of 10000 .
# Iterating from 9580 to 9600 out of 10000 .
# Iterating from 9600 to 9620 out of 10000 .
# Iterating from 9620 to 9640 out of 10000 .
# Iterating from 9640 to 9660 out of 10000 .
# Iterating from 9660 to 9680 out of 10000 .
# Iterating from 9680 to 9700 out of 10000 .
# Iterating from 9700 to 9720 out of 10000 .
# Iterating from 9720 to 9740 out of 10000 .
# Iterating from 9740 to 9760 out of 10000 .
# Iterating from 9760 to 9780 out of 10000 .
# Iterating from 9780 to 9800 out of 10000 .
# Iterating from 9800 to 9820 out of 10000 .
# Iterating from 9820 to 9840 out of 10000 .
# Iterating from 9840 to 9860 out of 10000 .
# Iterating from 9860 to 9880 out of 10000 .
# Iterating from 9880 to 9900 out of 10000 .
# Iterating from 9900 to 9920 out of 10000 .
# Iterating from 9920 to 9940 out of 10000 .
# Iterating from 9940 to 9960 out of 10000 .
# Iterating from 9960 to 9980 out of 10000 .
# Iterating from 9980 to 10000 out of 10000 .
# MMD metric calculation completed in 204.9948138500331 seconds.
# Saving mmd to results/5D_unimodal/5D_10K/null_hypothesis/MMD.json
# Computing and savng ks with max_vectorize = 10000
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f18360fc720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# KS tests calculation completed in 30.629391792987008 seconds.
# Saving ks to results/5D_unimodal/5D_10K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 500
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f183c1491c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2500 to 3000 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f183c1491c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# SKS metric calculation completed in 351.5772333709756 seconds.
# Saving sks to results/5D_unimodal/5D_10K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 500
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# SWD metric calculation completed in 259.58792467799503 seconds.
# Saving swd to results/5D_unimodal/5D_10K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0009995545098442906], [0.95, [9500, 500], 0.010497180865968162], [0.99, [9900, 100], 0.01945128781781326]]
# Computing time for metric fgd: 381.01109528698726
# ThresholdS for metric mmd: [[0.68, [6800, 3199], -0.4562511792173609], [0.95, [9500, 500], 82.8069046981982], [0.99, [9900, 100], 179.7980294173758]]
# Computing time for metric mmd: 204.9948138500331
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9178249657917351], [0.95, [9500, 500], 1.128542771075286], [0.99, [9900, 100], 1.2515795371222282]]
# Computing time for metric ks: 30.629391792987008
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9105417664639198], [0.95, [9500, 500], 1.1361795956329976], [0.99, [9900, 100], 1.294359352272415]]
# Computing time for metric sks: 351.5772333709756
# ThresholdS for metric swd: [[0.68, [6800, 3199], 1.16470031302645], [0.95, [9500, 500], 1.6085753716560776], [0.99, [9900, 100], 1.9589921507630303]]
# Computing time for metric swd: 259.58792467799503
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f18360ff4c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f18360ff560>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f18360ff6a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f18360ff740>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f18360ff7e0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f18360ff880>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 10000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 10000, 'ba...             20
# 2  {'niter': 10000, 'batch_size_test': 10000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 10000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 10000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 10000, 'ba...           2000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_unimodal/5D_10K/null_hypothesis/FGD...
# 1  $d_{\mathrm{MMD}}$  results/5D_unimodal/5D_10K/null_hypothesis/MMD...
# 2      $\overline{D}$  results/5D_unimodal/5D_10K/null_hypothesis/KS....
# 3     $\widetilde{D}$  results/5D_unimodal/5D_10K/null_hypothesis/SKS...
# 4     $\widetilde{W}$  results/5D_unimodal/5D_10K/null_hypothesis/SWD...
# 5           $t_{\mu}$  results/5D_unimodal/5D_10K/null_hypothesis/LR....
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0009995545098442906], ...
# 1  [[0.68, [6800, 3199], -0.4562511792173609], [0...
# 2  [[0.68, [6800, 3199], 0.9178249657917351], [0....
# 3  [[0.68, [6800, 3199], 0.9105417664639198], [0....
# 4  [[0.68, [6800, 3199], 1.16470031302645], [0.95...
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{2})$"
        dist_null = dist_null * 100
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-2})$"
        dist_null = dist_null / 100
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.2022526182038898 +/- 0.001810846705080054
# sigma = 0.4255404452082145 +/- 0.010046331748553535
# 68%CL = 0.09995545098442907, 95%CL = 1.049718086596816, 99%CL = 1.9451287817813259
# mu = 0.2022526182038898 +/- 0.001810846705080054
# sigma = 0.4255404452082145 +/- 0.010046331748553535
# /tmp/ipykernel_163778/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_163778/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_163778/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.0128971129888669 seconds.
# mu = -0.004379604013020129 +/- 0.0018623179464408713
# sigma = 0.4315458198663117 +/- 0.0087665130598393
# 68%CL = -0.004562511792173609, 95%CL = 0.8280690469819819, 99%CL = 1.797980294173758
# mu = -0.004379604013020129 +/- 0.0018623179464408713
# sigma = 0.4315458198663117 +/- 0.0087665130598393
# /tmp/ipykernel_163778/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_163778/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_163778/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.7129145149956457 seconds.
# mu = 0.8657554642499187 +/- 0.0002013031912490786
# sigma = 0.1418813558044462 +/- 0.0011254054684481755
# 68%CL = 0.9178249657917351, 95%CL = 1.128542771075286, 99%CL = 1.2515795371222282
# mu = 0.8657554642499187 +/- 0.0002013031912490786
# sigma = 0.1418813558044462 +/- 0.0011254054684481755
# /tmp/ipykernel_163778/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_163778/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_163778/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_163778/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3636547569767572 seconds.
# mu = 0.867153246909498 +/- 0.00020204169802826637
# sigma = 0.14214137259371964 +/- 0.0013374460020327233
# 68%CL = 0.9105417664639198, 95%CL = 1.1361795956329976, 99%CL = 1.294359352272415
# mu = 0.867153246909498 +/- 0.00020204169802826637
# sigma = 0.14214137259371964 +/- 0.0013374460020327233
# /tmp/ipykernel_163778/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_163778/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_163778/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_163778/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3135032929712906 seconds.
# mu = 1.0994084728019606 +/- 0.0006846337667795525
# sigma = 0.26165507195152027 +/- 0.0028978379725793303
# 68%CL = 1.16470031302645, 95%CL = 1.6085753716560776, 99%CL = 1.9589921507630303
# mu = 1.0994084728019606 +/- 0.0006846337667795525
# sigma = 0.26165507195152027 +/- 0.0028978379725793303
# /tmp/ipykernel_163778/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_163778/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_163778/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_163778/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9451185230282135 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f18360ff4c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f18360ff560>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f18360ff6a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f18360ff740>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f18360ff7e0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f18360ff880>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 10000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 10000, 'ba...             20
# 2  {'niter': 10000, 'batch_size_test': 10000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 10000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 10000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 10000, 'ba...           2000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_unimodal/5D_10K/null_hypothesis/FGD...
# 1  $d_{\mathrm{MMD}}$  results/5D_unimodal/5D_10K/null_hypothesis/MMD...
# 2      $\overline{D}$  results/5D_unimodal/5D_10K/null_hypothesis/KS....
# 3     $\widetilde{D}$  results/5D_unimodal/5D_10K/null_hypothesis/SKS...
# 4     $\widetilde{W}$  results/5D_unimodal/5D_10K/null_hypothesis/SWD...
# 5           $t_{\mu}$  results/5D_unimodal/5D_10K/null_hypothesis/LR....
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0009995545098442906], ...
# 1  [[0.68, [6800, 3199], -0.4562511792173609], [0...
# 2  [[0.68, [6800, 3199], 0.9178249657917351], [0....
# 3  [[0.68, [6800, 3199], 0.9105417664639198], [0....
# 4  [[0.68, [6800, 3199], 1.16470031302645], [0.95...
# 5                                                 []
#
#                                          null_figure
# 0  results/5D_unimodal/5D_10K/null_hypothesis/FGD...
# 1  results/5D_unimodal/5D_10K/null_hypothesis/MMD...
# 2  results/5D_unimodal/5D_10K/null_hypothesis/KS.pdf
# 3  results/5D_unimodal/5D_10K/null_hypothesis/SKS...
# 4  results/5D_unimodal/5D_10K/null_hypothesis/SWD...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 10000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 50,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = mean
# statistic = 7.565625049402504 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.994457755275368
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 44 calls to <function generate_and_clean_data_simple_1 at 0x7f1b3e2c4ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.8648288241423594 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9776099071032258
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = mean
# WARNING:tensorflow:6 out of the last 45 calls to <function generate_and_clean_data_simple_1 at 0x7f1b3e2c4ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.4559101605443532 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9099741369059344
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = mean
# WARNING:tensorflow:5 out of the last 14 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f1824665800> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.1083402656363561 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6466709383304408
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = mean
# WARNING:tensorflow:6 out of the last 15 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f1820333d80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.024249674322224312 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7915820514847319
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = mean
# statistic = 0.004632100468233574 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7753283540938325
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.1171875 - deformation = mean
# statistic = 0.012526640991517476 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.17629220188649822
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.09765625 - deformation = mean
# statistic = 0.008120150676986992 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.2553567017374887
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.107421875 - deformation = mean
# statistic = 0.010011170925730681 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.047396294463234505
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.1123046875 - deformation = mean
# statistic = 0.01157537701721525 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.09769562340289897
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.10986328125 - deformation = mean
# statistic = 0.010701349557202994 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.02247191011235955
# relative_error_metric = 0.019262532558546135
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.108642578125 - deformation = mean
# statistic = 0.010624176003318154 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.011299435028248588
# relative_error_metric = 0.012025282100570195
# =======> statistic within required accuracy at 0.95 CL in 95.32032533094753 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.1080322265625 - deformation = mean
# statistic = 0.010158834091584381 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9154020791014459
# relative_error_metric = 0.6276538647603235
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.55401611328125 - deformation = mean
# statistic = 7.889723295354247 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.8376705261951163
# relative_error_metric = 1.9901626711544849
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.331024169921875 - deformation = mean
# statistic = 2.1232381694059996 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.6997137101049729
# relative_error_metric = 1.9636880878799574
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.7195281982421875 - deformation = mean
# statistic = 0.6067305548900963 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.477827970867521
# relative_error_metric = 1.8757467145090214
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.41378021240234375 - deformation = mean
# statistic = 0.19577362551576433 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.1718692886906938
# relative_error_metric = 1.6384937502534263
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.2609062194824219 - deformation = mean
# statistic = 0.07459424491078241 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.8287235692498578
# relative_error_metric = 1.1726863678279165
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.18446922302246094 - deformation = mean
# statistic = 0.035400290865739883 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.5226435394998533
# relative_error_metric = 0.5815330544974385
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.14625072479248047 - deformation = mean
# statistic = 0.02121123999618265 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.30059819603577925
# relative_error_metric = 0.08656383520572083
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.12714147567749023 - deformation = mean
# statistic = 0.014780113551881486 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.13979366698933451
# relative_error_metric = 0.27291750141828497
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.13669610023498535 - deformation = mean
# statistic = 0.018006241703103214 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.0675365384048232
# relative_error_metric = 0.07715650942239127
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.1414734125137329 - deformation = mean
# statistic = 0.019538060157965075 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.034348208986245715
# relative_error_metric = 0.004451079315597766
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.13908475637435913 - deformation = mean
# statistic = 0.019015996097351377 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.01702788515365993
# relative_error_metric = 0.02263178868681605
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.14027908444404602 - deformation = mean
# statistic = 0.018858829104730534 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.008477852601717044
# relative_error_metric = 0.030929621764432143
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.14087624847888947 - deformation = mean
# statistic = 0.01911747993012309 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.004229961054276232
# relative_error_metric = 0.017309751240783704
# =======> statistic within required accuracy at 0.99 CL in 105.68222400295781 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 201.00258386001224 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_diag
# statistic = 72.87910874561881 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9994239408633074
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_diag
# statistic = 18.263732945736947 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9977022986373172
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_diag
# statistic = 4.58677315519269 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9908665968293109
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_diag
# statistic = 1.1595333971348134 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.964113140072272
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_diag
# statistic = 0.2952953343975405 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.862688844991219
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_diag
# statistic = 0.07588153638345171 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5138996641657738
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_diag
# statistic = 0.020261540883766763 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6349002469767945
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_diag
# statistic = 0.006673382198264609 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.4453900146895865
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.029296875 - deformation = cov_diag
# statistic = 0.012189581249021638 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.14919717273671754
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0244140625 - deformation = cov_diag
# statistic = 0.009207448520888294 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.13090653163364294
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.02685546875 - deformation = cov_diag
# statistic = 0.01074489416635716 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.023322891008720995
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.025634765625 - deformation = cov_diag
# statistic = 0.009839508185777817 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.06467844185618614
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0262451171875 - deformation = cov_diag
# statistic = 0.010277628916024524 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.022988505747126436
# relative_error_metric = 0.02113636199296923
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.02655029296875 - deformation = cov_diag
# statistic = 0.010055128127312307 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.011428571428571429
# relative_error_metric = 0.0430173309286449
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.026702880859375 - deformation = cov_diag
# statistic = 0.010669781543729672 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.0057306590257879654
# relative_error_metric = 0.01630849759363032
# =======> statistic within required accuracy at 0.95 CL in 116.72399737796513 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0266265869140625 - deformation = cov_diag
# statistic = 0.010360422877297378 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.978811565606739
# relative_error_metric = 0.6098854932204113
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5133132934570312 - deformation = cov_diag
# statistic = 73.67061091785698 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9580673745550665
# relative_error_metric = 1.9989441567975055
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2699699401855469 - deformation = cov_diag
# statistic = 18.854042721502594 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9178569852454435
# relative_error_metric = 1.9958775438595087
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6482982635498047 - deformation = cov_diag
# statistic = 4.935063551430036 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.8421952494665894
# relative_error_metric = 1.9842961109622865
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3374624252319336 - deformation = cov_diag
# statistic = 1.3500093992180329 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.7074716783445747
# relative_error_metric = 1.9431855532562532
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.18204450607299805 - deformation = cov_diag
# statistic = 0.39845794614671304 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.48959702021183
# relative_error_metric = 1.8138228472887552
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.10433554649353027 - deformation = cov_diag
# statistic = 0.13385416808078737 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.1867393659144905
# relative_error_metric = 1.4924828290343761
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.06548106670379639 - deformation = cov_diag
# statistic = 0.054556144854571206 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.8436753790501582
# relative_error_metric = 0.948684632587104
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.04605382680892944 - deformation = cov_diag
# statistic = 0.02795503226869629 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.5345935417734495
# relative_error_metric = 0.3587599474232528
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.03634020686149597 - deformation = cov_diag
# statistic = 0.017560204085633756 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.23578454688327966
# relative_error_metric = 0.10218900319462015
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.04119701683521271 - deformation = cov_diag
# statistic = 0.022225967093455735 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.12527686038165173
# relative_error_metric = 0.1331507692409098
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.03876861184835434 - deformation = cov_diag
# statistic = 0.020225510073754678 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.06466364479088497
# relative_error_metric = 0.039026448558539324
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.037554409354925156 - deformation = cov_diag
# statistic = 0.018835588680927263 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.03181746409632462
# relative_error_metric = 0.03216241141563221
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.03816151060163975 - deformation = cov_diag
# statistic = 0.019274291690737074 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.015783186803302394
# relative_error_metric = 0.009141044721466625
# =======> statistic within required accuracy at 0.99 CL in 109.23603716195794 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 225.96006982098334 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_off_diag
# statistic = 9.512836642448782 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.99559096381132
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_off_diag
# statistic = 4.803023378713904 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9912769203031018
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_off_diag
# statistic = 3.949109245093978 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9893957330737253
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_off_diag
# statistic = 1.9248328740494187 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9783041020020182
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_off_diag
# statistic = 0.7851037300385221 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9472238871419374
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_off_diag
# statistic = 0.285417421957988 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8581052673198004
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_off_diag
# statistic = 0.09343809218684357 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.596010841838677
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_off_diag
# statistic = 0.027610720445394983 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8981622703176179
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_off_diag
# statistic = 0.007117257430743715 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.383767381995415
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0146484375 - deformation = cov_off_diag
# statistic = 0.01601086119715446 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.4160005720570969
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01220703125 - deformation = cov_off_diag
# statistic = 0.011231990532062908 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.06763347323601389
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.010986328125 - deformation = cov_off_diag
# statistic = 0.008819738580992031 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.1736759621100042
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0115966796875 - deformation = cov_off_diag
# statistic = 0.010105379330009049 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.038034257124569856
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.01190185546875 - deformation = cov_off_diag
# statistic = 0.010685860601158517 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.025974025974025976
# relative_error_metric = 0.01781422516527306
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.011749267578125 - deformation = cov_off_diag
# statistic = 0.010727095484027421 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.013071895424836602
# relative_error_metric = 0.021665249195580452
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0116729736328125 - deformation = cov_off_diag
# statistic = 0.010160040043411311 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.006514657980456026
# relative_error_metric = 0.03264145008041916
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.01171112060546875 - deformation = cov_off_diag
# statistic = 0.01041673621139313 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.0032520325203252032
# relative_error_metric = 0.0076929304326362686
# =======> statistic within required accuracy at 0.95 CL in 128.9305926769739 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.011730194091796875 - deformation = cov_off_diag
# statistic = 0.010534159985541596 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9906378087905647
# relative_error_metric = 0.5947636927585914
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5058650970458984 - deformation = cov_off_diag
# statistic = 9.526389725505808 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9813628598161288
# relative_error_metric = 1.9918493141502505
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2587976455688477 - deformation = cov_off_diag
# statistic = 4.82529168852637 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.963069855769772
# relative_error_metric = 1.9839402932929242
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6352639198303223 - deformation = cov_off_diag
# statistic = 4.0011747414033225 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9274788203516244
# relative_error_metric = 1.9806484983418553
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.32349705696105957 - deformation = cov_off_diag
# statistic = 2.0072041431587677 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.8600329292447966
# relative_error_metric = 1.9616090875232002
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16761362552642822 - deformation = cov_off_diag
# statistic = 0.8646809863458633 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.738375281249896
# relative_error_metric = 1.9119982908158726
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08967190980911255 - deformation = cov_off_diag
# statistic = 0.3520980677615901 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.5372800507863358
# relative_error_metric = 1.7905926894963344
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.05070105195045471 - deformation = cov_off_diag
# statistic = 0.14385092978549113 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.2484408154302586
# relative_error_metric = 1.5235511653598106
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.031215623021125793 - deformation = cov_off_diag
# statistic = 0.0635936662197027 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.907442458393259
# relative_error_metric = 1.0630959800868311
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.021472908556461334 - deformation = cov_off_diag
# statistic = 0.032672422155167684 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.5868556663439132
# relative_error_metric = 0.5072982849535379
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.016601551324129105 - deformation = cov_off_diag
# statistic = 0.020339774209310955 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.3438797829655718
# relative_error_metric = 0.04465758621330817
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.01416587270796299 - deformation = cov_off_diag
# statistic = 0.014950796122539306 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.15832840692971695
# relative_error_metric = 0.2616406438096628
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.015383712016046047 - deformation = cov_off_diag
# statistic = 0.017738718224668333 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.07615002541207082
# relative_error_metric = 0.09209837670844599
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.015992631670087576 - deformation = cov_off_diag
# statistic = 0.018830005240512402 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.037363701010672476
# relative_error_metric = 0.0324588083455941
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.01629709149710834 - deformation = cov_off_diag
# statistic = 0.019389213650867175 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.018508959696308374
# relative_error_metric = 0.003196362796507071
# =======> statistic within required accuracy at 0.99 CL in 119.28456899599405 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 248.21519581996836 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_up
# statistic = 2498554.8098130063 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999999983194796
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_up
# statistic = 6310.148087970039 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999933458528978
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_up
# statistic = 256.20446336525066 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998361191580134
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_up
# statistic = 29.60793218361807 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9985823446967035
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_up
# statistic = 5.1963973456401416 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9919359373902954
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_up
# statistic = 1.0946560988024843 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9620064255010226
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_up
# statistic = 0.2501779308710585 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8389231592380342
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_up
# statistic = 0.059080344893737126 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3965188758093243
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.013896968037610804 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.27873792072687115
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.004145567389171932 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.8675439017489905
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00732421875 - deformation = power_abs_up
# statistic = 0.008234730227659382 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.24156111215779247
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.008544921875 - deformation = power_abs_up
# statistic = 0.010267464420606536 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.022125727860147743
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0091552734375 - deformation = power_abs_up
# statistic = 0.012767935463667493 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.19520681225279668
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00885009765625 - deformation = power_abs_up
# statistic = 0.01177179673768321 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.03508771929824561
# relative_error_metric = 0.11447457484586576
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.008697509765625 - deformation = power_abs_up
# statistic = 0.011261659847711663 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.017699115044247787
# relative_error_metric = 0.07026835591133972
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0086212158203125 - deformation = power_abs_up
# statistic = 0.010781028203960152 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.008888888888888889
# relative_error_metric = 0.02667962675422165
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00858306884765625 - deformation = power_abs_up
# statistic = 0.010671659597215843 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.004454342984409799
# relative_error_metric = 0.01648448638942953
# =======> statistic within required accuracy at 0.95 CL in 129.1073056810419 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.008563995361328125 - deformation = power_abs_up
# statistic = 0.010693269029613334 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9931605183687304
# relative_error_metric = 0.5810680072377702
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.504281997680664 - deformation = power_abs_up
# statistic = 2555026.257440661 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9863676558212615
# relative_error_metric = 1.999999969548199
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.256422996520996 - deformation = power_abs_up
# statistic = 6506.704191664088 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.972919894303151
# relative_error_metric = 1.9999880423458039
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6324934959411621 - deformation = power_abs_up
# statistic = 267.5548394603717 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9465633240230735
# relative_error_metric = 1.9997092203774376
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3205287456512451 - deformation = power_abs_up
# statistic = 31.729309859384244 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.89590781814296
# relative_error_metric = 1.9975493484325102
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16454637050628662 - deformation = power_abs_up
# statistic = 5.876176998042679 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.80211478802194
# relative_error_metric = 1.9868029075954714
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08655518293380737 - deformation = power_abs_up
# statistic = 1.3679936354270412 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.6398625171148646
# relative_error_metric = 1.9439219892856807
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04755958914756775 - deformation = power_abs_up
# statistic = 0.37992736850405534 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.3896330438430433
# relative_error_metric = 1.8051845033787985
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.028061792254447937 - deformation = power_abs_up
# statistic = 0.12459883347979384 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.0647032139028405
# relative_error_metric = 1.4598744480713917
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.01831289380788803 - deformation = power_abs_up
# statistic = 0.05196793482038657 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.7254484241223833
# relative_error_metric = 0.9105852962667563
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.013438444584608078 - deformation = power_abs_up
# statistic = 0.02735788942731706 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.44308260677064154
# relative_error_metric = 0.33782271233260547
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.011001219972968102 - deformation = power_abs_up
# statistic = 0.01790401105299556 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.19944828668971631
# relative_error_metric = 0.08284108608895716
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.01221983227878809 - deformation = power_abs_up
# statistic = 0.02233672137480714 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.10495754392248315
# relative_error_metric = 0.1380986370369344
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.011610526125878096 - deformation = power_abs_up
# statistic = 0.020029480536681403 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.053892888257849755
# relative_error_metric = 0.02928984125519532
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.011305873049423099 - deformation = power_abs_up
# statistic = 0.018864368040178502 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.02658821520122111
# relative_error_metric = 0.030636029293615183
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.011458199587650597 - deformation = power_abs_up
# statistic = 0.019314424059298268 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.013206324451477298
# relative_error_metric = 0.007061072885691024
# =======> statistic within required accuracy at 0.99 CL in 125.02984279801603 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 254.13718195504043 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_down
# statistic = 21546000.564409293 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999999980512053
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_down
# statistic = 31.15143782413613 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9986525636659875
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_down
# statistic = 19.473446715052937 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9978449576898716
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_down
# statistic = 8.25370181955141 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9949192022769837
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_down
# statistic = 2.759425512975528 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9848411930205752
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_down
# statistic = 0.805683186067693 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9485546024322764
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_down
# statistic = 0.2195658288286034 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8174903322371716
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_down
# statistic = 0.057543570489466844 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.38288859797374
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.01486676062768505 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.34455053153393234
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.005006774452105627 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.708258802508554
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00732421875 - deformation = power_abs_down
# statistic = 0.008500588337324953 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.21019231334772878
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.008544921875 - deformation = power_abs_down
# statistic = 0.011613272273624664 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.10095599584595898
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0079345703125 - deformation = power_abs_down
# statistic = 0.009977353130043188 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.050777979711405595
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00823974609375 - deformation = power_abs_down
# statistic = 0.010286301855958834 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.02029294250927884
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.008392333984375 - deformation = power_abs_down
# statistic = 0.01115367781455176 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.01834862385321101
# relative_error_metric = 0.06064396412824706
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0083160400390625 - deformation = power_abs_down
# statistic = 0.010870208390992625 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.009216589861751152
# relative_error_metric = 0.0349155922175137
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00827789306640625 - deformation = power_abs_down
# statistic = 0.010751519959696535 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.004618937644341801
# relative_error_metric = 0.023939260646107487
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.008258819580078125 - deformation = power_abs_down
# statistic = 0.010120696964411997 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.002306805074971165
# relative_error_metric = 0.03652014088486074
#
# ------------ 19 - 0.95 CL ------------
# eps = 0.008268356323242188 - deformation = power_abs_down
# statistic = 0.010973275816684976 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.001154068090017311
# relative_error_metric = 0.044348842481908714
#
# ------------ 20 - 0.95 CL ------------
# eps = 0.008263587951660156 - deformation = power_abs_down
# statistic = 0.010799283351375314 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.0005772005772005772
# relative_error_metric = 0.02837114014082442
#
# ------------ 21 - 0.95 CL ------------
# eps = 0.00826120376586914 - deformation = power_abs_down
# statistic = 0.011059920921981305 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.0002886419396738346
# relative_error_metric = 0.05220924979142767
#
# ------------ 22 - 0.95 CL ------------
# eps = 0.008260011672973633 - deformation = power_abs_down
# statistic = 0.010642390198581875 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.00014433138485963774
# relative_error_metric = 0.013738153169741599
# =======> statistic within required accuracy at 0.95 CL in 168.31932224496268 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.008259415626525879 - deformation = power_abs_down
# statistic = 0.010667526837191176 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9934033643698605
# relative_error_metric = 0.5832740153445982
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.504129707813263 - deformation = power_abs_down
# statistic = 23243043.41949058 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9868501012849193
# relative_error_metric = 1.9999999966525406
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2561945617198944 - deformation = power_abs_down
# statistic = 31.17207173559607 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9738719928933781
# relative_error_metric = 1.9975055674193003
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6322269886732101 - deformation = power_abs_down
# statistic = 19.70153229523052 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.9484178551108753
# relative_error_metric = 1.9960547022949642
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.320243202149868 - deformation = power_abs_down
# statistic = 8.552295871314652 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.8994295304867503
# relative_error_metric = 1.9909230697281637
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16425130888819695 - deformation = power_abs_down
# statistic = 3.0027674868005416 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.8084892252406954
# relative_error_metric = 1.9742556191084881
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08625536225736141 - deformation = power_abs_down
# statistic = 0.9667454965721027 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.6504497683241584
# relative_error_metric = 1.921105855846625
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.047257388941943645 - deformation = power_abs_down
# statistic = 0.3160690317855423 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.4049069869401836
# relative_error_metric = 1.7681059932130714
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.027758402284234762 - deformation = power_abs_down
# statistic = 0.11458844342032255 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 1.0827411425101012
# relative_error_metric = 1.4195366511663328
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.01800890895538032 - deformation = power_abs_down
# statistic = 0.04914882263154263 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.7423003548212557
# relative_error_metric = 0.8658159475021141
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0131341622909531 - deformation = power_abs_down
# statistic = 0.026849134166722476 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.4557205609300589
# relative_error_metric = 0.31955848486132954
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.01069678895873949 - deformation = power_abs_down
# statistic = 0.017423396181693807 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.2045552698820658
# relative_error_metric = 0.10998828552112128
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.011915475624846295 - deformation = power_abs_down
# statistic = 0.022030885806800023 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.10778988204405218
# relative_error_metric = 0.12437139925841154
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.011306132291792892 - deformation = power_abs_down
# statistic = 0.019775506423862034 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.05538749388003731
# relative_error_metric = 0.01653046660154139
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.01100146062526619 - deformation = power_abs_down
# statistic = 0.0186651900348759 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.027315512494735593
# relative_error_metric = 0.04124713652585821
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.011153796458529541 - deformation = power_abs_down
# statistic = 0.01933999712434554 - next threshold = 0.01945128781781326 at 0.99 CL
# relative_error_eps = 0.013565121684650377
# relative_error_metric = 0.005737922506751964
# =======> statistic within required accuracy at 0.99 CL in 114.64002036600141 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 282.9593775300309 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# Computing exclusion limits for fgd with random_normal deformation.
#
# ======================================================
# =============== fgd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 13.059600895432032 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9967874209345056
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 1.8818532219216262 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9778113380048326
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 0.20391295507910118 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.804166331601833
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 0.016912188514396527 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.46808867138868937
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 0.002651572372170544 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.1933615836733455
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.234375 - deformation = random_normal
# statistic = 0.005315149669540798 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.6554418002824234
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.2734375 - deformation = random_normal
# statistic = 0.009981590816288076 - next threshold = 0.010497180865968162 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.05035361082001002
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.29296875 - deformation = random_normal
# ...
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08721232414245605 - deformation = power_abs_down
# statistic = 9.745463484342194 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 1.6171217383780576
# relative_error_metric = 1.3305140497478867
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04822194576263428 - deformation = power_abs_down
# statistic = 5.709969108371483 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 1.3572843937712027
# relative_error_metric = 0.9782229511566921
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.02872675657272339 - deformation = power_abs_down
# statistic = 3.6189745133884776 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 1.0271891463251863
# relative_error_metric = 0.5951926436899764
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.018979161977767944 - deformation = power_abs_down
# statistic = 2.5779986928444867 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.6910558369735738
# relative_error_metric = 0.2728709681896836
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.014105364680290222 - deformation = power_abs_down
# statistic = 2.073564702262928 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.4176896332644793
# relative_error_metric = 0.05682377492777291
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.011668466031551361 - deformation = power_abs_down
# statistic = 1.8317805955627058 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.18909867733547633
# relative_error_metric = 0.06711642386034684
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.012886915355920792 - deformation = power_abs_down
# statistic = 1.9514001588608876 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.09028131915753997
# relative_error_metric = 0.0038829822181564843
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.013496140018105507 - deformation = power_abs_down
# statistic = 2.0122001115702246 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.046183025699478866
# relative_error_metric = 0.026796970427179555
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.01319152768701315 - deformation = power_abs_down
# statistic = 1.9817232592254839 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.023361235990266956
# relative_error_metric = 0.011536538977078669
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.01303922152146697 - deformation = power_abs_down
# statistic = 1.9665424336461799 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.01174923717069604
# relative_error_metric = 0.003846753974929419
# =======> statistic within required accuracy at 0.99 CL in 101.81315558904316 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 198.12516974203754 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 32.70430705964918 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8124814637911622
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 10.507338573889493 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4689380004229982
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 3.2243067914052568 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6686409331882871
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 1.4306021420693424 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.11711933823080689
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_normal
# statistic = 2.129340988919779 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.2786395237497894
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.390625 - deformation = random_normal
# statistic = 1.7428224008198754 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.08011405286852508
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.3515625 - deformation = random_normal
# statistic = 1.5485007793473504 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.0380571069149747
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.37109375 - deformation = random_normal
# statistic = 1.6418713044629414 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.020486989096906914
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.361328125 - deformation = random_normal
# statistic = 1.587213233258747 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.02666666666666667
# relative_error_metric = 0.013368930826324128
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.3662109375 - deformation = random_normal
# statistic = 1.624718154643192 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.013422818791946308
# relative_error_metric = 0.009985349524137327
# =======> statistic within required accuracy at 0.95 CL in 66.09826875297586 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.36376953125 - deformation = random_normal
# statistic = 1.6182612699008183 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 1.728720983158853
# relative_error_metric = 0.19049859811105077
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.681884765625 - deformation = random_normal
# statistic = 36.425586084602244 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 1.5222444889779558
# relative_error_metric = 1.7958563318058676
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.5228271484375 - deformation = random_normal
# statistic = 14.752972680759465 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 1.2287285668068586
# relative_error_metric = 1.5311162581989322
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.94329833984375 - deformation = random_normal
# statistic = 6.473637493258999 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.8867616156899369
# relative_error_metric = 1.070756225063541
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.653533935546875 - deformation = random_normal
# statistic = 3.5122691970874915 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.5696715164241788
# relative_error_metric = 0.5677948639520547
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.5086517333984375 - deformation = random_normal
# statistic = 2.3636436210765126 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.33213817227809356
# relative_error_metric = 0.1872244119893907
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.43621063232421875 - deformation = random_normal
# statistic = 1.9609613625803852 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.18110724333603548
# relative_error_metric = 0.0010047118215314203
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.3999900817871094 - deformation = random_normal
# statistic = 1.7755437199869266 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.08663123560137771
# relative_error_metric = 0.09824429976047559
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.41810035705566406 - deformation = random_normal
# statistic = 1.8958607457027654 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.04239738337370648
# relative_error_metric = 0.032754248608627856
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.4271554946899414 - deformation = random_normal
# statistic = 1.9328527806266318 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.020976356034706534
# relative_error_metric = 0.013432893960173773
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.4316830635070801 - deformation = random_normal
# statistic = 1.9374797818985439 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.010433464003450351
# relative_error_metric = 0.011041972962341844
# =======> statistic within required accuracy at 0.99 CL in 73.12943162798183 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 139.22773187200073 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_uniform
# statistic = 13.786794973341754 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5820625719007204
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_uniform
# statistic = 4.152299883337866 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8831034865671511
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_uniform
# statistic = 1.6041968789093275 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.002725678887434057
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.9375 - deformation = random_uniform
# statistic = 2.6031252433010605 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.4722794721509921
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.78125 - deformation = random_uniform
# statistic = 2.0448502402591915 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.23883057434110533
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.703125 - deformation = random_uniform
# statistic = 1.8035819708444845 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.11430105919177717
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.6640625 - deformation = random_uniform
# statistic = 1.7103033614919465 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.06130262538359025
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.64453125 - deformation = random_uniform
# statistic = 1.6457887327193694 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.03076923076923077
# relative_error_metric = 0.022869820259668567
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.634765625 - deformation = random_uniform
# statistic = 1.6399392542685343 - next threshold = 1.6085753716560776 at 0.95 CL
# relative_error_eps = 0.015503875968992248
# relative_error_metric = 0.019309676097597823
# =======> statistic within required accuracy at 0.95 CL in 69.17776537599275 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.6298828125 - deformation = random_uniform
# statistic = 1.626266982364249 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 1.5524718126626194
# relative_error_metric = 0.18560731932844046
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.81494140625 - deformation = random_uniform
# statistic = 16.780510175659526 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 1.2686038270729978
# relative_error_metric = 1.581847561020686
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.722412109375 - deformation = random_uniform
# statistic = 7.148307297061747 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.9289050337311884
# relative_error_metric = 1.1395947121378889
#
# ------------ 4 - 0.99 CL ------------
# eps = 1.1761474609375 - deformation = random_uniform
# statistic = 3.7199830428281837 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.6049340993578912
# relative_error_metric = 0.6201791105030539
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.90301513671875 - deformation = random_uniform
# statistic = 2.4710433791032336 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.35636074059327094
# relative_error_metric = 0.231172515384165
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.766448974609375 - deformation = random_uniform
# statistic = 1.9911764703445098 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.19560703748224237
# relative_error_metric = 0.016295162393576867
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.6981658935546875 - deformation = random_uniform
# statistic = 1.7847782447260105 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.09324373600041673
# relative_error_metric = 0.09306869152388957
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.7323074340820312 - deformation = random_uniform
# statistic = 1.875307697581853 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.045559825905469725
# relative_error_metric = 0.04365044805627324
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.7493782043457031 - deformation = random_uniform
# statistic = 1.9458283637877098 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.022523372717778364
# relative_error_metric = 0.006742326274033638
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.7579135894775391 - deformation = random_uniform
# statistic = 1.9567051802951954 - next threshold = 1.9589921507630303 at 0.99 CL
# relative_error_eps = 0.011198628637208226
# relative_error_metric = 0.001168103800922189
# =======> statistic within required accuracy at 0.99 CL in 69.41878020198783 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 138.59657721797703 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T19:30:01.649463', 'fgd_cov_diag_2024-05-02T19:33:22.654163', 'fgd_cov_off_diag_2024-05-02T19:37:08.617244', 'fgd_power_abs_up_2024-05-02T19:41:16.835343', 'fgd_power_abs_down_2024-05-02T19:45:30.977660', 'fgd_random_normal_2024-05-02T19:50:13.940820', 'fgd_random_uniform_2024-05-02T19:52:40.321873', 'mmd_mean_2024-05-02T19:55:09.442119', 'mmd_cov_diag_2024-05-02T19:58:20.969311', 'mmd_cov_off_diag_2024-05-02T20:02:12.422198', 'mmd_power_abs_up_2024-05-02T20:05:40.543427', 'mmd_power_abs_down_2024-05-02T20:10:12.208573', 'mmd_random_normal_2024-05-02T20:14:34.917945', 'mmd_random_uniform_2024-05-02T20:17:59.507944', 'ks_mean_2024-05-02T20:20:58.834464', 'ks_cov_diag_2024-05-02T20:23:41.210805', 'ks_cov_off_diag_2024-05-02T20:26:40.106738', 'ks_power_abs_up_2024-05-02T20:29:01.513600', 'ks_power_abs_down_2024-05-02T20:32:14.522542', 'ks_random_normal_2024-05-02T20:35:35.686582', 'ks_random_uniform_2024-05-02T20:38:10.074802', 'sks_mean_2024-05-02T20:40:29.040247', 'sks_cov_diag_2024-05-02T20:44:06.439735', 'sks_cov_off_diag_2024-05-02T20:48:18.398705', 'sks_power_abs_up_2024-05-02T20:52:38.982733', 'sks_power_abs_down_2024-05-02T20:57:30.741969', 'sks_random_normal_2024-05-02T21:02:20.352327', 'sks_random_uniform_2024-05-02T21:05:44.418903', 'swd_mean_2024-05-02T21:08:52.670000', 'swd_cov_diag_2024-05-02T21:11:35.111247', 'swd_cov_off_diag_2024-05-02T21:14:38.748517', 'swd_power_abs_up_2024-05-02T21:17:35.804311', 'swd_power_abs_down_2024-05-02T21:21:06.605376', 'swd_random_normal_2024-05-02T21:24:24.739239', 'swd_random_uniform_2024-05-02T21:26:43.975945'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.1,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.05 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.95303942199098 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.050000.json
# ThresholdS: [[0.95, [9500, 500], 1.2585838009098596], [0.99, [9900, 100], 3.6232993587626274]]
# Null distribution computed in 12.134801370964851 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.042308356962167 seconds.
# statistic = 4.802062830164175 - next threshold = 1.2585838009098596 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1693402519415192
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.025 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.509855541982688 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.025000.json
# ThresholdS: [[0.95, [9500, 500], 1.8852389542478352], [0.99, [9900, 100], 3.067596733215378]]
# Null distribution computed in 11.680288154981099 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.0671116260346025 seconds.
# statistic = 1.145084361268602 - next threshold = 1.8852389542478352 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.48849876129675873
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.037500000000000006 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# WARNING:tensorflow:5 out of the last 13 calls to <function LRMetric.Test_tf.<locals>.get_logprobs at 0x7efb7cfdee80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function LRMetric.Test_tf.<locals>.batched_test_sub at 0x7efb7cfdf7e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.568885551998392 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.037500.json
# ThresholdS: [[0.95, [9500, 500], 1.8858981410425084], [0.99, [9900, 100], 3.6594348094320845]]
# Null distribution computed in 11.738729920005426 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.023519776004832 seconds.
# statistic = 2.659586832263017 - next threshold = 1.8858981410425084 at 0.95 CL
# relative_error_eps = 0.40000000000000013
# relative_error_metric = 0.3404207453172479
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.03125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# WARNING:tensorflow:5 out of the last 13 calls to <function LRMetric.Test_tf.<locals>.get_logprobs at 0x7efc7b039940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function LRMetric.Test_tf.<locals>.batched_test_sub at 0x7efc7b03b100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.547334126953501 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.031250.json
# ThresholdS: [[0.95, [9500, 500], 1.9640652385213768], [0.99, [9900, 100], 3.4420124621587775]]
# Null distribution computed in 11.72880137199536 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.042478530027438 seconds.
# statistic = 1.8238389058978366 - next threshold = 1.9640652385213768 at 0.95 CL
# relative_error_eps = 0.18181818181818196
# relative_error_metric = 0.074039007998731
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.034375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.587189625017345 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.034375.json
# ThresholdS: [[0.95, [9500, 500], 1.9446058624855591], [0.99, [9900, 100], 3.5703478085402063]]
# Null distribution computed in 11.765179164998699 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.0239227379788645 seconds.
# statistic = 2.222088696368578 - next threshold = 1.9446058624855591 at 0.95 CL
# relative_error_eps = 0.09523809523809532
# relative_error_metric = 0.13319086866752636
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.0328125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.54244023800129 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.032813.json
# ThresholdS: [[0.95, [9500, 500], 1.9592415936948069], [0.99, [9900, 100], 3.5110861785614103]]
# Null distribution computed in 11.717260391975287 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.03013477800414 seconds.
# statistic = 2.018057757962448 - next threshold = 1.9592415936948069 at 0.95 CL
# relative_error_eps = 0.0487804878048781
# relative_error_metric = 0.029575930332291344
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.03203125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.505849779001437 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.032031.json
# ThresholdS: [[0.95, [9500, 500], 1.9628799268956367], [0.99, [9900, 100], 3.4777758311476386]]
# Null distribution computed in 11.676470658974722 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.984412510006223 seconds.
# statistic = 1.9197218211302496 - next threshold = 1.9628799268956367 at 0.95 CL
# relative_error_eps = 0.0240963855421688
# relative_error_metric = 0.022231538832089042
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.032421875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.498403595993295 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.032422.json
# ThresholdS: [[0.95, [9500, 500], 1.9613673879612388], [0.99, [9900, 100], 3.4947376325205415]]
# Null distribution computed in 11.669432957016397 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.98466625798028 seconds.
# statistic = 1.9685831618350567 - next threshold = 1.9613673879612388 at 0.95 CL
# relative_error_eps = 0.012121212121212293
# relative_error_metric = 0.0036721957604234534
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.0322265625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.45178062497871 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.032227.json
# ThresholdS: [[0.95, [9500, 500], 1.9622003143552316], [0.99, [9900, 100], 3.486333388760884]]
# Null distribution computed in 11.62334245099919 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.9605928510427475 seconds.
# statistic = 1.944075834568207 - next threshold = 1.9622003143552316 at 0.95 CL
# relative_error_eps = 0.006042296072507639
# relative_error_metric = 0.00927967153168096
# =======> statistic within required accuracy at 0.95 CL in 210.07973207504256 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.03232421875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.419682241044939 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.032324.json
# ThresholdS: [[0.95, [9500, 500], 1.9618030154002235], [0.99, [9900, 100], 3.4905546748621217]]
# Null distribution computed in 11.592277770978399 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.003526009968482 seconds.
# statistic = 1.9563103339575856 - next threshold = 3.4905546748621217 at 0.99 CL
# relative_error_eps = 1.022878228782288
# relative_error_metric = 0.5633495004632012
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.066162109375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.466486301040277 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.066162.json
# ThresholdS: [[0.95, [9500, 500], -0.48340219309696447], [0.99, [9900, 100], 2.645689194507332]]
# Null distribution computed in 11.635645122034475 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.922460616973694 seconds.
# statistic = 8.50310549886431 - next threshold = 2.645689194507332 at 0.99 CL
# relative_error_eps = 0.6871591472483887
# relative_error_metric = 1.0507712206485285
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.0492431640625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.563551852013916 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.049243.json
# ThresholdS: [[0.95, [9500, 500], 1.3144255895435253], [0.99, [9900, 100], 3.643347113076623]]
# Null distribution computed in 11.735753309039865 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.94523074105382 seconds.
# statistic = 4.654482738033457 - next threshold = 3.643347113076623 at 0.99 CL
# relative_error_eps = 0.41484585453457035
# relative_error_metric = 0.24371086009230833
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.04078369140625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.518813185044564 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.040784.json
# ThresholdS: [[0.95, [9500, 500], 1.7819205970801382], [0.99, [9900, 100], 3.710757188577636]]
# Null distribution computed in 11.68843903299421 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.936143609986175 seconds.
# statistic = 3.1615902414243005 - next threshold = 3.710757188577636 at 0.99 CL
# relative_error_eps = 0.18793220338983038
# relative_error_metric = 0.15981932018043526
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.045013427734375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.548016719985753 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.045013.json
# ThresholdS: [[0.95, [9500, 500], 1.5841246669741873], [0.99, [9900, 100], 3.7130037244277463]]
# Null distribution computed in 11.719359972979873 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.930153115012217 seconds.
# statistic = 3.872084916072697 - next threshold = 3.7130037244277463 at 0.99 CL
# relative_error_eps = 0.09859856299352629
# relative_error_metric = 0.041945769966494385
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.0428985595703125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.477051872003358 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.042899.json
# ThresholdS: [[0.95, [9500, 500], 1.6920105254067375], [0.99, [9900, 100], 3.720868349902845]]
# Null distribution computed in 11.645675089035649 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.96915636700578 seconds.
# statistic = 3.5078496853298224 - next threshold = 3.720868349902845 at 0.99 CL
# relative_error_eps = 0.04811330579373066
# relative_error_metric = 0.05893677510584114
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.04395599365234375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.420392771018669 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.043956.json
# ThresholdS: [[0.95, [9500, 500], 1.6403145695199215], [0.99, [9900, 100], 3.719183010535914]]
# Null distribution computed in 11.591443826968316 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.9389435179764405 seconds.
# statistic = 3.687720327351221 - next threshold = 3.719183010535914 at 0.99 CL
# relative_error_eps = 0.02377073078704107
# relative_error_metric = 0.00849550257359456
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.044484710693359374 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.40484162903158 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.044485.json
# ThresholdS: [[0.95, [9500, 500], 1.6127813615897089], [0.99, [9900, 100], 3.716655110886223]]
# Null distribution computed in 11.573763530992437 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.928370269015431 seconds.
# statistic = 3.779340878361073 - next threshold = 3.716655110886223 at 0.99 CL
# relative_error_eps = 0.011956418595422777
# relative_error_metric = 0.016725133675303507
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.04422035217285156 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.41421757498756 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_mean_0.044220.json
# ThresholdS: [[0.95, [9500, 500], 1.6266884014059135], [0.99, [9900, 100], 3.7180594965621667]]
# Null distribution computed in 11.586040080001112 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 5.922349756001495 seconds.
# statistic = 3.733390167037976 - next threshold = 3.7180594965621667 at 0.99 CL
# relative_error_eps = 0.005996132364838202
# relative_error_metric = 0.004114815550777592
# =======> statistic within required accuracy at 0.99 CL in 207.7192264070036 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 417.79899473203113 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# Computing exclusion limits for lr with cov_diag deformation.
#
# ======================================================
# =============== lr - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.05 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.485672479961067 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_cov_diag_0.050000.json
# ThresholdS: [[0.95, [9500, 500], -85.61161142883428], [0.99, [9900, 100], -73.99655669752022]]
# Null distribution computed in 11.669567608041689 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.382885688974056 seconds.
# statistic = 126.77421352729407 - next threshold = -85.61161142883428 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 10.319358550176561
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.025 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.471200256957673 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_cov_diag_0.025000.json
# ThresholdS: [[0.95, [9500, 500], -15.13162595021384], [0.99, [9900, 100], -8.96906320495002]]
# Null distribution computed in 11.650266021024436 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.287530275993049 seconds.
# statistic = 32.38093694037523 - next threshold = -15.13162595021384 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 5.5089229845399785
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.0125 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.437701250019018 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_cov_diag_0.012500.json
# ThresholdS: [[0.95, [9500, 500], -0.09410496252873644], [0.99, [9900, 100], 3.043210331484268]]
# Null distribution computed in 11.616048233001493 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.328584567003418 seconds.
# statistic = 8.4092719498281 - next threshold = -0.09410496252873644 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.0452690668377302
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.00625 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.467116712999996 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_cov_diag_0.006250.json
# ThresholdS: [[0.95, [9500, 500], 1.8754601977905234], [0.99, [9900, 100], 3.4422566068337637]]
# Null distribution computed in 11.649188975046854 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.297368892002851 seconds.
# statistic = 2.2555302908590305 - next threshold = 1.8754601977905234 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.18400918332433844
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.003125 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.41385634400649 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_cov_diag_0.003125.json
# ThresholdS: [[0.95, [9500, 500], 1.4277427452791644], [0.99, [9900, 100], 2.211773229886848]]
# Null distribution computed in 11.59428736299742 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.301738362002652 seconds.
# statistic = 0.640006463109021 - next threshold = 1.4277427452791644 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7619263293387358
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.004687500000000001 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.5031365469913 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_cov_diag_0.004688.json
# ...
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.079464731970802 seconds.
# statistic = 10.007818159365529 - next threshold = 2.8782266896462265 at 0.99 CL
# relative_error_eps = 0.9557684891275328
# relative_error_metric = 1.1065600893459686
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.003214740753173828 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.678776634973474 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_power_abs_down_0.003215.json
# ThresholdS: [[0.95, [9500, 500], 1.5992973564009305], [0.99, [9900, 100], 3.678488018634867]]
# Null distribution computed in 11.845991698035505 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.121406388003379 seconds.
# statistic = 5.0589352842043205 - next threshold = 3.678488018634867 at 0.99 CL
# relative_error_eps = 0.6279210275000489
# relative_error_metric = 0.3159849804051231
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.002446603775024414 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.724753848044202 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_power_abs_down_0.002447.json
# ThresholdS: [[0.95, [9500, 500], 1.8795013361604698], [0.99, [9900, 100], 3.4554113844261005]]
# Null distribution computed in 11.88632306701038 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.04026410903316 seconds.
# statistic = 3.1960454679548276 - next threshold = 3.4554113844261005 at 0.99 CL
# relative_error_eps = 0.27136203222518895
# relative_error_metric = 0.07798770171031971
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.0028306722640991213 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.70397018600488 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_power_abs_down_0.002831.json
# ThresholdS: [[0.95, [9500, 500], 1.7919067383814775], [0.99, [9900, 100], 3.6199900456344016]]
# Null distribution computed in 11.869605714979116 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.055042384949047 seconds.
# statistic = 4.076453534284118 - next threshold = 3.6199900456344016 at 0.99 CL
# relative_error_eps = 0.1455555806546343
# relative_error_metric = 0.11861673093809622
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.0026386380195617676 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.704475275997538 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_power_abs_down_0.002639.json
# ThresholdS: [[0.95, [9500, 500], 1.8488083866118163], [0.99, [9900, 100], 3.550641574502553]]
# Null distribution computed in 11.867231492011342 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.059998293989338 seconds.
# statistic = 3.6234585153012926 - next threshold = 3.550641574502553 at 0.99 CL
# relative_error_eps = 0.07552610172511207
# relative_error_metric = 0.020299951181955354
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0025426208972930907 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.706823915999848 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_power_abs_down_0.002543.json
# ThresholdS: [[0.95, [9500, 500], 1.867427548018094], [0.99, [9900, 100], 3.506258339958777]]
# Null distribution computed in 11.864822402014397 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.008269991027191 seconds.
# statistic = 3.4065527782573914 - next threshold = 3.506258339958777 at 0.99 CL
# relative_error_eps = 0.037063240347371566
# relative_error_metric = 0.02884660379006979
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0025906294584274294 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.743482763995416 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_power_abs_down_0.002591.json
# ThresholdS: [[0.95, [9500, 500], 1.8589307848054428], [0.99, [9900, 100], 3.5292721162161573]]
# Null distribution computed in 11.905168354976922 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.089175276982132 seconds.
# statistic = 3.5142733474349668 - next threshold = 3.5292721162161573 at 0.99 CL
# relative_error_eps = 0.01836148613029023
# relative_error_metric = 0.00425886901947126
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0026146337389945985 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 11.690966453985311 seconds.
# Saving lr to results/5D_unimodal/5D_10K/null_hypothesis/LR_power_abs_down_0.002615.json
# ThresholdS: [[0.95, [9500, 500], 1.8540803207949443], [0.99, [9900, 100], 3.540145469669757]]
# Null distribution computed in 11.854385618993547 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 10000
# LR metric calculation completed in 6.079492299002595 seconds.
# statistic = 3.568598480803006 - next threshold = 3.540145469669757 at 0.99 CL
# relative_error_eps = 0.009223080430998195
# relative_error_metric = 0.008005074126029417
# =======> statistic within required accuracy at 0.99 CL in 306.2024488989846 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 611.7643842310063 seconds.
# Saving results in the file results/5D_unimodal/5D_10K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T19:30:01.649463', 'fgd_cov_diag_2024-05-02T19:33:22.654163', 'fgd_cov_off_diag_2024-05-02T19:37:08.617244', 'fgd_power_abs_up_2024-05-02T19:41:16.835343', 'fgd_power_abs_down_2024-05-02T19:45:30.977660', 'fgd_random_normal_2024-05-02T19:50:13.940820', 'fgd_random_uniform_2024-05-02T19:52:40.321873', 'mmd_mean_2024-05-02T19:55:09.442119', 'mmd_cov_diag_2024-05-02T19:58:20.969311', 'mmd_cov_off_diag_2024-05-02T20:02:12.422198', 'mmd_power_abs_up_2024-05-02T20:05:40.543427', 'mmd_power_abs_down_2024-05-02T20:10:12.208573', 'mmd_random_normal_2024-05-02T20:14:34.917945', 'mmd_random_uniform_2024-05-02T20:17:59.507944', 'ks_mean_2024-05-02T20:20:58.834464', 'ks_cov_diag_2024-05-02T20:23:41.210805', 'ks_cov_off_diag_2024-05-02T20:26:40.106738', 'ks_power_abs_up_2024-05-02T20:29:01.513600', 'ks_power_abs_down_2024-05-02T20:32:14.522542', 'ks_random_normal_2024-05-02T20:35:35.686582', 'ks_random_uniform_2024-05-02T20:38:10.074802', 'sks_mean_2024-05-02T20:40:29.040247', 'sks_cov_diag_2024-05-02T20:44:06.439735', 'sks_cov_off_diag_2024-05-02T20:48:18.398705', 'sks_power_abs_up_2024-05-02T20:52:38.982733', 'sks_power_abs_down_2024-05-02T20:57:30.741969', 'sks_random_normal_2024-05-02T21:02:20.352327', 'sks_random_uniform_2024-05-02T21:05:44.418903', 'swd_mean_2024-05-02T21:08:52.670000', 'swd_cov_diag_2024-05-02T21:11:35.111247', 'swd_cov_off_diag_2024-05-02T21:14:38.748517', 'swd_power_abs_up_2024-05-02T21:17:35.804311', 'swd_power_abs_down_2024-05-02T21:21:06.605376', 'swd_random_normal_2024-05-02T21:24:24.739239', 'swd_random_uniform_2024-05-02T21:26:43.975945', 'lr_mean_2024-05-02T21:29:02.606752', 'lr_cov_diag_2024-05-02T21:36:00.415420', 'lr_cov_off_diag_2024-05-02T21:45:10.853294', 'lr_power_abs_up_2024-05-02T21:58:08.585653', 'lr_power_abs_down_2024-05-02T22:07:52.541868'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean    5  10000                10000
# 14        ks        mean    5  10000                10000
# 0        fgd        mean    5  10000                10000
# 28       swd        mean    5  10000                10000
# 21       sks        mean    5  10000                10000
# 7        mmd        mean    5  10000                10000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.03232                             0.04409
# 14                             0.09338                             0.11794
# 0                              0.10803                             0.14117
# 28                             0.10803                             0.14267
# 21                             0.11169                             0.14630
# 7                              0.11780                             0.16905
#
#     $t^{\mu}$ (s)
# 35            417
# 14            162
# 0             201
# 28            162
# 21            217
# 7             191
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.03232
# 14        ks                             0.09338
# 0        fgd                             0.10803
# 28       swd                             0.10803
# 21       sks                             0.11169
# 7        mmd                             0.11780
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.04409            417
# 14                             0.11794            162
# 0                              0.14117            201
# 28                             0.14267            162
# 21                             0.14630            217
# 7                              0.16905            191

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag    5  10000                10000
# 1        fgd    cov_diag    5  10000                10000
# 8        mmd    cov_diag    5  10000                10000
# 29       swd    cov_diag    5  10000                10000
# 22       sks    cov_diag    5  10000                10000
# 15        ks    cov_diag    5  10000                10000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00564
# 1                                      0.02663
# 8                                      0.03387
# 29                                     0.03387
# 22                                     0.04425
# 15                                     0.05341
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00815                    550
# 1                                      0.03847                    225
# 8                                      0.04827                    231
# 29                                     0.04691                    183
# 22                                     0.06300                    251
# 15                                     0.07212                    178
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00564
# 1        fgd                                     0.02663
# 8        mmd                                     0.03387
# 29       swd                                     0.03387
# 22       sks                                     0.04425
# 15        ks                                     0.05341
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00815                    550
# 1                                      0.03847                    225
# 8                                      0.04827                    231
# 29                                     0.04691                    183
# 22                                     0.06300                    251
# 15                                     0.07212                    178

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag    5  10000                10000
# 2        fgd  cov_off_diag    5  10000                10000
# 23       sks  cov_off_diag    5  10000                10000
# 30       swd  cov_off_diag    5  10000                10000
# 9        mmd  cov_off_diag    5  10000                10000
# 16        ks  cov_off_diag    5  10000                10000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00069
# 2                                           0.01173
# 23                                          0.03326
# 30                                          0.03693
# 9                                           0.06287
# 16                                          1.04492
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00097
# 2                                           0.01645
# 23                                          0.04994
# 30                                          0.05419
# 9                                           0.08999
# 16                                          1.04589
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                         777
# 2                          248
# 23                         260
# 30                         177
# 9                          208
# 16                         141
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00069
# 2        fgd                                          0.01173
# 23       sks                                          0.03326
# 30       swd                                          0.03693
# 9        mmd                                          0.06287
# 16        ks                                          1.04492
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00097
# 2                                           0.01645
# 23                                          0.04994
# 30                                          0.05419
# 9                                           0.08999
# 16                                          1.04589
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                         777
# 2                          248
# 23                         260
# 30                         177
# 9                          208
# 16                         141

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up    5  10000                10000
# 10       mmd  power_abs_up    5  10000                10000
# 3        fgd  power_abs_up    5  10000                10000
# 31       swd  power_abs_up    5  10000                10000
# 24       sks  power_abs_up    5  10000                10000
# 17        ks  power_abs_up    5  10000                10000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00297
# 10                                      0.00629
# 3                                       0.00856
# 31                                      0.00954
# 24                                      0.01091
# 17                                      0.01274
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00388                     583
# 10                                      0.00908                     271
# 3                                       0.01153                     254
# 31                                      0.01312                     210
# 24                                      0.01434                     291
# 17                                      0.01624                     193
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00297
# 10       mmd                                      0.00629
# 3        fgd                                      0.00856
# 31       swd                                      0.00954
# 24       sks                                      0.01091
# 17        ks                                      0.01274
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00388                     583
# 10                                      0.00908                     271
# 3                                       0.01153                     254
# 31                                      0.01312                     210
# 24                                      0.01434                     291
# 17                                      0.01624                     193

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down    5  10000                10000
# 11       mmd  power_abs_down    5  10000                10000
# 4        fgd  power_abs_down    5  10000                10000
# 32       swd  power_abs_down    5  10000                10000
# 25       sks  power_abs_down    5  10000                10000
# 18        ks  power_abs_down    5  10000                10000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00168
# 11                                      0.00698
# 4                                       0.00826
# 32                                      0.00923
# 25                                      0.01045
# 18                                      0.01335
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00260                     611
# 11                                      0.01010                     262
# 4                                       0.01123                     282
# 32                                      0.01296                     198
# 25                                      0.01373                     289
# 18                                      0.01685                     201
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00168
# 11       mmd                                      0.00698
# 4        fgd                                      0.00826
# 32       swd                                      0.00923
# 25       sks                                      0.01045
# 18        ks                                      0.01335
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00260                     611
# 11                                      0.01010                     262
# 4                                       0.01123                     282
# 32                                      0.01296                     198
# 25                                      0.01373                     289
# 18                                      0.01685                     201

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        fgd  random_normal    5  10000                10000
# 19        ks  random_normal    5  10000                10000
# 26       sks  random_normal    5  10000                10000
# 33       swd  random_normal    5  10000                10000
# 12       mmd  random_normal    5  10000                10000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                                      0.27588
# 19                                     0.30396
# 26                                     0.34912
# 33                                     0.36377
# 12                                     0.78094
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.32432                    146
# 19                                     0.34294                    154
# 26                                     0.42860                    204
# 33                                     0.43395                    139
# 12                                     0.95193                    204
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        fgd                                     0.27588
# 19        ks                                     0.30396
# 26       sks                                     0.34912
# 33       swd                                     0.36377
# 12       mmd                                     0.78094
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.32432                    146
# 19                                     0.34294                    154
# 26                                     0.42860                    204
# 33                                     0.43395                    139
# 12                                     0.95193                    204

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform    5  10000                10000
# 20        ks  random_uniform    5  10000                10000
# 27       sks  random_uniform    5  10000                10000
# 34       swd  random_uniform    5  10000                10000
# 13       mmd  random_uniform    5  10000                10000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                                      0.48279
# 20                                     0.49316
# 27                                     0.60059
# 34                                     0.62988
# 13                                     1.34155
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.56660                    149
# 20                                     0.59219                    138
# 27                                     0.71873                    188
# 34                                     0.76218                    138
# 13                                     1.63809                    179
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                                     0.48279
# 20        ks                                     0.49316
# 27       sks                                     0.60059
# 34       swd                                     0.62988
# 13       mmd                                     1.34155
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.56660                    149
# 20                                     0.59219                    138
# 27                                     0.71873                    188
# 34                                     0.76218                    138
# 13                                     1.63809                    179

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.11 & 0.14 & 201 & cov_diag & 5 & 10000 & 10000 & 0.027 & 0.038 & 225 & cov_off_diag & 5 & 10000 & 10000 & 0.012 & 0.016 & 248 & 0.0086 & 0.012 & 254 \\
# $\overline{D}$ & 0.093 & 0.12 & 162 & cov_diag & 5 & 10000 & 10000 & 0.053 & 0.072 & 178 & cov_off_diag & 5 & 10000 & 10000 & 1 & 1 & 141 & 0.013 & 0.016 & 193 \\
# $t_{\mathrm{LLR}}$ & 0.032 & 0.044 & 417 & cov_diag & 5 & 10000 & 10000 & 0.0056 & 0.0081 & 550 & cov_off_diag & 5 & 10000 & 10000 & 0.00069 & 0.00097 & 777 & 0.003 & 0.0039 & 583 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.12 & 0.17 & 191 & cov_diag & 5 & 10000 & 10000 & 0.034 & 0.048 & 231 & cov_off_diag & 5 & 10000 & 10000 & 0.063 & 0.09 & 208 & 0.0063 & 0.0091 & 271 \\
# $\widetilde{D}$ & 0.11 & 0.15 & 217 & cov_diag & 5 & 10000 & 10000 & 0.044 & 0.063 & 251 & cov_off_diag & 5 & 10000 & 10000 & 0.033 & 0.05 & 260 & 0.011 & 0.014 & 291 \\
# $\widetilde{W}$ & 0.11 & 0.14 & 162 & cov_diag & 5 & 10000 & 10000 & 0.034 & 0.047 & 183 & cov_off_diag & 5 & 10000 & 10000 & 0.037 & 0.054 & 177 & 0.0095 & 0.013 & 210 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.0083 & 0.011 & 282 & 0.28 & 0.32 & 1.5e+02 & 0.48 & 0.57 & 1.5e+02 & 381 \\
# $\overline{D}$ & 0.013 & 0.017 & 201 & 0.3 & 0.34 & 1.5e+02 & 0.49 & 0.59 & 1.4e+02 & 30 \\
# $t_{\mathrm{LLR}}$ & 0.0017 & 0.0026 & 611 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.007 & 0.01 & 262 & 0.78 & 0.95 & 2e+02 & 1.3 & 1.6 & 1.8e+02 & 204 \\
# $\widetilde{D}$ & 0.01 & 0.014 & 289 & 0.35 & 0.43 & 2e+02 & 0.6 & 0.72 & 1.9e+02 & 351 \\
# $\widetilde{W}$ & 0.0092 & 0.013 & 198 & 0.36 & 0.43 & 1.4e+02 & 0.63 & 0.76 & 1.4e+02 & 259 \\
# \bottomrule
# \end{tabular}
