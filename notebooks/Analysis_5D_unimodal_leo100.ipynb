# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [3]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/5D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-02 19:12:09.869136: Importing os...
# 2024-05-02 19:12:09.869396: Importing sys...
# Visible devices: [3]
# 2024-05-02 19:12:09.869650: Importing timer from timeit...
# 2024-05-02 19:12:09.869719: Setting env variables for tf import (only device(s) [3] will be available)...
# 2024-05-02 19:12:09.869856: Importing numpy...
# 2024-05-02 19:12:10.027086: Importing matplotlib...
# 2024-05-02 19:12:10.456617: Importing h5py...
# 2024-05-02 19:12:10.488120: Importing importlib.util...
# 2024-05-02 19:12:10.488251: Importing json...
# 2024-05-02 19:12:10.488318: Importing pandas...
# 2024-05-02 19:12:11.054056: Importing random...
# 2024-05-02 19:12:11.054225: Importing scipy utils...
# 2024-05-02 19:12:11.523020: Importing subprocess...
# 2024-05-02 19:12:11.523180: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-02 19:12:15.723924: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-02 19:12:17.187323: Importing timeit...
# 2024-05-02 19:12:17.187425: Importing tqdm...
# 2024-05-02 19:12:17.198045: Importing typing...
# 2024-05-02 19:12:17.198179: Setting tf configs...
# 2024-05-02 19:12:17.308142: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-02 19:12:22.969659: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #3, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-02 19:12:23.002055: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)
# sample from dist_1:  tf.Tensor(
# [[ 1.1610332  -2.23691168 -2.20072828  5.13732308  1.32224517]
#  [-2.52914258 -0.85839971 -1.86610514  1.33679732 -0.66477288]], shape=(2, 5), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[ 1.1610332  -2.23691168 -2.20072828  5.13732308  1.32224517]
#  [-2.52914258 -0.85839971 -1.86610514  1.33679732 -0.66477288]], shape=(2, 5), dtype=float64)

# %% [markdown]
# # Fixed $n=100000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 100_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 1000000000
# batch_size 100000
# niter 10000
# niter * batch_size 1000000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000           100000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims    nsamples  small_sample  \
# 0       True        5           0  float64     5  1000000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/5D_unimodal/5D_100K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/5D_unimodal/5D_100K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 2000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/5D_unimodal/5D_100K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/5D_unimodal/5D_100K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/5D_unimodal/5D_100K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 200,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/5D_unimodal/5D_100K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 500
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714669948.549510  166510 service.cc:145] XLA service 0x10c66c0d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714669948.549563  166510 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1714669951.814769  166510 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# FGD metric calculation completed in 2268.633506648999 seconds.
# Saving fgd to results/5D_unimodal/5D_100K/null_hypothesis/FGD.json
# Computing and savng mmd with max_vectorize = 1
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10000
# Iterating from 0 to 1 out of 10000 .
# Iterating from 1 to 2 out of 10000 .
# Iterating from 2 to 3 out of 10000 .
# Iterating from 3 to 4 out of 10000 .
# Iterating from 4 to 5 out of 10000 .
# Iterating from 5 to 6 out of 10000 .
# Iterating from 6 to 7 out of 10000 .
# Iterating from 7 to 8 out of 10000 .
# Iterating from 8 to 9 out of 10000 .
# Iterating from 9 to 10 out of 10000 .
# Iterating from 10 to 11 out of 10000 .
# Iterating from 11 to 12 out of 10000 .
# Iterating from 12 to 13 out of 10000 .
# Iterating from 13 to 14 out of 10000 .
# Iterating from 14 to 15 out of 10000 .
# Iterating from 15 to 16 out of 10000 .
# Iterating from 16 to 17 out of 10000 .
# Iterating from 17 to 18 out of 10000 .
# Iterating from 18 to 19 out of 10000 .
# Iterating from 19 to 20 out of 10000 .
# Iterating from 20 to 21 out of 10000 .
# Iterating from 21 to 22 out of 10000 .
# Iterating from 22 to 23 out of 10000 .
# Iterating from 23 to 24 out of 10000 .
# Iterating from 24 to 25 out of 10000 .
# Iterating from 25 to 26 out of 10000 .
# Iterating from 26 to 27 out of 10000 .
# Iterating from 27 to 28 out of 10000 .
# Iterating from 28 to 29 out of 10000 .
# Iterating from 29 to 30 out of 10000 .
# Iterating from 30 to 31 out of 10000 .
# Iterating from 31 to 32 out of 10000 .
# Iterating from 32 to 33 out of 10000 .
# Iterating from 33 to 34 out of 10000 .
# Iterating from 34 to 35 out of 10000 .
# Iterating from 35 to 36 out of 10000 .
# Iterating from 36 to 37 out of 10000 .
# Iterating from 37 to 38 out of 10000 .
# Iterating from 38 to 39 out of 10000 .
# Iterating from 39 to 40 out of 10000 .
# Iterating from 40 to 41 out of 10000 .
# Iterating from 41 to 42 out of 10000 .
# Iterating from 42 to 43 out of 10000 .
# Iterating from 43 to 44 out of 10000 .
# Iterating from 44 to 45 out of 10000 .
# Iterating from 45 to 46 out of 10000 .
# Iterating from 46 to 47 out of 10000 .
# Iterating from 47 to 48 out of 10000 .
# Iterating from 48 to 49 out of 10000 .
# Iterating from 49 to 50 out of 10000 .
# Iterating from 50 to 51 out of 10000 .
# Iterating from 51 to 52 out of 10000 .
# Iterating from 52 to 53 out of 10000 .
# Iterating from 53 to 54 out of 10000 .
# Iterating from 54 to 55 out of 10000 .
# Iterating from 55 to 56 out of 10000 .
# Iterating from 56 to 57 out of 10000 .
# Iterating from 57 to 58 out of 10000 .
# Iterating from 58 to 59 out of 10000 .
# Iterating from 59 to 60 out of 10000 .
# Iterating from 60 to 61 out of 10000 .
# Iterating from 61 to 62 out of 10000 .
# Iterating from 62 to 63 out of 10000 .
# Iterating from 63 to 64 out of 10000 .
# Iterating from 64 to 65 out of 10000 .
# Iterating from 65 to 66 out of 10000 .
# Iterating from 66 to 67 out of 10000 .
# Iterating from 67 to 68 out of 10000 .
# Iterating from 68 to 69 out of 10000 .
# Iterating from 69 to 70 out of 10000 .
# Iterating from 70 to 71 out of 10000 .
# Iterating from 71 to 72 out of 10000 .
# Iterating from 72 to 73 out of 10000 .
# Iterating from 73 to 74 out of 10000 .
# Iterating from 74 to 75 out of 10000 .
# Iterating from 75 to 76 out of 10000 .
# Iterating from 76 to 77 out of 10000 .
# Iterating from 77 to 78 out of 10000 .
# Iterating from 78 to 79 out of 10000 .
# Iterating from 79 to 80 out of 10000 .
# Iterating from 80 to 81 out of 10000 .
# Iterating from 81 to 82 out of 10000 .
# Iterating from 82 to 83 out of 10000 .
# Iterating from 83 to 84 out of 10000 .
# Iterating from 84 to 85 out of 10000 .
# Iterating from 85 to 86 out of 10000 .
# Iterating from 86 to 87 out of 10000 .
# Iterating from 87 to 88 out of 10000 .
# Iterating from 88 to 89 out of 10000 .
# Iterating from 89 to 90 out of 10000 .
# Iterating from 90 to 91 out of 10000 .
# Iterating from 91 to 92 out of 10000 .
# Iterating from 92 to 93 out of 10000 .
# Iterating from 93 to 94 out of 10000 .
# Iterating from 94 to 95 out of 10000 .
# Iterating from 95 to 96 out of 10000 .
# Iterating from 96 to 97 out of 10000 .
# Iterating from 97 to 98 out of 10000 .
# Iterating from 98 to 99 out of 10000 .
# Iterating from 99 to 100 out of 10000 .
# Iterating from 100 to 101 out of 10000 .
# Iterating from 101 to 102 out of 10000 .
# Iterating from 102 to 103 out of 10000 .
# Iterating from 103 to 104 out of 10000 .
# Iterating from 104 to 105 out of 10000 .
# Iterating from 105 to 106 out of 10000 .
# Iterating from 106 to 107 out of 10000 .
# Iterating from 107 to 108 out of 10000 .
# Iterating from 108 to 109 out of 10000 .
# Iterating from 109 to 110 out of 10000 .
# Iterating from 110 to 111 out of 10000 .
# Iterating from 111 to 112 out of 10000 .
# Iterating from 112 to 113 out of 10000 .
# Iterating from 113 to 114 out of 10000 .
# Iterating from 114 to 115 out of 10000 .
# Iterating from 115 to 116 out of 10000 .
# Iterating from 116 to 117 out of 10000 .
# Iterating from 117 to 118 out of 10000 .
# Iterating from 118 to 119 out of 10000 .
# Iterating from 119 to 120 out of 10000 .
# Iterating from 120 to 121 out of 10000 .
# Iterating from 121 to 122 out of 10000 .
# Iterating from 122 to 123 out of 10000 .
# Iterating from 123 to 124 out of 10000 .
# Iterating from 124 to 125 out of 10000 .
# Iterating from 125 to 126 out of 10000 .
# Iterating from 126 to 127 out of 10000 .
# Iterating from 127 to 128 out of 10000 .
# Iterating from 128 to 129 out of 10000 .
# Iterating from 129 to 130 out of 10000 .
# Iterating from 130 to 131 out of 10000 .
# Iterating from 131 to 132 out of 10000 .
# Iterating from 132 to 133 out of 10000 .
# Iterating from 133 to 134 out of 10000 .
# Iterating from 134 to 135 out of 10000 .
# Iterating from 135 to 136 out of 10000 .
# Iterating from 136 to 137 out of 10000 .
# Iterating from 137 to 138 out of 10000 .
# Iterating from 138 to 139 out of 10000 .
# Iterating from 139 to 140 out of 10000 .
# Iterating from 140 to 141 out of 10000 .
# Iterating from 141 to 142 out of 10000 .
# Iterating from 142 to 143 out of 10000 .
# Iterating from 143 to 144 out of 10000 .
# Iterating from 144 to 145 out of 10000 .
# Iterating from 145 to 146 out of 10000 .
# Iterating from 146 to 147 out of 10000 .
# Iterating from 147 to 148 out of 10000 .
# Iterating from 148 to 149 out of 10000 .
# Iterating from 149 to 150 out of 10000 .
# Iterating from 150 to 151 out of 10000 .
# Iterating from 151 to 152 out of 10000 .
# Iterating from 152 to 153 out of 10000 .
# Iterating from 153 to 154 out of 10000 .
# Iterating from 154 to 155 out of 10000 .
# Iterating from 155 to 156 out of 10000 .
# Iterating from 156 to 157 out of 10000 .
# Iterating from 157 to 158 out of 10000 .
# Iterating from 158 to 159 out of 10000 .
# Iterating from 159 to 160 out of 10000 .
# Iterating from 160 to 161 out of 10000 .
# Iterating from 161 to 162 out of 10000 .
# Iterating from 162 to 163 out of 10000 .
# Iterating from 163 to 164 out of 10000 .
# Iterating from 164 to 165 out of 10000 .
# Iterating from 165 to 166 out of 10000 .
# Iterating from 166 to 167 out of 10000 .
# Iterating from 167 to 168 out of 10000 .
# Iterating from 168 to 169 out of 10000 .
# Iterating from 169 to 170 out of 10000 .
# Iterating from 170 to 171 out of 10000 .
# Iterating from 171 to 172 out of 10000 .
# Iterating from 172 to 173 out of 10000 .
# Iterating from 173 to 174 out of 10000 .
# Iterating from 174 to 175 out of 10000 .
# Iterating from 175 to 176 out of 10000 .
# Iterating from 176 to 177 out of 10000 .
# Iterating from 177 to 178 out of 10000 .
# Iterating from 178 to 179 out of 10000 .
# Iterating from 179 to 180 out of 10000 .
# Iterating from 180 to 181 out of 10000 .
# Iterating from 181 to 182 out of 10000 .
# Iterating from 182 to 183 out of 10000 .
# Iterating from 183 to 184 out of 10000 .
# Iterating from 184 to 185 out of 10000 .
# Iterating from 185 to 186 out of 10000 .
# Iterating from 186 to 187 out of 10000 .
# Iterating from 187 to 188 out of 10000 .
# Iterating from 188 to 189 out of 10000 .
# Iterating from 189 to 190 out of 10000 .
# Iterating from 190 to 191 out of 10000 .
# Iterating from 191 to 192 out of 10000 .
# Iterating from 192 to 193 out of 10000 .
# Iterating from 193 to 194 out of 10000 .
# Iterating from 194 to 195 out of 10000 .
# Iterating from 195 to 196 out of 10000 .
# Iterating from 196 to 197 out of 10000 .
# Iterating from 197 to 198 out of 10000 .
# Iterating from 198 to 199 out of 10000 .
# Iterating from 199 to 200 out of 10000 .
# Iterating from 200 to 201 out of 10000 .
# Iterating from 201 to 202 out of 10000 .
# Iterating from 202 to 203 out of 10000 .
# Iterating from 203 to 204 out of 10000 .
# Iterating from 204 to 205 out of 10000 .
# Iterating from 205 to 206 out of 10000 .
# Iterating from 206 to 207 out of 10000 .
# Iterating from 207 to 208 out of 10000 .
# Iterating from 208 to 209 out of 10000 .
# Iterating from 209 to 210 out of 10000 .
# Iterating from 210 to 211 out of 10000 .
# Iterating from 211 to 212 out of 10000 .
# Iterating from 212 to 213 out of 10000 .
# Iterating from 213 to 214 out of 10000 .
# Iterating from 214 to 215 out of 10000 .
# Iterating from 215 to 216 out of 10000 .
# Iterating from 216 to 217 out of 10000 .
# Iterating from 217 to 218 out of 10000 .
# Iterating from 218 to 219 out of 10000 .
# Iterating from 219 to 220 out of 10000 .
# Iterating from 220 to 221 out of 10000 .
# Iterating from 221 to 222 out of 10000 .
# Iterating from 222 to 223 out of 10000 .
# Iterating from 223 to 224 out of 10000 .
# Iterating from 224 to 225 out of 10000 .
# Iterating from 225 to 226 out of 10000 .
# Iterating from 226 to 227 out of 10000 .
# Iterating from 227 to 228 out of 10000 .
# Iterating from 228 to 229 out of 10000 .
# Iterating from 229 to 230 out of 10000 .
# Iterating from 230 to 231 out of 10000 .
# Iterating from 231 to 232 out of 10000 .
# Iterating from 232 to 233 out of 10000 .
# Iterating from 233 to 234 out of 10000 .
# Iterating from 234 to 235 out of 10000 .
# Iterating from 235 to 236 out of 10000 .
# Iterating from 236 to 237 out of 10000 .
# Iterating from 237 to 238 out of 10000 .
# Iterating from 238 to 239 out of 10000 .
# Iterating from 239 to 240 out of 10000 .
# Iterating from 240 to 241 out of 10000 .
# Iterating from 241 to 242 out of 10000 .
# Iterating from 242 to 243 out of 10000 .
# Iterating from 243 to 244 out of 10000 .
# Iterating from 244 to 245 out of 10000 .
# Iterating from 245 to 246 out of 10000 .
# Iterating from 246 to 247 out of 10000 .
# Iterating from 247 to 248 out of 10000 .
# Iterating from 248 to 249 out of 10000 .
# Iterating from 249 to 250 out of 10000 .
# Iterating from 250 to 251 out of 10000 .
# Iterating from 251 to 252 out of 10000 .
# Iterating from 252 to 253 out of 10000 .
# Iterating from 253 to 254 out of 10000 .
# Iterating from 254 to 255 out of 10000 .
# Iterating from 255 to 256 out of 10000 .
# Iterating from 256 to 257 out of 10000 .
# Iterating from 257 to 258 out of 10000 .
# Iterating from 258 to 259 out of 10000 .
# Iterating from 259 to 260 out of 10000 .
# Iterating from 260 to 261 out of 10000 .
# Iterating from 261 to 262 out of 10000 .
# Iterating from 262 to 263 out of 10000 .
# Iterating from 263 to 264 out of 10000 .
# Iterating from 264 to 265 out of 10000 .
# Iterating from 265 to 266 out of 10000 .
# Iterating from 266 to 267 out of 10000 .
# Iterating from 267 to 268 out of 10000 .
# Iterating from 268 to 269 out of 10000 .
# Iterating from 269 to 270 out of 10000 .
# Iterating from 270 to 271 out of 10000 .
# Iterating from 271 to 272 out of 10000 .
# Iterating from 272 to 273 out of 10000 .
# Iterating from 273 to 274 out of 10000 .
# Iterating from 274 to 275 out of 10000 .
# Iterating from 275 to 276 out of 10000 .
# Iterating from 276 to 277 out of 10000 .
# Iterating from 277 to 278 out of 10000 .
# Iterating from 278 to 279 out of 10000 .
# Iterating from 279 to 280 out of 10000 .
# Iterating from 280 to 281 out of 10000 .
# Iterating from 281 to 282 out of 10000 .
# Iterating from 282 to 283 out of 10000 .
# Iterating from 283 to 284 out of 10000 .
# Iterating from 284 to 285 out of 10000 .
# Iterating from 285 to 286 out of 10000 .
# Iterating from 286 to 287 out of 10000 .
# Iterating from 287 to 288 out of 10000 .
# Iterating from 288 to 289 out of 10000 .
# Iterating from 289 to 290 out of 10000 .
# Iterating from 290 to 291 out of 10000 .
# Iterating from 291 to 292 out of 10000 .
# Iterating from 292 to 293 out of 10000 .
# Iterating from 293 to 294 out of 10000 .
# Iterating from 294 to 295 out of 10000 .
# Iterating from 295 to 296 out of 10000 .
# Iterating from 296 to 297 out of 10000 .
# Iterating from 297 to 298 out of 10000 .
# Iterating from 298 to 299 out of 10000 .
# Iterating from 299 to 300 out of 10000 .
# Iterating from 300 to 301 out of 10000 .
# Iterating from 301 to 302 out of 10000 .
# Iterating from 302 to 303 out of 10000 .
# Iterating from 303 to 304 out of 10000 .
# Iterating from 304 to 305 out of 10000 .
# Iterating from 305 to 306 out of 10000 .
# Iterating from 306 to 307 out of 10000 .
# Iterating from 307 to 308 out of 10000 .
# Iterating from 308 to 309 out of 10000 .
# Iterating from 309 to 310 out of 10000 .
# Iterating from 310 to 311 out of 10000 .
# Iterating from 311 to 312 out of 10000 .
# Iterating from 312 to 313 out of 10000 .
# Iterating from 313 to 314 out of 10000 .
# Iterating from 314 to 315 out of 10000 .
# Iterating from 315 to 316 out of 10000 .
# Iterating from 316 to 317 out of 10000 .
# Iterating from 317 to 318 out of 10000 .
# Iterating from 318 to 319 out of 10000 .
# Iterating from 319 to 320 out of 10000 .
# Iterating from 320 to 321 out of 10000 .
# Iterating from 321 to 322 out of 10000 .
# Iterating from 322 to 323 out of 10000 .
# Iterating from 323 to 324 out of 10000 .
# Iterating from 324 to 325 out of 10000 .
# Iterating from 325 to 326 out of 10000 .
# Iterating from 326 to 327 out of 10000 .
# Iterating from 327 to 328 out of 10000 .
# Iterating from 328 to 329 out of 10000 .
# Iterating from 329 to 330 out of 10000 .
# Iterating from 330 to 331 out of 10000 .
# Iterating from 331 to 332 out of 10000 .
# Iterating from 332 to 333 out of 10000 .
# Iterating from 333 to 334 out of 10000 .
# Iterating from 334 to 335 out of 10000 .
# Iterating from 335 to 336 out of 10000 .
# Iterating from 336 to 337 out of 10000 .
# Iterating from 337 to 338 out of 10000 .
# Iterating from 338 to 339 out of 10000 .
# Iterating from 339 to 340 out of 10000 .
# Iterating from 340 to 341 out of 10000 .
# Iterating from 341 to 342 out of 10000 .
# Iterating from 342 to 343 out of 10000 .
# Iterating from 343 to 344 out of 10000 .
# Iterating from 344 to 345 out of 10000 .
# Iterating from 345 to 346 out of 10000 .
# Iterating from 346 to 347 out of 10000 .
# Iterating from 347 to 348 out of 10000 .
# Iterating from 348 to 349 out of 10000 .
# Iterating from 349 to 350 out of 10000 .
# Iterating from 350 to 351 out of 10000 .
# Iterating from 351 to 352 out of 10000 .
# Iterating from 352 to 353 out of 10000 .
# Iterating from 353 to 354 out of 10000 .
# Iterating from 354 to 355 out of 10000 .
# Iterating from 355 to 356 out of 10000 .
# Iterating from 356 to 357 out of 10000 .
# Iterating from 357 to 358 out of 10000 .
# Iterating from 358 to 359 out of 10000 .
# Iterating from 359 to 360 out of 10000 .
# Iterating from 360 to 361 out of 10000 .
# Iterating from 361 to 362 out of 10000 .
# Iterating from 362 to 363 out of 10000 .
# Iterating from 363 to 364 out of 10000 .
# Iterating from 364 to 365 out of 10000 .
# Iterating from 365 to 366 out of 10000 .
# Iterating from 366 to 367 out of 10000 .
# Iterating from 367 to 368 out of 10000 .
# Iterating from 368 to 369 out of 10000 .
# Iterating from 369 to 370 out of 10000 .
# Iterating from 370 to 371 out of 10000 .
# Iterating from 371 to 372 out of 10000 .
# Iterating from 372 to 373 out of 10000 .
# Iterating from 373 to 374 out of 10000 .
# Iterating from 374 to 375 out of 10000 .
# Iterating from 375 to 376 out of 10000 .
# Iterating from 376 to 377 out of 10000 .
# Iterating from 377 to 378 out of 10000 .
# Iterating from 378 to 379 out of 10000 .
# Iterating from 379 to 380 out of 10000 .
# Iterating from 380 to 381 out of 10000 .
# Iterating from 381 to 382 out of 10000 .
# Iterating from 382 to 383 out of 10000 .
# Iterating from 383 to 384 out of 10000 .
# Iterating from 384 to 385 out of 10000 .
# Iterating from 385 to 386 out of 10000 .
# Iterating from 386 to 387 out of 10000 .
# Iterating from 387 to 388 out of 10000 .
# Iterating from 388 to 389 out of 10000 .
# Iterating from 389 to 390 out of 10000 .
# Iterating from 390 to 391 out of 10000 .
# Iterating from 391 to 392 out of 10000 .
# Iterating from 392 to 393 out of 10000 .
# Iterating from 393 to 394 out of 10000 .
# Iterating from 394 to 395 out of 10000 .
# Iterating from 395 to 396 out of 10000 .
# Iterating from 396 to 397 out of 10000 .
# Iterating from 397 to 398 out of 10000 .
# Iterating from 398 to 399 out of 10000 .
# Iterating from 399 to 400 out of 10000 .
# Iterating from 400 to 401 out of 10000 .
# Iterating from 401 to 402 out of 10000 .
# Iterating from 402 to 403 out of 10000 .
# Iterating from 403 to 404 out of 10000 .
# Iterating from 404 to 405 out of 10000 .
# Iterating from 405 to 406 out of 10000 .
# Iterating from 406 to 407 out of 10000 .
# Iterating from 407 to 408 out of 10000 .
# Iterating from 408 to 409 out of 10000 .
# Iterating from 409 to 410 out of 10000 .
# Iterating from 410 to 411 out of 10000 .
# Iterating from 411 to 412 out of 10000 .
# Iterating from 412 to 413 out of 10000 .
# Iterating from 413 to 414 out of 10000 .
# Iterating from 414 to 415 out of 10000 .
# Iterating from 415 to 416 out of 10000 .
# Iterating from 416 to 417 out of 10000 .
# Iterating from 417 to 418 out of 10000 .
# Iterating from 418 to 419 out of 10000 .
# Iterating from 419 to 420 out of 10000 .
# Iterating from 420 to 421 out of 10000 .
# Iterating from 421 to 422 out of 10000 .
# Iterating from 422 to 423 out of 10000 .
# Iterating from 423 to 424 out of 10000 .
# Iterating from 424 to 425 out of 10000 .
# Iterating from 425 to 426 out of 10000 .
# Iterating from 426 to 427 out of 10000 .
# Iterating from 427 to 428 out of 10000 .
# Iterating from 428 to 429 out of 10000 .
# Iterating from 429 to 430 out of 10000 .
# Iterating from 430 to 431 out of 10000 .
# Iterating from 431 to 432 out of 10000 .
# Iterating from 432 to 433 out of 10000 .
# Iterating from 433 to 434 out of 10000 .
# Iterating from 434 to 435 out of 10000 .
# Iterating from 435 to 436 out of 10000 .
# Iterating from 436 to 437 out of 10000 .
# Iterating from 437 to 438 out of 10000 .
# Iterating from 438 to 439 out of 10000 .
# Iterating from 439 to 440 out of 10000 .
# Iterating from 440 to 441 out of 10000 .
# Iterating from 441 to 442 out of 10000 .
# Iterating from 442 to 443 out of 10000 .
# Iterating from 443 to 444 out of 10000 .
# Iterating from 444 to 445 out of 10000 .
# Iterating from 445 to 446 out of 10000 .
# Iterating from 446 to 447 out of 10000 .
# Iterating from 447 to 448 out of 10000 .
# Iterating from 448 to 449 out of 10000 .
# Iterating from 449 to 450 out of 10000 .
# Iterating from 450 to 451 out of 10000 .
# Iterating from 451 to 452 out of 10000 .
# Iterating from 452 to 453 out of 10000 .
# Iterating from 453 to 454 out of 10000 .
# Iterating from 454 to 455 out of 10000 .
# Iterating from 455 to 456 out of 10000 .
# Iterating from 456 to 457 out of 10000 .
# Iterating from 457 to 458 out of 10000 .
# Iterating from 458 to 459 out of 10000 .
# Iterating from 459 to 460 out of 10000 .
# Iterating from 460 to 461 out of 10000 .
# Iterating from 461 to 462 out of 10000 .
# Iterating from 462 to 463 out of 10000 .
# Iterating from 463 to 464 out of 10000 .
# Iterating from 464 to 465 out of 10000 .
# Iterating from 465 to 466 out of 10000 .
# Iterating from 466 to 467 out of 10000 .
# Iterating from 467 to 468 out of 10000 .
# Iterating from 468 to 469 out of 10000 .
# Iterating from 469 to 470 out of 10000 .
# Iterating from 470 to 471 out of 10000 .
# Iterating from 471 to 472 out of 10000 .
# Iterating from 472 to 473 out of 10000 .
# Iterating from 473 to 474 out of 10000 .
# Iterating from 474 to 475 out of 10000 .
# Iterating from 475 to 476 out of 10000 .
# Iterating from 476 to 477 out of 10000 .
# Iterating from 477 to 478 out of 10000 .
# Iterating from 478 to 479 out of 10000 .
# Iterating from 479 to 480 out of 10000 .
# Iterating from 480 to 481 out of 10000 .
# Iterating from 481 to 482 out of 10000 .
# Iterating from 482 to 483 out of 10000 .
# Iterating from 483 to 484 out of 10000 .
# Iterating from 484 to 485 out of 10000 .
# Iterating from 485 to 486 out of 10000 .
# Iterating from 486 to 487 out of 10000 .
# Iterating from 487 to 488 out of 10000 .
# Iterating from 488 to 489 out of 10000 .
# Iterating from 489 to 490 out of 10000 .
# Iterating from 490 to 491 out of 10000 .
# Iterating from 491 to 492 out of 10000 .
# Iterating from 492 to 493 out of 10000 .
# Iterating from 493 to 494 out of 10000 .
# Iterating from 494 to 495 out of 10000 .
# Iterating from 495 to 496 out of 10000 .
# Iterating from 496 to 497 out of 10000 .
# Iterating from 497 to 498 out of 10000 .
# Iterating from 498 to 499 out of 10000 .
# Iterating from 499 to 500 out of 10000 .
# Iterating from 500 to 501 out of 10000 .
# Iterating from 501 to 502 out of 10000 .
# Iterating from 502 to 503 out of 10000 .
# Iterating from 503 to 504 out of 10000 .
# Iterating from 504 to 505 out of 10000 .
# Iterating from 505 to 506 out of 10000 .
# Iterating from 506 to 507 out of 10000 .
# Iterating from 507 to 508 out of 10000 .
# Iterating from 508 to 509 out of 10000 .
# Iterating from 509 to 510 out of 10000 .
# Iterating from 510 to 511 out of 10000 .
# Iterating from 511 to 512 out of 10000 .
# Iterating from 512 to 513 out of 10000 .
# Iterating from 513 to 514 out of 10000 .
# Iterating from 514 to 515 out of 10000 .
# Iterating from 515 to 516 out of 10000 .
# Iterating from 516 to 517 out of 10000 .
# Iterating from 517 to 518 out of 10000 .
# Iterating from 518 to 519 out of 10000 .
# Iterating from 519 to 520 out of 10000 .
# Iterating from 520 to 521 out of 10000 .
# Iterating from 521 to 522 out of 10000 .
# Iterating from 522 to 523 out of 10000 .
# Iterating from 523 to 524 out of 10000 .
# Iterating from 524 to 525 out of 10000 .
# Iterating from 525 to 526 out of 10000 .
# Iterating from 526 to 527 out of 10000 .
# Iterating from 527 to 528 out of 10000 .
# Iterating from 528 to 529 out of 10000 .
# Iterating from 529 to 530 out of 10000 .
# Iterating from 530 to 531 out of 10000 .
# Iterating from 531 to 532 out of 10000 .
# Iterating from 532 to 533 out of 10000 .
# Iterating from 533 to 534 out of 10000 .
# Iterating from 534 to 535 out of 10000 .
# Iterating from 535 to 536 out of 10000 .
# Iterating from 536 to 537 out of 10000 .
# Iterating from 537 to 538 out of 10000 .
# Iterating from 538 to 539 out of 10000 .
# Iterating from 539 to 540 out of 10000 .
# Iterating from 540 to 541 out of 10000 .
# Iterating from 541 to 542 out of 10000 .
# Iterating from 542 to 543 out of 10000 .
# Iterating from 543 to 544 out of 10000 .
# Iterating from 544 to 545 out of 10000 .
# Iterating from 545 to 546 out of 10000 .
# Iterating from 546 to 547 out of 10000 .
# Iterating from 547 to 548 out of 10000 .
# Iterating from 548 to 549 out of 10000 .
# Iterating from 549 to 550 out of 10000 .
# Iterating from 550 to 551 out of 10000 .
# Iterating from 551 to 552 out of 10000 .
# Iterating from 552 to 553 out of 10000 .
# Iterating from 553 to 554 out of 10000 .
# Iterating from 554 to 555 out of 10000 .
# Iterating from 555 to 556 out of 10000 .
# Iterating from 556 to 557 out of 10000 .
# Iterating from 557 to 558 out of 10000 .
# Iterating from 558 to 559 out of 10000 .
# Iterating from 559 to 560 out of 10000 .
# Iterating from 560 to 561 out of 10000 .
# Iterating from 561 to 562 out of 10000 .
# Iterating from 562 to 563 out of 10000 .
# Iterating from 563 to 564 out of 10000 .
# Iterating from 564 to 565 out of 10000 .
# Iterating from 565 to 566 out of 10000 .
# Iterating from 566 to 567 out of 10000 .
# Iterating from 567 to 568 out of 10000 .
# Iterating from 568 to 569 out of 10000 .
# Iterating from 569 to 570 out of 10000 .
# Iterating from 570 to 571 out of 10000 .
# Iterating from 571 to 572 out of 10000 .
# Iterating from 572 to 573 out of 10000 .
# Iterating from 573 to 574 out of 10000 .
# Iterating from 574 to 575 out of 10000 .
# Iterating from 575 to 576 out of 10000 .
# Iterating from 576 to 577 out of 10000 .
# Iterating from 577 to 578 out of 10000 .
# Iterating from 578 to 579 out of 10000 .
# Iterating from 579 to 580 out of 10000 .
# Iterating from 580 to 581 out of 10000 .
# Iterating from 581 to 582 out of 10000 .
# Iterating from 582 to 583 out of 10000 .
# Iterating from 583 to 584 out of 10000 .
# Iterating from 584 to 585 out of 10000 .
# Iterating from 585 to 586 out of 10000 .
# Iterating from 586 to 587 out of 10000 .
# Iterating from 587 to 588 out of 10000 .
# Iterating from 588 to 589 out of 10000 .
# Iterating from 589 to 590 out of 10000 .
# Iterating from 590 to 591 out of 10000 .
# Iterating from 591 to 592 out of 10000 .
# Iterating from 592 to 593 out of 10000 .
# Iterating from 593 to 594 out of 10000 .
# Iterating from 594 to 595 out of 10000 .
# Iterating from 595 to 596 out of 10000 .
# Iterating from 596 to 597 out of 10000 .
# Iterating from 597 to 598 out of 10000 .
# Iterating from 598 to 599 out of 10000 .
# Iterating from 599 to 600 out of 10000 .
# Iterating from 600 to 601 out of 10000 .
# Iterating from 601 to 602 out of 10000 .
# Iterating from 602 to 603 out of 10000 .
# Iterating from 603 to 604 out of 10000 .
# Iterating from 604 to 605 out of 10000 .
# Iterating from 605 to 606 out of 10000 .
# Iterating from 606 to 607 out of 10000 .
# Iterating from 607 to 608 out of 10000 .
# Iterating from 608 to 609 out of 10000 .
# Iterating from 609 to 610 out of 10000 .
# Iterating from 610 to 611 out of 10000 .
# Iterating from 611 to 612 out of 10000 .
# Iterating from 612 to 613 out of 10000 .
# Iterating from 613 to 614 out of 10000 .
# Iterating from 614 to 615 out of 10000 .
# Iterating from 615 to 616 out of 10000 .
# Iterating from 616 to 617 out of 10000 .
# Iterating from 617 to 618 out of 10000 .
# Iterating from 618 to 619 out of 10000 .
# Iterating from 619 to 620 out of 10000 .
# Iterating from 620 to 621 out of 10000 .
# Iterating from 621 to 622 out of 10000 .
# Iterating from 622 to 623 out of 10000 .
# Iterating from 623 to 624 out of 10000 .
# Iterating from 624 to 625 out of 10000 .
# Iterating from 625 to 626 out of 10000 .
# Iterating from 626 to 627 out of 10000 .
# Iterating from 627 to 628 out of 10000 .
# Iterating from 628 to 629 out of 10000 .
# Iterating from 629 to 630 out of 10000 .
# Iterating from 630 to 631 out of 10000 .
# Iterating from 631 to 632 out of 10000 .
# Iterating from 632 to 633 out of 10000 .
# Iterating from 633 to 634 out of 10000 .
# Iterating from 634 to 635 out of 10000 .
# Iterating from 635 to 636 out of 10000 .
# Iterating from 636 to 637 out of 10000 .
# Iterating from 637 to 638 out of 10000 .
# Iterating from 638 to 639 out of 10000 .
# Iterating from 639 to 640 out of 10000 .
# Iterating from 640 to 641 out of 10000 .
# Iterating from 641 to 642 out of 10000 .
# Iterating from 642 to 643 out of 10000 .
# Iterating from 643 to 644 out of 10000 .
# Iterating from 644 to 645 out of 10000 .
# Iterating from 645 to 646 out of 10000 .
# Iterating from 646 to 647 out of 10000 .
# Iterating from 647 to 648 out of 10000 .
# Iterating from 648 to 649 out of 10000 .
# Iterating from 649 to 650 out of 10000 .
# Iterating from 650 to 651 out of 10000 .
# Iterating from 651 to 652 out of 10000 .
# Iterating from 652 to 653 out of 10000 .
# Iterating from 653 to 654 out of 10000 .
# Iterating from 654 to 655 out of 10000 .
# Iterating from 655 to 656 out of 10000 .
# Iterating from 656 to 657 out of 10000 .
# Iterating from 657 to 658 out of 10000 .
# Iterating from 658 to 659 out of 10000 .
# Iterating from 659 to 660 out of 10000 .
# Iterating from 660 to 661 out of 10000 .
# Iterating from 661 to 662 out of 10000 .
# Iterating from 662 to 663 out of 10000 .
# Iterating from 663 to 664 out of 10000 .
# Iterating from 664 to 665 out of 10000 .
# Iterating from 665 to 666 out of 10000 .
# Iterating from 666 to 667 out of 10000 .
# Iterating from 667 to 668 out of 10000 .
# Iterating from 668 to 669 out of 10000 .
# Iterating from 669 to 670 out of 10000 .
# Iterating from 670 to 671 out of 10000 .
# Iterating from 671 to 672 out of 10000 .
# Iterating from 672 to 673 out of 10000 .
# Iterating from 673 to 674 out of 10000 .
# Iterating from 674 to 675 out of 10000 .
# Iterating from 675 to 676 out of 10000 .
# Iterating from 676 to 677 out of 10000 .
# Iterating from 677 to 678 out of 10000 .
# Iterating from 678 to 679 out of 10000 .
# Iterating from 679 to 680 out of 10000 .
# Iterating from 680 to 681 out of 10000 .
# Iterating from 681 to 682 out of 10000 .
# Iterating from 682 to 683 out of 10000 .
# Iterating from 683 to 684 out of 10000 .
# Iterating from 684 to 685 out of 10000 .
# Iterating from 685 to 686 out of 10000 .
# Iterating from 686 to 687 out of 10000 .
# Iterating from 687 to 688 out of 10000 .
# Iterating from 688 to 689 out of 10000 .
# Iterating from 689 to 690 out of 10000 .
# Iterating from 690 to 691 out of 10000 .
# Iterating from 691 to 692 out of 10000 .
# Iterating from 692 to 693 out of 10000 .
# Iterating from 693 to 694 out of 10000 .
# Iterating from 694 to 695 out of 10000 .
# Iterating from 695 to 696 out of 10000 .
# Iterating from 696 to 697 out of 10000 .
# Iterating from 697 to 698 out of 10000 .
# Iterating from 698 to 699 out of 10000 .
# Iterating from 699 to 700 out of 10000 .
# Iterating from 700 to 701 out of 10000 .
# Iterating from 701 to 702 out of 10000 .
# Iterating from 702 to 703 out of 10000 .
# Iterating from 703 to 704 out of 10000 .
# Iterating from 704 to 705 out of 10000 .
# Iterating from 705 to 706 out of 10000 .
# Iterating from 706 to 707 out of 10000 .
# Iterating from 707 to 708 out of 10000 .
# Iterating from 708 to 709 out of 10000 .
# Iterating from 709 to 710 out of 10000 .
# Iterating from 710 to 711 out of 10000 .
# Iterating from 711 to 712 out of 10000 .
# Iterating from 712 to 713 out of 10000 .
# Iterating from 713 to 714 out of 10000 .
# Iterating from 714 to 715 out of 10000 .
# Iterating from 715 to 716 out of 10000 .
# Iterating from 716 to 717 out of 10000 .
# Iterating from 717 to 718 out of 10000 .
# Iterating from 718 to 719 out of 10000 .
# Iterating from 719 to 720 out of 10000 .
# Iterating from 720 to 721 out of 10000 .
# Iterating from 721 to 722 out of 10000 .
# Iterating from 722 to 723 out of 10000 .
# Iterating from 723 to 724 out of 10000 .
# Iterating from 724 to 725 out of 10000 .
# Iterating from 725 to 726 out of 10000 .
# Iterating from 726 to 727 out of 10000 .
# Iterating from 727 to 728 out of 10000 .
# Iterating from 728 to 729 out of 10000 .
# Iterating from 729 to 730 out of 10000 .
# Iterating from 730 to 731 out of 10000 .
# Iterating from 731 to 732 out of 10000 .
# Iterating from 732 to 733 out of 10000 .
# Iterating from 733 to 734 out of 10000 .
# Iterating from 734 to 735 out of 10000 .
# Iterating from 735 to 736 out of 10000 .
# Iterating from 736 to 737 out of 10000 .
# Iterating from 737 to 738 out of 10000 .
# Iterating from 738 to 739 out of 10000 .
# Iterating from 739 to 740 out of 10000 .
# Iterating from 740 to 741 out of 10000 .
# Iterating from 741 to 742 out of 10000 .
# Iterating from 742 to 743 out of 10000 .
# Iterating from 743 to 744 out of 10000 .
# Iterating from 744 to 745 out of 10000 .
# Iterating from 745 to 746 out of 10000 .
# Iterating from 746 to 747 out of 10000 .
# Iterating from 747 to 748 out of 10000 .
# Iterating from 748 to 749 out of 10000 .
# Iterating from 749 to 750 out of 10000 .
# Iterating from 750 to 751 out of 10000 .
# Iterating from 751 to 752 out of 10000 .
# Iterating from 752 to 753 out of 10000 .
# Iterating from 753 to 754 out of 10000 .
# Iterating from 754 to 755 out of 10000 .
# Iterating from 755 to 756 out of 10000 .
# Iterating from 756 to 757 out of 10000 .
# Iterating from 757 to 758 out of 10000 .
# Iterating from 758 to 759 out of 10000 .
# Iterating from 759 to 760 out of 10000 .
# Iterating from 760 to 761 out of 10000 .
# Iterating from 761 to 762 out of 10000 .
# Iterating from 762 to 763 out of 10000 .
# Iterating from 763 to 764 out of 10000 .
# Iterating from 764 to 765 out of 10000 .
# Iterating from 765 to 766 out of 10000 .
# Iterating from 766 to 767 out of 10000 .
# Iterating from 767 to 768 out of 10000 .
# Iterating from 768 to 769 out of 10000 .
# Iterating from 769 to 770 out of 10000 .
# Iterating from 770 to 771 out of 10000 .
# Iterating from 771 to 772 out of 10000 .
# Iterating from 772 to 773 out of 10000 .
# Iterating from 773 to 774 out of 10000 .
# Iterating from 774 to 775 out of 10000 .
# Iterating from 775 to 776 out of 10000 .
# Iterating from 776 to 777 out of 10000 .
# Iterating from 777 to 778 out of 10000 .
# Iterating from 778 to 779 out of 10000 .
# Iterating from 779 to 780 out of 10000 .
# Iterating from 780 to 781 out of 10000 .
# Iterating from 781 to 782 out of 10000 .
# Iterating from 782 to 783 out of 10000 .
# Iterating from 783 to 784 out of 10000 .
# Iterating from 784 to 785 out of 10000 .
# Iterating from 785 to 786 out of 10000 .
# Iterating from 786 to 787 out of 10000 .
# Iterating from 787 to 788 out of 10000 .
# Iterating from 788 to 789 out of 10000 .
# Iterating from 789 to 790 out of 10000 .
# Iterating from 790 to 791 out of 10000 .
# Iterating from 791 to 792 out of 10000 .
# Iterating from 792 to 793 out of 10000 .
# Iterating from 793 to 794 out of 10000 .
# Iterating from 794 to 795 out of 10000 .
# Iterating from 795 to 796 out of 10000 .
# Iterating from 796 to 797 out of 10000 .
# Iterating from 797 to 798 out of 10000 .
# Iterating from 798 to 799 out of 10000 .
# Iterating from 799 to 800 out of 10000 .
# Iterating from 800 to 801 out of 10000 .
# Iterating from 801 to 802 out of 10000 .
# Iterating from 802 to 803 out of 10000 .
# Iterating from 803 to 804 out of 10000 .
# Iterating from 804 to 805 out of 10000 .
# Iterating from 805 to 806 out of 10000 .
# Iterating from 806 to 807 out of 10000 .
# Iterating from 807 to 808 out of 10000 .
# Iterating from 808 to 809 out of 10000 .
# Iterating from 809 to 810 out of 10000 .
# Iterating from 810 to 811 out of 10000 .
# Iterating from 811 to 812 out of 10000 .
# Iterating from 812 to 813 out of 10000 .
# Iterating from 813 to 814 out of 10000 .
# Iterating from 814 to 815 out of 10000 .
# Iterating from 815 to 816 out of 10000 .
# Iterating from 816 to 817 out of 10000 .
# Iterating from 817 to 818 out of 10000 .
# Iterating from 818 to 819 out of 10000 .
# Iterating from 819 to 820 out of 10000 .
# Iterating from 820 to 821 out of 10000 .
# Iterating from 821 to 822 out of 10000 .
# Iterating from 822 to 823 out of 10000 .
# Iterating from 823 to 824 out of 10000 .
# Iterating from 824 to 825 out of 10000 .
# Iterating from 825 to 826 out of 10000 .
# Iterating from 826 to 827 out of 10000 .
# Iterating from 827 to 828 out of 10000 .
# Iterating from 828 to 829 out of 10000 .
# Iterating from 829 to 830 out of 10000 .
# Iterating from 830 to 831 out of 10000 .
# Iterating from 831 to 832 out of 10000 .
# Iterating from 832 to 833 out of 10000 .
# Iterating from 833 to 834 out of 10000 .
# Iterating from 834 to 835 out of 10000 .
# Iterating from 835 to 836 out of 10000 .
# Iterating from 836 to 837 out of 10000 .
# Iterating from 837 to 838 out of 10000 .
# Iterating from 838 to 839 out of 10000 .
# Iterating from 839 to 840 out of 10000 .
# Iterating from 840 to 841 out of 10000 .
# Iterating from 841 to 842 out of 10000 .
# Iterating from 842 to 843 out of 10000 .
# Iterating from 843 to 844 out of 10000 .
# Iterating from 844 to 845 out of 10000 .
# Iterating from 845 to 846 out of 10000 .
# Iterating from 846 to 847 out of 10000 .
# Iterating from 847 to 848 out of 10000 .
# Iterating from 848 to 849 out of 10000 .
# Iterating from 849 to 850 out of 10000 .
# Iterating from 850 to 851 out of 10000 .
# Iterating from 851 to 852 out of 10000 .
# Iterating from 852 to 853 out of 10000 .
# Iterating from 853 to 854 out of 10000 .
# Iterating from 854 to 855 out of 10000 .
# Iterating from 855 to 856 out of 10000 .
# Iterating from 856 to 857 out of 10000 .
# Iterating from 857 to 858 out of 10000 .
# Iterating from 858 to 859 out of 10000 .
# Iterating from 859 to 860 out of 10000 .
# Iterating from 860 to 861 out of 10000 .
# Iterating from 861 to 862 out of 10000 .
# Iterating from 862 to 863 out of 10000 .
# Iterating from 863 to 864 out of 10000 .
# Iterating from 864 to 865 out of 10000 .
# Iterating from 865 to 866 out of 10000 .
# Iterating from 866 to 867 out of 10000 .
# Iterating from 867 to 868 out of 10000 .
# Iterating from 868 to 869 out of 10000 .
# Iterating from 869 to 870 out of 10000 .
# Iterating from 870 to 871 out of 10000 .
# Iterating from 871 to 872 out of 10000 .
# Iterating from 872 to 873 out of 10000 .
# Iterating from 873 to 874 out of 10000 .
# Iterating from 874 to 875 out of 10000 .
# Iterating from 875 to 876 out of 10000 .
# Iterating from 876 to 877 out of 10000 .
# Iterating from 877 to 878 out of 10000 .
# Iterating from 878 to 879 out of 10000 .
# Iterating from 879 to 880 out of 10000 .
# Iterating from 880 to 881 out of 10000 .
# Iterating from 881 to 882 out of 10000 .
# Iterating from 882 to 883 out of 10000 .
# Iterating from 883 to 884 out of 10000 .
# Iterating from 884 to 885 out of 10000 .
# Iterating from 885 to 886 out of 10000 .
# Iterating from 886 to 887 out of 10000 .
# Iterating from 887 to 888 out of 10000 .
# Iterating from 888 to 889 out of 10000 .
# Iterating from 889 to 890 out of 10000 .
# Iterating from 890 to 891 out of 10000 .
# Iterating from 891 to 892 out of 10000 .
# Iterating from 892 to 893 out of 10000 .
# Iterating from 893 to 894 out of 10000 .
# Iterating from 894 to 895 out of 10000 .
# Iterating from 895 to 896 out of 10000 .
# Iterating from 896 to 897 out of 10000 .
# Iterating from 897 to 898 out of 10000 .
# Iterating from 898 to 899 out of 10000 .
# Iterating from 899 to 900 out of 10000 .
# Iterating from 900 to 901 out of 10000 .
# Iterating from 901 to 902 out of 10000 .
# Iterating from 902 to 903 out of 10000 .
# Iterating from 903 to 904 out of 10000 .
# Iterating from 904 to 905 out of 10000 .
# Iterating from 905 to 906 out of 10000 .
# Iterating from 906 to 907 out of 10000 .
# Iterating from 907 to 908 out of 10000 .
# Iterating from 908 to 909 out of 10000 .
# Iterating from 909 to 910 out of 10000 .
# Iterating from 910 to 911 out of 10000 .
# Iterating from 911 to 912 out of 10000 .
# Iterating from 912 to 913 out of 10000 .
# Iterating from 913 to 914 out of 10000 .
# Iterating from 914 to 915 out of 10000 .
# Iterating from 915 to 916 out of 10000 .
# Iterating from 916 to 917 out of 10000 .
# Iterating from 917 to 918 out of 10000 .
# Iterating from 918 to 919 out of 10000 .
# Iterating from 919 to 920 out of 10000 .
# Iterating from 920 to 921 out of 10000 .
# Iterating from 921 to 922 out of 10000 .
# Iterating from 922 to 923 out of 10000 .
# Iterating from 923 to 924 out of 10000 .
# Iterating from 924 to 925 out of 10000 .
# Iterating from 925 to 926 out of 10000 .
# Iterating from 926 to 927 out of 10000 .
# Iterating from 927 to 928 out of 10000 .
# Iterating from 928 to 929 out of 10000 .
# Iterating from 929 to 930 out of 10000 .
# Iterating from 930 to 931 out of 10000 .
# Iterating from 931 to 932 out of 10000 .
# Iterating from 932 to 933 out of 10000 .
# Iterating from 933 to 934 out of 10000 .
# Iterating from 934 to 935 out of 10000 .
# Iterating from 935 to 936 out of 10000 .
# Iterating from 936 to 937 out of 10000 .
# Iterating from 937 to 938 out of 10000 .
# Iterating from 938 to 939 out of 10000 .
# Iterating from 939 to 940 out of 10000 .
# Iterating from 940 to 941 out of 10000 .
# Iterating from 941 to 942 out of 10000 .
# Iterating from 942 to 943 out of 10000 .
# Iterating from 943 to 944 out of 10000 .
# Iterating from 944 to 945 out of 10000 .
# Iterating from 945 to 946 out of 10000 .
# Iterating from 946 to 947 out of 10000 .
# Iterating from 947 to 948 out of 10000 .
# Iterating from 948 to 949 out of 10000 .
# Iterating from 949 to 950 out of 10000 .
# Iterating from 950 to 951 out of 10000 .
# Iterating from 951 to 952 out of 10000 .
# Iterating from 952 to 953 out of 10000 .
# Iterating from 953 to 954 out of 10000 .
# Iterating from 954 to 955 out of 10000 .
# Iterating from 955 to 956 out of 10000 .
# Iterating from 956 to 957 out of 10000 .
# Iterating from 957 to 958 out of 10000 .
# Iterating from 958 to 959 out of 10000 .
# Iterating from 959 to 960 out of 10000 .
# Iterating from 960 to 961 out of 10000 .
# Iterating from 961 to 962 out of 10000 .
# Iterating from 962 to 963 out of 10000 .
# Iterating from 963 to 964 out of 10000 .
# Iterating from 964 to 965 out of 10000 .
# Iterating from 965 to 966 out of 10000 .
# Iterating from 966 to 967 out of 10000 .
# Iterating from 967 to 968 out of 10000 .
# Iterating from 968 to 969 out of 10000 .
# Iterating from 969 to 970 out of 10000 .
# Iterating from 970 to 971 out of 10000 .
# Iterating from 971 to 972 out of 10000 .
# Iterating from 972 to 973 out of 10000 .
# Iterating from 973 to 974 out of 10000 .
# Iterating from 974 to 975 out of 10000 .
# Iterating from 975 to 976 out of 10000 .
# Iterating from 976 to 977 out of 10000 .
# Iterating from 977 to 978 out of 10000 .
# Iterating from 978 to 979 out of 10000 .
# Iterating from 979 to 980 out of 10000 .
# Iterating from 980 to 981 out of 10000 .
# Iterating from 981 to 982 out of 10000 .
# Iterating from 982 to 983 out of 10000 .
# Iterating from 983 to 984 out of 10000 .
# Iterating from 984 to 985 out of 10000 .
# Iterating from 985 to 986 out of 10000 .
# Iterating from 986 to 987 out of 10000 .
# Iterating from 987 to 988 out of 10000 .
# Iterating from 988 to 989 out of 10000 .
# Iterating from 989 to 990 out of 10000 .
# Iterating from 990 to 991 out of 10000 .
# Iterating from 991 to 992 out of 10000 .
# Iterating from 992 to 993 out of 10000 .
# Iterating from 993 to 994 out of 10000 .
# Iterating from 994 to 995 out of 10000 .
# Iterating from 995 to 996 out of 10000 .
# Iterating from 996 to 997 out of 10000 .
# Iterating from 997 to 998 out of 10000 .
# Iterating from 998 to 999 out of 10000 .
# Iterating from 999 to 1000 out of 10000 .
# Iterating from 1000 to 1001 out of 10000 .
# Iterating from 1001 to 1002 out of 10000 .
# Iterating from 1002 to 1003 out of 10000 .
# Iterating from 1003 to 1004 out of 10000 .
# Iterating from 1004 to 1005 out of 10000 .
# Iterating from 1005 to 1006 out of 10000 .
# Iterating from 1006 to 1007 out of 10000 .
# Iterating from 1007 to 1008 out of 10000 .
# Iterating from 1008 to 1009 out of 10000 .
# Iterating from 1009 to 1010 out of 10000 .
# Iterating from 1010 to 1011 out of 10000 .
# Iterating from 1011 to 1012 out of 10000 .
# Iterating from 1012 to 1013 out of 10000 .
# Iterating from 1013 to 1014 out of 10000 .
# Iterating from 1014 to 1015 out of 10000 .
# Iterating from 1015 to 1016 out of 10000 .
# Iterating from 1016 to 1017 out of 10000 .
# Iterating from 1017 to 1018 out of 10000 .
# Iterating from 1018 to 1019 out of 10000 .
# Iterating from 1019 to 1020 out of 10000 .
# Iterating from 1020 to 1021 out of 10000 .
# Iterating from 1021 to 1022 out of 10000 .
# Iterating from 1022 to 1023 out of 10000 .
# Iterating from 1023 to 1024 out of 10000 .
# Iterating from 1024 to 1025 out of 10000 .
# Iterating from 1025 to 1026 out of 10000 .
# Iterating from 1026 to 1027 out of 10000 .
# Iterating from 1027 to 1028 out of 10000 .
# Iterating from 1028 to 1029 out of 10000 .
# Iterating from 1029 to 1030 out of 10000 .
# Iterating from 1030 to 1031 out of 10000 .
# Iterating from 1031 to 1032 out of 10000 .
# Iterating from 1032 to 1033 out of 10000 .
# Iterating from 1033 to 1034 out of 10000 .
# Iterating from 1034 to 1035 out of 10000 .
# Iterating from 1035 to 1036 out of 10000 .
# Iterating from 1036 to 1037 out of 10000 .
# Iterating from 1037 to 1038 out of 10000 .
# Iterating from 1038 to 1039 out of 10000 .
# Iterating from 1039 to 1040 out of 10000 .
# Iterating from 1040 to 1041 out of 10000 .
# Iterating from 1041 to 1042 out of 10000 .
# Iterating from 1042 to 1043 out of 10000 .
# Iterating from 1043 to 1044 out of 10000 .
# Iterating from 1044 to 1045 out of 10000 .
# Iterating from 1045 to 1046 out of 10000 .
# Iterating from 1046 to 1047 out of 10000 .
# Iterating from 1047 to 1048 out of 10000 .
# Iterating from 1048 to 1049 out of 10000 .
# Iterating from 1049 to 1050 out of 10000 .
# Iterating from 1050 to 1051 out of 10000 .
# Iterating from 1051 to 1052 out of 10000 .
# Iterating from 1052 to 1053 out of 10000 .
# Iterating from 1053 to 1054 out of 10000 .
# Iterating from 1054 to 1055 out of 10000 .
# Iterating from 1055 to 1056 out of 10000 .
# Iterating from 1056 to 1057 out of 10000 .
# Iterating from 1057 to 1058 out of 10000 .
# Iterating from 1058 to 1059 out of 10000 .
# Iterating from 1059 to 1060 out of 10000 .
# Iterating from 1060 to 1061 out of 10000 .
# Iterating from 1061 to 1062 out of 10000 .
# Iterating from 1062 to 1063 out of 10000 .
# Iterating from 1063 to 1064 out of 10000 .
# Iterating from 1064 to 1065 out of 10000 .
# Iterating from 1065 to 1066 out of 10000 .
# Iterating from 1066 to 1067 out of 10000 .
# Iterating from 1067 to 1068 out of 10000 .
# Iterating from 1068 to 1069 out of 10000 .
# Iterating from 1069 to 1070 out of 10000 .
# Iterating from 1070 to 1071 out of 10000 .
# Iterating from 1071 to 1072 out of 10000 .
# Iterating from 1072 to 1073 out of 10000 .
# Iterating from 1073 to 1074 out of 10000 .
# Iterating from 1074 to 1075 out of 10000 .
# Iterating from 1075 to 1076 out of 10000 .
# Iterating from 1076 to 1077 out of 10000 .
# Iterating from 1077 to 1078 out of 10000 .
# Iterating from 1078 to 1079 out of 10000 .
# Iterating from 1079 to 1080 out of 10000 .
# Iterating from 1080 to 1081 out of 10000 .
# Iterating from 1081 to 1082 out of 10000 .
# Iterating from 1082 to 1083 out of 10000 .
# Iterating from 1083 to 1084 out of 10000 .
# Iterating from 1084 to 1085 out of 10000 .
# Iterating from 1085 to 1086 out of 10000 .
# Iterating from 1086 to 1087 out of 10000 .
# Iterating from 1087 to 1088 out of 10000 .
# Iterating from 1088 to 1089 out of 10000 .
# Iterating from 1089 to 1090 out of 10000 .
# Iterating from 1090 to 1091 out of 10000 .
# Iterating from 1091 to 1092 out of 10000 .
# Iterating from 1092 to 1093 out of 10000 .
# Iterating from 1093 to 1094 out of 10000 .
# Iterating from 1094 to 1095 out of 10000 .
# Iterating from 1095 to 1096 out of 10000 .
# Iterating from 1096 to 1097 out of 10000 .
# Iterating from 1097 to 1098 out of 10000 .
# Iterating from 1098 to 1099 out of 10000 .
# Iterating from 1099 to 1100 out of 10000 .
# Iterating from 1100 to 1101 out of 10000 .
# Iterating from 1101 to 1102 out of 10000 .
# Iterating from 1102 to 1103 out of 10000 .
# Iterating from 1103 to 1104 out of 10000 .
# Iterating from 1104 to 1105 out of 10000 .
# Iterating from 1105 to 1106 out of 10000 .
# Iterating from 1106 to 1107 out of 10000 .
# Iterating from 1107 to 1108 out of 10000 .
# Iterating from 1108 to 1109 out of 10000 .
# Iterating from 1109 to 1110 out of 10000 .
# Iterating from 1110 to 1111 out of 10000 .
# Iterating from 1111 to 1112 out of 10000 .
# Iterating from 1112 to 1113 out of 10000 .
# Iterating from 1113 to 1114 out of 10000 .
# ...
# Iterating from 9954 to 9955 out of 10000 .
# Iterating from 9955 to 9956 out of 10000 .
# Iterating from 9956 to 9957 out of 10000 .
# Iterating from 9957 to 9958 out of 10000 .
# Iterating from 9958 to 9959 out of 10000 .
# Iterating from 9959 to 9960 out of 10000 .
# Iterating from 9960 to 9961 out of 10000 .
# Iterating from 9961 to 9962 out of 10000 .
# Iterating from 9962 to 9963 out of 10000 .
# Iterating from 9963 to 9964 out of 10000 .
# Iterating from 9964 to 9965 out of 10000 .
# Iterating from 9965 to 9966 out of 10000 .
# Iterating from 9966 to 9967 out of 10000 .
# Iterating from 9967 to 9968 out of 10000 .
# Iterating from 9968 to 9969 out of 10000 .
# Iterating from 9969 to 9970 out of 10000 .
# Iterating from 9970 to 9971 out of 10000 .
# Iterating from 9971 to 9972 out of 10000 .
# Iterating from 9972 to 9973 out of 10000 .
# Iterating from 9973 to 9974 out of 10000 .
# Iterating from 9974 to 9975 out of 10000 .
# Iterating from 9975 to 9976 out of 10000 .
# Iterating from 9976 to 9977 out of 10000 .
# Iterating from 9977 to 9978 out of 10000 .
# Iterating from 9978 to 9979 out of 10000 .
# Iterating from 9979 to 9980 out of 10000 .
# Iterating from 9980 to 9981 out of 10000 .
# Iterating from 9981 to 9982 out of 10000 .
# Iterating from 9982 to 9983 out of 10000 .
# Iterating from 9983 to 9984 out of 10000 .
# Iterating from 9984 to 9985 out of 10000 .
# Iterating from 9985 to 9986 out of 10000 .
# Iterating from 9986 to 9987 out of 10000 .
# Iterating from 9987 to 9988 out of 10000 .
# Iterating from 9988 to 9989 out of 10000 .
# Iterating from 9989 to 9990 out of 10000 .
# Iterating from 9990 to 9991 out of 10000 .
# Iterating from 9991 to 9992 out of 10000 .
# Iterating from 9992 to 9993 out of 10000 .
# Iterating from 9993 to 9994 out of 10000 .
# Iterating from 9994 to 9995 out of 10000 .
# Iterating from 9995 to 9996 out of 10000 .
# Iterating from 9996 to 9997 out of 10000 .
# Iterating from 9997 to 9998 out of 10000 .
# Iterating from 9998 to 9999 out of 10000 .
# Iterating from 9999 to 10000 out of 10000 .
# MMD metric calculation completed in 16279.80358493101 seconds.
# Saving mmd to results/5D_unimodal/5D_100K/null_hypothesis/MMD.json
# Computing and savng ks with max_vectorize = 2000
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 25
# Iterating from 0 to 400 out of 10000 .
# Iterating from 400 to 800 out of 10000 .
# Iterating from 800 to 1200 out of 10000 .
# Iterating from 1200 to 1600 out of 10000 .
# Iterating from 1600 to 2000 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f09b832a020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2000 to 2400 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f09b832a020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2400 to 2800 out of 10000 .
# Iterating from 2800 to 3200 out of 10000 .
# Iterating from 3200 to 3600 out of 10000 .
# Iterating from 3600 to 4000 out of 10000 .
# Iterating from 4000 to 4400 out of 10000 .
# Iterating from 4400 to 4800 out of 10000 .
# Iterating from 4800 to 5200 out of 10000 .
# Iterating from 5200 to 5600 out of 10000 .
# Iterating from 5600 to 6000 out of 10000 .
# Iterating from 6000 to 6400 out of 10000 .
# Iterating from 6400 to 6800 out of 10000 .
# Iterating from 6800 to 7200 out of 10000 .
# Iterating from 7200 to 7600 out of 10000 .
# Iterating from 7600 to 8000 out of 10000 .
# Iterating from 8000 to 8400 out of 10000 .
# Iterating from 8400 to 8800 out of 10000 .
# Iterating from 8800 to 9200 out of 10000 .
# Iterating from 9200 to 9600 out of 10000 .
# Iterating from 9600 to 10000 out of 10000 .
# KS tests calculation completed in 66.15909963403828 seconds.
# Saving ks to results/5D_unimodal/5D_100K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 100
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f0a84291620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 500 to 600 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f0a84291620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SKS metric calculation completed in 646.6608149560052 seconds.
# Saving sks to results/5D_unimodal/5D_100K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 100
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SWD metric calculation completed in 351.0855571749853 seconds.
# Saving swd to results/5D_unimodal/5D_100K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.00025084886975117453], [0.95, [9500, 500], 0.0012295004163920943], [0.99, [9900, 100], 0.0020356050809735094]]
# Computing time for metric fgd: 2268.633506648999
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.07933369560169012], [0.95, [9500, 500], 8.884523334776986], [0.99, [9900, 100], 18.05518933264966]]
# Computing time for metric mmd: 16279.80358493101
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9181316920761391], [0.95, [9500, 500], 1.1220593124422433], [0.99, [9900, 100], 1.247725061392798]]
# Computing time for metric ks: 66.15909963403828
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9052286433964314], [0.95, [9500, 500], 1.127829109390323], [0.99, [9900, 100], 1.298642054941064]]
# Computing time for metric sks: 646.6608149560052
# ThresholdS for metric swd: [[0.68, [6800, 3199], 1.1569675592368323], [0.95, [9500, 500], 1.5852619435451714], [0.99, [9900, 100], 1.9330087260011688]]
# Computing time for metric swd: 351.0855571749853
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f0a84330400>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f0a843304a0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f0a84330540>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f0a843305e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f0a84330680>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f0a84330720>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            500
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...           2000
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...            200
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_unimodal/5D_100K/null_hypothesis/FG...
# 1  $d_{\mathrm{MMD}}$  results/5D_unimodal/5D_100K/null_hypothesis/MM...
# 2      $\overline{D}$  results/5D_unimodal/5D_100K/null_hypothesis/KS...
# 3     $\widetilde{D}$  results/5D_unimodal/5D_100K/null_hypothesis/SK...
# 4     $\widetilde{W}$  results/5D_unimodal/5D_100K/null_hypothesis/SW...
# 5           $t_{\mu}$  results/5D_unimodal/5D_100K/null_hypothesis/LR...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.00025084886975117453],...
# 1  [[0.68, [6800, 3199], 0.07933369560169012], [0...
# 2  [[0.68, [6800, 3199], 0.9181316920761391], [0....
# 3  [[0.68, [6800, 3199], 0.9052286433964314], [0....
# 4  [[0.68, [6800, 3199], 1.1569675592368323], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{2})$"
        dist_null = dist_null * 100
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-2})$"
        dist_null = dist_null / 100
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.027309088423774323 +/- 2.1473350681477447e-05
# sigma = 0.04633934686794522 +/- 0.0007959745902050537
# 68%CL = 0.025084886975117453, 95%CL = 0.12295004163920943, 99%CL = 0.20356050809735093
# mu = 0.027309088423774323 +/- 2.1473350681477447e-05
# sigma = 0.04633934686794522 +/- 0.0007959745902050537
# /tmp/ipykernel_166510/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_166510/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_166510/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2561821150011383 seconds.
# mu = 0.0007637616584701841 +/- 1.941883623590683e-05
# sigma = 0.0440668086385965 +/- 0.0007585277523922187
# 68%CL = 0.0007933369560169012, 95%CL = 0.08884523334776986, 99%CL = 0.1805518933264966
# mu = 0.0007637616584701841 +/- 1.941883623590683e-05
# sigma = 0.0440668086385965 +/- 0.0007585277523922187
# /tmp/ipykernel_166510/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_166510/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_166510/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9476736789802089 seconds.
# mu = 0.8655319830515247 +/- 0.00019647417415961997
# sigma = 0.1401692456138721 +/- 0.0010921518202057568
# 68%CL = 0.9181316920761391, 95%CL = 1.1220593124422433, 99%CL = 1.247725061392798
# mu = 0.8655319830515247 +/- 0.00019647417415961997
# sigma = 0.1401692456138721 +/- 0.0010921518202057568
# /tmp/ipykernel_166510/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_166510/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_166510/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_166510/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3526572839473374 seconds.
# mu = 0.8646116459121931 +/- 0.00019363870244019094
# sigma = 0.13915412406399996 +/- 0.0013093972974102194
# 68%CL = 0.9052286433964314, 95%CL = 1.127829109390323, 99%CL = 1.298642054941064
# mu = 0.8646116459121931 +/- 0.00019363870244019094
# sigma = 0.13915412406399996 +/- 0.0013093972974102194
# /tmp/ipykernel_166510/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_166510/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_166510/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_166510/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3203177959658206 seconds.
# mu = 1.0928033782382467 +/- 0.0006530333010804026
# sigma = 0.2555451625604372 +/- 0.002862489723561817
# 68%CL = 1.1569675592368323, 95%CL = 1.5852619435451714, 99%CL = 1.9330087260011688
# mu = 1.0928033782382467 +/- 0.0006530333010804026
# sigma = 0.2555451625604372 +/- 0.002862489723561817
# /tmp/ipykernel_166510/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_166510/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_166510/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_166510/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9422089559957385 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f0a84330400>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f0a843304a0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f0a84330540>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f0a843305e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f0a84330680>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f0a84330720>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            500
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...           2000
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...            200
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_unimodal/5D_100K/null_hypothesis/FG...
# 1  $d_{\mathrm{MMD}}$  results/5D_unimodal/5D_100K/null_hypothesis/MM...
# 2      $\overline{D}$  results/5D_unimodal/5D_100K/null_hypothesis/KS...
# 3     $\widetilde{D}$  results/5D_unimodal/5D_100K/null_hypothesis/SK...
# 4     $\widetilde{W}$  results/5D_unimodal/5D_100K/null_hypothesis/SW...
# 5           $t_{\mu}$  results/5D_unimodal/5D_100K/null_hypothesis/LR...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.00025084886975117453],...
# 1  [[0.68, [6800, 3199], 0.07933369560169012], [0...
# 2  [[0.68, [6800, 3199], 0.9181316920761391], [0....
# 3  [[0.68, [6800, 3199], 0.9052286433964314], [0....
# 4  [[0.68, [6800, 3199], 1.1569675592368323], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/5D_unimodal/5D_100K/null_hypothesis/FG...
# 1  results/5D_unimodal/5D_100K/null_hypothesis/MM...
# 2  results/5D_unimodal/5D_100K/null_hypothesis/KS...
# 3  results/5D_unimodal/5D_100K/null_hypothesis/SK...
# 4  results/5D_unimodal/5D_100K/null_hypothesis/SW...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = mean
# statistic = 7.654701234239326 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999357621974908
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 204 calls to <function generate_and_clean_data_simple_1 at 0x7f0b95708e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.9157266067960035 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.997434473513992
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = mean
# WARNING:tensorflow:6 out of the last 205 calls to <function generate_and_clean_data_simple_1 at 0x7f0b95708e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.4800592435189742 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.989781598411475
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = mean
# WARNING:tensorflow:5 out of the last 24 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f0904250d60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.12079231020248708 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9596957163590272
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = mean
# WARNING:tensorflow:6 out of the last 25 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f0a840c8040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.030703234698781827 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.845988711965001
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = mean
# statistic = 0.008050515164494397 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4700438137520266
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = mean
# statistic = 0.0022444566754735613 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5843228527249279
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = mean
# statistic = 0.0007794712644115118 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.4480194084175113
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.029296875 - deformation = mean
# statistic = 0.0013691980018077248 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.1075135032501404
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0244140625 - deformation = mean
# statistic = 0.0010580524012610028 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.1498964428781913
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.02685546875 - deformation = mean
# statistic = 0.0012060636465557632 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.019245455451469176
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.028076171875 - deformation = mean
# statistic = 0.001288215096558473 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.04664123477363774
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0274658203125 - deformation = mean
# statistic = 0.001248756577008597 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.02247191011235955
# relative_error_metric = 0.015540083750619639
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.02716064453125 - deformation = mean
# statistic = 0.0012191861724536947 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.0111731843575419
# relative_error_metric = 0.008424307124793248
# =======> statistic within required accuracy at 0.95 CL in 130.6608950549853 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.027313232421875 - deformation = mean
# statistic = 0.001229939528919084 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.978268127598871
# relative_error_metric = 0.49343411179486185
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5136566162109375 - deformation = mean
# statistic = 7.738403831748505 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9570034529349947
# relative_error_metric = 1.9989480674333358
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2704849243164062 - deformation = mean
# statistic = 1.9786642505094207 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.915816701449105
# relative_error_metric = 1.9958891195448352
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6488990783691406 - deformation = mean
# statistic = 0.5173750759102693 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.8384339830197727
# relative_error_metric = 1.9843237333734547
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3381061553955078 - deformation = mean
# statistic = 0.14123768403489873 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.7010204347939557
# relative_error_metric = 1.9431686089281526
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.1827096939086914 - deformation = mean
# statistic = 0.041771447001987816 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.4798047451470087
# relative_error_metric = 1.8141299188889952
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.1050114631652832 - deformation = mean
# statistic = 0.014175151996913068 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.1743572187888507
# relative_error_metric = 1.4977149873523623
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.0661623477935791 - deformation = mean
# statistic = 0.005921923822611666 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.8312142119291444
# relative_error_metric = 0.9767652216474437
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.04673779010772705 - deformation = mean
# statistic = 0.003122224262626215 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.5246263190514903
# relative_error_metric = 0.42134747362321145
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.037025511264801025 - deformation = mean
# statistic = 0.002037669095660381 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.30191073951409314
# relative_error_metric = 0.0010134425513075391
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.03216937184333801 - deformation = mean
# statistic = 0.001590423265270278 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.1403612291352165
# relative_error_metric = 0.24554789604135133
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.03459744155406952 - deformation = mean
# statistic = 0.0018219607515071808 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.06780144116291674
# relative_error_metric = 0.11076639453172471
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.03581147640943527 - deformation = mean
# statistic = 0.001922575747225884 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.0333356689816863
# relative_error_metric = 0.05711175848377969
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.03641849383711815 - deformation = mean
# statistic = 0.001980724821906694 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.016530074220231068
# relative_error_metric = 0.027328561345251846
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.03672200255095959 - deformation = mean
# statistic = 0.002008004525988037 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.008231022257907637
# relative_error_metric = 0.013651443966279509
# =======> statistic within required accuracy at 0.99 CL in 138.13288295594975 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 268.7938118229504 seconds.
# Saving results in the file results/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_diag
# statistic = 72.707916586707 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999323606185713
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_diag
# statistic = 18.183578885954223 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997295543862172
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_diag
# statistic = 4.549384945030271 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9989192664585131
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_diag
# statistic = 1.1390268703361106 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9956869334022467
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_diag
# statistic = 0.2858573920782942 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9828692922103388
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_diag
# statistic = 0.07207211545918626 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9329073226173328
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_diag
# statistic = 0.01847856268516595 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.750457381822591
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_diag
# statistic = 0.004796440604036351 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.183861632748157
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_diag
# statistic = 0.0012803663448469594 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.04053277189085042
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = cov_diag
# statistic = 0.0004934291100233468 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.8544415718501798
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00732421875 - deformation = cov_diag
# statistic = 0.0007761129090492179 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.45211856302671277
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.008544921875 - deformation = cov_diag
# statistic = 0.0010056339112923603 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.20031592940694024
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0091552734375 - deformation = cov_diag
# statistic = 0.0011379915542942052 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.07730447514156684
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00946044921875 - deformation = cov_diag
# statistic = 0.0012099978880761452 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.031746031746031744
# relative_error_metric = 0.01598896648563182
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.009613037109375 - deformation = cov_diag
# statistic = 0.0012460846000797586 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.016
# relative_error_metric = 0.013398193620754496
# =======> statistic within required accuracy at 0.95 CL in 137.41433722397778 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0095367431640625 - deformation = cov_diag
# statistic = 0.0012259503257229171 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9923851296812416
# relative_error_metric = 0.496483827065
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5047683715820312 - deformation = cov_diag
# statistic = 72.98328789817305 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9848280256709805
# relative_error_metric = 1.9998884375661699
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2571525573730469 - deformation = cov_diag
# statistic = 18.392239113727335 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9698845070846698
# relative_error_metric = 1.999557339419555
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6333446502685547 - deformation = cov_diag
# statistic = 4.671433029576827 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9406625031523046
# relative_error_metric = 1.998257735108457
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3214406967163086 - deformation = cov_diag
# statistic = 1.2051224931353723 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.8847444929478037
# relative_error_metric = 1.993254884893764
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16548871994018555 - deformation = cov_diag
# statistic = 0.3205008622458231 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.7820490117284875
# relative_error_metric = 1.9747550396661224
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08751273155212402 - deformation = cov_diag
# statistic = 0.09021195986917213 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.6069327240790556
# relative_error_metric = 1.9117329511267365
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04852473735809326 - deformation = cov_diag
# statistic = 0.028200413033473804 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.342990011395017
# relative_error_metric = 1.730704608884877
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.02903074026107788 - deformation = cov_diag
# statistic = 0.010327973422513976 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.0109032462464551
# relative_error_metric = 1.3414188034963144
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.01928374171257019 - deformation = cov_diag
# statistic = 0.004686802261854627 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.6763937935277725
# relative_error_metric = 0.788764216649136
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.014410242438316345 - deformation = cov_diag
# statistic = 0.0027549543382284557 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.407024028424665
# relative_error_metric = 0.3003195219212119
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.011973492801189423 - deformation = cov_diag
# statistic = 0.0018806527851916214 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.18471604683769324
# relative_error_metric = 0.07913283602727623
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.013191867619752884 - deformation = cov_diag
# statistic = 0.002251385076267781 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.09682951471257646
# relative_error_metric = 0.10066736212575195
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.012582680210471153 - deformation = cov_diag
# statistic = 0.0020565330371561737 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.0496158264557312
# relative_error_metric = 0.010228372346449272
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.012278086505830288 - deformation = cov_diag
# statistic = 0.00196386349410741 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.02450396708329517
# relative_error_metric = 0.03587555972465555
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.01243038335815072 - deformation = cov_diag
# statistic = 0.002010558307310694 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.012177384981461002
# relative_error_metric = 0.012380505312928735
# =======> statistic within required accuracy at 0.99 CL in 147.60332657099934 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 285.0176975289942 seconds.
# Saving results in the file results/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_off_diag
# statistic = 9.575562709898382 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999486466704345
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_off_diag
# statistic = 4.837515032018364 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9989836203104745
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_off_diag
# statistic = 3.9633073461465935 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9987595015872202
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_off_diag
# statistic = 1.935056345596309 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9974600848961968
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_off_diag
# statistic = 0.7915939112331462 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9937968511104682
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_off_diag
# statistic = 0.2898366479915026 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9831034914486987
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_off_diag
# statistic = 0.09616365541777479 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9495036214460248
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_off_diag
# statistic = 0.029199527807838375 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8383779583978892
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_off_diag
# statistic = 0.00821905311426131 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4794968722341273
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = cov_off_diag
# statistic = 0.0022235059684478555 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5757333994051299
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = cov_off_diag
# statistic = 0.0006151551317575207 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.666081302008743
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = cov_off_diag
# statistic = 0.0012930609698035204 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.0503936623776554
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0030517578125 - deformation = cov_off_diag
# statistic = 0.0009197062589817839 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.2882869860400171
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00335693359375 - deformation = cov_off_diag
# statistic = 0.0010997956758784044 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.1113681862465662
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.003509521484375 - deformation = cov_off_diag
# statistic = 0.001196214934734748 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.0425531914893617
# relative_error_metric = 0.02744384796994735
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0035858154296875 - deformation = cov_off_diag
# statistic = 0.001243186560140013 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.021505376344086023
# relative_error_metric = 0.011069855487420587
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00354766845703125 - deformation = cov_off_diag
# statistic = 0.0012177113060454583 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.0106951871657754
# relative_error_metric = 0.009634728567656126
# =======> statistic within required accuracy at 0.95 CL in 152.4878733450314 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.003566741943359375 - deformation = cov_off_diag
# statistic = 0.0012288251719780874 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9971486404580472
# relative_error_metric = 0.4942852788880734
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5017833709716797 - deformation = cov_off_diag
# statistic = 9.581355503447167 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.994305399592699
# relative_error_metric = 1.9991503612623462
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2526750564575195 - deformation = cov_off_diag
# statistic = 4.843502217600478 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9886431355877519
# relative_error_metric = 1.9983196044233154
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6281208992004395 - deformation = cov_off_diag
# statistic = 3.97920297948563 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9774145212852285
# relative_error_metric = 1.9979548022177172
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3158438205718994 - deformation = cov_off_diag
# statistic = 1.9597519060684025 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9553334502745008
# relative_error_metric = 1.9958494891635212
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.1597052812576294 - deformation = cov_off_diag
# statistic = 0.8157007074846897 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.912618417450032
# relative_error_metric = 1.9900427311362177
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08163601160049438 - deformation = cov_off_diag
# statistic = 0.30984471544261794 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.8325527382622169
# relative_error_metric = 1.9738924844304881
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04260137677192688 - deformation = cov_off_diag
# statistic = 0.11100315078050435 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.6909779265336686
# relative_error_metric = 1.9279678879881508
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.023084059357643127 - deformation = cov_off_diag
# statistic = 0.03926135764367704 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.4646702133905134
# relative_error_metric = 1.802832465472485
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.013325400650501251 - deformation = cov_off_diag
# statistic = 0.014655900279069675 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.1554080428717926
# relative_error_metric = 1.512181786587943
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.008446071296930313 - deformation = cov_off_diag
# statistic = 0.0062626355992529605 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.8123541515165141
# relative_error_metric = 1.0187775171071778
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.006006406620144844 - deformation = cov_off_diag
# statistic = 0.003289566622623812 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.5096890872635612
# relative_error_metric = 0.47095628514784316
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0047865742817521095 - deformation = cov_off_diag
# statistic = 0.00214958085144107 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.2920594182046435
# relative_error_metric = 0.0544662876670829
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.004176658112555742 - deformation = cov_off_diag
# statistic = 0.0016540222184910642 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.1360929054084769
# relative_error_metric = 0.20684087118382888
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.004481616197153926 - deformation = cov_off_diag
# statistic = 0.0018903466464586156 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.06580747024831952
# relative_error_metric = 0.0739990935191167
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.004634095239453018 - deformation = cov_off_diag
# statistic = 0.0020138740385096674 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.03237116893993032
# relative_error_metric = 0.010732759361216544
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.004710334760602564 - deformation = cov_off_diag
# statistic = 0.002077995653065534 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.01631763973813115
# relative_error_metric = 0.020609959416456214
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.004672215000027791 - deformation = cov_off_diag
# statistic = 0.0020463666728689984 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.008192239371744741
# relative_error_metric = 0.005272741971013738
# =======> statistic within required accuracy at 0.99 CL in 163.71016019699164 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 316.1980661940179 seconds.
# Saving results in the file results/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_up
# statistic = 2472169.913460738 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999999998010654
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_up
# statistic = 6306.623564947623 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999992201848333
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_up
# statistic = 256.75582371416476 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999808456998396
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_up
# statistic = 29.751643366487258 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998347049816811
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_up
# statistic = 5.242196770040973 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9990620633509661
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_up
# statistic = 1.1114802373693693 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9955801576111352
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_up
# statistic = 0.2575725729333766 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9809970546143125
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_up
# statistic = 0.06281892691867497 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9232143259374654
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.01610323904225539 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.716259413158447
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.004316360630857415 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1132122453721631
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_up
# statistic = 0.0012707483148471127 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.03299503600553738
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.001220703125 - deformation = power_abs_up
# statistic = 0.00048253476293907266 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.8726054960445794
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0018310546875 - deformation = power_abs_up
# statistic = 0.0008113596155237289 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.4097692093816378
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00213623046875 - deformation = power_abs_up
# statistic = 0.0010268268921080435 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.17964904605863702
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.002288818359375 - deformation = power_abs_up
# statistic = 0.0011461879216602346 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.07013756257284337
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0023651123046875 - deformation = power_abs_up
# statistic = 0.0012068338075069567 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.031746031746031744
# relative_error_metric = 0.01860714237216804
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00240325927734375 - deformation = power_abs_up
# statistic = 0.0012266458809260176 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.015748031496062992
# relative_error_metric = 0.002324401823452933
# =======> statistic within required accuracy at 0.95 CL in 154.9872700709966 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.002422332763671875 - deformation = power_abs_up
# statistic = 0.001258799993291856 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9980630721658132
# relative_error_metric = 0.4715905118953089
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.501211166381836 - deformation = power_abs_up
# statistic = 2486601.2126308973 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9961298923912008
# relative_error_metric = 1.9999999967254818
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.251816749572754 - deformation = power_abs_up
# statistic = 6360.599271197539 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.992274733588561
# relative_error_metric = 1.9999987198662625
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6271195411682129 - deformation = power_abs_up
# statistic = 259.93631384021097 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.984608917284292
# relative_error_metric = 1.9999686755711839
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3147709369659424 - deformation = power_abs_up
# statistic = 30.344816817693918 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9694529109556864
# relative_error_metric = 1.9997316881431242
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.15859663486480713 - deformation = power_abs_up
# statistic = 5.428551143961616 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9398249088452497
# relative_error_metric = 1.9985006370950011
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.0805094838142395 - deformation = power_abs_up
# statistic = 1.1860600130468968 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.8831650932717152
# relative_error_metric = 1.9931466624405831
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04146590828895569 - deformation = power_abs_up
# statistic = 0.2914881496305984 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.7792271728760156
# relative_error_metric = 1.9722597568571747
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.021944120526313782 - deformation = power_abs_up
# statistic = 0.07938843393531006 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.6023495525025915
# relative_error_metric = 1.8999997983118266
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.012183226644992828 - deformation = power_abs_up
# statistic = 0.0247233405909651 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.3365997985027993
# relative_error_metric = 1.695712214385458
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.007302779704332352 - deformation = power_abs_up
# statistic = 0.009158238306848828 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.0036792801558283
# relative_error_metric = 1.2725983344780318
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.004862556234002113 - deformation = power_abs_up
# statistic = 0.004286155394264771 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.6699411538348446
# relative_error_metric = 0.7120011338950433
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.003642444498836994 - deformation = power_abs_up
# statistic = 0.002600529366466344 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.4023599490479507
# relative_error_metric = 0.2437048760761435
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0030323886312544346 - deformation = power_abs_up
# statistic = 0.0018709857910477491 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.18279284461279208
# relative_error_metric = 0.08427772209511496
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0033374165650457144 - deformation = power_abs_up
# statistic = 0.0021960656631703043 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.09577308077441768
# relative_error_metric = 0.07583793347762488
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.0031849025981500745 - deformation = power_abs_up
# statistic = 0.002031701898180002 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.04676679048650281
# relative_error_metric = 0.0019192958945624691
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0032611595815978944 - deformation = power_abs_up
# statistic = 0.0021129461142052166 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.02366002105514951
# relative_error_metric = 0.037285803931545895
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.0032230310898739845 - deformation = power_abs_up
# statistic = 0.0020703325142191705 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.011900401464880708
# relative_error_metric = 0.016915714104530365
# =======> statistic within required accuracy at 0.99 CL in 164.67369400401367 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 319.66099755704636 seconds.
# Saving results in the file results/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_down
# statistic = 1.2828427124746191 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9961699960358963
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_down
# statistic = 31.18204276218116 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998422871844828
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_down
# statistic = 19.477033821003502 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.99974751333913
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_down
# statistic = 8.246111093201787 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9994036863629263
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_down
# statistic = 2.747975749196931 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9982111187710483
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_down
# statistic = 0.7961256821969875 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9938321067288363
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_down
# statistic = 0.21337565603463943 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.977083487895173
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_down
# statistic = 0.05476023569300411 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9121624424884003
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.013686805875209923 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6702935988692291
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.0033487835597402226 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9257980301774442
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_down
# statistic = 0.0008812508378819263 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.3299769006935365
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_down
# statistic = 0.0018674415925197952 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.41198135082409343
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0030517578125 - deformation = power_abs_down
# statistic = 0.0013001939061528778 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.0558909344348475
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00274658203125 - deformation = power_abs_down
# statistic = 0.0010699805831116036 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.13874420646652025
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.002899169921875 - deformation = power_abs_down
# statistic = 0.0011775335035901669 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.04317921103688511
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0029754638671875 - deformation = power_abs_down
# statistic = 0.001245298859578614 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.025974025974025976
# relative_error_metric = 0.012767454185004877
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00293731689453125 - deformation = power_abs_down
# statistic = 0.0012059520454612467 - next threshold = 0.0012295004163920943 at 0.95 CL
# relative_error_eps = 0.012903225806451613
# relative_error_metric = 0.019337984460536504
# =======> statistic within required accuracy at 0.95 CL in 154.57356396503747 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.002956390380859375 - deformation = power_abs_down
# statistic = 0.0012235855784600842 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9976362853079883
# relative_error_metric = 0.4982951826786003
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5014781951904297 - deformation = power_abs_down
# statistic = 1.2828427124746191 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9952781511677056
# relative_error_metric = 1.9936628860393686
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2522172927856445 - deformation = power_abs_down
# statistic = 31.19283532543302 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.990578545676958
# relative_error_metric = 1.999738982080034
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.627586841583252 - deformation = power_abs_down
# statistic = 19.55820859895913 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.981245438973944
# relative_error_metric = 1.9995837260394627
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31527161598205566 - deformation = power_abs_down
# statistic = 8.351548840945943 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9628393438447045
# relative_error_metric = 1.9990252782650968
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.15911400318145752 - deformation = power_abs_down
# statistic = 2.8343869242116053 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.9270344122482155
# relative_error_metric = 1.9971293344909635
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08103519678115845 - deformation = power_abs_down
# statistic = 0.8519451173651849 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.8592054046957551
# relative_error_metric = 1.9904653347436567
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04199579358100891 - deformation = power_abs_down
# statistic = 0.2454637112113247 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.7369302115895235
# relative_error_metric = 1.967101241143318
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.022476091980934143 - deformation = power_abs_down
# statistic = 0.07231884953996519 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.5350213417938825
# relative_error_metric = 1.8904918290988164
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.012716241180896759 - deformation = power_abs_down
# statistic = 0.023253203915041577 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 1.2454642044738762
# relative_error_metric = 1.6780227837073274
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.007836315780878067 - deformation = power_abs_down
# statistic = 0.008901164611700839 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.9043006131898818
# relative_error_metric = 1.2555004308678108
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.005396353080868721 - deformation = power_abs_down
# statistic = 0.004113715863174095 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.5842302499027171
# relative_error_metric = 0.6758830124741995
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.004176371730864048 - deformation = power_abs_down
# statistic = 0.0024343402391206292 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.34207823866704007
# relative_error_metric = 0.17840717485050686
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0035663810558617115 - deformation = power_abs_down
# statistic = 0.0017626637462729606 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.15756429058360474
# relative_error_metric = 0.14371880828583472
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0038713763933628798 - deformation = power_abs_down
# statistic = 0.0020356928953439296 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.08201271406960574
# relative_error_metric = 4.313826741793258e-05
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.0037188787246122956 - deformation = power_abs_down
# statistic = 0.0019217212896652798 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.040182488303835924
# relative_error_metric = 0.05755592571448514
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0037951275589875877 - deformation = power_abs_down
# statistic = 0.0020108109246978674 - next threshold = 0.0020356050809735094 at 0.99 CL
# relative_error_eps = 0.01989142243953712
# relative_error_metric = 0.01225487257903835
# =======> statistic within required accuracy at 0.99 CL in 154.86816185398493 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 309.4417592330137 seconds.
# Saving results in the file results/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with random_normal deformation.
#
# ======================================================
# =============== fgd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# ...
# relative_error_metric = 0.8716587594578936
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.00814119353890419 - deformation = power_abs_down
# statistic = 3.1987383264841998 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.855867790735093
# relative_error_metric = 0.49329383835082924
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0057013798505067825 - deformation = power_abs_down
# statistic = 2.365156737002273 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.5444222658405281
# relative_error_metric = 0.2010848650294308
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.004481473006308079 - deformation = power_abs_down
# statistic = 1.9662338248775377 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.31509768132763616
# relative_error_metric = 0.017041822068176577
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.003871519584208727 - deformation = power_abs_down
# statistic = 1.774430625106918 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.14604428664089444
# relative_error_metric = 0.08554589077599056
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.004176496295258403 - deformation = power_abs_down
# statistic = 1.869543824758192 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.07044994049459073
# relative_error_metric = 0.033380157352619934
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.004328984650783241 - deformation = power_abs_down
# statistic = 1.917697676984444 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.03461530863884327
# relative_error_metric = 0.007952332592717774
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.00440522882854566 - deformation = power_abs_down
# statistic = 1.9419114799474164 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.017458739231154506
# relative_error_metric = 0.004595064400335551
# =======> statistic within required accuracy at 0.99 CL in 129.57269050501054 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 245.73374073498417 seconds.
# Saving results in the file results/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 102.94360592535425 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9393368750330897
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 32.74656267436358 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8153011718790806
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 9.212054115444381 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4127200000873086
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 2.6616263723657707 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5068955662375233
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 1.2391881937135771 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.24505566252798064
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.234375 - deformation = random_normal
# statistic = 1.7874818948140268 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.11991420692490724
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.1953125 - deformation = random_normal
# statistic = 1.4730875199273514 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.07335618441095637
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.21484375 - deformation = random_normal
# statistic = 1.6090473132470067 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.014892339964428679
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.205078125 - deformation = random_normal
# statistic = 1.5332650529410061 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.03334708383974428
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.2099609375 - deformation = random_normal
# statistic = 1.568445140165329 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.022988505747126436
# relative_error_metric = 0.010664784606474312
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.21240234375 - deformation = random_normal
# statistic = 1.597309615167166 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.011560693641618497
# relative_error_metric = 0.007571029527373186
# =======> statistic within required accuracy at 0.95 CL in 81.98921148298541 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.211181640625 - deformation = random_normal
# statistic = 1.5858767786016752 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 1.8379011478097915
# relative_error_metric = 0.19729652865683242
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.6055908203125 - deformation = random_normal
# statistic = 109.67843151958063 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 1.7001083423618635
# relative_error_metric = 1.9307236347188816
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.40838623046875 - deformation = random_normal
# statistic = 40.256658139195004 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 1.478424722065197
# relative_error_metric = 1.8167315487768612
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.809783935546875 - deformation = random_normal
# statistic = 14.924521768363764 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 1.1726199372291137
# relative_error_metric = 1.5413305106231716
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.5104827880859375 - deformation = random_normal
# statistic = 6.359914425632844 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.8294745744793318
# relative_error_metric = 1.0676345647214665
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.36083221435546875 - deformation = random_normal
# statistic = 3.3874839857673256 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.5232410803601201
# relative_error_metric = 0.54674457369295
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.2860069274902344 - deformation = random_normal
# statistic = 2.323322716788505 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.300993593432309
# relative_error_metric = 0.1834039458785746
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.2485942840576172 - deformation = random_normal
# statistic = 1.9243392254947762 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.13996467880906935
# relative_error_metric = 0.004495057544928199
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.2673006057739258 - deformation = random_normal
# statistic = 2.1106194439168564 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.07251989537022488
# relative_error_metric = 0.08784720575299
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.2579474449157715 - deformation = random_normal
# statistic = 2.0121830919323 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.03692947815813875
# relative_error_metric = 0.04013714393872152
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.25327086448669434 - deformation = random_normal
# statistic = 1.9529777070466179 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.018636800912124846
# relative_error_metric = 0.010277432198746703
# =======> statistic within required accuracy at 0.99 CL in 80.02315868303413 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 162.012401141983 seconds.
# Saving results in the file results/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_uniform
# statistic = 42.81844884899353 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8571955437731977
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_uniform
# statistic = 12.222763347901326 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.540770845914607
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_uniform
# statistic = 3.3849056917690925 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.724178289455273
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_uniform
# statistic = 1.3780804249003626 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1398296199932436
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_uniform
# statistic = 2.148357696184139 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.30163530673938305
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.390625 - deformation = random_uniform
# statistic = 1.70352250724695 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.07191749138396401
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.3515625 - deformation = random_uniform
# statistic = 1.524180529800225 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.03928769499262034
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.37109375 - deformation = random_uniform
# statistic = 1.60864326102193 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.014641209415560984
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.361328125 - deformation = random_uniform
# statistic = 1.5760140768090458 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.02666666666666667
# relative_error_metric = 0.005850717670068766
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.3662109375 - deformation = random_uniform
# statistic = 1.5883292244557288 - next threshold = 1.5852619435451714 at 0.95 CL
# relative_error_eps = 0.013422818791946308
# relative_error_metric = 0.0019330031804251245
# =======> statistic within required accuracy at 0.95 CL in 70.47977134399116 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.36376953125 - deformation = random_uniform
# statistic = 1.568245448795982 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 1.728720983158853
# relative_error_metric = 0.2083614950498815
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.681884765625 - deformation = random_uniform
# statistic = 48.38736575355999 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 1.5222444889779558
# relative_error_metric = 1.8463438520882782
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.5228271484375 - deformation = random_uniform
# statistic = 17.596150580813777 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 1.2287285668068586
# relative_error_metric = 1.6040774319810844
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.94329833984375 - deformation = random_uniform
# statistic = 7.1909424982124435 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.8867616156899369
# relative_error_metric = 1.1525563087749744
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.653533935546875 - deformation = random_uniform
# statistic = 3.658868153159901 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.5696715164241788
# relative_error_metric = 0.6172737577933429
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.5086517333984375 - deformation = random_uniform
# statistic = 2.416847231038078 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.33213817227809356
# relative_error_metric = 0.22246185152587752
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.43621063232421875 - deformation = random_uniform
# statistic = 1.9526077271798041 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.18110724333603548
# relative_error_metric = 0.010087975184782093
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.3999900817871094 - deformation = random_uniform
# statistic = 1.7533329134661202 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.08663123560137771
# relative_error_metric = 0.09748191030987212
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.41810035705566406 - deformation = random_uniform
# statistic = 1.8537304114140334 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.04239738337370648
# relative_error_metric = 0.04187154789925675
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.4271554946899414 - deformation = random_uniform
# statistic = 1.9125628778619164 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.020976356034706534
# relative_error_metric = 0.010633450756040256
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.4316830635070801 - deformation = random_uniform
# statistic = 1.9184938942011003 - next threshold = 1.9330087260011688 at 0.99 CL
# relative_error_eps = 0.010433464003450351
# relative_error_metric = 0.007537230650673291
# =======> statistic within required accuracy at 0.99 CL in 77.75761307997163 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 148.23741672898177 seconds.
# Saving results in the file results/5D_unimodal/5D_100K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-03T00:39:29.855446', 'fgd_cov_diag_2024-05-03T00:43:58.654730', 'fgd_cov_off_diag_2024-05-03T00:48:43.674863', 'fgd_power_abs_up_2024-05-03T00:53:59.875377', 'fgd_power_abs_down_2024-05-03T00:59:19.539298', 'fgd_random_normal_2024-05-03T01:04:28.984212', 'fgd_random_uniform_2024-05-03T01:08:35.300482', 'mmd_mean_2024-05-03T01:12:17.415567', 'mmd_cov_diag_2024-05-03T01:23:13.760197', 'mmd_cov_off_diag_2024-05-03T01:35:56.978848', 'mmd_power_abs_up_2024-05-03T01:47:54.588940', 'mmd_power_abs_down_2024-05-03T02:02:11.387282', 'mmd_random_normal_2024-05-03T02:16:55.191999', 'mmd_random_uniform_2024-05-03T02:25:14.637262', 'ks_mean_2024-05-03T02:34:24.355505', 'ks_cov_diag_2024-05-03T02:37:38.805840', 'ks_cov_off_diag_2024-05-03T02:41:14.228383', 'ks_power_abs_up_2024-05-03T02:44:23.443764', 'ks_power_abs_down_2024-05-03T02:48:18.320040', 'ks_random_normal_2024-05-03T02:52:10.656404', 'ks_random_uniform_2024-05-03T02:55:14.126264', 'sks_mean_2024-05-03T02:57:56.118260', 'sks_cov_diag_2024-05-03T03:02:36.754402', 'sks_cov_off_diag_2024-05-03T03:07:52.896722', 'sks_power_abs_up_2024-05-03T03:13:28.691352', 'sks_power_abs_down_2024-05-03T03:19:14.052347', 'sks_random_normal_2024-05-03T03:25:04.386457', 'sks_random_uniform_2024-05-03T03:29:02.111543', 'swd_mean_2024-05-03T03:32:47.366988', 'swd_cov_diag_2024-05-03T03:36:01.506247', 'swd_cov_off_diag_2024-05-03T03:39:36.840279', 'swd_power_abs_up_2024-05-03T03:43:26.957236', 'swd_power_abs_down_2024-05-03T03:47:20.670619', 'swd_random_normal_2024-05-03T03:51:26.413613', 'swd_random_uniform_2024-05-03T03:54:08.435209'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.1,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.05 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 73.40237044700189 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.050000.json
# ThresholdS: [[0.95, [9500, 500], -30.840872113369308], [0.99, [9900, 100], -23.47788522410921]]
# Null distribution computed in 73.57419273699634 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.38657835702179 seconds.
# statistic = 54.279221050737384 - next threshold = -30.840872113369308 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 7.263318196308493
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.025 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.4118799760472 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.025000.json
# ThresholdS: [[0.95, [9500, 500], -2.860965518467488], [0.99, [9900, 100], 0.820527926162558]]
# Null distribution computed in 72.58020283398218 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.380938047019299 seconds.
# statistic = 14.58013998725031 - next threshold = -2.860965518467488 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.976507526562879
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.0125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.94611631002044 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.012500.json
# ThresholdS: [[0.95, [9500, 500], 1.709384874991275], [0.99, [9900, 100], 3.550131597306298]]
# Null distribution computed in 73.11373398499563 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.3838341779774055 seconds.
# statistic = 4.15020235913672 - next threshold = 1.709384874991275 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.833102191884572
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.00625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.82395550596993 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.006250.json
# ThresholdS: [[0.95, [9500, 500], 1.6396593461342104], [0.99, [9900, 100], 2.5600327072917217]]
# Null distribution computed in 72.98844599095173 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.318576574965846 seconds.
# statistic = 1.290134270979178 - next threshold = 1.6396593461342104 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.23860047555117941
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.009375000000000001 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 73.15297275298508 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.009375.json
# ThresholdS: [[0.95, [9500, 500], 1.8707638375577498], [0.99, [9900, 100], 3.251323879623289]]
# Null distribution computed in 73.31956926896237 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.368549143022392 seconds.
# statistic = 2.5239265878159873 - next threshold = 1.8707638375577498 at 0.95 CL
# relative_error_eps = 0.40000000000000013
# relative_error_metric = 0.2972508582115614
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.0078125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.94857986399438 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.007812.json
# ThresholdS: [[0.95, [9500, 500], 1.80427202367705], [0.99, [9900, 100], 2.954738724959303]]
# Null distribution computed in 73.11611754604382 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.337285272020381 seconds.
# statistic = 1.8579699974841948 - next threshold = 1.80427202367705 at 0.95 CL
# relative_error_eps = 0.22222222222222215
# relative_error_metric = 0.02932519123360282
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.00703125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.9834035319509 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.007031.json
# ThresholdS: [[0.95, [9500, 500], 1.7342307931926697], [0.99, [9900, 100], 2.769650824247916]]
# Null distribution computed in 73.15018796204822 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.355359909997787 seconds.
# statistic = 1.561787026224528 - next threshold = 1.7342307931926697 at 0.95 CL
# relative_error_eps = 0.10526315789473682
# relative_error_metric = 0.10463764240123757
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.007421875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 73.06467845395673 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.007422.json
# ThresholdS: [[0.95, [9500, 500], 1.7723176851773474], [0.99, [9900, 100], 2.8652610515107333]]
# Null distribution computed in 73.23654598399298 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.344898583018221 seconds.
# statistic = 1.7068122349472374 - next threshold = 1.7723176851773474 at 0.95 CL
# relative_error_eps = 0.05128205128205133
# relative_error_metric = 0.0376562253977364
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.0076171875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.62522245198488 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.007617.json
# ThresholdS: [[0.95, [9500, 500], 1.7890614236128208], [0.99, [9900, 100], 2.910766457585276]]
# Null distribution computed in 72.79605059704045 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.402093128999695 seconds.
# statistic = 1.7816245469971668 - next threshold = 1.7890614236128208 at 0.95 CL
# relative_error_eps = 0.025316455696202552
# relative_error_metric = 0.0041655170333467365
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.00771484375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 73.2643192189862 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.007715.json
# ThresholdS: [[0.95, [9500, 500], 1.796858366023659], [0.99, [9900, 100], 2.932944233651013]]
# Null distribution computed in 73.4372657900094 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.348146541975439 seconds.
# statistic = 1.8196056299772028 - next threshold = 1.796858366023659 at 0.95 CL
# relative_error_eps = 0.012738853503184782
# relative_error_metric = 0.012579837088768486
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.007666015625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.96843160002027 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.007666.json
# ThresholdS: [[0.95, [9500, 500], 1.7930078055775567], [0.99, [9900, 100], 2.9219032562128255]]
# Null distribution computed in 73.133136020042 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.38313053001184 seconds.
# statistic = 1.8005671778266494 - next threshold = 1.7930078055775567 at 0.95 CL
# relative_error_eps = 0.006389776357827454
# relative_error_metric = 0.004207159880622129
# =======> statistic within required accuracy at 0.95 CL in 939.4375153850415 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.007641601562499999 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.54786639998201 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.007642.json
# ThresholdS: [[0.95, [9500, 500], 1.7910465922027], [0.99, [9900, 100], 2.916346834341926]]
# Null distribution computed in 72.71653530898038 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.360775265027769 seconds.
# statistic = 1.7910838848208606 - next threshold = 2.916346834341926 at 0.99 CL
# relative_error_eps = 1.7160353821728282
# relative_error_metric = 0.47807945210553954
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.05382080078125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# ...
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 76.40732613095315 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_power_abs_down_0.000909.json
# ThresholdS: [[0.95, [9500, 500], 1.877680872309692], [0.99, [9900, 100], 3.8001997464574058]]
# Null distribution computed in 76.56542477902258 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.569570256979205 seconds.
# statistic = 4.0450715186240105 - next threshold = 3.8001997464574058 at 0.99 CL
# relative_error_eps = 0.05487579197171115
# relative_error_metric = 0.06242531682913414
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0008847292512655259 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 76.4188735220232 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_power_abs_down_0.000885.json
# ThresholdS: [[0.95, [9500, 500], 1.9034629032973778], [0.99, [9900, 100], 3.7743427214089675]]
# Null distribution computed in 76.57674928900087 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.577556442993227 seconds.
# statistic = 3.8611516841016233 - next threshold = 3.7743427214089675 at 0.99 CL
# relative_error_eps = 0.027819550958643753
# relative_error_metric = 0.022738268953482608
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0008725916966795922 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 76.15368240803946 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_power_abs_down_0.000873.json
# ThresholdS: [[0.95, [9500, 500], 1.9147289643336762], [0.99, [9900, 100], 3.759920076763257]]
# Null distribution computed in 76.31087033002404 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.517575048026629 seconds.
# statistic = 3.771190913794818 - next threshold = 3.759920076763257 at 0.99 CL
# relative_error_eps = 0.014007193940727292
# relative_error_metric = 0.0029931405992267464
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0008665229193866254 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 76.66650556400418 seconds.
# Saving lr to results/5D_unimodal/5D_100K/null_hypothesis/LR_power_abs_down_0.000867.json
# ThresholdS: [[0.95, [9500, 500], 1.9199980823335339], [0.99, [9900, 100], 3.7522826364664303]]
# Null distribution computed in 76.82436310499907 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 6.525460775010288 seconds.
# statistic = 3.726377337734797 - next threshold = 3.7522826364664303 at 0.99 CL
# relative_error_eps = 0.006979157367665647
# relative_error_metric = 0.006927791561856739
# =======> statistic within required accuracy at 0.99 CL in 1346.877025305992 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2695.541581875994 seconds.
# Saving results in the file results/5D_unimodal/5D_100K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-03T00:39:29.855446', 'fgd_cov_diag_2024-05-03T00:43:58.654730', 'fgd_cov_off_diag_2024-05-03T00:48:43.674863', 'fgd_power_abs_up_2024-05-03T00:53:59.875377', 'fgd_power_abs_down_2024-05-03T00:59:19.539298', 'fgd_random_normal_2024-05-03T01:04:28.984212', 'fgd_random_uniform_2024-05-03T01:08:35.300482', 'mmd_mean_2024-05-03T01:12:17.415567', 'mmd_cov_diag_2024-05-03T01:23:13.760197', 'mmd_cov_off_diag_2024-05-03T01:35:56.978848', 'mmd_power_abs_up_2024-05-03T01:47:54.588940', 'mmd_power_abs_down_2024-05-03T02:02:11.387282', 'mmd_random_normal_2024-05-03T02:16:55.191999', 'mmd_random_uniform_2024-05-03T02:25:14.637262', 'ks_mean_2024-05-03T02:34:24.355505', 'ks_cov_diag_2024-05-03T02:37:38.805840', 'ks_cov_off_diag_2024-05-03T02:41:14.228383', 'ks_power_abs_up_2024-05-03T02:44:23.443764', 'ks_power_abs_down_2024-05-03T02:48:18.320040', 'ks_random_normal_2024-05-03T02:52:10.656404', 'ks_random_uniform_2024-05-03T02:55:14.126264', 'sks_mean_2024-05-03T02:57:56.118260', 'sks_cov_diag_2024-05-03T03:02:36.754402', 'sks_cov_off_diag_2024-05-03T03:07:52.896722', 'sks_power_abs_up_2024-05-03T03:13:28.691352', 'sks_power_abs_down_2024-05-03T03:19:14.052347', 'sks_random_normal_2024-05-03T03:25:04.386457', 'sks_random_uniform_2024-05-03T03:29:02.111543', 'swd_mean_2024-05-03T03:32:47.366988', 'swd_cov_diag_2024-05-03T03:36:01.506247', 'swd_cov_off_diag_2024-05-03T03:39:36.840279', 'swd_power_abs_up_2024-05-03T03:43:26.957236', 'swd_power_abs_down_2024-05-03T03:47:20.670619', 'swd_random_normal_2024-05-03T03:51:26.413613', 'swd_random_uniform_2024-05-03T03:54:08.435209', 'lr_mean_2024-05-03T03:56:36.706146', 'lr_cov_diag_2024-05-03T04:27:54.187885', 'lr_cov_off_diag_2024-05-03T05:08:13.526459', 'lr_power_abs_up_2024-05-03T06:05:44.492647', 'lr_power_abs_down_2024-05-03T06:47:19.751715'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean    5  10000               100000
# 14        ks        mean    5  10000               100000
# 0        fgd        mean    5  10000               100000
# 28       swd        mean    5  10000               100000
# 21       sks        mean    5  10000               100000
# 7        mmd        mean    5  10000               100000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.00764                             0.01129
# 14                             0.02701                             0.03399
# 0                              0.02731                             0.03687
# 28                             0.02914                             0.03916
# 21                             0.03036                             0.04159
# 7                              0.04120                             0.05603
#
#     $t^{\mu}$ (s)
# 35           1877
# 14            194
# 0             268
# 28            194
# 21            280
# 7             656
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.00764
# 14        ks                             0.02701
# 0        fgd                             0.02731
# 28       swd                             0.02914
# 21       sks                             0.03036
# 7        mmd                             0.04120
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.01129           1877
# 14                             0.03399            194
# 0                              0.03687            268
# 28                             0.03916            194
# 21                             0.04159            280
# 7                              0.05603            656

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag    5  10000               100000
# 1        fgd    cov_diag    5  10000               100000
# 29       swd    cov_diag    5  10000               100000
# 8        mmd    cov_diag    5  10000               100000
# 22       sks    cov_diag    5  10000               100000
# 15        ks    cov_diag    5  10000               100000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00208
# 1                                      0.00954
# 29                                     0.01152
# 8                                      0.01183
# 22                                     0.01694
# 15                                     0.02182
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00289                   2419
# 1                                      0.01251                    285
# 29                                     0.01563                    215
# 8                                      0.01616                    763
# 22                                     0.02287                    316
# 15                                     0.02744                    215
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00208
# 1        fgd                                     0.00954
# 29       swd                                     0.01152
# 8        mmd                                     0.01183
# 22       sks                                     0.01694
# 15        ks                                     0.02182
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00289                   2419
# 1                                      0.01251                    285
# 29                                     0.01563                    215
# 8                                      0.01616                    763
# 22                                     0.02287                    316
# 15                                     0.02744                    215

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag    5  10000               100000
# 2        fgd  cov_off_diag    5  10000               100000
# 23       sks  cov_off_diag    5  10000               100000
# 30       swd  cov_off_diag    5  10000               100000
# 9        mmd  cov_off_diag    5  10000               100000
# 16        ks  cov_off_diag    5  10000               100000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00030
# 2                                           0.00357
# 23                                          0.01060
# 30                                          0.01106
# 9                                           0.02060
# 16                                          1.01013
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00037
# 2                                           0.00465
# 23                                          0.01510
# 30                                          0.01609
# 9                                           0.02805
# 16                                          1.01257
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        3450
# 2                          316
# 23                         335
# 30                         230
# 9                          717
# 16                         189
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00030
# 2        fgd                                          0.00357
# 23       sks                                          0.01060
# 30       swd                                          0.01106
# 9        mmd                                          0.02060
# 16        ks                                          1.01013
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00037
# 2                                           0.00465
# 23                                          0.01510
# 30                                          0.01609
# 9                                           0.02805
# 16                                          1.01257
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        3450
# 2                          316
# 23                         335
# 30                         230
# 9                          717
# 16                         189

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up    5  10000               100000
# 10       mmd  power_abs_up    5  10000               100000
# 3        fgd  power_abs_up    5  10000               100000
# 31       swd  power_abs_up    5  10000               100000
# 24       sks  power_abs_up    5  10000               100000
# 17        ks  power_abs_up    5  10000               100000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00091
# 10                                      0.00223
# 3                                       0.00242
# 31                                      0.00277
# 24                                      0.00326
# 17                                      0.00393
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00120                    2495
# 10                                      0.00305                     856
# 3                                       0.00320                     319
# 31                                      0.00387                     233
# 24                                      0.00437                     345
# 17                                      0.00496                     234
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00091
# 10       mmd                                      0.00223
# 3        fgd                                      0.00242
# 31       swd                                      0.00277
# 24       sks                                      0.00326
# 17        ks                                      0.00393
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00120                    2495
# 10                                      0.00305                     856
# 3                                       0.00320                     319
# 31                                      0.00387                     233
# 24                                      0.00437                     345
# 17                                      0.00496                     234

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down    5  10000               100000
# 11       mmd  power_abs_down    5  10000               100000
# 4        fgd  power_abs_down    5  10000               100000
# 32       swd  power_abs_down    5  10000               100000
# 25       sks  power_abs_down    5  10000               100000
# 18        ks  power_abs_down    5  10000               100000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00057
# 11                                      0.00236
# 4                                       0.00296
# 32                                      0.00326
# 25                                      0.00372
# 18                                      0.00492
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00087                    2695
# 11                                      0.00321                     883
# 4                                       0.00383                     309
# 32                                      0.00437                     245
# 25                                      0.00482                     350
# 18                                      0.00587                     232
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00057
# 11       mmd                                      0.00236
# 4        fgd                                      0.00296
# 32       swd                                      0.00326
# 25       sks                                      0.00372
# 18        ks                                      0.00492
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00087                    2695
# 11                                      0.00321                     883
# 4                                       0.00383                     309
# 32                                      0.00437                     245
# 25                                      0.00482                     350
# 18                                      0.00587                     232

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        fgd  random_normal    5  10000               100000
# 19        ks  random_normal    5  10000               100000
# 33       swd  random_normal    5  10000               100000
# 26       sks  random_normal    5  10000               100000
# 12       mmd  random_normal    5  10000               100000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                                      0.15915
# 19                                     0.18738
# 33                                     0.21118
# 26                                     0.21606
# 12                                     0.46143
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.18160                    246
# 19                                     0.20970                    183
# 33                                     0.25093                    162
# 26                                     0.25110                    237
# 12                                     0.54564                    499
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        fgd                                     0.15915
# 19        ks                                     0.18738
# 33       swd                                     0.21118
# 26       sks                                     0.21606
# 12       mmd                                     0.46143
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.18160                    246
# 19                                     0.20970                    183
# 33                                     0.25093                    162
# 26                                     0.25110                    237
# 12                                     0.54564                    499

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform    5  10000               100000
# 20        ks  random_uniform    5  10000               100000
# 34       swd  random_uniform    5  10000               100000
# 27       sks  random_uniform    5  10000               100000
# 13       mmd  random_uniform    5  10000               100000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                                      0.27710
# 20                                     0.32104
# 34                                     0.36377
# 27                                     0.36865
# 13                                     0.81787
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.31342                    222
# 20                                     0.36445                    161
# 34                                     0.43395                    148
# 27                                     0.43423                    225
# 13                                     0.93529                    549
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                                     0.27710
# 20        ks                                     0.32104
# 34       swd                                     0.36377
# 27       sks                                     0.36865
# 13       mmd                                     0.81787
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.31342                    222
# 20                                     0.36445                    161
# 34                                     0.43395                    148
# 27                                     0.43423                    225
# 13                                     0.93529                    549

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.027 & 0.037 & 268 & cov_diag & 5 & 10000 & 100000 & 0.0095 & 0.013 & 285 & cov_off_diag & 5 & 10000 & 100000 & 0.0036 & 0.0046 & 316 & 0.0024 & 0.0032 & 319 \\
# $\overline{D}$ & 0.027 & 0.034 & 194 & cov_diag & 5 & 10000 & 100000 & 0.022 & 0.027 & 215 & cov_off_diag & 5 & 10000 & 100000 & 1 & 1 & 189 & 0.0039 & 0.005 & 234 \\
# $t_{\mathrm{LLR}}$ & 0.0076 & 0.011 & 1877 & cov_diag & 5 & 10000 & 100000 & 0.0021 & 0.0029 & 2419 & cov_off_diag & 5 & 10000 & 100000 & 0.0003 & 0.00037 & 3450 & 0.00091 & 0.0012 & 2495 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.041 & 0.056 & 656 & cov_diag & 5 & 10000 & 100000 & 0.012 & 0.016 & 763 & cov_off_diag & 5 & 10000 & 100000 & 0.021 & 0.028 & 717 & 0.0022 & 0.0031 & 856 \\
# $\widetilde{D}$ & 0.03 & 0.042 & 280 & cov_diag & 5 & 10000 & 100000 & 0.017 & 0.023 & 316 & cov_off_diag & 5 & 10000 & 100000 & 0.011 & 0.015 & 335 & 0.0033 & 0.0044 & 345 \\
# $\widetilde{W}$ & 0.029 & 0.039 & 194 & cov_diag & 5 & 10000 & 100000 & 0.012 & 0.016 & 215 & cov_off_diag & 5 & 10000 & 100000 & 0.011 & 0.016 & 230 & 0.0028 & 0.0039 & 233 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.003 & 0.0038 & 309 & 0.16 & 0.18 & 2.5e+02 & 0.28 & 0.31 & 2.2e+02 & 2268 \\
# $\overline{D}$ & 0.0049 & 0.0059 & 232 & 0.19 & 0.21 & 1.8e+02 & 0.32 & 0.36 & 1.6e+02 & 66 \\
# $t_{\mathrm{LLR}}$ & 0.00057 & 0.00087 & 2695 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.0024 & 0.0032 & 883 & 0.46 & 0.55 & 5e+02 & 0.82 & 0.94 & 5.5e+02 & 16279 \\
# $\widetilde{D}$ & 0.0037 & 0.0048 & 350 & 0.22 & 0.25 & 2.4e+02 & 0.37 & 0.43 & 2.2e+02 & 646 \\
# $\widetilde{W}$ & 0.0033 & 0.0044 & 245 & 0.21 & 0.25 & 1.6e+02 & 0.36 & 0.43 & 1.5e+02 & 351 \\
# \bottomrule
# \end{tabular}
