# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [3]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_unimodal import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results_leonardo/5D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-16 16:32:29.106396: Importing os...
# 2024-04-16 16:32:29.106542: Importing sys...
# Visible devices: [3]
# 2024-04-16 16:32:29.106779: Importing timer from timeit...
# 2024-04-16 16:32:29.106847: Setting env variables for tf import (only device(s) [3] will be available)...
# 2024-04-16 16:32:29.106978: Importing numpy...
# 2024-04-16 16:32:29.216792: Importing matplotlib...
# 2024-04-16 16:32:29.565974: Importing h5py...
# 2024-04-16 16:32:29.589218: Importing importlib.util...
# 2024-04-16 16:32:29.589319: Importing json...
# 2024-04-16 16:32:29.589386: Importing pandas...
# 2024-04-16 16:32:30.011001: Importing random...
# 2024-04-16 16:32:30.011143: Importing scipy utils...
# 2024-04-16 16:32:30.396012: Importing subprocess...
# 2024-04-16 16:32:30.396140: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-16 16:32:36.721190: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-16 16:32:37.822984: Importing timeit...
# 2024-04-16 16:32:37.823074: Importing tqdm...
# 2024-04-16 16:32:37.830526: Importing typing...
# 2024-04-16 16:32:37.830630: Setting tf configs...
# 2024-04-16 16:32:37.944724: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-16 16:32:42.466497: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #3, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-04-16 16:32:42.499159: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = 0.,
                                                             eps_scale = 0.,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
dist_2 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = eps_loc,
                                                             eps_scale = eps_scale,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)

# %% [markdown]
# # Fixed $n=100000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 100_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 1000000000
# batch_size 100000
# niter 10000
# niter * batch_size 1000000000
# small_sample False

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               #min_samples_input = 20_000,
                               #max_samples_input = 50_000,
                               num_batches = 20)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4,
                               block_size = 5_000,
                               num_batches = 1,
                               batch_size = 100_000)
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000           100000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims    nsamples  small_sample  \
# 0       True        5           0  float64     5  1000000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fn": {"name": "fn", # type: ignore
                                      "object_name": "FNMetric",
                                      "class_name": "GMetrics.FNMetric",
                                      "kwargs": {},
                                      "result_key": "metric_list", 
                                      "scale_func": lambda ns, ndims: np.sqrt(ns)/ndims,
                                      "scale_func_string": "lambda ns, ndims: np.sqrt(ns)/ndims",
                                      "test_config": test_config_null,
                                      "max_vectorize": 500, # optimized for 5D
                                      "latex": "$\overline{\|\cdot\|}_{F}$",
                                      "null_file": null_hypotheses_dir+"FN.json"},
                               "fpd": {"name": "fpd",
                                       "object_name": "FPDMetric",
                                       "class_name": "GMetrics.FPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100, # optimized for 5D
                                       "latex": "$d_{\mathrm{FPD}}$",
                                       "null_file": null_hypotheses_dir+"FPD.json"},
                               "kpd": {"name": "kpd",
                                       "object_name": "KPDMetric" ,
                                       "class_name": "GMetrics.KPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1, # optimized for 5D
                                       "latex": "$d_{\mathrm{KPD}}$",
                                       "null_file": null_hypotheses_dir+"KPD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fn': {'name': 'fn',
#   'object_name': 'FNMetric',
#   'class_name': 'GMetrics.FNMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)/ndims',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\overline{\\|\\cdot\\|}_{F}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_100K/null_hypothesis/FN.json'},
#  'fpd': {'name': 'fpd',
#   'object_name': 'FPDMetric',
#   'class_name': 'GMetrics.FPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 100,
#   'latex': '$d_{\\mathrm{FPD}}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_100K/null_hypothesis/FPD.json'},
#  'kpd': {'name': 'kpd',
#   'object_name': 'KPDMetric',
#   'class_name': 'GMetrics.KPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{KPD}}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_100K/null_hypothesis/KPD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_100K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 50,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_100K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 50,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_100K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 200,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fn from results_leonardo/5D_unimodal/5D_100K/null_hypothesis/FN.json
# Loading fpd from results_leonardo/5D_unimodal/5D_100K/null_hypothesis/FPD.json
# Computing and savng kpd with max_vectorize = 1
#
# ------------------------------------------
# Starting KPD metric calculation...
# Running TF KPD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10000
# Iterating from 0 to 1 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713277977.806434  736307 service.cc:145] XLA service 0x10d890d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1713277977.806476  736307 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1713277980.044097  736307 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# Iterating from 1 to 2 out of 10000 .
# Iterating from 2 to 3 out of 10000 .
# Iterating from 3 to 4 out of 10000 .
# Iterating from 4 to 5 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fe6600caca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 5 to 6 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7fe6600caca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 6 to 7 out of 10000 .
# Iterating from 7 to 8 out of 10000 .
# Iterating from 8 to 9 out of 10000 .
# Iterating from 9 to 10 out of 10000 .
# Iterating from 10 to 11 out of 10000 .
# Iterating from 11 to 12 out of 10000 .
# Iterating from 12 to 13 out of 10000 .
# Iterating from 13 to 14 out of 10000 .
# Iterating from 14 to 15 out of 10000 .
# Iterating from 15 to 16 out of 10000 .
# Iterating from 16 to 17 out of 10000 .
# Iterating from 17 to 18 out of 10000 .
# Iterating from 18 to 19 out of 10000 .
# Iterating from 19 to 20 out of 10000 .
# Iterating from 20 to 21 out of 10000 .
# Iterating from 21 to 22 out of 10000 .
# Iterating from 22 to 23 out of 10000 .
# Iterating from 23 to 24 out of 10000 .
# Iterating from 24 to 25 out of 10000 .
# Iterating from 25 to 26 out of 10000 .
# Iterating from 26 to 27 out of 10000 .
# Iterating from 27 to 28 out of 10000 .
# Iterating from 28 to 29 out of 10000 .
# Iterating from 29 to 30 out of 10000 .
# Iterating from 30 to 31 out of 10000 .
# Iterating from 31 to 32 out of 10000 .
# Iterating from 32 to 33 out of 10000 .
# Iterating from 33 to 34 out of 10000 .
# Iterating from 34 to 35 out of 10000 .
# Iterating from 35 to 36 out of 10000 .
# Iterating from 36 to 37 out of 10000 .
# Iterating from 37 to 38 out of 10000 .
# Iterating from 38 to 39 out of 10000 .
# Iterating from 39 to 40 out of 10000 .
# Iterating from 40 to 41 out of 10000 .
# Iterating from 41 to 42 out of 10000 .
# Iterating from 42 to 43 out of 10000 .
# Iterating from 43 to 44 out of 10000 .
# Iterating from 44 to 45 out of 10000 .
# Iterating from 45 to 46 out of 10000 .
# Iterating from 46 to 47 out of 10000 .
# Iterating from 47 to 48 out of 10000 .
# Iterating from 48 to 49 out of 10000 .
# Iterating from 49 to 50 out of 10000 .
# Iterating from 50 to 51 out of 10000 .
# Iterating from 51 to 52 out of 10000 .
# Iterating from 52 to 53 out of 10000 .
# Iterating from 53 to 54 out of 10000 .
# Iterating from 54 to 55 out of 10000 .
# Iterating from 55 to 56 out of 10000 .
# Iterating from 56 to 57 out of 10000 .
# Iterating from 57 to 58 out of 10000 .
# Iterating from 58 to 59 out of 10000 .
# Iterating from 59 to 60 out of 10000 .
# Iterating from 60 to 61 out of 10000 .
# Iterating from 61 to 62 out of 10000 .
# Iterating from 62 to 63 out of 10000 .
# Iterating from 63 to 64 out of 10000 .
# Iterating from 64 to 65 out of 10000 .
# Iterating from 65 to 66 out of 10000 .
# Iterating from 66 to 67 out of 10000 .
# Iterating from 67 to 68 out of 10000 .
# Iterating from 68 to 69 out of 10000 .
# Iterating from 69 to 70 out of 10000 .
# Iterating from 70 to 71 out of 10000 .
# Iterating from 71 to 72 out of 10000 .
# Iterating from 72 to 73 out of 10000 .
# Iterating from 73 to 74 out of 10000 .
# Iterating from 74 to 75 out of 10000 .
# Iterating from 75 to 76 out of 10000 .
# Iterating from 76 to 77 out of 10000 .
# Iterating from 77 to 78 out of 10000 .
# Iterating from 78 to 79 out of 10000 .
# Iterating from 79 to 80 out of 10000 .
# Iterating from 80 to 81 out of 10000 .
# Iterating from 81 to 82 out of 10000 .
# Iterating from 82 to 83 out of 10000 .
# Iterating from 83 to 84 out of 10000 .
# Iterating from 84 to 85 out of 10000 .
# Iterating from 85 to 86 out of 10000 .
# Iterating from 86 to 87 out of 10000 .
# Iterating from 87 to 88 out of 10000 .
# Iterating from 88 to 89 out of 10000 .
# Iterating from 89 to 90 out of 10000 .
# Iterating from 90 to 91 out of 10000 .
# Iterating from 91 to 92 out of 10000 .
# Iterating from 92 to 93 out of 10000 .
# Iterating from 93 to 94 out of 10000 .
# Iterating from 94 to 95 out of 10000 .
# Iterating from 95 to 96 out of 10000 .
# Iterating from 96 to 97 out of 10000 .
# Iterating from 97 to 98 out of 10000 .
# Iterating from 98 to 99 out of 10000 .
# Iterating from 99 to 100 out of 10000 .
# Iterating from 100 to 101 out of 10000 .
# Iterating from 101 to 102 out of 10000 .
# Iterating from 102 to 103 out of 10000 .
# Iterating from 103 to 104 out of 10000 .
# Iterating from 104 to 105 out of 10000 .
# Iterating from 105 to 106 out of 10000 .
# Iterating from 106 to 107 out of 10000 .
# Iterating from 107 to 108 out of 10000 .
# Iterating from 108 to 109 out of 10000 .
# Iterating from 109 to 110 out of 10000 .
# Iterating from 110 to 111 out of 10000 .
# Iterating from 111 to 112 out of 10000 .
# Iterating from 112 to 113 out of 10000 .
# Iterating from 113 to 114 out of 10000 .
# Iterating from 114 to 115 out of 10000 .
# Iterating from 115 to 116 out of 10000 .
# Iterating from 116 to 117 out of 10000 .
# Iterating from 117 to 118 out of 10000 .
# Iterating from 118 to 119 out of 10000 .
# Iterating from 119 to 120 out of 10000 .
# Iterating from 120 to 121 out of 10000 .
# Iterating from 121 to 122 out of 10000 .
# Iterating from 122 to 123 out of 10000 .
# Iterating from 123 to 124 out of 10000 .
# Iterating from 124 to 125 out of 10000 .
# Iterating from 125 to 126 out of 10000 .
# Iterating from 126 to 127 out of 10000 .
# Iterating from 127 to 128 out of 10000 .
# Iterating from 128 to 129 out of 10000 .
# Iterating from 129 to 130 out of 10000 .
# Iterating from 130 to 131 out of 10000 .
# Iterating from 131 to 132 out of 10000 .
# Iterating from 132 to 133 out of 10000 .
# Iterating from 133 to 134 out of 10000 .
# Iterating from 134 to 135 out of 10000 .
# Iterating from 135 to 136 out of 10000 .
# Iterating from 136 to 137 out of 10000 .
# Iterating from 137 to 138 out of 10000 .
# Iterating from 138 to 139 out of 10000 .
# Iterating from 139 to 140 out of 10000 .
# Iterating from 140 to 141 out of 10000 .
# Iterating from 141 to 142 out of 10000 .
# Iterating from 142 to 143 out of 10000 .
# Iterating from 143 to 144 out of 10000 .
# Iterating from 144 to 145 out of 10000 .
# Iterating from 145 to 146 out of 10000 .
# Iterating from 146 to 147 out of 10000 .
# Iterating from 147 to 148 out of 10000 .
# Iterating from 148 to 149 out of 10000 .
# Iterating from 149 to 150 out of 10000 .
# Iterating from 150 to 151 out of 10000 .
# Iterating from 151 to 152 out of 10000 .
# Iterating from 152 to 153 out of 10000 .
# Iterating from 153 to 154 out of 10000 .
# Iterating from 154 to 155 out of 10000 .
# Iterating from 155 to 156 out of 10000 .
# Iterating from 156 to 157 out of 10000 .
# Iterating from 157 to 158 out of 10000 .
# Iterating from 158 to 159 out of 10000 .
# Iterating from 159 to 160 out of 10000 .
# Iterating from 160 to 161 out of 10000 .
# Iterating from 161 to 162 out of 10000 .
# Iterating from 162 to 163 out of 10000 .
# Iterating from 163 to 164 out of 10000 .
# Iterating from 164 to 165 out of 10000 .
# Iterating from 165 to 166 out of 10000 .
# Iterating from 166 to 167 out of 10000 .
# Iterating from 167 to 168 out of 10000 .
# Iterating from 168 to 169 out of 10000 .
# Iterating from 169 to 170 out of 10000 .
# Iterating from 170 to 171 out of 10000 .
# Iterating from 171 to 172 out of 10000 .
# Iterating from 172 to 173 out of 10000 .
# Iterating from 173 to 174 out of 10000 .
# Iterating from 174 to 175 out of 10000 .
# Iterating from 175 to 176 out of 10000 .
# Iterating from 176 to 177 out of 10000 .
# Iterating from 177 to 178 out of 10000 .
# Iterating from 178 to 179 out of 10000 .
# Iterating from 179 to 180 out of 10000 .
# Iterating from 180 to 181 out of 10000 .
# Iterating from 181 to 182 out of 10000 .
# Iterating from 182 to 183 out of 10000 .
# Iterating from 183 to 184 out of 10000 .
# Iterating from 184 to 185 out of 10000 .
# Iterating from 185 to 186 out of 10000 .
# Iterating from 186 to 187 out of 10000 .
# Iterating from 187 to 188 out of 10000 .
# Iterating from 188 to 189 out of 10000 .
# Iterating from 189 to 190 out of 10000 .
# Iterating from 190 to 191 out of 10000 .
# Iterating from 191 to 192 out of 10000 .
# Iterating from 192 to 193 out of 10000 .
# Iterating from 193 to 194 out of 10000 .
# Iterating from 194 to 195 out of 10000 .
# Iterating from 195 to 196 out of 10000 .
# Iterating from 196 to 197 out of 10000 .
# Iterating from 197 to 198 out of 10000 .
# Iterating from 198 to 199 out of 10000 .
# Iterating from 199 to 200 out of 10000 .
# Iterating from 200 to 201 out of 10000 .
# Iterating from 201 to 202 out of 10000 .
# Iterating from 202 to 203 out of 10000 .
# Iterating from 203 to 204 out of 10000 .
# Iterating from 204 to 205 out of 10000 .
# Iterating from 205 to 206 out of 10000 .
# Iterating from 206 to 207 out of 10000 .
# Iterating from 207 to 208 out of 10000 .
# Iterating from 208 to 209 out of 10000 .
# Iterating from 209 to 210 out of 10000 .
# Iterating from 210 to 211 out of 10000 .
# Iterating from 211 to 212 out of 10000 .
# Iterating from 212 to 213 out of 10000 .
# Iterating from 213 to 214 out of 10000 .
# Iterating from 214 to 215 out of 10000 .
# Iterating from 215 to 216 out of 10000 .
# Iterating from 216 to 217 out of 10000 .
# Iterating from 217 to 218 out of 10000 .
# Iterating from 218 to 219 out of 10000 .
# Iterating from 219 to 220 out of 10000 .
# Iterating from 220 to 221 out of 10000 .
# Iterating from 221 to 222 out of 10000 .
# Iterating from 222 to 223 out of 10000 .
# Iterating from 223 to 224 out of 10000 .
# Iterating from 224 to 225 out of 10000 .
# Iterating from 225 to 226 out of 10000 .
# Iterating from 226 to 227 out of 10000 .
# Iterating from 227 to 228 out of 10000 .
# Iterating from 228 to 229 out of 10000 .
# Iterating from 229 to 230 out of 10000 .
# Iterating from 230 to 231 out of 10000 .
# Iterating from 231 to 232 out of 10000 .
# Iterating from 232 to 233 out of 10000 .
# Iterating from 233 to 234 out of 10000 .
# Iterating from 234 to 235 out of 10000 .
# Iterating from 235 to 236 out of 10000 .
# Iterating from 236 to 237 out of 10000 .
# Iterating from 237 to 238 out of 10000 .
# Iterating from 238 to 239 out of 10000 .
# Iterating from 239 to 240 out of 10000 .
# Iterating from 240 to 241 out of 10000 .
# Iterating from 241 to 242 out of 10000 .
# Iterating from 242 to 243 out of 10000 .
# Iterating from 243 to 244 out of 10000 .
# Iterating from 244 to 245 out of 10000 .
# Iterating from 245 to 246 out of 10000 .
# Iterating from 246 to 247 out of 10000 .
# Iterating from 247 to 248 out of 10000 .
# Iterating from 248 to 249 out of 10000 .
# Iterating from 249 to 250 out of 10000 .
# Iterating from 250 to 251 out of 10000 .
# Iterating from 251 to 252 out of 10000 .
# Iterating from 252 to 253 out of 10000 .
# Iterating from 253 to 254 out of 10000 .
# Iterating from 254 to 255 out of 10000 .
# Iterating from 255 to 256 out of 10000 .
# Iterating from 256 to 257 out of 10000 .
# Iterating from 257 to 258 out of 10000 .
# Iterating from 258 to 259 out of 10000 .
# Iterating from 259 to 260 out of 10000 .
# Iterating from 260 to 261 out of 10000 .
# Iterating from 261 to 262 out of 10000 .
# Iterating from 262 to 263 out of 10000 .
# Iterating from 263 to 264 out of 10000 .
# Iterating from 264 to 265 out of 10000 .
# Iterating from 265 to 266 out of 10000 .
# Iterating from 266 to 267 out of 10000 .
# Iterating from 267 to 268 out of 10000 .
# Iterating from 268 to 269 out of 10000 .
# Iterating from 269 to 270 out of 10000 .
# Iterating from 270 to 271 out of 10000 .
# Iterating from 271 to 272 out of 10000 .
# Iterating from 272 to 273 out of 10000 .
# Iterating from 273 to 274 out of 10000 .
# Iterating from 274 to 275 out of 10000 .
# Iterating from 275 to 276 out of 10000 .
# Iterating from 276 to 277 out of 10000 .
# Iterating from 277 to 278 out of 10000 .
# Iterating from 278 to 279 out of 10000 .
# Iterating from 279 to 280 out of 10000 .
# Iterating from 280 to 281 out of 10000 .
# Iterating from 281 to 282 out of 10000 .
# Iterating from 282 to 283 out of 10000 .
# Iterating from 283 to 284 out of 10000 .
# Iterating from 284 to 285 out of 10000 .
# Iterating from 285 to 286 out of 10000 .
# Iterating from 286 to 287 out of 10000 .
# Iterating from 287 to 288 out of 10000 .
# Iterating from 288 to 289 out of 10000 .
# Iterating from 289 to 290 out of 10000 .
# Iterating from 290 to 291 out of 10000 .
# Iterating from 291 to 292 out of 10000 .
# Iterating from 292 to 293 out of 10000 .
# Iterating from 293 to 294 out of 10000 .
# Iterating from 294 to 295 out of 10000 .
# Iterating from 295 to 296 out of 10000 .
# Iterating from 296 to 297 out of 10000 .
# Iterating from 297 to 298 out of 10000 .
# Iterating from 298 to 299 out of 10000 .
# Iterating from 299 to 300 out of 10000 .
# Iterating from 300 to 301 out of 10000 .
# Iterating from 301 to 302 out of 10000 .
# Iterating from 302 to 303 out of 10000 .
# Iterating from 303 to 304 out of 10000 .
# Iterating from 304 to 305 out of 10000 .
# Iterating from 305 to 306 out of 10000 .
# Iterating from 306 to 307 out of 10000 .
# Iterating from 307 to 308 out of 10000 .
# Iterating from 308 to 309 out of 10000 .
# Iterating from 309 to 310 out of 10000 .
# Iterating from 310 to 311 out of 10000 .
# Iterating from 311 to 312 out of 10000 .
# Iterating from 312 to 313 out of 10000 .
# Iterating from 313 to 314 out of 10000 .
# Iterating from 314 to 315 out of 10000 .
# Iterating from 315 to 316 out of 10000 .
# Iterating from 316 to 317 out of 10000 .
# Iterating from 317 to 318 out of 10000 .
# Iterating from 318 to 319 out of 10000 .
# Iterating from 319 to 320 out of 10000 .
# Iterating from 320 to 321 out of 10000 .
# Iterating from 321 to 322 out of 10000 .
# Iterating from 322 to 323 out of 10000 .
# Iterating from 323 to 324 out of 10000 .
# Iterating from 324 to 325 out of 10000 .
# Iterating from 325 to 326 out of 10000 .
# Iterating from 326 to 327 out of 10000 .
# Iterating from 327 to 328 out of 10000 .
# Iterating from 328 to 329 out of 10000 .
# Iterating from 329 to 330 out of 10000 .
# Iterating from 330 to 331 out of 10000 .
# Iterating from 331 to 332 out of 10000 .
# Iterating from 332 to 333 out of 10000 .
# Iterating from 333 to 334 out of 10000 .
# Iterating from 334 to 335 out of 10000 .
# Iterating from 335 to 336 out of 10000 .
# Iterating from 336 to 337 out of 10000 .
# Iterating from 337 to 338 out of 10000 .
# Iterating from 338 to 339 out of 10000 .
# Iterating from 339 to 340 out of 10000 .
# Iterating from 340 to 341 out of 10000 .
# Iterating from 341 to 342 out of 10000 .
# Iterating from 342 to 343 out of 10000 .
# Iterating from 343 to 344 out of 10000 .
# Iterating from 344 to 345 out of 10000 .
# Iterating from 345 to 346 out of 10000 .
# Iterating from 346 to 347 out of 10000 .
# Iterating from 347 to 348 out of 10000 .
# Iterating from 348 to 349 out of 10000 .
# Iterating from 349 to 350 out of 10000 .
# Iterating from 350 to 351 out of 10000 .
# Iterating from 351 to 352 out of 10000 .
# Iterating from 352 to 353 out of 10000 .
# Iterating from 353 to 354 out of 10000 .
# Iterating from 354 to 355 out of 10000 .
# Iterating from 355 to 356 out of 10000 .
# Iterating from 356 to 357 out of 10000 .
# Iterating from 357 to 358 out of 10000 .
# Iterating from 358 to 359 out of 10000 .
# Iterating from 359 to 360 out of 10000 .
# Iterating from 360 to 361 out of 10000 .
# Iterating from 361 to 362 out of 10000 .
# Iterating from 362 to 363 out of 10000 .
# Iterating from 363 to 364 out of 10000 .
# Iterating from 364 to 365 out of 10000 .
# Iterating from 365 to 366 out of 10000 .
# Iterating from 366 to 367 out of 10000 .
# Iterating from 367 to 368 out of 10000 .
# Iterating from 368 to 369 out of 10000 .
# Iterating from 369 to 370 out of 10000 .
# Iterating from 370 to 371 out of 10000 .
# Iterating from 371 to 372 out of 10000 .
# Iterating from 372 to 373 out of 10000 .
# Iterating from 373 to 374 out of 10000 .
# Iterating from 374 to 375 out of 10000 .
# Iterating from 375 to 376 out of 10000 .
# Iterating from 376 to 377 out of 10000 .
# Iterating from 377 to 378 out of 10000 .
# Iterating from 378 to 379 out of 10000 .
# Iterating from 379 to 380 out of 10000 .
# Iterating from 380 to 381 out of 10000 .
# Iterating from 381 to 382 out of 10000 .
# Iterating from 382 to 383 out of 10000 .
# Iterating from 383 to 384 out of 10000 .
# Iterating from 384 to 385 out of 10000 .
# Iterating from 385 to 386 out of 10000 .
# Iterating from 386 to 387 out of 10000 .
# Iterating from 387 to 388 out of 10000 .
# Iterating from 388 to 389 out of 10000 .
# Iterating from 389 to 390 out of 10000 .
# Iterating from 390 to 391 out of 10000 .
# Iterating from 391 to 392 out of 10000 .
# Iterating from 392 to 393 out of 10000 .
# Iterating from 393 to 394 out of 10000 .
# Iterating from 394 to 395 out of 10000 .
# Iterating from 395 to 396 out of 10000 .
# Iterating from 396 to 397 out of 10000 .
# Iterating from 397 to 398 out of 10000 .
# Iterating from 398 to 399 out of 10000 .
# Iterating from 399 to 400 out of 10000 .
# Iterating from 400 to 401 out of 10000 .
# Iterating from 401 to 402 out of 10000 .
# Iterating from 402 to 403 out of 10000 .
# Iterating from 403 to 404 out of 10000 .
# Iterating from 404 to 405 out of 10000 .
# Iterating from 405 to 406 out of 10000 .
# Iterating from 406 to 407 out of 10000 .
# Iterating from 407 to 408 out of 10000 .
# Iterating from 408 to 409 out of 10000 .
# Iterating from 409 to 410 out of 10000 .
# Iterating from 410 to 411 out of 10000 .
# Iterating from 411 to 412 out of 10000 .
# Iterating from 412 to 413 out of 10000 .
# Iterating from 413 to 414 out of 10000 .
# Iterating from 414 to 415 out of 10000 .
# Iterating from 415 to 416 out of 10000 .
# Iterating from 416 to 417 out of 10000 .
# Iterating from 417 to 418 out of 10000 .
# Iterating from 418 to 419 out of 10000 .
# Iterating from 419 to 420 out of 10000 .
# Iterating from 420 to 421 out of 10000 .
# Iterating from 421 to 422 out of 10000 .
# Iterating from 422 to 423 out of 10000 .
# Iterating from 423 to 424 out of 10000 .
# Iterating from 424 to 425 out of 10000 .
# Iterating from 425 to 426 out of 10000 .
# Iterating from 426 to 427 out of 10000 .
# Iterating from 427 to 428 out of 10000 .
# Iterating from 428 to 429 out of 10000 .
# Iterating from 429 to 430 out of 10000 .
# Iterating from 430 to 431 out of 10000 .
# Iterating from 431 to 432 out of 10000 .
# Iterating from 432 to 433 out of 10000 .
# Iterating from 433 to 434 out of 10000 .
# Iterating from 434 to 435 out of 10000 .
# Iterating from 435 to 436 out of 10000 .
# Iterating from 436 to 437 out of 10000 .
# Iterating from 437 to 438 out of 10000 .
# Iterating from 438 to 439 out of 10000 .
# Iterating from 439 to 440 out of 10000 .
# Iterating from 440 to 441 out of 10000 .
# Iterating from 441 to 442 out of 10000 .
# Iterating from 442 to 443 out of 10000 .
# Iterating from 443 to 444 out of 10000 .
# Iterating from 444 to 445 out of 10000 .
# Iterating from 445 to 446 out of 10000 .
# Iterating from 446 to 447 out of 10000 .
# Iterating from 447 to 448 out of 10000 .
# Iterating from 448 to 449 out of 10000 .
# Iterating from 449 to 450 out of 10000 .
# Iterating from 450 to 451 out of 10000 .
# Iterating from 451 to 452 out of 10000 .
# Iterating from 452 to 453 out of 10000 .
# Iterating from 453 to 454 out of 10000 .
# Iterating from 454 to 455 out of 10000 .
# Iterating from 455 to 456 out of 10000 .
# Iterating from 456 to 457 out of 10000 .
# Iterating from 457 to 458 out of 10000 .
# Iterating from 458 to 459 out of 10000 .
# Iterating from 459 to 460 out of 10000 .
# Iterating from 460 to 461 out of 10000 .
# Iterating from 461 to 462 out of 10000 .
# Iterating from 462 to 463 out of 10000 .
# Iterating from 463 to 464 out of 10000 .
# Iterating from 464 to 465 out of 10000 .
# Iterating from 465 to 466 out of 10000 .
# Iterating from 466 to 467 out of 10000 .
# Iterating from 467 to 468 out of 10000 .
# Iterating from 468 to 469 out of 10000 .
# Iterating from 469 to 470 out of 10000 .
# Iterating from 470 to 471 out of 10000 .
# Iterating from 471 to 472 out of 10000 .
# Iterating from 472 to 473 out of 10000 .
# Iterating from 473 to 474 out of 10000 .
# Iterating from 474 to 475 out of 10000 .
# Iterating from 475 to 476 out of 10000 .
# Iterating from 476 to 477 out of 10000 .
# Iterating from 477 to 478 out of 10000 .
# Iterating from 478 to 479 out of 10000 .
# Iterating from 479 to 480 out of 10000 .
# Iterating from 480 to 481 out of 10000 .
# Iterating from 481 to 482 out of 10000 .
# Iterating from 482 to 483 out of 10000 .
# Iterating from 483 to 484 out of 10000 .
# Iterating from 484 to 485 out of 10000 .
# Iterating from 485 to 486 out of 10000 .
# Iterating from 486 to 487 out of 10000 .
# Iterating from 487 to 488 out of 10000 .
# Iterating from 488 to 489 out of 10000 .
# Iterating from 489 to 490 out of 10000 .
# Iterating from 490 to 491 out of 10000 .
# Iterating from 491 to 492 out of 10000 .
# Iterating from 492 to 493 out of 10000 .
# Iterating from 493 to 494 out of 10000 .
# Iterating from 494 to 495 out of 10000 .
# Iterating from 495 to 496 out of 10000 .
# Iterating from 496 to 497 out of 10000 .
# Iterating from 497 to 498 out of 10000 .
# Iterating from 498 to 499 out of 10000 .
# Iterating from 499 to 500 out of 10000 .
# Iterating from 500 to 501 out of 10000 .
# Iterating from 501 to 502 out of 10000 .
# Iterating from 502 to 503 out of 10000 .
# Iterating from 503 to 504 out of 10000 .
# Iterating from 504 to 505 out of 10000 .
# Iterating from 505 to 506 out of 10000 .
# Iterating from 506 to 507 out of 10000 .
# Iterating from 507 to 508 out of 10000 .
# Iterating from 508 to 509 out of 10000 .
# Iterating from 509 to 510 out of 10000 .
# Iterating from 510 to 511 out of 10000 .
# Iterating from 511 to 512 out of 10000 .
# Iterating from 512 to 513 out of 10000 .
# Iterating from 513 to 514 out of 10000 .
# Iterating from 514 to 515 out of 10000 .
# Iterating from 515 to 516 out of 10000 .
# Iterating from 516 to 517 out of 10000 .
# Iterating from 517 to 518 out of 10000 .
# Iterating from 518 to 519 out of 10000 .
# Iterating from 519 to 520 out of 10000 .
# Iterating from 520 to 521 out of 10000 .
# Iterating from 521 to 522 out of 10000 .
# Iterating from 522 to 523 out of 10000 .
# Iterating from 523 to 524 out of 10000 .
# Iterating from 524 to 525 out of 10000 .
# Iterating from 525 to 526 out of 10000 .
# Iterating from 526 to 527 out of 10000 .
# Iterating from 527 to 528 out of 10000 .
# Iterating from 528 to 529 out of 10000 .
# Iterating from 529 to 530 out of 10000 .
# Iterating from 530 to 531 out of 10000 .
# Iterating from 531 to 532 out of 10000 .
# Iterating from 532 to 533 out of 10000 .
# Iterating from 533 to 534 out of 10000 .
# Iterating from 534 to 535 out of 10000 .
# Iterating from 535 to 536 out of 10000 .
# Iterating from 536 to 537 out of 10000 .
# Iterating from 537 to 538 out of 10000 .
# Iterating from 538 to 539 out of 10000 .
# Iterating from 539 to 540 out of 10000 .
# Iterating from 540 to 541 out of 10000 .
# Iterating from 541 to 542 out of 10000 .
# Iterating from 542 to 543 out of 10000 .
# Iterating from 543 to 544 out of 10000 .
# Iterating from 544 to 545 out of 10000 .
# Iterating from 545 to 546 out of 10000 .
# Iterating from 546 to 547 out of 10000 .
# Iterating from 547 to 548 out of 10000 .
# Iterating from 548 to 549 out of 10000 .
# Iterating from 549 to 550 out of 10000 .
# Iterating from 550 to 551 out of 10000 .
# Iterating from 551 to 552 out of 10000 .
# Iterating from 552 to 553 out of 10000 .
# Iterating from 553 to 554 out of 10000 .
# Iterating from 554 to 555 out of 10000 .
# Iterating from 555 to 556 out of 10000 .
# Iterating from 556 to 557 out of 10000 .
# Iterating from 557 to 558 out of 10000 .
# Iterating from 558 to 559 out of 10000 .
# Iterating from 559 to 560 out of 10000 .
# Iterating from 560 to 561 out of 10000 .
# Iterating from 561 to 562 out of 10000 .
# Iterating from 562 to 563 out of 10000 .
# Iterating from 563 to 564 out of 10000 .
# Iterating from 564 to 565 out of 10000 .
# Iterating from 565 to 566 out of 10000 .
# Iterating from 566 to 567 out of 10000 .
# Iterating from 567 to 568 out of 10000 .
# Iterating from 568 to 569 out of 10000 .
# Iterating from 569 to 570 out of 10000 .
# Iterating from 570 to 571 out of 10000 .
# Iterating from 571 to 572 out of 10000 .
# Iterating from 572 to 573 out of 10000 .
# Iterating from 573 to 574 out of 10000 .
# Iterating from 574 to 575 out of 10000 .
# Iterating from 575 to 576 out of 10000 .
# Iterating from 576 to 577 out of 10000 .
# Iterating from 577 to 578 out of 10000 .
# Iterating from 578 to 579 out of 10000 .
# Iterating from 579 to 580 out of 10000 .
# Iterating from 580 to 581 out of 10000 .
# Iterating from 581 to 582 out of 10000 .
# Iterating from 582 to 583 out of 10000 .
# Iterating from 583 to 584 out of 10000 .
# Iterating from 584 to 585 out of 10000 .
# Iterating from 585 to 586 out of 10000 .
# Iterating from 586 to 587 out of 10000 .
# Iterating from 587 to 588 out of 10000 .
# Iterating from 588 to 589 out of 10000 .
# Iterating from 589 to 590 out of 10000 .
# Iterating from 590 to 591 out of 10000 .
# Iterating from 591 to 592 out of 10000 .
# Iterating from 592 to 593 out of 10000 .
# Iterating from 593 to 594 out of 10000 .
# Iterating from 594 to 595 out of 10000 .
# Iterating from 595 to 596 out of 10000 .
# Iterating from 596 to 597 out of 10000 .
# Iterating from 597 to 598 out of 10000 .
# Iterating from 598 to 599 out of 10000 .
# Iterating from 599 to 600 out of 10000 .
# Iterating from 600 to 601 out of 10000 .
# Iterating from 601 to 602 out of 10000 .
# Iterating from 602 to 603 out of 10000 .
# Iterating from 603 to 604 out of 10000 .
# Iterating from 604 to 605 out of 10000 .
# Iterating from 605 to 606 out of 10000 .
# Iterating from 606 to 607 out of 10000 .
# Iterating from 607 to 608 out of 10000 .
# Iterating from 608 to 609 out of 10000 .
# Iterating from 609 to 610 out of 10000 .
# Iterating from 610 to 611 out of 10000 .
# Iterating from 611 to 612 out of 10000 .
# Iterating from 612 to 613 out of 10000 .
# Iterating from 613 to 614 out of 10000 .
# Iterating from 614 to 615 out of 10000 .
# Iterating from 615 to 616 out of 10000 .
# Iterating from 616 to 617 out of 10000 .
# Iterating from 617 to 618 out of 10000 .
# Iterating from 618 to 619 out of 10000 .
# Iterating from 619 to 620 out of 10000 .
# Iterating from 620 to 621 out of 10000 .
# Iterating from 621 to 622 out of 10000 .
# Iterating from 622 to 623 out of 10000 .
# Iterating from 623 to 624 out of 10000 .
# Iterating from 624 to 625 out of 10000 .
# Iterating from 625 to 626 out of 10000 .
# Iterating from 626 to 627 out of 10000 .
# Iterating from 627 to 628 out of 10000 .
# Iterating from 628 to 629 out of 10000 .
# Iterating from 629 to 630 out of 10000 .
# Iterating from 630 to 631 out of 10000 .
# Iterating from 631 to 632 out of 10000 .
# Iterating from 632 to 633 out of 10000 .
# Iterating from 633 to 634 out of 10000 .
# Iterating from 634 to 635 out of 10000 .
# Iterating from 635 to 636 out of 10000 .
# Iterating from 636 to 637 out of 10000 .
# Iterating from 637 to 638 out of 10000 .
# Iterating from 638 to 639 out of 10000 .
# Iterating from 639 to 640 out of 10000 .
# Iterating from 640 to 641 out of 10000 .
# Iterating from 641 to 642 out of 10000 .
# Iterating from 642 to 643 out of 10000 .
# Iterating from 643 to 644 out of 10000 .
# Iterating from 644 to 645 out of 10000 .
# Iterating from 645 to 646 out of 10000 .
# Iterating from 646 to 647 out of 10000 .
# Iterating from 647 to 648 out of 10000 .
# Iterating from 648 to 649 out of 10000 .
# Iterating from 649 to 650 out of 10000 .
# Iterating from 650 to 651 out of 10000 .
# Iterating from 651 to 652 out of 10000 .
# Iterating from 652 to 653 out of 10000 .
# Iterating from 653 to 654 out of 10000 .
# Iterating from 654 to 655 out of 10000 .
# Iterating from 655 to 656 out of 10000 .
# Iterating from 656 to 657 out of 10000 .
# Iterating from 657 to 658 out of 10000 .
# Iterating from 658 to 659 out of 10000 .
# Iterating from 659 to 660 out of 10000 .
# Iterating from 660 to 661 out of 10000 .
# Iterating from 661 to 662 out of 10000 .
# Iterating from 662 to 663 out of 10000 .
# Iterating from 663 to 664 out of 10000 .
# Iterating from 664 to 665 out of 10000 .
# Iterating from 665 to 666 out of 10000 .
# Iterating from 666 to 667 out of 10000 .
# Iterating from 667 to 668 out of 10000 .
# Iterating from 668 to 669 out of 10000 .
# Iterating from 669 to 670 out of 10000 .
# Iterating from 670 to 671 out of 10000 .
# Iterating from 671 to 672 out of 10000 .
# Iterating from 672 to 673 out of 10000 .
# Iterating from 673 to 674 out of 10000 .
# Iterating from 674 to 675 out of 10000 .
# Iterating from 675 to 676 out of 10000 .
# Iterating from 676 to 677 out of 10000 .
# Iterating from 677 to 678 out of 10000 .
# Iterating from 678 to 679 out of 10000 .
# Iterating from 679 to 680 out of 10000 .
# Iterating from 680 to 681 out of 10000 .
# Iterating from 681 to 682 out of 10000 .
# Iterating from 682 to 683 out of 10000 .
# Iterating from 683 to 684 out of 10000 .
# Iterating from 684 to 685 out of 10000 .
# Iterating from 685 to 686 out of 10000 .
# Iterating from 686 to 687 out of 10000 .
# Iterating from 687 to 688 out of 10000 .
# Iterating from 688 to 689 out of 10000 .
# Iterating from 689 to 690 out of 10000 .
# Iterating from 690 to 691 out of 10000 .
# Iterating from 691 to 692 out of 10000 .
# Iterating from 692 to 693 out of 10000 .
# Iterating from 693 to 694 out of 10000 .
# Iterating from 694 to 695 out of 10000 .
# Iterating from 695 to 696 out of 10000 .
# Iterating from 696 to 697 out of 10000 .
# Iterating from 697 to 698 out of 10000 .
# Iterating from 698 to 699 out of 10000 .
# Iterating from 699 to 700 out of 10000 .
# Iterating from 700 to 701 out of 10000 .
# Iterating from 701 to 702 out of 10000 .
# Iterating from 702 to 703 out of 10000 .
# Iterating from 703 to 704 out of 10000 .
# Iterating from 704 to 705 out of 10000 .
# Iterating from 705 to 706 out of 10000 .
# Iterating from 706 to 707 out of 10000 .
# Iterating from 707 to 708 out of 10000 .
# Iterating from 708 to 709 out of 10000 .
# Iterating from 709 to 710 out of 10000 .
# Iterating from 710 to 711 out of 10000 .
# Iterating from 711 to 712 out of 10000 .
# Iterating from 712 to 713 out of 10000 .
# Iterating from 713 to 714 out of 10000 .
# Iterating from 714 to 715 out of 10000 .
# Iterating from 715 to 716 out of 10000 .
# Iterating from 716 to 717 out of 10000 .
# Iterating from 717 to 718 out of 10000 .
# Iterating from 718 to 719 out of 10000 .
# Iterating from 719 to 720 out of 10000 .
# Iterating from 720 to 721 out of 10000 .
# Iterating from 721 to 722 out of 10000 .
# Iterating from 722 to 723 out of 10000 .
# Iterating from 723 to 724 out of 10000 .
# Iterating from 724 to 725 out of 10000 .
# Iterating from 725 to 726 out of 10000 .
# Iterating from 726 to 727 out of 10000 .
# Iterating from 727 to 728 out of 10000 .
# Iterating from 728 to 729 out of 10000 .
# Iterating from 729 to 730 out of 10000 .
# Iterating from 730 to 731 out of 10000 .
# Iterating from 731 to 732 out of 10000 .
# Iterating from 732 to 733 out of 10000 .
# Iterating from 733 to 734 out of 10000 .
# Iterating from 734 to 735 out of 10000 .
# Iterating from 735 to 736 out of 10000 .
# Iterating from 736 to 737 out of 10000 .
# Iterating from 737 to 738 out of 10000 .
# Iterating from 738 to 739 out of 10000 .
# Iterating from 739 to 740 out of 10000 .
# Iterating from 740 to 741 out of 10000 .
# Iterating from 741 to 742 out of 10000 .
# Iterating from 742 to 743 out of 10000 .
# Iterating from 743 to 744 out of 10000 .
# Iterating from 744 to 745 out of 10000 .
# Iterating from 745 to 746 out of 10000 .
# Iterating from 746 to 747 out of 10000 .
# Iterating from 747 to 748 out of 10000 .
# Iterating from 748 to 749 out of 10000 .
# Iterating from 749 to 750 out of 10000 .
# Iterating from 750 to 751 out of 10000 .
# Iterating from 751 to 752 out of 10000 .
# Iterating from 752 to 753 out of 10000 .
# Iterating from 753 to 754 out of 10000 .
# Iterating from 754 to 755 out of 10000 .
# Iterating from 755 to 756 out of 10000 .
# Iterating from 756 to 757 out of 10000 .
# Iterating from 757 to 758 out of 10000 .
# Iterating from 758 to 759 out of 10000 .
# Iterating from 759 to 760 out of 10000 .
# Iterating from 760 to 761 out of 10000 .
# Iterating from 761 to 762 out of 10000 .
# Iterating from 762 to 763 out of 10000 .
# Iterating from 763 to 764 out of 10000 .
# Iterating from 764 to 765 out of 10000 .
# Iterating from 765 to 766 out of 10000 .
# Iterating from 766 to 767 out of 10000 .
# Iterating from 767 to 768 out of 10000 .
# Iterating from 768 to 769 out of 10000 .
# Iterating from 769 to 770 out of 10000 .
# Iterating from 770 to 771 out of 10000 .
# Iterating from 771 to 772 out of 10000 .
# Iterating from 772 to 773 out of 10000 .
# Iterating from 773 to 774 out of 10000 .
# Iterating from 774 to 775 out of 10000 .
# Iterating from 775 to 776 out of 10000 .
# Iterating from 776 to 777 out of 10000 .
# Iterating from 777 to 778 out of 10000 .
# Iterating from 778 to 779 out of 10000 .
# Iterating from 779 to 780 out of 10000 .
# Iterating from 780 to 781 out of 10000 .
# Iterating from 781 to 782 out of 10000 .
# Iterating from 782 to 783 out of 10000 .
# Iterating from 783 to 784 out of 10000 .
# Iterating from 784 to 785 out of 10000 .
# Iterating from 785 to 786 out of 10000 .
# Iterating from 786 to 787 out of 10000 .
# Iterating from 787 to 788 out of 10000 .
# Iterating from 788 to 789 out of 10000 .
# Iterating from 789 to 790 out of 10000 .
# Iterating from 790 to 791 out of 10000 .
# Iterating from 791 to 792 out of 10000 .
# Iterating from 792 to 793 out of 10000 .
# Iterating from 793 to 794 out of 10000 .
# Iterating from 794 to 795 out of 10000 .
# Iterating from 795 to 796 out of 10000 .
# Iterating from 796 to 797 out of 10000 .
# Iterating from 797 to 798 out of 10000 .
# Iterating from 798 to 799 out of 10000 .
# Iterating from 799 to 800 out of 10000 .
# Iterating from 800 to 801 out of 10000 .
# Iterating from 801 to 802 out of 10000 .
# Iterating from 802 to 803 out of 10000 .
# Iterating from 803 to 804 out of 10000 .
# Iterating from 804 to 805 out of 10000 .
# Iterating from 805 to 806 out of 10000 .
# Iterating from 806 to 807 out of 10000 .
# Iterating from 807 to 808 out of 10000 .
# Iterating from 808 to 809 out of 10000 .
# Iterating from 809 to 810 out of 10000 .
# Iterating from 810 to 811 out of 10000 .
# Iterating from 811 to 812 out of 10000 .
# Iterating from 812 to 813 out of 10000 .
# Iterating from 813 to 814 out of 10000 .
# Iterating from 814 to 815 out of 10000 .
# Iterating from 815 to 816 out of 10000 .
# Iterating from 816 to 817 out of 10000 .
# Iterating from 817 to 818 out of 10000 .
# Iterating from 818 to 819 out of 10000 .
# Iterating from 819 to 820 out of 10000 .
# Iterating from 820 to 821 out of 10000 .
# Iterating from 821 to 822 out of 10000 .
# Iterating from 822 to 823 out of 10000 .
# Iterating from 823 to 824 out of 10000 .
# Iterating from 824 to 825 out of 10000 .
# Iterating from 825 to 826 out of 10000 .
# Iterating from 826 to 827 out of 10000 .
# Iterating from 827 to 828 out of 10000 .
# Iterating from 828 to 829 out of 10000 .
# Iterating from 829 to 830 out of 10000 .
# Iterating from 830 to 831 out of 10000 .
# Iterating from 831 to 832 out of 10000 .
# Iterating from 832 to 833 out of 10000 .
# Iterating from 833 to 834 out of 10000 .
# Iterating from 834 to 835 out of 10000 .
# Iterating from 835 to 836 out of 10000 .
# Iterating from 836 to 837 out of 10000 .
# Iterating from 837 to 838 out of 10000 .
# Iterating from 838 to 839 out of 10000 .
# Iterating from 839 to 840 out of 10000 .
# Iterating from 840 to 841 out of 10000 .
# Iterating from 841 to 842 out of 10000 .
# Iterating from 842 to 843 out of 10000 .
# Iterating from 843 to 844 out of 10000 .
# Iterating from 844 to 845 out of 10000 .
# Iterating from 845 to 846 out of 10000 .
# Iterating from 846 to 847 out of 10000 .
# Iterating from 847 to 848 out of 10000 .
# Iterating from 848 to 849 out of 10000 .
# Iterating from 849 to 850 out of 10000 .
# Iterating from 850 to 851 out of 10000 .
# Iterating from 851 to 852 out of 10000 .
# Iterating from 852 to 853 out of 10000 .
# Iterating from 853 to 854 out of 10000 .
# Iterating from 854 to 855 out of 10000 .
# Iterating from 855 to 856 out of 10000 .
# Iterating from 856 to 857 out of 10000 .
# Iterating from 857 to 858 out of 10000 .
# Iterating from 858 to 859 out of 10000 .
# Iterating from 859 to 860 out of 10000 .
# Iterating from 860 to 861 out of 10000 .
# Iterating from 861 to 862 out of 10000 .
# Iterating from 862 to 863 out of 10000 .
# Iterating from 863 to 864 out of 10000 .
# Iterating from 864 to 865 out of 10000 .
# Iterating from 865 to 866 out of 10000 .
# Iterating from 866 to 867 out of 10000 .
# Iterating from 867 to 868 out of 10000 .
# Iterating from 868 to 869 out of 10000 .
# Iterating from 869 to 870 out of 10000 .
# Iterating from 870 to 871 out of 10000 .
# Iterating from 871 to 872 out of 10000 .
# Iterating from 872 to 873 out of 10000 .
# Iterating from 873 to 874 out of 10000 .
# Iterating from 874 to 875 out of 10000 .
# Iterating from 875 to 876 out of 10000 .
# Iterating from 876 to 877 out of 10000 .
# Iterating from 877 to 878 out of 10000 .
# Iterating from 878 to 879 out of 10000 .
# Iterating from 879 to 880 out of 10000 .
# Iterating from 880 to 881 out of 10000 .
# Iterating from 881 to 882 out of 10000 .
# Iterating from 882 to 883 out of 10000 .
# Iterating from 883 to 884 out of 10000 .
# Iterating from 884 to 885 out of 10000 .
# Iterating from 885 to 886 out of 10000 .
# Iterating from 886 to 887 out of 10000 .
# Iterating from 887 to 888 out of 10000 .
# Iterating from 888 to 889 out of 10000 .
# Iterating from 889 to 890 out of 10000 .
# Iterating from 890 to 891 out of 10000 .
# Iterating from 891 to 892 out of 10000 .
# Iterating from 892 to 893 out of 10000 .
# Iterating from 893 to 894 out of 10000 .
# Iterating from 894 to 895 out of 10000 .
# Iterating from 895 to 896 out of 10000 .
# Iterating from 896 to 897 out of 10000 .
# Iterating from 897 to 898 out of 10000 .
# Iterating from 898 to 899 out of 10000 .
# Iterating from 899 to 900 out of 10000 .
# Iterating from 900 to 901 out of 10000 .
# Iterating from 901 to 902 out of 10000 .
# Iterating from 902 to 903 out of 10000 .
# Iterating from 903 to 904 out of 10000 .
# Iterating from 904 to 905 out of 10000 .
# Iterating from 905 to 906 out of 10000 .
# Iterating from 906 to 907 out of 10000 .
# Iterating from 907 to 908 out of 10000 .
# Iterating from 908 to 909 out of 10000 .
# Iterating from 909 to 910 out of 10000 .
# Iterating from 910 to 911 out of 10000 .
# Iterating from 911 to 912 out of 10000 .
# Iterating from 912 to 913 out of 10000 .
# Iterating from 913 to 914 out of 10000 .
# Iterating from 914 to 915 out of 10000 .
# Iterating from 915 to 916 out of 10000 .
# Iterating from 916 to 917 out of 10000 .
# Iterating from 917 to 918 out of 10000 .
# Iterating from 918 to 919 out of 10000 .
# Iterating from 919 to 920 out of 10000 .
# Iterating from 920 to 921 out of 10000 .
# Iterating from 921 to 922 out of 10000 .
# Iterating from 922 to 923 out of 10000 .
# Iterating from 923 to 924 out of 10000 .
# Iterating from 924 to 925 out of 10000 .
# Iterating from 925 to 926 out of 10000 .
# Iterating from 926 to 927 out of 10000 .
# Iterating from 927 to 928 out of 10000 .
# Iterating from 928 to 929 out of 10000 .
# Iterating from 929 to 930 out of 10000 .
# Iterating from 930 to 931 out of 10000 .
# Iterating from 931 to 932 out of 10000 .
# Iterating from 932 to 933 out of 10000 .
# Iterating from 933 to 934 out of 10000 .
# Iterating from 934 to 935 out of 10000 .
# Iterating from 935 to 936 out of 10000 .
# Iterating from 936 to 937 out of 10000 .
# Iterating from 937 to 938 out of 10000 .
# Iterating from 938 to 939 out of 10000 .
# Iterating from 939 to 940 out of 10000 .
# Iterating from 940 to 941 out of 10000 .
# Iterating from 941 to 942 out of 10000 .
# Iterating from 942 to 943 out of 10000 .
# Iterating from 943 to 944 out of 10000 .
# Iterating from 944 to 945 out of 10000 .
# Iterating from 945 to 946 out of 10000 .
# Iterating from 946 to 947 out of 10000 .
# Iterating from 947 to 948 out of 10000 .
# Iterating from 948 to 949 out of 10000 .
# Iterating from 949 to 950 out of 10000 .
# Iterating from 950 to 951 out of 10000 .
# Iterating from 951 to 952 out of 10000 .
# Iterating from 952 to 953 out of 10000 .
# Iterating from 953 to 954 out of 10000 .
# Iterating from 954 to 955 out of 10000 .
# Iterating from 955 to 956 out of 10000 .
# Iterating from 956 to 957 out of 10000 .
# Iterating from 957 to 958 out of 10000 .
# Iterating from 958 to 959 out of 10000 .
# Iterating from 959 to 960 out of 10000 .
# Iterating from 960 to 961 out of 10000 .
# Iterating from 961 to 962 out of 10000 .
# Iterating from 962 to 963 out of 10000 .
# Iterating from 963 to 964 out of 10000 .
# Iterating from 964 to 965 out of 10000 .
# Iterating from 965 to 966 out of 10000 .
# Iterating from 966 to 967 out of 10000 .
# Iterating from 967 to 968 out of 10000 .
# Iterating from 968 to 969 out of 10000 .
# Iterating from 969 to 970 out of 10000 .
# Iterating from 970 to 971 out of 10000 .
# Iterating from 971 to 972 out of 10000 .
# Iterating from 972 to 973 out of 10000 .
# Iterating from 973 to 974 out of 10000 .
# Iterating from 974 to 975 out of 10000 .
# Iterating from 975 to 976 out of 10000 .
# Iterating from 976 to 977 out of 10000 .
# Iterating from 977 to 978 out of 10000 .
# Iterating from 978 to 979 out of 10000 .
# Iterating from 979 to 980 out of 10000 .
# Iterating from 980 to 981 out of 10000 .
# Iterating from 981 to 982 out of 10000 .
# Iterating from 982 to 983 out of 10000 .
# Iterating from 983 to 984 out of 10000 .
# Iterating from 984 to 985 out of 10000 .
# Iterating from 985 to 986 out of 10000 .
# Iterating from 986 to 987 out of 10000 .
# Iterating from 987 to 988 out of 10000 .
# Iterating from 988 to 989 out of 10000 .
# Iterating from 989 to 990 out of 10000 .
# Iterating from 990 to 991 out of 10000 .
# Iterating from 991 to 992 out of 10000 .
# Iterating from 992 to 993 out of 10000 .
# Iterating from 993 to 994 out of 10000 .
# Iterating from 994 to 995 out of 10000 .
# Iterating from 995 to 996 out of 10000 .
# Iterating from 996 to 997 out of 10000 .
# Iterating from 997 to 998 out of 10000 .
# Iterating from 998 to 999 out of 10000 .
# Iterating from 999 to 1000 out of 10000 .
# Iterating from 1000 to 1001 out of 10000 .
# Iterating from 1001 to 1002 out of 10000 .
# Iterating from 1002 to 1003 out of 10000 .
# Iterating from 1003 to 1004 out of 10000 .
# Iterating from 1004 to 1005 out of 10000 .
# Iterating from 1005 to 1006 out of 10000 .
# Iterating from 1006 to 1007 out of 10000 .
# Iterating from 1007 to 1008 out of 10000 .
# Iterating from 1008 to 1009 out of 10000 .
# Iterating from 1009 to 1010 out of 10000 .
# Iterating from 1010 to 1011 out of 10000 .
# Iterating from 1011 to 1012 out of 10000 .
# Iterating from 1012 to 1013 out of 10000 .
# Iterating from 1013 to 1014 out of 10000 .
# Iterating from 1014 to 1015 out of 10000 .
# Iterating from 1015 to 1016 out of 10000 .
# Iterating from 1016 to 1017 out of 10000 .
# Iterating from 1017 to 1018 out of 10000 .
# Iterating from 1018 to 1019 out of 10000 .
# Iterating from 1019 to 1020 out of 10000 .
# Iterating from 1020 to 1021 out of 10000 .
# Iterating from 1021 to 1022 out of 10000 .
# Iterating from 1022 to 1023 out of 10000 .
# Iterating from 1023 to 1024 out of 10000 .
# Iterating from 1024 to 1025 out of 10000 .
# Iterating from 1025 to 1026 out of 10000 .
# Iterating from 1026 to 1027 out of 10000 .
# Iterating from 1027 to 1028 out of 10000 .
# Iterating from 1028 to 1029 out of 10000 .
# Iterating from 1029 to 1030 out of 10000 .
# Iterating from 1030 to 1031 out of 10000 .
# Iterating from 1031 to 1032 out of 10000 .
# Iterating from 1032 to 1033 out of 10000 .
# Iterating from 1033 to 1034 out of 10000 .
# Iterating from 1034 to 1035 out of 10000 .
# Iterating from 1035 to 1036 out of 10000 .
# Iterating from 1036 to 1037 out of 10000 .
# Iterating from 1037 to 1038 out of 10000 .
# Iterating from 1038 to 1039 out of 10000 .
# Iterating from 1039 to 1040 out of 10000 .
# Iterating from 1040 to 1041 out of 10000 .
# Iterating from 1041 to 1042 out of 10000 .
# Iterating from 1042 to 1043 out of 10000 .
# Iterating from 1043 to 1044 out of 10000 .
# Iterating from 1044 to 1045 out of 10000 .
# Iterating from 1045 to 1046 out of 10000 .
# Iterating from 1046 to 1047 out of 10000 .
# Iterating from 1047 to 1048 out of 10000 .
# Iterating from 1048 to 1049 out of 10000 .
# Iterating from 1049 to 1050 out of 10000 .
# Iterating from 1050 to 1051 out of 10000 .
# Iterating from 1051 to 1052 out of 10000 .
# Iterating from 1052 to 1053 out of 10000 .
# Iterating from 1053 to 1054 out of 10000 .
# Iterating from 1054 to 1055 out of 10000 .
# Iterating from 1055 to 1056 out of 10000 .
# Iterating from 1056 to 1057 out of 10000 .
# Iterating from 1057 to 1058 out of 10000 .
# Iterating from 1058 to 1059 out of 10000 .
# Iterating from 1059 to 1060 out of 10000 .
# Iterating from 1060 to 1061 out of 10000 .
# Iterating from 1061 to 1062 out of 10000 .
# Iterating from 1062 to 1063 out of 10000 .
# Iterating from 1063 to 1064 out of 10000 .
# Iterating from 1064 to 1065 out of 10000 .
# Iterating from 1065 to 1066 out of 10000 .
# Iterating from 1066 to 1067 out of 10000 .
# Iterating from 1067 to 1068 out of 10000 .
# Iterating from 1068 to 1069 out of 10000 .
# Iterating from 1069 to 1070 out of 10000 .
# Iterating from 1070 to 1071 out of 10000 .
# Iterating from 1071 to 1072 out of 10000 .
# Iterating from 1072 to 1073 out of 10000 .
# Iterating from 1073 to 1074 out of 10000 .
# Iterating from 1074 to 1075 out of 10000 .
# Iterating from 1075 to 1076 out of 10000 .
# Iterating from 1076 to 1077 out of 10000 .
# Iterating from 1077 to 1078 out of 10000 .
# Iterating from 1078 to 1079 out of 10000 .
# Iterating from 1079 to 1080 out of 10000 .
# Iterating from 1080 to 1081 out of 10000 .
# Iterating from 1081 to 1082 out of 10000 .
# Iterating from 1082 to 1083 out of 10000 .
# Iterating from 1083 to 1084 out of 10000 .
# Iterating from 1084 to 1085 out of 10000 .
# Iterating from 1085 to 1086 out of 10000 .
# Iterating from 1086 to 1087 out of 10000 .
# Iterating from 1087 to 1088 out of 10000 .
# Iterating from 1088 to 1089 out of 10000 .
# Iterating from 1089 to 1090 out of 10000 .
# Iterating from 1090 to 1091 out of 10000 .
# Iterating from 1091 to 1092 out of 10000 .
# Iterating from 1092 to 1093 out of 10000 .
# Iterating from 1093 to 1094 out of 10000 .
# Iterating from 1094 to 1095 out of 10000 .
# Iterating from 1095 to 1096 out of 10000 .
# Iterating from 1096 to 1097 out of 10000 .
# Iterating from 1097 to 1098 out of 10000 .
# Iterating from 1098 to 1099 out of 10000 .
# Iterating from 1099 to 1100 out of 10000 .
# Iterating from 1100 to 1101 out of 10000 .
# Iterating from 1101 to 1102 out of 10000 .
# Iterating from 1102 to 1103 out of 10000 .
# Iterating from 1103 to 1104 out of 10000 .
# Iterating from 1104 to 1105 out of 10000 .
# Iterating from 1105 to 1106 out of 10000 .
# Iterating from 1106 to 1107 out of 10000 .
# Iterating from 1107 to 1108 out of 10000 .
# ...
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# SKS metric calculation completed in 752.7953578820452 seconds.
# Saving sks to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 50
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# SWD metric calculation completed in 349.93459392897785 seconds.
# Saving swd to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fn: [[0.68, [6800, 3199], 0.6864965309141355], [0.95, [9500, 500], 1.0649348701336006], [0.99, [9900, 100], 1.3101005770964511]]
# Computing time for metric fn: 22.262674685800448
# ThresholdS for metric fpd: [[0.68, [6800, 3199], 0.336860673008416], [0.95, [9500, 500], 0.3477311650345061], [0.99, [9900, 100], 0.3572972443114822]]
# Computing time for metric fpd: 263.01628754800186
# ThresholdS for metric kpd: [[0.68, [6800, 3199], -0.07998042113732673], [0.95, [9500, 500], -0.03772345929001775], [0.99, [9900, 100], -0.013588570245803844]]
# Computing time for metric kpd: 30477.472858420108
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9225997387330281], [0.95, [9500, 500], 1.1484487598657587], [0.99, [9900, 100], 1.3018394222155032]]
# Computing time for metric ks: 87.83812924008816
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9066588006737435], [0.95, [9500, 500], 1.0886312421137199], [0.99, [9900, 100], 1.2107876027270617]]
# Computing time for metric sks: 752.7953578820452
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.5723781863565185], [0.95, [9500, 500], 0.7456241616928099], [0.99, [9900, 100], 0.8680672200370332]]
# Computing time for metric swd: 349.93459392897785
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7fe70890ab60>
# 1          metric_list  <function <lambda> at 0x7fe7089098a0>
# 2          metric_list  <function <lambda> at 0x7fe70890aca0>
# 3      statistic_means  <function <lambda> at 0x7fe70890afc0>
# 4         metric_means  <function <lambda> at 0x7fe70890b060>
# 5         metric_means  <function <lambda> at 0x7fe70890b100>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7fe70890b1a0>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1              lambda ns, ndims: 10000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            500
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...           1000
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
# 6  {'niter': 10000, 'batch_size_test': 100000, 'b...            200
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 1  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 2  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 3  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 4  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 5  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 6  results_leonardo/5D_unimodal/5D_100K/null_hypo...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.6864965309141355], [0....
# 1  [[0.68, [6800, 3199], 0.336860673008416], [0.9...
# 2  [[0.68, [6800, 3199], -0.07998042113732673], [...
# 3  [[0.68, [6800, 3199], 0.9225997387330281], [0....
# 4  [[0.68, [6800, 3199], 0.9066588006737435], [0....
# 5  [[0.68, [6800, 3199], 0.5723781863565185], [0....
# 6                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.6031738045338384 +/- 0.0006094264710318534
# sigma = 0.24686564585455253 +/- 0.002043813857228116
# /tmp/ipykernel_736307/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_736307/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_736307/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_736307/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.4007802500855178 seconds.
# mu = 0.33551827327741035 +/- 3.955387247050431e-07
# sigma = 0.00628918694828706 +/- 7.737377144647847e-05
# /tmp/ipykernel_736307/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_736307/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_736307/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_736307/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.002617395017296 seconds.
# mu = -0.09602558759166185 +/- 1.2185595543294852e-05
# sigma = 0.034907872383310404 +/- 0.000249868811846431
# /tmp/ipykernel_736307/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_736307/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_736307/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_736307/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9877715609036386 seconds.
# mu = 0.8671576558296965 +/- 0.000229855907338346
# sigma = 0.15160999549447457 +/- 0.0012416355438809427
# /tmp/ipykernel_736307/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_736307/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_736307/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_736307/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3028484880924225 seconds.
# mu = 0.865879352134588 +/- 0.00014409841001630991
# sigma = 0.12004099717026259 +/- 0.0010252371802540133
# /tmp/ipykernel_736307/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_736307/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_736307/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_736307/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.345299341948703 seconds.
# mu = 0.5416624783925067 +/- 0.00011419865682139421
# sigma = 0.10686377160731049 +/- 0.0010551935622729644
# /tmp/ipykernel_736307/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_736307/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_736307/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_736307/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.4390459679998457 seconds.
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7fe70890ab60>
# 1          metric_list  <function <lambda> at 0x7fe7089098a0>
# 2          metric_list  <function <lambda> at 0x7fe70890aca0>
# 3      statistic_means  <function <lambda> at 0x7fe70890afc0>
# 4         metric_means  <function <lambda> at 0x7fe70890b060>
# 5         metric_means  <function <lambda> at 0x7fe70890b100>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7fe70890b1a0>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1              lambda ns, ndims: 10000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            500
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...           1000
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
# 6  {'niter': 10000, 'batch_size_test': 100000, 'b...            200
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 1  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 2  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 3  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 4  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 5  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 6  results_leonardo/5D_unimodal/5D_100K/null_hypo...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.6864965309141355], [0....
# 1  [[0.68, [6800, 3199], 0.336860673008416], [0.9...
# 2  [[0.68, [6800, 3199], -0.07998042113732673], [...
# 3  [[0.68, [6800, 3199], 0.9225997387330281], [0....
# 4  [[0.68, [6800, 3199], 0.9066588006737435], [0....
# 5  [[0.68, [6800, 3199], 0.5723781863565185], [0....
# 6                                                 []
#
#                                          null_figure
# 0  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 1  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 2  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 3  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 4  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 5  results_leonardo/5D_unimodal/5D_100K/null_hypo...
# 6                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.01,
                                                 fn_tol = 0.01,
                                                 eps_min = 0.,
                                                 eps_max = 5,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fn with mean deformation.
#
# ======================================================
# =============== fn - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 80.53851451585216 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9477995169004958
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 49.967151435058504 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.916528212171075
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 29.182461328360052 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8591700438417722
#
# ------------ 4 ------------
# eps = 0.3125
# WARNING:tensorflow:5 out of the last 407 calls to <function generate_and_clean_data_simple_1 at 0x7fe7e7e1cf40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 15.739915669195643 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7465172647287093
#
# ------------ 5 ------------
# eps = 0.15625
# WARNING:tensorflow:6 out of the last 409 calls to <function generate_and_clean_data_simple_1 at 0x7fe7e7e1cf40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7fdf4e0527a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 8.219515812794835 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5411963910404634
#
# ------------ 6 ------------
# eps = 0.078125
# WARNING:tensorflow:6 out of the last 6 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7fe4f01bdda0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 4.276642569307545 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2025315501220044
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 2.2800668707492644 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7265359451172945
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 1.3130731571028675 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.20869423830972814
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 0.894605868901077 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.17384583830232817
#
# ------------ 10 ------------
# eps = 0.0146484375
# statistic = 1.0916897577229212 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.024811816802734418
#
# ------------ 11 ------------
# eps = 0.01220703125
# statistic = 0.9890951933841442 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.0738447582598405
#
# ------------ 12 ------------
# eps = 0.013427734375
# statistic = 1.0395253740455184 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.024148231032982612
#
# ------------ 13 ------------
# eps = 0.0140380859375
# statistic = 1.0654074820322048 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.0004436957262984317
#
# ------------ 14 ------------
# eps = 0.01373291015625
# statistic = 1.0524143979775695 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.02197802197802198
# relative_error_metric = 0.011826553459647402
#
# ------------ 15 ------------
# eps = 0.013885498046875
# statistic = 1.0588981885786768 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.01092896174863388
# relative_error_metric = 0.005684704388756359
#
# ------------ 16 ------------
# eps = 0.0139617919921875
# statistic = 1.0621496790299287 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.005449591280653951
# relative_error_metric = 0.0026187873958908527
# =======> statistic within required accuracy at 0.95 CL in 51.79029179504141 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.01399993896484375
# statistic = 1.0637777953824736 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9888313209930082
# relative_error_metric = 0.2075277188331723
#
# ------------ 2 ------------
# eps = 2.506999969482422
# statistic = 80.69472584479033 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9777866886580466
# relative_error_metric = 1.9360964160642726
#
# ------------ 3 ------------
# eps = 1.2604999542236328
# statistic = 50.26048102457836 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9560613883463907
# relative_error_metric = 1.8983838819414127
#
# ------------ 4 ------------
# eps = 0.6372499465942383
# statistic = 29.66521720569999 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.914011876084553
# relative_error_metric = 1.830820063085961
#
# ------------ 5 ------------
# eps = 0.325624942779541
# statistic = 16.347904691263516 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.8351129176055991
# relative_error_metric = 1.7032279564569117
#
# ------------ 6 ------------
# eps = 0.16981244087219238
# statistic = 8.892405094620923 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.6953428495456992
# relative_error_metric = 1.4863612452661648
#
# ------------ 7 ------------
# eps = 0.09190618991851807
# statistic = 4.9795178744603525 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.4712321520027465
# relative_error_metric = 1.1668171370413254
#
# ------------ 8 ------------
# eps = 0.05295306444168091
# statistic = 2.9886771744835743 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.1635960597711177
# relative_error_metric = 0.7809552828220341
#
# ------------ 9 ------------
# eps = 0.03347650170326233
# statistic = 1.997563549876116 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.8204727424523476
# relative_error_metric = 0.4156788273474942
#
# ------------ 10 ------------
# eps = 0.02373822033405304
# statistic = 1.514299009064247 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.516097316357132
# relative_error_metric = 0.1445959934057133
#
# ------------ 11 ------------
# eps = 0.018869079649448395
# statistic = 1.2821193273625717 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.22855898808373648
# relative_error_metric = 0.021588638900385936
#
# ------------ 12 ------------
# eps = 0.021303649991750717
# statistic = 1.3969867313965303 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.12120512417486068
# relative_error_metric = 0.06419161585774502
#
# ------------ 13 ------------
# eps = 0.020086364820599556
# statistic = 1.3391975060821457 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.062496279414144894
# relative_error_metric = 0.02196576457020227
#
# ------------ 14 ------------
# eps = 0.019477722235023975
# statistic = 1.3105622862458555 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.031744111929294216
# relative_error_metric = 0.0003523605846923065
#
# ------------ 15 ------------
# eps = 0.019173400942236185
# statistic = 1.2963157962371932 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.0157470866443971
# relative_error_metric = 0.010577573867545195
#
# ------------ 16 ------------
# eps = 0.01932556158863008
# statistic = 1.3034329142227776 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.007842668526994083
# relative_error_metric = 0.005102412420441462
# =======> statistic within required accuracy at 0.99 CL in 48.559375525219366 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 100.34970023809001 seconds.
# Saving results in the file results_leonardo/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fn with std deformation.
#
# ======================================================
# =============== fn - only diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 88.93732077288695 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9526707475262624
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 62.763483973960895 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9332626507490478
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 39.28242221015916 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8944233330560574
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 22.971089775956536 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8227768716642865
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 12.667579852433562 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.689806305211222
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 6.684460811397411 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.450313333375587
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 3.443017114407658 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0550610354453707
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 1.789726385398692 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.507795111493846
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 1.0250128404533767 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.03820385503234571
#
# ------------ 10 ------------
# eps = 0.0146484375
# statistic = 1.392255634935581 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.26641871204265033
#
# ------------ 11 ------------
# eps = 0.01220703125
# statistic = 1.2028816851550552 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.1216560613774127
#
# ------------ 12 ------------
# eps = 0.010986328125
# statistic = 1.1121368458499712 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.04336281195499839
#
# ------------ 13 ------------
# eps = 0.0103759765625
# statistic = 1.0680640935621155 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.0029341068437212436
#
# ------------ 14 ------------
# eps = 0.01007080078125
# statistic = 1.0464026164591989 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.029850746268656716
# relative_error_metric = 0.01755498947191847
#
# ------------ 15 ------------
# eps = 0.010223388671875
# statistic = 1.057200456621056 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.014814814814814815
# relative_error_metric = 0.007289274548171873
#
# ------------ 16 ------------
# eps = 0.0102996826171875
# statistic = 1.0626241795615639 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.007380073800738007
# relative_error_metric = 0.002172151764594054
# =======> statistic within required accuracy at 0.95 CL in 49.75993424304761 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.01033782958984375
# statistic = 1.0653421285716442 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.99174680036241
# relative_error_metric = 0.20607396502621045
#
# ------------ 2 ------------
# eps = 2.505168914794922
# statistic = 89.00567607224727 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9835614360996323
# relative_error_metric = 1.9419768892789133
#
# ------------ 3 ------------
# eps = 1.2577533721923828
# statistic = 63.00115900671663 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9673908956222879
# relative_error_metric = 1.9185150105549356
#
# ------------ 4 ------------
# eps = 0.6340456008911133
# statistic = 39.69518105319276 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.935828085572419
# relative_error_metric = 1.8722017725512976
#
# ------------ 5 ------------
# eps = 0.3221917152404785
# statistic = 23.551391368474754 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.8756461824152344
# relative_error_metric = 1.7892160969318123
#
# ------------ 6 ------------
# eps = 0.16626477241516113
# statistic = 13.389312497872254 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.765851024334267
# relative_error_metric = 1.6434958129512283
#
# ------------ 7 ------------
# eps = 0.08830130100250244
# statistic = 7.501407677535724 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.5807818042286799
# relative_error_metric = 1.4052774897383833
#
# ------------ 8 ------------
# eps = 0.049319565296173096
# statistic = 4.309075550014046 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.3068534347102814
# relative_error_metric = 1.067407358330921
#
# ------------ 9 ------------
# eps = 0.029828697443008423
# statistic = 2.6582958276459916 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.9705030179593623
# relative_error_metric = 0.6794660175270677
#
# ------------ 10 ------------
# eps = 0.020083263516426086
# statistic = 1.8356053898584077 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.6407024160860141
# relative_error_metric = 0.3341093021930855
#
# ------------ 11 ------------
# eps = 0.015210546553134918
# statistic = 1.4369831871556022 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.38145022885380625
# relative_error_metric = 0.09237622216714413
#
# ------------ 12 ------------
# eps = 0.012774188071489334
# statistic = 1.2460466264971184 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.17412053495063629
# relative_error_metric = 0.05011757578693607
#
# ------------ 13 ------------
# eps = 0.013992367312312126
# statistic = 1.3405231500788177 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.09102248857617351
# relative_error_metric = 0.02295502954301817
#
# ------------ 14 ------------
# eps = 0.01338327769190073
# statistic = 1.2930067479292089 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.04449864982671004
# relative_error_metric = 0.013133403300667769
#
# ------------ 15 ------------
# eps = 0.013687822502106428
# statistic = 1.3166994914521568 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.022499625654159142
# relative_error_metric = 0.005024298906274822
#
# ------------ 16 ------------
# eps = 0.01353555009700358
# statistic = 1.3048362659810462 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.011186887631095871
# relative_error_metric = 0.004026339014145677
#
# ------------ 17 ------------
# eps = 0.013611686299555004
# statistic = 1.310763727679182 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.005609130995085466
# relative_error_metric = 0.0005060548777916071
# =======> statistic within required accuracy at 0.99 CL in 50.105926803080365 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 99.86589545896277 seconds.
# Saving results in the file results_leonardo/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fn with off deformation.
#
# ======================================================
# =============== fn - only off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 110.79011752086639 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9619173261334315
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 110.79011752086639 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9619173261334315
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 83.92690908973321 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9498806087494014
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 50.34993649415869 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9171496618098556
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 27.94930234782629 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.853184509089985
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 14.779956353313807 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7311600679068846
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 7.595347794436005 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5081292787403378
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 3.851742560014894 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1336142057206813
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 1.9757120550168956 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5990680321018964
#
# ------------ 10 ------------
# eps = 0.0048828125
# statistic = 1.103195689469056 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.03529383335887976
#
# ------------ 11 ------------
# eps = 0.00244140625
# statistic = 0.7651224263570741 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.32765361429005313
#
# ------------ 12 ------------
# eps = 0.003662109375
# statistic = 0.9175667356405224 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.14866886772132948
#
# ------------ 13 ------------
# eps = 0.0042724609375
# statistic = 1.0072943442099915 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.05563141907722547
#
# ------------ 14 ------------
# eps = 0.00457763671875
# statistic = 1.0545747378655832 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.00977597103492002
#
# ------------ 15 ------------
# eps = 0.004730224609375
# statistic = 1.0787287189448684 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.01286941559444751
#
# ------------ 16 ------------
# eps = 0.0046539306640625
# statistic = 1.0666112849290799 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.01652892561983471
# relative_error_metric = 0.0015729565991312179
#
# ------------ 17 ------------
# eps = 0.00461578369140625
# statistic = 1.0605827301057413 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.00823045267489712
# relative_error_metric = 0.004095134312102755
# =======> statistic within required accuracy at 0.95 CL in 51.311599402921274 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.004634857177734375
# statistic = 1.0635944587466908 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9962955481788351
# relative_error_metric = 0.20769822123523193
#
# ------------ 2 ------------
# eps = 2.502317428588867
# statistic = 110.79011752086639 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9926047939499303
# relative_error_metric = 1.9532525235249205
#
# ------------ 3 ------------
# eps = 1.2534761428833008
# statistic = 110.79011752086639 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9852640754988724
# relative_error_metric = 1.9532525235249205
#
# ------------ 4 ------------
# eps = 0.6290555000305176
# statistic = 84.28611580120115 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9707437102363152
# relative_error_metric = 1.9387776407636346
#
# ------------ 5 ------------
# eps = 0.316845178604126
# statistic = 50.90964266698198 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.942331010801811
# relative_error_metric = 1.8996471069593004
#
# ------------ 6 ------------
# eps = 0.16074001789093018
# statistic = 28.661742398643856 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.8878945262801268
# relative_error_metric = 1.8251558199932023
#
# ------------ 7 ------------
# eps = 0.08268743753433228
# statistic = 15.591731416016081 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.7876896298697975
# relative_error_metric = 1.6899506331312923
#
# ------------ 8 ------------
# eps = 0.043661147356033325
# statistic = 8.463158988773735 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.616129141739353
# relative_error_metric = 1.4638019922558752
#
# ------------ 9 ------------
# eps = 0.02414800226688385
# statistic = 4.743493087244638 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.355886487004196
# relative_error_metric = 1.1343320019553704
#
# ------------ 10 ------------
# eps = 0.014391429722309113
# statistic = 2.858867376396188 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.0255887126933252
# relative_error_metric = 0.7429976994676707
#
# ------------ 11 ------------
# eps = 0.009513143450021744
# statistic = 1.928290656173831 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.6896078676610955
# relative_error_metric = 0.3817883847549217
#
# ------------ 12 ------------
# eps = 0.007074000313878059
# statistic = 1.4793598973934148 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.4166321330481559
# relative_error_metric = 0.12135631377097583
#
# ------------ 13 ------------
# eps = 0.005854428745806217
# statistic = 1.2651323442336024 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.18866508257757733
# relative_error_metric = 0.03492362379370603
#
# ------------ 14 ------------
# eps = 0.006464214529842138
# statistic = 1.3710301086358923 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.09900210118777497
# relative_error_metric = 0.04545062414426726
#
# ------------ 15 ------------
# eps = 0.006159321637824178
# statistic = 1.3177389726548947 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.050757320950067214
# relative_error_metric = 0.005813441356544282
#
# ------------ 16 ------------
# eps = 0.0060068751918151975
# statistic = 1.2913447093987418 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.025060657515845734
# relative_error_metric = 0.014419574991698735
#
# ------------ 17 ------------
# eps = 0.006083098414819688
# statistic = 1.3045198066865489 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.012452312970265878
# relative_error_metric = 0.00426889535820693
#
# ------------ 18 ------------
# eps = 0.006121210026321933
# statistic = 1.3111239662600946 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.006245599525126393
# relative_error_metric = 0.0007808481468993515
# =======> statistic within required accuracy at 0.99 CL in 52.523603721987456 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 103.83523749792948 seconds.
# Saving results in the file results_leonardo/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fn with cov deformation.
#
# ======================================================
# =============== fn - only cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 37.273987894407696 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8888925620916475
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 8.502624773599255 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5547726234113726
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 6.909961485808585 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4658564462269879
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 5.115118227346927 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3107276890111177
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 3.0154255248605 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9560384210766361
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.7112410436427021 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.46560894812314785
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.0539871284881643 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.010333312554739705
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.3760500558678346 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.25490955099331175
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 1.212053756004066 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.12922232828190747
#
# ------------ 10 ------------
# eps = 0.0439453125
# statistic = 1.1320276668090816 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.06107777947715773
#
# ------------ 11 ------------
# eps = 0.04150390625
# statistic = 1.0927193645312827 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.025754352992519693
#
# ------------ 12 ------------
# eps = 0.040283203125
# statistic = 1.0732755901680766 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.03076923076923077
# relative_error_metric = 0.007801589403223924
#
# ------------ 13 ------------
# eps = 0.0396728515625
# statistic = 1.063611191942719 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.015267175572519083
# relative_error_metric = 0.0012437392964758664
#
# ------------ 14 ------------
# eps = 0.03997802734375
# statistic = 1.0684384456001013 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.007662835249042145
# relative_error_metric = 0.0032845404418080206
# =======> statistic within required accuracy at 0.95 CL in 40.44325800705701 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.039825439453125
# statistic = 1.0660235705010883 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9683914136062248
# relative_error_metric = 0.20544129130806998
#
# ------------ 2 ------------
# eps = 2.5199127197265625
# statistic = 37.73908089944156 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9377663855026677
# relative_error_metric = 1.86579994483279
#
# ------------ 3 ------------
# eps = 1.2798690795898438
# statistic = 8.920713778863659 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.8792889145830323
# relative_error_metric = 1.487782484750793
#
# ------------ 4 ------------
# eps = 0.6598472595214844
# statistic = 6.93237146465718 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.772319603085898
# relative_error_metric = 1.3642195834162782
#
# ------------ 5 ------------
# eps = 0.3498363494873047
# statistic = 5.498193227131157 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.5911794219143884
# relative_error_metric = 1.2302913976579892
#
# ------------ 6 ------------
# eps = 0.19483089447021484
# statistic = 3.6048093828961685 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.3211273902176344
# relative_error_metric = 0.9337745043057365
#
# ------------ 7 ------------
# eps = 0.11732816696166992
# statistic = 2.3804009407969313 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.9863308806796632
# relative_error_metric = 0.5800297647954529
#
# ------------ 8 ------------
# eps = 0.07857680320739746
# statistic = 1.7190313862091378 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.6545714487077515
# relative_error_metric = 0.26999867557201723
#
# ------------ 9 ------------
# eps = 0.05920112133026123
# statistic = 1.3863714310974176 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.3913229283912868
# relative_error_metric = 0.05657084795925891
#
# ------------ 10 ------------
# eps = 0.049513280391693115
# statistic = 1.223409500740863 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.17822553010677522
# relative_error_metric = 0.06843554885685747
#
# ------------ 11 ------------
# eps = 0.05435720086097717
# statistic = 1.3043994218741444 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.08531158924885543
# relative_error_metric = 0.004361182042112413
#
# ------------ 12 ------------
# eps = 0.0567791610956192
# statistic = 1.3452828472823408 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.04358537911449559
# relative_error_metric = 0.02649882488749838
#
# ------------ 13 ------------
# eps = 0.05556818097829819
# statistic = 1.324813165528027 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.02203276617390547
# relative_error_metric = 0.01116741561104892
#
# ------------ 14 ------------
# eps = 0.05496269091963768
# statistic = 1.3145989947705303 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.011077399525341933
# relative_error_metric = 0.0034277581497675434
#
# ------------ 15 ------------
# eps = 0.054659945890307426
# statistic = 1.3094973441877076 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.0055234035257723
# relative_error_metric = 0.0004605538154098258
# =======> statistic within required accuracy at 0.99 CL in 44.847401737002656 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 85.29069412383251 seconds.
# Saving results in the file results_leonardo/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fn with mean_std deformation.
#
# ======================================================
# =============== fn - mean + diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 94.15891590077611 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9552660447351315
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 68.32730846444656 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9386136075757672
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 42.29213814827882 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.901752143676179
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 24.314438967308952 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8321574240633962
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 13.285303626810656 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7031589766649893
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 7.008093986830753 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.472349281043427
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 3.6438848303047062 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0953700180667576
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 1.9329858328056893 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5791020168218689
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 1.127236992086452 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.05684054523878155
#
# ------------ 10 ------------
# eps = 0.0048828125
# statistic = 0.799748630780245 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.28443029524677277
#
# ------------ 11 ------------
# eps = 0.00732421875
# statistic = 0.9509620891294788 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.11307401450298836
#
# ------------ 12 ------------
# eps = 0.008544921875
# statistic = 1.0367489928519174 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.026822185560909376
#
# ------------ 13 ------------
# eps = 0.0091552734375
# statistic = 1.0814802056599453 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.0154167157256178
#
# ------------ 14 ------------
# eps = 0.00885009765625
# statistic = 1.0589778933682574 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.005609436383367648
#
# ------------ 15 ------------
# eps = 0.009002685546875
# statistic = 1.0701959853586054 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.017094017094017096
# relative_error_metric = 0.004928143126658155
#
# ------------ 16 ------------
# eps = 0.0089263916015625
# statistic = 1.0645785374539292 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.00851063829787234
# relative_error_metric = 0.00033466112812604405
# =======> statistic within required accuracy at 0.95 CL in 46.39878852199763 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.00896453857421875
# statistic = 1.067385178106817 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9928412042008423
# relative_error_metric = 0.20417821512363388
#
# ------------ 2 ------------
# eps = 2.5044822692871094
# statistic = 94.2118693271255 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9857334739749728
# relative_error_metric = 1.9451392981777884
#
# ------------ 3 ------------
# eps = 1.256723403930664
# statistic = 68.54906039200662 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9716690401380381
# relative_error_metric = 1.9249861831191546
#
# ------------ 4 ------------
# eps = 0.6328439712524414
# statistic = 42.69195806339871 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.944129512544856
# relative_error_metric = 1.8809055196439595
#
# ------------ 5 ------------
# eps = 0.3209042549133301
# statistic = 24.860582341580052 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.8912957060358349
# relative_error_metric = 1.7997605823023426
#
# ------------ 6 ------------
# eps = 0.16493439674377441
# statistic = 13.94782741949639 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.793798885362326
# relative_error_metric = 1.6565456129065488
#
# ------------ 7 ------------
# eps = 0.08694946765899658
# statistic = 7.747331959625043 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.6261426698235737
# relative_error_metric = 1.4214251900701802
#
# ------------ 8 ------------
# eps = 0.047957003116607666
# statistic = 4.421846047534541 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.3700424613999174
# relative_error_metric = 1.0857552151886678
#
# ------------ 9 ------------
# eps = 0.028460770845413208
# statistic = 2.712164163420745 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.0418742061738275
# relative_error_metric = 0.6971513198527116
#
# ------------ 10 ------------
# eps = 0.01871265470981598
# statistic = 1.8625480135161185 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.7044150781878824
# relative_error_metric = 0.3482563042464163
#
# ------------ 11 ------------
# eps = 0.013838596642017365
# statistic = 1.4511631073352198 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.4274901693630466
# relative_error_metric = 0.10217244447467716
#
# ------------ 12 ------------
# eps = 0.011401567608118057
# statistic = 1.2540336985457368 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.19310722463988972
# relative_error_metric = 0.04373162441867237
#
# ------------ 13 ------------
# eps = 0.012620082125067711
# statistic = 1.3515868504542632 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.1014513599593689
# relative_error_metric = 0.03117291153603844
#
# ------------ 14 ------------
# eps = 0.012010824866592884
# statistic = 1.3025263688972402 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.04947095603755931
# relative_error_metric = 0.005798155156307756
#
# ------------ 15 ------------
# eps = 0.012315453495830297
# statistic = 1.3269898389158317 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.025045230897955476
# relative_error_metric = 0.0128090123242114
#
# ------------ 16 ------------
# eps = 0.01216313918121159
# statistic = 1.3147409077992145 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.012601517427386112
# relative_error_metric = 0.0035357035687416534
#
# ------------ 17 ------------
# eps = 0.012086982023902237
# statistic = 1.3086292745107688 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.006280971271458507
# relative_error_metric = 0.0011236764913183316
# =======> statistic within required accuracy at 0.99 CL in 48.5529133901 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 94.95173791702837 seconds.
# Saving results in the file results_leonardo/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for fn with mean_off deformation.
#
# ======================================================
# =============== fn - mean + off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 110.79011752086639 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9619173261334315
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 110.79011752086639 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9619173261334315
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 83.89444348758363 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.949861456582239
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 49.922465911703625 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.916455057225592
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 27.532471037012854 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8510445494823744
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 14.51808647223698 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7266422610259748
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 7.465632734609125 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5006499358652148
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 3.8054901280757587 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.125386494587121
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 1.976789643541674 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5995643387877305
#
# ------------ 10 ------------
# eps = 0.0048828125
# statistic = 1.1253174258258898 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.055137534432614085
#
# ------------ 11 ------------
# eps = 0.00244140625
# statistic = 0.7866025829672817 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.3006499130764856
#
# ------------ 12 ------------
# eps = 0.003662109375
# statistic = 0.941513796222827 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.12302440224887254
#
# ------------ 13 ------------
# eps = 0.0042724609375
# statistic = 1.0307115502165354 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.032661349342841164
#
# ------------ 14 ------------
# eps = 0.00457763671875
# statistic = 1.0774248875524335 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.01166005604242998
#
# ------------ 15 ------------
# eps = 0.004425048828125
# statistic = 1.0539110176788786 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.01040552549681004
#
# ------------ 16 ------------
# eps = 0.0045013427734375
# statistic = 1.065629934807163 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.017094017094017096
# relative_error_metric = 0.0006524698727309733
#
# ------------ 17 ------------
# eps = 0.00446319580078125
# statistic = 1.059760815218279 - next threshold = 1.0649348701336006 at 0.95 CL
# relative_error_eps = 0.00851063829787234
# relative_error_metric = 0.004870396218143343
# =======> statistic within required accuracy at 0.95 CL in 50.17175121488981 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.004482269287109375
# statistic = 1.0626929795570064 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9964173962093004
# relative_error_metric = 0.20853697688591477
#
# ------------ 2 ------------
# eps = 2.5022411346435547
# statistic = 110.7901175208664 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9928476045181835
# relative_error_metric = 1.9532525235249205
#
# ------------ 3 ------------
# eps = 1.253361701965332
# statistic = 110.79011752086639 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9857461835027237
# relative_error_metric = 1.9532525235249205
#
# ------------ 4 ------------
# eps = 0.6289219856262207
# statistic = 84.24627251973307 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9716941005536965
# relative_error_metric = 1.938749129740985
#
# ------------ 5 ------------
# eps = 0.31670212745666504
# statistic = 50.467175716741664 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.9441782436189126
# relative_error_metric = 1.8987895331023923
#
# ------------ 6 ------------
# eps = 0.1605921983718872
# statistic = 28.216521107852582 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.8913879450729196
# relative_error_metric = 1.82251940759423
#
# ------------ 7 ------------
# eps = 0.08253723382949829
# statistic = 15.290832021430878 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.7939648411412759
# relative_error_metric = 1.6843308484457866
#
# ------------ 8 ------------
# eps = 0.04350975155830383
# statistic = 8.28774388051516 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.6264154575572316
# relative_error_metric = 1.4540021635556013
#
# ------------ 9 ------------
# eps = 0.023996010422706604
# statistic = 4.647607242831394 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.3704297685418951
# relative_error_metric = 1.1203995787008447
#
# ------------ 10 ------------
# eps = 0.01423913985490799
# statistic = 2.8084905834473384 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 1.0423222412142896
# relative_error_metric = 0.7276226010027422
#
# ------------ 11 ------------
# eps = 0.009360704571008682
# statistic = 1.9028012656833508 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.7048247484825529
# relative_error_metric = 0.3689503866536397
#
# ------------ 12 ------------
# eps = 0.006921486929059029
# statistic = 1.4666910040413819 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.4277919653335446
# relative_error_metric = 0.11278514960115617
#
# ------------ 13 ------------
# eps = 0.005701878108084202
# statistic = 1.2586443034606931 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.19323038150068964
# relative_error_metric = 0.04006335858825923
#
# ------------ 14 ------------
# eps = 0.006311682518571615
# statistic = 1.3614965237753662 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.10151934625183026
# relative_error_metric = 0.038475821569160386
#
# ------------ 15 ------------
# eps = 0.0060067803133279085
# statistic = 1.3097423505254548 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.049503287772909625
# relative_error_metric = 0.00027347179269364685
#
# ------------ 16 ------------
# eps = 0.006159231415949762
# statistic = 1.335542211494694 - next threshold = 1.3101005770964511 at 0.99 CL
# relative_error_eps = 0.025061804314223654
# relative_error_metric = 0.019232856762035535
#
# ------------ 17 ------------
# eps = 0.006083005864638835
# ...
# relative_error_eps = 2.0
# relative_error_metric = 1.87475093272484
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 11.956380615933096 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7651948098756196
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 6.125957022763324 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.565966468748445
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 3.124523278806543 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2293583919928341
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 1.6235081589597244 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7411017017615271
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 0.920700311178824 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.21013452342123912
#
# ------------ 10 ------------
# eps = 0.0048828125
# statistic = 0.6318711108404651 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.16515926133546413
#
# ------------ 11 ------------
# eps = 0.00732421875
# statistic = 0.7667319098225963 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.027913728158787534
#
# ------------ 12 ------------
# eps = 0.006103515625
# statistic = 0.6961782933676487 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.06858896397577265
#
# ------------ 13 ------------
# eps = 0.0067138671875
# statistic = 0.7308008431253147 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.020080015604072247
#
# ------------ 14 ------------
# eps = 0.00701904296875
# statistic = 0.7486146477742398 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.0040026882751045
#
# ------------ 15 ------------
# eps = 0.006866455078125
# statistic = 0.7396681892280206 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.02197802197802198
# relative_error_metric = 0.008019932858466274
#
# ------------ 16 ------------
# eps = 0.0069427490234375
# statistic = 0.7441317537890372 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.01092896174863388
# relative_error_metric = 0.002003560299057436
#
# ------------ 17 ------------
# eps = 0.00698089599609375
# statistic = 0.746370728805631 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.005479452054794521
# relative_error_metric = 0.0010007636320681526
# =======> statistic within required accuracy at 0.95 CL in 83.74257953302003 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.006961822509765625
# statistic = 0.7452506247350204 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.994438285925435
# relative_error_metric = 0.15225343933311003
#
# ------------ 2 ------------
# eps = 2.503480911254883
# statistic = 147.124712590211 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.9889074187335463
# relative_error_metric = 1.9765375791670365
#
# ------------ 3 ------------
# eps = 1.2552213668823242
# statistic = 80.90957690713223 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.9779372041450856
# relative_error_metric = 1.9575401209314793
#
# ------------ 4 ------------
# eps = 0.6310915946960449
# statistic = 44.250416868432566 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.9563558641202605
# relative_error_metric = 1.9230411005533872
#
# ------------ 5 ------------
# eps = 0.3190267086029053
# statistic = 23.518437224743145 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.9145758596352653
# relative_error_metric = 1.8576151457864492
#
# ------------ 6 ------------
# eps = 0.16299426555633545
# statistic = 12.449679145992398 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.8361500882025958
# relative_error_metric = 1.7392750406326172
#
# ------------ 7 ------------
# eps = 0.08497804403305054
# statistic = 6.646694083794577 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.6971140911315759
# relative_error_metric = 1.5379402299341565
#
# ------------ 8 ------------
# eps = 0.04596993327140808
# statistic = 3.658605903134794 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.4739020153764297
# relative_error_metric = 1.2329313856629607
#
# ------------ 9 ------------
# eps = 0.026465877890586853
# statistic = 2.151892203737666 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.1669397025357788
# relative_error_metric = 0.8502266444997185
#
# ------------ 10 ------------
# eps = 0.01671385020017624
# statistic = 1.4129207315644687 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.8238015290957754
# relative_error_metric = 0.47773466856314517
#
# ------------ 11 ------------
# eps = 0.011837836354970932
# statistic = 1.0612801474124003 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.5187342898387891
# relative_error_metric = 0.20028837796149848
#
# ------------ 12 ------------
# eps = 0.009399829432368279
# statistic = 0.8967387690445114 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.2980147641845859
# relative_error_metric = 0.03249257899719589
#
# ------------ 13 ------------
# eps = 0.008180825971066952
# statistic = 0.8190440257859715 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.13867554233082066
# relative_error_metric = 0.0581149516636021
#
# ------------ 14 ------------
# eps = 0.008790327701717615
# statistic = 0.8574546576190216 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.06701445470292718
# relative_error_metric = 0.012300698768801058
#
# ------------ 15 ------------
# eps = 0.009095078567042947
# statistic = 0.87699400047578 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.03407815967341183
# relative_error_metric = 0.010230908043585505
#
# ------------ 16 ------------
# eps = 0.008942703134380281
# statistic = 0.8671978017956076 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.016895141008458157
# relative_error_metric = 0.0010020581645879155
#
# ------------ 17 ------------
# eps = 0.009018890850711614
# statistic = 0.8720894528051248 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.008483402574912745
# relative_error_metric = 0.0046228398061678435
# =======> statistic within required accuracy at 0.99 CL in 80.23309536487795 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 163.9757077950053 seconds.
# Saving results in the file results_leonardo/5D_unimodal/5D_100K/exclusion_limits.json
# Computing exclusion limits for swd with mean_cov deformation.
#
# ======================================================
# =============== swd - mean + cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 140.49859709665733 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.978884115610536
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 70.89350724198262 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9583677720774508
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 35.95393015765352 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9187320744873733
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 18.2241221946673 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8427761451975726
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 9.20411961355019 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.700243874199826
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 4.641077288683373 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4463222671152576
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 2.358485619349511 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0391781034980812
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 1.2447092080132152 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5015089973536653
#
# ------------ 9 ------------
# eps = 0.009765625
# statistic = 0.7436016169792864 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.002716236506900824
#
# ------------ 10 ------------
# eps = 0.0146484375
# statistic = 0.9828358481024739 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.27447749449263686
#
# ------------ 11 ------------
# eps = 0.01220703125
# statistic = 0.8590085175019201 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.1413212597240773
#
# ------------ 12 ------------
# eps = 0.010986328125
# statistic = 0.8000130700464108 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.07037732688724124
#
# ------------ 13 ------------
# eps = 0.0103759765625
# statistic = 0.7714493405426182 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.034046048278813835
#
# ------------ 14 ------------
# eps = 0.01007080078125
# statistic = 0.7574301921463372 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.03076923076923077
# relative_error_metric = 0.015709385922567643
#
# ------------ 15 ------------
# eps = 0.009918212890625
# statistic = 0.7504915618229744 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.015503875968992248
# relative_error_metric = 0.006506716096434582
#
# ------------ 16 ------------
# eps = 0.0098419189453125
# statistic = 0.7470404505263355 - next threshold = 0.7456241616928099 at 0.95 CL
# relative_error_eps = 0.007782101167315175
# relative_error_metric = 0.0018976651847061982
# =======> statistic within required accuracy at 0.95 CL in 73.38364639994688 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.00980377197265625
# statistic = 0.7453194925228206 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.9921723305591301
# relative_error_metric = 0.15216156989350296
#
# ------------ 2 ------------
# eps = 2.504901885986328
# statistic = 140.76797613448764 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.9844056946519724
# relative_error_metric = 1.9754845673607473
#
# ------------ 3 ------------
# eps = 1.2573528289794922
# statistic = 71.30481454972501 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.9690526902032799
# relative_error_metric = 1.9518895630186281
#
# ------------ 4 ------------
# eps = 0.6335783004760742
# statistic = 36.4366035745492 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.9390485225344074
# relative_error_metric = 1.906921337028605
#
# ------------ 5 ------------
# eps = 0.32169103622436523
# statistic = 18.750727454824617 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.8817022562014973
# relative_error_metric = 1.8230131393037468
#
# ------------ 6 ------------
# eps = 0.16574740409851074
# statistic = 9.75644579654737 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.7766173444789255
# relative_error_metric = 1.6731832438128624
#
# ------------ 7 ------------
# eps = 0.0877755880355835
# statistic = 5.20624927421993 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.5981210792188674
# relative_error_metric = 1.428368791216093
#
# ------------ 8 ------------
# eps = 0.04878968000411987
# statistic = 2.924751519553967 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 1.330725762561862
# relative_error_metric = 1.0845149429622976
#
# ------------ 9 ------------
# eps = 0.02929672598838806
# statistic = 1.79483072637323 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.9970693485874565
# relative_error_metric = 0.6960563453702958
#
# ------------ 10 ------------
# eps = 0.019550248980522156
# statistic = 1.2457525487650092 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.6640641855105424
# relative_error_metric = 0.35734865791516396
#
# ------------ 11 ------------
# eps = 0.014677010476589203
# statistic = 0.9843214051653457 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.3981276753744573
# relative_error_metric = 0.12551813755130506
#
# ------------ 12 ------------
# eps = 0.012240391224622726
# statistic = 0.8606521084473193 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.18104416459013353
# relative_error_metric = 0.008578733941981238
#
# ------------ 13 ------------
# eps = 0.013458700850605965
# statistic = 0.9216664487004457 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.0948134371764491
# relative_error_metric = 0.059896318206074405
#
# ------------ 14 ------------
# eps = 0.012849546037614346
# statistic = 0.8909303215163389 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.048557699178344266
# relative_error_metric = 0.025995603676757024
#
# ------------ 15 ------------
# eps = 0.012544968631118536
# statistic = 0.87573007608359 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.024577202692924183
# relative_error_metric = 0.008788700456875522
#
# ------------ 16 ------------
# eps = 0.012392679927870631
# statistic = 0.8681752535484255 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.01236457300067435
# relative_error_metric = 0.00012444518900545982
#
# ------------ 17 ------------
# eps = 0.012316535576246679
# statistic = 0.8644096102630899 - next threshold = 0.8680672200370332 at 0.99 CL
# relative_error_eps = 0.006163235057888779
# relative_error_metric = 0.004222405413998672
# =======> statistic within required accuracy at 0.99 CL in 77.26336131594144 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 150.6470400399994 seconds.
# Saving results in the file results_leonardo/5D_unimodal/5D_100K/exclusion_limits.json
# dict_keys(['2024-04-17T01:20:57.954776', '2024-04-17T01:22:38.307208', '2024-04-17T01:24:18.175940', '2024-04-17T01:26:02.014242', '2024-04-17T01:27:27.307904', '2024-04-17T01:29:02.266754', '2024-04-17T01:30:44.038430', '2024-04-17T01:32:16.094169', '2024-04-17T01:34:57.085261', '2024-04-17T01:37:41.822009', '2024-04-17T01:40:37.339497', '2024-04-17T01:43:22.489518', '2024-04-17T01:46:19.580577', '2024-04-17T01:49:25.287404', '2024-04-17T01:52:24.190821', '2024-04-17T02:01:10.493986', '2024-04-17T02:07:10.899169', '2024-04-17T02:13:33.773414', '2024-04-17T02:19:53.826445', '2024-04-17T02:28:47.629273', '2024-04-17T02:37:41.230324', '2024-04-17T02:46:35.015621', '2024-04-17T02:49:02.231520', '2024-04-17T02:51:21.720035', '2024-04-17T02:53:39.780916', '2024-04-17T02:56:03.760128', '2024-04-17T02:58:38.159824', '2024-04-17T03:01:10.128627', '2024-04-17T03:03:49.538976', '2024-04-17T03:08:00.511801', '2024-04-17T03:12:07.599653', '2024-04-17T03:16:20.021804', '2024-04-17T03:20:17.027075', '2024-04-17T03:24:32.726377', '2024-04-17T03:29:06.227863', '2024-04-17T03:33:32.258186', '2024-04-17T03:36:03.280463', '2024-04-17T03:38:34.682184', '2024-04-17T03:41:04.697057', '2024-04-17T03:43:33.297222', '2024-04-17T03:46:03.712538', '2024-04-17T03:48:47.699383'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.1,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 0.05
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 71.81197277200408 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.050000.json
# ThresholdS: [[0.95, [9500, 500], -620.3627764799043], [0.99, [9900, 100], -591.5857105234815]]
# Null distribution computed in 72.07136863004416 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.7048435150645673 seconds.
# statistic = 679.5074721831043 - next threshold = -620.3627764799043 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 43.95559849309292
#
# ------------ 2 ------------
# eps = 0.025
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 71.68242998002097 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.025000.json
# ThresholdS: [[0.95, [9500, 500], -138.68836268888384], [0.99, [9900, 100], -124.21805647314677]]
# Null distribution computed in 71.9468026550021 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.706470137927681 seconds.
# statistic = 163.92703062076413 - next threshold = -138.68836268888384 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 23.980298336379203
#
# ------------ 3 ------------
# eps = 0.0125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 71.6385660090018 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.012500.json
# ThresholdS: [[0.95, [9500, 500], -25.84651204062002], [0.99, [9900, 100], -18.448434472579716]]
# Null distribution computed in 71.90129406494088 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.732674110913649 seconds.
# statistic = 37.98230882808866 - next threshold = -25.84651204062002 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 10.519098496213775
#
# ------------ 4 ------------
# eps = 0.00625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 71.69365475187078 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.006250.json
# ThresholdS: [[0.95, [9500, 500], -1.9634134859533356], [0.99, [9900, 100], 1.7752963743478205]]
# Null distribution computed in 71.95614905795082 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.7009450800251216 seconds.
# statistic = 7.992649733426592 - next threshold = -1.9634134859533356 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 3.3025951582349533
#
# ------------ 5 ------------
# eps = 0.003125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 71.45572462794371 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.003125.json
# ThresholdS: [[0.95, [9500, 500], 1.7679036776722103], [0.99, [9900, 100], 3.6476047590665064]]
# Null distribution computed in 71.71596540487371 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.70308278221637 seconds.
# statistic = 1.2462897955498684 - next threshold = 1.7679036776722103 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.34610511021029644
#
# ------------ 6 ------------
# eps = 0.004687500000000001
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 71.60778732411563 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.004688.json
# ThresholdS: [[0.95, [9500, 500], 0.588379063656424], [0.99, [9900, 100], 3.4001771519568185]]
# Null distribution computed in 71.86804355913773 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.699875308200717 seconds.
# statistic = 3.9320124888501575 - next threshold = 0.588379063656424 at 0.95 CL
# relative_error_eps = 0.40000000000000013
# relative_error_metric = 1.4793556648161024
#
# ------------ 7 ------------
# eps = 0.00390625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 76.61019784002565 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.003906.json
# ThresholdS: [[0.95, [9500, 500], 1.3498332674072093], [0.99, [9900, 100], 3.696230247110109]]
# Null distribution computed in 76.87741936417297 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 4.269542795838788 seconds.
# statistic = 2.417280410427293 - next threshold = 1.3498332674072093 at 0.95 CL
# relative_error_eps = 0.22222222222222215
# relative_error_metric = 0.5667188379797966
#
# ------------ 8 ------------
# eps = 0.003515625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.86506153596565 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.003516.json
# ThresholdS: [[0.95, [9500, 500], 1.6018112626383707], [0.99, [9900, 100], 3.715022047111607]]
# Null distribution computed in 73.14104191516526 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 4.13341332715936 seconds.
# statistic = 1.7888166163268142 - next threshold = 1.6018112626383707 at 0.95 CL
# relative_error_eps = 0.11764705882352937
# relative_error_metric = 0.11030721174009653
#
# ------------ 9 ------------
# eps = 0.0033203125000000003
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.4824924999848 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.003320.json
# ThresholdS: [[0.95, [9500, 500], 1.695595645618303], [0.99, [9900, 100], 3.6920920051176895]]
# Null distribution computed in 72.76437436696142 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 4.079817280871794 seconds.
# statistic = 1.506810983727559 - next threshold = 1.695595645618303 at 0.95 CL
# relative_error_eps = 0.057142857142857065
# relative_error_metric = 0.11790174312080166
#
# ------------ 10 ------------
# eps = 0.00341796875
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.24864439899102 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.003418.json
# ThresholdS: [[0.95, [9500, 500], 1.6513876881283196], [0.99, [9900, 100], 3.70625136827892]]
# Null distribution computed in 72.51859963405877 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 4.030541194835678 seconds.
# statistic = 1.6451282570876762 - next threshold = 1.6513876881283196 at 0.95 CL
# relative_error_eps = 0.028169014084507067
# relative_error_metric = 0.003797603982305799
#
# ------------ 11 ------------
# eps = 0.003466796875
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.38778913090937 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.003467.json
# ThresholdS: [[0.95, [9500, 500], 1.6272704951938508], [0.99, [9900, 100], 3.7113102546703187]]
# Null distribution computed in 72.65859962604009 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.9719713910017163 seconds.
# statistic = 1.716301052482904 - next threshold = 1.6272704951938508 at 0.95 CL
# relative_error_eps = 0.014184397163120517
# relative_error_metric = 0.0532547642660228
#
# ------------ 12 ------------
# eps = 0.0034423828125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.33830336807296 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_0.003442.json
# ThresholdS: [[0.95, [9500, 500], 1.6394968514293184], [0.99, [9900, 100], 3.70894920303399]]
# Null distribution computed in 72.60437535797246 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.936878056032583 seconds.
# statistic = 1.6805468084843083 - next threshold = 1.6394968514293184 at 0.95 CL
# relative_error_eps = 0.007117437722419903
# relative_error_metric = 0.0247285645972847
#
# ------------ 13 ------------
# eps = 0.00343017578125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# ...
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 71.9472400911618 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_off_0.000488.json
# ThresholdS: [[0.95, [9500, 500], 1.7408554680981096], [0.99, [9900, 100], 3.6296179605788437]]
# Null distribution computed in 72.21122788311914 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.947231990052387 seconds.
# statistic = 0.9017118763469404 - next threshold = 1.7408554680981096 at 0.95 CL
# relative_error_eps = 0.18181818181818196
# relative_error_metric = 0.6350972235505263
#
# ------------ 11 ------------
# eps = 0.000537109375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 71.84731538500637 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_off_0.000537.json
# ThresholdS: [[0.95, [9500, 500], 1.577575889117497], [0.99, [9900, 100], 3.6526579722616046]]
# Null distribution computed in 72.11515539092943 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.927577320020646 seconds.
# statistic = 1.329334638974158 - next threshold = 1.577575889117497 at 0.95 CL
# relative_error_eps = 0.0869565217391305
# relative_error_metric = 0.17079387049886652
#
# ------------ 12 ------------
# eps = 0.0005615234375000001
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.0707346489653 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_off_0.000562.json
# ThresholdS: [[0.95, [9500, 500], 1.4732268641494408], [0.99, [9900, 100], 3.6412020128370757]]
# Null distribution computed in 72.33623944502324 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.946316718123853 seconds.
# statistic = 1.5660576440594949 - next threshold = 1.4732268641494408 at 0.95 CL
# relative_error_eps = 0.04444444444444448
# relative_error_metric = 0.06108725896461708
#
# ------------ 13 ------------
# eps = 0.00054931640625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 72.42726389807649 seconds.
# Saving lr to results_leonardo/5D_unimodal/5D_100K/null_hypothesis/LR_mean_off_0.000549.json
# ThresholdS: [[0.95, [9500, 500], 1.5272988667721914], [0.99, [9900, 100], 3.6488428536931057]]
# Null distribution computed in 72.72749235900119 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.955597900087014 seconds.
# statistic = 1.4457877086403597 - next threshold = 1.5272988667721914 at 0.95 CL
# relative_error_eps = 0.02197802197802209
# relative_error_metric = 0.05483268385517573
#
# ------------ 14 ------------
# eps = 0.0005554199218750001
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_std = results_df[results_df["Deformation"] == "std"]
results_df_off = results_df[results_df["Deformation"] == "off"]
results_df_cov = results_df[results_df["Deformation"] == "cov"]
results_df_mean_std = results_df[results_df["Deformation"] == "mean_std"]
results_df_mean_off = results_df[results_df["Deformation"] == "mean_off"]
results_df_mean_cov = results_df[results_df["Deformation"] == "mean_cov"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 42        lr        mean    5  10000                10000
# 35       swd        mean    5  10000                10000
# 28       sks        mean    5  10000                10000
# 7        fpd        mean    5  10000                10000
# 21        ks        mean    5  10000                10000
# 0         fn        mean    5  10000                10000
# 14       kpd        mean    5  10000                10000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 42                             0.01040                             0.01377
# 35                             0.02953                             0.03999
# 28                             0.03067                             0.04022
# 7                              0.03464                             0.05146
# 21                             0.04257                             0.05543
# 0                              0.05600                             0.07260
# 14                             0.38940                             0.41755
#
#     $t^{\mu}$ (s)
# 42            329
# 35            128
# 28            200
# 7             124
# 21            124
# 0              73
# 14            112
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 42        lr                             0.01040
# 35       swd                             0.02953
# 28       sks                             0.03067
# 7        fpd                             0.03464
# 21        ks                             0.04257
# 0         fn                             0.05600
# 14       kpd                             0.38940
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 42                             0.01377            329
# 35                             0.03999            128
# 28                             0.04022            200
# 7                              0.05146            124
# 21                             0.05543            124
# 0                              0.07260             73
# 14                             0.41755            112

# %%
sorted_df_std = results_df_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma}$ (s)"}, inplace=True)
display(sorted_df_std)
sorted_df_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 43        lr         std    5  10000                10000
# 8        fpd         std    5  10000                10000
# 36       swd         std    5  10000                10000
# 29       sks         std    5  10000                10000
# 1         fn         std    5  10000                10000
# 22        ks         std    5  10000                10000
# 15       kpd         std    5  10000                10000
#
#     $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 43                                0.00184
# 8                                 0.02144
# 36                                0.03220
# 29                                0.03372
# 1                                 0.03403
# 22                                0.06683
# 15                                3.97461
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 43                                0.00274               413
# 8                                 0.03192               133
# 36                                0.04417               129
# 29                                0.04539               203
# 1                                 0.04357                75
# 22                                0.08701               117
# 15                                4.28703                72
#    Statistic  $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 43        lr                                0.00184
# 8        fpd                                0.02144
# 36       swd                                0.03220
# 29       sks                                0.03372
# 1         fn                                0.03403
# 22        ks                                0.06683
# 15       kpd                                3.97461
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 43                                0.00274               413
# 8                                 0.03192               133
# 36                                0.04417               129
# 29                                0.04539               203
# 1                                 0.04357                75
# 22                                0.08701               117
# 15                                4.28703                72

# %%
sorted_df_off = results_df_off.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_off.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}-\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}-\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ij}-\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_off)
sorted_df_off.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_off)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 44        lr         off    5  10000                10000
# 9        fpd         off    5  10000                10000
# 2         fn         off    5  10000                10000
# 30       sks         off    5  10000                10000
# 37       swd         off    5  10000                10000
# 23        ks         off    5  10000                10000
# 16       kpd         off    5  10000                10000
#
#     $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 44                                            0.00089
# 9                                             0.01194
# 2                                             0.01534
# 30                                            0.02190
# 37                                            0.02251
# 23                                            0.06622
# 16                                            3.83789
#
#     $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 44                                            0.00138
# 9                                             0.01613
# 2                                             0.01952
# 30                                            0.03033
# 37                                            0.03177
# 23                                            0.08881
# 16                                            4.14658
#
#     $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 44                                467
# 9                                 143
# 2                                  81
# 30                                214
# 37                                128
# 23                                118
# 16                                 68
#    Statistic  $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 44        lr                                            0.00089
# 9        fpd                                            0.01194
# 2         fn                                            0.01534
# 30       sks                                            0.02190
# 37       swd                                            0.02251
# 23        ks                                            0.06622
# 16       kpd                                            3.83789
#
#     $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 44                                            0.00138
# 9                                             0.01613
# 2                                             0.01952
# 30                                            0.03033
# 37                                            0.03177
# 23                                            0.08881
# 16                                            4.14658
#
#     $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 44                                467
# 9                                 143
# 2                                  81
# 30                                214
# 37                                128
# 23                                118
# 16                                 68

# %%
sorted_df_cov = results_df_cov.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ij}}$ (s)"}, inplace=True)
display(sorted_df_cov)
sorted_df_cov.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 45        lr         cov    5  10000                10000
# 10       fpd         cov    5  10000                10000
# 38       swd         cov    5  10000                10000
# 31       sks         cov    5  10000                10000
# 24        ks         cov    5  10000                10000
# 3         fn         cov    5  10000                10000
# 17       kpd         cov    5  10000                10000
#
#     $\epsilon^{\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 45                                     0.01421
# 10                                     0.03708
# 38                                     0.04440
# 31                                     0.05936
# 24                                     0.06500
# 3                                      0.13733
# 17                                     3.92578
#
#     $\epsilon^{\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ij}}$ (s)
# 45                                     0.01953                    339
# 10                                     0.04844                    132
# 38                                     0.05968                    130
# 31                                     0.07896                    202
# 24                                     0.08699                    117
# 3                                      0.18897                     64
# 17                                     4.31183                     65
#    Statistic  $\epsilon^{\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 45        lr                                     0.01421
# 10       fpd                                     0.03708
# 38       swd                                     0.04440
# 31       sks                                     0.05936
# 24        ks                                     0.06500
# 3         fn                                     0.13733
# 17       kpd                                     3.92578
#
#     $\epsilon^{\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ij}}$ (s)
# 45                                     0.01953                    339
# 10                                     0.04844                    132
# 38                                     0.05968                    130
# 31                                     0.07896                    202
# 24                                     0.08699                    117
# 3                                      0.18897                     64
# 17                                     4.31183                     65

# %%
sorted_df_mean_std = results_df_mean_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\sigma}$ (s)"}, inplace=True)
display(sorted_df_mean_std)
sorted_df_mean_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 46        lr    mean_std    5  10000                10000
# 11       fpd    mean_std    5  10000                10000
# 39       swd    mean_std    5  10000                10000
# 32       sks    mean_std    5  10000                10000
# 4         fn    mean_std    5  10000                10000
# 25        ks    mean_std    5  10000                10000
# 18       kpd    mean_std    5  10000                10000
#
#     $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 46                                    0.00193
# 11                                    0.01961
# 39                                    0.02098
# 32                                    0.02129
# 4                                     0.03250
# 25                                    0.03403
# 18                                    0.37659
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 46                                    0.00295                   419
# 11                                    0.02546                   144
# 39                                    0.02881                   132
# 32                                    0.02790                   222
# 4                                     0.04205                    77
# 25                                    0.04357                   132
# 18                                    0.40311                   123
#    Statistic  $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 46        lr                                    0.00193
# 11       fpd                                    0.01961
# 39       swd                                    0.02098
# 32       sks                                    0.02129
# 4         fn                                    0.03250
# 25        ks                                    0.03403
# 18       kpd                                    0.37659
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 46                                    0.00295                   419
# 11                                    0.02546                   144
# 39                                    0.02881                   132
# 32                                    0.02790                   222
# 4                                     0.04205                    77
# 25                                    0.04357                   132
# 18                                    0.40311                   123

# %%
sorted_df_mean_off = results_df_mean_off.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean_off.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_mean_off)
sorted_df_mean_off.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean_off)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 47        lr    mean_off    5  10000                10000
# 12       fpd    mean_off    5  10000                10000
# 5         fn    mean_off    5  10000                10000
# 33       sks    mean_off    5  10000                10000
# 40       swd    mean_off    5  10000                10000
# 26        ks    mean_off    5  10000                10000
# 19       kpd    mean_off    5  10000                10000
#
#     $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 47                                            0.00092
# 12                                            0.01087
# 5                                             0.01564
# 33                                            0.01656
# 40                                            0.01717
# 26                                            0.03342
# 19                                            0.37231
#
#     $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 47                                            0.00143
# 12                                            0.01597
# 5                                             0.01982
# 33                                            0.02226
# 40                                            0.02378
# 26                                            0.04327
# 19                                            0.39999
#
#     $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 47                                    456
# 12                                    152
# 5                                      81
# 33                                    222
# 40                                    141
# 26                                    133
# 19                                    119
#    Statistic  $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 47        lr                                            0.00092
# 12       fpd                                            0.01087
# 5         fn                                            0.01564
# 33       sks                                            0.01656
# 40       swd                                            0.01717
# 26        ks                                            0.03342
# 19       kpd                                            0.37231
#
#     $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 47                                            0.00143
# 12                                            0.01597
# 5                                             0.01982
# 33                                            0.02226
# 40                                            0.02378
# 26                                            0.04327
# 19                                            0.39999
#
#     $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 47                                    456
# 12                                    152
# 5                                      81
# 33                                    222
# 40                                    141
# 26                                    133
# 19                                    119

# %%
sorted_df_mean_cov = results_df_mean_cov.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean_cov.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\Sigma_{ij}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\Sigma_{ij}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\Sigma_{ij}}$ (s)"}, inplace=True)
display(sorted_df_mean_cov)
sorted_df_mean_cov.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean_cov)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 48        lr    mean_cov    5  10000                10000
# 41       swd    mean_cov    5  10000                10000
# 13       fpd    mean_cov    5  10000                10000
# 34       sks    mean_cov    5  10000                10000
# 27        ks    mean_cov    5  10000                10000
# 6         fn    mean_cov    5  10000                10000
# 20       kpd    mean_cov    5  10000                10000
#
#     $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 48                                         0.00861
# 41                                         0.02388
# 13                                         0.02434
# 34                                         0.02602
# 27                                         0.03342
# 6                                          0.04990
# 20                                         0.37720
#
#     $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\mu-\Sigma_{ij}}$ (s)
# 48                                         0.01112                        411
# 41                                         0.03254                        128
# 13                                         0.03147                        143
# 34                                         0.03406                        220
# 27                                         0.04266                        130
# 6                                          0.06530                         76
# 20                                         0.40372                        118
#    Statistic  $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 48        lr                                         0.00861
# 41       swd                                         0.02388
# 13       fpd                                         0.02434
# 34       sks                                         0.02602
# 27        ks                                         0.03342
# 6         fn                                         0.04990
# 20       kpd                                         0.37720
#
#     $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\mu-\Sigma_{ij}}$ (s)
# 48                                         0.01112                        411
# 41                                         0.03254                        128
# 13                                         0.03147                        143
# 34                                         0.03406                        220
# 27                                         0.04266                        130
# 6                                          0.06530                         76
# 20                                         0.40372                        118

# %%
result_table = sorted_df_mean.merge(sorted_df_std, on='Statistic', how='outer').merge(sorted_df_off, on='Statistic', how='outer').merge(sorted_df_cov, on='Statistic', how='outer').merge(sorted_df_mean_std, on='Statistic', how='outer').merge(sorted_df_mean_off, on='Statistic', how='outer').merge(sorted_df_mean_cov, on='Statistic', how='outer').merge(times_df, on='Statistic', how='outer')
result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fpd","$d_{\\mathrm{FPD}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("kpd","$d_{\\mathrm{KPD}}$")
display(result_table)
print(result_table.to_latex(index=False, column_format='l|llr|llr|llr|llr|llr|llr|llr|r', longtable=False, float_format="%.2g"))
# Out:
#                     Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 0  $\overline{\|\cdot\|}_{F}$                             0.05600
# 1          $d_{\mathrm{FPD}}$                             0.03464
# 2          $d_{\mathrm{KPD}}$                             0.38940
# 3              $\overline{D}$                             0.04257
# 4          $t_{\mathrm{LLR}}$                             0.01040
# 5             $\widetilde{D}$                             0.03067
# 6             $\widetilde{W}$                             0.02953
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)  \
# 0                             0.07260             73
# 1                             0.05146            124
# 2                             0.41755            112
# 3                             0.05543            124
# 4                             0.01377            329
# 5                             0.04022            200
# 6                             0.03999            128
#
#    $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 0                                0.03403
# 1                                0.02144
# 2                                3.97461
# 3                                0.06683
# 4                                0.00184
# 5                                0.03372
# 6                                0.03220
#
#    $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)  \
# 0                                0.04357                75
# 1                                0.03192               133
# 2                                4.28703                72
# 3                                0.08701               117
# 4                                0.00274               413
# 5                                0.04539               203
# 6                                0.04417               129
#
#    $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 0                                            0.01534
# 1                                            0.01194
# 2                                            3.83789
# 3                                            0.06622
# 4                                            0.00089
# 5                                            0.02190
# 6                                            0.02251
#
#    $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 0                                            0.01952
# 1                                            0.01613
# 2                                            4.14658
# 3                                            0.08881
# 4                                            0.00138
# 5                                            0.03033
# 6                                            0.03177
#
#    $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s)  ...  \
# 0                                 81  ...
# 1                                143  ...
# 2                                 68  ...
# 3                                118  ...
# 4                                467  ...
# 5                                214  ...
# 6                                128  ...
#
#    $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 0                                    0.03250
# 1                                    0.01961
# 2                                    0.37659
# 3                                    0.03403
# 4                                    0.00193
# 5                                    0.02129
# 6                                    0.02098
#
#    $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)  \
# 0                                    0.04205                    77
# 1                                    0.02546                   144
# 2                                    0.40311                   123
# 3                                    0.04357                   132
# 4                                    0.00295                   419
# 5                                    0.02790                   222
# 6                                    0.02881                   132
#
#    $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 0                                            0.01564
# 1                                            0.01087
# 2                                            0.37231
# 3                                            0.03342
# 4                                            0.00092
# 5                                            0.01656
# 6                                            0.01717
#
#    $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 0                                            0.01982
# 1                                            0.01597
# 2                                            0.39999
# 3                                            0.04327
# 4                                            0.00143
# 5                                            0.02226
# 6                                            0.02378
#
#    $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s)  \
# 0                                     81
# 1                                    152
# 2                                    119
# 3                                    133
# 4                                    456
# 5                                    222
# 6                                    141
#
#    $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 0                                         0.04990
# 1                                         0.02434
# 2                                         0.37720
# 3                                         0.03342
# 4                                         0.00861
# 5                                         0.02602
# 6                                         0.02388
#
#    $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\mu-\Sigma_{ij}}$ (s)  \
# 0                                         0.06530                         76
# 1                                         0.03147                        143
# 2                                         0.40372                        118
# 3                                         0.04266                        130
# 4                                         0.01112                        411
# 5                                         0.03406                        220
# 6                                         0.03254                        128
#
#    $t^{\mathrm{null}}$ (s)
# 0                        7
# 1                       98
# 2                     2083
# 3                       26
# 4                        -
# 5                      324
# 6                      251
#
# [7 rows x 23 columns]
# \begin{tabular}{l|llr|llr|llr|llr|llr|llr|llr|r}
# \toprule
# Statistic & $\epsilon^{\mu}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu}_{99\%\mathrm{CL}}$ & $t^{\mu}$ (s) & $\epsilon^{\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\sigma}_{99\%\mathrm{CL}}$ & $t^{\sigma}$ (s) & $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$ & $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$ & $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s) & $\epsilon^{\Sigma_{ij}}_{95\%\mathrm{CL}}$ & $\epsilon^{\Sigma_{ij}}_{99\%\mathrm{CL}}$ & $t^{\Sigma_{ij}}$ (s) & $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$ & $t^{\mu-\sigma}$ (s) & $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$ & $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s) & $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$ & $t^{\mu-\Sigma_{ij}}$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $\overline{\|\cdot\|}_{F}$ & 0.056 & 0.073 & 73 & 0.034 & 0.044 & 75 & 0.015 & 0.02 & 81 & 0.14 & 0.19 & 64 & 0.033 & 0.042 & 77 & 0.016 & 0.02 & 81 & 0.05 & 0.065 & 76 & 7 \\
# $d_{\mathrm{FPD}}$ & 0.035 & 0.051 & 124 & 0.021 & 0.032 & 133 & 0.012 & 0.016 & 143 & 0.037 & 0.048 & 132 & 0.02 & 0.025 & 144 & 0.011 & 0.016 & 152 & 0.024 & 0.031 & 143 & 98 \\
# $d_{\mathrm{KPD}}$ & 0.39 & 0.42 & 112 & 4 & 4.3 & 72 & 3.8 & 4.1 & 68 & 3.9 & 4.3 & 65 & 0.38 & 0.4 & 123 & 0.37 & 0.4 & 119 & 0.38 & 0.4 & 118 & 2083 \\
# $\overline{D}$ & 0.043 & 0.055 & 124 & 0.067 & 0.087 & 117 & 0.066 & 0.089 & 118 & 0.065 & 0.087 & 117 & 0.034 & 0.044 & 132 & 0.033 & 0.043 & 133 & 0.033 & 0.043 & 130 & 26 \\
# $t_{\mathrm{LLR}}$ & 0.01 & 0.014 & 329 & 0.0018 & 0.0027 & 413 & 0.00089 & 0.0014 & 467 & 0.014 & 0.02 & 339 & 0.0019 & 0.0029 & 419 & 0.00092 & 0.0014 & 456 & 0.0086 & 0.011 & 411 & - \\
# $\widetilde{D}$ & 0.031 & 0.04 & 200 & 0.034 & 0.045 & 203 & 0.022 & 0.03 & 214 & 0.059 & 0.079 & 202 & 0.021 & 0.028 & 222 & 0.017 & 0.022 & 222 & 0.026 & 0.034 & 220 & 324 \\
# $\widetilde{W}$ & 0.03 & 0.04 & 128 & 0.032 & 0.044 & 129 & 0.023 & 0.032 & 128 & 0.044 & 0.06 & 130 & 0.021 & 0.029 & 132 & 0.017 & 0.024 & 141 & 0.024 & 0.033 & 128 & 251 \\
# \bottomrule
# \end{tabular}
