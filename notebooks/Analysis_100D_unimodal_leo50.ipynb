# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [2]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/100D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-30 09:17:43.508057: Importing os...
# 2024-04-30 09:17:43.508204: Importing sys...
# Visible devices: [2]
# 2024-04-30 09:17:43.508445: Importing timer from timeit...
# 2024-04-30 09:17:43.508514: Setting env variables for tf import (only device(s) [2] will be available)...
# 2024-04-30 09:17:43.508642: Importing numpy...
# 2024-04-30 09:17:43.629777: Importing matplotlib...
# 2024-04-30 09:17:43.998586: Importing h5py...
# 2024-04-30 09:17:44.026344: Importing importlib.util...
# 2024-04-30 09:17:44.026453: Importing json...
# 2024-04-30 09:17:44.026515: Importing pandas...
# 2024-04-30 09:17:44.483229: Importing random...
# 2024-04-30 09:17:44.483384: Importing scipy utils...
# 2024-04-30 09:17:44.891744: Importing subprocess...
# 2024-04-30 09:17:44.891877: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-30 09:17:48.249189: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-30 09:17:49.388615: Importing timeit...
# 2024-04-30 09:17:49.388709: Importing tqdm...
# 2024-04-30 09:17:49.396490: Importing typing...
# 2024-04-30 09:17:49.396597: Setting tf configs...
# 2024-04-30 09:17:49.524669: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-30 09:17:54.264578: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #2, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-04-30 09:17:54.294004: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 10
ndims = 100
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (100,) (100,)
# sample from dist_1:  tf.Tensor(
# [[  1.91544564  -2.76561943  -3.43238751   7.63969004   0.40053677
#    -1.53371952   5.40518506  -2.46227562  -6.61238919   0.11070361
#    -2.43762175   7.60029826   5.00623137  -0.80830675  -0.86605178
#    -3.75058169  -0.69380601  -5.33493967   5.27270148  -5.77781631
#     1.12998499  -4.47808311  -0.44031361  -2.594015    -2.44992317
#     1.56227034  -1.8473778   -5.48289763  -5.48753345   1.93092494
#     1.79804844   1.37683738  -5.50962657  -4.87417033  -0.72193383
#    -5.10550792   4.48638515 -10.64465497  -2.19470468   6.38369957
#    -1.69169541   1.54297027   5.89350422   2.06708108  -0.90056118
#    -4.52907036  -5.69635496   1.55048682   6.4208089   -7.28610231
#    -5.08435585  -3.3389148    5.70948589   8.2946287   -5.84409661
#    -3.41249172   0.17450962   2.34921217   2.76600152  -1.35626994
#     4.67985208   3.74505089  -1.53903479  -0.9632767    7.66386021
#    -6.44508355   7.20013913   6.46012388   7.95496576  -1.07239111
#     2.63046089  -1.89127358   0.33629951   0.08755734  -4.28856395
#     1.78142513  -1.78334129   3.21504492  -1.34998805  -3.46388964
#    -4.46767048  -3.0690922    4.10920542  -1.12462778   0.43631843
#    -3.45204044   8.14946355  -3.75325945  -3.65654744  -9.30852399
#    -0.23871862   0.24312011  -6.63856444  -1.3104451   -2.44773711
#    -6.17225405  -2.40174311  -4.69520006   3.0814107    0.60472495]
#  [ -1.92269202  -4.08394393   0.28484768  -0.46825721   1.55903162
#     8.68423884   0.1292585   -3.09593241  -3.92592339  -0.78352017
#    -4.50758392   1.57655743  -2.79706173  -6.67679694  -3.89510347
#    -0.67142402  -2.3331029   -4.65618365   6.25135925   2.17635361
#     0.02229862  -5.25625134  -2.13850902  -4.05479007  -3.57251666
#     2.04591286  -0.14158755  -1.07676659   1.27568216   0.48903681
#    -1.65055387   3.28812542  -5.22640853  -0.92624111  -2.08771499
#    -3.93104846   2.93525398  -4.66540103  -1.34764653  -0.10523317
#    -1.50393875   4.51796248   4.56419684   0.78592104   1.87166036
#    -4.43561494  -5.41652595  -2.73506816   1.76755216  -5.15925416
#    -4.3965557   -5.11767262  -0.32448409   3.31767934  -3.42011481
#     0.12151845   1.33857006  -1.59406799  -1.52287611   5.92251815
#     0.35865444   2.59290903  -6.12798207  -6.88506817   6.79410239
#    -4.32117031   6.36315359   0.14532651   3.96861049  -2.69664263
#     4.07705442  -6.06308564   3.31986369   1.93834979  -1.93673443
#    -3.60680136   3.69535118   3.06222825  -0.16709543  -2.17638917
#     2.96497292  -0.41208625   7.46657337  -1.19022553  -4.69285676
#    -3.57289518   3.99034323  -0.81382891  -0.80077353  -2.56404593
#    -0.40735411   4.1613677   -2.13420216   3.955205     0.10965705
#    -0.3132572   -1.46848024  -6.0741503    2.39560734  -1.95077145]], shape=(2, 100), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[  1.91544564  -2.76561943  -3.43238751   7.63969004   0.40053677
#    -1.53371952   5.40518506  -2.46227562  -6.61238919   0.11070361
#    -2.43762175   7.60029826   5.00623137  -0.80830675  -0.86605178
#    -3.75058169  -0.69380601  -5.33493967   5.27270148  -5.77781631
#     1.12998499  -4.47808311  -0.44031361  -2.594015    -2.44992317
#     1.56227034  -1.8473778   -5.48289763  -5.48753345   1.93092494
#     1.79804844   1.37683738  -5.50962657  -4.87417033  -0.72193383
#    -5.10550792   4.48638515 -10.64465497  -2.19470468   6.38369957
#    -1.69169541   1.54297027   5.89350422   2.06708108  -0.90056118
#    -4.52907036  -5.69635496   1.55048682   6.4208089   -7.28610231
#    -5.08435585  -3.3389148    5.70948589   8.2946287   -5.84409661
#    -3.41249172   0.17450962   2.34921217   2.76600152  -1.35626994
#     4.67985208   3.74505089  -1.53903479  -0.9632767    7.66386021
#    -6.44508355   7.20013913   6.46012388   7.95496576  -1.07239111
#     2.63046089  -1.89127358   0.33629951   0.08755734  -4.28856395
#     1.78142513  -1.78334129   3.21504492  -1.34998805  -3.46388964
#    -4.46767048  -3.0690922    4.10920542  -1.12462778   0.43631843
#    -3.45204044   8.14946355  -3.75325945  -3.65654744  -9.30852399
#    -0.23871862   0.24312011  -6.63856444  -1.3104451   -2.44773711
#    -6.17225405  -2.40174311  -4.69520006   3.0814107    0.60472495]
#  [ -1.92269202  -4.08394393   0.28484768  -0.46825721   1.55903162
#     8.68423884   0.1292585   -3.09593241  -3.92592339  -0.78352017
#    -4.50758392   1.57655743  -2.79706173  -6.67679694  -3.89510347
#    -0.67142402  -2.3331029   -4.65618365   6.25135925   2.17635361
#     0.02229862  -5.25625134  -2.13850902  -4.05479007  -3.57251666
#     2.04591286  -0.14158755  -1.07676659   1.27568216   0.48903681
#    -1.65055387   3.28812542  -5.22640853  -0.92624111  -2.08771499
#    -3.93104846   2.93525398  -4.66540103  -1.34764653  -0.10523317
#    -1.50393875   4.51796248   4.56419684   0.78592104   1.87166036
#    -4.43561494  -5.41652595  -2.73506816   1.76755216  -5.15925416
#    -4.3965557   -5.11767262  -0.32448409   3.31767934  -3.42011481
#     0.12151845   1.33857006  -1.59406799  -1.52287611   5.92251815
#     0.35865444   2.59290903  -6.12798207  -6.88506817   6.79410239
#    -4.32117031   6.36315359   0.14532651   3.96861049  -2.69664263
#     4.07705442  -6.06308564   3.31986369   1.93834979  -1.93673443
#    -3.60680136   3.69535118   3.06222825  -0.16709543  -2.17638917
#     2.96497292  -0.41208625   7.46657337  -1.19022553  -4.69285676
#    -3.57289518   3.99034323  -0.81382891  -0.80077353  -2.56404593
#    -0.40735411   4.1613677   -2.13420216   3.955205     0.10965705
#    -0.3132572   -1.46848024  -6.0741503    2.39560734  -1.95077145]], shape=(2, 100), dtype=float64)

# %% [markdown]
# # Fixed $n=50000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 50_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 500000000
# batch_size 50000
# niter 10000
# niter * batch_size 500000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            50000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...      100           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True      100           0  float64   100  500000000         False
#
#    ncomp
# 0     10
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 50,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 2,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 5000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 50,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 50,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fgd from results/100D_unimodal/100D_50K/null_hypothesis/FGD.json
# Loading mmd from results/100D_unimodal/100D_50K/null_hypothesis/MMD.json
# Loading ks from results/100D_unimodal/100D_50K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 50
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714461487.215440  897867 service.cc:145] XLA service 0x7fd66c004860 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714461487.215487  897867 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1714461490.246754  897867 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fd7f817be20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 250 to 300 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fd7f817be20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# SKS metric calculation completed in 648.5846998619381 seconds.
# Saving sks to results/100D_unimodal/100D_50K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 50
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# SWD metric calculation completed in 331.9788601939799 seconds.
# Saving swd to results/100D_unimodal/100D_50K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.00926976172594006], [0.95, [9500, 500], 0.04515285181353794], [0.99, [9900, 100], 0.07042080162453229]]
# Computing time for metric fgd: 14444.185531597002
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.35153751137772815], [0.95, [9500, 500], 2.0823982124746863], [0.99, [9900, 100], 3.5170548255579206]]
# Computing time for metric mmd: 14560.019923421089
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.8958108169263536], [0.95, [9500, 500], 0.997857833145669], [0.99, [9900, 100], 1.0667315899327268]]
# Computing time for metric ks: 643.955146637978
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.894957161854922], [0.95, [9500, 500], 0.9995334864024824], [0.99, [9900, 100], 1.0658149627208622]]
# Computing time for metric sks: 648.5846998619381
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.3824960895632244], [0.95, [9500, 500], 0.4474351679659045], [0.99, [9900, 100], 0.4926197446319285]]
# Computing time for metric swd: 331.9788601939799
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fd7f81796c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fd7f817b6a0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fd7f817a340>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fd7f817a3e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fd7f817b7e0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fd7f817b880>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 1  $d_{\mathrm{MMD}}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 2      $\overline{D}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 3     $\widetilde{D}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 4     $\widetilde{W}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 5           $t_{\mu}$  results/100D_unimodal/100D_50K/null_hypothesis...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.00926976172594006], [0...
# 1  [[0.68, [6800, 3199], 0.35153751137772815], [0...
# 2  [[0.68, [6800, 3199], 0.8958108169263536], [0....
# 3  [[0.68, [6800, 3199], 0.894957161854922], [0.9...
# 4  [[0.68, [6800, 3199], 0.3824960895632244], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{4})$"
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{3})$"
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.009914633369757913 +/- 2.7542498565534435e-06
# sigma = 0.016595932804616447 +/- 0.00023469142432251658
# 68%CL = 0.00926976172594006, 95%CL = 0.04515285181353794, 99%CL = 0.07042080162453229
# mu = 0.009914633369757913 +/- 2.7542498565534435e-06
# sigma = 0.016595932804616447 +/- 0.00023469142432251658
# /tmp/ipykernel_897628/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_897628/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_897628/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.7435670429840684 seconds.
# mu = -0.0011605963671433982 +/- 0.01251611386033591
# sigma = 1.1187543903974595 +/- 0.010716945030823195
# 68%CL = 0.35153751137772815, 95%CL = 2.0823982124746863, 99%CL = 3.5170548255579206
# mu = -0.0011605963671433982 +/- 0.01251611386033591
# sigma = 1.1187543903974595 +/- 0.010716945030823195
# /tmp/ipykernel_897628/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_897628/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_897628/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_897628/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.155763457994908 seconds.
# mu = 0.8661633525537547 +/- 5.3495048618454594e-05
# sigma = 0.07314030941857888 +/- 0.0005625586769896341
# 68%CL = 0.8958108169263536, 95%CL = 0.997857833145669, 99%CL = 1.0667315899327268
# mu = 0.8661633525537547 +/- 5.3495048618454594e-05
# sigma = 0.07314030941857888 +/- 0.0005625586769896341
# /tmp/ipykernel_897628/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_897628/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_897628/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_897628/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.6085329949855804 seconds.
# mu = 0.8659977390756598 +/- 5.478935843622111e-05
# sigma = 0.07401983412317344 +/- 0.0005678732784268568
# 68%CL = 0.894957161854922, 95%CL = 0.9995334864024824, 99%CL = 1.0658149627208622
# mu = 0.8659977390756598 +/- 5.478935843622111e-05
# sigma = 0.07401983412317344 +/- 0.0005678732784268568
# /tmp/ipykernel_897628/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_897628/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_897628/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_897628/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 4.941617902950384 seconds.
# mu = 0.3675265963364645 +/- 1.8695506368414023e-05
# sigma = 0.04323830057762912 +/- 0.00036870810086477674
# 68%CL = 0.3824960895632244, 95%CL = 0.4474351679659045, 99%CL = 0.4926197446319285
# mu = 0.3675265963364645 +/- 1.8695506368414023e-05
# sigma = 0.04323830057762912 +/- 0.00036870810086477674
# /tmp/ipykernel_897628/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_897628/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_897628/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_897628/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2399729510070756 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fd7f81796c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fd7f817b6a0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fd7f817a340>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fd7f817a3e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fd7f817b7e0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fd7f817b880>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 1  $d_{\mathrm{MMD}}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 2      $\overline{D}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 3     $\widetilde{D}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 4     $\widetilde{W}$  results/100D_unimodal/100D_50K/null_hypothesis...
# 5           $t_{\mu}$  results/100D_unimodal/100D_50K/null_hypothesis...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.00926976172594006], [0...
# 1  [[0.68, [6800, 3199], 0.35153751137772815], [0...
# 2  [[0.68, [6800, 3199], 0.8958108169263536], [0....
# 3  [[0.68, [6800, 3199], 0.894957161854922], [0.9...
# 4  [[0.68, [6800, 3199], 0.3824960895632244], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/100D_unimodal/100D_50K/null_hypothesis...
# 1  results/100D_unimodal/100D_50K/null_hypothesis...
# 2  results/100D_unimodal/100D_50K/null_hypothesis...
# 3  results/100D_unimodal/100D_50K/null_hypothesis...
# 4  results/100D_unimodal/100D_50K/null_hypothesis...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = mean
# statistic = 164.38784389662766 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9989016109246587
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 404 calls to <function generate_and_clean_data_simple_1 at 0x7fd8f3018e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 41.16478013523043 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.995617284616528
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = mean
# WARNING:tensorflow:6 out of the last 405 calls to <function generate_and_clean_data_simple_1 at 0x7fd8f3018e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 10.334176958037375 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.982598933595622
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = mean
# statistic = 2.6129226030997748 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9320518133071427
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = mean
# WARNING:tensorflow:5 out of the last 5 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7fd7b40e77e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.6654990425154493 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7458510858896834
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = mean
# WARNING:tensorflow:6 out of the last 6 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7fd7b40e6a20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.17463850399693698 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1782597336999359
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = mean
# statistic = 0.04762760896931333 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.05334651574036602
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = mean
# statistic = 0.01923990283107656 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.8048405173990678
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.029296875 - deformation = mean
# statistic = 0.0313190956317029 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.3617995001824938
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0341796875 - deformation = mean
# statistic = 0.039370120585372904 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.13683217861466382
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.03662109375 - deformation = mean
# statistic = 0.04288178257142737 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.05159490370981594
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.037841796875 - deformation = mean
# statistic = 0.04677101686763084 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.03520663517122824
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0372314453125 - deformation = mean
# statistic = 0.0453113856731681 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.01652892561983471
# relative_error_metric = 0.0035048957253070987
# =======> statistic within required accuracy at 0.95 CL in 368.07637503300793 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.03692626953125 - deformation = mean
# statistic = 0.043526005431768634 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9706755528627689
# relative_error_metric = 0.4720587945825456
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.518463134765625 - deformation = mean
# statistic = 166.79065525430354 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9421986027348181
# relative_error_metric = 1.9983118698910722
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2776947021484375 - deformation = mean
# statistic = 43.04018117396901 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.8876443619058674
# relative_error_metric = 1.9934660340243546
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6573104858398438 - deformation = mean
# statistic = 11.43307462743042 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.7872410572009452
# relative_error_metric = 1.9755132508866247
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3471183776855469 - deformation = mean
# statistic = 3.207538710293929 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.6153960764837347
# relative_error_metric = 1.9140675150275814
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.19202232360839844 - deformation = mean
# statistic = 0.9967732508379609 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.354854834006748
# relative_error_metric = 1.73605249593721
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.11447429656982422 - deformation = mean
# statistic = 0.36465136086643246 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.0244086800415735
# relative_error_metric = 1.352559803216601
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.07570028305053711 - deformation = mean
# statistic = 0.1597351180776557 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.6885412476978767
# relative_error_metric = 0.7761200891004006
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.056313276290893555 - deformation = mean
# statistic = 0.09128172711868321 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.4158537364955571
# relative_error_metric = 0.25801607007987093
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.04661977291107178 - deformation = mean
# statistic = 0.06811685602868509 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.18834579282310226
# relative_error_metric = 0.03326092897592311
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.051466524600982666 - deformation = mean
# statistic = 0.07521054707508289 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.09882627467542529
# relative_error_metric = 0.0657790440495076
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.04904314875602722 - deformation = mean
# statistic = 0.07179864477004029 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.05066489299560892
# relative_error_metric = 0.01937629741133038
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0478314608335495 - deformation = mean
# statistic = 0.06763692065400509 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.025015593407007534
# relative_error_metric = 0.04032923221651598
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.04843730479478836 - deformation = mean
# statistic = 0.06938492405228942 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.012430060369447106
# relative_error_metric = 0.014818814712030155
# =======> statistic within required accuracy at 0.99 CL in 386.93124418507796 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 755.0076613120036 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_diag
# statistic = 1628.5160580737897 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998890975629025
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_diag
# statistic = 406.9217512851762 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995562012404
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_diag
# statistic = 101.60773271586335 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9982232535137046
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_diag
# statistic = 25.33275107970839 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9928831235337048
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_diag
# statistic = 6.299229387388818 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9715320735030526
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_diag
# statistic = 1.5564531709408083 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8872310638895156
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_diag
# statistic = 0.3842899912834349 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5794285312763547
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_diag
# statistic = 0.09204184904034476 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6835394798046216
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_diag
# statistic = 0.025491354137605626 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.5566344022475077
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0146484375 - deformation = cov_diag
# statistic = 0.05224631685289359 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.14565760953564283
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01220703125 - deformation = cov_diag
# statistic = 0.03681365698618623 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.20347810220214654
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.013427734375 - deformation = cov_diag
# statistic = 0.044420885421423424 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.01634332595042875
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0140380859375 - deformation = cov_diag
# statistic = 0.05075750049686604 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.11687265343764416
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.01373291015625 - deformation = cov_diag
# statistic = 0.04457404757884436 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.02197802197802198
# relative_error_metric = 0.012901465193005857
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.013885498046875 - deformation = cov_diag
# statistic = 0.046297775196532776 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.011049723756906077
# relative_error_metric = 0.025039158733570085
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0138092041015625 - deformation = cov_diag
# statistic = 0.04687227399619806 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.00554016620498615
# relative_error_metric = 0.037368537506051666
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.01377105712890625 - deformation = cov_diag
# statistic = 0.04762614545619079 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.0027739251040221915
# relative_error_metric = 0.053315808867009984
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.013751983642578125 - deformation = cov_diag
# statistic = 0.04547941691188106 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.0013879250520471894
# relative_error_metric = 0.0072063758953775335
# =======> statistic within required accuracy at 0.95 CL in 504.15336049103644 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.013742446899414062 - deformation = cov_diag
# statistic = 0.04537111752985371 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9890361764331053
# relative_error_metric = 0.4326672237167034
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.506871223449707 - deformation = cov_diag
# statistic = 1637.4268363986887 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9781919029305104
# relative_error_metric = 1.9998279794330893
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2603068351745605 - deformation = cov_diag
# statistic = 413.65502325244745 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.956854269005848
# relative_error_metric = 1.999319154259071
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6370246410369873 - deformation = cov_diag
# statistic = 105.53096601298216 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9155307811094644
# relative_error_metric = 1.9973325804234687
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3253835439682007 - deformation = cov_diag
# statistic = 27.46558075792381 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.8379074766371566
# relative_error_metric = 1.9897703664096267
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16956299543380737 - deformation = cov_diag
# statistic = 7.428161826137125 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.7001191732336591
# relative_error_metric = 1.9624351400149587
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.09165272116661072 - deformation = cov_diag
# statistic = 2.1534118062817122 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.478441103075803
# relative_error_metric = 1.8733343483242937
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.05269758403301239 - deformation = cov_diag
# statistic = 0.7030953751052187 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.1726405477811432
# relative_error_metric = 1.6358405745449036
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.033220015466213226 - deformation = cov_diag
# statistic = 0.2742682142860971 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.8294952004499305
# relative_error_metric = 1.1827903022846435
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.023481231182813644 - deformation = cov_diag
# statistic = 0.1354238144854127 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.5232574955052238
# relative_error_metric = 0.6315736023541295
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.018611839041113853 - deformation = cov_diag
# statistic = 0.08339722282422476 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.3010044573785663
# relative_error_metric = 0.16872432533438808
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.016177142970263958 - deformation = cov_diag
# statistic = 0.06441146002521905 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.13996937708919582
# relative_error_metric = 0.08913803752581824
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.017394491005688906 - deformation = cov_diag
# statistic = 0.0738112629876098 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.07252241796136143
# relative_error_metric = 0.0470139753208814
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.016785816987976432 - deformation = cov_diag
# statistic = 0.06869897803595264 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.03561547882045299
# relative_error_metric = 0.02475310977032427
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.01709015399683267 - deformation = cov_diag
# statistic = 0.06823767244464674 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.017650580937340853
# relative_error_metric = 0.03148930052116912
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.017242322501260787 - deformation = cov_diag
# statistic = 0.07308888153997735 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.008864405947329122
# relative_error_metric = 0.03718327372218575
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.017166238249046728 - deformation = cov_diag
# statistic = 0.07144911344134915 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.00444204700062723
# relative_error_metric = 0.014496545181398434
# =======> statistic within required accuracy at 0.99 CL in 469.98238958697766 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 974.1357880770229 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_off_diag
# statistic = 680.860784414121 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997347483736454
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_off_diag
# statistic = 923.9433390079564 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999804530674521
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_off_diag
# statistic = 1062.3769734010934 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998300003333973
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_off_diag
# statistic = 1910.9069596242 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999054861678243
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_off_diag
# statistic = 1343.9462656655828 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998656156544115
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_off_diag
# statistic = 680.9322753145041 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997347762204973
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_off_diag
# statistic = 287.73066663694715 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9993723885225136
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_off_diag
# statistic = 106.38302800334736 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9983029738382923
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_off_diag
# statistic = 35.182535484296146 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9948730269914126
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = cov_off_diag
# statistic = 10.604607488001097 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9830408007794382
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = cov_off_diag
# statistic = 2.9871965578050763 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9404384578237417
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.001220703125 - deformation = cov_off_diag
# statistic = 0.793164926882983 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7845549601310142
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0006103515625 - deformation = cov_off_diag
# statistic = 0.2035907499654495 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2739053146998014
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00030517578125 - deformation = cov_off_diag
# statistic = 0.05062763445466294 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.11431937452885173
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.000152587890625 - deformation = cov_off_diag
# statistic = 0.017304900533728004 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.8917372218255614
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0002288818359375 - deformation = cov_off_diag
# statistic = 0.02888837508501752 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.4393356893127803
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00026702880859375 - deformation = cov_off_diag
# statistic = 0.040017547770273706 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.12058893860679505
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.000286102294921875 - deformation = cov_off_diag
# statistic = 0.044835095016846266 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.007062207948595701
#
# ------------ 19 - 0.95 CL ------------
# eps = 0.0002956390380859375 - deformation = cov_off_diag
# statistic = 0.04604074101145172 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.019472622372006632
#
# ------------ 20 - 0.95 CL ------------
# eps = 0.00029087066650390625 - deformation = cov_off_diag
# statistic = 0.045290200048374446 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.01652892561983471
# relative_error_metric = 0.0030372313186912098
# =======> statistic within required accuracy at 0.95 CL in 541.2888980939751 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0002884864807128906 - deformation = cov_off_diag
# statistic = 0.04582812028038495 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9997692241305733
# relative_error_metric = 0.42310381793066915
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5001442432403564 - deformation = cov_off_diag
# statistic = 680.8565411688493 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.999538501512504
# relative_error_metric = 1.9995863239051614
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2502163648605347 - deformation = cov_off_diag
# statistic = 923.8019385779241 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9990772159567283
# relative_error_metric = 1.9996951059270922
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6252524256706238 - deformation = cov_off_diag
# statistic = 1061.6740434613107 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9981552830511389
# relative_error_metric = 1.9997346977394475
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31277045607566833 - deformation = cov_off_diag
# statistic = 1911.1067275607868 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9963139659470237
# relative_error_metric = 1.9998526127173823
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.1565294712781906 - deformation = cov_off_diag
# statistic = 1345.9001961306078 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9926414937463623
# relative_error_metric = 1.9997907211324268
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.07840897887945175 - deformation = cov_off_diag
# statistic = 683.7768562880522 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9853369366145346
# relative_error_metric = 1.9995880904758487
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.03934873268008232 - deformation = cov_off_diag
# statistic = 290.6176503516147 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9708873138105278
# relative_error_metric = 1.9990309777577708
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.019818609580397606 - deformation = cov_off_diag
# statistic = 108.73328149929198 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9426100159195325
# relative_error_metric = 1.997411088037068
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.010053548030555248 - deformation = cov_off_diag
# statistic = 36.93071511982766 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.8884217683092932
# relative_error_metric = 1.9923871740830852
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0051710172556340694 - deformation = cov_off_diag
# statistic = 11.759906240618966 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.7886353817895386
# relative_error_metric = 1.9761897363029526
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.00272975186817348 - deformation = cov_off_diag
# statistic = 3.67031812718294 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.617675680491791
# relative_error_metric = 1.9246985122835265
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0015091191744431853 - deformation = cov_off_diag
# statistic = 1.191578036120251 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.35806503526416
# relative_error_metric = 1.776795985801776
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.000898802827578038 - deformation = cov_off_diag
# statistic = 0.43561960491203966 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.0280836230955057
# relative_error_metric = 1.4433582716723792
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0005936446541454643 - deformation = cov_off_diag
# statistic = 0.19276352722312998 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.691865781342302
# relative_error_metric = 0.9297113253989582
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.00044106556742917746 - deformation = cov_off_diag
# statistic = 0.10644042943229264 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.41828156635254793
# relative_error_metric = 0.4073207858220477
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.00036477602407103404 - deformation = cov_off_diag
# statistic = 0.07227896167501084 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.2335647394407772
# relative_error_metric = 0.02604293108150514
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.00032663125239196233 - deformation = cov_off_diag
# statistic = 0.0616511207868939 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.11033951471904473
# relative_error_metric = 0.13280159291267624
#
# ------------ 19 - 0.99 CL ------------
# eps = 0.0003457036382314982 - deformation = cov_off_diag
# statistic = 0.06615555647922217 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.053688759443798306
# relative_error_metric = 0.06245949452056556
#
# ------------ 20 - 0.99 CL ------------
# eps = 0.0003552398311512661 - deformation = cov_off_diag
# statistic = 0.06944467298330205 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.026488841462591655
# relative_error_metric = 0.013958107159285556
#
# ------------ 21 - 0.99 CL ------------
# eps = 0.0003600079276111501 - deformation = cov_off_diag
# statistic = 0.07109554638790266 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.013332712759936888
# relative_error_metric = 0.009535926737045
# =======> statistic within required accuracy at 0.99 CL in 562.3446067019831 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1103.6335390390595 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_up
# statistic = 42908091.82352633 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999999995790738
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_up
# statistic = 148463.87432246373 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999987834659902
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_up
# statistic = 6805.737617395833 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999734620669876
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_up
# statistic = 819.9319522675894 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997797360363765
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_up
# statistic = 146.31243579745265 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9987659580284085
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_up
# statistic = 31.129854175095783 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9942065319472664
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_up
# statistic = 7.1933919570642315 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.975048657979897
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_up
# statistic = 1.7376763473458516 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8986939369518343
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.4263411180575318 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6169380335796446
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.10629712219322429 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8074517117705977
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_up
# statistic = 0.0301781368238428 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.3975711791538704
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_up
# statistic = 0.06080195674443913 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.29539206655898415
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0030517578125 - deformation = power_abs_up
# statistic = 0.04187878510888567 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.07523854130356375
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00335693359375 - deformation = power_abs_up
# statistic = 0.05113452652496277 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.12424628886241143
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.003204345703125 - deformation = power_abs_up
# statistic = 0.04745295657068737 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.04878048780487805
# relative_error_metric = 0.04967517258974084
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0031280517578125 - deformation = power_abs_up
# statistic = 0.04418683357601734 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.024096385542168676
# relative_error_metric = 0.02162573627405088
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00316619873046875 - deformation = power_abs_up
# statistic = 0.04454683357176476 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.011976047904191617
# relative_error_metric = 0.013512159806805158
# =======> statistic within required accuracy at 0.95 CL in 454.8845679080114 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.003185272216796875 - deformation = power_abs_up
# statistic = 0.04643009933460075 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9974534045465115
# relative_error_metric = 0.4106207499131213
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5015926361083984 - deformation = power_abs_up
# statistic = 43221991.26966902 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.994913285994403
# relative_error_metric = 1.999999993482873
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2523889541625977 - deformation = power_abs_up
# statistic = 150131.93807004447 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9898523810066346
# relative_error_metric = 1.9999981237631517
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6277871131896973 - deformation = power_abs_up
# statistic = 6914.65573353365 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9798072163507137
# relative_error_metric = 1.9999592632882042
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31548619270324707 - deformation = power_abs_up
# statistic = 841.2880338403195 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9600181055734491
# relative_error_metric = 1.9996652042836867
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.15933573246002197 - deformation = power_abs_up
# statistic = 153.1385580710665 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.921603432783819
# relative_error_metric = 1.99816144452779
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08126050233840942 - deformation = power_abs_up
# statistic = 33.92020760498424 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.8491210610087065
# relative_error_metric = 1.991712915597543
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04222288727760315 - deformation = power_abs_up
# statistic = 8.465345942554155 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.7194097050165884
# relative_error_metric = 1.9669996597915196
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.022704079747200012 - deformation = power_abs_up
# statistic = 2.3541431463908293 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.5078637393123653
# relative_error_metric = 1.8838210859611673
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.012944675981998444 - deformation = power_abs_up
# statistic = 0.756784313934142 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.210097347483169
# relative_error_metric = 1.6594759858225885
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.00806497409939766 - deformation = power_abs_up
# statistic = 0.2916024720257358 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.8674835635512332
# relative_error_metric = 1.2219196195373652
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.005625123158097267 - deformation = power_abs_up
# statistic = 0.140199269699912 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.5538573100255917
# relative_error_metric = 0.6626003650705374
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.004405197687447071 - deformation = power_abs_up
# statistic = 0.08612109389173536 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.3214360865769634
# relative_error_metric = 0.20058901440313162
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.003795234952121973 - deformation = power_abs_up
# statistic = 0.06566165650168533 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.14876354995756744
# relative_error_metric = 0.06994501992950207
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.004100216319784522 - deformation = power_abs_up
# statistic = 0.07594169944338636 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.07725495533047749
# relative_error_metric = 0.07544142493564147
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.0039477256359532475 - deformation = power_abs_up
# statistic = 0.07175284631320658 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.039388211291201035
# relative_error_metric = 0.01873827826739906
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0038714802940376103 - deformation = power_abs_up
# statistic = 0.06765691046605188 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.019502067754270387
# relative_error_metric = 0.040033849295926884
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.003909602964995429 - deformation = power_abs_up
# statistic = 0.06807728894391236 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.009703723210256417
# relative_error_metric = 0.033841804908664536
#
# ------------ 19 - 0.99 CL ------------
# eps = 0.003928664300474338 - deformation = power_abs_up
# statistic = 0.06857564058592508 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.004840119809394498
# relative_error_metric = 0.0265497592494262
#
# ------------ 20 - 0.99 CL ------------
# eps = 0.003938194968213793 - deformation = power_abs_up
# statistic = 0.07047618694251286 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 0.002422991797346333
# relative_error_metric = 0.00078618171394357
# =======> statistic within required accuracy at 0.99 CL in 526.0239185770042 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 980.9085198990069 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_down
# statistic = 1.0 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8271913941192843
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_down
# statistic = 1020.850550948687 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998230853488932
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_down
# statistic = 587.6752054636647 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9996926915926958
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_down
# statistic = 241.37236664567118 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9992518711664753
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_down
# statistic = 79.305655443207 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9977238869882377
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_down
# statistic = 22.903466443041587 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9921297484204359
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_down
# statistic = 6.165098018791215 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9709172123610905
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_down
# statistic = 1.597825498487908 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8900707320817622
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.4112045780838972 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6042325698636184
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.10414435378958926 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7902559426713835
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_down
# statistic = 0.03163532077363753 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.3520732577547495
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_down
# statistic = 0.057613892831794467 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.24251115594372386
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0030517578125 - deformation = power_abs_down
# statistic = 0.04417866617667472 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.021810569411122086
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00335693359375 - deformation = power_abs_down
# statistic = 0.051227289023198244 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.12605163588524199
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.003204345703125 - deformation = power_abs_down
# statistic = 0.04829430794151833 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.04878048780487805
# relative_error_metric = 0.06723491941787801
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0031280517578125 - deformation = power_abs_down
# statistic = 0.04763471160942184 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.024691358024691357
# relative_error_metric = 0.053495526864320714
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00308990478515625 - deformation = power_abs_down
# statistic = 0.04628220099263558 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.012422360248447204
# relative_error_metric = 0.02470276211228676
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.003070831298828125 - deformation = power_abs_down
# statistic = 0.04816918526613606 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.006230529595015576
# relative_error_metric = 0.06464354073246209
#
# ------------ 19 - 0.95 CL ------------
# eps = 0.0030612945556640625 - deformation = power_abs_down
# statistic = 0.042386618287248545 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.003110419906687403
# relative_error_metric = 0.06319968633816396
#
# ------------ 20 - 0.95 CL ------------
# eps = 0.0030660629272460938 - deformation = power_abs_down
# statistic = 0.04418330901143233 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.001554001554001554
# relative_error_metric = 0.02170549513550647
#
# ------------ 21 - 0.95 CL ------------
# eps = 0.0030684471130371094 - deformation = power_abs_down
# statistic = 0.04526807190825584 - next threshold = 0.04515285181353794 at 0.95 CL
# relative_error_eps = 0.000777302759424796
# relative_error_metric = 0.0025485272650477998
# =======> statistic within required accuracy at 0.95 CL in 543.0438128070673 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0030672550201416016 - deformation = power_abs_down
# statistic = 0.045210947824850814 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9975477003495694
# relative_error_metric = 0.43603688294479875
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.501533627510071 - deformation = power_abs_down
# statistic = 1.0 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9951014071079574
# relative_error_metric = 1.7368481572194503
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2523004412651062 - deformation = power_abs_down
# statistic = 1021.7681370826624 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.990226751798002
# relative_error_metric = 1.9997243368785365
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6276838481426239 - deformation = power_abs_down
# statistic = 590.3933152219246 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9805485554935283
# relative_error_metric = 1.9995229457978314
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31537555158138275 - deformation = power_abs_down
# statistic = 244.64222660413756 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9614718253129864
# relative_error_metric = 1.9988489225649584
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.15922140330076218 - deformation = power_abs_down
# statistic = 81.91216848683587 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.9244000153337513
# relative_error_metric = 1.996564109417098
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08114432916045189 - deformation = power_abs_down
# statistic = 24.580304502804644 - next threshold = 0.07042080162453229 at 0.99 CL
# relative_error_eps = 1.8543072167570767
# relative_error_metric = 1.9885730256201624
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.042105792090296745 - deformation = power_abs_down
# ...
# eps = 0.04195794463157654 - deformation = power_abs_down
# statistic = 3.319855880457031 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 1.739884911292706
# relative_error_metric = 1.4831497503720472
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.02243809401988983 - deformation = power_abs_down
# statistic = 1.8298105352664518 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 1.5396427553500016
# relative_error_metric = 1.1515443991653718
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.012678168714046478 - deformation = power_abs_down
# statistic = 1.0824577632873849 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 1.2515603241748137
# relative_error_metric = 0.7489638010698735
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.007798206061124802 - deformation = power_abs_down
# statistic = 0.727501185097749 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.9107424370149565
# relative_error_metric = 0.3850133781704071
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.005358224734663963 - deformation = power_abs_down
# statistic = 0.5696365375606451 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.5896189737801838
# relative_error_metric = 0.1450060483892803
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.004138234071433544 - deformation = power_abs_down
# statistic = 0.5020852245950412 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.3457789433186812
# relative_error_metric = 0.019031733540989162
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0035282387398183346 - deformation = power_abs_down
# statistic = 0.47290165276280594 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.1591332407048873
# relative_error_metric = 0.040844443059113666
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0038332364056259394 - deformation = power_abs_down
# statistic = 0.4870649001937892 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.07652230957521211
# relative_error_metric = 0.011340066351917748
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.003985735238529742 - deformation = power_abs_down
# statistic = 0.49447067292946695 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.0390073886552046
# relative_error_metric = 0.003750271028081058
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.003909485822077841 - deformation = power_abs_down
# statistic = 0.49073939463449395 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.01931533414114015
# relative_error_metric = 0.003824340309354835
# =======> statistic within required accuracy at 0.99 CL in 127.47688653692603 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 254.78517086803913 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 12.175753495380432 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.85821802085075
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 3.4603689022581716 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5420085962086139
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 0.9625837290986815 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7306973859786231
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 0.44614223684674087 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.002893831272366845
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_normal
# statistic = 0.6301138024169015 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.3390632620364331
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.390625 - deformation = random_normal
# statistic = 0.5192381553652086 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.14855688197099343
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.3515625 - deformation = random_normal
# statistic = 0.47906133942656043 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.06827046018697847
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.33203125 - deformation = random_normal
# statistic = 0.4622964427315432 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.032671778337448935
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.322265625 - deformation = random_normal
# statistic = 0.4541832133736248 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.03076923076923077
# relative_error_metric = 0.014968739651680014
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.3173828125 - deformation = random_normal
# statistic = 0.4513581255496842 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.015503875968992248
# relative_error_metric = 0.008729387751515652
# =======> statistic within required accuracy at 0.95 CL in 75.79194995900616 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.31494140625 - deformation = random_normal
# statistic = 0.4479574812268987 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 1.7629765732659624
# relative_error_metric = 0.09496777548329285
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.657470703125 - deformation = random_normal
# statistic = 13.505802555085367 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 1.5761806981519506
# relative_error_metric = 1.8592356383927988
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.4862060546875 - deformation = random_normal
# statistic = 4.782307567447036 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 1.3005760759064724
# relative_error_metric = 1.6264443352583173
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.90057373046875 - deformation = random_normal
# statistic = 1.8658039938909012 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.9635952799397439
# relative_error_metric = 1.1644932391318705
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.607757568359375 - deformation = random_normal
# statistic = 0.9219737067480367 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.6346948900281131
# relative_error_metric = 0.6070351332352975
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.4613494873046875 - deformation = random_normal
# statistic = 0.6166736282779585 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.3771990171990172
# relative_error_metric = 0.22366289509259954
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.38814544677734375 - deformation = random_normal
# statistic = 0.5179633441520861 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.20823612392165375
# relative_error_metric = 0.05015638951697154
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.3515434265136719 - deformation = random_normal
# statistic = 0.47927570972728967 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.09896598849952296
# relative_error_metric = 0.027459815445760444
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.3698444366455078 - deformation = random_normal
# statistic = 0.4973626419389038 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.05073833666036514
# relative_error_metric = 0.009581781193914105
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.36069393157958984 - deformation = random_normal
# statistic = 0.4867669086665942 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.025051401716654157
# relative_error_metric = 0.011952043548117006
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.36526918411254883 - deformation = random_normal
# statistic = 0.492859023243338 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.012604641844914957
# relative_error_metric = 0.00048560886182345305
# =======> statistic within required accuracy at 0.99 CL in 83.03923668793868 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 158.8312189609278 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_uniform
# statistic = 4.530092232990078 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6404357971952335
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_uniform
# statistic = 1.2401550843941533 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9394696554091224
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_uniform
# statistic = 0.48811395050684336 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.08696236624613704
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_uniform
# statistic = 0.39649905266424557 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.12071110296635647
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_uniform
# statistic = 0.4230997016309187 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.05590922818808267
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.546875 - deformation = random_uniform
# statistic = 0.44882782549595124 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.0031076983880982214
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.5078125 - deformation = random_uniform
# statistic = 0.4361768122886329 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.025482578165199693
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.52734375 - deformation = random_uniform
# statistic = 0.44267782818637164 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.01068929405614249
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.537109375 - deformation = random_uniform
# statistic = 0.4451794311734769 - next threshold = 0.4474351679659045 at 0.95 CL
# relative_error_eps = 0.018018018018018018
# relative_error_metric = 0.005054223389584834
# =======> statistic within required accuracy at 0.95 CL in 66.95555504399817 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.5419921875 - deformation = random_uniform
# statistic = 0.4482808184983208 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 1.6088105726872246
# relative_error_metric = 0.09424784694803041
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.77099609375 - deformation = random_uniform
# statistic = 5.480453988573082 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 1.3456153279292558
# relative_error_metric = 1.6701063695943357
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.656494140625 - deformation = random_uniform
# statistic = 2.084389655510028 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 1.01388117712382
# relative_error_metric = 1.2353621300647297
#
# ------------ 4 - 0.99 CL ------------
# eps = 1.0992431640625 - deformation = random_uniform
# statistic = 0.9875541987165 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.6790628486426181
# relative_error_metric = 0.6687517454400498
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.82061767578125 - deformation = random_uniform
# statistic = 0.6391877015543954 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.4089585666293393
# relative_error_metric = 0.2589980432030806
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.681304931640625 - deformation = random_uniform
# statistic = 0.523369295136639 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.22776599725583135
# relative_error_metric = 0.06053126421858835
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.6116485595703125 - deformation = random_uniform
# statistic = 0.48132644650854733 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.1077476839558624
# relative_error_metric = 0.023190805048802273
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.6464767456054688 - deformation = random_uniform
# statistic = 0.4997898343203951 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.055365210272581185
# relative_error_metric = 0.014449859897636209
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.6290626525878906 - deformation = random_uniform
# statistic = 0.4902760927982697 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.02730467289719626
# relative_error_metric = 0.004768871215868168
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.6377696990966797 - deformation = random_uniform
# statistic = 0.4955822635051719 - next threshold = 0.4926197446319285 at 0.99 CL
# relative_error_eps = 0.013746170118265242
# relative_error_metric = 0.005995775861310404
# =======> statistic within required accuracy at 0.99 CL in 74.30848000000697 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 141.26406683493406 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-04-30T09:34:38.330622', 'fgd_cov_diag_2024-04-30T09:47:13.344109', 'fgd_cov_off_diag_2024-04-30T10:03:27.483890', 'fgd_power_abs_up_2024-04-30T10:21:51.120328', 'fgd_power_abs_down_2024-04-30T10:38:12.032240', 'fgd_random_normal_2024-04-30T10:55:52.523734', 'fgd_random_uniform_2024-04-30T11:09:53.716767', 'mmd_mean_2024-04-30T11:19:30.698301', 'mmd_cov_diag_2024-04-30T11:30:09.724069', 'mmd_cov_off_diag_2024-04-30T11:41:20.465843', 'mmd_power_abs_up_2024-04-30T11:56:26.098739', 'mmd_power_abs_down_2024-04-30T12:09:44.767257', 'mmd_random_normal_2024-04-30T12:23:22.059956', 'mmd_random_uniform_2024-04-30T12:30:02.496447', 'ks_mean_2024-04-30T12:37:04.466807', 'ks_cov_diag_2024-04-30T12:40:24.169762', 'ks_cov_off_diag_2024-04-30T12:43:57.669353', 'ks_power_abs_up_2024-04-30T12:48:48.887660', 'ks_power_abs_down_2024-04-30T12:52:53.087617', 'ks_random_normal_2024-04-30T12:56:58.440960', 'ks_random_uniform_2024-04-30T12:59:35.246878', 'sks_mean_2024-04-30T13:01:58.869777', 'sks_cov_diag_2024-04-30T13:06:01.579565', 'sks_cov_off_diag_2024-04-30T13:10:37.866017', 'sks_power_abs_up_2024-04-30T13:16:51.073979', 'sks_power_abs_down_2024-04-30T13:21:59.523940', 'sks_random_normal_2024-04-30T13:27:14.362382', 'sks_random_uniform_2024-04-30T13:30:35.566674', 'swd_mean_2024-04-30T13:33:36.440827', 'swd_cov_diag_2024-04-30T13:36:57.757687', 'swd_cov_off_diag_2024-04-30T13:40:53.316052', 'swd_power_abs_up_2024-04-30T13:46:01.918632', 'swd_power_abs_down_2024-04-30T13:50:14.899910', 'swd_random_normal_2024-04-30T13:54:29.694784', 'swd_random_uniform_2024-04-30T13:57:08.535575'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normnal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.005 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[18], line 7
#       5 if result == {}:
#       6     print(f"Computing exclusion limits for lr with {deformation} deformation.")
# ----> 7     result = compute_exclusion_LR_bisection(dist_1,
#       8                                             metric_config = metrics_config[unique_key]["lr"],
#       9                                             test_kwargs = test_kwargs,
#      10                                             model_dir = model_dir,
#      11                                             cl_list = [0.95, 0.99],
#      12                                             deformation = deformation,
#      13                                             seed_dist = 0,
#      14                                             x_tol = 0.01,
#      15                                             fn_tol = 0.01,
#      16                                             eps_min = 0.,
#      17                                             eps_max = 0.01,
#      18                                             max_iterations = 100,
#      19                                             save = True,
#      20                                             verbose = True)
#      21 else:
#      22     print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/utils_func/optimizers_deformations.py:304, in compute_exclusion_LR_bisection(reference_distribution, metric_config, test_kwargs, model_dir, cl_list, deformation, seed_dist, x_tol, fn_tol, eps_min, eps_max, max_iterations, save, verbose)
#     299 TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
#     300                                                    dist_2_input = dist_2,
#     301                                                    **test_kwargs_null)
#     303 LRMetric_null = GMetrics.LRMetric(TwoSampleTestInputs, **metric_kwargs_null)
# --> 304 LRMetric_null.Test_tf(max_vectorize = max_vectorize)
#     306 null_file = null_file_base.replace(".json", "_" + deformation + "_" + str(format(eps, '.6f')) + ".json")
#     307 print("Saving", metric_name, "to", null_file)
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:704, in LRMetric.Test_tf(self, max_vectorize)
#     702 lik_ratio_list: DataTypeTF
#     703 lik_ratio_norm_list: DataTypeTF
# --> 704 logprob_ref_ref_sum_list, logprob_ref_alt_sum_list, logprob_alt_alt_sum_list, lik_ratio_list, lik_ratio_norm_list = compute_test(max_vectorize = max_vectorize) # type: ignore
#     706 end_calculation()
#     708 timestamp: str = datetime.now().isoformat()
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:677, in LRMetric.Test_tf.<locals>.compute_test(max_vectorize)
#     674     res = res.write(i, chunk_result)
#     675     return i+1, res
# --> 677 _, res = tf.while_loop(lambda i, _: i < nchunks, body, [0, res])
#     679 for i in range(nchunks):
#     680     res_i = res.read(i)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/util/deprecation.py:660, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     652           _PRINTED_WARNING[(func, arg_name)] = True
#     653         _log_deprecation(
#     654             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     655             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     658             'in a future version' if date is None else
#     659             ('after %s' % date), instructions)
# --> 660 return func(*args, **kwargs)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py:241, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      35 @tf_export("while_loop", v1=[])
#      36 @deprecation.deprecated_arg_values(
#      37     None,
#    (...)
#      52                   maximum_iterations=None,
#      53                   name=None):
#      54   """Repeat `body` while the condition `cond` is true.
#      55
#      56   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#     245       shape_invariants=shape_invariants,
#     246       parallel_iterations=parallel_iterations,
#     247       back_prop=back_prop,
#     248       swap_memory=swap_memory,
#     249       name=name,
#     250       maximum_iterations=maximum_iterations,
#     251       return_same_structure=True)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py:488, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     485 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                         list(loop_vars))
#     487 while cond(*loop_vars):
# --> 488   loop_vars = body(*loop_vars)
#     489   if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490     packed = True
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:673, in LRMetric.Test_tf.<locals>.compute_test.<locals>.body(i, res)
#     671 end = tf.minimum(start + max_iter_per_chunk, niter)
#     672 conditional_tf_print(tf.logical_and(tf.logical_or(tf.math.logical_not(tf.equal(start,0)),tf.math.logical_not(tf.equal(end,niter))), self.verbose), "Iterating from", start, "to", end, "out of", niter, ".") # type: ignore
# --> 673 chunk_result = batched_test(start, end) # type: ignore
#     674 res = res.write(i, chunk_result)
#     675 return i+1, res
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:587, in LRMetric.Test_tf.<locals>.batched_test(start, end)
#     583 def batched_test(start: tf.Tensor,
#     584                  end: tf.Tensor
#     585                 ) -> DataTypeTF:
#     586     # Define the loop body to vectorize over ndims*chunk_size
# --> 587     dist_1_k: DataTypeTF = set_dist_num_from_symb(dist_1_symb, nsamples = batch_size * (end - start)) # type: ignore
#     588     if null:
#     589         dist_2_k: DataTypeTF = set_dist_num_from_symb(dist_1_symb, nsamples = batch_size * (end - start)) # type: ignore
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:527, in LRMetric.Test_tf.<locals>.set_dist_num_from_symb(dist, nsamples)
#     524 def set_dist_num_from_symb(dist: DistTypeTF,
#     525                            nsamples: int,
#     526                           ) -> tf.Tensor:
# --> 527     dist_num: tf.Tensor = generate_and_clean_data(dist, nsamples, self.Inputs.batch_size_gen, dtype = self.Inputs.dtype, seed_generator = self.Inputs.seed_generator, strategy = self.Inputs.strategy) # type: ignore
#     528     return dist_num
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/utils.py:542, in generate_and_clean_data(dist, n_samples, batch_size, dtype, seed_generator, strategy)
#     535     return generate_and_clean_data_mirror(dist = dist,
#     536                                           n_samples = n_samples,
#     537                                           batch_size = batch_size,
#     538                                           dtype = dtype,
#     539                                           seed_generator = seed_generator,
#     540                                           strategy = strategy)
#     541 else:
# --> 542     return generate_and_clean_data_simple(dist = dist,
#     543                                           n_samples = n_samples,
#     544                                           batch_size = batch_size,
#     545                                           dtype = dtype,
#     546                                           seed_generator = seed_generator)
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/utils.py:414, in generate_and_clean_data_simple(*args, **kwargs)
#     413 def generate_and_clean_data_simple(*args, **kwargs):
# --> 414     return generate_and_clean_data_simple_1(*args, **kwargs)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InternalError: Could not synchronize CUDA stream: CUDA_ERROR_ILLEGAL_ADDRESS: an illegal memory access was encountered [Op:__inference_generate_and_clean_data_simple_1_3886091]

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normnal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{} & \multicolumn{3}{c}{$\mu$-deformation} & \multicolumn{3}{c}{$\sigma$-deformation} & \multicolumn{3}{c}{$\Sigma_{ij}-\Sigma_{ii}$-deformation} & \multicolumn{3}{c}{$\Sigma_{ij}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) \\
# \midrule
# $t_{\mathrm{LLR}}$ & 0.01 & 0.014 & 329 & 0.0018 & 0.0027 & 413 & 0.0022 & 0.0034 & 662 & 0.014 & 0.02 & 339 \\
# $d_{\mathrm{MMD}}$ & 0.021 & 0.03 & 298 & 0.15 & 0.2 & 267 & 0.18 & 0.24 & 270 & 0.12 & 0.16 & 271 \\
# $\widetilde{W}$ & 0.03 & 0.04 & 128 & 0.032 & 0.044 & 129 & 0.065 & 0.091 & 163 & 0.044 & 0.06 & 130 \\
# $\widetilde{D}$ & 0.031 & 0.04 & 200 & 0.034 & 0.045 & 203 & 0.063 & 0.086 & 263 & 0.059 & 0.079 & 202 \\
# $d_{\mathrm{FGD}}$ & 0.035 & 0.045 & 218 & 0.026 & 0.034 & 232 & 0.035 & 0.044 & 236 & 0.039 & 0.051 & 226 \\
# $\overline{D}$ & 0.043 & 0.055 & 124 & 0.067 & 0.087 & 117 & 1.1 & 1.1 & 104 & 0.065 & 0.087 & 117 \\
# $\overline{\|\cdot\|}_{F}$ & 0.056 & 0.073 & 73 & 0.034 & 0.044 & 75 & 0.033 & 0.041 & 121 & 0.14 & 0.19 & 64 \\
# \toprule
# \multicolumn{1}{c}{} & \multicolumn{3}{c}{$\mu-\sigma$-deformation} & \multicolumn{3}{c}{$\mu-\Sigma_{ij}-\Sigma_{ii}$-deformation} & \multicolumn{3}{c}{$\mu-\Sigma_{ij}$-deformation} & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $t_{\mathrm{LLR}}$ & 0.0019 & 0.0029 & 419 & 0.0023 & 0.0035 & 637 & 0.0086 & 0.011 & 411 & - \\
# $d_{\mathrm{MMD}}$ & 0.02 & 0.028 & 310 & 0.021 & 0.029 & 323 & 0.02 & 0.028 & 326 & 2008 \\
# $d_{\mathrm{FGD}}$ & 0.02 & 0.026 & 246 & 0.024 & 0.031 & 232 & 0.025 & 0.033 & 239 & 428 \\
# $\widetilde{W}$ & 0.021 & 0.029 & 132 & 0.026 & 0.036 & 164 & 0.024 & 0.033 & 128 & 251 \\
# $\widetilde{D}$ & 0.021 & 0.028 & 222 & 0.026 & 0.034 & 295 & 0.026 & 0.034 & 220 & 324 \\
# $\overline{\|\cdot\|}_{F}$ & 0.033 & 0.042 & 77 & 0.032 & 0.04 & 111 & 0.05 & 0.065 & 76 & 7 \\
# $\overline{D}$ & 0.034 & 0.044 & 132 & 0.043 & 0.055 & 156 & 0.033 & 0.043 & 130 & 26 \\
# \bottomrule
# \end{tabular}
