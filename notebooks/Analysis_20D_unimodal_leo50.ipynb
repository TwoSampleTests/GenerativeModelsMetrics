# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [2]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/20D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-02 19:13:21.962158: Importing os...
# 2024-05-02 19:13:21.962659: Importing sys...
# Visible devices: [2]
# 2024-05-02 19:13:21.963030: Importing timer from timeit...
# 2024-05-02 19:13:21.963122: Setting env variables for tf import (only device(s) [2] will be available)...
# 2024-05-02 19:13:21.963301: Importing numpy...
# 2024-05-02 19:13:22.163606: Importing matplotlib...
# 2024-05-02 19:13:22.779642: Importing h5py...
# 2024-05-02 19:13:22.822357: Importing importlib.util...
# 2024-05-02 19:13:22.822523: Importing json...
# 2024-05-02 19:13:22.822588: Importing pandas...
# 2024-05-02 19:13:23.710268: Importing random...
# 2024-05-02 19:13:23.710618: Importing scipy utils...
# 2024-05-02 19:13:24.388598: Importing subprocess...
# 2024-05-02 19:13:24.388910: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-02 19:13:30.476469: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-02 19:13:32.310701: Importing timeit...
# 2024-05-02 19:13:32.310830: Importing tqdm...
# 2024-05-02 19:13:32.325925: Importing typing...
# 2024-05-02 19:13:32.326096: Setting tf configs...
# 2024-05-02 19:13:32.459614: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-02 19:13:39.259466: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #2, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-02 19:13:39.292428: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)
# sample from dist_1:  tf.Tensor(
# [[ 1.62394778 -1.11713055 -3.45135301  4.02315639  1.79363942  0.87873968
#   -0.51126516 -0.92759022  0.9684665   3.18830987 -3.42405188  3.36211729
#   -0.96854842 -3.80825042 -0.89370868 -1.73911197  1.43142731 -0.79816186
#    0.76473528 -1.33178131]
#  [-0.9054265  -2.92456346  0.09102918  3.39183213 -0.95867254  2.45738573
#    1.71250394 -2.52956172 -3.05196619  1.09518007 -3.53956728  3.61257976
#   -1.9952454  -6.54374378  1.52104688 -1.73495163 -0.51549626 -3.80685124
#    2.25790807 -0.79758678]], shape=(2, 20), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[ 1.62394778 -1.11713055 -3.45135301  4.02315639  1.79363942  0.87873968
#   -0.51126516 -0.92759022  0.9684665   3.18830987 -3.42405188  3.36211729
#   -0.96854842 -3.80825042 -0.89370868 -1.73911197  1.43142731 -0.79816186
#    0.76473528 -1.33178131]
#  [-0.9054265  -2.92456346  0.09102918  3.39183213 -0.95867254  2.45738573
#    1.71250394 -2.52956172 -3.05196619  1.09518007 -3.53956728  3.61257976
#   -1.9952454  -6.54374378  1.52104688 -1.73495163 -0.51549626 -3.80685124
#    2.25790807 -0.79758678]], shape=(2, 20), dtype=float64)

# %% [markdown]
# # Fixed $n=50000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 50_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 500000000
# batch_size 50000
# niter 10000
# niter * batch_size 500000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            50000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...       20           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True       20           0  float64    20  500000000         False
#
#    ncomp
# 0      5
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 2,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 5000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 200
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714670024.833260  702946 service.cc:145] XLA service 0x10cb73d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714670024.833323  702946 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1714670028.075673  702946 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# FGD metric calculation completed in 3057.1982885061298 seconds.
# Saving fgd to results/20D_unimodal/20D_50K/null_hypothesis/FGD.json
# Computing and savng mmd with max_vectorize = 2
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 5000
# Iterating from 0 to 2 out of 10000 .
# Iterating from 2 to 4 out of 10000 .
# Iterating from 4 to 6 out of 10000 .
# Iterating from 6 to 8 out of 10000 .
# Iterating from 8 to 10 out of 10000 .
# Iterating from 10 to 12 out of 10000 .
# Iterating from 12 to 14 out of 10000 .
# Iterating from 14 to 16 out of 10000 .
# Iterating from 16 to 18 out of 10000 .
# Iterating from 18 to 20 out of 10000 .
# Iterating from 20 to 22 out of 10000 .
# Iterating from 22 to 24 out of 10000 .
# Iterating from 24 to 26 out of 10000 .
# Iterating from 26 to 28 out of 10000 .
# Iterating from 28 to 30 out of 10000 .
# Iterating from 30 to 32 out of 10000 .
# Iterating from 32 to 34 out of 10000 .
# Iterating from 34 to 36 out of 10000 .
# Iterating from 36 to 38 out of 10000 .
# Iterating from 38 to 40 out of 10000 .
# Iterating from 40 to 42 out of 10000 .
# Iterating from 42 to 44 out of 10000 .
# Iterating from 44 to 46 out of 10000 .
# Iterating from 46 to 48 out of 10000 .
# Iterating from 48 to 50 out of 10000 .
# Iterating from 50 to 52 out of 10000 .
# Iterating from 52 to 54 out of 10000 .
# Iterating from 54 to 56 out of 10000 .
# Iterating from 56 to 58 out of 10000 .
# Iterating from 58 to 60 out of 10000 .
# Iterating from 60 to 62 out of 10000 .
# Iterating from 62 to 64 out of 10000 .
# Iterating from 64 to 66 out of 10000 .
# Iterating from 66 to 68 out of 10000 .
# Iterating from 68 to 70 out of 10000 .
# Iterating from 70 to 72 out of 10000 .
# Iterating from 72 to 74 out of 10000 .
# Iterating from 74 to 76 out of 10000 .
# Iterating from 76 to 78 out of 10000 .
# Iterating from 78 to 80 out of 10000 .
# Iterating from 80 to 82 out of 10000 .
# Iterating from 82 to 84 out of 10000 .
# Iterating from 84 to 86 out of 10000 .
# Iterating from 86 to 88 out of 10000 .
# Iterating from 88 to 90 out of 10000 .
# Iterating from 90 to 92 out of 10000 .
# Iterating from 92 to 94 out of 10000 .
# Iterating from 94 to 96 out of 10000 .
# Iterating from 96 to 98 out of 10000 .
# Iterating from 98 to 100 out of 10000 .
# Iterating from 100 to 102 out of 10000 .
# Iterating from 102 to 104 out of 10000 .
# Iterating from 104 to 106 out of 10000 .
# Iterating from 106 to 108 out of 10000 .
# Iterating from 108 to 110 out of 10000 .
# Iterating from 110 to 112 out of 10000 .
# Iterating from 112 to 114 out of 10000 .
# Iterating from 114 to 116 out of 10000 .
# Iterating from 116 to 118 out of 10000 .
# Iterating from 118 to 120 out of 10000 .
# Iterating from 120 to 122 out of 10000 .
# Iterating from 122 to 124 out of 10000 .
# Iterating from 124 to 126 out of 10000 .
# Iterating from 126 to 128 out of 10000 .
# Iterating from 128 to 130 out of 10000 .
# Iterating from 130 to 132 out of 10000 .
# Iterating from 132 to 134 out of 10000 .
# Iterating from 134 to 136 out of 10000 .
# Iterating from 136 to 138 out of 10000 .
# Iterating from 138 to 140 out of 10000 .
# Iterating from 140 to 142 out of 10000 .
# Iterating from 142 to 144 out of 10000 .
# Iterating from 144 to 146 out of 10000 .
# Iterating from 146 to 148 out of 10000 .
# Iterating from 148 to 150 out of 10000 .
# Iterating from 150 to 152 out of 10000 .
# Iterating from 152 to 154 out of 10000 .
# Iterating from 154 to 156 out of 10000 .
# Iterating from 156 to 158 out of 10000 .
# Iterating from 158 to 160 out of 10000 .
# Iterating from 160 to 162 out of 10000 .
# Iterating from 162 to 164 out of 10000 .
# Iterating from 164 to 166 out of 10000 .
# Iterating from 166 to 168 out of 10000 .
# Iterating from 168 to 170 out of 10000 .
# Iterating from 170 to 172 out of 10000 .
# Iterating from 172 to 174 out of 10000 .
# Iterating from 174 to 176 out of 10000 .
# Iterating from 176 to 178 out of 10000 .
# Iterating from 178 to 180 out of 10000 .
# Iterating from 180 to 182 out of 10000 .
# Iterating from 182 to 184 out of 10000 .
# Iterating from 184 to 186 out of 10000 .
# Iterating from 186 to 188 out of 10000 .
# Iterating from 188 to 190 out of 10000 .
# Iterating from 190 to 192 out of 10000 .
# Iterating from 192 to 194 out of 10000 .
# Iterating from 194 to 196 out of 10000 .
# Iterating from 196 to 198 out of 10000 .
# Iterating from 198 to 200 out of 10000 .
# Iterating from 200 to 202 out of 10000 .
# Iterating from 202 to 204 out of 10000 .
# Iterating from 204 to 206 out of 10000 .
# Iterating from 206 to 208 out of 10000 .
# Iterating from 208 to 210 out of 10000 .
# Iterating from 210 to 212 out of 10000 .
# Iterating from 212 to 214 out of 10000 .
# Iterating from 214 to 216 out of 10000 .
# Iterating from 216 to 218 out of 10000 .
# Iterating from 218 to 220 out of 10000 .
# Iterating from 220 to 222 out of 10000 .
# Iterating from 222 to 224 out of 10000 .
# Iterating from 224 to 226 out of 10000 .
# Iterating from 226 to 228 out of 10000 .
# Iterating from 228 to 230 out of 10000 .
# Iterating from 230 to 232 out of 10000 .
# Iterating from 232 to 234 out of 10000 .
# Iterating from 234 to 236 out of 10000 .
# Iterating from 236 to 238 out of 10000 .
# Iterating from 238 to 240 out of 10000 .
# Iterating from 240 to 242 out of 10000 .
# Iterating from 242 to 244 out of 10000 .
# Iterating from 244 to 246 out of 10000 .
# Iterating from 246 to 248 out of 10000 .
# Iterating from 248 to 250 out of 10000 .
# Iterating from 250 to 252 out of 10000 .
# Iterating from 252 to 254 out of 10000 .
# Iterating from 254 to 256 out of 10000 .
# Iterating from 256 to 258 out of 10000 .
# Iterating from 258 to 260 out of 10000 .
# Iterating from 260 to 262 out of 10000 .
# Iterating from 262 to 264 out of 10000 .
# Iterating from 264 to 266 out of 10000 .
# Iterating from 266 to 268 out of 10000 .
# Iterating from 268 to 270 out of 10000 .
# Iterating from 270 to 272 out of 10000 .
# Iterating from 272 to 274 out of 10000 .
# Iterating from 274 to 276 out of 10000 .
# Iterating from 276 to 278 out of 10000 .
# Iterating from 278 to 280 out of 10000 .
# Iterating from 280 to 282 out of 10000 .
# Iterating from 282 to 284 out of 10000 .
# Iterating from 284 to 286 out of 10000 .
# Iterating from 286 to 288 out of 10000 .
# Iterating from 288 to 290 out of 10000 .
# Iterating from 290 to 292 out of 10000 .
# Iterating from 292 to 294 out of 10000 .
# Iterating from 294 to 296 out of 10000 .
# Iterating from 296 to 298 out of 10000 .
# Iterating from 298 to 300 out of 10000 .
# Iterating from 300 to 302 out of 10000 .
# Iterating from 302 to 304 out of 10000 .
# Iterating from 304 to 306 out of 10000 .
# Iterating from 306 to 308 out of 10000 .
# Iterating from 308 to 310 out of 10000 .
# Iterating from 310 to 312 out of 10000 .
# Iterating from 312 to 314 out of 10000 .
# Iterating from 314 to 316 out of 10000 .
# Iterating from 316 to 318 out of 10000 .
# Iterating from 318 to 320 out of 10000 .
# Iterating from 320 to 322 out of 10000 .
# Iterating from 322 to 324 out of 10000 .
# Iterating from 324 to 326 out of 10000 .
# Iterating from 326 to 328 out of 10000 .
# Iterating from 328 to 330 out of 10000 .
# Iterating from 330 to 332 out of 10000 .
# Iterating from 332 to 334 out of 10000 .
# Iterating from 334 to 336 out of 10000 .
# Iterating from 336 to 338 out of 10000 .
# Iterating from 338 to 340 out of 10000 .
# Iterating from 340 to 342 out of 10000 .
# Iterating from 342 to 344 out of 10000 .
# Iterating from 344 to 346 out of 10000 .
# Iterating from 346 to 348 out of 10000 .
# Iterating from 348 to 350 out of 10000 .
# Iterating from 350 to 352 out of 10000 .
# Iterating from 352 to 354 out of 10000 .
# Iterating from 354 to 356 out of 10000 .
# Iterating from 356 to 358 out of 10000 .
# Iterating from 358 to 360 out of 10000 .
# Iterating from 360 to 362 out of 10000 .
# Iterating from 362 to 364 out of 10000 .
# Iterating from 364 to 366 out of 10000 .
# Iterating from 366 to 368 out of 10000 .
# Iterating from 368 to 370 out of 10000 .
# Iterating from 370 to 372 out of 10000 .
# Iterating from 372 to 374 out of 10000 .
# Iterating from 374 to 376 out of 10000 .
# Iterating from 376 to 378 out of 10000 .
# Iterating from 378 to 380 out of 10000 .
# Iterating from 380 to 382 out of 10000 .
# Iterating from 382 to 384 out of 10000 .
# Iterating from 384 to 386 out of 10000 .
# Iterating from 386 to 388 out of 10000 .
# Iterating from 388 to 390 out of 10000 .
# Iterating from 390 to 392 out of 10000 .
# Iterating from 392 to 394 out of 10000 .
# Iterating from 394 to 396 out of 10000 .
# Iterating from 396 to 398 out of 10000 .
# Iterating from 398 to 400 out of 10000 .
# Iterating from 400 to 402 out of 10000 .
# Iterating from 402 to 404 out of 10000 .
# Iterating from 404 to 406 out of 10000 .
# Iterating from 406 to 408 out of 10000 .
# Iterating from 408 to 410 out of 10000 .
# Iterating from 410 to 412 out of 10000 .
# Iterating from 412 to 414 out of 10000 .
# Iterating from 414 to 416 out of 10000 .
# Iterating from 416 to 418 out of 10000 .
# Iterating from 418 to 420 out of 10000 .
# Iterating from 420 to 422 out of 10000 .
# Iterating from 422 to 424 out of 10000 .
# Iterating from 424 to 426 out of 10000 .
# Iterating from 426 to 428 out of 10000 .
# Iterating from 428 to 430 out of 10000 .
# Iterating from 430 to 432 out of 10000 .
# Iterating from 432 to 434 out of 10000 .
# Iterating from 434 to 436 out of 10000 .
# Iterating from 436 to 438 out of 10000 .
# Iterating from 438 to 440 out of 10000 .
# Iterating from 440 to 442 out of 10000 .
# Iterating from 442 to 444 out of 10000 .
# Iterating from 444 to 446 out of 10000 .
# Iterating from 446 to 448 out of 10000 .
# Iterating from 448 to 450 out of 10000 .
# Iterating from 450 to 452 out of 10000 .
# Iterating from 452 to 454 out of 10000 .
# Iterating from 454 to 456 out of 10000 .
# Iterating from 456 to 458 out of 10000 .
# Iterating from 458 to 460 out of 10000 .
# Iterating from 460 to 462 out of 10000 .
# Iterating from 462 to 464 out of 10000 .
# Iterating from 464 to 466 out of 10000 .
# Iterating from 466 to 468 out of 10000 .
# Iterating from 468 to 470 out of 10000 .
# Iterating from 470 to 472 out of 10000 .
# Iterating from 472 to 474 out of 10000 .
# Iterating from 474 to 476 out of 10000 .
# Iterating from 476 to 478 out of 10000 .
# Iterating from 478 to 480 out of 10000 .
# Iterating from 480 to 482 out of 10000 .
# Iterating from 482 to 484 out of 10000 .
# Iterating from 484 to 486 out of 10000 .
# Iterating from 486 to 488 out of 10000 .
# Iterating from 488 to 490 out of 10000 .
# Iterating from 490 to 492 out of 10000 .
# Iterating from 492 to 494 out of 10000 .
# Iterating from 494 to 496 out of 10000 .
# Iterating from 496 to 498 out of 10000 .
# Iterating from 498 to 500 out of 10000 .
# Iterating from 500 to 502 out of 10000 .
# Iterating from 502 to 504 out of 10000 .
# Iterating from 504 to 506 out of 10000 .
# Iterating from 506 to 508 out of 10000 .
# Iterating from 508 to 510 out of 10000 .
# Iterating from 510 to 512 out of 10000 .
# Iterating from 512 to 514 out of 10000 .
# Iterating from 514 to 516 out of 10000 .
# Iterating from 516 to 518 out of 10000 .
# Iterating from 518 to 520 out of 10000 .
# Iterating from 520 to 522 out of 10000 .
# Iterating from 522 to 524 out of 10000 .
# Iterating from 524 to 526 out of 10000 .
# Iterating from 526 to 528 out of 10000 .
# Iterating from 528 to 530 out of 10000 .
# Iterating from 530 to 532 out of 10000 .
# Iterating from 532 to 534 out of 10000 .
# Iterating from 534 to 536 out of 10000 .
# Iterating from 536 to 538 out of 10000 .
# Iterating from 538 to 540 out of 10000 .
# Iterating from 540 to 542 out of 10000 .
# Iterating from 542 to 544 out of 10000 .
# Iterating from 544 to 546 out of 10000 .
# Iterating from 546 to 548 out of 10000 .
# Iterating from 548 to 550 out of 10000 .
# Iterating from 550 to 552 out of 10000 .
# Iterating from 552 to 554 out of 10000 .
# Iterating from 554 to 556 out of 10000 .
# Iterating from 556 to 558 out of 10000 .
# Iterating from 558 to 560 out of 10000 .
# Iterating from 560 to 562 out of 10000 .
# Iterating from 562 to 564 out of 10000 .
# Iterating from 564 to 566 out of 10000 .
# Iterating from 566 to 568 out of 10000 .
# Iterating from 568 to 570 out of 10000 .
# Iterating from 570 to 572 out of 10000 .
# Iterating from 572 to 574 out of 10000 .
# Iterating from 574 to 576 out of 10000 .
# Iterating from 576 to 578 out of 10000 .
# Iterating from 578 to 580 out of 10000 .
# Iterating from 580 to 582 out of 10000 .
# Iterating from 582 to 584 out of 10000 .
# Iterating from 584 to 586 out of 10000 .
# Iterating from 586 to 588 out of 10000 .
# Iterating from 588 to 590 out of 10000 .
# Iterating from 590 to 592 out of 10000 .
# Iterating from 592 to 594 out of 10000 .
# Iterating from 594 to 596 out of 10000 .
# Iterating from 596 to 598 out of 10000 .
# Iterating from 598 to 600 out of 10000 .
# Iterating from 600 to 602 out of 10000 .
# Iterating from 602 to 604 out of 10000 .
# Iterating from 604 to 606 out of 10000 .
# Iterating from 606 to 608 out of 10000 .
# Iterating from 608 to 610 out of 10000 .
# Iterating from 610 to 612 out of 10000 .
# Iterating from 612 to 614 out of 10000 .
# Iterating from 614 to 616 out of 10000 .
# Iterating from 616 to 618 out of 10000 .
# Iterating from 618 to 620 out of 10000 .
# Iterating from 620 to 622 out of 10000 .
# Iterating from 622 to 624 out of 10000 .
# Iterating from 624 to 626 out of 10000 .
# Iterating from 626 to 628 out of 10000 .
# Iterating from 628 to 630 out of 10000 .
# Iterating from 630 to 632 out of 10000 .
# Iterating from 632 to 634 out of 10000 .
# Iterating from 634 to 636 out of 10000 .
# Iterating from 636 to 638 out of 10000 .
# Iterating from 638 to 640 out of 10000 .
# Iterating from 640 to 642 out of 10000 .
# Iterating from 642 to 644 out of 10000 .
# Iterating from 644 to 646 out of 10000 .
# Iterating from 646 to 648 out of 10000 .
# Iterating from 648 to 650 out of 10000 .
# Iterating from 650 to 652 out of 10000 .
# Iterating from 652 to 654 out of 10000 .
# Iterating from 654 to 656 out of 10000 .
# Iterating from 656 to 658 out of 10000 .
# Iterating from 658 to 660 out of 10000 .
# Iterating from 660 to 662 out of 10000 .
# Iterating from 662 to 664 out of 10000 .
# Iterating from 664 to 666 out of 10000 .
# Iterating from 666 to 668 out of 10000 .
# Iterating from 668 to 670 out of 10000 .
# Iterating from 670 to 672 out of 10000 .
# Iterating from 672 to 674 out of 10000 .
# Iterating from 674 to 676 out of 10000 .
# Iterating from 676 to 678 out of 10000 .
# Iterating from 678 to 680 out of 10000 .
# Iterating from 680 to 682 out of 10000 .
# Iterating from 682 to 684 out of 10000 .
# Iterating from 684 to 686 out of 10000 .
# Iterating from 686 to 688 out of 10000 .
# Iterating from 688 to 690 out of 10000 .
# Iterating from 690 to 692 out of 10000 .
# Iterating from 692 to 694 out of 10000 .
# Iterating from 694 to 696 out of 10000 .
# Iterating from 696 to 698 out of 10000 .
# Iterating from 698 to 700 out of 10000 .
# Iterating from 700 to 702 out of 10000 .
# Iterating from 702 to 704 out of 10000 .
# Iterating from 704 to 706 out of 10000 .
# Iterating from 706 to 708 out of 10000 .
# Iterating from 708 to 710 out of 10000 .
# Iterating from 710 to 712 out of 10000 .
# Iterating from 712 to 714 out of 10000 .
# Iterating from 714 to 716 out of 10000 .
# Iterating from 716 to 718 out of 10000 .
# Iterating from 718 to 720 out of 10000 .
# Iterating from 720 to 722 out of 10000 .
# Iterating from 722 to 724 out of 10000 .
# Iterating from 724 to 726 out of 10000 .
# Iterating from 726 to 728 out of 10000 .
# Iterating from 728 to 730 out of 10000 .
# Iterating from 730 to 732 out of 10000 .
# Iterating from 732 to 734 out of 10000 .
# Iterating from 734 to 736 out of 10000 .
# Iterating from 736 to 738 out of 10000 .
# Iterating from 738 to 740 out of 10000 .
# Iterating from 740 to 742 out of 10000 .
# Iterating from 742 to 744 out of 10000 .
# Iterating from 744 to 746 out of 10000 .
# Iterating from 746 to 748 out of 10000 .
# Iterating from 748 to 750 out of 10000 .
# Iterating from 750 to 752 out of 10000 .
# Iterating from 752 to 754 out of 10000 .
# Iterating from 754 to 756 out of 10000 .
# Iterating from 756 to 758 out of 10000 .
# Iterating from 758 to 760 out of 10000 .
# Iterating from 760 to 762 out of 10000 .
# Iterating from 762 to 764 out of 10000 .
# Iterating from 764 to 766 out of 10000 .
# Iterating from 766 to 768 out of 10000 .
# Iterating from 768 to 770 out of 10000 .
# Iterating from 770 to 772 out of 10000 .
# Iterating from 772 to 774 out of 10000 .
# Iterating from 774 to 776 out of 10000 .
# Iterating from 776 to 778 out of 10000 .
# Iterating from 778 to 780 out of 10000 .
# Iterating from 780 to 782 out of 10000 .
# Iterating from 782 to 784 out of 10000 .
# Iterating from 784 to 786 out of 10000 .
# Iterating from 786 to 788 out of 10000 .
# Iterating from 788 to 790 out of 10000 .
# Iterating from 790 to 792 out of 10000 .
# Iterating from 792 to 794 out of 10000 .
# Iterating from 794 to 796 out of 10000 .
# Iterating from 796 to 798 out of 10000 .
# Iterating from 798 to 800 out of 10000 .
# Iterating from 800 to 802 out of 10000 .
# Iterating from 802 to 804 out of 10000 .
# Iterating from 804 to 806 out of 10000 .
# Iterating from 806 to 808 out of 10000 .
# Iterating from 808 to 810 out of 10000 .
# Iterating from 810 to 812 out of 10000 .
# Iterating from 812 to 814 out of 10000 .
# Iterating from 814 to 816 out of 10000 .
# Iterating from 816 to 818 out of 10000 .
# Iterating from 818 to 820 out of 10000 .
# Iterating from 820 to 822 out of 10000 .
# Iterating from 822 to 824 out of 10000 .
# Iterating from 824 to 826 out of 10000 .
# Iterating from 826 to 828 out of 10000 .
# Iterating from 828 to 830 out of 10000 .
# Iterating from 830 to 832 out of 10000 .
# Iterating from 832 to 834 out of 10000 .
# Iterating from 834 to 836 out of 10000 .
# Iterating from 836 to 838 out of 10000 .
# Iterating from 838 to 840 out of 10000 .
# Iterating from 840 to 842 out of 10000 .
# Iterating from 842 to 844 out of 10000 .
# Iterating from 844 to 846 out of 10000 .
# Iterating from 846 to 848 out of 10000 .
# Iterating from 848 to 850 out of 10000 .
# Iterating from 850 to 852 out of 10000 .
# Iterating from 852 to 854 out of 10000 .
# Iterating from 854 to 856 out of 10000 .
# Iterating from 856 to 858 out of 10000 .
# Iterating from 858 to 860 out of 10000 .
# Iterating from 860 to 862 out of 10000 .
# Iterating from 862 to 864 out of 10000 .
# Iterating from 864 to 866 out of 10000 .
# Iterating from 866 to 868 out of 10000 .
# Iterating from 868 to 870 out of 10000 .
# Iterating from 870 to 872 out of 10000 .
# Iterating from 872 to 874 out of 10000 .
# Iterating from 874 to 876 out of 10000 .
# Iterating from 876 to 878 out of 10000 .
# Iterating from 878 to 880 out of 10000 .
# Iterating from 880 to 882 out of 10000 .
# Iterating from 882 to 884 out of 10000 .
# Iterating from 884 to 886 out of 10000 .
# Iterating from 886 to 888 out of 10000 .
# Iterating from 888 to 890 out of 10000 .
# Iterating from 890 to 892 out of 10000 .
# Iterating from 892 to 894 out of 10000 .
# Iterating from 894 to 896 out of 10000 .
# Iterating from 896 to 898 out of 10000 .
# Iterating from 898 to 900 out of 10000 .
# Iterating from 900 to 902 out of 10000 .
# Iterating from 902 to 904 out of 10000 .
# Iterating from 904 to 906 out of 10000 .
# Iterating from 906 to 908 out of 10000 .
# Iterating from 908 to 910 out of 10000 .
# Iterating from 910 to 912 out of 10000 .
# Iterating from 912 to 914 out of 10000 .
# Iterating from 914 to 916 out of 10000 .
# Iterating from 916 to 918 out of 10000 .
# Iterating from 918 to 920 out of 10000 .
# Iterating from 920 to 922 out of 10000 .
# Iterating from 922 to 924 out of 10000 .
# Iterating from 924 to 926 out of 10000 .
# Iterating from 926 to 928 out of 10000 .
# Iterating from 928 to 930 out of 10000 .
# Iterating from 930 to 932 out of 10000 .
# Iterating from 932 to 934 out of 10000 .
# Iterating from 934 to 936 out of 10000 .
# Iterating from 936 to 938 out of 10000 .
# Iterating from 938 to 940 out of 10000 .
# Iterating from 940 to 942 out of 10000 .
# Iterating from 942 to 944 out of 10000 .
# Iterating from 944 to 946 out of 10000 .
# Iterating from 946 to 948 out of 10000 .
# Iterating from 948 to 950 out of 10000 .
# Iterating from 950 to 952 out of 10000 .
# Iterating from 952 to 954 out of 10000 .
# Iterating from 954 to 956 out of 10000 .
# Iterating from 956 to 958 out of 10000 .
# Iterating from 958 to 960 out of 10000 .
# Iterating from 960 to 962 out of 10000 .
# Iterating from 962 to 964 out of 10000 .
# Iterating from 964 to 966 out of 10000 .
# Iterating from 966 to 968 out of 10000 .
# Iterating from 968 to 970 out of 10000 .
# Iterating from 970 to 972 out of 10000 .
# Iterating from 972 to 974 out of 10000 .
# Iterating from 974 to 976 out of 10000 .
# Iterating from 976 to 978 out of 10000 .
# Iterating from 978 to 980 out of 10000 .
# Iterating from 980 to 982 out of 10000 .
# Iterating from 982 to 984 out of 10000 .
# Iterating from 984 to 986 out of 10000 .
# Iterating from 986 to 988 out of 10000 .
# Iterating from 988 to 990 out of 10000 .
# Iterating from 990 to 992 out of 10000 .
# Iterating from 992 to 994 out of 10000 .
# Iterating from 994 to 996 out of 10000 .
# Iterating from 996 to 998 out of 10000 .
# Iterating from 998 to 1000 out of 10000 .
# Iterating from 1000 to 1002 out of 10000 .
# Iterating from 1002 to 1004 out of 10000 .
# Iterating from 1004 to 1006 out of 10000 .
# Iterating from 1006 to 1008 out of 10000 .
# Iterating from 1008 to 1010 out of 10000 .
# Iterating from 1010 to 1012 out of 10000 .
# Iterating from 1012 to 1014 out of 10000 .
# Iterating from 1014 to 1016 out of 10000 .
# Iterating from 1016 to 1018 out of 10000 .
# Iterating from 1018 to 1020 out of 10000 .
# Iterating from 1020 to 1022 out of 10000 .
# Iterating from 1022 to 1024 out of 10000 .
# Iterating from 1024 to 1026 out of 10000 .
# Iterating from 1026 to 1028 out of 10000 .
# Iterating from 1028 to 1030 out of 10000 .
# Iterating from 1030 to 1032 out of 10000 .
# Iterating from 1032 to 1034 out of 10000 .
# Iterating from 1034 to 1036 out of 10000 .
# Iterating from 1036 to 1038 out of 10000 .
# Iterating from 1038 to 1040 out of 10000 .
# Iterating from 1040 to 1042 out of 10000 .
# Iterating from 1042 to 1044 out of 10000 .
# Iterating from 1044 to 1046 out of 10000 .
# Iterating from 1046 to 1048 out of 10000 .
# Iterating from 1048 to 1050 out of 10000 .
# Iterating from 1050 to 1052 out of 10000 .
# Iterating from 1052 to 1054 out of 10000 .
# Iterating from 1054 to 1056 out of 10000 .
# Iterating from 1056 to 1058 out of 10000 .
# Iterating from 1058 to 1060 out of 10000 .
# Iterating from 1060 to 1062 out of 10000 .
# Iterating from 1062 to 1064 out of 10000 .
# Iterating from 1064 to 1066 out of 10000 .
# Iterating from 1066 to 1068 out of 10000 .
# Iterating from 1068 to 1070 out of 10000 .
# Iterating from 1070 to 1072 out of 10000 .
# Iterating from 1072 to 1074 out of 10000 .
# Iterating from 1074 to 1076 out of 10000 .
# Iterating from 1076 to 1078 out of 10000 .
# Iterating from 1078 to 1080 out of 10000 .
# Iterating from 1080 to 1082 out of 10000 .
# Iterating from 1082 to 1084 out of 10000 .
# Iterating from 1084 to 1086 out of 10000 .
# Iterating from 1086 to 1088 out of 10000 .
# Iterating from 1088 to 1090 out of 10000 .
# Iterating from 1090 to 1092 out of 10000 .
# Iterating from 1092 to 1094 out of 10000 .
# Iterating from 1094 to 1096 out of 10000 .
# Iterating from 1096 to 1098 out of 10000 .
# Iterating from 1098 to 1100 out of 10000 .
# Iterating from 1100 to 1102 out of 10000 .
# Iterating from 1102 to 1104 out of 10000 .
# Iterating from 1104 to 1106 out of 10000 .
# Iterating from 1106 to 1108 out of 10000 .
# Iterating from 1108 to 1110 out of 10000 .
# Iterating from 1110 to 1112 out of 10000 .
# Iterating from 1112 to 1114 out of 10000 .
# Iterating from 1114 to 1116 out of 10000 .
# Iterating from 1116 to 1118 out of 10000 .
# Iterating from 1118 to 1120 out of 10000 .
# Iterating from 1120 to 1122 out of 10000 .
# Iterating from 1122 to 1124 out of 10000 .
# Iterating from 1124 to 1126 out of 10000 .
# Iterating from 1126 to 1128 out of 10000 .
# Iterating from 1128 to 1130 out of 10000 .
# Iterating from 1130 to 1132 out of 10000 .
# Iterating from 1132 to 1134 out of 10000 .
# Iterating from 1134 to 1136 out of 10000 .
# Iterating from 1136 to 1138 out of 10000 .
# Iterating from 1138 to 1140 out of 10000 .
# Iterating from 1140 to 1142 out of 10000 .
# Iterating from 1142 to 1144 out of 10000 .
# Iterating from 1144 to 1146 out of 10000 .
# Iterating from 1146 to 1148 out of 10000 .
# Iterating from 1148 to 1150 out of 10000 .
# Iterating from 1150 to 1152 out of 10000 .
# Iterating from 1152 to 1154 out of 10000 .
# Iterating from 1154 to 1156 out of 10000 .
# Iterating from 1156 to 1158 out of 10000 .
# Iterating from 1158 to 1160 out of 10000 .
# Iterating from 1160 to 1162 out of 10000 .
# Iterating from 1162 to 1164 out of 10000 .
# Iterating from 1164 to 1166 out of 10000 .
# Iterating from 1166 to 1168 out of 10000 .
# Iterating from 1168 to 1170 out of 10000 .
# Iterating from 1170 to 1172 out of 10000 .
# Iterating from 1172 to 1174 out of 10000 .
# Iterating from 1174 to 1176 out of 10000 .
# Iterating from 1176 to 1178 out of 10000 .
# Iterating from 1178 to 1180 out of 10000 .
# Iterating from 1180 to 1182 out of 10000 .
# Iterating from 1182 to 1184 out of 10000 .
# Iterating from 1184 to 1186 out of 10000 .
# Iterating from 1186 to 1188 out of 10000 .
# Iterating from 1188 to 1190 out of 10000 .
# Iterating from 1190 to 1192 out of 10000 .
# Iterating from 1192 to 1194 out of 10000 .
# Iterating from 1194 to 1196 out of 10000 .
# Iterating from 1196 to 1198 out of 10000 .
# Iterating from 1198 to 1200 out of 10000 .
# Iterating from 1200 to 1202 out of 10000 .
# Iterating from 1202 to 1204 out of 10000 .
# Iterating from 1204 to 1206 out of 10000 .
# Iterating from 1206 to 1208 out of 10000 .
# Iterating from 1208 to 1210 out of 10000 .
# Iterating from 1210 to 1212 out of 10000 .
# Iterating from 1212 to 1214 out of 10000 .
# Iterating from 1214 to 1216 out of 10000 .
# Iterating from 1216 to 1218 out of 10000 .
# Iterating from 1218 to 1220 out of 10000 .
# Iterating from 1220 to 1222 out of 10000 .
# Iterating from 1222 to 1224 out of 10000 .
# Iterating from 1224 to 1226 out of 10000 .
# Iterating from 1226 to 1228 out of 10000 .
# Iterating from 1228 to 1230 out of 10000 .
# Iterating from 1230 to 1232 out of 10000 .
# Iterating from 1232 to 1234 out of 10000 .
# Iterating from 1234 to 1236 out of 10000 .
# Iterating from 1236 to 1238 out of 10000 .
# Iterating from 1238 to 1240 out of 10000 .
# Iterating from 1240 to 1242 out of 10000 .
# Iterating from 1242 to 1244 out of 10000 .
# Iterating from 1244 to 1246 out of 10000 .
# Iterating from 1246 to 1248 out of 10000 .
# Iterating from 1248 to 1250 out of 10000 .
# Iterating from 1250 to 1252 out of 10000 .
# Iterating from 1252 to 1254 out of 10000 .
# Iterating from 1254 to 1256 out of 10000 .
# Iterating from 1256 to 1258 out of 10000 .
# Iterating from 1258 to 1260 out of 10000 .
# Iterating from 1260 to 1262 out of 10000 .
# Iterating from 1262 to 1264 out of 10000 .
# Iterating from 1264 to 1266 out of 10000 .
# Iterating from 1266 to 1268 out of 10000 .
# Iterating from 1268 to 1270 out of 10000 .
# Iterating from 1270 to 1272 out of 10000 .
# Iterating from 1272 to 1274 out of 10000 .
# Iterating from 1274 to 1276 out of 10000 .
# Iterating from 1276 to 1278 out of 10000 .
# Iterating from 1278 to 1280 out of 10000 .
# Iterating from 1280 to 1282 out of 10000 .
# Iterating from 1282 to 1284 out of 10000 .
# Iterating from 1284 to 1286 out of 10000 .
# Iterating from 1286 to 1288 out of 10000 .
# Iterating from 1288 to 1290 out of 10000 .
# Iterating from 1290 to 1292 out of 10000 .
# Iterating from 1292 to 1294 out of 10000 .
# Iterating from 1294 to 1296 out of 10000 .
# Iterating from 1296 to 1298 out of 10000 .
# Iterating from 1298 to 1300 out of 10000 .
# Iterating from 1300 to 1302 out of 10000 .
# Iterating from 1302 to 1304 out of 10000 .
# Iterating from 1304 to 1306 out of 10000 .
# Iterating from 1306 to 1308 out of 10000 .
# Iterating from 1308 to 1310 out of 10000 .
# Iterating from 1310 to 1312 out of 10000 .
# Iterating from 1312 to 1314 out of 10000 .
# Iterating from 1314 to 1316 out of 10000 .
# Iterating from 1316 to 1318 out of 10000 .
# Iterating from 1318 to 1320 out of 10000 .
# Iterating from 1320 to 1322 out of 10000 .
# Iterating from 1322 to 1324 out of 10000 .
# Iterating from 1324 to 1326 out of 10000 .
# Iterating from 1326 to 1328 out of 10000 .
# Iterating from 1328 to 1330 out of 10000 .
# Iterating from 1330 to 1332 out of 10000 .
# Iterating from 1332 to 1334 out of 10000 .
# Iterating from 1334 to 1336 out of 10000 .
# Iterating from 1336 to 1338 out of 10000 .
# Iterating from 1338 to 1340 out of 10000 .
# Iterating from 1340 to 1342 out of 10000 .
# Iterating from 1342 to 1344 out of 10000 .
# Iterating from 1344 to 1346 out of 10000 .
# Iterating from 1346 to 1348 out of 10000 .
# Iterating from 1348 to 1350 out of 10000 .
# Iterating from 1350 to 1352 out of 10000 .
# Iterating from 1352 to 1354 out of 10000 .
# Iterating from 1354 to 1356 out of 10000 .
# Iterating from 1356 to 1358 out of 10000 .
# Iterating from 1358 to 1360 out of 10000 .
# Iterating from 1360 to 1362 out of 10000 .
# Iterating from 1362 to 1364 out of 10000 .
# Iterating from 1364 to 1366 out of 10000 .
# Iterating from 1366 to 1368 out of 10000 .
# Iterating from 1368 to 1370 out of 10000 .
# Iterating from 1370 to 1372 out of 10000 .
# Iterating from 1372 to 1374 out of 10000 .
# Iterating from 1374 to 1376 out of 10000 .
# Iterating from 1376 to 1378 out of 10000 .
# Iterating from 1378 to 1380 out of 10000 .
# Iterating from 1380 to 1382 out of 10000 .
# Iterating from 1382 to 1384 out of 10000 .
# Iterating from 1384 to 1386 out of 10000 .
# Iterating from 1386 to 1388 out of 10000 .
# Iterating from 1388 to 1390 out of 10000 .
# Iterating from 1390 to 1392 out of 10000 .
# Iterating from 1392 to 1394 out of 10000 .
# Iterating from 1394 to 1396 out of 10000 .
# Iterating from 1396 to 1398 out of 10000 .
# Iterating from 1398 to 1400 out of 10000 .
# Iterating from 1400 to 1402 out of 10000 .
# Iterating from 1402 to 1404 out of 10000 .
# Iterating from 1404 to 1406 out of 10000 .
# Iterating from 1406 to 1408 out of 10000 .
# Iterating from 1408 to 1410 out of 10000 .
# Iterating from 1410 to 1412 out of 10000 .
# Iterating from 1412 to 1414 out of 10000 .
# Iterating from 1414 to 1416 out of 10000 .
# Iterating from 1416 to 1418 out of 10000 .
# Iterating from 1418 to 1420 out of 10000 .
# Iterating from 1420 to 1422 out of 10000 .
# Iterating from 1422 to 1424 out of 10000 .
# Iterating from 1424 to 1426 out of 10000 .
# Iterating from 1426 to 1428 out of 10000 .
# Iterating from 1428 to 1430 out of 10000 .
# Iterating from 1430 to 1432 out of 10000 .
# Iterating from 1432 to 1434 out of 10000 .
# Iterating from 1434 to 1436 out of 10000 .
# Iterating from 1436 to 1438 out of 10000 .
# Iterating from 1438 to 1440 out of 10000 .
# Iterating from 1440 to 1442 out of 10000 .
# Iterating from 1442 to 1444 out of 10000 .
# Iterating from 1444 to 1446 out of 10000 .
# Iterating from 1446 to 1448 out of 10000 .
# Iterating from 1448 to 1450 out of 10000 .
# Iterating from 1450 to 1452 out of 10000 .
# Iterating from 1452 to 1454 out of 10000 .
# Iterating from 1454 to 1456 out of 10000 .
# Iterating from 1456 to 1458 out of 10000 .
# Iterating from 1458 to 1460 out of 10000 .
# Iterating from 1460 to 1462 out of 10000 .
# Iterating from 1462 to 1464 out of 10000 .
# Iterating from 1464 to 1466 out of 10000 .
# Iterating from 1466 to 1468 out of 10000 .
# Iterating from 1468 to 1470 out of 10000 .
# Iterating from 1470 to 1472 out of 10000 .
# Iterating from 1472 to 1474 out of 10000 .
# Iterating from 1474 to 1476 out of 10000 .
# Iterating from 1476 to 1478 out of 10000 .
# Iterating from 1478 to 1480 out of 10000 .
# Iterating from 1480 to 1482 out of 10000 .
# Iterating from 1482 to 1484 out of 10000 .
# Iterating from 1484 to 1486 out of 10000 .
# Iterating from 1486 to 1488 out of 10000 .
# Iterating from 1488 to 1490 out of 10000 .
# Iterating from 1490 to 1492 out of 10000 .
# Iterating from 1492 to 1494 out of 10000 .
# Iterating from 1494 to 1496 out of 10000 .
# Iterating from 1496 to 1498 out of 10000 .
# Iterating from 1498 to 1500 out of 10000 .
# Iterating from 1500 to 1502 out of 10000 .
# Iterating from 1502 to 1504 out of 10000 .
# Iterating from 1504 to 1506 out of 10000 .
# Iterating from 1506 to 1508 out of 10000 .
# Iterating from 1508 to 1510 out of 10000 .
# Iterating from 1510 to 1512 out of 10000 .
# Iterating from 1512 to 1514 out of 10000 .
# Iterating from 1514 to 1516 out of 10000 .
# Iterating from 1516 to 1518 out of 10000 .
# Iterating from 1518 to 1520 out of 10000 .
# Iterating from 1520 to 1522 out of 10000 .
# Iterating from 1522 to 1524 out of 10000 .
# Iterating from 1524 to 1526 out of 10000 .
# Iterating from 1526 to 1528 out of 10000 .
# Iterating from 1528 to 1530 out of 10000 .
# Iterating from 1530 to 1532 out of 10000 .
# Iterating from 1532 to 1534 out of 10000 .
# Iterating from 1534 to 1536 out of 10000 .
# Iterating from 1536 to 1538 out of 10000 .
# Iterating from 1538 to 1540 out of 10000 .
# Iterating from 1540 to 1542 out of 10000 .
# Iterating from 1542 to 1544 out of 10000 .
# Iterating from 1544 to 1546 out of 10000 .
# Iterating from 1546 to 1548 out of 10000 .
# Iterating from 1548 to 1550 out of 10000 .
# Iterating from 1550 to 1552 out of 10000 .
# Iterating from 1552 to 1554 out of 10000 .
# Iterating from 1554 to 1556 out of 10000 .
# Iterating from 1556 to 1558 out of 10000 .
# Iterating from 1558 to 1560 out of 10000 .
# Iterating from 1560 to 1562 out of 10000 .
# Iterating from 1562 to 1564 out of 10000 .
# Iterating from 1564 to 1566 out of 10000 .
# Iterating from 1566 to 1568 out of 10000 .
# Iterating from 1568 to 1570 out of 10000 .
# Iterating from 1570 to 1572 out of 10000 .
# Iterating from 1572 to 1574 out of 10000 .
# Iterating from 1574 to 1576 out of 10000 .
# Iterating from 1576 to 1578 out of 10000 .
# Iterating from 1578 to 1580 out of 10000 .
# Iterating from 1580 to 1582 out of 10000 .
# Iterating from 1582 to 1584 out of 10000 .
# Iterating from 1584 to 1586 out of 10000 .
# Iterating from 1586 to 1588 out of 10000 .
# Iterating from 1588 to 1590 out of 10000 .
# Iterating from 1590 to 1592 out of 10000 .
# Iterating from 1592 to 1594 out of 10000 .
# Iterating from 1594 to 1596 out of 10000 .
# Iterating from 1596 to 1598 out of 10000 .
# Iterating from 1598 to 1600 out of 10000 .
# Iterating from 1600 to 1602 out of 10000 .
# Iterating from 1602 to 1604 out of 10000 .
# Iterating from 1604 to 1606 out of 10000 .
# Iterating from 1606 to 1608 out of 10000 .
# Iterating from 1608 to 1610 out of 10000 .
# Iterating from 1610 to 1612 out of 10000 .
# Iterating from 1612 to 1614 out of 10000 .
# Iterating from 1614 to 1616 out of 10000 .
# Iterating from 1616 to 1618 out of 10000 .
# Iterating from 1618 to 1620 out of 10000 .
# Iterating from 1620 to 1622 out of 10000 .
# Iterating from 1622 to 1624 out of 10000 .
# Iterating from 1624 to 1626 out of 10000 .
# Iterating from 1626 to 1628 out of 10000 .
# Iterating from 1628 to 1630 out of 10000 .
# Iterating from 1630 to 1632 out of 10000 .
# Iterating from 1632 to 1634 out of 10000 .
# Iterating from 1634 to 1636 out of 10000 .
# Iterating from 1636 to 1638 out of 10000 .
# Iterating from 1638 to 1640 out of 10000 .
# Iterating from 1640 to 1642 out of 10000 .
# Iterating from 1642 to 1644 out of 10000 .
# Iterating from 1644 to 1646 out of 10000 .
# Iterating from 1646 to 1648 out of 10000 .
# Iterating from 1648 to 1650 out of 10000 .
# Iterating from 1650 to 1652 out of 10000 .
# Iterating from 1652 to 1654 out of 10000 .
# Iterating from 1654 to 1656 out of 10000 .
# Iterating from 1656 to 1658 out of 10000 .
# Iterating from 1658 to 1660 out of 10000 .
# Iterating from 1660 to 1662 out of 10000 .
# Iterating from 1662 to 1664 out of 10000 .
# Iterating from 1664 to 1666 out of 10000 .
# Iterating from 1666 to 1668 out of 10000 .
# Iterating from 1668 to 1670 out of 10000 .
# Iterating from 1670 to 1672 out of 10000 .
# Iterating from 1672 to 1674 out of 10000 .
# Iterating from 1674 to 1676 out of 10000 .
# Iterating from 1676 to 1678 out of 10000 .
# Iterating from 1678 to 1680 out of 10000 .
# Iterating from 1680 to 1682 out of 10000 .
# Iterating from 1682 to 1684 out of 10000 .
# Iterating from 1684 to 1686 out of 10000 .
# Iterating from 1686 to 1688 out of 10000 .
# Iterating from 1688 to 1690 out of 10000 .
# Iterating from 1690 to 1692 out of 10000 .
# Iterating from 1692 to 1694 out of 10000 .
# Iterating from 1694 to 1696 out of 10000 .
# Iterating from 1696 to 1698 out of 10000 .
# Iterating from 1698 to 1700 out of 10000 .
# Iterating from 1700 to 1702 out of 10000 .
# Iterating from 1702 to 1704 out of 10000 .
# Iterating from 1704 to 1706 out of 10000 .
# Iterating from 1706 to 1708 out of 10000 .
# Iterating from 1708 to 1710 out of 10000 .
# Iterating from 1710 to 1712 out of 10000 .
# Iterating from 1712 to 1714 out of 10000 .
# Iterating from 1714 to 1716 out of 10000 .
# Iterating from 1716 to 1718 out of 10000 .
# Iterating from 1718 to 1720 out of 10000 .
# Iterating from 1720 to 1722 out of 10000 .
# Iterating from 1722 to 1724 out of 10000 .
# Iterating from 1724 to 1726 out of 10000 .
# Iterating from 1726 to 1728 out of 10000 .
# Iterating from 1728 to 1730 out of 10000 .
# Iterating from 1730 to 1732 out of 10000 .
# Iterating from 1732 to 1734 out of 10000 .
# Iterating from 1734 to 1736 out of 10000 .
# Iterating from 1736 to 1738 out of 10000 .
# Iterating from 1738 to 1740 out of 10000 .
# Iterating from 1740 to 1742 out of 10000 .
# Iterating from 1742 to 1744 out of 10000 .
# Iterating from 1744 to 1746 out of 10000 .
# Iterating from 1746 to 1748 out of 10000 .
# Iterating from 1748 to 1750 out of 10000 .
# Iterating from 1750 to 1752 out of 10000 .
# Iterating from 1752 to 1754 out of 10000 .
# Iterating from 1754 to 1756 out of 10000 .
# Iterating from 1756 to 1758 out of 10000 .
# Iterating from 1758 to 1760 out of 10000 .
# Iterating from 1760 to 1762 out of 10000 .
# Iterating from 1762 to 1764 out of 10000 .
# Iterating from 1764 to 1766 out of 10000 .
# Iterating from 1766 to 1768 out of 10000 .
# Iterating from 1768 to 1770 out of 10000 .
# Iterating from 1770 to 1772 out of 10000 .
# Iterating from 1772 to 1774 out of 10000 .
# Iterating from 1774 to 1776 out of 10000 .
# Iterating from 1776 to 1778 out of 10000 .
# Iterating from 1778 to 1780 out of 10000 .
# Iterating from 1780 to 1782 out of 10000 .
# Iterating from 1782 to 1784 out of 10000 .
# Iterating from 1784 to 1786 out of 10000 .
# Iterating from 1786 to 1788 out of 10000 .
# Iterating from 1788 to 1790 out of 10000 .
# Iterating from 1790 to 1792 out of 10000 .
# Iterating from 1792 to 1794 out of 10000 .
# Iterating from 1794 to 1796 out of 10000 .
# Iterating from 1796 to 1798 out of 10000 .
# Iterating from 1798 to 1800 out of 10000 .
# Iterating from 1800 to 1802 out of 10000 .
# Iterating from 1802 to 1804 out of 10000 .
# Iterating from 1804 to 1806 out of 10000 .
# Iterating from 1806 to 1808 out of 10000 .
# Iterating from 1808 to 1810 out of 10000 .
# Iterating from 1810 to 1812 out of 10000 .
# Iterating from 1812 to 1814 out of 10000 .
# Iterating from 1814 to 1816 out of 10000 .
# Iterating from 1816 to 1818 out of 10000 .
# Iterating from 1818 to 1820 out of 10000 .
# Iterating from 1820 to 1822 out of 10000 .
# Iterating from 1822 to 1824 out of 10000 .
# Iterating from 1824 to 1826 out of 10000 .
# Iterating from 1826 to 1828 out of 10000 .
# Iterating from 1828 to 1830 out of 10000 .
# Iterating from 1830 to 1832 out of 10000 .
# Iterating from 1832 to 1834 out of 10000 .
# Iterating from 1834 to 1836 out of 10000 .
# Iterating from 1836 to 1838 out of 10000 .
# Iterating from 1838 to 1840 out of 10000 .
# Iterating from 1840 to 1842 out of 10000 .
# Iterating from 1842 to 1844 out of 10000 .
# Iterating from 1844 to 1846 out of 10000 .
# Iterating from 1846 to 1848 out of 10000 .
# Iterating from 1848 to 1850 out of 10000 .
# Iterating from 1850 to 1852 out of 10000 .
# Iterating from 1852 to 1854 out of 10000 .
# Iterating from 1854 to 1856 out of 10000 .
# Iterating from 1856 to 1858 out of 10000 .
# Iterating from 1858 to 1860 out of 10000 .
# Iterating from 1860 to 1862 out of 10000 .
# Iterating from 1862 to 1864 out of 10000 .
# Iterating from 1864 to 1866 out of 10000 .
# Iterating from 1866 to 1868 out of 10000 .
# Iterating from 1868 to 1870 out of 10000 .
# Iterating from 1870 to 1872 out of 10000 .
# Iterating from 1872 to 1874 out of 10000 .
# Iterating from 1874 to 1876 out of 10000 .
# Iterating from 1876 to 1878 out of 10000 .
# Iterating from 1878 to 1880 out of 10000 .
# Iterating from 1880 to 1882 out of 10000 .
# Iterating from 1882 to 1884 out of 10000 .
# Iterating from 1884 to 1886 out of 10000 .
# Iterating from 1886 to 1888 out of 10000 .
# Iterating from 1888 to 1890 out of 10000 .
# Iterating from 1890 to 1892 out of 10000 .
# Iterating from 1892 to 1894 out of 10000 .
# Iterating from 1894 to 1896 out of 10000 .
# Iterating from 1896 to 1898 out of 10000 .
# Iterating from 1898 to 1900 out of 10000 .
# Iterating from 1900 to 1902 out of 10000 .
# Iterating from 1902 to 1904 out of 10000 .
# Iterating from 1904 to 1906 out of 10000 .
# Iterating from 1906 to 1908 out of 10000 .
# Iterating from 1908 to 1910 out of 10000 .
# Iterating from 1910 to 1912 out of 10000 .
# Iterating from 1912 to 1914 out of 10000 .
# Iterating from 1914 to 1916 out of 10000 .
# Iterating from 1916 to 1918 out of 10000 .
# Iterating from 1918 to 1920 out of 10000 .
# Iterating from 1920 to 1922 out of 10000 .
# Iterating from 1922 to 1924 out of 10000 .
# Iterating from 1924 to 1926 out of 10000 .
# Iterating from 1926 to 1928 out of 10000 .
# Iterating from 1928 to 1930 out of 10000 .
# Iterating from 1930 to 1932 out of 10000 .
# Iterating from 1932 to 1934 out of 10000 .
# Iterating from 1934 to 1936 out of 10000 .
# Iterating from 1936 to 1938 out of 10000 .
# Iterating from 1938 to 1940 out of 10000 .
# Iterating from 1940 to 1942 out of 10000 .
# Iterating from 1942 to 1944 out of 10000 .
# Iterating from 1944 to 1946 out of 10000 .
# Iterating from 1946 to 1948 out of 10000 .
# Iterating from 1948 to 1950 out of 10000 .
# Iterating from 1950 to 1952 out of 10000 .
# Iterating from 1952 to 1954 out of 10000 .
# Iterating from 1954 to 1956 out of 10000 .
# Iterating from 1956 to 1958 out of 10000 .
# Iterating from 1958 to 1960 out of 10000 .
# Iterating from 1960 to 1962 out of 10000 .
# Iterating from 1962 to 1964 out of 10000 .
# Iterating from 1964 to 1966 out of 10000 .
# Iterating from 1966 to 1968 out of 10000 .
# Iterating from 1968 to 1970 out of 10000 .
# Iterating from 1970 to 1972 out of 10000 .
# Iterating from 1972 to 1974 out of 10000 .
# Iterating from 1974 to 1976 out of 10000 .
# Iterating from 1976 to 1978 out of 10000 .
# Iterating from 1978 to 1980 out of 10000 .
# Iterating from 1980 to 1982 out of 10000 .
# Iterating from 1982 to 1984 out of 10000 .
# Iterating from 1984 to 1986 out of 10000 .
# Iterating from 1986 to 1988 out of 10000 .
# Iterating from 1988 to 1990 out of 10000 .
# Iterating from 1990 to 1992 out of 10000 .
# Iterating from 1992 to 1994 out of 10000 .
# Iterating from 1994 to 1996 out of 10000 .
# Iterating from 1996 to 1998 out of 10000 .
# Iterating from 1998 to 2000 out of 10000 .
# Iterating from 2000 to 2002 out of 10000 .
# Iterating from 2002 to 2004 out of 10000 .
# Iterating from 2004 to 2006 out of 10000 .
# Iterating from 2006 to 2008 out of 10000 .
# Iterating from 2008 to 2010 out of 10000 .
# Iterating from 2010 to 2012 out of 10000 .
# Iterating from 2012 to 2014 out of 10000 .
# Iterating from 2014 to 2016 out of 10000 .
# Iterating from 2016 to 2018 out of 10000 .
# Iterating from 2018 to 2020 out of 10000 .
# Iterating from 2020 to 2022 out of 10000 .
# Iterating from 2022 to 2024 out of 10000 .
# Iterating from 2024 to 2026 out of 10000 .
# Iterating from 2026 to 2028 out of 10000 .
# Iterating from 2028 to 2030 out of 10000 .
# Iterating from 2030 to 2032 out of 10000 .
# Iterating from 2032 to 2034 out of 10000 .
# Iterating from 2034 to 2036 out of 10000 .
# Iterating from 2036 to 2038 out of 10000 .
# Iterating from 2038 to 2040 out of 10000 .
# Iterating from 2040 to 2042 out of 10000 .
# Iterating from 2042 to 2044 out of 10000 .
# Iterating from 2044 to 2046 out of 10000 .
# Iterating from 2046 to 2048 out of 10000 .
# Iterating from 2048 to 2050 out of 10000 .
# Iterating from 2050 to 2052 out of 10000 .
# Iterating from 2052 to 2054 out of 10000 .
# Iterating from 2054 to 2056 out of 10000 .
# Iterating from 2056 to 2058 out of 10000 .
# Iterating from 2058 to 2060 out of 10000 .
# Iterating from 2060 to 2062 out of 10000 .
# Iterating from 2062 to 2064 out of 10000 .
# Iterating from 2064 to 2066 out of 10000 .
# Iterating from 2066 to 2068 out of 10000 .
# Iterating from 2068 to 2070 out of 10000 .
# Iterating from 2070 to 2072 out of 10000 .
# Iterating from 2072 to 2074 out of 10000 .
# Iterating from 2074 to 2076 out of 10000 .
# Iterating from 2076 to 2078 out of 10000 .
# Iterating from 2078 to 2080 out of 10000 .
# Iterating from 2080 to 2082 out of 10000 .
# Iterating from 2082 to 2084 out of 10000 .
# Iterating from 2084 to 2086 out of 10000 .
# Iterating from 2086 to 2088 out of 10000 .
# Iterating from 2088 to 2090 out of 10000 .
# Iterating from 2090 to 2092 out of 10000 .
# Iterating from 2092 to 2094 out of 10000 .
# Iterating from 2094 to 2096 out of 10000 .
# Iterating from 2096 to 2098 out of 10000 .
# Iterating from 2098 to 2100 out of 10000 .
# Iterating from 2100 to 2102 out of 10000 .
# Iterating from 2102 to 2104 out of 10000 .
# Iterating from 2104 to 2106 out of 10000 .
# Iterating from 2106 to 2108 out of 10000 .
# Iterating from 2108 to 2110 out of 10000 .
# Iterating from 2110 to 2112 out of 10000 .
# Iterating from 2112 to 2114 out of 10000 .
# Iterating from 2114 to 2116 out of 10000 .
# ...
# Iterating from 9740 to 9742 out of 10000 .
# Iterating from 9742 to 9744 out of 10000 .
# Iterating from 9744 to 9746 out of 10000 .
# Iterating from 9746 to 9748 out of 10000 .
# Iterating from 9748 to 9750 out of 10000 .
# Iterating from 9750 to 9752 out of 10000 .
# Iterating from 9752 to 9754 out of 10000 .
# Iterating from 9754 to 9756 out of 10000 .
# Iterating from 9756 to 9758 out of 10000 .
# Iterating from 9758 to 9760 out of 10000 .
# Iterating from 9760 to 9762 out of 10000 .
# Iterating from 9762 to 9764 out of 10000 .
# Iterating from 9764 to 9766 out of 10000 .
# Iterating from 9766 to 9768 out of 10000 .
# Iterating from 9768 to 9770 out of 10000 .
# Iterating from 9770 to 9772 out of 10000 .
# Iterating from 9772 to 9774 out of 10000 .
# Iterating from 9774 to 9776 out of 10000 .
# Iterating from 9776 to 9778 out of 10000 .
# Iterating from 9778 to 9780 out of 10000 .
# Iterating from 9780 to 9782 out of 10000 .
# Iterating from 9782 to 9784 out of 10000 .
# Iterating from 9784 to 9786 out of 10000 .
# Iterating from 9786 to 9788 out of 10000 .
# Iterating from 9788 to 9790 out of 10000 .
# Iterating from 9790 to 9792 out of 10000 .
# Iterating from 9792 to 9794 out of 10000 .
# Iterating from 9794 to 9796 out of 10000 .
# Iterating from 9796 to 9798 out of 10000 .
# Iterating from 9798 to 9800 out of 10000 .
# Iterating from 9800 to 9802 out of 10000 .
# Iterating from 9802 to 9804 out of 10000 .
# Iterating from 9804 to 9806 out of 10000 .
# Iterating from 9806 to 9808 out of 10000 .
# Iterating from 9808 to 9810 out of 10000 .
# Iterating from 9810 to 9812 out of 10000 .
# Iterating from 9812 to 9814 out of 10000 .
# Iterating from 9814 to 9816 out of 10000 .
# Iterating from 9816 to 9818 out of 10000 .
# Iterating from 9818 to 9820 out of 10000 .
# Iterating from 9820 to 9822 out of 10000 .
# Iterating from 9822 to 9824 out of 10000 .
# Iterating from 9824 to 9826 out of 10000 .
# Iterating from 9826 to 9828 out of 10000 .
# Iterating from 9828 to 9830 out of 10000 .
# Iterating from 9830 to 9832 out of 10000 .
# Iterating from 9832 to 9834 out of 10000 .
# Iterating from 9834 to 9836 out of 10000 .
# Iterating from 9836 to 9838 out of 10000 .
# Iterating from 9838 to 9840 out of 10000 .
# Iterating from 9840 to 9842 out of 10000 .
# Iterating from 9842 to 9844 out of 10000 .
# Iterating from 9844 to 9846 out of 10000 .
# Iterating from 9846 to 9848 out of 10000 .
# Iterating from 9848 to 9850 out of 10000 .
# Iterating from 9850 to 9852 out of 10000 .
# Iterating from 9852 to 9854 out of 10000 .
# Iterating from 9854 to 9856 out of 10000 .
# Iterating from 9856 to 9858 out of 10000 .
# Iterating from 9858 to 9860 out of 10000 .
# Iterating from 9860 to 9862 out of 10000 .
# Iterating from 9862 to 9864 out of 10000 .
# Iterating from 9864 to 9866 out of 10000 .
# Iterating from 9866 to 9868 out of 10000 .
# Iterating from 9868 to 9870 out of 10000 .
# Iterating from 9870 to 9872 out of 10000 .
# Iterating from 9872 to 9874 out of 10000 .
# Iterating from 9874 to 9876 out of 10000 .
# Iterating from 9876 to 9878 out of 10000 .
# Iterating from 9878 to 9880 out of 10000 .
# Iterating from 9880 to 9882 out of 10000 .
# Iterating from 9882 to 9884 out of 10000 .
# Iterating from 9884 to 9886 out of 10000 .
# Iterating from 9886 to 9888 out of 10000 .
# Iterating from 9888 to 9890 out of 10000 .
# Iterating from 9890 to 9892 out of 10000 .
# Iterating from 9892 to 9894 out of 10000 .
# Iterating from 9894 to 9896 out of 10000 .
# Iterating from 9896 to 9898 out of 10000 .
# Iterating from 9898 to 9900 out of 10000 .
# Iterating from 9900 to 9902 out of 10000 .
# Iterating from 9902 to 9904 out of 10000 .
# Iterating from 9904 to 9906 out of 10000 .
# Iterating from 9906 to 9908 out of 10000 .
# Iterating from 9908 to 9910 out of 10000 .
# Iterating from 9910 to 9912 out of 10000 .
# Iterating from 9912 to 9914 out of 10000 .
# Iterating from 9914 to 9916 out of 10000 .
# Iterating from 9916 to 9918 out of 10000 .
# Iterating from 9918 to 9920 out of 10000 .
# Iterating from 9920 to 9922 out of 10000 .
# Iterating from 9922 to 9924 out of 10000 .
# Iterating from 9924 to 9926 out of 10000 .
# Iterating from 9926 to 9928 out of 10000 .
# Iterating from 9928 to 9930 out of 10000 .
# Iterating from 9930 to 9932 out of 10000 .
# Iterating from 9932 to 9934 out of 10000 .
# Iterating from 9934 to 9936 out of 10000 .
# Iterating from 9936 to 9938 out of 10000 .
# Iterating from 9938 to 9940 out of 10000 .
# Iterating from 9940 to 9942 out of 10000 .
# Iterating from 9942 to 9944 out of 10000 .
# Iterating from 9944 to 9946 out of 10000 .
# Iterating from 9946 to 9948 out of 10000 .
# Iterating from 9948 to 9950 out of 10000 .
# Iterating from 9950 to 9952 out of 10000 .
# Iterating from 9952 to 9954 out of 10000 .
# Iterating from 9954 to 9956 out of 10000 .
# Iterating from 9956 to 9958 out of 10000 .
# Iterating from 9958 to 9960 out of 10000 .
# Iterating from 9960 to 9962 out of 10000 .
# Iterating from 9962 to 9964 out of 10000 .
# Iterating from 9964 to 9966 out of 10000 .
# Iterating from 9966 to 9968 out of 10000 .
# Iterating from 9968 to 9970 out of 10000 .
# Iterating from 9970 to 9972 out of 10000 .
# Iterating from 9972 to 9974 out of 10000 .
# Iterating from 9974 to 9976 out of 10000 .
# Iterating from 9976 to 9978 out of 10000 .
# Iterating from 9978 to 9980 out of 10000 .
# Iterating from 9980 to 9982 out of 10000 .
# Iterating from 9982 to 9984 out of 10000 .
# Iterating from 9984 to 9986 out of 10000 .
# Iterating from 9986 to 9988 out of 10000 .
# Iterating from 9988 to 9990 out of 10000 .
# Iterating from 9990 to 9992 out of 10000 .
# Iterating from 9992 to 9994 out of 10000 .
# Iterating from 9994 to 9996 out of 10000 .
# Iterating from 9996 to 9998 out of 10000 .
# Iterating from 9998 to 10000 out of 10000 .
# MMD metric calculation completed in 13833.076675942168 seconds.
# Saving mmd to results/20D_unimodal/20D_50K/null_hypothesis/MMD.json
# Computing and savng ks with max_vectorize = 5000
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 40
# Iterating from 0 to 250 out of 10000 .
# Iterating from 250 to 500 out of 10000 .
# Iterating from 500 to 750 out of 10000 .
# Iterating from 750 to 1000 out of 10000 .
# Iterating from 1000 to 1250 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f297014be20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 1250 to 1500 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f297014be20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 1500 to 1750 out of 10000 .
# Iterating from 1750 to 2000 out of 10000 .
# Iterating from 2000 to 2250 out of 10000 .
# Iterating from 2250 to 2500 out of 10000 .
# Iterating from 2500 to 2750 out of 10000 .
# Iterating from 2750 to 3000 out of 10000 .
# Iterating from 3000 to 3250 out of 10000 .
# Iterating from 3250 to 3500 out of 10000 .
# Iterating from 3500 to 3750 out of 10000 .
# Iterating from 3750 to 4000 out of 10000 .
# Iterating from 4000 to 4250 out of 10000 .
# Iterating from 4250 to 4500 out of 10000 .
# Iterating from 4500 to 4750 out of 10000 .
# Iterating from 4750 to 5000 out of 10000 .
# Iterating from 5000 to 5250 out of 10000 .
# Iterating from 5250 to 5500 out of 10000 .
# Iterating from 5500 to 5750 out of 10000 .
# Iterating from 5750 to 6000 out of 10000 .
# Iterating from 6000 to 6250 out of 10000 .
# Iterating from 6250 to 6500 out of 10000 .
# Iterating from 6500 to 6750 out of 10000 .
# Iterating from 6750 to 7000 out of 10000 .
# Iterating from 7000 to 7250 out of 10000 .
# Iterating from 7250 to 7500 out of 10000 .
# Iterating from 7500 to 7750 out of 10000 .
# Iterating from 7750 to 8000 out of 10000 .
# Iterating from 8000 to 8250 out of 10000 .
# Iterating from 8250 to 8500 out of 10000 .
# Iterating from 8500 to 8750 out of 10000 .
# Iterating from 8750 to 9000 out of 10000 .
# Iterating from 9000 to 9250 out of 10000 .
# Iterating from 9250 to 9500 out of 10000 .
# Iterating from 9500 to 9750 out of 10000 .
# Iterating from 9750 to 10000 out of 10000 .
# KS tests calculation completed in 127.1215640050359 seconds.
# Saving ks to results/20D_unimodal/20D_50K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 200
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f2a86aafc40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 1000 to 1200 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f2a86aafc40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# SKS metric calculation completed in 473.9060416079592 seconds.
# Saving sks to results/20D_unimodal/20D_50K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 200
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# SWD metric calculation completed in 309.43829459510744 seconds.
# Saving swd to results/20D_unimodal/20D_50K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0011908243112181754], [0.95, [9500, 500], 0.009010009476391752], [0.99, [9900, 100], 0.015440000517236289]]
# Computing time for metric fgd: 3057.1982885061298
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.19680809552858136], [0.95, [9500, 500], 5.816636178460726], [0.99, [9900, 100], 11.387090444833575]]
# Computing time for metric mmd: 13833.076675942168
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9059936906408849], [0.95, [9500, 500], 1.0930413278228723], [0.99, [9900, 100], 1.2411944942991966]]
# Computing time for metric ks: 127.1215640050359
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9020088370372847], [0.95, [9500, 500], 1.064455062531687], [0.99, [9900, 100], 1.1748185833309719]]
# Computing time for metric sks: 473.9060416079592
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.7076154045690974], [0.95, [9500, 500], 0.9011635284210486], [0.99, [9900, 100], 1.0514454672424403]]
# Computing time for metric swd: 309.43829459510744
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f29940a1300>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f29940a13a0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f29940a1440>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f29940a14e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f29940a1580>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f29940a1620>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_unimodal/20D_50K/null_hypothesis/F...
# 1  $d_{\mathrm{MMD}}$  results/20D_unimodal/20D_50K/null_hypothesis/M...
# 2      $\overline{D}$  results/20D_unimodal/20D_50K/null_hypothesis/K...
# 3     $\widetilde{D}$  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 4     $\widetilde{W}$  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 5           $t_{\mu}$  results/20D_unimodal/20D_50K/null_hypothesis/L...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0011908243112181754], ...
# 1  [[0.68, [6800, 3199], 0.19680809552858136], [0...
# 2  [[0.68, [6800, 3199], 0.9059936906408849], [0....
# 3  [[0.68, [6800, 3199], 0.9020088370372847], [0....
# 4  [[0.68, [6800, 3199], 0.7076154045690974], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{2})$"
        dist_null = dist_null * 100
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-1})$"
        dist_null = dist_null / 10
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 10
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 10
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.17883033606468665 +/- 0.0011759578709100104
# sigma = 0.34292242138857154 +/- 0.006388727197886073
# 68%CL = 0.11908243112181754, 95%CL = 0.9010009476391752, 99%CL = 1.544000051723629
# mu = 0.17883033606468665 +/- 0.0011759578709100104
# sigma = 0.34292242138857154 +/- 0.006388727197886073
# /tmp/ipykernel_702946/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_702946/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_702946/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 2.4506348171271384 seconds.
# mu = -0.005897488696490378 +/- 0.0009150395149411938
# sigma = 0.30249620079286843 +/- 0.005259284757805248
# 68%CL = 0.019680809552858135, 95%CL = 0.5816636178460726, 99%CL = 1.1387090444833574
# mu = -0.005897488696490378 +/- 0.0009150395149411938
# sigma = 0.30249620079286843 +/- 0.005259284757805248
# /tmp/ipykernel_702946/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_702946/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_702946/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9691767389886081 seconds.
# mu = 0.8677013274905123 +/- 0.0001455609063015876
# sigma = 0.12064862465092074 +/- 0.0011324506008104681
# 68%CL = 0.9059936906408849, 95%CL = 1.0930413278228723, 99%CL = 1.2411944942991966
# mu = 0.8677013274905123 +/- 0.0001455609063015876
# sigma = 0.12064862465092074 +/- 0.0011324506008104681
# /tmp/ipykernel_702946/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_702946/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_702946/2214353603.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_702946/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3105588720645756 seconds.
# mu = 0.8659159333115782 +/- 0.00011105286153368035
# sigma = 0.10538162151612603 +/- 0.0009100029527844334
# 68%CL = 0.9020088370372847, 95%CL = 1.064455062531687, 99%CL = 1.1748185833309719
# mu = 0.8659159333115782 +/- 0.00011105286153368035
# sigma = 0.10538162151612603 +/- 0.0009100029527844334
# /tmp/ipykernel_702946/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_702946/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_702946/2214353603.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_702946/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3170688019599766 seconds.
# mu = 0.6724685177934482 +/- 0.0001401317878848475
# sigma = 0.11837727310799465 +/- 0.0012020646764621635
# 68%CL = 0.7076154045690974, 95%CL = 0.9011635284210486, 99%CL = 1.0514454672424403
# mu = 0.6724685177934482 +/- 0.0001401317878848475
# sigma = 0.11837727310799465 +/- 0.0012020646764621635
# /tmp/ipykernel_702946/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_702946/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_702946/2214353603.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_702946/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9624662401620299 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f29940a1300>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f29940a13a0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f29940a1440>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f29940a14e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f29940a1580>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f29940a1620>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_unimodal/20D_50K/null_hypothesis/F...
# 1  $d_{\mathrm{MMD}}$  results/20D_unimodal/20D_50K/null_hypothesis/M...
# 2      $\overline{D}$  results/20D_unimodal/20D_50K/null_hypothesis/K...
# 3     $\widetilde{D}$  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 4     $\widetilde{W}$  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 5           $t_{\mu}$  results/20D_unimodal/20D_50K/null_hypothesis/L...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0011908243112181754], ...
# 1  [[0.68, [6800, 3199], 0.19680809552858136], [0...
# 2  [[0.68, [6800, 3199], 0.9059936906408849], [0....
# 3  [[0.68, [6800, 3199], 0.9020088370372847], [0....
# 4  [[0.68, [6800, 3199], 0.7076154045690974], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/20D_unimodal/20D_50K/null_hypothesis/F...
# 1  results/20D_unimodal/20D_50K/null_hypothesis/M...
# 2  results/20D_unimodal/20D_50K/null_hypothesis/K...
# 3  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 4  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = mean
# statistic = 23.63688636143332 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9984758438698944
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 104 calls to <function generate_and_clean_data_simple_1 at 0x7f2a866c0e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 5.914108554657091 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9939153610525706
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = mean
# WARNING:tensorflow:6 out of the last 105 calls to <function generate_and_clean_data_simple_1 at 0x7f2a866c0e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.4791799632320417 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9757826362450377
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = mean
# WARNING:tensorflow:5 out of the last 54 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f27f3facea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.3707787489366746 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.905105042981896
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = mean
# WARNING:tensorflow:6 out of the last 55 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f27f0348fe0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.09325747716790753 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6475904601926974
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = mean
# statistic = 0.02385805220027568 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.903493663237485
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = mean
# statistic = 0.006522660701966704 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.3202731720770909
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.05859375 - deformation = mean
# statistic = 0.01357768691565459 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.4044394222397309
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.048828125 - deformation = mean
# statistic = 0.009572135893332409 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.06050177799776854
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0439453125 - deformation = mean
# statistic = 0.007892648806935534 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.13221123573898166
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.04638671875 - deformation = mean
# statistic = 0.008695861655570703 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.03548515839516675
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.047607421875 - deformation = mean
# statistic = 0.009054410972237113 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.025974025974025976
# relative_error_metric = 0.004915905934721637
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0469970703125 - deformation = mean
# statistic = 0.008792644182953297 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.012903225806451613
# relative_error_metric = 0.024419426181933764
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.04730224609375 - deformation = mean
# statistic = 0.008923869131892765 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.006430868167202572
# relative_error_metric = 0.00960643777963284
# =======> statistic within required accuracy at 0.95 CL in 140.63569380994886 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.047454833984375 - deformation = mean
# statistic = 0.00910169492180273 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9623930590404788
# relative_error_metric = 0.5165336364944922
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5237274169921875 - deformation = mean
# statistic = 24.089148765675382 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9261742974985905
# relative_error_metric = 1.997437832162664
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2855911254882812 - deformation = mean
# statistic = 6.251376132323616 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.857604807554729
# relative_error_metric = 1.9901449155743864
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6665229797363281 - deformation = mean
# statistic = 1.68195411295414 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.7341383271444981
# relative_error_metric = 1.9636148130956819
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.35698890686035156 - deformation = mean
# statistic = 0.48386431498850124 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.5306656605909124
# relative_error_metric = 1.8763078945023952
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.20222187042236328 - deformation = mean
# statistic = 0.15575089718921056 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.2397395007734764
# relative_error_metric = 1.6392331432547926
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.12483835220336914 - deformation = mean
# statistic = 0.0597870416777886 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.8982771742890749
# relative_error_metric = 1.1790186046550475
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.08614659309387207 - deformation = mean
# statistic = 0.028837312565274914 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.5792117637611199
# relative_error_metric = 0.6051546995669138
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.06680071353912354 - deformation = mean
# statistic = 0.01751158407105651 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.3386422799430327
# relative_error_metric = 0.12573498845067527
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.05712777376174927 - deformation = mean
# statistic = 0.012931320431258808 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.15610518595115852
# relative_error_metric = 0.17684619553186856
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0619642436504364 - deformation = mean
# statistic = 0.015186770533847432 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.07512090236736035
# relative_error_metric = 0.016536511992497272
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.06438247859477997 - deformation = mean
# statistic = 0.016304776212934028 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.03827934593586379
# relative_error_metric = 0.054483022706274316
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.06317336112260818 - deformation = mean
# statistic = 0.01569833084002124 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.01932460629024657
# relative_error_metric = 0.01659243199778853
# =======> statistic within required accuracy at 0.99 CL in 126.11784825613722 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 266.75357529404573 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_diag
# statistic = 196.6653974240997 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998167527825514
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_diag
# statistic = 49.11062186042913 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9992662803743926
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_diag
# statistic = 12.25311383491346 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.997060864955947
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_diag
# statistic = 3.053288309075124 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9882310493111548
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_diag
# statistic = 0.7578236294284267 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9530014907052866
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_diag
# statistic = 0.1870038713130629 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8161352769486827
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_diag
# statistic = 0.04561271365618802 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3402006374143787
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_diag
# statistic = 0.010987846968977932 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.19780494954439276
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_diag
# statistic = 0.0028850191526175713 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.0298403668969227
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0146484375 - deformation = cov_diag
# statistic = 0.0061048188218778545 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.3844159651944564
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01708984375 - deformation = cov_diag
# statistic = 0.008351694255360436 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.07583532482786784
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.018310546875 - deformation = cov_diag
# statistic = 0.009616713939690682 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.06514344468926805
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0177001953125 - deformation = cov_diag
# statistic = 0.008959519460828659 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.005619514650549622
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.01800537109375 - deformation = cov_diag
# statistic = 0.00933491620915732 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.017094017094017096
# relative_error_metric = 0.03542197317501359
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.017852783203125 - deformation = cov_diag
# statistic = 0.00913557761827419 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.008583690987124463
# relative_error_metric = 0.013840074859782244
# =======> statistic within required accuracy at 0.95 CL in 148.00182502297685 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0177764892578125 - deformation = cov_diag
# statistic = 0.00901004794180646 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9858291900439418
# relative_error_metric = 0.5259664483856463
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5088882446289062 - deformation = cov_diag
# statistic = 198.07314335201596 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9718577791198006
# relative_error_metric = 1.999688220284967
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2633323669433594 - deformation = cov_diag
# statistic = 50.16672539686259 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.944496553366981
# relative_error_metric = 1.9987692838366002
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6405544281005859 - deformation = cov_diag
# statistic = 12.87184802842942 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.8919905549680578
# relative_error_metric = 1.9952076804731746
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3291654586791992 - deformation = cov_diag
# statistic = 3.3891348516446853 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.7950494096950205
# relative_error_metric = 1.9818597020918112
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.17347097396850586 - deformation = cov_diag
# statistic = 0.9358750813881637 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.6281992146107336
# relative_error_metric = 1.935079340963201
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.09562373161315918 - deformation = cov_diag
# statistic = 0.2812345377275109 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.3729645631629295
# relative_error_metric = 1.7918257413179322
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.05670011043548584 - deformation = cov_diag
# statistic = 0.09750960535259778 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.0452577410344854
# relative_error_metric = 1.453207458376447
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.03723829984664917 - deformation = cov_diag
# statistic = 0.041256596004431656 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.7075119583529705
# relative_error_metric = 0.9106929541115909
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.027507394552230835 - deformation = cov_diag
# statistic = 0.022317764408280653 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.42977344148472335
# relative_error_metric = 0.3643099057696779
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.022641941905021667 - deformation = cov_diag
# statistic = 0.014894098635098893 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.19403856525027002
# relative_error_metric = 0.03599262199255857
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.02507466822862625 - deformation = cov_diag
# statistic = 0.018395433699456433 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.10196559717007721
# relative_error_metric = 0.17469456211453493
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.02385830506682396 - deformation = cov_diag
# statistic = 0.016546616981858824 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.05231641726714956
# relative_error_metric = 0.06919246554618287
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.023250123485922813 - deformation = cov_diag
# statistic = 0.01572882018649571 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.026504868574564248
# relative_error_metric = 0.01853260166656468
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.02294603269547224 - deformation = cov_diag
# statistic = 0.01529340288362734 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.01316519882115395
# relative_error_metric = 0.00953995440705593
# =======> statistic within required accuracy at 0.99 CL in 146.946573860012 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 294.9484324050136 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_off_diag
# statistic = 76.1210375736693 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995265990361266
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_off_diag
# statistic = 72.07000700893417 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999499992655333
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_off_diag
# statistic = 62.610917633942144 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9994244637567966
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_off_diag
# statistic = 28.497841201579774 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9987357411859088
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_off_diag
# statistic = 11.555186801602101 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9968834811016847
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_off_diag
# statistic = 4.3124571264353 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.991660230941924
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_off_diag
# statistic = 1.4812417406799152 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9758161411977626
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_off_diag
# statistic = 0.46871421512766764 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9245589064790734
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_off_diag
# statistic = 0.13808899435118532 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.754994684071338
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = cov_off_diag
# statistic = 0.038704222623535886 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.244669015523742
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = cov_off_diag
# statistic = 0.010698415260663525 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.17133848156796372
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.001220703125 - deformation = cov_off_diag
# statistic = 0.003500619564818299 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.8807534606654078
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0018310546875 - deformation = cov_off_diag
# statistic = 0.006358070835288984 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.34512295450292807
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00213623046875 - deformation = cov_off_diag
# statistic = 0.008406270014970654 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.06933047459654314
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.002288818359375 - deformation = cov_off_diag
# statistic = 0.009563299434339525 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.059579040073801146
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0022125244140625 - deformation = cov_off_diag
# statistic = 0.008962189781090623 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.005321518487084396
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00225067138671875 - deformation = cov_off_diag
# statistic = 0.009225458542710164 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.017094017094017096
# relative_error_metric = 0.02362967225110165
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.002231597900390625 - deformation = cov_off_diag
# statistic = 0.009066188310220187 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.008583690987124463
# relative_error_metric = 0.006215779943506064
# =======> statistic within required accuracy at 0.95 CL in 176.29920382006094 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0022220611572265625 - deformation = cov_off_diag
# statistic = 0.008949050439966135 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9982231407322109
# relative_error_metric = 0.5322839407454095
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5011110305786133 - deformation = cov_off_diag
# statistic = 76.13030913004907 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9964494358907934
# relative_error_metric = 1.999188923836536
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.25166654586792 - deformation = cov_off_diag
# statistic = 72.03187219216986 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.992911455946638
# relative_error_metric = 1.9991427854809662
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6269443035125732 - deformation = cov_off_diag
# statistic = 62.80136331542211 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9858729818883898
# relative_error_metric = 1.99901682354388
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3145831823348999 - deformation = cov_off_diag
# statistic = 28.733477981049113 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9719441366218198
# relative_error_metric = 1.997851745164512
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.15840262174606323 - deformation = cov_off_diag
# statistic = 11.772756082298251 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9446645156382487
# relative_error_metric = 1.9947608606410123
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.0803123414516449 - deformation = cov_off_diag
# statistic = 4.492222730128794 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.8923086089199987
# relative_error_metric = 1.9862988857509105
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04126720130443573 - deformation = cov_off_diag
# statistic = 1.6168687002826823 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.7956220886306906
# relative_error_metric = 1.9621640183387616
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.021744631230831146 - deformation = cov_off_diag
# statistic = 0.563072411114344 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.629141790406792
# relative_error_metric = 1.8932434277515964
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.011983346194028854 - deformation = cov_off_diag
# statistic = 0.19937473911497167 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.374305543718129
# relative_error_metric = 1.7124964414700468
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0071027036756277084 - deformation = cov_off_diag
# statistic = 0.07718449102956096 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.0468129986946173
# relative_error_metric = 1.3332216885882524
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0046623824164271355 - deformation = cov_off_diag
# statistic = 0.03552208879969735 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.7089378344357468
# relative_error_metric = 0.7881187192923113
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.003442221786826849 - deformation = cov_off_diag
# statistic = 0.020214347208572223 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.4308261581040048
# relative_error_metric = 0.26781287533581816
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0028321414720267057 - deformation = cov_off_diag
# statistic = 0.014094492075635023 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.1944676422549422
# relative_error_metric = 0.09111437668145547
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0031371816294267774 - deformation = cov_off_diag
# statistic = 0.017014173218772126 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.10220259557596965
# relative_error_metric = 0.0970089526444648
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.0029846615507267416 - deformation = cov_off_diag
# statistic = 0.015517819935648838 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.052441204594147924
# relative_error_metric = 0.005027448139056365
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0029084015113767236 - deformation = cov_off_diag
# statistic = 0.014774417356322306 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.0258812907808245
# relative_error_metric = 0.04405732148799407
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.0029465315310517326 - deformation = cov_off_diag
# statistic = 0.01512166473916034 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.012857453517117885
# relative_error_metric = 0.020832358145753866
#
# ------------ 19 - 0.99 CL ------------
# eps = 0.002965596540889237 - deformation = cov_off_diag
# statistic = 0.015162506034506407 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.00640812870432206
# relative_error_metric = 0.018135408762069493
# =======> statistic within required accuracy at 0.99 CL in 186.31842751498334 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 362.61766587686725 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_up
# statistic = 4091850.333942628 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999999911922395
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_up
# statistic = 15966.49838141126 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999977427726037
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_up
# statistic = 783.0754726579814 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999539768202497
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_up
# statistic = 97.44955689620477 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9996302014379046
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_up
# statistic = 17.649997143939594 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9979591130128405
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_up
# statistic = 3.7755683471372437 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9904771325866233
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_up
# statistic = 0.8723327174570257 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9591078058464653
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_up
# statistic = 0.20850048442174077 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.834306670636104
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.05053166495947749 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.394709029481783
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.012374536907358928 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.31466904844179955
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_up
# statistic = 0.003255408913877521 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.9383455793207387
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_up
# statistic = 0.006962650880840379 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.2563578702309745
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0042724609375 - deformation = power_abs_up
# statistic = 0.009480602731354613 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.05090077599115011
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00396728515625 - deformation = power_abs_up
# statistic = 0.007863897101425583 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.1358443428237138
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.004119873046875 - deformation = power_abs_up
# statistic = 0.008774841849256776 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.02644583559670552
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0041961669921875 - deformation = power_abs_up
# statistic = 0.009123654034924121 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.01834862385321101
# relative_error_metric = 0.012534098083539719
# =======> statistic within required accuracy at 0.95 CL in 157.34659991390072 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00415802001953125 - deformation = power_abs_up
# statistic = 0.009027707567469944 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.99667634794673
# relative_error_metric = 0.5241433261805513
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5020790100097656 - deformation = power_abs_up
# statistic = 4130528.43622272 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.993363724229256
# relative_error_metric = 1.9999999850479173
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2531185150146484 - deformation = power_abs_up
# statistic = 16189.955414842048 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.986771342966587
# relative_error_metric = 1.9999961852925725
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6286382675170898 - deformation = power_abs_up
# statistic = 799.0570968205936 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9737165334157203
# relative_error_metric = 1.9999227103933332
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31639814376831055 - deformation = power_abs_up
# statistic = 100.71947748737114 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9481149266275446
# relative_error_metric = 1.999386905716418
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.1602780818939209 - deformation = power_abs_up
# statistic = 18.72118632667432 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.8988538411906712
# relative_error_metric = 1.996703782154244
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08221805095672607 - deformation = power_abs_up
# statistic = 4.215737013221582 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.807445744056861
# relative_error_metric = 1.9854035882052663
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04318803548812866 - deformation = power_abs_up
# statistic = 1.073396355939501 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.6487124450011645
# relative_error_metric = 1.9432788942959958
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.023673027753829956 - deformation = power_abs_up
# statistic = 0.30961045612702487 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.4023911635103952
# relative_error_metric = 1.8099987223320966
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.013915523886680603 - deformation = power_abs_up
# statistic = 0.10395119069214025 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.0797554611075155
# relative_error_metric = 1.4827088879560926
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.009036771953105927 - deformation = power_abs_up
# statistic = 0.04315786797066078 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.7394966049774842
# relative_error_metric = 0.9460367132346938
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.006597395986318588 - deformation = power_abs_up
# statistic = 0.02272529844071967 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.45360885445259747
# relative_error_metric = 0.3817760176074651
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.005377708002924919 - deformation = power_abs_up
# statistic = 0.015011738552722701 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.20370394854011106
# relative_error_metric = 0.02812725825147199
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.005987551994621754 - deformation = power_abs_up
# statistic = 0.01866832215192533 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.1073172090789787
# relative_error_metric = 0.18929817604944066
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.005682629998773336 - deformation = power_abs_up
# statistic = 0.016810224440618526 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.055137916364146944
# relative_error_metric = 0.08497453429691551
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.005530169000849128 - deformation = power_abs_up
# statistic = 0.015899636619887365 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.027954293557116244
# relative_error_metric = 0.029332573356863158
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0054539385018870234 - deformation = power_abs_up
# statistic = 0.01544951917662015 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.014075514544947352
# relative_error_metric = 0.0006163034892221512
# =======> statistic within required accuracy at 0.99 CL in 166.60871797706932 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 323.95535302488133 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_down
# statistic = 1.0 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.96428178356301
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_down
# statistic = 129.5539015802046 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997218336832405
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_down
# statistic = 74.70792348713346 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995176456498014
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_down
# statistic = 30.27749979422706 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.998810030005466
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_down
# statistic = 9.875186746942335 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9963537717030815
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_down
# statistic = 2.8438307380588883 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9873669646871444
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_down
# statistic = 0.7677352097920994 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9536012105236926
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_down
# statistic = 0.20099614092901502 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8283857980540408
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.052162227378589 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4108432230293282
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.014000322421062753 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.43374541200972855
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_down
# statistic = 0.004409572363762991 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.6856304715640399
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_down
# statistic = 0.008262542841916527 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.08654964485855829
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0042724609375 - deformation = power_abs_down
# statistic = 0.010911641941697707 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.19091112733547944
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00396728515625 - deformation = power_abs_down
# statistic = 0.009537769221873087 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.056908134830259534
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.003814697265625 - deformation = power_abs_down
# statistic = 0.008874456997421088 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.0392156862745098
# relative_error_metric = 0.015158683002274126
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0038909912109375 - deformation = power_abs_down
# statistic = 0.009186559376633926 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.019801980198019802
# relative_error_metric = 0.01940474620992273
# =======> statistic within required accuracy at 0.95 CL in 157.2476432819385 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00385284423828125 - deformation = power_abs_down
# statistic = 0.00903203697291439 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9969200978859978
# relative_error_metric = 0.5236967740753853
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5019264221191406 - deformation = power_abs_down
# statistic = 1.0 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9938496669838248
# relative_error_metric = 1.939179073074247
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.252889633178711 - deformation = power_abs_down
# statistic = 129.66861822853807 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.987737044597394
# relative_error_metric = 1.9995237656585374
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6283712387084961 - deformation = power_abs_down
# statistic = 75.1462769501139 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9756235528370052
# relative_error_metric = 1.999178305065736
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31611204147338867 - deformation = power_abs_down
# statistic = 30.79870238716864 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.9518341616804393
# relative_error_metric = 1.9979957254272431
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.15998244285583496 - deformation = power_abs_down
# statistic = 10.2838269598789 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.905933714119402
# relative_error_metric = 1.9940034565269131
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.0819176435470581 - deformation = power_abs_down
# statistic = 3.104625849628577 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.8203184177791367
# relative_error_metric = 1.9802055453201222
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04288524389266968 - deformation = power_abs_down
# statistic = 0.917582515776667 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.6702608606936307
# relative_error_metric = 1.9338065255763983
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.023369044065475464 - deformation = power_abs_down
# statistic = 0.2847060187006448 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.4338608409102105
# relative_error_metric = 1.7942334793249002
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.013610944151878357 - deformation = power_abs_down
# statistic = 0.09967558671329287 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 1.117523837965827
# relative_error_metric = 1.4634957475805142
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.008731894195079803 - deformation = power_abs_down
# statistic = 0.04234504666614806 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.7753915558331532
# relative_error_metric = 0.9312113586591692
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.006292369216680527 - deformation = power_abs_down
# statistic = 0.0225426114234139 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.4809213703051589
# relative_error_metric = 0.37399275843777197
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.005072606727480888 - deformation = power_abs_down
# statistic = 0.015042853451447019 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.2146528941535108
# relative_error_metric = 0.026057078920319016
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0056824879720807076 - deformation = power_abs_down
# statistic = 0.018594837918905822 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.11341252897097771
# relative_error_metric = 0.18538871031157084
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.005377547349780798 - deformation = power_abs_down
# statistic = 0.016795402157184867 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.058360981100446116
# relative_error_metric = 0.08409397913456754
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.005225077038630843 - deformation = power_abs_down
# statistic = 0.015871619010297287 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.029612544842698263
# relative_error_metric = 0.027569221878252483
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.005148841883055866 - deformation = power_abs_down
# statistic = 0.015441412118498216 - next threshold = 0.015440000517236289 at 0.99 CL
# relative_error_eps = 0.014916702804021454
# relative_error_metric = 9.142077006501542e-05
# =======> statistic within required accuracy at 0.99 CL in 168.3243880351074 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 325.5720665110275 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with random_normal deformation.
#
# ======================================================
# =============== fgd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 63.49714249126195 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9994324953333436
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 9.979164189003672 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9963917291399413
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 1.154535612604182 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9690256770154633
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 0.09815925829797204 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6637092083017087
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 0.00726654364443014 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.21423034951193337
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.234375 - deformation = random_normal
# statistic = 0.03328875977983863 - next threshold = 0.009010009476391752 at 0.95 CL
# relative_error_eps = 0.4
# ...
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04379361867904663 - deformation = power_abs_down
# statistic = 5.673586856591469 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 1.6072342540826159
# relative_error_metric = 1.3746079325055103
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.02428099513053894 - deformation = power_abs_down
# statistic = 3.246547810933471 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 1.3434112861444392
# relative_error_metric = 1.0214545261562822
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.014524683356285095 - deformation = power_abs_down
# statistic = 2.025686355202667 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 1.0113807072489738
# relative_error_metric = 0.633213618509258
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.009646527469158173 - deformation = power_abs_down
# statistic = 1.4316153505755846 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.6768213734697517
# relative_error_metric = 0.30621069013300806
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.007207449525594711 - deformation = power_abs_down
# statistic = 1.1506235280295785 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.40733373046300864
# relative_error_metric = 0.09007716016172042
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.005987910553812981 - deformation = power_abs_down
# statistic = 1.0190989612177326 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.1848436063044477
# relative_error_metric = 0.031244445258065
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.006597680039703846 - deformation = power_abs_down
# statistic = 1.0838473447017694 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.0968996220495165
# relative_error_metric = 0.030348884497791013
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.006292795296758413 - deformation = power_abs_down
# statistic = 1.0511958008905706 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.04730387902500841
# relative_error_metric = 0.0002374787897997564
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.00644523766823113 - deformation = power_abs_down
# statistic = 1.0674521485118966 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.023934994027995354
# relative_error_metric = 0.015108499014246065
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0063690164824947715 - deformation = power_abs_down
# statistic = 1.0593039296024511 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.01203953858503081
# relative_error_metric = 0.0074461348862707695
# =======> statistic within required accuracy at 0.99 CL in 122.33796258200891 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 228.51018429687247 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 32.07821795068864 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8906997659744615
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 9.695099885974631 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.659818374391576
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 2.6798854860742334 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9934083283715569
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 0.941748528912117 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.0440444245069382
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 0.6614365616005888 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.3068308626772705
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.234375 - deformation = random_normal
# statistic = 0.7570856851014769 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.1737710377241974
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.2734375 - deformation = random_normal
# statistic = 0.8379453340968185 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.07270182527010227
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.29296875 - deformation = random_normal
# statistic = 0.8870849858548251 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.015745621991386863
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.302734375 - deformation = random_normal
# statistic = 0.9153630203203573 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.015633673957748558
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.2978515625 - deformation = random_normal
# statistic = 0.8989689342021628 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.016260162601626018
# relative_error_metric = 0.0024382585886904774
# =======> statistic within required accuracy at 0.95 CL in 73.28522188402712 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.30029296875 - deformation = random_normal
# statistic = 0.9089338899781872 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 1.773376324274528
# relative_error_metric = 0.14539183626816193
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.650146484375 - deformation = random_normal
# statistic = 35.177301255377444 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 1.5928837401737692
# relative_error_metric = 1.883910368162313
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.4752197265625 - deformation = random_normal
# statistic = 13.054889864109825 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 1.323478858714335
# relative_error_metric = 1.7018515602970157
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.88775634765625 - deformation = random_normal
# statistic = 5.139764959943701 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.9889545337785769
# relative_error_metric = 1.3206850391481109
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.594024658203125 - deformation = random_normal
# statistic = 2.4540383779041184 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.6568844907012455
# relative_error_metric = 0.8002278559084547
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.4471588134765625 - deformation = random_normal
# statistic = 1.506319034791571 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.39297744207410434
# relative_error_metric = 0.3556805696438445
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.37372589111328125 - deformation = random_normal
# statistic = 1.1638757110308136 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.21789574961797498
# relative_error_metric = 0.10150243214485745
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.3370094299316406 - deformation = random_normal
# statistic = 1.019981297150945 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.10331964683466173
# relative_error_metric = 0.030379225210705928
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.35536766052246094 - deformation = random_normal
# statistic = 1.0855457445199874 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.053029572595418795
# relative_error_metric = 0.03191428873441538
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.3461885452270508 - deformation = random_normal
# statistic = 1.053272401734912 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.026871026054426043
# relative_error_metric = 0.0017360374227823796
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.3415989875793457 - deformation = random_normal
# statistic = 1.0450053327810531 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.013345858797347468
# relative_error_metric = 0.006143845075033448
# =======> statistic within required accuracy at 0.99 CL in 79.01670380984433 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 152.30195716489106 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_uniform
# statistic = 12.613203498970782 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7332724421071264
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_uniform
# statistic = 3.505623337348335 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1820221346114828
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_uniform
# statistic = 1.1169278603752018 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.21383009030413838
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_uniform
# statistic = 0.6815739878520215 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2774806792804187
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_uniform
# statistic = 0.8323930190060604 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.07934037054292259
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.546875 - deformation = random_uniform
# statistic = 0.9559010267618661 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.05895056064480857
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.5078125 - deformation = random_uniform
# statistic = 0.8883846567242603 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.01428167377985494
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.52734375 - deformation = random_uniform
# statistic = 0.918057227764429 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.03773584905660377
# relative_error_metric = 0.018572456680631646
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.517578125 - deformation = random_uniform
# statistic = 0.9026215840957369 - next threshold = 0.9011635284210486 at 0.95 CL
# relative_error_eps = 0.01904761904761905
# relative_error_metric = 0.0016166622781955077
# =======> statistic within required accuracy at 0.95 CL in 62.40138070588 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.5126953125 - deformation = random_uniform
# statistic = 0.8995098192455453 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 1.6279893711248892
# relative_error_metric = 0.15575513088298615
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.75634765625 - deformation = random_uniform
# statistic = 15.001926474270135 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 1.3726661687826736
# relative_error_metric = 1.7380125568452078
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.634521484375 - deformation = random_uniform
# statistic = 5.778315728202093 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 1.0449118817509948
# relative_error_metric = 1.3841978147383796
#
# ------------ 4 - 0.99 CL ------------
# eps = 1.0736083984375 - deformation = random_uniform
# statistic = 2.648708645028251 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.7071950750288573
# relative_error_metric = 0.863349541300922
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.79315185546875 - deformation = random_uniform
# statistic = 1.5632790585221472 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.42953961205889224
# relative_error_metric = 0.3915009678734999
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.652923583984375 - deformation = random_uniform
# statistic = 1.1760118858466564 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.24060740934677313
# relative_error_metric = 0.11184628826357922
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.5828094482421875 - deformation = random_uniform
# statistic = 1.0206953315733525 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.1134778045317034
# relative_error_metric = 0.02967958131673406
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.6178665161132812 - deformation = random_uniform
# statistic = 1.0969275045223223 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.058395552025417
# relative_error_metric = 0.042340913684574294
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.6003379821777344 - deformation = random_uniform
# statistic = 1.0585583907721938 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.02963034611726395
# relative_error_metric = 0.006742095283604202
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.5915737152099609 - deformation = random_uniform
# statistic = 1.0397007602142214 - next threshold = 1.0514454672424403 at 0.99 CL
# relative_error_eps = 0.01470623534777286
# relative_error_metric = 0.011232793645907043
# =======> statistic within required accuracy at 0.99 CL in 68.7588338709902 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 131.16024807700887 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-03T00:10:35.972227', 'fgd_cov_diag_2024-05-03T00:15:02.727757', 'fgd_cov_off_diag_2024-05-03T00:19:57.678755', 'fgd_power_abs_up_2024-05-03T00:26:00.299897', 'fgd_power_abs_down_2024-05-03T00:31:24.258125', 'fgd_random_normal_2024-05-03T00:36:49.835192', 'fgd_random_uniform_2024-05-03T00:41:03.422110', 'mmd_mean_2024-05-03T00:44:44.982358', 'mmd_cov_diag_2024-05-03T00:54:08.755554', 'mmd_cov_off_diag_2024-05-03T01:04:28.225491', 'mmd_power_abs_up_2024-05-03T01:15:53.947626', 'mmd_power_abs_down_2024-05-03T01:29:01.744940', 'mmd_random_normal_2024-05-03T01:41:31.158061', 'mmd_random_uniform_2024-05-03T01:49:47.010498', 'ks_mean_2024-05-03T01:57:19.772642', 'ks_cov_diag_2024-05-03T02:00:33.142331', 'ks_cov_off_diag_2024-05-03T02:04:05.759314', 'ks_power_abs_up_2024-05-03T02:07:03.647243', 'ks_power_abs_down_2024-05-03T02:11:01.792258', 'ks_random_normal_2024-05-03T02:14:59.355120', 'ks_random_uniform_2024-05-03T02:17:51.540040', 'sks_mean_2024-05-03T02:20:18.393124', 'sks_cov_diag_2024-05-03T02:24:46.478011', 'sks_cov_off_diag_2024-05-03T02:29:45.831919', 'sks_power_abs_up_2024-05-03T02:35:21.450670', 'sks_power_abs_down_2024-05-03T02:41:02.064266', 'sks_random_normal_2024-05-03T02:46:44.143148', 'sks_random_uniform_2024-05-03T02:50:20.933694', 'swd_mean_2024-05-03T02:53:34.778667', 'swd_cov_diag_2024-05-03T02:56:32.010644', 'swd_cov_off_diag_2024-05-03T02:59:54.710430', 'swd_power_abs_up_2024-05-03T03:03:34.836965', 'swd_power_abs_down_2024-05-03T03:07:15.773184', 'swd_random_normal_2024-05-03T03:11:04.292683', 'swd_random_uniform_2024-05-03T03:13:36.603871'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normnal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.005 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.66767944791354 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], 1.8864065620157722], [0.99, [9900, 100], 3.365364992887095]]
# Null distribution computed in 44.84228738793172 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.171307656913996 seconds.
# statistic = 1.6037702767709168 - next threshold = 1.8864065620157722 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.1619610113183319
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.0075 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.43396531813778 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.007500.json
# ThresholdS: [[0.95, [9500, 500], 1.6682951879790462], [0.99, [9900, 100], 3.8867328346153025]]
# Null distribution computed in 44.60107061616145 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.1775664400774986 seconds.
# statistic = 3.5669700701351323 - next threshold = 1.6682951879790462 at 0.95 CL
# relative_error_eps = 0.3999999999999999
# relative_error_metric = 0.7253404702706572
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.00625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.57507187104784 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.006250.json
# ThresholdS: [[0.95, [9500, 500], 1.8741270961413694], [0.99, [9900, 100], 3.722825134895159]]
# Null distribution computed in 44.742245136993006 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.203069355105981 seconds.
# statistic = 2.4885939521115006 - next threshold = 1.8741270961413694 at 0.95 CL
# relative_error_eps = 0.22222222222222227
# relative_error_metric = 0.2816897294940301
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.005625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.57900315383449 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.005625.json
# ThresholdS: [[0.95, [9500, 500], 1.9044608837060162], [0.99, [9900, 100], 3.5682891188478445]]
# Null distribution computed in 44.74969356087968 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.177662483183667 seconds.
# statistic = 2.0219880590893635 - next threshold = 1.9044608837060162 at 0.95 CL
# relative_error_eps = 0.11764705882352937
# relative_error_metric = 0.059864359422779366
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.0053124999999999995 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.515260425861925 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.005312.json
# ThresholdS: [[0.95, [9500, 500], 1.9014822368470279], [0.99, [9900, 100], 3.472875569853603]]
# Null distribution computed in 44.68142264895141 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.156974710058421 seconds.
# statistic = 1.8068306542074244 - next threshold = 1.9014822368470279 at 0.95 CL
# relative_error_eps = 0.0571428571428572
# relative_error_metric = 0.05104832597482867
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.00546875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.52886175783351 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.005469.json
# ThresholdS: [[0.95, [9500, 500], 1.9044836891023278], [0.99, [9900, 100], 3.5220944731765296]]
# Null distribution computed in 44.69416830595583 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.19203277095221 seconds.
# statistic = 1.912897228250643 - next threshold = 1.9044836891023278 at 0.95 CL
# relative_error_eps = 0.02898550724637684
# relative_error_metric = 0.004408016559243023
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.005390625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.47766001103446 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.005391.json
# ThresholdS: [[0.95, [9500, 500], 1.9033609958396736], [0.99, [9900, 100], 3.4978630533922455]]
# Null distribution computed in 44.64473525714129 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.157713114982471 seconds.
# statistic = 1.8594859090884366 - next threshold = 1.9033609958396736 at 0.95 CL
# relative_error_eps = 0.014388489208633108
# relative_error_metric = 0.02332015511647568
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.0054296875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.659470210783184 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.005430.json
# ThresholdS: [[0.95, [9500, 500], 1.9040168501933414], [0.99, [9900, 100], 3.5100732713360006]]
# Null distribution computed in 44.837044056970626 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.179408869007602 seconds.
# statistic = 1.886097060716708 - next threshold = 1.9040168501933414 at 0.95 CL
# relative_error_eps = 0.007168458781362013
# relative_error_metric = 0.009456069077528424
# =======> statistic within required accuracy at 0.95 CL in 453.0339344779495 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00544921875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.63766592205502 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.005449.json
# ThresholdS: [[0.95, [9500, 500], 1.9042738965784196], [0.99, [9900, 100], 3.516107499516122]]
# Null distribution computed in 44.8191057019867 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.17959186504595 seconds.
# statistic = 1.8994735173225996 - next threshold = 3.516107499516122 at 0.99 CL
# relative_error_eps = 0.5891276864728192
# relative_error_metric = 0.5970306702704311
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.007724609375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.56520251883194 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.007725.json
# ThresholdS: [[0.95, [9500, 500], 1.6107956182551106], [0.99, [9900, 100], 3.8956708502660127]]
# Null distribution computed in 44.73161613382399 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.17263119504787 seconds.
# statistic = 3.781254927646724 - next threshold = 3.8956708502660127 at 0.99 CL
# relative_error_eps = 0.25674931129476586
# relative_error_metric = 0.0298077449044706
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.0088623046875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.45264067687094 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.008862.json
# ThresholdS: [[0.95, [9500, 500], 1.2235527429216113], [0.99, [9900, 100], 3.844948790127657]]
# Null distribution computed in 44.62932687602006 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.2516874701250345 seconds.
# statistic = 4.962649368519651 - next threshold = 3.844948790127657 at 0.99 CL
# relative_error_eps = 0.13717986458639966
# relative_error_metric = 0.2538037177126739
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.00829345703125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.5396945818793 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.008293.json
# ThresholdS: [[0.95, [9500, 500], 1.4372161585203633], [0.99, [9900, 100], 3.890351798128837]]
# Null distribution computed in 44.706149094039574 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.18945744400844 seconds.
# statistic = 4.351910170348748 - next threshold = 3.890351798128837 at 0.99 CL
# relative_error_eps = 0.07102575826855657
# relative_error_metric = 0.11199798647146476
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.008009033203125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# ...
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 45.17902288096957 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_power_abs_down_0.000606.json
# ThresholdS: [[0.95, [9500, 500], 1.4671333251460246], [0.99, [9900, 100], 3.847000264929867]]
# Null distribution computed in 45.34261558391154 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.397744976915419 seconds.
# statistic = 3.93428576633235 - next threshold = 3.847000264929867 at 0.99 CL
# relative_error_eps = 0.06374641126952738
# relative_error_metric = 0.022434723785195284
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.0005871224403381347 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 45.019795092055574 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_power_abs_down_0.000587.json
# ThresholdS: [[0.95, [9500, 500], 1.5416607234792763], [0.99, [9900, 100], 3.8479786296025185]]
# Null distribution computed in 45.18499515205622 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.38201165292412 seconds.
# statistic = 3.6930583288637764 - next threshold = 3.8479786296025185 at 0.99 CL
# relative_error_eps = 0.031373223040073006
# relative_error_metric = 0.04108726733259505
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0005964791774749755 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 45.148656194796786 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_power_abs_down_0.000596.json
# ThresholdS: [[0.95, [9500, 500], 1.5053542776947368], [0.99, [9900, 100], 3.848446487938403]]
# Null distribution computed in 45.311832951847464 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.35311478911899 seconds.
# statistic = 3.8127191633624418 - next threshold = 3.848446487938403 at 0.99 CL
# relative_error_eps = 0.015564534119921808
# relative_error_metric = 0.009326863874792965
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.000601157546043396 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.972528035985306 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_power_abs_down_0.000601.json
# ThresholdS: [[0.95, [9500, 500], 1.4863613950789931], [0.99, [9900, 100], 3.847958033623031]]
# Null distribution computed in 45.13859897479415 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.371128741884604 seconds.
# statistic = 3.8736514139173757 - next threshold = 3.847958033623031 at 0.99 CL
# relative_error_eps = 0.007812667191227357
# relative_error_metric = 0.006654928734456799
# =======> statistic within required accuracy at 0.99 CL in 697.4091267620679 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1389.6696560741402 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-03T00:10:35.972227', 'fgd_cov_diag_2024-05-03T00:15:02.727757', 'fgd_cov_off_diag_2024-05-03T00:19:57.678755', 'fgd_power_abs_up_2024-05-03T00:26:00.299897', 'fgd_power_abs_down_2024-05-03T00:31:24.258125', 'fgd_random_normal_2024-05-03T00:36:49.835192', 'fgd_random_uniform_2024-05-03T00:41:03.422110', 'mmd_mean_2024-05-03T00:44:44.982358', 'mmd_cov_diag_2024-05-03T00:54:08.755554', 'mmd_cov_off_diag_2024-05-03T01:04:28.225491', 'mmd_power_abs_up_2024-05-03T01:15:53.947626', 'mmd_power_abs_down_2024-05-03T01:29:01.744940', 'mmd_random_normal_2024-05-03T01:41:31.158061', 'mmd_random_uniform_2024-05-03T01:49:47.010498', 'ks_mean_2024-05-03T01:57:19.772642', 'ks_cov_diag_2024-05-03T02:00:33.142331', 'ks_cov_off_diag_2024-05-03T02:04:05.759314', 'ks_power_abs_up_2024-05-03T02:07:03.647243', 'ks_power_abs_down_2024-05-03T02:11:01.792258', 'ks_random_normal_2024-05-03T02:14:59.355120', 'ks_random_uniform_2024-05-03T02:17:51.540040', 'sks_mean_2024-05-03T02:20:18.393124', 'sks_cov_diag_2024-05-03T02:24:46.478011', 'sks_cov_off_diag_2024-05-03T02:29:45.831919', 'sks_power_abs_up_2024-05-03T02:35:21.450670', 'sks_power_abs_down_2024-05-03T02:41:02.064266', 'sks_random_normal_2024-05-03T02:46:44.143148', 'sks_random_uniform_2024-05-03T02:50:20.933694', 'swd_mean_2024-05-03T02:53:34.778667', 'swd_cov_diag_2024-05-03T02:56:32.010644', 'swd_cov_off_diag_2024-05-03T02:59:54.710430', 'swd_power_abs_up_2024-05-03T03:03:34.836965', 'swd_power_abs_down_2024-05-03T03:07:15.773184', 'swd_random_normal_2024-05-03T03:11:04.292683', 'swd_random_uniform_2024-05-03T03:13:36.603871', 'lr_mean_2024-05-03T03:15:47.792390', 'lr_cov_diag_2024-05-03T03:30:54.228906', 'lr_cov_off_diag_2024-05-03T03:51:12.600362', 'lr_power_abs_up_2024-05-03T04:24:02.465153', 'lr_power_abs_down_2024-05-03T04:46:58.586716'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean   20  10000                50000
# 0        fgd        mean   20  10000                50000
# 14        ks        mean   20  10000                50000
# 21       sks        mean   20  10000                50000
# 28       swd        mean   20  10000                50000
# 7        mmd        mean   20  10000                50000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.00545                             0.00785
# 0                              0.04745                             0.06257
# 14                             0.04913                             0.06545
# 21                             0.05096                             0.06486
# 28                             0.05096                             0.06607
# 7                              0.06134                             0.08244
#
#     $t^{\mu}$ (s)
# 35            906
# 0             266
# 14            193
# 21            268
# 28            177
# 7             563
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.00545
# 0        fgd                             0.04745
# 14        ks                             0.04913
# 21       sks                             0.05096
# 28       swd                             0.05096
# 7        mmd                             0.06134
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.00785            906
# 0                              0.06257            266
# 14                             0.06545            193
# 21                             0.06486            268
# 28                             0.06607            177
# 7                              0.08244            563

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag   20  10000                50000
# 1        fgd    cov_diag   20  10000                50000
# 29       swd    cov_diag   20  10000                50000
# 8        mmd    cov_diag   20  10000                50000
# 22       sks    cov_diag   20  10000                50000
# 15        ks    cov_diag   20  10000                50000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00226
# 1                                      0.01778
# 29                                     0.02182
# 8                                      0.02426
# 22                                     0.02792
# 15                                     0.02975
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00292                   1218
# 1                                      0.02310                    294
# 29                                     0.02835                    202
# 8                                      0.03185                    619
# 22                                     0.03551                    299
# 15                                     0.04037                    212
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00226
# 1        fgd                                     0.01778
# 29       swd                                     0.02182
# 8        mmd                                     0.02426
# 22       sks                                     0.02792
# 15        ks                                     0.02975
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00292                   1218
# 1                                      0.02310                    294
# 29                                     0.02835                    202
# 8                                      0.03185                    619
# 22                                     0.03551                    299
# 15                                     0.04037                    212

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag   20  10000                50000
# 2        fgd  cov_off_diag   20  10000                50000
# 23       sks  cov_off_diag   20  10000                50000
# 9        mmd  cov_off_diag   20  10000                50000
# 30       swd  cov_off_diag   20  10000                50000
# 16        ks  cov_off_diag   20  10000                50000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00005
# 2                                           0.00222
# 23                                          0.01198
# 9                                           0.01274
# 30                                          0.01289
# 16                                          1.01440
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00009
# 2                                           0.00298
# 23                                          0.01609
# 9                                           0.01754
# 30                                          0.01761
# 16                                          1.02024
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        1969
# 2                          362
# 23                         335
# 9                          685
# 30                         220
# 16                         177
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00005
# 2        fgd                                          0.00222
# 23       sks                                          0.01198
# 9        mmd                                          0.01274
# 30       swd                                          0.01289
# 16        ks                                          1.01440
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00009
# 2                                           0.00298
# 23                                          0.01609
# 9                                           0.01754
# 30                                          0.01761
# 16                                          1.02024
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        1969
# 2                          362
# 23                         335
# 9                          685
# 30                         220
# 16                         177

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up   20  10000                50000
# 10       mmd  power_abs_up   20  10000                50000
# 3        fgd  power_abs_up   20  10000                50000
# 31       swd  power_abs_up   20  10000                50000
# 24       sks  power_abs_up   20  10000                50000
# 17        ks  power_abs_up   20  10000                50000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00041
# 10                                      0.00373
# 3                                       0.00416
# 31                                      0.00484
# 24                                      0.00515
# 17                                      0.00607
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00061                    1376
# 10                                      0.00497                     787
# 3                                       0.00542                     323
# 31                                      0.00633                     220
# 24                                      0.00656                     340
# 17                                      0.00797                     238
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00041
# 10       mmd                                      0.00373
# 3        fgd                                      0.00416
# 31       swd                                      0.00484
# 24       sks                                      0.00515
# 17        ks                                      0.00607
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00061                    1376
# 10                                      0.00497                     787
# 3                                       0.00542                     323
# 31                                      0.00633                     220
# 24                                      0.00656                     340
# 17                                      0.00797                     238

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down   20  10000                50000
# 11       mmd  power_abs_down   20  10000                50000
# 4        fgd  power_abs_down   20  10000                50000
# 32       swd  power_abs_down   20  10000                50000
# 25       sks  power_abs_down   20  10000                50000
# 18        ks  power_abs_down   20  10000                50000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00042
# 11                                      0.00341
# 4                                       0.00385
# 32                                      0.00477
# 25                                      0.00538
# 18                                      0.00637
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00060                    1389
# 11                                      0.00467                     749
# 4                                       0.00511                     325
# 32                                      0.00633                     228
# 25                                      0.00671                     342
# 18                                      0.00828                     237
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00042
# 11       mmd                                      0.00341
# 4        fgd                                      0.00385
# 32       swd                                      0.00477
# 25       sks                                      0.00538
# 18        ks                                      0.00637
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00060                    1389
# 11                                      0.00467                     749
# 4                                       0.00511                     325
# 32                                      0.00633                     228
# 25                                      0.00671                     342
# 18                                      0.00828                     237

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        fgd  random_normal   20  10000                50000
# 26       sks  random_normal   20  10000                50000
# 33       swd  random_normal   20  10000                50000
# 19        ks  random_normal   20  10000                50000
# 12       mmd  random_normal   20  10000                50000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                                      0.16663
# 26                                     0.29541
# 33                                     0.30029
# 19                                     0.32471
# 12                                     0.74707
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.19200                    253
# 26                                     0.33446                    216
# 33                                     0.34389                    152
# 19                                     0.39091                    172
# 12                                     0.86907                    495
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        fgd                                     0.16663
# 26       sks                                     0.29541
# 33       swd                                     0.30029
# 19        ks                                     0.32471
# 12       mmd                                     0.74707
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.19200                    253
# 26                                     0.33446                    216
# 33                                     0.34389                    152
# 19                                     0.39091                    172
# 12                                     0.86907                    495

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform   20  10000                50000
# 27       sks  random_uniform   20  10000                50000
# 34       swd  random_uniform   20  10000                50000
# 20        ks  random_uniform   20  10000                50000
# 13       mmd  random_uniform   20  10000                50000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                                      0.28564
# 27                                     0.51270
# 34                                     0.51270
# 20                                     0.56152
# 13                                     1.30371
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.33053                    221
# 27                                     0.58719                    193
# 34                                     0.59596                    131
# 20                                     0.66122                    146
# 13                                     1.50766                    452
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                                     0.28564
# 27       sks                                     0.51270
# 34       swd                                     0.51270
# 20        ks                                     0.56152
# 13       mmd                                     1.30371
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.33053                    221
# 27                                     0.58719                    193
# 34                                     0.59596                    131
# 20                                     0.66122                    146
# 13                                     1.50766                    452

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.047 & 0.063 & 266 & cov_diag & 20 & 10000 & 50000 & 0.018 & 0.023 & 294 & cov_off_diag & 20 & 10000 & 50000 & 0.0022 & 0.003 & 362 & 0.0042 & 0.0054 & 323 \\
# $\overline{D}$ & 0.049 & 0.065 & 193 & cov_diag & 20 & 10000 & 50000 & 0.03 & 0.04 & 212 & cov_off_diag & 20 & 10000 & 50000 & 1 & 1 & 177 & 0.0061 & 0.008 & 238 \\
# $t_{\mathrm{LLR}}$ & 0.0054 & 0.0078 & 906 & cov_diag & 20 & 10000 & 50000 & 0.0023 & 0.0029 & 1218 & cov_off_diag & 20 & 10000 & 50000 & 5e-05 & 9e-05 & 1969 & 0.00041 & 0.00061 & 1376 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.061 & 0.082 & 563 & cov_diag & 20 & 10000 & 50000 & 0.024 & 0.032 & 619 & cov_off_diag & 20 & 10000 & 50000 & 0.013 & 0.018 & 685 & 0.0037 & 0.005 & 787 \\
# $\widetilde{D}$ & 0.051 & 0.065 & 268 & cov_diag & 20 & 10000 & 50000 & 0.028 & 0.036 & 299 & cov_off_diag & 20 & 10000 & 50000 & 0.012 & 0.016 & 335 & 0.0052 & 0.0066 & 340 \\
# $\widetilde{W}$ & 0.051 & 0.066 & 177 & cov_diag & 20 & 10000 & 50000 & 0.022 & 0.028 & 202 & cov_off_diag & 20 & 10000 & 50000 & 0.013 & 0.018 & 220 & 0.0048 & 0.0063 & 220 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.0039 & 0.0051 & 325 & 0.17 & 0.19 & 2.5e+02 & 0.29 & 0.33 & 2.2e+02 & 3057 \\
# $\overline{D}$ & 0.0064 & 0.0083 & 237 & 0.32 & 0.39 & 1.7e+02 & 0.56 & 0.66 & 1.5e+02 & 127 \\
# $t_{\mathrm{LLR}}$ & 0.00042 & 0.0006 & 1389 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.0034 & 0.0047 & 749 & 0.75 & 0.87 & 5e+02 & 1.3 & 1.5 & 4.5e+02 & 13833 \\
# $\widetilde{D}$ & 0.0054 & 0.0067 & 342 & 0.3 & 0.33 & 2.2e+02 & 0.51 & 0.59 & 1.9e+02 & 473 \\
# $\widetilde{W}$ & 0.0048 & 0.0063 & 228 & 0.3 & 0.34 & 1.5e+02 & 0.51 & 0.6 & 1.3e+02 & 309 \\
# \bottomrule
# \end{tabular}
