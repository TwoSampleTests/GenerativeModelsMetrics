# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# %cd /mnt/project_mnt/teo_fs/rtorre/cernbox/git/GitHub/NormalizingFlows/NF4HEP/GenerativeModelsMetrics
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [2]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more import MixtureDistributions
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/20D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-24 16:54:28.578591: Importing os...
# 2024-05-24 16:54:28.578751: Importing sys...
# Visible devices: [2]
# 2024-05-24 16:54:28.578982: Importing timer from timeit...
# 2024-05-24 16:54:28.579050: Setting env variables for tf import (only device(s) [2] will be available)...
# 2024-05-24 16:54:28.579174: Importing numpy...
# 2024-05-24 16:54:38.811642: Importing matplotlib...
# 2024-05-24 16:54:41.031202: Importing h5py...
# 2024-05-24 16:54:41.381735: Importing importlib.util...
# 2024-05-24 16:54:41.381856: Importing json...
# 2024-05-24 16:54:41.381921: Importing pandas...
# 2024-05-24 16:54:45.041281: Importing random...
# 2024-05-24 16:54:45.041418: Importing scipy utils...
# 2024-05-24 16:54:52.234303: Importing subprocess...
# 2024-05-24 16:54:52.234438: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-24 16:55:36.660526: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-24 16:55:48.386868: Importing timeit...
# 2024-05-24 16:55:48.386957: Importing tqdm...
# 2024-05-24 16:55:48.398902: Importing typing...
# 2024-05-24 16:55:48.399011: Setting tf configs...
# 2024-05-24 16:55:50.013649: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-24 16:56:48.629241: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #2, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-24 16:56:48.661173: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)
# sample from dist_1:  tf.Tensor(
# [[ 1.62246227 -1.12148208 -3.44534996  4.02194848  1.78776681  0.88094347
#   -0.50568928 -0.93258241  0.96072818  3.18398396 -3.42493274  3.36118865
#   -0.97008955 -3.80922336 -0.88678123 -1.74309765  1.4275693  -0.80163333
#    0.77207225 -1.33233507]
#  [-0.90576152 -2.92629119  0.09540144  3.39476591 -0.96077947  2.45882417
#    1.71000076 -2.53187845 -3.05469271  1.09331411 -3.54069629  3.61418597
#   -1.99533712 -6.54250726  1.51932671 -1.73641701 -0.51890038 -3.80921806
#    2.25758194 -0.7973361 ]], shape=(2, 20), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[ 1.62246227 -1.12148208 -3.44534996  4.02194848  1.78776681  0.88094347
#   -0.50568928 -0.93258241  0.96072818  3.18398396 -3.42493274  3.36118865
#   -0.97008955 -3.80922336 -0.88678123 -1.74309765  1.4275693  -0.80163333
#    0.77207225 -1.33233507]
#  [-0.90576152 -2.92629119  0.09540144  3.39476591 -0.96077947  2.45882417
#    1.71000076 -2.53187845 -3.05469271  1.09331411 -3.54069629  3.61418597
#   -1.99533712 -6.54250726  1.51932671 -1.73641701 -0.51890038 -3.80921806
#    2.25758194 -0.7973361 ]], shape=(2, 20), dtype=float64)

# %% [markdown]
# # Fixed $n=50000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 50_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 500000000
# batch_size 50000
# niter 10000
# niter * batch_size 500000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            50000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...       20           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True       20           0  float64    20  500000000         False
#
#    ncomp
# 0      5
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 2,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 5000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/20D_unimodal/20D_50K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fgd from results/20D_unimodal/20D_50K/null_hypothesis/FGD.json
# Loading mmd from results/20D_unimodal/20D_50K/null_hypothesis/MMD.json
# Loading ks from results/20D_unimodal/20D_50K/null_hypothesis/KS.json
# Loading sks from results/20D_unimodal/20D_50K/null_hypothesis/SKS.json
# Loading swd from results/20D_unimodal/20D_50K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0011934391789521319], [0.95, [9500, 500], 0.008980428707655187], [0.99, [9900, 100], 0.015367761955947344]]
# Computing time for metric fgd: 3821.220763320045
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.19707489254119537], [0.95, [9500, 500], 5.836714089501243], [0.99, [9900, 100], 11.387773923555983]]
# Computing time for metric mmd: 13843.783102662012
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.905992924914736], [0.95, [9500, 500], 1.093358220644432], [0.99, [9900, 100], 1.2453050300697117]]
# Computing time for metric ks: 127.72473928402178
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9019460327675843], [0.95, [9500, 500], 1.0645504101627095], [0.99, [9900, 100], 1.1750718619801739]]
# Computing time for metric sks: 480.6510598799796
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.7077197698514474], [0.95, [9500, 500], 0.9011921783076113], [0.99, [9900, 100], 1.0517008458274566]]
# Computing time for metric swd: 313.98361301602563
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f32526b4220>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f32526b4360>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f32526b4400>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f32526b44a0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f32526b4540>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f32526b45e0>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_unimodal/20D_50K/null_hypothesis/F...
# 1  $d_{\mathrm{MMD}}$  results/20D_unimodal/20D_50K/null_hypothesis/M...
# 2      $\overline{D}$  results/20D_unimodal/20D_50K/null_hypothesis/K...
# 3     $\widetilde{D}$  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 4     $\widetilde{W}$  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 5           $t_{\mu}$  results/20D_unimodal/20D_50K/null_hypothesis/L...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0011934391789521319], ...
# 1  [[0.68, [6800, 3199], 0.19707489254119537], [0...
# 2  [[0.68, [6800, 3199], 0.905992924914736], [0.9...
# 3  [[0.68, [6800, 3199], 0.9019460327675843], [0....
# 4  [[0.68, [6800, 3199], 0.7077197698514474], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{2})$"
        dist_null = dist_null * 100
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-1})$"
        dist_null = dist_null / 10
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 10
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 10
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.17821513838009245 +/- 0.0011683637807117112
# sigma = 0.34181336730907863 +/- 0.006292452403001041
# 68%CL = 0.11934391789521319, 95%CL = 0.8980428707655187, 99%CL = 1.5367761955947346
# mu = 0.17821513838009245 +/- 0.0011683637807117112
# sigma = 0.34181336730907863 +/- 0.006292452403001041
# /tmp/ipykernel_2189470/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2189470/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2189470/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 3.452063966076821 seconds.
# mu = -0.005890935793459592 +/- 0.0009170383922739424
# sigma = 0.302826417651093 +/- 0.005264240592664786
# 68%CL = 0.019707489254119536, 95%CL = 0.5836714089501243, 99%CL = 1.1387773923555984
# mu = -0.005890935793459592 +/- 0.0009170383922739424
# sigma = 0.302826417651093 +/- 0.005264240592664786
# /tmp/ipykernel_2189470/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2189470/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2189470/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9120829231105745 seconds.
# mu = 0.8676576345865875 +/- 0.00014558441284223298
# sigma = 0.12065836599350788 +/- 0.0011335887213325888
# 68%CL = 0.905992924914736, 95%CL = 1.093358220644432, 99%CL = 1.2453050300697117
# mu = 0.8676576345865875 +/- 0.00014558441284223298
# sigma = 0.12065836599350788 +/- 0.0011335887213325888
# /tmp/ipykernel_2189470/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2189470/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2189470/2214353603.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2189470/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.253681872971356 seconds.
# mu = 0.8659156152039024 +/- 0.00011111890419823913
# sigma = 0.10541295185992997 +/- 0.0009104131282335486
# 68%CL = 0.9019460327675843, 95%CL = 1.0645504101627095, 99%CL = 1.1750718619801739
# mu = 0.8659156152039024 +/- 0.00011111890419823913
# sigma = 0.10541295185992997 +/- 0.0009104131282335486
# /tmp/ipykernel_2189470/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2189470/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2189470/2214353603.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2189470/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.264499780954793 seconds.
# mu = 0.6725616143312203 +/- 0.00014028146122805496
# sigma = 0.11844047501933405 +/- 0.0012032456341458013
# 68%CL = 0.7077197698514474, 95%CL = 0.9011921783076113, 99%CL = 1.0517008458274566
# mu = 0.6725616143312203 +/- 0.00014028146122805496
# sigma = 0.11844047501933405 +/- 0.0012032456341458013
# /tmp/ipykernel_2189470/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2189470/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2189470/2214353603.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2189470/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9152749429922551 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f32526b4220>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f32526b4360>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f32526b4400>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f32526b44a0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f32526b4540>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f32526b45e0>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_unimodal/20D_50K/null_hypothesis/F...
# 1  $d_{\mathrm{MMD}}$  results/20D_unimodal/20D_50K/null_hypothesis/M...
# 2      $\overline{D}$  results/20D_unimodal/20D_50K/null_hypothesis/K...
# 3     $\widetilde{D}$  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 4     $\widetilde{W}$  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 5           $t_{\mu}$  results/20D_unimodal/20D_50K/null_hypothesis/L...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0011934391789521319], ...
# 1  [[0.68, [6800, 3199], 0.19707489254119537], [0...
# 2  [[0.68, [6800, 3199], 0.905992924914736], [0.9...
# 3  [[0.68, [6800, 3199], 0.9019460327675843], [0....
# 4  [[0.68, [6800, 3199], 0.7077197698514474], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/20D_unimodal/20D_50K/null_hypothesis/F...
# 1  results/20D_unimodal/20D_50K/null_hypothesis/M...
# 2  results/20D_unimodal/20D_50K/null_hypothesis/K...
# 3  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 4  results/20D_unimodal/20D_50K/null_hypothesis/S...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        eps_max = 5.
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection(dist_1,
                                                     metric_config = metric_config,
                                                     test_kwargs = test_kwargs,
                                                     model_dir = model_dir,
                                                     deformation = deformation,
                                                     seed_dist = 0,
                                                     x_tol = 0.01,
                                                     fn_tol = 0.05,
                                                     bound = bound,
                                                     eps_min = 0.,
                                                     eps_max = eps_max,
                                                     max_iterations = 50,
                                                     save = True,
                                                     filename = "exclusion_limits.json",
                                                     verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Upper bounds for fgd with mean deformation already loaded.
# Central bounds for fgd with mean deformation already loaded.
# Lower bounds for fgd with mean deformation already loaded.
# Upper bounds for fgd with cov_diag deformation already loaded.
# Central bounds for fgd with cov_diag deformation already loaded.
# Lower bounds for fgd with cov_diag deformation already loaded.
# Upper bounds for fgd with cov_off_diag deformation already loaded.
# Central bounds for fgd with cov_off_diag deformation already loaded.
# Lower bounds for fgd with cov_off_diag deformation already loaded.
# Upper bounds for fgd with power_abs_up deformation already loaded.
# Central bounds for fgd with power_abs_up deformation already loaded.
# Lower bounds for fgd with power_abs_up deformation already loaded.
# Upper bounds for fgd with power_abs_down deformation already loaded.
# Central bounds for fgd with power_abs_down deformation already loaded.
# Lower bounds for fgd with power_abs_down deformation already loaded.
# Upper bounds for fgd with random_normal deformation already loaded.
# Central bounds for fgd with random_normal deformation already loaded.
# Lower bounds for fgd with random_normal deformation already loaded.
# Upper bounds for fgd with random_uniform deformation already loaded.
# Central bounds for fgd with random_uniform deformation already loaded.
# Lower bounds for fgd with random_uniform deformation already loaded.
# Upper bounds for mmd with mean deformation already loaded.
# Central bounds for mmd with mean deformation already loaded.
# Lower bounds for mmd with mean deformation already loaded.
# Upper bounds for mmd with cov_diag deformation already loaded.
# Central bounds for mmd with cov_diag deformation already loaded.
# Lower bounds for mmd with cov_diag deformation already loaded.
# Upper bounds for mmd with cov_off_diag deformation already loaded.
# Central bounds for mmd with cov_off_diag deformation already loaded.
# Lower bounds for mmd with cov_off_diag deformation already loaded.
# Upper bounds for mmd with power_abs_up deformation already loaded.
# Central bounds for mmd with power_abs_up deformation already loaded.
# Lower bounds for mmd with power_abs_up deformation already loaded.
# Upper bounds for mmd with power_abs_down deformation already loaded.
# Central bounds for mmd with power_abs_down deformation already loaded.
# Lower bounds for mmd with power_abs_down deformation already loaded.
# Upper bounds for mmd with random_normal deformation already loaded.
# Central bounds for mmd with random_normal deformation already loaded.
# Lower bounds for mmd with random_normal deformation already loaded.
# Computing upper bounds for mmd with random_uniform deformation.
#
# ======================================================
# =============== mmd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - upper bound -----------
# eps = 2.5 - deformation = random_uniform
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716562630.089099 2190842 service.cc:145] XLA service 0x113913d70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1716562630.089393 2190842 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1716562632.755883 2190842 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1716562632.799888 2190842 random_ops.cc:59] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. while/random_shiftMultivariateNormalTriL_CONSTRUCTED_AT_top_level/sample/random_shift/forward/random_uniform/RandomUniform
# statistic = 88.41283247651309 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7522868044606204
#
# ------------ 2 - 0.95 CL - upper bound -----------
# eps = 1.25 - deformation = random_uniform
# statistic = 1.9973603445661956 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.980167798314283
#
# ------------ 3 - 0.95 CL - upper bound -----------
# eps = 1.875 - deformation = random_uniform
# statistic = 24.13494219237442 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 1.221035496389194
#
# ------------ 4 - 0.95 CL - upper bound -----------
# eps = 1.5625 - deformation = random_uniform
# statistic = 9.813761609822317 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.5082334360600897
#
# ------------ 5 - 0.95 CL - upper bound -----------
# eps = 1.40625 - deformation = random_uniform
# statistic = 5.190808584152196 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.11714426249010963
#
# ------------ 6 - 0.95 CL - upper bound -----------
# eps = 1.484375 - deformation = random_uniform
# statistic = 7.4884884256292255 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.2479173332266328
#
# ------------ 7 - 0.95 CL - upper bound -----------
# eps = 1.4453125 - deformation = random_uniform
# statistic = 6.077582799284951 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.0273972602739726
# relative_error_metric = 0.040433558443623334
#
# ------------ 8 - 0.95 CL - upper bound -----------
# eps = 1.42578125 - deformation = random_uniform
# statistic = 5.690822198147494 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.013605442176870748
# relative_error_metric = 0.02531189453032835
#
# ------------ 9 - 0.95 CL - upper bound -----------
# eps = 1.435546875 - deformation = random_uniform
# statistic = 5.959826872685943 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.006825938566552901
# relative_error_metric = 0.02087269201697815
# =======> statistic within required accuracy at 0.95 CL in 1302.6124877289403 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - upper bound -----------
# eps = 1.4306640625 - deformation = random_uniform
# statistic = 5.850946223424586 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 1.1100987091875474
# relative_error_metric = 0.6423710870555775
#
# ------------ 2 - 0.99 CL - upper bound -----------
# eps = 3.21533203125 - deformation = random_uniform
# statistic = 260.2670576111473 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.7682606410930111
# relative_error_metric = 1.8323199501481906
#
# ------------ 3 - 0.99 CL - upper bound -----------
# eps = 2.322998046875 - deformation = random_uniform
# statistic = 63.41514749002552 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.47544715447154473
# relative_error_metric = 1.3910519157082881
#
# ------------ 4 - 0.99 CL - upper bound -----------
# eps = 1.8768310546875 - deformation = random_uniform
# statistic = 24.55582036670153 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.2697914744417789
# relative_error_metric = 0.7327061582550044
#
# ------------ 5 - 0.99 CL - upper bound -----------
# eps = 1.65374755859375 - deformation = random_uniform
# statistic = 13.250601294340697 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.14465222123280894
# relative_error_metric = 0.15121349149935864
#
# ------------ 6 - 0.99 CL - upper bound -----------
# eps = 1.542205810546875 - deformation = random_uniform
# statistic = 9.148628334008377 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.06980186201957508
# relative_error_metric = 0.21806600410963814
#
# ------------ 7 - 0.99 CL - upper bound -----------
# eps = 1.5979766845703125 - deformation = random_uniform
# statistic = 11.015195053350618 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.034302339222449026
# relative_error_metric = 0.03326156194649252
#
# ------------ 8 - 0.99 CL - upper bound -----------
# eps = 1.6258621215820312 - deformation = random_uniform
# statistic = 11.83639800023661 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.017299523138999656
# relative_error_metric = 0.03863423661801457
#
# ------------ 9 - 0.99 CL - upper bound -----------
# eps = 1.6119194030761719 - deformation = random_uniform
# statistic = 11.51725008307141 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.008687333250144095
# relative_error_metric = 0.011305481232236568
# =======> statistic within required accuracy at 0.99 CL in 1299.987706384156 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2602.6002290491015 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Computing central bounds for mmd with random_uniform deformation.
#
# ======================================================
# =============== mmd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - central bound -----------
# eps = 0.8024740219116211 - deformation = random_uniform
# statistic = 0.24975943467949605 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.835859347001356
#
# ------------ 2 - 0.95 CL - central bound -----------
# eps = 1.2037110328674316 - deformation = random_uniform
# statistic = 4.353396942793895 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.29112875061053317
#
# ------------ 3 - 0.95 CL - central bound -----------
# eps = 1.404329538345337 - deformation = random_uniform
# statistic = 8.893303827666239 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.41501507402820126
#
# ------------ 4 - 0.95 CL - central bound -----------
# eps = 1.3040202856063843 - deformation = random_uniform
# statistic = 6.42346919548109 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.09571718339620121
#
# ------------ 5 - 0.95 CL - central bound -----------
# eps = 1.253865659236908 - deformation = random_uniform
# statistic = 5.243309563685354 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.0392156862745098
# relative_error_metric = 0.10711250163174986
#
# ------------ 6 - 0.95 CL - central bound -----------
# eps = 1.2789429724216461 - deformation = random_uniform
# statistic = 5.816667801872862 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.019417475728155338
# relative_error_metric = 0.0034404240443229313
#
# ------------ 7 - 0.95 CL - central bound -----------
# eps = 1.2914816290140152 - deformation = random_uniform
# statistic = 5.93722711718256 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.00975609756097561
# relative_error_metric = 0.01707381171977623
# =======> statistic within required accuracy at 0.95 CL in 1011.1393717429601 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - central bound -----------
# eps = 1.2852123007178307 - deformation = random_uniform
# statistic = 5.923736711254917 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.22125813449023862
# relative_error_metric = 0.6312605904320898
#
# ------------ 2 - 0.99 CL - central bound -----------
# eps = 1.4450801722705364 - deformation = random_uniform
# statistic = 9.946133877835424 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.10483042137718397
# relative_error_metric = 0.13515011493829884
#
# ------------ 3 - 0.99 CL - central bound -----------
# eps = 1.5250141080468893 - deformation = random_uniform
# statistic = 12.750151222527784 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.05382585751978892
# relative_error_metric = 0.11288271802374349
#
# ------------ 4 - 0.99 CL - central bound -----------
# eps = 1.4850471401587129 - deformation = random_uniform
# statistic = 11.21822031025914 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.0265555844832075
# relative_error_metric = 0.015000765862641579
#
# ------------ 5 - 0.99 CL - central bound -----------
# eps = 1.505030624102801 - deformation = random_uniform
# statistic = 11.855344639077352 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.013366531254095138
# relative_error_metric = 0.04023304482670032
#
# ------------ 6 - 0.99 CL - central bound -----------
# eps = 1.495038882130757 - deformation = random_uniform
# statistic = 11.660464342631796 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.006705673525737953
# relative_error_metric = 0.02366258244352283
# =======> statistic within required accuracy at 0.99 CL in 866.3231878320221 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1877.462595651159 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Computing lower bounds for mmd with random_uniform deformation.
#
# ======================================================
# =============== mmd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - lower bound -----------
# eps = 0.7450215055723675 - deformation = random_uniform
# statistic = 2.336939930649558 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.856354856768727
#
# ------------ 2 - 0.95 CL - lower bound -----------
# eps = 1.1175322583585512 - deformation = random_uniform
# statistic = 5.862556449161943 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.0044177728133215945
#
# ------------ 3 - 0.95 CL - lower bound -----------
# eps = 0.9312768819654593 - deformation = random_uniform
# statistic = 3.649301319559761 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.46118684729355885
#
# ------------ 4 - 0.95 CL - lower bound -----------
# eps = 1.0244045701620053 - deformation = random_uniform
# statistic = 4.342662577831505 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.29354479365409253
#
# ------------ 5 - 0.95 CL - lower bound -----------
# eps = 1.0709684142602782 - deformation = random_uniform
# statistic = 4.951766106058919 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.0425531914893617
# relative_error_metric = 0.1640542444164676
#
# ------------ 6 - 0.95 CL - lower bound -----------
# eps = 1.0942503363094147 - deformation = random_uniform
# statistic = 5.455666893534948 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.021052631578947368
# relative_error_metric = 0.06748748497570474
#
# ------------ 7 - 0.95 CL - lower bound -----------
# eps = 1.105891297333983 - deformation = random_uniform
# statistic = 5.721919523757684 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.010471204188481676
# relative_error_metric = 0.019862999310208688
#
# ------------ 8 - 0.95 CL - lower bound -----------
# eps = 1.111711777846267 - deformation = random_uniform
# statistic = 5.780851675748359 - next threshold = 5.836714089501243 at 0.95 CL
# relative_error_eps = 0.005221932114882507
# relative_error_metric = 0.009616887888851752
# =======> statistic within required accuracy at 0.95 CL in 1155.825973086059 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - lower bound -----------
# eps = 1.1146220181024091 - deformation = random_uniform
# statistic = 5.6925232508973655 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.288268156424581
# relative_error_metric = 0.6668795764486917
#
# ------------ 2 - 0.99 CL - lower bound -----------
# eps = 1.302332514623572 - deformation = random_uniform
# statistic = 9.522021496155952 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.1344450234497134
# relative_error_metric = 0.17845726272779902
#
# ------------ 3 - 0.99 CL - lower bound -----------
# eps = 1.3961877628841535 - deformation = random_uniform
# statistic = 12.101577832513083 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.06956052844432462
# relative_error_metric = 0.06077680783784686
#
# ------------ 4 - 0.99 CL - lower bound -----------
# eps = 1.3492601387538627 - deformation = random_uniform
# statistic = 11.031552777676392 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.03418576917980654
# relative_error_metric = 0.031778041386051926
#
# ------------ 5 - 0.99 CL - lower bound -----------
# eps = 1.372723950819008 - deformation = random_uniform
# statistic = 11.453529580275863 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.017240227196792517
# relative_error_metric = 0.005757609823699288
#
# ------------ 6 - 0.99 CL - lower bound -----------
# eps = 1.3609920447864354 - deformation = random_uniform
# statistic = 11.289923136166069 - next threshold = 11.387773923555983 at 0.99 CL
# relative_error_eps = 0.008583119864266941
# relative_error_metric = 0.008629693494204714
# =======> statistic within required accuracy at 0.99 CL in 866.6445964321028 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2022.470605205046 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Upper bounds for ks with mean deformation already loaded.
# Central bounds for ks with mean deformation already loaded.
# Lower bounds for ks with mean deformation already loaded.
# Upper bounds for ks with cov_diag deformation already loaded.
# Central bounds for ks with cov_diag deformation already loaded.
# Lower bounds for ks with cov_diag deformation already loaded.
# Upper bounds for ks with cov_off_diag deformation already loaded.
# Central bounds for ks with cov_off_diag deformation already loaded.
# Lower bounds for ks with cov_off_diag deformation already loaded.
# Upper bounds for ks with power_abs_up deformation already loaded.
# Central bounds for ks with power_abs_up deformation already loaded.
# Lower bounds for ks with power_abs_up deformation already loaded.
# Upper bounds for ks with power_abs_down deformation already loaded.
# Central bounds for ks with power_abs_down deformation already loaded.
# Lower bounds for ks with power_abs_down deformation already loaded.
# Upper bounds for ks with random_normal deformation already loaded.
# Central bounds for ks with random_normal deformation already loaded.
# Lower bounds for ks with random_normal deformation already loaded.
# Upper bounds for ks with random_uniform deformation already loaded.
# Central bounds for ks with random_uniform deformation already loaded.
# Lower bounds for ks with random_uniform deformation already loaded.
# Upper bounds for sks with mean deformation already loaded.
# Central bounds for sks with mean deformation already loaded.
# Lower bounds for sks with mean deformation already loaded.
# Upper bounds for sks with cov_diag deformation already loaded.
# Central bounds for sks with cov_diag deformation already loaded.
# Lower bounds for sks with cov_diag deformation already loaded.
# Upper bounds for sks with cov_off_diag deformation already loaded.
# Central bounds for sks with cov_off_diag deformation already loaded.
# Lower bounds for sks with cov_off_diag deformation already loaded.
# Upper bounds for sks with power_abs_up deformation already loaded.
# Central bounds for sks with power_abs_up deformation already loaded.
# Lower bounds for sks with power_abs_up deformation already loaded.
# Upper bounds for sks with power_abs_down deformation already loaded.
# Central bounds for sks with power_abs_down deformation already loaded.
# Lower bounds for sks with power_abs_down deformation already loaded.
# Upper bounds for sks with random_normal deformation already loaded.
# Central bounds for sks with random_normal deformation already loaded.
# Lower bounds for sks with random_normal deformation already loaded.
# Upper bounds for sks with random_uniform deformation already loaded.
# Central bounds for sks with random_uniform deformation already loaded.
# Lower bounds for sks with random_uniform deformation already loaded.
# Upper bounds for swd with mean deformation already loaded.
# Central bounds for swd with mean deformation already loaded.
# Lower bounds for swd with mean deformation already loaded.
# Upper bounds for swd with cov_diag deformation already loaded.
# Central bounds for swd with cov_diag deformation already loaded.
# Lower bounds for swd with cov_diag deformation already loaded.
# Upper bounds for swd with cov_off_diag deformation already loaded.
# Central bounds for swd with cov_off_diag deformation already loaded.
# Lower bounds for swd with cov_off_diag deformation already loaded.
# Upper bounds for swd with power_abs_up deformation already loaded.
# Central bounds for swd with power_abs_up deformation already loaded.
# Lower bounds for swd with power_abs_up deformation already loaded.
# Upper bounds for swd with power_abs_down deformation already loaded.
# Central bounds for swd with power_abs_down deformation already loaded.
# Lower bounds for swd with power_abs_down deformation already loaded.
# Upper bounds for swd with random_normal deformation already loaded.
# Central bounds for swd with random_normal deformation already loaded.
# Lower bounds for swd with random_normal deformation already loaded.
# Upper bounds for swd with random_uniform deformation already loaded.
# Central bounds for swd with random_uniform deformation already loaded.
# Lower bounds for swd with random_uniform deformation already loaded.
# dict_keys(['fgd_mean_upper_2024-05-20T17:33:59.464851', 'fgd_mean_central_2024-05-20T17:47:25.369839', 'fgd_mean_lower_2024-05-20T17:56:07.631102', 'fgd_cov_diag_upper_2024-05-20T18:05:25.684866', 'fgd_cov_diag_central_2024-05-20T18:20:34.702428', 'fgd_cov_diag_lower_2024-05-20T18:29:21.504641', 'fgd_cov_off_diag_upper_2024-05-20T18:38:40.612730', 'fgd_cov_off_diag_central_2024-05-20T18:57:20.367102', 'fgd_cov_off_diag_lower_2024-05-20T19:06:08.878845', 'fgd_power_abs_up_upper_2024-05-20T19:16:54.609377', 'fgd_power_abs_up_central_2024-05-20T19:39:31.331655', 'fgd_power_abs_up_lower_2024-05-20T19:50:50.884715', 'fgd_power_abs_down_upper_2024-05-20T20:02:59.962084', 'fgd_power_abs_down_central_2024-05-20T20:25:47.097563', 'fgd_power_abs_down_lower_2024-05-20T20:37:06.739259', 'fgd_random_normal_upper_2024-05-20T20:48:58.315880', 'fgd_random_normal_central_2024-05-20T21:03:59.793675', 'fgd_random_normal_lower_2024-05-20T21:13:50.295449', 'fgd_random_uniform_upper_2024-05-20T21:24:30.409828', 'fgd_random_uniform_central_2024-05-20T21:38:07.458061', 'fgd_random_uniform_lower_2024-05-20T21:47:57.896297', 'mmd_mean_upper_2024-05-20T21:58:32.530435', 'mmd_mean_central_2024-05-20T22:52:02.004144', 'mmd_mean_lower_2024-05-20T23:28:28.962264', 'mmd_cov_diag_upper_2024-05-21T00:07:25.742268', 'mmd_cov_diag_central_2024-05-21T01:08:20.782262', 'mmd_cov_diag_lower_2024-05-21T01:44:53.419913', 'mmd_cov_off_diag_upper_2024-05-21T02:23:39.075184', 'mmd_cov_off_diag_central_2024-05-21T03:26:26.627551', 'mmd_cov_off_diag_lower_2024-05-21T04:05:05.418917', 'mmd_power_abs_up_upper_2024-05-21T04:43:45.356498', 'mmd_power_abs_up_central_2024-05-21T05:56:13.622690', 'mmd_power_abs_up_lower_2024-05-21T06:32:27.353362', 'mmd_power_abs_down_upper_2024-05-21T07:11:05.189269', 'mmd_power_abs_down_central_2024-05-21T08:23:32.961412', 'mmd_power_abs_down_lower_2024-05-21T09:02:14.226639', 'mmd_random_normal_upper_2024-05-21T11:07:22.584021', 'mmd_random_normal_central_2024-05-21T11:38:46.581015', 'mmd_random_normal_lower_2024-05-21T12:10:07.297882', 'mmd_random_uniform_upper_2024-05-24T16:57:05.611926', 'mmd_random_uniform_central_2024-05-24T17:40:28.277449', 'mmd_random_uniform_lower_2024-05-24T18:11:45.804086', 'ks_mean_upper_2024-05-21T20:01:30.182888', 'ks_mean_central_2024-05-21T20:04:40.549424', 'ks_mean_lower_2024-05-21T20:06:25.486998', 'ks_cov_diag_upper_2024-05-21T20:08:17.981182', 'ks_cov_diag_central_2024-05-21T20:11:47.140624', 'ks_cov_diag_lower_2024-05-21T20:13:36.332608', 'ks_cov_off_diag_upper_2024-05-21T20:15:32.757379', 'ks_cov_off_diag_central_2024-05-21T20:18:10.037748', 'ks_cov_off_diag_lower_2024-05-21T20:19:14.908001', 'ks_power_abs_up_upper_2024-05-21T20:20:25.913404', 'ks_power_abs_up_central_2024-05-21T20:24:23.335159', 'ks_power_abs_up_lower_2024-05-21T20:26:09.926411', 'ks_power_abs_down_upper_2024-05-21T20:28:05.467279', 'ks_power_abs_down_central_2024-05-21T20:32:02.720058', 'ks_power_abs_down_lower_2024-05-21T20:33:50.240632', 'ks_random_normal_upper_2024-05-21T20:35:47.262693', 'ks_random_normal_central_2024-05-21T20:38:41.274444', 'ks_random_normal_lower_2024-05-21T20:40:27.329259', 'ks_random_uniform_upper_2024-05-21T20:42:20.432031', 'ks_random_uniform_central_2024-05-21T20:44:59.021739', 'ks_random_uniform_lower_2024-05-21T20:46:43.629993', 'sks_mean_upper_2024-05-21T20:48:38.985035', 'sks_mean_central_2024-05-21T20:53:44.603665', 'sks_mean_lower_2024-05-21T20:56:33.791249', 'sks_cov_diag_upper_2024-05-21T20:59:34.849703', 'sks_cov_diag_central_2024-05-21T21:05:09.422922', 'sks_cov_diag_lower_2024-05-21T21:08:03.524747', 'sks_cov_off_diag_upper_2024-05-21T21:11:09.070806', 'sks_cov_off_diag_central_2024-05-21T21:17:19.729091', 'sks_cov_off_diag_lower_2024-05-21T21:20:14.644478', 'sks_power_abs_up_upper_2024-05-21T21:23:22.418790', 'sks_power_abs_up_central_2024-05-21T21:29:52.025578', 'sks_power_abs_up_lower_2024-05-21T21:32:45.049974', 'sks_power_abs_down_upper_2024-05-21T21:35:49.557443', 'sks_power_abs_down_central_2 ...

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]
eps_max_def = []
bounds = ["upper", "central", "lower"]

for deformation in deformations:
    eps_max = 0.02
    for bound in bounds:
        try:
            result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation and v["bound"] == bound}
        except:
            result = {}
        if result == {}:
            print(f"Computing {bound} bounds for lr with {deformation} deformation.")
            result = compute_exclusion_LR_bisection(dist_1,
                                                    metric_config = metrics_config[unique_key]["lr"],
                                                    test_kwargs = test_kwargs,
                                                    model_dir = model_dir,
                                                    cl_list = [0.95, 0.99],
                                                    deformation = deformation,
                                                    seed_dist = 0,
                                                    x_tol = 0.01,
                                                    fn_tol = 0.05,
                                                    bound = bound,
                                                    eps_min = 0.,
                                                    eps_max = eps_max,
                                                    max_iterations = 50,
                                                    save = True,
                                                    filename = "exclusion_limits.json",
                                                    verbose = True)
            eps_max = list(result.values())[0]["exclusion_list"][-1][3]
        else:
            print(f"{bound.capitalize()} bounds for lr with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing upper bounds for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - upper bound -----------
# eps = 0.01 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 44.464918380836025 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.010000.json
# ThresholdS: [[0.95, [9500, 500], 0.6779395228997286], [0.99, [9900, 100], 3.6345888675642466]]
# Null distribution computed in 44.63808372290805 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.9448571358807385 seconds.
# statistic = 2.385056036785755 - next threshold = 0.6779395228997286 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1146712299258557
#
# ------------ 2 - 0.95 CL - upper bound -----------
# eps = 0.005 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.82193215400912 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], 1.8875634495434586], [0.99, [9900, 100], 3.3658881215464453]]
# Null distribution computed in 43.99888906511478 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.803348024142906 seconds.
# statistic = -0.3560656696835809 - next threshold = 1.8875634495434586 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 2.9299802438268205
#
# ------------ 3 - 0.95 CL - upper bound -----------
# eps = 0.0075 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.740866309031844 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.007500.json
# ThresholdS: [[0.95, [9500, 500], 1.6698999088212185], [0.99, [9900, 100], 3.887386916825699]]
# Null distribution computed in 43.90300641604699 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.781417539110407 seconds.
# statistic = 0.6273467615582846 - next threshold = 1.6698999088212185 at 0.95 CL
# relative_error_eps = 0.28571428571428575
# relative_error_metric = 0.9076545072024894
#
# ------------ 4 - 0.95 CL - upper bound -----------
# eps = 0.00875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.679813424125314 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.008750.json
# ThresholdS: [[0.95, [9500, 500], 1.270706821428062], [0.99, [9900, 100], 3.8577749980918337]]
# Null distribution computed in 43.845204196171835 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.805501169059426 seconds.
# statistic = 1.4094142937090903 - next threshold = 1.270706821428062 at 0.95 CL
# relative_error_eps = 0.15384615384615397
# relative_error_metric = 0.10350836124354047
#
# ------------ 5 - 0.95 CL - upper bound -----------
# eps = 0.008125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.82283523399383 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.008125.json
# ThresholdS: [[0.95, [9500, 500], 1.494500141187265], [0.99, [9900, 100], 3.896777733850663]]
# Null distribution computed in 43.99930394790135 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.78471859684214 seconds.
# statistic = 0.994183751246549 - next threshold = 1.494500141187265 at 0.95 CL
# relative_error_eps = 0.07407407407407414
# relative_error_metric = 0.40207307280912274
#
# ------------ 6 - 0.95 CL - upper bound -----------
# eps = 0.0084375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.724678493104875 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.008438.json
# ThresholdS: [[0.95, [9500, 500], 1.3886526749117294], [0.99, [9900, 100], 3.883325559575314]]
# Null distribution computed in 43.889827037928626 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.7692536120302975 seconds.
# statistic = 1.1957498283247436 - next threshold = 1.3886526749117294 at 0.95 CL
# relative_error_eps = 0.03636363636363639
# relative_error_metric = 0.14928235547319862
#
# ------------ 7 - 0.95 CL - upper bound -----------
# eps = 0.00859375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.71053793816827 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.008594.json
# ThresholdS: [[0.95, [9500, 500], 1.3311920469001841], [0.99, [9900, 100], 3.8720625769053183]]
# Null distribution computed in 43.873960486846045 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.753486521076411 seconds.
# statistic = 1.301069762473397 - next threshold = 1.3311920469001841 at 0.95 CL
# relative_error_eps = 0.018018018018018032
# relative_error_metric = 0.022886997273235246
#
# ------------ 8 - 0.95 CL - upper bound -----------
# eps = 0.008671875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.57412952487357 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.008672.json
# ThresholdS: [[0.95, [9500, 500], 1.3013275085174232], [0.99, [9900, 100], 3.8652968618518755]]
# Null distribution computed in 43.736507690977305 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.853699091123417 seconds.
# statistic = 1.3548639534699713 - next threshold = 1.3013275085174232 at 0.95 CL
# relative_error_eps = 0.009049773755656116
# relative_error_metric = 0.04031068220699087
# =======> statistic within required accuracy at 0.95 CL in 399.0648370690178 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - upper bound -----------
# eps = 0.0086328125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.68515438004397 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.008633.json
# ThresholdS: [[0.95, [9500, 500], 1.3163542962971286], [0.99, [9900, 100], 3.868774238296194]]
# Null distribution computed in 43.85177661594935 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.80066899699159 seconds.
# statistic = 1.3278723392854759 - next threshold = 3.868774238296194 at 0.99 CL
# relative_error_eps = 0.7939972714870396
# relative_error_metric = 0.9779005984252104
#
# ------------ 2 - 0.99 CL - upper bound -----------
# eps = 0.01431640625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.70211931806989 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.014316.json
# ThresholdS: [[0.95, [9500, 500], -2.857274467379388], [0.99, [9900, 100], 1.3755848482846633]]
# Null distribution computed in 43.86788757983595 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.7802765250671655 seconds.
# statistic = 7.242383345063731 - next threshold = 1.3755848482846633 at 0.99 CL
# relative_error_eps = 0.49531914893617024
# relative_error_metric = 1.361527071150538
#
# ------------ 3 - 0.99 CL - upper bound -----------
# eps = 0.011474609375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.67604077816941 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.011475.json
# ThresholdS: [[0.95, [9500, 500], -0.27021418205445535], [0.99, [9900, 100], 3.1224254464478305]]
# Null distribution computed in 43.83898951415904 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.77398399496451 seconds.
# statistic = 3.784881938778846 - next threshold = 3.1224254464478305 at 0.99 CL
# relative_error_eps = 0.2826614861583293
# relative_error_metric = 0.1918132364422858
#
# ------------ 4 - 0.99 CL - upper bound -----------
# eps = 0.0100537109375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.78807752719149 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.010054.json
# ThresholdS: [[0.95, [9500, 500], 0.6481315324167787], [0.99, [9900, 100], 3.6206613183259986]]
# Null distribution computed in 43.9541558760684 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 6.221850401954725 seconds.
# statistic = 2.4313156631844164 - next threshold = 3.6206613183259986 at 0.99 CL
# relative_error_eps = 0.13200272170560218
# relative_error_metric = 0.39304368102363557
#
# ------------ 5 - 0.99 CL - upper bound -----------
# eps = 0.01076416015625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# ...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.42341003403999 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.005069.json
# ThresholdS: [[0.95, [9500, 500], 1.8919691557658005], [0.99, [9900, 100], 3.390808723963402]]
# Null distribution computed in 43.58981612697244 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.851885034935549 seconds.
# statistic = 3.4934625578130785 - next threshold = 3.390808723963402 at 0.99 CL
# relative_error_eps = 0.03403861605512401
# relative_error_metric = 0.0298227160575191
#
# ------------ 7 - 0.99 CL - lower bound -----------
# eps = 0.004984552000763589 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.45865520788357 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.004985.json
# ThresholdS: [[0.95, [9500, 500], 1.8865013864980211], [0.99, [9900, 100], 3.3602586269183954]]
# Null distribution computed in 43.626150484895334 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.8899635809939355 seconds.
# statistic = 3.408807828331004 - next threshold = 3.3602586269183954 at 0.99 CL
# relative_error_eps = 0.017165379467848567
# relative_error_metric = 0.014344430427318066
#
# ------------ 8 - 0.99 CL - lower bound -----------
# eps = 0.004942135187823391 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 43.465685619972646 seconds.
# Saving lr to results/20D_unimodal/20D_50K/null_hypothesis/LR_mean_0.004942.json
# ThresholdS: [[0.95, [9500, 500], 1.8834331571710672], [0.99, [9900, 100], 3.3446492333735565]]
# Null distribution computed in 43.63217841880396 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 50000
# LR metric calculation completed in 5.870751925045624 seconds.
# statistic = 3.3668148086693943 - next threshold = 3.3446492333735565 at 0.99 CL
# relative_error_eps = 0.008619679752384537
# relative_error_metric = 0.006605287656161146
# =======> statistic within required accuracy at 0.99 CL in 397.79756040591747 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 845.9051456460729 seconds.
# Saving results in the file results/20D_unimodal/20D_50K/exclusion_limits.json
# Upper bounds for lr with cov_diag deformation already loaded.
# Central bounds for lr with cov_diag deformation already loaded.
# Lower bounds for lr with cov_diag deformation already loaded.
# Upper bounds for lr with cov_off_diag deformation already loaded.
# Central bounds for lr with cov_off_diag deformation already loaded.
# Lower bounds for lr with cov_off_diag deformation already loaded.
# Upper bounds for lr with power_abs_up deformation already loaded.
# Central bounds for lr with power_abs_up deformation already loaded.
# Lower bounds for lr with power_abs_up deformation already loaded.
# Upper bounds for lr with power_abs_down deformation already loaded.
# Central bounds for lr with power_abs_down deformation already loaded.
# Lower bounds for lr with power_abs_down deformation already loaded.
# dict_keys(['fgd_mean_upper_2024-05-20T17:33:59.464851', 'fgd_mean_central_2024-05-20T17:47:25.369839', 'fgd_mean_lower_2024-05-20T17:56:07.631102', 'fgd_cov_diag_upper_2024-05-20T18:05:25.684866', 'fgd_cov_diag_central_2024-05-20T18:20:34.702428', 'fgd_cov_diag_lower_2024-05-20T18:29:21.504641', 'fgd_cov_off_diag_upper_2024-05-20T18:38:40.612730', 'fgd_cov_off_diag_central_2024-05-20T18:57:20.367102', 'fgd_cov_off_diag_lower_2024-05-20T19:06:08.878845', 'fgd_power_abs_up_upper_2024-05-20T19:16:54.609377', 'fgd_power_abs_up_central_2024-05-20T19:39:31.331655', 'fgd_power_abs_up_lower_2024-05-20T19:50:50.884715', 'fgd_power_abs_down_upper_2024-05-20T20:02:59.962084', 'fgd_power_abs_down_central_2024-05-20T20:25:47.097563', 'fgd_power_abs_down_lower_2024-05-20T20:37:06.739259', 'fgd_random_normal_upper_2024-05-20T20:48:58.315880', 'fgd_random_normal_central_2024-05-20T21:03:59.793675', 'fgd_random_normal_lower_2024-05-20T21:13:50.295449', 'fgd_random_uniform_upper_2024-05-20T21:24:30.409828', 'fgd_random_uniform_central_2024-05-20T21:38:07.458061', 'fgd_random_uniform_lower_2024-05-20T21:47:57.896297', 'mmd_mean_upper_2024-05-20T21:58:32.530435', 'mmd_mean_central_2024-05-20T22:52:02.004144', 'mmd_mean_lower_2024-05-20T23:28:28.962264', 'mmd_cov_diag_upper_2024-05-21T00:07:25.742268', 'mmd_cov_diag_central_2024-05-21T01:08:20.782262', 'mmd_cov_diag_lower_2024-05-21T01:44:53.419913', 'mmd_cov_off_diag_upper_2024-05-21T02:23:39.075184', 'mmd_cov_off_diag_central_2024-05-21T03:26:26.627551', 'mmd_cov_off_diag_lower_2024-05-21T04:05:05.418917', 'mmd_power_abs_up_upper_2024-05-21T04:43:45.356498', 'mmd_power_abs_up_central_2024-05-21T05:56:13.622690', 'mmd_power_abs_up_lower_2024-05-21T06:32:27.353362', 'mmd_power_abs_down_upper_2024-05-21T07:11:05.189269', 'mmd_power_abs_down_central_2024-05-21T08:23:32.961412', 'mmd_power_abs_down_lower_2024-05-21T09:02:14.226639', 'mmd_random_normal_upper_2024-05-21T11:07:22.584021', 'mmd_random_normal_central_2024-05-21T11:38:46.581015', 'mmd_random_normal_lower_2024-05-21T12:10:07.297882', 'mmd_random_uniform_upper_2024-05-24T16:57:05.611926', 'mmd_random_uniform_central_2024-05-24T17:40:28.277449', 'mmd_random_uniform_lower_2024-05-24T18:11:45.804086', 'ks_mean_upper_2024-05-21T20:01:30.182888', 'ks_mean_central_2024-05-21T20:04:40.549424', 'ks_mean_lower_2024-05-21T20:06:25.486998', 'ks_cov_diag_upper_2024-05-21T20:08:17.981182', 'ks_cov_diag_central_2024-05-21T20:11:47.140624', 'ks_cov_diag_lower_2024-05-21T20:13:36.332608', 'ks_cov_off_diag_upper_2024-05-21T20:15:32.757379', 'ks_cov_off_diag_central_2024-05-21T20:18:10.037748', 'ks_cov_off_diag_lower_2024-05-21T20:19:14.908001', 'ks_power_abs_up_upper_2024-05-21T20:20:25.913404', 'ks_power_abs_up_central_2024-05-21T20:24:23.335159', 'ks_power_abs_up_lower_2024-05-21T20:26:09.926411', 'ks_power_abs_down_upper_2024-05-21T20:28:05.467279', 'ks_power_abs_down_central_2024-05-21T20:32:02.720058', 'ks_power_abs_down_lower_2024-05-21T20:33:50.240632', 'ks_random_normal_upper_2024-05-21T20:35:47.262693', 'ks_random_normal_central_2024-05-21T20:38:41.274444', 'ks_random_normal_lower_2024-05-21T20:40:27.329259', 'ks_random_uniform_upper_2024-05-21T20:42:20.432031', 'ks_random_uniform_central_2024-05-21T20:44:59.021739', 'ks_random_uniform_lower_2024-05-21T20:46:43.629993', 'sks_mean_upper_2024-05-21T20:48:38.985035', 'sks_mean_central_2024-05-21T20:53:44.603665', 'sks_mean_lower_2024-05-21T20:56:33.791249', 'sks_cov_diag_upper_2024-05-21T20:59:34.849703', 'sks_cov_diag_central_2024-05-21T21:05:09.422922', 'sks_cov_diag_lower_2024-05-21T21:08:03.524747', 'sks_cov_off_diag_upper_2024-05-21T21:11:09.070806', 'sks_cov_off_diag_central_2024-05-21T21:17:19.729091', 'sks_cov_off_diag_lower_2024-05-21T21:20:14.644478', 'sks_power_abs_up_upper_2024-05-21T21:23:22.418790', 'sks_power_abs_up_central_2024-05-21T21:29:52.025578', 'sks_power_abs_up_lower_2024-05-21T21:32:45.049974', 'sks_power_abs_down_upper_2024-05-21T21:35:49.557443', 'sks_power_abs_down_central_2 ...

# %% [markdown]
# ### Show and save results

# %%
# Function to format bounds
def format_bounds(bounds):
    lower, central, upper = bounds
    return f"${central}_{{-{central-lower:.2g}}}^{{+{upper-central:.2g}}}$"

def format_times(times):
    return sum(times)

global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    pippo = global_result
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    bound = global_result["bound"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][1][3], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][2][3], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, bound, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
    "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "t (s)": lambda x: x.tolist()
}).reset_index()
results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
results_df["time"] = results_df["t (s)"]
results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["t (s)"] = results_df["t (s)"].apply(format_times)
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results
# Out:
# [['fgd', 'mean', 20, 10000, 50000, 'upper', 0.07642, 0.08972, 805],
#  ['fgd', 'mean', 20, 10000, 50000, 'central', 0.05029, 0.06539, 522],
#  ['fgd', 'mean', 20, 10000, 50000, 'lower', 0.02797, 0.04507, 558],
#  ['fgd', 'cov_diag', 20, 10000, 50000, 'upper', 0.02399, 0.02863, 909],
#  ['fgd', 'cov_diag', 20, 10000, 50000, 'central', 0.01695, 0.02215, 526],
#  ['fgd', 'cov_diag', 20, 10000, 50000, 'lower', 0.00999, 0.01621, 559],
#  ['fgd', 'cov_off_diag', 20, 10000, 50000, 'upper', 0.00294, 0.00356, 1119],
#  ['fgd', 'cov_off_diag', 20, 10000, 50000, 'central', 0.00236, 0.00308, 528],
#  ['fgd', 'cov_off_diag', 20, 10000, 50000, 'lower', 0.00162, 0.00254, 645],
#  ['fgd', 'power_abs_up', 20, 10000, 50000, 'upper', 0.00606, 0.00712, 1356],
#  ['fgd', 'power_abs_up', 20, 10000, 50000, 'central', 0.00419, 0.0054, 679],
#  ['fgd', 'power_abs_up', 20, 10000, 50000, 'lower', 0.00239, 0.00391, 729],
#  ['fgd', 'power_abs_down', 20, 10000, 50000, 'upper', 0.00578, 0.00691, 1367],
#  ['fgd', 'power_abs_down', 20, 10000, 50000, 'central', 0.00411, 0.0054, 679],
#  ['fgd', 'power_abs_down', 20, 10000, 50000, 'lower', 0.00258, 0.00403, 711],
#  ['fgd', 'random_normal', 20, 10000, 50000, 'upper', 0.18994, 0.20814, 901],
#  ['fgd', 'random_normal', 20, 10000, 50000, 'central', 0.16992, 0.1944, 590],
#  ['fgd', 'random_normal', 20, 10000, 50000, 'lower', 0.14011, 0.17659, 640],
#  ['fgd', 'random_uniform', 20, 10000, 50000, 'upper', 0.3291, 0.36186, 817],
#  ['fgd', 'random_uniform', 20, 10000, 50000, 'central', 0.2926, 0.33697, 590],
#  ['fgd', 'random_uniform', 20, 10000, 50000, 'lower', 0.24285, 0.30315, 634],
#  ['mmd', 'mean', 20, 10000, 50000, 'upper', 0.08716, 0.10632, 3209],
#  ['mmd', 'mean', 20, 10000, 50000, 'central', 0.0596, 0.08041, 2186],
#  ['mmd', 'mean', 20, 10000, 50000, 'lower', 0.03942, 0.06007, 2336],
#  ['mmd', 'cov_diag', 20, 10000, 50000, 'upper', 0.03406, 0.04149, 3655],
#  ['mmd', 'cov_diag', 20, 10000, 50000, 'central', 0.02325, 0.03109, 2192],
#  ['mmd', 'cov_diag', 20, 10000, 50000, 'lower', 0.01536, 0.02316, 2325],
#  ['mmd', 'cov_off_diag', 20, 10000, 50000, 'upper', 0.01984, 0.02426, 3767],
#  ['mmd', 'cov_off_diag', 20, 10000, 50000, 'central', 0.01275, 0.01756, 2318],
#  ['mmd', 'cov_off_diag', 20, 10000, 50000, 'lower', 0.00744, 0.01238, 2319],
#  ['mmd', 'power_abs_up', 20, 10000, 50000, 'upper', 0.00536, 0.00648, 4348],
#  ['mmd', 'power_abs_up', 20, 10000, 50000, 'central', 0.00358, 0.00483, 2173],
#  ['mmd', 'power_abs_up', 20, 10000, 50000, 'lower', 0.00233, 0.00357, 2317],
#  ['mmd', 'power_abs_down', 20, 10000, 50000, 'upper', 0.00536, 0.00654, 4347],
#  ['mmd',
#   'power_abs_down',
#   20,
#   10000,
#   50000,
#   'central',
#   0.00346,
#   0.00477,
#   2321],
#  ['mmd', 'power_abs_down', 20, 10000, 50000, 'lower', 0.00204, 0.00335, 2321],
#  ['mmd', 'random_normal', 20, 10000, 50000, 'upper', 0.82422, 0.93134, 1883],
#  ['mmd', 'random_normal', 20, 10000, 50000, 'central', 0.73852, 0.85602, 1880],
#  ['mmd', 'random_normal', 20, 10000, 50000, 'lower', 0.64703, 0.79397, 2025],
#  ['mmd', 'random_uniform', 20, 10000, 50000, 'upper', 1.43066, 1.60495, 2602],
#  ['mmd',
#   'random_uniform',
#   20,
#   10000,
#   50000,
#   'central',
#   1.28521,
#   1.49004,
#   1877],
#  ['mmd', 'random_uniform', 20, 10000, 50000, 'lower', 1.11462, 1.36686, 2022],
#  ['ks', 'mean', 20, 10000, 50000, 'upper', 0.06989, 0.08704, 190],
#  ['ks', 'mean', 20, 10000, 50000, 'central', 0.04811, 0.06605, 104],
#  ['ks', 'mean', 20, 10000, 50000, 'lower', 0.0267, 0.04561, 112],
#  ['ks', 'cov_diag', 20, 10000, 50000, 'upper', 0.03952, 0.04997, 209],
#  ['ks', 'cov_diag', 20, 10000, 50000, 'central', 0.02898, 0.04029, 109],
#  ['ks', 'cov_diag', 20, 10000, 50000, 'lower', 0.01724, 0.02994, 116],
#  ['ks', 'cov_off_diag', 20, 10000, 50000, 'upper', 1.01685, 1.02268, 157],
#  ['ks', 'cov_off_diag', 20, 10000, 50000, 'central', 1.0107, 1.01968, 64],
#  ['ks', 'cov_off_diag', 20, 10000, 50000, 'lower', 1.00773, 1.0152, 70],
#  ['ks', 'power_abs_up', 20, 10000, 50000, 'upper', 0.00805, 0.00992, 237],
#  ['ks', 'power_abs_up', 20, 10000, 50000, 'central', 0.00602, 0.00806, 106],
#  ['ks', 'power_abs_up', 20, 10000, 50000, 'lower', 0.00364, 0.00611, 115],
#  ['ks', 'power_abs_down', 20, 10000, 50000, 'upper', 0.00774, 0.00953, 237],
#  ['ks', 'power_abs_down', 20, 10000, 50000, 'central', 0.00575, 0.00773, 107],
#  ['ks', 'power_abs_down', 20, 10000, 50000, 'lower', 0.00352, 0.00587, 117],
#  ['ks', 'random_normal', 20, 10000, 50000, 'upper', 0.3772, 0.42798, 173],
#  ['ks', 'random_normal', 20, 10000, 50000, 'central', 0.32182, 0.3832, 106],
#  ['ks', 'random_normal', 20, 10000, 50000, 'lower', 0.24174, 0.32905, 113],
#  ['ks', 'random_uniform', 20, 10000, 50000, 'upper', 0.65186, 0.7389, 158],
#  ['ks', 'random_uniform', 20, 10000, 50000, 'central', 0.55562, 0.65585, 104],
#  ['ks', 'random_uniform', 20, 10000, 50000, 'lower', 0.41375, 0.56696, 115],
#  ['sks', 'mean', 20, 10000, 50000, 'upper', 0.06989, 0.08403, 305],
#  ['sks', 'mean', 20, 10000, 50000, 'central', 0.04841, 0.06372, 169],
#  ['sks', 'mean', 20, 10000, 50000, 'lower', 0.0275, 0.04377, 181],
#  ['sks', 'cov_diag', 20, 10000, 50000, 'upper', 0.03494, 0.04237, 334],
#  ['sks', 'cov_diag', 20, 10000, 50000, 'central', 0.02623, 0.03417, 174],
#  ['sks', 'cov_diag', 20, 10000, 50000, 'lower', 0.01622, 0.02555, 185],
#  ['sks', 'cov_off_diag', 20, 10000, 50000, 'upper', 0.01423, 0.01811, 370],
#  ['sks', 'cov_off_diag', 20, 10000, 50000, 'central', 0.01029, 0.01451, 174],
#  ['sks', 'cov_off_diag', 20, 10000, 50000, 'lower', 0.00592, 0.01045, 187],
#  ['sks', 'power_abs_up', 20, 10000, 50000, 'upper', 0.00677, 0.0081, 389],
#  ['sks', 'power_abs_up', 20, 10000, 50000, 'central', 0.00505, 0.00646, 172],
#  ['sks', 'power_abs_up', 20, 10000, 50000, 'lower', 0.00309, 0.00479, 184],
#  ['sks', 'power_abs_down', 20, 10000, 50000, 'upper', 0.00658, 0.00791, 389],
#  ['sks', 'power_abs_down', 20, 10000, 50000, 'central', 0.00487, 0.00632, 174],
#  ['sks', 'power_abs_down', 20, 10000, 50000, 'lower', 0.003, 0.00467, 185],
#  ['sks', 'random_normal', 20, 10000, 50000, 'upper', 0.32837, 0.36601, 272],
#  ['sks', 'random_normal', 20, 10000, 50000, 'central', 0.28237, 0.32811, 167],
#  ['sks', 'random_normal', 20, 10000, 50000, 'lower', 0.21596, 0.27992, 172],
#  ['sks', 'random_uniform', 20, 10000, 50000, 'upper', 0.57373, 0.63641, 244],
#  ['sks', 'random_uniform', 20, 10000, 50000, 'central', 0.48849, 0.56476, 161],
#  ['sks', 'random_uniform', 20, 10000, 50000, 'lower', 0.37393, 0.48575, 176],
#  ['swd', 'mean', 20, 10000, 50000, 'upper', 0.07172, 0.08706, 260],
#  ['swd', 'mean', 20, 10000, 50000, 'central', 0.04948, 0.06621, 153],
#  ['swd', 'mean', 20, 10000, 50000, 'lower', 0.02806, 0.0458, 157],
#  ['swd', 'cov_diag', 20, 10000, 50000, 'upper', 0.02724, 0.03346, 303],
#  ['swd', 'cov_diag', 20, 10000, 50000, 'central', 0.02059, 0.02732, 153],
#  ['swd', 'cov_diag', 20, 10000, 50000, 'lower', 0.01275, 0.02078, 159],
#  ['swd', 'cov_off_diag', 20, 10000, 50000, 'upper', 0.01499, 0.01948, 323],
#  ['swd', 'cov_off_diag', 20, 10000, 50000, 'central', 0.01153, 0.01644, 148],
#  ['swd', 'cov_off_diag', 20, 10000, 50000, 'lower', 0.00709, 0.0129, 157],
#  ['swd', 'power_abs_up', 20, 10000, 50000, 'upper', 0.00631, 0.00772, 341],
#  ['swd', 'power_abs_up', 20, 10000, 50000, 'central', 0.0046, 0.00614, 146],
#  ['swd', 'power_abs_up', 20, 10000, 50000, 'lower', 0.00272, 0.00447, 155],
#  ['swd', 'power_abs_down', 20, 10000, 50000, 'upper', 4.98047, 4.99023, 77],
#  ['swd', 'power_abs_down', 20, 10000, 50000, 'central', 0.00455, 0.00609, 353],
#  ['swd', 'power_abs_down', 20, 10000, 50000, 'lower', 0.00282, 0.00457, 156],
#  ['swd', 'random_normal', 20, 10000, 50000, 'upper', 0.33325, 0.37313, 239],
#  ['swd', 'random_normal', 20, 10000, 50000, 'central', 0.28641, 0.33654, 144],
#  ['swd', 'random_normal', 20, 10000, 50000, 'lower', 0.22151, 0.29071, 151],
#  ['swd', 'random_uniform', 20, 10000, 50000, 'upper', 0.57373, 0.64505, 209],
#  ['swd', 'random_uniform', 20, 10000, 50000, 'central', 0.49513, 0.5818, 147],
#  ['swd', 'random_uniform', 20, 10000, 50000, 'lower', 0.38522, 0.50348, 155],
#  ['lr', 'mean', 20, 10000, 50000, 'upper', 0.00863, 0.01099, 797],
#  ['lr', 'mean', 20, 10000, 50000, 'central', 0.00556, 0.00795, 798],
#  ['lr', 'mean', 20, 10000, 50000, 'lower', 0.00252, 0.00492, 845],
#  ['lr', 'cov_diag', 20, 10000, 50000, 'upper', 0.00253, 0.00318, 1300],
#  ['lr', 'cov_diag', 20, 10000, 50000, 'central', 0.00153, 0.0022, 831],
#  ['lr', 'cov_diag', 20, 10000, 50000, 'lower', 0.00055, 0.00121, 948],
#  ['lr', 'cov_off_diag', 20, 10000, 50000, 'upper', 0.00011, 0.00014, 2111],
#  ['lr', 'cov_off_diag', 20, 10000, 50000, 'central', 7e-05, 0.0001, 957],
#  ['lr', 'cov_off_diag', 20, 10000, 50000, 'lower', 3e-05, 6e-05, 1999],
#  ['lr', 'power_abs_up', 20, 10000, 50000, 'upper', 0.00067, 0.00086, 1255],
#  ['lr', 'power_abs_up', 20, 10000, 50000, 'central', 0.00042, 0.00061, 804],
#  ['lr', 'power_abs_up', 20, 10000, 50000, 'lower', 0.00016, 0.00036, 859],
#  ['lr', 'power_abs_down', 20, 10000, 50000, 'upper', 0.00067, 0.00085, 1260],
#  ['lr', 'power_abs_down', 20, 10000, 50000, 'central', 0.00042, 0.0006, 803],
#  ['lr', 'power_abs_down', 20, 10000, 50000, 'lower', 0.00016, 0.00035, 866]]

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
sorted_df_mean = results_df_mean.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_mean)
# Out:
# /tmp/ipykernel_2189470/2349835371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 16        lr        mean   20  10000                50000
# 9         ks        mean   20  10000                50000
# 28       sks        mean   20  10000                50000
# 35       swd        mean   20  10000                50000
# 2        fgd        mean   20  10000                50000
# 21       mmd        mean   20  10000                50000
#
#    $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 16       $0.00556_{-0.003}^{+0.0031}$        $0.00795_{-0.003}^{+0.003}$
# 9         $0.04811_{-0.021}^{+0.022}$         $0.06605_{-0.02}^{+0.021}$
# 28        $0.04841_{-0.021}^{+0.021}$          $0.06372_{-0.02}^{+0.02}$
# 35        $0.04948_{-0.021}^{+0.022}$         $0.06621_{-0.02}^{+0.021}$
# 2         $0.05029_{-0.022}^{+0.026}$         $0.06539_{-0.02}^{+0.024}$
# 21          $0.0596_{-0.02}^{+0.028}$         $0.08041_{-0.02}^{+0.026}$
#
#     $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 16           2440  [0.00252, 0.00556, 0.00863]  [0.00492, 0.00795, 0.01099]
# 9             406   [0.0267, 0.04811, 0.06989]  [0.04561, 0.06605, 0.08704]
# 28            655   [0.0275, 0.04841, 0.06989]  [0.04377, 0.06372, 0.08403]
# 35            570  [0.02806, 0.04948, 0.07172]   [0.0458, 0.06621, 0.08706]
# 2            1885  [0.02797, 0.05029, 0.07642]  [0.04507, 0.06539, 0.08972]
# 21           7731   [0.03942, 0.0596, 0.08716]  [0.06007, 0.08041, 0.10632]
#
#                   time
# 16     [797, 798, 845]
# 9      [190, 104, 112]
# 28     [305, 169, 181]
# 35     [260, 153, 157]
# 2      [805, 522, 558]
# 21  [3209, 2186, 2336]
#    Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 16        lr       $0.00556_{-0.003}^{+0.0031}$
# 9         ks        $0.04811_{-0.021}^{+0.022}$
# 28       sks        $0.04841_{-0.021}^{+0.021}$
# 35       swd        $0.04948_{-0.021}^{+0.022}$
# 2        fgd        $0.05029_{-0.022}^{+0.026}$
# 21       mmd          $0.0596_{-0.02}^{+0.028}$
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 16        $0.00795_{-0.003}^{+0.003}$           2440
# 9          $0.06605_{-0.02}^{+0.021}$            406
# 28          $0.06372_{-0.02}^{+0.02}$            655
# 35         $0.06621_{-0.02}^{+0.021}$            570
# 2          $0.06539_{-0.02}^{+0.024}$           1885
# 21         $0.08041_{-0.02}^{+0.026}$           7731

# %%
results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_diag)
# Out:
# /tmp/ipykernel_2189470/2882134307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 14        lr    cov_diag   20  10000                50000
# 0        fgd    cov_diag   20  10000                50000
# 33       swd    cov_diag   20  10000                50000
# 19       mmd    cov_diag   20  10000                50000
# 26       sks    cov_diag   20  10000                50000
# 7         ks    cov_diag   20  10000                50000
#
#    $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 14              $0.00153_{-0.00098}^{+0.001}$
# 0                 $0.01695_{-0.007}^{+0.007}$
# 33              $0.02059_{-0.0078}^{+0.0066}$
# 19               $0.02325_{-0.0079}^{+0.011}$
# 26                $0.02623_{-0.01}^{+0.0087}$
# 7                 $0.02898_{-0.012}^{+0.011}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)  \
# 14             $0.0022_{-0.00099}^{+0.00098}$                   3079
# 0               $0.02215_{-0.0059}^{+0.0065}$                   1994
# 33              $0.02732_{-0.0065}^{+0.0061}$                    615
# 19                $0.03109_{-0.0079}^{+0.01}$                   8172
# 26              $0.03417_{-0.0086}^{+0.0082}$                    693
# 7                 $0.04029_{-0.01}^{+0.0097}$                    434
#
#                           95%CL                        99%CL  \
# 14  [0.00055, 0.00153, 0.00253]   [0.00121, 0.0022, 0.00318]
# 0   [0.00999, 0.01695, 0.02399]  [0.01621, 0.02215, 0.02863]
# 33  [0.01275, 0.02059, 0.02724]  [0.02078, 0.02732, 0.03346]
# 19  [0.01536, 0.02325, 0.03406]  [0.02316, 0.03109, 0.04149]
# 26  [0.01622, 0.02623, 0.03494]  [0.02555, 0.03417, 0.04237]
# 7   [0.01724, 0.02898, 0.03952]  [0.02994, 0.04029, 0.04997]
#
#                   time
# 14    [1300, 831, 948]
# 0      [909, 526, 559]
# 33     [303, 153, 159]
# 19  [3655, 2192, 2325]
# 26     [334, 174, 185]
# 7      [209, 109, 116]
#    Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 14        lr              $0.00153_{-0.00098}^{+0.001}$
# 0        fgd                $0.01695_{-0.007}^{+0.007}$
# 33       swd              $0.02059_{-0.0078}^{+0.0066}$
# 19       mmd               $0.02325_{-0.0079}^{+0.011}$
# 26       sks                $0.02623_{-0.01}^{+0.0087}$
# 7         ks                $0.02898_{-0.012}^{+0.011}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)
# 14             $0.0022_{-0.00099}^{+0.00098}$                   3079
# 0               $0.02215_{-0.0059}^{+0.0065}$                   1994
# 33              $0.02732_{-0.0065}^{+0.0061}$                    615
# 19                $0.03109_{-0.0079}^{+0.01}$                   8172
# 26              $0.03417_{-0.0086}^{+0.0082}$                    693
# 7                 $0.04029_{-0.01}^{+0.0097}$                    434

# %%
results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
# /tmp/ipykernel_2189470/3376285218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 15        lr  cov_off_diag   20  10000                50000
# 1        fgd  cov_off_diag   20  10000                50000
# 27       sks  cov_off_diag   20  10000                50000
# 34       swd  cov_off_diag   20  10000                50000
# 20       mmd  cov_off_diag   20  10000                50000
# 8         ks  cov_off_diag   20  10000                50000
#
#    $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 15                       $7e-05_{-4e-05}^{+4e-05}$
# 1                  $0.00236_{-0.00074}^{+0.00058}$
# 27                   $0.01029_{-0.0044}^{+0.0039}$
# 34                   $0.01153_{-0.0044}^{+0.0035}$
# 20                   $0.01275_{-0.0053}^{+0.0071}$
# 8                      $1.0107_{-0.003}^{+0.0062}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 15                      $0.0001_{-4e-05}^{+4e-05}$
# 1                  $0.00308_{-0.00054}^{+0.00048}$
# 27                   $0.01451_{-0.0041}^{+0.0036}$
# 34                    $0.01644_{-0.0035}^{+0.003}$
# 20                   $0.01756_{-0.0052}^{+0.0067}$
# 8                     $1.01968_{-0.0045}^{+0.003}$
#
#     $t^{\Sigma_{i\neq j}}$ (s)                        95%CL  \
# 15                        5067      [3e-05, 7e-05, 0.00011]
# 1                         2292  [0.00162, 0.00236, 0.00294]
# 27                         731  [0.00592, 0.01029, 0.01423]
# 34                         628  [0.00709, 0.01153, 0.01499]
# 20                        8404  [0.00744, 0.01275, 0.01984]
# 8                          291   [1.00773, 1.0107, 1.01685]
#
#                           99%CL                time
# 15     [6e-05, 0.0001, 0.00014]   [2111, 957, 1999]
# 1   [0.00254, 0.00308, 0.00356]    [1119, 528, 645]
# 27  [0.01045, 0.01451, 0.01811]     [370, 174, 187]
# 34   [0.0129, 0.01644, 0.01948]     [323, 148, 157]
# 20  [0.01238, 0.01756, 0.02426]  [3767, 2318, 2319]
# 8    [1.0152, 1.01968, 1.02268]       [157, 64, 70]
#    Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 15        lr                       $7e-05_{-4e-05}^{+4e-05}$
# 1        fgd                 $0.00236_{-0.00074}^{+0.00058}$
# 27       sks                   $0.01029_{-0.0044}^{+0.0039}$
# 34       swd                   $0.01153_{-0.0044}^{+0.0035}$
# 20       mmd                   $0.01275_{-0.0053}^{+0.0071}$
# 8         ks                     $1.0107_{-0.003}^{+0.0062}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)
# 15                      $0.0001_{-4e-05}^{+4e-05}$                        5067
# 1                  $0.00308_{-0.00054}^{+0.00048}$                        2292
# 27                   $0.01451_{-0.0041}^{+0.0036}$                         731
# 34                    $0.01644_{-0.0035}^{+0.003}$                         628
# 20                   $0.01756_{-0.0052}^{+0.0067}$                        8404
# 8                     $1.01968_{-0.0045}^{+0.003}$                         291

# %%
results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
# /tmp/ipykernel_2189470/2976661110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 18        lr  power_abs_up   20  10000                50000
# 23       mmd  power_abs_up   20  10000                50000
# 4        fgd  power_abs_up   20  10000                50000
# 37       swd  power_abs_up   20  10000                50000
# 30       sks  power_abs_up   20  10000                50000
# 11        ks  power_abs_up   20  10000                50000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 18             $0.00042_{-0.00026}^{+0.00025}$
# 23               $0.00358_{-0.0012}^{+0.0018}$
# 4                $0.00419_{-0.0018}^{+0.0019}$
# 37                $0.0046_{-0.0019}^{+0.0017}$
# 30                $0.00505_{-0.002}^{+0.0017}$
# 11                $0.00602_{-0.0024}^{+0.002}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)  \
# 18             $0.00061_{-0.00025}^{+0.00025}$                    2918
# 23               $0.00483_{-0.0013}^{+0.0016}$                    8838
# 4                 $0.0054_{-0.0015}^{+0.0017}$                    2764
# 37               $0.00614_{-0.0017}^{+0.0016}$                     642
# 30               $0.00646_{-0.0017}^{+0.0016}$                     745
# 11               $0.00806_{-0.0019}^{+0.0019}$                     458
#
#                           95%CL                        99%CL  \
# 18  [0.00016, 0.00042, 0.00067]  [0.00036, 0.00061, 0.00086]
# 23  [0.00233, 0.00358, 0.00536]  [0.00357, 0.00483, 0.00648]
# 4   [0.00239, 0.00419, 0.00606]   [0.00391, 0.0054, 0.00712]
# 37   [0.00272, 0.0046, 0.00631]  [0.00447, 0.00614, 0.00772]
# 30  [0.00309, 0.00505, 0.00677]   [0.00479, 0.00646, 0.0081]
# 11  [0.00364, 0.00602, 0.00805]  [0.00611, 0.00806, 0.00992]
#
#                   time
# 18    [1255, 804, 859]
# 23  [4348, 2173, 2317]
# 4     [1356, 679, 729]
# 37     [341, 146, 155]
# 30     [389, 172, 184]
# 11     [237, 106, 115]
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 18        lr             $0.00042_{-0.00026}^{+0.00025}$
# 23       mmd               $0.00358_{-0.0012}^{+0.0018}$
# 4        fgd               $0.00419_{-0.0018}^{+0.0019}$
# 37       swd                $0.0046_{-0.0019}^{+0.0017}$
# 30       sks                $0.00505_{-0.002}^{+0.0017}$
# 11        ks                $0.00602_{-0.0024}^{+0.002}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 18             $0.00061_{-0.00025}^{+0.00025}$                    2918
# 23               $0.00483_{-0.0013}^{+0.0016}$                    8838
# 4                 $0.0054_{-0.0015}^{+0.0017}$                    2764
# 37               $0.00614_{-0.0017}^{+0.0016}$                     642
# 30               $0.00646_{-0.0017}^{+0.0016}$                     745
# 11               $0.00806_{-0.0019}^{+0.0019}$                     458

# %%
results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
# /tmp/ipykernel_2189470/1061777215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 17        lr  power_abs_down   20  10000                50000
# 22       mmd  power_abs_down   20  10000                50000
# 3        fgd  power_abs_down   20  10000                50000
# 36       swd  power_abs_down   20  10000                50000
# 29       sks  power_abs_down   20  10000                50000
# 10        ks  power_abs_down   20  10000                50000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 17             $0.00042_{-0.00026}^{+0.00025}$
# 22               $0.00346_{-0.0014}^{+0.0019}$
# 3                $0.00411_{-0.0015}^{+0.0017}$
# 36                    $0.00455_{-0.0017}^{+5}$
# 29               $0.00487_{-0.0019}^{+0.0017}$
# 10                $0.00575_{-0.0022}^{+0.002}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)  \
# 17              $0.0006_{-0.00025}^{+0.00025}$                    2929
# 22               $0.00477_{-0.0014}^{+0.0018}$                    8989
# 3                 $0.0054_{-0.0014}^{+0.0015}$                    2757
# 36                    $0.00609_{-0.0015}^{+5}$                     586
# 29               $0.00632_{-0.0017}^{+0.0016}$                     748
# 10               $0.00773_{-0.0019}^{+0.0018}$                     461
#
#                           95%CL                        99%CL  \
# 17  [0.00016, 0.00042, 0.00067]   [0.00035, 0.0006, 0.00085]
# 22  [0.00204, 0.00346, 0.00536]  [0.00335, 0.00477, 0.00654]
# 3   [0.00258, 0.00411, 0.00578]   [0.00403, 0.0054, 0.00691]
# 36  [0.00282, 0.00455, 4.98047]  [0.00457, 0.00609, 4.99023]
# 29    [0.003, 0.00487, 0.00658]  [0.00467, 0.00632, 0.00791]
# 10  [0.00352, 0.00575, 0.00774]  [0.00587, 0.00773, 0.00953]
#
#                   time
# 17    [1260, 803, 866]
# 22  [4347, 2321, 2321]
# 3     [1367, 679, 711]
# 36      [77, 353, 156]
# 29     [389, 174, 185]
# 10     [237, 107, 117]
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 17        lr             $0.00042_{-0.00026}^{+0.00025}$
# 22       mmd               $0.00346_{-0.0014}^{+0.0019}$
# 3        fgd               $0.00411_{-0.0015}^{+0.0017}$
# 36       swd                    $0.00455_{-0.0017}^{+5}$
# 29       sks               $0.00487_{-0.0019}^{+0.0017}$
# 10        ks                $0.00575_{-0.0022}^{+0.002}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 17              $0.0006_{-0.00025}^{+0.00025}$                    2929
# 22               $0.00477_{-0.0014}^{+0.0018}$                    8989
# 3                 $0.0054_{-0.0014}^{+0.0015}$                    2757
# 36                    $0.00609_{-0.0015}^{+5}$                     586
# 29               $0.00632_{-0.0017}^{+0.0016}$                     748
# 10               $0.00773_{-0.0019}^{+0.0018}$                     461

# %%
results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_normal = results_df_random_normal.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_normal)
# Out:
# /tmp/ipykernel_2189470/3420336598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        fgd  random_normal   20  10000                50000
# 31       sks  random_normal   20  10000                50000
# 38       swd  random_normal   20  10000                50000
# 12        ks  random_normal   20  10000                50000
# 24       mmd  random_normal   20  10000                50000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                   $0.16992_{-0.03}^{+0.02}$
# 31                $0.28237_{-0.066}^{+0.046}$
# 38                $0.28641_{-0.065}^{+0.047}$
# 12                 $0.32182_{-0.08}^{+0.055}$
# 24                $0.73852_{-0.091}^{+0.086}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)  \
# 5                  $0.1944_{-0.018}^{+0.014}$                   2131
# 31                $0.32811_{-0.048}^{+0.038}$                    611
# 38                $0.33654_{-0.046}^{+0.037}$                    534
# 12                 $0.3832_{-0.054}^{+0.045}$                    392
# 24                $0.85602_{-0.062}^{+0.075}$                   5788
#
#                           95%CL                        99%CL  \
# 5   [0.14011, 0.16992, 0.18994]   [0.17659, 0.1944, 0.20814]
# 31  [0.21596, 0.28237, 0.32837]  [0.27992, 0.32811, 0.36601]
# 38  [0.22151, 0.28641, 0.33325]  [0.29071, 0.33654, 0.37313]
# 12   [0.24174, 0.32182, 0.3772]   [0.32905, 0.3832, 0.42798]
# 24  [0.64703, 0.73852, 0.82422]  [0.79397, 0.85602, 0.93134]
#
#                   time
# 5      [901, 590, 640]
# 31     [272, 167, 172]
# 38     [239, 144, 151]
# 12     [173, 106, 113]
# 24  [1883, 1880, 2025]
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        fgd                  $0.16992_{-0.03}^{+0.02}$
# 31       sks                $0.28237_{-0.066}^{+0.046}$
# 38       swd                $0.28641_{-0.065}^{+0.047}$
# 12        ks                 $0.32182_{-0.08}^{+0.055}$
# 24       mmd                $0.73852_{-0.091}^{+0.086}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                  $0.1944_{-0.018}^{+0.014}$                   2131
# 31                $0.32811_{-0.048}^{+0.038}$                    611
# 38                $0.33654_{-0.046}^{+0.037}$                    534
# 12                 $0.3832_{-0.054}^{+0.045}$                    392
# 24                $0.85602_{-0.062}^{+0.075}$                   5788

# %%
results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_uniform)
# Out:
# /tmp/ipykernel_2189470/3647480920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform   20  10000                50000
# 13        ks  random_uniform   20  10000                50000
# 25       mmd  random_uniform   20  10000                50000
# 32       sks  random_uniform   20  10000                50000
# 39       swd  random_uniform   20  10000                50000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                   $0.2926_{-0.05}^{+0.036}$
# 13                 $0.55562_{-0.14}^{+0.096}$
# 25                  $1.28521_{-0.17}^{+0.15}$
# 32                 $0.48849_{-0.11}^{+0.085}$
# 39                 $0.49513_{-0.11}^{+0.079}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)  \
# 6                 $0.33697_{-0.034}^{+0.025}$                   2041
# 13                $0.65585_{-0.089}^{+0.083}$                    377
# 25                  $1.49004_{-0.12}^{+0.11}$                   6501
# 32                $0.56476_{-0.079}^{+0.072}$                    581
# 39                 $0.5818_{-0.078}^{+0.063}$                    511
#
#                           95%CL                        99%CL  \
# 6     [0.24285, 0.2926, 0.3291]  [0.30315, 0.33697, 0.36186]
# 13  [0.41375, 0.55562, 0.65186]   [0.56696, 0.65585, 0.7389]
# 25  [1.11462, 1.28521, 1.43066]  [1.36686, 1.49004, 1.60495]
# 32  [0.37393, 0.48849, 0.57373]  [0.48575, 0.56476, 0.63641]
# 39  [0.38522, 0.49513, 0.57373]   [0.50348, 0.5818, 0.64505]
#
#                   time
# 6      [817, 590, 634]
# 13     [158, 104, 115]
# 25  [2602, 1877, 2022]
# 32     [244, 161, 176]
# 39     [209, 147, 155]
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                  $0.2926_{-0.05}^{+0.036}$
# 13        ks                 $0.55562_{-0.14}^{+0.096}$
# 25       mmd                  $1.28521_{-0.17}^{+0.15}$
# 32       sks                 $0.48849_{-0.11}^{+0.085}$
# 39       swd                 $0.49513_{-0.11}^{+0.079}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                 $0.33697_{-0.034}^{+0.025}$                   2041
# 13                $0.65585_{-0.089}^{+0.083}$                    377
# 25                  $1.49004_{-0.12}^{+0.11}$                   6501
# 32                $0.56476_{-0.079}^{+0.072}$                    581
# 39                 $0.5818_{-0.078}^{+0.063}$                    511

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(sorted_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule\nStatistic",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\\nStatistic")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule\nStatistic",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\\nStatistic")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
string = string.replace("\n","\n\t\t")
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# 		\toprule
# 		\multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# 		\multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# 		Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# 		\midrule
# 		$d_{\mathrm{FGD}_{\infty}}$ & $0.05029_{-0.022}^{+0.026}$ & $0.06539_{-0.02}^{+0.024}$ & 1885 & $0.01695_{-0.007}^{+0.007}$ & $0.02215_{-0.0059}^{+0.0065}$ & 1994 & $0.00236_{-0.00074}^{+0.00058}$ & $0.00308_{-0.00054}^{+0.00048}$ & 2292 & $0.00419_{-0.0018}^{+0.0019}$ & $0.0054_{-0.0015}^{+0.0017}$ & 2764 \\
# 		$\overline{D}$ & $0.04811_{-0.021}^{+0.022}$ & $0.06605_{-0.02}^{+0.021}$ & 406 & $0.02898_{-0.012}^{+0.011}$ & $0.04029_{-0.01}^{+0.0097}$ & 434 & $1.0107_{-0.003}^{+0.0062}$ & $1.01968_{-0.0045}^{+0.003}$ & 291 & $0.00602_{-0.0024}^{+0.002}$ & $0.00806_{-0.0019}^{+0.0019}$ & 458 \\
# 		$t_{\mathrm{LLR}}$ & $0.00556_{-0.003}^{+0.0031}$ & $0.00795_{-0.003}^{+0.003}$ & 2440 & $0.00153_{-0.00098}^{+0.001}$ & $0.0022_{-0.00099}^{+0.00098}$ & 3079 & $7e-05_{-4e-05}^{+4e-05}$ & $0.0001_{-4e-05}^{+4e-05}$ & 5067 & $0.00042_{-0.00026}^{+0.00025}$ & $0.00061_{-0.00025}^{+0.00025}$ & 2918 \\
# 		$d_{\mathrm{MMD}^{2}_{u}}$ & $0.0596_{-0.02}^{+0.028}$ & $0.08041_{-0.02}^{+0.026}$ & 7731 & $0.02325_{-0.0079}^{+0.011}$ & $0.03109_{-0.0079}^{+0.01}$ & 8172 & $0.01275_{-0.0053}^{+0.0071}$ & $0.01756_{-0.0052}^{+0.0067}$ & 8404 & $0.00358_{-0.0012}^{+0.0018}$ & $0.00483_{-0.0013}^{+0.0016}$ & 8838 \\
# 		$\widetilde{D}$ & $0.04841_{-0.021}^{+0.021}$ & $0.06372_{-0.02}^{+0.02}$ & 655 & $0.02623_{-0.01}^{+0.0087}$ & $0.03417_{-0.0086}^{+0.0082}$ & 693 & $0.01029_{-0.0044}^{+0.0039}$ & $0.01451_{-0.0041}^{+0.0036}$ & 731 & $0.00505_{-0.002}^{+0.0017}$ & $0.00646_{-0.0017}^{+0.0016}$ & 745 \\
# 		$\widetilde{W}$ & $0.04948_{-0.021}^{+0.022}$ & $0.06621_{-0.02}^{+0.021}$ & 570 & $0.02059_{-0.0078}^{+0.0066}$ & $0.02732_{-0.0065}^{+0.0061}$ & 615 & $0.01153_{-0.0044}^{+0.0035}$ & $0.01644_{-0.0035}^{+0.003}$ & 628 & $0.0046_{-0.0019}^{+0.0017}$ & $0.00614_{-0.0017}^{+0.0016}$ & 642 \\
# 		\toprule
# 		\multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# 		Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# 		\midrule
# 		$d_{\mathrm{FGD}_{\infty}}$ & $0.00411_{-0.0015}^{+0.0017}$ & $0.0054_{-0.0014}^{+0.0015}$ & 2757 & $0.16992_{-0.03}^{+0.02}$ & $0.1944_{-0.018}^{+0.014}$ & 2.1e+03 & $0.2926_{-0.05}^{+0.036}$ & $0.33697_{-0.034}^{+0.025}$ & 2e+03 & 3821 \\
# 		$\overline{D}$ & $0.00575_{-0.0022}^{+0.002}$ & $0.00773_{-0.0019}^{+0.0018}$ & 461 & $0.32182_{-0.08}^{+0.055}$ & $0.3832_{-0.054}^{+0.045}$ & 3.9e+02 & $0.55562_{-0.14}^{+0.096}$ & $0.65585_{-0.089}^{+0.083}$ & 3.8e+02 & 127 \\
# 		$t_{\mathrm{LLR}}$ & $0.00042_{-0.00026}^{+0.00025}$ & $0.0006_{-0.00025}^{+0.00025}$ & 2929 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# 		$d_{\mathrm{MMD}^{2}_{u}}$ & $0.00346_{-0.0014}^{+0.0019}$ & $0.00477_{-0.0014}^{+0.0018}$ & 8989 & $0.73852_{-0.091}^{+0.086}$ & $0.85602_{-0.062}^{+0.075}$ & 5.8e+03 & $1.28521_{-0.17}^{+0.15}$ & $1.49004_{-0.12}^{+0.11}$ & 6.5e+03 & 13843 \\
# 		$\widetilde{D}$ & $0.00487_{-0.0019}^{+0.0017}$ & $0.00632_{-0.0017}^{+0.0016}$ & 748 & $0.28237_{-0.066}^{+0.046}$ & $0.32811_{-0.048}^{+0.038}$ & 6.1e+02 & $0.48849_{-0.11}^{+0.085}$ & $0.56476_{-0.079}^{+0.072}$ & 5.8e+02 & 480 \\
# 		$\widetilde{W}$ & $0.00455_{-0.0017}^{+5}$ & $0.00609_{-0.0015}^{+5}$ & 586 & $0.28641_{-0.065}^{+0.047}$ & $0.33654_{-0.046}^{+0.037}$ & 5.3e+02 & $0.49513_{-0.11}^{+0.079}$ & $0.5818_{-0.078}^{+0.063}$ & 5.1e+02 & 313 \\
# 		\bottomrule
# 		\end{tabular}
