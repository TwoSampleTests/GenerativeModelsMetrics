# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [2]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_unimodal import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/100D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-23 14:57:49.275959: Importing os...
# 2024-04-23 14:57:49.276100: Importing sys...
# Visible devices: [2]
# 2024-04-23 14:57:49.276350: Importing timer from timeit...
# 2024-04-23 14:57:49.276417: Setting env variables for tf import (only device(s) [2] will be available)...
# 2024-04-23 14:57:49.276550: Importing numpy...
# 2024-04-23 14:57:49.397462: Importing matplotlib...
# 2024-04-23 14:57:49.776374: Importing h5py...
# 2024-04-23 14:57:49.800206: Importing importlib.util...
# 2024-04-23 14:57:49.800310: Importing json...
# 2024-04-23 14:57:49.800375: Importing pandas...
# 2024-04-23 14:57:50.255407: Importing random...
# 2024-04-23 14:57:50.255564: Importing scipy utils...
# 2024-04-23 14:57:50.784949: Importing subprocess...
# 2024-04-23 14:57:50.785087: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-23 14:57:54.417023: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-23 14:57:55.524743: Importing timeit...
# 2024-04-23 14:57:55.524836: Importing tqdm...
# 2024-04-23 14:57:55.533274: Importing typing...
# 2024-04-23 14:57:55.533394: Setting tf configs...
# 2024-04-23 14:57:55.625459: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-23 14:58:00.657910: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #2, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-04-23 14:58:00.692376: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 10
ndims = 100
niter = 10_000
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = 0.,
                                                             eps_scale = 0.,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
dist_2 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = eps_loc,
                                                             eps_scale = eps_scale,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (100,) (100,)

# %% [markdown]
# # Fixed $n=50000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 50_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 500000000
# batch_size 50000
# niter 10000
# niter * batch_size 500000000
# small_sample False

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 1000,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 1000,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               #min_samples_input = 20_000,
                               #max_samples_input = 50_000,
                               num_batches = 20)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4,
                               block_size = 10_000,
                               num_batches = 1,
                               batch_size = 50_000)
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            50000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...      100           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True      100           0  float64   100  500000000         False
#
#    ncomp
# 0     10
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fn": {"name": "fn", # type: ignore
                                       "object_name": "FNMetric",
                                       "class_name": "GMetrics.FNMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns)/ndims,
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)/ndims",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50,
                                       "latex": "$\overline{\|\cdot\|}_{F}$",
                                       "null_file": null_hypotheses_dir+"FN.json"},
                               "fpd": {"name": "fpd",
                                       "object_name": "FPDMetric",
                                       "class_name": "GMetrics.FPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1000,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10,
                                       "latex": "$d_{\mathrm{FPD}}$",
                                       "null_file": null_hypotheses_dir+"FPD.json"},
                               "kpd": {"name": "kpd",
                                       "object_name": "KPDMetric" ,
                                       "class_name": "GMetrics.KPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1,
                                       "latex": "$d_{\mathrm{KPD}}$",
                                       "null_file": null_hypotheses_dir+"KPD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 1000, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 1000, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fn': {'name': 'fn',
#   'object_name': 'FNMetric',
#   'class_name': 'GMetrics.FNMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)/ndims',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 50,
#   'latex': '$\\overline{\\|\\cdot\\|}_{F}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/FN.json'},
#  'fpd': {'name': 'fpd',
#   'object_name': 'FPDMetric',
#   'class_name': 'GMetrics.FPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 10,
#   'latex': '$d_{\\mathrm{FPD}}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/FPD.json'},
#  'kpd': {'name': 'kpd',
#   'object_name': 'KPDMetric',
#   'class_name': 'GMetrics.KPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{KPD}}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/KPD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 5000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 1000, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 20,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 1000, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 20,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 20,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/100D_unimodal/100D_50K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fn from results/100D_unimodal/100D_50K/null_hypothesis/FN.json
# Loading fpd from results/100D_unimodal/100D_50K/null_hypothesis/FPD.json
# Loading kpd from results/100D_unimodal/100D_50K/null_hypothesis/KPD.json
# Loading ks from results/100D_unimodal/100D_50K/null_hypothesis/KS.json
# Loading sks from results/100D_unimodal/100D_50K/null_hypothesis/SKS.json
# Loading swd from results/100D_unimodal/100D_50K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fn: [[0.68, [6800, 3199], 0.9199293485916724], [0.95, [9500, 500], 1.060355820195381], [0.99, [9900, 100], 1.1491168318127254]]
# Computing time for metric fn: 34.85722121386789
# ThresholdS for metric fpd: [[0.68, [6800, 3199], 0.5093629878783318], [0.95, [9500, 500], 0.5852016278386474], [0.99, [9900, 100], 0.6350534414539619]]
# Computing time for metric fpd: 1475.88122712099
# ThresholdS for metric kpd: [[0.68, [6800, 3199], 0.0059429190102378016], [0.95, [9500, 500], 0.006888467828858325], [0.99, [9900, 100], 0.007504011971803948]]
# Computing time for metric kpd: 22379.43812136585
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.8941979620490395], [0.95, [9500, 500], 0.9992487923654776], [0.99, [9900, 100], 1.0683762518962197]]
# Computing time for metric ks: 599.9513686140999
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.893739436395866], [0.95, [9500, 500], 0.98900622440745], [0.99, [9900, 100], 1.0512334752782537]]
# Computing time for metric sks: 4655.108292541932
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.12934140839484362], [0.95, [9500, 500], 0.15000404909246748], [0.99, [9900, 100], 0.1644434771134675]]
# Computing time for metric swd: 2954.1000595891383
#   name object_name          class_name                                kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                    {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                    {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                    {}
# 3   ks      KSTest     GMetrics.KSTest                                    {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 1000, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 1000, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                   {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f821208af20>
# 1          metric_list  <function <lambda> at 0x7f8212089120>
# 2          metric_list  <function <lambda> at 0x7f8212088f40>
# 3      statistic_means  <function <lambda> at 0x7f821208be20>
# 4         metric_means  <function <lambda> at 0x7f8128090040>
# 5         metric_means  <function <lambda> at 0x7f81280900e0>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f8128090180>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...             10
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...             20
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...             20
# 6  {'niter': 10000, 'batch_size_test': 50000, 'ba...             20
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results/100D_unimodal/100D_50K/null_hypothesis...
# 1  results/100D_unimodal/100D_50K/null_hypothesis...
# 2  results/100D_unimodal/100D_50K/null_hypothesis...
# 3  results/100D_unimodal/100D_50K/null_hypothesis...
# 4  results/100D_unimodal/100D_50K/null_hypothesis...
# 5  results/100D_unimodal/100D_50K/null_hypothesis...
# 6  results/100D_unimodal/100D_50K/null_hypothesis...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.9199293485916724], [0....
# 1  [[0.68, [6800, 3199], 0.5093629878783318], [0....
# 2  [[0.68, [6800, 3199], 0.0059429190102378016], ...
# 3  [[0.68, [6800, 3199], 0.8941979620490395], [0....
# 4  [[0.68, [6800, 3199], 0.893739436395866], [0.9...
# 5  [[0.68, [6800, 3199], 0.12934140839484362], [0...
# 6                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    if "FPD" in latex:
        latex = r"$d_{\mathrm{FPD}}\,(\times 10^{3})$"
    elif "KPD" in latex:
        latex = r"$d_{\mathrm{KPD}}\,(\times 10^{4})$"
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.8729950496604691 +/- 0.00011597376592790471
# sigma = 0.1076911165918084 +/- 0.0007815828506675112
# /tmp/ipykernel_341986/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_341986/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_341986/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_341986/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.482120507862419 seconds.
# mu = 0.47321599134018405 +/- 7.307888780801395e-05
# sigma = 0.08548619058538867 +/- 0.0009328375093817993
# /tmp/ipykernel_341986/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_341986/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_341986/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_341986/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9785672980360687 seconds.
# mu = 0.00563803555627663 +/- 5.1790678619776536e-09
# sigma = 0.000719657408909104 +/- 5.417669017220867e-06
# /tmp/ipykernel_341986/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_341986/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_341986/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_341986/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9826652710326016 seconds.
# mu = 0.8662207659542468 +/- 5.408568123340398e-05
# sigma = 0.07354296787144504 +/- 0.0005841311749842091
# /tmp/ipykernel_341986/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_341986/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_341986/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_341986/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2744828930590302 seconds.
# mu = 0.8665557849857086 +/- 4.6802021228962487e-05
# sigma = 0.06841200276922353 +/- 0.0005266576011952655
# /tmp/ipykernel_341986/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_341986/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_341986/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_341986/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2613555879797786 seconds.
# mu = 0.12442867140367542 +/- 1.9100081681254883e-06
# sigma = 0.01382030451229454 +/- 0.00011547166476894302
# /tmp/ipykernel_341986/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_341986/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_341986/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_341986/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9406785219907761 seconds.
#   name object_name          class_name                                kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                    {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                    {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                    {}
# 3   ks      KSTest     GMetrics.KSTest                                    {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 1000, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 1000, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                   {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7fc60e50e840>
# 1          metric_list  <function <lambda> at 0x7fc60e50e980>
# 2          metric_list  <function <lambda> at 0x7fc60e50c720>
# 3      statistic_means  <function <lambda> at 0x7fc60e50cea0>
# 4         metric_means  <function <lambda> at 0x7fc5082fc040>
# 5         metric_means  <function <lambda> at 0x7fc5082fc0e0>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7fc5082fc180>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...             10
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...             20
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...             20
# 6  {'niter': 10000, 'batch_size_test': 50000, 'ba...             20
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results_leonardo/100D_unimodal/100D_50K/null_h...
# 1  results_leonardo/100D_unimodal/100D_50K/null_h...
# 2  results_leonardo/100D_unimodal/100D_50K/null_h...
# 3  results_leonardo/100D_unimodal/100D_50K/null_h...
# 4  results_leonardo/100D_unimodal/100D_50K/null_h...
# 5  results_leonardo/100D_unimodal/100D_50K/null_h...
# 6  results_leonardo/100D_unimodal/100D_50K/null_h...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.9199293485916724], [0....
# 1  [[0.68, [6800, 3199], 0.5093629878783318], [0....
# 2  [[0.68, [6800, 3199], 0.0059429190102378016], ...
# 3  [[0.68, [6800, 3199], 0.8941979620490395], [0....
# 4  [[0.68, [6800, 3199], 0.893739436395866], [0.9...
# 5  [[0.68, [6800, 3199], 0.12934140839484362], [0...
# 6                                                 []
#
#                                          null_figure
# 0  results_leonardo/100D_unimodal/100D_50K/null_h...
# 1  results_leonardo/100D_unimodal/100D_50K/null_h...
# 2  results_leonardo/100D_unimodal/100D_50K/null_h...
# 3  results_leonardo/100D_unimodal/100D_50K/null_h...
# 4  results_leonardo/100D_unimodal/100D_50K/null_h...
# 5  results_leonardo/100D_unimodal/100D_50K/null_h...
# 6                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.01,
                                                 fn_tol = 0.01,
                                                 eps_min = 0.,
                                                 eps_max = 50.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for fn with mean deformation already loaded.
# Exclusion limits for fn with std deformation already loaded.
# Computing exclusion limits for fn with off deformation.
#
# ======================================================
# =============== fn - only off-diag of cov matrix ===============
# ======================================================
# ------------ 1 ------------
# eps = 25.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713877109.047815  292997 service.cc:145] XLA service 0x10e9d3480 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1713877109.047854  292997 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1713877111.841931  292997 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 5 ------------
# eps = 1.5625
# WARNING:tensorflow:5 out of the last 9 calls to <function generate_and_clean_data_simple_1 at 0x7f8211ce0f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f7f81e311c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 6 ------------
# eps = 0.78125
# WARNING:tensorflow:6 out of the last 11 calls to <function generate_and_clean_data_simple_1 at 0x7f8211ce0f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f7f81e300e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 44.2201020070223 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9063299382491656
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 22.119439765117352 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8170206779791886
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 11.021621056688545 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6489462507665853
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 5.534883653305565 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.356896243446024
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 2.8565488919799193 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9171492307184571
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.6085414333374066 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.41079559163725665
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 1.099009908818666 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.03580133564584644
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.9318957818222865 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.12895965373349003
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 1.0044898113703518 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.0541115596933677
#
# ------------ 15 ------------
# eps = 0.01068115234375
# statistic = 1.0493433596010189 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.01043983966986706
#
# ------------ 16 ------------
# eps = 0.011444091796875
# statistic = 1.0736148320632546 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.012426611259943888
#
# ------------ 17 ------------
# eps = 0.0110626220703125
# statistic = 1.0613337919481314 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.03508771929824561
# relative_error_metric = 0.0009218801347311514
#
# ------------ 18 ------------
# eps = 0.01087188720703125
# statistic = 1.0553016314309713 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.017391304347826087
# relative_error_metric = 0.0047778895024092926
#
# ------------ 19 ------------
# eps = 0.010967254638671875
# statistic = 1.0583085534001901 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.008658008658008658
# relative_error_metric = 0.0019326013319576028
# =======> statistic within required accuracy at 0.95 CL in 128.24808376503643 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.011014938354492188
# statistic = 1.0598188927833712 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9991189990150715
# relative_error_metric = 0.08085155039600109
#
# ------------ 2 ------------
# eps = 25.005507469177246
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9982387738511287
# relative_error_metric = 1.919916926414483
#
# ------------ 3 ------------
# eps = 12.50826120376587
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.996480646890619
# relative_error_metric = 1.919916926414483
#
# ------------ 4 ------------
# eps = 6.259638071060181
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9929736578707484
# relative_error_metric = 1.919916926414483
#
# ------------ 5 ------------
# eps = 3.1353265047073364
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9859965123889756
# relative_error_metric = 1.919916926414483
#
# ------------ 6 ------------
# eps = 1.5731707215309143
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9721877589643402
# relative_error_metric = 1.919916926414483
#
# ------------ 7 ------------
# eps = 0.7920928299427032
# statistic = 44.824572790503474 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9451384295393042
# relative_error_metric = 1.9000196119778099
#
# ------------ 8 ------------
# eps = 0.4015538841485977
# statistic = 22.741990070861487 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.8932062942840555
# relative_error_metric = 1.807607602863457
#
# ------------ 9 ------------
# eps = 0.20628441125154495
# statistic = 11.642187663297634 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.7972393681902459
# relative_error_metric = 1.6406568752226984
#
# ------------ 10 ------------
# eps = 0.10864967480301857
# statistic = 6.147576285511156 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.6318063272391623
# relative_error_metric = 1.3700615808635388
#
# ------------ 11 ------------
# eps = 0.05983230657875538
# statistic = 3.4499963886991414 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.3781020919094038
# relative_error_metric = 1.0005753050934179
#
# ------------ 12 ------------
# eps = 0.03542362246662378
# statistic = 2.152942834420748 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.0512248304229437
# relative_error_metric = 0.6079999176714129
#
# ------------ 13 ------------
# eps = 0.023219280410557985
# statistic = 1.552755638505764 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.7129908317653944
# relative_error_metric = 0.29878449936273915
#
# ------------ 14 ------------
# eps = 0.017117109382525086
# statistic = 1.2846205445121393 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.43382345182099336
# relative_error_metric = 0.11135442469477554
#
# ------------ 15 ------------
# eps = 0.014066023868508637
# statistic = 1.1651342356073602 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.2432989202637857
# relative_error_metric = 0.013842408043039947
#
# ------------ 16 ------------
# eps = 0.012540481111500412
# statistic = 1.1104425570130718 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.11467441951917022
# relative_error_metric = 0.0342316957818498
#
# ------------ 17 ------------
# eps = 0.013303252490004525
# statistic = 1.1373152623673517 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.05573924341385473
# relative_error_metric = 0.010323131376097815
#
# ------------ 18 ------------
# eps = 0.01368463817925658
# statistic = 1.1511106667748914 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.02826346778456829
# relative_error_metric = 0.0017335980579227385
#
# ------------ 19 ------------
# eps = 0.013493945334630553
# statistic = 1.144183928862112 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.014032581538224162
# relative_error_metric = 0.004302011349930175
#
# ------------ 20 ------------
# eps = 0.013589291756943567
# statistic = 1.147640103913584 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.006991762649244224
# relative_error_metric = 0.0012859244059924431
# =======> statistic within required accuracy at 0.99 CL in 143.4129601949826 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 271.66107910405844 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Exclusion limits for fn with cov deformation already loaded.
# Exclusion limits for fn with mean_std deformation already loaded.
# Computing exclusion limits for fn with mean_off deformation.
#
# ======================================================
# =============== fn - mean + off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 56.24712336546884 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9259883118041152
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 44.626069503303775 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9071622861550535
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 22.712223804810325 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8215833810345057
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 11.419360555981815 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.660134641450821
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 5.758467248924223 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3779830862616669
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 2.9718955231744726 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9481252730548139
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.6621640822227253 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4420965014748476
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 1.1196478037283482 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.05439622474227728
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.9384195464926041 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.12201098305992047
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 1.017519675673034 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.04123071339694911
#
# ------------ 15 ------------
# eps = 0.01068115234375
# statistic = 1.0660817592430596 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.0053854757864001054
#
# ------------ 16 ------------
# eps = 0.009918212890625
# statistic = 1.0411299966412373 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.01829736218071135
#
# ------------ 17 ------------
# eps = 0.0102996826171875
# statistic = 1.0534440033097332 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.0065397080733848225
#
# ------------ 18 ------------
# eps = 0.01049041748046875
# statistic = 1.0597231259484414 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.018018018018018018
# relative_error_metric = 0.0005968591387509202
#
# ------------ 19 ------------
# eps = 0.010585784912109375
# statistic = 1.0628925921003176 - next threshold = 1.060355820195381 at 0.95 CL
# relative_error_eps = 0.00904977375565611
# relative_error_metric = 0.0023895196532314365
# =======> statistic within required accuracy at 0.95 CL in 126.49595973896794 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.010538101196289062
# statistic = 1.0613053853964673 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9991571295493789
# relative_error_metric = 0.0794521930992224
#
# ------------ 2 ------------
# eps = 25.005269050598145
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9983149692300801
# relative_error_metric = 1.919916926414483
#
# ------------ 3 ------------
# eps = 12.507903575897217
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9966327753986914
# relative_error_metric = 1.919916926414483
#
# ------------ 4 ------------
# eps = 6.259220838546753
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9932768699418475
# relative_error_metric = 1.919916926414483
#
# ------------ 5 ------------
# eps = 3.134879469871521
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9865987889261882
# relative_error_metric = 1.919916926414483
#
# ------------ 6 ------------
# eps = 1.572708785533905
# statistic = 56.24712336546884 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.973375974942094
# relative_error_metric = 1.919916926414483
#
# ------------ 7 ------------
# eps = 0.791623443365097
# statistic = 45.1896599758032 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.9474514764875637
# relative_error_metric = 1.9008073228532985
#
# ------------ 8 ------------
# eps = 0.40108077228069305
# statistic = 23.312650504953627 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.897593605392554
# relative_error_metric = 1.8120958611055729
#
# ------------ 9 ------------
# eps = 0.20580943673849106
# statistic = 12.028668179885877 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.8051634643613856
# relative_error_metric = 1.6511957568612345
#
# ------------ 10 ------------
# eps = 0.10817376896739006
# statistic = 6.365924342456862 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.6449183664023084
# relative_error_metric = 1.388364318882438
#
# ------------ 11 ------------
# eps = 0.05935593508183956
# statistic = 3.5642296373836504 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.3969098505426183
# relative_error_metric = 1.0247974857586488
#
# ------------ 12 ------------
# eps = 0.03494701813906431
# statistic = 2.2096611546331753 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 1.0732704365492731
# relative_error_metric = 0.6315060579176104
#
# ------------ 13 ------------
# eps = 0.022742559667676687
# statistic = 1.5798750270029176 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.7334264497494917
# relative_error_metric = 0.3156903482864454
#
# ------------ 14 ------------
# eps = 0.016640330431982875
# statistic = 1.2976934747557105 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.4490494020520348
# relative_error_metric = 0.12144516683139084
#
# ------------ 15 ------------
# eps = 0.013589215814135969
# statistic = 1.1719184982688533 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.25291785377782106
# relative_error_metric = 0.019647840910139432
#
# ------------ 16 ------------
# eps = 0.012063658505212516
# statistic = 1.1144206358838267 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.11893850879492386
# relative_error_metric = 0.030656612867298084
#
# ------------ 17 ------------
# eps = 0.012826437159674242
# statistic = 1.1426617986894343 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.057752019623969406
# relative_error_metric = 0.00563320823170143
#
# ------------ 18 ------------
# eps = 0.013207826486905105
# statistic = 1.1571679484121797 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.029299029341356014
# relative_error_metric = 0.006981892842105313
#
# ------------ 19 ------------
# eps = 0.013017131823289674
# statistic = 1.1498837428160356 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.014757610587077781
# relative_error_metric = 0.0006671690401243212
#
# ------------ 20 ------------
# eps = 0.012921784491481958
# statistic = 1.146264914423683 - next threshold = 1.1491168318127254 at 0.99 CL
# relative_error_eps = 0.007351681978588878
# relative_error_metric = 0.002484917721175185
# =======> statistic within required accuracy at 0.99 CL in 136.96805832895916 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 263.464052416035 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Exclusion limits for fn with mean_cov deformation already loaded.
# Exclusion limits for fpd with mean deformation already loaded.
# Exclusion limits for fpd with std deformation already loaded.
# Computing exclusion limits for fpd with off deformation.
#
# ======================================================
# =============== fpd - only off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 36965.853099534805 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999366775210454
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 17421.41016892551 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998656407339357
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 8221.561240497596 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997153046922929
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 4026.4003230892245 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9994187199092257
#
# ------------ 5 ------------
# eps = 1.5625
# WARNING:tensorflow:5 out of the last 5 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f7e9abce020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 2215.0099457995684 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9989434863521558
#
# ------------ 6 ------------
# eps = 0.78125
# WARNING:tensorflow:6 out of the last 6 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f7e9a2beac0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1037.2302221025716 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.99774448668055
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 352.031002999296 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9933616025564398
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 125.35175082637295 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9814128699659803
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 43.18596457516901 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9465217239015726
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 14.179979831039395 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8414644264363504
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 4.609984221797283 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5494277627202442
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 1.66215214926267 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9584165451806127
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.8048840516787064 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.31607033591819184
#
# ------------ 14 ------------
# eps = 0.0030517578125
# statistic = 0.569307243582968 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.02753445148690395
#
# ------------ 15 ------------
# eps = 0.00457763671875
# statistic = 0.6696132375954379 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.13454034070211549
#
# ------------ 16 ------------
# eps = 0.003814697265625
# statistic = 0.6149670001177532 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.04960198356424147
#
# ------------ 17 ------------
# eps = 0.0034332275390625
# statistic = 0.5909978070942837 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.009855776296928532
#
# ------------ 18 ------------
# eps = 0.00324249267578125
# statistic = 0.5798656502641564 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.05714285714285714
# relative_error_metric = 0.009159947540849506
#
# ------------ 19 ------------
# eps = 0.003337860107421875
# statistic = 0.5853602668471002 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.028985507246376812
# relative_error_metric = 0.00027104762110063166
#
# ------------ 20 ------------
# eps = 0.0032901763916015625
# statistic = 0.5825950631708353 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.014388489208633094
# relative_error_metric = 0.004464072706968984
#
# ------------ 21 ------------
# eps = 0.0033140182495117188
# statistic = 0.583973191887352 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.007168458781362007
# relative_error_metric = 0.002101372575887825
# =======> statistic within required accuracy at 0.95 CL in 200.61199168197345 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.003325939178466797
# statistic = 0.584665616290027 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9997339425635396
# relative_error_metric = 0.08262201831482902
#
# ------------ 2 ------------
# eps = 25.001662969589233
# statistic = 36968.50705535448 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9994679559042234
# relative_error_metric = 1.999931288268515
#
# ------------ 3 ------------
# eps = 12.50249445438385
# statistic = 17425.19622824307 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9989361948040838
# relative_error_metric = 1.999854227111192
#
# ------------ 4 ------------
# eps = 6.2529101967811584
# statistic = 8225.656642500226 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.997873520688038
# relative_error_metric = 1.999691207914853
#
# ------------ 5 ------------
# eps = 3.1281180679798126
# statistic = 4030.3009727324657 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9957515584875682
# relative_error_metric = 1.999369820371913
#
# ------------ 6 ------------
# eps = 1.5657220035791397
# statistic = 2218.329398554745 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9915211279710894
# relative_error_metric = 1.9988552255699583
#
# ------------ 7 ------------
# eps = 0.7845239713788033
# statistic = 1044.7144474800814 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9831138437212525
# relative_error_metric = 1.9975699861495353
#
# ------------ 8 ------------
# eps = 0.393924955278635
# statistic = 356.4706407009458 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.966510442394224
# relative_error_metric = 1.9928866612672858
#
# ------------ 9 ------------
# eps = 0.1986254472285509
# statistic = 128.5647739914525 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.934123964432438
# relative_error_metric = 1.9803388764808145
#
# ------------ 10 ------------
# eps = 0.10097569320350885
# statistic = 45.516185721624154 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.8724491994032664
# relative_error_metric = 1.9449589260899398
#
# ------------ 11 ------------
# eps = 0.052150816190987825
# statistic = 15.793127428594842 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.7601922350132213
# relative_error_metric = 1.845374616586608
#
# ------------ 12 ------------
# eps = 0.02773837768472731
# statistic = 5.637768019838752 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.571735094885352
# relative_error_metric = 1.5950444657973164
#
# ------------ 13 ------------
# eps = 0.015532158431597054
# statistic = 2.2945364156918626 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.294533468382968
# relative_error_metric = 1.1329114689485338
#
# ------------ 14 ------------
# eps = 0.009429048805031925
# statistic = 1.1902223084686026 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.9569761468157858
# relative_error_metric = 0.6083123243577778
#
# ------------ 15 ------------
# eps = 0.006377493991749361
# statistic = 0.8327296727308365 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.628963947038672
# relative_error_metric = 0.2693534615114622
#
# ------------ 16 ------------
# eps = 0.004851716585108079
# statistic = 0.6913904873696939 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.3731576507383544
# relative_error_metric = 0.08494448154426541
#
# ------------ 17 ------------
# eps = 0.004088827881787438
# statistic = 0.6335806941851366 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.17065822023377147
# relative_error_metric = 0.002321784078564727
#
# ------------ 18 ------------
# eps = 0.0044702722334477585
# statistic = 0.6613892604075778 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.08913188221302604
# relative_error_metric = 0.04062781782149071
#
# ------------ 19 ------------
# eps = 0.004279550057617598
# statistic = 0.6472089817269178 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.04558163534466752
# relative_error_metric = 0.018959520380862238
#
# ------------ 20 ------------
# eps = 0.004184188969702518
# statistic = 0.6403255987047968 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.02305352198041414
# relative_error_metric = 0.008267592746668594
#
# ------------ 21 ------------
# eps = 0.004136508425744978
# statistic = 0.6369358055917888 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.011593579198427725
# relative_error_metric = 0.0029597170608143143
#
# ------------ 22 ------------
# eps = 0.004112668153766208
# statistic = 0.6352539100308985 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.005813639822642598
# relative_error_metric = 0.00031562216293912784
# =======> statistic within required accuracy at 0.99 CL in 214.31258103298023 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 414.9246072219685 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Exclusion limits for fpd with cov deformation already loaded.
# Exclusion limits for fpd with mean_std deformation already loaded.
# Computing exclusion limits for fpd with mean_off deformation.
#
# ======================================================
# =============== fpd - mean + off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 394770.8681292784 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999940704767487
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 106872.19958111427 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999978097262871
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 30583.528658777403 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999234633207932
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 9616.412978080487 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997565969684497
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 3612.286752924349 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9993520925898287
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 1399.843167443415 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9983285067890286
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 446.1984519806219 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9947607606221733
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 149.29981518046213 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9843826517072858
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 49.223135892154204 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9530037213063975
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 15.740080830165544 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8566146394479741
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 4.994317105277405 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5804644408735062
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 1.735070788335253 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9911501360626656
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.8309454563321997 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.34705975281859247
#
# ------------ 14 ------------
# eps = 0.0030517578125
# statistic = 0.5764021457566764 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.015150574200934974
#
# ------------ 15 ------------
# eps = 0.00457763671875
# statistic = 0.6847109197081258 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.15671833790714368
#
# ------------ 16 ------------
# eps = 0.003814697265625
# statistic = 0.6256925386562288 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.0668777039942123
#
# ------------ 17 ------------
# eps = 0.0034332275390625
# statistic = 0.5998152857994836 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.024664049588913838
#
# ------------ 18 ------------
# eps = 0.00324249267578125
# statistic = 0.5877986449689957 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.00442799066726935
#
# ------------ 19 ------------
# eps = 0.003147125244140625
# statistic = 0.5820226205979652 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.029850746268656716
# relative_error_metric = 0.005447123369721267
#
# ------------ 20 ------------
# eps = 0.0031948089599609375
# statistic = 0.5848912247753237 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.014814814814814815
# relative_error_metric = 0.000530561421053385
#
# ------------ 21 ------------
# eps = 0.0032186508178710938
# statistic = 0.5863400892545926 - next threshold = 0.5852016278386474 at 0.95 CL
# relative_error_eps = 0.007434944237918215
# relative_error_metric = 0.0019435268916755018
# =======> statistic within required accuracy at 0.95 CL in 207.54658112407196 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0032067298889160156
# statistic = 0.585614445078482 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.999743478060818
# relative_error_metric = 0.08100319000923573
#
# ------------ 2 ------------
# eps = 25.001603364944458
# statistic = 394819.32274552365 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9994870219167025
# relative_error_metric = 1.9999935661465038
#
# ------------ 3 ------------
# eps = 12.502405047416687
# statistic = 106910.27311941226 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9989743069124422
# relative_error_metric = 1.9999762399009677
#
# ------------ 4 ------------
# eps = 6.2528058886528015
# statistic = 30607.56106748935 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9979496653319324
# relative_error_metric = 1.9999170087072178
#
# ------------ 5 ------------
# eps = 3.1280063092708588
# statistic = 9630.935375601704 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9959035302308572
# relative_error_metric = 1.999736261725486
#
# ------------ 6 ------------
# eps = 1.5656065195798874
# statistic = 3621.049297498356 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.991823807224979
# relative_error_metric = 1.9992986098401542
#
# ------------ 7 ------------
# eps = 0.7844066247344017
# statistic = 1409.8975483706702 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9837141924011705
# relative_error_metric = 1.9981991102066323
#
# ------------ 8 ------------
# eps = 0.39380667731165886
# statistic = 451.9950404921242 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.967691470053595
# relative_error_metric = 1.9943878814072211
#
# ------------ 9 ------------
# eps = 0.19850670360028744
# statistic = 153.18024018936796 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.9364101867992316
# relative_error_metric = 1.983485297814971
#
# ------------ 10 ------------
# eps = 0.10085671674460173
# statistic = 51.864822235490784 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.8767394318502935
# relative_error_metric = 1.9516148613103976
#
# ------------ 11 ------------
# eps = 0.05203172331675887
# statistic = 17.500964077864285 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.7677900301099254
# relative_error_metric = 1.85993541508713
#
# ------------ 12 ------------
# eps = 0.027619226602837443
# statistic = 6.091511916448139 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.5838922448652806
# relative_error_metric = 1.6223609478748753
#
# ------------ 13 ------------
# eps = 0.01541297824587673
# statistic = 2.423166342130533 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 1.3111106005095907
# relative_error_metric = 1.169381553460981
#
# ------------ 14 ------------
# eps = 0.009309854067396373
# statistic = 1.228289795946204 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.9752060465990671
# relative_error_metric = 0.6367440443446765
#
# ------------ 15 ------------
# eps = 0.006258291978156194
# statistic = 0.847822458814218 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.6448082491718765
# relative_error_metric = 0.28696806971072436
#
# ------------ 16 ------------
# eps = 0.004732510933536105
# statistic = 0.6978567056540017 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.3843644697878897
# relative_error_metric = 0.09423480545377351
#
# ------------ 17 ------------
# eps = 0.00396962041122606
# statistic = 0.636898000419274 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.2126123977796739
# relative_error_metric = 0.002900360665648642
#
# ------------ 18 ------------
# eps = 0.003588175150071038
# statistic = 0.6100309372702774 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.1009408783451023
# relative_error_metric = 0.040194069753446866
#
# ------------ 19 ------------
# eps = 0.003778897780648549
# statistic = 0.6231601641941544 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.049228155849852726
# relative_error_metric = 0.018905020906495703
#
# ------------ 20 ------------
# eps = 0.0038742590959373047
# statistic = 0.6299532539477856 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.0243148343116866
# relative_error_metric = 0.008063494880644268
#
# ------------ 21 ------------
# eps = 0.0039219397535816825
# statistic = 0.6334067022781635 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.012083962270732914
# relative_error_metric = 0.002596438183628328
#
# ------------ 22 ------------
# eps = 0.003945780082403871
# statistic = 0.6351476238466051 - next threshold = 0.6350534414539619 at 0.99 CL
# relative_error_eps = 0.006060289211913079
# relative_error_metric = 0.00014829525059617568
# =======> statistic within required accuracy at 0.99 CL in 218.50801619596314 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 426.05463054799475 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Exclusion limits for fpd with mean_cov deformation already loaded.
# Exclusion limits for kpd with mean deformation already loaded.
# Exclusion limits for kpd with std deformation already loaded.
# Computing exclusion limits for kpd with off deformation.
#
# ======================================================
# =============== kpd - only off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f7e9abe28e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f7df0980ae0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.012158621727653696 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5533815424303031
#
# ------------ 2 ------------
# eps = 12.5
# statistic = -0.00985712775403158 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = -11.281585634577263
#
# ------------ 3 ------------
# eps = 18.75
# statistic = -0.0007390394518580479 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 2.480720747718379
#
# ------------ 4 ------------
# eps = 21.875
# statistic = 0.005235752350785106 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.27263039660862143
#
# ------------ 5 ------------
# eps = 23.4375
# statistic = 0.008578500457101512 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.21853444023381316
#
# ------------ 6 ------------
# eps = 22.65625
# statistic = 0.0068774763382073445 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.0015969105377134243
#
# ------------ 7 ------------
# eps = 23.046875
# statistic = 0.007720573159009092 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.017094017094017096
# relative_error_metric = 0.1139164892263383
#
# ------------ 8 ------------
# eps = 22.8515625
# statistic = 0.007297171278342063 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.008583690987124463
# relative_error_metric = 0.057622141152073515
#
# ------------ 9 ------------
# eps = 22.75390625
# statistic = 0.007086860483784818 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.004301075268817204
# relative_error_metric = 0.028391841749722858
#
# ------------ 10 ------------
# eps = 22.705078125
# statistic = 0.0069820525840924574 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.002152852529601722
# relative_error_metric = 0.013494051044653347
#
# ------------ 11 ------------
# eps = 22.6806640625
# statistic = 0.006929735504090928 - next threshold = 0.006888467828858325 at 0.95 CL
# relative_error_eps = 0.0010770059235325794
# relative_error_metric = 0.005972943694380393
# =======> statistic within required accuracy at 0.95 CL in 286.46356508205645 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 22.66845703125
# statistic = 0.006903598684715462 - next threshold = 0.007504011971803948 at 0.99 CL
# relative_error_eps = 0.752225768520074
# relative_error_metric = 0.08334668411056768
#
# ------------ 2 ------------
# eps = 36.334228515625
# statistic = 0.04526561556161823 - next threshold = 0.007504011971803948 at 0.99 CL
# relative_error_eps = 0.46322540602048207
# relative_error_metric = 1.4311870428078193
#
# ------------ 3 ------------
# eps = 29.5013427734375
# statistic = 0.023802459584221225 - next threshold = 0.007504011971803948 at 0.99 CL
# relative_error_eps = 0.26194793799356536
# relative_error_metric = 1.0412190708397169
#
# ------------ 4 ------------
# eps = 26.08489990234375
# statistic = 0.014784235934151013 - next threshold = 0.007504011971803948 at 0.99 CL
# relative_error_eps = 0.1401521079152452
# relative_error_metric = 0.6532791624595974
#
# ------------ 5 ------------
# eps = 24.376678466796875
# ...
#
# ------------ 15 ------------
# eps = 0.02593994140625
# statistic = 0.1510427493693006 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.006900590088587353
#
# ------------ 16 ------------
# eps = 0.025177001953125
# statistic = 0.14993296474555148 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.029850746268656716
# relative_error_metric = 0.0004739951632270639
#
# ------------ 17 ------------
# eps = 0.0255584716796875
# statistic = 0.15048577507211888 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.015037593984962405
# relative_error_metric = 0.0032062715001460393
#
# ------------ 18 ------------
# eps = 0.02536773681640625
# statistic = 0.1502088348625526 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.007547169811320755
# relative_error_metric = 0.0013642703629988247
# =======> statistic within required accuracy at 0.95 CL in 208.38556377706118 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.025272369384765625
# statistic = 0.15007075787884397 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9979792318412057
# relative_error_metric = 0.09139630347716932
#
# ------------ 2 ------------
# eps = 25.012636184692383
# statistic = 50.89305717652157 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9959625430646202
# relative_error_metric = 1.9871169975021676
#
# ------------ 3 ------------
# eps = 12.518954277038574
# statistic = 32.43392962670285 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.991941354346632
# relative_error_metric = 1.97982187925885
#
# ------------ 4 ------------
# eps = 6.27211332321167
# statistic = 19.390748135844817 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9839473898418023
# relative_error_metric = 1.9663632082225162
#
# ------------ 5 ------------
# eps = 3.1486928462982178
# statistic = 10.185998376405525 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9681504141760704
# relative_error_metric = 1.936449678403803
#
# ------------ 6 ------------
# eps = 1.5869826078414917
# statistic = 4.124896275435556 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9372993236386356
# relative_error_metric = 1.8466491473278668
#
# ------------ 7 ------------
# eps = 0.8061274886131287
# statistic = 1.990550561855949 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.8784105186372084
# relative_error_metric = 1.6947676436411687
#
# ------------ 8 ------------
# eps = 0.41569992899894714
# statistic = 1.0624441928051886 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.7707577598194177
# relative_error_metric = 1.4638678629010258
#
# ------------ 9 ------------
# eps = 0.22048614919185638
# statistic = 0.5881958587406318 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.5886633833710018
# relative_error_metric = 1.126043674414885
#
# ------------ 10 ------------
# eps = 0.122879259288311
# statistic = 0.3535419273556395 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.3176620571473114
# relative_error_metric = 0.7301304191610671
#
# ------------ 11 ------------
# eps = 0.07407581433653831
# statistic = 0.2424219246342102 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.9824728167890485
# relative_error_metric = 0.3833132391488129
#
# ------------ 12 ------------
# eps = 0.04967409186065197
# statistic = 0.19208684602990395 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.6511774424140225
# relative_error_metric = 0.1550688237270648
#
# ------------ 13 ------------
# eps = 0.0374732306227088
# statistic = 0.16961669242719776 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.3888993407183858
# relative_error_metric = 0.030971757697683476
#
# ------------ 14 ------------
# eps = 0.03137280000373721
# statistic = 0.15940238724220882 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.1772195306966096
# relative_error_metric = 0.03113264936261222
#
# ------------ 15 ------------
# eps = 0.034423015313223004
# statistic = 0.16441033115573017 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.08485047500821953
# relative_error_metric = 0.00020158475835673005
#
# ------------ 16 ------------
# eps = 0.0359481229679659
# statistic = 0.1669901058063119 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.04334469192892328
# relative_error_metric = 0.015367354571674803
#
# ------------ 17 ------------
# eps = 0.03518556914059445
# statistic = 0.1656939676814957 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.02190976395669625
# relative_error_metric = 0.007575575492836547
#
# ------------ 18 ------------
# eps = 0.03480429222690873
# statistic = 0.16505061916314068 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.011015217180436904
# relative_error_metric = 0.0036852985017582548
#
# ------------ 19 ------------
# eps = 0.034613653770065866
# statistic = 0.16473006656030786 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.005522817348353451
# relative_error_metric = 0.0017412665893003602
# =======> statistic within required accuracy at 0.99 CL in 212.2587207290344 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 420.6443166350946 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Exclusion limits for swd with cov deformation already loaded.
# Exclusion limits for swd with mean_std deformation already loaded.
# Computing exclusion limits for swd with mean_off deformation.
#
# ======================================================
# =============== swd - mean + off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 183.10598443146773 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.996725803061909
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 93.9004696677513 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9936202745966347
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 48.32437779535846 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9876219938545012
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 24.575874038935773 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9757332704531783
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 12.072228828360272 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9509078085497156
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 6.006537720496403 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9025400592043835
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 3.038080942531654 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8117941654798229
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 1.5339873973636278 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6436940356006058
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 0.7789572617355669 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3540999077399227
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 0.4069930756522918 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9227660795469568
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 0.23297895138260516 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4333085394767453
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.16150241402917923 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.07382424635100755
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.13757652332799616 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.08642813149631938
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 0.14808317930971254 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.012887971034862946
#
# ------------ 15 ------------
# eps = 0.01068115234375
# statistic = 0.15446963238942973 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.029333131686311357
#
# ------------ 16 ------------
# eps = 0.009918212890625
# statistic = 0.1511912278578444 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.00788311674337948
#
# ------------ 17 ------------
# eps = 0.0095367431640625
# statistic = 0.1496151004564578 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.0392156862745098
# relative_error_metric = 0.002596286896850546
#
# ------------ 18 ------------
# eps = 0.00972747802734375
# statistic = 0.15039786110380146 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.019801980198019802
# relative_error_metric = 0.002621900846613684
#
# ------------ 19 ------------
# eps = 0.009632110595703125
# statistic = 0.15000512912817948 - next threshold = 0.15000404909246748 at 0.95 CL
# relative_error_eps = 0.009950248756218905
# relative_error_metric = 7.200017802181994e-06
# =======> statistic within required accuracy at 0.95 CL in 215.160683745984 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.009584426879882812
# statistic = 0.1498097720587316 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9992333927994226
# relative_error_metric = 0.09313319810238241
#
# ------------ 2 ------------
# eps = 25.00479221343994
# statistic = 183.13999446497172 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9984673730602691
# relative_error_metric = 1.9964115767417385
#
# ------------ 3 ------------
# eps = 12.507188320159912
# statistic = 93.95224650148785 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9969370932672244
# relative_error_metric = 1.9930110811525201
#
# ------------ 4 ------------
# eps = 6.2583863735198975
# statistic = 48.38672245527163 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9938835535868984
# relative_error_metric = 1.9864519441331252
#
# ------------ 5 ------------
# eps = 3.13398540019989
# statistic = 24.64625967751188 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9878044040284146
# relative_error_metric = 1.973488300417989
#
# ------------ 6 ------------
# eps = 1.5717849135398865
# statistic = 12.147499849599129 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9757566391736452
# relative_error_metric = 1.9465743229156416
#
# ------------ 7 ------------
# eps = 0.7906846702098846
# statistic = 6.0776597587982595 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.952093979813854
# relative_error_metric = 1.8946230327192284
#
# ------------ 8 ------------
# eps = 0.40013454854488373
# statistic = 3.1109602067155833 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.9064292604954762
# relative_error_metric = 1.7991777588511133
#
# ------------ 9 ------------
# eps = 0.20485948771238327
# statistic = 1.6078055110979592 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.8212226838312253
# relative_error_metric = 1.6288479142438654
#
# ------------ 10 ------------
# eps = 0.10722195729613304
# statistic = 0.8527129557389609 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.671784142707816
# relative_error_metric = 1.3533207998210621
#
# ------------ 11 ------------
# eps = 0.05840319208800793
# statistic = 0.47880183206739957 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.4361075133747894
# relative_error_metric = 0.977413594680536
#
# ------------ 12 ------------
# eps = 0.03399380948394537
# statistic = 0.2987723455633468 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 1.1202556432193478
# relative_error_metric = 0.5799839378267551
#
# ------------ 13 ------------
# eps = 0.02178911818191409
# statistic = 0.21601362838388044 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.7780243691295663
# relative_error_metric = 0.2710957452246739
#
# ------------ 14 ------------
# eps = 0.015686772530898452
# statistic = 0.17955130928641633 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.4829486366533312
# relative_error_metric = 0.08783756481347614
#
# ------------ 15 ------------
# eps = 0.012635599705390632
# statistic = 0.16358329476079475 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.21546025877015992
# relative_error_metric = 0.0052445862742109385
#
# ------------ 16 ------------
# eps = 0.014161186118144542
# statistic = 0.17132968415912786 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.11386338815411305
# relative_error_metric = 0.04101701886810331
#
# ------------ 17 ------------
# eps = 0.013398392911767587
# statistic = 0.16739240359559251 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.05859978664004237
# relative_error_metric = 0.017773403381357196
#
# ------------ 18 ------------
# eps = 0.01301699630857911
# statistic = 0.16547129735913577 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.02973551705884104
# relative_error_metric = 0.006230822777254119
#
# ------------ 19 ------------
# eps = 0.012826298006984871
# statistic = 0.1645231192278824 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.014979111435323355
# relative_error_metric = 0.00048419575300753505
#
# ------------ 20 ------------
# eps = 0.012730948856187752
# statistic = 0.16405215386221744 - next threshold = 0.1644434771134675 at 0.99 CL
# relative_error_eps = 0.007461613632140885
# relative_error_metric = 0.0023825172352384383
# =======> statistic within required accuracy at 0.99 CL in 218.19203920802101 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 433.3527564870892 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Exclusion limits for swd with mean_cov deformation already loaded.
# dict_keys(['2024-04-16T21:36:16.879651', '2024-04-16T21:40:40.097447', '2024-04-23T14:58:19.831660', '2024-04-16T21:50:13.213619', '2024-04-16T21:53:41.276948', '2024-04-23T15:02:51.516138', '2024-04-16T22:03:09.168811', '2024-04-16T22:07:21.529808', '2024-04-16T22:13:17.802259', '2024-04-23T15:07:15.003304', '2024-04-16T22:26:46.803896', '2024-04-16T22:32:34.319867', '2024-04-23T15:14:09.955315', '2024-04-16T22:46:03.854989', '2024-04-16T22:52:08.095597', '2024-04-16T23:05:29.000910', '2024-04-23T15:21:16.034468', '2024-04-16T23:20:58.173784', '2024-04-16T23:28:56.002395', '2024-04-23T15:30:21.444026', '2024-04-16T23:55:20.766686', '2024-04-17T00:07:42.802121', '2024-04-17T00:12:45.450372', '2024-04-23T15:43:19.924074', '2024-04-17T00:22:35.355951', '2024-04-17T00:27:35.814251', '2024-04-23T15:47:27.617034', '2024-04-17T00:38:06.835167', '2024-04-17T00:43:21.618305', '2024-04-17T00:52:22.225988', '2024-04-23T15:52:54.696489', '2024-04-17T01:10:56.319928', '2024-04-17T01:19:47.624705', '2024-04-23T16:01:45.310250', '2024-04-17T01:38:49.630112', '2024-04-17T01:48:10.467436', '2024-04-17T01:55:10.180350', '2024-04-23T16:11:19.356839', '2024-04-17T02:09:21.500802', '2024-04-17T02:16:22.766793', '2024-04-23T16:18:20.027694', '2024-04-17T02:30:51.679584'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.05,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for LR with mean deformation already loaded.
# Exclusion limits for LR with std deformation already loaded.
# Computing exclusion limits for lr with off deformation.
#
# ======================================================
# =============== lr - only off-diag of cov matrix ===============
# ======================================================
# ------------ 1 ------------
# eps = 0.025
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 500
# Iterating from 0 to 20 out of 10000 .
# Iterating from 20 to 40 out of 10000 .
# Iterating from 40 to 60 out of 10000 .
# Iterating from 60 to 80 out of 10000 .
# Iterating from 80 to 100 out of 10000 .
# Iterating from 100 to 120 out of 10000 .
# Iterating from 120 to 140 out of 10000 .
# Iterating from 140 to 160 out of 10000 .
# Iterating from 160 to 180 out of 10000 .
# Iterating from 180 to 200 out of 10000 .
# Iterating from 200 to 220 out of 10000 .
# Iterating from 220 to 240 out of 10000 .
# Iterating from 240 to 260 out of 10000 .
# Iterating from 260 to 280 out of 10000 .
# Iterating from 280 to 300 out of 10000 .
# Iterating from 300 to 320 out of 10000 .
# Iterating from 320 to 340 out of 10000 .
# Iterating from 340 to 360 out of 10000 .
# Iterating from 360 to 380 out of 10000 .
# Iterating from 380 to 400 out of 10000 .
# Iterating from 400 to 420 out of 10000 .
# Iterating from 420 to 440 out of 10000 .
# Iterating from 440 to 460 out of 10000 .
# Iterating from 460 to 480 out of 10000 .
# Iterating from 480 to 500 out of 10000 .
# Iterating from 500 to 520 out of 10000 .
# Iterating from 520 to 540 out of 10000 .
# Iterating from 540 to 560 out of 10000 .
# Iterating from 560 to 580 out of 10000 .
# Iterating from 580 to 600 out of 10000 .
# Iterating from 600 to 620 out of 10000 .
# Iterating from 620 to 640 out of 10000 .
# Iterating from 640 to 660 out of 10000 .
# Iterating from 660 to 680 out of 10000 .
# Iterating from 680 to 700 out of 10000 .
# Iterating from 700 to 720 out of 10000 .
# Iterating from 720 to 740 out of 10000 .
# Iterating from 740 to 760 out of 10000 .
# Iterating from 760 to 780 out of 10000 .
# Iterating from 780 to 800 out of 10000 .
# Iterating from 800 to 820 out of 10000 .
# Iterating from 820 to 840 out of 10000 .
# Iterating from 840 to 860 out of 10000 .
# Iterating from 860 to 880 out of 10000 .
# Iterating from 880 to 900 out of 10000 .
# Iterating from 900 to 920 out of 10000 .
# Iterating from 920 to 940 out of 10000 .
# Iterating from 940 to 960 out of 10000 .
# Iterating from 960 to 980 out of 10000 .
# Iterating from 980 to 1000 out of 10000 .
# Iterating from 1000 to 1020 out of 10000 .
# Iterating from 1020 to 1040 out of 10000 .
# Iterating from 1040 to 1060 out of 10000 .
# Iterating from 1060 to 1080 out of 10000 .
# Iterating from 1080 to 1100 out of 10000 .
# Iterating from 1100 to 1120 out of 10000 .
# Iterating from 1120 to 1140 out of 10000 .
# Iterating from 1140 to 1160 out of 10000 .
# Iterating from 1160 to 1180 out of 10000 .
# Iterating from 1180 to 1200 out of 10000 .
# Iterating from 1200 to 1220 out of 10000 .
# Iterating from 1220 to 1240 out of 10000 .
# Iterating from 1240 to 1260 out of 10000 .
# Iterating from 1260 to 1280 out of 10000 .
# Iterating from 1280 to 1300 out of 10000 .
# Iterating from 1300 to 1320 out of 10000 .
# Iterating from 1320 to 1340 out of 10000 .
# Iterating from 1340 to 1360 out of 10000 .
# Iterating from 1360 to 1380 out of 10000 .
# Iterating from 1380 to 1400 out of 10000 .
# Iterating from 1400 to 1420 out of 10000 .
# Iterating from 1420 to 1440 out of 10000 .
# Iterating from 1440 to 1460 out of 10000 .
# Iterating from 1460 to 1480 out of 10000 .
# Iterating from 1480 to 1500 out of 10000 .
# Iterating from 1500 to 1520 out of 10000 .
# Iterating from 1520 to 1540 out of 10000 .
# Iterating from 1540 to 1560 out of 10000 .
# Iterating from 1560 to 1580 out of 10000 .
# Iterating from 1580 to 1600 out of 10000 .
# Iterating from 1600 to 1620 out of 10000 .
# Iterating from 1620 to 1640 out of 10000 .
# Iterating from 1640 to 1660 out of 10000 .
# Iterating from 1660 to 1680 out of 10000 .
# Iterating from 1680 to 1700 out of 10000 .
# Iterating from 1700 to 1720 out of 10000 .
# Iterating from 1720 to 1740 out of 10000 .
# Iterating from 1740 to 1760 out of 10000 .
# Iterating from 1760 to 1780 out of 10000 .
# Iterating from 1780 to 1800 out of 10000 .
# Iterating from 1800 to 1820 out of 10000 .
# Iterating from 1820 to 1840 out of 10000 .
# Iterating from 1840 to 1860 out of 10000 .
# Iterating from 1860 to 1880 out of 10000 .
# Iterating from 1880 to 1900 out of 10000 .
# Iterating from 1900 to 1920 out of 10000 .
# Iterating from 1920 to 1940 out of 10000 .
# Iterating from 1940 to 1960 out of 10000 .
# Iterating from 1960 to 1980 out of 10000 .
# Iterating from 1980 to 2000 out of 10000 .
# Iterating from 2000 to 2020 out of 10000 .
# Iterating from 2020 to 2040 out of 10000 .
# Iterating from 2040 to 2060 out of 10000 .
# Iterating from 2060 to 2080 out of 10000 .
# Iterating from 2080 to 2100 out of 10000 .
# Iterating from 2100 to 2120 out of 10000 .
# Iterating from 2120 to 2140 out of 10000 .
# Iterating from 2140 to 2160 out of 10000 .
# Iterating from 2160 to 2180 out of 10000 .
# Iterating from 2180 to 2200 out of 10000 .
# Iterating from 2200 to 2220 out of 10000 .
# Iterating from 2220 to 2240 out of 10000 .
# Iterating from 2240 to 2260 out of 10000 .
# Iterating from 2260 to 2280 out of 10000 .
# Iterating from 2280 to 2300 out of 10000 .
# Iterating from 2300 to 2320 out of 10000 .
# Iterating from 2320 to 2340 out of 10000 .
# Iterating from 2340 to 2360 out of 10000 .
# Iterating from 2360 to 2380 out of 10000 .
# Iterating from 2380 to 2400 out of 10000 .
# Iterating from 2400 to 2420 out of 10000 .
# Iterating from 2420 to 2440 out of 10000 .
# Iterating from 2440 to 2460 out of 10000 .
# Iterating from 2460 to 2480 out of 10000 .
# Iterating from 2480 to 2500 out of 10000 .
# Iterating from 2500 to 2520 out of 10000 .
# Iterating from 2520 to 2540 out of 10000 .
# Iterating from 2540 to 2560 out of 10000 .
# Iterating from 2560 to 2580 out of 10000 .
# Iterating from 2580 to 2600 out of 10000 .
# Iterating from 2600 to 2620 out of 10000 .
# Iterating from 2620 to 2640 out of 10000 .
# Iterating from 2640 to 2660 out of 10000 .
# Iterating from 2660 to 2680 out of 10000 .
# Iterating from 2680 to 2700 out of 10000 .
# Iterating from 2700 to 2720 out of 10000 .
# Iterating from 2720 to 2740 out of 10000 .
# Iterating from 2740 to 2760 out of 10000 .
# Iterating from 2760 to 2780 out of 10000 .
# Iterating from 2780 to 2800 out of 10000 .
# Iterating from 2800 to 2820 out of 10000 .
# Iterating from 2820 to 2840 out of 10000 .
# Iterating from 2840 to 2860 out of 10000 .
# Iterating from 2860 to 2880 out of 10000 .
# Iterating from 2880 to 2900 out of 10000 .
# Iterating from 2900 to 2920 out of 10000 .
# Iterating from 2920 to 2940 out of 10000 .
# Iterating from 2940 to 2960 out of 10000 .
# Iterating from 2960 to 2980 out of 10000 .
# Iterating from 2980 to 3000 out of 10000 .
# Iterating from 3000 to 3020 out of 10000 .
# Iterating from 3020 to 3040 out of 10000 .
# Iterating from 3040 to 3060 out of 10000 .
# Iterating from 3060 to 3080 out of 10000 .
# Iterating from 3080 to 3100 out of 10000 .
# Iterating from 3100 to 3120 out of 10000 .
# Iterating from 3120 to 3140 out of 10000 .
# Iterating from 3140 to 3160 out of 10000 .
# Iterating from 3160 to 3180 out of 10000 .
# Iterating from 3180 to 3200 out of 10000 .
# Iterating from 3200 to 3220 out of 10000 .
# Iterating from 3220 to 3240 out of 10000 .
# Iterating from 3240 to 3260 out of 10000 .
# Iterating from 3260 to 3280 out of 10000 .
# Iterating from 3280 to 3300 out of 10000 .
# Iterating from 3300 to 3320 out of 10000 .
# Iterating from 3320 to 3340 out of 10000 .
# Iterating from 3340 to 3360 out of 10000 .
# Iterating from 3360 to 3380 out of 10000 .
# Iterating from 3380 to 3400 out of 10000 .
# Iterating from 3400 to 3420 out of 10000 .
# Iterating from 3420 to 3440 out of 10000 .
# Iterating from 3440 to 3460 out of 10000 .
# Iterating from 3460 to 3480 out of 10000 .
# Iterating from 3480 to 3500 out of 10000 .
# Iterating from 3500 to 3520 out of 10000 .
# Iterating from 3520 to 3540 out of 10000 .
# Iterating from 3540 to 3560 out of 10000 .
# Iterating from 3560 to 3580 out of 10000 .
# Iterating from 3580 to 3600 out of 10000 .
# Iterating from 3600 to 3620 out of 10000 .
# Iterating from 3620 to 3640 out of 10000 .
# Iterating from 3640 to 3660 out of 10000 .
# Iterating from 3660 to 3680 out of 10000 .
# Iterating from 3680 to 3700 out of 10000 .
# Iterating from 3700 to 3720 out of 10000 .
# Iterating from 3720 to 3740 out of 10000 .
# Iterating from 3740 to 3760 out of 10000 .
# Iterating from 3760 to 3780 out of 10000 .
# Iterating from 3780 to 3800 out of 10000 .
# Iterating from 3800 to 3820 out of 10000 .
# Iterating from 3820 to 3840 out of 10000 .
# Iterating from 3840 to 3860 out of 10000 .
# Iterating from 3860 to 3880 out of 10000 .
# Iterating from 3880 to 3900 out of 10000 .
# Iterating from 3900 to 3920 out of 10000 .
# Iterating from 3920 to 3940 out of 10000 .
# Iterating from 3940 to 3960 out of 10000 .
# Iterating from 3960 to 3980 out of 10000 .
# Iterating from 3980 to 4000 out of 10000 .
# Iterating from 4000 to 4020 out of 10000 .
# Iterating from 4020 to 4040 out of 10000 .
# Iterating from 4040 to 4060 out of 10000 .
# Iterating from 4060 to 4080 out of 10000 .
# Iterating from 4080 to 4100 out of 10000 .
# Iterating from 4100 to 4120 out of 10000 .
# Iterating from 4120 to 4140 out of 10000 .
# Iterating from 4140 to 4160 out of 10000 .
# Iterating from 4160 to 4180 out of 10000 .
# Iterating from 4180 to 4200 out of 10000 .
# Iterating from 4200 to 4220 out of 10000 .
# Iterating from 4220 to 4240 out of 10000 .
# Iterating from 4240 to 4260 out of 10000 .
# Iterating from 4260 to 4280 out of 10000 .
# Iterating from 4280 to 4300 out of 10000 .
# Iterating from 4300 to 4320 out of 10000 .
# Iterating from 4320 to 4340 out of 10000 .
# Iterating from 4340 to 4360 out of 10000 .
# Iterating from 4360 to 4380 out of 10000 .
# Iterating from 4380 to 4400 out of 10000 .
# Iterating from 4400 to 4420 out of 10000 .
# Iterating from 4420 to 4440 out of 10000 .
# Iterating from 4440 to 4460 out of 10000 .
# Iterating from 4460 to 4480 out of 10000 .
# Iterating from 4480 to 4500 out of 10000 .
# Iterating from 4500 to 4520 out of 10000 .
# Iterating from 4520 to 4540 out of 10000 .
# Iterating from 4540 to 4560 out of 10000 .
# Iterating from 4560 to 4580 out of 10000 .
# Iterating from 4580 to 4600 out of 10000 .
# Iterating from 4600 to 4620 out of 10000 .
# Iterating from 4620 to 4640 out of 10000 .
# Iterating from 4640 to 4660 out of 10000 .
# Iterating from 4660 to 4680 out of 10000 .
# Iterating from 4680 to 4700 out of 10000 .
# Iterating from 4700 to 4720 out of 10000 .
# Iterating from 4720 to 4740 out of 10000 .
# Iterating from 4740 to 4760 out of 10000 .
# Iterating from 4760 to 4780 out of 10000 .
# Iterating from 4780 to 4800 out of 10000 .
# Iterating from 4800 to 4820 out of 10000 .
# Iterating from 4820 to 4840 out of 10000 .
# Iterating from 4840 to 4860 out of 10000 .
# Iterating from 4860 to 4880 out of 10000 .
# Iterating from 4880 to 4900 out of 10000 .
# Iterating from 4900 to 4920 out of 10000 .
# Iterating from 4920 to 4940 out of 10000 .
# Iterating from 4940 to 4960 out of 10000 .
# Iterating from 4960 to 4980 out of 10000 .
# Iterating from 4980 to 5000 out of 10000 .
# Iterating from 5000 to 5020 out of 10000 .
# Iterating from 5020 to 5040 out of 10000 .
# Iterating from 5040 to 5060 out of 10000 .
# Iterating from 5060 to 5080 out of 10000 .
# Iterating from 5080 to 5100 out of 10000 .
# Iterating from 5100 to 5120 out of 10000 .
# Iterating from 5120 to 5140 out of 10000 .
# Iterating from 5140 to 5160 out of 10000 .
# Iterating from 5160 to 5180 out of 10000 .
# Iterating from 5180 to 5200 out of 10000 .
# Iterating from 5200 to 5220 out of 10000 .
# Iterating from 5220 to 5240 out of 10000 .
# Iterating from 5240 to 5260 out of 10000 .
# Iterating from 5260 to 5280 out of 10000 .
# Iterating from 5280 to 5300 out of 10000 .
# Iterating from 5300 to 5320 out of 10000 .
# Iterating from 5320 to 5340 out of 10000 .
# Iterating from 5340 to 5360 out of 10000 .
# Iterating from 5360 to 5380 out of 10000 .
# Iterating from 5380 to 5400 out of 10000 .
# Iterating from 5400 to 5420 out of 10000 .
# Iterating from 5420 to 5440 out of 10000 .
# Iterating from 5440 to 5460 out of 10000 .
# Iterating from 5460 to 5480 out of 10000 .
# Iterating from 5480 to 5500 out of 10000 .
# Iterating from 5500 to 5520 out of 10000 .
# Iterating from 5520 to 5540 out of 10000 .
# Iterating from 5540 to 5560 out of 10000 .
# Iterating from 5560 to 5580 out of 10000 .
# Iterating from 5580 to 5600 out of 10000 .
# Iterating from 5600 to 5620 out of 10000 .
# Iterating from 5620 to 5640 out of 10000 .
# Iterating from 5640 to 5660 out of 10000 .
# Iterating from 5660 to 5680 out of 10000 .
# Iterating from 5680 to 5700 out of 10000 .
# Iterating from 5700 to 5720 out of 10000 .
# Iterating from 5720 to 5740 out of 10000 .
# Iterating from 5740 to 5760 out of 10000 .
# Iterating from 5760 to 5780 out of 10000 .
# Iterating from 5780 to 5800 out of 10000 .
# Iterating from 5800 to 5820 out of 10000 .
# Iterating from 5820 to 5840 out of 10000 .
# Iterating from 5840 to 5860 out of 10000 .
# Iterating from 5860 to 5880 out of 10000 .
# Iterating from 5880 to 5900 out of 10000 .
# Iterating from 5900 to 5920 out of 10000 .
# Iterating from 5920 to 5940 out of 10000 .
# Iterating from 5940 to 5960 out of 10000 .
# Iterating from 5960 to 5980 out of 10000 .
# Iterating from 5980 to 6000 out of 10000 .
# Iterating from 6000 to 6020 out of 10000 .
# Iterating from 6020 to 6040 out of 10000 .
# Iterating from 6040 to 6060 out of 10000 .
# Iterating from 6060 to 6080 out of 10000 .
# Iterating from 6080 to 6100 out of 10000 .
# Iterating from 6100 to 6120 out of 10000 .
# Iterating from 6120 to 6140 out of 10000 .
# Iterating from 6140 to 6160 out of 10000 .
# Iterating from 6160 to 6180 out of 10000 .
# Iterating from 6180 to 6200 out of 10000 .
# Iterating from 6200 to 6220 out of 10000 .
# Iterating from 6220 to 6240 out of 10000 .
# Iterating from 6240 to 6260 out of 10000 .
# Iterating from 6260 to 6280 out of 10000 .
# Iterating from 6280 to 6300 out of 10000 .
# Iterating from 6300 to 6320 out of 10000 .
# Iterating from 6320 to 6340 out of 10000 .
# Iterating from 6340 to 6360 out of 10000 .
# Iterating from 6360 to 6380 out of 10000 .
# Iterating from 6380 to 6400 out of 10000 .
# Iterating from 6400 to 6420 out of 10000 .
# Iterating from 6420 to 6440 out of 10000 .
# Iterating from 6440 to 6460 out of 10000 .
# Iterating from 6460 to 6480 out of 10000 .
# Iterating from 6480 to 6500 out of 10000 .
# Iterating from 6500 to 6520 out of 10000 .
# Iterating from 6520 to 6540 out of 10000 .
# Iterating from 6540 to 6560 out of 10000 .
# Iterating from 6560 to 6580 out of 10000 .
# Iterating from 6580 to 6600 out of 10000 .
# Iterating from 6600 to 6620 out of 10000 .
# Iterating from 6620 to 6640 out of 10000 .
# Iterating from 6640 to 6660 out of 10000 .
# Iterating from 6660 to 6680 out of 10000 .
# Iterating from 6680 to 6700 out of 10000 .
# Iterating from 6700 to 6720 out of 10000 .
# Iterating from 6720 to 6740 out of 10000 .
# Iterating from 6740 to 6760 out of 10000 .
# Iterating from 6760 to 6780 out of 10000 .
# Iterating from 6780 to 6800 out of 10000 .
# Iterating from 6800 to 6820 out of 10000 .
# Iterating from 6820 to 6840 out of 10000 .
# Iterating from 6840 to 6860 out of 10000 .
# Iterating from 6860 to 6880 out of 10000 .
# Iterating from 6880 to 6900 out of 10000 .
# Iterating from 6900 to 6920 out of 10000 .
# Iterating from 6920 to 6940 out of 10000 .
# Iterating from 6940 to 6960 out of 10000 .
# Iterating from 6960 to 6980 out of 10000 .
# Iterating from 6980 to 7000 out of 10000 .
# Iterating from 7000 to 7020 out of 10000 .
# Iterating from 7020 to 7040 out of 10000 .
# Iterating from 7040 to 7060 out of 10000 .
# Iterating from 7060 to 7080 out of 10000 .
# Iterating from 7080 to 7100 out of 10000 .
# Iterating from 7100 to 7120 out of 10000 .
# Iterating from 7120 to 7140 out of 10000 .
# Iterating from 7140 to 7160 out of 10000 .
# Iterating from 7160 to 7180 out of 10000 .
# Iterating from 7180 to 7200 out of 10000 .
# Iterating from 7200 to 7220 out of 10000 .
# Iterating from 7220 to 7240 out of 10000 .
# Iterating from 7240 to 7260 out of 10000 .
# Iterating from 7260 to 7280 out of 10000 .
# Iterating from 7280 to 7300 out of 10000 .
# Iterating from 7300 to 7320 out of 10000 .
# Iterating from 7320 to 7340 out of 10000 .
# Iterating from 7340 to 7360 out of 10000 .
# Iterating from 7360 to 7380 out of 10000 .
# Iterating from 7380 to 7400 out of 10000 .
# Iterating from 7400 to 7420 out of 10000 .
# Iterating from 7420 to 7440 out of 10000 .
# Iterating from 7440 to 7460 out of 10000 .
# Iterating from 7460 to 7480 out of 10000 .
# Iterating from 7480 to 7500 out of 10000 .
# Iterating from 7500 to 7520 out of 10000 .
# Iterating from 7520 to 7540 out of 10000 .
# Iterating from 7540 to 7560 out of 10000 .
# Iterating from 7560 to 7580 out of 10000 .
# Iterating from 7580 to 7600 out of 10000 .
# Iterating from 7600 to 7620 out of 10000 .
# Iterating from 7620 to 7640 out of 10000 .
# Iterating from 7640 to 7660 out of 10000 .
# Iterating from 7660 to 7680 out of 10000 .
# Iterating from 7680 to 7700 out of 10000 .
# Iterating from 7700 to 7720 out of 10000 .
# Iterating from 7720 to 7740 out of 10000 .
# Iterating from 7740 to 7760 out of 10000 .
# Iterating from 7760 to 7780 out of 10000 .
# Iterating from 7780 to 7800 out of 10000 .
# Iterating from 7800 to 7820 out of 10000 .
# Iterating from 7820 to 7840 out of 10000 .
# Iterating from 7840 to 7860 out of 10000 .
# Iterating from 7860 to 7880 out of 10000 .
# Iterating from 7880 to 7900 out of 10000 .
# Iterating from 7900 to 7920 out of 10000 .
# Iterating from 7920 to 7940 out of 10000 .
# Iterating from 7940 to 7960 out of 10000 .
# Iterating from 7960 to 7980 out of 10000 .
# Iterating from 7980 to 8000 out of 10000 .
# Iterating from 8000 to 8020 out of 10000 .
# Iterating from 8020 to 8040 out of 10000 .
# Iterating from 8040 to 8060 out of 10000 .
# Iterating from 8060 to 8080 out of 10000 .
# Iterating from 8080 to 8100 out of 10000 .
# Iterating from 8100 to 8120 out of 10000 .
# Iterating from 8120 to 8140 out of 10000 .
# Iterating from 8140 to 8160 out of 10000 .
# Iterating from 8160 to 8180 out of 10000 .
# Iterating from 8180 to 8200 out of 10000 .
# Iterating from 8200 to 8220 out of 10000 .
# Iterating from 8220 to 8240 out of 10000 .
# Iterating from 8240 to 8260 out of 10000 .
# Iterating from 8260 to 8280 out of 10000 .
# Iterating from 8280 to 8300 out of 10000 .
# Iterating from 8300 to 8320 out of 10000 .
# Iterating from 8320 to 8340 out of 10000 .
# Iterating from 8340 to 8360 out of 10000 .
# Iterating from 8360 to 8380 out of 10000 .
# Iterating from 8380 to 8400 out of 10000 .
# Iterating from 8400 to 8420 out of 10000 .
# Iterating from 8420 to 8440 out of 10000 .
# Iterating from 8440 to 8460 out of 10000 .
# Iterating from 8460 to 8480 out of 10000 .
# Iterating from 8480 to 8500 out of 10000 .
# Iterating from 8500 to 8520 out of 10000 .
# Iterating from 8520 to 8540 out of 10000 .
# Iterating from 8540 to 8560 out of 10000 .
# Iterating from 8560 to 8580 out of 10000 .
# Iterating from 8580 to 8600 out of 10000 .
# Iterating from 8600 to 8620 out of 10000 .
# Iterating from 8620 to 8640 out of 10000 .
# Iterating from 8640 to 8660 out of 10000 .
# Iterating from 8660 to 8680 out of 10000 .
# Iterating from 8680 to 8700 out of 10000 .
# Iterating from 8700 to 8720 out of 10000 .
# Iterating from 8720 to 8740 out of 10000 .
# Iterating from 8740 to 8760 out of 10000 .
# Iterating from 8760 to 8780 out of 10000 .
# Iterating from 8780 to 8800 out of 10000 .
# Iterating from 8800 to 8820 out of 10000 .
# Iterating from 8820 to 8840 out of 10000 .
# Iterating from 8840 to 8860 out of 10000 .
# Iterating from 8860 to 8880 out of 10000 .
# Iterating from 8880 to 8900 out of 10000 .
# Iterating from 8900 to 8920 out of 10000 .
# Iterating from 8920 to 8940 out of 10000 .
# Iterating from 8940 to 8960 out of 10000 .
# Iterating from 8960 to 8980 out of 10000 .
# Iterating from 8980 to 9000 out of 10000 .
# Iterating from 9000 to 9020 out of 10000 .
# Iterating from 9020 to 9040 out of 10000 .
# Iterating from 9040 to 9060 out of 10000 .
# Iterating from 9060 to 9080 out of 10000 .
# Iterating from 9080 to 9100 out of 10000 .
# Iterating from 9100 to 9120 out of 10000 .
# Iterating from 9120 to 9140 out of 10000 .
# Iterating from 9140 to 9160 out of 10000 .
# Iterating from 9160 to 9180 out of 10000 .
# Iterating from 9180 to 9200 out of 10000 .
# Iterating from 9200 to 9220 out of 10000 .
# Iterating from 9220 to 9240 out of 10000 .
# Iterating from 9240 to 9260 out of 10000 .
# Iterating from 9260 to 9280 out of 10000 .
# Iterating from 9280 to 9300 out of 10000 .
# Iterating from 9300 to 9320 out of 10000 .
# Iterating from 9320 to 9340 out of 10000 .
# Iterating from 9340 to 9360 out of 10000 .
# Iterating from 9360 to 9380 out of 10000 .
# Iterating from 9380 to 9400 out of 10000 .
# Iterating from 9400 to 9420 out of 10000 .
# Iterating from 9420 to 9440 out of 10000 .
# Iterating from 9440 to 9460 out of 10000 .
# Iterating from 9460 to 9480 out of 10000 .
# Iterating from 9480 to 9500 out of 10000 .
# Iterating from 9500 to 9520 out of 10000 .
# Iterating from 9520 to 9540 out of 10000 .
# Iterating from 9540 to 9560 out of 10000 .
# Iterating from 9560 to 9580 out of 10000 .
# Iterating from 9580 to 9600 out of 10000 .
# Iterating from 9600 to 9620 out of 10000 .
# Iterating from 9620 to 9640 out of 10000 .
# Iterating from 9640 to 9660 out of 10000 .
# Iterating from 9660 to 9680 out of 10000 .
# Iterating from 9680 to 9700 out of 10000 .
# Iterating from 9700 to 9720 out of 10000 .
# Iterating from 9720 to 9740 out of 10000 .
# Iterating from 9740 to 9760 out of 10000 .
# Iterating from 9760 to 9780 out of 10000 .
# Iterating from 9780 to 9800 out of 10000 .
# Iterating from 9800 to 9820 out of 10000 .
# Iterating from 9820 to 9840 out of 10000 .
# Iterating from 9840 to 9860 out of 10000 .
# Iterating from 9860 to 9880 out of 10000 .
# Iterating from 9880 to 9900 out of 10000 .
# Iterating from 9900 to 9920 out of 10000 .
# Iterating from 9920 to 9940 out of 10000 .
# Iterating from 9940 to 9960 out of 10000 .
# Iterating from 9960 to 9980 out of 10000 .
# Iterating from 9980 to 10000 out of 10000 .
# LR metric calculation completed in 138.42488019005395 seconds.
# Saving lr to results/100D_unimodal/100D_50K/null_hypothesis/LR_off_0.025000.json
# ThresholdS: [[0.95, [9500, 500], -325327.9842133634], [0.99, [9900, 100], -324729.22665400273]]
# Null distribution computed in 141.77658553700894 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 3.5047172009944916 seconds.
# statistic = 496380.86828202265 - next threshold = -325327.9842133634 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 9.60765855506486
#
# ------------ 2 ------------
# eps = 0.0125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 500
# Iterating from 0 to 20 out of 10000 .
# Iterating from 20 to 40 out of 10000 .
# Iterating from 40 to 60 out of 10000 .
# Iterating from 60 to 80 out of 10000 .
# Iterating from 80 to 100 out of 10000 .
# Iterating from 100 to 120 out of 10000 .
# Iterating from 120 to 140 out of 10000 .
# Iterating from 140 to 160 out of 10000 .
# Iterating from 160 to 180 out of 10000 .
# Iterating from 180 to 200 out of 10000 .
# Iterating from 200 to 220 out of 10000 .
# Iterating from 220 to 240 out of 10000 .
# Iterating from 240 to 260 out of 10000 .
# Iterating from 260 to 280 out of 10000 .
# Iterating from 280 to 300 out of 10000 .
# Iterating from 300 to 320 out of 10000 .
# Iterating from 320 to 340 out of 10000 .
# Iterating from 340 to 360 out of 10000 .
# Iterating from 360 to 380 out of 10000 .
# Iterating from 380 to 400 out of 10000 .
# Iterating from 400 to 420 out of 10000 .
# Iterating from 420 to 440 out of 10000 .
# Iterating from 440 to 460 out of 10000 .
# Iterating from 460 to 480 out of 10000 .
# Iterating from 480 to 500 out of 10000 .
# Iterating from 500 to 520 out of 10000 .
# Iterating from 520 to 540 out of 10000 .
# Iterating from 540 to 560 out of 10000 .
# Iterating from 560 to 580 out of 10000 .
# Iterating from 580 to 600 out of 10000 .
# Iterating from 600 to 620 out of 10000 .
# Iterating from 620 to 640 out of 10000 .
# Iterating from 640 to 660 out of 10000 .
# Iterating from 660 to 680 out of 10000 .
# Iterating from 680 to 700 out of 10000 .
# Iterating from 700 to 720 out of 10000 .
# Iterating from 720 to 740 out of 10000 .
# Iterating from 740 to 760 out of 10000 .
# Iterating from 760 to 780 out of 10000 .
# Iterating from 780 to 800 out of 10000 .
# Iterating from 800 to 820 out of 10000 .
# Iterating from 820 to 840 out of 10000 .
# Iterating from 840 to 860 out of 10000 .
# Iterating from 860 to 880 out of 10000 .
# Iterating from 880 to 900 out of 10000 .
# Iterating from 900 to 920 out of 10000 .
# Iterating from 920 to 940 out of 10000 .
# Iterating from 940 to 960 out of 10000 .
# Iterating from 960 to 980 out of 10000 .
# Iterating from 980 to 1000 out of 10000 .
# Iterating from 1000 to 1020 out of 10000 .
# Iterating from 1020 to 1040 out of 10000 .
# Iterating from 1040 to 1060 out of 10000 .
# Iterating from 1060 to 1080 out of 10000 .
# Iterating from 1080 to 1100 out of 10000 .
# Iterating from 1100 to 1120 out of 10000 .
# Iterating from 1120 to 1140 out of 10000 .
# Iterating from 1140 to 1160 out of 10000 .
# Iterating from 1160 to 1180 out of 10000 .
# Iterating from 1180 to 1200 out of 10000 .
# Iterating from 1200 to 1220 out of 10000 .
# Iterating from 1220 to 1240 out of 10000 .
# Iterating from 1240 to 1260 out of 10000 .
# Iterating from 1260 to 1280 out of 10000 .
# Iterating from 1280 to 1300 out of 10000 .
# Iterating from 1300 to 1320 out of 10000 .
# Iterating from 1320 to 1340 out of 10000 .
# Iterating from 1340 to 1360 out of 10000 .
# Iterating from 1360 to 1380 out of 10000 .
# Iterating from 1380 to 1400 out of 10000 .
# Iterating from 1400 to 1420 out of 10000 .
# Iterating from 1420 to 1440 out of 10000 .
# Iterating from 1440 to 1460 out of 10000 .
# Iterating from 1460 to 1480 out of 10000 .
# Iterating from 1480 to 1500 out of 10000 .
# Iterating from 1500 to 1520 out of 10000 .
# Iterating from 1520 to 1540 out of 10000 .
# Iterating from 1540 to 1560 out of 10000 .
# Iterating from 1560 to 1580 out of 10000 .
# Iterating from 1580 to 1600 out of 10000 .
# Iterating from 1600 to 1620 out of 10000 .
# Iterating from 1620 to 1640 out of 10000 .
# Iterating from 1640 to 1660 out of 10000 .
# Iterating from 1660 to 1680 out of 10000 .
# Iterating from 1680 to 1700 out of 10000 .
# Iterating from 1700 to 1720 out of 10000 .
# Iterating from 1720 to 1740 out of 10000 .
# Iterating from 1740 to 1760 out of 10000 .
# Iterating from 1760 to 1780 out of 10000 .
# Iterating from 1780 to 1800 out of 10000 .
# Iterating from 1800 to 1820 out of 10000 .
# Iterating from 1820 to 1840 out of 10000 .
# Iterating from 1840 to 1860 out of 10000 .
# Iterating from 1860 to 1880 out of 10000 .
# Iterating from 1880 to 1900 out of 10000 .
# Iterating from 1900 to 1920 out of 10000 .
# Iterating from 1920 to 1940 out of 10000 .
# Iterating from 1940 to 1960 out of 10000 .
# Iterating from 1960 to 1980 out of 10000 .
# Iterating from 1980 to 2000 out of 10000 .
# Iterating from 2000 to 2020 out of 10000 .
# Iterating from 2020 to 2040 out of 10000 .
# Iterating from 2040 to 2060 out of 10000 .
# Iterating from 2060 to 2080 out of 10000 .
# Iterating from 2080 to 2100 out of 10000 .
# Iterating from 2100 to 2120 out of 10000 .
# Iterating from 2120 to 2140 out of 10000 .
# Iterating from 2140 to 2160 out of 10000 .
# Iterating from 2160 to 2180 out of 10000 .
# Iterating from 2180 to 2200 out of 10000 .
# Iterating from 2200 to 2220 out of 10000 .
# Iterating from 2220 to 2240 out of 10000 .
# Iterating from 2240 to 2260 out of 10000 .
# Iterating from 2260 to 2280 out of 10000 .
# Iterating from 2280 to 2300 out of 10000 .
# Iterating from 2300 to 2320 out of 10000 .
# Iterating from 2320 to 2340 out of 10000 .
# Iterating from 2340 to 2360 out of 10000 .
# Iterating from 2360 to 2380 out of 10000 .
# Iterating from 2380 to 2400 out of 10000 .
# Iterating from 2400 to 2420 out of 10000 .
# Iterating from 2420 to 2440 out of 10000 .
# Iterating from 2440 to 2460 out of 10000 .
# Iterating from 2460 to 2480 out of 10000 .
# Iterating from 2480 to 2500 out of 10000 .
# Iterating from 2500 to 2520 out of 10000 .
# Iterating from 2520 to 2540 out of 10000 .
# Iterating from 2540 to 2560 out of 10000 .
# Iterating from 2560 to 2580 out of 10000 .
# Iterating from 2580 to 2600 out of 10000 .
# Iterating from 2600 to 2620 out of 10000 .
# Iterating from 2620 to 2640 out of 10000 .
# Iterating from 2640 to 2660 out of 10000 .
# Iterating from 2660 to 2680 out of 10000 .
# Iterating from 2680 to 2700 out of 10000 .
# Iterating from 2700 to 2720 out of 10000 .
# Iterating from 2720 to 2740 out of 10000 .
# Iterating from 2740 to 2760 out of 10000 .
# Iterating from 2760 to 2780 out of 10000 .
# Iterating from 2780 to 2800 out of 10000 .
# Iterating from 2800 to 2820 out of 10000 .
# Iterating from 2820 to 2840 out of 10000 .
# Iterating from 2840 to 2860 out of 10000 .
# Iterating from 2860 to 2880 out of 10000 .
# Iterating from 2880 to 2900 out of 10000 .
# Iterating from 2900 to 2920 out of 10000 .
# Iterating from 2920 to 2940 out of 10000 .
# Iterating from 2940 to 2960 out of 10000 .
# Iterating from 2960 to 2980 out of 10000 .
# Iterating from 2980 to 3000 out of 10000 .
# Iterating from 3000 to 3020 out of 10000 .
# Iterating from 3020 to 3040 out of 10000 .
# Iterating from 3040 to 3060 out of 10000 .
# Iterating from 3060 to 3080 out of 10000 .
# Iterating from 3080 to 3100 out of 10000 .
# Iterating from 3100 to 3120 out of 10000 .
# Iterating from 3120 to 3140 out of 10000 .
# Iterating from 3140 to 3160 out of 10000 .
# Iterating from 3160 to 3180 out of 10000 .
# Iterating from 3180 to 3200 out of 10000 .
# Iterating from 3200 to 3220 out of 10000 .
# Iterating from 3220 to 3240 out of 10000 .
# Iterating from 3240 to 3260 out of 10000 .
# Iterating from 3260 to 3280 out of 10000 .
# Iterating from 3280 to 3300 out of 10000 .
# Iterating from 3300 to 3320 out of 10000 .
# Iterating from 3320 to 3340 out of 10000 .
# Iterating from 3340 to 3360 out of 10000 .
# Iterating from 3360 to 3380 out of 10000 .
# Iterating from 3380 to 3400 out of 10000 .
# Iterating from 3400 to 3420 out of 10000 .
# Iterating from 3420 to 3440 out of 10000 .
# Iterating from 3440 to 3460 out of 10000 .
# Iterating from 3460 to 3480 out of 10000 .
# Iterating from 3480 to 3500 out of 10000 .
# Iterating from 3500 to 3520 out of 10000 .
# Iterating from 3520 to 3540 out of 10000 .
# Iterating from 3540 to 3560 out of 10000 .
# Iterating from 3560 to 3580 out of 10000 .
# Iterating from 3580 to 3600 out of 10000 .
# Iterating from 3600 to 3620 out of 10000 .
# Iterating from 3620 to 3640 out of 10000 .
# Iterating from 3640 to 3660 out of 10000 .
# Iterating from 3660 to 3680 out of 10000 .
# Iterating from 3680 to 3700 out of 10000 .
# Iterating from 3700 to 3720 out of 10000 .
# Iterating from 3720 to 3740 out of 10000 .
# Iterating from 3740 to 3760 out of 10000 .
# Iterating from 3760 to 3780 out of 10000 .
# Iterating from 3780 to 3800 out of 10000 .
# Iterating from 3800 to 3820 out of 10000 .
# Iterating from 3820 to 3840 out of 10000 .
# Iterating from 3840 to 3860 out of 10000 .
# Iterating from 3860 to 3880 out of 10000 .
# Iterating from 3880 to 3900 out of 10000 .
# Iterating from 3900 to 3920 out of 10000 .
# Iterating from 3920 to 3940 out of 10000 .
# Iterating from 3940 to 3960 out of 10000 .
# Iterating from 3960 to 3980 out of 10000 .
# Iterating from 3980 to 4000 out of 10000 .
# Iterating from 4000 to 4020 out of 10000 .
# Iterating from 4020 to 4040 out of 10000 .
# Iterating from 4040 to 4060 out of 10000 .
# Iterating from 4060 to 4080 out of 10000 .
# Iterating from 4080 to 4100 out of 10000 .
# Iterating from 4100 to 4120 out of 10000 .
# Iterating from 4120 to 4140 out of 10000 .
# Iterating from 4140 to 4160 out of 10000 .
# Iterating from 4160 to 4180 out of 10000 .
# Iterating from 4180 to 4200 out of 10000 .
# Iterating from 4200 to 4220 out of 10000 .
# Iterating from 4220 to 4240 out of 10000 .
# Iterating from 4240 to 4260 out of 10000 .
# Iterating from 4260 to 4280 out of 10000 .
# Iterating from 4280 to 4300 out of 10000 .
# Iterating from 4300 to 4320 out of 10000 .
# Iterating from 4320 to 4340 out of 10000 .
# Iterating from 4340 to 4360 out of 10000 .
# Iterating from 4360 to 4380 out of 10000 .
# Iterating from 4380 to 4400 out of 10000 .
# Iterating from 4400 to 4420 out of 10000 .
# Iterating from 4420 to 4440 out of 10000 .
# Iterating from 4440 to 4460 out of 10000 .
# Iterating from 4460 to 4480 out of 10000 .
# Iterating from 4480 to 4500 out of 10000 .
# Iterating from 4500 to 4520 out of 10000 .
# Iterating from 4520 to 4540 out of 10000 .
# Iterating from 4540 to 4560 out of 10000 .
# Iterating from 4560 to 4580 out of 10000 .
# Iterating from 4580 to 4600 out of 10000 .
# Iterating from 4600 to 4620 out of 10000 .
# Iterating from 4620 to 4640 out of 10000 .
# Iterating from 4640 to 4660 out of 10000 .
# Iterating from 4660 to 4680 out of 10000 .
# Iterating from 4680 to 4700 out of 10000 .
# Iterating from 4700 to 4720 out of 10000 .
# Iterating from 4720 to 4740 out of 10000 .
# Iterating from 4740 to 4760 out of 10000 .
# Iterating from 4760 to 4780 out of 10000 .
# Iterating from 4780 to 4800 out of 10000 .
# Iterating from 4800 to 4820 out of 10000 .
# Iterating from 4820 to 4840 out of 10000 .
# Iterating from 4840 to 4860 out of 10000 .
# Iterating from 4860 to 4880 out of 10000 .
# Iterating from 4880 to 4900 out of 10000 .
# Iterating from 4900 to 4920 out of 10000 .
# Iterating from 4920 to 4940 out of 10000 .
# Iterating from 4940 to 4960 out of 10000 .
# Iterating from 4960 to 4980 out of 10000 .
# Iterating from 4980 to 5000 out of 10000 .
# Iterating from 5000 to 5020 out of 10000 .
# Iterating from 5020 to 5040 out of 10000 .
# Iterating from 5040 to 5060 out of 10000 .
# Iterating from 5060 to 5080 out of 10000 .
# Iterating from 5080 to 5100 out of 10000 .
# Iterating from 5100 to 5120 out of 10000 .
# Iterating from 5120 to 5140 out of 10000 .
# Iterating from 5140 to 5160 out of 10000 .
# Iterating from 5160 to 5180 out of 10000 .
# Iterating from 5180 to 5200 out of 10000 .
# Iterating from 5200 to 5220 out of 10000 .
# Iterating from 5220 to 5240 out of 10000 .
# Iterating from 5240 to 5260 out of 10000 .
# Iterating from 5260 to 5280 out of 10000 .
# Iterating from 5280 to 5300 out of 10000 .
# Iterating from 5300 to 5320 out of 10000 .
# Iterating from 5320 to 5340 out of 10000 .
# Iterating from 5340 to 5360 out of 10000 .
# Iterating from 5360 to 5380 out of 10000 .
# Iterating from 5380 to 5400 out of 10000 .
# Iterating from 5400 to 5420 out of 10000 .
# Iterating from 5420 to 5440 out of 10000 .
# Iterating from 5440 to 5460 out of 10000 .
# Iterating from 5460 to 5480 out of 10000 .
# Iterating from 5480 to 5500 out of 10000 .
# Iterating from 5500 to 5520 out of 10000 .
# Iterating from 5520 to 5540 out of 10000 .
# Iterating from 5540 to 5560 out of 10000 .
# Iterating from 5560 to 5580 out of 10000 .
# Iterating from 5580 to 5600 out of 10000 .
# Iterating from 5600 to 5620 out of 10000 .
# Iterating from 5620 to 5640 out of 10000 .
# Iterating from 5640 to 5660 out of 10000 .
# Iterating from 5660 to 5680 out of 10000 .
# Iterating from 5680 to 5700 out of 10000 .
# Iterating from 5700 to 5720 out of 10000 .
# Iterating from 5720 to 5740 out of 10000 .
# Iterating from 5740 to 5760 out of 10000 .
# Iterating from 5760 to 5780 out of 10000 .
# Iterating from 5780 to 5800 out of 10000 .
# Iterating from 5800 to 5820 out of 10000 .
# Iterating from 5820 to 5840 out of 10000 .
# Iterating from 5840 to 5860 out of 10000 .
# Iterating from 5860 to 5880 out of 10000 .
# Iterating from 5880 to 5900 out of 10000 .
# Iterating from 5900 to 5920 out of 10000 .
# Iterating from 5920 to 5940 out of 10000 .
# Iterating from 5940 to 5960 out of 10000 .
# Iterating from 5960 to 5980 out of 10000 .
# Iterating from 5980 to 6000 out of 10000 .
# Iterating from 6000 to 6020 out of 10000 .
# Iterating from 6020 to 6040 out of 10000 .
# Iterating from 6040 to 6060 out of 10000 .
# Iterating from 6060 to 6080 out of 10000 .
# Iterating from 6080 to 6100 out of 10000 .
# Iterating from 6100 to 6120 out of 10000 .
# Iterating from 6120 to 6140 out of 10000 .
# Iterating from 6140 to 6160 out of 10000 .
# Iterating from 6160 to 6180 out of 10000 .
# Iterating from 6180 to 6200 out of 10000 .
# Iterating from 6200 to 6220 out of 10000 .
# Iterating from 6220 to 6240 out of 10000 .
# Iterating from 6240 to 6260 out of 10000 .
# Iterating from 6260 to 6280 out of 10000 .
# Iterating from 6280 to 6300 out of 10000 .
# Iterating from 6300 to 6320 out of 10000 .
# Iterating from 6320 to 6340 out of 10000 .
# Iterating from 6340 to 6360 out of 10000 .
# Iterating from 6360 to 6380 out of 10000 .
# Iterating from 6380 to 6400 out of 10000 .
# Iterating from 6400 to 6420 out of 10000 .
# Iterating from 6420 to 6440 out of 10000 .
# Iterating from 6440 to 6460 out of 10000 .
# Iterating from 6460 to 6480 out of 10000 .
# Iterating from 6480 to 6500 out of 10000 .
# Iterating from 6500 to 6520 out of 10000 .
# Iterating from 6520 to 6540 out of 10000 .
# Iterating from 6540 to 6560 out of 10000 .
# Iterating from 6560 to 6580 out of 10000 .
# Iterating from 6580 to 6600 out of 10000 .
# Iterating from 6600 to 6620 out of 10000 .
# Iterating from 6620 to 6640 out of 10000 .
# Iterating from 6640 to 6660 out of 10000 .
# Iterating from 6660 to 6680 out of 10000 .
# Iterating from 6680 to 6700 out of 10000 .
# Iterating from 6700 to 6720 out of 10000 .
# Iterating from 6720 to 6740 out of 10000 .
# Iterating from 6740 to 6760 out of 10000 .
# Iterating from 6760 to 6780 out of 10000 .
# Iterating from 6780 to 6800 out of 10000 .
# Iterating from 6800 to 6820 out of 10000 .
# Iterating from 6820 to 6840 out of 10000 .
# Iterating from 6840 to 6860 out of 10000 .
# Iterating from 6860 to 6880 out of 10000 .
# Iterating from 6880 to 6900 out of 10000 .
# Iterating from 6900 to 6920 out of 10000 .
# Iterating from 6920 to 6940 out of 10000 .
# Iterating from 6940 to 6960 out of 10000 .
# Iterating from 6960 to 6980 out of 10000 .
# Iterating from 6980 to 7000 out of 10000 .
# Iterating from 7000 to 7020 out of 10000 .
# Iterating from 7020 to 7040 out of 10000 .
# Iterating from 7040 to 7060 out of 10000 .
# Iterating from 7060 to 7080 out of 10000 .
# Iterating from 7080 to 7100 out of 10000 .
# Iterating from 7100 to 7120 out of 10000 .
# Iterating from 7120 to 7140 out of 10000 .
# Iterating from 7140 to 7160 out of 10000 .
# Iterating from 7160 to 7180 out of 10000 .
# Iterating from 7180 to 7200 out of 10000 .
# Iterating from 7200 to 7220 out of 10000 .
# Iterating from 7220 to 7240 out of 10000 .
# Iterating from 7240 to 7260 out of 10000 .
# Iterating from 7260 to 7280 out of 10000 .
# Iterating from 7280 to 7300 out of 10000 .
# Iterating from 7300 to 7320 out of 10000 .
# Iterating from 7320 to 7340 out of 10000 .
# Iterating from 7340 to 7360 out of 10000 .
# Iterating from 7360 to 7380 out of 10000 .
# Iterating from 7380 to 7400 out of 10000 .
# Iterating from 7400 to 7420 out of 10000 .
# Iterating from 7420 to 7440 out of 10000 .
# Iterating from 7440 to 7460 out of 10000 .
# Iterating from 7460 to 7480 out of 10000 .
# Iterating from 7480 to 7500 out of 10000 .
# Iterating from 7500 to 7520 out of 10000 .
# Iterating from 7520 to 7540 out of 10000 .
# Iterating from 7540 to 7560 out of 10000 .
# Iterating from 7560 to 7580 out of 10000 .
# Iterating from 7580 to 7600 out of 10000 .
# Iterating from 7600 to 7620 out of 10000 .
# Iterating from 7620 to 7640 out of 10000 .
# Iterating from 7640 to 7660 out of 10000 .
# Iterating from 7660 to 7680 out of 10000 .
# Iterating from 7680 to 7700 out of 10000 .
# Iterating from 7700 to 7720 out of 10000 .
# Iterating from 7720 to 7740 out of 10000 .
# Iterating from 7740 to 7760 out of 10000 .
# Iterating from 7760 to 7780 out of 10000 .
# Iterating from 7780 to 7800 out of 10000 .
# Iterating from 7800 to 7820 out of 10000 .
# Iterating from 7820 to 7840 out of 10000 .
# Iterating from 7840 to 7860 out of 10000 .
# Iterating from 7860 to 7880 out of 10000 .
# Iterating from 7880 to 7900 out of 10000 .
# Iterating from 7900 to 7920 out of 10000 .
# Iterating from 7920 to 7940 out of 10000 .
# Iterating from 7940 to 7960 out of 10000 .
# Iterating from 7960 to 7980 out of 10000 .
# Iterating from 7980 to 8000 out of 10000 .
# Iterating from 8000 to 8020 out of 10000 .
# Iterating from 8020 to 8040 out of 10000 .
# Iterating from 8040 to 8060 out of 10000 .
# Iterating from 8060 to 8080 out of 10000 .
# Iterating from 8080 to 8100 out of 10000 .
# Iterating from 8100 to 8120 out of 10000 .
# Iterating from 8120 to 8140 out of 10000 .
# Iterating from 8140 to 8160 out of 10000 .
# Iterating from 8160 to 8180 out of 10000 .
# Iterating from 8180 to 8200 out of 10000 .
# Iterating from 8200 to 8220 out of 10000 .
# Iterating from 8220 to 8240 out of 10000 .
# Iterating from 8240 to 8260 out of 10000 .
# Iterating from 8260 to 8280 out of 10000 .
# Iterating from 8280 to 8300 out of 10000 .
# Iterating from 8300 to 8320 out of 10000 .
# Iterating from 8320 to 8340 out of 10000 .
# Iterating from 8340 to 8360 out of 10000 .
# Iterating from 8360 to 8380 out of 10000 .
# Iterating from 8380 to 8400 out of 10000 .
# Iterating from 8400 to 8420 out of 10000 .
# Iterating from 8420 to 8440 out of 10000 .
# Iterating from 8440 to 8460 out of 10000 .
# Iterating from 8460 to 8480 out of 10000 .
# Iterating from 8480 to 8500 out of 10000 .
# Iterating from 8500 to 8520 out of 10000 .
# Iterating from 8520 to 8540 out of 10000 .
# Iterating from 8540 to 8560 out of 10000 .
# Iterating from 8560 to 8580 out of 10000 .
# Iterating from 8580 to 8600 out of 10000 .
# Iterating from 8600 to 8620 out of 10000 .
# Iterating from 8620 to 8640 out of 10000 .
# Iterating from 8640 to 8660 out of 10000 .
# Iterating from 8660 to 8680 out of 10000 .
# Iterating from 8680 to 8700 out of 10000 .
# Iterating from 8700 to 8720 out of 10000 .
# Iterating from 8720 to 8740 out of 10000 .
# Iterating from 8740 to 8760 out of 10000 .
# Iterating from 8760 to 8780 out of 10000 .
# Iterating from 8780 to 8800 out of 10000 .
# Iterating from 8800 to 8820 out of 10000 .
# Iterating from 8820 to 8840 out of 10000 .
# Iterating from 8840 to 8860 out of 10000 .
# Iterating from 8860 to 8880 out of 10000 .
# Iterating from 8880 to 8900 out of 10000 .
# Iterating from 8900 to 8920 out of 10000 .
# Iterating from 8920 to 8940 out of 10000 .
# Iterating from 8940 to 8960 out of 10000 .
# Iterating from 8960 to 8980 out of 10000 .
# Iterating from 8980 to 9000 out of 10000 .
# Iterating from 9000 to 9020 out of 10000 .
# Iterating from 9020 to 9040 out of 10000 .
# Iterating from 9040 to 9060 out of 10000 .
# Iterating from 9060 to 9080 out of 10000 .
# Iterating from 9080 to 9100 out of 10000 .
# Iterating from 9100 to 9120 out of 10000 .
# Iterating from 9120 to 9140 out of 10000 .
# Iterating from 9140 to 9160 out of 10000 .
# Iterating from 9160 to 9180 out of 10000 .
# Iterating from 9180 to 9200 out of 10000 .
# Iterating from 9200 to 9220 out of 10000 .
# Iterating from 9220 to 9240 out of 10000 .
# Iterating from 9240 to 9260 out of 10000 .
# Iterating from 9260 to 9280 out of 10000 .
# Iterating from 9280 to 9300 out of 10000 .
# Iterating from 9300 to 9320 out of 10000 .
# Iterating from 9320 to 9340 out of 10000 .
# Iterating from 9340 to 9360 out of 10000 .
# Iterating from 9360 to 9380 out of 10000 .
# Iterating from 9380 to 9400 out of 10000 .
# Iterating from 9400 to 9420 out of 10000 .
# Iterating from 9420 to 9440 out of 10000 .
# Iterating from 9440 to 9460 out of 10000 .
# Iterating from 9460 to 9480 out of 10000 .
# Iterating from 9480 to 9500 out of 10000 .
# Iterating from 9500 to 9520 out of 10000 .
# Iterating from 9520 to 9540 out of 10000 .
# Iterating from 9540 to 9560 out of 10000 .
# Iterating from 9560 to 9580 out of 10000 .
# Iterating from 9580 to 9600 out of 10000 .
# Iterating from 9600 to 9620 out of 10000 .
# Iterating from 9620 to 9640 out of 10000 .
# Iterating from 9640 to 9660 out of 10000 .
# Iterating from 9660 to 9680 out of 10000 .
# Iterating from 9680 to 9700 out of 10000 .
# Iterating from 9700 to 9720 out of 10000 .
# Iterating from 9720 to 9740 out of 10000 .
# Iterating from 9740 to 9760 out of 10000 .
# Iterating from 9760 to 9780 out of 10000 .
# Iterating from 9780 to 9800 out of 10000 .
# Iterating from 9800 to 9820 out of 10000 .
# Iterating from 9820 to 9840 out of 10000 .
# Iterating from 9840 to 9860 out of 10000 .
# Iterating from 9860 to 9880 out of 10000 .
# Iterating from 9880 to 9900 out of 10000 .
# Iterating from 9900 to 9920 out of 10000 .
# Iterating from 9920 to 9940 out of 10000 .
# Iterating from 9940 to 9960 out of 10000 .
# Iterating from 9960 to 9980 out of 10000 .
# Iterating from 9980 to 10000 out of 10000 .
# LR metric calculation completed in 138.01947120402474 seconds.
# Saving lr to results/100D_unimodal/100D_50K/null_hypothesis/LR_off_0.012500.json
# ThresholdS: [[0.95, [9500, 500], -116211.05892969506], [0.99, [9900, 100], -115809.49701101621]]
# Null distribution computed in 141.49489580304362 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 3.619418859947473 seconds.
# statistic = 150553.8223869474 - next threshold = -116211.05892969506 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 15.535434802659035
#
# ------------ 3 ------------
# eps = 0.00625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 500
# Iterating from 0 to 20 out of 10000 .
# Iterating from 20 to 40 out of 10000 .
# Iterating from 40 to 60 out of 10000 .
# Iterating from 60 to 80 out of 10000 .
# Iterating from 80 to 100 out of 10000 .
# Iterating from 100 to 120 out of 10000 .
# Iterating from 120 to 140 out of 10000 .
# Iterating from 140 to 160 out of 10000 .
# Iterating from 160 to 180 out of 10000 .
# Iterating from 180 to 200 out of 10000 .
# Iterating from 200 to 220 out of 10000 .
# Iterating from 220 to 240 out of 10000 .
# Iterating from 240 to 260 out of 10000 .
# Iterating from 260 to 280 out of 10000 .
# Iterating from 280 to 300 out of 10000 .
# Iterating from 300 to 320 out of 10000 .
# Iterating from 320 to 340 out of 10000 .
# Iterating from 340 to 360 out of 10000 .
# Iterating from 360 to 380 out of 10000 .
# Iterating from 380 to 400 out of 10000 .
# Iterating from 400 to 420 out of 10000 .
# Iterating from 420 to 440 out of 10000 .
# Iterating from 440 to 460 out of 10000 .
# Iterating from 460 to 480 out of 10000 .
# Iterating from 480 to 500 out of 10000 .
# Iterating from 500 to 520 out of 10000 .
# ...
# Iterating from 3920 to 3940 out of 10000 .
# Iterating from 3940 to 3960 out of 10000 .
# Iterating from 3960 to 3980 out of 10000 .
# Iterating from 3980 to 4000 out of 10000 .
# Iterating from 4000 to 4020 out of 10000 .
# Iterating from 4020 to 4040 out of 10000 .
# Iterating from 4040 to 4060 out of 10000 .
# Iterating from 4060 to 4080 out of 10000 .
# Iterating from 4080 to 4100 out of 10000 .
# Iterating from 4100 to 4120 out of 10000 .
# Iterating from 4120 to 4140 out of 10000 .
# Iterating from 4140 to 4160 out of 10000 .
# Iterating from 4160 to 4180 out of 10000 .
# Iterating from 4180 to 4200 out of 10000 .
# Iterating from 4200 to 4220 out of 10000 .
# Iterating from 4220 to 4240 out of 10000 .
# Iterating from 4240 to 4260 out of 10000 .
# Iterating from 4260 to 4280 out of 10000 .
# Iterating from 4280 to 4300 out of 10000 .
# Iterating from 4300 to 4320 out of 10000 .
# Iterating from 4320 to 4340 out of 10000 .
# Iterating from 4340 to 4360 out of 10000 .
# Iterating from 4360 to 4380 out of 10000 .
# Iterating from 4380 to 4400 out of 10000 .
# Iterating from 4400 to 4420 out of 10000 .
# Iterating from 4420 to 4440 out of 10000 .
# Iterating from 4440 to 4460 out of 10000 .
# Iterating from 4460 to 4480 out of 10000 .
# Iterating from 4480 to 4500 out of 10000 .
# Iterating from 4500 to 4520 out of 10000 .
# Iterating from 4520 to 4540 out of 10000 .
# Iterating from 4540 to 4560 out of 10000 .
# Iterating from 4560 to 4580 out of 10000 .
# Iterating from 4580 to 4600 out of 10000 .
# Iterating from 4600 to 4620 out of 10000 .
# Iterating from 4620 to 4640 out of 10000 .
# Iterating from 4640 to 4660 out of 10000 .
# Iterating from 4660 to 4680 out of 10000 .
# Iterating from 4680 to 4700 out of 10000 .
# Iterating from 4700 to 4720 out of 10000 .
# Iterating from 4720 to 4740 out of 10000 .
# Iterating from 4740 to 4760 out of 10000 .
# Iterating from 4760 to 4780 out of 10000 .
# Iterating from 4780 to 4800 out of 10000 .
# Iterating from 4800 to 4820 out of 10000 .
# Iterating from 4820 to 4840 out of 10000 .
# Iterating from 4840 to 4860 out of 10000 .
# Iterating from 4860 to 4880 out of 10000 .
# Iterating from 4880 to 4900 out of 10000 .
# Iterating from 4900 to 4920 out of 10000 .
# Iterating from 4920 to 4940 out of 10000 .
# Iterating from 4940 to 4960 out of 10000 .
# Iterating from 4960 to 4980 out of 10000 .
# Iterating from 4980 to 5000 out of 10000 .
# Iterating from 5000 to 5020 out of 10000 .
# Iterating from 5020 to 5040 out of 10000 .
# Iterating from 5040 to 5060 out of 10000 .
# Iterating from 5060 to 5080 out of 10000 .
# Iterating from 5080 to 5100 out of 10000 .
# Iterating from 5100 to 5120 out of 10000 .
# Iterating from 5120 to 5140 out of 10000 .
# Iterating from 5140 to 5160 out of 10000 .
# Iterating from 5160 to 5180 out of 10000 .
# Iterating from 5180 to 5200 out of 10000 .
# Iterating from 5200 to 5220 out of 10000 .
# Iterating from 5220 to 5240 out of 10000 .
# Iterating from 5240 to 5260 out of 10000 .
# Iterating from 5260 to 5280 out of 10000 .
# Iterating from 5280 to 5300 out of 10000 .
# Iterating from 5300 to 5320 out of 10000 .
# Iterating from 5320 to 5340 out of 10000 .
# Iterating from 5340 to 5360 out of 10000 .
# Iterating from 5360 to 5380 out of 10000 .
# Iterating from 5380 to 5400 out of 10000 .
# Iterating from 5400 to 5420 out of 10000 .
# Iterating from 5420 to 5440 out of 10000 .
# Iterating from 5440 to 5460 out of 10000 .
# Iterating from 5460 to 5480 out of 10000 .
# Iterating from 5480 to 5500 out of 10000 .
# Iterating from 5500 to 5520 out of 10000 .
# Iterating from 5520 to 5540 out of 10000 .
# Iterating from 5540 to 5560 out of 10000 .
# Iterating from 5560 to 5580 out of 10000 .
# Iterating from 5580 to 5600 out of 10000 .
# Iterating from 5600 to 5620 out of 10000 .
# Iterating from 5620 to 5640 out of 10000 .
# Iterating from 5640 to 5660 out of 10000 .
# Iterating from 5660 to 5680 out of 10000 .
# Iterating from 5680 to 5700 out of 10000 .
# Iterating from 5700 to 5720 out of 10000 .
# Iterating from 5720 to 5740 out of 10000 .
# Iterating from 5740 to 5760 out of 10000 .
# Iterating from 5760 to 5780 out of 10000 .
# Iterating from 5780 to 5800 out of 10000 .
# Iterating from 5800 to 5820 out of 10000 .
# Iterating from 5820 to 5840 out of 10000 .
# Iterating from 5840 to 5860 out of 10000 .
# Iterating from 5860 to 5880 out of 10000 .
# Iterating from 5880 to 5900 out of 10000 .
# Iterating from 5900 to 5920 out of 10000 .
# Iterating from 5920 to 5940 out of 10000 .
# Iterating from 5940 to 5960 out of 10000 .
# Iterating from 5960 to 5980 out of 10000 .
# Iterating from 5980 to 6000 out of 10000 .
# Iterating from 6000 to 6020 out of 10000 .
# Iterating from 6020 to 6040 out of 10000 .
# Iterating from 6040 to 6060 out of 10000 .
# Iterating from 6060 to 6080 out of 10000 .
# Iterating from 6080 to 6100 out of 10000 .
# Iterating from 6100 to 6120 out of 10000 .
# Iterating from 6120 to 6140 out of 10000 .
# Iterating from 6140 to 6160 out of 10000 .
# Iterating from 6160 to 6180 out of 10000 .
# Iterating from 6180 to 6200 out of 10000 .
# Iterating from 6200 to 6220 out of 10000 .
# Iterating from 6220 to 6240 out of 10000 .
# Iterating from 6240 to 6260 out of 10000 .
# Iterating from 6260 to 6280 out of 10000 .
# Iterating from 6280 to 6300 out of 10000 .
# Iterating from 6300 to 6320 out of 10000 .
# Iterating from 6320 to 6340 out of 10000 .
# Iterating from 6340 to 6360 out of 10000 .
# Iterating from 6360 to 6380 out of 10000 .
# Iterating from 6380 to 6400 out of 10000 .
# Iterating from 6400 to 6420 out of 10000 .
# Iterating from 6420 to 6440 out of 10000 .
# Iterating from 6440 to 6460 out of 10000 .
# Iterating from 6460 to 6480 out of 10000 .
# Iterating from 6480 to 6500 out of 10000 .
# Iterating from 6500 to 6520 out of 10000 .
# Iterating from 6520 to 6540 out of 10000 .
# Iterating from 6540 to 6560 out of 10000 .
# Iterating from 6560 to 6580 out of 10000 .
# Iterating from 6580 to 6600 out of 10000 .
# Iterating from 6600 to 6620 out of 10000 .
# Iterating from 6620 to 6640 out of 10000 .
# Iterating from 6640 to 6660 out of 10000 .
# Iterating from 6660 to 6680 out of 10000 .
# Iterating from 6680 to 6700 out of 10000 .
# Iterating from 6700 to 6720 out of 10000 .
# Iterating from 6720 to 6740 out of 10000 .
# Iterating from 6740 to 6760 out of 10000 .
# Iterating from 6760 to 6780 out of 10000 .
# Iterating from 6780 to 6800 out of 10000 .
# Iterating from 6800 to 6820 out of 10000 .
# Iterating from 6820 to 6840 out of 10000 .
# Iterating from 6840 to 6860 out of 10000 .
# Iterating from 6860 to 6880 out of 10000 .
# Iterating from 6880 to 6900 out of 10000 .
# Iterating from 6900 to 6920 out of 10000 .
# Iterating from 6920 to 6940 out of 10000 .
# Iterating from 6940 to 6960 out of 10000 .
# Iterating from 6960 to 6980 out of 10000 .
# Iterating from 6980 to 7000 out of 10000 .
# Iterating from 7000 to 7020 out of 10000 .
# Iterating from 7020 to 7040 out of 10000 .
# Iterating from 7040 to 7060 out of 10000 .
# Iterating from 7060 to 7080 out of 10000 .
# Iterating from 7080 to 7100 out of 10000 .
# Iterating from 7100 to 7120 out of 10000 .
# Iterating from 7120 to 7140 out of 10000 .
# Iterating from 7140 to 7160 out of 10000 .
# Iterating from 7160 to 7180 out of 10000 .
# Iterating from 7180 to 7200 out of 10000 .
# Iterating from 7200 to 7220 out of 10000 .
# Iterating from 7220 to 7240 out of 10000 .
# Iterating from 7240 to 7260 out of 10000 .
# Iterating from 7260 to 7280 out of 10000 .
# Iterating from 7280 to 7300 out of 10000 .
# Iterating from 7300 to 7320 out of 10000 .
# Iterating from 7320 to 7340 out of 10000 .
# Iterating from 7340 to 7360 out of 10000 .
# Iterating from 7360 to 7380 out of 10000 .
# Iterating from 7380 to 7400 out of 10000 .
# Iterating from 7400 to 7420 out of 10000 .
# Iterating from 7420 to 7440 out of 10000 .
# Iterating from 7440 to 7460 out of 10000 .
# Iterating from 7460 to 7480 out of 10000 .
# Iterating from 7480 to 7500 out of 10000 .
# Iterating from 7500 to 7520 out of 10000 .
# Iterating from 7520 to 7540 out of 10000 .
# Iterating from 7540 to 7560 out of 10000 .
# Iterating from 7560 to 7580 out of 10000 .
# Iterating from 7580 to 7600 out of 10000 .
# Iterating from 7600 to 7620 out of 10000 .
# Iterating from 7620 to 7640 out of 10000 .
# Iterating from 7640 to 7660 out of 10000 .
# Iterating from 7660 to 7680 out of 10000 .
# Iterating from 7680 to 7700 out of 10000 .
# Iterating from 7700 to 7720 out of 10000 .
# Iterating from 7720 to 7740 out of 10000 .
# Iterating from 7740 to 7760 out of 10000 .
# Iterating from 7760 to 7780 out of 10000 .
# Iterating from 7780 to 7800 out of 10000 .
# Iterating from 7800 to 7820 out of 10000 .
# Iterating from 7820 to 7840 out of 10000 .
# Iterating from 7840 to 7860 out of 10000 .
# Iterating from 7860 to 7880 out of 10000 .
# Iterating from 7880 to 7900 out of 10000 .
# Iterating from 7900 to 7920 out of 10000 .
# Iterating from 7920 to 7940 out of 10000 .
# Iterating from 7940 to 7960 out of 10000 .
# Iterating from 7960 to 7980 out of 10000 .
# Iterating from 7980 to 8000 out of 10000 .
# Iterating from 8000 to 8020 out of 10000 .
# Iterating from 8020 to 8040 out of 10000 .
# Iterating from 8040 to 8060 out of 10000 .
# Iterating from 8060 to 8080 out of 10000 .
# Iterating from 8080 to 8100 out of 10000 .
# Iterating from 8100 to 8120 out of 10000 .
# Iterating from 8120 to 8140 out of 10000 .
# Iterating from 8140 to 8160 out of 10000 .
# Iterating from 8160 to 8180 out of 10000 .
# Iterating from 8180 to 8200 out of 10000 .
# Iterating from 8200 to 8220 out of 10000 .
# Iterating from 8220 to 8240 out of 10000 .
# Iterating from 8240 to 8260 out of 10000 .
# Iterating from 8260 to 8280 out of 10000 .
# Iterating from 8280 to 8300 out of 10000 .
# Iterating from 8300 to 8320 out of 10000 .
# Iterating from 8320 to 8340 out of 10000 .
# Iterating from 8340 to 8360 out of 10000 .
# Iterating from 8360 to 8380 out of 10000 .
# Iterating from 8380 to 8400 out of 10000 .
# Iterating from 8400 to 8420 out of 10000 .
# Iterating from 8420 to 8440 out of 10000 .
# Iterating from 8440 to 8460 out of 10000 .
# Iterating from 8460 to 8480 out of 10000 .
# Iterating from 8480 to 8500 out of 10000 .
# Iterating from 8500 to 8520 out of 10000 .
# Iterating from 8520 to 8540 out of 10000 .
# Iterating from 8540 to 8560 out of 10000 .
# Iterating from 8560 to 8580 out of 10000 .
# Iterating from 8580 to 8600 out of 10000 .
# Iterating from 8600 to 8620 out of 10000 .
# Iterating from 8620 to 8640 out of 10000 .
# Iterating from 8640 to 8660 out of 10000 .
# Iterating from 8660 to 8680 out of 10000 .
# Iterating from 8680 to 8700 out of 10000 .
# Iterating from 8700 to 8720 out of 10000 .
# Iterating from 8720 to 8740 out of 10000 .
# Iterating from 8740 to 8760 out of 10000 .
# Iterating from 8760 to 8780 out of 10000 .
# Iterating from 8780 to 8800 out of 10000 .
# Iterating from 8800 to 8820 out of 10000 .
# Iterating from 8820 to 8840 out of 10000 .
# Iterating from 8840 to 8860 out of 10000 .
# Iterating from 8860 to 8880 out of 10000 .
# Iterating from 8880 to 8900 out of 10000 .
# Iterating from 8900 to 8920 out of 10000 .
# Iterating from 8920 to 8940 out of 10000 .
# Iterating from 8940 to 8960 out of 10000 .
# Iterating from 8960 to 8980 out of 10000 .
# Iterating from 8980 to 9000 out of 10000 .
# Iterating from 9000 to 9020 out of 10000 .
# Iterating from 9020 to 9040 out of 10000 .
# Iterating from 9040 to 9060 out of 10000 .
# Iterating from 9060 to 9080 out of 10000 .
# Iterating from 9080 to 9100 out of 10000 .
# Iterating from 9100 to 9120 out of 10000 .
# Iterating from 9120 to 9140 out of 10000 .
# Iterating from 9140 to 9160 out of 10000 .
# Iterating from 9160 to 9180 out of 10000 .
# Iterating from 9180 to 9200 out of 10000 .
# Iterating from 9200 to 9220 out of 10000 .
# Iterating from 9220 to 9240 out of 10000 .
# Iterating from 9240 to 9260 out of 10000 .
# Iterating from 9260 to 9280 out of 10000 .
# Iterating from 9280 to 9300 out of 10000 .
# Iterating from 9300 to 9320 out of 10000 .
# Iterating from 9320 to 9340 out of 10000 .
# Iterating from 9340 to 9360 out of 10000 .
# Iterating from 9360 to 9380 out of 10000 .
# Iterating from 9380 to 9400 out of 10000 .
# Iterating from 9400 to 9420 out of 10000 .
# Iterating from 9420 to 9440 out of 10000 .
# Iterating from 9440 to 9460 out of 10000 .
# Iterating from 9460 to 9480 out of 10000 .
# Iterating from 9480 to 9500 out of 10000 .
# Iterating from 9500 to 9520 out of 10000 .
# Iterating from 9520 to 9540 out of 10000 .
# Iterating from 9540 to 9560 out of 10000 .
# Iterating from 9560 to 9580 out of 10000 .
# Iterating from 9580 to 9600 out of 10000 .
# Iterating from 9600 to 9620 out of 10000 .
# Iterating from 9620 to 9640 out of 10000 .
# Iterating from 9640 to 9660 out of 10000 .
# Iterating from 9660 to 9680 out of 10000 .
# Iterating from 9680 to 9700 out of 10000 .
# Iterating from 9700 to 9720 out of 10000 .
# Iterating from 9720 to 9740 out of 10000 .
# Iterating from 9740 to 9760 out of 10000 .
# Iterating from 9760 to 9780 out of 10000 .
# Iterating from 9780 to 9800 out of 10000 .
# Iterating from 9800 to 9820 out of 10000 .
# Iterating from 9820 to 9840 out of 10000 .
# Iterating from 9840 to 9860 out of 10000 .
# Iterating from 9860 to 9880 out of 10000 .
# Iterating from 9880 to 9900 out of 10000 .
# Iterating from 9900 to 9920 out of 10000 .
# Iterating from 9920 to 9940 out of 10000 .
# Iterating from 9940 to 9960 out of 10000 .
# Iterating from 9960 to 9980 out of 10000 .
# Iterating from 9980 to 10000 out of 10000 .
# LR metric calculation completed in 136.70607456495054 seconds.
# Saving lr to results/100D_unimodal/100D_50K/null_hypothesis/LR_mean_off_0.000061.json
# ThresholdS: [[0.95, [9500, 500], 1.2577567514493737], [0.99, [9900, 100], 4.10224210964017]]
# Null distribution computed in 139.73354939301498 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 3.509377836016938 seconds.
# statistic = 4.132039720770202 - next threshold = 4.10224210964017 at 0.99 CL
# relative_error_eps = 0.006295531889953975
# relative_error_metric = 0.007237452334940832
# =======> statistic within required accuracy at 0.99 CL in 2581.1355749249924 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 5165.9353812009795 seconds.
# Saving results in the file results/100D_unimodal/100D_50K/exclusion_limits.json
# Exclusion limits for LR with mean_cov deformation already loaded.
# dict_keys(['2024-04-16T21:36:16.879651', '2024-04-16T21:40:40.097447', '2024-04-23T14:58:19.831660', '2024-04-16T21:50:13.213619', '2024-04-16T21:53:41.276948', '2024-04-23T15:02:51.516138', '2024-04-16T22:03:09.168811', '2024-04-16T22:07:21.529808', '2024-04-16T22:13:17.802259', '2024-04-23T15:07:15.003304', '2024-04-16T22:26:46.803896', '2024-04-16T22:32:34.319867', '2024-04-23T15:14:09.955315', '2024-04-16T22:46:03.854989', '2024-04-16T22:52:08.095597', '2024-04-16T23:05:29.000910', '2024-04-23T15:21:16.034468', '2024-04-16T23:20:58.173784', '2024-04-16T23:28:56.002395', '2024-04-23T15:30:21.444026', '2024-04-16T23:55:20.766686', '2024-04-17T00:07:42.802121', '2024-04-17T00:12:45.450372', '2024-04-23T15:43:19.924074', '2024-04-17T00:22:35.355951', '2024-04-17T00:27:35.814251', '2024-04-23T15:47:27.617034', '2024-04-17T00:38:06.835167', '2024-04-17T00:43:21.618305', '2024-04-17T00:52:22.225988', '2024-04-23T15:52:54.696489', '2024-04-17T01:10:56.319928', '2024-04-17T01:19:47.624705', '2024-04-23T16:01:45.310250', '2024-04-17T01:38:49.630112', '2024-04-17T01:48:10.467436', '2024-04-17T01:55:10.180350', '2024-04-23T16:11:19.356839', '2024-04-17T02:09:21.500802', '2024-04-17T02:16:22.766793', '2024-04-23T16:18:20.027694', '2024-04-17T02:30:51.679584', '2024-04-17T02:38:05.993382', '2024-04-17T03:45:39.369753', '2024-04-23T16:25:33.425399', '2024-04-17T06:50:42.660825', '2024-04-17T07:53:23.848164', '2024-04-23T17:57:09.736300', '2024-04-17T11:01:57.663086'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_std = results_df[results_df["Deformation"] == "std"]
results_df_off = results_df[results_df["Deformation"] == "off"]
results_df_cov = results_df[results_df["Deformation"] == "cov"]
results_df_mean_std = results_df[results_df["Deformation"] == "mean_std"]
results_df_mean_off = results_df[results_df["Deformation"] == "mean_off"]
results_df_mean_cov = results_df[results_df["Deformation"] == "mean_cov"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 42        lr        mean  100  10000                50000
# 35       swd        mean  100  10000                50000
# 28       sks        mean  100  10000                50000
# 21        ks        mean  100  10000                50000
# 7        fpd        mean  100  10000                50000
# 0         fn        mean  100  10000                50000
# 14       kpd        mean  100  10000                50000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 42                             0.00044                             0.00068
# 35                             0.01063                             0.01411
# 28                             0.01121                             0.01450
# 21                             0.01149                             0.01516
# 7                              0.01245                             0.01650
# 0                              0.03672                             0.04567
# 14                             0.73929                             0.74981
#
#     $t^{\mu}$ (s)
# 42           4053
# 35            419
# 28            540
# 21            302
# 7             356
# 0             263
# 14            800
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 42        lr                             0.00044
# 35       swd                             0.01063
# 28       sks                             0.01121
# 21        ks                             0.01149
# 7        fpd                             0.01245
# 0         fn                             0.03672
# 14       kpd                             0.73929
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 42                             0.00068           4053
# 35                             0.01411            419
# 28                             0.01450            540
# 21                             0.01516            302
# 7                              0.01650            356
# 0                              0.04567            263
# 14                             0.74981            800

# %%
sorted_df_std = results_df_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma}$ (s)"}, inplace=True)
display(sorted_df_std)
sorted_df_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 43        lr         std  100  10000                50000
# 8        fpd         std  100  10000                50000
# 1         fn         std  100  10000                50000
# 36       swd         std  100  10000                50000
# 29       sks         std  100  10000                50000
# 22        ks         std  100  10000                50000
# 15       kpd         std  100  10000                50000
#
#     $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 43                                0.00004
# 8                                 0.00323
# 1                                 0.01111
# 36                                0.01140
# 29                                0.01273
# 22                                0.01845
# 15                               21.77734
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 43                                0.00006              5479
# 8                                 0.00401               398
# 1                                 0.01383               270
# 36                                0.01507               421
# 29                                0.01669               550
# 22                                0.02408               292
# 15                               21.97027               475
#    Statistic  $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 43        lr                                0.00004
# 8        fpd                                0.00323
# 1         fn                                0.01111
# 36       swd                                0.01140
# 29       sks                                0.01273
# 22        ks                                0.01845
# 15       kpd                               21.77734
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 43                                0.00006              5479
# 8                                 0.00401               398
# 1                                 0.01383               270
# 36                                0.01507               421
# 29                                0.01669               550
# 22                                0.02408               292
# 15                               21.97027               475

# %%
sorted_df_off = results_df_off.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_off.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}-\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}-\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ij}-\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_off)
sorted_df_off.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_off)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 44        lr         off  100  10000                50000
# 9        fpd         off  100  10000                50000
# 2         fn         off  100  10000                50000
# 37       swd         off  100  10000                50000
# 30       sks         off  100  10000                50000
# 23        ks         off  100  10000                50000
# 16       kpd         off  100  10000                50000
#
#     $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 44                                            0.00004
# 9                                             0.00333
# 2                                             0.01101
# 37                                            0.02527
# 30                                            0.02699
# 23                                            1.01624
# 16                                           22.66846
#
#     $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 44                                            0.00006
# 9                                             0.00410
# 2                                             0.01364
# 37                                            0.03452
# 30                                            0.03623
# 23                                            1.02446
# 16                                           22.96206
#
#     $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 44                               5496
# 9                                 414
# 2                                 271
# 37                                420
# 30                                530
# 23                                247
# 16                                545
#    Statistic  $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 44        lr                                            0.00004
# 9        fpd                                            0.00333
# 2         fn                                            0.01101
# 37       swd                                            0.02527
# 30       sks                                            0.02699
# 23        ks                                            1.01624
# 16       kpd                                           22.66846
#
#     $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 44                                            0.00006
# 9                                             0.00410
# 2                                             0.01364
# 37                                            0.03452
# 30                                            0.03623
# 23                                            1.02446
# 16                                           22.96206
#
#     $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 44                               5496
# 9                                 414
# 2                                 271
# 37                                420
# 30                                530
# 23                                247
# 16                                545

# %%
sorted_df_cov = results_df_cov.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ij}}$ (s)"}, inplace=True)
display(sorted_df_cov)
sorted_df_cov.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 45        lr         cov  100  10000                50000
# 38       swd         cov  100  10000                50000
# 10       fpd         cov  100  10000                50000
# 31       sks         cov  100  10000                50000
# 24        ks         cov  100  10000                50000
# 3         fn         cov  100  10000                50000
# 17       kpd         cov  100  10000                50000
#
#     $\epsilon^{\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 45                                     0.00089
# 38                                     0.01435
# 10                                     0.01473
# 31                                     0.01798
# 24                                     0.01826
# 3                                      0.41351
# 17                                    21.92383
#
#     $\epsilon^{\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ij}}$ (s)
# 45                                     0.00133                   3761
# 38                                     0.01869                    421
# 10                                     0.01941                    347
# 31                                     0.02303                    531
# 24                                     0.02389                    300
# 3                                      0.48161                    208
# 17                                    22.19801                    477
#    Statistic  $\epsilon^{\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 45        lr                                     0.00089
# 38       swd                                     0.01435
# 10       fpd                                     0.01473
# 31       sks                                     0.01798
# 24        ks                                     0.01826
# 3         fn                                     0.41351
# 17       kpd                                    21.92383
#
#     $\epsilon^{\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ij}}$ (s)
# 45                                     0.00133                   3761
# 38                                     0.01869                    421
# 10                                     0.01941                    347
# 31                                     0.02303                    531
# 24                                     0.02389                    300
# 3                                      0.48161                    208
# 17                                    22.19801                    477

# %%
sorted_df_mean_std = results_df_mean_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\sigma}$ (s)"}, inplace=True)
display(sorted_df_mean_std)
sorted_df_mean_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 46        lr    mean_std  100  10000                50000
# 11       fpd    mean_std  100  10000                50000
# 39       swd    mean_std  100  10000                50000
# 32       sks    mean_std  100  10000                50000
# 25        ks    mean_std  100  10000                50000
# 4         fn    mean_std  100  10000                50000
# 18       kpd    mean_std  100  10000                50000
#
#     $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 46                                    0.00004
# 11                                    0.00311
# 39                                    0.00765
# 32                                    0.00808
# 25                                    0.00947
# 4                                     0.01063
# 18                                    0.75150
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 46                                    0.00006                  5248
# 11                                    0.00384                   395
# 39                                    0.01018                   422
# 32                                    0.01042                   563
# 25                                    0.01237                   319
# 4                                     0.01316                   279
# 18                                    0.76202                   782
#    Statistic  $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 46        lr                                    0.00004
# 11       fpd                                    0.00311
# 39       swd                                    0.00765
# 32       sks                                    0.00808
# 25        ks                                    0.00947
# 4         fn                                    0.01063
# 18       kpd                                    0.75150
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 46                                    0.00006                  5248
# 11                                    0.00384                   395
# 39                                    0.01018                   422
# 32                                    0.01042                   563
# 25                                    0.01237                   319
# 4                                     0.01316                   279
# 18                                    0.76202                   782

# %%
sorted_df_mean_off = results_df_mean_off.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean_off.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_mean_off)
sorted_df_mean_off.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean_off)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 47        lr    mean_off  100  10000                50000
# 12       fpd    mean_off  100  10000                50000
# 40       swd    mean_off  100  10000                50000
# 33       sks    mean_off  100  10000                50000
# 5         fn    mean_off  100  10000                50000
# 26        ks    mean_off  100  10000                50000
# 19       kpd    mean_off  100  10000                50000
#
#     $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 47                                            0.00004
# 12                                            0.00321
# 40                                            0.00958
# 33                                            0.00997
# 5                                             0.01054
# 26                                            0.01168
# 19                                            0.76675
#
#     $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 47                                            0.00006
# 12                                            0.00393
# 40                                            0.01278
# 33                                            0.01287
# 5                                             0.01297
# 26                                            0.01535
# 19                                            0.77727
#
#     $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 47                                   5165
# 12                                    426
# 40                                    433
# 33                                    574
# 5                                     263
# 26                                    327
# 19                                    778
#    Statistic  $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 47        lr                                            0.00004
# 12       fpd                                            0.00321
# 40       swd                                            0.00958
# 33       sks                                            0.00997
# 5         fn                                            0.01054
# 26        ks                                            0.01168
# 19       kpd                                            0.76675
#
#     $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 47                                            0.00006
# 12                                            0.00393
# 40                                            0.01278
# 33                                            0.01287
# 5                                             0.01297
# 26                                            0.01535
# 19                                            0.77727
#
#     $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 47                                   5165
# 12                                    426
# 40                                    433
# 33                                    574
# 5                                     263
# 26                                    327
# 19                                    778

# %%
sorted_df_mean_cov = results_df_mean_cov.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean_cov.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\Sigma_{ij}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\Sigma_{ij}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\Sigma_{ij}}$ (s)"}, inplace=True)
display(sorted_df_mean_cov)
sorted_df_mean_cov.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean_cov)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 48        lr    mean_cov  100  10000                50000
# 41       swd    mean_cov  100  10000                50000
# 34       sks    mean_cov  100  10000                50000
# 27        ks    mean_cov  100  10000                50000
# 13       fpd    mean_cov  100  10000                50000
# 6         fn    mean_cov  100  10000                50000
# 20       kpd    mean_cov  100  10000                50000
#
#     $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 48                                         0.00037
# 41                                         0.00851
# 34                                         0.00927
# 27                                         0.00937
# 13                                         0.00942
# 6                                          0.03653
# 20                                         0.72174
#
#     $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\mu-\Sigma_{ij}}$ (s)
# 48                                         0.00059                       4112
# 41                                         0.01123                        434
# 34                                         0.01190                        560
# 27                                         0.01228                        314
# 13                                         0.01156                        364
# 6                                          0.04548                        252
# 20                                         0.73227                        742
#    Statistic  $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 48        lr                                         0.00037
# 41       swd                                         0.00851
# 34       sks                                         0.00927
# 27        ks                                         0.00937
# 13       fpd                                         0.00942
# 6         fn                                         0.03653
# 20       kpd                                         0.72174
#
#     $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\mu-\Sigma_{ij}}$ (s)
# 48                                         0.00059                       4112
# 41                                         0.01123                        434
# 34                                         0.01190                        560
# 27                                         0.01228                        314
# 13                                         0.01156                        364
# 6                                          0.04548                        252
# 20                                         0.73227                        742

# %%
result_table = sorted_df_mean.merge(sorted_df_std, on='Statistic', how='outer').merge(sorted_df_off, on='Statistic', how='outer').merge(sorted_df_cov, on='Statistic', how='outer').merge(sorted_df_mean_std, on='Statistic', how='outer').merge(sorted_df_mean_off, on='Statistic', how='outer').merge(sorted_df_mean_cov, on='Statistic', how='outer').merge(times_df, on='Statistic', how='outer')
result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fpd","$d_{\\mathrm{FPD}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("kpd","$d_{\\mathrm{KPD}}$")
display(result_table)
print(result_table.to_latex(index=False, column_format='l|llr|llr|llr|llr|llr|llr|llr|r', longtable=False, float_format="%.2g"))
# Out:
#                     Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 0  $\overline{\|\cdot\|}_{F}$                             0.03672
# 1          $d_{\mathrm{FPD}}$                             0.01245
# 2          $d_{\mathrm{KPD}}$                             0.73929
# 3              $\overline{D}$                             0.01149
# 4          $t_{\mathrm{LLR}}$                             0.00044
# 5             $\widetilde{D}$                             0.01121
# 6             $\widetilde{W}$                             0.01063
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)  \
# 0                             0.04567            263
# 1                             0.01650            356
# 2                             0.74981            800
# 3                             0.01516            302
# 4                             0.00068           4053
# 5                             0.01450            540
# 6                             0.01411            419
#
#    $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 0                                0.01111
# 1                                0.00323
# 2                               21.77734
# 3                                0.01845
# 4                                0.00004
# 5                                0.01273
# 6                                0.01140
#
#    $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)  \
# 0                                0.01383               270
# 1                                0.00401               398
# 2                               21.97027               475
# 3                                0.02408               292
# 4                                0.00006              5479
# 5                                0.01669               550
# 6                                0.01507               421
#
#    $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 0                                            0.00551
# 1                                            0.00165
# 2                                           21.58203
# 3                                            0.01855
# 4                                            0.00002
# 5                                            0.00927
# 6                                            0.00861
#
#    $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 0                                            0.00682
# 1                                            0.00204
# 2                                           21.97056
# 3                                            0.02417
# 4                                            0.00003
# 5                                            0.01228
# 6                                            0.01161
#
#    $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s)  ...  \
# 0                                303  ...
# 1                                410  ...
# 2                                454  ...
# 3                                297  ...
# 4                               5623  ...
# 5                                563  ...
# 6                                430  ...
#
#    $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 0                                    0.01063
# 1                                    0.00311
# 2                                    0.75150
# 3                                    0.00947
# 4                                    0.00004
# 5                                    0.00808
# 6                                    0.00765
#
#    $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)  \
# 0                                    0.01316                   279
# 1                                    0.00384                   395
# 2                                    0.76202                   782
# 3                                    0.01237                   319
# 4                                    0.00006                  5248
# 5                                    0.01042                   563
# 6                                    0.01018                   422
#
#    $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 0                                            0.00546
# 1                                            0.00163
# 2                                            0.76942
# 3                                            0.00958
# 4                                            0.00002
# 5                                            0.00679
# 6                                            0.00656
#
#    $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 0                                            0.00672
# 1                                            0.00201
# 2                                            0.77994
# 3                                            0.01249
# 4                                            0.00003
# 5                                            0.00882
# 6                                            0.00873
#
#    $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s)  \
# 0                                    288
# 1                                    414
# 2                                    802
# 3                                    311
# 4                                   5243
# 5                                    578
# 6                                    446
#
#    $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 0                                         0.03653
# 1                                         0.00942
# 2                                         0.72174
# 3                                         0.00937
# 4                                         0.00037
# 5                                         0.00927
# 6                                         0.00851
#
#    $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\mu-\Sigma_{ij}}$ (s)  \
# 0                                         0.04548                        252
# 1                                         0.01156                        364
# 2                                         0.73227                        742
# 3                                         0.01228                        314
# 4                                         0.00059                       4112
# 5                                         0.01190                        560
# 6                                         0.01123                        434
#
#    $t^{\mathrm{null}}$ (s)
# 0                       34
# 1                     1475
# 2                    22379
# 3                      599
# 4                        -
# 5                     4655
# 6                     2954
#
# [7 rows x 23 columns]
# \begin{tabular}{l|llr|llr|llr|llr|llr|llr|llr|r}
# \toprule
# Statistic & $\epsilon^{\mu}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu}_{99\%\mathrm{CL}}$ & $t^{\mu}$ (s) & $\epsilon^{\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\sigma}_{99\%\mathrm{CL}}$ & $t^{\sigma}$ (s) & $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$ & $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$ & $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s) & $\epsilon^{\Sigma_{ij}}_{95\%\mathrm{CL}}$ & $\epsilon^{\Sigma_{ij}}_{99\%\mathrm{CL}}$ & $t^{\Sigma_{ij}}$ (s) & $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$ & $t^{\mu-\sigma}$ (s) & $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$ & $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s) & $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$ & $t^{\mu-\Sigma_{ij}}$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $\overline{\|\cdot\|}_{F}$ & 0.037 & 0.046 & 263 & 0.011 & 0.014 & 270 & 0.0055 & 0.0068 & 303 & 0.41 & 0.48 & 208 & 0.011 & 0.013 & 279 & 0.0055 & 0.0067 & 288 & 0.037 & 0.045 & 252 & 34 \\
# $d_{\mathrm{FPD}}$ & 0.012 & 0.017 & 356 & 0.0032 & 0.004 & 398 & 0.0016 & 0.002 & 410 & 0.015 & 0.019 & 347 & 0.0031 & 0.0038 & 395 & 0.0016 & 0.002 & 414 & 0.0094 & 0.012 & 364 & 1475 \\
# $d_{\mathrm{KPD}}$ & 0.74 & 0.75 & 800 & 22 & 22 & 475 & 22 & 22 & 454 & 22 & 22 & 477 & 0.75 & 0.76 & 782 & 0.77 & 0.78 & 802 & 0.72 & 0.73 & 742 & 22379 \\
# $\overline{D}$ & 0.011 & 0.015 & 302 & 0.018 & 0.024 & 292 & 0.019 & 0.024 & 297 & 0.018 & 0.024 & 300 & 0.0095 & 0.012 & 319 & 0.0096 & 0.012 & 311 & 0.0094 & 0.012 & 314 & 599 \\
# $t_{\mathrm{LLR}}$ & 0.00044 & 0.00068 & 4053 & 4e-05 & 6e-05 & 5479 & 2e-05 & 3e-05 & 5623 & 0.00089 & 0.0013 & 3761 & 4e-05 & 6e-05 & 5248 & 2e-05 & 3e-05 & 5243 & 0.00037 & 0.00059 & 4112 & - \\
# $\widetilde{D}$ & 0.011 & 0.015 & 540 & 0.013 & 0.017 & 550 & 0.0093 & 0.012 & 563 & 0.018 & 0.023 & 531 & 0.0081 & 0.01 & 563 & 0.0068 & 0.0088 & 578 & 0.0093 & 0.012 & 560 & 4655 \\
# $\widetilde{W}$ & 0.011 & 0.014 & 419 & 0.011 & 0.015 & 421 & 0.0086 & 0.012 & 430 & 0.014 & 0.019 & 421 & 0.0076 & 0.01 & 422 & 0.0066 & 0.0087 & 446 & 0.0085 & 0.011 & 434 & 2954 \\
# \bottomrule
# \end{tabular}
