# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [3]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/20D_mixture/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-02 19:12:27.477962: Importing os...
# 2024-05-02 19:12:27.478435: Importing sys...
# Visible devices: [3]
# 2024-05-02 19:12:27.478884: Importing timer from timeit...
# 2024-05-02 19:12:27.478989: Setting env variables for tf import (only device(s) [3] will be available)...
# 2024-05-02 19:12:27.479186: Importing numpy...
# 2024-05-02 19:12:27.680545: Importing matplotlib...
# 2024-05-02 19:12:28.383673: Importing h5py...
# 2024-05-02 19:12:28.435327: Importing importlib.util...
# 2024-05-02 19:12:28.435586: Importing json...
# 2024-05-02 19:12:28.435688: Importing pandas...
# 2024-05-02 19:12:29.444446: Importing random...
# 2024-05-02 19:12:29.444885: Importing scipy utils...
# 2024-05-02 19:12:30.197393: Importing subprocess...
# 2024-05-02 19:12:30.197662: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-02 19:12:37.130233: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-02 19:12:39.079093: Importing timeit...
# 2024-05-02 19:12:39.079276: Importing tqdm...
# 2024-05-02 19:12:39.095754: Importing typing...
# 2024-05-02 19:12:39.095975: Setting tf configs...
# 2024-05-02 19:12:39.242111: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-02 19:12:47.524381: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #3, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-02 19:12:47.564628: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 10_000
dist_1 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
dist_2 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture.Mixture'> <class 'tensorflow_probability.python.distributions.mixture.Mixture'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)

# %% [markdown]
# # Fixed $n=100000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 100_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 1000000000
# batch_size 100000
# niter 10000
# niter * batch_size 1000000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000           100000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...       20           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims    nsamples  small_sample  \
# 0       True       20           0  float64    20  1000000000         False
#
#    ncomp
# 0      5
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/20D_mixture/20D_100K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/20D_mixture/20D_100K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 2000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/20D_mixture/20D_100K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/20D_mixture/20D_100K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/20D_mixture/20D_100K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/20D_mixture/20D_100K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 100
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714669976.518429 1167779 service.cc:145] XLA service 0xba2e04c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714669976.518540 1167779 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1714669976.760923 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1714669976.769755 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1714669976.774829 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1714669976.775423 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1714669976.776722 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1714669976.776996 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1714669976.777094 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1714669976.777170 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1714669976.777250 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1714669976.777341 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1714669976.777427 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1714669976.777515 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1714669976.777596 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_25/Assert/Assert
# W0000 00:00:1714669976.777676 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_27/Assert/Assert
# W0000 00:00:1714669976.777757 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_29/Assert/Assert
# W0000 00:00:1714669976.777838 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_31/Assert/Assert
# W0000 00:00:1714669976.777921 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_33/Assert/Assert
# W0000 00:00:1714669976.778000 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_35/Assert/Assert
# W0000 00:00:1714669976.778077 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_37/Assert/Assert
# W0000 00:00:1714669976.778161 1167779 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_39/Assert/Assert
# I0000 00:00:1714670033.013480 1167779 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# FGD metric calculation completed in 7356.78934881906 seconds.
# Saving fgd to results/20D_mixture/20D_100K/null_hypothesis/FGD.json
# Computing and savng mmd with max_vectorize = 1
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10000
# Iterating from 0 to 1 out of 10000 .
# Iterating from 1 to 2 out of 10000 .
# Iterating from 2 to 3 out of 10000 .
# Iterating from 3 to 4 out of 10000 .
# Iterating from 4 to 5 out of 10000 .
# Iterating from 5 to 6 out of 10000 .
# Iterating from 6 to 7 out of 10000 .
# Iterating from 7 to 8 out of 10000 .
# Iterating from 8 to 9 out of 10000 .
# Iterating from 9 to 10 out of 10000 .
# Iterating from 10 to 11 out of 10000 .
# Iterating from 11 to 12 out of 10000 .
# Iterating from 12 to 13 out of 10000 .
# Iterating from 13 to 14 out of 10000 .
# Iterating from 14 to 15 out of 10000 .
# Iterating from 15 to 16 out of 10000 .
# Iterating from 16 to 17 out of 10000 .
# Iterating from 17 to 18 out of 10000 .
# Iterating from 18 to 19 out of 10000 .
# Iterating from 19 to 20 out of 10000 .
# Iterating from 20 to 21 out of 10000 .
# Iterating from 21 to 22 out of 10000 .
# Iterating from 22 to 23 out of 10000 .
# Iterating from 23 to 24 out of 10000 .
# Iterating from 24 to 25 out of 10000 .
# Iterating from 25 to 26 out of 10000 .
# Iterating from 26 to 27 out of 10000 .
# Iterating from 27 to 28 out of 10000 .
# Iterating from 28 to 29 out of 10000 .
# Iterating from 29 to 30 out of 10000 .
# Iterating from 30 to 31 out of 10000 .
# Iterating from 31 to 32 out of 10000 .
# Iterating from 32 to 33 out of 10000 .
# Iterating from 33 to 34 out of 10000 .
# Iterating from 34 to 35 out of 10000 .
# Iterating from 35 to 36 out of 10000 .
# Iterating from 36 to 37 out of 10000 .
# Iterating from 37 to 38 out of 10000 .
# Iterating from 38 to 39 out of 10000 .
# Iterating from 39 to 40 out of 10000 .
# Iterating from 40 to 41 out of 10000 .
# Iterating from 41 to 42 out of 10000 .
# Iterating from 42 to 43 out of 10000 .
# Iterating from 43 to 44 out of 10000 .
# Iterating from 44 to 45 out of 10000 .
# Iterating from 45 to 46 out of 10000 .
# Iterating from 46 to 47 out of 10000 .
# Iterating from 47 to 48 out of 10000 .
# Iterating from 48 to 49 out of 10000 .
# Iterating from 49 to 50 out of 10000 .
# Iterating from 50 to 51 out of 10000 .
# Iterating from 51 to 52 out of 10000 .
# Iterating from 52 to 53 out of 10000 .
# Iterating from 53 to 54 out of 10000 .
# Iterating from 54 to 55 out of 10000 .
# Iterating from 55 to 56 out of 10000 .
# Iterating from 56 to 57 out of 10000 .
# Iterating from 57 to 58 out of 10000 .
# Iterating from 58 to 59 out of 10000 .
# Iterating from 59 to 60 out of 10000 .
# Iterating from 60 to 61 out of 10000 .
# Iterating from 61 to 62 out of 10000 .
# Iterating from 62 to 63 out of 10000 .
# Iterating from 63 to 64 out of 10000 .
# Iterating from 64 to 65 out of 10000 .
# Iterating from 65 to 66 out of 10000 .
# Iterating from 66 to 67 out of 10000 .
# Iterating from 67 to 68 out of 10000 .
# Iterating from 68 to 69 out of 10000 .
# Iterating from 69 to 70 out of 10000 .
# Iterating from 70 to 71 out of 10000 .
# Iterating from 71 to 72 out of 10000 .
# Iterating from 72 to 73 out of 10000 .
# Iterating from 73 to 74 out of 10000 .
# Iterating from 74 to 75 out of 10000 .
# Iterating from 75 to 76 out of 10000 .
# Iterating from 76 to 77 out of 10000 .
# Iterating from 77 to 78 out of 10000 .
# Iterating from 78 to 79 out of 10000 .
# Iterating from 79 to 80 out of 10000 .
# Iterating from 80 to 81 out of 10000 .
# Iterating from 81 to 82 out of 10000 .
# Iterating from 82 to 83 out of 10000 .
# Iterating from 83 to 84 out of 10000 .
# Iterating from 84 to 85 out of 10000 .
# Iterating from 85 to 86 out of 10000 .
# Iterating from 86 to 87 out of 10000 .
# Iterating from 87 to 88 out of 10000 .
# Iterating from 88 to 89 out of 10000 .
# Iterating from 89 to 90 out of 10000 .
# Iterating from 90 to 91 out of 10000 .
# Iterating from 91 to 92 out of 10000 .
# Iterating from 92 to 93 out of 10000 .
# Iterating from 93 to 94 out of 10000 .
# Iterating from 94 to 95 out of 10000 .
# Iterating from 95 to 96 out of 10000 .
# Iterating from 96 to 97 out of 10000 .
# Iterating from 97 to 98 out of 10000 .
# Iterating from 98 to 99 out of 10000 .
# Iterating from 99 to 100 out of 10000 .
# Iterating from 100 to 101 out of 10000 .
# Iterating from 101 to 102 out of 10000 .
# Iterating from 102 to 103 out of 10000 .
# Iterating from 103 to 104 out of 10000 .
# Iterating from 104 to 105 out of 10000 .
# Iterating from 105 to 106 out of 10000 .
# Iterating from 106 to 107 out of 10000 .
# Iterating from 107 to 108 out of 10000 .
# Iterating from 108 to 109 out of 10000 .
# Iterating from 109 to 110 out of 10000 .
# Iterating from 110 to 111 out of 10000 .
# Iterating from 111 to 112 out of 10000 .
# Iterating from 112 to 113 out of 10000 .
# Iterating from 113 to 114 out of 10000 .
# Iterating from 114 to 115 out of 10000 .
# Iterating from 115 to 116 out of 10000 .
# Iterating from 116 to 117 out of 10000 .
# Iterating from 117 to 118 out of 10000 .
# Iterating from 118 to 119 out of 10000 .
# Iterating from 119 to 120 out of 10000 .
# Iterating from 120 to 121 out of 10000 .
# Iterating from 121 to 122 out of 10000 .
# Iterating from 122 to 123 out of 10000 .
# Iterating from 123 to 124 out of 10000 .
# Iterating from 124 to 125 out of 10000 .
# Iterating from 125 to 126 out of 10000 .
# Iterating from 126 to 127 out of 10000 .
# Iterating from 127 to 128 out of 10000 .
# Iterating from 128 to 129 out of 10000 .
# Iterating from 129 to 130 out of 10000 .
# Iterating from 130 to 131 out of 10000 .
# Iterating from 131 to 132 out of 10000 .
# Iterating from 132 to 133 out of 10000 .
# Iterating from 133 to 134 out of 10000 .
# Iterating from 134 to 135 out of 10000 .
# Iterating from 135 to 136 out of 10000 .
# Iterating from 136 to 137 out of 10000 .
# Iterating from 137 to 138 out of 10000 .
# Iterating from 138 to 139 out of 10000 .
# Iterating from 139 to 140 out of 10000 .
# Iterating from 140 to 141 out of 10000 .
# Iterating from 141 to 142 out of 10000 .
# Iterating from 142 to 143 out of 10000 .
# Iterating from 143 to 144 out of 10000 .
# Iterating from 144 to 145 out of 10000 .
# Iterating from 145 to 146 out of 10000 .
# Iterating from 146 to 147 out of 10000 .
# Iterating from 147 to 148 out of 10000 .
# Iterating from 148 to 149 out of 10000 .
# Iterating from 149 to 150 out of 10000 .
# Iterating from 150 to 151 out of 10000 .
# Iterating from 151 to 152 out of 10000 .
# Iterating from 152 to 153 out of 10000 .
# Iterating from 153 to 154 out of 10000 .
# Iterating from 154 to 155 out of 10000 .
# Iterating from 155 to 156 out of 10000 .
# Iterating from 156 to 157 out of 10000 .
# Iterating from 157 to 158 out of 10000 .
# Iterating from 158 to 159 out of 10000 .
# Iterating from 159 to 160 out of 10000 .
# Iterating from 160 to 161 out of 10000 .
# Iterating from 161 to 162 out of 10000 .
# Iterating from 162 to 163 out of 10000 .
# Iterating from 163 to 164 out of 10000 .
# Iterating from 164 to 165 out of 10000 .
# Iterating from 165 to 166 out of 10000 .
# Iterating from 166 to 167 out of 10000 .
# Iterating from 167 to 168 out of 10000 .
# Iterating from 168 to 169 out of 10000 .
# Iterating from 169 to 170 out of 10000 .
# Iterating from 170 to 171 out of 10000 .
# Iterating from 171 to 172 out of 10000 .
# Iterating from 172 to 173 out of 10000 .
# Iterating from 173 to 174 out of 10000 .
# Iterating from 174 to 175 out of 10000 .
# Iterating from 175 to 176 out of 10000 .
# Iterating from 176 to 177 out of 10000 .
# Iterating from 177 to 178 out of 10000 .
# Iterating from 178 to 179 out of 10000 .
# Iterating from 179 to 180 out of 10000 .
# Iterating from 180 to 181 out of 10000 .
# Iterating from 181 to 182 out of 10000 .
# Iterating from 182 to 183 out of 10000 .
# Iterating from 183 to 184 out of 10000 .
# Iterating from 184 to 185 out of 10000 .
# Iterating from 185 to 186 out of 10000 .
# Iterating from 186 to 187 out of 10000 .
# Iterating from 187 to 188 out of 10000 .
# Iterating from 188 to 189 out of 10000 .
# Iterating from 189 to 190 out of 10000 .
# Iterating from 190 to 191 out of 10000 .
# Iterating from 191 to 192 out of 10000 .
# Iterating from 192 to 193 out of 10000 .
# Iterating from 193 to 194 out of 10000 .
# Iterating from 194 to 195 out of 10000 .
# Iterating from 195 to 196 out of 10000 .
# Iterating from 196 to 197 out of 10000 .
# Iterating from 197 to 198 out of 10000 .
# Iterating from 198 to 199 out of 10000 .
# Iterating from 199 to 200 out of 10000 .
# Iterating from 200 to 201 out of 10000 .
# Iterating from 201 to 202 out of 10000 .
# Iterating from 202 to 203 out of 10000 .
# Iterating from 203 to 204 out of 10000 .
# Iterating from 204 to 205 out of 10000 .
# Iterating from 205 to 206 out of 10000 .
# Iterating from 206 to 207 out of 10000 .
# Iterating from 207 to 208 out of 10000 .
# Iterating from 208 to 209 out of 10000 .
# Iterating from 209 to 210 out of 10000 .
# Iterating from 210 to 211 out of 10000 .
# Iterating from 211 to 212 out of 10000 .
# Iterating from 212 to 213 out of 10000 .
# Iterating from 213 to 214 out of 10000 .
# Iterating from 214 to 215 out of 10000 .
# Iterating from 215 to 216 out of 10000 .
# Iterating from 216 to 217 out of 10000 .
# Iterating from 217 to 218 out of 10000 .
# Iterating from 218 to 219 out of 10000 .
# Iterating from 219 to 220 out of 10000 .
# Iterating from 220 to 221 out of 10000 .
# Iterating from 221 to 222 out of 10000 .
# Iterating from 222 to 223 out of 10000 .
# Iterating from 223 to 224 out of 10000 .
# Iterating from 224 to 225 out of 10000 .
# Iterating from 225 to 226 out of 10000 .
# Iterating from 226 to 227 out of 10000 .
# Iterating from 227 to 228 out of 10000 .
# Iterating from 228 to 229 out of 10000 .
# Iterating from 229 to 230 out of 10000 .
# Iterating from 230 to 231 out of 10000 .
# Iterating from 231 to 232 out of 10000 .
# Iterating from 232 to 233 out of 10000 .
# Iterating from 233 to 234 out of 10000 .
# Iterating from 234 to 235 out of 10000 .
# Iterating from 235 to 236 out of 10000 .
# Iterating from 236 to 237 out of 10000 .
# Iterating from 237 to 238 out of 10000 .
# Iterating from 238 to 239 out of 10000 .
# Iterating from 239 to 240 out of 10000 .
# Iterating from 240 to 241 out of 10000 .
# Iterating from 241 to 242 out of 10000 .
# Iterating from 242 to 243 out of 10000 .
# Iterating from 243 to 244 out of 10000 .
# Iterating from 244 to 245 out of 10000 .
# Iterating from 245 to 246 out of 10000 .
# Iterating from 246 to 247 out of 10000 .
# Iterating from 247 to 248 out of 10000 .
# Iterating from 248 to 249 out of 10000 .
# Iterating from 249 to 250 out of 10000 .
# Iterating from 250 to 251 out of 10000 .
# Iterating from 251 to 252 out of 10000 .
# Iterating from 252 to 253 out of 10000 .
# Iterating from 253 to 254 out of 10000 .
# Iterating from 254 to 255 out of 10000 .
# Iterating from 255 to 256 out of 10000 .
# Iterating from 256 to 257 out of 10000 .
# Iterating from 257 to 258 out of 10000 .
# Iterating from 258 to 259 out of 10000 .
# Iterating from 259 to 260 out of 10000 .
# Iterating from 260 to 261 out of 10000 .
# Iterating from 261 to 262 out of 10000 .
# Iterating from 262 to 263 out of 10000 .
# Iterating from 263 to 264 out of 10000 .
# Iterating from 264 to 265 out of 10000 .
# Iterating from 265 to 266 out of 10000 .
# Iterating from 266 to 267 out of 10000 .
# Iterating from 267 to 268 out of 10000 .
# Iterating from 268 to 269 out of 10000 .
# Iterating from 269 to 270 out of 10000 .
# Iterating from 270 to 271 out of 10000 .
# Iterating from 271 to 272 out of 10000 .
# Iterating from 272 to 273 out of 10000 .
# Iterating from 273 to 274 out of 10000 .
# Iterating from 274 to 275 out of 10000 .
# Iterating from 275 to 276 out of 10000 .
# Iterating from 276 to 277 out of 10000 .
# Iterating from 277 to 278 out of 10000 .
# Iterating from 278 to 279 out of 10000 .
# Iterating from 279 to 280 out of 10000 .
# Iterating from 280 to 281 out of 10000 .
# Iterating from 281 to 282 out of 10000 .
# Iterating from 282 to 283 out of 10000 .
# Iterating from 283 to 284 out of 10000 .
# Iterating from 284 to 285 out of 10000 .
# Iterating from 285 to 286 out of 10000 .
# Iterating from 286 to 287 out of 10000 .
# Iterating from 287 to 288 out of 10000 .
# Iterating from 288 to 289 out of 10000 .
# Iterating from 289 to 290 out of 10000 .
# Iterating from 290 to 291 out of 10000 .
# Iterating from 291 to 292 out of 10000 .
# Iterating from 292 to 293 out of 10000 .
# Iterating from 293 to 294 out of 10000 .
# Iterating from 294 to 295 out of 10000 .
# Iterating from 295 to 296 out of 10000 .
# Iterating from 296 to 297 out of 10000 .
# Iterating from 297 to 298 out of 10000 .
# Iterating from 298 to 299 out of 10000 .
# Iterating from 299 to 300 out of 10000 .
# Iterating from 300 to 301 out of 10000 .
# Iterating from 301 to 302 out of 10000 .
# Iterating from 302 to 303 out of 10000 .
# Iterating from 303 to 304 out of 10000 .
# Iterating from 304 to 305 out of 10000 .
# Iterating from 305 to 306 out of 10000 .
# Iterating from 306 to 307 out of 10000 .
# Iterating from 307 to 308 out of 10000 .
# Iterating from 308 to 309 out of 10000 .
# Iterating from 309 to 310 out of 10000 .
# Iterating from 310 to 311 out of 10000 .
# Iterating from 311 to 312 out of 10000 .
# Iterating from 312 to 313 out of 10000 .
# Iterating from 313 to 314 out of 10000 .
# Iterating from 314 to 315 out of 10000 .
# Iterating from 315 to 316 out of 10000 .
# Iterating from 316 to 317 out of 10000 .
# Iterating from 317 to 318 out of 10000 .
# Iterating from 318 to 319 out of 10000 .
# Iterating from 319 to 320 out of 10000 .
# Iterating from 320 to 321 out of 10000 .
# Iterating from 321 to 322 out of 10000 .
# Iterating from 322 to 323 out of 10000 .
# Iterating from 323 to 324 out of 10000 .
# Iterating from 324 to 325 out of 10000 .
# Iterating from 325 to 326 out of 10000 .
# Iterating from 326 to 327 out of 10000 .
# Iterating from 327 to 328 out of 10000 .
# Iterating from 328 to 329 out of 10000 .
# Iterating from 329 to 330 out of 10000 .
# Iterating from 330 to 331 out of 10000 .
# Iterating from 331 to 332 out of 10000 .
# Iterating from 332 to 333 out of 10000 .
# Iterating from 333 to 334 out of 10000 .
# Iterating from 334 to 335 out of 10000 .
# Iterating from 335 to 336 out of 10000 .
# Iterating from 336 to 337 out of 10000 .
# Iterating from 337 to 338 out of 10000 .
# Iterating from 338 to 339 out of 10000 .
# Iterating from 339 to 340 out of 10000 .
# Iterating from 340 to 341 out of 10000 .
# Iterating from 341 to 342 out of 10000 .
# Iterating from 342 to 343 out of 10000 .
# Iterating from 343 to 344 out of 10000 .
# Iterating from 344 to 345 out of 10000 .
# Iterating from 345 to 346 out of 10000 .
# Iterating from 346 to 347 out of 10000 .
# Iterating from 347 to 348 out of 10000 .
# Iterating from 348 to 349 out of 10000 .
# Iterating from 349 to 350 out of 10000 .
# Iterating from 350 to 351 out of 10000 .
# Iterating from 351 to 352 out of 10000 .
# Iterating from 352 to 353 out of 10000 .
# Iterating from 353 to 354 out of 10000 .
# Iterating from 354 to 355 out of 10000 .
# Iterating from 355 to 356 out of 10000 .
# Iterating from 356 to 357 out of 10000 .
# Iterating from 357 to 358 out of 10000 .
# Iterating from 358 to 359 out of 10000 .
# Iterating from 359 to 360 out of 10000 .
# Iterating from 360 to 361 out of 10000 .
# Iterating from 361 to 362 out of 10000 .
# Iterating from 362 to 363 out of 10000 .
# Iterating from 363 to 364 out of 10000 .
# Iterating from 364 to 365 out of 10000 .
# Iterating from 365 to 366 out of 10000 .
# Iterating from 366 to 367 out of 10000 .
# Iterating from 367 to 368 out of 10000 .
# Iterating from 368 to 369 out of 10000 .
# Iterating from 369 to 370 out of 10000 .
# Iterating from 370 to 371 out of 10000 .
# Iterating from 371 to 372 out of 10000 .
# Iterating from 372 to 373 out of 10000 .
# Iterating from 373 to 374 out of 10000 .
# Iterating from 374 to 375 out of 10000 .
# Iterating from 375 to 376 out of 10000 .
# Iterating from 376 to 377 out of 10000 .
# Iterating from 377 to 378 out of 10000 .
# Iterating from 378 to 379 out of 10000 .
# Iterating from 379 to 380 out of 10000 .
# Iterating from 380 to 381 out of 10000 .
# Iterating from 381 to 382 out of 10000 .
# Iterating from 382 to 383 out of 10000 .
# Iterating from 383 to 384 out of 10000 .
# Iterating from 384 to 385 out of 10000 .
# Iterating from 385 to 386 out of 10000 .
# Iterating from 386 to 387 out of 10000 .
# Iterating from 387 to 388 out of 10000 .
# Iterating from 388 to 389 out of 10000 .
# Iterating from 389 to 390 out of 10000 .
# Iterating from 390 to 391 out of 10000 .
# Iterating from 391 to 392 out of 10000 .
# Iterating from 392 to 393 out of 10000 .
# Iterating from 393 to 394 out of 10000 .
# Iterating from 394 to 395 out of 10000 .
# Iterating from 395 to 396 out of 10000 .
# Iterating from 396 to 397 out of 10000 .
# Iterating from 397 to 398 out of 10000 .
# Iterating from 398 to 399 out of 10000 .
# Iterating from 399 to 400 out of 10000 .
# Iterating from 400 to 401 out of 10000 .
# Iterating from 401 to 402 out of 10000 .
# Iterating from 402 to 403 out of 10000 .
# Iterating from 403 to 404 out of 10000 .
# Iterating from 404 to 405 out of 10000 .
# Iterating from 405 to 406 out of 10000 .
# Iterating from 406 to 407 out of 10000 .
# Iterating from 407 to 408 out of 10000 .
# Iterating from 408 to 409 out of 10000 .
# Iterating from 409 to 410 out of 10000 .
# Iterating from 410 to 411 out of 10000 .
# Iterating from 411 to 412 out of 10000 .
# Iterating from 412 to 413 out of 10000 .
# Iterating from 413 to 414 out of 10000 .
# Iterating from 414 to 415 out of 10000 .
# Iterating from 415 to 416 out of 10000 .
# Iterating from 416 to 417 out of 10000 .
# Iterating from 417 to 418 out of 10000 .
# Iterating from 418 to 419 out of 10000 .
# Iterating from 419 to 420 out of 10000 .
# Iterating from 420 to 421 out of 10000 .
# Iterating from 421 to 422 out of 10000 .
# Iterating from 422 to 423 out of 10000 .
# Iterating from 423 to 424 out of 10000 .
# Iterating from 424 to 425 out of 10000 .
# Iterating from 425 to 426 out of 10000 .
# Iterating from 426 to 427 out of 10000 .
# Iterating from 427 to 428 out of 10000 .
# Iterating from 428 to 429 out of 10000 .
# Iterating from 429 to 430 out of 10000 .
# Iterating from 430 to 431 out of 10000 .
# Iterating from 431 to 432 out of 10000 .
# Iterating from 432 to 433 out of 10000 .
# Iterating from 433 to 434 out of 10000 .
# Iterating from 434 to 435 out of 10000 .
# Iterating from 435 to 436 out of 10000 .
# Iterating from 436 to 437 out of 10000 .
# Iterating from 437 to 438 out of 10000 .
# Iterating from 438 to 439 out of 10000 .
# Iterating from 439 to 440 out of 10000 .
# Iterating from 440 to 441 out of 10000 .
# Iterating from 441 to 442 out of 10000 .
# Iterating from 442 to 443 out of 10000 .
# Iterating from 443 to 444 out of 10000 .
# Iterating from 444 to 445 out of 10000 .
# Iterating from 445 to 446 out of 10000 .
# Iterating from 446 to 447 out of 10000 .
# Iterating from 447 to 448 out of 10000 .
# Iterating from 448 to 449 out of 10000 .
# Iterating from 449 to 450 out of 10000 .
# Iterating from 450 to 451 out of 10000 .
# Iterating from 451 to 452 out of 10000 .
# Iterating from 452 to 453 out of 10000 .
# Iterating from 453 to 454 out of 10000 .
# Iterating from 454 to 455 out of 10000 .
# Iterating from 455 to 456 out of 10000 .
# Iterating from 456 to 457 out of 10000 .
# Iterating from 457 to 458 out of 10000 .
# Iterating from 458 to 459 out of 10000 .
# Iterating from 459 to 460 out of 10000 .
# Iterating from 460 to 461 out of 10000 .
# Iterating from 461 to 462 out of 10000 .
# Iterating from 462 to 463 out of 10000 .
# Iterating from 463 to 464 out of 10000 .
# Iterating from 464 to 465 out of 10000 .
# Iterating from 465 to 466 out of 10000 .
# Iterating from 466 to 467 out of 10000 .
# Iterating from 467 to 468 out of 10000 .
# Iterating from 468 to 469 out of 10000 .
# Iterating from 469 to 470 out of 10000 .
# Iterating from 470 to 471 out of 10000 .
# Iterating from 471 to 472 out of 10000 .
# Iterating from 472 to 473 out of 10000 .
# Iterating from 473 to 474 out of 10000 .
# Iterating from 474 to 475 out of 10000 .
# Iterating from 475 to 476 out of 10000 .
# Iterating from 476 to 477 out of 10000 .
# Iterating from 477 to 478 out of 10000 .
# Iterating from 478 to 479 out of 10000 .
# Iterating from 479 to 480 out of 10000 .
# Iterating from 480 to 481 out of 10000 .
# Iterating from 481 to 482 out of 10000 .
# Iterating from 482 to 483 out of 10000 .
# Iterating from 483 to 484 out of 10000 .
# Iterating from 484 to 485 out of 10000 .
# Iterating from 485 to 486 out of 10000 .
# Iterating from 486 to 487 out of 10000 .
# Iterating from 487 to 488 out of 10000 .
# Iterating from 488 to 489 out of 10000 .
# Iterating from 489 to 490 out of 10000 .
# Iterating from 490 to 491 out of 10000 .
# Iterating from 491 to 492 out of 10000 .
# Iterating from 492 to 493 out of 10000 .
# Iterating from 493 to 494 out of 10000 .
# Iterating from 494 to 495 out of 10000 .
# Iterating from 495 to 496 out of 10000 .
# Iterating from 496 to 497 out of 10000 .
# Iterating from 497 to 498 out of 10000 .
# Iterating from 498 to 499 out of 10000 .
# Iterating from 499 to 500 out of 10000 .
# Iterating from 500 to 501 out of 10000 .
# Iterating from 501 to 502 out of 10000 .
# Iterating from 502 to 503 out of 10000 .
# Iterating from 503 to 504 out of 10000 .
# Iterating from 504 to 505 out of 10000 .
# Iterating from 505 to 506 out of 10000 .
# Iterating from 506 to 507 out of 10000 .
# Iterating from 507 to 508 out of 10000 .
# Iterating from 508 to 509 out of 10000 .
# Iterating from 509 to 510 out of 10000 .
# Iterating from 510 to 511 out of 10000 .
# Iterating from 511 to 512 out of 10000 .
# Iterating from 512 to 513 out of 10000 .
# Iterating from 513 to 514 out of 10000 .
# Iterating from 514 to 515 out of 10000 .
# Iterating from 515 to 516 out of 10000 .
# Iterating from 516 to 517 out of 10000 .
# Iterating from 517 to 518 out of 10000 .
# Iterating from 518 to 519 out of 10000 .
# Iterating from 519 to 520 out of 10000 .
# Iterating from 520 to 521 out of 10000 .
# Iterating from 521 to 522 out of 10000 .
# Iterating from 522 to 523 out of 10000 .
# Iterating from 523 to 524 out of 10000 .
# Iterating from 524 to 525 out of 10000 .
# Iterating from 525 to 526 out of 10000 .
# Iterating from 526 to 527 out of 10000 .
# Iterating from 527 to 528 out of 10000 .
# Iterating from 528 to 529 out of 10000 .
# Iterating from 529 to 530 out of 10000 .
# Iterating from 530 to 531 out of 10000 .
# Iterating from 531 to 532 out of 10000 .
# Iterating from 532 to 533 out of 10000 .
# Iterating from 533 to 534 out of 10000 .
# Iterating from 534 to 535 out of 10000 .
# Iterating from 535 to 536 out of 10000 .
# Iterating from 536 to 537 out of 10000 .
# Iterating from 537 to 538 out of 10000 .
# Iterating from 538 to 539 out of 10000 .
# Iterating from 539 to 540 out of 10000 .
# Iterating from 540 to 541 out of 10000 .
# Iterating from 541 to 542 out of 10000 .
# Iterating from 542 to 543 out of 10000 .
# Iterating from 543 to 544 out of 10000 .
# Iterating from 544 to 545 out of 10000 .
# Iterating from 545 to 546 out of 10000 .
# Iterating from 546 to 547 out of 10000 .
# Iterating from 547 to 548 out of 10000 .
# Iterating from 548 to 549 out of 10000 .
# Iterating from 549 to 550 out of 10000 .
# Iterating from 550 to 551 out of 10000 .
# Iterating from 551 to 552 out of 10000 .
# Iterating from 552 to 553 out of 10000 .
# Iterating from 553 to 554 out of 10000 .
# Iterating from 554 to 555 out of 10000 .
# Iterating from 555 to 556 out of 10000 .
# Iterating from 556 to 557 out of 10000 .
# Iterating from 557 to 558 out of 10000 .
# Iterating from 558 to 559 out of 10000 .
# Iterating from 559 to 560 out of 10000 .
# Iterating from 560 to 561 out of 10000 .
# Iterating from 561 to 562 out of 10000 .
# Iterating from 562 to 563 out of 10000 .
# Iterating from 563 to 564 out of 10000 .
# Iterating from 564 to 565 out of 10000 .
# Iterating from 565 to 566 out of 10000 .
# Iterating from 566 to 567 out of 10000 .
# Iterating from 567 to 568 out of 10000 .
# Iterating from 568 to 569 out of 10000 .
# Iterating from 569 to 570 out of 10000 .
# Iterating from 570 to 571 out of 10000 .
# Iterating from 571 to 572 out of 10000 .
# Iterating from 572 to 573 out of 10000 .
# Iterating from 573 to 574 out of 10000 .
# Iterating from 574 to 575 out of 10000 .
# Iterating from 575 to 576 out of 10000 .
# Iterating from 576 to 577 out of 10000 .
# Iterating from 577 to 578 out of 10000 .
# Iterating from 578 to 579 out of 10000 .
# Iterating from 579 to 580 out of 10000 .
# Iterating from 580 to 581 out of 10000 .
# Iterating from 581 to 582 out of 10000 .
# Iterating from 582 to 583 out of 10000 .
# Iterating from 583 to 584 out of 10000 .
# Iterating from 584 to 585 out of 10000 .
# Iterating from 585 to 586 out of 10000 .
# Iterating from 586 to 587 out of 10000 .
# Iterating from 587 to 588 out of 10000 .
# Iterating from 588 to 589 out of 10000 .
# Iterating from 589 to 590 out of 10000 .
# Iterating from 590 to 591 out of 10000 .
# Iterating from 591 to 592 out of 10000 .
# Iterating from 592 to 593 out of 10000 .
# Iterating from 593 to 594 out of 10000 .
# Iterating from 594 to 595 out of 10000 .
# Iterating from 595 to 596 out of 10000 .
# Iterating from 596 to 597 out of 10000 .
# Iterating from 597 to 598 out of 10000 .
# Iterating from 598 to 599 out of 10000 .
# Iterating from 599 to 600 out of 10000 .
# Iterating from 600 to 601 out of 10000 .
# Iterating from 601 to 602 out of 10000 .
# Iterating from 602 to 603 out of 10000 .
# Iterating from 603 to 604 out of 10000 .
# Iterating from 604 to 605 out of 10000 .
# Iterating from 605 to 606 out of 10000 .
# Iterating from 606 to 607 out of 10000 .
# Iterating from 607 to 608 out of 10000 .
# Iterating from 608 to 609 out of 10000 .
# Iterating from 609 to 610 out of 10000 .
# Iterating from 610 to 611 out of 10000 .
# Iterating from 611 to 612 out of 10000 .
# Iterating from 612 to 613 out of 10000 .
# Iterating from 613 to 614 out of 10000 .
# Iterating from 614 to 615 out of 10000 .
# Iterating from 615 to 616 out of 10000 .
# Iterating from 616 to 617 out of 10000 .
# Iterating from 617 to 618 out of 10000 .
# Iterating from 618 to 619 out of 10000 .
# Iterating from 619 to 620 out of 10000 .
# Iterating from 620 to 621 out of 10000 .
# Iterating from 621 to 622 out of 10000 .
# Iterating from 622 to 623 out of 10000 .
# Iterating from 623 to 624 out of 10000 .
# Iterating from 624 to 625 out of 10000 .
# Iterating from 625 to 626 out of 10000 .
# Iterating from 626 to 627 out of 10000 .
# Iterating from 627 to 628 out of 10000 .
# Iterating from 628 to 629 out of 10000 .
# Iterating from 629 to 630 out of 10000 .
# Iterating from 630 to 631 out of 10000 .
# Iterating from 631 to 632 out of 10000 .
# Iterating from 632 to 633 out of 10000 .
# Iterating from 633 to 634 out of 10000 .
# Iterating from 634 to 635 out of 10000 .
# Iterating from 635 to 636 out of 10000 .
# Iterating from 636 to 637 out of 10000 .
# Iterating from 637 to 638 out of 10000 .
# Iterating from 638 to 639 out of 10000 .
# Iterating from 639 to 640 out of 10000 .
# Iterating from 640 to 641 out of 10000 .
# Iterating from 641 to 642 out of 10000 .
# Iterating from 642 to 643 out of 10000 .
# Iterating from 643 to 644 out of 10000 .
# Iterating from 644 to 645 out of 10000 .
# Iterating from 645 to 646 out of 10000 .
# Iterating from 646 to 647 out of 10000 .
# Iterating from 647 to 648 out of 10000 .
# Iterating from 648 to 649 out of 10000 .
# Iterating from 649 to 650 out of 10000 .
# Iterating from 650 to 651 out of 10000 .
# Iterating from 651 to 652 out of 10000 .
# Iterating from 652 to 653 out of 10000 .
# Iterating from 653 to 654 out of 10000 .
# Iterating from 654 to 655 out of 10000 .
# Iterating from 655 to 656 out of 10000 .
# Iterating from 656 to 657 out of 10000 .
# Iterating from 657 to 658 out of 10000 .
# Iterating from 658 to 659 out of 10000 .
# Iterating from 659 to 660 out of 10000 .
# Iterating from 660 to 661 out of 10000 .
# Iterating from 661 to 662 out of 10000 .
# Iterating from 662 to 663 out of 10000 .
# Iterating from 663 to 664 out of 10000 .
# Iterating from 664 to 665 out of 10000 .
# Iterating from 665 to 666 out of 10000 .
# Iterating from 666 to 667 out of 10000 .
# Iterating from 667 to 668 out of 10000 .
# Iterating from 668 to 669 out of 10000 .
# Iterating from 669 to 670 out of 10000 .
# Iterating from 670 to 671 out of 10000 .
# Iterating from 671 to 672 out of 10000 .
# Iterating from 672 to 673 out of 10000 .
# Iterating from 673 to 674 out of 10000 .
# Iterating from 674 to 675 out of 10000 .
# Iterating from 675 to 676 out of 10000 .
# Iterating from 676 to 677 out of 10000 .
# Iterating from 677 to 678 out of 10000 .
# Iterating from 678 to 679 out of 10000 .
# Iterating from 679 to 680 out of 10000 .
# Iterating from 680 to 681 out of 10000 .
# Iterating from 681 to 682 out of 10000 .
# Iterating from 682 to 683 out of 10000 .
# Iterating from 683 to 684 out of 10000 .
# Iterating from 684 to 685 out of 10000 .
# Iterating from 685 to 686 out of 10000 .
# Iterating from 686 to 687 out of 10000 .
# Iterating from 687 to 688 out of 10000 .
# Iterating from 688 to 689 out of 10000 .
# Iterating from 689 to 690 out of 10000 .
# Iterating from 690 to 691 out of 10000 .
# Iterating from 691 to 692 out of 10000 .
# Iterating from 692 to 693 out of 10000 .
# Iterating from 693 to 694 out of 10000 .
# Iterating from 694 to 695 out of 10000 .
# Iterating from 695 to 696 out of 10000 .
# Iterating from 696 to 697 out of 10000 .
# Iterating from 697 to 698 out of 10000 .
# Iterating from 698 to 699 out of 10000 .
# Iterating from 699 to 700 out of 10000 .
# Iterating from 700 to 701 out of 10000 .
# Iterating from 701 to 702 out of 10000 .
# Iterating from 702 to 703 out of 10000 .
# Iterating from 703 to 704 out of 10000 .
# Iterating from 704 to 705 out of 10000 .
# Iterating from 705 to 706 out of 10000 .
# Iterating from 706 to 707 out of 10000 .
# Iterating from 707 to 708 out of 10000 .
# Iterating from 708 to 709 out of 10000 .
# Iterating from 709 to 710 out of 10000 .
# Iterating from 710 to 711 out of 10000 .
# Iterating from 711 to 712 out of 10000 .
# Iterating from 712 to 713 out of 10000 .
# Iterating from 713 to 714 out of 10000 .
# Iterating from 714 to 715 out of 10000 .
# Iterating from 715 to 716 out of 10000 .
# Iterating from 716 to 717 out of 10000 .
# Iterating from 717 to 718 out of 10000 .
# Iterating from 718 to 719 out of 10000 .
# Iterating from 719 to 720 out of 10000 .
# Iterating from 720 to 721 out of 10000 .
# Iterating from 721 to 722 out of 10000 .
# Iterating from 722 to 723 out of 10000 .
# Iterating from 723 to 724 out of 10000 .
# Iterating from 724 to 725 out of 10000 .
# Iterating from 725 to 726 out of 10000 .
# Iterating from 726 to 727 out of 10000 .
# Iterating from 727 to 728 out of 10000 .
# Iterating from 728 to 729 out of 10000 .
# Iterating from 729 to 730 out of 10000 .
# Iterating from 730 to 731 out of 10000 .
# Iterating from 731 to 732 out of 10000 .
# Iterating from 732 to 733 out of 10000 .
# Iterating from 733 to 734 out of 10000 .
# Iterating from 734 to 735 out of 10000 .
# Iterating from 735 to 736 out of 10000 .
# Iterating from 736 to 737 out of 10000 .
# Iterating from 737 to 738 out of 10000 .
# Iterating from 738 to 739 out of 10000 .
# Iterating from 739 to 740 out of 10000 .
# Iterating from 740 to 741 out of 10000 .
# Iterating from 741 to 742 out of 10000 .
# Iterating from 742 to 743 out of 10000 .
# Iterating from 743 to 744 out of 10000 .
# Iterating from 744 to 745 out of 10000 .
# Iterating from 745 to 746 out of 10000 .
# Iterating from 746 to 747 out of 10000 .
# Iterating from 747 to 748 out of 10000 .
# Iterating from 748 to 749 out of 10000 .
# Iterating from 749 to 750 out of 10000 .
# Iterating from 750 to 751 out of 10000 .
# Iterating from 751 to 752 out of 10000 .
# Iterating from 752 to 753 out of 10000 .
# Iterating from 753 to 754 out of 10000 .
# Iterating from 754 to 755 out of 10000 .
# Iterating from 755 to 756 out of 10000 .
# Iterating from 756 to 757 out of 10000 .
# Iterating from 757 to 758 out of 10000 .
# Iterating from 758 to 759 out of 10000 .
# Iterating from 759 to 760 out of 10000 .
# Iterating from 760 to 761 out of 10000 .
# Iterating from 761 to 762 out of 10000 .
# Iterating from 762 to 763 out of 10000 .
# Iterating from 763 to 764 out of 10000 .
# Iterating from 764 to 765 out of 10000 .
# Iterating from 765 to 766 out of 10000 .
# Iterating from 766 to 767 out of 10000 .
# Iterating from 767 to 768 out of 10000 .
# Iterating from 768 to 769 out of 10000 .
# Iterating from 769 to 770 out of 10000 .
# Iterating from 770 to 771 out of 10000 .
# Iterating from 771 to 772 out of 10000 .
# Iterating from 772 to 773 out of 10000 .
# Iterating from 773 to 774 out of 10000 .
# Iterating from 774 to 775 out of 10000 .
# Iterating from 775 to 776 out of 10000 .
# Iterating from 776 to 777 out of 10000 .
# Iterating from 777 to 778 out of 10000 .
# Iterating from 778 to 779 out of 10000 .
# Iterating from 779 to 780 out of 10000 .
# Iterating from 780 to 781 out of 10000 .
# Iterating from 781 to 782 out of 10000 .
# Iterating from 782 to 783 out of 10000 .
# Iterating from 783 to 784 out of 10000 .
# Iterating from 784 to 785 out of 10000 .
# Iterating from 785 to 786 out of 10000 .
# Iterating from 786 to 787 out of 10000 .
# Iterating from 787 to 788 out of 10000 .
# Iterating from 788 to 789 out of 10000 .
# Iterating from 789 to 790 out of 10000 .
# Iterating from 790 to 791 out of 10000 .
# Iterating from 791 to 792 out of 10000 .
# Iterating from 792 to 793 out of 10000 .
# Iterating from 793 to 794 out of 10000 .
# Iterating from 794 to 795 out of 10000 .
# Iterating from 795 to 796 out of 10000 .
# Iterating from 796 to 797 out of 10000 .
# Iterating from 797 to 798 out of 10000 .
# Iterating from 798 to 799 out of 10000 .
# Iterating from 799 to 800 out of 10000 .
# Iterating from 800 to 801 out of 10000 .
# Iterating from 801 to 802 out of 10000 .
# Iterating from 802 to 803 out of 10000 .
# Iterating from 803 to 804 out of 10000 .
# Iterating from 804 to 805 out of 10000 .
# Iterating from 805 to 806 out of 10000 .
# Iterating from 806 to 807 out of 10000 .
# Iterating from 807 to 808 out of 10000 .
# Iterating from 808 to 809 out of 10000 .
# Iterating from 809 to 810 out of 10000 .
# Iterating from 810 to 811 out of 10000 .
# Iterating from 811 to 812 out of 10000 .
# Iterating from 812 to 813 out of 10000 .
# Iterating from 813 to 814 out of 10000 .
# Iterating from 814 to 815 out of 10000 .
# Iterating from 815 to 816 out of 10000 .
# Iterating from 816 to 817 out of 10000 .
# Iterating from 817 to 818 out of 10000 .
# Iterating from 818 to 819 out of 10000 .
# Iterating from 819 to 820 out of 10000 .
# Iterating from 820 to 821 out of 10000 .
# Iterating from 821 to 822 out of 10000 .
# Iterating from 822 to 823 out of 10000 .
# Iterating from 823 to 824 out of 10000 .
# Iterating from 824 to 825 out of 10000 .
# Iterating from 825 to 826 out of 10000 .
# Iterating from 826 to 827 out of 10000 .
# Iterating from 827 to 828 out of 10000 .
# Iterating from 828 to 829 out of 10000 .
# Iterating from 829 to 830 out of 10000 .
# Iterating from 830 to 831 out of 10000 .
# Iterating from 831 to 832 out of 10000 .
# Iterating from 832 to 833 out of 10000 .
# Iterating from 833 to 834 out of 10000 .
# Iterating from 834 to 835 out of 10000 .
# Iterating from 835 to 836 out of 10000 .
# Iterating from 836 to 837 out of 10000 .
# Iterating from 837 to 838 out of 10000 .
# Iterating from 838 to 839 out of 10000 .
# Iterating from 839 to 840 out of 10000 .
# Iterating from 840 to 841 out of 10000 .
# Iterating from 841 to 842 out of 10000 .
# Iterating from 842 to 843 out of 10000 .
# Iterating from 843 to 844 out of 10000 .
# Iterating from 844 to 845 out of 10000 .
# Iterating from 845 to 846 out of 10000 .
# Iterating from 846 to 847 out of 10000 .
# Iterating from 847 to 848 out of 10000 .
# Iterating from 848 to 849 out of 10000 .
# Iterating from 849 to 850 out of 10000 .
# Iterating from 850 to 851 out of 10000 .
# Iterating from 851 to 852 out of 10000 .
# Iterating from 852 to 853 out of 10000 .
# Iterating from 853 to 854 out of 10000 .
# Iterating from 854 to 855 out of 10000 .
# Iterating from 855 to 856 out of 10000 .
# Iterating from 856 to 857 out of 10000 .
# Iterating from 857 to 858 out of 10000 .
# Iterating from 858 to 859 out of 10000 .
# Iterating from 859 to 860 out of 10000 .
# Iterating from 860 to 861 out of 10000 .
# Iterating from 861 to 862 out of 10000 .
# Iterating from 862 to 863 out of 10000 .
# Iterating from 863 to 864 out of 10000 .
# Iterating from 864 to 865 out of 10000 .
# Iterating from 865 to 866 out of 10000 .
# Iterating from 866 to 867 out of 10000 .
# Iterating from 867 to 868 out of 10000 .
# Iterating from 868 to 869 out of 10000 .
# Iterating from 869 to 870 out of 10000 .
# Iterating from 870 to 871 out of 10000 .
# Iterating from 871 to 872 out of 10000 .
# Iterating from 872 to 873 out of 10000 .
# Iterating from 873 to 874 out of 10000 .
# Iterating from 874 to 875 out of 10000 .
# Iterating from 875 to 876 out of 10000 .
# Iterating from 876 to 877 out of 10000 .
# Iterating from 877 to 878 out of 10000 .
# Iterating from 878 to 879 out of 10000 .
# Iterating from 879 to 880 out of 10000 .
# Iterating from 880 to 881 out of 10000 .
# Iterating from 881 to 882 out of 10000 .
# Iterating from 882 to 883 out of 10000 .
# Iterating from 883 to 884 out of 10000 .
# Iterating from 884 to 885 out of 10000 .
# Iterating from 885 to 886 out of 10000 .
# Iterating from 886 to 887 out of 10000 .
# Iterating from 887 to 888 out of 10000 .
# Iterating from 888 to 889 out of 10000 .
# Iterating from 889 to 890 out of 10000 .
# Iterating from 890 to 891 out of 10000 .
# Iterating from 891 to 892 out of 10000 .
# Iterating from 892 to 893 out of 10000 .
# Iterating from 893 to 894 out of 10000 .
# Iterating from 894 to 895 out of 10000 .
# Iterating from 895 to 896 out of 10000 .
# Iterating from 896 to 897 out of 10000 .
# Iterating from 897 to 898 out of 10000 .
# Iterating from 898 to 899 out of 10000 .
# Iterating from 899 to 900 out of 10000 .
# Iterating from 900 to 901 out of 10000 .
# Iterating from 901 to 902 out of 10000 .
# Iterating from 902 to 903 out of 10000 .
# Iterating from 903 to 904 out of 10000 .
# Iterating from 904 to 905 out of 10000 .
# Iterating from 905 to 906 out of 10000 .
# Iterating from 906 to 907 out of 10000 .
# Iterating from 907 to 908 out of 10000 .
# Iterating from 908 to 909 out of 10000 .
# Iterating from 909 to 910 out of 10000 .
# Iterating from 910 to 911 out of 10000 .
# Iterating from 911 to 912 out of 10000 .
# Iterating from 912 to 913 out of 10000 .
# Iterating from 913 to 914 out of 10000 .
# Iterating from 914 to 915 out of 10000 .
# Iterating from 915 to 916 out of 10000 .
# Iterating from 916 to 917 out of 10000 .
# Iterating from 917 to 918 out of 10000 .
# Iterating from 918 to 919 out of 10000 .
# Iterating from 919 to 920 out of 10000 .
# Iterating from 920 to 921 out of 10000 .
# Iterating from 921 to 922 out of 10000 .
# Iterating from 922 to 923 out of 10000 .
# Iterating from 923 to 924 out of 10000 .
# Iterating from 924 to 925 out of 10000 .
# Iterating from 925 to 926 out of 10000 .
# Iterating from 926 to 927 out of 10000 .
# Iterating from 927 to 928 out of 10000 .
# Iterating from 928 to 929 out of 10000 .
# Iterating from 929 to 930 out of 10000 .
# Iterating from 930 to 931 out of 10000 .
# Iterating from 931 to 932 out of 10000 .
# Iterating from 932 to 933 out of 10000 .
# Iterating from 933 to 934 out of 10000 .
# Iterating from 934 to 935 out of 10000 .
# Iterating from 935 to 936 out of 10000 .
# Iterating from 936 to 937 out of 10000 .
# Iterating from 937 to 938 out of 10000 .
# Iterating from 938 to 939 out of 10000 .
# Iterating from 939 to 940 out of 10000 .
# Iterating from 940 to 941 out of 10000 .
# Iterating from 941 to 942 out of 10000 .
# Iterating from 942 to 943 out of 10000 .
# Iterating from 943 to 944 out of 10000 .
# Iterating from 944 to 945 out of 10000 .
# Iterating from 945 to 946 out of 10000 .
# Iterating from 946 to 947 out of 10000 .
# Iterating from 947 to 948 out of 10000 .
# Iterating from 948 to 949 out of 10000 .
# Iterating from 949 to 950 out of 10000 .
# Iterating from 950 to 951 out of 10000 .
# Iterating from 951 to 952 out of 10000 .
# Iterating from 952 to 953 out of 10000 .
# Iterating from 953 to 954 out of 10000 .
# Iterating from 954 to 955 out of 10000 .
# Iterating from 955 to 956 out of 10000 .
# Iterating from 956 to 957 out of 10000 .
# Iterating from 957 to 958 out of 10000 .
# Iterating from 958 to 959 out of 10000 .
# Iterating from 959 to 960 out of 10000 .
# ...
# Iterating from 500 to 600 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7faecc182020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# KS tests calculation completed in 278.2584487970453 seconds.
# Saving ks to results/20D_mixture/20D_100K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 100
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fafc411f6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 500 to 600 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fafc411f6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SKS metric calculation completed in 738.2416128260083 seconds.
# Saving sks to results/20D_mixture/20D_100K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 100
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 100000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SWD metric calculation completed in 406.8666209678631 seconds.
# Saving swd to results/20D_mixture/20D_100K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0007442613804878556], [0.95, [9500, 500], 0.006059034008269291], [0.99, [9900, 100], 0.011194342160785652]]
# Computing time for metric fgd: 7356.78934881906
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.006840329725704919], [0.95, [9500, 500], 0.12188061963479413], [0.99, [9900, 100], 0.23109057101817143]]
# Computing time for metric mmd: 16645.558045957005
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9175707497183424], [0.95, [9500, 500], 1.1554886114461125], [0.99, [9900, 100], 1.3425378144642135]]
# Computing time for metric ks: 278.2584487970453
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9155139055397394], [0.95, [9500, 500], 1.1243404002839275], [0.99, [9900, 100], 1.2823866801183261]]
# Computing time for metric sks: 738.2416128260083
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.6321813196286373], [0.95, [9500, 500], 0.8822478617130829], [0.99, [9900, 100], 1.0839338673289005]]
# Computing time for metric swd: 406.8666209678631
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fb02812cfe0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fb02812d080>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fb02812d120>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fb02812d1c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fb02812d260>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fb02812d300>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...           2000
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_mixture/20D_100K/null_hypothesis/F...
# 1  $d_{\mathrm{MMD}}$  results/20D_mixture/20D_100K/null_hypothesis/M...
# 2      $\overline{D}$  results/20D_mixture/20D_100K/null_hypothesis/K...
# 3     $\widetilde{D}$  results/20D_mixture/20D_100K/null_hypothesis/S...
# 4     $\widetilde{W}$  results/20D_mixture/20D_100K/null_hypothesis/S...
# 5           $t_{\mu}$  results/20D_mixture/20D_100K/null_hypothesis/L...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0007442613804878556], ...
# 1  [[0.68, [6800, 3199], 0.006840329725704919], [...
# 2  [[0.68, [6800, 3199], 0.9175707497183424], [0....
# 3  [[0.68, [6800, 3199], 0.9155139055397394], [0....
# 4  [[0.68, [6800, 3199], 0.6321813196286373], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10)$"
        dist_null = dist_null * 10
    #elif "MMD" in latex:
    #    latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-2})$"
    #    dist_null = dist_null / 100
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 10
        #elif "MMD" in latex:
        #    threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 10
        #elif "MMD" in latex:
        #    threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.012069502137372196 +/- 5.848952744500076e-06
# sigma = 0.024184608213696737 +/- 0.0005033303425461425
# 68%CL = 0.007442613804878556, 95%CL = 0.060590340082692914, 99%CL = 0.11194342160785652
# mu = 0.012069502137372196 +/- 5.848952744500076e-06
# sigma = 0.024184608213696737 +/- 0.0005033303425461425
# /tmp/ipykernel_1167779/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1167779/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1167779/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3382204759400338 seconds.
# mu = 6.697444248745938e-05 +/- 3.9600689046784725e-05
# sigma = 0.0629290783714371 +/- 0.0010208325190300851
# 68%CL = 0.006840329725704919, 95%CL = 0.12188061963479413, 99%CL = 0.23109057101817143
# mu = 6.697444248745938e-05 +/- 3.9600689046784725e-05
# sigma = 0.0629290783714371 +/- 0.0010208325190300851
# /tmp/ipykernel_1167779/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1167779/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1167779/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9754321221262217 seconds.
# mu = 0.8699077529256373 +/- 0.00023473428633908984
# sigma = 0.1532104064151942 +/- 0.0014348351610748665
# 68%CL = 0.9175707497183424, 95%CL = 1.1554886114461125, 99%CL = 1.3425378144642135
# mu = 0.8699077529256373 +/- 0.00023473428633908984
# sigma = 0.1532104064151942 +/- 0.0014348351610748665
# /tmp/ipykernel_1167779/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1167779/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1167779/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1167779/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3278459969442338 seconds.
# mu = 0.8697647054022869 +/- 0.00018553940518437794
# sigma = 0.1362128500488768 +/- 0.001253687911974667
# 68%CL = 0.9155139055397394, 95%CL = 1.1243404002839275, 99%CL = 1.2823866801183261
# mu = 0.8697647054022869 +/- 0.00018553940518437794
# sigma = 0.1362128500488768 +/- 0.001253687911974667
# /tmp/ipykernel_1167779/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1167779/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1167779/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1167779/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 3.156092130113393 seconds.
# mu = 0.5775531761067821 +/- 0.0002681629644016617
# sigma = 0.16375682104928077 +/- 0.0014963781476358866
# 68%CL = 0.6321813196286373, 95%CL = 0.8822478617130829, 99%CL = 1.0839338673289005
# mu = 0.5775531761067821 +/- 0.0002681629644016617
# sigma = 0.16375682104928077 +/- 0.0014963781476358866
# /tmp/ipykernel_1167779/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1167779/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1167779/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1167779/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9647127869538963 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fb02812cfe0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fb02812d080>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fb02812d120>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fb02812d1c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fb02812d260>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fb02812d300>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...           2000
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_mixture/20D_100K/null_hypothesis/F...
# 1  $d_{\mathrm{MMD}}$  results/20D_mixture/20D_100K/null_hypothesis/M...
# 2      $\overline{D}$  results/20D_mixture/20D_100K/null_hypothesis/K...
# 3     $\widetilde{D}$  results/20D_mixture/20D_100K/null_hypothesis/S...
# 4     $\widetilde{W}$  results/20D_mixture/20D_100K/null_hypothesis/S...
# 5           $t_{\mu}$  results/20D_mixture/20D_100K/null_hypothesis/L...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0007442613804878556], ...
# 1  [[0.68, [6800, 3199], 0.006840329725704919], [...
# 2  [[0.68, [6800, 3199], 0.9175707497183424], [0....
# 3  [[0.68, [6800, 3199], 0.9155139055397394], [0....
# 4  [[0.68, [6800, 3199], 0.6321813196286373], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/20D_mixture/20D_100K/null_hypothesis/F...
# 1  results/20D_mixture/20D_100K/null_hypothesis/M...
# 2  results/20D_mixture/20D_100K/null_hypothesis/K...
# 3  results/20D_mixture/20D_100K/null_hypothesis/S...
# 4  results/20D_mixture/20D_100K/null_hypothesis/S...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 1.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = mean
# statistic = 0.9338986453309776 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9742157157010367
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 204 calls to <function generate_and_clean_data_simple_1 at 0x7fb12bef4e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.2310754600856654 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8977958220473963
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = mean
# WARNING:tensorflow:6 out of the last 205 calls to <function generate_and_clean_data_simple_1 at 0x7fb12bef4e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.056595282658882105 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.613176915457706
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = mean
# WARNING:tensorflow:5 out of the last 104 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7faddc0f4720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.013866843112427335 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7836853611877614
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = mean
# WARNING:tensorflow:6 out of the last 105 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7fad467127a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.003725871087813045 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.47689025034905935
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.046875 - deformation = mean
# statistic = 0.007395386734913671 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.19864886822741565
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = mean
# statistic = 0.005313350103613668 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.13113941585502045
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.04296875 - deformation = mean
# statistic = 0.006319062885796448 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.04201435483217436
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.041015625 - deformation = mean
# statistic = 0.005749737882782399 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.052384130769985826
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0419921875 - deformation = mean
# statistic = 0.0061207445204018935 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.023529411764705882
# relative_error_metric = 0.010133273275427117
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.04150390625 - deformation = mean
# statistic = 0.005944226375748945 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.011695906432748537
# relative_error_metric = 0.019129407985384803
# =======> statistic within required accuracy at 0.95 CL in 1053.4667819119059 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.041748046875 - deformation = mean
# statistic = 0.006070063869500333 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.839700023435669
# relative_error_metric = 0.5936234681107572
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5208740234375 - deformation = mean
# statistic = 1.0142852198658692 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.7031894120199609
# relative_error_metric = 1.9563351915520881
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.28131103515625 - deformation = mean
# statistic = 0.2931574667526194 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.483090874740223
# relative_error_metric = 1.8528762854966876
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.161529541015625 - deformation = mean
# statistic = 0.09557991459505173 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.1785017264674973
# relative_error_metric = 1.5806351642836924
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.1016387939453125 - deformation = mean
# statistic = 0.03703940657810249 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.8353729913802277
# relative_error_metric = 1.0716589563555705
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.07169342041015625 - deformation = mean
# statistic = 0.018223200292750798 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.5279440446566682
# relative_error_metric = 0.47786847885521905
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.056720733642578125 - deformation = mean
# statistic = 0.011164025474008068 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.23319371416688947
# relative_error_metric = 0.0027118873142067054
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.06420707702636719 - deformation = mean
# statistic = 0.014577018530383628 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.12381508178104446
# relative_error_metric = 0.2625143786650793
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.060463905334472656 - deformation = mean
# statistic = 0.012746638093927176 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.06388502323461673
# relative_error_metric = 0.12967689013785907
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.05859231948852539 - deformation = mean
# statistic = 0.011985712342464549 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.03246095381447221
# relative_error_metric = 0.06828026927787723
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.05765652656555176 - deformation = mean
# statistic = 0.011533262585125204 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.016363268734900457
# relative_error_metric = 0.02982456164022573
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.05718863010406494 - deformation = mean
# statistic = 0.011240840788968736 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.008215241418212301
# relative_error_metric = 0.004145152574616597
# =======> statistic within required accuracy at 0.99 CL in 1139.112019740045 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2192.57884073304 seconds.
# Saving results in the file results/20D_mixture/20D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = cov_diag
# statistic = 7.879849427995024 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9969266526298326
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = cov_diag
# statistic = 1.9688619292953518 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9877280476113153
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = cov_diag
# statistic = 0.4914822178122046 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9512881877745842
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = cov_diag
# statistic = 0.12280950834338338 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.811931324815157
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = cov_diag
# statistic = 0.03082523749317448 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3429140648168016
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = cov_diag
# statistic = 0.007810410516478497 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.25255178822542707
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = cov_diag
# statistic = 0.002623459097053555 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7913798190313653
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01171875 - deformation = cov_diag
# statistic = 0.004597187226662034 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.2743649459557562
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.013671875 - deformation = cov_diag
# statistic = 0.006193783910697968 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.02199492448509909
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0126953125 - deformation = cov_diag
# statistic = 0.0053373979595514025 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.12664245278794656
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01318359375 - deformation = cov_diag
# statistic = 0.0056272887834002625 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.07388897817828423
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.013427734375 - deformation = cov_diag
# statistic = 0.005934918200233101 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.018018018018018018
# relative_error_metric = 0.020696398631337844
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0135498046875 - deformation = cov_diag
# statistic = 0.005981605125424417 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.008968609865470852
# relative_error_metric = 0.01286125794239656
# =======> statistic within required accuracy at 0.95 CL in 1235.0680839451961 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.01361083984375 - deformation = cov_diag
# statistic = 0.006119991938328741 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.9462877100018066
# relative_error_metric = 0.5861444273177631
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.506805419921875 - deformation = cov_diag
# statistic = 8.095556688054383 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.895384976250513
# relative_error_metric = 1.9944765333884988
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.2602081298828125 - deformation = cov_diag
# statistic = 2.1321965196502823 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.801170242407356
# relative_error_metric = 1.979109097906059
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.13690948486328125 - deformation = cov_diag
# statistic = 0.5896787905317591 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.6382989507831112
# relative_error_metric = 1.9254794960751653
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.07526016235351562 - deformation = cov_diag
# statistic = 0.17796467652550416 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.387388934197536
# relative_error_metric = 1.7632818728172643
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.04443550109863281 - deformation = cov_diag
# statistic = 0.062150985656564905 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.0620707784313081
# relative_error_metric = 1.3894993726846485
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.029023170471191406 - deformation = cov_diag
# statistic = 0.026562392865160916 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.7230063751258249
# relative_error_metric = 0.8140561250232196
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.021317005157470703 - deformation = cov_diag
# statistic = 0.014331828641626554 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.4412619967508089
# relative_error_metric = 0.24582507929817748
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.01746392250061035 - deformation = cov_diag
# statistic = 0.009681676774108064 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.19871018511118352
# relative_error_metric = 0.1449189513953934
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.019390463829040527 - deformation = cov_diag
# statistic = 0.011910088354014355 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.10454882147258512
# relative_error_metric = 0.06195748410853217
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.01842719316482544 - deformation = cov_diag
# statistic = 0.01085718941272926 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.05094290555183419
# relative_error_metric = 0.03057862415881627
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.018908828496932983 - deformation = cov_diag
# statistic = 0.011236131032426442 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.0258000349619928
# relative_error_metric = 0.003726080255269527
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.01866801083087921 - deformation = cov_diag
# statistic = 0.01114403676777335 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.012817345490552353
# relative_error_metric = 0.004503943027664193
# =======> statistic within required accuracy at 0.99 CL in 1233.300751564093 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2468.3688710001297 seconds.
# Saving results in the file results/20D_mixture/20D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = cov_off_diag
# statistic = 49.38020183726185 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995092534724133
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = cov_off_diag
# statistic = 21.430746030893268 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9988694147304271
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = cov_off_diag
# statistic = 8.452315159829109 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9971346578576847
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = cov_off_diag
# statistic = 3.069054094011659 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9921186196981695
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = cov_off_diag
# statistic = 1.0242235234000139 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.976476224062218
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = cov_off_diag
# statistic = 0.31505207971750754 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9245241444561947
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = cov_off_diag
# statistic = 0.09041867417154617 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7487903009894703
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.00390625 - deformation = cov_off_diag
# statistic = 0.024873898760111687 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2164940772169246
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.001953125 - deformation = cov_off_diag
# statistic = 0.006790365976781435 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.11383130252976659
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0009765625 - deformation = cov_off_diag
# statistic = 0.0025402070464402514 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.8184040752996184
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00146484375 - deformation = cov_off_diag
# statistic = 0.003998390250634856 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.4097756452523287
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.001708984375 - deformation = cov_off_diag
# statistic = 0.005334772010811917 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.12713258348342113
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0018310546875 - deformation = cov_off_diag
# statistic = 0.006059444875315898 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 6.780835293826931e-05
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00177001953125 - deformation = cov_off_diag
# statistic = 0.005502232472610226 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.09632189286181153
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.001800537109375 - deformation = cov_off_diag
# statistic = 0.005601107701151015 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.01680672268907563
# relative_error_metric = 0.07854558178282077
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0018157958984375 - deformation = cov_off_diag
# statistic = 0.005925496676763245 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.008368200836820083
# relative_error_metric = 0.022284949659784458
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00182342529296875 - deformation = cov_off_diag
# statistic = 0.00585637592063943 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.0041753653444676405
# relative_error_metric = 0.03401613353447117
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.001827239990234375 - deformation = cov_off_diag
# statistic = 0.005947724073366195 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.0020855057351407717
# relative_error_metric = 0.018541213897421072
# =======> statistic within required accuracy at 0.95 CL in 1038.1654414548539 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0018291473388671875 - deformation = cov_off_diag
# statistic = 0.005999365880201874 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.9926967693294775
# relative_error_metric = 0.6042880649362711
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5009145736694336 - deformation = cov_off_diag
# statistic = 49.47878696017397 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.9854466817789496
# relative_error_metric = 1.999095223569199
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.2513718605041504 - deformation = cov_off_diag
# statistic = 21.580331876898754 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.9711036325731968
# relative_error_metric = 1.9979261600968434
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.1266005039215088 - deformation = cov_off_diag
# statistic = 8.604147829551371 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.9430303727864586
# relative_error_metric = 1.9948026012489475
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.06421482563018799 - deformation = cov_off_diag
# statistic = 3.1979794855921813 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.8892163958867687
# relative_error_metric = 1.9860470728460056
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.03302198648452759 - deformation = cov_off_diag
# statistic = 1.121055423625604 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.7900616550226183
# relative_error_metric = 1.9604527463849437
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.017425566911697388 - deformation = cov_off_diag
# statistic = 0.38136542008059027 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.620010494040221
# relative_error_metric = 1.8859348997271657
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.009627357125282288 - deformation = cov_off_diag
# statistic = 0.13266679333876685 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.3613593589244999
# relative_error_metric = 1.6887458973012075
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.0057282522320747375 - deformation = cov_off_diag
# statistic = 0.0508513697051331 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.0318641634880714
# relative_error_metric = 1.2783164654487833
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.0037786997854709625 - deformation = cov_off_diag
# statistic = 0.023268277316802033 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.6952944341662542
# relative_error_metric = 0.700697471001501
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.002803923562169075 - deformation = cov_off_diag
# statistic = 0.013074788965445183 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.4207905486979976
# relative_error_metric = 0.15496614154654142
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0023165354505181313 - deformation = cov_off_diag
# statistic = 0.009219539571467709 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.19036891436619996
# relative_error_metric = 0.19347644071022613
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.002560229506343603 - deformation = cov_off_diag
# statistic = 0.011171973203190477 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.09086021696731375
# relative_error_metric = 0.0020002362687958158
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.002682076534256339 - deformation = cov_off_diag
# statistic = 0.012227596879060238 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.04648604143637195
# relative_error_metric = 0.08822964798232905
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.002621153020299971 - deformation = cov_off_diag
# statistic = 0.01168216288273254 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.02351631582616748
# relative_error_metric = 0.04264818607727899
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.002590691263321787 - deformation = cov_off_diag
# statistic = 0.011451712611498648 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.011827693859155521
# relative_error_metric = 0.022729826744743442
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.002575460384832695 - deformation = cov_off_diag
# statistic = 0.01123689157104816 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.005931385582786212
# relative_error_metric = 0.0037937646026240724
# =======> statistic within required accuracy at 0.99 CL in 981.6184600028209 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2019.7839360849466 seconds.
# Saving results in the file results/20D_mixture/20D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = power_abs_up
# statistic = 127.13230339494399 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999809371966336
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = power_abs_up
# statistic = 21.225941035929566 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.998858509045156
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = power_abs_up
# statistic = 4.381708649907594 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9944764313475574
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = power_abs_up
# statistic = 0.9986975836160534 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9758786002421345
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = power_abs_up
# statistic = 0.23887897023867288 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.901051957585795
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = power_abs_up
# statistic = 0.0588345264806272 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6265247915126486
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = power_abs_up
# statistic = 0.015002749437366148 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8492837705014228
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.00390625 - deformation = power_abs_up
# statistic = 0.004001140960949731 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.4091167506760205
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.005859375 - deformation = power_abs_up
# statistic = 0.008532823679888505 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.3390643911812337
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.005992549359888806 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.01103334663163787
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00537109375 - deformation = power_abs_up
# statistic = 0.007290437849362066 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.18448727473646548
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.005126953125 - deformation = power_abs_up
# statistic = 0.00660613120357101 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.04878048780487805
# relative_error_metric = 0.0863940084714021
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0050048828125 - deformation = power_abs_up
# statistic = 0.006099680039764542 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.024691358024691357
# relative_error_metric = 0.0066859096010772195
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00494384765625 - deformation = power_abs_up
# statistic = 0.006264694181195571 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.012422360248447204
# relative_error_metric = 0.03337629161637821
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.004913330078125 - deformation = power_abs_up
# statistic = 0.00618252537435394 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.006230529595015576
# relative_error_metric = 0.020175757389200483
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0048980712890625 - deformation = power_abs_up
# statistic = 0.006003696082953326 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.003110419906687403
# relative_error_metric = 0.009175025039519308
# =======> statistic within required accuracy at 0.95 CL in 1521.3724635089748 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00490570068359375 - deformation = power_abs_up
# statistic = 0.006005996308259424 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.980472990927381
# relative_error_metric = 0.6032841576767266
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5024528503417969 - deformation = power_abs_up
# statistic = 128.90970398072756 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.9613235990706837
# relative_error_metric = 1.9996526756388944
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.2536792755126953 - deformation = power_abs_up
# statistic = 21.982668476522036 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.924114683602192
# relative_error_metric = 1.997964097120534
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.12929248809814453 - deformation = power_abs_up
# statistic = 4.717559033669136 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.8537774398260338
# relative_error_metric = 1.990530830203154
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.06709909439086914 - deformation = power_abs_up
# statistic = 1.1584881951319583 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.7274792225423
# relative_error_metric = 1.9617183575752266
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.036002397537231445 - deformation = power_abs_up
# statistic = 0.31909442450066966 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.5203198489343226
# relative_error_metric = 1.8644296350258889
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.020454049110412598 - deformation = power_abs_up
# statistic = 0.10101187830018007 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.2262225418717358
# relative_error_metric = 1.6009368423676673
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.012679874897003174 - deformation = power_abs_up
# statistic = 0.03882229452957531 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.8841535129492233
# relative_error_metric = 1.104750506909395
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.008792787790298462 - deformation = power_abs_up
# statistic = 0.018707397695307132 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.5675205865396121
# relative_error_metric = 0.502516279700067
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.006849244236946106 - deformation = power_abs_up
# statistic = 0.011545889245829376 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.33067676054463335
# relative_error_metric = 0.030918514306891447
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.005877472460269928 - deformation = power_abs_up
# statistic = 0.008577018512012457 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.15271366524388066
# relative_error_metric = 0.264759081793917
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.006363358348608017 - deformation = power_abs_up
# statistic = 0.01006482882673895 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.07354885386007566
# relative_error_metric = 0.10626127751731505
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0066063012927770615 - deformation = power_abs_up
# statistic = 0.010758305674713394 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.03611045626242146
# relative_error_metric = 0.039725183890314576
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.006727772764861584 - deformation = power_abs_up
# statistic = 0.01111774324978545 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.017893690796490735
# relative_error_metric = 0.006866136409096924
# =======> statistic within required accuracy at 0.99 CL in 1322.9265719170216 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2844.299068651162 seconds.
# Saving results in the file results/20D_mixture/20D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = power_abs_down
# statistic = 29.404862677271545 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9991759477560411
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = power_abs_down
# statistic = 10.223987010356817 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9976308869062789
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = power_abs_down
# statistic = 3.0389462532699456 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9920406916420366
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = power_abs_down
# statistic = 0.8302279276312851 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.971019354426426
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = power_abs_down
# statistic = 0.21727822702742333 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8914818963898556
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = power_abs_down
# statistic = 0.05573867394898628 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6078149686418646
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = power_abs_down
# statistic = 0.014332129871316723 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8114392990906996
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.00390625 - deformation = power_abs_down
# statistic = 0.003803855293654982 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.4573058959861424
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.005859375 - deformation = power_abs_down
# statistic = 0.008279529048737815 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.3097235101788517
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.005799170222251326 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.04382852259351855
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00537109375 - deformation = power_abs_down
# statistic = 0.007013491010695541 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.14602488823568227
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.005126953125 - deformation = power_abs_down
# statistic = 0.006366588082629934 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.04878048780487805
# relative_error_metric = 0.049503207503132106
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0050048828125 - deformation = power_abs_down
# statistic = 0.006121327355028116 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.024691358024691357
# relative_error_metric = 0.010228489106494088
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00494384765625 - deformation = power_abs_down
# statistic = 0.00611276811465537 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.012422360248447204
# relative_error_metric = 0.008829277019690355
# =======> statistic within required accuracy at 0.95 CL in 1325.753154702019 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.004913330078125 - deformation = power_abs_down
# statistic = 0.006013050429263753 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.9804427708099244
# relative_error_metric = 0.6022169488383856
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5024566650390625 - deformation = power_abs_down
# statistic = 29.601654497500352 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.9612643228775075
# relative_error_metric = 1.998487907432156
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.25368499755859375 - deformation = power_abs_down
# statistic = 10.474660926589426 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.9240005900575305
# relative_error_metric = 1.9957297361545137
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.12929916381835938 - deformation = power_abs_down
# statistic = 3.23315215859427 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.8535656424977973
# relative_error_metric = 1.9861983395938994
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.06710624694824219 - deformation = power_abs_down
# statistic = 0.9515798109131328 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.7271114171455813
# relative_error_metric = 1.9534913058268353
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.036009788513183594 - deformation = power_abs_down
# statistic = 0.28667697900614253 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.5197501806063713
# relative_error_metric = 1.8496754623180083
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.020461559295654297 - deformation = power_abs_down
# statistic = 0.09492592784375739 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.225481537160575
# relative_error_metric = 1.5780507471265792
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.012687444686889648 - deformation = power_abs_down
# statistic = 0.03705261659906611 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.8833832274494399
# relative_error_metric = 1.0719131362036511
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.008800387382507324 - deformation = power_abs_down
# statistic = 0.018016898784261177 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.5668860125696503
# relative_error_metric = 0.4671185750930848
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.006856858730316162 - deformation = power_abs_down
# statistic = 0.011061217262455573 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.24825932200163695
# relative_error_metric = 0.011963293826805181
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.007828623056411743 - deformation = power_abs_down
# statistic = 0.014436033326757256 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.13234354040380467
# relative_error_metric = 0.2529569781408125
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.007342740893363953 - deformation = power_abs_down
# statistic = 0.012782632466718302 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.06843603706086246
# relative_error_metric = 0.13248462999253663
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.007099799811840057 - deformation = power_abs_down
# statistic = 0.012009188585258724 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.03481364551408769
# relative_error_metric = 0.07023469258978902
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.00697832927107811 - deformation = power_abs_down
# statistic = 0.011591595121104253 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.017559651628833113
# relative_error_metric = 0.03486825715388369
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.006917594000697136 - deformation = power_abs_down
# statistic = 0.011415328202013101 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.008818538430093536
# relative_error_metric = 0.01954792243154975
# =======> statistic within required accuracy at 0.99 CL in 1423.9819471391384 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2749.735136140138 seconds.
# Saving results in the file results/20D_mixture/20D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with random_normal deformation.
#
# ======================================================
# =============== fgd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = random_normal
# statistic = 0.5337738233742038 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9551043703590172
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = random_normal
# statistic = 0.041394717752677106 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4892682847255276
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = random_normal
# statistic = 0.003281230740164044 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.5948018269120636
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.1875 - deformation = random_normal
# statistic = 0.013760091801400037 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.777133953039802
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 0.00679880223515919 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.11506885184791303
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.140625 - deformation = random_normal
# statistic = 0.004593289569663389 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.2751971300688488
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.1484375 - deformation = random_normal
# statistic = 0.005655010622261149 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.06898102214074403
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.15234375 - deformation = random_normal
# statistic = 0.006235412781964364 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.025974025974025976
# relative_error_metric = 0.028692429469080783
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.150390625 - deformation = random_normal
# statistic = 0.005954268311376959 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.012903225806451613
# relative_error_metric = 0.017441614987246362
# =======> statistic within required accuracy at 0.95 CL in 851.4538564041723 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.1513671875 - deformation = random_normal
# statistic = 0.00613771332873306 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.474130619168787
# relative_error_metric = 0.5835001895892277
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.57568359375 - deformation = random_normal
# statistic = 0.8693249426616191 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.1672263263935527
# relative_error_metric = 1.9491466349289852
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.363525390625 - deformation = random_normal
# statistic = 0.1696936051922306 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.8240872451398767
# relative_error_metric = 1.7524579757889769
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.2574462890625 - deformation = random_normal
# statistic = 0.04623323560941064 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.5189608838459242
# relative_error_metric = 1.2202810847721124
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.20440673828125 - deformation = random_normal
# statistic = 0.01919030065235236 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.29816435066049063
# relative_error_metric = 0.5263157800301235
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.177886962890625 - deformation = random_normal
# statistic = 0.011167555979334318 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.1387403209068412
# relative_error_metric = 0.0023956983690285503
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.1911468505859375 - deformation = random_normal
# statistic = 0.014819986460828095 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.07186272482943974
# relative_error_metric = 0.27874210038464053
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.18451690673828125 - deformation = random_normal
# statistic = 0.012836307624479121 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.036588703395717986
# relative_error_metric = 0.1366559355128464
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.18120193481445312 - deformation = random_normal
# statistic = 0.012121545467932569 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.018463238184271192
# relative_error_metric = 0.07953403463867093
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.17954444885253906 - deformation = random_normal
# statistic = 0.011592013361240638 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.009274428085828481
# relative_error_metric = 0.03490432685214448
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.17871570587158203 - deformation = random_normal
# statistic = 0.011413735335071113 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.0046479909072675
# relative_error_metric = 0.019408388380274075
# =======> statistic within required accuracy at 0.99 CL in 1044.6180266470183 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1896.0719175059348 seconds.
# Saving results in the file results/20D_mixture/20D_100K/exclusion_limits.json
# Computing exclusion limits for fgd with random_uniform deformation.
#
# ======================================================
# =============== fgd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = random_uniform
# W0000 00:00:1714709627.767161 1167779 random_ops.cc:59] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. while/random_shiftMixture_CONSTRUCTED_AT_top_level/sample/random_shift/forward/random_uniform/RandomUniform
# statistic = 0.0715099755334236 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6875538803927825
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = random_uniform
# statistic = 0.005164204881771046 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1594600516420138
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.375 - deformation = random_uniform
# statistic = 0.023782846205487485 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 1.1878482233869239
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_uniform
# statistic = 0.011878852411237057 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.6488856342226665
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.28125 - deformation = random_uniform
# statistic = 0.007986473086833127 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.27445631766985784
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.265625 - deformation = random_uniform
# statistic = 0.006508254349593326 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.07149041679193814
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.2578125 - deformation = random_uniform
# statistic = 0.005696768772696687 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.029850746268656716
# relative_error_metric = 0.06163173069884335
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.26171875 - deformation = random_uniform
# statistic = 0.006072345415391463 - next threshold = 0.006059034008269291 at 0.95 CL
# relative_error_eps = 0.015037593984962405
# relative_error_metric = 0.0021945413884607197
# =======> statistic within required accuracy at 0.95 CL in 756.9024325569626 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.259765625 - deformation = random_uniform
# statistic = 0.0058840768851877775 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 1.1751937984496124
# relative_error_metric = 0.6218684834120958
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.6298828125 - deformation = random_uniform
# statistic = 0.1689132436838618 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.8320526893523601
# relative_error_metric = 1.751385437580816
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.44482421875 - deformation = random_uniform
# statistic = 0.04572318873324732 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.5252945252945252
# relative_error_metric = 1.2132939018997941
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.352294921875 - deformation = random_uniform
# statistic = 0.018785800286666897 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.30235341045073794
# relative_error_metric = 0.506432425342015
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3060302734375 - deformation = random_uniform
# statistic = 0.011055056671631355 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.14055256814389022
# relative_error_metric = 0.012520382254226095
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.32916259765625 - deformation = random_uniform
# statistic = 0.014387970239332712 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.07283559142884596
# relative_error_metric = 0.24967469934674738
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.317596435546875 - deformation = random_uniform
# statistic = 0.012567562611367942 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.03709322241252753
# relative_error_metric = 0.11558168116148308
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.3118133544921875 - deformation = random_uniform
# statistic = 0.011783472925558619 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.018720209429255882
# relative_error_metric = 0.05127822315212974
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.30892181396484375 - deformation = random_uniform
# statistic = 0.011356987855598145 - next threshold = 0.011194342160785652 at 0.99 CL
# relative_error_eps = 0.00940411647209161
# relative_error_metric = 0.014424488018607283
# =======> statistic within required accuracy at 0.99 CL in 853.6407109249849 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1610.5431769089773 seconds.
# Saving results in the file results/20D_mixture/20D_100K/exclusion_limits.json
# Computing exclusion limits for mmd with mean deformation.
#
# ======================================================
# =============== mmd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = mean
# statistic = 31.82913565718503 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9847415658295393
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = mean
# statistic = 7.893706200154314 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9391781925016933
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = mean
# statistic = 1.9729731105117252 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7672761245697675
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = mean
# statistic = 0.4876050609402739 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2001083961821968
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = mean
# statistic = 0.1120831564352784 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.08375196677097034
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.046875 - deformation = mean
# statistic = 0.26925690798849045 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.7535778489433953
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = mean
# statistic = 0.18302277685841234 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.401059207124841
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.03515625 - deformation = mean
# statistic = 0.1456410492772207 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.17763368282694997
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.033203125 - deformation = mean
# statistic = 0.1283841076624313 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.051972869671828285
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0322265625 - deformation = mean
# statistic = 0.12011413108721172 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 0.029850746268656716
# relative_error_metric = 0.014599395584507367
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.03271484375 - deformation = mean
# statistic = 0.12421924441292873 - next threshold = 0.12188061963479413 at 0.95 CL
# relative_error_eps = 0.015037593984962405
# relative_error_metric = 0.0190054942710663
# =======> statistic within required accuracy at 0.95 CL in 1166.4516167549882 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.032470703125 - deformation = mean
# statistic = 0.12215921897530961 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 1.8742019389926696
# relative_error_metric = 0.6167383824622914
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5162353515625 - deformation = mean
# statistic = 33.96121765969282 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 1.7632925472747498
# relative_error_metric = 1.972965782893755
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.27435302734375 - deformation = mean
# statistic = 9.508763207312807 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 1.576685896160732
# relative_error_metric = 1.9050948499730882
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.153411865234375 - deformation = mean
# statistic = 2.9724007956145284 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 1.3012641602364143
# relative_error_metric = 1.711451607548949
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.0929412841796875 - deformation = mean
# statistic = 1.0887067247943107 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 0.9643508942693758
# relative_error_metric = 1.2996179890612385
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.06270599365234375 - deformation = mean
# statistic = 0.4908922303134517 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 0.6353507014028056
# relative_error_metric = 0.719689330039726
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.047588348388671875 - deformation = mean
# statistic = 0.2778927967581623 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 0.3776623624148282
# relative_error_metric = 0.1839047352154639
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04002952575683594 - deformation = mean
# statistic = 0.19286740204049266 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 0.17254065350371162
# relative_error_metric = 0.18031583980796953
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.043808937072753906 - deformation = mean
# statistic = 0.23359052388291418 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 0.09015936572215082
# relative_error_metric = 0.01075986474239888
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.04191923141479492 - deformation = mean
# statistic = 0.21278156141349883 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 0.044085991601079066
# relative_error_metric = 0.08249677448489559
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.042864084243774414 - deformation = mean
# statistic = 0.22307419333386064 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 0.021802697416740707
# relative_error_metric = 0.03530162757451232
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.04333651065826416 - deformation = mean
# statistic = 0.22830439640389955 - next threshold = 0.23109057101817143 at 0.99 CL
# relative_error_eps = 0.010842251128204217
# relative_error_metric = 0.012129756796887489
# =======> statistic within required accuracy at 0.99 CL in 1266.9044989310205 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2433.3561518199276 seconds.
# Saving results in the file results/20D_mixture/20D_100K/exclusion_limits.json
# Computing exclusion limits for mmd with cov_diag deformation.
#
# ======================================================
# =============== mmd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = cov_diag

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.05,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for LR with mean deformation already loaded.
# Exclusion limits for LR with cov_diag deformation already loaded.
# Computing exclusion limits for lr with cov_off_diag deformation.
#
# ======================================================
# =============== lr - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.025 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714586276.533289 1041566 service.cc:145] XLA service 0x11dcecdd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714586276.533336 1041566 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1714586276.629580 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1714586276.634334 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1714586276.637603 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1714586276.637902 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1714586276.638742 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1714586276.638806 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1714586276.638867 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1714586276.638933 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1714586276.638994 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1714586276.639054 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1714586276.639112 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1714586276.639172 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1714586276.639230 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_25/Assert/Assert
# W0000 00:00:1714586276.639288 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_27/Assert/Assert
# W0000 00:00:1714586276.639353 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_29/Assert/Assert
# W0000 00:00:1714586276.639413 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_31/Assert/Assert
# W0000 00:00:1714586276.639473 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_33/Assert/Assert
# W0000 00:00:1714586276.639532 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_35/Assert/Assert
# W0000 00:00:1714586276.639590 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_37/Assert/Assert
# W0000 00:00:1714586276.639649 1041566 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_39/Assert/Assert
# I0000 00:00:1714586316.049312 1041566 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 105.62493412801996 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_cov_off_diag_0.025000.json
# ThresholdS: [[0.95, [9500, 500], -387786902.0813388], [0.99, [9900, 100], -386742380.1410886]]
# Null distribution computed in 107.50232962495647 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 45.729928768007085 seconds.
# statistic = 460794317.6581449 - next threshold = -387786902.0813388 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 23.246439092115235
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.0125 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 104.60599329392426 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_cov_off_diag_0.012500.json
# ThresholdS: [[0.95, [9500, 500], -297219969.0256375], [0.99, [9900, 100], -296311941.9154321]]
# Null distribution computed in 105.05258592311293 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 47.69094590912573 seconds.
# statistic = 356764897.89654446 - next threshold = -297219969.0256375 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 21.966097846552717
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.00625 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 106.7168371300213 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_cov_off_diag_0.006250.json
# ThresholdS: [[0.95, [9500, 500], -114071218.97583283], [0.99, [9900, 100], -113697441.22656251]]
# Null distribution computed in 107.18680400308222 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 48.44799501798116 seconds.
# statistic = 143936873.99682045 - next threshold = -114071218.97583283 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 17.27791289300986
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.003125 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 106.89211108814925 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_cov_off_diag_0.003125.json
# ThresholdS: [[0.95, [9500, 500], -35179740.559353635], [0.99, [9900, 100], -35063301.67789008]]
# Null distribution computed in 107.4430757148657 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 51.16721814498305 seconds.
# statistic = 40165003.73701521 - next threshold = -35179740.559353635 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 30.226987667965247
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.0015625 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 106.30163144809194 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_cov_off_diag_0.001563.json
# ThresholdS: [[0.95, [9500, 500], -9898610.36098381], [0.99, [9900, 100], -9865185.090863047]]
# Null distribution computed in 106.82872202899307 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 47.74211391992867 seconds.
# statistic = 10650730.865586773 - next threshold = -9898610.36098381 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 54.64374684856751
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.00078125 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 106.03161023417488 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_cov_off_diag_0.000781.json
# ThresholdS: [[0.95, [9500, 500], -2635754.1689952337], [0.99, [9900, 100], -2626248.1930126986]]
# Null distribution computed in 106.59034062898718 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 47.81002835696563 seconds.
# statistic = 2747134.3260902865 - next threshold = -2635754.1689952337 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 96.65794402663157
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.000390625 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 103.85058317193761 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_cov_off_diag_0.000391.json
# ThresholdS: [[0.95, [9500, 500], -680509.7068295616], [0.99, [9900, 100], -677880.2131834825]]
# Null distribution computed in 104.31606785999611 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 46.668049320112914 seconds.
# statistic = 697908.2699498493 - next threshold = -680509.7068295616 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 158.45193275438893
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.0001953125 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# ...
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 97.15339936106466 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_power_abs_down_0.000015.json
# ThresholdS: [[0.95, [9500, 500], 1.6965414078926335], [0.99, [9900, 100], 3.85354556414867]]
# Null distribution computed in 97.45591344381683 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 81.57965316204354 seconds.
# statistic = 3.967588556207028 - next threshold = 3.85354556414867 at 0.99 CL
# relative_error_eps = 0.025353017155666097
# relative_error_metric = 0.02916277621720967
#
# ------------ 19 - 0.99 CL ------------
# eps = 1.5043232360767435e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 96.74019759194925 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_power_abs_down_0.000015.json
# ThresholdS: [[0.95, [9500, 500], 1.7237833958345692], [0.99, [9900, 100], 3.847475424219439]]
# Null distribution computed in 97.04100649803877 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 80.38336871215142 seconds.
# statistic = 3.8518981342256122 - next threshold = 3.847475424219439 at 0.99 CL
# relative_error_eps = 0.012757368020403715
# relative_error_metric = 0.0011488493115968611
#
# ------------ 20 - 0.99 CL ------------
# eps = 1.4947884528737633e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 95.40118867508136 seconds.
# Saving lr to results/20D_mixture/20D_100K/null_hypothesis/LR_power_abs_down_0.000015.json
# ThresholdS: [[0.95, [9500, 500], 1.7303272597556179], [0.99, [9900, 100], 3.8456893158536203]]
# Null distribution computed in 95.69945745682344 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 81.86994971288368 seconds.
# statistic = 3.823241876611995 - next threshold = 3.8456893158536203 at 0.99 CL
# relative_error_eps = 0.006358404882424901
# relative_error_metric = 0.005854124565279452
# =======> statistic within required accuracy at 0.99 CL in 3549.2278097979724 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 7095.315985916182 seconds.
# Saving results in the file results/20D_mixture/20D_100K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-04-30T14:55:37.757852', 'fgd_cov_diag_2024-04-30T15:54:07.330150', 'fgd_cov_off_diag_2024-04-30T16:34:46.765004', 'fgd_power_abs_up_2024-04-30T17:09:35.619671', 'fgd_power_abs_down_2024-04-30T17:56:08.868849', 'fgd_random_normal_2024-04-30T18:41:40.891987', 'fgd_random_uniform_2024-04-30T19:14:52.605679', 'mmd_mean_2024-04-30T19:41:41.708956', 'mmd_cov_diag_2024-04-30T20:20:13.166013', 'mmd_cov_off_diag_2024-04-30T21:07:06.416210', 'mmd_power_abs_up_2024-04-30T21:48:41.106332', 'mmd_power_abs_down_2024-04-30T22:40:38.366229', 'mmd_random_normal_2024-04-30T23:32:30.364881', 'mmd_random_uniform_2024-05-01T00:01:08.009314', 'ks_mean_2024-05-01T00:29:36.420345', 'ks_cov_diag_2024-05-01T01:10:13.908027', 'ks_cov_off_diag_2024-05-01T01:56:32.493743', 'ks_power_abs_up_2024-05-01T02:32:29.790764', 'ks_power_abs_down_2024-05-01T03:22:48.843623', 'ks_random_normal_2024-05-01T04:12:55.578065', 'ks_random_uniform_2024-05-01T04:52:17.230015', 'sks_mean_2024-05-01T05:29:10.151081', 'sks_cov_diag_2024-05-01T06:02:23.259323', 'sks_cov_off_diag_2024-05-01T06:41:43.104472', 'sks_power_abs_up_2024-05-01T07:14:00.915347', 'sks_power_abs_down_2024-05-01T07:55:33.675876', 'sks_random_normal_2024-05-01T08:41:10.711549', 'sks_random_uniform_2024-05-01T09:08:40.591334', 'swd_mean_2024-05-01T09:32:29.639411', 'swd_cov_diag_2024-05-01T10:02:23.315643', 'swd_cov_off_diag_2024-05-01T10:37:34.597177', 'swd_power_abs_up_2024-05-01T11:05:41.720187', 'swd_power_abs_down_2024-05-01T11:44:50.165456', 'swd_random_normal_2024-05-01T12:23:53.319036', 'swd_random_uniform_2024-05-01T12:48:14.545001', 'lr_mean_2024-05-01T13:09:50.599932', 'lr_cov_diag_2024-05-01T14:31:39.380955', 'lr_cov_off_diag_2024-05-01T19:57:53.549218', 'lr_power_abs_up_2024-05-01T21:56:49.447807', 'lr_power_abs_down_2024-05-02T00:01:11.738957'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean   20  10000               100000
# 14        ks        mean   20  10000               100000
# 21       sks        mean   20  10000               100000
# 7        mmd        mean   20  10000               100000
# 28       swd        mean   20  10000               100000
# 0        fgd        mean   20  10000               100000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.00016                             0.00023
# 14                             0.00351                             0.00488
# 21                             0.02563                             0.03491
# 7                              0.03247                             0.04357
# 28                             0.03589                             0.04954
# 0                              0.04181                             0.05664
#
#     $t^{\mu}$ (s)
# 35           4908
# 14           2437
# 21           1993
# 7            2311
# 28           1793
# 0            2564
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.00016
# 14        ks                             0.00351
# 21       sks                             0.02563
# 7        mmd                             0.03247
# 28       swd                             0.03589
# 0        fgd                             0.04181
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.00023           4908
# 14                             0.00488           2437
# 21                             0.03491           1993
# 7                              0.04357           2311
# 28                             0.04954           1793
# 0                              0.05664           2564

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag   20  10000               100000
# 15        ks    cov_diag   20  10000               100000
# 22       sks    cov_diag   20  10000               100000
# 8        mmd    cov_diag   20  10000               100000
# 29       swd    cov_diag   20  10000               100000
# 1        fgd    cov_diag   20  10000               100000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00004
# 15                                     0.00086
# 22                                     0.00702
# 8                                      0.00787
# 29                                     0.01019
# 1                                      0.01093
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00005                   5460
# 15                                     0.00121                   2778
# 22                                     0.00926                   2359
# 8                                      0.01033                   2813
# 29                                     0.01418                   2111
# 1                                      0.01491                   2439
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00004
# 15        ks                                     0.00086
# 22       sks                                     0.00702
# 8        mmd                                     0.00787
# 29       swd                                     0.01019
# 1        fgd                                     0.01093
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00005                   5460
# 15                                     0.00121                   2778
# 22                                     0.00926                   2359
# 8                                      0.01033                   2813
# 29                                     0.01418                   2111
# 1                                      0.01491                   2439

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag   20  10000               100000
# 16        ks  cov_off_diag   20  10000               100000
# 23       sks  cov_off_diag   20  10000               100000
# 9        mmd  cov_off_diag   20  10000               100000
# 2        fgd  cov_off_diag   20  10000               100000
# 30       swd  cov_off_diag   20  10000               100000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00000
# 16                                          0.00002
# 23                                          0.00020
# 9                                           0.00024
# 2                                           0.00028
# 30                                          0.00030
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00000
# 16                                          0.00002
# 23                                          0.00027
# 9                                           0.00031
# 2                                           0.00038
# 30                                          0.00042
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        7135
# 16                        2157
# 23                        1937
# 9                         2494
# 2                         2088
# 30                        1687
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00000
# 16        ks                                          0.00002
# 23       sks                                          0.00020
# 9        mmd                                          0.00024
# 2        fgd                                          0.00028
# 30       swd                                          0.00030
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00000
# 16                                          0.00002
# 23                                          0.00027
# 9                                           0.00031
# 2                                           0.00038
# 30                                          0.00042
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        7135
# 16                        2157
# 23                        1937
# 9                         2494
# 2                         2088
# 30                        1687

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up   20  10000               100000
# 17        ks  power_abs_up   20  10000               100000
# 10       mmd  power_abs_up   20  10000               100000
# 24       sks  power_abs_up   20  10000               100000
# 31       swd  power_abs_up   20  10000               100000
# 3        fgd  power_abs_up   20  10000               100000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00001
# 17                                      0.00028
# 10                                      0.00267
# 24                                      0.00320
# 31                                      0.00430
# 3                                       0.00486
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00002                    7462
# 17                                      0.00043                    3019
# 10                                      0.00351                    3117
# 24                                      0.00421                    2492
# 31                                      0.00603                    2348
# 3                                       0.00674                    2793
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00001
# 17        ks                                      0.00028
# 10       mmd                                      0.00267
# 24       sks                                      0.00320
# 31       swd                                      0.00430
# 3        fgd                                      0.00486
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00002                    7462
# 17                                      0.00043                    3019
# 10                                      0.00351                    3117
# 24                                      0.00421                    2492
# 31                                      0.00603                    2348
# 3                                       0.00674                    2793

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down   20  10000               100000
# 18        ks  power_abs_down   20  10000               100000
# 11       mmd  power_abs_down   20  10000               100000
# 25       sks  power_abs_down   20  10000               100000
# 32       swd  power_abs_down   20  10000               100000
# 4        fgd  power_abs_down   20  10000               100000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00001
# 18                                      0.00029
# 11                                      0.00261
# 25                                      0.00298
# 32                                      0.00424
# 4                                       0.00491
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00001                    7095
# 18                                      0.00043                    3006
# 11                                      0.00348                    3111
# 25                                      0.00398                    2565
# 32                                      0.00597                    2343
# 4                                       0.00684                    2732
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00001
# 18        ks                                      0.00029
# 11       mmd                                      0.00261
# 25       sks                                      0.00298
# 32       swd                                      0.00424
# 4        fgd                                      0.00491
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00001                    7095
# 18                                      0.00043                    3006
# 11                                      0.00348                    3111
# 25                                      0.00398                    2565
# 32                                      0.00597                    2343
# 4                                       0.00684                    2732

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 19        ks  random_normal   20  10000               100000
# 26       sks  random_normal   20  10000               100000
# 5        fgd  random_normal   20  10000               100000
# 33       swd  random_normal   20  10000               100000
# 12       mmd  random_normal   20  10000               100000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 19                                     0.00601
# 26                                     0.13184
# 5                                      0.15137
# 33                                     0.16309
# 12                                     0.38184
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 19                                     0.00789                   2361
# 26                                     0.15473                   1649
# 5                                      0.17820                   1991
# 33                                     0.19087                   1461
# 12                                     0.44220                   1717
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 19        ks                                     0.00601
# 26       sks                                     0.13184
# 5        fgd                                     0.15137
# 33       swd                                     0.16309
# 12       mmd                                     0.38184
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 19                                     0.00789                   2361
# 26                                     0.15473                   1649
# 5                                      0.17820                   1991
# 33                                     0.19087                   1461
# 12                                     0.44220                   1717

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 20        ks  random_uniform   20  10000               100000
# 27       sks  random_uniform   20  10000               100000
# 6        fgd  random_uniform   20  10000               100000
# 34       swd  random_uniform   20  10000               100000
# 13       mmd  random_uniform   20  10000               100000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 20                                     0.00995
# 27                                     0.22852
# 6                                      0.26270
# 34                                     0.27930
# 13                                     0.66113
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 20                                     0.01273                   2212
# 27                                     0.26619                   1429
# 6                                      0.30734                   1609
# 34                                     0.33279                   1295
# 13                                     0.76571                   1708
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 20        ks                                     0.00995
# 27       sks                                     0.22852
# 6        fgd                                     0.26270
# 34       swd                                     0.27930
# 13       mmd                                     0.66113
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 20                                     0.01273                   2212
# 27                                     0.26619                   1429
# 6                                      0.30734                   1609
# 34                                     0.33279                   1295
# 13                                     0.76571                   1708

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.042 & 0.057 & 2564 & cov_diag & 20 & 10000 & 100000 & 0.011 & 0.015 & 2439 & cov_off_diag & 20 & 10000 & 100000 & 0.00028 & 0.00038 & 2088 & 0.0049 & 0.0067 & 2793 \\
# $\overline{D}$ & 0.0035 & 0.0049 & 2437 & cov_diag & 20 & 10000 & 100000 & 0.00086 & 0.0012 & 2778 & cov_off_diag & 20 & 10000 & 100000 & 2e-05 & 2e-05 & 2157 & 0.00028 & 0.00043 & 3019 \\
# $t_{\mathrm{LLR}}$ & 0.00016 & 0.00023 & 4908 & cov_diag & 20 & 10000 & 100000 & 4e-05 & 5e-05 & 5460 & cov_off_diag & 20 & 10000 & 100000 & 0 & 0 & 7135 & 1e-05 & 2e-05 & 7462 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.032 & 0.044 & 2311 & cov_diag & 20 & 10000 & 100000 & 0.0079 & 0.01 & 2813 & cov_off_diag & 20 & 10000 & 100000 & 0.00024 & 0.00031 & 2494 & 0.0027 & 0.0035 & 3117 \\
# $\widetilde{D}$ & 0.026 & 0.035 & 1993 & cov_diag & 20 & 10000 & 100000 & 0.007 & 0.0093 & 2359 & cov_off_diag & 20 & 10000 & 100000 & 0.0002 & 0.00027 & 1937 & 0.0032 & 0.0042 & 2492 \\
# $\widetilde{W}$ & 0.036 & 0.05 & 1793 & cov_diag & 20 & 10000 & 100000 & 0.01 & 0.014 & 2111 & cov_off_diag & 20 & 10000 & 100000 & 0.0003 & 0.00042 & 1687 & 0.0043 & 0.006 & 2348 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.0049 & 0.0068 & 2732 & 0.15 & 0.18 & 2e+03 & 0.26 & 0.31 & 1.6e+03 & 5527 \\
# $\overline{D}$ & 0.00029 & 0.00043 & 3006 & 0.006 & 0.0079 & 2.4e+03 & 0.01 & 0.013 & 2.2e+03 & 277 \\
# $t_{\mathrm{LLR}}$ & 1e-05 & 1e-05 & 7095 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.0026 & 0.0035 & 3111 & 0.38 & 0.44 & 1.7e+03 & 0.66 & 0.77 & 1.7e+03 & 16652 \\
# $\widetilde{D}$ & 0.003 & 0.004 & 2565 & 0.13 & 0.15 & 1.6e+03 & 0.23 & 0.27 & 1.4e+03 & 736 \\
# $\widetilde{W}$ & 0.0042 & 0.006 & 2343 & 0.16 & 0.19 & 1.5e+03 & 0.28 & 0.33 & 1.3e+03 & 404 \\
# \bottomrule
# \end{tabular}
