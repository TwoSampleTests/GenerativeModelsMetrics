# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [2]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/20D_mixture/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-04 09:09:02.337332: Importing os...
# 2024-05-04 09:09:02.337453: Importing sys...
# Visible devices: [2]
# 2024-05-04 09:09:02.337688: Importing timer from timeit...
# 2024-05-04 09:09:02.337757: Setting env variables for tf import (only device(s) [2] will be available)...
# 2024-05-04 09:09:02.337892: Importing numpy...
# 2024-05-04 09:09:02.454615: Importing matplotlib...
# 2024-05-04 09:09:02.801920: Importing h5py...
# 2024-05-04 09:09:02.824679: Importing importlib.util...
# 2024-05-04 09:09:02.824780: Importing json...
# 2024-05-04 09:09:02.824844: Importing pandas...
# 2024-05-04 09:09:03.256814: Importing random...
# 2024-05-04 09:09:03.256956: Importing scipy utils...
# 2024-05-04 09:09:03.658392: Importing subprocess...
# 2024-05-04 09:09:03.658529: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-04 09:09:06.886751: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-04 09:09:08.004269: Importing timeit...
# 2024-05-04 09:09:08.004359: Importing tqdm...
# 2024-05-04 09:09:08.012039: Importing typing...
# 2024-05-04 09:09:08.012144: Setting tf configs...
# 2024-05-04 09:09:08.101454: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-04 09:09:12.651134: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #2, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-04 09:09:12.680697: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 10_000
dist_1 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
dist_2 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture.Mixture'> <class 'tensorflow_probability.python.distributions.mixture.Mixture'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...       20           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True       20           0  float64    20  200000000         False
#
#    ncomp
# 0      5
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 500,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/20D_mixture/20D_20K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 2,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/20D_mixture/20D_20K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 10000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/20D_mixture/20D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/20D_mixture/20D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/20D_mixture/20D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 500,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/20D_mixture/20D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fgd from results/20D_mixture/20D_20K/null_hypothesis/FGD.json
# Loading mmd from results/20D_mixture/20D_20K/null_hypothesis/MMD.json
# Loading ks from results/20D_mixture/20D_20K/null_hypothesis/KS.json
# Loading sks from results/20D_mixture/20D_20K/null_hypothesis/SKS.json
# Loading swd from results/20D_mixture/20D_20K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0034455522800551485], [0.95, [9500, 500], 0.03004778280334781], [0.99, [9900, 100], 0.054289305547389234]]
# Computing time for metric fgd: 2033.9952914591413
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.03528078810404622], [0.95, [9500, 500], 0.6167642792718198], [0.99, [9900, 100], 1.2566289135268107]]
# Computing time for metric mmd: 2347.0404497301206
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9172505140304565], [0.95, [9500, 500], 1.1547505110502243], [0.99, [9900, 100], 1.3217499107122421]]
# Computing time for metric ks: 193.22769812797196
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.91210026293993], [0.95, [9500, 500], 1.1182505637407303], [0.99, [9900, 100], 1.2537500821053982]]
# Computing time for metric sks: 457.7144865691662
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.6304276846894187], [0.95, [9500, 500], 0.8819261865494903], [0.99, [9900, 100], 1.0511501574645423]]
# Computing time for metric swd: 328.93139816005714
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fb59c01d260>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fb59c01d440>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fb59c01d4e0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fb59c01d580>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fb59c01d620>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fb59c01d6c0>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_mixture/20D_20K/null_hypothesis/FG...
# 1  $d_{\mathrm{MMD}}$  results/20D_mixture/20D_20K/null_hypothesis/MM...
# 2      $\overline{D}$  results/20D_mixture/20D_20K/null_hypothesis/KS...
# 3     $\widetilde{D}$  results/20D_mixture/20D_20K/null_hypothesis/SK...
# 4     $\widetilde{W}$  results/20D_mixture/20D_20K/null_hypothesis/SW...
# 5           $t_{\mu}$  results/20D_mixture/20D_20K/null_hypothesis/LR...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0034455522800551485], ...
# 1  [[0.68, [6800, 3199], 0.03528078810404622], [0...
# 2  [[0.68, [6800, 3199], 0.9172505140304565], [0....
# 3  [[0.68, [6800, 3199], 0.91210026293993], [0.95...
# 4  [[0.68, [6800, 3199], 0.6304276846894187], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10)$"
        dist_null = dist_null * 10
    #elif "MMD" in latex:
    #    latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-2})$"
    #    dist_null = dist_null / 100
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 10
        #elif "MMD" in latex:
        #    threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 10
        #elif "MMD" in latex:
        #    threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.05874716324871679 +/- 0.00013624214133281897
# sigma = 0.1167228089675788 +/- 0.002236516689913373
# 68%CL = 0.03445552280055149, 95%CL = 0.3004778280334781, 99%CL = 0.5428930554738923
# mu = 0.05874716324871679 +/- 0.00013624214133281897
# sigma = 0.1167228089675788 +/- 0.002236516689913373
# /tmp/ipykernel_3230864/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_3230864/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_3230864/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.5014281880576164 seconds.
# mu = 0.0042482431527197835 +/- 0.0010437037674154751
# sigma = 0.32306404433416525 +/- 0.005888579329615179
# 68%CL = 0.03528078810404622, 95%CL = 0.6167642792718198, 99%CL = 1.2566289135268107
# mu = 0.0042482431527197835 +/- 0.0010437037674154751
# sigma = 0.32306404433416525 +/- 0.005888579329615179
# /tmp/ipykernel_3230864/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_3230864/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_3230864/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.8921222391072661 seconds.
# mu = 0.8681718004113064 +/- 0.00022745355778862987
# sigma = 0.150815635061034 +/- 0.0013224381304944007
# 68%CL = 0.9172505140304565, 95%CL = 1.1547505110502243, 99%CL = 1.3217499107122421
# mu = 0.8681718004113064 +/- 0.00022745355778862987
# sigma = 0.150815635061034 +/- 0.0013224381304944007
# /tmp/ipykernel_3230864/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_3230864/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_3230864/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_3230864/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2459089569747448 seconds.
# mu = 0.8677030140673742 +/- 0.0001795401844630158
# sigma = 0.13399260593891582 +/- 0.0011368433719734755
# 68%CL = 0.91210026293993, 95%CL = 1.1182505637407303, 99%CL = 1.2537500821053982
# mu = 0.8677030140673742 +/- 0.0001795401844630158
# sigma = 0.13399260593891582 +/- 0.0011368433719734755
# /tmp/ipykernel_3230864/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_3230864/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_3230864/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_3230864/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2891873780172318 seconds.
# mu = 0.5762674237908137 +/- 0.00025898294779007846
# sigma = 0.16092947144326253 +/- 0.0013784779775846171
# 68%CL = 0.6304276846894187, 95%CL = 0.8819261865494903, 99%CL = 1.0511501574645423
# mu = 0.5762674237908137 +/- 0.00025898294779007846
# sigma = 0.16092947144326253 +/- 0.0013784779775846171
# /tmp/ipykernel_3230864/197952925.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_3230864/197952925.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_3230864/197952925.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_3230864/197952925.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.8966664648614824 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fb59c01d260>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fb59c01d440>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fb59c01d4e0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fb59c01d580>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fb59c01d620>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fb59c01d6c0>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_mixture/20D_20K/null_hypothesis/FG...
# 1  $d_{\mathrm{MMD}}$  results/20D_mixture/20D_20K/null_hypothesis/MM...
# 2      $\overline{D}$  results/20D_mixture/20D_20K/null_hypothesis/KS...
# 3     $\widetilde{D}$  results/20D_mixture/20D_20K/null_hypothesis/SK...
# 4     $\widetilde{W}$  results/20D_mixture/20D_20K/null_hypothesis/SW...
# 5           $t_{\mu}$  results/20D_mixture/20D_20K/null_hypothesis/LR...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0034455522800551485], ...
# 1  [[0.68, [6800, 3199], 0.03528078810404622], [0...
# 2  [[0.68, [6800, 3199], 0.9172505140304565], [0....
# 3  [[0.68, [6800, 3199], 0.91210026293993], [0.95...
# 4  [[0.68, [6800, 3199], 0.6304276846894187], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/20D_mixture/20D_20K/null_hypothesis/FG...
# 1  results/20D_mixture/20D_20K/null_hypothesis/MM...
# 2  results/20D_mixture/20D_20K/null_hypothesis/KS...
# 3  results/20D_mixture/20D_20K/null_hypothesis/SK...
# 4  results/20D_mixture/20D_20K/null_hypothesis/SW...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for fgd with mean deformation already loaded.
# Exclusion limits for fgd with cov_diag deformation already loaded.
# Exclusion limits for fgd with cov_off_diag deformation already loaded.
# Exclusion limits for fgd with power_abs_up deformation already loaded.
# Exclusion limits for fgd with power_abs_down deformation already loaded.
# Exclusion limits for fgd with random_normal deformation already loaded.
# Exclusion limits for fgd with random_uniform deformation already loaded.
# Exclusion limits for mmd with mean deformation already loaded.
# Exclusion limits for mmd with cov_diag deformation already loaded.
# Exclusion limits for mmd with cov_off_diag deformation already loaded.
# Exclusion limits for mmd with power_abs_up deformation already loaded.
# Exclusion limits for mmd with power_abs_down deformation already loaded.
# Exclusion limits for mmd with random_normal deformation already loaded.
# Exclusion limits for mmd with random_uniform deformation already loaded.
# Exclusion limits for ks with mean deformation already loaded.
# Exclusion limits for ks with cov_diag deformation already loaded.
# Exclusion limits for ks with cov_off_diag deformation already loaded.
# Exclusion limits for ks with power_abs_up deformation already loaded.
# Exclusion limits for ks with power_abs_down deformation already loaded.
# Exclusion limits for ks with random_normal deformation already loaded.
# Exclusion limits for ks with random_uniform deformation already loaded.
# Exclusion limits for sks with mean deformation already loaded.
# Exclusion limits for sks with cov_diag deformation already loaded.
# Exclusion limits for sks with cov_off_diag deformation already loaded.
# Exclusion limits for sks with power_abs_up deformation already loaded.
# Exclusion limits for sks with power_abs_down deformation already loaded.
# Exclusion limits for sks with random_normal deformation already loaded.
# Exclusion limits for sks with random_uniform deformation already loaded.
# Exclusion limits for swd with mean deformation already loaded.
# Exclusion limits for swd with cov_diag deformation already loaded.
# Exclusion limits for swd with cov_off_diag deformation already loaded.
# Computing exclusion limits for swd with power_abs_up deformation.
#
# ======================================================
# =============== swd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_up
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714806564.142760 3230864 service.cc:145] XLA service 0xc17556f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714806564.142805 3230864 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1714806564.241009 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1714806564.246638 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1714806564.250518 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1714806564.250879 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1714806564.251864 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1714806564.251939 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1714806564.252010 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1714806564.252084 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1714806564.252155 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1714806564.252226 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1714806564.252296 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1714806564.252367 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1714806564.252436 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_25/Assert/Assert
# W0000 00:00:1714806564.252506 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_27/Assert/Assert
# W0000 00:00:1714806564.252575 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_29/Assert/Assert
# W0000 00:00:1714806564.252645 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_31/Assert/Assert
# W0000 00:00:1714806564.252712 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_33/Assert/Assert
# W0000 00:00:1714806564.252784 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_35/Assert/Assert
# W0000 00:00:1714806564.252854 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_37/Assert/Assert
# W0000 00:00:1714806564.252923 3230864 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_39/Assert/Assert
# I0000 00:00:1714806604.711715 3230864 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# statistic = 1786.1356975004069 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9980259261579527
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_up
# statistic = 225.8329195778148 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9844399040816918
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_up
# WARNING:tensorflow:5 out of the last 5 calls to <function generate_and_clean_data_simple_1 at 0x7fb686348ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function generate_and_clean_data_simple_1 at 0x7fb686348ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 63.47875482425583 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9451885112028924
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_up
# statistic = 24.557189404629504 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8613275397270026
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_up
# WARNING:tensorflow:5 out of the last 5 calls to <function SWDMetric.Test_tf.<locals>.batched_test_sub at 0x7fb43c263880> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 10.928112096615823 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7012960786734663
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_up
# WARNING:tensorflow:6 out of the last 6 calls to <function SWDMetric.Test_tf.<locals>.batched_test_sub at 0x7fb41c3acae0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 5.226432413814965 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4224791016710314
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_up
# statistic = 2.642407612021035 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9990435220327872
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_up
# statistic = 1.4441487890898494 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.483408839722226
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.9018481815240368 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.022336900149610532
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.6818497689489545 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2558888527439501
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00732421875 - deformation = power_abs_up
# statistic = 0.7838286750405675 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.11778145004515624
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.008544921875 - deformation = power_abs_up
# statistic = 0.8412997116371774 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.04715165313504593
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0091552734375 - deformation = power_abs_up
# statistic = 0.871232971064424 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.012198796029015397
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00946044921875 - deformation = power_abs_up
# statistic = 0.886461491937504 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.0051293112287392325
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.009307861328125 - deformation = power_abs_up
# statistic = 0.8788266153369225 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.016260162601626018
# relative_error_metric = 0.0035207340965148375
# =======> statistic within required accuracy at 0.95 CL in 1245.866638201056 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0093841552734375 - deformation = power_abs_up
# statistic = 0.8826389451152368 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.9925067393655096
# relative_error_metric = 0.1742808583671327
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5046920776367188 - deformation = power_abs_up
# statistic = 1799.6342486794533 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.9850694181018131
# relative_error_metric = 1.9976649998758398
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2570381164550781 - deformation = power_abs_up
# statistic = 228.6852279013648 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.9703601066313237
# relative_error_metric = 1.9816981504392766
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6332111358642578 - deformation = power_abs_up
# statistic = 64.76699875675746 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.941585907006426
# relative_error_metric = 1.936117914295374
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.32129764556884766 - deformation = power_abs_up
# statistic = 25.42297215483523 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.886487187991175
# relative_error_metric = 1.8411807356535206
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16534090042114258 - deformation = power_abs_up
# statistic = 11.636919969598722 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.7851674967592277
# relative_error_metric = 1.668617797052533
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08736252784729004 - deformation = power_abs_up
# statistic = 5.864703771642737 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.6120112867651588
# relative_error_metric = 1.3920344945167293
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04837334156036377 - deformation = power_abs_up
# statistic = 3.239642965878388 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.3500995861755813
# relative_error_metric = 1.0200877765501797
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.028878748416900635 - deformation = power_abs_up
# statistic = 2.0063044849338976 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.0189813769092368
# relative_error_metric = 0.624803595921919
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.019131451845169067 - deformation = power_abs_up
# statistic = 1.4207616343428298 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.6836464348235048
# relative_error_metric = 0.299049082660058
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.014257803559303284 - deformation = power_abs_up
# statistic = 1.1421689507413326 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.4122880274299833
# relative_error_metric = 0.0829963984139483
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.011820979416370392 - deformation = power_abs_up
# statistic = 1.0090076994022448 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.18688173794045257
# relative_error_metric = 0.04091187276919678
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.013039391487836838 - deformation = power_abs_up
# statistic = 1.0749188138303696 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.0980204258545675
# relative_error_metric = 0.022359252391845618
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.012430185452103615 - deformation = power_abs_up
# statistic = 1.041777562532791 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.04783793913576071
# relative_error_metric = 0.008956443972908245
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.012734788469970226 - deformation = power_abs_up
# statistic = 1.0583049159874207 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.02420849064337192
# relative_error_metric = 0.006783513536669137
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.01258248696103692 - deformation = power_abs_up
# statistic = 1.0500333279556027 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.012031429633757161
# relative_error_metric = 0.0010630480552404845
# =======> statistic within required accuracy at 0.99 CL in 1328.4550090858247 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2574.321681866888 seconds.
# Saving results in the file results/20D_mixture/20D_20K/exclusion_limits.json
# Computing exclusion limits for swd with power_abs_down deformation.
#
# ======================================================
# =============== swd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_down
# statistic = 15447.84101674835 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999771650720954
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_down
# statistic = 32.805505482424365 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8952812793547873
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_down
# statistic = 25.261568884648522 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.865063766853255
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_down
# statistic = 15.529850388946747 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.785050403899293
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_down
# statistic = 8.694568319875374 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6316288028117985
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_down
# statistic = 4.6631444517757705 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3638124784532213
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_down
# statistic = 2.494551337531462 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9552115418987804
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_down
# statistic = 1.3999439586055449 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.45402914197894406
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.887831826153521 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.006673951536471129
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.6760975482479528 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2642175901489679
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00732421875 - deformation = power_abs_down
# statistic = 0.7747552075038568 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.12938031347526852
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.008544921875 - deformation = power_abs_down
# statistic = 0.8299333405066103 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.06074429031252647
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0091552734375 - deformation = power_abs_down
# statistic = 0.8585788507469148 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.026828231234356972
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00946044921875 - deformation = power_abs_down
# statistic = 0.8731352595105638 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.031746031746031744
# relative_error_metric = 0.010017799728506681
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.009613037109375 - deformation = power_abs_down
# statistic = 0.8804665426258422 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.015748031496062992
# relative_error_metric = 0.0016564343457443349
# =======> statistic within required accuracy at 0.95 CL in 1244.7892483179457 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0096893310546875 - deformation = power_abs_down
# statistic = 0.8841450333649137 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.9922635274050835
# relative_error_metric = 0.17258878634225433
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5048446655273438 - deformation = power_abs_down
# statistic = 16259.465529900002 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.9845866771849447
# relative_error_metric = 1.9997414226919978
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2572669982910156 - deformation = power_abs_down
# statistic = 32.78118349960566 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.96940910801656
# relative_error_metric = 1.8757224177180134
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6334781646728516 - deformation = power_abs_down
# statistic = 25.465653652954487 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.9397399208196795
# relative_error_metric = 1.8414363714451105
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.32158374786376953 - deformation = power_abs_down
# statistic = 15.881588925999592 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.8830049083816736
# relative_error_metric = 1.751688099064597
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16563653945922852 - deformation = power_abs_down
# statistic = 9.150009818227542 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.7789412132667908
# relative_error_metric = 1.5878311250997792
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08766293525695801 - deformation = power_abs_down
# statistic = 5.178506758749637 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.6018857527704646
# relative_error_metric = 1.3250670644614977
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.048676133155822754 - deformation = power_abs_down
# statistic = 3.035244447121905 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.3359544939287793
# relative_error_metric = 0.971073271989188
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.029182732105255127 - deformation = power_abs_down
# statistic = 1.9377079284483192 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.0029517070066625
# relative_error_metric = 0.5932417970343367
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.019436031579971313 - deformation = power_abs_down
# statistic = 1.3947221336210827 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.6692929902740756
# relative_error_metric = 0.28094024157250047
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.014562681317329407 - deformation = power_abs_down
# statistic = 1.1319716636055326 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.4018924440484785
# relative_error_metric = 0.07404214035236471
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.012126006186008453 - deformation = power_abs_down
# statistic = 1.0053834289256771 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.18259984729606557
# relative_error_metric = 0.04450861278584647
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.01334434375166893 - deformation = power_abs_down
# statistic = 1.068144844684463 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.09566712421632129
# relative_error_metric = 0.016038057186647223
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.012735174968838692 - deformation = power_abs_down
# statistic = 1.0366181210584027 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.04671625955667799
# relative_error_metric = 0.013921120035812383
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.013039759360253811 - deformation = power_abs_down
# statistic = 1.0523469260540461 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.023634154603554572
# relative_error_metric = 0.0011378847148215863
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.012887467164546251 - deformation = power_abs_down
# statistic = 1.044473646994065 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.011747665764549723
# relative_error_metric = 0.006371859735771791
# =======> statistic within required accuracy at 0.99 CL in 1327.479630884016 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 2572.2689142171293 seconds.
# Saving results in the file results/20D_mixture/20D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 23.105077903643245 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8529326658329839
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 9.25308222561382 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6519287796580155
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 3.3622918537900977 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1688210377816257
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 1.1631372560146085 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.27501451897505536
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 0.6419557750993704 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.3149461933265076
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.234375 - deformation = random_normal
# statistic = 0.8285699396488727 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.062386866691365964
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.2734375 - deformation = random_normal
# statistic = 0.9816149342429064 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.10698851405117092
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.25390625 - deformation = random_normal
# statistic = 0.9020910545097756 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.02260613574374687
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.244140625 - deformation = random_normal
# statistic = 0.8678439959567521 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.0392156862745098
# relative_error_metric = 0.01609604590766073
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.2490234375 - deformation = random_normal
# statistic = 0.8826132051306405 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.019801980198019802
# relative_error_metric = 0.0007786945243495108
# =======> statistic within required accuracy at 0.95 CL in 830.2890412269626 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.24658203125 - deformation = random_normal
# statistic = 0.8741904118897704 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.8120055839925546
# relative_error_metric = 0.1838217595281001
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.623291015625 - deformation = random_normal
# statistic = 24.635970566342795 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.6563164610803913
# relative_error_metric = 1.836314833606039
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.4349365234375 - deformation = random_normal
# statistic = 11.135524812978193 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.4134301270417422
# relative_error_metric = 1.6549837720251088
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.84075927734375 - deformation = random_normal
# statistic = 5.267326119958175 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.0928992422116195
# relative_error_metric = 1.334554654437476
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.543670654296875 - deformation = random_normal
# statistic = 2.6954661313240678 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.751882602819077
# relative_error_metric = 0.8777605429090688
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.3951263427734375 - deformation = random_normal
# statistic = 1.635301260352344 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.46296516466531923
# relative_error_metric = 0.4348867796481541
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.32085418701171875 - deformation = random_normal
# statistic = 1.2010973243972902 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.261781512605042
# relative_error_metric = 0.1331533662622131
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.2837181091308594 - deformation = random_normal
# statistic = 1.028924250941884 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.12285074297252106
# relative_error_metric = 0.021370299478551617
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.30228614807128906 - deformation = random_normal
# statistic = 1.1118551663722043 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.06337168616856803
# relative_error_metric = 0.056130244561750024
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.2930021286010742 - deformation = random_normal
# statistic = 1.065682069892166 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.03219592052717306
# relative_error_metric = 0.013729866958582516
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.2883601188659668 - deformation = random_normal
# statistic = 1.0431262985608347 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.01596942269757752
# relative_error_metric = 0.007662654928505174
# =======> statistic within required accuracy at 0.99 CL in 915.3761132708751 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1745.6651898759883 seconds.
# Saving results in the file results/20D_mixture/20D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_uniform
# W0000 00:00:1714813496.862308 3230864 random_ops.cc:59] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. while/random_shiftMixture_CONSTRUCTED_AT_top_level/sample/random_shift/forward/random_uniform/RandomUniform
# statistic = 11.330296009883538 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7111332655551958
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_uniform
# statistic = 4.228778578311936 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3097420202292562
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_uniform
# statistic = 1.4348386299563634 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4773142612211938
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_uniform
# statistic = 0.6839523854297532 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2528597104046217
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_uniform
# statistic = 0.9705976198981751 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.09573041171192073
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.390625 - deformation = random_uniform
# statistic = 0.8048719912527911 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.09136148747456277
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.4296875 - deformation = random_uniform
# statistic = 0.8813998225357702 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.0005970127032755985
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.44921875 - deformation = random_uniform
# statistic = 0.927589910415268 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.05047064675729933
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.439453125 - deformation = random_uniform
# statistic = 0.9020168482255853 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.02247191011235955
# relative_error_metric = 0.02252388252815265
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.4345703125 - deformation = random_uniform
# statistic = 0.8907669478101579 - next threshold = 0.8819261865494903 at 0.95 CL
# relative_error_eps = 0.011299435028248588
# relative_error_metric = 0.00997438427363361
# =======> statistic within required accuracy at 0.95 CL in 833.6543539089616 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.43212890625 - deformation = random_uniform
# statistic = 0.8861302924727293 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.6817977528089887
# relative_error_metric = 0.17036239125538716
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.716064453125 - deformation = random_uniform
# statistic = 12.633374640401987 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.4509499806126405
# relative_error_metric = 1.6927477795565335
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.5740966796875 - deformation = random_uniform
# statistic = 5.960201078351239 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 1.1384240949193793
# relative_error_metric = 1.4003152190721824
#
# ------------ 4 - 0.99 CL ------------
# eps = 1.00311279296875 - deformation = random_uniform
# statistic = 3.0085541347721545 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.7956623431852009
# relative_error_metric = 0.9643086473321332
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.717620849609375 - deformation = random_uniform
# statistic = 1.7654007854349536 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.49661579296615793
# relative_error_metric = 0.5071810469262286
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.5748748779296875 - deformation = random_uniform
# statistic = 1.2646736272977541 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.28350632623683614
# relative_error_metric = 0.18440390088240546
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.5035018920898438 - deformation = random_uniform
# statistic = 1.0619720568569462 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.15256655930199373
# relative_error_metric = 0.010242568384411885
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.4678153991699219 - deformation = random_uniform
# statistic = 0.9682910523958052 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.0734806087383407
# relative_error_metric = 0.08206141844007156
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.4856586456298828 - deformation = random_uniform
# statistic = 1.014372011473468 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.036077554207923176
# relative_error_metric = 0.0356114754362417
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.4945802688598633 - deformation = random_uniform
# statistic = 1.0341862775182298 - next threshold = 1.0511501574645423 at 0.99 CL
# relative_error_eps = 0.01787753269027724
# relative_error_metric = 0.01626968163192592
# =======> statistic within required accuracy at 0.99 CL in 828.3860138009768 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1662.0404034540989 seconds.
# Saving results in the file results/20D_mixture/20D_20K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T20:40:05.430053', 'fgd_cov_diag_2024-05-02T21:17:15.923873', 'fgd_cov_off_diag_2024-05-02T21:55:05.303381', 'fgd_power_abs_up_2024-05-02T22:22:40.561140', 'fgd_power_abs_down_2024-05-02T23:07:36.348003', 'fgd_random_normal_2024-05-02T23:49:51.608252', 'fgd_random_uniform_2024-05-03T00:22:30.699810', 'mmd_mean_2024-05-03T00:54:12.129164', 'mmd_cov_diag_2024-05-03T01:34:02.934711', 'mmd_cov_off_diag_2024-05-03T02:19:10.547449', 'mmd_power_abs_up_2024-05-03T02:49:53.592187', 'mmd_power_abs_down_2024-05-03T03:42:03.282499', 'mmd_random_normal_2024-05-03T04:34:12.660813', 'mmd_random_uniform_2024-05-03T05:09:07.711076', 'ks_mean_2024-05-03T05:40:56.875998', 'ks_cov_diag_2024-05-03T06:28:43.995939', 'ks_cov_off_diag_2024-05-03T07:21:15.590462', 'ks_power_abs_up_2024-05-03T07:57:34.566514', 'ks_power_abs_down_2024-05-03T08:55:59.600673', 'ks_random_normal_2024-05-03T10:39:51.514125', 'ks_random_uniform_2024-05-03T11:25:25.045110', 'sks_mean_2024-05-03T12:07:57.435679', 'sks_cov_diag_2024-05-03T12:47:18.768471', 'sks_cov_off_diag_2024-05-03T13:31:33.614700', 'sks_power_abs_up_2024-05-03T14:01:43.659055', 'sks_power_abs_down_2024-05-03T14:50:47.018087', 'sks_random_normal_2024-05-03T15:39:58.650728', 'sks_random_uniform_2024-05-03T16:14:05.585498', 'swd_mean_2024-05-03T16:46:35.237884', 'swd_cov_diag_2024-05-03T17:23:30.500271', 'swd_cov_off_diag_2024-05-03T18:04:47.124389', 'swd_power_abs_up_2024-05-04T09:09:22.904107', 'swd_power_abs_down_2024-05-04T09:52:17.235417', 'swd_random_normal_2024-05-04T10:35:09.513257', 'swd_random_uniform_2024-05-04T11:04:15.187767'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normnal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.005 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 55.535798924043775 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -355.0284385270115], [0.99, [9900, 100], -330.63359375868356]]
# Null distribution computed in 55.934263915987685 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 82.88095112796873 seconds.
# statistic = 401.2310345548048 - next threshold = -355.0284385270115 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 32.736665819681896
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.0025 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 53.66702267504297 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -74.8664978906138], [0.99, [9900, 100], -62.948964045694964]]
# Null distribution computed in 54.03108861413784 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 83.92244591983035 seconds.
# statistic = 97.98409917588809 - next threshold = -74.8664978906138 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 14.95402528432794
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.00125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.84820383694023 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.001250.json
# ThresholdS: [[0.95, [9500, 500], -11.777464140039514], [0.99, [9900, 100], -5.806676327889663]]
# Null distribution computed in 55.215316315880045 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 82.52180027589202 seconds.
# statistic = 23.334195062540775 - next threshold = -11.777464140039514 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 6.07639988125309
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.000625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 53.860747162019834 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000625.json
# ThresholdS: [[0.95, [9500, 500], 0.530038509793691], [0.99, [9900, 100], 3.50692412837403]]
# Null distribution computed in 54.21457207784988 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 83.2608520470094 seconds.
# statistic = 5.252633899928829 - next threshold = 0.530038509793691 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6333608600047778
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.0003125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 56.35992534109391 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000313.json
# ThresholdS: [[0.95, [9500, 500], 1.8720100443002345], [0.99, [9900, 100], 3.340422278109603]]
# Null distribution computed in 58.05036178510636 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 81.92158020404167 seconds.
# statistic = 1.022701042121822 - next threshold = 1.8720100443002345 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.5868005316055097
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.00046875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.7448203319218 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000469.json
# ThresholdS: [[0.95, [9500, 500], 1.6002704484369783], [0.99, [9900, 100], 3.8287959819538067]]
# Null distribution computed in 55.11987346201204 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 84.05750560993329 seconds.
# statistic = 2.736763494034837 - next threshold = 1.6002704484369783 at 0.95 CL
# relative_error_eps = 0.3999999999999999
# relative_error_metric = 0.5240876878865903
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.000390625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.247474319068715 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000391.json
# ThresholdS: [[0.95, [9500, 500], 1.8364522273025585], [0.99, [9900, 100], 3.6839649553361062]]
# Null distribution computed in 54.61235034791753 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 86.05746517400257 seconds.
# statistic = 1.7795062738523153 - next threshold = 1.8364522273025585 at 0.95 CL
# relative_error_eps = 0.18181818181818174
# relative_error_metric = 0.03149701714334149
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.0004296875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.9035170560237 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000430.json
# ThresholdS: [[0.95, [9500, 500], 1.7441481209969418], [0.99, [9900, 100], 3.78200186000647]]
# Null distribution computed in 55.26516566495411 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 83.57140842592344 seconds.
# statistic = 2.233078385385015 - next threshold = 1.7441481209969418 at 0.95 CL
# relative_error_eps = 0.09523809523809518
# relative_error_metric = 0.24586493306505094
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.00041015625000000004 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.04872898501344 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000410.json
# ThresholdS: [[0.95, [9500, 500], 1.7965717498377192], [0.99, [9900, 100], 3.739127943785177]]
# Null distribution computed in 54.41333830496296 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 83.30156757682562 seconds.
# statistic = 2.0000282049584457 - next threshold = 1.7965717498377192 at 0.95 CL
# relative_error_eps = 0.048780487804878085
# relative_error_metric = 0.10717824239749266
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.00040039062500000003 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.50430398900062 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000400.json
# ThresholdS: [[0.95, [9500, 500], 1.8180798824509723], [0.99, [9900, 100], 3.713082583568534]]
# Null distribution computed in 54.874504121020436 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 86.195483104093 seconds.
# statistic = 1.8882012082547313 - next threshold = 1.8180798824509723 at 0.95 CL
# relative_error_eps = 0.024691358024691377
# relative_error_metric = 0.037839183854458995
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.0003955078125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.76205098303035 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000396.json
# ThresholdS: [[0.95, [9500, 500], 1.8276580283881325], [0.99, [9900, 100], 3.6989078028925544]]
# Null distribution computed in 55.13114691898227 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 85.6693357101176 seconds.
# statistic = 1.8334622332442523 - next threshold = 1.8276580283881325 at 0.95 CL
# relative_error_eps = 0.012422360248447215
# relative_error_metric = 0.0031707261391800572
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.00039306640625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.30402653082274 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000393.json
# ThresholdS: [[0.95, [9500, 500], 1.832153121243767], [0.99, [9900, 100], 3.6915323875772863]]
# Null distribution computed in 54.667216622969136 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 83.65078781708144 seconds.
# statistic = 1.8063863765805321 - next threshold = 1.832153121243767 at 0.95 CL
# relative_error_eps = 0.0061919504643962895
# relative_error_metric = 0.014163234824655492
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.00039428710937500005 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.92656862991862 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000394.json
# ThresholdS: [[0.95, [9500, 500], 1.8299300731243962], [0.99, [9900, 100], 3.6952440973712393]]
# Null distribution computed in 55.29523520404473 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 83.07627353188582 seconds.
# statistic = 1.819899835699266 - next threshold = 1.8299300731243962 at 0.95 CL
# relative_error_eps = 0.003091190108191588
# relative_error_metric = 0.005496276635183224
# =======> statistic within required accuracy at 0.95 CL in 2866.3782018639613 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00039489746093750004 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 55.15029151993804 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000395.json
# ThresholdS: [[0.95, [9500, 500], 1.8288001753848246], [0.99, [9900, 100], 3.697081950707136]]
# Null distribution computed in 55.50686992309056 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 84.23966499883682 seconds.
# statistic = 1.826674917140695 - next threshold = 3.697081950707136 at 0.99 CL
# relative_error_eps = 1.848041806118255
# relative_error_metric = 0.6772227953962028
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.00519744873046875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.01851771888323 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.005197.json
# ThresholdS: [[0.95, [9500, 500], -385.81358930883954], [0.99, [9900, 100], -360.4204447512874]]
# Null distribution computed in 54.37964295898564 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 82.65616612602025 seconds.
# statistic = 433.92729097629143 - next threshold = -360.4204447512874 at 0.99 CL
# relative_error_eps = 1.717544338335607
# relative_error_metric = 21.612891220937023
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.002796173095703125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 55.17607350414619 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.002796.json
# ThresholdS: [[0.95, [9500, 500], -97.3407442938621], [0.99, [9900, 100], -83.9193778676559]]
# Null distribution computed in 55.54441207903437 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 84.99038967792876 seconds.
# statistic = 123.19129458590817 - next threshold = -83.9193778676559 at 0.99 CL
# relative_error_eps = 1.5049968918854302
# relative_error_metric = 10.547520455364277
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.0015955352783203125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 55.442843036027625 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.001596.json
# ThresholdS: [[0.95, [9500, 500], -24.066032886667745], [0.99, [9900, 100], -16.425177927413376]]
# Null distribution computed in 55.823773368028924 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 83.69700668612495 seconds.
# statistic = 38.83756266132658 - next threshold = -16.425177927413376 at 0.99 CL
# relative_error_eps = 1.2064088313082142
# relative_error_metric = 4.931446719734325
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.0009952163696289062 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 53.200563264777884 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000995.json
# ThresholdS: [[0.95, [9500, 500], -5.207550690022844], [0.99, [9900, 100], -0.4832962576106178]]
# Null distribution computed in 53.55985640315339 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 82.88830606313422 seconds.
# statistic = 14.414263266698585 - next threshold = -0.4832962576106178 at 0.99 CL
# relative_error_eps = 0.8636974836036332
# relative_error_metric = 2.1387689044975375
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.0006950569152832031 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.289930613012984 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_mean_0.000695.json
# ThresholdS: [[0.95, [9500, 500], -0.21070810574612894], [0.99, [9900, 100], 3.0990617265536256]]
# Null distribution computed in 54.652359797852114 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# ...
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_power_abs_down_0.000032.json
# ThresholdS: [[0.95, [9500, 500], 1.7216012541951289], [0.99, [9900, 100], 3.7977273609572855]]
# Null distribution computed in 55.177572762127966 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 83.61531550507061 seconds.
# statistic = 3.6217515487359133 - next threshold = 3.7977273609572855 at 0.99 CL
# relative_error_eps = 0.2624750248622417
# relative_error_metric = 0.04743616482054233
#
# ------------ 12 - 0.99 CL ------------
# eps = 3.712218254804611e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 56.229134131921455 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_power_abs_down_0.000037.json
# ThresholdS: [[0.95, [9500, 500], 1.4391273943762826], [0.99, [9900, 100], 3.828135242928569]]
# Null distribution computed in 56.543559414101765 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 84.255236255005 seconds.
# statistic = 4.71495463828963 - next threshold = 3.828135242928569 at 0.99 CL
# relative_error_eps = 0.1404539242457195
# relative_error_metric = 0.20761092478043908
#
# ------------ 13 - 0.99 CL ------------
# eps = 3.468627110123634e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 53.79439649102278 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_power_abs_down_0.000035.json
# ThresholdS: [[0.95, [9500, 500], 1.6005571178003868], [0.99, [9900, 100], 3.830873982599526]]
# Null distribution computed in 54.103190660942346 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 81.32170347310603 seconds.
# statistic = 4.150445257483298 - next threshold = 3.830873982599526 at 0.99 CL
# relative_error_eps = 0.07278261302698413
# relative_error_metric = 0.08007981269032806
#
# ------------ 14 - 0.99 CL ------------
# eps = 3.346831537783146e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 53.60858971811831 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_power_abs_down_0.000033.json
# ThresholdS: [[0.95, [9500, 500], 1.6634304944269322], [0.99, [9900, 100], 3.8191878450765717]]
# Null distribution computed in 53.9112450981047 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 79.72455657483079 seconds.
# statistic = 3.8880715688450236 - next threshold = 3.8191878450765717 at 0.99 CL
# relative_error_eps = 0.037065741900823596
# relative_error_metric = 0.017875024069911916
#
# ------------ 15 - 0.99 CL ------------
# eps = 3.2859337516129017e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.057006706018 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_power_abs_down_0.000033.json
# ThresholdS: [[0.95, [9500, 500], 1.6940302348618554], [0.99, [9900, 100], 3.8091207365923156]]
# Null distribution computed in 54.35496339015663 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 81.32759903906845 seconds.
# statistic = 3.7473987574383845 - next threshold = 3.8091207365923156 at 0.99 CL
# relative_error_eps = 0.018362714045558972
# relative_error_metric = 0.01633608679305034
#
# ------------ 16 - 0.99 CL ------------
# eps = 3.3163826446980235e-05 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 54.34164184704423 seconds.
# Saving lr to results/20D_mixture/20D_20K/null_hypothesis/LR_power_abs_down_0.000033.json
# ThresholdS: [[0.95, [9500, 500], 1.68043390898034], [0.99, [9900, 100], 3.81401690437369]]
# Null distribution computed in 54.650738154072315 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 82.11577625013888 seconds.
# statistic = 3.81102134984544 - next threshold = 3.81401690437369 at 0.99 CL
# relative_error_eps = 0.009139400971134427
# relative_error_metric = 0.0007857152786328192
# =======> statistic within required accuracy at 0.99 CL in 3534.7536712209694 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 7080.0675911568105 seconds.
# Saving results in the file results/20D_mixture/20D_20K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T20:40:05.430053', 'fgd_cov_diag_2024-05-02T21:17:15.923873', 'fgd_cov_off_diag_2024-05-02T21:55:05.303381', 'fgd_power_abs_up_2024-05-02T22:22:40.561140', 'fgd_power_abs_down_2024-05-02T23:07:36.348003', 'fgd_random_normal_2024-05-02T23:49:51.608252', 'fgd_random_uniform_2024-05-03T00:22:30.699810', 'mmd_mean_2024-05-03T00:54:12.129164', 'mmd_cov_diag_2024-05-03T01:34:02.934711', 'mmd_cov_off_diag_2024-05-03T02:19:10.547449', 'mmd_power_abs_up_2024-05-03T02:49:53.592187', 'mmd_power_abs_down_2024-05-03T03:42:03.282499', 'mmd_random_normal_2024-05-03T04:34:12.660813', 'mmd_random_uniform_2024-05-03T05:09:07.711076', 'ks_mean_2024-05-03T05:40:56.875998', 'ks_cov_diag_2024-05-03T06:28:43.995939', 'ks_cov_off_diag_2024-05-03T07:21:15.590462', 'ks_power_abs_up_2024-05-03T07:57:34.566514', 'ks_power_abs_down_2024-05-03T08:55:59.600673', 'ks_random_normal_2024-05-03T10:39:51.514125', 'ks_random_uniform_2024-05-03T11:25:25.045110', 'sks_mean_2024-05-03T12:07:57.435679', 'sks_cov_diag_2024-05-03T12:47:18.768471', 'sks_cov_off_diag_2024-05-03T13:31:33.614700', 'sks_power_abs_up_2024-05-03T14:01:43.659055', 'sks_power_abs_down_2024-05-03T14:50:47.018087', 'sks_random_normal_2024-05-03T15:39:58.650728', 'sks_random_uniform_2024-05-03T16:14:05.585498', 'swd_mean_2024-05-03T16:46:35.237884', 'swd_cov_diag_2024-05-03T17:23:30.500271', 'swd_cov_off_diag_2024-05-03T18:04:47.124389', 'swd_power_abs_up_2024-05-04T09:09:22.904107', 'swd_power_abs_down_2024-05-04T09:52:17.235417', 'swd_random_normal_2024-05-04T10:35:09.513257', 'swd_random_uniform_2024-05-04T11:04:15.187767', 'lr_mean_2024-05-04T11:31:57.262614', 'lr_cov_diag_2024-05-04T13:03:46.787605', 'lr_cov_off_diag_2024-05-04T14:47:46.379105', 'lr_power_abs_up_2024-05-04T16:23:52.627664', 'lr_power_abs_down_2024-05-04T18:21:11.809888'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean   20  10000                20000
# 14        ks        mean   20  10000                20000
# 21       sks        mean   20  10000                20000
# 7        mmd        mean   20  10000                20000
# 28       swd        mean   20  10000                20000
# 0        fgd        mean   20  10000                20000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.00039                             0.00054
# 14                             0.00816                             0.01098
# 21                             0.05951                             0.07700
# 7                              0.07111                             0.10179
# 28                             0.07996                             0.10578
# 0                              0.09705                             0.12697
#
#     $t^{\mu}$ (s)
# 35           5509
# 14           2867
# 21           2361
# 7            2390
# 28           2215
# 0            2230
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.00039
# 14        ks                             0.00816
# 21       sks                             0.05951
# 7        mmd                             0.07111
# 28       swd                             0.07996
# 0        fgd                             0.09705
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.00054           5509
# 14                             0.01098           2867
# 21                             0.07700           2361
# 7                              0.10179           2390
# 28                             0.10578           2215
# 0                              0.12697           2230

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag   20  10000                20000
# 15        ks    cov_diag   20  10000                20000
# 8        mmd    cov_diag   20  10000                20000
# 22       sks    cov_diag   20  10000                20000
# 29       swd    cov_diag   20  10000                20000
# 1        fgd    cov_diag   20  10000                20000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00012
# 15                                     0.00292
# 8                                      0.01572
# 22                                     0.02151
# 29                                     0.02731
# 1                                      0.03326
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00016                   6239
# 15                                     0.00402                   3151
# 8                                      0.02195                   2707
# 22                                     0.02774                   2654
# 29                                     0.03672                   2476
# 1                                      0.04387                   2269
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00012
# 15        ks                                     0.00292
# 8        mmd                                     0.01572
# 22       sks                                     0.02151
# 29       swd                                     0.02731
# 1        fgd                                     0.03326
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00016                   6239
# 15                                     0.00402                   3151
# 8                                      0.02195                   2707
# 22                                     0.02774                   2654
# 29                                     0.03672                   2476
# 1                                      0.04387                   2269

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag   20  10000                20000
# 16        ks  cov_off_diag   20  10000                20000
# 23       sks  cov_off_diag   20  10000                20000
# 2        fgd  cov_off_diag   20  10000                20000
# 30       swd  cov_off_diag   20  10000                20000
# 9        mmd  cov_off_diag   20  10000                20000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00001
# 16                                          0.00056
# 23                                          0.00408
# 2                                           0.00460
# 30                                          0.00614
# 9                                           0.00801
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00001
# 16                                          0.00079
# 23                                          0.00534
# 2                                           0.00616
# 30                                          0.00820
# 9                                           0.01163
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        5766
# 16                        2178
# 23                        1810
# 2                         1655
# 30                        1633
# 9                         1843
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00001
# 16        ks                                          0.00056
# 23       sks                                          0.00408
# 2        fgd                                          0.00460
# 30       swd                                          0.00614
# 9        mmd                                          0.00801
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00001
# 16                                          0.00079
# 23                                          0.00534
# 2                                           0.00616
# 30                                          0.00820
# 9                                           0.01163
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        5766
# 16                        2178
# 23                        1810
# 2                         1655
# 30                        1633
# 9                         1843

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up   20  10000                20000
# 17        ks  power_abs_up   20  10000                20000
# 10       mmd  power_abs_up   20  10000                20000
# 24       sks  power_abs_up   20  10000                20000
# 31       swd  power_abs_up   20  10000                20000
# 3        fgd  power_abs_up   20  10000                20000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00003
# 17                                      0.00067
# 10                                      0.00551
# 24                                      0.00706
# 31                                      0.00938
# 3                                       0.01186
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00004                    7039
# 17                                      0.00097                    3505
# 10                                      0.00772                    3129
# 24                                      0.00896                    2943
# 31                                      0.01266                    2574
# 3                                       0.01559                    2695
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00003
# 17        ks                                      0.00067
# 10       mmd                                      0.00551
# 24       sks                                      0.00706
# 31       swd                                      0.00938
# 3        fgd                                      0.01186
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00004                    7039
# 17                                      0.00097                    3505
# 10                                      0.00772                    3129
# 24                                      0.00896                    2943
# 31                                      0.01266                    2574
# 3                                       0.01559                    2695

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down   20  10000                20000
# 18        ks  power_abs_down   20  10000                20000
# 11       mmd  power_abs_down   20  10000                20000
# 25       sks  power_abs_down   20  10000                20000
# 32       swd  power_abs_down   20  10000                20000
# 4        fgd  power_abs_down   20  10000                20000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00002
# 18                                      0.00070
# 11                                      0.00546
# 25                                      0.00721
# 32                                      0.00969
# 4                                       0.01183
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00003                    7080
# 18                                      0.00098                    3547
# 11                                      0.00786                    3129
# 25                                      0.00911                    2951
# 32                                      0.01296                    2572
# 4                                       0.01563                    2535
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00002
# 18        ks                                      0.00070
# 11       mmd                                      0.00546
# 25       sks                                      0.00721
# 32       swd                                      0.00969
# 4        fgd                                      0.01183
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00003                    7080
# 18                                      0.00098                    3547
# 11                                      0.00786                    3129
# 25                                      0.00911                    2951
# 32                                      0.01296                    2572
# 4                                       0.01563                    2535

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 19        ks  random_normal   20  10000                20000
# 26       sks  random_normal   20  10000                20000
# 5        fgd  random_normal   20  10000                20000
# 33       swd  random_normal   20  10000                20000
# 12       mmd  random_normal   20  10000                20000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 19                                     0.01137
# 26                                     0.20630
# 5                                      0.23804
# 33                                     0.24658
# 12                                     0.55542
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 19                                     0.01510                   2733
# 26                                     0.23673                   2046
# 5                                      0.27408                   1959
# 33                                     0.29068                   1745
# 12                                     0.66610                   2095
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 19        ks                                     0.01137
# 26       sks                                     0.20630
# 5        fgd                                     0.23804
# 33       swd                                     0.24658
# 12       mmd                                     0.55542
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 19                                     0.01510                   2733
# 26                                     0.23673                   2046
# 5                                      0.27408                   1959
# 33                                     0.29068                   1745
# 12                                     0.66610                   2095

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 20        ks  random_uniform   20  10000                20000
# 27       sks  random_uniform   20  10000                20000
# 6        fgd  random_uniform   20  10000                20000
# 34       swd  random_uniform   20  10000                20000
# 13       mmd  random_uniform   20  10000                20000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 20                                     0.01755
# 27                                     0.35400
# 6                                      0.41077
# 34                                     0.43213
# 13                                     0.96558
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 20                                     0.02317                   2552
# 27                                     0.41072                   1949
# 6                                      0.47799                   1901
# 34                                     0.49904                   1662
# 13                                     1.14681                   1909
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 20        ks                                     0.01755
# 27       sks                                     0.35400
# 6        fgd                                     0.41077
# 34       swd                                     0.43213
# 13       mmd                                     0.96558
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 20                                     0.02317                   2552
# 27                                     0.41072                   1949
# 6                                      0.47799                   1901
# 34                                     0.49904                   1662
# 13                                     1.14681                   1909

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.097 & 0.13 & 2230 & cov_diag & 20 & 10000 & 20000 & 0.033 & 0.044 & 2269 & cov_off_diag & 20 & 10000 & 20000 & 0.0046 & 0.0062 & 1655 & 0.012 & 0.016 & 2695 \\
# $\overline{D}$ & 0.0082 & 0.011 & 2867 & cov_diag & 20 & 10000 & 20000 & 0.0029 & 0.004 & 3151 & cov_off_diag & 20 & 10000 & 20000 & 0.00056 & 0.00079 & 2178 & 0.00067 & 0.00097 & 3505 \\
# $t_{\mathrm{LLR}}$ & 0.00039 & 0.00054 & 5509 & cov_diag & 20 & 10000 & 20000 & 0.00012 & 0.00016 & 6239 & cov_off_diag & 20 & 10000 & 20000 & 1e-05 & 1e-05 & 5766 & 3e-05 & 4e-05 & 7039 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.071 & 0.1 & 2390 & cov_diag & 20 & 10000 & 20000 & 0.016 & 0.022 & 2707 & cov_off_diag & 20 & 10000 & 20000 & 0.008 & 0.012 & 1843 & 0.0055 & 0.0077 & 3129 \\
# $\widetilde{D}$ & 0.06 & 0.077 & 2361 & cov_diag & 20 & 10000 & 20000 & 0.022 & 0.028 & 2654 & cov_off_diag & 20 & 10000 & 20000 & 0.0041 & 0.0053 & 1810 & 0.0071 & 0.009 & 2943 \\
# $\widetilde{W}$ & 0.08 & 0.11 & 2215 & cov_diag & 20 & 10000 & 20000 & 0.027 & 0.037 & 2476 & cov_off_diag & 20 & 10000 & 20000 & 0.0061 & 0.0082 & 1633 & 0.0094 & 0.013 & 2574 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.012 & 0.016 & 2535 & 0.24 & 0.27 & 2e+03 & 0.41 & 0.48 & 1.9e+03 & 2033 \\
# $\overline{D}$ & 0.0007 & 0.00098 & 3547 & 0.011 & 0.015 & 2.7e+03 & 0.018 & 0.023 & 2.6e+03 & 193 \\
# $t_{\mathrm{LLR}}$ & 2e-05 & 3e-05 & 7080 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.0055 & 0.0079 & 3129 & 0.56 & 0.67 & 2.1e+03 & 0.97 & 1.1 & 1.9e+03 & 2347 \\
# $\widetilde{D}$ & 0.0072 & 0.0091 & 2951 & 0.21 & 0.24 & 2e+03 & 0.35 & 0.41 & 1.9e+03 & 457 \\
# $\widetilde{W}$ & 0.0097 & 0.013 & 2572 & 0.25 & 0.29 & 1.7e+03 & 0.43 & 0.5 & 1.7e+03 & 328 \\
# \bottomrule
# \end{tabular}
