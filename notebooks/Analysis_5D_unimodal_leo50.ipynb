# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [2]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/5D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-02 19:09:34.037631: Importing os...
# 2024-05-02 19:09:34.037861: Importing sys...
# Visible devices: [2]
# 2024-05-02 19:09:34.038093: Importing timer from timeit...
# 2024-05-02 19:09:34.038160: Setting env variables for tf import (only device(s) [2] will be available)...
# 2024-05-02 19:09:34.038283: Importing numpy...
# 2024-05-02 19:09:34.163990: Importing matplotlib...
# 2024-05-02 19:09:34.512441: Importing h5py...
# 2024-05-02 19:09:34.536319: Importing importlib.util...
# 2024-05-02 19:09:34.536417: Importing json...
# 2024-05-02 19:09:34.536484: Importing pandas...
# 2024-05-02 19:09:34.932117: Importing random...
# 2024-05-02 19:09:34.932255: Importing scipy utils...
# 2024-05-02 19:09:35.330462: Importing subprocess...
# 2024-05-02 19:09:35.330606: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-02 19:09:38.659643: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-02 19:09:39.879304: Importing timeit...
# 2024-05-02 19:09:39.879398: Importing tqdm...
# 2024-05-02 19:09:39.888571: Importing typing...
# 2024-05-02 19:09:39.888691: Setting tf configs...
# 2024-05-02 19:09:39.984181: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-02 19:09:44.750999: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #2, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-02 19:09:44.780394: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)
# sample from dist_1:  tf.Tensor(
# [[ 1.1610332  -2.23691168 -2.20072828  5.13732308  1.32224517]
#  [-2.52914258 -0.85839971 -1.86610514  1.33679732 -0.66477288]], shape=(2, 5), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[ 1.1610332  -2.23691168 -2.20072828  5.13732308  1.32224517]
#  [-2.52914258 -0.85839971 -1.86610514  1.33679732 -0.66477288]], shape=(2, 5), dtype=float64)

# %% [markdown]
# # Fixed $n=50000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 50_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory was created
# Null hypothesis directory was created

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 500000000
# batch_size 50000
# niter 10000
# niter * batch_size 500000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            50000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True        5           0  float64     5  500000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/5D_unimodal/5D_50K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 2,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/5D_unimodal/5D_50K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 5000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/5D_unimodal/5D_50K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/5D_unimodal/5D_50K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/5D_unimodal/5D_50K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/5D_unimodal/5D_50K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 1000
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714669789.736595  164502 service.cc:145] XLA service 0x10ced1600 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714669789.736637  164502 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1714669792.843790  164502 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# FGD metric calculation completed in 1307.4540228959522 seconds.
# Saving fgd to results/5D_unimodal/5D_50K/null_hypothesis/FGD.json
# Computing and savng mmd with max_vectorize = 2
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 5000
# Iterating from 0 to 2 out of 10000 .
# Iterating from 2 to 4 out of 10000 .
# Iterating from 4 to 6 out of 10000 .
# Iterating from 6 to 8 out of 10000 .
# Iterating from 8 to 10 out of 10000 .
# Iterating from 10 to 12 out of 10000 .
# Iterating from 12 to 14 out of 10000 .
# Iterating from 14 to 16 out of 10000 .
# Iterating from 16 to 18 out of 10000 .
# Iterating from 18 to 20 out of 10000 .
# Iterating from 20 to 22 out of 10000 .
# Iterating from 22 to 24 out of 10000 .
# Iterating from 24 to 26 out of 10000 .
# Iterating from 26 to 28 out of 10000 .
# Iterating from 28 to 30 out of 10000 .
# Iterating from 30 to 32 out of 10000 .
# Iterating from 32 to 34 out of 10000 .
# Iterating from 34 to 36 out of 10000 .
# Iterating from 36 to 38 out of 10000 .
# Iterating from 38 to 40 out of 10000 .
# Iterating from 40 to 42 out of 10000 .
# Iterating from 42 to 44 out of 10000 .
# Iterating from 44 to 46 out of 10000 .
# Iterating from 46 to 48 out of 10000 .
# Iterating from 48 to 50 out of 10000 .
# Iterating from 50 to 52 out of 10000 .
# Iterating from 52 to 54 out of 10000 .
# Iterating from 54 to 56 out of 10000 .
# Iterating from 56 to 58 out of 10000 .
# Iterating from 58 to 60 out of 10000 .
# Iterating from 60 to 62 out of 10000 .
# Iterating from 62 to 64 out of 10000 .
# Iterating from 64 to 66 out of 10000 .
# Iterating from 66 to 68 out of 10000 .
# Iterating from 68 to 70 out of 10000 .
# Iterating from 70 to 72 out of 10000 .
# Iterating from 72 to 74 out of 10000 .
# Iterating from 74 to 76 out of 10000 .
# Iterating from 76 to 78 out of 10000 .
# Iterating from 78 to 80 out of 10000 .
# Iterating from 80 to 82 out of 10000 .
# Iterating from 82 to 84 out of 10000 .
# Iterating from 84 to 86 out of 10000 .
# Iterating from 86 to 88 out of 10000 .
# Iterating from 88 to 90 out of 10000 .
# Iterating from 90 to 92 out of 10000 .
# Iterating from 92 to 94 out of 10000 .
# Iterating from 94 to 96 out of 10000 .
# Iterating from 96 to 98 out of 10000 .
# Iterating from 98 to 100 out of 10000 .
# Iterating from 100 to 102 out of 10000 .
# Iterating from 102 to 104 out of 10000 .
# Iterating from 104 to 106 out of 10000 .
# Iterating from 106 to 108 out of 10000 .
# Iterating from 108 to 110 out of 10000 .
# Iterating from 110 to 112 out of 10000 .
# Iterating from 112 to 114 out of 10000 .
# Iterating from 114 to 116 out of 10000 .
# Iterating from 116 to 118 out of 10000 .
# Iterating from 118 to 120 out of 10000 .
# Iterating from 120 to 122 out of 10000 .
# Iterating from 122 to 124 out of 10000 .
# Iterating from 124 to 126 out of 10000 .
# Iterating from 126 to 128 out of 10000 .
# Iterating from 128 to 130 out of 10000 .
# Iterating from 130 to 132 out of 10000 .
# Iterating from 132 to 134 out of 10000 .
# Iterating from 134 to 136 out of 10000 .
# Iterating from 136 to 138 out of 10000 .
# Iterating from 138 to 140 out of 10000 .
# Iterating from 140 to 142 out of 10000 .
# Iterating from 142 to 144 out of 10000 .
# Iterating from 144 to 146 out of 10000 .
# Iterating from 146 to 148 out of 10000 .
# Iterating from 148 to 150 out of 10000 .
# Iterating from 150 to 152 out of 10000 .
# Iterating from 152 to 154 out of 10000 .
# Iterating from 154 to 156 out of 10000 .
# Iterating from 156 to 158 out of 10000 .
# Iterating from 158 to 160 out of 10000 .
# Iterating from 160 to 162 out of 10000 .
# Iterating from 162 to 164 out of 10000 .
# Iterating from 164 to 166 out of 10000 .
# Iterating from 166 to 168 out of 10000 .
# Iterating from 168 to 170 out of 10000 .
# Iterating from 170 to 172 out of 10000 .
# Iterating from 172 to 174 out of 10000 .
# Iterating from 174 to 176 out of 10000 .
# Iterating from 176 to 178 out of 10000 .
# Iterating from 178 to 180 out of 10000 .
# Iterating from 180 to 182 out of 10000 .
# Iterating from 182 to 184 out of 10000 .
# Iterating from 184 to 186 out of 10000 .
# Iterating from 186 to 188 out of 10000 .
# Iterating from 188 to 190 out of 10000 .
# Iterating from 190 to 192 out of 10000 .
# Iterating from 192 to 194 out of 10000 .
# Iterating from 194 to 196 out of 10000 .
# Iterating from 196 to 198 out of 10000 .
# Iterating from 198 to 200 out of 10000 .
# Iterating from 200 to 202 out of 10000 .
# Iterating from 202 to 204 out of 10000 .
# Iterating from 204 to 206 out of 10000 .
# Iterating from 206 to 208 out of 10000 .
# Iterating from 208 to 210 out of 10000 .
# Iterating from 210 to 212 out of 10000 .
# Iterating from 212 to 214 out of 10000 .
# Iterating from 214 to 216 out of 10000 .
# Iterating from 216 to 218 out of 10000 .
# Iterating from 218 to 220 out of 10000 .
# Iterating from 220 to 222 out of 10000 .
# Iterating from 222 to 224 out of 10000 .
# Iterating from 224 to 226 out of 10000 .
# Iterating from 226 to 228 out of 10000 .
# Iterating from 228 to 230 out of 10000 .
# Iterating from 230 to 232 out of 10000 .
# Iterating from 232 to 234 out of 10000 .
# Iterating from 234 to 236 out of 10000 .
# Iterating from 236 to 238 out of 10000 .
# Iterating from 238 to 240 out of 10000 .
# Iterating from 240 to 242 out of 10000 .
# Iterating from 242 to 244 out of 10000 .
# Iterating from 244 to 246 out of 10000 .
# Iterating from 246 to 248 out of 10000 .
# Iterating from 248 to 250 out of 10000 .
# Iterating from 250 to 252 out of 10000 .
# Iterating from 252 to 254 out of 10000 .
# Iterating from 254 to 256 out of 10000 .
# Iterating from 256 to 258 out of 10000 .
# Iterating from 258 to 260 out of 10000 .
# Iterating from 260 to 262 out of 10000 .
# Iterating from 262 to 264 out of 10000 .
# Iterating from 264 to 266 out of 10000 .
# Iterating from 266 to 268 out of 10000 .
# Iterating from 268 to 270 out of 10000 .
# Iterating from 270 to 272 out of 10000 .
# Iterating from 272 to 274 out of 10000 .
# Iterating from 274 to 276 out of 10000 .
# Iterating from 276 to 278 out of 10000 .
# Iterating from 278 to 280 out of 10000 .
# Iterating from 280 to 282 out of 10000 .
# Iterating from 282 to 284 out of 10000 .
# Iterating from 284 to 286 out of 10000 .
# Iterating from 286 to 288 out of 10000 .
# Iterating from 288 to 290 out of 10000 .
# Iterating from 290 to 292 out of 10000 .
# Iterating from 292 to 294 out of 10000 .
# Iterating from 294 to 296 out of 10000 .
# Iterating from 296 to 298 out of 10000 .
# Iterating from 298 to 300 out of 10000 .
# Iterating from 300 to 302 out of 10000 .
# Iterating from 302 to 304 out of 10000 .
# Iterating from 304 to 306 out of 10000 .
# Iterating from 306 to 308 out of 10000 .
# Iterating from 308 to 310 out of 10000 .
# Iterating from 310 to 312 out of 10000 .
# Iterating from 312 to 314 out of 10000 .
# Iterating from 314 to 316 out of 10000 .
# Iterating from 316 to 318 out of 10000 .
# Iterating from 318 to 320 out of 10000 .
# Iterating from 320 to 322 out of 10000 .
# Iterating from 322 to 324 out of 10000 .
# Iterating from 324 to 326 out of 10000 .
# Iterating from 326 to 328 out of 10000 .
# Iterating from 328 to 330 out of 10000 .
# Iterating from 330 to 332 out of 10000 .
# Iterating from 332 to 334 out of 10000 .
# Iterating from 334 to 336 out of 10000 .
# Iterating from 336 to 338 out of 10000 .
# Iterating from 338 to 340 out of 10000 .
# Iterating from 340 to 342 out of 10000 .
# Iterating from 342 to 344 out of 10000 .
# Iterating from 344 to 346 out of 10000 .
# Iterating from 346 to 348 out of 10000 .
# Iterating from 348 to 350 out of 10000 .
# Iterating from 350 to 352 out of 10000 .
# Iterating from 352 to 354 out of 10000 .
# Iterating from 354 to 356 out of 10000 .
# Iterating from 356 to 358 out of 10000 .
# Iterating from 358 to 360 out of 10000 .
# Iterating from 360 to 362 out of 10000 .
# Iterating from 362 to 364 out of 10000 .
# Iterating from 364 to 366 out of 10000 .
# Iterating from 366 to 368 out of 10000 .
# Iterating from 368 to 370 out of 10000 .
# Iterating from 370 to 372 out of 10000 .
# Iterating from 372 to 374 out of 10000 .
# Iterating from 374 to 376 out of 10000 .
# Iterating from 376 to 378 out of 10000 .
# Iterating from 378 to 380 out of 10000 .
# Iterating from 380 to 382 out of 10000 .
# Iterating from 382 to 384 out of 10000 .
# Iterating from 384 to 386 out of 10000 .
# Iterating from 386 to 388 out of 10000 .
# Iterating from 388 to 390 out of 10000 .
# Iterating from 390 to 392 out of 10000 .
# Iterating from 392 to 394 out of 10000 .
# Iterating from 394 to 396 out of 10000 .
# Iterating from 396 to 398 out of 10000 .
# Iterating from 398 to 400 out of 10000 .
# Iterating from 400 to 402 out of 10000 .
# Iterating from 402 to 404 out of 10000 .
# Iterating from 404 to 406 out of 10000 .
# Iterating from 406 to 408 out of 10000 .
# Iterating from 408 to 410 out of 10000 .
# Iterating from 410 to 412 out of 10000 .
# Iterating from 412 to 414 out of 10000 .
# Iterating from 414 to 416 out of 10000 .
# Iterating from 416 to 418 out of 10000 .
# Iterating from 418 to 420 out of 10000 .
# Iterating from 420 to 422 out of 10000 .
# Iterating from 422 to 424 out of 10000 .
# Iterating from 424 to 426 out of 10000 .
# Iterating from 426 to 428 out of 10000 .
# Iterating from 428 to 430 out of 10000 .
# Iterating from 430 to 432 out of 10000 .
# Iterating from 432 to 434 out of 10000 .
# Iterating from 434 to 436 out of 10000 .
# Iterating from 436 to 438 out of 10000 .
# Iterating from 438 to 440 out of 10000 .
# Iterating from 440 to 442 out of 10000 .
# Iterating from 442 to 444 out of 10000 .
# Iterating from 444 to 446 out of 10000 .
# Iterating from 446 to 448 out of 10000 .
# Iterating from 448 to 450 out of 10000 .
# Iterating from 450 to 452 out of 10000 .
# Iterating from 452 to 454 out of 10000 .
# Iterating from 454 to 456 out of 10000 .
# Iterating from 456 to 458 out of 10000 .
# Iterating from 458 to 460 out of 10000 .
# Iterating from 460 to 462 out of 10000 .
# Iterating from 462 to 464 out of 10000 .
# Iterating from 464 to 466 out of 10000 .
# Iterating from 466 to 468 out of 10000 .
# Iterating from 468 to 470 out of 10000 .
# Iterating from 470 to 472 out of 10000 .
# Iterating from 472 to 474 out of 10000 .
# Iterating from 474 to 476 out of 10000 .
# Iterating from 476 to 478 out of 10000 .
# Iterating from 478 to 480 out of 10000 .
# Iterating from 480 to 482 out of 10000 .
# Iterating from 482 to 484 out of 10000 .
# Iterating from 484 to 486 out of 10000 .
# Iterating from 486 to 488 out of 10000 .
# Iterating from 488 to 490 out of 10000 .
# Iterating from 490 to 492 out of 10000 .
# Iterating from 492 to 494 out of 10000 .
# Iterating from 494 to 496 out of 10000 .
# Iterating from 496 to 498 out of 10000 .
# Iterating from 498 to 500 out of 10000 .
# Iterating from 500 to 502 out of 10000 .
# Iterating from 502 to 504 out of 10000 .
# Iterating from 504 to 506 out of 10000 .
# Iterating from 506 to 508 out of 10000 .
# Iterating from 508 to 510 out of 10000 .
# Iterating from 510 to 512 out of 10000 .
# Iterating from 512 to 514 out of 10000 .
# Iterating from 514 to 516 out of 10000 .
# Iterating from 516 to 518 out of 10000 .
# Iterating from 518 to 520 out of 10000 .
# Iterating from 520 to 522 out of 10000 .
# Iterating from 522 to 524 out of 10000 .
# Iterating from 524 to 526 out of 10000 .
# Iterating from 526 to 528 out of 10000 .
# Iterating from 528 to 530 out of 10000 .
# Iterating from 530 to 532 out of 10000 .
# Iterating from 532 to 534 out of 10000 .
# Iterating from 534 to 536 out of 10000 .
# Iterating from 536 to 538 out of 10000 .
# Iterating from 538 to 540 out of 10000 .
# Iterating from 540 to 542 out of 10000 .
# Iterating from 542 to 544 out of 10000 .
# Iterating from 544 to 546 out of 10000 .
# Iterating from 546 to 548 out of 10000 .
# Iterating from 548 to 550 out of 10000 .
# Iterating from 550 to 552 out of 10000 .
# Iterating from 552 to 554 out of 10000 .
# Iterating from 554 to 556 out of 10000 .
# Iterating from 556 to 558 out of 10000 .
# Iterating from 558 to 560 out of 10000 .
# Iterating from 560 to 562 out of 10000 .
# Iterating from 562 to 564 out of 10000 .
# Iterating from 564 to 566 out of 10000 .
# Iterating from 566 to 568 out of 10000 .
# Iterating from 568 to 570 out of 10000 .
# Iterating from 570 to 572 out of 10000 .
# Iterating from 572 to 574 out of 10000 .
# Iterating from 574 to 576 out of 10000 .
# Iterating from 576 to 578 out of 10000 .
# Iterating from 578 to 580 out of 10000 .
# Iterating from 580 to 582 out of 10000 .
# Iterating from 582 to 584 out of 10000 .
# Iterating from 584 to 586 out of 10000 .
# Iterating from 586 to 588 out of 10000 .
# Iterating from 588 to 590 out of 10000 .
# Iterating from 590 to 592 out of 10000 .
# Iterating from 592 to 594 out of 10000 .
# Iterating from 594 to 596 out of 10000 .
# Iterating from 596 to 598 out of 10000 .
# Iterating from 598 to 600 out of 10000 .
# Iterating from 600 to 602 out of 10000 .
# Iterating from 602 to 604 out of 10000 .
# Iterating from 604 to 606 out of 10000 .
# Iterating from 606 to 608 out of 10000 .
# Iterating from 608 to 610 out of 10000 .
# Iterating from 610 to 612 out of 10000 .
# Iterating from 612 to 614 out of 10000 .
# Iterating from 614 to 616 out of 10000 .
# Iterating from 616 to 618 out of 10000 .
# Iterating from 618 to 620 out of 10000 .
# Iterating from 620 to 622 out of 10000 .
# Iterating from 622 to 624 out of 10000 .
# Iterating from 624 to 626 out of 10000 .
# Iterating from 626 to 628 out of 10000 .
# Iterating from 628 to 630 out of 10000 .
# Iterating from 630 to 632 out of 10000 .
# Iterating from 632 to 634 out of 10000 .
# Iterating from 634 to 636 out of 10000 .
# Iterating from 636 to 638 out of 10000 .
# Iterating from 638 to 640 out of 10000 .
# Iterating from 640 to 642 out of 10000 .
# Iterating from 642 to 644 out of 10000 .
# Iterating from 644 to 646 out of 10000 .
# Iterating from 646 to 648 out of 10000 .
# Iterating from 648 to 650 out of 10000 .
# Iterating from 650 to 652 out of 10000 .
# Iterating from 652 to 654 out of 10000 .
# Iterating from 654 to 656 out of 10000 .
# Iterating from 656 to 658 out of 10000 .
# Iterating from 658 to 660 out of 10000 .
# Iterating from 660 to 662 out of 10000 .
# Iterating from 662 to 664 out of 10000 .
# Iterating from 664 to 666 out of 10000 .
# Iterating from 666 to 668 out of 10000 .
# Iterating from 668 to 670 out of 10000 .
# Iterating from 670 to 672 out of 10000 .
# Iterating from 672 to 674 out of 10000 .
# Iterating from 674 to 676 out of 10000 .
# Iterating from 676 to 678 out of 10000 .
# Iterating from 678 to 680 out of 10000 .
# Iterating from 680 to 682 out of 10000 .
# Iterating from 682 to 684 out of 10000 .
# Iterating from 684 to 686 out of 10000 .
# Iterating from 686 to 688 out of 10000 .
# Iterating from 688 to 690 out of 10000 .
# Iterating from 690 to 692 out of 10000 .
# Iterating from 692 to 694 out of 10000 .
# Iterating from 694 to 696 out of 10000 .
# Iterating from 696 to 698 out of 10000 .
# Iterating from 698 to 700 out of 10000 .
# Iterating from 700 to 702 out of 10000 .
# Iterating from 702 to 704 out of 10000 .
# Iterating from 704 to 706 out of 10000 .
# Iterating from 706 to 708 out of 10000 .
# Iterating from 708 to 710 out of 10000 .
# Iterating from 710 to 712 out of 10000 .
# Iterating from 712 to 714 out of 10000 .
# Iterating from 714 to 716 out of 10000 .
# Iterating from 716 to 718 out of 10000 .
# Iterating from 718 to 720 out of 10000 .
# Iterating from 720 to 722 out of 10000 .
# Iterating from 722 to 724 out of 10000 .
# Iterating from 724 to 726 out of 10000 .
# Iterating from 726 to 728 out of 10000 .
# Iterating from 728 to 730 out of 10000 .
# Iterating from 730 to 732 out of 10000 .
# Iterating from 732 to 734 out of 10000 .
# Iterating from 734 to 736 out of 10000 .
# Iterating from 736 to 738 out of 10000 .
# Iterating from 738 to 740 out of 10000 .
# Iterating from 740 to 742 out of 10000 .
# Iterating from 742 to 744 out of 10000 .
# Iterating from 744 to 746 out of 10000 .
# Iterating from 746 to 748 out of 10000 .
# Iterating from 748 to 750 out of 10000 .
# Iterating from 750 to 752 out of 10000 .
# Iterating from 752 to 754 out of 10000 .
# Iterating from 754 to 756 out of 10000 .
# Iterating from 756 to 758 out of 10000 .
# Iterating from 758 to 760 out of 10000 .
# Iterating from 760 to 762 out of 10000 .
# Iterating from 762 to 764 out of 10000 .
# Iterating from 764 to 766 out of 10000 .
# Iterating from 766 to 768 out of 10000 .
# Iterating from 768 to 770 out of 10000 .
# Iterating from 770 to 772 out of 10000 .
# Iterating from 772 to 774 out of 10000 .
# Iterating from 774 to 776 out of 10000 .
# Iterating from 776 to 778 out of 10000 .
# Iterating from 778 to 780 out of 10000 .
# Iterating from 780 to 782 out of 10000 .
# Iterating from 782 to 784 out of 10000 .
# Iterating from 784 to 786 out of 10000 .
# Iterating from 786 to 788 out of 10000 .
# Iterating from 788 to 790 out of 10000 .
# Iterating from 790 to 792 out of 10000 .
# Iterating from 792 to 794 out of 10000 .
# Iterating from 794 to 796 out of 10000 .
# Iterating from 796 to 798 out of 10000 .
# Iterating from 798 to 800 out of 10000 .
# Iterating from 800 to 802 out of 10000 .
# Iterating from 802 to 804 out of 10000 .
# Iterating from 804 to 806 out of 10000 .
# Iterating from 806 to 808 out of 10000 .
# Iterating from 808 to 810 out of 10000 .
# Iterating from 810 to 812 out of 10000 .
# Iterating from 812 to 814 out of 10000 .
# Iterating from 814 to 816 out of 10000 .
# Iterating from 816 to 818 out of 10000 .
# Iterating from 818 to 820 out of 10000 .
# Iterating from 820 to 822 out of 10000 .
# Iterating from 822 to 824 out of 10000 .
# Iterating from 824 to 826 out of 10000 .
# Iterating from 826 to 828 out of 10000 .
# Iterating from 828 to 830 out of 10000 .
# Iterating from 830 to 832 out of 10000 .
# Iterating from 832 to 834 out of 10000 .
# Iterating from 834 to 836 out of 10000 .
# Iterating from 836 to 838 out of 10000 .
# Iterating from 838 to 840 out of 10000 .
# Iterating from 840 to 842 out of 10000 .
# Iterating from 842 to 844 out of 10000 .
# Iterating from 844 to 846 out of 10000 .
# Iterating from 846 to 848 out of 10000 .
# Iterating from 848 to 850 out of 10000 .
# Iterating from 850 to 852 out of 10000 .
# Iterating from 852 to 854 out of 10000 .
# Iterating from 854 to 856 out of 10000 .
# Iterating from 856 to 858 out of 10000 .
# Iterating from 858 to 860 out of 10000 .
# Iterating from 860 to 862 out of 10000 .
# Iterating from 862 to 864 out of 10000 .
# Iterating from 864 to 866 out of 10000 .
# Iterating from 866 to 868 out of 10000 .
# Iterating from 868 to 870 out of 10000 .
# Iterating from 870 to 872 out of 10000 .
# Iterating from 872 to 874 out of 10000 .
# Iterating from 874 to 876 out of 10000 .
# Iterating from 876 to 878 out of 10000 .
# Iterating from 878 to 880 out of 10000 .
# Iterating from 880 to 882 out of 10000 .
# Iterating from 882 to 884 out of 10000 .
# Iterating from 884 to 886 out of 10000 .
# Iterating from 886 to 888 out of 10000 .
# Iterating from 888 to 890 out of 10000 .
# Iterating from 890 to 892 out of 10000 .
# Iterating from 892 to 894 out of 10000 .
# Iterating from 894 to 896 out of 10000 .
# Iterating from 896 to 898 out of 10000 .
# Iterating from 898 to 900 out of 10000 .
# Iterating from 900 to 902 out of 10000 .
# Iterating from 902 to 904 out of 10000 .
# Iterating from 904 to 906 out of 10000 .
# Iterating from 906 to 908 out of 10000 .
# Iterating from 908 to 910 out of 10000 .
# Iterating from 910 to 912 out of 10000 .
# Iterating from 912 to 914 out of 10000 .
# Iterating from 914 to 916 out of 10000 .
# Iterating from 916 to 918 out of 10000 .
# Iterating from 918 to 920 out of 10000 .
# Iterating from 920 to 922 out of 10000 .
# Iterating from 922 to 924 out of 10000 .
# Iterating from 924 to 926 out of 10000 .
# Iterating from 926 to 928 out of 10000 .
# Iterating from 928 to 930 out of 10000 .
# Iterating from 930 to 932 out of 10000 .
# Iterating from 932 to 934 out of 10000 .
# Iterating from 934 to 936 out of 10000 .
# Iterating from 936 to 938 out of 10000 .
# Iterating from 938 to 940 out of 10000 .
# Iterating from 940 to 942 out of 10000 .
# Iterating from 942 to 944 out of 10000 .
# Iterating from 944 to 946 out of 10000 .
# Iterating from 946 to 948 out of 10000 .
# Iterating from 948 to 950 out of 10000 .
# Iterating from 950 to 952 out of 10000 .
# Iterating from 952 to 954 out of 10000 .
# Iterating from 954 to 956 out of 10000 .
# Iterating from 956 to 958 out of 10000 .
# Iterating from 958 to 960 out of 10000 .
# Iterating from 960 to 962 out of 10000 .
# Iterating from 962 to 964 out of 10000 .
# Iterating from 964 to 966 out of 10000 .
# Iterating from 966 to 968 out of 10000 .
# Iterating from 968 to 970 out of 10000 .
# Iterating from 970 to 972 out of 10000 .
# Iterating from 972 to 974 out of 10000 .
# Iterating from 974 to 976 out of 10000 .
# Iterating from 976 to 978 out of 10000 .
# Iterating from 978 to 980 out of 10000 .
# Iterating from 980 to 982 out of 10000 .
# Iterating from 982 to 984 out of 10000 .
# Iterating from 984 to 986 out of 10000 .
# Iterating from 986 to 988 out of 10000 .
# Iterating from 988 to 990 out of 10000 .
# Iterating from 990 to 992 out of 10000 .
# Iterating from 992 to 994 out of 10000 .
# Iterating from 994 to 996 out of 10000 .
# Iterating from 996 to 998 out of 10000 .
# Iterating from 998 to 1000 out of 10000 .
# Iterating from 1000 to 1002 out of 10000 .
# Iterating from 1002 to 1004 out of 10000 .
# Iterating from 1004 to 1006 out of 10000 .
# Iterating from 1006 to 1008 out of 10000 .
# Iterating from 1008 to 1010 out of 10000 .
# Iterating from 1010 to 1012 out of 10000 .
# Iterating from 1012 to 1014 out of 10000 .
# Iterating from 1014 to 1016 out of 10000 .
# Iterating from 1016 to 1018 out of 10000 .
# Iterating from 1018 to 1020 out of 10000 .
# Iterating from 1020 to 1022 out of 10000 .
# Iterating from 1022 to 1024 out of 10000 .
# Iterating from 1024 to 1026 out of 10000 .
# Iterating from 1026 to 1028 out of 10000 .
# Iterating from 1028 to 1030 out of 10000 .
# Iterating from 1030 to 1032 out of 10000 .
# Iterating from 1032 to 1034 out of 10000 .
# Iterating from 1034 to 1036 out of 10000 .
# Iterating from 1036 to 1038 out of 10000 .
# Iterating from 1038 to 1040 out of 10000 .
# Iterating from 1040 to 1042 out of 10000 .
# Iterating from 1042 to 1044 out of 10000 .
# Iterating from 1044 to 1046 out of 10000 .
# Iterating from 1046 to 1048 out of 10000 .
# Iterating from 1048 to 1050 out of 10000 .
# Iterating from 1050 to 1052 out of 10000 .
# Iterating from 1052 to 1054 out of 10000 .
# Iterating from 1054 to 1056 out of 10000 .
# Iterating from 1056 to 1058 out of 10000 .
# Iterating from 1058 to 1060 out of 10000 .
# Iterating from 1060 to 1062 out of 10000 .
# Iterating from 1062 to 1064 out of 10000 .
# Iterating from 1064 to 1066 out of 10000 .
# Iterating from 1066 to 1068 out of 10000 .
# Iterating from 1068 to 1070 out of 10000 .
# Iterating from 1070 to 1072 out of 10000 .
# Iterating from 1072 to 1074 out of 10000 .
# Iterating from 1074 to 1076 out of 10000 .
# Iterating from 1076 to 1078 out of 10000 .
# Iterating from 1078 to 1080 out of 10000 .
# Iterating from 1080 to 1082 out of 10000 .
# Iterating from 1082 to 1084 out of 10000 .
# Iterating from 1084 to 1086 out of 10000 .
# Iterating from 1086 to 1088 out of 10000 .
# Iterating from 1088 to 1090 out of 10000 .
# Iterating from 1090 to 1092 out of 10000 .
# Iterating from 1092 to 1094 out of 10000 .
# Iterating from 1094 to 1096 out of 10000 .
# Iterating from 1096 to 1098 out of 10000 .
# Iterating from 1098 to 1100 out of 10000 .
# Iterating from 1100 to 1102 out of 10000 .
# Iterating from 1102 to 1104 out of 10000 .
# Iterating from 1104 to 1106 out of 10000 .
# Iterating from 1106 to 1108 out of 10000 .
# Iterating from 1108 to 1110 out of 10000 .
# Iterating from 1110 to 1112 out of 10000 .
# Iterating from 1112 to 1114 out of 10000 .
# Iterating from 1114 to 1116 out of 10000 .
# Iterating from 1116 to 1118 out of 10000 .
# Iterating from 1118 to 1120 out of 10000 .
# Iterating from 1120 to 1122 out of 10000 .
# Iterating from 1122 to 1124 out of 10000 .
# Iterating from 1124 to 1126 out of 10000 .
# Iterating from 1126 to 1128 out of 10000 .
# Iterating from 1128 to 1130 out of 10000 .
# Iterating from 1130 to 1132 out of 10000 .
# Iterating from 1132 to 1134 out of 10000 .
# Iterating from 1134 to 1136 out of 10000 .
# Iterating from 1136 to 1138 out of 10000 .
# Iterating from 1138 to 1140 out of 10000 .
# Iterating from 1140 to 1142 out of 10000 .
# Iterating from 1142 to 1144 out of 10000 .
# Iterating from 1144 to 1146 out of 10000 .
# Iterating from 1146 to 1148 out of 10000 .
# Iterating from 1148 to 1150 out of 10000 .
# Iterating from 1150 to 1152 out of 10000 .
# Iterating from 1152 to 1154 out of 10000 .
# Iterating from 1154 to 1156 out of 10000 .
# Iterating from 1156 to 1158 out of 10000 .
# Iterating from 1158 to 1160 out of 10000 .
# Iterating from 1160 to 1162 out of 10000 .
# Iterating from 1162 to 1164 out of 10000 .
# Iterating from 1164 to 1166 out of 10000 .
# Iterating from 1166 to 1168 out of 10000 .
# Iterating from 1168 to 1170 out of 10000 .
# Iterating from 1170 to 1172 out of 10000 .
# Iterating from 1172 to 1174 out of 10000 .
# Iterating from 1174 to 1176 out of 10000 .
# Iterating from 1176 to 1178 out of 10000 .
# Iterating from 1178 to 1180 out of 10000 .
# Iterating from 1180 to 1182 out of 10000 .
# Iterating from 1182 to 1184 out of 10000 .
# Iterating from 1184 to 1186 out of 10000 .
# Iterating from 1186 to 1188 out of 10000 .
# Iterating from 1188 to 1190 out of 10000 .
# Iterating from 1190 to 1192 out of 10000 .
# Iterating from 1192 to 1194 out of 10000 .
# Iterating from 1194 to 1196 out of 10000 .
# Iterating from 1196 to 1198 out of 10000 .
# Iterating from 1198 to 1200 out of 10000 .
# Iterating from 1200 to 1202 out of 10000 .
# Iterating from 1202 to 1204 out of 10000 .
# Iterating from 1204 to 1206 out of 10000 .
# Iterating from 1206 to 1208 out of 10000 .
# Iterating from 1208 to 1210 out of 10000 .
# Iterating from 1210 to 1212 out of 10000 .
# Iterating from 1212 to 1214 out of 10000 .
# Iterating from 1214 to 1216 out of 10000 .
# Iterating from 1216 to 1218 out of 10000 .
# Iterating from 1218 to 1220 out of 10000 .
# Iterating from 1220 to 1222 out of 10000 .
# Iterating from 1222 to 1224 out of 10000 .
# Iterating from 1224 to 1226 out of 10000 .
# Iterating from 1226 to 1228 out of 10000 .
# Iterating from 1228 to 1230 out of 10000 .
# Iterating from 1230 to 1232 out of 10000 .
# Iterating from 1232 to 1234 out of 10000 .
# Iterating from 1234 to 1236 out of 10000 .
# Iterating from 1236 to 1238 out of 10000 .
# Iterating from 1238 to 1240 out of 10000 .
# Iterating from 1240 to 1242 out of 10000 .
# Iterating from 1242 to 1244 out of 10000 .
# Iterating from 1244 to 1246 out of 10000 .
# Iterating from 1246 to 1248 out of 10000 .
# Iterating from 1248 to 1250 out of 10000 .
# Iterating from 1250 to 1252 out of 10000 .
# Iterating from 1252 to 1254 out of 10000 .
# Iterating from 1254 to 1256 out of 10000 .
# Iterating from 1256 to 1258 out of 10000 .
# Iterating from 1258 to 1260 out of 10000 .
# Iterating from 1260 to 1262 out of 10000 .
# Iterating from 1262 to 1264 out of 10000 .
# Iterating from 1264 to 1266 out of 10000 .
# Iterating from 1266 to 1268 out of 10000 .
# Iterating from 1268 to 1270 out of 10000 .
# Iterating from 1270 to 1272 out of 10000 .
# Iterating from 1272 to 1274 out of 10000 .
# Iterating from 1274 to 1276 out of 10000 .
# Iterating from 1276 to 1278 out of 10000 .
# Iterating from 1278 to 1280 out of 10000 .
# Iterating from 1280 to 1282 out of 10000 .
# Iterating from 1282 to 1284 out of 10000 .
# Iterating from 1284 to 1286 out of 10000 .
# Iterating from 1286 to 1288 out of 10000 .
# Iterating from 1288 to 1290 out of 10000 .
# Iterating from 1290 to 1292 out of 10000 .
# Iterating from 1292 to 1294 out of 10000 .
# Iterating from 1294 to 1296 out of 10000 .
# Iterating from 1296 to 1298 out of 10000 .
# Iterating from 1298 to 1300 out of 10000 .
# Iterating from 1300 to 1302 out of 10000 .
# Iterating from 1302 to 1304 out of 10000 .
# Iterating from 1304 to 1306 out of 10000 .
# Iterating from 1306 to 1308 out of 10000 .
# Iterating from 1308 to 1310 out of 10000 .
# Iterating from 1310 to 1312 out of 10000 .
# Iterating from 1312 to 1314 out of 10000 .
# Iterating from 1314 to 1316 out of 10000 .
# Iterating from 1316 to 1318 out of 10000 .
# Iterating from 1318 to 1320 out of 10000 .
# Iterating from 1320 to 1322 out of 10000 .
# Iterating from 1322 to 1324 out of 10000 .
# Iterating from 1324 to 1326 out of 10000 .
# Iterating from 1326 to 1328 out of 10000 .
# Iterating from 1328 to 1330 out of 10000 .
# Iterating from 1330 to 1332 out of 10000 .
# Iterating from 1332 to 1334 out of 10000 .
# Iterating from 1334 to 1336 out of 10000 .
# Iterating from 1336 to 1338 out of 10000 .
# Iterating from 1338 to 1340 out of 10000 .
# Iterating from 1340 to 1342 out of 10000 .
# Iterating from 1342 to 1344 out of 10000 .
# Iterating from 1344 to 1346 out of 10000 .
# Iterating from 1346 to 1348 out of 10000 .
# Iterating from 1348 to 1350 out of 10000 .
# Iterating from 1350 to 1352 out of 10000 .
# Iterating from 1352 to 1354 out of 10000 .
# Iterating from 1354 to 1356 out of 10000 .
# Iterating from 1356 to 1358 out of 10000 .
# Iterating from 1358 to 1360 out of 10000 .
# Iterating from 1360 to 1362 out of 10000 .
# Iterating from 1362 to 1364 out of 10000 .
# Iterating from 1364 to 1366 out of 10000 .
# Iterating from 1366 to 1368 out of 10000 .
# Iterating from 1368 to 1370 out of 10000 .
# Iterating from 1370 to 1372 out of 10000 .
# Iterating from 1372 to 1374 out of 10000 .
# Iterating from 1374 to 1376 out of 10000 .
# Iterating from 1376 to 1378 out of 10000 .
# Iterating from 1378 to 1380 out of 10000 .
# Iterating from 1380 to 1382 out of 10000 .
# Iterating from 1382 to 1384 out of 10000 .
# Iterating from 1384 to 1386 out of 10000 .
# Iterating from 1386 to 1388 out of 10000 .
# Iterating from 1388 to 1390 out of 10000 .
# Iterating from 1390 to 1392 out of 10000 .
# Iterating from 1392 to 1394 out of 10000 .
# Iterating from 1394 to 1396 out of 10000 .
# Iterating from 1396 to 1398 out of 10000 .
# Iterating from 1398 to 1400 out of 10000 .
# Iterating from 1400 to 1402 out of 10000 .
# Iterating from 1402 to 1404 out of 10000 .
# Iterating from 1404 to 1406 out of 10000 .
# Iterating from 1406 to 1408 out of 10000 .
# Iterating from 1408 to 1410 out of 10000 .
# Iterating from 1410 to 1412 out of 10000 .
# Iterating from 1412 to 1414 out of 10000 .
# Iterating from 1414 to 1416 out of 10000 .
# Iterating from 1416 to 1418 out of 10000 .
# Iterating from 1418 to 1420 out of 10000 .
# Iterating from 1420 to 1422 out of 10000 .
# Iterating from 1422 to 1424 out of 10000 .
# Iterating from 1424 to 1426 out of 10000 .
# Iterating from 1426 to 1428 out of 10000 .
# Iterating from 1428 to 1430 out of 10000 .
# Iterating from 1430 to 1432 out of 10000 .
# Iterating from 1432 to 1434 out of 10000 .
# Iterating from 1434 to 1436 out of 10000 .
# Iterating from 1436 to 1438 out of 10000 .
# Iterating from 1438 to 1440 out of 10000 .
# Iterating from 1440 to 1442 out of 10000 .
# Iterating from 1442 to 1444 out of 10000 .
# Iterating from 1444 to 1446 out of 10000 .
# Iterating from 1446 to 1448 out of 10000 .
# Iterating from 1448 to 1450 out of 10000 .
# Iterating from 1450 to 1452 out of 10000 .
# Iterating from 1452 to 1454 out of 10000 .
# Iterating from 1454 to 1456 out of 10000 .
# Iterating from 1456 to 1458 out of 10000 .
# Iterating from 1458 to 1460 out of 10000 .
# Iterating from 1460 to 1462 out of 10000 .
# Iterating from 1462 to 1464 out of 10000 .
# Iterating from 1464 to 1466 out of 10000 .
# Iterating from 1466 to 1468 out of 10000 .
# Iterating from 1468 to 1470 out of 10000 .
# Iterating from 1470 to 1472 out of 10000 .
# Iterating from 1472 to 1474 out of 10000 .
# Iterating from 1474 to 1476 out of 10000 .
# Iterating from 1476 to 1478 out of 10000 .
# Iterating from 1478 to 1480 out of 10000 .
# Iterating from 1480 to 1482 out of 10000 .
# Iterating from 1482 to 1484 out of 10000 .
# Iterating from 1484 to 1486 out of 10000 .
# Iterating from 1486 to 1488 out of 10000 .
# Iterating from 1488 to 1490 out of 10000 .
# Iterating from 1490 to 1492 out of 10000 .
# Iterating from 1492 to 1494 out of 10000 .
# Iterating from 1494 to 1496 out of 10000 .
# Iterating from 1496 to 1498 out of 10000 .
# Iterating from 1498 to 1500 out of 10000 .
# Iterating from 1500 to 1502 out of 10000 .
# Iterating from 1502 to 1504 out of 10000 .
# Iterating from 1504 to 1506 out of 10000 .
# Iterating from 1506 to 1508 out of 10000 .
# Iterating from 1508 to 1510 out of 10000 .
# Iterating from 1510 to 1512 out of 10000 .
# Iterating from 1512 to 1514 out of 10000 .
# Iterating from 1514 to 1516 out of 10000 .
# Iterating from 1516 to 1518 out of 10000 .
# Iterating from 1518 to 1520 out of 10000 .
# Iterating from 1520 to 1522 out of 10000 .
# Iterating from 1522 to 1524 out of 10000 .
# Iterating from 1524 to 1526 out of 10000 .
# Iterating from 1526 to 1528 out of 10000 .
# Iterating from 1528 to 1530 out of 10000 .
# Iterating from 1530 to 1532 out of 10000 .
# Iterating from 1532 to 1534 out of 10000 .
# Iterating from 1534 to 1536 out of 10000 .
# Iterating from 1536 to 1538 out of 10000 .
# Iterating from 1538 to 1540 out of 10000 .
# Iterating from 1540 to 1542 out of 10000 .
# Iterating from 1542 to 1544 out of 10000 .
# Iterating from 1544 to 1546 out of 10000 .
# Iterating from 1546 to 1548 out of 10000 .
# Iterating from 1548 to 1550 out of 10000 .
# Iterating from 1550 to 1552 out of 10000 .
# Iterating from 1552 to 1554 out of 10000 .
# Iterating from 1554 to 1556 out of 10000 .
# Iterating from 1556 to 1558 out of 10000 .
# Iterating from 1558 to 1560 out of 10000 .
# Iterating from 1560 to 1562 out of 10000 .
# Iterating from 1562 to 1564 out of 10000 .
# Iterating from 1564 to 1566 out of 10000 .
# Iterating from 1566 to 1568 out of 10000 .
# Iterating from 1568 to 1570 out of 10000 .
# Iterating from 1570 to 1572 out of 10000 .
# Iterating from 1572 to 1574 out of 10000 .
# Iterating from 1574 to 1576 out of 10000 .
# Iterating from 1576 to 1578 out of 10000 .
# Iterating from 1578 to 1580 out of 10000 .
# Iterating from 1580 to 1582 out of 10000 .
# Iterating from 1582 to 1584 out of 10000 .
# Iterating from 1584 to 1586 out of 10000 .
# Iterating from 1586 to 1588 out of 10000 .
# Iterating from 1588 to 1590 out of 10000 .
# Iterating from 1590 to 1592 out of 10000 .
# Iterating from 1592 to 1594 out of 10000 .
# Iterating from 1594 to 1596 out of 10000 .
# Iterating from 1596 to 1598 out of 10000 .
# Iterating from 1598 to 1600 out of 10000 .
# Iterating from 1600 to 1602 out of 10000 .
# Iterating from 1602 to 1604 out of 10000 .
# Iterating from 1604 to 1606 out of 10000 .
# Iterating from 1606 to 1608 out of 10000 .
# Iterating from 1608 to 1610 out of 10000 .
# Iterating from 1610 to 1612 out of 10000 .
# Iterating from 1612 to 1614 out of 10000 .
# Iterating from 1614 to 1616 out of 10000 .
# Iterating from 1616 to 1618 out of 10000 .
# Iterating from 1618 to 1620 out of 10000 .
# Iterating from 1620 to 1622 out of 10000 .
# Iterating from 1622 to 1624 out of 10000 .
# Iterating from 1624 to 1626 out of 10000 .
# Iterating from 1626 to 1628 out of 10000 .
# Iterating from 1628 to 1630 out of 10000 .
# Iterating from 1630 to 1632 out of 10000 .
# Iterating from 1632 to 1634 out of 10000 .
# Iterating from 1634 to 1636 out of 10000 .
# Iterating from 1636 to 1638 out of 10000 .
# Iterating from 1638 to 1640 out of 10000 .
# Iterating from 1640 to 1642 out of 10000 .
# Iterating from 1642 to 1644 out of 10000 .
# Iterating from 1644 to 1646 out of 10000 .
# Iterating from 1646 to 1648 out of 10000 .
# Iterating from 1648 to 1650 out of 10000 .
# Iterating from 1650 to 1652 out of 10000 .
# Iterating from 1652 to 1654 out of 10000 .
# Iterating from 1654 to 1656 out of 10000 .
# Iterating from 1656 to 1658 out of 10000 .
# Iterating from 1658 to 1660 out of 10000 .
# Iterating from 1660 to 1662 out of 10000 .
# Iterating from 1662 to 1664 out of 10000 .
# Iterating from 1664 to 1666 out of 10000 .
# Iterating from 1666 to 1668 out of 10000 .
# Iterating from 1668 to 1670 out of 10000 .
# Iterating from 1670 to 1672 out of 10000 .
# Iterating from 1672 to 1674 out of 10000 .
# Iterating from 1674 to 1676 out of 10000 .
# Iterating from 1676 to 1678 out of 10000 .
# Iterating from 1678 to 1680 out of 10000 .
# Iterating from 1680 to 1682 out of 10000 .
# Iterating from 1682 to 1684 out of 10000 .
# Iterating from 1684 to 1686 out of 10000 .
# Iterating from 1686 to 1688 out of 10000 .
# Iterating from 1688 to 1690 out of 10000 .
# Iterating from 1690 to 1692 out of 10000 .
# Iterating from 1692 to 1694 out of 10000 .
# Iterating from 1694 to 1696 out of 10000 .
# Iterating from 1696 to 1698 out of 10000 .
# Iterating from 1698 to 1700 out of 10000 .
# Iterating from 1700 to 1702 out of 10000 .
# Iterating from 1702 to 1704 out of 10000 .
# Iterating from 1704 to 1706 out of 10000 .
# Iterating from 1706 to 1708 out of 10000 .
# Iterating from 1708 to 1710 out of 10000 .
# Iterating from 1710 to 1712 out of 10000 .
# Iterating from 1712 to 1714 out of 10000 .
# Iterating from 1714 to 1716 out of 10000 .
# Iterating from 1716 to 1718 out of 10000 .
# Iterating from 1718 to 1720 out of 10000 .
# Iterating from 1720 to 1722 out of 10000 .
# Iterating from 1722 to 1724 out of 10000 .
# Iterating from 1724 to 1726 out of 10000 .
# Iterating from 1726 to 1728 out of 10000 .
# Iterating from 1728 to 1730 out of 10000 .
# Iterating from 1730 to 1732 out of 10000 .
# Iterating from 1732 to 1734 out of 10000 .
# Iterating from 1734 to 1736 out of 10000 .
# Iterating from 1736 to 1738 out of 10000 .
# Iterating from 1738 to 1740 out of 10000 .
# Iterating from 1740 to 1742 out of 10000 .
# Iterating from 1742 to 1744 out of 10000 .
# Iterating from 1744 to 1746 out of 10000 .
# Iterating from 1746 to 1748 out of 10000 .
# Iterating from 1748 to 1750 out of 10000 .
# Iterating from 1750 to 1752 out of 10000 .
# Iterating from 1752 to 1754 out of 10000 .
# Iterating from 1754 to 1756 out of 10000 .
# Iterating from 1756 to 1758 out of 10000 .
# Iterating from 1758 to 1760 out of 10000 .
# Iterating from 1760 to 1762 out of 10000 .
# Iterating from 1762 to 1764 out of 10000 .
# Iterating from 1764 to 1766 out of 10000 .
# Iterating from 1766 to 1768 out of 10000 .
# Iterating from 1768 to 1770 out of 10000 .
# Iterating from 1770 to 1772 out of 10000 .
# Iterating from 1772 to 1774 out of 10000 .
# Iterating from 1774 to 1776 out of 10000 .
# Iterating from 1776 to 1778 out of 10000 .
# Iterating from 1778 to 1780 out of 10000 .
# Iterating from 1780 to 1782 out of 10000 .
# Iterating from 1782 to 1784 out of 10000 .
# Iterating from 1784 to 1786 out of 10000 .
# Iterating from 1786 to 1788 out of 10000 .
# Iterating from 1788 to 1790 out of 10000 .
# Iterating from 1790 to 1792 out of 10000 .
# Iterating from 1792 to 1794 out of 10000 .
# Iterating from 1794 to 1796 out of 10000 .
# Iterating from 1796 to 1798 out of 10000 .
# Iterating from 1798 to 1800 out of 10000 .
# Iterating from 1800 to 1802 out of 10000 .
# Iterating from 1802 to 1804 out of 10000 .
# Iterating from 1804 to 1806 out of 10000 .
# Iterating from 1806 to 1808 out of 10000 .
# Iterating from 1808 to 1810 out of 10000 .
# Iterating from 1810 to 1812 out of 10000 .
# Iterating from 1812 to 1814 out of 10000 .
# Iterating from 1814 to 1816 out of 10000 .
# Iterating from 1816 to 1818 out of 10000 .
# Iterating from 1818 to 1820 out of 10000 .
# Iterating from 1820 to 1822 out of 10000 .
# Iterating from 1822 to 1824 out of 10000 .
# Iterating from 1824 to 1826 out of 10000 .
# Iterating from 1826 to 1828 out of 10000 .
# Iterating from 1828 to 1830 out of 10000 .
# Iterating from 1830 to 1832 out of 10000 .
# Iterating from 1832 to 1834 out of 10000 .
# Iterating from 1834 to 1836 out of 10000 .
# Iterating from 1836 to 1838 out of 10000 .
# Iterating from 1838 to 1840 out of 10000 .
# Iterating from 1840 to 1842 out of 10000 .
# Iterating from 1842 to 1844 out of 10000 .
# Iterating from 1844 to 1846 out of 10000 .
# Iterating from 1846 to 1848 out of 10000 .
# Iterating from 1848 to 1850 out of 10000 .
# Iterating from 1850 to 1852 out of 10000 .
# Iterating from 1852 to 1854 out of 10000 .
# Iterating from 1854 to 1856 out of 10000 .
# Iterating from 1856 to 1858 out of 10000 .
# Iterating from 1858 to 1860 out of 10000 .
# Iterating from 1860 to 1862 out of 10000 .
# Iterating from 1862 to 1864 out of 10000 .
# Iterating from 1864 to 1866 out of 10000 .
# Iterating from 1866 to 1868 out of 10000 .
# Iterating from 1868 to 1870 out of 10000 .
# Iterating from 1870 to 1872 out of 10000 .
# Iterating from 1872 to 1874 out of 10000 .
# Iterating from 1874 to 1876 out of 10000 .
# Iterating from 1876 to 1878 out of 10000 .
# Iterating from 1878 to 1880 out of 10000 .
# Iterating from 1880 to 1882 out of 10000 .
# Iterating from 1882 to 1884 out of 10000 .
# Iterating from 1884 to 1886 out of 10000 .
# Iterating from 1886 to 1888 out of 10000 .
# Iterating from 1888 to 1890 out of 10000 .
# Iterating from 1890 to 1892 out of 10000 .
# Iterating from 1892 to 1894 out of 10000 .
# Iterating from 1894 to 1896 out of 10000 .
# Iterating from 1896 to 1898 out of 10000 .
# Iterating from 1898 to 1900 out of 10000 .
# Iterating from 1900 to 1902 out of 10000 .
# Iterating from 1902 to 1904 out of 10000 .
# Iterating from 1904 to 1906 out of 10000 .
# Iterating from 1906 to 1908 out of 10000 .
# Iterating from 1908 to 1910 out of 10000 .
# Iterating from 1910 to 1912 out of 10000 .
# Iterating from 1912 to 1914 out of 10000 .
# Iterating from 1914 to 1916 out of 10000 .
# Iterating from 1916 to 1918 out of 10000 .
# Iterating from 1918 to 1920 out of 10000 .
# Iterating from 1920 to 1922 out of 10000 .
# Iterating from 1922 to 1924 out of 10000 .
# Iterating from 1924 to 1926 out of 10000 .
# Iterating from 1926 to 1928 out of 10000 .
# Iterating from 1928 to 1930 out of 10000 .
# Iterating from 1930 to 1932 out of 10000 .
# Iterating from 1932 to 1934 out of 10000 .
# Iterating from 1934 to 1936 out of 10000 .
# Iterating from 1936 to 1938 out of 10000 .
# Iterating from 1938 to 1940 out of 10000 .
# Iterating from 1940 to 1942 out of 10000 .
# Iterating from 1942 to 1944 out of 10000 .
# Iterating from 1944 to 1946 out of 10000 .
# Iterating from 1946 to 1948 out of 10000 .
# Iterating from 1948 to 1950 out of 10000 .
# Iterating from 1950 to 1952 out of 10000 .
# Iterating from 1952 to 1954 out of 10000 .
# Iterating from 1954 to 1956 out of 10000 .
# Iterating from 1956 to 1958 out of 10000 .
# Iterating from 1958 to 1960 out of 10000 .
# Iterating from 1960 to 1962 out of 10000 .
# Iterating from 1962 to 1964 out of 10000 .
# Iterating from 1964 to 1966 out of 10000 .
# Iterating from 1966 to 1968 out of 10000 .
# Iterating from 1968 to 1970 out of 10000 .
# Iterating from 1970 to 1972 out of 10000 .
# Iterating from 1972 to 1974 out of 10000 .
# Iterating from 1974 to 1976 out of 10000 .
# Iterating from 1976 to 1978 out of 10000 .
# Iterating from 1978 to 1980 out of 10000 .
# Iterating from 1980 to 1982 out of 10000 .
# Iterating from 1982 to 1984 out of 10000 .
# Iterating from 1984 to 1986 out of 10000 .
# Iterating from 1986 to 1988 out of 10000 .
# Iterating from 1988 to 1990 out of 10000 .
# Iterating from 1990 to 1992 out of 10000 .
# Iterating from 1992 to 1994 out of 10000 .
# Iterating from 1994 to 1996 out of 10000 .
# Iterating from 1996 to 1998 out of 10000 .
# Iterating from 1998 to 2000 out of 10000 .
# Iterating from 2000 to 2002 out of 10000 .
# Iterating from 2002 to 2004 out of 10000 .
# Iterating from 2004 to 2006 out of 10000 .
# Iterating from 2006 to 2008 out of 10000 .
# Iterating from 2008 to 2010 out of 10000 .
# Iterating from 2010 to 2012 out of 10000 .
# Iterating from 2012 to 2014 out of 10000 .
# Iterating from 2014 to 2016 out of 10000 .
# Iterating from 2016 to 2018 out of 10000 .
# Iterating from 2018 to 2020 out of 10000 .
# Iterating from 2020 to 2022 out of 10000 .
# Iterating from 2022 to 2024 out of 10000 .
# Iterating from 2024 to 2026 out of 10000 .
# Iterating from 2026 to 2028 out of 10000 .
# Iterating from 2028 to 2030 out of 10000 .
# Iterating from 2030 to 2032 out of 10000 .
# Iterating from 2032 to 2034 out of 10000 .
# Iterating from 2034 to 2036 out of 10000 .
# Iterating from 2036 to 2038 out of 10000 .
# Iterating from 2038 to 2040 out of 10000 .
# Iterating from 2040 to 2042 out of 10000 .
# Iterating from 2042 to 2044 out of 10000 .
# Iterating from 2044 to 2046 out of 10000 .
# Iterating from 2046 to 2048 out of 10000 .
# Iterating from 2048 to 2050 out of 10000 .
# Iterating from 2050 to 2052 out of 10000 .
# Iterating from 2052 to 2054 out of 10000 .
# Iterating from 2054 to 2056 out of 10000 .
# Iterating from 2056 to 2058 out of 10000 .
# Iterating from 2058 to 2060 out of 10000 .
# Iterating from 2060 to 2062 out of 10000 .
# Iterating from 2062 to 2064 out of 10000 .
# Iterating from 2064 to 2066 out of 10000 .
# Iterating from 2066 to 2068 out of 10000 .
# Iterating from 2068 to 2070 out of 10000 .
# Iterating from 2070 to 2072 out of 10000 .
# Iterating from 2072 to 2074 out of 10000 .
# Iterating from 2074 to 2076 out of 10000 .
# Iterating from 2076 to 2078 out of 10000 .
# Iterating from 2078 to 2080 out of 10000 .
# Iterating from 2080 to 2082 out of 10000 .
# Iterating from 2082 to 2084 out of 10000 .
# Iterating from 2084 to 2086 out of 10000 .
# Iterating from 2086 to 2088 out of 10000 .
# Iterating from 2088 to 2090 out of 10000 .
# Iterating from 2090 to 2092 out of 10000 .
# Iterating from 2092 to 2094 out of 10000 .
# Iterating from 2094 to 2096 out of 10000 .
# Iterating from 2096 to 2098 out of 10000 .
# Iterating from 2098 to 2100 out of 10000 .
# Iterating from 2100 to 2102 out of 10000 .
# Iterating from 2102 to 2104 out of 10000 .
# Iterating from 2104 to 2106 out of 10000 .
# Iterating from 2106 to 2108 out of 10000 .
# Iterating from 2108 to 2110 out of 10000 .
# Iterating from 2110 to 2112 out of 10000 .
# Iterating from 2112 to 2114 out of 10000 .
# Iterating from 2114 to 2116 out of 10000 .
# Iterating from 2116 to 2118 out of 10000 .
# Iterating from 2118 to 2120 out of 10000 .
# Iterating from 2120 to 2122 out of 10000 .
# Iterating from 2122 to 2124 out of 10000 .
# Iterating from 2124 to 2126 out of 10000 .
# Iterating from 2126 to 2128 out of 10000 .
# Iterating from 2128 to 2130 out of 10000 .
# Iterating from 2130 to 2132 out of 10000 .
# Iterating from 2132 to 2134 out of 10000 .
# Iterating from 2134 to 2136 out of 10000 .
# Iterating from 2136 to 2138 out of 10000 .
# Iterating from 2138 to 2140 out of 10000 .
# Iterating from 2140 to 2142 out of 10000 .
# Iterating from 2142 to 2144 out of 10000 .
# Iterating from 2144 to 2146 out of 10000 .
# Iterating from 2146 to 2148 out of 10000 .
# Iterating from 2148 to 2150 out of 10000 .
# Iterating from 2150 to 2152 out of 10000 .
# Iterating from 2152 to 2154 out of 10000 .
# Iterating from 2154 to 2156 out of 10000 .
# Iterating from 2156 to 2158 out of 10000 .
# Iterating from 2158 to 2160 out of 10000 .
# Iterating from 2160 to 2162 out of 10000 .
# Iterating from 2162 to 2164 out of 10000 .
# Iterating from 2164 to 2166 out of 10000 .
# Iterating from 2166 to 2168 out of 10000 .
# Iterating from 2168 to 2170 out of 10000 .
# Iterating from 2170 to 2172 out of 10000 .
# Iterating from 2172 to 2174 out of 10000 .
# Iterating from 2174 to 2176 out of 10000 .
# Iterating from 2176 to 2178 out of 10000 .
# Iterating from 2178 to 2180 out of 10000 .
# Iterating from 2180 to 2182 out of 10000 .
# Iterating from 2182 to 2184 out of 10000 .
# Iterating from 2184 to 2186 out of 10000 .
# Iterating from 2186 to 2188 out of 10000 .
# Iterating from 2188 to 2190 out of 10000 .
# Iterating from 2190 to 2192 out of 10000 .
# Iterating from 2192 to 2194 out of 10000 .
# Iterating from 2194 to 2196 out of 10000 .
# ...
# Iterating from 9680 to 9682 out of 10000 .
# Iterating from 9682 to 9684 out of 10000 .
# Iterating from 9684 to 9686 out of 10000 .
# Iterating from 9686 to 9688 out of 10000 .
# Iterating from 9688 to 9690 out of 10000 .
# Iterating from 9690 to 9692 out of 10000 .
# Iterating from 9692 to 9694 out of 10000 .
# Iterating from 9694 to 9696 out of 10000 .
# Iterating from 9696 to 9698 out of 10000 .
# Iterating from 9698 to 9700 out of 10000 .
# Iterating from 9700 to 9702 out of 10000 .
# Iterating from 9702 to 9704 out of 10000 .
# Iterating from 9704 to 9706 out of 10000 .
# Iterating from 9706 to 9708 out of 10000 .
# Iterating from 9708 to 9710 out of 10000 .
# Iterating from 9710 to 9712 out of 10000 .
# Iterating from 9712 to 9714 out of 10000 .
# Iterating from 9714 to 9716 out of 10000 .
# Iterating from 9716 to 9718 out of 10000 .
# Iterating from 9718 to 9720 out of 10000 .
# Iterating from 9720 to 9722 out of 10000 .
# Iterating from 9722 to 9724 out of 10000 .
# Iterating from 9724 to 9726 out of 10000 .
# Iterating from 9726 to 9728 out of 10000 .
# Iterating from 9728 to 9730 out of 10000 .
# Iterating from 9730 to 9732 out of 10000 .
# Iterating from 9732 to 9734 out of 10000 .
# Iterating from 9734 to 9736 out of 10000 .
# Iterating from 9736 to 9738 out of 10000 .
# Iterating from 9738 to 9740 out of 10000 .
# Iterating from 9740 to 9742 out of 10000 .
# Iterating from 9742 to 9744 out of 10000 .
# Iterating from 9744 to 9746 out of 10000 .
# Iterating from 9746 to 9748 out of 10000 .
# Iterating from 9748 to 9750 out of 10000 .
# Iterating from 9750 to 9752 out of 10000 .
# Iterating from 9752 to 9754 out of 10000 .
# Iterating from 9754 to 9756 out of 10000 .
# Iterating from 9756 to 9758 out of 10000 .
# Iterating from 9758 to 9760 out of 10000 .
# Iterating from 9760 to 9762 out of 10000 .
# Iterating from 9762 to 9764 out of 10000 .
# Iterating from 9764 to 9766 out of 10000 .
# Iterating from 9766 to 9768 out of 10000 .
# Iterating from 9768 to 9770 out of 10000 .
# Iterating from 9770 to 9772 out of 10000 .
# Iterating from 9772 to 9774 out of 10000 .
# Iterating from 9774 to 9776 out of 10000 .
# Iterating from 9776 to 9778 out of 10000 .
# Iterating from 9778 to 9780 out of 10000 .
# Iterating from 9780 to 9782 out of 10000 .
# Iterating from 9782 to 9784 out of 10000 .
# Iterating from 9784 to 9786 out of 10000 .
# Iterating from 9786 to 9788 out of 10000 .
# Iterating from 9788 to 9790 out of 10000 .
# Iterating from 9790 to 9792 out of 10000 .
# Iterating from 9792 to 9794 out of 10000 .
# Iterating from 9794 to 9796 out of 10000 .
# Iterating from 9796 to 9798 out of 10000 .
# Iterating from 9798 to 9800 out of 10000 .
# Iterating from 9800 to 9802 out of 10000 .
# Iterating from 9802 to 9804 out of 10000 .
# Iterating from 9804 to 9806 out of 10000 .
# Iterating from 9806 to 9808 out of 10000 .
# Iterating from 9808 to 9810 out of 10000 .
# Iterating from 9810 to 9812 out of 10000 .
# Iterating from 9812 to 9814 out of 10000 .
# Iterating from 9814 to 9816 out of 10000 .
# Iterating from 9816 to 9818 out of 10000 .
# Iterating from 9818 to 9820 out of 10000 .
# Iterating from 9820 to 9822 out of 10000 .
# Iterating from 9822 to 9824 out of 10000 .
# Iterating from 9824 to 9826 out of 10000 .
# Iterating from 9826 to 9828 out of 10000 .
# Iterating from 9828 to 9830 out of 10000 .
# Iterating from 9830 to 9832 out of 10000 .
# Iterating from 9832 to 9834 out of 10000 .
# Iterating from 9834 to 9836 out of 10000 .
# Iterating from 9836 to 9838 out of 10000 .
# Iterating from 9838 to 9840 out of 10000 .
# Iterating from 9840 to 9842 out of 10000 .
# Iterating from 9842 to 9844 out of 10000 .
# Iterating from 9844 to 9846 out of 10000 .
# Iterating from 9846 to 9848 out of 10000 .
# Iterating from 9848 to 9850 out of 10000 .
# Iterating from 9850 to 9852 out of 10000 .
# Iterating from 9852 to 9854 out of 10000 .
# Iterating from 9854 to 9856 out of 10000 .
# Iterating from 9856 to 9858 out of 10000 .
# Iterating from 9858 to 9860 out of 10000 .
# Iterating from 9860 to 9862 out of 10000 .
# Iterating from 9862 to 9864 out of 10000 .
# Iterating from 9864 to 9866 out of 10000 .
# Iterating from 9866 to 9868 out of 10000 .
# Iterating from 9868 to 9870 out of 10000 .
# Iterating from 9870 to 9872 out of 10000 .
# Iterating from 9872 to 9874 out of 10000 .
# Iterating from 9874 to 9876 out of 10000 .
# Iterating from 9876 to 9878 out of 10000 .
# Iterating from 9878 to 9880 out of 10000 .
# Iterating from 9880 to 9882 out of 10000 .
# Iterating from 9882 to 9884 out of 10000 .
# Iterating from 9884 to 9886 out of 10000 .
# Iterating from 9886 to 9888 out of 10000 .
# Iterating from 9888 to 9890 out of 10000 .
# Iterating from 9890 to 9892 out of 10000 .
# Iterating from 9892 to 9894 out of 10000 .
# Iterating from 9894 to 9896 out of 10000 .
# Iterating from 9896 to 9898 out of 10000 .
# Iterating from 9898 to 9900 out of 10000 .
# Iterating from 9900 to 9902 out of 10000 .
# Iterating from 9902 to 9904 out of 10000 .
# Iterating from 9904 to 9906 out of 10000 .
# Iterating from 9906 to 9908 out of 10000 .
# Iterating from 9908 to 9910 out of 10000 .
# Iterating from 9910 to 9912 out of 10000 .
# Iterating from 9912 to 9914 out of 10000 .
# Iterating from 9914 to 9916 out of 10000 .
# Iterating from 9916 to 9918 out of 10000 .
# Iterating from 9918 to 9920 out of 10000 .
# Iterating from 9920 to 9922 out of 10000 .
# Iterating from 9922 to 9924 out of 10000 .
# Iterating from 9924 to 9926 out of 10000 .
# Iterating from 9926 to 9928 out of 10000 .
# Iterating from 9928 to 9930 out of 10000 .
# Iterating from 9930 to 9932 out of 10000 .
# Iterating from 9932 to 9934 out of 10000 .
# Iterating from 9934 to 9936 out of 10000 .
# Iterating from 9936 to 9938 out of 10000 .
# Iterating from 9938 to 9940 out of 10000 .
# Iterating from 9940 to 9942 out of 10000 .
# Iterating from 9942 to 9944 out of 10000 .
# Iterating from 9944 to 9946 out of 10000 .
# Iterating from 9946 to 9948 out of 10000 .
# Iterating from 9948 to 9950 out of 10000 .
# Iterating from 9950 to 9952 out of 10000 .
# Iterating from 9952 to 9954 out of 10000 .
# Iterating from 9954 to 9956 out of 10000 .
# Iterating from 9956 to 9958 out of 10000 .
# Iterating from 9958 to 9960 out of 10000 .
# Iterating from 9960 to 9962 out of 10000 .
# Iterating from 9962 to 9964 out of 10000 .
# Iterating from 9964 to 9966 out of 10000 .
# Iterating from 9966 to 9968 out of 10000 .
# Iterating from 9968 to 9970 out of 10000 .
# Iterating from 9970 to 9972 out of 10000 .
# Iterating from 9972 to 9974 out of 10000 .
# Iterating from 9974 to 9976 out of 10000 .
# Iterating from 9976 to 9978 out of 10000 .
# Iterating from 9978 to 9980 out of 10000 .
# Iterating from 9980 to 9982 out of 10000 .
# Iterating from 9982 to 9984 out of 10000 .
# Iterating from 9984 to 9986 out of 10000 .
# Iterating from 9986 to 9988 out of 10000 .
# Iterating from 9988 to 9990 out of 10000 .
# Iterating from 9990 to 9992 out of 10000 .
# Iterating from 9992 to 9994 out of 10000 .
# Iterating from 9994 to 9996 out of 10000 .
# Iterating from 9996 to 9998 out of 10000 .
# Iterating from 9998 to 10000 out of 10000 .
# MMD metric calculation completed in 13796.460939258977 seconds.
# Saving mmd to results/5D_unimodal/5D_50K/null_hypothesis/MMD.json
# Computing and savng ks with max_vectorize = 5000
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f6e180b0860> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 5000 to 6000 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f6e180b0860> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# KS tests calculation completed in 41.796542408003006 seconds.
# Saving ks to results/5D_unimodal/5D_50K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 200
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f6e33d96020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 1000 to 1200 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f6e33d96020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# SKS metric calculation completed in 476.55355824000435 seconds.
# Saving sks to results/5D_unimodal/5D_50K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 200
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# SWD metric calculation completed in 312.79341152502457 seconds.
# Saving swd to results/5D_unimodal/5D_50K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.00020161700277864327], [0.95, [9500, 500], 0.002091095997342832], [0.99, [9900, 100], 0.003945024361980691]]
# Computing time for metric fgd: 1307.4540228959522
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.2934891524732848], [0.95, [9500, 500], 17.115542876668314], [0.99, [9900, 100], 33.71292738522834]]
# Computing time for metric mmd: 13796.460939258977
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9176942807038486], [0.95, [9500, 500], 1.1226073102703782], [0.99, [9900, 100], 1.276294438525733]]
# Computing time for metric ks: 41.796542408003006
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9090295886636403], [0.95, [9500, 500], 1.127827663014987], [0.99, [9900, 100], 1.283948990520711]]
# Computing time for metric sks: 476.55355824000435
# ThresholdS for metric swd: [[0.68, [6800, 3199], 1.1599848669812065], [0.95, [9500, 500], 1.582954005685028], [0.99, [9900, 100], 1.9286091864422517]]
# Computing time for metric swd: 312.79341152502457
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f6e180b02c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f6e180b0400>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f6e180b04a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f6e180b0540>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f6e180b05e0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f6e180b0680>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...           1000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_unimodal/5D_50K/null_hypothesis/FGD...
# 1  $d_{\mathrm{MMD}}$  results/5D_unimodal/5D_50K/null_hypothesis/MMD...
# 2      $\overline{D}$  results/5D_unimodal/5D_50K/null_hypothesis/KS....
# 3     $\widetilde{D}$  results/5D_unimodal/5D_50K/null_hypothesis/SKS...
# 4     $\widetilde{W}$  results/5D_unimodal/5D_50K/null_hypothesis/SWD...
# 5           $t_{\mu}$  results/5D_unimodal/5D_50K/null_hypothesis/LR....
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.00020161700277864327],...
# 1  [[0.68, [6800, 3199], 0.2934891524732848], [0....
# 2  [[0.68, [6800, 3199], 0.9176942807038486], [0....
# 3  [[0.68, [6800, 3199], 0.9090295886636403], [0....
# 4  [[0.68, [6800, 3199], 1.1599848669812065], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{2})$"
        dist_null = dist_null * 100
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-2})$"
        dist_null = dist_null / 100
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.040498332106210275 +/- 7.07117516202293e-05
# sigma = 0.08409027983080404 +/- 0.0018753898380497616
# 68%CL = 0.020161700277864326, 95%CL = 0.2091095997342832, 99%CL = 0.39450243619806913
# mu = 0.040498332106210275 +/- 7.07117516202293e-05
# sigma = 0.08409027983080404 +/- 0.0018753898380497616
# /tmp/ipykernel_164502/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164502/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164502/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.4102049359935336 seconds.
# mu = 0.001386509909558935 +/- 7.272712019892455e-05
# sigma = 0.08528019711452628 +/- 0.0015736730784294778
# 68%CL = 0.0029348915247328477, 95%CL = 0.17115542876668313, 99%CL = 0.3371292738522834
# mu = 0.001386509909558935 +/- 7.272712019892455e-05
# sigma = 0.08528019711452628 +/- 0.0015736730784294778
# /tmp/ipykernel_164502/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164502/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164502/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.737546771997586 seconds.
# mu = 0.8659351897912944 +/- 0.00020025446480595888
# sigma = 0.14151129453367278 +/- 0.001176280659996323
# 68%CL = 0.9176942807038486, 95%CL = 1.1226073102703782, 99%CL = 1.276294438525733
# mu = 0.8659351897912944 +/- 0.00020025446480595888
# sigma = 0.14151129453367278 +/- 0.001176280659996323
# /tmp/ipykernel_164502/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164502/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164502/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_164502/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2848796620382927 seconds.
# mu = 0.8662069767387642 +/- 0.00019130957653328346
# sigma = 0.13831470512323824 +/- 0.0012654481145629715
# 68%CL = 0.9090295886636403, 95%CL = 1.127827663014987, 99%CL = 1.283948990520711
# mu = 0.8662069767387642 +/- 0.00019130957653328346
# sigma = 0.13831470512323824 +/- 0.0012654481145629715
# /tmp/ipykernel_164502/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164502/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164502/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_164502/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.280753382947296 seconds.
# mu = 1.0957000227406395 +/- 0.0006390148381895107
# sigma = 0.25278742812677824 +/- 0.0027532433994483965
# 68%CL = 1.1599848669812065, 95%CL = 1.582954005685028, 99%CL = 1.9286091864422517
# mu = 1.0957000227406395 +/- 0.0006390148381895107
# sigma = 0.25278742812677824 +/- 0.0027532433994483965
# /tmp/ipykernel_164502/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164502/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164502/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_164502/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.8868555880035274 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f6e180b02c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f6e180b0400>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f6e180b04a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f6e180b0540>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f6e180b05e0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f6e180b0680>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...           1000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_unimodal/5D_50K/null_hypothesis/FGD...
# 1  $d_{\mathrm{MMD}}$  results/5D_unimodal/5D_50K/null_hypothesis/MMD...
# 2      $\overline{D}$  results/5D_unimodal/5D_50K/null_hypothesis/KS....
# 3     $\widetilde{D}$  results/5D_unimodal/5D_50K/null_hypothesis/SKS...
# 4     $\widetilde{W}$  results/5D_unimodal/5D_50K/null_hypothesis/SWD...
# 5           $t_{\mu}$  results/5D_unimodal/5D_50K/null_hypothesis/LR....
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.00020161700277864327],...
# 1  [[0.68, [6800, 3199], 0.2934891524732848], [0....
# 2  [[0.68, [6800, 3199], 0.9176942807038486], [0....
# 3  [[0.68, [6800, 3199], 0.9090295886636403], [0....
# 4  [[0.68, [6800, 3199], 1.1599848669812065], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/5D_unimodal/5D_50K/null_hypothesis/FGD...
# 1  results/5D_unimodal/5D_50K/null_hypothesis/MMD...
# 2  results/5D_unimodal/5D_50K/null_hypothesis/KS.pdf
# 3  results/5D_unimodal/5D_50K/null_hypothesis/SKS...
# 4  results/5D_unimodal/5D_50K/null_hypothesis/SWD...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = mean
# statistic = 7.609241911828006 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9989010618795984
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 104 calls to <function generate_and_clean_data_simple_1 at 0x7f6f09fc4f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.892875810215136 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9955859999655143
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = mean
# WARNING:tensorflow:6 out of the last 105 calls to <function generate_and_clean_data_simple_1 at 0x7f6f09fc4f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.4687448055638005 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9822350335612948
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = mean
# WARNING:tensorflow:5 out of the last 14 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f6c991aab60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.11520085377466549 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9286874844724637
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = mean
# WARNING:tensorflow:6 out of the last 15 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f6c99374540> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.027603269792238056 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7183174731313438
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = mean
# statistic = 0.006246272325957198 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9967596890261163
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = mean
# statistic = 0.001317955781658771 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.45358079947409186
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.05859375 - deformation = mean
# statistic = 0.00324683093918112 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.4330276362272207
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.048828125 - deformation = mean
# statistic = 0.002168272818937942 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.036238618877103904
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0439453125 - deformation = mean
# statistic = 0.0017017578321767593 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.20530090673986598
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.04638671875 - deformation = mean
# statistic = 0.0019303668855390553 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.0799356435629185
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.047607421875 - deformation = mean
# statistic = 0.0020501983958653557 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.02531645569620253
# relative_error_metric = 0.019751120106094894
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0482177734375 - deformation = mean
# statistic = 0.0021070517617387437 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.012738853503184714
# relative_error_metric = 0.0076013353085992545
# =======> statistic within required accuracy at 0.95 CL in 97.43939424294513 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.04791259765625 - deformation = mean
# statistic = 0.002075458608985849 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9620337343570522
# relative_error_metric = 0.6210683634554649
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.523956298828125 - deformation = mean
# statistic = 7.756027494810577 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9254820528033225
# relative_error_metric = 1.997966475086228
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2859344482421875 - deformation = mean
# statistic = 2.0038031165419583 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.8563175656351885
# relative_error_metric = 1.992140399920471
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6669235229492188 - deformation = mean
# statistic = 0.5344171488556286 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.7318960456801324
# relative_error_metric = 1.9706886957647662
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3574180603027344 - deformation = mean
# statistic = 0.15127091606602314 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.5271751917556822
# relative_error_metric = 1.8983345563322327
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.2026653289794922 - deformation = mean
# statistic = 0.04737877080428456 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.2351665080875356
# relative_error_metric = 1.6925383752935146
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.1252889633178711 - deformation = mean
# statistic = 0.01733536058599654 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.8934834677752388
# relative_error_metric = 1.258467481368437
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.08660078048706055 - deformation = mean
# statistic = 0.007849706101381058 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.5752317481699427
# relative_error_metric = 0.6621061416417395
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.06725668907165527 - deformation = mean
# statistic = 0.004448333978182323 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.33592448064920144
# relative_error_metric = 0.119930448767628
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.05758464336395264 - deformation = mean
# statistic = 0.0031177363374832274 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.15494941489336306
# relative_error_metric = 0.23426760715827652
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.062420666217803955 - deformation = mean
# statistic = 0.003766523889785331 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.07458546394714162
# relative_error_metric = 0.0462943280305565
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.06483867764472961 - deformation = mean
# statistic = 0.0041170182921170684 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.03800131846566193
# relative_error_metric = 0.042667581285731976
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.06362967193126678 - deformation = mean
# statistic = 0.0039424956733595685 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.018821845496623794
# relative_error_metric = 0.0006411872451145204
# =======> statistic within required accuracy at 0.99 CL in 96.46071957401 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 193.9001469570212 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_diag
# statistic = 72.80866784174371 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998851215931353
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_diag
# statistic = 18.22475788987635 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995410954468402
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_diag
# statistic = 4.5671255350105895 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9981694052471473
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_diag
# statistic = 1.1476464550034529 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9927249623341514
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_diag
# statistic = 0.29009220093240823 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.97137281946893
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_diag
# statistic = 0.0741769743395793 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8903291514729454
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_diag
# statistic = 0.01934812758064374 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6098560211872723
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_diag
# statistic = 0.005142818465402367 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8437264454192721
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_diag
# statistic = 0.001466208925760624 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.3513261219322437
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0146484375 - deformation = cov_diag
# statistic = 0.0029763901373229457 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.349401701930262
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01220703125 - deformation = cov_diag
# statistic = 0.0021122261695080934 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.010054034083755206
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.010986328125 - deformation = cov_diag
# statistic = 0.0017721136636197267 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.16513850487919282
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0115966796875 - deformation = cov_diag
# statistic = 0.0019356532435625881 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.07720508255204499
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.01190185546875 - deformation = cov_diag
# statistic = 0.0020197143232072567 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.02531645569620253
# relative_error_metric = 0.03472876078895474
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.012054443359375 - deformation = cov_diag
# statistic = 0.0020623920223296287 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.012578616352201259
# relative_error_metric = 0.013821624079448628
# =======> statistic within required accuracy at 0.95 CL in 111.41219214897137 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0121307373046875 - deformation = cov_diag
# statistic = 0.002083892722245419 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9903188979374382
# relative_error_metric = 0.6174016373868153
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5060653686523438 - deformation = cov_diag
# statistic = 73.16161175658854 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9807310681229455
# relative_error_metric = 1.9997843234147021
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2590980529785156 - deformation = cov_diag
# statistic = 18.48993405090225 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9618298849195037
# relative_error_metric = 1.9991467394491067
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6356143951416016 - deformation = cov_diag
# statistic = 4.723454667138126 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9250894421460225
# relative_error_metric = 1.9966619921145454
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.32387256622314453 - deformation = cov_diag
# statistic = 1.2322074230855038 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.8555878805080537
# relative_error_metric = 1.9872345053553007
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16800165176391602 - deformation = cov_diag
# statistic = 0.334610055007312 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.7306261829444232
# relative_error_metric = 1.9533898664958147
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.09006619453430176 - deformation = cov_diag
# statistic = 0.09795151205804702 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.5252015070746188
# relative_error_metric = 1.8451360762364326
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.05109846591949463 - deformation = cov_diag
# statistic = 0.03246455889273506 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.2325864198112764
# relative_error_metric = 1.5665949445911622
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.031614601612091064 - deformation = cov_diag
# statistic = 0.012880016404569757 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.8907858432401131
# relative_error_metric = 1.0621064360631518
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.021872669458389282 - deformation = cov_diag
# statistic = 0.0063666760477602835 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.5729974188515862
# relative_error_metric = 0.46969007817410463
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.01700170338153839 - deformation = cov_diag
# statistic = 0.003930741193953078 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.2506003683664806
# relative_error_metric = 0.0036271186403845565
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.019437186419963837 - deformation = cov_diag
# statistic = 0.005087862027215486 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.13367493091543312
# relative_error_metric = 0.25303930903009936
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.018219444900751114 - deformation = cov_diag
# statistic = 0.004497735605057151 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.06914831449859618
# relative_error_metric = 0.1309314122951146
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.017610574141144753 - deformation = cov_diag
# statistic = 0.004214347344481068 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.035182357428362704
# relative_error_metric = 0.06601561791506283
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.017306138761341572 - deformation = cov_diag
# statistic = 0.004076359530556219 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.017747276470220168
# relative_error_metric = 0.03274626182589805
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.01715392107143998 - deformation = cov_diag
# statistic = 0.004012166303217061 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.008913184422152583
# relative_error_metric = 0.016875790479679603
# =======> statistic within required accuracy at 0.99 CL in 120.97171387600247 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 232.38394037401304 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_off_diag
# statistic = 9.559007006450857 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9991251649235529
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_off_diag
# statistic = 4.834616476028538 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9982706450896996
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_off_diag
# statistic = 3.967450701871192 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9978928590715777
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_off_diag
# statistic = 1.936432872446069 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9956851789683634
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_off_diag
# statistic = 0.7909188078456737 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9894523587299018
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_off_diag
# statistic = 0.2886971340089454 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9712354795474687
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_off_diag
# statistic = 0.09524985007313273 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.914071268802797
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_off_diag
# statistic = 0.02850921671249257 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7266569113627754
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_off_diag
# statistic = 0.007745803853869054 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1496930825883267
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = cov_off_diag
# statistic = 0.0018490260904447347 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1228743178534464
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00732421875 - deformation = cov_off_diag
# statistic = 0.004365668386658948 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.7045548680549435
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.006103515625 - deformation = cov_off_diag
# statistic = 0.0029932995179061655 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.3548911637017484
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0054931640625 - deformation = cov_off_diag
# statistic = 0.002391610857312893 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.1340774089021447
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00518798828125 - deformation = cov_off_diag
# statistic = 0.0021108085206433024 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.00938266122711338
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.005035400390625 - deformation = cov_off_diag
# statistic = 0.001979109824430235 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.029850746268656716
# relative_error_metric = 0.05502727764455566
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0051116943359375 - deformation = cov_off_diag
# statistic = 0.002050001114447053 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.014814814814814815
# relative_error_metric = 0.01984734083090198
# =======> statistic within required accuracy at 0.95 CL in 119.0826612439705 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00514984130859375 - deformation = cov_off_diag
# statistic = 0.0020765352237202203 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9958843659255985
# relative_error_metric = 0.6205997338953437
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.502574920654297 - deformation = cov_off_diag
# statistic = 9.567478628848287 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9917856355103936
# relative_error_metric = 1.9983513322552984
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2538623809814453 - deformation = cov_off_diag
# statistic = 4.843219217960103 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9836384708030026
# relative_error_metric = 1.9967444681758166
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6295061111450195 - deformation = cov_off_diag
# statistic = 3.9905506872743217 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9675424690263492
# relative_error_metric = 1.9960495395196058
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31732797622680664 - deformation = cov_off_diag
# statistic = 1.972104497398051 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9361216055361274
# relative_error_metric = 1.992014320858787
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.1612389087677002 - deformation = cov_off_diag
# statistic = 0.8258763423930932 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.876197367761164
# relative_error_metric = 1.9809837417062068
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08319437503814697 - deformation = cov_off_diag
# statistic = 0.31764719908415334 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.7668283665166613
# relative_error_metric = 1.9509313462905737
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04417210817337036 - deformation = cov_off_diag
# statistic = 0.11678491431567214 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.582348924753923
# relative_error_metric = 1.8692942477999979
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.024660974740982056 - deformation = cov_off_diag
# statistic = 0.04323724260410778 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.308996935873276
# relative_error_metric = 1.6655502487986753
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.014905408024787903 - deformation = cov_off_diag
# statistic = 0.017361873804114657 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.9728691530108442
# relative_error_metric = 1.259390206640548
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.010027624666690826 - deformation = cov_off_diag
# statistic = 0.008184682569772308 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.6427665021341771
# relative_error_metric = 0.6990536921701037
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.007588732987642288 - deformation = cov_off_diag
# statistic = 0.004693961943174635 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.3829143862306751
# relative_error_metric = 0.17338552342582464
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.006369287148118019 - deformation = cov_off_diag
# statistic = 0.0032722050610303538 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.1747304886600731
# relative_error_metric = 0.18644808458081014
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.006979010067880154 - deformation = cov_off_diag
# statistic = 0.003953744981716833 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.09135591003043755
# relative_error_metric = 0.0022080958075070857
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.006674148607999086 - deformation = cov_off_diag
# statistic = 0.0036020321977359277 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.04465801169068076
# relative_error_metric = 0.09089428746977414
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.00682657933793962 - deformation = cov_off_diag
# statistic = 0.0037781717133734878 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.02208246608815936
# relative_error_metric = 0.043208186605453155
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.006902794702909887 - deformation = cov_off_diag
# statistic = 0.003864075231278736 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.010980613288934658
# relative_error_metric = 0.020732001105947726
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.00694090238539502 - deformation = cov_off_diag
# statistic = 0.003909529954370028 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.005475276171893907
# relative_error_metric = 0.009037917666894319
# =======> statistic within required accuracy at 0.99 CL in 133.7936247199541 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 252.876318722032 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_up
# statistic = 2474337.8949231156 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999999996619547
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_up
# statistic = 6298.023679493835 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999986719038165
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_up
# statistic = 256.29564237138044 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999673645807312
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_up
# statistic = 29.674155829168022 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999718145491562
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_up
# statistic = 5.219201181833636 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9983980241778678
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_up
# statistic = 1.1028437087279175 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9924299750957244
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_up
# statistic = 0.2537067250634599 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.967300800473265
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_up
# statistic = 0.06079898625394127 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8669999515034734
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.0148522848909385 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5063332374734937
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.003580203141908403 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.525137929776765
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_up
# statistic = 0.0007820896954749556 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.9111880969893799
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_up
# statistic = 0.0019160090519058765 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.08738824826655464
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0042724609375 - deformation = power_abs_up
# statistic = 0.002693756024074979 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.25190330820453305
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00396728515625 - deformation = power_abs_up
# statistic = 0.0022832264192856875 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.08784465507731774
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.003814697265625 - deformation = power_abs_up
# statistic = 0.002094058601722325 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.0014157681917675606
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0037384033203125 - deformation = power_abs_up
# statistic = 0.0020044321597111406 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.04232120220315174
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00377655029296875 - deformation = power_abs_up
# statistic = 0.0020515874651963594 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.010050251256281407
# relative_error_metric = 0.01907388411580755
# =======> statistic within required accuracy at 0.95 CL in 127.38870904303622 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.003795623779296875 - deformation = power_abs_up
# statistic = 0.0020706528494775804 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9969658043096252
# relative_error_metric = 0.6231622630725364
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5018978118896484 - deformation = power_abs_up
# statistic = 2497241.9612873667 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.993940801016971
# relative_error_metric = 1.99999999368099
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2528467178344727 - deformation = power_abs_up
# statistic = 6384.046529718232 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9879182050338282
# relative_error_metric = 1.9999975281997673
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6283211708068848 - deformation = power_abs_up
# statistic = 261.28350406169653 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9759815033436554
# relative_error_metric = 1.99993960637029
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3160583972930908 - deformation = power_abs_up
# statistic = 30.604987552363713 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9525330490881918
# relative_error_metric = 1.9994844610340998
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.15992701053619385 - deformation = power_abs_up
# statistic = 5.512354141549869 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9072669751457145
# relative_error_metric = 1.9971393688099013
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08186131715774536 - deformation = power_abs_up
# statistic = 1.2204106124967375 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.8227523076227223
# relative_error_metric = 1.9871115083127242
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04282847046852112 - deformation = power_abs_up
# statistic = 0.3074877560579995 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.6743637520015084
# relative_error_metric = 1.949330647125063
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.023312047123908997 - deformation = power_abs_up
# statistic = 0.08731535369981004 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.4399188638743599
# relative_error_metric = 1.8270870909910286
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.013553835451602936 - deformation = power_abs_up
# statistic = 0.02889292615067342 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.124900960016834
# relative_error_metric = 1.5194554714417425
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.008674729615449905 - deformation = power_abs_up
# statistic = 0.011657544436908474 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.7825128417304335
# relative_error_metric = 0.9886218319994693
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.00623517669737339 - deformation = power_abs_up
# statistic = 0.005943457022861489 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.4864124102060352
# relative_error_metric = 0.4041940482274959
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.005015400238335133 - deformation = power_abs_up
# statistic = 0.003770134870181922 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.21683802813112185
# relative_error_metric = 0.045336586462064926
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.005625288467854261 - deformation = power_abs_up
# statistic = 0.004812729041731839 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.11463322466418432
# relative_error_metric = 0.1981569107399887
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.005320344353094697 - deformation = power_abs_up
# statistic = 0.0042672764590042005 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.059007672270156
# relative_error_metric = 0.078480344071191
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.005167872295714915 - deformation = power_abs_up
# statistic = 0.004041029714099546 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.029945591040592856
# relative_error_metric = 0.02404325119871378
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.005091636267025024 - deformation = power_abs_up
# statistic = 0.00390949362460639 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.014861536149355531
# relative_error_metric = 0.009047210136885774
# =======> statistic within required accuracy at 0.99 CL in 127.62562554201577 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 255.01436733896844 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_down
# statistic = 5319687.994449863 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999999984276553
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_down
# statistic = 31.160626876099276 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997315900366308
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_down
# statistic = 19.46462390568391 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999570323807142
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_down
# statistic = 8.242932216952934 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.998985523306376
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_down
# statistic = 2.748897917479856 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9969594993115587
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_down
# statistic = 0.7979192717100486 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9895446555107263
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_down
# statistic = 0.21504297042602855 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9614782510770912
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_down
# statistic = 0.056015823972302384 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8560518438468112
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.014223226654691496 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4872981141924193
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.0035164229525009956 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5083627778726846
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_down
# statistic = 0.0009493464927157922 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7510416713095107
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_down
# statistic = 0.001986096409199073 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.05150582934241002
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0042724609375 - deformation = power_abs_down
# statistic = 0.0026777063955013723 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.2460200066325981
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00396728515625 - deformation = power_abs_down
# statistic = 0.002302035526649315 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.09603151107790968
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.003814697265625 - deformation = power_abs_down
# statistic = 0.0021009947905048106 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.00472260438188702
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0037384033203125 - deformation = power_abs_down
# statistic = 0.002070386722306445 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.009952834809864149
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00377655029296875 - deformation = power_abs_down
# statistic = 0.002110473360071867 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.01015228426395939
# relative_error_metric = 0.009223869026386142
# =======> statistic within required accuracy at 0.95 CL in 126.8741171300062 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.003757476806640625 - deformation = power_abs_down
# statistic = 0.002091704678359523 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9969962758394608
# relative_error_metric = 0.6140145337769608
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5018787384033203 - deformation = power_abs_down
# statistic = 5504395.526606183 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.994001560507736
# relative_error_metric = 1.9999999971331823
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2528181076049805 - deformation = power_abs_down
# statistic = 31.174849194787168 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.988038994698755
# relative_error_metric = 1.9994938836525555
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6282877922058105 - deformation = power_abs_down
# statistic = 19.567487174604057 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9762202045273654
# relative_error_metric = 1.9991937177980899
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3160226345062256 - deformation = power_abs_down
# statistic = 8.376981165751596 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9529992432460643
# relative_error_metric = 1.998117141579586
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.1598900556564331 - deformation = power_abs_down
# statistic = 2.858664042495739 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.9081568356067091
# relative_error_metric = 1.9944875122381818
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08182376623153687 - deformation = power_abs_down
# statistic = 0.8689885538349384 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.8243784888721737
# relative_error_metric = 1.9819229116142865
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.042790621519088745 - deformation = power_abs_down
# statistic = 0.2561481145067197 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.6771101770605579
# relative_error_metric = 1.9393290514445718
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.023274049162864685 - deformation = power_abs_down
# statistic = 0.07895085100437903 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.4439859871944345
# relative_error_metric = 1.8096395341965767
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.013515762984752655 - deformation = power_abs_down
# statistic = 0.02712087062317254 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 1.1298732948724861
# relative_error_metric = 1.492044331719261
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.00863661989569664 - deformation = power_abs_down
# statistic = 0.011094230469827805 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.787333390441582
# relative_error_metric = 0.9507394066794213
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0061970483511686325 - deformation = power_abs_down
# statistic = 0.00561464615102341 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.4901432274977336
# relative_error_metric = 0.34930530017148986
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.004977262578904629 - deformation = power_abs_down
# statistic = 0.0036280650885593554 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.21831964044981278
# relative_error_metric = 0.08370672906781342
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.005587155465036631 - deformation = power_abs_down
# statistic = 0.00456502913483387 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.11546170997687434
# relative_error_metric = 0.14571113403347122
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.00528220902197063 - deformation = power_abs_down
# statistic = 0.004112064154290799 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.05944681264871093
# relative_error_metric = 0.04146405788462346
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.005129735800437629 - deformation = power_abs_down
# statistic = 0.0038679109559568076 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.029288134759387588
# relative_error_metric = 0.019739932019363075
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0052059724112041295 - deformation = power_abs_down
# statistic = 0.003984430592627899 - next threshold = 0.003945024361980691 at 0.99 CL
# relative_error_eps = 0.014752082625674387
# relative_error_metric = 0.009939202851339668
# =======> statistic within required accuracy at 0.99 CL in 127.47314631898189 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 254.34729660203448 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# Computing exclusion limits for fgd with random_normal deformation.
#
# ======================================================
# =============== fgd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 13.0279799784618 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9993580707318037
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 1.8711528340584167 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9955348132428636
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 0.2004452374144723 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9587018099495062
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 0.0155938915775489 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5270347828094228
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 0.000921164762481055 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7767795208607221
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.234375 - deformation = random_normal
# statistic = 0.0050695115299219315 - next threshold = 0.002091095997342832 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.831889060038124
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.1953125 - deformation = random_normal
# ...
# relative_error_metric = 1.06506426402746
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.013915523886680603 - deformation = power_abs_down
# statistic = 3.8916463914341617 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 1.0797554611075155
# relative_error_metric = 0.6745536097946223
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.009036771953105927 - deformation = power_abs_down
# statistic = 2.693882051425769 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.7394966049774842
# relative_error_metric = 0.33110841128883367
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.006597395986318588 - deformation = power_abs_down
# statistic = 2.1169669174879777 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.45360885445259747
# relative_error_metric = 0.09311787800147364
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.005377708002924919 - deformation = power_abs_down
# statistic = 1.842454287989227 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.20370394854011106
# relative_error_metric = 0.045692627046545975
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.005987551994621754 - deformation = power_abs_down
# statistic = 1.977990164045501 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.1073172090789787
# relative_error_metric = 0.025280799576790004
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.005682629998773336 - deformation = power_abs_down
# statistic = 1.9097472683310763 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.05225659651597419
# relative_error_metric = 0.009828122183763782
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.005835090996697545 - deformation = power_abs_down
# statistic = 1.9437634545750913 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.026474160640661628
# relative_error_metric = 0.007826864580294265
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.005758860497735441 - deformation = power_abs_down
# statistic = 1.9267265968189213 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.013150046211372812
# relative_error_metric = 0.0009766151272758226
# =======> statistic within required accuracy at 0.99 CL in 119.0003608270199 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 234.63544778898358 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 72.85009458430923 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9149327329367072
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 23.176862502585298 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7442704787159813
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 6.644109833205116 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2303674619845548
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 2.0989712341567746 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.2802975046250085
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 1.204737204738358 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2713477013038525
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.234375 - deformation = random_normal
# statistic = 1.515121734869481 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.04378993704227905
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.2734375 - deformation = random_normal
# statistic = 1.781315561654271 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.11792251007170115
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.25390625 - deformation = random_normal
# statistic = 1.655462565257281 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.04478025478430317
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.244140625 - deformation = random_normal
# statistic = 1.5863511635487157 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.002143787159826655
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.2392578125 - deformation = random_normal
# statistic = 1.5507513481267887 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.020552447612260785
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.24169921875 - deformation = random_normal
# statistic = 1.5932371928668287 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.01015228426395939
# relative_error_metric = 0.00647516886671637
# =======> statistic within required accuracy at 0.95 CL in 77.99974368896801 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.240478515625 - deformation = random_normal
# statistic = 1.5644451143702427 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 1.816445376193804
# relative_error_metric = 0.20850753564712884
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.6202392578125 - deformation = random_normal
# statistic = 78.29439607792035 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 1.6637508000853425
# relative_error_metric = 1.9038375996966552
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.43035888671875 - deformation = random_normal
# statistic = 29.299276238059907 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 1.4242922374429223
# relative_error_metric = 1.7529632044917114
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.835418701171875 - deformation = random_normal
# statistic = 11.332147848605848 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 1.1059424195149625
# relative_error_metric = 1.4182506530072305
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.5379486083984375 - deformation = random_normal
# statistic = 5.106911237802745 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.7642850142115064
# relative_error_metric = 0.9035016202661558
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.38921356201171875 - deformation = random_normal
# statistic = 2.9090189963087214 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.4724056460895378
# relative_error_metric = 0.40532664885747727
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.3148460388183594 - deformation = random_normal
# statistic = 2.13510384461238 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.26783444959642794
# relative_error_metric = 0.10162856313529502
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.2776622772216797 - deformation = random_normal
# statistic = 1.8268252212892355 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.1255130454377183
# relative_error_metric = 0.05420622708439203
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.29625415802001953 - deformation = random_normal
# statistic = 1.9764409991726768 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.06478950473167773
# relative_error_metric = 0.024497412559061932
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.2869582176208496 - deformation = random_normal
# statistic = 1.9048487794822977 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.03187840583442688
# relative_error_metric = 0.012396331026013195
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.29160618782043457 - deformation = random_normal
# statistic = 1.9286532974488773 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.01606725251630317
# relative_error_metric = 2.2871664456241e-05
# =======> statistic within required accuracy at 0.99 CL in 76.69296191300964 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 154.69273767300183 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_uniform
# statistic = 30.39895405379723 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8020188160455046
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_uniform
# statistic = 8.792429395998667 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.389727031994538
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_uniform
# statistic = 2.6098388707583906 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4898333379846938
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_uniform
# statistic = 1.2723617326385501 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.21755371490288059
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_uniform
# statistic = 1.777332821336189 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.11569179993094302
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.390625 - deformation = random_uniform
# statistic = 1.4906583027929152 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.060056828011479234
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.4296875 - deformation = random_uniform
# statistic = 1.6234442811412881 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.02525592383367777
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.41015625 - deformation = random_uniform
# statistic = 1.5594390294302405 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.014966285879592348
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.419921875 - deformation = random_uniform
# statistic = 1.5888715367054385 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.023529411764705882
# relative_error_metric = 0.0037313092673758454
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.4150390625 - deformation = random_uniform
# statistic = 1.5757411754687223 - next threshold = 1.582954005685028 at 0.95 CL
# relative_error_eps = 0.011695906432748537
# relative_error_metric = 0.004566968195817571
# =======> statistic within required accuracy at 0.95 CL in 68.76308901398443 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.41748046875 - deformation = random_uniform
# statistic = 1.5747702423568104 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 1.6917530419107707
# relative_error_metric = 0.20199864232618114
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.708740234375 - deformation = random_uniform
# statistic = 34.83616854391834 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 1.4658336587270597
# relative_error_metric = 1.7901677305831125
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.5631103515625 - deformation = random_uniform
# statistic = 13.10235312400726 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 1.1568567026194145
# relative_error_metric = 1.4867636158993003
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.99029541015625 - deformation = random_uniform
# statistic = 5.687556651411931 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.8137871233470626
# relative_error_metric = 0.9870970630095273
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.703887939453125 - deformation = random_uniform
# statistic = 3.1546155513981367 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.5108177983399101
# relative_error_metric = 0.4823734649500288
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.5606842041015625 - deformation = random_uniform
# statistic = 2.209112391066281 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.29280087356680445
# relative_error_metric = 0.1355834119669937
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.48908233642578125 - deformation = random_uniform
# statistic = 1.8611348948558148 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.13641484065554707
# relative_error_metric = 0.035608890805801034
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.5248832702636719 - deformation = random_uniform
# statistic = 2.0380752448035335 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.07061567690600253
# relative_error_metric = 0.055192723423629006
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.5069828033447266 - deformation = random_uniform
# statistic = 1.9376987562897 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.03594236200871272
# relative_error_metric = 0.004701937860141326
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.4980325698852539 - deformation = random_uniform
# statistic = 1.9099469117569212 - next threshold = 1.9286091864422517 at 0.99 CL
# relative_error_eps = 0.017811137417147845
# relative_error_metric = 0.00972359095863452
# =======> statistic within required accuracy at 0.99 CL in 69.1451671460527 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 137.90828796901042 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T23:35:34.305518', 'fgd_cov_diag_2024-05-02T23:38:48.208109', 'fgd_cov_off_diag_2024-05-02T23:42:40.594316', 'fgd_power_abs_up_2024-05-02T23:46:53.473320', 'fgd_power_abs_down_2024-05-02T23:51:08.490997', 'fgd_random_normal_2024-05-02T23:55:22.841224', 'fgd_random_uniform_2024-05-02T23:58:30.541193', 'mmd_mean_2024-05-03T00:01:19.029209', 'mmd_cov_diag_2024-05-03T00:10:42.320703', 'mmd_cov_off_diag_2024-05-03T00:21:42.477808', 'mmd_power_abs_up_2024-05-03T00:32:03.188655', 'mmd_power_abs_down_2024-05-03T00:44:59.212836', 'mmd_random_normal_2024-05-03T00:58:00.147107', 'mmd_random_uniform_2024-05-03T01:06:41.284286', 'ks_mean_2024-05-03T01:15:40.563686', 'ks_cov_diag_2024-05-03T01:18:44.360148', 'ks_cov_off_diag_2024-05-03T01:22:07.508900', 'ks_power_abs_up_2024-05-03T01:24:54.357509', 'ks_power_abs_down_2024-05-03T01:28:43.944956', 'ks_random_normal_2024-05-03T01:32:22.746910', 'ks_random_uniform_2024-05-03T01:35:07.018751', 'sks_mean_2024-05-03T01:37:36.346149', 'sks_cov_diag_2024-05-03T01:41:55.408347', 'sks_cov_off_diag_2024-05-03T01:47:00.177719', 'sks_power_abs_up_2024-05-03T01:52:10.140072', 'sks_power_abs_down_2024-05-03T01:57:32.646166', 'sks_random_normal_2024-05-03T02:02:57.766960', 'sks_random_uniform_2024-05-03T02:06:45.964579', 'swd_mean_2024-05-03T02:10:13.144546', 'swd_cov_diag_2024-05-03T02:13:07.074036', 'swd_cov_off_diag_2024-05-03T02:16:46.637347', 'swd_power_abs_up_2024-05-03T02:20:15.421273', 'swd_power_abs_down_2024-05-03T02:23:54.924429', 'swd_random_normal_2024-05-03T02:27:49.568987', 'swd_random_uniform_2024-05-03T02:30:24.270799'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.1,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.05 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.46510520001175 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.050000.json
# ThresholdS: [[0.95, [9500, 500], -11.191944760387118], [0.99, [9900, 100], -5.819767191720709]]
# Null distribution computed in 38.63461448199814 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.179466589994263 seconds.
# statistic = 27.47581684479738 - next threshold = -11.191944760387118 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 4.749209697146167
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.025 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.355254582013 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.025000.json
# ThresholdS: [[0.95, [9500, 500], 0.6837628887503893], [0.99, [9900, 100], 3.36985167324823]]
# Null distribution computed in 38.52321266999934 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.168066062033176 seconds.
# statistic = 7.458173153355961 - next threshold = 0.6837628887503893 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.664078477052985
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.0125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.45641616702778 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.012500.json
# ThresholdS: [[0.95, [9500, 500], 1.9118152616523407], [0.99, [9900, 100], 3.254859653983579]]
# Null distribution computed in 38.62905772199156 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.181703064998146 seconds.
# statistic = 2.1591527594749205 - next threshold = 1.9118152616523407 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.12151286698346078
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.00625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.49555687204702 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.006250.json
# ThresholdS: [[0.95, [9500, 500], 1.3483910850631389], [0.99, [9900, 100], 2.019913281228758]]
# Null distribution computed in 38.66530470800353 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.172216690029018 seconds.
# statistic = 0.6870929254099419 - next threshold = 1.3483910850631389 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.6497699380104687
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.009375000000000001 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.31166256801225 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.009375.json
# ThresholdS: [[0.95, [9500, 500], 1.7282240368552433], [0.99, [9900, 100], 2.73550733118599]]
# Null distribution computed in 38.48571475298377 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.228801438992377 seconds.
# statistic = 1.325001978804987 - next threshold = 1.7282240368552433 at 0.95 CL
# relative_error_eps = 0.28571428571428564
# relative_error_metric = 0.26412853551102966
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.010937500000000001 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.557245614996646 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.010938.json
# ThresholdS: [[0.95, [9500, 500], 1.844549865251645], [0.99, [9900, 100], 3.0197137083356833]]
# Null distribution computed in 38.733117691008374 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.200210710987449 seconds.
# statistic = 1.7175471532326505 - next threshold = 1.844549865251645 at 0.95 CL
# relative_error_eps = 0.1333333333333333
# relative_error_metric = 0.07130783432340947
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.01171875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.47781370795565 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.011719.json
# ThresholdS: [[0.95, [9500, 500], 1.8843151173485586], [0.99, [9900, 100], 3.143419235056197]]
# Null distribution computed in 38.64615193801001 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.189222451008391 seconds.
# statistic = 1.93221740236667 - next threshold = 1.8843151173485586 at 0.95 CL
# relative_error_eps = 0.06896551724137921
# relative_error_metric = 0.025102516365659414
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.011328125000000001 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.442574892018456 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.011328.json
# ThresholdS: [[0.95, [9500, 500], 1.8659656297536635], [0.99, [9900, 100], 3.083099610314138]]
# Null distribution computed in 38.61133170098765 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.235993809008505 seconds.
# statistic = 1.8233491392720123 - next threshold = 1.8659656297536635 at 0.95 CL
# relative_error_eps = 0.03389830508474564
# relative_error_metric = 0.023102658975832534
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.0115234375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.32998314697761 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.011523.json
# ThresholdS: [[0.95, [9500, 500], 1.875523658143922], [0.99, [9900, 100], 3.1136427073602966]]
# Null distribution computed in 38.498917418008205 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.2247960370150395 seconds.
# statistic = 1.8773999862182984 - next threshold = 1.875523658143922 at 0.95 CL
# relative_error_eps = 0.017094017094017033
# relative_error_metric = 0.0009999287234074212
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.011425781250000001 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.58411511499435 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.011426.json
# ThresholdS: [[0.95, [9500, 500], 1.8708404651381547], [0.99, [9900, 100], 3.098466979861943]]
# Null distribution computed in 38.756161132012494 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.2587535660131834 seconds.
# statistic = 1.8502787415887205 - next threshold = 1.8708404651381547 at 0.95 CL
# relative_error_eps = 0.00851063829787231
# relative_error_metric = 0.011051365144262843
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.011474609375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.42062924901256 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.011475.json
# ThresholdS: [[0.95, [9500, 500], 1.8732060169383786], [0.99, [9900, 100], 3.106078798826142]]
# Null distribution computed in 38.59400501899654 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.202426896023098 seconds.
# statistic = 1.8638154086390963 - next threshold = 1.8732060169383786 at 0.95 CL
# relative_error_eps = 0.004246284501061632
# relative_error_metric = 0.005025718201672432
# =======> statistic within required accuracy at 0.95 CL in 556.435997491004 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0114990234375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.48461375804618 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.011499.json
# ThresholdS: [[0.95, [9500, 500], 1.874370826427224], [0.99, [9900, 100], 3.109866741896975]]
# Null distribution computed in 38.65420790598728 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.253241411992349 seconds.
# statistic = 1.8706017085590876 - next threshold = 3.109866741896975 at 0.99 CL
# relative_error_eps = 1.58747536676155
# relative_error_metric = 0.4976499884160125
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.05574951171875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.38629257003777 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.055750.json
# ThresholdS: [[0.95, [9500, 500], -15.699483611996778], [0.99, [9900, 100], -9.709558085430857]]
# Null distribution computed in 38.55476212996291 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.298632582009304 seconds.
# statistic = 33.85584196364501 - next threshold = -9.709558085430857 at 0.99 CL
# relative_error_eps = 1.3160283172989653
# relative_error_metric = 3.6084558823879727
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.033624267578125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.44208449695725 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.033624.json
# ThresholdS: [[0.95, [9500, 500], -1.9940021898408506], [0.99, [9900, 100], 1.618708531176985]]
# Null distribution computed in 38.61252347001573 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.267903775034938 seconds.
# statistic = 12.944667633166354 - next threshold = 1.618708531176985 at 0.99 CL
# relative_error_eps = 0.9806573786013797
# relative_error_metric = 1.555402946978683
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.0225616455078125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.43531478900695 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.022562.json
# ThresholdS: [[0.95, [9500, 500], 1.1698228689880092], [0.99, [9900, 100], 3.593926187396439]]
# Null distribution computed in 38.60248284798581 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.239748950989451 seconds.
# statistic = 6.177996120217289 - next threshold = 3.593926187396439 at 0.99 CL
# relative_error_eps = 0.6495833706657109
# relative_error_metric = 0.5288764792588433
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.01703033447265625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.392268755007535 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.017030.json
# ThresholdS: [[0.95, [9500, 500], 1.829506485443061], [0.99, [9900, 100], 3.659306102217515]]
# Null distribution computed in 38.56301852798788 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.253698223037645 seconds.
# statistic = 3.7168892767185984 - next threshold = 3.659306102217515 at 0.99 CL
# relative_error_eps = 0.3877627426859923
# relative_error_metric = 0.015613245458633414
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.014264678955078124 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.407313093019184 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.014265.json
# ThresholdS: [[0.95, [9500, 500], 1.9287910654101625], [0.99, [9900, 100], 3.461438831532265]]
# Null distribution computed in 38.57755400601309 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.264211250003427 seconds.
# statistic = 2.7168930832461413 - next threshold = 3.461438831532265 at 0.99 CL
# relative_error_eps = 0.1767473609790585
# relative_error_metric = 0.24101837148152888
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.015647506713867186 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 44.280224003014155 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.015648.json
# ThresholdS: [[0.95, [9500, 500], 1.8983618777953666], [0.99, [9900, 100], 3.5795855694082808]]
# Null distribution computed in 44.457173931004945 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 7.032461772032548 seconds.
# statistic = 3.19767807758892 - next threshold = 3.5795855694082808 at 0.99 CL
# relative_error_eps = 0.08463397266030842
# relative_error_metric = 0.1127025630730988
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.016338920593261717 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.86896746995626 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.016339.json
# ThresholdS: [[0.95, [9500, 500], 1.8687374572525615], [0.99, [9900, 100], 3.6242491112816095]]
# Null distribution computed in 39.050071559031494 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.767360027006362 seconds.
# statistic = 3.4524804015121795 - next threshold = 3.6242491112816095 at 0.99 CL
# relative_error_eps = 0.04144017467748113
# relative_error_metric = 0.04854465878875121
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.016684627532958983 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.4289681649534 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.016685.json
# ThresholdS: [[0.95, [9500, 500], 1.850322790214989], [0.99, [9900, 100], 3.64297842561674]]
# Null distribution computed in 38.60079361696262 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.627004345005844 seconds.
# statistic = 3.5834840202152836 - next threshold = 3.64297842561674 at 0.99 CL
# relative_error_eps = 0.020507627423082257
# relative_error_metric = 0.01646570665727895
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.016857481002807616 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.500223515031394 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.016857.json
# ThresholdS: [[0.95, [9500, 500], 1.8402148425869784], [0.99, [9900, 100], 3.651442468675081]]
# Null distribution computed in 38.67365117400186 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.595703652012162 seconds.
# statistic = 3.6498864437254515 - next threshold = 3.651442468675081 at 0.99 CL
# relative_error_eps = 0.010201511512229854
# relative_error_metric = 0.00042623061316594607
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.016943907737731932 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.52142430603271 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_mean_0.016944.json
# ThresholdS: [[0.95, [9500, 500], 1.834935715039872], [0.99, [9900, 100], 3.6554493366357863]]
# Null distribution computed in 38.69412411097437 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.528928334999364 seconds.
# statistic = 3.683312809049 - next threshold = 3.6554493366357863 at 0.99 CL
# relative_error_eps = 0.005113797873083296
# relative_error_metric = 0.0075935074226646405
# =======> statistic within required accuracy at 0.99 CL in 568.4767659109784 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1124.9127985230298 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# Computing exclusion limits for lr with cov_diag deformation.
#
# ======================================================
# =============== lr - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.05 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# ...
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_power_abs_down_0.001081.json
# ThresholdS: [[0.95, [9500, 500], 1.9370825870942052], [0.99, [9900, 100], 3.614207324656866]]
# Null distribution computed in 38.97089923301246 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.41742928896565 seconds.
# statistic = 3.4128945339593266 - next threshold = 3.614207324656866 at 0.99 CL
# relative_error_eps = 0.3043390835503888
# relative_error_metric = 0.05729610719978451
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.0012746274471282962 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.83536991401343 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_power_abs_down_0.001275.json
# ThresholdS: [[0.95, [9500, 500], 1.8484531502527812], [0.99, [9900, 100], 3.8308084309145656]]
# Null distribution computed in 38.99993780400837 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.451872165023815 seconds.
# statistic = 4.459144320492144 - next threshold = 3.8308084309145656 at 0.99 CL
# relative_error_eps = 0.16470076147719986
# relative_error_metric = 0.15158973963294478
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0011776477098464969 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.9176278829691 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_power_abs_down_0.001178.json
# ThresholdS: [[0.95, [9500, 500], 1.9094348190083381], [0.99, [9900, 100], 3.739012869470898]]
# Null distribution computed in 39.081867984030396 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.381421058031265 seconds.
# statistic = 3.919550957908594 - next threshold = 3.739012869470898 at 0.99 CL
# relative_error_eps = 0.08588678548098677
# relative_error_metric = 0.047146721632656256
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0011291578412055974 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.708847077039536 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_power_abs_down_0.001129.json
# ThresholdS: [[0.95, [9500, 500], 1.927431750191073], [0.99, [9900, 100], 3.68069583116241]]
# Null distribution computed in 38.873233932012226 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.393832711037248 seconds.
# statistic = 3.6619489718186435 - next threshold = 3.68069583116241 at 0.99 CL
# relative_error_eps = 0.04204070743525317
# relative_error_metric = 0.005106296122660175
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.001153402775526047 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.771788018988445 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_power_abs_down_0.001153.json
# ThresholdS: [[0.95, [9500, 500], 1.9194759762291687], [0.99, [9900, 100], 3.7108869106504523]]
# Null distribution computed in 38.93289496196667 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.496654832968488 seconds.
# statistic = 3.7897193003395184 - next threshold = 3.7108869106504523 at 0.99 CL
# relative_error_eps = 0.021243628005082747
# relative_error_metric = 0.021020271554467174
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0011412803083658222 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.869024550018366 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_power_abs_down_0.001141.json
# ThresholdS: [[0.95, [9500, 500], 1.9237047266031317], [0.99, [9900, 100], 3.6960865653754498]]
# Null distribution computed in 39.03152876900276 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.496791957993992 seconds.
# statistic = 3.725733422496715 - next threshold = 3.6960865653754498 at 0.99 CL
# relative_error_eps = 0.010678526664567482
# relative_error_metric = 0.007989107030273012
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0011352190747857098 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.894386579981074 seconds.
# Saving lr to results/5D_unimodal/5D_50K/null_hypothesis/LR_power_abs_down_0.001135.json
# ThresholdS: [[0.95, [9500, 500], 1.9256337142671267], [0.99, [9900, 100], 3.6884560379849596]]
# Null distribution computed in 39.060535559023265 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 6.4749957919702865 seconds.
# statistic = 3.6937764580178594 - next threshold = 3.6884560379849596 at 0.99 CL
# relative_error_eps = 0.005353555353181036
# relative_error_metric = 0.0014414122112194594
# =======> statistic within required accuracy at 0.99 CL in 771.7802306869999 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1490.7930882460205 seconds.
# Saving results in the file results/5D_unimodal/5D_50K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T23:35:34.305518', 'fgd_cov_diag_2024-05-02T23:38:48.208109', 'fgd_cov_off_diag_2024-05-02T23:42:40.594316', 'fgd_power_abs_up_2024-05-02T23:46:53.473320', 'fgd_power_abs_down_2024-05-02T23:51:08.490997', 'fgd_random_normal_2024-05-02T23:55:22.841224', 'fgd_random_uniform_2024-05-02T23:58:30.541193', 'mmd_mean_2024-05-03T00:01:19.029209', 'mmd_cov_diag_2024-05-03T00:10:42.320703', 'mmd_cov_off_diag_2024-05-03T00:21:42.477808', 'mmd_power_abs_up_2024-05-03T00:32:03.188655', 'mmd_power_abs_down_2024-05-03T00:44:59.212836', 'mmd_random_normal_2024-05-03T00:58:00.147107', 'mmd_random_uniform_2024-05-03T01:06:41.284286', 'ks_mean_2024-05-03T01:15:40.563686', 'ks_cov_diag_2024-05-03T01:18:44.360148', 'ks_cov_off_diag_2024-05-03T01:22:07.508900', 'ks_power_abs_up_2024-05-03T01:24:54.357509', 'ks_power_abs_down_2024-05-03T01:28:43.944956', 'ks_random_normal_2024-05-03T01:32:22.746910', 'ks_random_uniform_2024-05-03T01:35:07.018751', 'sks_mean_2024-05-03T01:37:36.346149', 'sks_cov_diag_2024-05-03T01:41:55.408347', 'sks_cov_off_diag_2024-05-03T01:47:00.177719', 'sks_power_abs_up_2024-05-03T01:52:10.140072', 'sks_power_abs_down_2024-05-03T01:57:32.646166', 'sks_random_normal_2024-05-03T02:02:57.766960', 'sks_random_uniform_2024-05-03T02:06:45.964579', 'swd_mean_2024-05-03T02:10:13.144546', 'swd_cov_diag_2024-05-03T02:13:07.074036', 'swd_cov_off_diag_2024-05-03T02:16:46.637347', 'swd_power_abs_up_2024-05-03T02:20:15.421273', 'swd_power_abs_down_2024-05-03T02:23:54.924429', 'swd_random_normal_2024-05-03T02:27:49.568987', 'swd_random_uniform_2024-05-03T02:30:24.270799', 'lr_mean_2024-05-03T02:32:42.206344', 'lr_cov_diag_2024-05-03T02:51:27.129290', 'lr_cov_off_diag_2024-05-03T03:13:57.607588', 'lr_power_abs_up_2024-05-03T03:45:56.156569', 'lr_power_abs_down_2024-05-03T04:11:45.768873'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean    5  10000                50000
# 14        ks        mean    5  10000                50000
# 28       swd        mean    5  10000                50000
# 21       sks        mean    5  10000                50000
# 0        fgd        mean    5  10000                50000
# 7        mmd        mean    5  10000                50000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.01150                             0.01690
# 14                             0.03815                             0.05056
# 28                             0.04547                             0.06059
# 21                             0.04608                             0.06029
# 0                              0.04791                             0.06423
# 7                              0.05341                             0.07454
#
#     $t^{\mu}$ (s)
# 35           1124
# 14            183
# 28            173
# 21            259
# 0             193
# 7             563
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.01150
# 14        ks                             0.03815
# 28       swd                             0.04547
# 21       sks                             0.04608
# 0        fgd                             0.04791
# 7        mmd                             0.05341
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.01690           1124
# 14                             0.05056            183
# 28                             0.06059            173
# 21                             0.06029            259
# 0                              0.06423            193
# 7                              0.07454            563

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag    5  10000                50000
# 1        fgd    cov_diag    5  10000                50000
# 29       swd    cov_diag    5  10000                50000
# 8        mmd    cov_diag    5  10000                50000
# 22       sks    cov_diag    5  10000                50000
# 15        ks    cov_diag    5  10000                50000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00336
# 1                                      0.01213
# 29                                     0.01488
# 8                                      0.01541
# 22                                     0.02060
# 15                                     0.02792
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00448                   1350
# 1                                      0.01708                    232
# 29                                     0.02081                    219
# 8                                      0.02142                    660
# 22                                     0.02865                    304
# 15                                     0.03855                    203
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00336
# 1        fgd                                     0.01213
# 29       swd                                     0.01488
# 8        mmd                                     0.01541
# 22       sks                                     0.02060
# 15        ks                                     0.02792
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00448                   1350
# 1                                      0.01708                    232
# 29                                     0.02081                    219
# 8                                      0.02142                    660
# 22                                     0.02865                    304
# 15                                     0.03855                    203

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag    5  10000                50000
# 2        fgd  cov_off_diag    5  10000                50000
# 23       sks  cov_off_diag    5  10000                50000
# 30       swd  cov_off_diag    5  10000                50000
# 9        mmd  cov_off_diag    5  10000                50000
# 16        ks  cov_off_diag    5  10000                50000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00033
# 2                                           0.00515
# 23                                          0.01335
# 30                                          0.01541
# 9                                           0.02701
# 16                                          1.01501
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00045
# 2                                           0.00696
# 23                                          0.01990
# 30                                          0.02256
# 9                                           0.03702
# 16                                          1.02085
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        1918
# 2                          252
# 23                         309
# 30                         208
# 9                          620
# 16                         166
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00033
# 2        fgd                                          0.00515
# 23       sks                                          0.01335
# 30       swd                                          0.01541
# 9        mmd                                          0.02701
# 16        ks                                          1.01501
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00045
# 2                                           0.00696
# 23                                          0.01990
# 30                                          0.02256
# 9                                           0.03702
# 16                                          1.02085
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        1918
# 2                          252
# 23                         309
# 30                         208
# 9                          620
# 16                         166

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up    5  10000                50000
# 10       mmd  power_abs_up    5  10000                50000
# 3        fgd  power_abs_up    5  10000                50000
# 31       swd  power_abs_up    5  10000                50000
# 24       sks  power_abs_up    5  10000                50000
# 17        ks  power_abs_up    5  10000                50000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00139
# 10                                      0.00292
# 3                                       0.00380
# 31                                      0.00408
# 24                                      0.00469
# 17                                      0.00561
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00183                    1549
# 10                                      0.00400                     776
# 3                                       0.00513                     255
# 31                                      0.00572                     219
# 24                                      0.00610                     322
# 17                                      0.00755                     229
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00139
# 10       mmd                                      0.00292
# 3        fgd                                      0.00380
# 31       swd                                      0.00408
# 24       sks                                      0.00469
# 17        ks                                      0.00561
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00183                    1549
# 10                                      0.00400                     776
# 3                                       0.00513                     255
# 31                                      0.00572                     219
# 24                                      0.00610                     322
# 17                                      0.00755                     229

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down    5  10000                50000
# 11       mmd  power_abs_down    5  10000                50000
# 4        fgd  power_abs_down    5  10000                50000
# 32       swd  power_abs_down    5  10000                50000
# 25       sks  power_abs_down    5  10000                50000
# 18        ks  power_abs_down    5  10000                50000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00069
# 11                                      0.00314
# 4                                       0.00376
# 32                                      0.00416
# 25                                      0.00492
# 18                                      0.00622
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00113                    1490
# 11                                      0.00432                     780
# 4                                       0.00517                     254
# 32                                      0.00580                     234
# 25                                      0.00641                     325
# 18                                      0.00797                     218
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00069
# 11       mmd                                      0.00314
# 4        fgd                                      0.00376
# 32       swd                                      0.00416
# 25       sks                                      0.00492
# 18        ks                                      0.00622
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00113                    1490
# 11                                      0.00432                     780
# 4                                       0.00517                     254
# 32                                      0.00580                     234
# 25                                      0.00641                     325
# 18                                      0.00797                     218

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        fgd  random_normal    5  10000                50000
# 19        ks  random_normal    5  10000                50000
# 26       sks  random_normal    5  10000                50000
# 33       swd  random_normal    5  10000                50000
# 12       mmd  random_normal    5  10000                50000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                                      0.18982
# 19                                     0.21118
# 26                                     0.23560
# 33                                     0.24048
# 12                                     0.53833
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.22153                    187
# 19                                     0.24626                    164
# 26                                     0.27980                    228
# 33                                     0.28928                    154
# 12                                     0.62656                    521
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        fgd                                     0.18982
# 19        ks                                     0.21118
# 26       sks                                     0.23560
# 33       swd                                     0.24048
# 12       mmd                                     0.53833
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.22153                    187
# 19                                     0.24626                    164
# 26                                     0.27980                    228
# 33                                     0.28928                    154
# 12                                     0.62656                    521

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform    5  10000                50000
# 20        ks  random_uniform    5  10000                50000
# 27       sks  random_uniform    5  10000                50000
# 34       swd  random_uniform    5  10000                50000
# 13       mmd  random_uniform    5  10000                50000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                                      0.32471
# 20                                     0.36377
# 27                                     0.40283
# 34                                     0.41748
# 13                                     0.91736
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.38292                    168
# 20                                     0.42489                    149
# 27                                     0.48813                    207
# 34                                     0.50251                    137
# 13                                     1.08780                    539
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                                     0.32471
# 20        ks                                     0.36377
# 27       sks                                     0.40283
# 34       swd                                     0.41748
# 13       mmd                                     0.91736
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.38292                    168
# 20                                     0.42489                    149
# 27                                     0.48813                    207
# 34                                     0.50251                    137
# 13                                     1.08780                    539

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.048 & 0.064 & 193 & cov_diag & 5 & 10000 & 50000 & 0.012 & 0.017 & 232 & cov_off_diag & 5 & 10000 & 50000 & 0.0052 & 0.007 & 252 & 0.0038 & 0.0051 & 255 \\
# $\overline{D}$ & 0.038 & 0.051 & 183 & cov_diag & 5 & 10000 & 50000 & 0.028 & 0.039 & 203 & cov_off_diag & 5 & 10000 & 50000 & 1 & 1 & 166 & 0.0056 & 0.0076 & 229 \\
# $t_{\mathrm{LLR}}$ & 0.011 & 0.017 & 1124 & cov_diag & 5 & 10000 & 50000 & 0.0034 & 0.0045 & 1350 & cov_off_diag & 5 & 10000 & 50000 & 0.00033 & 0.00045 & 1918 & 0.0014 & 0.0018 & 1549 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.053 & 0.075 & 563 & cov_diag & 5 & 10000 & 50000 & 0.015 & 0.021 & 660 & cov_off_diag & 5 & 10000 & 50000 & 0.027 & 0.037 & 620 & 0.0029 & 0.004 & 776 \\
# $\widetilde{D}$ & 0.046 & 0.06 & 259 & cov_diag & 5 & 10000 & 50000 & 0.021 & 0.029 & 304 & cov_off_diag & 5 & 10000 & 50000 & 0.013 & 0.02 & 309 & 0.0047 & 0.0061 & 322 \\
# $\widetilde{W}$ & 0.045 & 0.061 & 173 & cov_diag & 5 & 10000 & 50000 & 0.015 & 0.021 & 219 & cov_off_diag & 5 & 10000 & 50000 & 0.015 & 0.023 & 208 & 0.0041 & 0.0057 & 219 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.0038 & 0.0052 & 254 & 0.19 & 0.22 & 1.9e+02 & 0.32 & 0.38 & 1.7e+02 & 1307 \\
# $\overline{D}$ & 0.0062 & 0.008 & 218 & 0.21 & 0.25 & 1.6e+02 & 0.36 & 0.42 & 1.5e+02 & 41 \\
# $t_{\mathrm{LLR}}$ & 0.00069 & 0.0011 & 1490 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.0031 & 0.0043 & 780 & 0.54 & 0.63 & 5.2e+02 & 0.92 & 1.1 & 5.4e+02 & 13796 \\
# $\widetilde{D}$ & 0.0049 & 0.0064 & 325 & 0.24 & 0.28 & 2.3e+02 & 0.4 & 0.49 & 2.1e+02 & 476 \\
# $\widetilde{W}$ & 0.0042 & 0.0058 & 234 & 0.24 & 0.29 & 1.5e+02 & 0.42 & 0.5 & 1.4e+02 & 312 \\
# \bottomrule
# \end{tabular}
