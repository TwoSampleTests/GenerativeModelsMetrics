# %%
import pandas as pd

# %%
ks_results = {"5D_unimodal": {"10K": "mu = 0.8653553242156943 +/- 0.00014368295196135687 \
                                      sigma = 0.11986782385667842 +/- 0.0009619110349003553 \
                                      68%CL = 0.9071474963608753, 95%CL = 1.0883793400844244, 99%CL = 1.198475667036836",
                              "20K": "mu = 0.8667149733239785 +/- 0.00014398077220061515 \
                                      sigma = 0.11999198814946568 +/- 0.0009926774399841225 \
                                      68%CL = 0.9092509746551514, 95%CL = 1.091250404715538, 99%CL = 1.2057003565132618",
                              "50K": "mu = 0.8664596922331977 +/- 0.00014380396148422074 \
                                      sigma = 0.11991828946587786 +/- 0.0010303458919960521 \
                                      68%CL = 0.9059613828876086, 95%CL = 1.089089135384617, 99%CL = 1.2154849737958495",
                             "100K": "mu = 0.865879352134588 +/- 0.00014409841001630991 \
                                      sigma = 0.12004099717026259 +/- 0.0010252371802540133 \
                                      68%CL = 0.9066588006737435, 95%CL = 1.0886312421137199, 99%CL = 1.2107876027270617"},
               "5D_mixture": {"10K": "mu = 0.8641125120923411 +/- 0.00017197174905408282 \
                                      sigma = 0.13113799947158064 +/- 0.0012591139555934523 \
                                      68%CL = 0.9062283657910839, 95%CL = 1.1068345889394846, 99%CL = 1.2480436536081871",
                              "20K": "mu = 0.8683062179060653 +/- 0.00017048418516868815 \
                                      sigma = 0.13056959261967854 +/- 0.0012143195048050744 \
                                      68%CL = 0.9108503349125385, 95%CL = 1.1089506559073925, 99%CL = 1.2629506178200245",
                              "50K": "mu = 0.8681516134119874 +/- 0.00016924598357191862 \
                                      sigma = 0.13009457466471022 +/- 0.0011652934262257292 \
                                      68%CL = 0.9121602305718006, 95%CL = 1.1096755356387438, 99%CL = 1.2692760577053381",
                             "100K": "mu = 0.8689293527700909 +/- 0.00017416942795426158 \
                                      sigma = 0.1319732654571605 +/- 0.001199891859395542 \
                                      68%CL = 0.9117351041017392, 95%CL = 1.1124223535563071, 99%CL = 1.265660243663076"},
             "20D_unimodal": {"10K": "mu = 0.8666203877216206 +/- 0.0001356941764711491 \
                                      sigma = 0.11648784334476671 +/- 0.0010318221418334234 \
                                      68%CL = 0.9055213524073136, 95%CL = 1.0858332753076616, 99%CL = 1.2153754996184916",
                              "20K": "mu = 0.8658526310138405 +/- 0.00013098520621847905 \
                                      sigma = 0.11444876854666416 +/- 0.0009489896381201503 \
                                      68%CL = 0.9048002772033215, 95%CL = 1.0811004787683487, 99%CL = 1.2127505615353584",
                              "50K": "mu = 0.8673627625838782 +/- 0.0001350739171896792 \
                                      sigma = 0.11622130492714286 +/- 0.0010167182938079162 \
                                      68%CL = 0.9051712124041097, 95%CL = 1.0860214450011858, 99%CL = 1.2144733317493273",
                             "100K": "mu = 0.8668801748175944 +/- 0.0001346382919099102 \
                                      sigma = 0.1160337416055822 +/- 0.0009820466638004156 \
                                      68%CL = 0.9054295005779338, 95%CL = 1.0848732656815778, 99%CL = 1.2053976747108415"},
              "20D_mixture": {"10K": "mu = 0.8644640350571903 +/- 0.0002347751242327214 \
                                      sigma = 0.15322373322456329 +/- 0.0014248537469858798 \
                                      68%CL = 0.9090568803073205, 95%CL = 1.1593018835616806, 99%CL = 1.3432204571688977",
                              "20K": "mu = 0.8685079028550535 +/- 0.00023901411358594565 \
                                      sigma = 0.15460081292992792 +/- 0.0013969523515819566 \
                                      68%CL = 0.9153506718575954, 95%CL = 1.1692005209624767, 99%CL = 1.322800386697054",
                              "50K": "mu = 0.865353462100772 +/- 0.0002327056819423629 \
                                      sigma = 0.15254693767570782 +/- 0.0014016555861021656 \
                                      68%CL = 0.9118751448364196, 95%CL = 1.1608093289295256, 99%CL = 1.3268295075957064",
                             "100K": "mu = 0.8708943339587834 +/- 0.0002445563281378403 \
                                      sigma = 0.15638296842618132 +/- 0.0014885699064338955 \
                                      68%CL = 0.9168789846737446, 95%CL = 1.170024215635068, 99%CL = 1.3546998469604685"},
            "100D_unimodal": {"10K": "mu = 0.8648519881247019 +/- 4.671219940125676e-05 \
                                      sigma = 0.06834632353042609 +/- 0.0005488108187221746 \
                                      68%CL = 0.8915276108849348, 95%CL = 0.9871850860820219, 99%CL = 1.0483638708736165",
                              "20K": "mu = 0.8658674803469331 +/- 4.695965880957206e-05 \
                                      sigma = 0.06852711785094427 +/- 0.0005479119102433421 \
                                      68%CL = 0.8927605114877224, 95%CL = 0.9866203181445599, 99%CL = 1.0566456243395805",
                              "50K": "mu = 0.8665557849857086 +/- 4.6802021228962487e-05 \
                                      sigma = 0.06841200276922353 +/- 0.0005266576011952655 \
                                      68%CL = 0.893739436395866, 95%CL = 0.98900622440745, 99%CL = 1.0512334752782537",
                             "100K": "mu = 0.8675048624766729 +/- 4.656733078694245e-05 \
                                      sigma = 0.0682402599547675 +/- 0.0005252892686958336 \
                                      68%CL = 0.8936635805181075, 95%CL = 0.9928801559283454, 99%CL = 1.0498350892001214"},
             "100D_mixture": {"10K": "mu = 0.864318154218513 +/- 0.00012835307403313297 \
                                      sigma = 0.11329301568637537 +/- 0.0009140666435986401 \
                                      68%CL = 0.903803078077085, 95%CL = 1.0769097338066926, 99%CL = 1.1813566708429235",
                              "20K": "mu = 0.8645101934252307 +/- 0.00012856559626431182 \
                                      sigma = 0.11338677006790158 +/- 0.0009818499289136761 \
                                      68%CL = 0.9049254469573498, 95%CL = 1.070170383900404, 99%CL = 1.1980904266238213",
                              "50K": "mu = 0.8667433041997571 +/- 0.00013014084764409592 \
                                      sigma = 0.1140792915669167 +/- 0.000938568841171295 \
                                      68%CL = 0.9078717223737124, 95%CL = 1.0778094738209232, 99%CL = 1.1930141509406538",
                             "100K": "mu = 0.8667111344444797 +/- 0.000127170747754699 \
                                      sigma = 0.11277000831546435 +/- 0.0009840315047732727 \
                                      68%CL = 0.906523021635548, 95%CL = 1.0731505575089073, 99%CL = 1.1863828824868625"}}

# %%
ks_results
# Out:
# {'5D_unimodal': {'10K': 'mu = 0.8653553242156943 +/- 0.00014368295196135687                                       sigma = 0.11986782385667842 +/- 0.0009619110349003553                                       68%CL = 0.9071474963608753, 95%CL = 1.0883793400844244, 99%CL = 1.198475667036836',
#   '20K': 'mu = 0.8667149733239785 +/- 0.00014398077220061515                                       sigma = 0.11999198814946568 +/- 0.0009926774399841225                                       68%CL = 0.9092509746551514, 95%CL = 1.091250404715538, 99%CL = 1.2057003565132618',
#   '50K': 'mu = 0.8664596922331977 +/- 0.00014380396148422074                                       sigma = 0.11991828946587786 +/- 0.0010303458919960521                                       68%CL = 0.9059613828876086, 95%CL = 1.089089135384617, 99%CL = 1.2154849737958495',
# ...

# %%
res = {"D": [], "model": [], "n": [], "mu": [], "delta_mu": [], "sigma": [], "delta_sigma": [], "68%CL": [], "95%CL": [], "99%CL": []}
for k, v in ks_results.items():
    lst = k.split("_")
    for k1, v1 in v.items():
        res["n"].append(k1)
        res["mu"].append(float(v1.split("mu = ")[1].split(" +/- ")[0]))
        res["delta_mu"].append(float(v1.split(" +/- ")[1].split(" ")[0]))
        res["sigma"].append(float(v1.split("sigma = ")[1].split(" +/- ")[0]))
        res["delta_sigma"].append(float(v1.split(" +/- ")[2].split(" ")[0]))
        res["68%CL"].append(float(v1.split("68%CL = ")[1].split(",")[0]))
        res["95%CL"].append(float(v1.split("95%CL = ")[1].split(",")[0]))
        res["99%CL"].append(float(v1.split("99%CL = ")[1]))
        res["D"].append(lst[0].replace("D",""))
        res["model"].append(lst[1])

# %%
pd.DataFrame(res)
# Out:
#       D     model     n        mu  delta_mu     sigma  delta_sigma     68%CL  \
# 0     5  unimodal   10K  0.865355  0.000144  0.119868     0.000962  0.907147
# 1     5  unimodal   20K  0.866715  0.000144  0.119992     0.000993  0.909251
# 2     5  unimodal   50K  0.866460  0.000144  0.119918     0.001030  0.905961
# 3     5  unimodal  100K  0.865879  0.000144  0.120041     0.001025  0.906659
# 4     5   mixture   10K  0.864113  0.000172  0.131138     0.001259  0.906228
# 5     5   mixture   20K  0.868306  0.000170  0.130570     0.001214  0.910850
# 6     5   mixture   50K  0.868152  0.000169  0.130095     0.001165  0.912160
# 7     5   mixture  100K  0.868929  0.000174  0.131973     0.001200  0.911735
# 8    20  unimodal   10K  0.866620  0.000136  0.116488     0.001032  0.905521
# 9    20  unimodal   20K  0.865853  0.000131  0.114449     0.000949  0.904800
# 10   20  unimodal   50K  0.867363  0.000135  0.116221     0.001017  0.905171
# ...
