# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_unimodal import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results_leonardo/100D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-16 19:25:47.037384: Importing os...
# 2024-04-16 19:25:47.037520: Importing sys...
# Visible devices: [1]
# 2024-04-16 19:25:47.037792: Importing timer from timeit...
# 2024-04-16 19:25:47.037878: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-04-16 19:25:47.038028: Importing numpy...
# 2024-04-16 19:25:47.166868: Importing matplotlib...
# 2024-04-16 19:25:47.547362: Importing h5py...
# 2024-04-16 19:25:47.664355: Importing importlib.util...
# 2024-04-16 19:25:47.664450: Importing json...
# 2024-04-16 19:25:47.664512: Importing pandas...
# 2024-04-16 19:25:48.201663: Importing random...
# 2024-04-16 19:25:48.201801: Importing scipy utils...
# 2024-04-16 19:25:48.771843: Importing subprocess...
# 2024-04-16 19:25:48.771982: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-16 19:25:56.616020: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-16 19:25:57.746886: Importing timeit...
# 2024-04-16 19:25:57.746989: Importing tqdm...
# 2024-04-16 19:25:57.755924: Importing typing...
# 2024-04-16 19:25:57.756033: Setting tf configs...
# 2024-04-16 19:25:58.565319: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-16 19:26:05.003563: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-04-16 19:26:05.033627: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 10
ndims = 100
niter = 10_000
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = 0.,
                                                             eps_scale = 0.,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
dist_2 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = eps_loc,
                                                             eps_scale = eps_scale,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (100,) (100,)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 1000,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 1000,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               #min_samples_input = 20_000,
                               #max_samples_input = 50_000,
                               num_batches = 20)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4,
                               block_size = 10_000,
                               num_batches = 1,
                               batch_size = 20_000)
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...      100           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True      100           0  float64   100  200000000         False
#
#    ncomp
# 0     10
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fn": {"name": "fn", # type: ignore
                                       "object_name": "FNMetric",
                                       "class_name": "GMetrics.FNMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns)/ndims,
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)/ndims",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\overline{\|\cdot\|}_{F}$",
                                       "null_file": null_hypotheses_dir+"FN.json"},
                               "fpd": {"name": "fpd",
                                       "object_name": "FPDMetric",
                                       "class_name": "GMetrics.FPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1000,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20,
                                       "latex": "$d_{\mathrm{FPD}}$",
                                       "null_file": null_hypotheses_dir+"FPD.json"},
                               "kpd": {"name": "kpd",
                                       "object_name": "KPDMetric" ,
                                       "class_name": "GMetrics.KPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1,
                                       "latex": "$d_{\mathrm{KPD}}$",
                                       "null_file": null_hypotheses_dir+"KPD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 1000, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 1000, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fn': {'name': 'fn',
#   'object_name': 'FNMetric',
#   'class_name': 'GMetrics.FNMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)/ndims',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$\\overline{\\|\\cdot\\|}_{F}$',
#   'null_file': 'results_leonardo/100D_unimodal/100D_20K/null_hypothesis/FN.json'},
#  'fpd': {'name': 'fpd',
#   'object_name': 'FPDMetric',
#   'class_name': 'GMetrics.FPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 20,
#   'latex': '$d_{\\mathrm{FPD}}$',
#   'null_file': 'results_leonardo/100D_unimodal/100D_20K/null_hypothesis/FPD.json'},
#  'kpd': {'name': 'kpd',
#   'object_name': 'KPDMetric',
#   'class_name': 'GMetrics.KPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{KPD}}$',
#   'null_file': 'results_leonardo/100D_unimodal/100D_20K/null_hypothesis/KPD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 5000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results_leonardo/100D_unimodal/100D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 1000, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 20,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results_leonardo/100D_unimodal/100D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 1000, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 20,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results_leonardo/100D_unimodal/100D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 20,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results_leonardo/100D_unimodal/100D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fn from results_leonardo/100D_unimodal/100D_20K/null_hypothesis/FN.json
# Loading fpd from results_leonardo/100D_unimodal/100D_20K/null_hypothesis/FPD.json
# Loading kpd from results_leonardo/100D_unimodal/100D_20K/null_hypothesis/KPD.json
# Loading ks from results_leonardo/100D_unimodal/100D_20K/null_hypothesis/KS.json
# Loading sks from results_leonardo/100D_unimodal/100D_20K/null_hypothesis/SKS.json
# Loading swd from results_leonardo/100D_unimodal/100D_20K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fn: [[0.68, [6800, 3199], 0.920718786721005], [0.95, [9500, 500], 1.0614378183041988], [0.99, [9900, 100], 1.1564223220806207]]
# Computing time for metric fn: 19.54989374615252
# ThresholdS for metric fpd: [[0.68, [6800, 3199], 0.857102570992948], [0.95, [9500, 500], 1.0872098175233125], [0.99, [9900, 100], 1.2381252587695903]]
# Computing time for metric fpd: 1432.6830542169046
# ThresholdS for metric kpd: [[0.68, [6800, 3199], -0.010081266620387552], [0.95, [9500, 500], -0.008362142511764148], [0.99, [9900, 100], -0.006952602843446343]]
# Computing time for metric kpd: 19303.824737829855
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.8957504853606224], [0.95, [9500, 500], 0.9974004179239273], [0.99, [9900, 100], 1.066550612449646]]
# Computing time for metric ks: 501.7251929529011
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.8927605114877224], [0.95, [9500, 500], 0.9866203181445599], [0.99, [9900, 100], 1.0566456243395805]]
# Computing time for metric sks: 3922.9438743321225
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.12935794992191169], [0.95, [9500, 500], 0.1499729298431156], [0.99, [9900, 100], 0.16515236874492245]]
# Computing time for metric swd: 2696.140832208097
#   name object_name          class_name                                kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                    {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                    {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                    {}
# 3   ks      KSTest     GMetrics.KSTest                                    {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 1000, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 1000, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                   {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f281ea6b060>
# 1          metric_list  <function <lambda> at 0x7f281ea6a980>
# 2          metric_list  <function <lambda> at 0x7f281ea6bec0>
# 3      statistic_means  <function <lambda> at 0x7f281ea6bf60>
# 4         metric_means  <function <lambda> at 0x7f27e0068040>
# 5         metric_means  <function <lambda> at 0x7f27e00680e0>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f27e0068180>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...             20
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...           5000
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...             20
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...             20
# 6  {'niter': 10000, 'batch_size_test': 20000, 'ba...             20
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results_leonardo/100D_unimodal/100D_20K/null_h...
# 1  results_leonardo/100D_unimodal/100D_20K/null_h...
# 2  results_leonardo/100D_unimodal/100D_20K/null_h...
# 3  results_leonardo/100D_unimodal/100D_20K/null_h...
# 4  results_leonardo/100D_unimodal/100D_20K/null_h...
# 5  results_leonardo/100D_unimodal/100D_20K/null_h...
# 6  results_leonardo/100D_unimodal/100D_20K/null_h...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.920718786721005], [0.9...
# 1  [[0.68, [6800, 3199], 0.857102570992948], [0.9...
# 2  [[0.68, [6800, 3199], -0.010081266620387552], ...
# 3  [[0.68, [6800, 3199], 0.8957504853606224], [0....
# 4  [[0.68, [6800, 3199], 0.8927605114877224], [0....
# 5  [[0.68, [6800, 3199], 0.12935794992191169], [0...
# 6                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    if "FPD" in latex:
        latex = r"$d_{\mathrm{FPD}}\,(\times 10^{3})$"
    elif "KPD" in latex:
        latex = r"$d_{\mathrm{KPD}}\,(\times 10^{4})$"
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.8757534735320361 +/- 0.00011595370549362402
# sigma = 0.10768180231293681 +/- 0.0007986502391254554
# /tmp/ipykernel_524863/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_524863/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_524863/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_524863/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.5308622741140425 seconds.
# mu = 0.7965579085061602 +/- 0.0002545664549082612
# sigma = 0.1595513882447474 +/- 0.0012894754881227729
# /tmp/ipykernel_524863/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_524863/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_524863/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_524863/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9989514991175383 seconds.
# mu = -0.01049674488800967 +/- 1.4265466608641295e-08
# sigma = 0.0011943812878909856 +/- 1.0449474243223926e-05
# /tmp/ipykernel_524863/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_524863/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_524863/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_524863/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9642135379835963 seconds.
# mu = 0.8659933351095765 +/- 5.405548397592317e-05
# sigma = 0.07352243465495628 +/- 0.0005753493977979736
# /tmp/ipykernel_524863/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_524863/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_524863/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_524863/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3026029728353024 seconds.
# mu = 0.8658674803469331 +/- 4.695965880957206e-05
# sigma = 0.06852711785094427 +/- 0.0005479119102433421
# /tmp/ipykernel_524863/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_524863/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_524863/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_524863/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.288621551124379 seconds.
# mu = 0.12441786059678593 +/- 1.927664378649783e-06
# sigma = 0.013884035359540766 +/- 0.00012392293593757622
# /tmp/ipykernel_524863/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_524863/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_524863/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_524863/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9076513817999512 seconds.
#   name object_name          class_name                                kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                    {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                    {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                    {}
# 3   ks      KSTest     GMetrics.KSTest                                    {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 1000, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 1000, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                   {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f281ea6b060>
# 1          metric_list  <function <lambda> at 0x7f281ea6a980>
# 2          metric_list  <function <lambda> at 0x7f281ea6bec0>
# 3      statistic_means  <function <lambda> at 0x7f281ea6bf60>
# 4         metric_means  <function <lambda> at 0x7f27e0068040>
# 5         metric_means  <function <lambda> at 0x7f27e00680e0>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f27e0068180>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...             20
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...           5000
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...             20
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...             20
# 6  {'niter': 10000, 'batch_size_test': 20000, 'ba...             20
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results_leonardo/100D_unimodal/100D_20K/null_h...
# 1  results_leonardo/100D_unimodal/100D_20K/null_h...
# 2  results_leonardo/100D_unimodal/100D_20K/null_h...
# 3  results_leonardo/100D_unimodal/100D_20K/null_h...
# 4  results_leonardo/100D_unimodal/100D_20K/null_h...
# 5  results_leonardo/100D_unimodal/100D_20K/null_h...
# 6  results_leonardo/100D_unimodal/100D_20K/null_h...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.920718786721005], [0.9...
# 1  [[0.68, [6800, 3199], 0.857102570992948], [0.9...
# 2  [[0.68, [6800, 3199], -0.010081266620387552], ...
# 3  [[0.68, [6800, 3199], 0.8957504853606224], [0....
# 4  [[0.68, [6800, 3199], 0.8927605114877224], [0....
# 5  [[0.68, [6800, 3199], 0.12935794992191169], [0...
# 6                                                 []
#
#                                          null_figure
# 0  results_leonardo/100D_unimodal/100D_20K/null_h...
# 1  results_leonardo/100D_unimodal/100D_20K/null_h...
# 2  results_leonardo/100D_unimodal/100D_20K/null_h...
# 3  results_leonardo/100D_unimodal/100D_20K/null_h...
# 4  results_leonardo/100D_unimodal/100D_20K/null_h...
# 5  results_leonardo/100D_unimodal/100D_20K/null_h...
# 6                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.01,
                                                 fn_tol = 0.01,
                                                 eps_min = 0.,
                                                 eps_max = 50.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for fn with mean deformation already loaded.
# Exclusion limits for fn with std deformation already loaded.
# Exclusion limits for fn with off deformation already loaded.
# Computing exclusion limits for fn with cov deformation.
#
# ======================================================
# =============== fn - only cov matrix ===============
# ======================================================
# ------------ 1 ------------
# eps = 25.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713288418.603807  524863 service.cc:145] XLA service 0x114d4abd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1713288418.604123  524863 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1713288421.415193  524863 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# statistic = 34.12840113720527 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8793472377471037
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 30.537131217764067 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8656346979393126
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 21.987746816295974 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8157960318108908
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 10.850644643758653 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6435760676826656
#
# ------------ 5 ------------
# eps = 1.5625
# WARNING:tensorflow:5 out of the last 9 calls to <function generate_and_clean_data_simple_1 at 0x7f28fddbcea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f27082b6480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 3.762624895543231 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1198805809407486
#
# ------------ 6 ------------
# eps = 0.78125
# WARNING:tensorflow:6 out of the last 11 calls to <function generate_and_clean_data_simple_1 at 0x7f28fddbcea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f27120b0d60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.3439301600200995 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.2348849275965661
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 0.8886511697411501 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.17720898853568684
#
# ------------ 8 ------------
# eps = 0.5859375
# statistic = 1.0468142834437892 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.013872662428070103
#
# ------------ 9 ------------
# eps = 0.68359375
# statistic = 1.176794027407672 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.10307798034817443
#
# ------------ 10 ------------
# eps = 0.634765625
# statistic = 1.1071952771145548 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.04219935489043195
#
# ------------ 11 ------------
# eps = 0.6103515625
# statistic = 1.0758664881607143 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.013501745926278879
#
# ------------ 12 ------------
# eps = 0.59814453125
# statistic = 1.0610582107916102 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.0003576991498545237
#
# ------------ 13 ------------
# eps = 0.604248046875
# statistic = 1.0683914757703583 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.01015228426395939
# relative_error_metric = 0.006529779156954427
#
# ------------ 14 ------------
# eps = 0.6011962890625
# statistic = 1.0647071641946964 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.005089058524173028
# relative_error_metric = 0.0030753743676078236
# =======> statistic within required accuracy at 0.95 CL in 93.33536863909103 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.59967041015625
# statistic = 1.062878272805219 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9525949157142426
# relative_error_metric = 0.0843004769078733
#
# ------------ 2 ------------
# eps = 25.299835205078125
# statistic = 34.16091437267339 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.907385041388046
# relative_error_metric = 1.8690249684368305
#
# ------------ 3 ------------
# eps = 12.949752807617188
# statistic = 30.825603387326225 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.8229679889636532
# relative_error_metric = 1.8553659692993767
#
# ------------ 4 ------------
# eps = 6.774711608886719
# statistic = 23.23904275750293 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.6747277759097845
# relative_error_metric = 1.810387329233838
#
# ------------ 5 ------------
# eps = 3.6871910095214844
# statistic = 13.338121684148726 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.4404573869324375
# relative_error_metric = 1.6808668636740491
#
# ------------ 6 ------------
# eps = 2.143430709838867
# statistic = 6.283594346543401 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.1255584334312583
# relative_error_metric = 1.3782689617040909
#
# ------------ 7 ------------
# eps = 1.3715505599975586
# statistic = 3.032635422089966 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.783149288211033
# relative_error_metric = 0.8957685544536825
#
# ------------ 8 ------------
# eps = 0.9856104850769043
# statistic = 1.808597688865802 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.4869043411563884
# relative_error_metric = 0.4399129613813362
#
# ------------ 9 ------------
# eps = 0.7926404476165771
# statistic = 1.3658260021846795 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.27719389873753697
# relative_error_metric = 0.1660452526339218
#
# ------------ 10 ------------
# eps = 0.6961554288864136
# statistic = 1.196207271129558 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.14891664577617195
# relative_error_metric = 0.03382168545678322
#
# ------------ 11 ------------
# eps = 0.6479129195213318
# statistic = 1.125020599283514 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.07178579783123741
# relative_error_metric = 0.027527949529704394
#
# ------------ 12 ------------
# eps = 0.6720341742038727
# statistic = 1.159475697147276 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.036548820475016126
# relative_error_metric = 0.0026368821436042636
#
# ------------ 13 ------------
# eps = 0.6599735468626022
# statistic = 1.1419641395707205 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.018108945091720757
# relative_error_metric = 0.012581158783464354
#
# ------------ 14 ------------
# eps = 0.6660038605332375
# statistic = 1.1506488227675997 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.009013665552220307
# relative_error_metric = 0.005005046615847462
# =======> statistic within required accuracy at 0.99 CL in 87.42017176304944 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 180.75557668088004 seconds.
# Saving results in the file results_leonardo/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fn with mean_std deformation.
#
# ======================================================
# =============== fn - mean + diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 35.56753584160217 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8840876265702158
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 35.44786494962274 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8837076867721876
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 34.64217798822385 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.881083437144747
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 31.360600542136844 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.869047367533895
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 24.74261614153183 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8354618510786986
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 17.17249775698257 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7671511311594605
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 10.740183781904104 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6402400096320782
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 6.200584327185696 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4153486194126197
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 3.4280102494747995 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0542821279772068
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 1.9244039222524623 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.578038743464935
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.2114845387890147 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.13202978097035142
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.9331777011974344 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.12860635631553793
#
# ------------ 13 ------------
# eps = 0.018310546875
# statistic = 1.0598975097456282 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.001452206577813038
#
# ------------ 14 ------------
# eps = 0.0213623046875
# statistic = 1.1332538764717548 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.06544523619285611
#
# ------------ 15 ------------
# eps = 0.01983642578125
# statistic = 1.0958928376998602 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.031942270230824174
#
# ------------ 16 ------------
# eps = 0.019073486328125
# statistic = 1.0777143870902468 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.015217775289670613
#
# ------------ 17 ------------
# eps = 0.0186920166015625
# statistic = 1.0687594355429773 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.020618556701030927
# relative_error_metric = 0.006874121375901191
#
# ------------ 18 ------------
# eps = 0.01850128173828125
# statistic = 1.0643166762738965 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.010362694300518135
# relative_error_metric = 0.002708551694977404
#
# ------------ 19 ------------
# eps = 0.018405914306640625
# statistic = 1.062104122670323 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.005194805194805195
# relative_error_metric = 0.0006275405757405116
# =======> statistic within required accuracy at 0.95 CL in 124.55423657200299 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.018358230590820312
# statistic = 1.0610000709529661 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.998531880594226
# relative_error_metric = 0.08606592179048966
#
# ------------ 2 ------------
# eps = 25.00917911529541
# statistic = 35.567554428522456 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9970659149820287
# relative_error_metric = 1.8740417106857434
#
# ------------ 3 ------------
# eps = 12.513768672943115
# statistic = 35.44830996415746 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.994140426207895
# relative_error_metric = 1.8736313859052163
#
# ------------ 4 ------------
# eps = 6.266063451766968
# statistic = 34.64829809048621 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9883150867215946
# relative_error_metric = 1.8708078366477356
#
# ------------ 5 ------------
# eps = 3.142210841178894
# statistic = 31.40123948512969 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9767659175623826
# relative_error_metric = 1.857923172870539
#
# ------------ 6 ------------
# eps = 1.5802845358848572
# statistic = 24.866176200226562 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9540654585857418
# relative_error_metric = 1.8222433749513052
#
# ------------ 7 ------------
# eps = 0.7993213832378387
# statistic = 17.41143495426917 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9101935267537822
# relative_error_metric = 1.7508765163649604
#
# ------------ 8 ------------
# eps = 0.40883980691432953
# statistic = 11.107588929686468 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.8281056654844863
# relative_error_metric = 1.6228241157512
#
# ------------ 9 ------------
# eps = 0.21359901875257492
# statistic = 6.678787067649782 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.683420446779961
# relative_error_metric = 1.4096278659271866
#
# ------------ 10 ------------
# eps = 0.11597862467169762
# statistic = 3.976547850885351 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.4533672667878048
# relative_error_metric = 1.0988279431887618
#
# ------------ 11 ------------
# eps = 0.06716842763125896
# statistic = 2.491938133836931 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.1414031146568984
# relative_error_metric = 0.7321183462506486
#
# ------------ 12 ------------
# eps = 0.04276332911103964
# statistic = 1.7393583123491887 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.7985757771648183
# relative_error_metric = 0.40261060063574217
#
# ------------ 13 ------------
# eps = 0.030560779850929976
# statistic = 1.3798850005705061 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.49888782090715833
# relative_error_metric = 0.17621104232456067
#
# ------------ 14 ------------
# eps = 0.024459505220875144
# statistic = 1.2126807730931024 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.2849881954004816
# relative_error_metric = 0.04749345955192074
#
# ------------ 15 ------------
# eps = 0.021408867905847728
# statistic = 1.134413799028658 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.13301702707437502
# relative_error_metric = 0.019214401981147038
#
# ------------ 16 ------------
# eps = 0.022934186563361436
# statistic = 1.1730100121559668 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.06879628278980444
# relative_error_metric = 0.014241830364892143
#
# ------------ 17 ------------
# eps = 0.022171527234604582
# statistic = 1.1535695052082455 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.03381652852997285
# relative_error_metric = 0.0024699800567895306
#
# ------------ 18 ------------
# eps = 0.02255285689898301
# statistic = 1.1632552041883248 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.01705242774229962
# relative_error_metric = 0.005891234475763036
#
# ------------ 19 ------------
# eps = 0.022362192066793796
# statistic = 1.1584035876363035 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.008562717652160103
# relative_error_metric = 0.001711805235431353
# =======> statistic within required accuracy at 0.99 CL in 118.82027456117794 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 243.37454708502628 seconds.
# Saving results in the file results_leonardo/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fn with mean_off deformation.
#
# ======================================================
# =============== fn - mean + off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 35.58646134236776 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8841474853823803
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 35.58646134236776 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8841474853823803
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 35.58646134236776 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8841474853823803
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 35.58646134236776 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8841474853823803
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 35.58646134236776 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8841474853823803
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 31.45300972779725 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8694195475043256
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 20.277927646099794 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8010366671727378
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 11.810944324840477 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6701658460724058
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 6.465900290093775 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4359558170397626
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 3.4585453649251883 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.060671002279407
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.9092741376603641 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5707967193883532
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 1.1980490753128734 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.12092237170712872
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.9270591765001102 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.13515599184228394
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 1.0497363743713035 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.011085247227341286
#
# ------------ 15 ------------
# eps = 0.01068115234375
# statistic = 1.12132986052494 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.054877156924797374
#
# ------------ 16 ------------
# eps = 0.009918212890625
# statistic = 1.0848213457910805 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.02179003158431578
#
# ------------ 17 ------------
# eps = 0.0095367431640625
# statistic = 1.0670912450562193 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.005312050325585091
#
# ------------ 18 ------------
# eps = 0.00934600830078125
# statistic = 1.058365646120848 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.0028985443555581106
#
# ------------ 19 ------------
# eps = 0.009441375732421875
# statistic = 1.062716564455039 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.01015228426395939
# relative_error_metric = 0.0012040049077591505
#
# ------------ 20 ------------
# eps = 0.009393692016601562
# statistic = 1.0605381151770472 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.005063291139240506
# relative_error_metric = 0.000847986174542114
# =======> statistic within required accuracy at 0.95 CL in 128.134654232068 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.009417533874511719
# statistic = 1.0616265947756998 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9992467391672273
# relative_error_metric = 0.08547667870127641
#
# ------------ 2 ------------
# eps = 25.004708766937256
# statistic = 35.58646134236776 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9984940455227163
# relative_error_metric = 1.8741065254821518
#
# ------------ 3 ------------
# eps = 12.507063150405884
# statistic = 35.58646134236776 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9969903572379288
# relative_error_metric = 1.8741065254821518
#
# ------------ 4 ------------
# eps = 6.258240342140198
# statistic = 35.58646134236776 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9939897588152977
# relative_error_metric = 1.8741065254821518
#
# ------------ 5 ------------
# eps = 3.1338289380073547
# statistic = 35.58646134236776 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9880155324009658
# relative_error_metric = 1.8741065254821518
#
# ------------ 6 ------------
# eps = 1.5716232359409332
# statistic = 35.58646134236776 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9761738367427146
# relative_error_metric = 1.8741065254821518
#
# ------------ 7 ------------
# eps = 0.7905203849077225
# statistic = 31.653078377405997 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.952908676269037
# relative_error_metric = 1.8590137249971967
#
# ------------ 8 ------------
# eps = 0.3999689593911171
# statistic = 20.6230994256884 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9079839317668823
# relative_error_metric = 1.787612908038428
#
# ------------ 9 ------------
# eps = 0.2046932466328144
# statistic = 12.280193689555706 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.824062406345028
# relative_error_metric = 1.6557400104076383
#
# ------------ 10 ------------
# eps = 0.10705539025366306
# statistic = 7.019116503599892 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.6765760301802668
# relative_error_metric = 1.4342037403342096
#
# ------------ 11 ------------
# eps = 0.05823646206408739
# statistic = 4.0537821939413154 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.4431942271047042
# relative_error_metric = 1.112186618759783
#
# ------------ 12 ------------
# eps = 0.033826997969299555
# statistic = 2.502435485915865 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.1289040742977114
# relative_error_metric = 0.7357559295655127
#
# ------------ 13 ------------
# eps = 0.021622265921905637
# statistic = 1.7375796437304523 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.7863924463071182
# relative_error_metric = 0.40162883682558687
#
# ------------ 14 ------------
# eps = 0.015519899898208678
# statistic = 1.377739248681698 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.4894141136825771
# relative_error_metric = 0.17466678459219268
#
# ------------ 15 ------------
# eps = 0.012468716886360198
# statistic = 1.2116452683058296 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.27882190012218655
# relative_error_metric = 0.04663967063220269
#
# ------------ 16 ------------
# eps = 0.010943125380435959
# statistic = 1.134167572779703 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.13032648080735704
# relative_error_metric = 0.019431456805824084
#
# ------------ 17 ------------
# eps = 0.011705921133398078
# statistic = 1.1723544684850147 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.06735786890597838
# relative_error_metric = 0.0136828454053119
#
# ------------ 18 ------------
# eps = 0.011324523256917018
# statistic = 1.1531154193780928 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.03312119123862392
# relative_error_metric = 0.002863692281936225
#
# ------------ 19 ------------
# eps = 0.011515222195157548
# statistic = 1.1626995270855442 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.01669886721291883
# relative_error_metric = 0.005413432681150862
#
# ------------ 20 ------------
# eps = 0.011419872726037283
# statistic = 1.157898498117052 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.008384436253371975
# relative_error_metric = 0.0012756883346062265
# =======> statistic within required accuracy at 0.99 CL in 126.83083873195574 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 254.96552888001315 seconds.
# Saving results in the file results_leonardo/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fn with mean_cov deformation.
#
# ======================================================
# =============== fn - mean + cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 39.39003988272229 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8950408856606724
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 38.18771185687887 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8918256495146097
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 34.21235822027285 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.879634409957651
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 25.39391003894697 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8395125516350723
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 15.054267734246318 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7365457404658993
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 7.9666514117949205 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5297176218571575
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 4.105681830579803 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1783137295584405
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 2.1834087975583527 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6915402249026859
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 1.3050417532885663 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.20587875586046936
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 0.9623547417231622 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.09791821408780858
#
# ------------ 11 ------------
# eps = 0.0732421875
# statistic = 1.1187533514234793 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.05257844717024484
#
# ------------ 12 ------------
# eps = 0.06103515625
# statistic = 1.0359096636849225 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.024343276293983866
#
# ------------ 13 ------------
# eps = 0.067138671875
# statistic = 1.0762991412954075 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.013903790103336358
#
# ------------ 14 ------------
# eps = 0.0640869140625
# statistic = 1.0558311905515976 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.005296093910741309
#
# ------------ 15 ------------
# eps = 0.06561279296875
# statistic = 1.0659988142872519 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.023529411764705882
# relative_error_metric = 0.004287785509735486
#
# ------------ 16 ------------
# eps = 0.064849853515625
# statistic = 1.060898174430269 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.011695906432748537
# relative_error_metric = 0.0005085376451016185
#
# ------------ 17 ------------
# eps = 0.0652313232421875
# statistic = 1.0634443176115134 - next threshold = 1.0614378183041988 at 0.95 CL
# relative_error_eps = 0.005865102639296188
# relative_error_metric = 0.0018885746869436242
# =======> statistic within required accuracy at 0.95 CL in 110.11111196293496 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.06504058837890625
# statistic = 1.0621701980678315 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9948035125816714
# relative_error_metric = 0.0849656916777872
#
# ------------ 2 ------------
# eps = 25.032520294189453
# statistic = 39.391122680682635 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9896339586650302
# relative_error_metric = 1.885919374699325
#
# ------------ 3 ------------
# eps = 12.54878044128418
# statistic = 38.19967840367307 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.979374818074252
# relative_error_metric = 1.8824657625368981
#
# ------------ 4 ------------
# eps = 6.306910514831543
# statistic = 34.29420884019889 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9591706921001726
# relative_error_metric = 1.8695174349041108
#
# ------------ 5 ------------
# eps = 3.1859755516052246
# statistic = 25.692057483834397 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.9199750655446162
# relative_error_metric = 1.8277113146903987
#
# ------------ 6 ------------
# eps = 1.6255080699920654
# statistic = 15.57507160372865 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.846107740095266
# relative_error_metric = 1.7235339947028223
#
# ------------ 7 ------------
# eps = 0.8452743291854858
# statistic = 8.585411554932302 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.7142062065601356
# relative_error_metric = 1.5251726372344148
#
# ------------ 8 ------------
# eps = 0.45515745878219604
# statistic = 4.749295196259384 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.4998782580299572
# relative_error_metric = 1.2167438970865838
#
# ------------ 9 ------------
# eps = 0.26009902358055115
# statistic = 2.8114554011918793 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 1.1998441778663824
# relative_error_metric = 0.8342157669850133
#
# ------------ 10 ------------
# eps = 0.1625698059797287
# statistic = 1.8751178724205715 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.8569838638137963
# relative_error_metric = 0.4741454866035214
#
# ------------ 11 ------------
# eps = 0.11380519717931747
# statistic = 1.4391077706097277 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.545325780512013
# relative_error_metric = 0.21782482840420062
#
# ------------ 12 ------------
# eps = 0.08942289277911186
# statistic = 1.239669218590553 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.3157031580204023
# relative_error_metric = 0.06948557273117685
#
# ------------ 13 ------------
# eps = 0.07723174057900906
# statistic = 1.1475101222916497 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.14630438955640046
# relative_error_metric = 0.00773651138143434
#
# ------------ 14 ------------
# eps = 0.08332731667906046
# statistic = 1.1928334568421417 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.0759293957519179
# relative_error_metric = 0.030998016553324938
#
# ------------ 15 ------------
# eps = 0.08027952862903476
# statistic = 1.1699715948442833 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.03869930152108833
# relative_error_metric = 0.011648304842176002
#
# ------------ 16 ------------
# eps = 0.0787556346040219
# statistic = 1.1586893427424578 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.019538684117541675
# relative_error_metric = 0.001958454701156193
#
# ------------ 17 ------------
# eps = 0.07799368759151548
# statistic = 1.1530866653636933 - next threshold = 1.1564223220806207 at 0.99 CL
# relative_error_eps = 0.009721854000184223
# relative_error_metric = 0.002888628479093805
# =======> statistic within required accuracy at 0.99 CL in 107.67742515704595 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 217.78857157705352 seconds.
# Saving results in the file results_leonardo/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fpd with mean deformation.
#
# ======================================================
# =============== fpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 384377.777693298 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999886860603762
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 97566.62580829968 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999554274755906
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 25187.331402331874 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998273476657245
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 6480.2790355724055 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9993290242974333
#
# ------------ 5 ------------
# eps = 1.5625
# WARNING:tensorflow:5 out of the last 5 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f24f9ae1da0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1639.5913669884656 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9973493654811054
#
# ------------ 6 ------------
# eps = 0.78125
# WARNING:tensorflow:6 out of the last 6 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f24f9e2ef20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 412.43147289944824 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9894833306163586
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 104.0655676078833 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9586426590284003
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 26.709505088869996 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8435484450325097
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 7.3069596782143424 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4819214369805755
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 2.4285917398584123 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7630589499676137
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.1956838071643279 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.09503201416654487
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.8798601975011352 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.21082078262435436
#
# ------------ 13 ------------
# eps = 0.018310546875
# statistic = 1.0123241539749352 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.07133551022747976
#
# ------------ 14 ------------
# eps = 0.0213623046875
# statistic = 1.0977445317999444 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.009642960531321663
#
# ------------ 15 ------------
# eps = 0.01983642578125
# statistic = 1.0534347992938453 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.03155593223099865
#
# ------------ 16 ------------
# eps = 0.020599365234375
# statistic = 1.0752153708465726 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.011093513654251994
#
# ------------ 17 ------------
# eps = 0.0209808349609375
# statistic = 1.0864352293727408 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 0.018018018018018018
# relative_error_metric = 0.000712708960166
#
# ------------ 18 ------------
# eps = 0.02117156982421875
# statistic = 1.0920652828545985 - next threshold = 1.0872098175233125 at 0.95 CL
# relative_error_eps = 0.00904977375565611
# relative_error_metric = 0.004456037083564172
# =======> statistic within required accuracy at 0.95 CL in 164.58574099908583 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.021076202392578125
# statistic = 1.089244123138044 - next threshold = 1.2381252587695903 at 0.99 CL
# relative_error_eps = 1.9983146142392219
# relative_error_metric = 0.1279394124447194
#
# ------------ 2 ------------
# eps = 25.01053810119629
# statistic = 384699.9668483452 - next threshold = 1.2381252587695903 at 0.99 CL
# relative_error_eps = 1.9966320666119315
# relative_error_metric = 1.9999871263698397
#
# ------------ 3 ------------
# eps = 12.515807151794434
# statistic = 97809.27844683474 - next threshold = 1.2381252587695903 at 0.99 CL
# relative_error_eps = 1.9932754571300884
# relative_error_metric = 1.9999493663748171
#
# ------------ 4 ------------
# eps = 6.268441677093506
# statistic = 25332.277934767306 - next threshold = 1.2381252587695903 at 0.99 CL
# relative_error_eps = 1.986595982206318
# relative_error_metric = 1.9998045079481528
#
# ------------ 5 ------------
# eps = 3.144758939743042

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.005,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for LR with mean deformation already loaded.
# Exclusion limits for LR with std deformation already loaded.
# Computing exclusion limits for lr with both deformation.
#
# ======================================================
# =============== lr - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 0.0025
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 500
# Iterating from 0 to 20 out of 10000 .
# Iterating from 20 to 40 out of 10000 .
# Iterating from 40 to 60 out of 10000 .
# Iterating from 60 to 80 out of 10000 .
# Iterating from 80 to 100 out of 10000 .
# Iterating from 100 to 120 out of 10000 .
# Iterating from 120 to 140 out of 10000 .
# Iterating from 140 to 160 out of 10000 .
# Iterating from 160 to 180 out of 10000 .
# Iterating from 180 to 200 out of 10000 .
# Iterating from 200 to 220 out of 10000 .
# Iterating from 220 to 240 out of 10000 .
# Iterating from 240 to 260 out of 10000 .
# Iterating from 260 to 280 out of 10000 .
# Iterating from 280 to 300 out of 10000 .
# Iterating from 300 to 320 out of 10000 .
# Iterating from 320 to 340 out of 10000 .
# Iterating from 340 to 360 out of 10000 .
# Iterating from 360 to 380 out of 10000 .
# Iterating from 380 to 400 out of 10000 .
# Iterating from 400 to 420 out of 10000 .
# Iterating from 420 to 440 out of 10000 .
# Iterating from 440 to 460 out of 10000 .
# Iterating from 460 to 480 out of 10000 .
# Iterating from 480 to 500 out of 10000 .
# Iterating from 500 to 520 out of 10000 .
# Iterating from 520 to 540 out of 10000 .
# Iterating from 540 to 560 out of 10000 .
# Iterating from 560 to 580 out of 10000 .
# Iterating from 580 to 600 out of 10000 .
# Iterating from 600 to 620 out of 10000 .
# Iterating from 620 to 640 out of 10000 .
# Iterating from 640 to 660 out of 10000 .
# Iterating from 660 to 680 out of 10000 .
# Iterating from 680 to 700 out of 10000 .
# Iterating from 700 to 720 out of 10000 .
# Iterating from 720 to 740 out of 10000 .
# Iterating from 740 to 760 out of 10000 .
# Iterating from 760 to 780 out of 10000 .
# Iterating from 780 to 800 out of 10000 .
# Iterating from 800 to 820 out of 10000 .
# Iterating from 820 to 840 out of 10000 .
# Iterating from 840 to 860 out of 10000 .
# Iterating from 860 to 880 out of 10000 .
# Iterating from 880 to 900 out of 10000 .
# Iterating from 900 to 920 out of 10000 .
# Iterating from 920 to 940 out of 10000 .
# Iterating from 940 to 960 out of 10000 .
# Iterating from 960 to 980 out of 10000 .
# Iterating from 980 to 1000 out of 10000 .
# Iterating from 1000 to 1020 out of 10000 .
# Iterating from 1020 to 1040 out of 10000 .
# Iterating from 1040 to 1060 out of 10000 .
# Iterating from 1060 to 1080 out of 10000 .
# Iterating from 1080 to 1100 out of 10000 .
# Iterating from 1100 to 1120 out of 10000 .
# Iterating from 1120 to 1140 out of 10000 .
# Iterating from 1140 to 1160 out of 10000 .
# Iterating from 1160 to 1180 out of 10000 .
# Iterating from 1180 to 1200 out of 10000 .
# Iterating from 1200 to 1220 out of 10000 .
# Iterating from 1220 to 1240 out of 10000 .
# Iterating from 1240 to 1260 out of 10000 .
# Iterating from 1260 to 1280 out of 10000 .
# Iterating from 1280 to 1300 out of 10000 .
# Iterating from 1300 to 1320 out of 10000 .
# Iterating from 1320 to 1340 out of 10000 .
# Iterating from 1340 to 1360 out of 10000 .
# Iterating from 1360 to 1380 out of 10000 .
# Iterating from 1380 to 1400 out of 10000 .
# Iterating from 1400 to 1420 out of 10000 .
# Iterating from 1420 to 1440 out of 10000 .
# Iterating from 1440 to 1460 out of 10000 .
# Iterating from 1460 to 1480 out of 10000 .
# Iterating from 1480 to 1500 out of 10000 .
# Iterating from 1500 to 1520 out of 10000 .
# Iterating from 1520 to 1540 out of 10000 .
# Iterating from 1540 to 1560 out of 10000 .
# Iterating from 1560 to 1580 out of 10000 .
# Iterating from 1580 to 1600 out of 10000 .
# Iterating from 1600 to 1620 out of 10000 .
# Iterating from 1620 to 1640 out of 10000 .
# Iterating from 1640 to 1660 out of 10000 .
# Iterating from 1660 to 1680 out of 10000 .
# Iterating from 1680 to 1700 out of 10000 .
# Iterating from 1700 to 1720 out of 10000 .
# Iterating from 1720 to 1740 out of 10000 .
# Iterating from 1740 to 1760 out of 10000 .
# Iterating from 1760 to 1780 out of 10000 .
# Iterating from 1780 to 1800 out of 10000 .
# Iterating from 1800 to 1820 out of 10000 .
# Iterating from 1820 to 1840 out of 10000 .
# Iterating from 1840 to 1860 out of 10000 .
# Iterating from 1860 to 1880 out of 10000 .
# Iterating from 1880 to 1900 out of 10000 .
# Iterating from 1900 to 1920 out of 10000 .
# Iterating from 1920 to 1940 out of 10000 .
# Iterating from 1940 to 1960 out of 10000 .
# Iterating from 1960 to 1980 out of 10000 .
# Iterating from 1980 to 2000 out of 10000 .
# Iterating from 2000 to 2020 out of 10000 .
# Iterating from 2020 to 2040 out of 10000 .
# Iterating from 2040 to 2060 out of 10000 .
# Iterating from 2060 to 2080 out of 10000 .
# Iterating from 2080 to 2100 out of 10000 .
# Iterating from 2100 to 2120 out of 10000 .
# Iterating from 2120 to 2140 out of 10000 .
# Iterating from 2140 to 2160 out of 10000 .
# Iterating from 2160 to 2180 out of 10000 .
# Iterating from 2180 to 2200 out of 10000 .
# Iterating from 2200 to 2220 out of 10000 .
# Iterating from 2220 to 2240 out of 10000 .
# Iterating from 2240 to 2260 out of 10000 .
# Iterating from 2260 to 2280 out of 10000 .
# Iterating from 2280 to 2300 out of 10000 .
# Iterating from 2300 to 2320 out of 10000 .
# Iterating from 2320 to 2340 out of 10000 .
# Iterating from 2340 to 2360 out of 10000 .
# Iterating from 2360 to 2380 out of 10000 .
# Iterating from 2380 to 2400 out of 10000 .
# Iterating from 2400 to 2420 out of 10000 .
# Iterating from 2420 to 2440 out of 10000 .
# Iterating from 2440 to 2460 out of 10000 .
# Iterating from 2460 to 2480 out of 10000 .
# Iterating from 2480 to 2500 out of 10000 .
# Iterating from 2500 to 2520 out of 10000 .
# Iterating from 2520 to 2540 out of 10000 .
# Iterating from 2540 to 2560 out of 10000 .
# Iterating from 2560 to 2580 out of 10000 .
# Iterating from 2580 to 2600 out of 10000 .
# Iterating from 2600 to 2620 out of 10000 .
# Iterating from 2620 to 2640 out of 10000 .
# Iterating from 2640 to 2660 out of 10000 .
# Iterating from 2660 to 2680 out of 10000 .
# Iterating from 2680 to 2700 out of 10000 .
# Iterating from 2700 to 2720 out of 10000 .
# Iterating from 2720 to 2740 out of 10000 .
# Iterating from 2740 to 2760 out of 10000 .
# Iterating from 2760 to 2780 out of 10000 .
# Iterating from 2780 to 2800 out of 10000 .
# Iterating from 2800 to 2820 out of 10000 .
# Iterating from 2820 to 2840 out of 10000 .
# Iterating from 2840 to 2860 out of 10000 .
# Iterating from 2860 to 2880 out of 10000 .
# Iterating from 2880 to 2900 out of 10000 .
# Iterating from 2900 to 2920 out of 10000 .
# Iterating from 2920 to 2940 out of 10000 .
# Iterating from 2940 to 2960 out of 10000 .
# Iterating from 2960 to 2980 out of 10000 .
# Iterating from 2980 to 3000 out of 10000 .
# Iterating from 3000 to 3020 out of 10000 .
# Iterating from 3020 to 3040 out of 10000 .
# Iterating from 3040 to 3060 out of 10000 .
# Iterating from 3060 to 3080 out of 10000 .
# Iterating from 3080 to 3100 out of 10000 .
# Iterating from 3100 to 3120 out of 10000 .
# Iterating from 3120 to 3140 out of 10000 .
# Iterating from 3140 to 3160 out of 10000 .
# Iterating from 3160 to 3180 out of 10000 .
# Iterating from 3180 to 3200 out of 10000 .
# Iterating from 3200 to 3220 out of 10000 .
# Iterating from 3220 to 3240 out of 10000 .
# Iterating from 3240 to 3260 out of 10000 .
# Iterating from 3260 to 3280 out of 10000 .
# Iterating from 3280 to 3300 out of 10000 .
# Iterating from 3300 to 3320 out of 10000 .
# Iterating from 3320 to 3340 out of 10000 .
# Iterating from 3340 to 3360 out of 10000 .
# Iterating from 3360 to 3380 out of 10000 .
# Iterating from 3380 to 3400 out of 10000 .
# Iterating from 3400 to 3420 out of 10000 .
# Iterating from 3420 to 3440 out of 10000 .
# Iterating from 3440 to 3460 out of 10000 .
# Iterating from 3460 to 3480 out of 10000 .
# Iterating from 3480 to 3500 out of 10000 .
# Iterating from 3500 to 3520 out of 10000 .
# Iterating from 3520 to 3540 out of 10000 .
# Iterating from 3540 to 3560 out of 10000 .
# Iterating from 3560 to 3580 out of 10000 .
# Iterating from 3580 to 3600 out of 10000 .
# Iterating from 3600 to 3620 out of 10000 .
# Iterating from 3620 to 3640 out of 10000 .
# Iterating from 3640 to 3660 out of 10000 .
# Iterating from 3660 to 3680 out of 10000 .
# Iterating from 3680 to 3700 out of 10000 .
# Iterating from 3700 to 3720 out of 10000 .
# Iterating from 3720 to 3740 out of 10000 .
# Iterating from 3740 to 3760 out of 10000 .
# Iterating from 3760 to 3780 out of 10000 .
# Iterating from 3780 to 3800 out of 10000 .
# Iterating from 3800 to 3820 out of 10000 .
# Iterating from 3820 to 3840 out of 10000 .
# Iterating from 3840 to 3860 out of 10000 .
# Iterating from 3860 to 3880 out of 10000 .
# Iterating from 3880 to 3900 out of 10000 .
# Iterating from 3900 to 3920 out of 10000 .
# Iterating from 3920 to 3940 out of 10000 .
# Iterating from 3940 to 3960 out of 10000 .
# Iterating from 3960 to 3980 out of 10000 .
# Iterating from 3980 to 4000 out of 10000 .
# Iterating from 4000 to 4020 out of 10000 .
# Iterating from 4020 to 4040 out of 10000 .
# Iterating from 4040 to 4060 out of 10000 .
# Iterating from 4060 to 4080 out of 10000 .
# Iterating from 4080 to 4100 out of 10000 .
# Iterating from 4100 to 4120 out of 10000 .
# Iterating from 4120 to 4140 out of 10000 .
# Iterating from 4140 to 4160 out of 10000 .
# Iterating from 4160 to 4180 out of 10000 .
# Iterating from 4180 to 4200 out of 10000 .
# Iterating from 4200 to 4220 out of 10000 .
# Iterating from 4220 to 4240 out of 10000 .
# Iterating from 4240 to 4260 out of 10000 .
# Iterating from 4260 to 4280 out of 10000 .
# Iterating from 4280 to 4300 out of 10000 .
# Iterating from 4300 to 4320 out of 10000 .
# Iterating from 4320 to 4340 out of 10000 .
# Iterating from 4340 to 4360 out of 10000 .
# Iterating from 4360 to 4380 out of 10000 .
# Iterating from 4380 to 4400 out of 10000 .
# Iterating from 4400 to 4420 out of 10000 .
# Iterating from 4420 to 4440 out of 10000 .
# Iterating from 4440 to 4460 out of 10000 .
# Iterating from 4460 to 4480 out of 10000 .
# Iterating from 4480 to 4500 out of 10000 .
# Iterating from 4500 to 4520 out of 10000 .
# Iterating from 4520 to 4540 out of 10000 .
# Iterating from 4540 to 4560 out of 10000 .
# Iterating from 4560 to 4580 out of 10000 .
# Iterating from 4580 to 4600 out of 10000 .
# Iterating from 4600 to 4620 out of 10000 .
# Iterating from 4620 to 4640 out of 10000 .
# Iterating from 4640 to 4660 out of 10000 .
# Iterating from 4660 to 4680 out of 10000 .
# Iterating from 4680 to 4700 out of 10000 .
# Iterating from 4700 to 4720 out of 10000 .
# Iterating from 4720 to 4740 out of 10000 .
# Iterating from 4740 to 4760 out of 10000 .
# Iterating from 4760 to 4780 out of 10000 .
# Iterating from 4780 to 4800 out of 10000 .
# Iterating from 4800 to 4820 out of 10000 .
# Iterating from 4820 to 4840 out of 10000 .
# Iterating from 4840 to 4860 out of 10000 .
# Iterating from 4860 to 4880 out of 10000 .
# Iterating from 4880 to 4900 out of 10000 .
# Iterating from 4900 to 4920 out of 10000 .
# Iterating from 4920 to 4940 out of 10000 .
# Iterating from 4940 to 4960 out of 10000 .
# Iterating from 4960 to 4980 out of 10000 .
# Iterating from 4980 to 5000 out of 10000 .
# Iterating from 5000 to 5020 out of 10000 .
# Iterating from 5020 to 5040 out of 10000 .
# Iterating from 5040 to 5060 out of 10000 .
# Iterating from 5060 to 5080 out of 10000 .
# Iterating from 5080 to 5100 out of 10000 .
# Iterating from 5100 to 5120 out of 10000 .
# Iterating from 5120 to 5140 out of 10000 .
# Iterating from 5140 to 5160 out of 10000 .
# Iterating from 5160 to 5180 out of 10000 .
# Iterating from 5180 to 5200 out of 10000 .
# Iterating from 5200 to 5220 out of 10000 .
# Iterating from 5220 to 5240 out of 10000 .
# Iterating from 5240 to 5260 out of 10000 .
# Iterating from 5260 to 5280 out of 10000 .
# Iterating from 5280 to 5300 out of 10000 .
# Iterating from 5300 to 5320 out of 10000 .
# Iterating from 5320 to 5340 out of 10000 .
# Iterating from 5340 to 5360 out of 10000 .
# Iterating from 5360 to 5380 out of 10000 .
# Iterating from 5380 to 5400 out of 10000 .
# Iterating from 5400 to 5420 out of 10000 .
# Iterating from 5420 to 5440 out of 10000 .
# Iterating from 5440 to 5460 out of 10000 .
# Iterating from 5460 to 5480 out of 10000 .
# Iterating from 5480 to 5500 out of 10000 .
# Iterating from 5500 to 5520 out of 10000 .
# Iterating from 5520 to 5540 out of 10000 .
# Iterating from 5540 to 5560 out of 10000 .
# Iterating from 5560 to 5580 out of 10000 .
# Iterating from 5580 to 5600 out of 10000 .
# Iterating from 5600 to 5620 out of 10000 .
# Iterating from 5620 to 5640 out of 10000 .
# Iterating from 5640 to 5660 out of 10000 .
# Iterating from 5660 to 5680 out of 10000 .
# Iterating from 5680 to 5700 out of 10000 .
# Iterating from 5700 to 5720 out of 10000 .
# Iterating from 5720 to 5740 out of 10000 .
# Iterating from 5740 to 5760 out of 10000 .
# Iterating from 5760 to 5780 out of 10000 .
# Iterating from 5780 to 5800 out of 10000 .
# Iterating from 5800 to 5820 out of 10000 .
# Iterating from 5820 to 5840 out of 10000 .
# Iterating from 5840 to 5860 out of 10000 .
# Iterating from 5860 to 5880 out of 10000 .
# Iterating from 5880 to 5900 out of 10000 .
# Iterating from 5900 to 5920 out of 10000 .
# Iterating from 5920 to 5940 out of 10000 .
# Iterating from 5940 to 5960 out of 10000 .
# Iterating from 5960 to 5980 out of 10000 .
# Iterating from 5980 to 6000 out of 10000 .
# Iterating from 6000 to 6020 out of 10000 .
# Iterating from 6020 to 6040 out of 10000 .
# Iterating from 6040 to 6060 out of 10000 .
# Iterating from 6060 to 6080 out of 10000 .
# Iterating from 6080 to 6100 out of 10000 .
# Iterating from 6100 to 6120 out of 10000 .
# Iterating from 6120 to 6140 out of 10000 .
# Iterating from 6140 to 6160 out of 10000 .
# Iterating from 6160 to 6180 out of 10000 .
# Iterating from 6180 to 6200 out of 10000 .
# Iterating from 6200 to 6220 out of 10000 .
# Iterating from 6220 to 6240 out of 10000 .
# Iterating from 6240 to 6260 out of 10000 .
# Iterating from 6260 to 6280 out of 10000 .
# Iterating from 6280 to 6300 out of 10000 .
# Iterating from 6300 to 6320 out of 10000 .
# Iterating from 6320 to 6340 out of 10000 .
# Iterating from 6340 to 6360 out of 10000 .
# Iterating from 6360 to 6380 out of 10000 .
# Iterating from 6380 to 6400 out of 10000 .
# Iterating from 6400 to 6420 out of 10000 .
# Iterating from 6420 to 6440 out of 10000 .
# Iterating from 6440 to 6460 out of 10000 .
# Iterating from 6460 to 6480 out of 10000 .
# Iterating from 6480 to 6500 out of 10000 .
# Iterating from 6500 to 6520 out of 10000 .
# Iterating from 6520 to 6540 out of 10000 .
# Iterating from 6540 to 6560 out of 10000 .
# Iterating from 6560 to 6580 out of 10000 .
# Iterating from 6580 to 6600 out of 10000 .
# Iterating from 6600 to 6620 out of 10000 .
# Iterating from 6620 to 6640 out of 10000 .
# Iterating from 6640 to 6660 out of 10000 .
# Iterating from 6660 to 6680 out of 10000 .
# Iterating from 6680 to 6700 out of 10000 .
# Iterating from 6700 to 6720 out of 10000 .
# Iterating from 6720 to 6740 out of 10000 .
# Iterating from 6740 to 6760 out of 10000 .
# Iterating from 6760 to 6780 out of 10000 .
# Iterating from 6780 to 6800 out of 10000 .
# Iterating from 6800 to 6820 out of 10000 .
# Iterating from 6820 to 6840 out of 10000 .
# Iterating from 6840 to 6860 out of 10000 .
# Iterating from 6860 to 6880 out of 10000 .
# Iterating from 6880 to 6900 out of 10000 .
# Iterating from 6900 to 6920 out of 10000 .
# Iterating from 6920 to 6940 out of 10000 .
# Iterating from 6940 to 6960 out of 10000 .
# Iterating from 6960 to 6980 out of 10000 .
# Iterating from 6980 to 7000 out of 10000 .
# Iterating from 7000 to 7020 out of 10000 .
# Iterating from 7020 to 7040 out of 10000 .
# Iterating from 7040 to 7060 out of 10000 .
# Iterating from 7060 to 7080 out of 10000 .
# Iterating from 7080 to 7100 out of 10000 .
# Iterating from 7100 to 7120 out of 10000 .
# Iterating from 7120 to 7140 out of 10000 .
# Iterating from 7140 to 7160 out of 10000 .
# Iterating from 7160 to 7180 out of 10000 .
# Iterating from 7180 to 7200 out of 10000 .
# Iterating from 7200 to 7220 out of 10000 .
# Iterating from 7220 to 7240 out of 10000 .
# Iterating from 7240 to 7260 out of 10000 .
# Iterating from 7260 to 7280 out of 10000 .
# Iterating from 7280 to 7300 out of 10000 .
# Iterating from 7300 to 7320 out of 10000 .
# Iterating from 7320 to 7340 out of 10000 .
# Iterating from 7340 to 7360 out of 10000 .
# Iterating from 7360 to 7380 out of 10000 .
# Iterating from 7380 to 7400 out of 10000 .
# Iterating from 7400 to 7420 out of 10000 .
# Iterating from 7420 to 7440 out of 10000 .
# Iterating from 7440 to 7460 out of 10000 .
# Iterating from 7460 to 7480 out of 10000 .
# Iterating from 7480 to 7500 out of 10000 .
# Iterating from 7500 to 7520 out of 10000 .
# Iterating from 7520 to 7540 out of 10000 .
# Iterating from 7540 to 7560 out of 10000 .
# Iterating from 7560 to 7580 out of 10000 .
# Iterating from 7580 to 7600 out of 10000 .
# Iterating from 7600 to 7620 out of 10000 .
# Iterating from 7620 to 7640 out of 10000 .
# Iterating from 7640 to 7660 out of 10000 .
# Iterating from 7660 to 7680 out of 10000 .
# Iterating from 7680 to 7700 out of 10000 .
# Iterating from 7700 to 7720 out of 10000 .
# Iterating from 7720 to 7740 out of 10000 .
# Iterating from 7740 to 7760 out of 10000 .
# Iterating from 7760 to 7780 out of 10000 .
# Iterating from 7780 to 7800 out of 10000 .
# Iterating from 7800 to 7820 out of 10000 .
# Iterating from 7820 to 7840 out of 10000 .
# Iterating from 7840 to 7860 out of 10000 .
# Iterating from 7860 to 7880 out of 10000 .
# Iterating from 7880 to 7900 out of 10000 .
# Iterating from 7900 to 7920 out of 10000 .
# Iterating from 7920 to 7940 out of 10000 .
# Iterating from 7940 to 7960 out of 10000 .
# Iterating from 7960 to 7980 out of 10000 .
# Iterating from 7980 to 8000 out of 10000 .
# Iterating from 8000 to 8020 out of 10000 .
# Iterating from 8020 to 8040 out of 10000 .
# Iterating from 8040 to 8060 out of 10000 .
# Iterating from 8060 to 8080 out of 10000 .
# Iterating from 8080 to 8100 out of 10000 .
# Iterating from 8100 to 8120 out of 10000 .
# Iterating from 8120 to 8140 out of 10000 .
# Iterating from 8140 to 8160 out of 10000 .
# Iterating from 8160 to 8180 out of 10000 .
# Iterating from 8180 to 8200 out of 10000 .
# Iterating from 8200 to 8220 out of 10000 .
# Iterating from 8220 to 8240 out of 10000 .
# Iterating from 8240 to 8260 out of 10000 .
# Iterating from 8260 to 8280 out of 10000 .
# Iterating from 8280 to 8300 out of 10000 .
# Iterating from 8300 to 8320 out of 10000 .
# Iterating from 8320 to 8340 out of 10000 .
# Iterating from 8340 to 8360 out of 10000 .
# Iterating from 8360 to 8380 out of 10000 .
# Iterating from 8380 to 8400 out of 10000 .
# Iterating from 8400 to 8420 out of 10000 .
# Iterating from 8420 to 8440 out of 10000 .
# Iterating from 8440 to 8460 out of 10000 .
# Iterating from 8460 to 8480 out of 10000 .
# Iterating from 8480 to 8500 out of 10000 .
# Iterating from 8500 to 8520 out of 10000 .
# Iterating from 8520 to 8540 out of 10000 .
# Iterating from 8540 to 8560 out of 10000 .
# Iterating from 8560 to 8580 out of 10000 .
# Iterating from 8580 to 8600 out of 10000 .
# Iterating from 8600 to 8620 out of 10000 .
# Iterating from 8620 to 8640 out of 10000 .
# Iterating from 8640 to 8660 out of 10000 .
# Iterating from 8660 to 8680 out of 10000 .
# Iterating from 8680 to 8700 out of 10000 .
# Iterating from 8700 to 8720 out of 10000 .
# Iterating from 8720 to 8740 out of 10000 .
# Iterating from 8740 to 8760 out of 10000 .
# Iterating from 8760 to 8780 out of 10000 .
# Iterating from 8780 to 8800 out of 10000 .
# Iterating from 8800 to 8820 out of 10000 .
# Iterating from 8820 to 8840 out of 10000 .
# Iterating from 8840 to 8860 out of 10000 .
# Iterating from 8860 to 8880 out of 10000 .
# Iterating from 8880 to 8900 out of 10000 .
# Iterating from 8900 to 8920 out of 10000 .
# Iterating from 8920 to 8940 out of 10000 .
# Iterating from 8940 to 8960 out of 10000 .
# Iterating from 8960 to 8980 out of 10000 .
# Iterating from 8980 to 9000 out of 10000 .
# Iterating from 9000 to 9020 out of 10000 .
# Iterating from 9020 to 9040 out of 10000 .
# Iterating from 9040 to 9060 out of 10000 .
# Iterating from 9060 to 9080 out of 10000 .
# Iterating from 9080 to 9100 out of 10000 .
# Iterating from 9100 to 9120 out of 10000 .
# Iterating from 9120 to 9140 out of 10000 .
# Iterating from 9140 to 9160 out of 10000 .
# Iterating from 9160 to 9180 out of 10000 .
# Iterating from 9180 to 9200 out of 10000 .
# Iterating from 9200 to 9220 out of 10000 .
# Iterating from 9220 to 9240 out of 10000 .
# Iterating from 9240 to 9260 out of 10000 .
# Iterating from 9260 to 9280 out of 10000 .
# Iterating from 9280 to 9300 out of 10000 .
# Iterating from 9300 to 9320 out of 10000 .
# Iterating from 9320 to 9340 out of 10000 .
# Iterating from 9340 to 9360 out of 10000 .
# Iterating from 9360 to 9380 out of 10000 .
# Iterating from 9380 to 9400 out of 10000 .
# Iterating from 9400 to 9420 out of 10000 .
# Iterating from 9420 to 9440 out of 10000 .
# Iterating from 9440 to 9460 out of 10000 .
# Iterating from 9460 to 9480 out of 10000 .
# Iterating from 9480 to 9500 out of 10000 .
# Iterating from 9500 to 9520 out of 10000 .
# Iterating from 9520 to 9540 out of 10000 .
# Iterating from 9540 to 9560 out of 10000 .
# Iterating from 9560 to 9580 out of 10000 .
# Iterating from 9580 to 9600 out of 10000 .
# Iterating from 9600 to 9620 out of 10000 .
# Iterating from 9620 to 9640 out of 10000 .
# Iterating from 9640 to 9660 out of 10000 .
# Iterating from 9660 to 9680 out of 10000 .
# Iterating from 9680 to 9700 out of 10000 .
# Iterating from 9700 to 9720 out of 10000 .
# Iterating from 9720 to 9740 out of 10000 .
# Iterating from 9740 to 9760 out of 10000 .
# Iterating from 9760 to 9780 out of 10000 .
# Iterating from 9780 to 9800 out of 10000 .
# Iterating from 9800 to 9820 out of 10000 .
# Iterating from 9820 to 9840 out of 10000 .
# Iterating from 9840 to 9860 out of 10000 .
# Iterating from 9860 to 9880 out of 10000 .
# Iterating from 9880 to 9900 out of 10000 .
# Iterating from 9900 to 9920 out of 10000 .
# Iterating from 9920 to 9940 out of 10000 .
# Iterating from 9940 to 9960 out of 10000 .
# Iterating from 9960 to 9980 out of 10000 .
# Iterating from 9980 to 10000 out of 10000 .
# LR metric calculation completed in 190.89964674698422 seconds.
# Saving lr to ../results/100D_20K/null_hypothesis/LR_both_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -37669.31534118292], [0.99, [9900, 100], -36927.02404609298]]
# Null distribution computed in 191.62108862103196 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 15.326400921971072 seconds.
# statistic = 366108.68984169455 - next threshold = -37669.31534118292 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.4587673496634825
#
# ------------ 2 ------------
# eps = 0.00125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 500
# Iterating from 0 to 20 out of 10000 .
# Iterating from 20 to 40 out of 10000 .
# Iterating from 40 to 60 out of 10000 .
# Iterating from 60 to 80 out of 10000 .
# Iterating from 80 to 100 out of 10000 .
# Iterating from 100 to 120 out of 10000 .
# Iterating from 120 to 140 out of 10000 .
# Iterating from 140 to 160 out of 10000 .
# Iterating from 160 to 180 out of 10000 .
# Iterating from 180 to 200 out of 10000 .
# Iterating from 200 to 220 out of 10000 .
# Iterating from 220 to 240 out of 10000 .
# Iterating from 240 to 260 out of 10000 .
# Iterating from 260 to 280 out of 10000 .
# Iterating from 280 to 300 out of 10000 .
# Iterating from 300 to 320 out of 10000 .
# Iterating from 320 to 340 out of 10000 .
# Iterating from 340 to 360 out of 10000 .
# Iterating from 360 to 380 out of 10000 .
# Iterating from 380 to 400 out of 10000 .
# Iterating from 400 to 420 out of 10000 .
# Iterating from 420 to 440 out of 10000 .
# Iterating from 440 to 460 out of 10000 .
# Iterating from 460 to 480 out of 10000 .
# Iterating from 480 to 500 out of 10000 .
# Iterating from 500 to 520 out of 10000 .
# Iterating from 520 to 540 out of 10000 .
# Iterating from 540 to 560 out of 10000 .
# Iterating from 560 to 580 out of 10000 .
# Iterating from 580 to 600 out of 10000 .
# Iterating from 600 to 620 out of 10000 .
# Iterating from 620 to 640 out of 10000 .
# Iterating from 640 to 660 out of 10000 .
# Iterating from 660 to 680 out of 10000 .
# Iterating from 680 to 700 out of 10000 .
# Iterating from 700 to 720 out of 10000 .
# Iterating from 720 to 740 out of 10000 .
# Iterating from 740 to 760 out of 10000 .
# Iterating from 760 to 780 out of 10000 .
# Iterating from 780 to 800 out of 10000 .
# Iterating from 800 to 820 out of 10000 .
# Iterating from 820 to 840 out of 10000 .
# Iterating from 840 to 860 out of 10000 .
# Iterating from 860 to 880 out of 10000 .
# Iterating from 880 to 900 out of 10000 .
# Iterating from 900 to 920 out of 10000 .
# Iterating from 920 to 940 out of 10000 .
# Iterating from 940 to 960 out of 10000 .
# Iterating from 960 to 980 out of 10000 .
# Iterating from 980 to 1000 out of 10000 .
# Iterating from 1000 to 1020 out of 10000 .
# Iterating from 1020 to 1040 out of 10000 .
# Iterating from 1040 to 1060 out of 10000 .
# Iterating from 1060 to 1080 out of 10000 .
# Iterating from 1080 to 1100 out of 10000 .
# Iterating from 1100 to 1120 out of 10000 .
# Iterating from 1120 to 1140 out of 10000 .
# Iterating from 1140 to 1160 out of 10000 .
# Iterating from 1160 to 1180 out of 10000 .
# Iterating from 1180 to 1200 out of 10000 .
# Iterating from 1200 to 1220 out of 10000 .
# Iterating from 1220 to 1240 out of 10000 .
# Iterating from 1240 to 1260 out of 10000 .
# Iterating from 1260 to 1280 out of 10000 .
# Iterating from 1280 to 1300 out of 10000 .
# Iterating from 1300 to 1320 out of 10000 .
# Iterating from 1320 to 1340 out of 10000 .
# Iterating from 1340 to 1360 out of 10000 .
# Iterating from 1360 to 1380 out of 10000 .
# Iterating from 1380 to 1400 out of 10000 .
# Iterating from 1400 to 1420 out of 10000 .
# Iterating from 1420 to 1440 out of 10000 .
# Iterating from 1440 to 1460 out of 10000 .
# Iterating from 1460 to 1480 out of 10000 .
# Iterating from 1480 to 1500 out of 10000 .
# Iterating from 1500 to 1520 out of 10000 .
# Iterating from 1520 to 1540 out of 10000 .
# Iterating from 1540 to 1560 out of 10000 .
# Iterating from 1560 to 1580 out of 10000 .
# Iterating from 1580 to 1600 out of 10000 .
# Iterating from 1600 to 1620 out of 10000 .
# Iterating from 1620 to 1640 out of 10000 .
# Iterating from 1640 to 1660 out of 10000 .
# Iterating from 1660 to 1680 out of 10000 .
# Iterating from 1680 to 1700 out of 10000 .
# Iterating from 1700 to 1720 out of 10000 .
# Iterating from 1720 to 1740 out of 10000 .
# Iterating from 1740 to 1760 out of 10000 .
# Iterating from 1760 to 1780 out of 10000 .
# Iterating from 1780 to 1800 out of 10000 .
# Iterating from 1800 to 1820 out of 10000 .
# Iterating from 1820 to 1840 out of 10000 .
# Iterating from 1840 to 1860 out of 10000 .
# Iterating from 1860 to 1880 out of 10000 .
# Iterating from 1880 to 1900 out of 10000 .
# Iterating from 1900 to 1920 out of 10000 .
# Iterating from 1920 to 1940 out of 10000 .
# Iterating from 1940 to 1960 out of 10000 .
# Iterating from 1960 to 1980 out of 10000 .
# Iterating from 1980 to 2000 out of 10000 .
# Iterating from 2000 to 2020 out of 10000 .
# Iterating from 2020 to 2040 out of 10000 .
# Iterating from 2040 to 2060 out of 10000 .
# Iterating from 2060 to 2080 out of 10000 .
# Iterating from 2080 to 2100 out of 10000 .
# Iterating from 2100 to 2120 out of 10000 .
# Iterating from 2120 to 2140 out of 10000 .
# Iterating from 2140 to 2160 out of 10000 .
# Iterating from 2160 to 2180 out of 10000 .
# Iterating from 2180 to 2200 out of 10000 .
# Iterating from 2200 to 2220 out of 10000 .
# Iterating from 2220 to 2240 out of 10000 .
# Iterating from 2240 to 2260 out of 10000 .
# Iterating from 2260 to 2280 out of 10000 .
# Iterating from 2280 to 2300 out of 10000 .
# Iterating from 2300 to 2320 out of 10000 .
# Iterating from 2320 to 2340 out of 10000 .
# Iterating from 2340 to 2360 out of 10000 .
# Iterating from 2360 to 2380 out of 10000 .
# Iterating from 2380 to 2400 out of 10000 .
# Iterating from 2400 to 2420 out of 10000 .
# Iterating from 2420 to 2440 out of 10000 .
# Iterating from 2440 to 2460 out of 10000 .
# Iterating from 2460 to 2480 out of 10000 .
# Iterating from 2480 to 2500 out of 10000 .
# Iterating from 2500 to 2520 out of 10000 .
# Iterating from 2520 to 2540 out of 10000 .
# Iterating from 2540 to 2560 out of 10000 .
# Iterating from 2560 to 2580 out of 10000 .
# Iterating from 2580 to 2600 out of 10000 .
# Iterating from 2600 to 2620 out of 10000 .
# Iterating from 2620 to 2640 out of 10000 .
# Iterating from 2640 to 2660 out of 10000 .
# Iterating from 2660 to 2680 out of 10000 .
# Iterating from 2680 to 2700 out of 10000 .
# Iterating from 2700 to 2720 out of 10000 .
# Iterating from 2720 to 2740 out of 10000 .
# Iterating from 2740 to 2760 out of 10000 .
# Iterating from 2760 to 2780 out of 10000 .
# Iterating from 2780 to 2800 out of 10000 .
# Iterating from 2800 to 2820 out of 10000 .
# Iterating from 2820 to 2840 out of 10000 .
# Iterating from 2840 to 2860 out of 10000 .
# Iterating from 2860 to 2880 out of 10000 .
# Iterating from 2880 to 2900 out of 10000 .
# Iterating from 2900 to 2920 out of 10000 .
# Iterating from 2920 to 2940 out of 10000 .
# Iterating from 2940 to 2960 out of 10000 .
# Iterating from 2960 to 2980 out of 10000 .
# Iterating from 2980 to 3000 out of 10000 .
# Iterating from 3000 to 3020 out of 10000 .
# Iterating from 3020 to 3040 out of 10000 .
# Iterating from 3040 to 3060 out of 10000 .
# Iterating from 3060 to 3080 out of 10000 .
# Iterating from 3080 to 3100 out of 10000 .
# Iterating from 3100 to 3120 out of 10000 .
# Iterating from 3120 to 3140 out of 10000 .
# Iterating from 3140 to 3160 out of 10000 .
# Iterating from 3160 to 3180 out of 10000 .
# Iterating from 3180 to 3200 out of 10000 .
# Iterating from 3200 to 3220 out of 10000 .
# Iterating from 3220 to 3240 out of 10000 .
# Iterating from 3240 to 3260 out of 10000 .
# Iterating from 3260 to 3280 out of 10000 .
# Iterating from 3280 to 3300 out of 10000 .
# Iterating from 3300 to 3320 out of 10000 .
# Iterating from 3320 to 3340 out of 10000 .
# Iterating from 3340 to 3360 out of 10000 .
# Iterating from 3360 to 3380 out of 10000 .
# Iterating from 3380 to 3400 out of 10000 .
# Iterating from 3400 to 3420 out of 10000 .
# Iterating from 3420 to 3440 out of 10000 .
# Iterating from 3440 to 3460 out of 10000 .
# Iterating from 3460 to 3480 out of 10000 .
# Iterating from 3480 to 3500 out of 10000 .
# Iterating from 3500 to 3520 out of 10000 .
# Iterating from 3520 to 3540 out of 10000 .
# Iterating from 3540 to 3560 out of 10000 .
# Iterating from 3560 to 3580 out of 10000 .
# Iterating from 3580 to 3600 out of 10000 .
# Iterating from 3600 to 3620 out of 10000 .
# Iterating from 3620 to 3640 out of 10000 .
# Iterating from 3640 to 3660 out of 10000 .
# Iterating from 3660 to 3680 out of 10000 .
# Iterating from 3680 to 3700 out of 10000 .
# Iterating from 3700 to 3720 out of 10000 .
# Iterating from 3720 to 3740 out of 10000 .
# Iterating from 3740 to 3760 out of 10000 .
# Iterating from 3760 to 3780 out of 10000 .
# Iterating from 3780 to 3800 out of 10000 .
# Iterating from 3800 to 3820 out of 10000 .
# Iterating from 3820 to 3840 out of 10000 .
# Iterating from 3840 to 3860 out of 10000 .
# Iterating from 3860 to 3880 out of 10000 .
# Iterating from 3880 to 3900 out of 10000 .
# Iterating from 3900 to 3920 out of 10000 .
# Iterating from 3920 to 3940 out of 10000 .
# Iterating from 3940 to 3960 out of 10000 .
# Iterating from 3960 to 3980 out of 10000 .
# Iterating from 3980 to 4000 out of 10000 .
# Iterating from 4000 to 4020 out of 10000 .
# Iterating from 4020 to 4040 out of 10000 .
# Iterating from 4040 to 4060 out of 10000 .
# Iterating from 4060 to 4080 out of 10000 .
# Iterating from 4080 to 4100 out of 10000 .
# Iterating from 4100 to 4120 out of 10000 .
# Iterating from 4120 to 4140 out of 10000 .
# Iterating from 4140 to 4160 out of 10000 .
# Iterating from 4160 to 4180 out of 10000 .
# Iterating from 4180 to 4200 out of 10000 .
# Iterating from 4200 to 4220 out of 10000 .
# Iterating from 4220 to 4240 out of 10000 .
# Iterating from 4240 to 4260 out of 10000 .
# Iterating from 4260 to 4280 out of 10000 .
# Iterating from 4280 to 4300 out of 10000 .
# Iterating from 4300 to 4320 out of 10000 .
# Iterating from 4320 to 4340 out of 10000 .
# Iterating from 4340 to 4360 out of 10000 .
# Iterating from 4360 to 4380 out of 10000 .
# Iterating from 4380 to 4400 out of 10000 .
# Iterating from 4400 to 4420 out of 10000 .
# Iterating from 4420 to 4440 out of 10000 .
# Iterating from 4440 to 4460 out of 10000 .
# Iterating from 4460 to 4480 out of 10000 .
# Iterating from 4480 to 4500 out of 10000 .
# Iterating from 4500 to 4520 out of 10000 .
# Iterating from 4520 to 4540 out of 10000 .
# Iterating from 4540 to 4560 out of 10000 .
# Iterating from 4560 to 4580 out of 10000 .
# Iterating from 4580 to 4600 out of 10000 .
# Iterating from 4600 to 4620 out of 10000 .
# Iterating from 4620 to 4640 out of 10000 .
# Iterating from 4640 to 4660 out of 10000 .
# Iterating from 4660 to 4680 out of 10000 .
# Iterating from 4680 to 4700 out of 10000 .
# Iterating from 4700 to 4720 out of 10000 .
# Iterating from 4720 to 4740 out of 10000 .
# Iterating from 4740 to 4760 out of 10000 .
# Iterating from 4760 to 4780 out of 10000 .
# Iterating from 4780 to 4800 out of 10000 .
# Iterating from 4800 to 4820 out of 10000 .
# Iterating from 4820 to 4840 out of 10000 .
# Iterating from 4840 to 4860 out of 10000 .
# Iterating from 4860 to 4880 out of 10000 .
# Iterating from 4880 to 4900 out of 10000 .
# Iterating from 4900 to 4920 out of 10000 .
# Iterating from 4920 to 4940 out of 10000 .
# Iterating from 4940 to 4960 out of 10000 .
# Iterating from 4960 to 4980 out of 10000 .
# Iterating from 4980 to 5000 out of 10000 .
# Iterating from 5000 to 5020 out of 10000 .
# Iterating from 5020 to 5040 out of 10000 .
# Iterating from 5040 to 5060 out of 10000 .
# Iterating from 5060 to 5080 out of 10000 .
# Iterating from 5080 to 5100 out of 10000 .
# Iterating from 5100 to 5120 out of 10000 .
# Iterating from 5120 to 5140 out of 10000 .
# Iterating from 5140 to 5160 out of 10000 .
# Iterating from 5160 to 5180 out of 10000 .
# Iterating from 5180 to 5200 out of 10000 .
# Iterating from 5200 to 5220 out of 10000 .
# Iterating from 5220 to 5240 out of 10000 .
# Iterating from 5240 to 5260 out of 10000 .
# Iterating from 5260 to 5280 out of 10000 .
# Iterating from 5280 to 5300 out of 10000 .
# Iterating from 5300 to 5320 out of 10000 .
# Iterating from 5320 to 5340 out of 10000 .
# Iterating from 5340 to 5360 out of 10000 .
# Iterating from 5360 to 5380 out of 10000 .
# Iterating from 5380 to 5400 out of 10000 .
# Iterating from 5400 to 5420 out of 10000 .
# Iterating from 5420 to 5440 out of 10000 .
# Iterating from 5440 to 5460 out of 10000 .
# Iterating from 5460 to 5480 out of 10000 .
# Iterating from 5480 to 5500 out of 10000 .
# Iterating from 5500 to 5520 out of 10000 .
# Iterating from 5520 to 5540 out of 10000 .
# Iterating from 5540 to 5560 out of 10000 .
# Iterating from 5560 to 5580 out of 10000 .
# Iterating from 5580 to 5600 out of 10000 .
# Iterating from 5600 to 5620 out of 10000 .
# Iterating from 5620 to 5640 out of 10000 .
# Iterating from 5640 to 5660 out of 10000 .
# Iterating from 5660 to 5680 out of 10000 .
# Iterating from 5680 to 5700 out of 10000 .
# Iterating from 5700 to 5720 out of 10000 .
# Iterating from 5720 to 5740 out of 10000 .
# Iterating from 5740 to 5760 out of 10000 .
# Iterating from 5760 to 5780 out of 10000 .
# Iterating from 5780 to 5800 out of 10000 .
# Iterating from 5800 to 5820 out of 10000 .
# Iterating from 5820 to 5840 out of 10000 .
# Iterating from 5840 to 5860 out of 10000 .
# Iterating from 5860 to 5880 out of 10000 .
# Iterating from 5880 to 5900 out of 10000 .
# Iterating from 5900 to 5920 out of 10000 .
# Iterating from 5920 to 5940 out of 10000 .
# Iterating from 5940 to 5960 out of 10000 .
# Iterating from 5960 to 5980 out of 10000 .
# Iterating from 5980 to 6000 out of 10000 .
# Iterating from 6000 to 6020 out of 10000 .
# Iterating from 6020 to 6040 out of 10000 .
# Iterating from 6040 to 6060 out of 10000 .
# Iterating from 6060 to 6080 out of 10000 .
# Iterating from 6080 to 6100 out of 10000 .
# Iterating from 6100 to 6120 out of 10000 .
# Iterating from 6120 to 6140 out of 10000 .
# Iterating from 6140 to 6160 out of 10000 .
# Iterating from 6160 to 6180 out of 10000 .
# Iterating from 6180 to 6200 out of 10000 .
# Iterating from 6200 to 6220 out of 10000 .
# Iterating from 6220 to 6240 out of 10000 .
# Iterating from 6240 to 6260 out of 10000 .
# Iterating from 6260 to 6280 out of 10000 .
# Iterating from 6280 to 6300 out of 10000 .
# Iterating from 6300 to 6320 out of 10000 .
# Iterating from 6320 to 6340 out of 10000 .
# Iterating from 6340 to 6360 out of 10000 .
# Iterating from 6360 to 6380 out of 10000 .
# Iterating from 6380 to 6400 out of 10000 .
# Iterating from 6400 to 6420 out of 10000 .
# Iterating from 6420 to 6440 out of 10000 .
# Iterating from 6440 to 6460 out of 10000 .
# Iterating from 6460 to 6480 out of 10000 .
# Iterating from 6480 to 6500 out of 10000 .
# Iterating from 6500 to 6520 out of 10000 .
# Iterating from 6520 to 6540 out of 10000 .
# Iterating from 6540 to 6560 out of 10000 .
# Iterating from 6560 to 6580 out of 10000 .
# Iterating from 6580 to 6600 out of 10000 .
# Iterating from 6600 to 6620 out of 10000 .
# Iterating from 6620 to 6640 out of 10000 .
# Iterating from 6640 to 6660 out of 10000 .
# Iterating from 6660 to 6680 out of 10000 .
# Iterating from 6680 to 6700 out of 10000 .
# Iterating from 6700 to 6720 out of 10000 .
# Iterating from 6720 to 6740 out of 10000 .
# Iterating from 6740 to 6760 out of 10000 .
# Iterating from 6760 to 6780 out of 10000 .
# Iterating from 6780 to 6800 out of 10000 .
# Iterating from 6800 to 6820 out of 10000 .
# Iterating from 6820 to 6840 out of 10000 .
# Iterating from 6840 to 6860 out of 10000 .
# Iterating from 6860 to 6880 out of 10000 .
# Iterating from 6880 to 6900 out of 10000 .
# Iterating from 6900 to 6920 out of 10000 .
# Iterating from 6920 to 6940 out of 10000 .
# Iterating from 6940 to 6960 out of 10000 .
# Iterating from 6960 to 6980 out of 10000 .
# Iterating from 6980 to 7000 out of 10000 .
# Iterating from 7000 to 7020 out of 10000 .
# Iterating from 7020 to 7040 out of 10000 .
# Iterating from 7040 to 7060 out of 10000 .
# Iterating from 7060 to 7080 out of 10000 .
# Iterating from 7080 to 7100 out of 10000 .
# Iterating from 7100 to 7120 out of 10000 .
# Iterating from 7120 to 7140 out of 10000 .
# Iterating from 7140 to 7160 out of 10000 .
# Iterating from 7160 to 7180 out of 10000 .
# Iterating from 7180 to 7200 out of 10000 .
# Iterating from 7200 to 7220 out of 10000 .
# Iterating from 7220 to 7240 out of 10000 .
# Iterating from 7240 to 7260 out of 10000 .
# Iterating from 7260 to 7280 out of 10000 .
# Iterating from 7280 to 7300 out of 10000 .
# Iterating from 7300 to 7320 out of 10000 .
# Iterating from 7320 to 7340 out of 10000 .
# Iterating from 7340 to 7360 out of 10000 .
# Iterating from 7360 to 7380 out of 10000 .
# Iterating from 7380 to 7400 out of 10000 .
# Iterating from 7400 to 7420 out of 10000 .
# Iterating from 7420 to 7440 out of 10000 .
# Iterating from 7440 to 7460 out of 10000 .
# Iterating from 7460 to 7480 out of 10000 .
# Iterating from 7480 to 7500 out of 10000 .
# Iterating from 7500 to 7520 out of 10000 .
# Iterating from 7520 to 7540 out of 10000 .
# Iterating from 7540 to 7560 out of 10000 .
# Iterating from 7560 to 7580 out of 10000 .
# Iterating from 7580 to 7600 out of 10000 .
# Iterating from 7600 to 7620 out of 10000 .
# Iterating from 7620 to 7640 out of 10000 .
# Iterating from 7640 to 7660 out of 10000 .
# Iterating from 7660 to 7680 out of 10000 .
# Iterating from 7680 to 7700 out of 10000 .
# Iterating from 7700 to 7720 out of 10000 .
# Iterating from 7720 to 7740 out of 10000 .
# Iterating from 7740 to 7760 out of 10000 .
# Iterating from 7760 to 7780 out of 10000 .
# Iterating from 7780 to 7800 out of 10000 .
# Iterating from 7800 to 7820 out of 10000 .
# Iterating from 7820 to 7840 out of 10000 .
# Iterating from 7840 to 7860 out of 10000 .
# Iterating from 7860 to 7880 out of 10000 .
# Iterating from 7880 to 7900 out of 10000 .
# Iterating from 7900 to 7920 out of 10000 .
# Iterating from 7920 to 7940 out of 10000 .
# Iterating from 7940 to 7960 out of 10000 .
# Iterating from 7960 to 7980 out of 10000 .
# Iterating from 7980 to 8000 out of 10000 .
# Iterating from 8000 to 8020 out of 10000 .
# Iterating from 8020 to 8040 out of 10000 .
# Iterating from 8040 to 8060 out of 10000 .
# Iterating from 8060 to 8080 out of 10000 .
# Iterating from 8080 to 8100 out of 10000 .
# Iterating from 8100 to 8120 out of 10000 .
# Iterating from 8120 to 8140 out of 10000 .
# Iterating from 8140 to 8160 out of 10000 .
# Iterating from 8160 to 8180 out of 10000 .
# Iterating from 8180 to 8200 out of 10000 .
# Iterating from 8200 to 8220 out of 10000 .
# Iterating from 8220 to 8240 out of 10000 .
# Iterating from 8240 to 8260 out of 10000 .
# Iterating from 8260 to 8280 out of 10000 .
# Iterating from 8280 to 8300 out of 10000 .
# Iterating from 8300 to 8320 out of 10000 .
# Iterating from 8320 to 8340 out of 10000 .
# Iterating from 8340 to 8360 out of 10000 .
# Iterating from 8360 to 8380 out of 10000 .
# Iterating from 8380 to 8400 out of 10000 .
# Iterating from 8400 to 8420 out of 10000 .
# Iterating from 8420 to 8440 out of 10000 .
# Iterating from 8440 to 8460 out of 10000 .
# Iterating from 8460 to 8480 out of 10000 .
# Iterating from 8480 to 8500 out of 10000 .
# Iterating from 8500 to 8520 out of 10000 .
# Iterating from 8520 to 8540 out of 10000 .
# Iterating from 8540 to 8560 out of 10000 .
# Iterating from 8560 to 8580 out of 10000 .
# Iterating from 8580 to 8600 out of 10000 .
# Iterating from 8600 to 8620 out of 10000 .
# Iterating from 8620 to 8640 out of 10000 .
# Iterating from 8640 to 8660 out of 10000 .
# Iterating from 8660 to 8680 out of 10000 .
# Iterating from 8680 to 8700 out of 10000 .
# Iterating from 8700 to 8720 out of 10000 .
# Iterating from 8720 to 8740 out of 10000 .
# Iterating from 8740 to 8760 out of 10000 .
# Iterating from 8760 to 8780 out of 10000 .
# Iterating from 8780 to 8800 out of 10000 .
# Iterating from 8800 to 8820 out of 10000 .
# Iterating from 8820 to 8840 out of 10000 .
# Iterating from 8840 to 8860 out of 10000 .
# Iterating from 8860 to 8880 out of 10000 .
# Iterating from 8880 to 8900 out of 10000 .
# Iterating from 8900 to 8920 out of 10000 .
# Iterating from 8920 to 8940 out of 10000 .
# Iterating from 8940 to 8960 out of 10000 .
# Iterating from 8960 to 8980 out of 10000 .
# Iterating from 8980 to 9000 out of 10000 .
# Iterating from 9000 to 9020 out of 10000 .
# Iterating from 9020 to 9040 out of 10000 .
# Iterating from 9040 to 9060 out of 10000 .
# Iterating from 9060 to 9080 out of 10000 .
# Iterating from 9080 to 9100 out of 10000 .
# Iterating from 9100 to 9120 out of 10000 .
# Iterating from 9120 to 9140 out of 10000 .
# Iterating from 9140 to 9160 out of 10000 .
# Iterating from 9160 to 9180 out of 10000 .
# Iterating from 9180 to 9200 out of 10000 .
# Iterating from 9200 to 9220 out of 10000 .
# Iterating from 9220 to 9240 out of 10000 .
# Iterating from 9240 to 9260 out of 10000 .
# Iterating from 9260 to 9280 out of 10000 .
# Iterating from 9280 to 9300 out of 10000 .
# Iterating from 9300 to 9320 out of 10000 .
# Iterating from 9320 to 9340 out of 10000 .
# Iterating from 9340 to 9360 out of 10000 .
# Iterating from 9360 to 9380 out of 10000 .
# Iterating from 9380 to 9400 out of 10000 .
# Iterating from 9400 to 9420 out of 10000 .
# Iterating from 9420 to 9440 out of 10000 .
# Iterating from 9440 to 9460 out of 10000 .
# Iterating from 9460 to 9480 out of 10000 .
# Iterating from 9480 to 9500 out of 10000 .
# Iterating from 9500 to 9520 out of 10000 .
# Iterating from 9520 to 9540 out of 10000 .
# Iterating from 9540 to 9560 out of 10000 .
# Iterating from 9560 to 9580 out of 10000 .
# Iterating from 9580 to 9600 out of 10000 .
# Iterating from 9600 to 9620 out of 10000 .
# Iterating from 9620 to 9640 out of 10000 .
# Iterating from 9640 to 9660 out of 10000 .
# Iterating from 9660 to 9680 out of 10000 .
# Iterating from 9680 to 9700 out of 10000 .
# Iterating from 9700 to 9720 out of 10000 .
# Iterating from 9720 to 9740 out of 10000 .
# Iterating from 9740 to 9760 out of 10000 .
# Iterating from 9760 to 9780 out of 10000 .
# Iterating from 9780 to 9800 out of 10000 .
# Iterating from 9800 to 9820 out of 10000 .
# Iterating from 9820 to 9840 out of 10000 .
# Iterating from 9840 to 9860 out of 10000 .
# Iterating from 9860 to 9880 out of 10000 .
# Iterating from 9880 to 9900 out of 10000 .
# Iterating from 9900 to 9920 out of 10000 .
# Iterating from 9920 to 9940 out of 10000 .
# Iterating from 9940 to 9960 out of 10000 .
# Iterating from 9960 to 9980 out of 10000 .
# Iterating from 9980 to 10000 out of 10000 .
# LR metric calculation completed in 180.89505719800945 seconds.
# Saving lr to ../results/100D_20K/null_hypothesis/LR_both_0.001250.json
# ThresholdS: [[0.95, [9500, 500], -28474.30550028127], [0.99, [9900, 100], -27873.974153609983]]
# Null distribution computed in 181.31953982403502 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 15.072013361030258 seconds.
# statistic = 88532.15212816329 - next threshold = -28474.30550028127 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 3.8964586377335744
#
# ------------ 3 ------------
# eps = 0.000625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 500
# Iterating from 0 to 20 out of 10000 .
# Iterating from 20 to 40 out of 10000 .
# Iterating from 40 to 60 out of 10000 .
# Iterating from 60 to 80 out of 10000 .
# Iterating from 80 to 100 out of 10000 .
# Iterating from 100 to 120 out of 10000 .
# Iterating from 120 to 140 out of 10000 .
# Iterating from 140 to 160 out of 10000 .
# Iterating from 160 to 180 out of 10000 .
# Iterating from 180 to 200 out of 10000 .
# Iterating from 200 to 220 out of 10000 .
# Iterating from 220 to 240 out of 10000 .
# Iterating from 240 to 260 out of 10000 .
# Iterating from 260 to 280 out of 10000 .
# Iterating from 280 to 300 out of 10000 .
# Iterating from 300 to 320 out of 10000 .
# Iterating from 320 to 340 out of 10000 .
# Iterating from 340 to 360 out of 10000 .
# Iterating from 360 to 380 out of 10000 .
# Iterating from 380 to 400 out of 10000 .
# Iterating from 400 to 420 out of 10000 .
# Iterating from 420 to 440 out of 10000 .
# Iterating from 440 to 460 out of 10000 .
# Iterating from 460 to 480 out of 10000 .
# Iterating from 480 to 500 out of 10000 .
# Iterating from 500 to 520 out of 10000 .
# Iterating from 520 to 540 out of 10000 .
# ...
# Iterating from 3480 to 3500 out of 10000 .
# Iterating from 3500 to 3520 out of 10000 .
# Iterating from 3520 to 3540 out of 10000 .
# Iterating from 3540 to 3560 out of 10000 .
# Iterating from 3560 to 3580 out of 10000 .
# Iterating from 3580 to 3600 out of 10000 .
# Iterating from 3600 to 3620 out of 10000 .
# Iterating from 3620 to 3640 out of 10000 .
# Iterating from 3640 to 3660 out of 10000 .
# Iterating from 3660 to 3680 out of 10000 .
# Iterating from 3680 to 3700 out of 10000 .
# Iterating from 3700 to 3720 out of 10000 .
# Iterating from 3720 to 3740 out of 10000 .
# Iterating from 3740 to 3760 out of 10000 .
# Iterating from 3760 to 3780 out of 10000 .
# Iterating from 3780 to 3800 out of 10000 .
# Iterating from 3800 to 3820 out of 10000 .
# Iterating from 3820 to 3840 out of 10000 .
# Iterating from 3840 to 3860 out of 10000 .
# Iterating from 3860 to 3880 out of 10000 .
# Iterating from 3880 to 3900 out of 10000 .
# Iterating from 3900 to 3920 out of 10000 .
# Iterating from 3920 to 3940 out of 10000 .
# Iterating from 3940 to 3960 out of 10000 .
# Iterating from 3960 to 3980 out of 10000 .
# Iterating from 3980 to 4000 out of 10000 .
# Iterating from 4000 to 4020 out of 10000 .
# Iterating from 4020 to 4040 out of 10000 .
# Iterating from 4040 to 4060 out of 10000 .
# Iterating from 4060 to 4080 out of 10000 .
# Iterating from 4080 to 4100 out of 10000 .
# Iterating from 4100 to 4120 out of 10000 .
# Iterating from 4120 to 4140 out of 10000 .
# Iterating from 4140 to 4160 out of 10000 .
# Iterating from 4160 to 4180 out of 10000 .
# Iterating from 4180 to 4200 out of 10000 .
# Iterating from 4200 to 4220 out of 10000 .
# Iterating from 4220 to 4240 out of 10000 .
# Iterating from 4240 to 4260 out of 10000 .
# Iterating from 4260 to 4280 out of 10000 .
# Iterating from 4280 to 4300 out of 10000 .
# Iterating from 4300 to 4320 out of 10000 .
# Iterating from 4320 to 4340 out of 10000 .
# Iterating from 4340 to 4360 out of 10000 .
# Iterating from 4360 to 4380 out of 10000 .
# Iterating from 4380 to 4400 out of 10000 .
# Iterating from 4400 to 4420 out of 10000 .
# Iterating from 4420 to 4440 out of 10000 .
# Iterating from 4440 to 4460 out of 10000 .
# Iterating from 4460 to 4480 out of 10000 .
# Iterating from 4480 to 4500 out of 10000 .
# Iterating from 4500 to 4520 out of 10000 .
# Iterating from 4520 to 4540 out of 10000 .
# Iterating from 4540 to 4560 out of 10000 .
# Iterating from 4560 to 4580 out of 10000 .
# Iterating from 4580 to 4600 out of 10000 .
# Iterating from 4600 to 4620 out of 10000 .
# Iterating from 4620 to 4640 out of 10000 .
# Iterating from 4640 to 4660 out of 10000 .
# Iterating from 4660 to 4680 out of 10000 .
# Iterating from 4680 to 4700 out of 10000 .
# Iterating from 4700 to 4720 out of 10000 .
# Iterating from 4720 to 4740 out of 10000 .
# Iterating from 4740 to 4760 out of 10000 .
# Iterating from 4760 to 4780 out of 10000 .
# Iterating from 4780 to 4800 out of 10000 .
# Iterating from 4800 to 4820 out of 10000 .
# Iterating from 4820 to 4840 out of 10000 .
# Iterating from 4840 to 4860 out of 10000 .
# Iterating from 4860 to 4880 out of 10000 .
# Iterating from 4880 to 4900 out of 10000 .
# Iterating from 4900 to 4920 out of 10000 .
# Iterating from 4920 to 4940 out of 10000 .
# Iterating from 4940 to 4960 out of 10000 .
# Iterating from 4960 to 4980 out of 10000 .
# Iterating from 4980 to 5000 out of 10000 .
# Iterating from 5000 to 5020 out of 10000 .
# Iterating from 5020 to 5040 out of 10000 .
# Iterating from 5040 to 5060 out of 10000 .
# Iterating from 5060 to 5080 out of 10000 .
# Iterating from 5080 to 5100 out of 10000 .
# Iterating from 5100 to 5120 out of 10000 .
# Iterating from 5120 to 5140 out of 10000 .
# Iterating from 5140 to 5160 out of 10000 .
# Iterating from 5160 to 5180 out of 10000 .
# Iterating from 5180 to 5200 out of 10000 .
# Iterating from 5200 to 5220 out of 10000 .
# Iterating from 5220 to 5240 out of 10000 .
# Iterating from 5240 to 5260 out of 10000 .
# Iterating from 5260 to 5280 out of 10000 .
# Iterating from 5280 to 5300 out of 10000 .
# Iterating from 5300 to 5320 out of 10000 .
# Iterating from 5320 to 5340 out of 10000 .
# Iterating from 5340 to 5360 out of 10000 .
# Iterating from 5360 to 5380 out of 10000 .
# Iterating from 5380 to 5400 out of 10000 .
# Iterating from 5400 to 5420 out of 10000 .
# Iterating from 5420 to 5440 out of 10000 .
# Iterating from 5440 to 5460 out of 10000 .
# Iterating from 5460 to 5480 out of 10000 .
# Iterating from 5480 to 5500 out of 10000 .
# Iterating from 5500 to 5520 out of 10000 .
# Iterating from 5520 to 5540 out of 10000 .
# Iterating from 5540 to 5560 out of 10000 .
# Iterating from 5560 to 5580 out of 10000 .
# Iterating from 5580 to 5600 out of 10000 .
# Iterating from 5600 to 5620 out of 10000 .
# Iterating from 5620 to 5640 out of 10000 .
# Iterating from 5640 to 5660 out of 10000 .
# Iterating from 5660 to 5680 out of 10000 .
# Iterating from 5680 to 5700 out of 10000 .
# Iterating from 5700 to 5720 out of 10000 .
# Iterating from 5720 to 5740 out of 10000 .
# Iterating from 5740 to 5760 out of 10000 .
# Iterating from 5760 to 5780 out of 10000 .
# Iterating from 5780 to 5800 out of 10000 .
# Iterating from 5800 to 5820 out of 10000 .
# Iterating from 5820 to 5840 out of 10000 .
# Iterating from 5840 to 5860 out of 10000 .
# Iterating from 5860 to 5880 out of 10000 .
# Iterating from 5880 to 5900 out of 10000 .
# Iterating from 5900 to 5920 out of 10000 .
# Iterating from 5920 to 5940 out of 10000 .
# Iterating from 5940 to 5960 out of 10000 .
# Iterating from 5960 to 5980 out of 10000 .
# Iterating from 5980 to 6000 out of 10000 .
# Iterating from 6000 to 6020 out of 10000 .
# Iterating from 6020 to 6040 out of 10000 .
# Iterating from 6040 to 6060 out of 10000 .
# Iterating from 6060 to 6080 out of 10000 .
# Iterating from 6080 to 6100 out of 10000 .
# Iterating from 6100 to 6120 out of 10000 .
# Iterating from 6120 to 6140 out of 10000 .
# Iterating from 6140 to 6160 out of 10000 .
# Iterating from 6160 to 6180 out of 10000 .
# Iterating from 6180 to 6200 out of 10000 .
# Iterating from 6200 to 6220 out of 10000 .
# Iterating from 6220 to 6240 out of 10000 .
# Iterating from 6240 to 6260 out of 10000 .
# Iterating from 6260 to 6280 out of 10000 .
# Iterating from 6280 to 6300 out of 10000 .
# Iterating from 6300 to 6320 out of 10000 .
# Iterating from 6320 to 6340 out of 10000 .
# Iterating from 6340 to 6360 out of 10000 .
# Iterating from 6360 to 6380 out of 10000 .
# Iterating from 6380 to 6400 out of 10000 .
# Iterating from 6400 to 6420 out of 10000 .
# Iterating from 6420 to 6440 out of 10000 .
# Iterating from 6440 to 6460 out of 10000 .
# Iterating from 6460 to 6480 out of 10000 .
# Iterating from 6480 to 6500 out of 10000 .
# Iterating from 6500 to 6520 out of 10000 .
# Iterating from 6520 to 6540 out of 10000 .
# Iterating from 6540 to 6560 out of 10000 .
# Iterating from 6560 to 6580 out of 10000 .
# Iterating from 6580 to 6600 out of 10000 .
# Iterating from 6600 to 6620 out of 10000 .
# Iterating from 6620 to 6640 out of 10000 .
# Iterating from 6640 to 6660 out of 10000 .
# Iterating from 6660 to 6680 out of 10000 .
# Iterating from 6680 to 6700 out of 10000 .
# Iterating from 6700 to 6720 out of 10000 .
# Iterating from 6720 to 6740 out of 10000 .
# Iterating from 6740 to 6760 out of 10000 .
# Iterating from 6760 to 6780 out of 10000 .
# Iterating from 6780 to 6800 out of 10000 .
# Iterating from 6800 to 6820 out of 10000 .
# Iterating from 6820 to 6840 out of 10000 .
# Iterating from 6840 to 6860 out of 10000 .
# Iterating from 6860 to 6880 out of 10000 .
# Iterating from 6880 to 6900 out of 10000 .
# Iterating from 6900 to 6920 out of 10000 .
# Iterating from 6920 to 6940 out of 10000 .
# Iterating from 6940 to 6960 out of 10000 .
# Iterating from 6960 to 6980 out of 10000 .
# Iterating from 6980 to 7000 out of 10000 .
# Iterating from 7000 to 7020 out of 10000 .
# Iterating from 7020 to 7040 out of 10000 .
# Iterating from 7040 to 7060 out of 10000 .
# Iterating from 7060 to 7080 out of 10000 .
# Iterating from 7080 to 7100 out of 10000 .
# Iterating from 7100 to 7120 out of 10000 .
# Iterating from 7120 to 7140 out of 10000 .
# Iterating from 7140 to 7160 out of 10000 .
# Iterating from 7160 to 7180 out of 10000 .
# Iterating from 7180 to 7200 out of 10000 .
# Iterating from 7200 to 7220 out of 10000 .
# Iterating from 7220 to 7240 out of 10000 .
# Iterating from 7240 to 7260 out of 10000 .
# Iterating from 7260 to 7280 out of 10000 .
# Iterating from 7280 to 7300 out of 10000 .
# Iterating from 7300 to 7320 out of 10000 .
# Iterating from 7320 to 7340 out of 10000 .
# Iterating from 7340 to 7360 out of 10000 .
# Iterating from 7360 to 7380 out of 10000 .
# Iterating from 7380 to 7400 out of 10000 .
# Iterating from 7400 to 7420 out of 10000 .
# Iterating from 7420 to 7440 out of 10000 .
# Iterating from 7440 to 7460 out of 10000 .
# Iterating from 7460 to 7480 out of 10000 .
# Iterating from 7480 to 7500 out of 10000 .
# Iterating from 7500 to 7520 out of 10000 .
# Iterating from 7520 to 7540 out of 10000 .
# Iterating from 7540 to 7560 out of 10000 .
# Iterating from 7560 to 7580 out of 10000 .
# Iterating from 7580 to 7600 out of 10000 .
# Iterating from 7600 to 7620 out of 10000 .
# Iterating from 7620 to 7640 out of 10000 .
# Iterating from 7640 to 7660 out of 10000 .
# Iterating from 7660 to 7680 out of 10000 .
# Iterating from 7680 to 7700 out of 10000 .
# Iterating from 7700 to 7720 out of 10000 .
# Iterating from 7720 to 7740 out of 10000 .
# Iterating from 7740 to 7760 out of 10000 .
# Iterating from 7760 to 7780 out of 10000 .
# Iterating from 7780 to 7800 out of 10000 .
# Iterating from 7800 to 7820 out of 10000 .
# Iterating from 7820 to 7840 out of 10000 .
# Iterating from 7840 to 7860 out of 10000 .
# Iterating from 7860 to 7880 out of 10000 .
# Iterating from 7880 to 7900 out of 10000 .
# Iterating from 7900 to 7920 out of 10000 .
# Iterating from 7920 to 7940 out of 10000 .
# Iterating from 7940 to 7960 out of 10000 .
# Iterating from 7960 to 7980 out of 10000 .
# Iterating from 7980 to 8000 out of 10000 .
# Iterating from 8000 to 8020 out of 10000 .
# Iterating from 8020 to 8040 out of 10000 .
# Iterating from 8040 to 8060 out of 10000 .
# Iterating from 8060 to 8080 out of 10000 .
# Iterating from 8080 to 8100 out of 10000 .
# Iterating from 8100 to 8120 out of 10000 .
# Iterating from 8120 to 8140 out of 10000 .
# Iterating from 8140 to 8160 out of 10000 .
# Iterating from 8160 to 8180 out of 10000 .
# Iterating from 8180 to 8200 out of 10000 .
# Iterating from 8200 to 8220 out of 10000 .
# Iterating from 8220 to 8240 out of 10000 .
# Iterating from 8240 to 8260 out of 10000 .
# Iterating from 8260 to 8280 out of 10000 .
# Iterating from 8280 to 8300 out of 10000 .
# Iterating from 8300 to 8320 out of 10000 .
# Iterating from 8320 to 8340 out of 10000 .
# Iterating from 8340 to 8360 out of 10000 .
# Iterating from 8360 to 8380 out of 10000 .
# Iterating from 8380 to 8400 out of 10000 .
# Iterating from 8400 to 8420 out of 10000 .
# Iterating from 8420 to 8440 out of 10000 .
# Iterating from 8440 to 8460 out of 10000 .
# Iterating from 8460 to 8480 out of 10000 .
# Iterating from 8480 to 8500 out of 10000 .
# Iterating from 8500 to 8520 out of 10000 .
# Iterating from 8520 to 8540 out of 10000 .
# Iterating from 8540 to 8560 out of 10000 .
# Iterating from 8560 to 8580 out of 10000 .
# Iterating from 8580 to 8600 out of 10000 .
# Iterating from 8600 to 8620 out of 10000 .
# Iterating from 8620 to 8640 out of 10000 .
# Iterating from 8640 to 8660 out of 10000 .
# Iterating from 8660 to 8680 out of 10000 .
# Iterating from 8680 to 8700 out of 10000 .
# Iterating from 8700 to 8720 out of 10000 .
# Iterating from 8720 to 8740 out of 10000 .
# Iterating from 8740 to 8760 out of 10000 .
# Iterating from 8760 to 8780 out of 10000 .
# Iterating from 8780 to 8800 out of 10000 .
# Iterating from 8800 to 8820 out of 10000 .
# Iterating from 8820 to 8840 out of 10000 .
# Iterating from 8840 to 8860 out of 10000 .
# Iterating from 8860 to 8880 out of 10000 .
# Iterating from 8880 to 8900 out of 10000 .
# Iterating from 8900 to 8920 out of 10000 .
# Iterating from 8920 to 8940 out of 10000 .
# Iterating from 8940 to 8960 out of 10000 .
# Iterating from 8960 to 8980 out of 10000 .
# Iterating from 8980 to 9000 out of 10000 .
# Iterating from 9000 to 9020 out of 10000 .
# Iterating from 9020 to 9040 out of 10000 .
# Iterating from 9040 to 9060 out of 10000 .
# Iterating from 9060 to 9080 out of 10000 .
# Iterating from 9080 to 9100 out of 10000 .
# Iterating from 9100 to 9120 out of 10000 .
# Iterating from 9120 to 9140 out of 10000 .
# Iterating from 9140 to 9160 out of 10000 .
# Iterating from 9160 to 9180 out of 10000 .
# Iterating from 9180 to 9200 out of 10000 .
# Iterating from 9200 to 9220 out of 10000 .
# Iterating from 9220 to 9240 out of 10000 .
# Iterating from 9240 to 9260 out of 10000 .
# Iterating from 9260 to 9280 out of 10000 .
# Iterating from 9280 to 9300 out of 10000 .
# Iterating from 9300 to 9320 out of 10000 .
# Iterating from 9320 to 9340 out of 10000 .
# Iterating from 9340 to 9360 out of 10000 .
# Iterating from 9360 to 9380 out of 10000 .
# Iterating from 9380 to 9400 out of 10000 .
# Iterating from 9400 to 9420 out of 10000 .
# Iterating from 9420 to 9440 out of 10000 .
# Iterating from 9440 to 9460 out of 10000 .
# Iterating from 9460 to 9480 out of 10000 .
# Iterating from 9480 to 9500 out of 10000 .
# Iterating from 9500 to 9520 out of 10000 .
# Iterating from 9520 to 9540 out of 10000 .
# Iterating from 9540 to 9560 out of 10000 .
# Iterating from 9560 to 9580 out of 10000 .
# Iterating from 9580 to 9600 out of 10000 .
# Iterating from 9600 to 9620 out of 10000 .
# Iterating from 9620 to 9640 out of 10000 .
# Iterating from 9640 to 9660 out of 10000 .
# Iterating from 9660 to 9680 out of 10000 .
# Iterating from 9680 to 9700 out of 10000 .
# Iterating from 9700 to 9720 out of 10000 .
# Iterating from 9720 to 9740 out of 10000 .
# Iterating from 9740 to 9760 out of 10000 .
# Iterating from 9760 to 9780 out of 10000 .
# Iterating from 9780 to 9800 out of 10000 .
# Iterating from 9800 to 9820 out of 10000 .
# Iterating from 9820 to 9840 out of 10000 .
# Iterating from 9840 to 9860 out of 10000 .
# Iterating from 9860 to 9880 out of 10000 .
# Iterating from 9880 to 9900 out of 10000 .
# Iterating from 9900 to 9920 out of 10000 .
# Iterating from 9920 to 9940 out of 10000 .
# Iterating from 9940 to 9960 out of 10000 .
# Iterating from 9960 to 9980 out of 10000 .
# Iterating from 9980 to 10000 out of 10000 .
# LR metric calculation completed in 184.87606910197064 seconds.
# Saving lr to ../results/100D_20K/null_hypothesis/LR_both_0.000008.json
# ThresholdS: [[0.95, [9500, 500], 1.4151279787520261], [0.99, [9900, 100], 3.96154304093624]]
# Null distribution computed in 185.3863124809577 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.243638982006814 seconds.
# statistic = 3.983706404063948 - next threshold = 3.96154304093624 at 0.99 CL
# relative_error_eps = 0.009061902533660016
# relative_error_metric = 0.005579022604923969
# =======> statistic within required accuracy at 0.99 CL in 3431.4869082079967 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 6872.793694077001 seconds.
# Saving results in the file ../results/100D_20K/exclusion_limits.json
# dict_keys(['2024-04-12T05:42:55.372272', '2024-04-12T05:49:51.980996', '2024-04-12T05:54:48.432679', '2024-04-12T06:01:16.705141', '2024-04-12T06:10:33.841812', '2024-04-12T06:18:47.660824', '2024-04-12T06:28:13.176086', '2024-04-12T06:38:00.286379', '2024-04-12T06:43:29.264308', '2024-04-12T06:52:55.471331', '2024-04-12T07:02:40.013732', '2024-04-12T07:12:14.083457', '2024-04-12T07:22:44.432936', '2024-04-12T07:36:17.417489', '2024-04-12T07:46:55.855578', '2024-04-12T08:00:14.886500', '2024-04-12T08:10:08.280177', '2024-04-12T08:18:17.364163', '2024-04-12T08:28:38.052124', '2024-04-12T10:29:52.969177', '2024-04-12T14:41:04.366059'])
