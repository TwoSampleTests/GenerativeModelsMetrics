# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/100D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-02 19:16:24.281617: Importing os...
# 2024-05-02 19:16:24.281735: Importing sys...
# Visible devices: [1]
# 2024-05-02 19:16:24.281967: Importing timer from timeit...
# 2024-05-02 19:16:24.282034: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-05-02 19:16:24.282159: Importing numpy...
# 2024-05-02 19:16:24.384023: Importing matplotlib...
# 2024-05-02 19:16:24.735372: Importing h5py...
# 2024-05-02 19:16:24.766235: Importing importlib.util...
# 2024-05-02 19:16:24.766340: Importing json...
# 2024-05-02 19:16:24.766405: Importing pandas...
# 2024-05-02 19:16:25.206431: Importing random...
# 2024-05-02 19:16:25.206579: Importing scipy utils...
# 2024-05-02 19:16:25.600189: Importing subprocess...
# 2024-05-02 19:16:25.600313: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-02 19:16:29.149979: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-02 19:16:30.219664: Importing timeit...
# 2024-05-02 19:16:30.219759: Importing tqdm...
# 2024-05-02 19:16:30.227711: Importing typing...
# 2024-05-02 19:16:30.227821: Setting tf configs...
# 2024-05-02 19:16:30.317017: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-02 19:16:35.116333: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-02 19:16:35.146293: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 10
ndims = 100
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (100,) (100,)
# sample from dist_1:  tf.Tensor(
# [[  1.91544564  -2.76561943  -3.43238751   7.63969004   0.40053677
#    -1.53371952   5.40518506  -2.46227562  -6.61238919   0.11070361
#    -2.43762175   7.60029826   5.00623137  -0.80830675  -0.86605178
#    -3.75058169  -0.69380601  -5.33493967   5.27270148  -5.77781631
#     1.12998499  -4.47808311  -0.44031361  -2.594015    -2.44992317
#     1.56227034  -1.8473778   -5.48289763  -5.48753345   1.93092494
#     1.79804844   1.37683738  -5.50962657  -4.87417033  -0.72193383
#    -5.10550792   4.48638515 -10.64465497  -2.19470468   6.38369957
#    -1.69169541   1.54297027   5.89350422   2.06708108  -0.90056118
#    -4.52907036  -5.69635496   1.55048682   6.4208089   -7.28610231
#    -5.08435585  -3.3389148    5.70948589   8.2946287   -5.84409661
#    -3.41249172   0.17450962   2.34921217   2.76600152  -1.35626994
#     4.67985208   3.74505089  -1.53903479  -0.9632767    7.66386021
#    -6.44508355   7.20013913   6.46012388   7.95496576  -1.07239111
#     2.63046089  -1.89127358   0.33629951   0.08755734  -4.28856395
#     1.78142513  -1.78334129   3.21504492  -1.34998805  -3.46388964
#    -4.46767048  -3.0690922    4.10920542  -1.12462778   0.43631843
#    -3.45204044   8.14946355  -3.75325945  -3.65654744  -9.30852399
#    -0.23871862   0.24312011  -6.63856444  -1.3104451   -2.44773711
#    -6.17225405  -2.40174311  -4.69520006   3.0814107    0.60472495]
#  [ -1.92269202  -4.08394393   0.28484768  -0.46825721   1.55903162
#     8.68423884   0.1292585   -3.09593241  -3.92592339  -0.78352017
#    -4.50758392   1.57655743  -2.79706173  -6.67679694  -3.89510347
#    -0.67142402  -2.3331029   -4.65618365   6.25135925   2.17635361
#     0.02229862  -5.25625134  -2.13850902  -4.05479007  -3.57251666
#     2.04591286  -0.14158755  -1.07676659   1.27568216   0.48903681
#    -1.65055387   3.28812542  -5.22640853  -0.92624111  -2.08771499
#    -3.93104846   2.93525398  -4.66540103  -1.34764653  -0.10523317
#    -1.50393875   4.51796248   4.56419684   0.78592104   1.87166036
#    -4.43561494  -5.41652595  -2.73506816   1.76755216  -5.15925416
#    -4.3965557   -5.11767262  -0.32448409   3.31767934  -3.42011481
#     0.12151845   1.33857006  -1.59406799  -1.52287611   5.92251815
#     0.35865444   2.59290903  -6.12798207  -6.88506817   6.79410239
#    -4.32117031   6.36315359   0.14532651   3.96861049  -2.69664263
#     4.07705442  -6.06308564   3.31986369   1.93834979  -1.93673443
#    -3.60680136   3.69535118   3.06222825  -0.16709543  -2.17638917
#     2.96497292  -0.41208625   7.46657337  -1.19022553  -4.69285676
#    -3.57289518   3.99034323  -0.81382891  -0.80077353  -2.56404593
#    -0.40735411   4.1613677   -2.13420216   3.955205     0.10965705
#    -0.3132572   -1.46848024  -6.0741503    2.39560734  -1.95077145]], shape=(2, 100), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[  1.91544564  -2.76561943  -3.43238751   7.63969004   0.40053677
#    -1.53371952   5.40518506  -2.46227562  -6.61238919   0.11070361
#    -2.43762175   7.60029826   5.00623137  -0.80830675  -0.86605178
#    -3.75058169  -0.69380601  -5.33493967   5.27270148  -5.77781631
#     1.12998499  -4.47808311  -0.44031361  -2.594015    -2.44992317
#     1.56227034  -1.8473778   -5.48289763  -5.48753345   1.93092494
#     1.79804844   1.37683738  -5.50962657  -4.87417033  -0.72193383
#    -5.10550792   4.48638515 -10.64465497  -2.19470468   6.38369957
#    -1.69169541   1.54297027   5.89350422   2.06708108  -0.90056118
#    -4.52907036  -5.69635496   1.55048682   6.4208089   -7.28610231
#    -5.08435585  -3.3389148    5.70948589   8.2946287   -5.84409661
#    -3.41249172   0.17450962   2.34921217   2.76600152  -1.35626994
#     4.67985208   3.74505089  -1.53903479  -0.9632767    7.66386021
#    -6.44508355   7.20013913   6.46012388   7.95496576  -1.07239111
#     2.63046089  -1.89127358   0.33629951   0.08755734  -4.28856395
#     1.78142513  -1.78334129   3.21504492  -1.34998805  -3.46388964
#    -4.46767048  -3.0690922    4.10920542  -1.12462778   0.43631843
#    -3.45204044   8.14946355  -3.75325945  -3.65654744  -9.30852399
#    -0.23871862   0.24312011  -6.63856444  -1.3104451   -2.44773711
#    -6.17225405  -2.40174311  -4.69520006   3.0814107    0.60472495]
#  [ -1.92269202  -4.08394393   0.28484768  -0.46825721   1.55903162
#     8.68423884   0.1292585   -3.09593241  -3.92592339  -0.78352017
#    -4.50758392   1.57655743  -2.79706173  -6.67679694  -3.89510347
#    -0.67142402  -2.3331029   -4.65618365   6.25135925   2.17635361
#     0.02229862  -5.25625134  -2.13850902  -4.05479007  -3.57251666
#     2.04591286  -0.14158755  -1.07676659   1.27568216   0.48903681
#    -1.65055387   3.28812542  -5.22640853  -0.92624111  -2.08771499
#    -3.93104846   2.93525398  -4.66540103  -1.34764653  -0.10523317
#    -1.50393875   4.51796248   4.56419684   0.78592104   1.87166036
#    -4.43561494  -5.41652595  -2.73506816   1.76755216  -5.15925416
#    -4.3965557   -5.11767262  -0.32448409   3.31767934  -3.42011481
#     0.12151845   1.33857006  -1.59406799  -1.52287611   5.92251815
#     0.35865444   2.59290903  -6.12798207  -6.88506817   6.79410239
#    -4.32117031   6.36315359   0.14532651   3.96861049  -2.69664263
#     4.07705442  -6.06308564   3.31986369   1.93834979  -1.93673443
#    -3.60680136   3.69535118   3.06222825  -0.16709543  -2.17638917
#     2.96497292  -0.41208625   7.46657337  -1.19022553  -4.69285676
#    -3.57289518   3.99034323  -0.81382891  -0.80077353  -2.56404593
#    -0.40735411   4.1613677   -2.13420216   3.955205     0.10965705
#    -0.3132572   -1.46848024  -6.0741503    2.39560734  -1.95077145]], shape=(2, 100), dtype=float64)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory was created
# Null hypothesis directory was created

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...      100           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True      100           0  float64   100  200000000         False
#
#    ncomp
# 0     10
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 2,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 10000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 100
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714670201.002384  962056 service.cc:145] XLA service 0x10e2d6e70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714670201.002810  962056 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1714670204.256794  962056 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# FGD metric calculation completed in 7488.625817649066 seconds.
# Saving fgd to results/100D_unimodal/100D_20K/null_hypothesis/FGD.json
# Computing and savng mmd with max_vectorize = 2
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 5000
# Iterating from 0 to 2 out of 10000 .
# Iterating from 2 to 4 out of 10000 .
# Iterating from 4 to 6 out of 10000 .
# Iterating from 6 to 8 out of 10000 .
# Iterating from 8 to 10 out of 10000 .
# Iterating from 10 to 12 out of 10000 .
# Iterating from 12 to 14 out of 10000 .
# Iterating from 14 to 16 out of 10000 .
# Iterating from 16 to 18 out of 10000 .
# Iterating from 18 to 20 out of 10000 .
# Iterating from 20 to 22 out of 10000 .
# Iterating from 22 to 24 out of 10000 .
# Iterating from 24 to 26 out of 10000 .
# Iterating from 26 to 28 out of 10000 .
# Iterating from 28 to 30 out of 10000 .
# Iterating from 30 to 32 out of 10000 .
# Iterating from 32 to 34 out of 10000 .
# Iterating from 34 to 36 out of 10000 .
# Iterating from 36 to 38 out of 10000 .
# Iterating from 38 to 40 out of 10000 .
# Iterating from 40 to 42 out of 10000 .
# Iterating from 42 to 44 out of 10000 .
# Iterating from 44 to 46 out of 10000 .
# Iterating from 46 to 48 out of 10000 .
# Iterating from 48 to 50 out of 10000 .
# Iterating from 50 to 52 out of 10000 .
# Iterating from 52 to 54 out of 10000 .
# Iterating from 54 to 56 out of 10000 .
# Iterating from 56 to 58 out of 10000 .
# Iterating from 58 to 60 out of 10000 .
# Iterating from 60 to 62 out of 10000 .
# Iterating from 62 to 64 out of 10000 .
# Iterating from 64 to 66 out of 10000 .
# Iterating from 66 to 68 out of 10000 .
# Iterating from 68 to 70 out of 10000 .
# Iterating from 70 to 72 out of 10000 .
# Iterating from 72 to 74 out of 10000 .
# Iterating from 74 to 76 out of 10000 .
# Iterating from 76 to 78 out of 10000 .
# Iterating from 78 to 80 out of 10000 .
# Iterating from 80 to 82 out of 10000 .
# Iterating from 82 to 84 out of 10000 .
# Iterating from 84 to 86 out of 10000 .
# Iterating from 86 to 88 out of 10000 .
# Iterating from 88 to 90 out of 10000 .
# Iterating from 90 to 92 out of 10000 .
# Iterating from 92 to 94 out of 10000 .
# Iterating from 94 to 96 out of 10000 .
# Iterating from 96 to 98 out of 10000 .
# Iterating from 98 to 100 out of 10000 .
# Iterating from 100 to 102 out of 10000 .
# Iterating from 102 to 104 out of 10000 .
# Iterating from 104 to 106 out of 10000 .
# Iterating from 106 to 108 out of 10000 .
# Iterating from 108 to 110 out of 10000 .
# Iterating from 110 to 112 out of 10000 .
# Iterating from 112 to 114 out of 10000 .
# Iterating from 114 to 116 out of 10000 .
# Iterating from 116 to 118 out of 10000 .
# Iterating from 118 to 120 out of 10000 .
# Iterating from 120 to 122 out of 10000 .
# Iterating from 122 to 124 out of 10000 .
# Iterating from 124 to 126 out of 10000 .
# Iterating from 126 to 128 out of 10000 .
# Iterating from 128 to 130 out of 10000 .
# Iterating from 130 to 132 out of 10000 .
# Iterating from 132 to 134 out of 10000 .
# Iterating from 134 to 136 out of 10000 .
# Iterating from 136 to 138 out of 10000 .
# Iterating from 138 to 140 out of 10000 .
# Iterating from 140 to 142 out of 10000 .
# Iterating from 142 to 144 out of 10000 .
# Iterating from 144 to 146 out of 10000 .
# Iterating from 146 to 148 out of 10000 .
# Iterating from 148 to 150 out of 10000 .
# Iterating from 150 to 152 out of 10000 .
# Iterating from 152 to 154 out of 10000 .
# Iterating from 154 to 156 out of 10000 .
# Iterating from 156 to 158 out of 10000 .
# Iterating from 158 to 160 out of 10000 .
# Iterating from 160 to 162 out of 10000 .
# Iterating from 162 to 164 out of 10000 .
# Iterating from 164 to 166 out of 10000 .
# Iterating from 166 to 168 out of 10000 .
# Iterating from 168 to 170 out of 10000 .
# Iterating from 170 to 172 out of 10000 .
# Iterating from 172 to 174 out of 10000 .
# Iterating from 174 to 176 out of 10000 .
# Iterating from 176 to 178 out of 10000 .
# Iterating from 178 to 180 out of 10000 .
# Iterating from 180 to 182 out of 10000 .
# Iterating from 182 to 184 out of 10000 .
# Iterating from 184 to 186 out of 10000 .
# Iterating from 186 to 188 out of 10000 .
# Iterating from 188 to 190 out of 10000 .
# Iterating from 190 to 192 out of 10000 .
# Iterating from 192 to 194 out of 10000 .
# Iterating from 194 to 196 out of 10000 .
# Iterating from 196 to 198 out of 10000 .
# Iterating from 198 to 200 out of 10000 .
# Iterating from 200 to 202 out of 10000 .
# Iterating from 202 to 204 out of 10000 .
# Iterating from 204 to 206 out of 10000 .
# Iterating from 206 to 208 out of 10000 .
# Iterating from 208 to 210 out of 10000 .
# Iterating from 210 to 212 out of 10000 .
# Iterating from 212 to 214 out of 10000 .
# Iterating from 214 to 216 out of 10000 .
# Iterating from 216 to 218 out of 10000 .
# Iterating from 218 to 220 out of 10000 .
# Iterating from 220 to 222 out of 10000 .
# Iterating from 222 to 224 out of 10000 .
# Iterating from 224 to 226 out of 10000 .
# Iterating from 226 to 228 out of 10000 .
# Iterating from 228 to 230 out of 10000 .
# Iterating from 230 to 232 out of 10000 .
# Iterating from 232 to 234 out of 10000 .
# Iterating from 234 to 236 out of 10000 .
# Iterating from 236 to 238 out of 10000 .
# Iterating from 238 to 240 out of 10000 .
# Iterating from 240 to 242 out of 10000 .
# Iterating from 242 to 244 out of 10000 .
# Iterating from 244 to 246 out of 10000 .
# Iterating from 246 to 248 out of 10000 .
# Iterating from 248 to 250 out of 10000 .
# Iterating from 250 to 252 out of 10000 .
# Iterating from 252 to 254 out of 10000 .
# Iterating from 254 to 256 out of 10000 .
# Iterating from 256 to 258 out of 10000 .
# Iterating from 258 to 260 out of 10000 .
# Iterating from 260 to 262 out of 10000 .
# Iterating from 262 to 264 out of 10000 .
# Iterating from 264 to 266 out of 10000 .
# Iterating from 266 to 268 out of 10000 .
# Iterating from 268 to 270 out of 10000 .
# Iterating from 270 to 272 out of 10000 .
# Iterating from 272 to 274 out of 10000 .
# Iterating from 274 to 276 out of 10000 .
# Iterating from 276 to 278 out of 10000 .
# Iterating from 278 to 280 out of 10000 .
# Iterating from 280 to 282 out of 10000 .
# Iterating from 282 to 284 out of 10000 .
# Iterating from 284 to 286 out of 10000 .
# Iterating from 286 to 288 out of 10000 .
# Iterating from 288 to 290 out of 10000 .
# Iterating from 290 to 292 out of 10000 .
# Iterating from 292 to 294 out of 10000 .
# Iterating from 294 to 296 out of 10000 .
# Iterating from 296 to 298 out of 10000 .
# Iterating from 298 to 300 out of 10000 .
# Iterating from 300 to 302 out of 10000 .
# Iterating from 302 to 304 out of 10000 .
# Iterating from 304 to 306 out of 10000 .
# Iterating from 306 to 308 out of 10000 .
# Iterating from 308 to 310 out of 10000 .
# Iterating from 310 to 312 out of 10000 .
# Iterating from 312 to 314 out of 10000 .
# Iterating from 314 to 316 out of 10000 .
# Iterating from 316 to 318 out of 10000 .
# Iterating from 318 to 320 out of 10000 .
# Iterating from 320 to 322 out of 10000 .
# Iterating from 322 to 324 out of 10000 .
# Iterating from 324 to 326 out of 10000 .
# Iterating from 326 to 328 out of 10000 .
# Iterating from 328 to 330 out of 10000 .
# Iterating from 330 to 332 out of 10000 .
# Iterating from 332 to 334 out of 10000 .
# Iterating from 334 to 336 out of 10000 .
# Iterating from 336 to 338 out of 10000 .
# Iterating from 338 to 340 out of 10000 .
# Iterating from 340 to 342 out of 10000 .
# Iterating from 342 to 344 out of 10000 .
# Iterating from 344 to 346 out of 10000 .
# Iterating from 346 to 348 out of 10000 .
# Iterating from 348 to 350 out of 10000 .
# Iterating from 350 to 352 out of 10000 .
# Iterating from 352 to 354 out of 10000 .
# Iterating from 354 to 356 out of 10000 .
# Iterating from 356 to 358 out of 10000 .
# Iterating from 358 to 360 out of 10000 .
# Iterating from 360 to 362 out of 10000 .
# Iterating from 362 to 364 out of 10000 .
# Iterating from 364 to 366 out of 10000 .
# Iterating from 366 to 368 out of 10000 .
# Iterating from 368 to 370 out of 10000 .
# Iterating from 370 to 372 out of 10000 .
# Iterating from 372 to 374 out of 10000 .
# Iterating from 374 to 376 out of 10000 .
# Iterating from 376 to 378 out of 10000 .
# Iterating from 378 to 380 out of 10000 .
# Iterating from 380 to 382 out of 10000 .
# Iterating from 382 to 384 out of 10000 .
# Iterating from 384 to 386 out of 10000 .
# Iterating from 386 to 388 out of 10000 .
# Iterating from 388 to 390 out of 10000 .
# Iterating from 390 to 392 out of 10000 .
# Iterating from 392 to 394 out of 10000 .
# Iterating from 394 to 396 out of 10000 .
# Iterating from 396 to 398 out of 10000 .
# Iterating from 398 to 400 out of 10000 .
# Iterating from 400 to 402 out of 10000 .
# Iterating from 402 to 404 out of 10000 .
# Iterating from 404 to 406 out of 10000 .
# Iterating from 406 to 408 out of 10000 .
# Iterating from 408 to 410 out of 10000 .
# Iterating from 410 to 412 out of 10000 .
# Iterating from 412 to 414 out of 10000 .
# Iterating from 414 to 416 out of 10000 .
# Iterating from 416 to 418 out of 10000 .
# Iterating from 418 to 420 out of 10000 .
# Iterating from 420 to 422 out of 10000 .
# Iterating from 422 to 424 out of 10000 .
# Iterating from 424 to 426 out of 10000 .
# Iterating from 426 to 428 out of 10000 .
# Iterating from 428 to 430 out of 10000 .
# Iterating from 430 to 432 out of 10000 .
# Iterating from 432 to 434 out of 10000 .
# Iterating from 434 to 436 out of 10000 .
# Iterating from 436 to 438 out of 10000 .
# Iterating from 438 to 440 out of 10000 .
# Iterating from 440 to 442 out of 10000 .
# Iterating from 442 to 444 out of 10000 .
# Iterating from 444 to 446 out of 10000 .
# Iterating from 446 to 448 out of 10000 .
# Iterating from 448 to 450 out of 10000 .
# Iterating from 450 to 452 out of 10000 .
# Iterating from 452 to 454 out of 10000 .
# Iterating from 454 to 456 out of 10000 .
# Iterating from 456 to 458 out of 10000 .
# Iterating from 458 to 460 out of 10000 .
# Iterating from 460 to 462 out of 10000 .
# Iterating from 462 to 464 out of 10000 .
# Iterating from 464 to 466 out of 10000 .
# Iterating from 466 to 468 out of 10000 .
# Iterating from 468 to 470 out of 10000 .
# Iterating from 470 to 472 out of 10000 .
# Iterating from 472 to 474 out of 10000 .
# Iterating from 474 to 476 out of 10000 .
# Iterating from 476 to 478 out of 10000 .
# Iterating from 478 to 480 out of 10000 .
# Iterating from 480 to 482 out of 10000 .
# Iterating from 482 to 484 out of 10000 .
# Iterating from 484 to 486 out of 10000 .
# Iterating from 486 to 488 out of 10000 .
# Iterating from 488 to 490 out of 10000 .
# Iterating from 490 to 492 out of 10000 .
# Iterating from 492 to 494 out of 10000 .
# Iterating from 494 to 496 out of 10000 .
# Iterating from 496 to 498 out of 10000 .
# Iterating from 498 to 500 out of 10000 .
# Iterating from 500 to 502 out of 10000 .
# Iterating from 502 to 504 out of 10000 .
# Iterating from 504 to 506 out of 10000 .
# Iterating from 506 to 508 out of 10000 .
# Iterating from 508 to 510 out of 10000 .
# Iterating from 510 to 512 out of 10000 .
# Iterating from 512 to 514 out of 10000 .
# Iterating from 514 to 516 out of 10000 .
# Iterating from 516 to 518 out of 10000 .
# Iterating from 518 to 520 out of 10000 .
# Iterating from 520 to 522 out of 10000 .
# Iterating from 522 to 524 out of 10000 .
# Iterating from 524 to 526 out of 10000 .
# Iterating from 526 to 528 out of 10000 .
# Iterating from 528 to 530 out of 10000 .
# Iterating from 530 to 532 out of 10000 .
# Iterating from 532 to 534 out of 10000 .
# Iterating from 534 to 536 out of 10000 .
# Iterating from 536 to 538 out of 10000 .
# Iterating from 538 to 540 out of 10000 .
# Iterating from 540 to 542 out of 10000 .
# Iterating from 542 to 544 out of 10000 .
# Iterating from 544 to 546 out of 10000 .
# Iterating from 546 to 548 out of 10000 .
# Iterating from 548 to 550 out of 10000 .
# Iterating from 550 to 552 out of 10000 .
# Iterating from 552 to 554 out of 10000 .
# Iterating from 554 to 556 out of 10000 .
# Iterating from 556 to 558 out of 10000 .
# Iterating from 558 to 560 out of 10000 .
# Iterating from 560 to 562 out of 10000 .
# Iterating from 562 to 564 out of 10000 .
# Iterating from 564 to 566 out of 10000 .
# Iterating from 566 to 568 out of 10000 .
# Iterating from 568 to 570 out of 10000 .
# Iterating from 570 to 572 out of 10000 .
# Iterating from 572 to 574 out of 10000 .
# Iterating from 574 to 576 out of 10000 .
# Iterating from 576 to 578 out of 10000 .
# Iterating from 578 to 580 out of 10000 .
# Iterating from 580 to 582 out of 10000 .
# Iterating from 582 to 584 out of 10000 .
# Iterating from 584 to 586 out of 10000 .
# Iterating from 586 to 588 out of 10000 .
# Iterating from 588 to 590 out of 10000 .
# Iterating from 590 to 592 out of 10000 .
# Iterating from 592 to 594 out of 10000 .
# Iterating from 594 to 596 out of 10000 .
# Iterating from 596 to 598 out of 10000 .
# Iterating from 598 to 600 out of 10000 .
# Iterating from 600 to 602 out of 10000 .
# Iterating from 602 to 604 out of 10000 .
# Iterating from 604 to 606 out of 10000 .
# Iterating from 606 to 608 out of 10000 .
# Iterating from 608 to 610 out of 10000 .
# Iterating from 610 to 612 out of 10000 .
# Iterating from 612 to 614 out of 10000 .
# Iterating from 614 to 616 out of 10000 .
# Iterating from 616 to 618 out of 10000 .
# Iterating from 618 to 620 out of 10000 .
# Iterating from 620 to 622 out of 10000 .
# Iterating from 622 to 624 out of 10000 .
# Iterating from 624 to 626 out of 10000 .
# Iterating from 626 to 628 out of 10000 .
# Iterating from 628 to 630 out of 10000 .
# Iterating from 630 to 632 out of 10000 .
# Iterating from 632 to 634 out of 10000 .
# Iterating from 634 to 636 out of 10000 .
# Iterating from 636 to 638 out of 10000 .
# Iterating from 638 to 640 out of 10000 .
# Iterating from 640 to 642 out of 10000 .
# Iterating from 642 to 644 out of 10000 .
# Iterating from 644 to 646 out of 10000 .
# Iterating from 646 to 648 out of 10000 .
# Iterating from 648 to 650 out of 10000 .
# Iterating from 650 to 652 out of 10000 .
# Iterating from 652 to 654 out of 10000 .
# Iterating from 654 to 656 out of 10000 .
# Iterating from 656 to 658 out of 10000 .
# Iterating from 658 to 660 out of 10000 .
# Iterating from 660 to 662 out of 10000 .
# Iterating from 662 to 664 out of 10000 .
# Iterating from 664 to 666 out of 10000 .
# Iterating from 666 to 668 out of 10000 .
# Iterating from 668 to 670 out of 10000 .
# Iterating from 670 to 672 out of 10000 .
# Iterating from 672 to 674 out of 10000 .
# Iterating from 674 to 676 out of 10000 .
# Iterating from 676 to 678 out of 10000 .
# Iterating from 678 to 680 out of 10000 .
# Iterating from 680 to 682 out of 10000 .
# Iterating from 682 to 684 out of 10000 .
# Iterating from 684 to 686 out of 10000 .
# Iterating from 686 to 688 out of 10000 .
# Iterating from 688 to 690 out of 10000 .
# Iterating from 690 to 692 out of 10000 .
# Iterating from 692 to 694 out of 10000 .
# Iterating from 694 to 696 out of 10000 .
# Iterating from 696 to 698 out of 10000 .
# Iterating from 698 to 700 out of 10000 .
# Iterating from 700 to 702 out of 10000 .
# Iterating from 702 to 704 out of 10000 .
# Iterating from 704 to 706 out of 10000 .
# Iterating from 706 to 708 out of 10000 .
# Iterating from 708 to 710 out of 10000 .
# Iterating from 710 to 712 out of 10000 .
# Iterating from 712 to 714 out of 10000 .
# Iterating from 714 to 716 out of 10000 .
# Iterating from 716 to 718 out of 10000 .
# Iterating from 718 to 720 out of 10000 .
# Iterating from 720 to 722 out of 10000 .
# Iterating from 722 to 724 out of 10000 .
# Iterating from 724 to 726 out of 10000 .
# Iterating from 726 to 728 out of 10000 .
# Iterating from 728 to 730 out of 10000 .
# Iterating from 730 to 732 out of 10000 .
# Iterating from 732 to 734 out of 10000 .
# Iterating from 734 to 736 out of 10000 .
# Iterating from 736 to 738 out of 10000 .
# Iterating from 738 to 740 out of 10000 .
# Iterating from 740 to 742 out of 10000 .
# Iterating from 742 to 744 out of 10000 .
# Iterating from 744 to 746 out of 10000 .
# Iterating from 746 to 748 out of 10000 .
# Iterating from 748 to 750 out of 10000 .
# Iterating from 750 to 752 out of 10000 .
# Iterating from 752 to 754 out of 10000 .
# Iterating from 754 to 756 out of 10000 .
# Iterating from 756 to 758 out of 10000 .
# Iterating from 758 to 760 out of 10000 .
# Iterating from 760 to 762 out of 10000 .
# Iterating from 762 to 764 out of 10000 .
# Iterating from 764 to 766 out of 10000 .
# Iterating from 766 to 768 out of 10000 .
# Iterating from 768 to 770 out of 10000 .
# Iterating from 770 to 772 out of 10000 .
# Iterating from 772 to 774 out of 10000 .
# Iterating from 774 to 776 out of 10000 .
# Iterating from 776 to 778 out of 10000 .
# Iterating from 778 to 780 out of 10000 .
# Iterating from 780 to 782 out of 10000 .
# Iterating from 782 to 784 out of 10000 .
# Iterating from 784 to 786 out of 10000 .
# Iterating from 786 to 788 out of 10000 .
# Iterating from 788 to 790 out of 10000 .
# Iterating from 790 to 792 out of 10000 .
# Iterating from 792 to 794 out of 10000 .
# Iterating from 794 to 796 out of 10000 .
# Iterating from 796 to 798 out of 10000 .
# Iterating from 798 to 800 out of 10000 .
# Iterating from 800 to 802 out of 10000 .
# Iterating from 802 to 804 out of 10000 .
# Iterating from 804 to 806 out of 10000 .
# Iterating from 806 to 808 out of 10000 .
# Iterating from 808 to 810 out of 10000 .
# Iterating from 810 to 812 out of 10000 .
# Iterating from 812 to 814 out of 10000 .
# Iterating from 814 to 816 out of 10000 .
# Iterating from 816 to 818 out of 10000 .
# Iterating from 818 to 820 out of 10000 .
# Iterating from 820 to 822 out of 10000 .
# Iterating from 822 to 824 out of 10000 .
# Iterating from 824 to 826 out of 10000 .
# Iterating from 826 to 828 out of 10000 .
# Iterating from 828 to 830 out of 10000 .
# Iterating from 830 to 832 out of 10000 .
# Iterating from 832 to 834 out of 10000 .
# Iterating from 834 to 836 out of 10000 .
# Iterating from 836 to 838 out of 10000 .
# Iterating from 838 to 840 out of 10000 .
# Iterating from 840 to 842 out of 10000 .
# Iterating from 842 to 844 out of 10000 .
# Iterating from 844 to 846 out of 10000 .
# Iterating from 846 to 848 out of 10000 .
# Iterating from 848 to 850 out of 10000 .
# Iterating from 850 to 852 out of 10000 .
# Iterating from 852 to 854 out of 10000 .
# Iterating from 854 to 856 out of 10000 .
# Iterating from 856 to 858 out of 10000 .
# Iterating from 858 to 860 out of 10000 .
# Iterating from 860 to 862 out of 10000 .
# Iterating from 862 to 864 out of 10000 .
# Iterating from 864 to 866 out of 10000 .
# Iterating from 866 to 868 out of 10000 .
# Iterating from 868 to 870 out of 10000 .
# Iterating from 870 to 872 out of 10000 .
# Iterating from 872 to 874 out of 10000 .
# Iterating from 874 to 876 out of 10000 .
# Iterating from 876 to 878 out of 10000 .
# Iterating from 878 to 880 out of 10000 .
# Iterating from 880 to 882 out of 10000 .
# Iterating from 882 to 884 out of 10000 .
# Iterating from 884 to 886 out of 10000 .
# Iterating from 886 to 888 out of 10000 .
# Iterating from 888 to 890 out of 10000 .
# Iterating from 890 to 892 out of 10000 .
# Iterating from 892 to 894 out of 10000 .
# Iterating from 894 to 896 out of 10000 .
# Iterating from 896 to 898 out of 10000 .
# Iterating from 898 to 900 out of 10000 .
# Iterating from 900 to 902 out of 10000 .
# Iterating from 902 to 904 out of 10000 .
# Iterating from 904 to 906 out of 10000 .
# Iterating from 906 to 908 out of 10000 .
# Iterating from 908 to 910 out of 10000 .
# Iterating from 910 to 912 out of 10000 .
# Iterating from 912 to 914 out of 10000 .
# Iterating from 914 to 916 out of 10000 .
# Iterating from 916 to 918 out of 10000 .
# Iterating from 918 to 920 out of 10000 .
# Iterating from 920 to 922 out of 10000 .
# Iterating from 922 to 924 out of 10000 .
# Iterating from 924 to 926 out of 10000 .
# Iterating from 926 to 928 out of 10000 .
# Iterating from 928 to 930 out of 10000 .
# Iterating from 930 to 932 out of 10000 .
# Iterating from 932 to 934 out of 10000 .
# Iterating from 934 to 936 out of 10000 .
# Iterating from 936 to 938 out of 10000 .
# Iterating from 938 to 940 out of 10000 .
# Iterating from 940 to 942 out of 10000 .
# Iterating from 942 to 944 out of 10000 .
# Iterating from 944 to 946 out of 10000 .
# Iterating from 946 to 948 out of 10000 .
# Iterating from 948 to 950 out of 10000 .
# Iterating from 950 to 952 out of 10000 .
# Iterating from 952 to 954 out of 10000 .
# Iterating from 954 to 956 out of 10000 .
# Iterating from 956 to 958 out of 10000 .
# Iterating from 958 to 960 out of 10000 .
# Iterating from 960 to 962 out of 10000 .
# Iterating from 962 to 964 out of 10000 .
# Iterating from 964 to 966 out of 10000 .
# Iterating from 966 to 968 out of 10000 .
# Iterating from 968 to 970 out of 10000 .
# Iterating from 970 to 972 out of 10000 .
# Iterating from 972 to 974 out of 10000 .
# Iterating from 974 to 976 out of 10000 .
# Iterating from 976 to 978 out of 10000 .
# Iterating from 978 to 980 out of 10000 .
# Iterating from 980 to 982 out of 10000 .
# Iterating from 982 to 984 out of 10000 .
# Iterating from 984 to 986 out of 10000 .
# Iterating from 986 to 988 out of 10000 .
# Iterating from 988 to 990 out of 10000 .
# Iterating from 990 to 992 out of 10000 .
# Iterating from 992 to 994 out of 10000 .
# Iterating from 994 to 996 out of 10000 .
# Iterating from 996 to 998 out of 10000 .
# Iterating from 998 to 1000 out of 10000 .
# Iterating from 1000 to 1002 out of 10000 .
# Iterating from 1002 to 1004 out of 10000 .
# Iterating from 1004 to 1006 out of 10000 .
# Iterating from 1006 to 1008 out of 10000 .
# Iterating from 1008 to 1010 out of 10000 .
# Iterating from 1010 to 1012 out of 10000 .
# Iterating from 1012 to 1014 out of 10000 .
# Iterating from 1014 to 1016 out of 10000 .
# Iterating from 1016 to 1018 out of 10000 .
# Iterating from 1018 to 1020 out of 10000 .
# Iterating from 1020 to 1022 out of 10000 .
# Iterating from 1022 to 1024 out of 10000 .
# Iterating from 1024 to 1026 out of 10000 .
# Iterating from 1026 to 1028 out of 10000 .
# Iterating from 1028 to 1030 out of 10000 .
# Iterating from 1030 to 1032 out of 10000 .
# Iterating from 1032 to 1034 out of 10000 .
# Iterating from 1034 to 1036 out of 10000 .
# Iterating from 1036 to 1038 out of 10000 .
# Iterating from 1038 to 1040 out of 10000 .
# Iterating from 1040 to 1042 out of 10000 .
# Iterating from 1042 to 1044 out of 10000 .
# Iterating from 1044 to 1046 out of 10000 .
# Iterating from 1046 to 1048 out of 10000 .
# Iterating from 1048 to 1050 out of 10000 .
# Iterating from 1050 to 1052 out of 10000 .
# Iterating from 1052 to 1054 out of 10000 .
# Iterating from 1054 to 1056 out of 10000 .
# Iterating from 1056 to 1058 out of 10000 .
# Iterating from 1058 to 1060 out of 10000 .
# Iterating from 1060 to 1062 out of 10000 .
# Iterating from 1062 to 1064 out of 10000 .
# Iterating from 1064 to 1066 out of 10000 .
# Iterating from 1066 to 1068 out of 10000 .
# Iterating from 1068 to 1070 out of 10000 .
# Iterating from 1070 to 1072 out of 10000 .
# Iterating from 1072 to 1074 out of 10000 .
# Iterating from 1074 to 1076 out of 10000 .
# Iterating from 1076 to 1078 out of 10000 .
# Iterating from 1078 to 1080 out of 10000 .
# Iterating from 1080 to 1082 out of 10000 .
# Iterating from 1082 to 1084 out of 10000 .
# Iterating from 1084 to 1086 out of 10000 .
# Iterating from 1086 to 1088 out of 10000 .
# Iterating from 1088 to 1090 out of 10000 .
# Iterating from 1090 to 1092 out of 10000 .
# Iterating from 1092 to 1094 out of 10000 .
# Iterating from 1094 to 1096 out of 10000 .
# Iterating from 1096 to 1098 out of 10000 .
# Iterating from 1098 to 1100 out of 10000 .
# Iterating from 1100 to 1102 out of 10000 .
# Iterating from 1102 to 1104 out of 10000 .
# Iterating from 1104 to 1106 out of 10000 .
# Iterating from 1106 to 1108 out of 10000 .
# Iterating from 1108 to 1110 out of 10000 .
# Iterating from 1110 to 1112 out of 10000 .
# Iterating from 1112 to 1114 out of 10000 .
# Iterating from 1114 to 1116 out of 10000 .
# Iterating from 1116 to 1118 out of 10000 .
# Iterating from 1118 to 1120 out of 10000 .
# Iterating from 1120 to 1122 out of 10000 .
# Iterating from 1122 to 1124 out of 10000 .
# Iterating from 1124 to 1126 out of 10000 .
# Iterating from 1126 to 1128 out of 10000 .
# Iterating from 1128 to 1130 out of 10000 .
# Iterating from 1130 to 1132 out of 10000 .
# Iterating from 1132 to 1134 out of 10000 .
# Iterating from 1134 to 1136 out of 10000 .
# Iterating from 1136 to 1138 out of 10000 .
# Iterating from 1138 to 1140 out of 10000 .
# Iterating from 1140 to 1142 out of 10000 .
# Iterating from 1142 to 1144 out of 10000 .
# Iterating from 1144 to 1146 out of 10000 .
# Iterating from 1146 to 1148 out of 10000 .
# Iterating from 1148 to 1150 out of 10000 .
# Iterating from 1150 to 1152 out of 10000 .
# Iterating from 1152 to 1154 out of 10000 .
# Iterating from 1154 to 1156 out of 10000 .
# Iterating from 1156 to 1158 out of 10000 .
# Iterating from 1158 to 1160 out of 10000 .
# Iterating from 1160 to 1162 out of 10000 .
# Iterating from 1162 to 1164 out of 10000 .
# Iterating from 1164 to 1166 out of 10000 .
# Iterating from 1166 to 1168 out of 10000 .
# Iterating from 1168 to 1170 out of 10000 .
# Iterating from 1170 to 1172 out of 10000 .
# Iterating from 1172 to 1174 out of 10000 .
# Iterating from 1174 to 1176 out of 10000 .
# Iterating from 1176 to 1178 out of 10000 .
# Iterating from 1178 to 1180 out of 10000 .
# Iterating from 1180 to 1182 out of 10000 .
# Iterating from 1182 to 1184 out of 10000 .
# Iterating from 1184 to 1186 out of 10000 .
# Iterating from 1186 to 1188 out of 10000 .
# Iterating from 1188 to 1190 out of 10000 .
# Iterating from 1190 to 1192 out of 10000 .
# Iterating from 1192 to 1194 out of 10000 .
# Iterating from 1194 to 1196 out of 10000 .
# Iterating from 1196 to 1198 out of 10000 .
# Iterating from 1198 to 1200 out of 10000 .
# Iterating from 1200 to 1202 out of 10000 .
# Iterating from 1202 to 1204 out of 10000 .
# Iterating from 1204 to 1206 out of 10000 .
# Iterating from 1206 to 1208 out of 10000 .
# Iterating from 1208 to 1210 out of 10000 .
# Iterating from 1210 to 1212 out of 10000 .
# Iterating from 1212 to 1214 out of 10000 .
# Iterating from 1214 to 1216 out of 10000 .
# Iterating from 1216 to 1218 out of 10000 .
# Iterating from 1218 to 1220 out of 10000 .
# Iterating from 1220 to 1222 out of 10000 .
# Iterating from 1222 to 1224 out of 10000 .
# Iterating from 1224 to 1226 out of 10000 .
# Iterating from 1226 to 1228 out of 10000 .
# Iterating from 1228 to 1230 out of 10000 .
# Iterating from 1230 to 1232 out of 10000 .
# Iterating from 1232 to 1234 out of 10000 .
# Iterating from 1234 to 1236 out of 10000 .
# Iterating from 1236 to 1238 out of 10000 .
# Iterating from 1238 to 1240 out of 10000 .
# Iterating from 1240 to 1242 out of 10000 .
# Iterating from 1242 to 1244 out of 10000 .
# Iterating from 1244 to 1246 out of 10000 .
# Iterating from 1246 to 1248 out of 10000 .
# Iterating from 1248 to 1250 out of 10000 .
# Iterating from 1250 to 1252 out of 10000 .
# Iterating from 1252 to 1254 out of 10000 .
# Iterating from 1254 to 1256 out of 10000 .
# Iterating from 1256 to 1258 out of 10000 .
# Iterating from 1258 to 1260 out of 10000 .
# Iterating from 1260 to 1262 out of 10000 .
# Iterating from 1262 to 1264 out of 10000 .
# Iterating from 1264 to 1266 out of 10000 .
# Iterating from 1266 to 1268 out of 10000 .
# Iterating from 1268 to 1270 out of 10000 .
# Iterating from 1270 to 1272 out of 10000 .
# Iterating from 1272 to 1274 out of 10000 .
# Iterating from 1274 to 1276 out of 10000 .
# Iterating from 1276 to 1278 out of 10000 .
# Iterating from 1278 to 1280 out of 10000 .
# Iterating from 1280 to 1282 out of 10000 .
# Iterating from 1282 to 1284 out of 10000 .
# Iterating from 1284 to 1286 out of 10000 .
# Iterating from 1286 to 1288 out of 10000 .
# Iterating from 1288 to 1290 out of 10000 .
# Iterating from 1290 to 1292 out of 10000 .
# Iterating from 1292 to 1294 out of 10000 .
# Iterating from 1294 to 1296 out of 10000 .
# Iterating from 1296 to 1298 out of 10000 .
# Iterating from 1298 to 1300 out of 10000 .
# Iterating from 1300 to 1302 out of 10000 .
# Iterating from 1302 to 1304 out of 10000 .
# Iterating from 1304 to 1306 out of 10000 .
# Iterating from 1306 to 1308 out of 10000 .
# Iterating from 1308 to 1310 out of 10000 .
# Iterating from 1310 to 1312 out of 10000 .
# Iterating from 1312 to 1314 out of 10000 .
# Iterating from 1314 to 1316 out of 10000 .
# Iterating from 1316 to 1318 out of 10000 .
# Iterating from 1318 to 1320 out of 10000 .
# Iterating from 1320 to 1322 out of 10000 .
# Iterating from 1322 to 1324 out of 10000 .
# Iterating from 1324 to 1326 out of 10000 .
# Iterating from 1326 to 1328 out of 10000 .
# Iterating from 1328 to 1330 out of 10000 .
# Iterating from 1330 to 1332 out of 10000 .
# Iterating from 1332 to 1334 out of 10000 .
# Iterating from 1334 to 1336 out of 10000 .
# Iterating from 1336 to 1338 out of 10000 .
# Iterating from 1338 to 1340 out of 10000 .
# Iterating from 1340 to 1342 out of 10000 .
# Iterating from 1342 to 1344 out of 10000 .
# Iterating from 1344 to 1346 out of 10000 .
# Iterating from 1346 to 1348 out of 10000 .
# Iterating from 1348 to 1350 out of 10000 .
# Iterating from 1350 to 1352 out of 10000 .
# Iterating from 1352 to 1354 out of 10000 .
# Iterating from 1354 to 1356 out of 10000 .
# Iterating from 1356 to 1358 out of 10000 .
# Iterating from 1358 to 1360 out of 10000 .
# Iterating from 1360 to 1362 out of 10000 .
# Iterating from 1362 to 1364 out of 10000 .
# Iterating from 1364 to 1366 out of 10000 .
# Iterating from 1366 to 1368 out of 10000 .
# Iterating from 1368 to 1370 out of 10000 .
# Iterating from 1370 to 1372 out of 10000 .
# Iterating from 1372 to 1374 out of 10000 .
# Iterating from 1374 to 1376 out of 10000 .
# Iterating from 1376 to 1378 out of 10000 .
# Iterating from 1378 to 1380 out of 10000 .
# Iterating from 1380 to 1382 out of 10000 .
# Iterating from 1382 to 1384 out of 10000 .
# Iterating from 1384 to 1386 out of 10000 .
# Iterating from 1386 to 1388 out of 10000 .
# Iterating from 1388 to 1390 out of 10000 .
# Iterating from 1390 to 1392 out of 10000 .
# Iterating from 1392 to 1394 out of 10000 .
# Iterating from 1394 to 1396 out of 10000 .
# Iterating from 1396 to 1398 out of 10000 .
# Iterating from 1398 to 1400 out of 10000 .
# Iterating from 1400 to 1402 out of 10000 .
# Iterating from 1402 to 1404 out of 10000 .
# Iterating from 1404 to 1406 out of 10000 .
# Iterating from 1406 to 1408 out of 10000 .
# Iterating from 1408 to 1410 out of 10000 .
# Iterating from 1410 to 1412 out of 10000 .
# Iterating from 1412 to 1414 out of 10000 .
# Iterating from 1414 to 1416 out of 10000 .
# Iterating from 1416 to 1418 out of 10000 .
# Iterating from 1418 to 1420 out of 10000 .
# Iterating from 1420 to 1422 out of 10000 .
# Iterating from 1422 to 1424 out of 10000 .
# Iterating from 1424 to 1426 out of 10000 .
# Iterating from 1426 to 1428 out of 10000 .
# Iterating from 1428 to 1430 out of 10000 .
# Iterating from 1430 to 1432 out of 10000 .
# Iterating from 1432 to 1434 out of 10000 .
# Iterating from 1434 to 1436 out of 10000 .
# Iterating from 1436 to 1438 out of 10000 .
# Iterating from 1438 to 1440 out of 10000 .
# Iterating from 1440 to 1442 out of 10000 .
# Iterating from 1442 to 1444 out of 10000 .
# Iterating from 1444 to 1446 out of 10000 .
# Iterating from 1446 to 1448 out of 10000 .
# Iterating from 1448 to 1450 out of 10000 .
# Iterating from 1450 to 1452 out of 10000 .
# Iterating from 1452 to 1454 out of 10000 .
# Iterating from 1454 to 1456 out of 10000 .
# Iterating from 1456 to 1458 out of 10000 .
# Iterating from 1458 to 1460 out of 10000 .
# Iterating from 1460 to 1462 out of 10000 .
# Iterating from 1462 to 1464 out of 10000 .
# Iterating from 1464 to 1466 out of 10000 .
# Iterating from 1466 to 1468 out of 10000 .
# Iterating from 1468 to 1470 out of 10000 .
# Iterating from 1470 to 1472 out of 10000 .
# Iterating from 1472 to 1474 out of 10000 .
# Iterating from 1474 to 1476 out of 10000 .
# Iterating from 1476 to 1478 out of 10000 .
# Iterating from 1478 to 1480 out of 10000 .
# Iterating from 1480 to 1482 out of 10000 .
# Iterating from 1482 to 1484 out of 10000 .
# Iterating from 1484 to 1486 out of 10000 .
# Iterating from 1486 to 1488 out of 10000 .
# Iterating from 1488 to 1490 out of 10000 .
# Iterating from 1490 to 1492 out of 10000 .
# Iterating from 1492 to 1494 out of 10000 .
# Iterating from 1494 to 1496 out of 10000 .
# Iterating from 1496 to 1498 out of 10000 .
# Iterating from 1498 to 1500 out of 10000 .
# Iterating from 1500 to 1502 out of 10000 .
# Iterating from 1502 to 1504 out of 10000 .
# Iterating from 1504 to 1506 out of 10000 .
# Iterating from 1506 to 1508 out of 10000 .
# Iterating from 1508 to 1510 out of 10000 .
# Iterating from 1510 to 1512 out of 10000 .
# Iterating from 1512 to 1514 out of 10000 .
# Iterating from 1514 to 1516 out of 10000 .
# Iterating from 1516 to 1518 out of 10000 .
# Iterating from 1518 to 1520 out of 10000 .
# Iterating from 1520 to 1522 out of 10000 .
# Iterating from 1522 to 1524 out of 10000 .
# Iterating from 1524 to 1526 out of 10000 .
# Iterating from 1526 to 1528 out of 10000 .
# Iterating from 1528 to 1530 out of 10000 .
# Iterating from 1530 to 1532 out of 10000 .
# Iterating from 1532 to 1534 out of 10000 .
# Iterating from 1534 to 1536 out of 10000 .
# Iterating from 1536 to 1538 out of 10000 .
# Iterating from 1538 to 1540 out of 10000 .
# Iterating from 1540 to 1542 out of 10000 .
# Iterating from 1542 to 1544 out of 10000 .
# Iterating from 1544 to 1546 out of 10000 .
# Iterating from 1546 to 1548 out of 10000 .
# Iterating from 1548 to 1550 out of 10000 .
# Iterating from 1550 to 1552 out of 10000 .
# Iterating from 1552 to 1554 out of 10000 .
# Iterating from 1554 to 1556 out of 10000 .
# Iterating from 1556 to 1558 out of 10000 .
# Iterating from 1558 to 1560 out of 10000 .
# Iterating from 1560 to 1562 out of 10000 .
# Iterating from 1562 to 1564 out of 10000 .
# Iterating from 1564 to 1566 out of 10000 .
# Iterating from 1566 to 1568 out of 10000 .
# Iterating from 1568 to 1570 out of 10000 .
# Iterating from 1570 to 1572 out of 10000 .
# Iterating from 1572 to 1574 out of 10000 .
# Iterating from 1574 to 1576 out of 10000 .
# Iterating from 1576 to 1578 out of 10000 .
# Iterating from 1578 to 1580 out of 10000 .
# Iterating from 1580 to 1582 out of 10000 .
# Iterating from 1582 to 1584 out of 10000 .
# Iterating from 1584 to 1586 out of 10000 .
# Iterating from 1586 to 1588 out of 10000 .
# Iterating from 1588 to 1590 out of 10000 .
# Iterating from 1590 to 1592 out of 10000 .
# Iterating from 1592 to 1594 out of 10000 .
# Iterating from 1594 to 1596 out of 10000 .
# Iterating from 1596 to 1598 out of 10000 .
# Iterating from 1598 to 1600 out of 10000 .
# Iterating from 1600 to 1602 out of 10000 .
# Iterating from 1602 to 1604 out of 10000 .
# Iterating from 1604 to 1606 out of 10000 .
# Iterating from 1606 to 1608 out of 10000 .
# Iterating from 1608 to 1610 out of 10000 .
# Iterating from 1610 to 1612 out of 10000 .
# Iterating from 1612 to 1614 out of 10000 .
# Iterating from 1614 to 1616 out of 10000 .
# Iterating from 1616 to 1618 out of 10000 .
# Iterating from 1618 to 1620 out of 10000 .
# Iterating from 1620 to 1622 out of 10000 .
# Iterating from 1622 to 1624 out of 10000 .
# Iterating from 1624 to 1626 out of 10000 .
# Iterating from 1626 to 1628 out of 10000 .
# Iterating from 1628 to 1630 out of 10000 .
# Iterating from 1630 to 1632 out of 10000 .
# Iterating from 1632 to 1634 out of 10000 .
# Iterating from 1634 to 1636 out of 10000 .
# Iterating from 1636 to 1638 out of 10000 .
# Iterating from 1638 to 1640 out of 10000 .
# Iterating from 1640 to 1642 out of 10000 .
# Iterating from 1642 to 1644 out of 10000 .
# Iterating from 1644 to 1646 out of 10000 .
# Iterating from 1646 to 1648 out of 10000 .
# Iterating from 1648 to 1650 out of 10000 .
# Iterating from 1650 to 1652 out of 10000 .
# Iterating from 1652 to 1654 out of 10000 .
# Iterating from 1654 to 1656 out of 10000 .
# Iterating from 1656 to 1658 out of 10000 .
# Iterating from 1658 to 1660 out of 10000 .
# Iterating from 1660 to 1662 out of 10000 .
# Iterating from 1662 to 1664 out of 10000 .
# Iterating from 1664 to 1666 out of 10000 .
# Iterating from 1666 to 1668 out of 10000 .
# Iterating from 1668 to 1670 out of 10000 .
# Iterating from 1670 to 1672 out of 10000 .
# Iterating from 1672 to 1674 out of 10000 .
# Iterating from 1674 to 1676 out of 10000 .
# Iterating from 1676 to 1678 out of 10000 .
# Iterating from 1678 to 1680 out of 10000 .
# Iterating from 1680 to 1682 out of 10000 .
# Iterating from 1682 to 1684 out of 10000 .
# Iterating from 1684 to 1686 out of 10000 .
# Iterating from 1686 to 1688 out of 10000 .
# Iterating from 1688 to 1690 out of 10000 .
# Iterating from 1690 to 1692 out of 10000 .
# Iterating from 1692 to 1694 out of 10000 .
# Iterating from 1694 to 1696 out of 10000 .
# Iterating from 1696 to 1698 out of 10000 .
# Iterating from 1698 to 1700 out of 10000 .
# Iterating from 1700 to 1702 out of 10000 .
# Iterating from 1702 to 1704 out of 10000 .
# Iterating from 1704 to 1706 out of 10000 .
# Iterating from 1706 to 1708 out of 10000 .
# Iterating from 1708 to 1710 out of 10000 .
# Iterating from 1710 to 1712 out of 10000 .
# Iterating from 1712 to 1714 out of 10000 .
# Iterating from 1714 to 1716 out of 10000 .
# Iterating from 1716 to 1718 out of 10000 .
# Iterating from 1718 to 1720 out of 10000 .
# Iterating from 1720 to 1722 out of 10000 .
# Iterating from 1722 to 1724 out of 10000 .
# Iterating from 1724 to 1726 out of 10000 .
# Iterating from 1726 to 1728 out of 10000 .
# Iterating from 1728 to 1730 out of 10000 .
# Iterating from 1730 to 1732 out of 10000 .
# Iterating from 1732 to 1734 out of 10000 .
# Iterating from 1734 to 1736 out of 10000 .
# Iterating from 1736 to 1738 out of 10000 .
# Iterating from 1738 to 1740 out of 10000 .
# Iterating from 1740 to 1742 out of 10000 .
# Iterating from 1742 to 1744 out of 10000 .
# Iterating from 1744 to 1746 out of 10000 .
# Iterating from 1746 to 1748 out of 10000 .
# Iterating from 1748 to 1750 out of 10000 .
# Iterating from 1750 to 1752 out of 10000 .
# Iterating from 1752 to 1754 out of 10000 .
# Iterating from 1754 to 1756 out of 10000 .
# Iterating from 1756 to 1758 out of 10000 .
# Iterating from 1758 to 1760 out of 10000 .
# Iterating from 1760 to 1762 out of 10000 .
# Iterating from 1762 to 1764 out of 10000 .
# Iterating from 1764 to 1766 out of 10000 .
# Iterating from 1766 to 1768 out of 10000 .
# Iterating from 1768 to 1770 out of 10000 .
# Iterating from 1770 to 1772 out of 10000 .
# Iterating from 1772 to 1774 out of 10000 .
# Iterating from 1774 to 1776 out of 10000 .
# Iterating from 1776 to 1778 out of 10000 .
# Iterating from 1778 to 1780 out of 10000 .
# Iterating from 1780 to 1782 out of 10000 .
# Iterating from 1782 to 1784 out of 10000 .
# Iterating from 1784 to 1786 out of 10000 .
# Iterating from 1786 to 1788 out of 10000 .
# Iterating from 1788 to 1790 out of 10000 .
# Iterating from 1790 to 1792 out of 10000 .
# Iterating from 1792 to 1794 out of 10000 .
# Iterating from 1794 to 1796 out of 10000 .
# Iterating from 1796 to 1798 out of 10000 .
# Iterating from 1798 to 1800 out of 10000 .
# Iterating from 1800 to 1802 out of 10000 .
# Iterating from 1802 to 1804 out of 10000 .
# Iterating from 1804 to 1806 out of 10000 .
# Iterating from 1806 to 1808 out of 10000 .
# Iterating from 1808 to 1810 out of 10000 .
# Iterating from 1810 to 1812 out of 10000 .
# Iterating from 1812 to 1814 out of 10000 .
# Iterating from 1814 to 1816 out of 10000 .
# Iterating from 1816 to 1818 out of 10000 .
# Iterating from 1818 to 1820 out of 10000 .
# Iterating from 1820 to 1822 out of 10000 .
# Iterating from 1822 to 1824 out of 10000 .
# Iterating from 1824 to 1826 out of 10000 .
# Iterating from 1826 to 1828 out of 10000 .
# Iterating from 1828 to 1830 out of 10000 .
# Iterating from 1830 to 1832 out of 10000 .
# Iterating from 1832 to 1834 out of 10000 .
# Iterating from 1834 to 1836 out of 10000 .
# Iterating from 1836 to 1838 out of 10000 .
# Iterating from 1838 to 1840 out of 10000 .
# Iterating from 1840 to 1842 out of 10000 .
# Iterating from 1842 to 1844 out of 10000 .
# Iterating from 1844 to 1846 out of 10000 .
# Iterating from 1846 to 1848 out of 10000 .
# Iterating from 1848 to 1850 out of 10000 .
# Iterating from 1850 to 1852 out of 10000 .
# Iterating from 1852 to 1854 out of 10000 .
# Iterating from 1854 to 1856 out of 10000 .
# Iterating from 1856 to 1858 out of 10000 .
# Iterating from 1858 to 1860 out of 10000 .
# Iterating from 1860 to 1862 out of 10000 .
# Iterating from 1862 to 1864 out of 10000 .
# Iterating from 1864 to 1866 out of 10000 .
# Iterating from 1866 to 1868 out of 10000 .
# Iterating from 1868 to 1870 out of 10000 .
# Iterating from 1870 to 1872 out of 10000 .
# Iterating from 1872 to 1874 out of 10000 .
# Iterating from 1874 to 1876 out of 10000 .
# Iterating from 1876 to 1878 out of 10000 .
# Iterating from 1878 to 1880 out of 10000 .
# Iterating from 1880 to 1882 out of 10000 .
# Iterating from 1882 to 1884 out of 10000 .
# Iterating from 1884 to 1886 out of 10000 .
# Iterating from 1886 to 1888 out of 10000 .
# Iterating from 1888 to 1890 out of 10000 .
# Iterating from 1890 to 1892 out of 10000 .
# Iterating from 1892 to 1894 out of 10000 .
# Iterating from 1894 to 1896 out of 10000 .
# Iterating from 1896 to 1898 out of 10000 .
# Iterating from 1898 to 1900 out of 10000 .
# Iterating from 1900 to 1902 out of 10000 .
# Iterating from 1902 to 1904 out of 10000 .
# Iterating from 1904 to 1906 out of 10000 .
# Iterating from 1906 to 1908 out of 10000 .
# Iterating from 1908 to 1910 out of 10000 .
# Iterating from 1910 to 1912 out of 10000 .
# Iterating from 1912 to 1914 out of 10000 .
# Iterating from 1914 to 1916 out of 10000 .
# Iterating from 1916 to 1918 out of 10000 .
# Iterating from 1918 to 1920 out of 10000 .
# Iterating from 1920 to 1922 out of 10000 .
# Iterating from 1922 to 1924 out of 10000 .
# Iterating from 1924 to 1926 out of 10000 .
# Iterating from 1926 to 1928 out of 10000 .
# Iterating from 1928 to 1930 out of 10000 .
# Iterating from 1930 to 1932 out of 10000 .
# Iterating from 1932 to 1934 out of 10000 .
# Iterating from 1934 to 1936 out of 10000 .
# Iterating from 1936 to 1938 out of 10000 .
# Iterating from 1938 to 1940 out of 10000 .
# Iterating from 1940 to 1942 out of 10000 .
# Iterating from 1942 to 1944 out of 10000 .
# Iterating from 1944 to 1946 out of 10000 .
# Iterating from 1946 to 1948 out of 10000 .
# Iterating from 1948 to 1950 out of 10000 .
# Iterating from 1950 to 1952 out of 10000 .
# Iterating from 1952 to 1954 out of 10000 .
# Iterating from 1954 to 1956 out of 10000 .
# Iterating from 1956 to 1958 out of 10000 .
# Iterating from 1958 to 1960 out of 10000 .
# Iterating from 1960 to 1962 out of 10000 .
# Iterating from 1962 to 1964 out of 10000 .
# Iterating from 1964 to 1966 out of 10000 .
# Iterating from 1966 to 1968 out of 10000 .
# Iterating from 1968 to 1970 out of 10000 .
# Iterating from 1970 to 1972 out of 10000 .
# Iterating from 1972 to 1974 out of 10000 .
# Iterating from 1974 to 1976 out of 10000 .
# Iterating from 1976 to 1978 out of 10000 .
# Iterating from 1978 to 1980 out of 10000 .
# Iterating from 1980 to 1982 out of 10000 .
# Iterating from 1982 to 1984 out of 10000 .
# Iterating from 1984 to 1986 out of 10000 .
# Iterating from 1986 to 1988 out of 10000 .
# Iterating from 1988 to 1990 out of 10000 .
# Iterating from 1990 to 1992 out of 10000 .
# Iterating from 1992 to 1994 out of 10000 .
# Iterating from 1994 to 1996 out of 10000 .
# Iterating from 1996 to 1998 out of 10000 .
# Iterating from 1998 to 2000 out of 10000 .
# Iterating from 2000 to 2002 out of 10000 .
# Iterating from 2002 to 2004 out of 10000 .
# Iterating from 2004 to 2006 out of 10000 .
# Iterating from 2006 to 2008 out of 10000 .
# Iterating from 2008 to 2010 out of 10000 .
# Iterating from 2010 to 2012 out of 10000 .
# Iterating from 2012 to 2014 out of 10000 .
# Iterating from 2014 to 2016 out of 10000 .
# Iterating from 2016 to 2018 out of 10000 .
# ...
# Iterating from 500 to 600 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f0bafaed760> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# KS tests calculation completed in 530.9745206860825 seconds.
# Saving ks to results/100D_unimodal/100D_20K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 100
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f0bafaefd80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 500 to 600 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f0bafaefd80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SKS metric calculation completed in 600.3909771349281 seconds.
# Saving sks to results/100D_unimodal/100D_20K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 100
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SWD metric calculation completed in 298.20035643689334 seconds.
# Saving swd to results/100D_unimodal/100D_20K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.023705292642235906], [0.95, [9500, 500], 0.10808373744214016], [0.99, [9900, 100], 0.1648822897830853]]
# Computing time for metric fgd: 7488.625817649066
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.8239903680732823], [0.95, [9500, 500], 5.0631036241175025], [0.99, [9900, 100], 8.34905088339292]]
# Computing time for metric mmd: 2375.8348439799156
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.8958505541086197], [0.95, [9500, 500], 0.9957506358623504], [0.99, [9900, 100], 1.05635055154562]]
# Computing time for metric ks: 530.9745206860825
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.8951503783464432], [0.95, [9500, 500], 0.9985505603253841], [0.99, [9900, 100], 1.0643506422638893]]
# Computing time for metric sks: 600.3909771349281
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.3830072195264897], [0.95, [9500, 500], 0.44684544568681733], [0.99, [9900, 100], 0.48971344995573707]]
# Computing time for metric swd: 298.20035643689334
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f0bac0e2480>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f0bac0e3880>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f0bac0e3920>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f0bac0e39c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f0bac0e3a60>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f0bac0e3b00>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 1  $d_{\mathrm{MMD}}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 2      $\overline{D}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 3     $\widetilde{D}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 4     $\widetilde{W}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 5           $t_{\mu}$  results/100D_unimodal/100D_20K/null_hypothesis...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.023705292642235906], [...
# 1  [[0.68, [6800, 3199], 0.8239903680732823], [0....
# 2  [[0.68, [6800, 3199], 0.8958505541086197], [0....
# 3  [[0.68, [6800, 3199], 0.8951503783464432], [0....
# 4  [[0.68, [6800, 3199], 0.3830072195264897], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10)$"
        dist_null = dist_null * 10
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-1})$"
        dist_null = dist_null / 10
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 10
        elif "MMD" in latex:
            threshold_value = threshold_value / 10
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 10
        elif "MMD" in latex:
            threshold_value = threshold_value / 10
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.2413905698667599 +/- 0.0015506057380003982
# sigma = 0.39377731498911894 +/- 0.005177354836384494
# 68%CL = 0.23705292642235906, 95%CL = 1.0808373744214015, 99%CL = 1.648822897830853
# mu = 0.2413905698667599 +/- 0.0015506057380003982
# sigma = 0.39377731498911894 +/- 0.005177354836384494
# /tmp/ipykernel_962056/2009291306.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_962056/2009291306.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_962056/2009291306.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 2.2163584630470723 seconds.
# mu = -0.0037526905458895627 +/- 0.0007591412891411679
# sigma = 0.27552518744048937 +/- 0.0027635615296335747
# 68%CL = 0.08239903680732823, 95%CL = 0.5063103624117502, 99%CL = 0.834905088339292
# mu = -0.0037526905458895627 +/- 0.0007591412891411679
# sigma = 0.27552518744048937 +/- 0.0027635615296335747
# /tmp/ipykernel_962056/2009291306.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_962056/2009291306.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_962056/2009291306.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_962056/2009291306.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.4564676901791245 seconds.
# mu = 0.8659962367941625 +/- 5.265407282107566e-05
# sigma = 0.07256312618753114 +/- 0.0005390671604663675
# 68%CL = 0.8958505541086197, 95%CL = 0.9957506358623504, 99%CL = 1.05635055154562
# mu = 0.8659962367941625 +/- 5.265407282107566e-05
# sigma = 0.07256312618753114 +/- 0.0005390671604663675
# /tmp/ipykernel_962056/2009291306.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_962056/2009291306.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_962056/2009291306.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_962056/2009291306.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 6.6721528568305075 seconds.
# mu = 0.8655796067370102 +/- 5.4403857149576096e-05
# sigma = 0.07375897040331847 +/- 0.0005543541078516184
# 68%CL = 0.8951503783464432, 95%CL = 0.9985505603253841, 99%CL = 1.0643506422638893
# mu = 0.8655796067370102 +/- 5.4403857149576096e-05
# sigma = 0.07375897040331847 +/- 0.0005543541078516184
# /tmp/ipykernel_962056/2009291306.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_962056/2009291306.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_962056/2009291306.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_962056/2009291306.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.897570095025003 seconds.
# mu = 0.367320682381955 +/- 1.8368422000667308e-05
# sigma = 0.04285839707766415 +/- 0.0003470241731386383
# 68%CL = 0.3830072195264897, 95%CL = 0.44684544568681733, 99%CL = 0.48971344995573707
# mu = 0.367320682381955 +/- 1.8368422000667308e-05
# sigma = 0.04285839707766415 +/- 0.0003470241731386383
# /tmp/ipykernel_962056/2009291306.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_962056/2009291306.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_962056/2009291306.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_962056/2009291306.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.5172125969547778 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f0bac0e2480>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f0bac0e3880>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f0bac0e3920>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f0bac0e39c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f0bac0e3a60>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f0bac0e3b00>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 1  $d_{\mathrm{MMD}}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 2      $\overline{D}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 3     $\widetilde{D}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 4     $\widetilde{W}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 5           $t_{\mu}$  results/100D_unimodal/100D_20K/null_hypothesis...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.023705292642235906], [...
# 1  [[0.68, [6800, 3199], 0.8239903680732823], [0....
# 2  [[0.68, [6800, 3199], 0.8958505541086197], [0....
# 3  [[0.68, [6800, 3199], 0.8951503783464432], [0....
# 4  [[0.68, [6800, 3199], 0.3830072195264897], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/100D_unimodal/100D_20K/null_hypothesis...
# 1  results/100D_unimodal/100D_20K/null_hypothesis...
# 2  results/100D_unimodal/100D_20K/null_hypothesis...
# 3  results/100D_unimodal/100D_20K/null_hypothesis...
# 4  results/100D_unimodal/100D_20K/null_hypothesis...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = mean
# statistic = 163.70508354225973 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9973608046474653
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 204 calls to <function generate_and_clean_data_simple_1 at 0x7f0c82760f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 40.84407501337741 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9894429265036018
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = mean
# WARNING:tensorflow:6 out of the last 205 calls to <function generate_and_clean_data_simple_1 at 0x7f0c82760f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 10.184340740103066 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.957994838756235
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = mean
# WARNING:tensorflow:5 out of the last 104 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f0b58211ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 2.5358275735470244 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8364790271248506
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = mean
# WARNING:tensorflow:6 out of the last 105 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f0b7c299300> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.63205606351016 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.41587393461033
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = mean
# statistic = 0.16885629142772915 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.43888602332850385
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = mean
# statistic = 0.057900304385805366 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.6046778052115824
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.05859375 - deformation = mean
# statistic = 0.09718759230662995 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.10616334145490179
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.068359375 - deformation = mean
# statistic = 0.13608756461214572 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.2293785300270836
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0634765625 - deformation = mean
# statistic = 0.10892221911924985 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.007727729601491259
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.06103515625 - deformation = mean
# statistic = 0.1042760853132958 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.0392156862745098
# relative_error_metric = 0.035860381492495784
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.062255859375 - deformation = mean
# statistic = 0.11094194373077801 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.019801980198019802
# relative_error_metric = 0.026099279987001452
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0616455078125 - deformation = mean
# statistic = 0.10579872409662135 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.009852216748768473
# relative_error_metric = 0.02136700063277233
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.06195068359375 - deformation = mean
# statistic = 0.1071085263710686 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.004914004914004914
# relative_error_metric = 0.009063625743702923
# =======> statistic within required accuracy at 0.95 CL in 385.7818414119538 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.062103271484375 - deformation = mean
# statistic = 0.10585922504594532 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.950926902788244
# relative_error_metric = 0.4360104491135185
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5310516357421875 - deformation = mean
# statistic = 167.74491495359916 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9042043013916268
# relative_error_metric = 1.996072122234914
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2965774536132812 - deformation = mean
# statistic = 43.958307627309345 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.817165960075245
# relative_error_metric = 1.9850525503624827
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6793403625488281 - deformation = mean
# statistic = 12.02227814563752 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.6649602551899776
# relative_error_metric = 1.945883279158655
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.37072181701660156 - deformation = mean
# statistic = 3.567110003330734 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.4260658807976203
# relative_error_metric = 1.823276923602096
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.21641254425048828 - deformation = mean
# statistic = 1.2081736879791007 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.1080826584944101
# relative_error_metric = 1.519663313212295
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.13925790786743164 - deformation = mean
# statistic = 0.5061986127605521 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.7663307955527665
# relative_error_metric = 1.0172136375323915
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.10068058967590332 - deformation = mean
# statistic = 0.2727386142093604 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.4739698139184053
# relative_error_metric = 0.4929212633230927
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.08139193058013916 - deformation = mean
# statistic = 0.17854174030262304 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.26884047436083824
# relative_error_metric = 0.07954860069709593
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.07174760103225708 - deformation = mean
# statistic = 0.14002523657348018 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.12595480012688504
# relative_error_metric = 0.1630465046673643
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.07656976580619812 - deformation = mean
# statistic = 0.16470702462464726 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.06105486183368347
# relative_error_metric = 0.0010635366547182958
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.07898084819316864 - deformation = mean
# statistic = 0.173127859708106 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.031000615490728124
# relative_error_metric = 0.048788889549221004
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.07777530699968338 - deformation = mean
# statistic = 0.16426399117569032 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.015381101839377494
# relative_error_metric = 0.003756983707024929
# =======> statistic within required accuracy at 0.99 CL in 348.18502250500023 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 733.9669145708904 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_diag
# statistic = 1632.3129846400768 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997351572102668
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_diag
# statistic = 408.37980754344045 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9989416211373783
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_diag
# statistic = 102.17789736480913 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9957732726898676
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_diag
# statistic = 25.60700532048197 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9831874994173766
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_diag
# statistic = 6.435788395513322 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9339328548931622
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_diag
# statistic = 1.6296310022958913 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7512048785212369
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_diag
# statistic = 0.41892423107357546 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.17964248057538
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_diag
# statistic = 0.12528772837040433 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.1474386842312871
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_diag
# statistic = 0.04766091292236887 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.775921668941515
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0146484375 - deformation = cov_diag
# statistic = 0.07675812274027581 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.3389450276138733
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01708984375 - deformation = cov_diag
# statistic = 0.0985892441636242 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.09187938553697374
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.018310546875 - deformation = cov_diag
# statistic = 0.10650883269840986 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.01467809200196259
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0189208984375 - deformation = cov_diag
# statistic = 0.10980645765352248 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.015812737334288778
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.01861572265625 - deformation = cov_diag
# statistic = 0.10831145896052848 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.01652892561983471
# relative_error_metric = 0.0021046818244946056
# =======> statistic within required accuracy at 0.95 CL in 361.4145036279224 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.018463134765625 - deformation = cov_diag
# statistic = 0.11536080194001816 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9852838335005625
# relative_error_metric = 0.35341808098518457
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5092315673828125 - deformation = cov_diag
# statistic = 1644.4111669881381 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9707826506896864
# relative_error_metric = 1.9995989670654504
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2638473510742188 - deformation = cov_diag
# statistic = 417.3884159995408 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9424066636918043
# relative_error_metric = 1.9984204910802184
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6411552429199219 - deformation = cov_diag
# statistic = 107.55985632530141 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.8880374750600006
# relative_error_metric = 1.9938776443775936
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.32980918884277344 - deformation = cov_diag
# statistic = 28.4820454086698 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.787946000711958
# relative_error_metric = 1.9769773161689528
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.17413616180419922 - deformation = cov_diag
# statistic = 7.979729350041978 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.616548240944765
# relative_error_metric = 1.9190226387336369
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.09629964828491211 - deformation = cov_diag
# statistic = 2.452243163506452 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.3564765762958346
# relative_error_metric = 1.7479948245112356
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.057381391525268555 - deformation = cov_diag
# statistic = 0.8912707614067277 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.0262640868868176
# relative_error_metric = 1.3755363785681003
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.03792226314544678 - deformation = cov_diag
# statistic = 0.4031743040829828 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.6902187126713814
# relative_error_metric = 0.8389727955735344
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.02819269895553589 - deformation = cov_diag
# statistic = 0.22926026673071592 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.4170781406698137
# relative_error_metric = 0.32667356459579044
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.023327916860580444 - deformation = cov_diag
# statistic = 0.16531208330201239 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.23281453352587758
# relative_error_metric = 0.002603275851804496
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.020895525813102722 - deformation = cov_diag
# statistic = 0.13594425278571945 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.11000459938978059
# relative_error_metric = 0.1923901843917059
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.022111721336841583 - deformation = cov_diag
# statistic = 0.15013013284514573 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.053530158777006315
# relative_error_metric = 0.09366079480204921
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.022719819098711014 - deformation = cov_diag
# statistic = 0.15705048035115016 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.026411624771607443
# relative_error_metric = 0.04865493766707589
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.02302386797964573 - deformation = cov_diag
# statistic = 0.1627875555647776 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.013119187620617704
# relative_error_metric = 0.012785639252729497
# =======> statistic within required accuracy at 0.99 CL in 377.312324634986 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 738.726877461886 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_off_diag
# statistic = 641.6124590819492 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9993262878138993
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_off_diag
# statistic = 727.5785014049761 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9994058775321741
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_off_diag
# statistic = 619.4945944272013 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999302238410187
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_off_diag
# statistic = 277.1368728271979 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9984406030135744
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_off_diag
# statistic = 114.19460303106887 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9962176309062258
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_off_diag
# statistic = 43.82934651582818 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.99016021311951
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_off_diag
# statistic = 15.552728389646086 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9723938358841073
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_off_diag
# statistic = 5.078297499822357 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9166403451674157
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_off_diag
# statistic = 1.5472661859027936 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7388256442511263
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = cov_off_diag
# statistic = 0.4450969952889716 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2184562400897854
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = cov_off_diag
# statistic = 0.13215427151676817 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.2003890573264381
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.001220703125 - deformation = cov_off_diag
# statistic = 0.05218101422480189 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.6976296738476072
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0018310546875 - deformation = cov_off_diag
# statistic = 0.08632677385792614 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.22382497158945122
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00213623046875 - deformation = cov_off_diag
# statistic = 0.10690289592479833 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.010985255211903036
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.002288818359375 - deformation = cov_off_diag
# statistic = 0.11826262826234524 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.08994083725200602
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0022125244140625 - deformation = cov_off_diag
# statistic = 0.11384402335601473 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.03508771929824561
# relative_error_metric = 0.051911359742989556
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00217437744140625 - deformation = cov_off_diag
# statistic = 0.10987942292525525 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.017699115044247787
# relative_error_metric = 0.016476963172017828
# =======> statistic within required accuracy at 0.95 CL in 403.4341383050196 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.002155303955078125 - deformation = cov_off_diag
# statistic = 0.10703664581766917 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9982764997693103
# relative_error_metric = 0.4254624183315289
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.501077651977539 - deformation = cov_off_diag
# statistic = 641.7533921512111 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9965559674340814
# relative_error_metric = 1.9989725652230312
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2516164779663086 - deformation = cov_off_diag
# statistic = 727.1925605450557 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9931237758381348
# relative_error_metric = 1.9990932530276146
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6268858909606934 - deformation = cov_off_diag
# statistic = 621.3749123375663 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9862946721295942
# relative_error_metric = 1.9989388786287965
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31452059745788574 - deformation = cov_off_diag
# statistic = 279.36535035456535 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.972775901854717
# relative_error_metric = 1.9976405802231367
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.15833795070648193 - deformation = cov_off_diag
# statistic = 116.23483239106284 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9462830021206032
# relative_error_metric = 1.9943339280432029
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08024662733078003 - deformation = cov_off_diag
# statistic = 45.532570133567575 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.8953760465831209
# relative_error_metric = 1.985567485184462
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04120096564292908 - deformation = cov_off_diag
# statistic = 16.886185239984513 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.8011541144972316
# relative_error_metric = 1.9613203596794777
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.0216781347990036 - deformation = cov_off_diag
# statistic = 6.03698240095203 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.6382722648935406
# relative_error_metric = 1.8936563127348454
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.011916719377040863 - deformation = cov_off_diag
# statistic = 2.1822095436878333 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.3873506590459652
# relative_error_metric = 1.7190015534428327
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.007036011666059494 - deformation = cov_off_diag
# statistic = 0.8595421104471305 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.06202591928342
# relative_error_metric = 1.3561953825151691
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0045956578105688095 - deformation = cov_off_diag
# statistic = 0.395927317897916 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.7229647982628825
# relative_error_metric = 0.8239695788031268
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0033754808828234673 - deformation = cov_off_diag
# statistic = 0.22880292656867735 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.4412310236274834
# relative_error_metric = 0.32472967808106945
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.002765392418950796 - deformation = cov_off_diag
# statistic = 0.16806628594548606 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.24796834329899883
# relative_error_metric = 0.01912605365818674
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0024603481870144606 - deformation = cov_off_diag
# statistic = 0.1334011067798113 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.11674679435413356
# relative_error_metric = 0.21108236908946312
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.0026128703029826283 - deformation = cov_off_diag
# statistic = 0.1527700171976015 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.05671798640336328
# relative_error_metric = 0.07626119703402771
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0026891313609667122 - deformation = cov_off_diag
# statistic = 0.15703070348332532 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.027962499041570676
# relative_error_metric = 0.048780797693755255
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.002727261889958754 - deformation = cov_off_diag
# statistic = 0.16425827198372328 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.013884190355905341
# relative_error_metric = 0.003791801265771268
# =======> statistic within required accuracy at 0.99 CL in 433.06837970088236 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 836.5025678891689 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_up
# statistic = 43127899.584949374 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999999899755156
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_up
# statistic = 148556.62741600705 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999970897654133
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_up
# statistic = 6806.401481474136 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999364821358692
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_up
# statistic = 819.7228285286528 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9994726535151333
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_up
# statistic = 146.18568254080523 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9970447479700106
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_up
# statistic = 31.071203146273653 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.98613390513449
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_up
# statistic = 7.170652158961336 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9406030173478086
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_up
# statistic = 1.7299112459341863 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.764779037114466
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.4333468992178474 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2014952230343363
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.12278961124316612 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.12739342920928406
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_up
# statistic = 0.04949283637197396 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7436498922648643
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_up
# statistic = 0.07627556110473384 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.34506723108754916
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0042724609375 - deformation = power_abs_up
# statistic = 0.09144720996082539 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.16675636233727922
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00457763671875 - deformation = power_abs_up
# statistic = 0.10528254453745092 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.026257128152583867
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.004730224609375 - deformation = power_abs_up
# statistic = 0.11035919629022813 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.020833439738323727
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0046539306640625 - deformation = power_abs_up
# statistic = 0.10705363860613352 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.016260162601626018
# relative_error_metric = 0.009576195963043568
# =======> statistic within required accuracy at 0.95 CL in 369.45135357696563 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00469207763671875 - deformation = power_abs_up
# statistic = 0.11285213390105889 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.996249857082968
# relative_error_metric = 0.37467559974631126
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5023460388183594 - deformation = power_abs_up
# statistic = 43596827.5844645 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9925137514169855
# relative_error_metric = 1.999999984872084
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.253519058227539 - deformation = power_abs_up
# statistic = 150969.1145799045 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9850833377547694
# relative_error_metric = 1.9999956313684384
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6291055679321289 - deformation = power_abs_up
# statistic = 6965.0456730586375 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.970387535078282
# relative_error_metric = 1.9999053109516371
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31689882278442383 - deformation = power_abs_up
# statistic = 851.3082089158897 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.94163917411128
# relative_error_metric = 1.9992254257169788
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.1607954502105713 - deformation = power_abs_up
# statistic = 156.29984516012058 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.8865877640990916
# relative_error_metric = 1.9957848061356607
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08274376392364502 - deformation = power_abs_up
# statistic = 35.2385984607015 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.7853476307662943
# relative_error_metric = 1.9813710645068898
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.043717920780181885 - deformation = power_abs_up
# statistic = 9.076448182398405 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.612305078276501
# relative_error_metric = 1.9286326615937313
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.024204999208450317 - deformation = power_abs_up
# statistic = 2.6831247267683387 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.3505117957973443
# relative_error_metric = 1.7684243208322752
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.014448538422584534 - deformation = power_abs_up
# statistic = 0.9466290085707394 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.019451072592166
# relative_error_metric = 1.4066374672852
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.009570308029651642 - deformation = power_abs_up
# statistic = 0.4169368474350589 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.6840693425413932
# relative_error_metric = 0.8664361191593792
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.007131192833185196 - deformation = power_abs_up
# statistic = 0.2337962043459938 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.4125956862232319
# relative_error_metric = 0.34571172299349767
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.005911635234951973 - deformation = power_abs_up
# statistic = 0.1709777225849173 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.23002463627460884
# relative_error_metric = 0.03629746071201368
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0053018564358353615 - deformation = power_abs_up
# statistic = 0.13388378803573597 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.10875805984770433
# relative_error_metric = 0.20751018304124574
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.005606745835393667 - deformation = power_abs_up
# statistic = 0.15424744083233208 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.052939627139659606
# relative_error_metric = 0.06664906419245072
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.00575919053517282 - deformation = power_abs_up
# statistic = 0.15618736410400635 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.02612406401771223
# relative_error_metric = 0.05416223908932008
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0058354128850623965 - deformation = power_abs_up
# statistic = 0.16086036500795392 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.01297727720374456
# relative_error_metric = 0.02469387853249622
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.005873524060007185 - deformation = power_abs_up
# statistic = 0.16752197665314067 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.006509758336487778
# relative_error_metric = 0.01588238862488731
# =======> statistic within required accuracy at 0.99 CL in 431.3777243399527 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 800.8291260828264 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_down
# statistic = 1.0 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6098354888173463
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_down
# statistic = 1021.2403728434423 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995767018131931
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_down
# statistic = 587.8629371273009 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9992647002412929
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_down
# statistic = 241.50224656056747 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9982106106587607
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_down
# statistic = 79.46703090133018 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9945669578770808
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_down
# statistic = 22.98477624438747 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.98127841462215
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_down
# statistic = 6.204489784807665 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.931512092770925
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_down
# statistic = 1.6310555583003297 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7514086704688085
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.43609983408026426 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2055347268954424
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.1201337604253188 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.10560121897556594
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_down
# statistic = 0.052342685381437305 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.6949111135140356
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_down
# statistic = 0.07915998104615724 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.30894234134525195
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0042724609375 - deformation = power_abs_down
# statistic = 0.10096537224744007 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.06810232490604953
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00457763671875 - deformation = power_abs_down
# statistic = 0.10856830250832243 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.004473210280346955
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.004425048828125 - deformation = power_abs_down
# statistic = 0.11303099919154846 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.03508771929824561
# relative_error_metric = 0.04474836751929588
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0043487548828125 - deformation = power_abs_down
# statistic = 0.0998355863054474 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.017391304347826087
# relative_error_metric = 0.07933991884954335
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00438690185546875 - deformation = power_abs_down
# statistic = 0.10645886872061905 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.008658008658008658
# relative_error_metric = 0.015147282403089933
# =======> statistic within required accuracy at 0.95 CL in 403.1617348731961 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.004405975341796875 - deformation = power_abs_down
# statistic = 0.10613524062081554 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9964783230109575
# relative_error_metric = 0.4335295143064605
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5022029876708984 - deformation = power_abs_down
# statistic = 1.0 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9929690264308297
# relative_error_metric = 1.4338233442838648
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2533044815063477 - deformation = power_abs_down
# statistic = 1022.4945441097382 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9859873142731488
# relative_error_metric = 1.9993550842615762
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6288552284240723 - deformation = power_abs_down
# statistic = 591.711562927359 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.9721696177463865
# relative_error_metric = 1.9988856979113427
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31663060188293457 - deformation = power_abs_down
# statistic = 246.22950524151847 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.945103135849687
# relative_error_metric = 1.9973232784815418
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16051828861236572 - deformation = power_abs_down
# statistic = 83.16088294322971 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.893139426882113
# relative_error_metric = 1.9920849312660014
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.0824621319770813 - deformation = power_abs_down
# statistic = 25.37544586238976 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.7971188516575693
# relative_error_metric = 1.974176950460355
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04343405365943909 - deformation = power_abs_down
# statistic = 7.605971173407864 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.6316076362175245
# relative_error_metric = 1.915127834766618
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.02392001450061798 - deformation = power_abs_down
# statistic = 2.4220254450675034 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.377818693530781
# relative_error_metric = 1.7450511472646573
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.014162994921207428 - deformation = power_abs_down
# statistic = 0.8822439944769943 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 1.0508950621618314
# relative_error_metric = 1.370153181095652
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.009284485131502151 - deformation = power_abs_down
# statistic = 0.39458564239473015 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.7126874657313391
# relative_error_metric = 0.8211493077627846
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.006845230236649513 - deformation = power_abs_down
# statistic = 0.22384868499827046 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.43359884909141627
# relative_error_metric = 0.30337893834341956
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.005625602789223194 - deformation = power_abs_down
# statistic = 0.1584774154483775 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.19559678890672497
# relative_error_metric = 0.03961454832551351
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.006235416512936354 - deformation = power_abs_down
# statistic = 0.1866865400361781 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.1028265291840694
# relative_error_metric = 0.12403972368256909
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.005930509651079774 - deformation = power_abs_down
# statistic = 0.1723274592607144 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.05276979839572866
# relative_error_metric = 0.04415749840412865
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.005778056220151484 - deformation = power_abs_down
# statistic = 0.1664454134392797 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.026737634087964493
# relative_error_metric = 0.009435514392500646
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.005701829504687339 - deformation = power_abs_down
# statistic = 0.1590703189684867 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.013280047779432955
# relative_error_metric = 0.03588161143073621
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.0057399428624194115 - deformation = power_abs_down
# statistic = 0.16047800920143246 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.006618051878428404
# relative_error_metric = 0.02707325137946486
#
# ------------ 19 - 0.99 CL ------------
# eps = 0.005758999541285448 - deformation = power_abs_down
# statistic = 0.16958398157881166 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.003314509838730271
# relative_error_metric = 0.028114594494576466
#
# ------------ 20 - 0.99 CL ------------
# eps = 0.00574947120185243 - deformation = power_abs_down
# statistic = 0.1628425759725479 - next threshold = 0.1648822897830853 at 0.99 CL
# relative_error_eps = 0.0016558828093992512
# relative_error_metric = 0.012447720778430761
# =======> statistic within required accuracy at 0.99 CL in 473.9120193729177 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 877.0738010511268 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with random_normal deformation.
#
# ======================================================
# =============== fgd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 363.97931201796894 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9988125517257427
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 59.352537665253294 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.992729054295605
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 7.1488454978973035 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9404245327812768
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 0.6396701052801124 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4218218281639132
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 0.061654275141411786 - next threshold = 0.10808373744214016 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# ...
# statistic = 3.9977891923962323 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.7760401478417145
# relative_error_metric = 1.563486875453675
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04394501447677612 - deformation = power_abs_down
# statistic = 2.2175319004079115 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.5971872388956314
# relative_error_metric = 1.2764402385768887
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.024432986974716187 - deformation = power_abs_down
# statistic = 1.2901212225167962 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.3294312938154536
# relative_error_metric = 0.8994181144354699
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.014676973223686218 - deformation = power_abs_down
# statistic = 0.8325467333526495 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.9956166195887302
# relative_error_metric = 0.5185564652474368
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.009798966348171234 - deformation = power_abs_down
# statistic = 0.62074584311615 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.6627760132612904
# relative_error_metric = 0.23599675193484174
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.007359962910413742 - deformation = power_abs_down
# statistic = 0.526713530167163 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.39720199536800405
# relative_error_metric = 0.07280420715898775
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.006140461191534996 - deformation = power_abs_down
# statistic = 0.48471279542729795 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.18066124584970858
# relative_error_metric = 0.010263792774738786
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.006750212050974369 - deformation = power_abs_down
# statistic = 0.5052118510403382 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.09460341565847895
# relative_error_metric = 0.03115490392913877
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0064453366212546825 - deformation = power_abs_down
# statistic = 0.49483107270176474 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.04844753336333948
# relative_error_metric = 0.010395919388620608
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.006292898906394839 - deformation = power_abs_down
# statistic = 0.4897369020619933 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.02452075925722191
# relative_error_metric = 4.7888300224493425e-05
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.006216680048964918 - deformation = power_abs_down
# statistic = 0.48721719490277837 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.012185679102695217
# relative_error_metric = 0.005110403826712217
# =======> statistic within required accuracy at 0.99 CL in 174.87970737111755 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 313.5332931471057 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 7.714821922372373 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7810028634905886
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 2.2153973293539178 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3286180360767734
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 0.6713178021536266 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4015019397218469
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 0.39488417695628686 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1234630867982704
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_normal
# statistic = 0.4883120706743448 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.08868372282111425
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.390625 - deformation = random_normal
# statistic = 0.4317686976419186 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.034319383905609895
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.4296875 - deformation = random_normal
# statistic = 0.4560629623516834 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.020417390253105374
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.41015625 - deformation = random_normal
# statistic = 0.4426948277730237 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.009332051707226053
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.419921875 - deformation = random_normal
# statistic = 0.44978056579390024 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.023529411764705882
# relative_error_metric = 0.006547033143140154
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.4150390625 - deformation = random_normal
# statistic = 0.447277148558263 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.011834319526627219
# relative_error_metric = 0.0009656458168584011
# =======> statistic within required accuracy at 0.95 CL in 96.58959046402015 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.41259765625 - deformation = random_normal
# statistic = 0.4457109347515575 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.695083446098331
# relative_error_metric = 0.09408032530165118
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.706298828125 - deformation = random_normal
# statistic = 8.831487566790715 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.4708414872798434
# relative_error_metric = 1.7898496345799566
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.5594482421875 - deformation = random_normal
# statistic = 3.32579421818264 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.163107397090684
# relative_error_metric = 1.4866072957524177
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.98602294921875 - deformation = random_normal
# statistic = 1.4296095823410209 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.8199869081387737
# relative_error_metric = 0.9794037966194331
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.699310302734375 - deformation = random_normal
# statistic = 0.7965439424744574 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.5157129134074379
# relative_error_metric = 0.47709034649590487
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.5559539794921875 - deformation = random_normal
# statistic = 0.5794838867032894 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.2960220559275305
# relative_error_metric = 0.1679211753894982
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.48427581787109375 - deformation = random_normal
# statistic = 0.5027320188126982 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.15984007485857685
# relative_error_metric = 0.026235333359154598
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.4484367370605469 - deformation = random_normal
# statistic = 0.471261302005812 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.07684914418928038
# relative_error_metric = 0.03840298178960559
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.4663562774658203 - deformation = random_normal
# statistic = 0.48707054291889407 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.03770026384165488
# relative_error_metric = 0.0054114462483461565
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.47531604766845703 - deformation = random_normal
# statistic = 0.49332529110784673 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.01902948608234633
# relative_error_metric = 0.007348319046311209
# =======> statistic within required accuracy at 0.99 CL in 91.74904778995551 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 188.33867326099426 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_uniform
# statistic = 2.8861447053678817 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.463730253693769
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_uniform
# statistic = 0.8350289645640794 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6056498449037363
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_uniform
# statistic = 0.413405710236765 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.0777441220968795
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.9375 - deformation = random_uniform
# statistic = 0.563959727678189 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.23172473801552498
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.78125 - deformation = random_uniform
# statistic = 0.4715539412220525 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.0538077352564412
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.703125 - deformation = random_uniform
# statistic = 0.4401702641148162 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.015050875645695018
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.7421875 - deformation = random_uniform
# statistic = 0.45578573944226275 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.019809405885232997
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.72265625 - deformation = random_uniform
# statistic = 0.44696813295691684 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.0273972602739726
# relative_error_metric = 0.0002745254111840038
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.712890625 - deformation = random_uniform
# statistic = 0.4426864058101454 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.013605442176870748
# relative_error_metric = 0.009351075781430034
# =======> statistic within required accuracy at 0.95 CL in 84.23956779111177 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.7177734375 - deformation = random_uniform
# statistic = 0.44639000850233973 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.497865072587532
# relative_error_metric = 0.09256122506962744
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.85888671875 - deformation = random_uniform
# statistic = 3.6937238831193535 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.197269624573379
# relative_error_metric = 1.5317597363450721
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.788330078125 - deformation = random_uniform
# statistic = 1.5562866812543887 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.8543594739405748
# relative_error_metric = 1.0425935121204681
#
# ------------ 4 - 0.99 CL ------------
# eps = 1.2530517578125 - deformation = random_uniform
# statistic = 0.8358172013881868 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.5432022297925054
# relative_error_metric = 0.5222116155240069
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.98541259765625 - deformation = random_uniform
# statistic = 0.5961408224742037 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.31428059487547033
# relative_error_metric = 0.19602514853176742
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.851593017578125 - deformation = random_uniform
# statistic = 0.5111629925166195 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.1705396208070005
# relative_error_metric = 0.04286151946567532
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.7846832275390625 - deformation = random_uniform
# statistic = 0.4744024979568541 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.08178299995337343
# relative_error_metric = 0.03176164035463319
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.8181381225585938 - deformation = random_uniform
# statistic = 0.49218727161573206 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.04174500797296332
# relative_error_metric = 0.005038842737656405
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.8014106750488281 - deformation = random_uniform
# statistic = 0.4818293320242222 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.020656923131278634
# relative_error_metric = 0.01623009933838924
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.8097743988037109 - deformation = random_uniform
# statistic = 0.4861515484383959 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.010275397043919414
# relative_error_metric = 0.007299988263135892
# =======> statistic within required accuracy at 0.99 CL in 89.96048282505944 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 174.20009320997633 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T22:25:17.809750', 'fgd_cov_diag_2024-05-02T22:37:31.785396', 'fgd_cov_off_diag_2024-05-02T22:49:50.519004', 'fgd_power_abs_up_2024-05-02T23:03:47.029243', 'fgd_power_abs_down_2024-05-02T23:17:07.867752', 'fgd_random_normal_2024-05-02T23:31:44.947598', 'fgd_random_uniform_2024-05-02T23:41:43.519610', 'mmd_mean_2024-05-02T23:51:31.334587', 'mmd_cov_diag_2024-05-02T23:59:20.224777', 'mmd_cov_off_diag_2024-05-03T00:07:20.636605', 'mmd_power_abs_up_2024-05-03T00:14:08.841253', 'mmd_power_abs_down_2024-05-03T00:21:26.139686', 'mmd_random_normal_2024-05-03T00:28:42.885537', 'mmd_random_uniform_2024-05-03T00:33:28.029184', 'ks_mean_2024-05-03T00:36:56.050822', 'ks_cov_diag_2024-05-03T00:40:42.480603', 'ks_cov_off_diag_2024-05-03T00:45:00.844773', 'ks_power_abs_up_2024-05-03T00:48:36.737858', 'ks_power_abs_down_2024-05-03T00:53:29.187157', 'ks_random_normal_2024-05-03T00:58:24.958829', 'ks_random_uniform_2024-05-03T01:01:27.738158', 'sks_mean_2024-05-03T01:04:05.345524', 'sks_cov_diag_2024-05-03T01:08:41.920546', 'sks_cov_off_diag_2024-05-03T01:14:24.879227', 'sks_power_abs_up_2024-05-03T01:19:49.065645', 'sks_power_abs_down_2024-05-03T01:26:12.693896', 'sks_random_normal_2024-05-03T01:32:30.312562', 'sks_random_uniform_2024-05-03T01:36:34.598419', 'swd_mean_2024-05-03T01:40:12.456820', 'swd_cov_diag_2024-05-03T01:43:53.934006', 'swd_cov_off_diag_2024-05-03T01:48:50.669265', 'swd_power_abs_up_2024-05-03T01:53:03.205865', 'swd_power_abs_down_2024-05-03T01:58:13.189873', 'swd_random_normal_2024-05-03T02:03:26.733561', 'swd_random_uniform_2024-05-03T02:06:35.083750'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normnal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.005 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 60.19433666206896 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], 1.8423281840237182], [0.99, [9900, 100], 3.978728600174841]]
# Null distribution computed in 60.418829526985064 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 8.546090809162706 seconds.
# statistic = 3.3401711989444847 - next threshold = 1.8423281840237182 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5780388589502921
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.0025 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 58.23244039108977 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_mean_0.002500.json
# ThresholdS: [[0.95, [9500, 500], 1.7136364040904972], [0.99, [9900, 100], 2.7818366128246033]]
# Null distribution computed in 58.45569908595644 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 7.455688998103142 seconds.
# statistic = 0.8776132870643317 - next threshold = 1.7136364040904972 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.6452663515059248
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.00375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 66.1266878650058 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_mean_0.003750.json
# ThresholdS: [[0.95, [9500, 500], 1.9761003714182226], [0.99, [9900, 100], 3.578400684519382]]
# Null distribution computed in 66.37390979495831 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 11.17116254195571 seconds.
# statistic = 1.9107741651164574 - next threshold = 1.9761003714182226 at 0.95 CL
# relative_error_eps = 0.28571428571428575
# relative_error_metric = 0.03361374579381531
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.004375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 60.30657183402218 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_mean_0.004375.json
# ThresholdS: [[0.95, [9500, 500], 1.9587437973905215], [0.99, [9900, 100], 3.828094160699573]]
# Null distribution computed in 60.58563356101513 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 9.770006243139505 seconds.
# statistic = 2.575943162624338 - next threshold = 1.9587437973905215 at 0.95 CL
# relative_error_eps = 0.15384615384615397
# relative_error_metric = 0.27221255653413134
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.0040625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 59.60953419399448 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_mean_0.004063.json
# ThresholdS: [[0.95, [9500, 500], 1.979804465638849], [0.99, [9900, 100], 3.7156298025268653]]
# Null distribution computed in 59.84070296399295 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 9.725126719800755 seconds.
# statistic = 2.2309762838871556 - next threshold = 1.979804465638849 at 0.95 CL
# relative_error_eps = 0.08000000000000007
# relative_error_metric = 0.11929940464203954
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.00390625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 60.852045978885144 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_mean_0.003906.json
# ThresholdS: [[0.95, [9500, 500], 1.9810480136725188], [0.99, [9900, 100], 3.650110838008562]]
# Null distribution computed in 61.10724670509808 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 9.217424664879218 seconds.
# statistic = 2.0677796296870956 - next threshold = 1.9810480136725188 at 0.95 CL
# relative_error_eps = 0.04081632653061228
# relative_error_metric = 0.042842829408568796
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.003828125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 61.37519567320123 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_mean_0.003828.json
# ThresholdS: [[0.95, [9500, 500], 1.979348091660639], [0.99, [9900, 100], 3.6150296610377843]]
# Null distribution computed in 61.59209483116865 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 9.341460221912712 seconds.
# statistic = 1.9885029986816354 - next threshold = 1.979348091660639 at 0.95 CL
# relative_error_eps = 0.020618556701030948
# relative_error_metric = 0.004614541630999915
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.0037890625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 61.18455107300542 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_mean_0.003789.json
# ThresholdS: [[0.95, [9500, 500], 1.9779177066475202], [0.99, [9900, 100], 3.5969086472281275]]
# Null distribution computed in 61.41087787505239 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 9.14134014188312 seconds.
# statistic = 1.9494451071860839 - next threshold = 1.9779177066475202 at 0.95 CL
# relative_error_eps = 0.010256410256410265
# relative_error_metric = 0.014499602308778522
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.00380859375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# ...
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 58.19763438194059 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_power_abs_down_0.000345.json
# ThresholdS: [[0.95, [9500, 500], 1.6276265874961109], [0.99, [9900, 100], 3.9755441937185108]]
# Null distribution computed in 58.35745267593302 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.691951744956896 seconds.
# statistic = 3.8902948557608648 - next threshold = 3.9755441937185108 at 0.99 CL
# relative_error_eps = 0.027273107140451107
# relative_error_metric = 0.021675840917006427
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0003494790196418762 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 58.59750907612033 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_power_abs_down_0.000349.json
# ThresholdS: [[0.95, [9500, 500], 1.5976236829853219], [0.99, [9900, 100], 3.97818137207922]]
# Null distribution computed in 58.75945362402126 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.689630375010893 seconds.
# statistic = 3.9963883736257912 - next threshold = 3.97818137207922 at 0.99 CL
# relative_error_eps = 0.013730169667323927
# relative_error_metric = 0.004566265548402083
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.00034709617495536804 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 64.96411320799962 seconds.
# Saving lr to results/100D_unimodal/100D_20K/null_hypothesis/LR_power_abs_down_0.000347.json
# ThresholdS: [[0.95, [9500, 500], 1.6128045365941253], [0.99, [9900, 100], 3.977041638318878]]
# Null distribution computed in 65.1312536150217 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 8.297529259929433 seconds.
# statistic = 3.9431634101128528 - next threshold = 3.977041638318878 at 0.99 CL
# relative_error_eps = 0.006841600748892368
# relative_error_metric = 0.008554886647217156
# =======> statistic within required accuracy at 0.99 CL in 886.0792588428594 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1776.4208664959297 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T22:25:17.809750', 'fgd_cov_diag_2024-05-02T22:37:31.785396', 'fgd_cov_off_diag_2024-05-02T22:49:50.519004', 'fgd_power_abs_up_2024-05-02T23:03:47.029243', 'fgd_power_abs_down_2024-05-02T23:17:07.867752', 'fgd_random_normal_2024-05-02T23:31:44.947598', 'fgd_random_uniform_2024-05-02T23:41:43.519610', 'mmd_mean_2024-05-02T23:51:31.334587', 'mmd_cov_diag_2024-05-02T23:59:20.224777', 'mmd_cov_off_diag_2024-05-03T00:07:20.636605', 'mmd_power_abs_up_2024-05-03T00:14:08.841253', 'mmd_power_abs_down_2024-05-03T00:21:26.139686', 'mmd_random_normal_2024-05-03T00:28:42.885537', 'mmd_random_uniform_2024-05-03T00:33:28.029184', 'ks_mean_2024-05-03T00:36:56.050822', 'ks_cov_diag_2024-05-03T00:40:42.480603', 'ks_cov_off_diag_2024-05-03T00:45:00.844773', 'ks_power_abs_up_2024-05-03T00:48:36.737858', 'ks_power_abs_down_2024-05-03T00:53:29.187157', 'ks_random_normal_2024-05-03T00:58:24.958829', 'ks_random_uniform_2024-05-03T01:01:27.738158', 'sks_mean_2024-05-03T01:04:05.345524', 'sks_cov_diag_2024-05-03T01:08:41.920546', 'sks_cov_off_diag_2024-05-03T01:14:24.879227', 'sks_power_abs_up_2024-05-03T01:19:49.065645', 'sks_power_abs_down_2024-05-03T01:26:12.693896', 'sks_random_normal_2024-05-03T01:32:30.312562', 'sks_random_uniform_2024-05-03T01:36:34.598419', 'swd_mean_2024-05-03T01:40:12.456820', 'swd_cov_diag_2024-05-03T01:43:53.934006', 'swd_cov_off_diag_2024-05-03T01:48:50.669265', 'swd_power_abs_up_2024-05-03T01:53:03.205865', 'swd_power_abs_down_2024-05-03T01:58:13.189873', 'swd_random_normal_2024-05-03T02:03:26.733561', 'swd_random_uniform_2024-05-03T02:06:35.083750', 'lr_mean_2024-05-03T02:09:29.349302', 'lr_cov_diag_2024-05-03T02:29:18.223218', 'lr_cov_off_diag_2024-05-03T02:57:14.726769', 'lr_power_abs_up_2024-05-03T03:41:41.286799', 'lr_power_abs_down_2024-05-03T04:12:15.616798'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean  100  10000                20000
# 7        mmd        mean  100  10000                20000
# 14        ks        mean  100  10000                20000
# 0        fgd        mean  100  10000                20000
# 28       swd        mean  100  10000                20000
# 21       sks        mean  100  10000                20000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.00382                             0.00548
# 7                              0.04181                             0.05407
# 14                             0.06073                             0.07460
# 0                              0.06210                             0.07838
# 28                             0.06409                             0.08036
# 21                             0.06775                             0.08521
#
#     $t^{\mu}$ (s)
# 35           1188
# 7             468
# 14            226
# 0             733
# 28            221
# 21            276
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.00382
# 7        mmd                             0.04181
# 14        ks                             0.06073
# 0        fgd                             0.06210
# 28       swd                             0.06409
# 21       sks                             0.06775
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.00548           1188
# 7                              0.05407            468
# 14                             0.07460            226
# 0                              0.07838            733
# 28                             0.08036            221
# 21                             0.08521            276

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag  100  10000                20000
# 1        fgd    cov_diag  100  10000                20000
# 29       swd    cov_diag  100  10000                20000
# 8        mmd    cov_diag  100  10000                20000
# 15        ks    cov_diag  100  10000                20000
# 22       sks    cov_diag  100  10000                20000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00047
# 1                                      0.01846
# 29                                     0.02243
# 8                                      0.02579
# 15                                     0.02762
# 22                                     0.02853
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00081                   1676
# 1                                      0.02318                    738
# 29                                     0.02866                    296
# 8                                      0.03338                    480
# 15                                     0.03460                    258
# 22                                     0.03612                    342
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00047
# 1        fgd                                     0.01846
# 29       swd                                     0.02243
# 8        mmd                                     0.02579
# 15        ks                                     0.02762
# 22       sks                                     0.02853
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00081                   1676
# 1                                      0.02318                    738
# 29                                     0.02866                    296
# 8                                      0.03338                    480
# 15                                     0.03460                    258
# 22                                     0.03612                    342

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag  100  10000                20000
# 2        fgd  cov_off_diag  100  10000                20000
# 9        mmd  cov_off_diag  100  10000                20000
# 30       swd  cov_off_diag  100  10000                20000
# 23       sks  cov_off_diag  100  10000                20000
# 16        ks  cov_off_diag  100  10000                20000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00002
# 2                                           0.00216
# 9                                           0.01518
# 30                                          0.02548
# 23                                          0.02853
# 16                                          1.01501
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00003
# 2                                           0.00275
# 9                                           0.01990
# 30                                          0.03307
# 23                                          0.03733
# 16                                          1.01696
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        2666
# 2                          836
# 9                          408
# 30                         252
# 23                         324
# 16                         215
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00002
# 2        fgd                                          0.00216
# 9        mmd                                          0.01518
# 30       swd                                          0.02548
# 23       sks                                          0.02853
# 16        ks                                          1.01501
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00003
# 2                                           0.00275
# 9                                           0.01990
# 30                                          0.03307
# 23                                          0.03733
# 16                                          1.01696
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        2666
# 2                          836
# 9                          408
# 30                         252
# 23                         324
# 16                         215

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up  100  10000                20000
# 10       mmd  power_abs_up  100  10000                20000
# 3        fgd  power_abs_up  100  10000                20000
# 31       swd  power_abs_up  100  10000                20000
# 24       sks  power_abs_up  100  10000                20000
# 17        ks  power_abs_up  100  10000                20000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00025
# 10                                      0.00329
# 3                                       0.00469
# 31                                      0.00523
# 24                                      0.00591
# 17                                      0.00629
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00036                    1834
# 10                                      0.00424                     437
# 3                                       0.00585                     800
# 31                                      0.00656                     309
# 24                                      0.00740                     383
# 17                                      0.00763                     292
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00025
# 10       mmd                                      0.00329
# 3        fgd                                      0.00469
# 31       swd                                      0.00523
# 24       sks                                      0.00591
# 17        ks                                      0.00629
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00036                    1834
# 10                                      0.00424                     437
# 3                                       0.00585                     800
# 31                                      0.00656                     309
# 24                                      0.00740                     383
# 17                                      0.00763                     292

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down  100  10000                20000
# 11       mmd  power_abs_down  100  10000                20000
# 4        fgd  power_abs_down  100  10000                20000
# 32       swd  power_abs_down  100  10000                20000
# 25       sks  power_abs_down  100  10000                20000
# 18        ks  power_abs_down  100  10000                20000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00024
# 11                                      0.00326
# 4                                       0.00441
# 32                                      0.00492
# 25                                      0.00546
# 18                                      0.00553
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00035                    1776
# 11                                      0.00429                     436
# 4                                       0.00575                     877
# 32                                      0.00625                     313
# 25                                      0.00686                     377
# 18                                      0.00702                     295
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00024
# 11       mmd                                      0.00326
# 4        fgd                                      0.00441
# 32       swd                                      0.00492
# 25       sks                                      0.00546
# 18        ks                                      0.00553
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00035                    1776
# 11                                      0.00429                     436
# 4                                       0.00575                     877
# 32                                      0.00625                     313
# 25                                      0.00686                     377
# 18                                      0.00702                     295

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        fgd  random_normal  100  10000                20000
# 33       swd  random_normal  100  10000                20000
# 26       sks  random_normal  100  10000                20000
# 19        ks  random_normal  100  10000                20000
# 12       mmd  random_normal  100  10000                20000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                                      0.18921
# 33                                     0.41260
# 26                                     0.43701
# 19                                     0.46143
# 12                                     1.01074
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.21211                    598
# 33                                     0.47084                    188
# 26                                     0.50385                    244
# 19                                     0.51904                    182
# 12                                     1.14466                    285
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        fgd                                     0.18921
# 33       swd                                     0.41260
# 26       sks                                     0.43701
# 19        ks                                     0.46143
# 12       mmd                                     1.01074
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.21211                    598
# 33                                     0.47084                    188
# 26                                     0.50385                    244
# 19                                     0.51904                    182
# 12                                     1.14466                    285

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform  100  10000                20000
# 34       swd  random_uniform  100  10000                20000
# 27       sks  random_uniform  100  10000                20000
# 20        ks  random_uniform  100  10000                20000
# 13       mmd  random_uniform  100  10000                20000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                                      0.32166
# 34                                     0.71777
# 27                                     0.76660
# 20                                     0.79590
# 13                                     1.74805
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.37077                    587
# 34                                     0.81396                    174
# 27                                     0.87409                    217
# 20                                     0.88622                    157
# 13                                     1.98940                    208
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                                     0.32166
# 34       swd                                     0.71777
# 27       sks                                     0.76660
# 20        ks                                     0.79590
# 13       mmd                                     1.74805
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.37077                    587
# 34                                     0.81396                    174
# 27                                     0.87409                    217
# 20                                     0.88622                    157
# 13                                     1.98940                    208

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.062 & 0.078 & 733 & cov_diag & 100 & 10000 & 20000 & 0.018 & 0.023 & 738 & cov_off_diag & 100 & 10000 & 20000 & 0.0022 & 0.0027 & 836 & 0.0047 & 0.0059 & 800 \\
# $\overline{D}$ & 0.061 & 0.075 & 226 & cov_diag & 100 & 10000 & 20000 & 0.028 & 0.035 & 258 & cov_off_diag & 100 & 10000 & 20000 & 1 & 1 & 215 & 0.0063 & 0.0076 & 292 \\
# $t_{\mathrm{LLR}}$ & 0.0038 & 0.0055 & 1188 & cov_diag & 100 & 10000 & 20000 & 0.00047 & 0.00081 & 1676 & cov_off_diag & 100 & 10000 & 20000 & 2e-05 & 3e-05 & 2666 & 0.00025 & 0.00036 & 1834 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.042 & 0.054 & 468 & cov_diag & 100 & 10000 & 20000 & 0.026 & 0.033 & 480 & cov_off_diag & 100 & 10000 & 20000 & 0.015 & 0.02 & 408 & 0.0033 & 0.0042 & 437 \\
# $\widetilde{D}$ & 0.068 & 0.085 & 276 & cov_diag & 100 & 10000 & 20000 & 0.029 & 0.036 & 342 & cov_off_diag & 100 & 10000 & 20000 & 0.029 & 0.037 & 324 & 0.0059 & 0.0074 & 383 \\
# $\widetilde{W}$ & 0.064 & 0.08 & 221 & cov_diag & 100 & 10000 & 20000 & 0.022 & 0.029 & 296 & cov_off_diag & 100 & 10000 & 20000 & 0.025 & 0.033 & 252 & 0.0052 & 0.0066 & 309 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.0044 & 0.0057 & 877 & 0.19 & 0.21 & 6e+02 & 0.32 & 0.37 & 5.9e+02 & 7488 \\
# $\overline{D}$ & 0.0055 & 0.007 & 295 & 0.46 & 0.52 & 1.8e+02 & 0.8 & 0.89 & 1.6e+02 & 530 \\
# $t_{\mathrm{LLR}}$ & 0.00024 & 0.00035 & 1776 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.0033 & 0.0043 & 436 & 1 & 1.1 & 2.8e+02 & 1.7 & 2 & 2.1e+02 & 2375 \\
# $\widetilde{D}$ & 0.0055 & 0.0069 & 377 & 0.44 & 0.5 & 2.4e+02 & 0.77 & 0.87 & 2.2e+02 & 600 \\
# $\widetilde{W}$ & 0.0049 & 0.0063 & 313 & 0.41 & 0.47 & 1.9e+02 & 0.72 & 0.81 & 1.7e+02 & 298 \\
# \bottomrule
# \end{tabular}
