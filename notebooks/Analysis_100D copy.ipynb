# %% [markdown]
# https://arxiv.org/pdf/2211.10295.pdf

# %% [markdown]
# # 1 Initialize

# %%
visible_devices = [2]
import datetime
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if len(visible_devices) == 0:
        visible_devices = int(visible_devices) # type: ignore
    elif len(visible_devices) == 1:
        if len(visible_devices[0]) == 0: # type: ignore
            visible_devices = int(visible_devices[0])
        else:
            visible_devices = [int(i) for i in visible_devices[0]] # type: ignore
    else:
        visible_devices = [int(i) for i in visible_devices]
print("Visible devices:", visible_devices)
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

sys.path.insert(0,'../utils_func/')
import MixtureDistributions # type: ignore

sys.path.insert(0,'../')
import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore

print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
gpu_models = get_gpu_info()
if gpu_models:
    training_device = gpu_models[eval(os.environ["CUDA_VISIBLE_DEVICES"])]
    print("Successfully loaded GPU model: {}".format(training_device))
else:
    training_device = 'undetermined'
    print("Failed to load GPU model. Defaulting to 'undetermined'.")
    
results_dir = "../results/"
null_hypotheses_dir = "../results/null_hypotheses/"
if not os.path.exists(results_dir):
    print("WARNING: Results directory does not exist")
if not os.path.exists(null_hypotheses_dir):
    print("WARNING: Null hypotheses directory does not exist")
    
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-01-09 18:01:57.915635: Importing os...
# 2024-01-09 18:01:57.915841: Importing sys...
# Visible devices: [2]
# 2024-01-09 18:01:57.916451: Importing timer from timeit...
# 2024-01-09 18:01:57.916598: Setting env variables for tf import (only device [2] will be available)...
# 2024-01-09 18:01:57.916847: Importing numpy...
# 2024-01-09 18:01:58.053671: Importing matplotlib...
# 2024-01-09 18:01:58.444931: Importing h5py...
# 2024-01-09 18:01:58.465851: Importing importlib.util...
# 2024-01-09 18:01:58.465959: Importing json...
# 2024-01-09 18:01:58.466021: Importing pandas...
# 2024-01-09 18:01:58.748285: Importing random...
# 2024-01-09 18:01:58.748444: Importing scipy utils...
# 2024-01-09 18:01:59.072009: Importing subprocess...
# 2024-01-09 18:01:59.072165: Importing tensorflow...
# Tensorflow version: 2.12.0
# 2024-01-09 18:02:00.990815: Importing tensorflow_probability...
# Tensorflow probability version: 0.20.1
# 2024-01-09 18:02:01.246895: Importing timeit...
# 2024-01-09 18:02:01.246993: Importing tqdm...
# 2024-01-09 18:02:01.250232: Importing typing...
# 2024-01-09 18:02:01.250347: Setting tf configs...
# 2024-01-09 18:02:01.501982: Importing GMetrics module...
# 2024-01-09 18:02:03.691264: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU model: NVIDIA A40
# 2024-01-09 18:02:03.738998: All done.

# %%
#seed = 0
#ndims = 5
#epsilon = 0.005
#GMetrics.utils.reset_random_seeds(seed)
#loc1 = np.array(np.zeros(ndims,dtype=np.float64),dtype=np.float64)
#scale1 = np.array(np.ones(ndims,dtype=np.float64),dtype=np.float64)
#loc2 = np.array(np.random.uniform(-epsilon,epsilon,ndims),dtype=np.float64)
#scale2 = np.array(np.random.uniform(1-epsilon,1+epsilon,ndims),dtype=np.float64)
#dist_1 = tfd.Independent(tfp.distributions.Normal(loc=loc1, scale=scale1), reinterpreted_batch_ndims=1)
#dist_2 = tfd.Independent(tfp.distributions.Normal(loc=loc2, scale=scale2), reinterpreted_batch_ndims=1)
#print(dist_1.dtype, dist_2.dtype)
#print('Types of distributions: ', type(dist_1), type(dist_2))
#print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
#print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
#print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)

# %% [markdown]
# # Null hypotheses

# %%
seed = 0
ncomp = 3
ndims = 100
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MixtureGaussian(ncomp, ndims, 0., 0., seed)
dist_2 = MixtureDistributions.MixtureGaussian(ncomp, ndims, eps_loc, eps_scale, seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture.Mixture'> <class 'tensorflow_probability.python.distributions.mixture.Mixture'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (100,) (100,)

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = 10_000,
                                                   batch_size_test = 10_000,
                                                   batch_size_gen = 100,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 100000000
# batch_size 10000
# niter 10000
# niter * batch_size 100000000
# small_sample False

# %%
TwoSampleTestInputs.dist_1_num
# Out:
# <tf.Tensor: shape=(1, 0), dtype=float64, numpy=array([], shape=(1, 0), dtype=float64)>

# %%
TwoSampleTestInputs.dist_2_num
# Out:
# <tf.Tensor: shape=(1, 0), dtype=float64, numpy=array([], shape=(1, 0), dtype=float64)>

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
MultiKSTest = GMetrics.MultiKSTest(TwoSampleTestInputs,
                                   progress_bar = True,
                                   verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
#d1 = np.array(TwoSampleTestInputs.dist_1_num).reshape(TwoSampleTestInputs.niter,TwoSampleTestInputs.batch_size_test,-1)
#d2 = np.array(TwoSampleTestInputs.dist_2_num).reshape(TwoSampleTestInputs.niter,TwoSampleTestInputs.batch_size_test,-1)
#print("------------------------------------------")
#print("Starting FPD metric calculation...")
#print("Running Jetnet FPD calculation...")
#print("niter = 10")
#print("batch_size = 10000")
#start = timer()
#FPDResult = [JMetrics.fpd(s1,s2)[0] for s1,s2 in zip(d1,d2)]
#end = timer()
#print(f"FPD metric calculation completed in {end-start} seconds.")

# %% [markdown]
# ## FN Test

# %%
FNMetric.Test_tf(max_vectorize = 1000)
FNMetric.Results[-1].result_value
# Out:
# ------------------------------------------
# Starting FN metric calculation...
# Running TF FN calculation...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7ff69460dcf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 5000 to 6000 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7ff69460d870> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# FN metric calculation completed in 320.90287630446255 seconds.
# {'metric_list': array([0.25455899, 0.17927174, 0.20059946, ..., 0.23806497, 0.21825904,
#         0.2859777 ])}

# %%
FNMetric.Results.save_to_json(null_hypotheses_dir+"Null_20D_FN.json")

# %%
FNMetric.Results.load_from_json(null_hypotheses_dir+"Null_20D_FN.json")

# %%
start = timer()

nsamples = FNMetric.Inputs.batch_size_test
niter = FNMetric.Inputs.niter
ns = nsamples**2 /(2*nsamples)

scale = 'log'
num_bins = 50  # number of bins|
dist_null = np.array(FNMetric.Results[-1].result_value["metric_list"])*np.sqrt(ns)/ndims
# Compute the mean and standard deviation of the sample and their standard errors
mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
print("mu =", mu, "+/-", deltamu)
print("sigma =", sigma, "+/-", deltasigma)
# Minimum and maximum x values
min_x = min(dist_null) # lower limit of the binning
max_x = max(dist_null) # upper limit of the binning
# Create an array of values
x = np.linspace(min_x, max_x, num_bins + 1)
# Create histogram for values and normalize counts to sum to 1
counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
cum_counts = np.cumsum(counts)/np.sum(counts)
# Get the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
# Calculate the theoretical PDF and CDF of the KS distribution for each x value
#theoretical_pdf_ks = kstwobign.pdf(x)
#theoretical_cdf_ks = kstwobign.cdf(x)

# Empirical SKS Normal
#empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=0.155)
#empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=0.155)
# Set up the figure and the two subplots
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
# Draw the first plot
ax[0].plot(bin_centers, counts, linestyle = '-', label='sFN Null', drawstyle='steps-mid')
#ax[0].plot(x, theoretical_pdf_ks, label='Theoretical distribution (KS)')
#ax[0].plot(x, empirical_pdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[0].set_yscale(scale)
#ax[0].set_xlim(0.005, 0.2)
#ax[0].set_ylim(0.01, 40)
ax[0].set_xlabel('Scaled Frobeinus Norm')
ax[0].set_ylabel('Number of pseudo-experiments')
ax[0].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - PDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[0].legend(loc='upper right')
# Draw the second plot
ax[1].plot(bin_centers, cum_counts, linestyle = '-', label='sFN Null', drawstyle='steps-mid')
#ax[1].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
#ax[1].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[1].set_yscale(scale)
#ax[1].set_xlim(0.005, 0.2)
#ax[1].set_ylim(9e-4, 1.5)
ax[1].set_xlabel('Scaled Frobeinus Norm')
ax[1].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[1].legend(loc='lower right')
## Draw the third plot
#ax[2].plot(bin_centers, cum_counts, linestyle = '-', label='FN Null', drawstyle='steps-mid')
##ax[2].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
##ax[2].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
#ax[2].set_yscale(scale)
#ax[2].set_xlim(0.25, 2)
#ax[2].set_ylim(0.8, 1)
#ax[2].set_xlabel('KS vs SKS')
#ax[2].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
#ax[2].legend(loc='lower right')
# Adjust the width space
plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
# Display the figure with the two subplots
plt.tight_layout()
#plt.savefig(results_path+'SKS_nsamples_'+str(nsamples)+'_ndims_'+'_'+str(ndims)+'_niter_'+str(niter)+'.pdf')
plt.show()
plt.close()
end = timer()
print("Time elapsed:", end-start, "seconds.")
# Out:
# mu = 0.747439595885676 +/- 0.0005708374865563447
# sigma = 0.23892205560733498 +/- 0.002175023154019007
# Time elapsed: 0.8281051367521286 seconds.

# %%
cl_list = [0.68, 0.95, 0.99]
fn_thresholds = [[cl, [int(cl*len(dist_null)), int((1-cl)*len(dist_null))], np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
fn_thresholds
# Out:
# [[0.68, [6800, 3199], 0.8186004313807393],
#  [0.95, [9500, 500], 1.2038495020448647],
#  [0.99, [9900, 100], 1.4759807705243078]]

# %% [markdown]
# ## KS Test

# %%
KSTest.Test_tf(max_vectorize=1000)
KSTest.Results[-1].result_value
# Out:
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# KS tests calculation completed in 746.5777342300862 seconds.
# {'statistic_lists': array([[0.0095    , 0.0079    , 0.01320001, ..., 0.01670003, 0.01120001,
#          0.0158    ],
#         [0.00829999, 0.01010001, 0.0133    , ..., 0.0126    , 0.00830001,
#          0.01100001],
#         [0.01320004, 0.0174    , 0.0122    , ..., 0.01730001, 0.01840001,
#          0.0169    ],
#         ...,
#         [0.01010001, 0.00890002, 0.00830001, ..., 0.01090001, 0.01000001,
#          0.01050001],
#         [0.01950002, 0.01460001, 0.01610005, ..., 0.01020002, 0.01480001,
#          0.01620001],
#         [0.01440001, 0.016     , 0.01110005, ..., 0.01660001, 0.0183    ,
#          0.01909995]]),
#  'statistic_means': array([0.01273   , 0.01055001, 0.01582501, ..., 0.010355  , 0.01338501,
#         0.015025  ]),
#  'statistic_stds': array([0.00341059, 0.00235043, 0.00298578, ..., 0.00154805, 0.00301916,
#         0.0027727 ]),
#  'pvalue_lists': array([[0.75759816, 0.91390467, 0.34831828, ..., 0.12294781, 0.55727684,
#          0.16466999],
#         [0.88114113, 0.68752146, 0.33934999, ..., 0.40533996, 0.8811397 ,
#          0.58061683],
#         [0.34831548, 0.09685266, 0.44627738, ..., 0.10027063, 0.06771171,
#          0.11496317],
#         ...,
#         [0.68752146, 0.82323891, 0.8811397 , ..., 0.59238249, 0.69937348,
#          0.63986593],
#         [0.0446291 , 0.23689765, 0.14966011, ..., 0.67563021, 0.22342992,
#          0.14491093],
#         [0.25096452, 0.15453792, 0.5689069 , ..., 0.12710845, 0.07024294,
#          0.05208117]]),
#  'pvalue_means': array([0.45812727, 0.63402106, 0.21689474, ..., 0.66079979, 0.38559295,
#         0.26055182]),
#  'pvalue_stds': array([0.28306122, 0.23886998, 0.18337304, ..., 0.16634213, 0.25586576,
#         0.18379397])}

# %%
KSTest.Results.save_to_json(null_hypotheses_dir+"Null_20D_KS.json")

# %%
KSTest.Results.load_from_json(null_hypotheses_dir+"Null_20D_KS.json")

# %%
start = timer()

nsamples = KSTest.Inputs.batch_size_test
niter = KSTest.Inputs.niter
ns = nsamples**2 /(2*nsamples)

scale = 'log'
num_bins = 50  # number of bins|
dist_null = np.array(KSTest.Results[-1].result_value["statistic_means"])*np.sqrt(ns)
# Compute the mean and standard deviation of the sample and their standard errors
mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
print("mu =", mu, "+/-", deltamu)
print("sigma =", sigma, "+/-", deltasigma)
# Minimum and maximum x values
min_x = min(dist_null) # lower limit of the binning
max_x = max(dist_null) # upper limit of the binning
# Create an array of values
x = np.linspace(min_x, max_x, num_bins + 1)
# Create histogram for values and normalize counts to sum to 1
counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
cum_counts = np.cumsum(counts)/np.sum(counts)
# Get the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
# Calculate the theoretical PDF and CDF of the KS distribution for each x value
theoretical_pdf_ks = kstwobign.pdf(x)
theoretical_cdf_ks = kstwobign.cdf(x)

# Empirical SKS Normal
#shape_fit, loc_fit, scale_fit = lognorm.fit(bin_centers, floc=0)
#empirical_pdf_norm = lognorm.pdf(x, shape_fit, loc_fit, scale_fit)
#empirical_cdf_norm = lognorm.cdf(x, shape_fit, loc_fit, scale_fit)
empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
# Set up the figure and the two subplots
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
# Draw the first plot
ax[0].plot(bin_centers, counts, linestyle = '-', label='KS Null', drawstyle='steps-mid')
ax[0].plot(x, theoretical_pdf_ks, label='Theoretical distribution (KS)')
#ax[0].plot(x, empirical_pdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[0].set_yscale(scale)
#ax[0].set_xlim(0.005*np.sqrt(ns), 0.025*np.sqrt(ns))
#ax[0].set_ylim(0.01, 5)
ax[0].set_xlabel('KS mean')
ax[0].set_ylabel('Number of pseudo-experiments')
ax[0].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - PDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[0].legend(loc='upper right')
# Draw the second plot
ax[1].plot(bin_centers, cum_counts, linestyle = '-', label='KS Null', drawstyle='steps-mid')
ax[1].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
#ax[1].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[1].set_yscale(scale)
#ax[1].set_xlim(0.005*np.sqrt(ns), 0.025*np.sqrt(ns))
#ax[1].set_ylim(9e-4, 1.5)
ax[1].set_xlabel('KS mean')
ax[1].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[1].legend(loc='lower right')
## Draw the third plot
#ax[2].plot(bin_centers, cum_counts, linestyle = '-', label='FN Null', drawstyle='steps-mid')
##ax[2].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
##ax[2].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
#ax[2].set_yscale(scale)
#ax[2].set_xlim(0.25, 2)
#ax[2].set_ylim(0.8, 1)
#ax[2].set_xlabel('KS vs SKS')
#ax[2].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
#ax[2].legend(loc='lower right')
# Adjust the width space
plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
# Display the figure with the two subplots
plt.tight_layout()
#plt.savefig(results_path+'SKS_nsamples_'+str(nsamples)+'_ndims_'+'_'+str(ndims)+'_niter_'+str(niter)+'.pdf')
plt.show()
plt.close()
end = timer()
print("Time elapsed:", end-start, "seconds.")
# Out:
# mu = 0.8658474889110941 +/- 0.0002117773982439262
# sigma = 0.1455257359520735 +/- 0.001645280787731525
# Time elapsed: 1.1460302658379078 seconds.

# %%
cl_list = [0.68, 0.95, 0.99]
ks_thresholds = [[cl, [int(cl*len(dist_null)), int((1-cl)*len(dist_null))], np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
ks_thresholds
# Out:
# [[0.68, [6800, 3199], 0.8941368037382328],
#  [0.95, [9500, 500], 1.1596554165953459],
#  [0.99, [9900, 100], 1.370373063828215]]

# %% [markdown]
# ## MultiKS Test (TO RERUN)

# %%
MultiKSTest.Test_tf()
MultiKSTest.Results[-1].result_value
# Out:
# ------------------------------------------
# Starting MultiKS tests calculation...
# Running TF MultiKS tests...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.

# %%
MultiKSTest.Results.save_to_json(null_hypotheses_dir+"Null_20D_MultiKS.json")

# %%
MultiKSTest.Results.load_from_json(null_hypotheses_dir+"Null_20D_MultiKS.json")

# %%
start = timer()

nsamples = MultiKSTest.Inputs.batch_size_test
niter = MultiKSTest.Inputs.niter
ns = nsamples**2 /(2*nsamples)

scale = 'log'
num_bins = 50  # number of bins|
dist_null = np.array(MultiKSTest.Results[-1].result_value["metric_list"])*np.sqrt(ns)
# Compute the mean and standard deviation of the sample and their standard errors
mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
print("mu =", mu, "+/-", deltamu)
print("sigma =", sigma, "+/-", deltasigma)
# Minimum and maximum x values
min_x = min(dist_null) # lower limit of the binning
max_x = max(dist_null) # upper limit of the binning
# Create an array of values
x = np.linspace(min_x, max_x, num_bins + 1)
# Create histogram for values and normalize counts to sum to 1
counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
cum_counts = np.cumsum(counts)/np.sum(counts)
# Get the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
# Calculate the theoretical PDF and CDF of the KS distribution for each x value
theoretical_pdf_ks = kstwobign.pdf(x)
theoretical_cdf_ks = kstwobign.cdf(x)

# Empirical SKS Normal
empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
# Set up the figure and the two subplots
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
# Draw the first plot
ax[0].plot(bin_centers, counts, linestyle = '-', label='MultiKS Null', drawstyle='steps-mid')
ax[0].plot(x, theoretical_pdf_ks, label='Theoretical distribution (KS)')
#ax[0].plot(x, empirical_pdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[0].set_yscale(scale)
#ax[0].set_xlim(0.005*np.sqrt(ns), 0.04*np.sqrt(ns))
ax[0].set_ylim(0.01, 4)
ax[0].set_xlabel('Multivariate KS')
ax[0].set_ylabel('Number of pseudo-experiments')
ax[0].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - PDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[0].legend(loc='upper right')
# Draw the second plot
ax[1].plot(bin_centers, cum_counts, linestyle = '-', label='MultiKS Null', drawstyle='steps-mid')
ax[1].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
#ax[1].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[1].set_yscale(scale)
#ax[1].set_xlim(0.005*np.sqrt(ns), 0.04*np.sqrt(ns))
ax[1].set_ylim(9e-4, 1.5)
ax[1].set_xlabel('Multivariate KS')
ax[1].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[1].legend(loc='lower right')
## Draw the third plot
#ax[2].plot(bin_centers, cum_counts, linestyle = '-', label='FN Null', drawstyle='steps-mid')
##ax[2].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
##ax[2].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
#ax[2].set_yscale(scale)
#ax[2].set_xlim(0.25, 2)
#ax[2].set_ylim(0.8, 1)
#ax[2].set_xlabel('KS vs SKS')
#ax[2].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
#ax[2].legend(loc='lower right')
# Adjust the width space
plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
# Display the figure with the two subplots
plt.tight_layout()
#plt.savefig(results_path+'SKS_nsamples_'+str(nsamples)+'_ndims_'+'_'+str(ndims)+'_niter_'+str(niter)+'.pdf')
plt.show()
plt.close()
end = timer()
print("Time elapsed:", end-start, "seconds.")
# Out:
# mu = 0.03380111696923397 +/- 1.6511439122407998e-06
# sigma = 0.012849684479553574 +/- 0.0002597216086130338
# Time elapsed: 1.3924284968525171 seconds.

# %%
cl_list = [0.68, 0.95, 0.99]
multi_ks_thresholds = [[cl, [int(cl*len(dist_null)), int((1-cl)*len(dist_null))], np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
multi_ks_thresholds
# Out:
# [[0.68, [6800, 3199], 0.035355336622712695],
#  [0.95, [9500, 500], 0.05656854106588222],
#  [0.99, [9900, 100], 0.07778174550905174]]

# %% [markdown]
# ## SKS Test

# %%
#tf.config.run_functions_eagerly(True)#
SKSTest.Test_tf(max_vectorize=100)
SKSTest.Results[-1].result_value
# Out:
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SKS metric calculation completed in 1400.7055098377168 seconds.
# {'metric_lists': array([[0.0054    , 0.00980002, 0.01620001, ..., 0.02219999, 0.01010001,
#          0.0131    ],
#         [0.01190001, 0.0194    , 0.01980001, ..., 0.01890001, 0.0191    ,
#          0.0205    ],
#         [0.0131    , 0.01100004, 0.01850003, ..., 0.01200001, 0.01670003,
#          0.01660001],
#         ...,
#         [0.0133    , 0.0107    , 0.01840001, ..., 0.01210004, 0.0115    ,
#          0.0122    ],
#         [0.0087    , 0.01410002, 0.01880002, ..., 0.01429999, 0.01109999,
#          0.01720002],
#         [0.01429999, 0.01570001, 0.01120001, ..., 0.00800002, 0.01150003,
#          0.01120001]]),
#  'metric_means': array([0.011586  , 0.01777501, 0.01472001, ..., 0.01166201, 0.011991  ,
#         0.01179801]),
#  'metric_stds': array([0.00310725, 0.00354074, 0.00314995, ..., 0.00322052, 0.00317074,
#         0.00251639])}

# %%
SKSTest.Results.save_to_json(null_hypotheses_dir+"Null_20D_SKS.json")

# %%
SKSTest.Results.load_from_json(null_hypotheses_dir+"Null_20D_SKS.json")

# %%
start = timer()

nsamples = SKSTest.Inputs.batch_size_test
niter = SKSTest.Inputs.niter
ns = nsamples**2 /(2*nsamples)

scale = 'log'
num_bins = 50  # number of bins|
dist_null = np.array(SKSTest.Results[-1].result_value["metric_means"])*np.sqrt(ns)
# Compute the mean and standard deviation of the sample and their standard errors
mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
print("mu =", mu, "+/-", deltamu)
print("sigma =", sigma, "+/-", deltasigma)
# Minimum and maximum x values
min_x = min(dist_null) # lower limit of the binning
max_x = max(dist_null) # upper limit of the binning
# Create an array of values
x = np.linspace(min_x, max_x, num_bins + 1)
# Create histogram for values and normalize counts to sum to 1
counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
cum_counts = np.cumsum(counts)/np.sum(counts)
# Get the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
# Calculate the theoretical PDF and CDF of the KS distribution for each x value
theoretical_pdf_ks = kstwobign.pdf(x)
theoretical_cdf_ks = kstwobign.cdf(x)

# Empirical SKS Normal
empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
# Set up the figure and the two subplots
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
# Draw the first plot
ax[0].plot(bin_centers, counts, linestyle = '-', label='Sliced KS Null', drawstyle='steps-mid')
ax[0].plot(x, theoretical_pdf_ks, label='Theoretical distribution (KS)')
#ax[0].plot(x, empirical_pdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[0].set_yscale(scale)
#ax[0].set_xlim(0.005*np.sqrt(ns), 0.025*np.sqrt(ns))
#ax[0].set_ylim(0.01, 4)
ax[0].set_xlabel('Sliced KS')
ax[0].set_ylabel('Number of pseudo-experiments')
ax[0].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - PDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[0].legend(loc='upper right')
# Draw the second plot
ax[1].plot(bin_centers, cum_counts, linestyle = '-', label='Sliced KS Null', drawstyle='steps-mid')
ax[1].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
#ax[1].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[1].set_yscale(scale)
#ax[1].set_xlim(0.005*np.sqrt(ns), 0.025*np.sqrt(ns))
#ax[1].set_ylim(9e-4, 1.5)
ax[1].set_xlabel('Sliced KS')
ax[1].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[1].legend(loc='lower right')
## Draw the third plot
#ax[2].plot(bin_centers, cum_counts, linestyle = '-', label='FN Null', drawstyle='steps-mid')
##ax[2].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
##ax[2].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
#ax[2].set_yscale(scale)
#ax[2].set_xlim(0.25, 2)
#ax[2].set_ylim(0.8, 1)
#ax[2].set_xlabel('KS vs SKS')
#ax[2].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
#ax[2].legend(loc='lower right')
# Adjust the width space
plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
# Display the figure with the two subplots
plt.tight_layout()
#plt.savefig(results_path+'SKS_nsamples_'+str(nsamples)+'_ndims_'+'_'+str(ndims)+'_niter_'+str(niter)+'.pdf')
plt.show()
plt.close()
end = timer()
print("Time elapsed:", end-start, "seconds.")
# Out:
# mu = 0.8668035162525525 +/- 0.00019693599400883753
# sigma = 0.140333885433575 +/- 0.0015126396170603035
# Time elapsed: 0.8699593171477318 seconds.

# %%
cl_list = [0.68, 0.95, 0.99]
[[cl, [int(cl*len(dist_null)), int((1-cl)*len(dist_null))], np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
# Out:
# [[0.68, [6800, 3199], 0.8943488814115835],
#  [0.95, [9500, 500], 1.1580999081257106],
#  [0.99, [9900, 100], 1.3365030397696707]]

# %% [markdown]
# ## SWD Test

# %%
SWDMetric.Test_tf(max_vectorize=100)
SWDMetric.Results[-1].result_value
# Out:
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SWD metric calculation completed in 840.9830082394183 seconds.
# {'metric_lists': array([[0.00877103, 0.03132907, 0.03585822, ..., 0.05868376, 0.01651061,
#          0.05307966],
#         [0.01805976, 0.06362214, 0.05277477, ..., 0.08653715, 0.05301344,
#          0.16897984],
#         [0.03478863, 0.03476205, 0.07361608, ..., 0.05483988, 0.03300669,
#          0.10544259],
#         ...,
#         [0.02605265, 0.02756849, 0.05282951, ..., 0.03573821, 0.02364113,
#          0.03707389],
#         [0.01325854, 0.04377104, 0.03271386, ..., 0.04969791, 0.02371171,
#          0.07033093],
#         [0.02426292, 0.03351795, 0.02781683, ..., 0.02943675, 0.02075174,
#          0.05619857]]),
#  'metric_means': array([0.02450169, 0.06165841, 0.04629684, ..., 0.02757477, 0.0293908 ,
#         0.02779175]),
#  'metric_stds': array([0.01097966, 0.04202119, 0.02817618, ..., 0.01311516, 0.01450569,
#         0.01309976])}

# %%
SWDMetric.Results.save_to_json(null_hypotheses_dir+"Null_20D_SWD.json")

# %%
SWDMetric.Results.load_from_json(null_hypotheses_dir+"Null_20D_SWD.json")

# %%
start = timer()

nsamples = SWDMetric.Inputs.batch_size_test
niter = SWDMetric.Inputs.niter
ns = nsamples**2 /(2*nsamples)

scale = 'log'
num_bins = 50  # number of bins|
dist_null = np.array(SWDMetric.Results[-1].result_value["metric_means"])*np.sqrt(ns/ndims)
# Compute the mean and standard deviation of the sample and their standard errors
mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
print("mu =", mu, "+/-", deltamu)
print("sigma =", sigma, "+/-", deltasigma)
# Minimum and maximum x values
min_x = min(dist_null) # lower limit of the binning
max_x = max(dist_null) # upper limit of the binning
# Create an array of values
x = np.linspace(min_x, max_x, num_bins + 1)
# Create histogram for values and normalize counts to sum to 1
counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
cum_counts = np.cumsum(counts)/np.sum(counts)
# Get the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
# Calculate the theoretical PDF and CDF of the KS distribution for each x value
#theoretical_pdf_ks = kstwobign.pdf(x)
#theoretical_cdf_ks = kstwobign.cdf(x)

# Empirical SKS Normal
#empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=0.155)
#empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=0.155)
# Set up the figure and the two subplots
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
# Draw the first plot
ax[0].plot(bin_centers, counts, linestyle = '-', label='Sliced WD Null', drawstyle='steps-mid')
#ax[0].plot(x, theoretical_pdf_ks, label='Theoretical distribution (KS)')
#ax[0].plot(x, empirical_pdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[0].set_yscale(scale)
#ax[0].set_xlim(0.008*np.sqrt(ns), 0.055*np.sqrt(ns))
#ax[0].set_ylim(0.01, 1.8)
ax[0].set_xlabel('Sliced WD')
ax[0].set_ylabel('Number of pseudo-experiments')
ax[0].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - PDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[0].legend(loc='upper right')
# Draw the second plot
ax[1].plot(bin_centers, cum_counts, linestyle = '-', label='Sliced WD Null', drawstyle='steps-mid')
#ax[1].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
#ax[1].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[1].set_yscale(scale)
#ax[0].set_xlim(0.008*np.sqrt(ns), 0.055*np.sqrt(ns))
#ax[1].set_ylim(9e-4, 1.5)
ax[1].set_xlabel('Sliced WD')
ax[1].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[1].legend(loc='lower right')
## Draw the third plot
#ax[2].plot(bin_centers, cum_counts, linestyle = '-', label='FN Null', drawstyle='steps-mid')
##ax[2].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
##ax[2].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
#ax[2].set_yscale(scale)
#ax[2].set_xlim(0.25, 2)
#ax[2].set_ylim(0.8, 1)
#ax[2].set_xlabel('KS vs SKS')
#ax[2].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
#ax[2].legend(loc='lower right')
# Adjust the width space
plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
# Display the figure with the two subplots
plt.tight_layout()
#plt.savefig(results_path+'SKS_nsamples_'+str(nsamples)+'_ndims_'+'_'+str(ndims)+'_niter_'+str(niter)+'.pdf')
plt.show()
plt.close()
end = timer()
print("Time elapsed:", end-start, "seconds.")
# Out:
# mu = 0.4766663833363448 +/- 0.00033413912562495527
# sigma = 0.1827947279395539 +/- 0.0016528240832427233
# Time elapsed: 0.8704855442047119 seconds.

# %%
cl_list = [0.68, 0.95, 0.99]
swd_thresholds = [[cl, [int(cl*len(dist_null)), int((1-cl)*len(dist_null))], np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
swd_thresholds
# Out:
# [[0.68, [6800, 3199], 2.366246550926112],
#  [0.95, [9500, 500], 3.7742962907850215],
#  [0.99, [9900, 100], 4.653294549981494]]

# %% [markdown]
# ## FPD Test (TensorFlow)

# %%
FPDMetric.Test_tf(max_vectorize=80)
#FPDMetric.Test_tf(max_vectorize=100)
FPDMetric.Results[-1].result_value
# Out:
# ------------------------------------------
# Starting FPD metric calculation...
# Running TF FPD calculation...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 125
# Iterating from 0 to 80 out of 10000 .
# Iterating from 80 to 160 out of 10000 .
# Iterating from 160 to 240 out of 10000 .
# Iterating from 240 to 320 out of 10000 .
# Iterating from 320 to 400 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f0a481152d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 400 to 480 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f0a48115240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 480 to 560 out of 10000 .
# Iterating from 560 to 640 out of 10000 .
# Iterating from 640 to 720 out of 10000 .
# Iterating from 720 to 800 out of 10000 .
# Iterating from 800 to 880 out of 10000 .
# Iterating from 880 to 960 out of 10000 .
# Iterating from 960 to 1040 out of 10000 .
# Iterating from 1040 to 1120 out of 10000 .
# Iterating from 1120 to 1200 out of 10000 .
# Iterating from 1200 to 1280 out of 10000 .
# Iterating from 1280 to 1360 out of 10000 .
# Iterating from 1360 to 1440 out of 10000 .
# Iterating from 1440 to 1520 out of 10000 .
# Iterating from 1520 to 1600 out of 10000 .
# Iterating from 1600 to 1680 out of 10000 .
# Iterating from 1680 to 1760 out of 10000 .
# Iterating from 1760 to 1840 out of 10000 .
# Iterating from 1840 to 1920 out of 10000 .
# Iterating from 1920 to 2000 out of 10000 .
# Iterating from 2000 to 2080 out of 10000 .
# Iterating from 2080 to 2160 out of 10000 .
# Iterating from 2160 to 2240 out of 10000 .
# Iterating from 2240 to 2320 out of 10000 .
# Iterating from 2320 to 2400 out of 10000 .
# Iterating from 2400 to 2480 out of 10000 .
# Iterating from 2480 to 2560 out of 10000 .
# Iterating from 2560 to 2640 out of 10000 .
# Iterating from 2640 to 2720 out of 10000 .
# Iterating from 2720 to 2800 out of 10000 .
# Iterating from 2800 to 2880 out of 10000 .
# Iterating from 2880 to 2960 out of 10000 .
# Iterating from 2960 to 3040 out of 10000 .
# Iterating from 3040 to 3120 out of 10000 .
# Iterating from 3120 to 3200 out of 10000 .
# Iterating from 3200 to 3280 out of 10000 .
# Iterating from 3280 to 3360 out of 10000 .
# Iterating from 3360 to 3440 out of 10000 .
# Iterating from 3440 to 3520 out of 10000 .
# Iterating from 3520 to 3600 out of 10000 .
# Iterating from 3600 to 3680 out of 10000 .
# Iterating from 3680 to 3760 out of 10000 .
# Iterating from 3760 to 3840 out of 10000 .
# Iterating from 3840 to 3920 out of 10000 .
# Iterating from 3920 to 4000 out of 10000 .
# Iterating from 4000 to 4080 out of 10000 .
# Iterating from 4080 to 4160 out of 10000 .
# Iterating from 4160 to 4240 out of 10000 .
# Iterating from 4240 to 4320 out of 10000 .
# Iterating from 4320 to 4400 out of 10000 .
# Iterating from 4400 to 4480 out of 10000 .
# Iterating from 4480 to 4560 out of 10000 .
# Iterating from 4560 to 4640 out of 10000 .
# Iterating from 4640 to 4720 out of 10000 .
# Iterating from 4720 to 4800 out of 10000 .
# Iterating from 4800 to 4880 out of 10000 .
# Iterating from 4880 to 4960 out of 10000 .
# Iterating from 4960 to 5040 out of 10000 .
# Iterating from 5040 to 5120 out of 10000 .
# Iterating from 5120 to 5200 out of 10000 .
# Iterating from 5200 to 5280 out of 10000 .
# Iterating from 5280 to 5360 out of 10000 .
# Iterating from 5360 to 5440 out of 10000 .
# Iterating from 5440 to 5520 out of 10000 .
# Iterating from 5520 to 5600 out of 10000 .
# Iterating from 5600 to 5680 out of 10000 .
# Iterating from 5680 to 5760 out of 10000 .
# Iterating from 5760 to 5840 out of 10000 .
# Iterating from 5840 to 5920 out of 10000 .
# Iterating from 5920 to 6000 out of 10000 .
# Iterating from 6000 to 6080 out of 10000 .
# Iterating from 6080 to 6160 out of 10000 .
# Iterating from 6160 to 6240 out of 10000 .
# Iterating from 6240 to 6320 out of 10000 .
# Iterating from 6320 to 6400 out of 10000 .
# Iterating from 6400 to 6480 out of 10000 .
# Iterating from 6480 to 6560 out of 10000 .
# Iterating from 6560 to 6640 out of 10000 .
# Iterating from 6640 to 6720 out of 10000 .
# Iterating from 6720 to 6800 out of 10000 .
# Iterating from 6800 to 6880 out of 10000 .
# Iterating from 6880 to 6960 out of 10000 .
# Iterating from 6960 to 7040 out of 10000 .
# Iterating from 7040 to 7120 out of 10000 .
# Iterating from 7120 to 7200 out of 10000 .
# Iterating from 7200 to 7280 out of 10000 .
# Iterating from 7280 to 7360 out of 10000 .
# Iterating from 7360 to 7440 out of 10000 .
# Iterating from 7440 to 7520 out of 10000 .
# Iterating from 7520 to 7600 out of 10000 .
# Iterating from 7600 to 7680 out of 10000 .
# Iterating from 7680 to 7760 out of 10000 .
# Iterating from 7760 to 7840 out of 10000 .
# Iterating from 7840 to 7920 out of 10000 .
# Iterating from 7920 to 8000 out of 10000 .
# Iterating from 8000 to 8080 out of 10000 .
# Iterating from 8080 to 8160 out of 10000 .
# Iterating from 8160 to 8240 out of 10000 .
# Iterating from 8240 to 8320 out of 10000 .
# Iterating from 8320 to 8400 out of 10000 .
# Iterating from 8400 to 8480 out of 10000 .
# Iterating from 8480 to 8560 out of 10000 .
# Iterating from 8560 to 8640 out of 10000 .
# Iterating from 8640 to 8720 out of 10000 .
# Iterating from 8720 to 8800 out of 10000 .
# Iterating from 8800 to 8880 out of 10000 .
# Iterating from 8880 to 8960 out of 10000 .
# Iterating from 8960 to 9040 out of 10000 .
# Iterating from 9040 to 9120 out of 10000 .
# Iterating from 9120 to 9200 out of 10000 .
# Iterating from 9200 to 9280 out of 10000 .
# Iterating from 9280 to 9360 out of 10000 .
# Iterating from 9360 to 9440 out of 10000 .
# Iterating from 9440 to 9520 out of 10000 .
# Iterating from 9520 to 9600 out of 10000 .
# Iterating from 9600 to 9680 out of 10000 .
# Iterating from 9680 to 9760 out of 10000 .
# Iterating from 9760 to 9840 out of 10000 .
# Iterating from 9840 to 9920 out of 10000 .
# Iterating from 9920 to 10000 out of 10000 .
# FPD metric calculation completed in 10920.050352433696 seconds.
# {'metric_list': array([0.0022059 , 0.00262446, 0.00312404, ..., 0.00322589, 0.00214031,
#         0.00271133]),
#  'metric_error_list': array([0.00020357, 0.00029882, 0.00028478, ..., 0.00040737, 0.00017937,
#         0.00026621])}

# %%
FPDMetric.Results.save_to_json(null_hypotheses_dir+"Null_100D_FPD_tf.json")

# %%
FPDMetric.Results.load_from_json(null_hypotheses_dir+"Null_100D_FPD_tf.json")

# %%
start = timer()

nsamples = FPDMetric.Inputs.batch_size_test
niter = FPDMetric.Inputs.niter
ns = nsamples**2 /(2*nsamples)

scale = 'log'
num_bins = 50  # number of bins|
dist_null = np.array(FPDMetric.Results[-1].result_value["metric_list"])*(ns/ndims)**(3/2)
# Compute the mean and standard deviation of the sample and their standard errors
mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
print("mu =", mu, "+/-", deltamu)
print("sigma =", sigma, "+/-", deltasigma)
# Minimum and maximum x values
min_x = min(dist_null) # lower limit of the binning
max_x = max(dist_null) # upper limit of the binning
# Create an array of values
x = np.linspace(min_x, max_x, num_bins + 1)
# Create histogram for values and normalize counts to sum to 1
counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
cum_counts = np.cumsum(counts)/np.sum(counts)
# Get the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
# Calculate the theoretical PDF and CDF of the KS distribution for each x value
#theoretical_pdf_ks = kstwobign.pdf(x)
#theoretical_cdf_ks = kstwobign.cdf(x)

# Empirical SKS Normal
#empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
#empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
# Set up the figure and the two subplots
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
# Draw the first plot
ax[0].plot(bin_centers, counts, linestyle = '-', label='FPD Null', drawstyle='steps-mid')
#ax[0].plot(x, theoretical_pdf_ks, label='Theoretical distribution (KS)')
#ax[0].plot(x, empirical_pdf_norm, label='FPD - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[0].set_yscale(scale)
#ax[0].set_xlim(0.005*np.sqrt(ns), 0.025*np.sqrt(ns))
#ax[0].set_ylim(0.01, 5)
ax[0].set_xlabel('FPD')
ax[0].set_ylabel('Number of pseudo-experiments')
ax[0].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - PDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[0].legend(loc='upper right')
# Draw the second plot
ax[1].plot(bin_centers, cum_counts, linestyle = '-', label='KS Null', drawstyle='steps-mid')
#ax[1].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
#ax[1].plot(x, empirical_cdf_norm, label='FPD - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[1].set_yscale(scale)
#ax[1].set_xlim(0.005*np.sqrt(ns), 0.025*np.sqrt(ns))
#ax[1].set_ylim(9e-4, 1.5)
ax[1].set_xlabel('FPD')
ax[1].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[1].legend(loc='lower right')
## Draw the third plot
#ax[2].plot(bin_centers, cum_counts, linestyle = '-', label='FN Null', drawstyle='steps-mid')
##ax[2].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
##ax[2].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
#ax[2].set_yscale(scale)
#ax[2].set_xlim(0.25, 2)
#ax[2].set_ylim(0.8, 1)
#ax[2].set_xlabel('KS vs SKS')
#ax[2].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
#ax[2].legend(loc='lower right')
# Adjust the width space
plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
# Display the figure with the two subplots
plt.tight_layout()
#plt.savefig(results_path+'SKS_nsamples_'+str(nsamples)+'_ndims_'+'_'+str(ndims)+'_niter_'+str(niter)+'.pdf')
plt.show()
plt.close()
end = timer()
print("Time elapsed:", end-start, "seconds.")
# Out:
# mu = 1.234056783131788 +/- 0.0035709474432357585
# sigma = 0.5975740492387331 +/- 0.008087579128609967
# Time elapsed: 0.6551245432347059 seconds.

# %%
cl_list = [0.68, 0.95, 0.99]
fpd_thresholds = [[cl, [int(cl*len(dist_null_tf)), int((1-cl)*len(dist_null_tf))], np.sort(dist_null_tf)[int(len(dist_null_tf)*cl)]] for cl in cl_list]
fpd_thresholds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 cl_list = [0.68, 0.95, 0.99]
# ----> 2 fpd_thresholds = [[cl, [int(cl*len(dist_null_tf)), int((1-cl)*len(dist_null_tf))], np.sort(dist_null_tf)[int(len(dist_null_tf)*cl)]] for cl in cl_list]
#       3 fpd_thresholds
#
# Cell In[12], line 2, in <listcomp>(.0)
#       1 cl_list = [0.68, 0.95, 0.99]
# ----> 2 fpd_thresholds = [[cl, [int(cl*len(dist_null_tf)), int((1-cl)*len(dist_null_tf))], np.sort(dist_null_tf)[int(len(dist_null_tf)*cl)]] for cl in cl_list]
#       3 fpd_thresholds
#
# NameError: name 'dist_null_tf' is not defined

# %% [markdown]
# ## KPD Test

# %%
KPDMetric.Test_tf(max_vectorize=4)
KPDMetric.Results[-1].result_value
# Out:
# ------------------------------------------
# Starting KPD metric calculation...
# Running TF KPD calculation...
# niter = 10000
# batch_size = 10000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 2500
# Iterating from 0 to 4 out of 10000 .
# Iterating from 4 to 8 out of 10000 .
# Iterating from 8 to 12 out of 10000 .
# Iterating from 12 to 16 out of 10000 .
# Iterating from 16 to 20 out of 10000 .
# Iterating from 20 to 24 out of 10000 .
# Iterating from 24 to 28 out of 10000 .
# Iterating from 28 to 32 out of 10000 .
# Iterating from 32 to 36 out of 10000 .
# Iterating from 36 to 40 out of 10000 .
# Iterating from 40 to 44 out of 10000 .
# Iterating from 44 to 48 out of 10000 .
# Iterating from 48 to 52 out of 10000 .
# Iterating from 52 to 56 out of 10000 .
# Iterating from 56 to 60 out of 10000 .
# Iterating from 60 to 64 out of 10000 .
# Iterating from 64 to 68 out of 10000 .
# Iterating from 68 to 72 out of 10000 .
# Iterating from 72 to 76 out of 10000 .
# Iterating from 76 to 80 out of 10000 .
# Iterating from 80 to 84 out of 10000 .
# Iterating from 84 to 88 out of 10000 .
# Iterating from 88 to 92 out of 10000 .
# Iterating from 92 to 96 out of 10000 .
# Iterating from 96 to 100 out of 10000 .
# Iterating from 100 to 104 out of 10000 .
# Iterating from 104 to 108 out of 10000 .
# Iterating from 108 to 112 out of 10000 .
# Iterating from 112 to 116 out of 10000 .
# Iterating from 116 to 120 out of 10000 .
# Iterating from 120 to 124 out of 10000 .
# Iterating from 124 to 128 out of 10000 .
# Iterating from 128 to 132 out of 10000 .
# Iterating from 132 to 136 out of 10000 .
# Iterating from 136 to 140 out of 10000 .
# Iterating from 140 to 144 out of 10000 .
# Iterating from 144 to 148 out of 10000 .
# Iterating from 148 to 152 out of 10000 .
# Iterating from 152 to 156 out of 10000 .
# Iterating from 156 to 160 out of 10000 .
# Iterating from 160 to 164 out of 10000 .
# Iterating from 164 to 168 out of 10000 .
# Iterating from 168 to 172 out of 10000 .
# Iterating from 172 to 176 out of 10000 .
# Iterating from 176 to 180 out of 10000 .
# Iterating from 180 to 184 out of 10000 .
# Iterating from 184 to 188 out of 10000 .
# Iterating from 188 to 192 out of 10000 .
# Iterating from 192 to 196 out of 10000 .
# Iterating from 196 to 200 out of 10000 .
# Iterating from 200 to 204 out of 10000 .
# Iterating from 204 to 208 out of 10000 .
# Iterating from 208 to 212 out of 10000 .
# Iterating from 212 to 216 out of 10000 .
# Iterating from 216 to 220 out of 10000 .
# Iterating from 220 to 224 out of 10000 .
# Iterating from 224 to 228 out of 10000 .
# Iterating from 228 to 232 out of 10000 .
# Iterating from 232 to 236 out of 10000 .
# Iterating from 236 to 240 out of 10000 .
# Iterating from 240 to 244 out of 10000 .
# Iterating from 244 to 248 out of 10000 .
# Iterating from 248 to 252 out of 10000 .
# Iterating from 252 to 256 out of 10000 .
# Iterating from 256 to 260 out of 10000 .
# Iterating from 260 to 264 out of 10000 .
# Iterating from 264 to 268 out of 10000 .
# Iterating from 268 to 272 out of 10000 .
# Iterating from 272 to 276 out of 10000 .
# Iterating from 276 to 280 out of 10000 .
# Iterating from 280 to 284 out of 10000 .
# Iterating from 284 to 288 out of 10000 .
# Iterating from 288 to 292 out of 10000 .
# Iterating from 292 to 296 out of 10000 .
# Iterating from 296 to 300 out of 10000 .
# Iterating from 300 to 304 out of 10000 .
# Iterating from 304 to 308 out of 10000 .
# Iterating from 308 to 312 out of 10000 .
# Iterating from 312 to 316 out of 10000 .
# Iterating from 316 to 320 out of 10000 .
# Iterating from 320 to 324 out of 10000 .
# Iterating from 324 to 328 out of 10000 .
# Iterating from 328 to 332 out of 10000 .
# Iterating from 332 to 336 out of 10000 .
# Iterating from 336 to 340 out of 10000 .
# Iterating from 340 to 344 out of 10000 .
# Iterating from 344 to 348 out of 10000 .
# Iterating from 348 to 352 out of 10000 .
# Iterating from 352 to 356 out of 10000 .
# Iterating from 356 to 360 out of 10000 .
# Iterating from 360 to 364 out of 10000 .
# Iterating from 364 to 368 out of 10000 .
# Iterating from 368 to 372 out of 10000 .
# Iterating from 372 to 376 out of 10000 .
# Iterating from 376 to 380 out of 10000 .
# Iterating from 380 to 384 out of 10000 .
# Iterating from 384 to 388 out of 10000 .
# Iterating from 388 to 392 out of 10000 .
# Iterating from 392 to 396 out of 10000 .
# Iterating from 396 to 400 out of 10000 .
# Iterating from 400 to 404 out of 10000 .
# Iterating from 404 to 408 out of 10000 .
# Iterating from 408 to 412 out of 10000 .
# Iterating from 412 to 416 out of 10000 .
# Iterating from 416 to 420 out of 10000 .
# Iterating from 420 to 424 out of 10000 .
# Iterating from 424 to 428 out of 10000 .
# Iterating from 428 to 432 out of 10000 .
# Iterating from 432 to 436 out of 10000 .
# Iterating from 436 to 440 out of 10000 .
# Iterating from 440 to 444 out of 10000 .
# Iterating from 444 to 448 out of 10000 .
# Iterating from 448 to 452 out of 10000 .
# Iterating from 452 to 456 out of 10000 .
# Iterating from 456 to 460 out of 10000 .
# Iterating from 460 to 464 out of 10000 .
# Iterating from 464 to 468 out of 10000 .
# Iterating from 468 to 472 out of 10000 .
# Iterating from 472 to 476 out of 10000 .
# Iterating from 476 to 480 out of 10000 .
# Iterating from 480 to 484 out of 10000 .
# Iterating from 484 to 488 out of 10000 .
# Iterating from 488 to 492 out of 10000 .
# Iterating from 492 to 496 out of 10000 .
# Iterating from 496 to 500 out of 10000 .
# Iterating from 500 to 504 out of 10000 .
# Iterating from 504 to 508 out of 10000 .
# Iterating from 508 to 512 out of 10000 .
# Iterating from 512 to 516 out of 10000 .
# Iterating from 516 to 520 out of 10000 .
# Iterating from 520 to 524 out of 10000 .
# Iterating from 524 to 528 out of 10000 .
# Iterating from 528 to 532 out of 10000 .
# Iterating from 532 to 536 out of 10000 .
# Iterating from 536 to 540 out of 10000 .
# Iterating from 540 to 544 out of 10000 .
# Iterating from 544 to 548 out of 10000 .
# Iterating from 548 to 552 out of 10000 .
# Iterating from 552 to 556 out of 10000 .
# Iterating from 556 to 560 out of 10000 .
# Iterating from 560 to 564 out of 10000 .
# Iterating from 564 to 568 out of 10000 .
# Iterating from 568 to 572 out of 10000 .
# Iterating from 572 to 576 out of 10000 .
# Iterating from 576 to 580 out of 10000 .
# Iterating from 580 to 584 out of 10000 .
# Iterating from 584 to 588 out of 10000 .
# Iterating from 588 to 592 out of 10000 .
# Iterating from 592 to 596 out of 10000 .
# Iterating from 596 to 600 out of 10000 .
# Iterating from 600 to 604 out of 10000 .
# Iterating from 604 to 608 out of 10000 .
# Iterating from 608 to 612 out of 10000 .
# Iterating from 612 to 616 out of 10000 .
# Iterating from 616 to 620 out of 10000 .
# Iterating from 620 to 624 out of 10000 .
# Iterating from 624 to 628 out of 10000 .
# Iterating from 628 to 632 out of 10000 .
# Iterating from 632 to 636 out of 10000 .
# Iterating from 636 to 640 out of 10000 .
# Iterating from 640 to 644 out of 10000 .
# Iterating from 644 to 648 out of 10000 .
# Iterating from 648 to 652 out of 10000 .
# Iterating from 652 to 656 out of 10000 .
# Iterating from 656 to 660 out of 10000 .
# Iterating from 660 to 664 out of 10000 .
# Iterating from 664 to 668 out of 10000 .
# Iterating from 668 to 672 out of 10000 .
# Iterating from 672 to 676 out of 10000 .
# Iterating from 676 to 680 out of 10000 .
# Iterating from 680 to 684 out of 10000 .
# Iterating from 684 to 688 out of 10000 .
# Iterating from 688 to 692 out of 10000 .
# Iterating from 692 to 696 out of 10000 .
# Iterating from 696 to 700 out of 10000 .
# Iterating from 700 to 704 out of 10000 .
# Iterating from 704 to 708 out of 10000 .
# Iterating from 708 to 712 out of 10000 .
# Iterating from 712 to 716 out of 10000 .
# Iterating from 716 to 720 out of 10000 .
# Iterating from 720 to 724 out of 10000 .
# Iterating from 724 to 728 out of 10000 .
# Iterating from 728 to 732 out of 10000 .
# Iterating from 732 to 736 out of 10000 .
# Iterating from 736 to 740 out of 10000 .
# Iterating from 740 to 744 out of 10000 .
# Iterating from 744 to 748 out of 10000 .
# Iterating from 748 to 752 out of 10000 .
# Iterating from 752 to 756 out of 10000 .
# Iterating from 756 to 760 out of 10000 .
# Iterating from 760 to 764 out of 10000 .
# Iterating from 764 to 768 out of 10000 .
# Iterating from 768 to 772 out of 10000 .
# Iterating from 772 to 776 out of 10000 .
# Iterating from 776 to 780 out of 10000 .
# Iterating from 780 to 784 out of 10000 .
# Iterating from 784 to 788 out of 10000 .
# Iterating from 788 to 792 out of 10000 .
# Iterating from 792 to 796 out of 10000 .
# Iterating from 796 to 800 out of 10000 .
# Iterating from 800 to 804 out of 10000 .
# Iterating from 804 to 808 out of 10000 .
# Iterating from 808 to 812 out of 10000 .
# Iterating from 812 to 816 out of 10000 .
# Iterating from 816 to 820 out of 10000 .
# Iterating from 820 to 824 out of 10000 .
# Iterating from 824 to 828 out of 10000 .
# Iterating from 828 to 832 out of 10000 .
# Iterating from 832 to 836 out of 10000 .
# Iterating from 836 to 840 out of 10000 .
# Iterating from 840 to 844 out of 10000 .
# Iterating from 844 to 848 out of 10000 .
# Iterating from 848 to 852 out of 10000 .
# Iterating from 852 to 856 out of 10000 .
# Iterating from 856 to 860 out of 10000 .
# Iterating from 860 to 864 out of 10000 .
# Iterating from 864 to 868 out of 10000 .
# Iterating from 868 to 872 out of 10000 .
# Iterating from 872 to 876 out of 10000 .
# Iterating from 876 to 880 out of 10000 .
# Iterating from 880 to 884 out of 10000 .
# Iterating from 884 to 888 out of 10000 .
# Iterating from 888 to 892 out of 10000 .
# Iterating from 892 to 896 out of 10000 .
# Iterating from 896 to 900 out of 10000 .
# Iterating from 900 to 904 out of 10000 .
# Iterating from 904 to 908 out of 10000 .
# Iterating from 908 to 912 out of 10000 .
# Iterating from 912 to 916 out of 10000 .
# Iterating from 916 to 920 out of 10000 .
# Iterating from 920 to 924 out of 10000 .
# Iterating from 924 to 928 out of 10000 .
# Iterating from 928 to 932 out of 10000 .
# Iterating from 932 to 936 out of 10000 .
# Iterating from 936 to 940 out of 10000 .
# Iterating from 940 to 944 out of 10000 .
# Iterating from 944 to 948 out of 10000 .
# Iterating from 948 to 952 out of 10000 .
# Iterating from 952 to 956 out of 10000 .
# Iterating from 956 to 960 out of 10000 .
# Iterating from 960 to 964 out of 10000 .
# Iterating from 964 to 968 out of 10000 .
# Iterating from 968 to 972 out of 10000 .
# Iterating from 972 to 976 out of 10000 .
# Iterating from 976 to 980 out of 10000 .
# Iterating from 980 to 984 out of 10000 .
# Iterating from 984 to 988 out of 10000 .
# Iterating from 988 to 992 out of 10000 .
# Iterating from 992 to 996 out of 10000 .
# Iterating from 996 to 1000 out of 10000 .
# Iterating from 1000 to 1004 out of 10000 .
# Iterating from 1004 to 1008 out of 10000 .
# Iterating from 1008 to 1012 out of 10000 .
# Iterating from 1012 to 1016 out of 10000 .
# Iterating from 1016 to 1020 out of 10000 .
# Iterating from 1020 to 1024 out of 10000 .
# Iterating from 1024 to 1028 out of 10000 .
# Iterating from 1028 to 1032 out of 10000 .
# Iterating from 1032 to 1036 out of 10000 .
# Iterating from 1036 to 1040 out of 10000 .
# Iterating from 1040 to 1044 out of 10000 .
# Iterating from 1044 to 1048 out of 10000 .
# Iterating from 1048 to 1052 out of 10000 .
# Iterating from 1052 to 1056 out of 10000 .
# Iterating from 1056 to 1060 out of 10000 .
# Iterating from 1060 to 1064 out of 10000 .
# Iterating from 1064 to 1068 out of 10000 .
# Iterating from 1068 to 1072 out of 10000 .
# Iterating from 1072 to 1076 out of 10000 .
# Iterating from 1076 to 1080 out of 10000 .
# Iterating from 1080 to 1084 out of 10000 .
# Iterating from 1084 to 1088 out of 10000 .
# Iterating from 1088 to 1092 out of 10000 .
# Iterating from 1092 to 1096 out of 10000 .
# Iterating from 1096 to 1100 out of 10000 .
# Iterating from 1100 to 1104 out of 10000 .
# Iterating from 1104 to 1108 out of 10000 .
# Iterating from 1108 to 1112 out of 10000 .
# Iterating from 1112 to 1116 out of 10000 .
# Iterating from 1116 to 1120 out of 10000 .
# Iterating from 1120 to 1124 out of 10000 .
# Iterating from 1124 to 1128 out of 10000 .
# Iterating from 1128 to 1132 out of 10000 .
# Iterating from 1132 to 1136 out of 10000 .
# Iterating from 1136 to 1140 out of 10000 .
# Iterating from 1140 to 1144 out of 10000 .
# Iterating from 1144 to 1148 out of 10000 .
# Iterating from 1148 to 1152 out of 10000 .
# Iterating from 1152 to 1156 out of 10000 .
# Iterating from 1156 to 1160 out of 10000 .
# Iterating from 1160 to 1164 out of 10000 .
# Iterating from 1164 to 1168 out of 10000 .
# Iterating from 1168 to 1172 out of 10000 .
# Iterating from 1172 to 1176 out of 10000 .
# Iterating from 1176 to 1180 out of 10000 .
# Iterating from 1180 to 1184 out of 10000 .
# Iterating from 1184 to 1188 out of 10000 .
# Iterating from 1188 to 1192 out of 10000 .
# Iterating from 1192 to 1196 out of 10000 .
# Iterating from 1196 to 1200 out of 10000 .
# Iterating from 1200 to 1204 out of 10000 .
# Iterating from 1204 to 1208 out of 10000 .
# Iterating from 1208 to 1212 out of 10000 .
# Iterating from 1212 to 1216 out of 10000 .
# Iterating from 1216 to 1220 out of 10000 .
# Iterating from 1220 to 1224 out of 10000 .
# Iterating from 1224 to 1228 out of 10000 .
# Iterating from 1228 to 1232 out of 10000 .
# Iterating from 1232 to 1236 out of 10000 .
# Iterating from 1236 to 1240 out of 10000 .
# Iterating from 1240 to 1244 out of 10000 .
# Iterating from 1244 to 1248 out of 10000 .
# Iterating from 1248 to 1252 out of 10000 .
# Iterating from 1252 to 1256 out of 10000 .
# Iterating from 1256 to 1260 out of 10000 .
# Iterating from 1260 to 1264 out of 10000 .
# Iterating from 1264 to 1268 out of 10000 .
# Iterating from 1268 to 1272 out of 10000 .
# Iterating from 1272 to 1276 out of 10000 .
# Iterating from 1276 to 1280 out of 10000 .
# Iterating from 1280 to 1284 out of 10000 .
# Iterating from 1284 to 1288 out of 10000 .
# Iterating from 1288 to 1292 out of 10000 .
# Iterating from 1292 to 1296 out of 10000 .
# Iterating from 1296 to 1300 out of 10000 .
# Iterating from 1300 to 1304 out of 10000 .
# Iterating from 1304 to 1308 out of 10000 .
# Iterating from 1308 to 1312 out of 10000 .
# Iterating from 1312 to 1316 out of 10000 .
# Iterating from 1316 to 1320 out of 10000 .
# Iterating from 1320 to 1324 out of 10000 .
# Iterating from 1324 to 1328 out of 10000 .
# Iterating from 1328 to 1332 out of 10000 .
# Iterating from 1332 to 1336 out of 10000 .
# Iterating from 1336 to 1340 out of 10000 .
# Iterating from 1340 to 1344 out of 10000 .
# Iterating from 1344 to 1348 out of 10000 .
# Iterating from 1348 to 1352 out of 10000 .
# Iterating from 1352 to 1356 out of 10000 .
# Iterating from 1356 to 1360 out of 10000 .
# Iterating from 1360 to 1364 out of 10000 .
# Iterating from 1364 to 1368 out of 10000 .
# Iterating from 1368 to 1372 out of 10000 .
# Iterating from 1372 to 1376 out of 10000 .
# Iterating from 1376 to 1380 out of 10000 .
# Iterating from 1380 to 1384 out of 10000 .
# Iterating from 1384 to 1388 out of 10000 .
# Iterating from 1388 to 1392 out of 10000 .
# Iterating from 1392 to 1396 out of 10000 .
# Iterating from 1396 to 1400 out of 10000 .
# Iterating from 1400 to 1404 out of 10000 .
# Iterating from 1404 to 1408 out of 10000 .
# Iterating from 1408 to 1412 out of 10000 .
# Iterating from 1412 to 1416 out of 10000 .
# Iterating from 1416 to 1420 out of 10000 .
# Iterating from 1420 to 1424 out of 10000 .
# Iterating from 1424 to 1428 out of 10000 .
# Iterating from 1428 to 1432 out of 10000 .
# Iterating from 1432 to 1436 out of 10000 .
# Iterating from 1436 to 1440 out of 10000 .
# Iterating from 1440 to 1444 out of 10000 .
# Iterating from 1444 to 1448 out of 10000 .
# Iterating from 1448 to 1452 out of 10000 .
# Iterating from 1452 to 1456 out of 10000 .
# Iterating from 1456 to 1460 out of 10000 .
# Iterating from 1460 to 1464 out of 10000 .
# Iterating from 1464 to 1468 out of 10000 .
# Iterating from 1468 to 1472 out of 10000 .
# Iterating from 1472 to 1476 out of 10000 .
# Iterating from 1476 to 1480 out of 10000 .
# Iterating from 1480 to 1484 out of 10000 .
# Iterating from 1484 to 1488 out of 10000 .
# Iterating from 1488 to 1492 out of 10000 .
# Iterating from 1492 to 1496 out of 10000 .
# Iterating from 1496 to 1500 out of 10000 .
# Iterating from 1500 to 1504 out of 10000 .
# Iterating from 1504 to 1508 out of 10000 .
# Iterating from 1508 to 1512 out of 10000 .
# Iterating from 1512 to 1516 out of 10000 .
# Iterating from 1516 to 1520 out of 10000 .
# Iterating from 1520 to 1524 out of 10000 .
# Iterating from 1524 to 1528 out of 10000 .
# Iterating from 1528 to 1532 out of 10000 .
# Iterating from 1532 to 1536 out of 10000 .
# Iterating from 1536 to 1540 out of 10000 .
# Iterating from 1540 to 1544 out of 10000 .
# Iterating from 1544 to 1548 out of 10000 .
# Iterating from 1548 to 1552 out of 10000 .
# Iterating from 1552 to 1556 out of 10000 .
# Iterating from 1556 to 1560 out of 10000 .
# Iterating from 1560 to 1564 out of 10000 .
# Iterating from 1564 to 1568 out of 10000 .
# Iterating from 1568 to 1572 out of 10000 .
# Iterating from 1572 to 1576 out of 10000 .
# Iterating from 1576 to 1580 out of 10000 .
# Iterating from 1580 to 1584 out of 10000 .
# Iterating from 1584 to 1588 out of 10000 .
# Iterating from 1588 to 1592 out of 10000 .
# Iterating from 1592 to 1596 out of 10000 .
# Iterating from 1596 to 1600 out of 10000 .
# Iterating from 1600 to 1604 out of 10000 .
# Iterating from 1604 to 1608 out of 10000 .
# Iterating from 1608 to 1612 out of 10000 .
# Iterating from 1612 to 1616 out of 10000 .
# Iterating from 1616 to 1620 out of 10000 .
# Iterating from 1620 to 1624 out of 10000 .
# Iterating from 1624 to 1628 out of 10000 .
# Iterating from 1628 to 1632 out of 10000 .
# Iterating from 1632 to 1636 out of 10000 .
# Iterating from 1636 to 1640 out of 10000 .
# Iterating from 1640 to 1644 out of 10000 .
# Iterating from 1644 to 1648 out of 10000 .
# Iterating from 1648 to 1652 out of 10000 .
# Iterating from 1652 to 1656 out of 10000 .
# Iterating from 1656 to 1660 out of 10000 .
# Iterating from 1660 to 1664 out of 10000 .
# Iterating from 1664 to 1668 out of 10000 .
# Iterating from 1668 to 1672 out of 10000 .
# Iterating from 1672 to 1676 out of 10000 .
# Iterating from 1676 to 1680 out of 10000 .
# Iterating from 1680 to 1684 out of 10000 .
# Iterating from 1684 to 1688 out of 10000 .
# Iterating from 1688 to 1692 out of 10000 .
# Iterating from 1692 to 1696 out of 10000 .
# Iterating from 1696 to 1700 out of 10000 .
# Iterating from 1700 to 1704 out of 10000 .
# Iterating from 1704 to 1708 out of 10000 .
# Iterating from 1708 to 1712 out of 10000 .
# Iterating from 1712 to 1716 out of 10000 .
# Iterating from 1716 to 1720 out of 10000 .
# Iterating from 1720 to 1724 out of 10000 .
# Iterating from 1724 to 1728 out of 10000 .
# Iterating from 1728 to 1732 out of 10000 .
# Iterating from 1732 to 1736 out of 10000 .
# Iterating from 1736 to 1740 out of 10000 .
# Iterating from 1740 to 1744 out of 10000 .
# Iterating from 1744 to 1748 out of 10000 .
# Iterating from 1748 to 1752 out of 10000 .
# Iterating from 1752 to 1756 out of 10000 .
# Iterating from 1756 to 1760 out of 10000 .
# Iterating from 1760 to 1764 out of 10000 .
# Iterating from 1764 to 1768 out of 10000 .
# Iterating from 1768 to 1772 out of 10000 .
# Iterating from 1772 to 1776 out of 10000 .
# Iterating from 1776 to 1780 out of 10000 .
# Iterating from 1780 to 1784 out of 10000 .
# Iterating from 1784 to 1788 out of 10000 .
# Iterating from 1788 to 1792 out of 10000 .
# Iterating from 1792 to 1796 out of 10000 .
# Iterating from 1796 to 1800 out of 10000 .
# Iterating from 1800 to 1804 out of 10000 .
# Iterating from 1804 to 1808 out of 10000 .
# Iterating from 1808 to 1812 out of 10000 .
# Iterating from 1812 to 1816 out of 10000 .
# Iterating from 1816 to 1820 out of 10000 .
# Iterating from 1820 to 1824 out of 10000 .
# Iterating from 1824 to 1828 out of 10000 .
# Iterating from 1828 to 1832 out of 10000 .
# Iterating from 1832 to 1836 out of 10000 .
# Iterating from 1836 to 1840 out of 10000 .
# Iterating from 1840 to 1844 out of 10000 .
# Iterating from 1844 to 1848 out of 10000 .
# Iterating from 1848 to 1852 out of 10000 .
# Iterating from 1852 to 1856 out of 10000 .
# Iterating from 1856 to 1860 out of 10000 .
# Iterating from 1860 to 1864 out of 10000 .
# Iterating from 1864 to 1868 out of 10000 .
# Iterating from 1868 to 1872 out of 10000 .
# Iterating from 1872 to 1876 out of 10000 .
# Iterating from 1876 to 1880 out of 10000 .
# Iterating from 1880 to 1884 out of 10000 .
# Iterating from 1884 to 1888 out of 10000 .
# Iterating from 1888 to 1892 out of 10000 .
# Iterating from 1892 to 1896 out of 10000 .
# Iterating from 1896 to 1900 out of 10000 .
# Iterating from 1900 to 1904 out of 10000 .
# Iterating from 1904 to 1908 out of 10000 .
# Iterating from 1908 to 1912 out of 10000 .
# Iterating from 1912 to 1916 out of 10000 .
# Iterating from 1916 to 1920 out of 10000 .
# Iterating from 1920 to 1924 out of 10000 .
# Iterating from 1924 to 1928 out of 10000 .
# Iterating from 1928 to 1932 out of 10000 .
# Iterating from 1932 to 1936 out of 10000 .
# Iterating from 1936 to 1940 out of 10000 .
# Iterating from 1940 to 1944 out of 10000 .
# Iterating from 1944 to 1948 out of 10000 .
# Iterating from 1948 to 1952 out of 10000 .
# Iterating from 1952 to 1956 out of 10000 .
# Iterating from 1956 to 1960 out of 10000 .
# Iterating from 1960 to 1964 out of 10000 .
# Iterating from 1964 to 1968 out of 10000 .
# Iterating from 1968 to 1972 out of 10000 .
# Iterating from 1972 to 1976 out of 10000 .
# Iterating from 1976 to 1980 out of 10000 .
# Iterating from 1980 to 1984 out of 10000 .
# Iterating from 1984 to 1988 out of 10000 .
# Iterating from 1988 to 1992 out of 10000 .
# Iterating from 1992 to 1996 out of 10000 .
# Iterating from 1996 to 2000 out of 10000 .
# Iterating from 2000 to 2004 out of 10000 .
# Iterating from 2004 to 2008 out of 10000 .
# Iterating from 2008 to 2012 out of 10000 .
# Iterating from 2012 to 2016 out of 10000 .
# Iterating from 2016 to 2020 out of 10000 .
# Iterating from 2020 to 2024 out of 10000 .
# Iterating from 2024 to 2028 out of 10000 .
# Iterating from 2028 to 2032 out of 10000 .
# Iterating from 2032 to 2036 out of 10000 .
# Iterating from 2036 to 2040 out of 10000 .
# Iterating from 2040 to 2044 out of 10000 .
# Iterating from 2044 to 2048 out of 10000 .
# Iterating from 2048 to 2052 out of 10000 .
# Iterating from 2052 to 2056 out of 10000 .
# Iterating from 2056 to 2060 out of 10000 .
# Iterating from 2060 to 2064 out of 10000 .
# Iterating from 2064 to 2068 out of 10000 .
# Iterating from 2068 to 2072 out of 10000 .
# Iterating from 2072 to 2076 out of 10000 .
# Iterating from 2076 to 2080 out of 10000 .
# Iterating from 2080 to 2084 out of 10000 .
# Iterating from 2084 to 2088 out of 10000 .
# Iterating from 2088 to 2092 out of 10000 .
# Iterating from 2092 to 2096 out of 10000 .
# Iterating from 2096 to 2100 out of 10000 .
# Iterating from 2100 to 2104 out of 10000 .
# Iterating from 2104 to 2108 out of 10000 .
# Iterating from 2108 to 2112 out of 10000 .
# Iterating from 2112 to 2116 out of 10000 .
# Iterating from 2116 to 2120 out of 10000 .
# Iterating from 2120 to 2124 out of 10000 .
# Iterating from 2124 to 2128 out of 10000 .
# Iterating from 2128 to 2132 out of 10000 .
# Iterating from 2132 to 2136 out of 10000 .
# Iterating from 2136 to 2140 out of 10000 .
# Iterating from 2140 to 2144 out of 10000 .
# Iterating from 2144 to 2148 out of 10000 .
# Iterating from 2148 to 2152 out of 10000 .
# Iterating from 2152 to 2156 out of 10000 .
# Iterating from 2156 to 2160 out of 10000 .
# Iterating from 2160 to 2164 out of 10000 .
# Iterating from 2164 to 2168 out of 10000 .
# Iterating from 2168 to 2172 out of 10000 .
# Iterating from 2172 to 2176 out of 10000 .
# Iterating from 2176 to 2180 out of 10000 .
# Iterating from 2180 to 2184 out of 10000 .
# Iterating from 2184 to 2188 out of 10000 .
# Iterating from 2188 to 2192 out of 10000 .
# Iterating from 2192 to 2196 out of 10000 .
# Iterating from 2196 to 2200 out of 10000 .
# Iterating from 2200 to 2204 out of 10000 .
# Iterating from 2204 to 2208 out of 10000 .
# Iterating from 2208 to 2212 out of 10000 .
# Iterating from 2212 to 2216 out of 10000 .
# Iterating from 2216 to 2220 out of 10000 .
# Iterating from 2220 to 2224 out of 10000 .
# Iterating from 2224 to 2228 out of 10000 .
# Iterating from 2228 to 2232 out of 10000 .
# Iterating from 2232 to 2236 out of 10000 .
# Iterating from 2236 to 2240 out of 10000 .
# Iterating from 2240 to 2244 out of 10000 .
# Iterating from 2244 to 2248 out of 10000 .
# Iterating from 2248 to 2252 out of 10000 .
# Iterating from 2252 to 2256 out of 10000 .
# Iterating from 2256 to 2260 out of 10000 .
# Iterating from 2260 to 2264 out of 10000 .
# Iterating from 2264 to 2268 out of 10000 .
# Iterating from 2268 to 2272 out of 10000 .
# Iterating from 2272 to 2276 out of 10000 .
# Iterating from 2276 to 2280 out of 10000 .
# Iterating from 2280 to 2284 out of 10000 .
# Iterating from 2284 to 2288 out of 10000 .
# Iterating from 2288 to 2292 out of 10000 .
# Iterating from 2292 to 2296 out of 10000 .
# Iterating from 2296 to 2300 out of 10000 .
# Iterating from 2300 to 2304 out of 10000 .
# Iterating from 2304 to 2308 out of 10000 .
# Iterating from 2308 to 2312 out of 10000 .
# Iterating from 2312 to 2316 out of 10000 .
# Iterating from 2316 to 2320 out of 10000 .
# Iterating from 2320 to 2324 out of 10000 .
# Iterating from 2324 to 2328 out of 10000 .
# Iterating from 2328 to 2332 out of 10000 .
# Iterating from 2332 to 2336 out of 10000 .
# Iterating from 2336 to 2340 out of 10000 .
# Iterating from 2340 to 2344 out of 10000 .
# Iterating from 2344 to 2348 out of 10000 .
# Iterating from 2348 to 2352 out of 10000 .
# Iterating from 2352 to 2356 out of 10000 .
# Iterating from 2356 to 2360 out of 10000 .
# Iterating from 2360 to 2364 out of 10000 .
# Iterating from 2364 to 2368 out of 10000 .
# Iterating from 2368 to 2372 out of 10000 .
# Iterating from 2372 to 2376 out of 10000 .
# Iterating from 2376 to 2380 out of 10000 .
# Iterating from 2380 to 2384 out of 10000 .
# Iterating from 2384 to 2388 out of 10000 .
# Iterating from 2388 to 2392 out of 10000 .
# Iterating from 2392 to 2396 out of 10000 .
# Iterating from 2396 to 2400 out of 10000 .
# Iterating from 2400 to 2404 out of 10000 .
# Iterating from 2404 to 2408 out of 10000 .
# Iterating from 2408 to 2412 out of 10000 .
# Iterating from 2412 to 2416 out of 10000 .
# Iterating from 2416 to 2420 out of 10000 .
# Iterating from 2420 to 2424 out of 10000 .
# Iterating from 2424 to 2428 out of 10000 .
# Iterating from 2428 to 2432 out of 10000 .
# Iterating from 2432 to 2436 out of 10000 .
# Iterating from 2436 to 2440 out of 10000 .
# Iterating from 2440 to 2444 out of 10000 .
# Iterating from 2444 to 2448 out of 10000 .
# Iterating from 2448 to 2452 out of 10000 .
# Iterating from 2452 to 2456 out of 10000 .
# Iterating from 2456 to 2460 out of 10000 .
# Iterating from 2460 to 2464 out of 10000 .
# Iterating from 2464 to 2468 out of 10000 .
# Iterating from 2468 to 2472 out of 10000 .
# Iterating from 2472 to 2476 out of 10000 .
# Iterating from 2476 to 2480 out of 10000 .
# Iterating from 2480 to 2484 out of 10000 .
# Iterating from 2484 to 2488 out of 10000 .
# Iterating from 2488 to 2492 out of 10000 .
# Iterating from 2492 to 2496 out of 10000 .
# Iterating from 2496 to 2500 out of 10000 .
# Iterating from 2500 to 2504 out of 10000 .
# Iterating from 2504 to 2508 out of 10000 .
# Iterating from 2508 to 2512 out of 10000 .
# Iterating from 2512 to 2516 out of 10000 .
# Iterating from 2516 to 2520 out of 10000 .
# Iterating from 2520 to 2524 out of 10000 .
# Iterating from 2524 to 2528 out of 10000 .
# Iterating from 2528 to 2532 out of 10000 .
# Iterating from 2532 to 2536 out of 10000 .
# Iterating from 2536 to 2540 out of 10000 .
# Iterating from 2540 to 2544 out of 10000 .
# Iterating from 2544 to 2548 out of 10000 .
# Iterating from 2548 to 2552 out of 10000 .
# Iterating from 2552 to 2556 out of 10000 .
# Iterating from 2556 to 2560 out of 10000 .
# Iterating from 2560 to 2564 out of 10000 .
# Iterating from 2564 to 2568 out of 10000 .
# Iterating from 2568 to 2572 out of 10000 .
# Iterating from 2572 to 2576 out of 10000 .
# Iterating from 2576 to 2580 out of 10000 .
# Iterating from 2580 to 2584 out of 10000 .
# Iterating from 2584 to 2588 out of 10000 .
# Iterating from 2588 to 2592 out of 10000 .
# Iterating from 2592 to 2596 out of 10000 .
# Iterating from 2596 to 2600 out of 10000 .
# Iterating from 2600 to 2604 out of 10000 .
# Iterating from 2604 to 2608 out of 10000 .
# Iterating from 2608 to 2612 out of 10000 .
# Iterating from 2612 to 2616 out of 10000 .
# Iterating from 2616 to 2620 out of 10000 .
# Iterating from 2620 to 2624 out of 10000 .
# Iterating from 2624 to 2628 out of 10000 .
# Iterating from 2628 to 2632 out of 10000 .
# Iterating from 2632 to 2636 out of 10000 .
# Iterating from 2636 to 2640 out of 10000 .
# Iterating from 2640 to 2644 out of 10000 .
# Iterating from 2644 to 2648 out of 10000 .
# Iterating from 2648 to 2652 out of 10000 .
# Iterating from 2652 to 2656 out of 10000 .
# Iterating from 2656 to 2660 out of 10000 .
# Iterating from 2660 to 2664 out of 10000 .
# Iterating from 2664 to 2668 out of 10000 .
# Iterating from 2668 to 2672 out of 10000 .
# Iterating from 2672 to 2676 out of 10000 .
# Iterating from 2676 to 2680 out of 10000 .
# Iterating from 2680 to 2684 out of 10000 .
# Iterating from 2684 to 2688 out of 10000 .
# Iterating from 2688 to 2692 out of 10000 .
# Iterating from 2692 to 2696 out of 10000 .
# Iterating from 2696 to 2700 out of 10000 .
# Iterating from 2700 to 2704 out of 10000 .
# Iterating from 2704 to 2708 out of 10000 .
# Iterating from 2708 to 2712 out of 10000 .
# Iterating from 2712 to 2716 out of 10000 .
# Iterating from 2716 to 2720 out of 10000 .
# Iterating from 2720 to 2724 out of 10000 .
# Iterating from 2724 to 2728 out of 10000 .
# Iterating from 2728 to 2732 out of 10000 .
# Iterating from 2732 to 2736 out of 10000 .
# Iterating from 2736 to 2740 out of 10000 .
# Iterating from 2740 to 2744 out of 10000 .
# Iterating from 2744 to 2748 out of 10000 .
# Iterating from 2748 to 2752 out of 10000 .
# Iterating from 2752 to 2756 out of 10000 .
# Iterating from 2756 to 2760 out of 10000 .
# Iterating from 2760 to 2764 out of 10000 .
# Iterating from 2764 to 2768 out of 10000 .
# Iterating from 2768 to 2772 out of 10000 .
# Iterating from 2772 to 2776 out of 10000 .
# Iterating from 2776 to 2780 out of 10000 .
# Iterating from 2780 to 2784 out of 10000 .
# Iterating from 2784 to 2788 out of 10000 .
# Iterating from 2788 to 2792 out of 10000 .
# Iterating from 2792 to 2796 out of 10000 .
# Iterating from 2796 to 2800 out of 10000 .
# Iterating from 2800 to 2804 out of 10000 .
# Iterating from 2804 to 2808 out of 10000 .
# Iterating from 2808 to 2812 out of 10000 .
# Iterating from 2812 to 2816 out of 10000 .
# Iterating from 2816 to 2820 out of 10000 .
# Iterating from 2820 to 2824 out of 10000 .
# Iterating from 2824 to 2828 out of 10000 .
# Iterating from 2828 to 2832 out of 10000 .
# Iterating from 2832 to 2836 out of 10000 .
# Iterating from 2836 to 2840 out of 10000 .
# Iterating from 2840 to 2844 out of 10000 .
# Iterating from 2844 to 2848 out of 10000 .
# Iterating from 2848 to 2852 out of 10000 .
# Iterating from 2852 to 2856 out of 10000 .
# Iterating from 2856 to 2860 out of 10000 .
# Iterating from 2860 to 2864 out of 10000 .
# Iterating from 2864 to 2868 out of 10000 .
# Iterating from 2868 to 2872 out of 10000 .
# Iterating from 2872 to 2876 out of 10000 .
# Iterating from 2876 to 2880 out of 10000 .
# Iterating from 2880 to 2884 out of 10000 .
# Iterating from 2884 to 2888 out of 10000 .
# Iterating from 2888 to 2892 out of 10000 .
# Iterating from 2892 to 2896 out of 10000 .
# Iterating from 2896 to 2900 out of 10000 .
# Iterating from 2900 to 2904 out of 10000 .
# Iterating from 2904 to 2908 out of 10000 .
# Iterating from 2908 to 2912 out of 10000 .
# Iterating from 2912 to 2916 out of 10000 .
# Iterating from 2916 to 2920 out of 10000 .
# Iterating from 2920 to 2924 out of 10000 .
# Iterating from 2924 to 2928 out of 10000 .
# Iterating from 2928 to 2932 out of 10000 .
# Iterating from 2932 to 2936 out of 10000 .
# Iterating from 2936 to 2940 out of 10000 .
# Iterating from 2940 to 2944 out of 10000 .
# Iterating from 2944 to 2948 out of 10000 .
# Iterating from 2948 to 2952 out of 10000 .
# Iterating from 2952 to 2956 out of 10000 .
# Iterating from 2956 to 2960 out of 10000 .
# Iterating from 2960 to 2964 out of 10000 .
# Iterating from 2964 to 2968 out of 10000 .
# Iterating from 2968 to 2972 out of 10000 .
# Iterating from 2972 to 2976 out of 10000 .
# Iterating from 2976 to 2980 out of 10000 .
# Iterating from 2980 to 2984 out of 10000 .
# Iterating from 2984 to 2988 out of 10000 .
# Iterating from 2988 to 2992 out of 10000 .
# Iterating from 2992 to 2996 out of 10000 .
# Iterating from 2996 to 3000 out of 10000 .
# Iterating from 3000 to 3004 out of 10000 .
# Iterating from 3004 to 3008 out of 10000 .
# Iterating from 3008 to 3012 out of 10000 .
# Iterating from 3012 to 3016 out of 10000 .
# Iterating from 3016 to 3020 out of 10000 .
# Iterating from 3020 to 3024 out of 10000 .
# Iterating from 3024 to 3028 out of 10000 .
# Iterating from 3028 to 3032 out of 10000 .
# Iterating from 3032 to 3036 out of 10000 .
# Iterating from 3036 to 3040 out of 10000 .
# Iterating from 3040 to 3044 out of 10000 .
# Iterating from 3044 to 3048 out of 10000 .
# Iterating from 3048 to 3052 out of 10000 .
# Iterating from 3052 to 3056 out of 10000 .
# Iterating from 3056 to 3060 out of 10000 .
# Iterating from 3060 to 3064 out of 10000 .
# Iterating from 3064 to 3068 out of 10000 .
# Iterating from 3068 to 3072 out of 10000 .
# Iterating from 3072 to 3076 out of 10000 .
# Iterating from 3076 to 3080 out of 10000 .
# Iterating from 3080 to 3084 out of 10000 .
# Iterating from 3084 to 3088 out of 10000 .
# Iterating from 3088 to 3092 out of 10000 .
# Iterating from 3092 to 3096 out of 10000 .
# Iterating from 3096 to 3100 out of 10000 .
# Iterating from 3100 to 3104 out of 10000 .
# Iterating from 3104 to 3108 out of 10000 .
# Iterating from 3108 to 3112 out of 10000 .
# Iterating from 3112 to 3116 out of 10000 .
# Iterating from 3116 to 3120 out of 10000 .
# Iterating from 3120 to 3124 out of 10000 .
# Iterating from 3124 to 3128 out of 10000 .
# Iterating from 3128 to 3132 out of 10000 .
# Iterating from 3132 to 3136 out of 10000 .
# Iterating from 3136 to 3140 out of 10000 .
# Iterating from 3140 to 3144 out of 10000 .
# Iterating from 3144 to 3148 out of 10000 .
# Iterating from 3148 to 3152 out of 10000 .
# Iterating from 3152 to 3156 out of 10000 .
# Iterating from 3156 to 3160 out of 10000 .
# Iterating from 3160 to 3164 out of 10000 .
# Iterating from 3164 to 3168 out of 10000 .
# Iterating from 3168 to 3172 out of 10000 .
# Iterating from 3172 to 3176 out of 10000 .
# Iterating from 3176 to 3180 out of 10000 .
# Iterating from 3180 to 3184 out of 10000 .
# Iterating from 3184 to 3188 out of 10000 .
# Iterating from 3188 to 3192 out of 10000 .
# Iterating from 3192 to 3196 out of 10000 .
# Iterating from 3196 to 3200 out of 10000 .
# Iterating from 3200 to 3204 out of 10000 .
# Iterating from 3204 to 3208 out of 10000 .
# Iterating from 3208 to 3212 out of 10000 .
# Iterating from 3212 to 3216 out of 10000 .
# Iterating from 3216 to 3220 out of 10000 .
# Iterating from 3220 to 3224 out of 10000 .
# Iterating from 3224 to 3228 out of 10000 .
# Iterating from 3228 to 3232 out of 10000 .
# Iterating from 3232 to 3236 out of 10000 .
# Iterating from 3236 to 3240 out of 10000 .
# Iterating from 3240 to 3244 out of 10000 .
# Iterating from 3244 to 3248 out of 10000 .
# Iterating from 3248 to 3252 out of 10000 .
# Iterating from 3252 to 3256 out of 10000 .
# Iterating from 3256 to 3260 out of 10000 .
# Iterating from 3260 to 3264 out of 10000 .
# Iterating from 3264 to 3268 out of 10000 .
# Iterating from 3268 to 3272 out of 10000 .
# Iterating from 3272 to 3276 out of 10000 .
# Iterating from 3276 to 3280 out of 10000 .
# Iterating from 3280 to 3284 out of 10000 .
# Iterating from 3284 to 3288 out of 10000 .
# Iterating from 3288 to 3292 out of 10000 .
# Iterating from 3292 to 3296 out of 10000 .
# Iterating from 3296 to 3300 out of 10000 .
# Iterating from 3300 to 3304 out of 10000 .
# Iterating from 3304 to 3308 out of 10000 .
# Iterating from 3308 to 3312 out of 10000 .
# Iterating from 3312 to 3316 out of 10000 .
# Iterating from 3316 to 3320 out of 10000 .
# Iterating from 3320 to 3324 out of 10000 .
# Iterating from 3324 to 3328 out of 10000 .
# Iterating from 3328 to 3332 out of 10000 .
# Iterating from 3332 to 3336 out of 10000 .
# Iterating from 3336 to 3340 out of 10000 .
# Iterating from 3340 to 3344 out of 10000 .
# Iterating from 3344 to 3348 out of 10000 .
# Iterating from 3348 to 3352 out of 10000 .
# Iterating from 3352 to 3356 out of 10000 .
# Iterating from 3356 to 3360 out of 10000 .
# Iterating from 3360 to 3364 out of 10000 .
# Iterating from 3364 to 3368 out of 10000 .
# Iterating from 3368 to 3372 out of 10000 .
# Iterating from 3372 to 3376 out of 10000 .
# Iterating from 3376 to 3380 out of 10000 .
# Iterating from 3380 to 3384 out of 10000 .
# Iterating from 3384 to 3388 out of 10000 .
# Iterating from 3388 to 3392 out of 10000 .
# Iterating from 3392 to 3396 out of 10000 .
# Iterating from 3396 to 3400 out of 10000 .
# Iterating from 3400 to 3404 out of 10000 .
# Iterating from 3404 to 3408 out of 10000 .
# Iterating from 3408 to 3412 out of 10000 .
# Iterating from 3412 to 3416 out of 10000 .
# Iterating from 3416 to 3420 out of 10000 .
# Iterating from 3420 to 3424 out of 10000 .
# Iterating from 3424 to 3428 out of 10000 .
# Iterating from 3428 to 3432 out of 10000 .
# Iterating from 3432 to 3436 out of 10000 .
# Iterating from 3436 to 3440 out of 10000 .
# Iterating from 3440 to 3444 out of 10000 .
# Iterating from 3444 to 3448 out of 10000 .
# Iterating from 3448 to 3452 out of 10000 .
# Iterating from 3452 to 3456 out of 10000 .
# Iterating from 3456 to 3460 out of 10000 .
# Iterating from 3460 to 3464 out of 10000 .
# Iterating from 3464 to 3468 out of 10000 .
# Iterating from 3468 to 3472 out of 10000 .
# Iterating from 3472 to 3476 out of 10000 .
# Iterating from 3476 to 3480 out of 10000 .
# Iterating from 3480 to 3484 out of 10000 .
# Iterating from 3484 to 3488 out of 10000 .
# Iterating from 3488 to 3492 out of 10000 .
# Iterating from 3492 to 3496 out of 10000 .
# Iterating from 3496 to 3500 out of 10000 .
# Iterating from 3500 to 3504 out of 10000 .
# Iterating from 3504 to 3508 out of 10000 .
# Iterating from 3508 to 3512 out of 10000 .
# Iterating from 3512 to 3516 out of 10000 .
# Iterating from 3516 to 3520 out of 10000 .
# Iterating from 3520 to 3524 out of 10000 .
# Iterating from 3524 to 3528 out of 10000 .
# Iterating from 3528 to 3532 out of 10000 .
# Iterating from 3532 to 3536 out of 10000 .
# Iterating from 3536 to 3540 out of 10000 .
# Iterating from 3540 to 3544 out of 10000 .
# Iterating from 3544 to 3548 out of 10000 .
# Iterating from 3548 to 3552 out of 10000 .
# Iterating from 3552 to 3556 out of 10000 .
# Iterating from 3556 to 3560 out of 10000 .
# Iterating from 3560 to 3564 out of 10000 .
# Iterating from 3564 to 3568 out of 10000 .
# Iterating from 3568 to 3572 out of 10000 .
# Iterating from 3572 to 3576 out of 10000 .
# Iterating from 3576 to 3580 out of 10000 .
# Iterating from 3580 to 3584 out of 10000 .
# Iterating from 3584 to 3588 out of 10000 .
# Iterating from 3588 to 3592 out of 10000 .
# Iterating from 3592 to 3596 out of 10000 .
# Iterating from 3596 to 3600 out of 10000 .
# Iterating from 3600 to 3604 out of 10000 .
# Iterating from 3604 to 3608 out of 10000 .
# Iterating from 3608 to 3612 out of 10000 .
# Iterating from 3612 to 3616 out of 10000 .
# Iterating from 3616 to 3620 out of 10000 .
# Iterating from 3620 to 3624 out of 10000 .
# Iterating from 3624 to 3628 out of 10000 .
# Iterating from 3628 to 3632 out of 10000 .
# Iterating from 3632 to 3636 out of 10000 .
# Iterating from 3636 to 3640 out of 10000 .
# Iterating from 3640 to 3644 out of 10000 .
# Iterating from 3644 to 3648 out of 10000 .
# Iterating from 3648 to 3652 out of 10000 .
# Iterating from 3652 to 3656 out of 10000 .
# Iterating from 3656 to 3660 out of 10000 .
# Iterating from 3660 to 3664 out of 10000 .
# Iterating from 3664 to 3668 out of 10000 .
# Iterating from 3668 to 3672 out of 10000 .
# Iterating from 3672 to 3676 out of 10000 .
# Iterating from 3676 to 3680 out of 10000 .
# Iterating from 3680 to 3684 out of 10000 .
# Iterating from 3684 to 3688 out of 10000 .
# Iterating from 3688 to 3692 out of 10000 .
# Iterating from 3692 to 3696 out of 10000 .
# Iterating from 3696 to 3700 out of 10000 .
# Iterating from 3700 to 3704 out of 10000 .
# Iterating from 3704 to 3708 out of 10000 .
# Iterating from 3708 to 3712 out of 10000 .
# Iterating from 3712 to 3716 out of 10000 .
# Iterating from 3716 to 3720 out of 10000 .
# Iterating from 3720 to 3724 out of 10000 .
# Iterating from 3724 to 3728 out of 10000 .
# Iterating from 3728 to 3732 out of 10000 .
# Iterating from 3732 to 3736 out of 10000 .
# Iterating from 3736 to 3740 out of 10000 .
# Iterating from 3740 to 3744 out of 10000 .
# Iterating from 3744 to 3748 out of 10000 .
# Iterating from 3748 to 3752 out of 10000 .
# Iterating from 3752 to 3756 out of 10000 .
# Iterating from 3756 to 3760 out of 10000 .
# Iterating from 3760 to 3764 out of 10000 .
# Iterating from 3764 to 3768 out of 10000 .
# Iterating from 3768 to 3772 out of 10000 .
# Iterating from 3772 to 3776 out of 10000 .
# Iterating from 3776 to 3780 out of 10000 .
# Iterating from 3780 to 3784 out of 10000 .
# Iterating from 3784 to 3788 out of 10000 .
# Iterating from 3788 to 3792 out of 10000 .
# Iterating from 3792 to 3796 out of 10000 .
# Iterating from 3796 to 3800 out of 10000 .
# Iterating from 3800 to 3804 out of 10000 .
# Iterating from 3804 to 3808 out of 10000 .
# Iterating from 3808 to 3812 out of 10000 .
# Iterating from 3812 to 3816 out of 10000 .
# Iterating from 3816 to 3820 out of 10000 .
# Iterating from 3820 to 3824 out of 10000 .
# Iterating from 3824 to 3828 out of 10000 .
# Iterating from 3828 to 3832 out of 10000 .
# Iterating from 3832 to 3836 out of 10000 .
# Iterating from 3836 to 3840 out of 10000 .
# Iterating from 3840 to 3844 out of 10000 .
# Iterating from 3844 to 3848 out of 10000 .
# Iterating from 3848 to 3852 out of 10000 .
# Iterating from 3852 to 3856 out of 10000 .
# Iterating from 3856 to 3860 out of 10000 .
# Iterating from 3860 to 3864 out of 10000 .
# Iterating from 3864 to 3868 out of 10000 .
# Iterating from 3868 to 3872 out of 10000 .
# Iterating from 3872 to 3876 out of 10000 .
# Iterating from 3876 to 3880 out of 10000 .
# Iterating from 3880 to 3884 out of 10000 .
# Iterating from 3884 to 3888 out of 10000 .
# Iterating from 3888 to 3892 out of 10000 .
# Iterating from 3892 to 3896 out of 10000 .
# Iterating from 3896 to 3900 out of 10000 .
# Iterating from 3900 to 3904 out of 10000 .
# Iterating from 3904 to 3908 out of 10000 .
# Iterating from 3908 to 3912 out of 10000 .
# Iterating from 3912 to 3916 out of 10000 .
# Iterating from 3916 to 3920 out of 10000 .
# Iterating from 3920 to 3924 out of 10000 .
# Iterating from 3924 to 3928 out of 10000 .
# Iterating from 3928 to 3932 out of 10000 .
# Iterating from 3932 to 3936 out of 10000 .
# Iterating from 3936 to 3940 out of 10000 .
# Iterating from 3940 to 3944 out of 10000 .
# Iterating from 3944 to 3948 out of 10000 .
# Iterating from 3948 to 3952 out of 10000 .
# Iterating from 3952 to 3956 out of 10000 .
# Iterating from 3956 to 3960 out of 10000 .
# Iterating from 3960 to 3964 out of 10000 .
# Iterating from 3964 to 3968 out of 10000 .
# Iterating from 3968 to 3972 out of 10000 .
# Iterating from 3972 to 3976 out of 10000 .
# Iterating from 3976 to 3980 out of 10000 .
# Iterating from 3980 to 3984 out of 10000 .
# Iterating from 3984 to 3988 out of 10000 .
# Iterating from 3988 to 3992 out of 10000 .
# Iterating from 3992 to 3996 out of 10000 .
# Iterating from 3996 to 4000 out of 10000 .
# Iterating from 4000 to 4004 out of 10000 .
# Iterating from 4004 to 4008 out of 10000 .
# Iterating from 4008 to 4012 out of 10000 .
# Iterating from 4012 to 4016 out of 10000 .
# Iterating from 4016 to 4020 out of 10000 .
# Iterating from 4020 to 4024 out of 10000 .
# Iterating from 4024 to 4028 out of 10000 .
# Iterating from 4028 to 4032 out of 10000 .
# Iterating from 4032 to 4036 out of 10000 .
# Iterating from 4036 to 4040 out of 10000 .
# Iterating from 4040 to 4044 out of 10000 .
# Iterating from 4044 to 4048 out of 10000 .
# Iterating from 4048 to 4052 out of 10000 .
# Iterating from 4052 to 4056 out of 10000 .
# Iterating from 4056 to 4060 out of 10000 .
# Iterating from 4060 to 4064 out of 10000 .
# Iterating from 4064 to 4068 out of 10000 .
# Iterating from 4068 to 4072 out of 10000 .
# Iterating from 4072 to 4076 out of 10000 .
# Iterating from 4076 to 4080 out of 10000 .
# Iterating from 4080 to 4084 out of 10000 .
# Iterating from 4084 to 4088 out of 10000 .
# Iterating from 4088 to 4092 out of 10000 .
# Iterating from 4092 to 4096 out of 10000 .
# Iterating from 4096 to 4100 out of 10000 .
# Iterating from 4100 to 4104 out of 10000 .
# Iterating from 4104 to 4108 out of 10000 .
# Iterating from 4108 to 4112 out of 10000 .
# Iterating from 4112 to 4116 out of 10000 .
# Iterating from 4116 to 4120 out of 10000 .
# Iterating from 4120 to 4124 out of 10000 .
# Iterating from 4124 to 4128 out of 10000 .
# Iterating from 4128 to 4132 out of 10000 .
# Iterating from 4132 to 4136 out of 10000 .
# Iterating from 4136 to 4140 out of 10000 .
# Iterating from 4140 to 4144 out of 10000 .
# Iterating from 4144 to 4148 out of 10000 .
# Iterating from 4148 to 4152 out of 10000 .
# Iterating from 4152 to 4156 out of 10000 .
# Iterating from 4156 to 4160 out of 10000 .
# Iterating from 4160 to 4164 out of 10000 .
# Iterating from 4164 to 4168 out of 10000 .
# Iterating from 4168 to 4172 out of 10000 .
# Iterating from 4172 to 4176 out of 10000 .
# Iterating from 4176 to 4180 out of 10000 .
# Iterating from 4180 to 4184 out of 10000 .
# Iterating from 4184 to 4188 out of 10000 .
# Iterating from 4188 to 4192 out of 10000 .
# Iterating from 4192 to 4196 out of 10000 .
# Iterating from 4196 to 4200 out of 10000 .
# Iterating from 4200 to 4204 out of 10000 .
# Iterating from 4204 to 4208 out of 10000 .
# Iterating from 4208 to 4212 out of 10000 .
# Iterating from 4212 to 4216 out of 10000 .
# Iterating from 4216 to 4220 out of 10000 .
# Iterating from 4220 to 4224 out of 10000 .
# Iterating from 4224 to 4228 out of 10000 .
# Iterating from 4228 to 4232 out of 10000 .
# Iterating from 4232 to 4236 out of 10000 .
# Iterating from 4236 to 4240 out of 10000 .
# Iterating from 4240 to 4244 out of 10000 .
# Iterating from 4244 to 4248 out of 10000 .
# Iterating from 4248 to 4252 out of 10000 .
# Iterating from 4252 to 4256 out of 10000 .
# Iterating from 4256 to 4260 out of 10000 .
# Iterating from 4260 to 4264 out of 10000 .
# Iterating from 4264 to 4268 out of 10000 .
# Iterating from 4268 to 4272 out of 10000 .
# Iterating from 4272 to 4276 out of 10000 .
# Iterating from 4276 to 4280 out of 10000 .
# Iterating from 4280 to 4284 out of 10000 .
# Iterating from 4284 to 4288 out of 10000 .
# Iterating from 4288 to 4292 out of 10000 .
# Iterating from 4292 to 4296 out of 10000 .
# Iterating from 4296 to 4300 out of 10000 .
# Iterating from 4300 to 4304 out of 10000 .
# Iterating from 4304 to 4308 out of 10000 .
# Iterating from 4308 to 4312 out of 10000 .
# Iterating from 4312 to 4316 out of 10000 .
# Iterating from 4316 to 4320 out of 10000 .
# Iterating from 4320 to 4324 out of 10000 .
# Iterating from 4324 to 4328 out of 10000 .
# Iterating from 4328 to 4332 out of 10000 .
# Iterating from 4332 to 4336 out of 10000 .
# Iterating from 4336 to 4340 out of 10000 .
# Iterating from 4340 to 4344 out of 10000 .
# Iterating from 4344 to 4348 out of 10000 .
# Iterating from 4348 to 4352 out of 10000 .
# Iterating from 4352 to 4356 out of 10000 .
# Iterating from 4356 to 4360 out of 10000 .
# Iterating from 4360 to 4364 out of 10000 .
# Iterating from 4364 to 4368 out of 10000 .
# Iterating from 4368 to 4372 out of 10000 .
# Iterating from 4372 to 4376 out of 10000 .
# Iterating from 4376 to 4380 out of 10000 .
# Iterating from 4380 to 4384 out of 10000 .
# Iterating from 4384 to 4388 out of 10000 .
# Iterating from 4388 to 4392 out of 10000 .
# Iterating from 4392 to 4396 out of 10000 .
# Iterating from 4396 to 4400 out of 10000 .
# Iterating from 4400 to 4404 out of 10000 .
# Iterating from 4404 to 4408 out of 10000 .
# Iterating from 4408 to 4412 out of 10000 .
# Iterating from 4412 to 4416 out of 10000 .
# Iterating from 4416 to 4420 out of 10000 .
# Iterating from 4420 to 4424 out of 10000 .
# Iterating from 4424 to 4428 out of 10000 .
# Iterating from 4428 to 4432 out of 10000 .
# Iterating from 4432 to 4436 out of 10000 .
# Iterating from 4436 to 4440 out of 10000 .
# Iterating from 4440 to 4444 out of 10000 .
# Iterating from 4444 to 4448 out of 10000 .
# Iterating from 4448 to 4452 out of 10000 .
# Iterating from 4452 to 4456 out of 10000 .
# Iterating from 4456 to 4460 out of 10000 .
# Iterating from 4460 to 4464 out of 10000 .
# Iterating from 4464 to 4468 out of 10000 .
# Iterating from 4468 to 4472 out of 10000 .
# Iterating from 4472 to 4476 out of 10000 .
# Iterating from 4476 to 4480 out of 10000 .
# Iterating from 4480 to 4484 out of 10000 .
# ...
# Iterating from 8544 to 8548 out of 10000 .
# Iterating from 8548 to 8552 out of 10000 .
# Iterating from 8552 to 8556 out of 10000 .
# Iterating from 8556 to 8560 out of 10000 .
# Iterating from 8560 to 8564 out of 10000 .
# Iterating from 8564 to 8568 out of 10000 .
# Iterating from 8568 to 8572 out of 10000 .
# Iterating from 8572 to 8576 out of 10000 .
# Iterating from 8576 to 8580 out of 10000 .
# Iterating from 8580 to 8584 out of 10000 .
# Iterating from 8584 to 8588 out of 10000 .
# Iterating from 8588 to 8592 out of 10000 .
# Iterating from 8592 to 8596 out of 10000 .
# Iterating from 8596 to 8600 out of 10000 .
# Iterating from 8600 to 8604 out of 10000 .
# Iterating from 8604 to 8608 out of 10000 .
# Iterating from 8608 to 8612 out of 10000 .
# Iterating from 8612 to 8616 out of 10000 .
# Iterating from 8616 to 8620 out of 10000 .
# Iterating from 8620 to 8624 out of 10000 .
# Iterating from 8624 to 8628 out of 10000 .
# Iterating from 8628 to 8632 out of 10000 .
# Iterating from 8632 to 8636 out of 10000 .
# Iterating from 8636 to 8640 out of 10000 .
# Iterating from 8640 to 8644 out of 10000 .
# Iterating from 8644 to 8648 out of 10000 .
# Iterating from 8648 to 8652 out of 10000 .
# Iterating from 8652 to 8656 out of 10000 .
# Iterating from 8656 to 8660 out of 10000 .
# Iterating from 8660 to 8664 out of 10000 .
# Iterating from 8664 to 8668 out of 10000 .
# Iterating from 8668 to 8672 out of 10000 .
# Iterating from 8672 to 8676 out of 10000 .
# Iterating from 8676 to 8680 out of 10000 .
# Iterating from 8680 to 8684 out of 10000 .
# Iterating from 8684 to 8688 out of 10000 .
# Iterating from 8688 to 8692 out of 10000 .
# Iterating from 8692 to 8696 out of 10000 .
# Iterating from 8696 to 8700 out of 10000 .
# Iterating from 8700 to 8704 out of 10000 .
# Iterating from 8704 to 8708 out of 10000 .
# Iterating from 8708 to 8712 out of 10000 .
# Iterating from 8712 to 8716 out of 10000 .
# Iterating from 8716 to 8720 out of 10000 .
# Iterating from 8720 to 8724 out of 10000 .
# Iterating from 8724 to 8728 out of 10000 .
# Iterating from 8728 to 8732 out of 10000 .
# Iterating from 8732 to 8736 out of 10000 .
# Iterating from 8736 to 8740 out of 10000 .
# Iterating from 8740 to 8744 out of 10000 .
# Iterating from 8744 to 8748 out of 10000 .
# Iterating from 8748 to 8752 out of 10000 .
# Iterating from 8752 to 8756 out of 10000 .
# Iterating from 8756 to 8760 out of 10000 .
# Iterating from 8760 to 8764 out of 10000 .
# Iterating from 8764 to 8768 out of 10000 .
# Iterating from 8768 to 8772 out of 10000 .
# Iterating from 8772 to 8776 out of 10000 .
# Iterating from 8776 to 8780 out of 10000 .
# Iterating from 8780 to 8784 out of 10000 .
# Iterating from 8784 to 8788 out of 10000 .
# Iterating from 8788 to 8792 out of 10000 .
# Iterating from 8792 to 8796 out of 10000 .
# Iterating from 8796 to 8800 out of 10000 .
# Iterating from 8800 to 8804 out of 10000 .
# Iterating from 8804 to 8808 out of 10000 .
# Iterating from 8808 to 8812 out of 10000 .
# Iterating from 8812 to 8816 out of 10000 .
# Iterating from 8816 to 8820 out of 10000 .
# Iterating from 8820 to 8824 out of 10000 .
# Iterating from 8824 to 8828 out of 10000 .
# Iterating from 8828 to 8832 out of 10000 .
# Iterating from 8832 to 8836 out of 10000 .
# Iterating from 8836 to 8840 out of 10000 .
# Iterating from 8840 to 8844 out of 10000 .
# Iterating from 8844 to 8848 out of 10000 .
# Iterating from 8848 to 8852 out of 10000 .
# Iterating from 8852 to 8856 out of 10000 .
# Iterating from 8856 to 8860 out of 10000 .
# Iterating from 8860 to 8864 out of 10000 .
# Iterating from 8864 to 8868 out of 10000 .
# Iterating from 8868 to 8872 out of 10000 .
# Iterating from 8872 to 8876 out of 10000 .
# Iterating from 8876 to 8880 out of 10000 .
# Iterating from 8880 to 8884 out of 10000 .
# Iterating from 8884 to 8888 out of 10000 .
# Iterating from 8888 to 8892 out of 10000 .
# Iterating from 8892 to 8896 out of 10000 .
# Iterating from 8896 to 8900 out of 10000 .
# Iterating from 8900 to 8904 out of 10000 .
# Iterating from 8904 to 8908 out of 10000 .
# Iterating from 8908 to 8912 out of 10000 .
# Iterating from 8912 to 8916 out of 10000 .
# Iterating from 8916 to 8920 out of 10000 .
# Iterating from 8920 to 8924 out of 10000 .
# Iterating from 8924 to 8928 out of 10000 .
# Iterating from 8928 to 8932 out of 10000 .
# Iterating from 8932 to 8936 out of 10000 .
# Iterating from 8936 to 8940 out of 10000 .
# Iterating from 8940 to 8944 out of 10000 .
# Iterating from 8944 to 8948 out of 10000 .
# Iterating from 8948 to 8952 out of 10000 .
# Iterating from 8952 to 8956 out of 10000 .
# Iterating from 8956 to 8960 out of 10000 .
# Iterating from 8960 to 8964 out of 10000 .
# Iterating from 8964 to 8968 out of 10000 .
# Iterating from 8968 to 8972 out of 10000 .
# Iterating from 8972 to 8976 out of 10000 .
# Iterating from 8976 to 8980 out of 10000 .
# Iterating from 8980 to 8984 out of 10000 .
# Iterating from 8984 to 8988 out of 10000 .
# Iterating from 8988 to 8992 out of 10000 .
# Iterating from 8992 to 8996 out of 10000 .
# Iterating from 8996 to 9000 out of 10000 .
# Iterating from 9000 to 9004 out of 10000 .
# Iterating from 9004 to 9008 out of 10000 .
# Iterating from 9008 to 9012 out of 10000 .
# Iterating from 9012 to 9016 out of 10000 .
# Iterating from 9016 to 9020 out of 10000 .
# Iterating from 9020 to 9024 out of 10000 .
# Iterating from 9024 to 9028 out of 10000 .
# Iterating from 9028 to 9032 out of 10000 .
# Iterating from 9032 to 9036 out of 10000 .
# Iterating from 9036 to 9040 out of 10000 .
# Iterating from 9040 to 9044 out of 10000 .
# Iterating from 9044 to 9048 out of 10000 .
# Iterating from 9048 to 9052 out of 10000 .
# Iterating from 9052 to 9056 out of 10000 .
# Iterating from 9056 to 9060 out of 10000 .
# Iterating from 9060 to 9064 out of 10000 .
# Iterating from 9064 to 9068 out of 10000 .
# Iterating from 9068 to 9072 out of 10000 .
# Iterating from 9072 to 9076 out of 10000 .
# Iterating from 9076 to 9080 out of 10000 .
# Iterating from 9080 to 9084 out of 10000 .
# Iterating from 9084 to 9088 out of 10000 .
# Iterating from 9088 to 9092 out of 10000 .
# Iterating from 9092 to 9096 out of 10000 .
# Iterating from 9096 to 9100 out of 10000 .
# Iterating from 9100 to 9104 out of 10000 .
# Iterating from 9104 to 9108 out of 10000 .
# Iterating from 9108 to 9112 out of 10000 .
# Iterating from 9112 to 9116 out of 10000 .
# Iterating from 9116 to 9120 out of 10000 .
# Iterating from 9120 to 9124 out of 10000 .
# Iterating from 9124 to 9128 out of 10000 .
# Iterating from 9128 to 9132 out of 10000 .
# Iterating from 9132 to 9136 out of 10000 .
# Iterating from 9136 to 9140 out of 10000 .
# Iterating from 9140 to 9144 out of 10000 .
# Iterating from 9144 to 9148 out of 10000 .
# Iterating from 9148 to 9152 out of 10000 .
# Iterating from 9152 to 9156 out of 10000 .
# Iterating from 9156 to 9160 out of 10000 .
# Iterating from 9160 to 9164 out of 10000 .
# Iterating from 9164 to 9168 out of 10000 .
# Iterating from 9168 to 9172 out of 10000 .
# Iterating from 9172 to 9176 out of 10000 .
# Iterating from 9176 to 9180 out of 10000 .
# Iterating from 9180 to 9184 out of 10000 .
# Iterating from 9184 to 9188 out of 10000 .
# Iterating from 9188 to 9192 out of 10000 .
# Iterating from 9192 to 9196 out of 10000 .
# Iterating from 9196 to 9200 out of 10000 .
# Iterating from 9200 to 9204 out of 10000 .
# Iterating from 9204 to 9208 out of 10000 .
# Iterating from 9208 to 9212 out of 10000 .
# Iterating from 9212 to 9216 out of 10000 .
# Iterating from 9216 to 9220 out of 10000 .
# Iterating from 9220 to 9224 out of 10000 .
# Iterating from 9224 to 9228 out of 10000 .
# Iterating from 9228 to 9232 out of 10000 .
# Iterating from 9232 to 9236 out of 10000 .
# Iterating from 9236 to 9240 out of 10000 .
# Iterating from 9240 to 9244 out of 10000 .
# Iterating from 9244 to 9248 out of 10000 .
# Iterating from 9248 to 9252 out of 10000 .
# Iterating from 9252 to 9256 out of 10000 .
# Iterating from 9256 to 9260 out of 10000 .
# Iterating from 9260 to 9264 out of 10000 .
# Iterating from 9264 to 9268 out of 10000 .
# Iterating from 9268 to 9272 out of 10000 .
# Iterating from 9272 to 9276 out of 10000 .
# Iterating from 9276 to 9280 out of 10000 .
# Iterating from 9280 to 9284 out of 10000 .
# Iterating from 9284 to 9288 out of 10000 .
# Iterating from 9288 to 9292 out of 10000 .
# Iterating from 9292 to 9296 out of 10000 .
# Iterating from 9296 to 9300 out of 10000 .
# Iterating from 9300 to 9304 out of 10000 .
# Iterating from 9304 to 9308 out of 10000 .
# Iterating from 9308 to 9312 out of 10000 .
# Iterating from 9312 to 9316 out of 10000 .
# Iterating from 9316 to 9320 out of 10000 .
# Iterating from 9320 to 9324 out of 10000 .
# Iterating from 9324 to 9328 out of 10000 .
# Iterating from 9328 to 9332 out of 10000 .
# Iterating from 9332 to 9336 out of 10000 .
# Iterating from 9336 to 9340 out of 10000 .
# Iterating from 9340 to 9344 out of 10000 .
# Iterating from 9344 to 9348 out of 10000 .
# Iterating from 9348 to 9352 out of 10000 .
# Iterating from 9352 to 9356 out of 10000 .
# Iterating from 9356 to 9360 out of 10000 .
# Iterating from 9360 to 9364 out of 10000 .
# Iterating from 9364 to 9368 out of 10000 .
# Iterating from 9368 to 9372 out of 10000 .
# Iterating from 9372 to 9376 out of 10000 .
# Iterating from 9376 to 9380 out of 10000 .
# Iterating from 9380 to 9384 out of 10000 .
# Iterating from 9384 to 9388 out of 10000 .
# Iterating from 9388 to 9392 out of 10000 .
# Iterating from 9392 to 9396 out of 10000 .
# Iterating from 9396 to 9400 out of 10000 .
# Iterating from 9400 to 9404 out of 10000 .
# Iterating from 9404 to 9408 out of 10000 .
# Iterating from 9408 to 9412 out of 10000 .
# Iterating from 9412 to 9416 out of 10000 .
# Iterating from 9416 to 9420 out of 10000 .
# Iterating from 9420 to 9424 out of 10000 .
# Iterating from 9424 to 9428 out of 10000 .
# Iterating from 9428 to 9432 out of 10000 .
# Iterating from 9432 to 9436 out of 10000 .
# Iterating from 9436 to 9440 out of 10000 .
# Iterating from 9440 to 9444 out of 10000 .
# Iterating from 9444 to 9448 out of 10000 .
# Iterating from 9448 to 9452 out of 10000 .
# Iterating from 9452 to 9456 out of 10000 .
# Iterating from 9456 to 9460 out of 10000 .
# Iterating from 9460 to 9464 out of 10000 .
# Iterating from 9464 to 9468 out of 10000 .
# Iterating from 9468 to 9472 out of 10000 .
# Iterating from 9472 to 9476 out of 10000 .
# Iterating from 9476 to 9480 out of 10000 .
# Iterating from 9480 to 9484 out of 10000 .
# Iterating from 9484 to 9488 out of 10000 .
# Iterating from 9488 to 9492 out of 10000 .
# Iterating from 9492 to 9496 out of 10000 .
# Iterating from 9496 to 9500 out of 10000 .
# Iterating from 9500 to 9504 out of 10000 .
# Iterating from 9504 to 9508 out of 10000 .
# Iterating from 9508 to 9512 out of 10000 .
# Iterating from 9512 to 9516 out of 10000 .
# Iterating from 9516 to 9520 out of 10000 .
# Iterating from 9520 to 9524 out of 10000 .
# Iterating from 9524 to 9528 out of 10000 .
# Iterating from 9528 to 9532 out of 10000 .
# Iterating from 9532 to 9536 out of 10000 .
# Iterating from 9536 to 9540 out of 10000 .
# Iterating from 9540 to 9544 out of 10000 .
# Iterating from 9544 to 9548 out of 10000 .
# Iterating from 9548 to 9552 out of 10000 .
# Iterating from 9552 to 9556 out of 10000 .
# Iterating from 9556 to 9560 out of 10000 .
# Iterating from 9560 to 9564 out of 10000 .
# Iterating from 9564 to 9568 out of 10000 .
# Iterating from 9568 to 9572 out of 10000 .
# Iterating from 9572 to 9576 out of 10000 .
# Iterating from 9576 to 9580 out of 10000 .
# Iterating from 9580 to 9584 out of 10000 .
# Iterating from 9584 to 9588 out of 10000 .
# Iterating from 9588 to 9592 out of 10000 .
# Iterating from 9592 to 9596 out of 10000 .
# Iterating from 9596 to 9600 out of 10000 .
# Iterating from 9600 to 9604 out of 10000 .
# Iterating from 9604 to 9608 out of 10000 .
# Iterating from 9608 to 9612 out of 10000 .
# Iterating from 9612 to 9616 out of 10000 .
# Iterating from 9616 to 9620 out of 10000 .
# Iterating from 9620 to 9624 out of 10000 .
# Iterating from 9624 to 9628 out of 10000 .
# Iterating from 9628 to 9632 out of 10000 .
# Iterating from 9632 to 9636 out of 10000 .
# Iterating from 9636 to 9640 out of 10000 .
# Iterating from 9640 to 9644 out of 10000 .
# Iterating from 9644 to 9648 out of 10000 .
# Iterating from 9648 to 9652 out of 10000 .
# Iterating from 9652 to 9656 out of 10000 .
# Iterating from 9656 to 9660 out of 10000 .
# Iterating from 9660 to 9664 out of 10000 .
# Iterating from 9664 to 9668 out of 10000 .
# Iterating from 9668 to 9672 out of 10000 .
# Iterating from 9672 to 9676 out of 10000 .
# Iterating from 9676 to 9680 out of 10000 .
# Iterating from 9680 to 9684 out of 10000 .
# Iterating from 9684 to 9688 out of 10000 .
# Iterating from 9688 to 9692 out of 10000 .
# Iterating from 9692 to 9696 out of 10000 .
# Iterating from 9696 to 9700 out of 10000 .
# Iterating from 9700 to 9704 out of 10000 .
# Iterating from 9704 to 9708 out of 10000 .
# Iterating from 9708 to 9712 out of 10000 .
# Iterating from 9712 to 9716 out of 10000 .
# Iterating from 9716 to 9720 out of 10000 .
# Iterating from 9720 to 9724 out of 10000 .
# Iterating from 9724 to 9728 out of 10000 .
# Iterating from 9728 to 9732 out of 10000 .
# Iterating from 9732 to 9736 out of 10000 .
# Iterating from 9736 to 9740 out of 10000 .
# Iterating from 9740 to 9744 out of 10000 .
# Iterating from 9744 to 9748 out of 10000 .
# Iterating from 9748 to 9752 out of 10000 .
# Iterating from 9752 to 9756 out of 10000 .
# Iterating from 9756 to 9760 out of 10000 .
# Iterating from 9760 to 9764 out of 10000 .
# Iterating from 9764 to 9768 out of 10000 .
# Iterating from 9768 to 9772 out of 10000 .
# Iterating from 9772 to 9776 out of 10000 .
# Iterating from 9776 to 9780 out of 10000 .
# Iterating from 9780 to 9784 out of 10000 .
# Iterating from 9784 to 9788 out of 10000 .
# Iterating from 9788 to 9792 out of 10000 .
# Iterating from 9792 to 9796 out of 10000 .
# Iterating from 9796 to 9800 out of 10000 .
# Iterating from 9800 to 9804 out of 10000 .
# Iterating from 9804 to 9808 out of 10000 .
# Iterating from 9808 to 9812 out of 10000 .
# Iterating from 9812 to 9816 out of 10000 .
# Iterating from 9816 to 9820 out of 10000 .
# Iterating from 9820 to 9824 out of 10000 .
# Iterating from 9824 to 9828 out of 10000 .
# Iterating from 9828 to 9832 out of 10000 .
# Iterating from 9832 to 9836 out of 10000 .
# Iterating from 9836 to 9840 out of 10000 .
# Iterating from 9840 to 9844 out of 10000 .
# Iterating from 9844 to 9848 out of 10000 .
# Iterating from 9848 to 9852 out of 10000 .
# Iterating from 9852 to 9856 out of 10000 .
# Iterating from 9856 to 9860 out of 10000 .
# Iterating from 9860 to 9864 out of 10000 .
# Iterating from 9864 to 9868 out of 10000 .
# Iterating from 9868 to 9872 out of 10000 .
# Iterating from 9872 to 9876 out of 10000 .
# Iterating from 9876 to 9880 out of 10000 .
# Iterating from 9880 to 9884 out of 10000 .
# Iterating from 9884 to 9888 out of 10000 .
# Iterating from 9888 to 9892 out of 10000 .
# Iterating from 9892 to 9896 out of 10000 .
# Iterating from 9896 to 9900 out of 10000 .
# Iterating from 9900 to 9904 out of 10000 .
# Iterating from 9904 to 9908 out of 10000 .
# Iterating from 9908 to 9912 out of 10000 .
# Iterating from 9912 to 9916 out of 10000 .
# Iterating from 9916 to 9920 out of 10000 .
# Iterating from 9920 to 9924 out of 10000 .
# Iterating from 9924 to 9928 out of 10000 .
# Iterating from 9928 to 9932 out of 10000 .
# Iterating from 9932 to 9936 out of 10000 .
# Iterating from 9936 to 9940 out of 10000 .
# Iterating from 9940 to 9944 out of 10000 .
# Iterating from 9944 to 9948 out of 10000 .
# Iterating from 9948 to 9952 out of 10000 .
# Iterating from 9952 to 9956 out of 10000 .
# Iterating from 9956 to 9960 out of 10000 .
# Iterating from 9960 to 9964 out of 10000 .
# Iterating from 9964 to 9968 out of 10000 .
# Iterating from 9968 to 9972 out of 10000 .
# Iterating from 9972 to 9976 out of 10000 .
# Iterating from 9976 to 9980 out of 10000 .
# Iterating from 9980 to 9984 out of 10000 .
# Iterating from 9984 to 9988 out of 10000 .
# Iterating from 9988 to 9992 out of 10000 .
# Iterating from 9992 to 9996 out of 10000 .
# Iterating from 9996 to 10000 out of 10000 .
# KPD metric calculation completed in 20944.294048491865 seconds.
# {'metric_list': array([-1.38133389e-04, -6.03371070e-05, -8.19768747e-05, ...,
#          2.64014931e-05, -9.87640947e-05,  7.27801007e-05]),
#  'metric_error_list': array([9.90573839e-05, 2.08303463e-04, 1.81777284e-04, ...,
#         1.96117540e-04, 2.68182118e-04, 1.25815931e-04])}

# %%
KPDMetric.Results.save_to_json(null_hypotheses_dir+"Null_100D_KPD.json")

# %%
KPDMetric.Results.load_from_json(null_hypotheses_dir+"Null_100D_KPD.json")

# %%
start = timer()

nsamples = KPDMetric.Inputs.batch_size_test
niter = KPDMetric.Inputs.niter
ns = nsamples**2 /(2*nsamples)

scale = 'log'
num_bins = 50  # number of bins|
dist_null = np.array(KPDMetric.Results[-1].result_value["metric_list"])*ns/np.sqrt(ndims)
# Compute the mean and standard deviation of the sample and their standard errors
mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
print("mu =", mu, "+/-", deltamu)
print("sigma =", sigma, "+/-", deltasigma)
# Minimum and maximum x values
min_x = min(dist_null) # lower limit of the binning
max_x = max(dist_null) # upper limit of the binning
# Create an array of values
x = np.linspace(min_x, max_x, num_bins + 1)
# Create histogram for values and normalize counts to sum to 1
counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
cum_counts = np.cumsum(counts)/np.sum(counts)
# Get the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
# Calculate the theoretical PDF and CDF of the KS distribution for each x value
#theoretical_pdf_ks = kstwobign.pdf(x)
#theoretical_cdf_ks = kstwobign.cdf(x)

# Empirical SKS Normal
#empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
#empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
# Set up the figure and the two subplots
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
# Draw the first plot
ax[0].plot(bin_centers, counts, linestyle = '-', label='KPD Null', drawstyle='steps-mid')
#ax[0].plot(x, theoretical_pdf_ks, label='Theoretical distribution (KS)')
#ax[0].plot(x, empirical_pdf_norm, label='KPD - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[0].set_yscale(scale)
#ax[0].set_xlim(0.005*np.sqrt(ns), 0.025*np.sqrt(ns))
#ax[0].set_ylim(0.01, 5)
ax[0].set_xlabel('KPD')
ax[0].set_ylabel('Number of pseudo-experiments')
ax[0].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - PDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[0].legend(loc='upper right')
# Draw the second plot
ax[1].plot(bin_centers, cum_counts, linestyle = '-', label='KS Null', drawstyle='steps-mid')
#ax[1].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
#ax[1].plot(x, empirical_cdf_norm, label='KPD - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
ax[1].set_yscale(scale)
#ax[1].set_xlim(0.005*np.sqrt(ns), 0.025*np.sqrt(ns))
#ax[1].set_ylim(9e-4, 1.5)
ax[1].set_xlabel('KPD')
ax[1].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
ax[1].legend(loc='lower right')
## Draw the third plot
#ax[2].plot(bin_centers, cum_counts, linestyle = '-', label='FN Null', drawstyle='steps-mid')
##ax[2].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
##ax[2].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
#ax[2].set_yscale(scale)
#ax[2].set_xlim(0.25, 2)
#ax[2].set_ylim(0.8, 1)
#ax[2].set_xlabel('KS vs SKS')
#ax[2].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys')
#ax[2].legend(loc='lower right')
# Adjust the width space
plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
# Display the figure with the two subplots
plt.tight_layout()
#plt.savefig(results_path+'SKS_nsamples_'+str(nsamples)+'_ndims_'+'_'+str(ndims)+'_niter_'+str(niter)+'.pdf')
plt.show()
plt.close()
end = timer()
print("Time elapsed:", end-start, "seconds.")
# Out:
# mu = 0.017010195257243545 +/- 5.2964868683339965e-05
# sigma = 0.07277696660574688 +/- 0.0010726763195829001
# Time elapsed: 0.6327220425009727 seconds.

# %%
cl_list = [0.68, 0.95, 0.99]
kpd_thresholds = [[cl, [int(cl*len(dist_null)), int((1-cl)*len(dist_null))], np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
kpd_thresholds
# Out:
# [[0.68, [6800, 3199], 0.02934541750065911],
#  [0.95, [9500, 500], 0.15536237972302303],
#  [0.99, [9900, 100], 0.2835153946787461]]

# %% [markdown]
# # Alternative hypotheses

# %% [markdown]
# ## Thresholds

# %%
print(f"fn_thresholds: {fn_thresholds}")
print(f"fpd_thresholds: {fpd_thresholds}")
print(f"kpd_thresholds: {kpd_thresholds}")
print(f"ks_thresholds: {ks_thresholds}")
print(f"multi_ks_thresholds: {multi_ks_thresholds}")
print(f"sks_thresholds: {sks_thresholds}")
print(f"swd_thresholds: {swd_thresholds}")

# %% [markdown]
# ## Scan

# %%
niter = 10_000
nsamples = 10_000
ns = nsamples**2 /(2*nsamples)

fn_list = []
fpd_list = []
kpd_list = []
ks_list = []
multi_ks_list = []
sks_list = []
swd_list = []
exclusion_list = []

fn_threshold_number = 0
fpd_threshold_number = 0
kpd_threshold_number = 0
ks_threshold_number = 0
multi_ks_threshold_number = 0
sks_threshold_number = 0
swd_threshold_number = 0

start = timer()  
for i in range(500):
    seed = 0
    ncomp = 3
    ndims = 20
    delta = 0.0001
    eps = 0+i*delta
    print("\n------------------")
    print(f"eps = {eps}")
    eps_loc = 10*eps
    eps_scale = eps
    dist_1 = MixtureDistributions.MixtureGaussian(ncomp, ndims, 0., 0., seed)
    dist_2 = MixtureDistributions.MixtureGaussian(ncomp, ndims, eps_loc, eps_scale, seed)

    TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                       dist_2_input = dist_2,
                                                       niter = 10,
                                                       batch_size_test = 10_000,
                                                       batch_size_gen = 100,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = False)

    FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             verbose = False)
    FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = False,
                               verbose = False)
    KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                                 progress_bar = False,
                                 verbose = False)
    KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                             verbose = False)
    MultiKSTest = GMetrics.MultiKSTest(TwoSampleTestInputs,
                                       verbose = False)
    SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                               nslices = 100,
                               seed_slicing = 0,
                               verbose = False)
    SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                                   nslices = 100,
                                   seed_slicing = 0,
                                   verbose = False)

    if fn_threshold_number < len(fn_thresholds):
        FNMetric.Test_tf(max_vectorize = 1000)
        fn = np.mean(FNMetric.Results[-1].result_value["metric_list"])*np.sqrt(ns)
        fn_list.append(fn)
        print(f"fn statistic = {fn}")
        fn_threshold = fn_thresholds[fn_threshold_number]
        if fn > fn_threshold[1]:
            end = timer()
            print(f"=======> fn excluded at {fn_threshold[0]} CL in {end-start} seconds")
            exclusion_list.append([eps, "fn statistic", fn, fn_threshold[0]])
            fn_threshold_number += 1
            
    if fpd_threshold_number < len(fpd_thresholds):
        FPDMetric.Test_tf(max_vectorize=400)
        fpd = np.mean(FPDMetric.Results[-1].result_value["metric_list"])*np.sqrt(ns)
        fpd_list.append(fpd)
        print(f"fpd statistic = {fpd}")
        fpd_threshold = fpd_thresholds[fpd_threshold_number]
        if fpd > fpd_threshold[1]:
            end = timer()
            print(f"=======> fpd excluded at {fpd_threshold[0]} CL in {end-start} seconds")
            exclusion_list.append([eps, "fpd statistic", fpd, fpd_threshold[0]])
            fpd_threshold_number += 1
            
    if kpd_threshold_number < len(kpd_thresholds):
        KPDMetric.Test_tf(max_vectorize=2)
        kpd = np.mean(KPDMetric.Results[-1].result_value["metric_list"])*np.sqrt(ns)
        kpd_list.append(kpd)
        print(f"kpd statistic = {kpd}")
        kpd_threshold = kpd_thresholds[kpd_threshold_number]
        if kpd > kpd_threshold[1]:
            end = timer()
            print(f"=======> kpd excluded at {kpd_threshold[0]} CL in {end-start} seconds")
            exclusion_list.append([eps, "kpd statistic", kpd, kpd_threshold[0]])
            kpd_threshold_number += 1

    if ks_threshold_number < len(ks_thresholds):
        KSTest.Test_tf(max_vectorize=1000)
        ks = np.mean(KSTest.Results[-1].result_value["statistic_means"])*np.sqrt(ns)
        ks_list.append(ks)
        print(f"ks statistic = {ks}")
        ks_threshold = ks_thresholds[ks_threshold_number]
        if ks > ks_threshold[1]:
            end = timer()
            print(f"=======> ks excluded at {ks_threshold[0]} CL in {end-start} seconds")
            exclusion_list.append([eps, "ks statistic", ks, ks_threshold[0]])
            ks_threshold_number += 1
            
    if multi_ks_threshold_number < len(multi_ks_thresholds):
        MultiKSTest.Test_tf()
        multi_ks = np.mean(MultiKSTest.Results[-1].result_value["metric_list"])*np.sqrt(ns)
        multi_ks_list.append(multi_ks)
        print(f"multi ks statistic = {multi_ks}")
        multi_ks_threshold = multi_ks_thresholds[multi_ks_threshold_number]
        if multi_ks > multi_ks_threshold[1]:
            end = timer()
            print(f"=======> multi ks excluded at {multi_ks_threshold[0]} CL in {end-start} seconds")
            exclusion_list.append([eps, "multi ks statistic", multi_ks, multi_ks_threshold[0]])
            multi_ks_threshold_number += 1
            
    if sks_threshold_number < len(sks_thresholds):
        SKSTest.Test_tf(max_vectorize=1000)
        sks = np.mean(SKSTest.Results[-1].result_value["metric_means"])*np.sqrt(ns)
        sks_list.append(sks)
        print(f"sks statistic = {sks}")
        sks_threshold = sks_thresholds[sks_threshold_number]
        if sks > sks_threshold[1]:
            end = timer()
            print(f"=======> sks excluded at {sks_threshold[0]} CL in {end-start} seconds")
            exclusion_list.append([eps, "sks statistic", sks, sks_threshold[0]])
            sks_threshold_number += 1
            
    if swd_threshold_number < len(swd_thresholds):
        SWDMetric.Test_tf(max_vectorize=1000)
        swd = np.mean(SWDMetric.Results[-1].result_value["metric_means"])*np.sqrt(ns)
        swd_list.append(swd)
        print(f"swd statistic = {swd}")
        swd_threshold = swd_thresholds[swd_threshold_number]
        if swd > swd_threshold[1]:
            end = timer()
            print(f"=======> swd excluded at {swd_threshold[0]} CL in {end-start} seconds")
            exclusion_list.append([eps, "swd statistic", swd, swd_threshold[0]])
            swd_threshold_number += 1
            
    if fn_threshold_number >= len(fn_thresholds) and fpd_threshold_number >= len(fpd_thresholds) and kpd_threshold_number >= len(kpd_thresholds) and ks_threshold_number >= len(ks_thresholds) and multi_ks_threshold_number >= len(multi_ks_thresholds) and sks_threshold_number >= len(sks_thresholds) and swd_threshold_number >= len(swd_thresholds):
        break
                        
end = timer()
print("Time elapsed:", end-start, "seconds.")
# Out:
# ------------------
# eps = 0.0
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 3.982985091055575
# fpd statistic = 0.005039475382416134
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f002fa83880> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f002fa83d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# kpd statistic = 0.0003957628994051469
# ks statistic = 0.9080666848825835
# multi ks statistic = 1.0104556782339025
# sks statistic = 0.85002045275276
# swd statistic = 1.459186855551259
#
# ------------------
# eps = 0.0001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 3.9877684827831668
# fpd statistic = 0.005037485356850035
# kpd statistic = 0.0003881246867572807
# ks statistic = 0.9058044738621854
# multi ks statistic = 1.0118697576850035
# sks statistic = 0.8514700936072922
# swd statistic = 1.4597670239692266
#
# ------------------
# eps = 0.0002
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 3.9935467885671825
# fpd statistic = 0.005037222068513778
# kpd statistic = 0.000384305180100593
# ks statistic = 0.9084908086191485
# multi ks statistic = 1.0203550773285806
# sks statistic = 0.8538742025299142
# swd statistic = 1.461314217409751
#
# ------------------
# eps = 0.00030000000000000003
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.00033020464691
# fpd statistic = 0.00503868686850042
# kpd statistic = 0.00038625900045562004
# ks statistic = 0.9172595025986886
# multi ks statistic = 1.0253052246861851
# sks statistic = 0.8564693947269725
# swd statistic = 1.4638067891281525
#
# ------------------
# eps = 0.0004
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# WARNING:tensorflow:5 out of the last 9 calls to <function generate_and_clean_data_simple_1 at 0x7efc8de14d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Setting dist_num from dist_symb.
# fn statistic = 4.008130779401926
# fpd statistic = 0.005041881822620922
# kpd statistic = 0.00039440599143762646
# ks statistic = 0.937340937554159
# multi ks statistic = 1.037325742957515
# sks statistic = 0.8599766578966966
# swd statistic = 1.4672375620145952
#
# ------------------
# eps = 0.0005
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# WARNING:tensorflow:6 out of the last 11 calls to <function generate_and_clean_data_simple_1 at 0x7efc8de14d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Setting dist_num from dist_symb.
# fn statistic = 4.016962521737524
# fpd statistic = 0.0050468097054775255
# kpd statistic = 0.0004071063712396829
# ks statistic = 0.9602515113260595
# multi ks statistic = 1.0542964349282296
# sks statistic = 0.863879831439175
# swd statistic = 1.4715947515230499
#
# ------------------
# eps = 0.0006000000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.026841491216056
# fpd statistic = 0.005053474006263308
# kpd statistic = 0.0004109447386791332
# ks statistic = 0.9909401806235242
# multi ks statistic = 1.0847020934062999
# sks statistic = 0.8681507625766912
# swd statistic = 1.4768769638181207
#
# ------------------
# eps = 0.0007
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.0377858536353175
# fpd statistic = 0.005061878911498235
# kpd statistic = 0.0004144503159656723
# ks statistic = 1.0284166894357216
# multi ks statistic = 1.1235929398190454
# sks statistic = 0.873715694159723
# swd statistic = 1.4830692187852963
#
# ------------------
# eps = 0.0008
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.049815883119703
# fpd statistic = 0.005072029313979076
# kpd statistic = 0.0004264624461718102
# ks statistic = 1.0681561204963854
# multi ks statistic = 1.1716762246262593
# sks statistic = 0.8794007376755658
# swd statistic = 1.490167724367588
#
# ------------------
# eps = 0.0009000000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.0629538899699575
# fpd statistic = 0.005083930796012806
# kpd statistic = 0.00044291388150746475
# ks statistic = 1.1084609884083156
# multi ks statistic = 1.2416797692426256
# sks statistic = 0.885481974738301
# swd statistic = 1.4981428352817652
#
# ------------------
# eps = 0.001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.077224053154402
# fpd statistic = 0.00509758962437191
# kpd statistic = 0.0004621511049089529
# ks statistic = 1.150887381160314
# =======> ks excluded at 0.95 CL in 566.4682732280344 seconds
# multi ks statistic = 1.3328962968665707
# sks statistic = 0.8927156185918905
# swd statistic = 1.5069601499902678
#
# ------------------
# eps = 0.0011
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.092652138240412
# fpd statistic = 0.005113012742706851
# kpd statistic = 0.0004795556032141205
# ks statistic = 1.1941622005095491
# multi ks statistic = 1.4205775863500922
# sks statistic = 0.9001755778510935
# swd statistic = 1.5166098383513749
#
# ------------------
# eps = 0.0012000000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.109265086616498
# fpd statistic = 0.005130207754905982
# kpd statistic = 0.0004976589293556519
# ks statistic = 1.2353161799050039
# multi ks statistic = 1.530886280735438
# =======> multi ks excluded at 0.95 CL in 668.7911080960184 seconds
# sks statistic = 0.9083921981645233
# swd statistic = 1.527072336691037
#
# ------------------
# eps = 0.0013000000000000002
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.127090470772695
# fpd statistic = 0.005149182919325132
# kpd statistic = 0.0005172062650660918
# ks statistic = 1.274489378592636
# multi ks statistic = 1.620688926471634
# sks statistic = 0.9179168788487142
# swd statistic = 1.5383379471305363
#
# ------------------
# eps = 0.0014
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.146155823378575
# fpd statistic = 0.00516994713215836
# kpd statistic = 0.0005391630242777097
# ks statistic = 1.3180470296371594
# =======> ks excluded at 0.99 CL in 773.0408458914608 seconds
# multi ks statistic = 1.7239264333480646
# =======> multi ks excluded at 0.99 CL in 773.2350117601454 seconds
# sks statistic = 0.9276112993798377
# swd statistic = 1.550374805069604
#
# ------------------
# eps = 0.0015
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.1664878642695005
# fpd statistic = 0.005192509909930839
# kpd statistic = 0.0005653538447132813
# sks statistic = 0.938635215905457
# swd statistic = 1.5631673736969516
#
# ------------------
# eps = 0.0016
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.1881116672857255
# fpd statistic = 0.005216881375168722
# kpd statistic = 0.00061217515434504
# sks statistic = 0.9497720925705305
# swd statistic = 1.5766919941393873
#
# ------------------
# eps = 0.0017000000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.211049825022627
# fpd statistic = 0.005243072238087993
# kpd statistic = 0.0006702240896543342
# sks statistic = 0.9618635624271504
# swd statistic = 1.590922586660573
#
# ------------------
# eps = 0.0018000000000000002
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.235321679984359
# fpd statistic = 0.005271093777193398
# kpd statistic = 0.0007325898815560472
# sks statistic = 0.9740399911107451
# swd statistic = 1.6058354768801388
#
# ------------------
# eps = 0.0019
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.260942691619949
# fpd statistic = 0.005300957817053502
# kpd statistic = 0.0007995084016771093
# sks statistic = 0.9862093536117693
# swd statistic = 1.6214096360272134
#
# ------------------
# eps = 0.002
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.287923998147228
# fpd statistic = 0.005332676706686364
# kpd statistic = 0.0008698314796153952
# sks statistic = 0.9991917485769037
# swd statistic = 1.6376213462840543
#
# ------------------
# eps = 0.0021000000000000003
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.316272210543414
# fpd statistic = 0.005366263293243539
# kpd statistic = 0.000942938375049853
# sks statistic = 1.0125773110752703
# swd statistic = 1.6544395977371336
#
# ------------------
# eps = 0.0022
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.345989447308771
# fpd statistic = 0.00540173090152535
# kpd statistic = 0.0010187979650582342
# sks statistic = 1.0267265678832094
# swd statistic = 1.6718207864696033
#
# ------------------
# eps = 0.0023
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.377073588513169
# fpd statistic = 0.005439093302220851
# kpd statistic = 0.0010918885205090728
# sks statistic = 1.0409960354056353
# swd statistic = 1.6897114746336388
#
# ------------------
# eps = 0.0024000000000000002
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.409518702542521
# fpd statistic = 0.005478364686025513
# kpd statistic = 0.001167760404061929
# sks statistic = 1.0557320224429616
# swd statistic = 1.7080809872727747
#
# ------------------
# eps = 0.0025
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.443315583622509
# fpd statistic = 0.005519559634822224
# kpd statistic = 0.0012464137435976937
# sks statistic = 1.0707509399572521
# swd statistic = 1.7269029758470376
#
# ------------------
# eps = 0.0026000000000000003
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.478452334485052
# fpd statistic = 0.005562693089539933
# kpd statistic = 0.0013229868540724898
# sks statistic = 1.0862718988772035
# swd statistic = 1.7461471637648345
#
# ------------------
# eps = 0.0027
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.514914935252738
# fpd statistic = 0.0056077803190846005
# kpd statistic = 0.0013937617444041987
# sks statistic = 1.1019555051197365
# swd statistic = 1.7657911883823256
#
# ------------------
# eps = 0.0028
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.552687753442531
# fpd statistic = 0.005654836886247628
# kpd statistic = 0.0014636296145079325
# sks statistic = 1.1180563783334174
# =======> sks excluded at 0.95 CL in 1530.708667547442 seconds
# swd statistic = 1.7858156222334463
#
# ------------------
# eps = 0.0029000000000000002
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.591753966820175
# fpd statistic = 0.0057038786150202195
# kpd statistic = 0.0015335321899918966
# sks statistic = 1.1347581338979622
# swd statistic = 1.8062039397182588
#
# ------------------
# eps = 0.003
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.632095887056129
# fpd statistic = 0.005754921555142221
# kpd statistic = 0.0016126120700331685
# sks statistic = 1.1511560831246392
# swd statistic = 1.8269335992095648
#
# ------------------
# eps = 0.0031000000000000003
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.673695185342267
# fpd statistic = 0.0058079819432196676
# kpd statistic = 0.001693611079120406
# sks statistic = 1.1676599197227548
# swd statistic = 1.8479824623741186
#
# ------------------
# eps = 0.0032
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.716533030248194
# fpd statistic = 0.005863076169625746
# kpd statistic = 0.0017738907257820308
# sks statistic = 1.1842061731726294
# swd statistic = 1.8693383325207145
#
# ------------------
# eps = 0.0033
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.760590153187538
# fpd statistic = 0.005920220737395846
# kpd statistic = 0.001856955500345274
# sks statistic = 1.2010070265147352
# swd statistic = 1.8909904980471204
#
# ------------------
# eps = 0.0034000000000000002
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.805846858646892
# fpd statistic = 0.0059794322259222495
# kpd statistic = 0.0019458885462496378
# sks statistic = 1.2176665627908734
# swd statistic = 1.9129228625191093
#
# ------------------
# eps = 0.0035
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.852282995806677
# fpd statistic = 0.006040727251483754
# kpd statistic = 0.002048191721432012
# sks statistic = 1.2348068299723935
# swd statistic = 1.9351190437772061
#
# ------------------
# eps = 0.0036000000000000003
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.899877906310962
# fpd statistic = 0.0061041224279076295
# kpd statistic = 0.0021532821211138484
# sks statistic = 1.251947044470353
# swd statistic = 1.957563204051393
#
# ------------------
# eps = 0.0037
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.948610360512515
# fpd statistic = 0.006169634323725515
# kpd statistic = 0.002261159875707026
# sks statistic = 1.2691509336367897
# swd statistic = 1.9802459469855147
#
# ------------------
# eps = 0.0038
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 4.998458492037328
# fpd statistic = 0.00623727942893708
# kpd statistic = 0.00237182511522148
# sks statistic = 1.2864044770591279
# =======> sks excluded at 0.99 CL in 2039.9462076779455 seconds
# swd statistic = 2.0031582747437424
#
# ------------------
# eps = 0.0039000000000000003
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.0493997382754925
# fpd statistic = 0.006307074109070141
# kpd statistic = 0.0024852779701789976
# swd statistic = 2.0262913314703903
#
# ------------------
# eps = 0.004
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.1014107925044305
# fpd statistic = 0.006379034568521849
# kpd statistic = 0.0026096817694192982
# swd statistic = 2.0496332185184545
#
# ------------------
# eps = 0.0041
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.154467571783431
# fpd statistic = 0.006453176809080823
# kpd statistic = 0.002743599451704604
# swd statistic = 2.0731744813555664
#
# ------------------
# eps = 0.004200000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.208545203447801
# fpd statistic = 0.006529516593046884
# kpd statistic = 0.0028803004626440747
# swd statistic = 2.0969093365171436
#
# ------------------
# eps = 0.0043
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.263618031884572
# fpd statistic = 0.006608069406626252
# kpd statistic = 0.0030184932376087904
# swd statistic = 2.120832530623965
#
# ------------------
# eps = 0.0044
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.31965964624925
# fpd statistic = 0.006688850416051201
# kpd statistic = 0.0031585534766060725
# swd statistic = 2.1449406735936734
#
# ------------------
# eps = 0.0045000000000000005
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.376642928823186
# fpd statistic = 0.006771874436539315
# kpd statistic = 0.003301291653911435
# swd statistic = 2.1692233625392188
#
# ------------------
# eps = 0.0046
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.434540122830138
# fpd statistic = 0.006857155897354561
# kpd statistic = 0.0034381569700903366
# swd statistic = 2.19367531556365
#
# ------------------
# eps = 0.0047
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.4933229177465215
# fpd statistic = 0.006944708802338659
# kpd statistic = 0.0035774549133441346
# swd statistic = 2.2182914444980377
# =======> swd excluded at 0.95 CL in 2439.8351557590067 seconds
#
# ------------------
# eps = 0.0048000000000000004
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.55296254946989
# fpd statistic = 0.007034546702470975
# kpd statistic = 0.003719540663893733
# swd statistic = 2.243064536540724
#
# ------------------
# eps = 0.0049
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.613429912222823
# fpd statistic = 0.007126682662713864
# kpd statistic = 0.00386441435347617
# swd statistic = 2.267986408263281
#
# ------------------
# eps = 0.005
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.6746956787447544
# fpd statistic = 0.007221129232952841
# kpd statistic = 0.004009164130774553
# swd statistic = 2.293050242310636
#
# ------------------
# eps = 0.0051
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.736730425205488
# fpd statistic = 0.007317898420265562
# kpd statistic = 0.004154881571583437
# swd statistic = 2.3182510744896963
#
# ------------------
# eps = 0.005200000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.799504757344328
# fpd statistic = 0.00741700166531544
# kpd statistic = 0.00429672194564995
# swd statistic = 2.3435867963657966
#
# ------------------
# eps = 0.0053
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.862989434566237
# fpd statistic = 0.007518449816133343
# kpd statistic = 0.00442566678403502
# swd statistic = 2.369048892453407
#
# ------------------
# eps = 0.0054
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.927155489094083
# fpd statistic = 0.00762225310937574
# kpd statistic = 0.004555882481900618
# swd statistic = 2.3946344453603357
#
# ------------------
# eps = 0.0055000000000000005
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 5.9919743377331836
# fpd statistic = 0.007728421152961391
# kpd statistic = 0.004688892651711981
# swd statistic = 2.420341883717365
#
# ------------------
# eps = 0.0056
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.0574178843144955
# =======> fn excluded at 0.95 CL in 2801.626900336705 seconds
# fpd statistic = 0.007836962907939853
# kpd statistic = 0.004824697426411979
# swd statistic = 2.4461673197689207
#
# ------------------
# eps = 0.0057
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.1234586114116025
# fpd statistic = 0.007947886676032351
# kpd statistic = 0.004963698441649293
# swd statistic = 2.4721063637348686
#
# ------------------
# eps = 0.0058000000000000005
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.190069660433237
# fpd statistic = 0.008061200088458799
# kpd statistic = 0.005110272943597051
# swd statistic = 2.498157529805697
#
# ------------------
# eps = 0.0059
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.257224899662721
# fpd statistic = 0.008176910098827223
# kpd statistic = 0.0052572351845186745
# swd statistic = 2.524321753562299
#
# ------------------
# eps = 0.006
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.324898980223298
# fpd statistic = 0.008295022977601227
# kpd statistic = 0.00540362712789103
# swd statistic = 2.550597319812714
#
# ------------------
# eps = 0.0061
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.393067380287999
# fpd statistic = 0.008415544309111447
# kpd statistic = 0.005546948470023901
# swd statistic = 2.5769804754487535
#
# ------------------
# eps = 0.006200000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.461706438125123
# fpd statistic = 0.008538478990182459
# kpd statistic = 0.00569021565318339
# swd statistic = 2.6034701926161476
#
# ------------------
# eps = 0.0063
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.53079337476345
# fpd statistic = 0.008663831236979794
# kpd statistic = 0.0058372311983420425
# swd statistic = 2.630062685332618
#
# ------------------
# eps = 0.0064
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.600306307202355
# fpd statistic = 0.008791604586030172
# kpd statistic = 0.005996266837335109
# swd statistic = 2.656750916215891
#
# ------------------
# eps = 0.006500000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.670224253165817
# fpd statistic = 0.008921801904395989
# kpd statistic = 0.006158088465748948
# swd statistic = 2.683535479984285
#
# ------------------
# eps = 0.0066
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.74052712843162
# fpd statistic = 0.009054425401321484
# kpd statistic = 0.006322696218187583
# swd statistic = 2.7104153926616084
# =======> swd excluded at 0.99 CL in 3286.8244822937995 seconds
#
# ------------------
# eps = 0.0067
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.811195737764243
# fpd statistic = 0.009189476637781527
# kpd statistic = 0.006490090230206518
#
# ------------------
# eps = 0.0068000000000000005
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.882211760433721
# fpd statistic = 0.009326956545577617
# kpd statistic = 0.006660270636695537
#
# ------------------
# eps = 0.006900000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 6.953557731255525
# fpd statistic = 0.009466865441578806
# kpd statistic = 0.0068326776644885056
#
# ------------------
# eps = 0.007
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.025217018008377
# fpd statistic = 0.009609203049437362
# =======> fpd excluded at 0.95 CL in 3425.302451991476 seconds
# kpd statistic = 0.00700470321580037
#
# ------------------
# eps = 0.0071
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.097173796009519
# fpd statistic = 0.009753968520056435
# kpd statistic = 0.007176497245731059
#
# ------------------
# eps = 0.007200000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.16941302054025
# fpd statistic = 0.009901160454586746
# kpd statistic = 0.0073510761566474864
#
# ------------------
# eps = 0.0073
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.241920397734533
# fpd statistic = 0.010050776929234655
# kpd statistic = 0.0075284400842558835
#
# ------------------
# eps = 0.0074
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.314682354458585
# fpd statistic = 0.01020281552251555
# kpd statistic = 0.007708589163709809
#
# ------------------
# eps = 0.007500000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.387686007634345
# fpd statistic = 0.010357273340806907
# kpd statistic = 0.007891523530602447
#
# ------------------
# eps = 0.0076
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.460919133389778
# fpd statistic = 0.010514147047451246
# kpd statistic = 0.008081286230860255
#
# ------------------
# eps = 0.0077
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.534370136351646
# fpd statistic = 0.010673432892579143
# kpd statistic = 0.008276026036522426
#
# ------------------
# eps = 0.0078000000000000005
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.608028019340942
# fpd statistic = 0.01083512674268794
# kpd statistic = 0.008480989426942262
#
# ------------------
# eps = 0.0079
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fn statistic = 7.68188235367881
# =======> fn excluded at 0.99 CL in 3804.897219837643 seconds
# fpd statistic = 0.010999224109935774
# kpd statistic = 0.008689776547677403
#
# ------------------
# eps = 0.008
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.01116572018462186
# kpd statistic = 0.008900750075475323
#
# ------------------
# eps = 0.0081
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.01133460986412893
# kpd statistic = 0.009114326493476113
#
# ------------------
# eps = 0.0082
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.011505887784794487
# kpd statistic = 0.009331381748895603
#
# ------------------
# eps = 0.0083
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.01167954835184116
# kpd statistic = 0.009548652589936089
#
# ------------------
# eps = 0.008400000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.011855585769034461
# kpd statistic = 0.009764225877369557
# =======> kpd excluded at 0.95 CL in 4047.927249685861 seconds
#
# ------------------
# eps = 0.0085
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.012033994068781811
# kpd statistic = 0.00998585549358842
#
# ------------------
# eps = 0.0086
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.012214767140003805
# kpd statistic = 0.010211278325966012
#
# ------------------
# eps = 0.008700000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.012397898756531188
# kpd statistic = 0.010438912809566464
#
# ------------------
# eps = 0.0088
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.01258338260363511
# kpd statistic = 0.010663149231547578
#
# ------------------
# eps = 0.0089
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.012771212303572246
# kpd statistic = 0.010890170331316201
#
# ------------------
# eps = 0.009000000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.012961381440413052
# kpd statistic = 0.01111997624680496
#
# ------------------
# eps = 0.0091
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.013153883583019214
# kpd statistic = 0.011352567115365544
#
# ------------------
# eps = 0.0092
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.013348712306730829
# kpd statistic = 0.01158794307607988
#
# ------------------
# eps = 0.009300000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.01354586121364682
# kpd statistic = 0.011826104267194609
#
# ------------------
# eps = 0.0094
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.013745323951532346
# kpd statistic = 0.01206705082688729
#
# ------------------
# eps = 0.0095
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.013947094230310918
# kpd statistic = 0.012310782894233572
#
# ------------------
# eps = 0.009600000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.014151165837958056
# kpd statistic = 0.012557300607706188
#
# ------------------
# eps = 0.0097
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# fpd statistic = 0.014357532653492577
# =======> fpd excluded at 0.99 CL in 4558.557556193322 seconds
# kpd statistic = 0.012806604107096754
#
# ------------------
# eps = 0.0098
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.013058693530812054
#
# ------------------
# eps = 0.0099
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.013313569019014248
#
# ------------------
# eps = 0.01
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.013572652055165156
#
# ------------------
# eps = 0.010100000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.013841147321507034
#
# ------------------
# eps = 0.0102
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.014109464499157173
#
# ------------------
# eps = 0.0103
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.01437775626867933
#
# ------------------
# eps = 0.010400000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.014651863174344876
#
# ------------------
# eps = 0.0105
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.014928757481157844
#
# ------------------
# eps = 0.0106
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.015208439329179903
#
# ------------------
# eps = 0.010700000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.015490908859345695
#
# ------------------
# eps = 0.0108
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.015776166212602416
#
# ------------------
# eps = 0.0109
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.016065674582856973
#
# ------------------
# eps = 0.011000000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.016358661109430402
#
# ------------------
# eps = 0.0111
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.016654435362235754
#
# ------------------
# eps = 0.0112
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.01695299748241179
#
# ------------------
# eps = 0.011300000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.017254347611756687
#
# ------------------
# eps = 0.0114
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.017558485892429768
#
# ------------------
# eps = 0.0115
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.01786541246600627
#
# ------------------
# eps = 0.011600000000000001
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.01818170814655318
#
# ------------------
# eps = 0.0117
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# kpd statistic = 0.01850402001449033
# =======> kpd excluded at 0.99 CL in 5298.372823297977 seconds
# Time elapsed: 5298.373051056638 seconds.

# %% [markdown]
# ## Results

# %%
print(f"fn_thresholds: {fn_thresholds}")
print(f"fpd_thresholds: {fpd_thresholds}")
print(f"kpd_thresholds: {kpd_thresholds}")
print(f"ks_thresholds: {ks_thresholds}")
print(f"multi_ks_thresholds: {multi_ks_thresholds}")
print(f"sks_thresholds: {sks_thresholds}")
print(f"swd_thresholds: {swd_thresholds}")
# Out:
# fn_thresholds: [[0.95, 6.00966873581687], [0.99, 7.646027712249452]]
# fpd_thresholds: [[0.95, 0.009537109454941324], [0.99, 0.01421343518915221]]
# kpd_thresholds: [[0.95, 0.009722819813022865], [0.99, 0.018193513236146715]]
# ks_thresholds: [[0.95, 1.1313706138761246], [0.99, 1.2855206049622938]]
# multi_ks_thresholds: [[0.95, 1.4566393387274343], [0.99, 1.668772856652466]]
# sks_thresholds: [[0.95, 1.112986448315256], [0.99, 1.2742067049480295]]
# swd_thresholds: [[0.95, 2.202632934055404], [0.99, 2.709669622518888]]

# %%
exclusion_list
# Out:
# [[0.001, 'ks statistic', 1.150887381160314, 0.95],
#  [0.0012000000000000001, 'multi ks statistic', 1.530886280735438, 0.95],
#  [0.0014, 'ks statistic', 1.3180470296371594, 0.99],
#  [0.0014, 'multi ks statistic', 1.7239264333480646, 0.99],
#  [0.0028, 'sks statistic', 1.1180563783334174, 0.95],
#  [0.0038, 'sks statistic', 1.2864044770591279, 0.99],
#  [0.0047, 'swd statistic', 2.2182914444980377, 0.95],
#  [0.0056, 'fn statistic', 6.0574178843144955, 0.95],
#  [0.0066, 'swd statistic', 2.7104153926616084, 0.99],
#  [0.007, 'fpd statistic', 0.009609203049437362, 0.95],
#  [0.0079, 'fn statistic', 7.68188235367881, 0.99],
#  [0.008400000000000001, 'kpd statistic', 0.009764225877369557, 0.95],
#  [0.0097, 'fpd statistic', 0.014357532653492577, 0.99],
#  [0.0117, 'kpd statistic', 0.01850402001449033, 0.99]]

# %% [markdown]
# # Backup

# %%
seed = 0
for ncomp in [3]:
    for nsamples in [1000, 10_000, 100000]:
        for ndims in [4, 8, 16, 32, 64]:
            start = timer()
            result_dict = {}
            seed = seed + 1
            result_dict['ncomp'] = ncomp
            result_dict['ndims'] = ndims
            result_dict['seed'] = seed
            result_dict['nsamples'] = nsamples
            dist = MixtureGaussian(ncomp,ndims,seed)
            niter = 10000
            ns = nsamples**2 /(2*nsamples)
            result_dict['niter'] = niter
            result_dict['ns'] = ns
            sks_means_10, sks_stds_10, sks_dists_10 = [], [], []
            sks_means_100, sks_stds_100, sks_dists_100 = [], [], []
            sks_means_300, sks_stds_300, sks_dists_300 = [], [], []
            sks_means_1000, sks_stds_1000, sks_dists_1000 = [], [], []
            data_mean_cov = []
            s = dist.sample(2*nsamples)
            s1, s2 = s[:nsamples], s[nsamples:]
            _, _, _, sliced_data1_cov_10, _ = sks_2samp_tf(s1,s2, nslices = 10, cov = True) # type: ignore
            _, _, _, sliced_data1_cov_100, _ = sks_2samp_tf(s1,s2, nslices = 100, cov = True) # type: ignore
            _, _, _, sliced_data1_cov_300, _ = sks_2samp_tf(s1,s2, nslices = 300, cov = True) # type: ignore
            _, _, _, sliced_data1_cov_1000, _ = sks_2samp_tf(s1,s2, nslices = 1000, cov = True) # type: ignore
            for i in tqdm(range(niter)):
                s = dist.sample(2*nsamples)
                s1, s2 = s[:nsamples], s[nsamples:]
                sks_mean_1000, sks_std_1000, sks_proj_1000, _, _ = sks_2samp_tf(s1,s2, nslices = 1000, cov = False) # type: ignore
                sks_proj_10 = sks_proj_1000[:10]; sks_mean_10 = tf.reduce_mean(sks_proj_10); sks_std_10 = tf.math.reduce_std(sks_proj_10)
                sks_proj_100 = sks_proj_1000[:100]; sks_mean_100 = tf.reduce_mean(sks_proj_100); sks_std_100 = tf.math.reduce_std(sks_proj_100)
                sks_proj_300 = sks_proj_1000[:300]; sks_mean_300 = tf.reduce_mean(sks_proj_300); sks_std_300 = tf.math.reduce_std(sks_proj_300)
                sks_means_10.append(sks_mean_10); sks_stds_10.append(sks_std_10); sks_dists_10.append(sks_proj_10)
                sks_means_100.append(sks_mean_100); sks_stds_100.append(sks_std_100); sks_dists_100.append(sks_proj_100)
                sks_means_300.append(sks_mean_300); sks_stds_300.append(sks_std_300); sks_dists_300.append(sks_proj_300)
                sks_means_1000.append(sks_mean_1000); sks_stds_1000.append(sks_std_1000); sks_dists_1000.append(sks_proj_1000)
            data_mean_cov = tf.sqrt(tf.reduce_mean(tfp.stats.covariance(s1, sample_axis=0, event_axis=-1))).numpy()
            sliced_data_mean_cov_10 = tf.sqrt(tf.reduce_mean(sliced_data1_cov_10)).numpy()
            sliced_data_mean_cov_100 = tf.sqrt(tf.reduce_mean(sliced_data1_cov_100)).numpy()
            sliced_data_mean_cov_300 = tf.sqrt(tf.reduce_mean(sliced_data1_cov_300)).numpy()
            sliced_data_mean_cov_1000 = tf.sqrt(tf.reduce_mean(sliced_data1_cov_1000)).numpy()
            sks_means_10 = tf.stack(sks_means_10).numpy(); sks_stds_10 = tf.stack(sks_stds_10).numpy(); sks_dists_10 = tf.stack(sks_dists_10).numpy()
            sks_means_100 = tf.stack(sks_means_100).numpy(); sks_stds_100 = tf.stack(sks_stds_100).numpy(); sks_dists_100 = tf.stack(sks_dists_100).numpy()
            sks_means_300 = tf.stack(sks_means_300).numpy(); sks_stds_300 = tf.stack(sks_stds_300).numpy(); sks_dists_300 = tf.stack(sks_dists_300).numpy()
            sks_means_1000 = tf.stack(sks_means_1000).numpy(); sks_stds_1000 = tf.stack(sks_stds_1000).numpy(); sks_dists_1000 = tf.stack(sks_dists_1000).numpy()
            result_dict['10'] = {'sliced_data_mean_cov': sliced_data_mean_cov_10, 'sks_means': sks_means_10, 'sks_stds': sks_stds_10, 'mu': tf.math.reduce_mean(sks_means_10*np.sqrt(ns)).numpy(), 'sigma': tf.math.reduce_std(sks_means_10*np.sqrt(ns)).numpy()}
            result_dict['100'] = {'sliced_data_mean_cov': sliced_data_mean_cov_100, 'sks_means': sks_means_100, 'sks_stds': sks_stds_100, 'mu': tf.math.reduce_mean(sks_means_100*np.sqrt(ns)).numpy(), 'sigma': tf.math.reduce_std(sks_means_100*np.sqrt(ns)).numpy()}
            result_dict['300'] = {'sliced_data_mean_cov': sliced_data_mean_cov_300, 'sks_means': sks_means_300, 'sks_stds': sks_stds_300, 'mu': tf.math.reduce_mean(sks_means_300*np.sqrt(ns)).numpy(), 'sigma': tf.math.reduce_std(sks_means_300*np.sqrt(ns)).numpy()}
            result_dict['1000'] = {'sliced_data_mean_cov': sliced_data_mean_cov_1000, 'sks_means': sks_means_1000, 'sks_stds': sks_stds_1000, 'mu': tf.math.reduce_mean(sks_means_1000*np.sqrt(ns)).numpy(), 'sigma': tf.math.reduce_std(sks_means_1000*np.sqrt(ns)).numpy()}
            
            dict_to_save = Utils.convert_types_dict(result_dict)
            with codecs.open(results_path+'SKS_nsamples_'+str(nsamples)+'_ndims_'+'_'+str(ndims)+'_niter_'+str(niter)+'.json', "w", encoding="utf-8") as f:
                json.dump(dict_to_save, f, separators=(",", ":"), indent=4)
    
            print("================== ncomp =", ncomp, "ndims =", ndims, "==================")
            print(f"The square root of the mean covariance of the data is {data_mean_cov}")
            print(f"The square root of the mean covariance of the sliced data (10 slices) is {tf.sqrt(tf.reduce_mean(sliced_data1_cov_10))}")
            print(f"The square root of the mean covariance of the sliced data (100 slices) is {tf.sqrt(tf.reduce_mean(sliced_data1_cov_100))}")
            print(f"The square root of the mean covariance of the sliced data (300 slices) is {tf.sqrt(tf.reduce_mean(sliced_data1_cov_300))}")
            print(f"The square root of the mean covariance of the sliced data (1000 slices) is {tf.sqrt(tf.reduce_mean(sliced_data1_cov_1000))}")
            print(f"The estimated mean and variance (10 slices) of the (scaled) SKS statistic are {tf.math.reduce_mean(sks_means_10*np.sqrt(ns))} and {tf.math.reduce_std(sks_means_10*np.sqrt(ns))}")
            print(f"The estimated mean and variance (100 slices) of the (scaled) SKS statistic are {tf.math.reduce_mean(sks_means_100*np.sqrt(ns))} and {tf.math.reduce_std(sks_means_100*np.sqrt(ns))}")
            print(f"The estimated mean and variance (300 slices) of the (scaled) SKS statistic are {tf.math.reduce_mean(sks_means_300*np.sqrt(ns))} and {tf.math.reduce_std(sks_means_300*np.sqrt(ns))}")
            print(f"The estimated mean and variance (1000 slices) of the (scaled) SKS statistic are {tf.math.reduce_mean(sks_means_1000*np.sqrt(ns))} and {tf.math.reduce_std(sks_means_1000*np.sqrt(ns))}")
            print(f"The ratio of the estimated variance (10 slices) of the (scaled) SKS statistic to the square root of the mean covariance of the sliced data is {tf.math.reduce_std(sks_means_10*np.sqrt(ns))/sliced_data_mean_cov_10}")
            print(f"The ratio of the estimated variance (100 slices) of the (scaled) SKS statistic to the square root of the mean covariance of the sliced data is {tf.math.reduce_std(sks_means_100*np.sqrt(ns))/sliced_data_mean_cov_100}")
            print(f"The ratio of the estimated variance (300 slices) of the (scaled) SKS statistic to the square root of the mean covariance of the sliced data is {tf.math.reduce_std(sks_means_300*np.sqrt(ns))/sliced_data_mean_cov_300}")
            print(f"The ratio of the estimated variance (1000 slices) of the (scaled) SKS statistic to the square root of the mean covariance of the sliced data is {tf.math.reduce_std(sks_means_1000*np.sqrt(ns))/sliced_data_mean_cov_1000}")

            scale = 'log'
            num_bins = 50  # number of bins|

            d0 = sks_dists_100[:,0]*np.sqrt(ns)
            d10 = np.mean(sks_dists_10,axis=1)*np.sqrt(ns)
            d100 = np.mean(sks_dists_100,axis=1)*np.sqrt(ns)
            d300 = np.mean(sks_dists_300,axis=1)*np.sqrt(ns)
            d1000 = np.mean(sks_dists_1000,axis=1)*np.sqrt(ns)

            # Compute the mean and standard deviation of the sample and their standard errors
            mu0, deltamu0, sigma0, deltasigma0 = (np.mean(d0), se_mean(d0), np.std(d0), se_std(d0))
            mu10, deltamu10, sigma10, deltasigma10 = (np.mean(d10), se_mean(d10), np.std(d10), se_std(d10))
            mu100, deltamu100, sigma100, deltasigma100 = (np.mean(d100), se_mean(d100), np.std(d100), se_std(d100))
            mu300, deltamu300, sigma300, deltasigma300 = (np.mean(d300), se_mean(d300), np.std(d300), se_std(d300))
            mu1000, deltamu1000, sigma1000, deltasigma1000 = (np.mean(d1000), se_mean(d1000), np.std(d1000), se_std(d1000))

            # Minimum and maximum x values
            min_x = min(d0) # lower limit of the binning
            max_x = max(d0) # upper limit of the binning

            # Create an array of values
            x = np.linspace(min_x, max_x, num_bins + 1)

            # Create histogram for values and normalize counts to sum to 1
            counts0, bin_edges0 = np.histogram(d0, bins=x, density=True); cum_counts0 = np.cumsum(counts0)/np.sum(counts0)
            counts10, bin_edges10 = np.histogram(d10, bins=x, density=True); cum_counts10 = np.cumsum(counts10)/np.sum(counts10)
            counts100, bin_edges100 = np.histogram(d100, bins=x, density=True); cum_counts100 = np.cumsum(counts100)/np.sum(counts100)
            counts300, bin_edges300 = np.histogram(d300, bins=x, density=True); cum_counts300 = np.cumsum(counts300)/np.sum(counts300)
            counts1000, bin_edges1000 = np.histogram(d1000, bins=x, density=True); cum_counts1000 = np.cumsum(counts1000)/np.sum(counts1000)

            # Get the bin centers
            bin_centers0 = (bin_edges0[:-1] + bin_edges0[1:]) / 2
            bin_centers10 = (bin_edges10[:-1] + bin_edges10[1:]) / 2
            bin_centers100 = (bin_edges100[:-1] + bin_edges100[1:]) / 2
            bin_centers300 = (bin_edges300[:-1] + bin_edges300[1:]) / 2
            bin_centers1000 = (bin_edges1000[:-1] + bin_edges1000[1:]) / 2

            # Calculate the theoretical PDF and CDF of the KS distribution for each x value
            theoretical_pdf_ks = kstwobign.pdf(x)
            theoretical_cdf_ks = kstwobign.cdf(x)

            ## Fit SKS to normal
            #def normal_pdf(x, mu, sigma):
            #    return norm.pdf(x, loc=mu, scale=sigma)
            #params_norm, cov_norm = curve_fit(normal_pdf, bin_centers2, counts2, p0=[mu2, sigma2])
            #loc_fit_norm, sigma_fit_norm = params_norm
            #
            ## Calculate the theoretical PDF and CDF of the Normal distribution for each x value
            #empirical_pdf_norm_1 = norm.pdf(x, loc=loc_fit_norm, scale=sigma_fit_norm)
            #empirical_cdf_norm_1 = norm.cdf(x, loc=loc_fit_norm, scale=sigma_fit_norm)
            #
            ## Fit SKS to log-normal
            #def lognormal_pdf(x, scale, s):
            #    return lognorm.pdf(x, scale=scale, s=s)
            #params, cov = curve_fit(lognormal_pdf, bin_centers2, counts2, p0=[mu2, sigma2])
            #scale_fit_lognorm, s_fit_lognorm = params
            #
            #empirical_pdf_lognorm_1 = lognorm.pdf(x, scale=scale_fit_lognorm, s=s_fit_lognorm)
            #empirical_cdf_lognorm_1 = lognorm.cdf(x, scale=scale_fit_lognorm, s=s_fit_lognorm)
            
            # Empirical SKS Normal
            empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=0.155)
            empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=0.155)

            # Set up the figure and the two subplots
            fig, ax = plt.subplots(1, 3, figsize=(25, 6))

            # Draw the first plot
            ax[0].plot(bin_centers0, counts0, linestyle = '-', label='Expected KS', drawstyle='steps-mid')
            ax[0].plot(bin_centers10, counts10, linestyle = '-', label='SKS (10 slices)', drawstyle='steps-mid')
            ax[0].plot(bin_centers100, counts100, linestyle = '-', label='SKS (100 slices)', drawstyle='steps-mid')
            ax[0].plot(bin_centers300, counts300, linestyle = '-', label='SKS (300 slices)', drawstyle='steps-mid')
            ax[0].plot(bin_centers1000, counts1000, linestyle = '-', label='SKS (1000 slices)', drawstyle='steps-mid')
            ax[0].plot(x, theoretical_pdf_ks, label='Theoretical distribution (KS)')
            ax[0].plot(x, empirical_pdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
            #ax[0].plot(x, empirical_pdf_lognorm_1, label='SKS - Log-Normal fit with scale='+str(round(scale_fit_lognorm,3))+', s='+str(round(s_fit_lognorm,3)))
            ax[0].set_yscale(scale)
            ax[0].set_xlim(0.25, 2)
            ax[0].set_ylim(1e-1, 10)
            ax[0].set_xlabel('KS vs SKS')
            ax[0].set_ylabel('Number of pseudo-experiments')
            ax[0].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - PDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys - 100 slices')
            ax[0].legend(loc='upper right')

            # Draw the second plot
            ax[1].plot(bin_centers0, cum_counts0, linestyle = '-', label='Expected KS', drawstyle='steps-mid')
            ax[1].plot(bin_centers10, cum_counts10, linestyle = '-', label='SKS (10 slices)', drawstyle='steps-mid')
            ax[1].plot(bin_centers100, cum_counts100, linestyle = '-', label='SKS (100 slices)', drawstyle='steps-mid')
            ax[1].plot(bin_centers300, cum_counts300, linestyle = '-', label='SKS (300 slices)', drawstyle='steps-mid')
            ax[1].plot(bin_centers1000, cum_counts1000, linestyle = '-', label='SKS (1000 slices)', drawstyle='steps-mid')
            ax[1].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
            ax[1].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
            ax[1].set_yscale(scale)
            ax[1].set_xlim(0.25, 2)
            ax[1].set_ylim(9e-4, 1.5)
            ax[1].set_xlabel('KS vs SKS')
            ax[1].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys - 100 slices')
            ax[1].legend(loc='lower right')

            # Draw the third plot
            ax[2].plot(bin_centers0, cum_counts0, linestyle = '-', label='Expected KS', drawstyle='steps-mid')
            ax[2].plot(bin_centers10, cum_counts10, linestyle = '-', label='SKS (10 slices)', drawstyle='steps-mid')
            ax[2].plot(bin_centers100, cum_counts100, linestyle = '-', label='SKS (100 slices)', drawstyle='steps-mid')
            ax[2].plot(bin_centers300, cum_counts300, linestyle = '-', label='SKS (300 slices)', drawstyle='steps-mid')
            ax[2].plot(x, theoretical_cdf_ks, label='Theoretical distribution (KS)')
            ax[2].plot(x, empirical_cdf_norm, label='SKS - Normal approximation $\\mu =$'+str(kstwobign.mean())+', $\\sigma =$'+str(0.155))
            #ax[2].plot(x, empirical_cdf_lognorm_1, label='SKS - SKS - Log-Normal fit with scale='+str(round(scale_fit_lognorm,3))+', s='+str(round(s_fit_lognorm,3)))
            ax[2].set_yscale(scale)
            ax[2].set_xlim(0.25, 2)
            ax[2].set_ylim(0.8, 1)
            ax[2].set_xlabel('KS vs SKS')
            ax[2].set_title('CMoG - ncop = '+str(ncomp)+' - ndims = '+str(ndims)+' - CDF with '+str(int(nsamples/1000))+'K test samples - '+str(int(niter/1000))+'K toys - 100 slices')
            ax[2].legend(loc='lower right')

            # Adjust the width space
            plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking

            # Display the figure with the two subplots
            plt.tight_layout()
            plt.savefig(results_path+'SKS_nsamples_'+str(nsamples)+'_ndims_'+'_'+str(ndims)+'_niter_'+str(niter)+'.pdf')
            plt.show()
            plt.close()
            end = timer()
            print("Time elapsed:", end-start, "seconds.")
