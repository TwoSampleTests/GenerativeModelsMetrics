# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_unimodal import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results_leonardo/20D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-16 17:25:23.369305: Importing os...
# 2024-04-16 17:25:23.369661: Importing sys...
# Visible devices: [1]
# 2024-04-16 17:25:23.369892: Importing timer from timeit...
# 2024-04-16 17:25:23.369957: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-04-16 17:25:23.370083: Importing numpy...
# 2024-04-16 17:25:23.479793: Importing matplotlib...
# 2024-04-16 17:25:23.819213: Importing h5py...
# 2024-04-16 17:25:23.842721: Importing importlib.util...
# 2024-04-16 17:25:23.842818: Importing json...
# 2024-04-16 17:25:23.842879: Importing pandas...
# 2024-04-16 17:25:24.254830: Importing random...
# 2024-04-16 17:25:24.254960: Importing scipy utils...
# 2024-04-16 17:25:24.625757: Importing subprocess...
# 2024-04-16 17:25:24.625873: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-16 17:25:27.716544: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-16 17:25:28.795990: Importing timeit...
# 2024-04-16 17:25:28.796077: Importing tqdm...
# 2024-04-16 17:25:28.803545: Importing typing...
# 2024-04-16 17:25:28.803650: Setting tf configs...
# 2024-04-16 17:25:28.914999: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-16 17:25:33.344040: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-04-16 17:25:33.376676: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 10_000
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = 0.,
                                                             eps_scale = 0.,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
dist_2 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = eps_loc,
                                                             eps_scale = eps_scale,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               #min_samples_input = 20_000,
                               #max_samples_input = 50_000,
                               num_batches = 20)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4,
                               block_size = 10_000,
                               num_batches = 1,
                               batch_size = 20_000)
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...       20           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True       20           0  float64    20  200000000         False
#
#    ncomp
# 0      5
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fn": {"name": "fn", # type: ignore
                                       "object_name": "FNMetric",
                                       "class_name": "GMetrics.FNMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns)/ndims,
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)/ndims",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\overline{\|\cdot\|}_{F}$",
                                       "null_file": null_hypotheses_dir+"FN.json"},
                               "fpd": {"name": "fpd",
                                       "object_name": "FPDMetric",
                                       "class_name": "GMetrics.FPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1000,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$d_{\mathrm{FPD}}$",
                                       "null_file": null_hypotheses_dir+"FPD.json"},
                               "kpd": {"name": "kpd",
                                       "object_name": "KPDMetric" ,
                                       "class_name": "GMetrics.KPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1,
                                       "latex": "$d_{\mathrm{KPD}}$",
                                       "null_file": null_hypotheses_dir+"KPD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fn': {'name': 'fn',
#   'object_name': 'FNMetric',
#   'class_name': 'GMetrics.FNMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)/ndims',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 500,
#   'latex': '$\\overline{\\|\\cdot\\|}_{F}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_20K/null_hypothesis/FN.json'},
#  'fpd': {'name': 'fpd',
#   'object_name': 'FPDMetric',
#   'class_name': 'GMetrics.FPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$d_{\\mathrm{FPD}}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_20K/null_hypothesis/FPD.json'},
#  'kpd': {'name': 'kpd',
#   'object_name': 'KPDMetric',
#   'class_name': 'GMetrics.KPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{KPD}}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_20K/null_hypothesis/KPD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 10000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fn from results_leonardo/20D_unimodal/20D_20K/null_hypothesis/FN.json
# Loading fpd from results_leonardo/20D_unimodal/20D_20K/null_hypothesis/FPD.json
# Loading kpd from results_leonardo/20D_unimodal/20D_20K/null_hypothesis/KPD.json
# Loading ks from results_leonardo/20D_unimodal/20D_20K/null_hypothesis/KS.json
# Loading sks from results_leonardo/20D_unimodal/20D_20K/null_hypothesis/SKS.json
# Loading swd from results_leonardo/20D_unimodal/20D_20K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fn: [[0.68, [6800, 3199], 0.7485835927158977], [0.95, [9500, 500], 1.033776381540505], [0.99, [9900, 100], 1.2475201008590582]]
# Computing time for metric fn: 9.69810863607563
# ThresholdS for metric fpd: [[0.68, [6800, 3199], 0.11582248190997987], [0.95, [9500, 500], 0.16861427140297167], [0.99, [9900, 100], 0.28060237149143374]]
# Computing time for metric fpd: 259.1181438108906
# ThresholdS for metric kpd: [[0.68, [6800, 3199], 0.47344702138518713], [0.95, [9500, 500], 0.5156398157246667], [0.99, [9900, 100], 0.5468218312632]]
# Computing time for metric kpd: 18913.08449595305
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9120000898838043], [0.95, [9500, 500], 1.1075008660554886], [0.99, [9900, 100], 1.2549996376037598]]
# Computing time for metric ks: 100.53717305394821
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9048002772033215], [0.95, [9500, 500], 1.0811004787683487], [0.99, [9900, 100], 1.2127505615353584]]
# Computing time for metric sks: 396.12231810204685
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.2947600178370888], [0.95, [9500, 500], 0.38341068851014204], [0.99, [9900, 100], 0.4489561272558803]]
# Computing time for metric swd: 276.57439835509285
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f4b1893bce0>
# 1          metric_list  <function <lambda> at 0x7f4b1893bd80>
# 2          metric_list  <function <lambda> at 0x7f4b140880e0>
# 3      statistic_means  <function <lambda> at 0x7f4b14088180>
# 4         metric_means  <function <lambda> at 0x7f4b14088220>
# 5         metric_means  <function <lambda> at 0x7f4b140882c0>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f4b14088360>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
# 6  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 1  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 2  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 3  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 4  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 5  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 6  results_leonardo/20D_unimodal/20D_20K/null_hyp...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.7485835927158977], [0....
# 1  [[0.68, [6800, 3199], 0.11582248190997987], [0...
# 2  [[0.68, [6800, 3199], 0.47344702138518713], [0...
# 3  [[0.68, [6800, 3199], 0.9120000898838043], [0....
# 4  [[0.68, [6800, 3199], 0.9048002772033215], [0....
# 5  [[0.68, [6800, 3199], 0.2947600178370888], [0....
# 6                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    if "FPD" in latex:
        latex = r"$d_{\mathrm{FPD}}\,(\times 10^{3})$"
    elif "KPD" in latex:
        latex = r"$d_{\mathrm{KPD}}\,(\times 10^{4})$"
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.6813296237439926 +/- 0.00037890648929053315
# sigma = 0.1946552052452061 +/- 0.001672019019464477
# /tmp/ipykernel_1258190/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1258190/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1258190/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1258190/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.482032123953104 seconds.
# mu = 0.11199703219235012 +/- 1.3270502216664146e-05
# sigma = 0.036428700521243064 +/- 0.0006519430998089134
# /tmp/ipykernel_1258190/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1258190/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1258190/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1258190/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.0607051050756127 seconds.
# mu = 0.45970185353897414 +/- 1.0815171433572777e-05
# sigma = 0.032886427950710576 +/- 0.0002471158078606443
# /tmp/ipykernel_1258190/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1258190/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1258190/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1258190/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.0048875221982598 seconds.
# mu = 0.8676754004731775 +/- 0.00016787066129602296
# sigma = 0.12956491087328503 +/- 0.001113531509799755
# /tmp/ipykernel_1258190/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1258190/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1258190/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1258190/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2488289528992027 seconds.
# mu = 0.8658526310138405 +/- 0.00013098520621847905
# sigma = 0.11444876854666416 +/- 0.0009489896381201503
# /tmp/ipykernel_1258190/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1258190/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1258190/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1258190/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3000382028985769 seconds.
# mu = 0.2802814187915494 +/- 2.8090848521128723e-05
# sigma = 0.0530008004855858 +/- 0.0005176362112236936
# /tmp/ipykernel_1258190/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1258190/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1258190/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1258190/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9921295729000121 seconds.
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f4b1893bce0>
# 1          metric_list  <function <lambda> at 0x7f4b1893bd80>
# 2          metric_list  <function <lambda> at 0x7f4b140880e0>
# 3      statistic_means  <function <lambda> at 0x7f4b14088180>
# 4         metric_means  <function <lambda> at 0x7f4b14088220>
# 5         metric_means  <function <lambda> at 0x7f4b140882c0>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f4b14088360>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
# 6  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 1  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 2  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 3  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 4  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 5  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 6  results_leonardo/20D_unimodal/20D_20K/null_hyp...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.7485835927158977], [0....
# 1  [[0.68, [6800, 3199], 0.11582248190997987], [0...
# 2  [[0.68, [6800, 3199], 0.47344702138518713], [0...
# 3  [[0.68, [6800, 3199], 0.9120000898838043], [0....
# 4  [[0.68, [6800, 3199], 0.9048002772033215], [0....
# 5  [[0.68, [6800, 3199], 0.2947600178370888], [0....
# 6                                                 []
#
#                                          null_figure
# 0  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 1  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 2  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 3  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 4  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 5  results_leonardo/20D_unimodal/20D_20K/null_hyp...
# 6                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.01,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 50.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for fn with mean deformation already loaded.
# Exclusion limits for fn with std deformation already loaded.
# Exclusion limits for fn with off deformation already loaded.
# Exclusion limits for fn with cov deformation already loaded.
# Exclusion limits for fn with mean_std deformation already loaded.
# Exclusion limits for fn with mean_off deformation already loaded.
# Exclusion limits for fn with mean_cov deformation already loaded.
# Computing exclusion limits for fpd with mean deformation.
#
# ======================================================
# =============== fpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 58005.494709611026 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999883725649021
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 14624.24460321986 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999538814258337
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 3728.1016913435565 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999819096516528
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 950.7117921430487 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9992907025099456
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 240.92669262067784 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9972025291810689
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 60.9285980225448 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.988960918832647
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 15.472871118403342 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9568802406674604
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 4.010082173385224 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8385962956335125
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 1.1059202380845072 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4708208521689208
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 0.36694259450431427 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7406433778618633
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 0.1738291181730913 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.030456694033869306
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.13257406575641428 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.23932006123786428
#
# ------------ 13 ------------
# eps = 0.018310546875
# statistic = 0.1495796413386248 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.11964169836149428
#
# ------------ 14 ------------
# eps = 0.0213623046875
# statistic = 0.17272534413579044 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.024087873458988662
#
# ------------ 15 ------------
# eps = 0.01983642578125
# statistic = 0.15497337687593543 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.08431035362189633
#
# ------------ 16 ------------
# eps = 0.020599365234375
# statistic = 0.15783198259268572 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.06605858500939872
#
# ------------ 17 ------------
# eps = 0.0209808349609375
# statistic = 0.1711827406225169 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.01834862385321101
# relative_error_metric = 0.01511766807032764
#
# ------------ 18 ------------
# eps = 0.02079010009765625
# statistic = 0.1704217837398654 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.009216589861751152
# relative_error_metric = 0.01066265554636798
# =======> statistic within required accuracy at 0.95 CL in 79.7413981279824 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.020694732666015625
# statistic = 0.1581970475396907 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.998345106338357
# relative_error_metric = 0.5579101459250598
#
# ------------ 2 ------------
# eps = 25.010347366333008
# statistic = 58053.36274249432 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9966929490855128
# relative_error_metric = 1.9999806659940478
#
# ------------ 3 ------------
# eps = 12.515521049499512
# statistic = 14660.228896565974 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9933968167027065
# relative_error_metric = 1.9999234399400616
#
# ------------ 4 ------------
# eps = 6.268107891082764
# statistic = 3749.3751567311633 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9868370919526939
# relative_error_metric = 1.9997006633253622
#
# ------------ 5 ------------
# eps = 3.1444013118743896
# statistic = 962.4110243423231 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9738463131926594
# relative_error_metric = 1.9988340923980017
#
# ------------ 6 ------------
# eps = 1.5825480222702026
# statistic = 247.09415146120506 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9483678124169315
# relative_error_metric = 1.9954627161075427
#
# ------------ 7 ------------
# eps = 0.8016213774681091
# statistic = 64.11818600644855 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.8993344169670217
# relative_error_metric = 1.982570953363616
#
# ------------ 8 ------------
# eps = 0.4111580550670624
# statistic = 17.117276300083958 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.8083167852207382
# relative_error_metric = 1.9354858424320707
#
# ------------ 9 ------------
# eps = 0.215926393866539
# statistic = 4.884518433902723 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.6501625536269533
# relative_error_metric = 1.782694436731556
#
# ------------ 10 ------------
# eps = 0.11831056326627731
# statistic = 1.562007157194713 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.4044908137573213
# relative_error_metric = 1.3908587421850263
#
# ------------ 11 ------------
# eps = 0.06950264796614647
# statistic = 0.6116594249806536 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.082246844820839
# relative_error_metric = 0.7420625982154249
#
# ------------ 12 ------------
# eps = 0.04509869031608105
# statistic = 0.3317785730416861 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.7418357806586864
# relative_error_metric = 0.16713845199500513
#
# ------------ 13 ------------
# eps = 0.032896711491048336
# statistic = 0.22982048185571874 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.3128896971441041
# relative_error_metric = 0.198979686362816
#
# ------------ 14 ------------
# eps = 0.03899770090356469
# statistic = 0.27405939975222154 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.14509515388315747
# relative_error_metric = 0.023592654401047457
#
# ------------ 15 ------------
# eps = 0.04204819560982287
# statistic = 0.2990384950569852 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.07527820253686211
# relative_error_metric = 0.06361222829347021
#
# ------------ 16 ------------
# eps = 0.04052294825669378
# statistic = 0.28617522552733526 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.03836103878013491
# relative_error_metric = 0.01966504697861928
#
# ------------ 17 ------------
# eps = 0.039760324580129236
# statistic = 0.2800428126541007 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.018998320562107346
# relative_error_metric = 0.0019961246547969967
#
# ------------ 18 ------------
# eps = 0.04014163641841151
# statistic = 0.28308956384055695 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.009544492613622741
# relative_error_metric = 0.008824651172837343
# =======> statistic within required accuracy at 0.99 CL in 79.88327892986126 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 159.62471114099026 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_20K/exclusion_limits.json
# Computing exclusion limits for fpd with std deformation.
#
# ======================================================
# =============== fpd - only diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 5928.6029327524 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998862399941937
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 2808.055314152834 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997598278831026
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 1319.334187442848 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9994888551318455
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 595.9508301772514 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9988685873411904
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 254.64573199346052 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9973531431981826
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 104.61252566818244 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9935631824009477
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 41.39510047642432 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9837729353667275
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 15.596101724272524 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9572173018659582
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 5.514139407082956 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8813150940950893
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 1.850733454311107 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.666002503172956
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 0.6104779999267104 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1343039708752516
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.2445896714809488 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.367738020831619
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.1306965762853149 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.25336666151936915
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 0.19656268906493685 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.15306780376371126
#
# ------------ 15 ------------
# eps = 0.00762939453125
# statistic = 0.17753858426950045 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.05156284410360559
#
# ------------ 16 ------------
# eps = 0.006866455078125
# statistic = 0.14707073464910206 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.1364875514570109
#
# ------------ 17 ------------
# eps = 0.0072479248046875
# statistic = 0.1512080225329601 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.10884950298992274
#
# ------------ 18 ------------
# eps = 0.00743865966796875
# statistic = 0.15340983920127022 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.02531645569620253
# relative_error_metric = 0.09443039636486877
#
# ------------ 19 ------------
# eps = 0.007534027099609375
# statistic = 0.16630007832696794 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.012578616352201259
# relative_error_metric = 0.013819611359559768
#
# ------------ 20 ------------
# eps = 0.0075817108154296875
# statistic = 0.17693231175832871 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.006309148264984227
# relative_error_metric = 0.04814424891288365
#
# ------------ 21 ------------
# eps = 0.007557868957519531
# statistic = 0.16659309209247142 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.0031496062992125984
# relative_error_metric = 0.012059277513620162
# =======> statistic within required accuracy at 0.95 CL in 95.9313513119705 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.007569789886474609
# statistic = 0.1767814597361669 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.999394508477954
# relative_error_metric = 0.4539771835686255
#
# ------------ 2 ------------
# eps = 25.003784894943237
# statistic = 5929.568785138785 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9987893834649322
# relative_error_metric = 1.9998107187193779
#
# ------------ 3 ------------
# eps = 12.505677342414856
# statistic = 2809.433214376956 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.997580231635661
# relative_error_metric = 1.9996005253349023
#
# ------------ 4 ------------
# eps = 6.256623566150665
# statistic = 1320.8840113695853 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9951663114746103
# relative_error_metric = 1.999150439336407
#
# ------------ 5 ------------
# eps = 3.13209667801857
# statistic = 597.5605747881846 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9903559311616619
# relative_error_metric = 1.9981225624315502
#
# ------------ 6 ------------
# eps = 1.5698332339525223
# statistic = 256.15001843292777 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9808044240512444
# relative_error_metric = 1.9956229506349719
#
# ------------ 7 ------------
# eps = 0.7887015119194984
# statistic = 105.91939191492783 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9619738153601365
# relative_error_metric = 1.9894311718799282
#
# ------------ 8 ------------
# eps = 0.3981356509029865
# statistic = 42.48877377564139 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9253666416526771
# relative_error_metric = 1.9737567019424254
#
# ------------ 9 ------------
# eps = 0.20285272039473057
# statistic = 16.475869829898624 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.8561030399958927
# relative_error_metric = 1.9330163609335012
#
# ------------ 10 ------------
# eps = 0.10521125514060259
# statistic = 6.1842577534903445 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.731522619438144
# relative_error_metric = 1.8263830207820777
#
# ------------ 11 ------------
# eps = 0.0563905225135386
# statistic = 2.3216167330801136 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.5265945645085344
# relative_error_metric = 1.5686721829096177
#
# ------------ 12 ------------
# eps = 0.031980156200006604
# statistic = 0.9291833235810663 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.2344070588695866
# relative_error_metric = 1.072224534859894
#
# ------------ 13 ------------
# eps = 0.019774973043240607
# statistic = 0.4479968372122703 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.8926888990142077
# relative_error_metric = 0.4594966992035536
#
# ------------ 14 ------------
# eps = 0.013672381464857608
# statistic = 0.27834834492646576 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.36490728000060213
# relative_error_metric = 0.008065206819710947
#
# ------------ 15 ------------
# eps = 0.016723677254049107
# statistic = 0.35322871581077897 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.20076917322794594
# relative_error_metric = 0.22916624247152695
#
# ------------ 16 ------------
# eps = 0.015198029359453358
# statistic = 0.29910734182702803 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.10568937892016723
# relative_error_metric = 0.06384219518995238
#
# ------------ 17 ------------
# eps = 0.014435205412155483
# statistic = 0.29719184281225935 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.05427886432482943
# relative_error_metric = 0.057423459460624
#
# ------------ 18 ------------
# eps = 0.014053793438506545
# statistic = 0.2875742313428968 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.027512772676238063
# relative_error_metric = 0.02454117194085128
#
# ------------ 19 ------------
# eps = 0.013863087451682077
# statistic = 0.28299383466151945 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.013851660736376104
# relative_error_metric = 0.008486441689909786
#
# ------------ 20 ------------
# eps = 0.013767734458269842
# statistic = 0.28067886675701864 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.006949897272982557
# relative_error_metric = 0.0002725737486740519
# =======> statistic within required accuracy at 0.99 CL in 92.7368471159134 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 188.66823132010177 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_20K/exclusion_limits.json
# Computing exclusion limits for fpd with off deformation.
#
# ======================================================
# =============== fpd - only off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 5931.46828189404 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998862949473442
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 2822.4835467777775 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997610555438183
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 1372.4984888723725 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.99950865210941
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 713.764203276019 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9990552933426864
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 423.000486448461 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9984061759602376
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 239.27281662480698 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9971832064188415
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 97.95611724762581 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9931265331871904
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 39.10346278568199 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9828260398697142
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 14.824452483967184 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.955015401677558
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 5.291741058335268 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8764810996935213
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.7775908477998605 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6534501533486126
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.5900752158355871 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.111023551852889
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.23912387058343465 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.34585726435577724
#
# ------------ 14 ------------
# eps = 0.0030517578125
# statistic = 0.129811385239684 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.26005060422637505
#
# ------------ 15 ------------
# eps = 0.00457763671875
# statistic = 0.19397678071596136 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.1398959470443334
#
# ------------ 16 ------------
# eps = 0.003814697265625
# statistic = 0.15407687675754533 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.09010098187257967
#
# ------------ 17 ------------
# eps = 0.0041961669921875
# statistic = 0.17374312030913439 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.029961958060923964
#
# ------------ 18 ------------
# eps = 0.00400543212890625
# statistic = 0.15862409432978655 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.06105749275953584
#
# ------------ 19 ------------
# eps = 0.004100799560546875
# statistic = 0.17121133714977316 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.023529411764705882
# relative_error_metric = 0.015284697100150398
#
# ------------ 20 ------------
# eps = 0.0040531158447265625
# statistic = 0.15981403727358665 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.011695906432748537
# relative_error_metric = 0.053589985375174454
#
# ------------ 21 ------------
# eps = 0.004076957702636719
# statistic = 0.16041589742629778 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.0058309037900874635
# relative_error_metric = 0.049833570008760784
#
# ------------ 22 ------------
# eps = 0.004088878631591797
# statistic = 0.17089999088018146 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.00291970802919708
# relative_error_metric = 0.013464644824278475
# =======> statistic within required accuracy at 0.95 CL in 101.48874780279584 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.004082918167114258
# statistic = 0.16056708298652636 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9996733932168063
# relative_error_metric = 0.5441686285690213
#
# ------------ 2 ------------
# eps = 25.002041459083557
# statistic = 5931.988660011581 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9993468930881861
# relative_error_metric = 1.9998107959304745
#
# ------------ 3 ------------
# eps = 12.503062188625336
# statistic = 2823.2191536321857 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9986942125857652
# relative_error_metric = 1.999602475798491
#
# ------------ 4 ------------
# eps = 6.253572553396225
# statistic = 1373.2885654557922 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9973901291397915
# relative_error_metric = 1.9991828518634116
#
# ------------ 5 ------------
# eps = 3.1288277357816696
# statistic = 714.5197421331677 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.994787060828603
# relative_error_metric = 1.998429758051189
#
# ------------ 6 ------------
# eps = 1.566455326974392
# statistic = 423.6880088243478 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9896012257460272
# relative_error_metric = 1.9973526118294467
#
# ------------ 7 ------------
# eps = 0.7852691225707531
# statistic = 240.86576480404858 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9793100266730284
# relative_error_metric = 1.9953455260424942
#
# ------------ 8 ------------
# eps = 0.3946760203689337
# statistic = 99.27735762860335 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9590437452551783
# relative_error_metric = 1.9887260698595604
#
# ------------ 9 ------------
# eps = 0.19937946926802397
# statistic = 40.20237152334444 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9197312443133334
# relative_error_metric = 1.9722745298089648
#
# ------------ 10 ------------
# eps = 0.10173119371756911
# statistic = 15.731135168072553 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.8456569508776357
# relative_error_metric = 1.9299008316122885
#
# ------------ 11 ------------
# eps = 0.052907055942341685
# statistic = 5.97199573793942 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.7134290210925498
# relative_error_metric = 1.820489104477578
#
# ------------ 12 ------------
# eps = 0.02849498705472797
# statistic = 2.278775028489019 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.4986886800349803
# relative_error_metric = 1.5614521383308664
#
# ------------ 13 ------------
# eps = 0.016288952610921115
# statistic = 0.932897702111441 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.1983223903979607
# relative_error_metric = 1.075064344550629
#
# ------------ 14 ------------
# eps = 0.010185935389017686
# statistic = 0.4528714634157875 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.8554320356425128
# relative_error_metric = 0.46973479823215364
#
# ------------ 15 ------------
# eps = 0.007134426778065972
# statistic = 0.27585599120961946 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.3523608318942578
# relative_error_metric = 0.017059246836637773
#
# ------------ 16 ------------
# eps = 0.00866018108354183
# statistic = 0.3671036201760375 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.19319939043051923
# relative_error_metric = 0.2671003504596666
#
# ------------ 17 ------------
# eps = 0.0078973039308039
# statistic = 0.31990430157913347 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.10150223783449934
# relative_error_metric = 0.13089589791479717
#
# ------------ 18 ------------
# eps = 0.007515865354434936
# statistic = 0.29504263315528007 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.05207248741788059
# relative_error_metric = 0.05017071822835892
#
# ------------ 19 ------------
# eps = 0.007325146066250454
# statistic = 0.2853514203511251 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.026379657302179227
# relative_error_metric = 0.01678246149470972
#
# ------------ 20 ------------
# eps = 0.007229786422158213
# statistic = 0.2804339470535271 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.01310341276652215
# relative_error_metric = 0.000600404759333449
#
# ------------ 21 ------------
# eps = 0.007277466244204334
# statistic = 0.28263005683213505 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.006573239350366324
# relative_error_metric = 0.007200172570803846
# =======> statistic within required accuracy at 0.99 CL in 99.69513890286908 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 201.18392000813037 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_20K/exclusion_limits.json
# Computing exclusion limits for fpd with cov deformation.
#
# ======================================================
# =============== fpd - only cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 5860.709237166934 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998849221733144
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 2654.713676835666 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997459559364004
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 1083.7186549126563 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9993777424047803
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 374.77490344778306 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9982011768340076
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 114.88164719490324 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.994137717924184
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 33.815589663867996 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9801538065479916
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 9.62261776943377 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.931116218796685
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 2.6588572957002587 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.761462823018633
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 0.7617959298363904 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2750970650219984
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 0.27085248323007727 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4652830310792162
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 0.14317421769329192 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.16318789563668096
#
# ------------ 12 ------------
# eps = 0.03662109375
# statistic = 0.20564476557891948 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.197886974083886
#
# ------------ 13 ------------
# eps = 0.030517578125
# statistic = 0.16944642912629868 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.004923126065964942
#
# ------------ 14 ------------
# eps = 0.0274658203125
# statistic = 0.15169641791104133 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.10563402381707664
#
# ------------ 15 ------------
# eps = 0.02899169921875
# statistic = 0.16430561622800544 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.025884035980104206
#
# ------------ 16 ------------
# eps = 0.029754638671875
# statistic = 0.16680330314928132 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.02531645569620253
# relative_error_metric = 0.010798290793842834
#
# ------------ 17 ------------
# eps = 0.0301361083984375
# statistic = 0.1680928830383903 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.012578616352201259
# relative_error_metric = 0.0030969841757382504
#
# ------------ 18 ------------
# eps = 0.03032684326171875
# statistic = 0.16876698302853307 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.006309148264984227
# relative_error_metric = 0.0009052762923579183
# =======> statistic within required accuracy at 0.95 CL in 85.53862586291507 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.030231475830078125
# statistic = 0.1684292656173532 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.997582943357383
# relative_error_metric = 0.4996222831706817
#
# ------------ 2 ------------
# eps = 25.01511573791504
# statistic = 5864.622641747079 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9951717218256833
# relative_error_metric = 1.9998086226764116
#
# ------------ 3 ------------
# eps = 12.522673606872559
# statistic = 2660.4755944338995 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9903666997779708
# relative_error_metric = 1.9995781614687909
#
# ------------ 4 ------------
# eps = 6.276452541351318
# statistic = 1090.1748406362788 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.980825755184361
# relative_error_metric = 1.9989706966083185
#
# ------------ 5 ------------
# eps = 3.1533420085906982
# statistic = 380.3729077041863 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9620156707825094
# relative_error_metric = 1.9970513617863588
#
# ------------ 6 ------------
# eps = 1.5917867422103882
# statistic = 118.65368558310844 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9254472594849144
# relative_error_metric = 1.9905627762584814
#
# ------------ 7 ------------
# eps = 0.8110091090202332
# statistic = 36.13914158127204 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.8562528894848436
# relative_error_metric = 1.9691812911309452
#
# ------------ 8 ------------
# eps = 0.42062029242515564
# statistic = 11.015601076344593 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.7317834555949783
# relative_error_metric = 1.9006383435683651
#
# ------------ 9 ------------
# eps = 0.22542588412761688
# statistic = 3.4762835567764085 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.5270001092856362
# relative_error_metric = 1.7012394021547428
#
# ------------ 10 ------------
# eps = 0.1278286799788475
# statistic = 1.2339749401261506 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.2349374660461783
# relative_error_metric = 1.2589288923343307
#
# ------------ 11 ------------
# eps = 0.07903007790446281
# statistic = 0.5316717039838905 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.893243788074706
# relative_error_metric = 0.6181887125858023
#
# ------------ 12 ------------
# eps = 0.05463077686727047
# statistic = 0.3114729515779295 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.5750330744626737
# relative_error_metric = 0.10427923233300898
#
# ------------ 13 ------------
# eps = 0.0424311263486743
# statistic = 0.23546531867645656 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.2513787616847819
# relative_error_metric = 0.17492686976893637
#
# ------------ 14 ------------
# eps = 0.048530951607972383
# statistic = 0.26903255329518316 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.1182575233946753
# relative_error_metric = 0.04210001102365282
#
# ------------ 15 ------------
# eps = 0.05158086423762143
# statistic = 0.2978316818855001 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.06093012306065924
# relative_error_metric = 0.05957225475741115
#
# ------------ 16 ------------
# eps = 0.050055907922796905
# statistic = 0.2891438651307796 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.030936299666763957
# relative_error_metric = 0.029983501742757622
#
# ------------ 17 ------------
# eps = 0.049293429765384644
# statistic = 0.28429538181869246 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.015588714116211638
# relative_error_metric = 0.013074969074027352
#
# ------------ 18 ------------
# eps = 0.048912190686678514
# statistic = 0.27136965219089887 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.007764098978270262
# relative_error_metric = 0.03345357700899866
#
# ------------ 19 ------------
# eps = 0.04910281022603158
# statistic = 0.2725459625676146 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.003874528932603405
# relative_error_metric = 0.029129289298226932
#
# ------------ 20 ------------
# eps = 0.04919811999570811
# statistic = 0.2731359169915474 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.0019353897853718804
# relative_error_metric = 0.026967448902048764
#
# ------------ 21 ------------
# eps = 0.04924577488054638
# statistic = 0.2734313172990652 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.0009672269024191705
# relative_error_metric = 0.025886708109839025
#
# ------------ 22 ------------
# eps = 0.04926960232296551
# statistic = 0.28414450229232513 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.0004837304204786366
# relative_error_metric = 0.012544136020300183
# =======> statistic within required accuracy at 0.99 CL in 104.44705832214095 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 189.9857181739062 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_20K/exclusion_limits.json
# Computing exclusion limits for fpd with mean_std deformation.
#
# ======================================================
# =============== fpd - mean + diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 63675.47349513251 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999894079264335
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 17235.81143669903 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.99996086923496
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 4925.35893262348 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998630690663706
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 1501.2642777735796 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995507910548749
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 482.99689903542344 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9986040868666393
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 162.2651113509083 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.995847801415452
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 55.98044635411375 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.987988096717946
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 19.305182018792646 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9653659165598103
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 6.511593438179272 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.89903650980127
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 2.125609721430631 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7060195134744178
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 0.696560708482863 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2204385225045624
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.2690807218464618 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4590705947885328
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.14701806977882442 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1368440353310207
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 0.21019766279422292 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.2195463639728128
#
# ------------ 15 ------------
# eps = 0.00762939453125
# statistic = 0.17601167749762311 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.04293005862298074
#
# ------------ 16 ------------
# eps = 0.006866455078125
# statistic = 0.1560091477263574 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.07765997727719338
#
# ------------ 17 ------------
# eps = 0.0072479248046875
# statistic = 0.17290093405475193 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.025103787961856437
#
# ------------ 18 ------------
# eps = 0.00705718994140625
# statistic = 0.1703037795731968 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.0273972602739726
# relative_error_metric = 0.00997000994995068
#
# ------------ 19 ------------
# eps = 0.006961822509765625
# statistic = 0.16903565527958614 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.013793103448275862
# relative_error_metric = 0.002495980856590783
#
# ------------ 20 ------------
# eps = 0.0069141387939453125
# statistic = 0.16840916326201671 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 0.006872852233676976
# relative_error_metric = 0.0012171743555983597
# =======> statistic within required accuracy at 0.95 CL in 96.18530802289024 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.006937980651855469
# statistic = 0.16872177971678515 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.999445038554087
# relative_error_metric = 0.49799500638372146
#
# ------------ 2 ------------
# eps = 25.003468990325928
# statistic = 63692.392687541964 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.998890385004945
# relative_error_metric = 1.999982377729996
#
# ------------ 3 ------------
# eps = 12.505203485488892
# statistic = 17249.09555977019 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9977820005726021
# relative_error_metric = 1.999934930430213
#
# ------------ 4 ------------
# eps = 6.2560707330703735
# statistic = 4933.77899278017 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.99556891521696
# relative_error_metric = 1.999772518052464
#
# ------------ 5 ------------
# eps = 3.1315043568611145
# statistic = 1506.4925921403724 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9911574215413455
# relative_error_metric = 1.9992550906201056
#
# ------------ 6 ------------
# eps = 1.569221168756485
# statistic = 486.3305837388333 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.982392690092343
# relative_error_metric = 1.9976934161852347
#
# ------------ 7 ------------
# eps = 0.7880795747041702
# statistic = 164.4682462228894 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9650926920789895
# relative_error_metric = 1.993187148222631
#
# ------------ 8 ------------
# eps = 0.39750877767801285
# statistic = 57.4950473595383 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.9313830015055102
# relative_error_metric = 1.980572966445362
#
# ------------ 9 ------------
# eps = 0.20222337916493416
# statistic = 20.372988103646275 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.8673181192179542
# relative_error_metric = 1.9456554787741696
#
# ------------ 10 ------------
# eps = 0.10458067990839481
# statistic = 7.253885237448991 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.7511454812315619
# relative_error_metric = 1.851030415839574
#
# ------------ 11 ------------
# eps = 0.05575933028012514
# statistic = 2.630955595292949 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.5573666207546042
# relative_error_metric = 1.6144986640244159
#
# ------------ 12 ------------
# eps = 0.031348655465990305
# statistic = 1.0363876403560097 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 1.2751538024390072
# relative_error_metric = 1.1477463945294129
#
# ------------ 13 ------------
# eps = 0.019143318058922887
# statistic = 0.4758519135497525 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.9359455249844166
# relative_error_metric = 0.5162229784915241
#
# ------------ 14 ------------
# eps = 0.013040649355389178
# statistic = 0.2905586071538302 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.610919637765028
# relative_error_metric = 0.03486315079160917
#
# ------------ 15 ------------
# eps = 0.009989315003622323
# statistic = 0.22634957049694726 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.26498819574359295
# relative_error_metric = 0.21403528224665494
#
# ------------ 16 ------------
# eps = 0.01151498217950575
# statistic = 0.25948345003805445 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.12426210042412215
# relative_error_metric = 0.07820579845466734
#
# ------------ 17 ------------
# eps = 0.012277815767447464
# statistic = 0.27085107957223625 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.06025907054323417
# relative_error_metric = 0.03536578436634581
#
# ------------ 18 ------------
# eps = 0.012659232561418321
# statistic = 0.2805616013905552 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.0296823771568704
# relative_error_metric = 0.0001453054823500755
#
# ------------ 19 ------------
# eps = 0.01284994095840375
# statistic = 0.2855242670324947 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.014952142360648195
# relative_error_metric = 0.01738796660017244
#
# ------------ 20 ------------
# eps = 0.012754586759911035
# statistic = 0.2830340167615823 - next threshold = 0.28060237149143374 at 0.99 CL
# relative_error_eps = 0.007504121854890591
# relative_error_metric = 0.00862841832368349
# =======> statistic within required accuracy at 0.99 CL in 99.13007159694098 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 195.31541345315054 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_20K/exclusion_limits.json
# Computing exclusion limits for fpd with mean_off deformation.
#
# ======================================================
# =============== fpd - mean + off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 63685.22081549476 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999894095475956
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 17257.31474583968 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999609179929927
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 4979.975037700282 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9998645707568403
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 1615.2255589839153 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995824814173666
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 648.2507043998892 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9989598442455512
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 295.044204044764 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9977153529800673
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 111.84261983057534 - next threshold = 0.16861427140297167 at 0.95 CL
# relative_error_eps = 2.0
# ...
# =============== sks - only cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 33.54835420846939 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8751235919210967
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 28.952495157718662 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8560145123010248
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 23.694269955158234 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8254556101751884
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 17.79113531112671 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.770859056488217
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 11.962594985961914 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.66846804061269
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 7.398095205426217 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4899985710750623
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 4.377180337905884 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.207735537925606
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 2.5772153958678246 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8179254981628766
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 1.6017204150557518 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.38811382264532013
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 1.1298254132270813 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.044076497213352384
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 0.9422854520380497 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.137210627608719
#
# ------------ 12 ------------
# eps = 0.03662109375
# statistic = 1.0280004795640707 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.05035320760203154
#
# ------------ 13 ------------
# eps = 0.042724609375
# statistic = 1.0770004149526358 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.0037996961380648182
#
# ------------ 14 ------------
# eps = 0.0457763671875
# statistic = 1.1030754260718822 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.020121957443845154
#
# ------------ 15 ------------
# eps = 0.04425048828125
# statistic = 1.089985342696309 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.03508771929824561
# relative_error_metric = 0.0081847192221692
#
# ------------ 16 ------------
# eps = 0.043487548828125
# statistic = 1.0836104210466146 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.017699115044247787
# relative_error_metric = 0.0023189630342606024
#
# ------------ 17 ------------
# eps = 0.0431060791015625
# statistic = 1.0804154444485903 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.00881057268722467
# relative_error_metric = 0.0006338461932206291
# =======> statistic within required accuracy at 0.95 CL in 129.9620667230338 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.04329681396484375
# statistic = 1.0819253511726856 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9965392516703446
# relative_error_metric = 0.11402499990360769
#
# ------------ 2 ------------
# eps = 25.021648406982422
# statistic = 33.55382412672043 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9930904594311805
# relative_error_metric = 1.860469364910426
#
# ------------ 3 ------------
# eps = 12.532472610473633
# statistic = 28.971225023269653 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9862284962443078
# relative_error_metric = 1.8392855098722154
#
# ------------ 4 ------------
# eps = 6.287884712219238
# statistic = 23.743024915456772 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9726453498224432
# relative_error_metric = 1.8056160486531947
#
# ------------ 5 ------------
# eps = 3.165590763092041
# statistic = 17.90512517094612 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9460288801958534
# relative_error_metric = 1.7462583022286557
#
# ------------ 6 ------------
# eps = 1.6044437885284424
# statistic = 12.168655097484589 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.8948941019009207
# relative_error_metric = 1.6374818632845543
#
# ------------ 7 ------------
# eps = 0.8238703012466431
# statistic = 7.689225152134896 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.800283875136181
# relative_error_metric = 1.4550645382359304
#
# ------------ 8 ------------
# eps = 0.4335835576057434
# statistic = 4.74241528660059 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.6368329120173484
# relative_error_metric = 1.1854127374706338
#
# ------------ 9 ------------
# eps = 0.23844018578529358
# statistic = 2.9930503852665424 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.3852874985785726
# relative_error_metric = 0.8465925260133518
#
# ------------ 10 ------------
# eps = 0.14086849987506866
# statistic = 2.035710494965315 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.0596098024738807
# relative_error_metric = 0.506676804256641
#
# ------------ 11 ------------
# eps = 0.09208265691995621
# statistic = 1.5455004200339317 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.7207273397696519
# relative_error_metric = 0.24127598302113704
#
# ------------ 12 ------------
# eps = 0.06768973544239998
# statistic = 1.306265452876687 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.43956536369197513
# relative_error_metric = 0.07424715905441005
#
# ------------ 13 ------------
# eps = 0.055493274703621864
# statistic = 1.191095495596528 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.19802180064150665
# relative_error_metric = 0.018017015585987898
#
# ------------ 14 ------------
# eps = 0.06159150507301092
# statistic = 1.2482854910194874 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.10416777280570352
# relative_error_metric = 0.028878024316010734
#
# ------------ 15 ------------
# eps = 0.05854238988831639
# statistic = 1.2196604628115892 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.05347651886987092
# relative_error_metric = 0.00568152438635323
#
# ------------ 16 ------------
# eps = 0.05701783229596913
# statistic = 1.205380391329527 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.026385508153766453
# relative_error_metric = 0.00609575771494071
#
# ------------ 17 ------------
# eps = 0.05778011109214276
# statistic = 1.2126454152166843 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.013106299980632058
# relative_error_metric = 8.670445542248628e-05
#
# ------------ 18 ------------
# eps = 0.05816125049022958
# statistic = 1.2161904573440552 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.006574692463241941
# relative_error_metric = 0.002832424321512537
# =======> statistic within required accuracy at 0.99 CL in 137.5325315410737 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 267.4946302389726 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_20K/exclusion_limits.json
# Computing exclusion limits for sks with mean_std deformation.
#
# ======================================================
# =============== sks - mean + diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 84.50153172016144 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9494710339707515
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 75.40312230587006 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9434602097317522
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 61.52469396591187 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9309264908554986
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 44.60535854101181 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9053460914271967
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 29.192319214344025 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8571551559450268
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 17.803680449724197 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.771011274557656
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 10.329190194606781 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6210086106602006
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 5.8097755536437035 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3724452602639987
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 3.2592353969812393 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0036711353988108
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 1.9164204038679598 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5573405209207085
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.266665542498231 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.1580779873709673
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.9978155046701431 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.08012346315261248
#
# ------------ 13 ------------
# eps = 0.018310546875
# statistic = 1.1229755636304617 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.037997858564387976
#
# ------------ 14 ------------
# eps = 0.0152587890625
# statistic = 1.058150539174676 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.021456051114319474
#
# ------------ 15 ------------
# eps = 0.01678466796875
# statistic = 1.090080365538597 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.008271892038652218
#
# ------------ 16 ------------
# eps = 0.016021728515625
# statistic = 1.0736354067921638 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.006928990254638983
#
# ------------ 17 ------------
# eps = 0.0164031982421875
# statistic = 1.0812855325639248 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.023529411764705882
# relative_error_metric = 0.0001711570409781569
#
# ------------ 18 ------------
# eps = 0.01621246337890625
# statistic = 1.0773704387247562 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.011695906432748537
# relative_error_metric = 0.00345618744580965
#
# ------------ 19 ------------
# eps = 0.016307830810546875
# statistic = 1.079355413094163 - next threshold = 1.0811004787683487 at 0.95 CL
# relative_error_eps = 0.0058309037900874635
# relative_error_metric = 0.0016154605893678726
# =======> statistic within required accuracy at 0.95 CL in 145.4921982300002 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.016355514526367188
# statistic = 1.0803204588592052 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9986919867025004
# relative_error_metric = 0.11550458010093924
#
# ------------ 2 ------------
# eps = 25.008177757263184
# statistic = 84.50480461120605 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9973856831855794
# relative_error_metric = 1.9434071324553588
#
# ------------ 3 ------------
# eps = 12.512266635894775
# statistic = 75.419362783432 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9947781921012544
# relative_error_metric = 1.936697527519512
#
# ------------ 4 ------------
# eps = 6.264311075210571
# statistic = 61.57845973968505 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.989583580473389
# relative_error_metric = 1.9227439282843837
#
# ------------ 5 ------------
# eps = 3.1403332948684692
# statistic = 44.724690318107605 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9792751005703313
# relative_error_metric = 1.8943998151997374
#
# ------------ 6 ------------
# eps = 1.5783444046974182
# statistic = 29.39022958278656 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.9589753173516729
# relative_error_metric = 1.8414859525685283
#
# ------------ 7 ------------
# eps = 0.7973499596118927
# statistic = 18.080145120620728 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.919599830424205
# relative_error_metric = 1.74856017852063
#
# ------------ 8 ------------
# eps = 0.40685273706912994
# statistic = 10.676480084657669 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.8454140299513837
# relative_error_metric = 1.5919835025073938
#
# ------------ 9 ------------
# eps = 0.21160412579774857
# statistic = 6.215120479464531 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.7130103468646867
# relative_error_metric = 1.3469188924571818
#
# ------------ 10 ------------
# eps = 0.11397982016205788
# statistic = 3.702265471220016 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.4980481826983882
# relative_error_metric = 1.0130241256971149
#
# ------------ 11 ------------
# eps = 0.06516766734421253
# statistic = 2.367440387606621 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 1.1975036228427878
# relative_error_metric = 0.6450437099440145
#
# ------------ 12 ------------
# eps = 0.04076159093528986
# statistic = 1.6946455277502537 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.8545978025902091
# relative_error_metric = 0.33149591690707925
#
# ------------ 13 ------------
# eps = 0.028558552730828524
# statistic = 1.3715905137360096 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.5433949294585998
# relative_error_metric = 0.12292491399106228
#
# ------------ 14 ------------
# eps = 0.022457033628597856
# statistic = 1.21994542889297 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.31440961195690725
# relative_error_metric = 0.005915138912482727
#
# ------------ 15 ------------
# eps = 0.01940627407748252
# statistic = 1.147960377857089 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.14574861463573413
# relative_error_metric = 0.05489039983433447
#
# ------------ 16 ------------
# eps = 0.02093165385304019
# statistic = 1.182990511879325 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.07031232628104747
# relative_error_metric = 0.02484412859659838
#
# ------------ 17 ------------
# eps = 0.021694343740819022
# statistic = 1.2018104083836079 - next threshold = 1.2127505615353584 at 0.99 CL
# relative_error_eps = 0.034548860453315754
# relative_error_metric = 0.009061815616209286
#
# ------------ 18 ------------
# eps = 0.02207568868470844

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for LR with mean deformation already loaded.
# Computing exclusion limits for lr with std deformation.
#
# ======================================================
# =============== lr - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 0.005
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 111.7613059229916 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -150.0385391278643], [0.99, [9900, 100], -134.17530807188328]]
# Null distribution computed in 112.28718340900377 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 67.71786773498752 seconds.
# statistic = 194.21436517136777 - next threshold = -150.0385391278643 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 15.585578590436262
#
# ------------ 2 ------------
# eps = 0.0025
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 101.92741828001454 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -29.664208941177478], [0.99, [9900, 100], -21.585034016052013]]
# Null distribution computed in 102.33068571498734 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 61.23910541299847 seconds.
# statistic = 48.16333226397346 - next threshold = -29.664208941177478 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 8.41418696952478
#
# ------------ 3 ------------
# eps = 0.00125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 97.5671907979995 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.001250.json
# ThresholdS: [[0.95, [9500, 500], -2.886822703377606], [0.99, [9900, 100], 1.2315022544545169]]
# Null distribution computed in 97.88705277300323 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 61.330189892993076 seconds.
# statistic = 11.709995784617245 - next threshold = -2.886822703377606 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 3.3087458114204926
#
# ------------ 4 ------------
# eps = 0.000625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 101.69149030098924 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.000625.json
# ThresholdS: [[0.95, [9500, 500], 1.6321488351052595], [0.99, [9900, 100], 3.7284576349557064]]
# Null distribution computed in 102.08475344700855 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 62.11820477299625 seconds.
# statistic = 2.7442850379398114 - next threshold = 1.6321488351052595 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5082385499684201
#
# ------------ 5 ------------
# eps = 0.0003125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 98.3243175529933 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.000313.json
# ThresholdS: [[0.95, [9500, 500], 1.5986167260388293], [0.99, [9900, 100], 2.6470859690551247]]
# Null distribution computed in 98.67815708898706 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 58.40715939999791 seconds.
# statistic = 0.5921852947387343 - next threshold = 1.5986167260388293 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.9187789875626375
#
# ------------ 6 ------------
# eps = 0.00046875
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 100.69177944402327 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.000469.json
# ThresholdS: [[0.95, [9500, 500], 1.8123608213246611], [0.99, [9900, 100], 3.3823809252191457]]
# Null distribution computed in 101.05290368100395 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 61.250899887993 seconds.
# statistic = 1.4735332277473423 - next threshold = 1.8123608213246611 at 0.95 CL
# relative_error_eps = 0.28571428571428575
# relative_error_metric = 0.20623159999514284
#
# ------------ 7 ------------
# eps = 0.000546875
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 97.05635647699819 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.000547.json
# ThresholdS: [[0.95, [9500, 500], 1.7726955872389407], [0.99, [9900, 100], 3.6042340176059646]]
# Null distribution computed in 97.5502892130171 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 59.254379705991596 seconds.
# statistic = 2.0602693494779944 - next threshold = 1.7726955872389407 at 0.95 CL
# relative_error_eps = 0.15384615384615397
# relative_error_metric = 0.15005290525061282
#
# ------------ 8 ------------
# eps = 0.0005078125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 98.5577630129992 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.000508.json
# ThresholdS: [[0.95, [9500, 500], 1.8052897166277178], [0.99, [9900, 100], 3.5054196622898006]]
# Null distribution computed in 98.92558644799283 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 63.487778771988815 seconds.
# statistic = 1.7547368898332503 - next threshold = 1.8052897166277178 at 0.95 CL
# relative_error_eps = 0.07407407407407414
# relative_error_metric = 0.028400252235598982
#
# ------------ 9 ------------
# eps = 0.00052734375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 99.64390736501082 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.000527.json
# ThresholdS: [[0.95, [9500, 500], 1.792708808754867], [0.99, [9900, 100], 3.557852099163372]]
# Null distribution computed in 100.02549316498335 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 61.914720126020256 seconds.
# statistic = 1.9044625771532182 - next threshold = 1.792708808754867 at 0.95 CL
# relative_error_eps = 0.03773584905660381
# relative_error_metric = 0.06045365861280062
#
# ------------ 10 ------------
# eps = 0.000517578125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 103.46161834598752 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.000518.json
# ThresholdS: [[0.95, [9500, 500], 1.7997524630118122], [0.99, [9900, 100], 3.532392543756447]]
# Null distribution computed in 103.77069271702203 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 62.20639257400762 seconds.
# statistic = 1.8288395282924057 - next threshold = 1.7997524630118122 at 0.95 CL
# relative_error_eps = 0.019047619047619063
# relative_error_metric = 0.016032149853331266
#
# ------------ 11 ------------
# eps = 0.0005126953125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 98.78637782298028 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.000513.json
# ThresholdS: [[0.95, [9500, 500], 1.8027094332197755], [0.99, [9900, 100], 3.519095312326845]]
# Null distribution computed in 99.07834426799673 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 61.354914160998305 seconds.
# statistic = 1.7915981490677757 - next threshold = 1.8027094332197755 at 0.95 CL
# relative_error_eps = 0.009478672985781998
# relative_error_metric = 0.006182711911888278
# =======> statistic within required accuracy at 0.95 CL in 2463.962490153004 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0005151367187500001
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 104.72556988801807 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_std_0.000515.json
# ThresholdS: [[0.95, [9500, 500], 1.8012780285328045], [0.99, [9900, 100], 3.5257912248728456]]
# Null distribution computed in 105.02469095902052 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 72.71923763302038 seconds.
# statistic = 1.8101713247061877 - next threshold = 3.5257912248728456 at 0.99 CL
# relative_error_eps = 1.804039934989552
# relative_error_metric = 0.6430404577340998
#
# ------------ 2 ------------
# eps = 0.005257568359375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# ...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 106.63026825000998 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_both_0.000430.json
# ThresholdS: [[0.95, [9500, 500], 1.4648661819565338], [0.99, [9900, 100], 3.746336493553335]]
# Null distribution computed in 107.03532297402853 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 67.96592910197796 seconds.
# statistic = 3.8828930579589955 - next threshold = 3.746336493553335 at 0.99 CL
# relative_error_eps = 0.0450755583406228
# relative_error_metric = 0.03579825812911637
#
# ------------ 11 ------------
# eps = 0.0004204207658767701
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 107.0789520299877 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_both_0.000420.json
# ThresholdS: [[0.95, [9500, 500], 1.5170061011798757], [0.99, [9900, 100], 3.7484590239908675]]
# Null distribution computed in 107.53316251799697 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 69.27785653196042 seconds.
# statistic = 3.7126737143569524 - next threshold = 3.7484590239908675 at 0.99 CL
# relative_error_eps = 0.022286633557526744
# relative_error_metric = 0.009592460257405733
#
# ------------ 12 ------------
# eps = 0.000425158441066742
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 113.10441709897714 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_both_0.000425.json
# ThresholdS: [[0.95, [9500, 500], 1.4914083181039053], [0.99, [9900, 100], 3.7478714417695227]]
# Null distribution computed in 113.52487862796988 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 70.66162213502685 seconds.
# statistic = 3.7973067469666035 - next threshold = 3.7478714417695227 at 0.99 CL
# relative_error_eps = 0.011205751397546837
# relative_error_metric = 0.013103813842562576
#
# ------------ 13 ------------
# eps = 0.0004227896034717561
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# Iterating from 200 to 400 out of 10000 .
# Iterating from 400 to 600 out of 10000 .
# Iterating from 600 to 800 out of 10000 .
# Iterating from 800 to 1000 out of 10000 .
# Iterating from 1000 to 1200 out of 10000 .
# Iterating from 1200 to 1400 out of 10000 .
# Iterating from 1400 to 1600 out of 10000 .
# Iterating from 1600 to 1800 out of 10000 .
# Iterating from 1800 to 2000 out of 10000 .
# Iterating from 2000 to 2200 out of 10000 .
# Iterating from 2200 to 2400 out of 10000 .
# Iterating from 2400 to 2600 out of 10000 .
# Iterating from 2600 to 2800 out of 10000 .
# Iterating from 2800 to 3000 out of 10000 .
# Iterating from 3000 to 3200 out of 10000 .
# Iterating from 3200 to 3400 out of 10000 .
# Iterating from 3400 to 3600 out of 10000 .
# Iterating from 3600 to 3800 out of 10000 .
# Iterating from 3800 to 4000 out of 10000 .
# Iterating from 4000 to 4200 out of 10000 .
# Iterating from 4200 to 4400 out of 10000 .
# Iterating from 4400 to 4600 out of 10000 .
# Iterating from 4600 to 4800 out of 10000 .
# Iterating from 4800 to 5000 out of 10000 .
# Iterating from 5000 to 5200 out of 10000 .
# Iterating from 5200 to 5400 out of 10000 .
# Iterating from 5400 to 5600 out of 10000 .
# Iterating from 5600 to 5800 out of 10000 .
# Iterating from 5800 to 6000 out of 10000 .
# Iterating from 6000 to 6200 out of 10000 .
# Iterating from 6200 to 6400 out of 10000 .
# Iterating from 6400 to 6600 out of 10000 .
# Iterating from 6600 to 6800 out of 10000 .
# Iterating from 6800 to 7000 out of 10000 .
# Iterating from 7000 to 7200 out of 10000 .
# Iterating from 7200 to 7400 out of 10000 .
# Iterating from 7400 to 7600 out of 10000 .
# Iterating from 7600 to 7800 out of 10000 .
# Iterating from 7800 to 8000 out of 10000 .
# Iterating from 8000 to 8200 out of 10000 .
# Iterating from 8200 to 8400 out of 10000 .
# Iterating from 8400 to 8600 out of 10000 .
# Iterating from 8600 to 8800 out of 10000 .
# Iterating from 8800 to 9000 out of 10000 .
# Iterating from 9000 to 9200 out of 10000 .
# Iterating from 9200 to 9400 out of 10000 .
# Iterating from 9400 to 9600 out of 10000 .
# Iterating from 9600 to 9800 out of 10000 .
# Iterating from 9800 to 10000 out of 10000 .
# LR metric calculation completed in 110.57932580797933 seconds.
# Saving lr to ../results/20D_20K/null_hypothesis/LR_both_0.000423.json
# ThresholdS: [[0.95, [9500, 500], 1.5043252683152435], [0.99, [9900, 100], 3.7482836682410072]]
# Null distribution computed in 110.98361501202453 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 69.51551511499565 seconds.
# statistic = 3.754871069815409 - next threshold = 3.7482836682410072 at 0.99 CL
# relative_error_eps = 0.005618615902022575
# relative_error_metric = 0.0017559018317962142
# =======> statistic within required accuracy at 0.99 CL in 3213.3403277330217 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 6389.6932285219955 seconds.
# Saving results in the file ../results/20D_20K/exclusion_limits.json
# dict_keys(['2024-04-11T18:40:59.225729', '2024-04-11T19:09:39.150441', '2024-04-11T19:31:31.905127', '2024-04-11T19:59:42.398795', '2024-04-11T20:29:28.809567', '2024-04-11T20:56:21.792966', '2024-04-11T21:34:50.706514', '2024-04-11T22:10:23.651475', '2024-04-11T22:33:52.643222', '2024-04-11T23:11:51.918645', '2024-04-11T23:57:22.155691', '2024-04-12T00:38:42.283455', '2024-04-12T01:20:33.419206', '2024-04-12T01:51:55.309916', '2024-04-12T02:21:07.702944', '2024-04-12T02:54:15.253239', '2024-04-12T03:24:48.988198', '2024-04-12T03:51:24.781222', '2024-04-12T04:22:53.829915', '2024-04-12T07:34:24.898809', '2024-04-12T09:03:30.508826'])
