# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# %cd /mnt/project_mnt/teo_fs/rtorre/cernbox/git/GitHub/NormalizingFlows/NF4HEP/GenerativeModelsMetrics
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more import MixtureDistributions
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/20D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-24 11:47:53.254014: Importing os...
# 2024-05-24 11:47:53.254168: Importing sys...
# Visible devices: [1]
# 2024-05-24 11:47:53.254411: Importing timer from timeit...
# 2024-05-24 11:47:53.254480: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-05-24 11:47:53.254606: Importing numpy...
# 2024-05-24 11:47:53.465750: Importing matplotlib...
# 2024-05-24 11:47:53.871994: Importing h5py...
# 2024-05-24 11:47:53.972924: Importing importlib.util...
# 2024-05-24 11:47:53.973026: Importing json...
# 2024-05-24 11:47:53.973088: Importing pandas...
# 2024-05-24 11:47:54.575425: Importing random...
# 2024-05-24 11:47:54.575576: Importing scipy utils...
# 2024-05-24 11:47:55.291687: Importing subprocess...
# 2024-05-24 11:47:55.291828: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-24 11:48:03.673840: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-24 11:48:05.006746: Importing timeit...
# 2024-05-24 11:48:05.006839: Importing tqdm...
# 2024-05-24 11:48:05.016907: Importing typing...
# 2024-05-24 11:48:05.017024: Setting tf configs...
# 2024-05-24 11:48:05.964239: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-24 11:48:14.085624: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-24 11:48:14.117194: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)
# sample from dist_1:  tf.Tensor(
# [[ 1.62246227 -1.12148208 -3.44534996  4.02194848  1.78776681  0.88094347
#   -0.50568928 -0.93258241  0.96072818  3.18398396 -3.42493274  3.36118865
#   -0.97008955 -3.80922336 -0.88678123 -1.74309765  1.4275693  -0.80163333
#    0.77207225 -1.33233507]
#  [-0.90576152 -2.92629119  0.09540144  3.39476591 -0.96077947  2.45882417
#    1.71000076 -2.53187845 -3.05469271  1.09331411 -3.54069629  3.61418597
#   -1.99533712 -6.54250726  1.51932671 -1.73641701 -0.51890038 -3.80921806
#    2.25758194 -0.7973361 ]], shape=(2, 20), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[ 1.62246227 -1.12148208 -3.44534996  4.02194848  1.78776681  0.88094347
#   -0.50568928 -0.93258241  0.96072818  3.18398396 -3.42493274  3.36118865
#   -0.97008955 -3.80922336 -0.88678123 -1.74309765  1.4275693  -0.80163333
#    0.77207225 -1.33233507]
#  [-0.90576152 -2.92629119  0.09540144  3.39476591 -0.96077947  2.45882417
#    1.71000076 -2.53187845 -3.05469271  1.09331411 -3.54069629  3.61418597
#   -1.99533712 -6.54250726  1.51932671 -1.73641701 -0.51890038 -3.80921806
#    2.25758194 -0.7973361 ]], shape=(2, 20), dtype=float64)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...       20           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True       20           0  float64    20  200000000         False
#
#    ncomp
# 0      5
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 500,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/20D_unimodal/20D_20K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 2,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/20D_unimodal/20D_20K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 10000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/20D_unimodal/20D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/20D_unimodal/20D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/20D_unimodal/20D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 500,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/20D_unimodal/20D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fgd from results/20D_unimodal/20D_20K/null_hypothesis/FGD.json
# Loading mmd from results/20D_unimodal/20D_20K/null_hypothesis/MMD.json
# Loading ks from results/20D_unimodal/20D_20K/null_hypothesis/KS.json
# Loading sks from results/20D_unimodal/20D_20K/null_hypothesis/SKS.json
# Loading swd from results/20D_unimodal/20D_20K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0032331308874788446], [0.95, [9500, 500], 0.02340283931188074], [0.99, [9900, 100], 0.04031432773438884]]
# Computing time for metric fgd: 1150.4399695189786
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.5250005113775842], [0.95, [9500, 500], 15.034728323509626], [0.99, [9900, 100], 29.0570523735405]]
# Computing time for metric mmd: 2284.967773596989
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9060009568929671], [0.95, [9500, 500], 1.1007513105869293], [0.99, [9900, 100], 1.2334998697042465]]
# Computing time for metric ks: 108.46430869196774
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.902500469237566], [0.95, [9500, 500], 1.067950390279293], [0.99, [9900, 100], 1.184050366282463]]
# Computing time for metric sks: 398.50881816004403
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.707078210544279], [0.95, [9500, 500], 0.9086919418955559], [0.99, [9900, 100], 1.0620889433639924]]
# Computing time for metric swd: 276.53056102001574
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f9660098220>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f9660098360>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f9660098400>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f96600984a0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f9660098540>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f96600985e0>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_unimodal/20D_20K/null_hypothesis/F...
# 1  $d_{\mathrm{MMD}}$  results/20D_unimodal/20D_20K/null_hypothesis/M...
# 2      $\overline{D}$  results/20D_unimodal/20D_20K/null_hypothesis/K...
# 3     $\widetilde{D}$  results/20D_unimodal/20D_20K/null_hypothesis/S...
# 4     $\widetilde{W}$  results/20D_unimodal/20D_20K/null_hypothesis/S...
# 5           $t_{\mu}$  results/20D_unimodal/20D_20K/null_hypothesis/L...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0032331308874788446], ...
# 1  [[0.68, [6800, 3199], 0.5250005113775842], [0....
# 2  [[0.68, [6800, 3199], 0.9060009568929671], [0....
# 3  [[0.68, [6800, 3199], 0.902500469237566], [0.9...
# 4  [[0.68, [6800, 3199], 0.707078210544279], [0.9...
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{2})$"
        dist_null = dist_null * 100
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-1})$"
        dist_null = dist_null / 10
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 10
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 10
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.4690716550227786 +/- 0.007837881268531398
# sigma = 0.8853180935986453 +/- 0.016200591579584946
# 68%CL = 0.32331308874788445, 95%CL = 2.340283931188074, 99%CL = 4.031432773438884
# mu = 0.4690716550227786 +/- 0.007837881268531398
# sigma = 0.8853180935986453 +/- 0.016200591579584946
# /tmp/ipykernel_2066063/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2066063/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2066063/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.5654616060201079 seconds.
# mu = -0.003836925382593036 +/- 0.005832982248471971
# sigma = 0.7637396315808137 +/- 0.013439880028341941
# 68%CL = 0.05250005113775842, 95%CL = 1.5034728323509625, 99%CL = 2.90570523735405
# mu = -0.003836925382593036 +/- 0.005832982248471971
# sigma = 0.7637396315808137 +/- 0.013439880028341941
# /tmp/ipykernel_2066063/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2066063/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2066063/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.939092354150489 seconds.
# mu = 0.8675440228674561 +/- 0.00014955435127776023
# sigma = 0.1222924164769673 +/- 0.001109587594306082
# 68%CL = 0.9060009568929671, 95%CL = 1.1007513105869293, 99%CL = 1.2334998697042465
# mu = 0.8675440228674561 +/- 0.00014955435127776023
# sigma = 0.1222924164769673 +/- 0.001109587594306082
# /tmp/ipykernel_2066063/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2066063/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2066063/2214353603.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2066063/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.285175294149667 seconds.
# mu = 0.8672962450748309 +/- 0.00011467390711894699
# sigma = 0.10708590342288148 +/- 0.0009441834049966305
# 68%CL = 0.902500469237566, 95%CL = 1.067950390279293, 99%CL = 1.184050366282463
# mu = 0.8672962450748309 +/- 0.00011467390711894699
# sigma = 0.10708590342288148 +/- 0.0009441834049966305
# /tmp/ipykernel_2066063/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2066063/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2066063/2214353603.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2066063/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3263252000324428 seconds.
# mu = 0.6755264122372958 +/- 0.0001456400750182621
# sigma = 0.12068142981348129 +/- 0.001227251965330865
# 68%CL = 0.707078210544279, 95%CL = 0.9086919418955559, 99%CL = 1.0620889433639924
# mu = 0.6755264122372958 +/- 0.0001456400750182621
# sigma = 0.12068142981348129 +/- 0.001227251965330865
# /tmp/ipykernel_2066063/2214353603.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2066063/2214353603.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2066063/2214353603.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2066063/2214353603.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9412314759101719 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f9660098220>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f9660098360>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f9660098400>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f96600984a0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f9660098540>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f96600985e0>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/20D_unimodal/20D_20K/null_hypothesis/F...
# 1  $d_{\mathrm{MMD}}$  results/20D_unimodal/20D_20K/null_hypothesis/M...
# 2      $\overline{D}$  results/20D_unimodal/20D_20K/null_hypothesis/K...
# 3     $\widetilde{D}$  results/20D_unimodal/20D_20K/null_hypothesis/S...
# 4     $\widetilde{W}$  results/20D_unimodal/20D_20K/null_hypothesis/S...
# 5           $t_{\mu}$  results/20D_unimodal/20D_20K/null_hypothesis/L...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0032331308874788446], ...
# 1  [[0.68, [6800, 3199], 0.5250005113775842], [0....
# 2  [[0.68, [6800, 3199], 0.9060009568929671], [0....
# 3  [[0.68, [6800, 3199], 0.902500469237566], [0.9...
# 4  [[0.68, [6800, 3199], 0.707078210544279], [0.9...
# 5                                                 []
#
#                                          null_figure
# 0  results/20D_unimodal/20D_20K/null_hypothesis/F...
# 1  results/20D_unimodal/20D_20K/null_hypothesis/M...
# 2  results/20D_unimodal/20D_20K/null_hypothesis/K...
# 3  results/20D_unimodal/20D_20K/null_hypothesis/S...
# 4  results/20D_unimodal/20D_20K/null_hypothesis/S...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        eps_max = 5.
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection(dist_1,
                                                     metric_config = metric_config,
                                                     test_kwargs = test_kwargs,
                                                     model_dir = model_dir,
                                                     deformation = deformation,
                                                     seed_dist = 0,
                                                     x_tol = 0.01,
                                                     fn_tol = 0.05,
                                                     bound = bound,
                                                     eps_min = 0.,
                                                     eps_max = eps_max,
                                                     max_iterations = 50,
                                                     save = True,
                                                     filename = "exclusion_limits.json",
                                                     verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Upper bounds for fgd with mean deformation already loaded.
# Central bounds for fgd with mean deformation already loaded.
# Lower bounds for fgd with mean deformation already loaded.
# Upper bounds for fgd with cov_diag deformation already loaded.
# Central bounds for fgd with cov_diag deformation already loaded.
# Lower bounds for fgd with cov_diag deformation already loaded.
# Upper bounds for fgd with cov_off_diag deformation already loaded.
# Central bounds for fgd with cov_off_diag deformation already loaded.
# Lower bounds for fgd with cov_off_diag deformation already loaded.
# Upper bounds for fgd with power_abs_up deformation already loaded.
# Central bounds for fgd with power_abs_up deformation already loaded.
# Lower bounds for fgd with power_abs_up deformation already loaded.
# Upper bounds for fgd with power_abs_down deformation already loaded.
# Central bounds for fgd with power_abs_down deformation already loaded.
# Lower bounds for fgd with power_abs_down deformation already loaded.
# Upper bounds for fgd with random_normal deformation already loaded.
# Central bounds for fgd with random_normal deformation already loaded.
# Lower bounds for fgd with random_normal deformation already loaded.
# Upper bounds for fgd with random_uniform deformation already loaded.
# Central bounds for fgd with random_uniform deformation already loaded.
# Lower bounds for fgd with random_uniform deformation already loaded.
# Upper bounds for mmd with mean deformation already loaded.
# Central bounds for mmd with mean deformation already loaded.
# Lower bounds for mmd with mean deformation already loaded.
# Upper bounds for mmd with cov_diag deformation already loaded.
# Central bounds for mmd with cov_diag deformation already loaded.
# Lower bounds for mmd with cov_diag deformation already loaded.
# Upper bounds for mmd with cov_off_diag deformation already loaded.
# Central bounds for mmd with cov_off_diag deformation already loaded.
# Lower bounds for mmd with cov_off_diag deformation already loaded.
# Upper bounds for mmd with power_abs_up deformation already loaded.
# Central bounds for mmd with power_abs_up deformation already loaded.
# Lower bounds for mmd with power_abs_up deformation already loaded.
# Upper bounds for mmd with power_abs_down deformation already loaded.
# Central bounds for mmd with power_abs_down deformation already loaded.
# Lower bounds for mmd with power_abs_down deformation already loaded.
# Computing upper bounds for mmd with random_normal deformation.
#
# ======================================================
# =============== mmd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - upper bound -----------
# eps = 2.5 - deformation = random_normal
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716544112.269961 2066890 service.cc:145] XLA service 0x7f9500003210 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1716544112.270006 2066890 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1716544114.650488 2066890 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# statistic = 901.1013152974775 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9343559139357271
#
# ------------ 2 - 0.95 CL - upper bound -----------
# eps = 1.25 - deformation = random_normal
# statistic = 37.81559949926395 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8620900612819998
#
# ------------ 3 - 0.95 CL - upper bound -----------
# eps = 0.625 - deformation = random_normal
# statistic = -5.589471731426398 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 4.36710212239712
#
# ------------ 4 - 0.95 CL - upper bound -----------
# eps = 0.9375 - deformation = random_normal
# statistic = 4.812708478697484 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 1.0300594426052452
#
# ------------ 5 - 0.95 CL - upper bound -----------
# eps = 1.09375 - deformation = random_normal
# statistic = 17.843166173896336 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.17084049287939004
#
# ------------ 6 - 0.95 CL - upper bound -----------
# eps = 1.015625 - deformation = random_normal
# statistic = 10.320920466306921 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.37181520348995256
#
# ------------ 7 - 0.95 CL - upper bound -----------
# eps = 1.0546875 - deformation = random_normal
# statistic = 13.094531021896998 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.1379486944742079
#
# ------------ 8 - 0.95 CL - upper bound -----------
# eps = 1.07421875 - deformation = random_normal
# statistic = 15.115745004301683 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.01834862385321101
# relative_error_metric = 0.005374156479150608
#
# ------------ 9 - 0.95 CL - upper bound -----------
# eps = 1.064453125 - deformation = random_normal
# statistic = 14.542643254059712 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.0091324200913242
# relative_error_metric = 0.033274428605623456
# =======> statistic within required accuracy at 0.95 CL in 266.8487493628636 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - upper bound -----------
# eps = 1.0693359375 - deformation = random_normal
# statistic = 15.022104480091265 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 1.2952534191472245
# relative_error_metric = 0.6368065496376603
#
# ------------ 2 - 0.99 CL - upper bound -----------
# eps = 3.03466796875 - deformation = random_normal
# statistic = 2110.4027857348383 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.9577632361689471
# relative_error_metric = 1.9456740400432446
#
# ------------ 3 - 0.99 CL - upper bound -----------
# eps = 2.052001953125 - deformation = random_normal
# statistic = 380.3994358815391 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.6296441141963238
# relative_error_metric = 1.7161402668462413
#
# ------------ 4 - 0.99 CL - upper bound -----------
# eps = 1.5606689453125 - deformation = random_normal
# statistic = 109.55595294238641 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.3736365746112787
# relative_error_metric = 1.1614913100740112
#
# ------------ 5 - 0.99 CL - upper bound -----------
# eps = 1.31500244140625 - deformation = random_normal
# statistic = 48.21185898275516 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.20606681172404967
# relative_error_metric = 0.49579594879730315
#
# ------------ 6 - 0.99 CL - upper bound -----------
# eps = 1.192169189453125 - deformation = random_normal
# statistic = 29.22245107773519 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.10862964712232642
# relative_error_metric = 0.005676050563230027
#
# ------------ 7 - 0.99 CL - upper bound -----------
# eps = 1.1307525634765625 - deformation = random_normal
# statistic = 21.308118468900197 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.0528787729497159
# relative_error_metric = 0.3077100216290973
#
# ------------ 8 - 0.99 CL - upper bound -----------
# eps = 1.1614608764648438 - deformation = random_normal
# statistic = 24.891381139681002 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.026094426165740127
# relative_error_metric = 0.15443159189556782
#
# ------------ 9 - 0.99 CL - upper bound -----------
# eps = 1.1768150329589844 - deformation = random_normal
# statistic = 26.519097694345657 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.012962649855478531
# relative_error_metric = 0.0913325113774429
#
# ------------ 10 - 0.99 CL - upper bound -----------
# eps = 1.1844921112060547 - deformation = random_normal
# statistic = 27.86914068157136 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.0064603889876450075
# relative_error_metric = 0.04173515312429518
# =======> statistic within required accuracy at 0.99 CL in 294.5088545260951 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 561.3576400489546 seconds.
# Saving results in the file results/20D_unimodal/20D_20K/exclusion_limits.json
# Computing central bounds for mmd with random_normal deformation.
#
# ======================================================
# =============== mmd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - central bound -----------
# eps = 0.5941653251647949 - deformation = random_normal
# statistic = 3.5669886137787032 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.2329764772135743
#
# ------------ 2 - 0.95 CL - central bound -----------
# eps = 0.8912479877471924 - deformation = random_normal
# statistic = 15.531665101292091 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.03251523795275428
#
# ------------ 3 - 0.95 CL - central bound -----------
# eps = 0.7427066564559937 - deformation = random_normal
# statistic = 7.8964040273602585 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.6225880333274146
#
# ------------ 4 - 0.95 CL - central bound -----------
# eps = 0.816977322101593 - deformation = random_normal
# statistic = 10.982423672955957 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.31151024148255524
#
# ------------ 5 - 0.95 CL - central bound -----------
# eps = 0.8541126549243927 - deformation = random_normal
# statistic = 13.375075105448268 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.0425531914893617
# relative_error_metric = 0.11683665620647599
#
# ------------ 6 - 0.95 CL - central bound -----------
# eps = 0.8726803213357925 - deformation = random_normal
# statistic = 14.353980828005914 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.021052631578947368
# relative_error_metric = 0.046327145026620255
#
# ------------ 7 - 0.95 CL - central bound -----------
# eps = 0.8819641545414925 - deformation = random_normal
# statistic = 15.1019599056906 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.010582010582010581
# relative_error_metric = 0.004461776401551156
#
# ------------ 8 - 0.95 CL - central bound -----------
# eps = 0.8773222379386425 - deformation = random_normal
# statistic = 14.801222452106959 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.005277044854881266
# relative_error_metric = 0.01565265160535786
# =======> statistic within required accuracy at 0.95 CL in 235.07623252202757 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - central bound -----------
# eps = 0.8796431962400675 - deformation = random_normal
# statistic = 14.914992498369502 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.29854096520763185
# relative_error_metric = 0.6432295753525512
#
# ------------ 2 - 0.99 CL - central bound -----------
# eps = 1.0339869232848287 - deformation = random_normal
# statistic = 27.464099038223686 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.13890339425587467
# relative_error_metric = 0.056366627201627044
#
# ------------ 3 - 0.99 CL - central bound -----------
# eps = 1.1111587868072093 - deformation = random_normal
# statistic = 36.60882957586589 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.07195022991614823
# relative_error_metric = 0.23000611514344116
#
# ------------ 4 - 0.99 CL - central bound -----------
# eps = 1.072572855046019 - deformation = random_normal
# statistic = 31.935170353435897 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.036634072441812424
# relative_error_metric = 0.09437655659079389
#
# ------------ 5 - 0.99 CL - central bound -----------
# eps = 1.0532798891654238 - deformation = random_normal
# statistic = 29.159081423737078 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.018486343734797416
# relative_error_metric = 0.0035051812458679206
#
# ------------ 6 - 0.99 CL - central bound -----------
# eps = 1.0436334062251262 - deformation = random_normal
# statistic = 28.722113337832525 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.00920065027152295
# relative_error_metric = 0.011593765039153117
# =======> statistic within required accuracy at 0.99 CL in 176.1277080529835 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 411.20397776481695 seconds.
# Saving results in the file results/20D_unimodal/20D_20K/exclusion_limits.json
# Computing lower bounds for mmd with random_normal deformation.
#
# ======================================================
# =============== mmd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - lower bound -----------
# eps = 0.5242283238476375 - deformation = random_normal
# statistic = 11.64311108428741 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.25426476165314643
#
# ------------ 2 - 0.95 CL - lower bound -----------
# eps = 0.7863424857714563 - deformation = random_normal
# statistic = 21.3334395705202 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.3463859529775524
#
# ------------ 3 - 0.95 CL - lower bound -----------
# eps = 0.6552854048095469 - deformation = random_normal
# statistic = 15.167310538476698 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.008779686402824073
#
# ------------ 4 - 0.95 CL - lower bound -----------
# eps = 0.5897568643285922 - deformation = random_normal
# statistic = 12.964831078975594 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.14785212972674913
#
# ------------ 5 - 0.95 CL - lower bound -----------
# eps = 0.6225211345690695 - deformation = random_normal
# statistic = 14.74063060032571 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.019754436810398176
#
# ------------ 6 - 0.95 CL - lower bound -----------
# eps = 0.6389032696893082 - deformation = random_normal
# statistic = 14.24159712032652 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.02531645569620253
# relative_error_metric = 0.05418242837234829
#
# ------------ 7 - 0.95 CL - lower bound -----------
# eps = 0.6470943372494276 - deformation = random_normal
# statistic = 15.036272280987372 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.012738853503184714
# relative_error_metric = 0.00010268746943630622
#
# ------------ 8 - 0.95 CL - lower bound -----------
# eps = 0.6429988034693679 - deformation = random_normal
# statistic = 14.958680058254096 - next threshold = 15.034728323509626 at 0.95 CL
# relative_error_eps = 0.006349206349206349
# relative_error_metric = 0.005070998553253303
# =======> statistic within required accuracy at 0.95 CL in 234.72021703515202 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - lower bound -----------
# eps = 0.6450465703593977 - deformation = random_normal
# statistic = 15.186488798173519 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.47642079806529625
# relative_error_metric = 0.6270096474210239
#
# ------------ 2 - 0.99 CL - lower bound -----------
# eps = 0.8467516090273364 - deformation = random_normal
# statistic = 25.6122913820521 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.21285791464073472
# relative_error_metric = 0.12602166972732343
#
# ------------ 3 - 0.99 CL - lower bound -----------
# eps = 0.9476041283613057 - deformation = random_normal
# statistic = 34.17769212911563 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.11241084165477888
# relative_error_metric = 0.16195652550980222
#
# ------------ 4 - 0.99 CL - lower bound -----------
# eps = 0.897177868694321 - deformation = random_normal
# statistic = 28.550463438836243 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.054669071735812404
# relative_error_metric = 0.01758759868605267
#
# ------------ 5 - 0.99 CL - lower bound -----------
# eps = 0.9223909985278134 - deformation = random_normal
# statistic = 31.48415430757588 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.027713300977702752
# relative_error_metric = 0.08018016379552695
#
# ------------ 6 - 0.99 CL - lower bound -----------
# eps = 0.9097844336110672 - deformation = random_normal
# statistic = 29.729986667123804 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.013953323653362609
# relative_error_metric = 0.022893967941396726
#
# ------------ 7 - 0.99 CL - lower bound -----------
# eps = 0.9034811511526941 - deformation = random_normal
# statistic = 29.250099364894727 - next threshold = 29.0570523735405 at 0.99 CL
# relative_error_eps = 0.007001083924160848
# relative_error_metric = 0.006621726000962325
# =======> statistic within required accuracy at 0.99 CL in 206.55362864397466 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 441.2738856950309 seconds.
# Saving results in the file results/20D_unimodal/20D_20K/exclusion_limits.json
# Upper bounds for mmd with random_uniform deformation already loaded.
# Central bounds for mmd with random_uniform deformation already loaded.
# Lower bounds for mmd with random_uniform deformation already loaded.
# Upper bounds for ks with mean deformation already loaded.
# Central bounds for ks with mean deformation already loaded.
# Lower bounds for ks with mean deformation already loaded.
# Upper bounds for ks with cov_diag deformation already loaded.
# Central bounds for ks with cov_diag deformation already loaded.
# Lower bounds for ks with cov_diag deformation already loaded.
# Upper bounds for ks with cov_off_diag deformation already loaded.
# Central bounds for ks with cov_off_diag deformation already loaded.
# Lower bounds for ks with cov_off_diag deformation already loaded.
# Upper bounds for ks with power_abs_up deformation already loaded.
# Central bounds for ks with power_abs_up deformation already loaded.
# Lower bounds for ks with power_abs_up deformation already loaded.
# Upper bounds for ks with power_abs_down deformation already loaded.
# Central bounds for ks with power_abs_down deformation already loaded.
# Lower bounds for ks with power_abs_down deformation already loaded.
# Upper bounds for ks with random_normal deformation already loaded.
# Central bounds for ks with random_normal deformation already loaded.
# Lower bounds for ks with random_normal deformation already loaded.
# Upper bounds for ks with random_uniform deformation already loaded.
# Central bounds for ks with random_uniform deformation already loaded.
# Lower bounds for ks with random_uniform deformation already loaded.
# Upper bounds for sks with mean deformation already loaded.
# Central bounds for sks with mean deformation already loaded.
# Lower bounds for sks with mean deformation already loaded.
# Upper bounds for sks with cov_diag deformation already loaded.
# Central bounds for sks with cov_diag deformation already loaded.
# Lower bounds for sks with cov_diag deformation already loaded.
# Upper bounds for sks with cov_off_diag deformation already loaded.
# Central bounds for sks with cov_off_diag deformation already loaded.
# Lower bounds for sks with cov_off_diag deformation already loaded.
# Upper bounds for sks with power_abs_up deformation already loaded.
# Central bounds for sks with power_abs_up deformation already loaded.
# Lower bounds for sks with power_abs_up deformation already loaded.
# Upper bounds for sks with power_abs_down deformation already loaded.
# Central bounds for sks with power_abs_down deformation already loaded.
# Lower bounds for sks with power_abs_down deformation already loaded.
# Upper bounds for sks with random_normal deformation already loaded.
# Central bounds for sks with random_normal deformation already loaded.
# Lower bounds for sks with random_normal deformation already loaded.
# Upper bounds for sks with random_uniform deformation already loaded.
# Central bounds for sks with random_uniform deformation already loaded.
# Lower bounds for sks with random_uniform deformation already loaded.
# Upper bounds for swd with mean deformation already loaded.
# Central bounds for swd with mean deformation already loaded.
# Lower bounds for swd with mean deformation already loaded.
# Upper bounds for swd with cov_diag deformation already loaded.
# Central bounds for swd with cov_diag deformation already loaded.
# Lower bounds for swd with cov_diag deformation already loaded.
# Upper bounds for swd with cov_off_diag deformation already loaded.
# Central bounds for swd with cov_off_diag deformation already loaded.
# Lower bounds for swd with cov_off_diag deformation already loaded.
# Upper bounds for swd with power_abs_up deformation already loaded.
# Central bounds for swd with power_abs_up deformation already loaded.
# Lower bounds for swd with power_abs_up deformation already loaded.
# Upper bounds for swd with power_abs_down deformation already loaded.
# Central bounds for swd with power_abs_down deformation already loaded.
# Lower bounds for swd with power_abs_down deformation already loaded.
# Upper bounds for swd with random_normal deformation already loaded.
# Central bounds for swd with random_normal deformation already loaded.
# Lower bounds for swd with random_normal deformation already loaded.
# Upper bounds for swd with random_uniform deformation already loaded.
# Central bounds for swd with random_uniform deformation already loaded.
# Lower bounds for swd with random_uniform deformation already loaded.
# dict_keys(['fgd_mean_upper_2024-05-20T13:34:32.502083', 'fgd_mean_central_2024-05-20T13:41:46.781959', 'fgd_mean_lower_2024-05-20T13:47:18.292436', 'fgd_cov_diag_upper_2024-05-20T13:52:47.433375', 'fgd_cov_diag_central_2024-05-20T14:02:24.880464', 'fgd_cov_diag_lower_2024-05-20T14:07:51.816256', 'fgd_cov_off_diag_upper_2024-05-20T14:12:26.909324', 'fgd_cov_off_diag_central_2024-05-20T14:21:39.720667', 'fgd_cov_off_diag_lower_2024-05-20T14:26:11.293675', 'fgd_power_abs_up_upper_2024-05-20T14:30:43.296154', 'fgd_power_abs_up_central_2024-05-20T14:39:27.406698', 'fgd_power_abs_up_lower_2024-05-20T14:43:57.862441', 'fgd_power_abs_down_upper_2024-05-20T14:48:48.402230', 'fgd_power_abs_down_central_2024-05-20T14:57:34.805325', 'fgd_power_abs_down_lower_2024-05-20T15:02:08.273299', 'fgd_random_normal_upper_2024-05-20T15:06:58.722412', 'fgd_random_normal_central_2024-05-20T15:12:46.679277', 'fgd_random_normal_lower_2024-05-20T15:16:48.880940', 'fgd_random_uniform_upper_2024-05-20T15:21:08.959211', 'fgd_random_uniform_central_2024-05-20T15:26:21.706789', 'fgd_random_uniform_lower_2024-05-20T15:30:21.356186', 'mmd_mean_upper_2024-05-20T15:34:41.862979', 'mmd_mean_central_2024-05-20T15:44:36.605868', 'mmd_mean_lower_2024-05-20T15:52:30.227726', 'mmd_cov_diag_upper_2024-05-20T16:00:56.115119', 'mmd_cov_diag_central_2024-05-20T16:12:24.551627', 'mmd_cov_diag_lower_2024-05-20T16:20:23.385496', 'mmd_cov_off_diag_upper_2024-05-20T16:28:55.892361', 'mmd_cov_off_diag_central_2024-05-20T16:41:21.993788', 'mmd_cov_off_diag_lower_2024-05-20T16:49:18.700063', 'mmd_power_abs_up_upper_2024-05-20T16:57:16.616565', 'mmd_power_abs_up_central_2024-05-20T17:11:44.044336', 'mmd_power_abs_up_lower_2024-05-20T17:19:41.183822', 'mmd_power_abs_down_upper_2024-05-20T17:28:10.546396', 'mmd_power_abs_down_central_2024-05-20T17:43:13.639875', 'mmd_power_abs_down_lower_2024-05-20T17:51:46.771137', 'mmd_random_normal_upper_2024-05-24T11:48:27.747327', 'mmd_random_normal_central_2024-05-24T11:57:49.191419', 'mmd_random_normal_lower_2024-05-24T12:04:41.137279', 'mmd_random_uniform_upper_2024-05-21T08:33:25.517679', 'mmd_random_uniform_central_2024-05-21T08:42:16.040217', 'mmd_random_uniform_lower_2024-05-21T08:49:08.870937', 'ks_mean_upper_2024-05-21T08:56:32.358530', 'ks_mean_central_2024-05-21T08:59:19.676226', 'ks_mean_lower_2024-05-21T09:00:55.785615', 'ks_cov_diag_upper_2024-05-21T09:02:39.336549', 'ks_cov_diag_central_2024-05-21T09:05:44.754041', 'ks_cov_diag_lower_2024-05-21T09:07:25.467579', 'ks_cov_off_diag_upper_2024-05-21T09:09:06.718050', 'ks_cov_off_diag_central_2024-05-21T09:11:18.127874', 'ks_cov_off_diag_lower_2024-05-21T09:12:17.200913', 'ks_power_abs_up_upper_2024-05-21T09:13:22.715683', 'ks_power_abs_up_central_2024-05-21T09:17:01.074511', 'ks_power_abs_up_lower_2024-05-21T09:18:39.358445', 'ks_power_abs_down_upper_2024-05-21T09:20:25.768364', 'ks_power_abs_down_central_2024-05-21T09:24:04.473804', 'ks_power_abs_down_lower_2024-05-21T09:25:43.199472', 'ks_random_normal_upper_2024-05-21T09:27:23.879937', 'ks_random_normal_central_2024-05-21T09:29:55.281095', 'ks_random_normal_lower_2024-05-21T09:31:33.696766', 'ks_random_uniform_upper_2024-05-21T09:33:17.513099', 'ks_random_uniform_central_2024-05-21T09:35:36.060577', 'ks_random_uniform_lower_2024-05-21T09:37:12.280225', 'sks_mean_upper_2024-05-21T09:38:55.278994', 'sks_mean_central_2024-05-21T09:43:19.824192', 'sks_mean_lower_2024-05-21T09:45:52.330035', 'sks_cov_diag_upper_2024-05-21T09:48:35.191183', 'sks_cov_diag_central_2024-05-21T09:53:28.692451', 'sks_cov_diag_lower_2024-05-21T09:56:06.768199', 'sks_cov_off_diag_upper_2024-05-21T09:58:56.177409', 'sks_cov_off_diag_central_2024-05-21T11:07:22.625405', 'sks_cov_off_diag_lower_2024-05-21T11:12:30.587913', 'sks_power_abs_up_upper_2024-05-21T11:15:08.810850', 'sks_power_abs_up_central_2024-05-21T11:20:34.153696', 'sks_power_abs_up_lower_2024-05-21T11:23:02.138964', 'sks_power_abs_down_upper_2024-05-21T11:25:40.915690', 'sks_power_abs_down_central_2 ...

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]
eps_max_def = []
bounds = ["upper", "central", "lower"]

for deformation in deformations:
    eps_max = 0.1
    for bound in bounds:
        try:
            result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation and v["bound"] == bound}
        except:
            result = {}
        if result == {}:
            print(f"Computing {bound} bounds for lr with {deformation} deformation.")
            result = compute_exclusion_LR_bisection(dist_1,
                                                    metric_config = metrics_config[unique_key]["lr"],
                                                    test_kwargs = test_kwargs,
                                                    model_dir = model_dir,
                                                    cl_list = [0.95, 0.99],
                                                    deformation = deformation,
                                                    seed_dist = 0,
                                                    x_tol = 0.01,
                                                    fn_tol = 0.05,
                                                    bound = bound,
                                                    eps_min = 0.,
                                                    eps_max = eps_max,
                                                    max_iterations = 50,
                                                    save = True,
                                                    filename = "exclusion_limits.json",
                                                    verbose = True)
            eps_max = list(result.values())[0]["exclusion_list"][-1][3]
        else:
            print(f"{bound.capitalize()} bounds for lr with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing upper bounds for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - upper bound -----------
# eps = 0.05 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.432588018942624 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.050000.json
# ThresholdS: [[0.95, [9500, 500], -40.20681706834193], [0.99, [9900, 100], -31.310258938959638]]
# Null distribution computed in 20.600721577182412 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.306095770094544 seconds.
# statistic = 46.27966930167833 - next threshold = -40.20681706834193 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 28.482987251117375
#
# ------------ 2 - 0.95 CL - upper bound -----------
# eps = 0.025 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.901113481959328 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.025000.json
# ThresholdS: [[0.95, [9500, 500], -4.617471653728931], [0.99, [9900, 100], -0.16919258887315042]]
# Null distribution computed in 20.063972779083997 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.288511417107657 seconds.
# statistic = 7.653897770298064 - next threshold = -4.617471653728931 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 8.082771622246781
#
# ------------ 3 - 0.95 CL - upper bound -----------
# eps = 0.0125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.018589650979266 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.012500.json
# ThresholdS: [[0.95, [9500, 500], 1.5627483930402475], [0.99, [9900, 100], 3.78688792579741]]
# Null distribution computed in 20.183214340126142 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.3030552649870515 seconds.
# statistic = -0.04453533493962558 - next threshold = 1.5627483930402475 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 2.1173361925771923
#
# ------------ 4 - 0.95 CL - upper bound -----------
# eps = 0.018750000000000003 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.95527070388198 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.018750.json
# ThresholdS: [[0.95, [9500, 500], -0.5594905753270044], [0.99, [9900, 100], 2.776718723644103]]
# Null distribution computed in 20.114092556992546 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.281613716855645 seconds.
# statistic = 2.836810162639625 - next threshold = -0.5594905753270044 at 0.95 CL
# relative_error_eps = 0.40000000000000013
# relative_error_metric = 2.9827177150612196
#
# ------------ 5 - 0.95 CL - upper bound -----------
# eps = 0.015625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.605953166028485 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.015625.json
# ThresholdS: [[0.95, [9500, 500], 0.743596672775592], [0.99, [9900, 100], 3.5237710883104545]]
# Null distribution computed in 20.76696878601797 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.565298043889925 seconds.
# statistic = 1.1541696500974767 - next threshold = 0.743596672775592 at 0.95 CL
# relative_error_eps = 0.22222222222222215
# relative_error_metric = 0.4326907611052024
#
# ------------ 6 - 0.95 CL - upper bound -----------
# eps = 0.0140625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.131739765172824 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.014063.json
# ThresholdS: [[0.95, [9500, 500], 1.2136644738876623], [0.99, [9900, 100], 3.7158214481983114]]
# Null distribution computed in 20.29571467707865 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.584277326008305 seconds.
# statistic = 0.494325216618678 - next threshold = 1.2136644738876623 at 0.95 CL
# relative_error_eps = 0.10526315789473682
# relative_error_metric = 0.8423227157252141
#
# ------------ 7 - 0.95 CL - upper bound -----------
# eps = 0.01484375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.080142623977736 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.014844.json
# ThresholdS: [[0.95, [9500, 500], 0.9937535584942447], [0.99, [9900, 100], 3.6349192534170007]]
# Null distribution computed in 20.241392333991826 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.4533920888789 seconds.
# statistic = 0.8091244480687201 - next threshold = 0.9937535584942447 at 0.95 CL
# relative_error_eps = 0.05128205128205133
# relative_error_metric = 0.20481597729122505
#
# ------------ 8 - 0.95 CL - upper bound -----------
# eps = 0.015234375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.01156262680888 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.015234.json
# ThresholdS: [[0.95, [9500, 500], 0.8724558616374596], [0.99, [9900, 100], 3.583125917195541]]
# Null distribution computed in 20.174827130045742 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.38016226189211 seconds.
# statistic = 0.9778663027895549 - next threshold = 0.8724558616374596 at 0.95 CL
# relative_error_eps = 0.025974025974026
# relative_error_metric = 0.11393739228621037
#
# ------------ 9 - 0.95 CL - upper bound -----------
# eps = 0.015039062499999999 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.941641850862652 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.015039.json
# ThresholdS: [[0.95, [9500, 500], 0.9340498969369189], [0.99, [9900, 100], 3.609967771848065]]
# Null distribution computed in 20.103361362125725 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.39050163095817 seconds.
# statistic = 0.8925501888848739 - next threshold = 0.9340498969369189 at 0.95 CL
# relative_error_eps = 0.012903225806451682
# relative_error_metric = 0.04543929278682159
#
# ------------ 10 - 0.95 CL - upper bound -----------
# eps = 0.01513671875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.99328430206515 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.015137.json
# ThresholdS: [[0.95, [9500, 500], 0.9034891759226378], [0.99, [9900, 100], 3.596783141157252]]
# Null distribution computed in 20.156550002051517 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.3393546340521425 seconds.
# statistic = 0.934971949198133 - next threshold = 0.9034891759226378 at 0.95 CL
# relative_error_eps = 0.0064724919093852055
# relative_error_metric = 0.03424904975722787
# =======> statistic within required accuracy at 0.95 CL in 257.45381078799255 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - upper bound -----------
# eps = 0.015087890625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.89540850906633 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.015088.json
# ThresholdS: [[0.95, [9500, 500], 0.9188286106709584], [0.99, [9900, 100], 3.6034345309084745]]
# Null distribution computed in 20.056413995102048 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.411333458963782 seconds.
# statistic = 0.9137019948552045 - next threshold = 3.6034345309084745 at 0.99 CL
# relative_error_eps = 1.4756045820958845
# relative_error_metric = 1.1909015902938807
#
# ------------ 2 - 0.99 CL - upper bound -----------
# eps = 0.0575439453125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.971530401147902 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.057544.json
# ThresholdS: [[0.95, [9500, 500], -57.02929751982783], [0.99, [9900, 100], -46.79043643065605]]
# Null distribution computed in 20.13118177698925 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.374094492988661 seconds.
# statistic = 64.01841505603355 - next threshold = -46.79043643065605 at 0.99 CL
# relative_error_eps = 1.1690756302521006
# relative_error_metric = 12.863825048338958
#
# ------------ 3 - 0.99 CL - upper bound -----------
# eps = 0.03631591796875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.983014363097027 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.036316.json
# ThresholdS: [[0.95, [9500, 500], -16.88977126325943], [0.99, [9900, 100], -10.42803775871942]]
# Null distribution computed in 20.143718336010352 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.355876651126891 seconds.
# statistic = 21.300595334163134 - next threshold = -10.42803775871942 at 0.99 CL
# relative_error_eps = 0.825932082640703
# relative_error_metric = 5.836461729031164
#
# ------------ 4 - 0.99 CL - upper bound -----------
# eps = 0.025701904296875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.101833324879408 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.025702.json
# ThresholdS: [[0.95, [9500, 500], -5.194105528505642], [0.99, [9900, 100], -0.6209358161168796]]
# Null distribution computed in 20.266707956092432 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.314638186013326 seconds.
# statistic = 8.315782866700388 - next threshold = -0.6209358161168796 at 0.99 CL
# relative_error_eps = 0.5204249588508156
# relative_error_metric = 2.322780069329536
#
# ------------ 5 - 0.99 CL - upper bound -----------
# eps = 0.0203948974609375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.954182768939063 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.020395.json
# ThresholdS: [[0.95, [9500, 500], -1.439797009593671], [0.99, [9900, 100], 2.1890908065548325]]
# Null distribution computed in 20.11708123795688 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.311857453081757 seconds.
# statistic = 3.916900981339265 - next threshold = 2.1890908065548325 at 0.99 CL
# relative_error_eps = 0.299131332243915
# relative_error_metric = 0.5659392396203464
#
# ------------ 6 - 0.99 CL - upper bound -----------
# eps = 0.017741394042968747 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.00025176210329 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.017741.json
# ThresholdS: [[0.95, [9500, 500], -0.08602383700696141], [0.99, [9900, 100], 3.0707230311860485]]
# Null distribution computed in 20.161412989953533 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.34962606895715 seconds.
# statistic = 2.240841125777971 - next threshold = 3.0707230311860485 at 0.99 CL
# relative_error_eps = 0.1391589645100629
# relative_error_metric = 0.31248117536903525
#
# ------------ 7 - 0.99 CL - upper bound -----------
# eps = 0.019068145751953123 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.059596386970952 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.019068.json
# ThresholdS: [[0.95, [9500, 500], -0.7192953330159898], [0.99, [9900, 100], 2.6735220096486754]]
# Null distribution computed in 20.222287261858582 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.370183236896992 seconds.
# statistic = 3.0352559629528306 - next threshold = 2.6735220096486754 at 0.99 CL
# relative_error_eps = 0.07208738367152367
# relative_error_metric = 0.12672903204161995
#
# ------------ 8 - 0.99 CL - upper bound -----------
# eps = 0.018404769897460933 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.01864868402481 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.018405.json
# ThresholdS: [[0.95, [9500, 500], -0.39175581235807594], [0.99, [9900, 100], 2.883026292906125]]
# Null distribution computed in 20.18237288016826 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.346477871062234 seconds.
# statistic = 2.6271447716873446 - next threshold = 2.883026292906125 at 0.99 CL
# relative_error_eps = 0.03540561725693007
# relative_error_metric = 0.09287607162071258
#
# ------------ 9 - 0.99 CL - upper bound -----------
# eps = 0.01873645782470703 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 20.001576252048835 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.018736.json
# ThresholdS: [[0.95, [9500, 500], -0.5527996291120927], [0.99, [9900, 100], 2.7810000943584323]]
# Null distribution computed in 20.1630498690065 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# ...
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.4707587661687285 seconds.
# statistic = 3.275930466097086 - next threshold = 3.5042890388341816 at 0.99 CL
# relative_error_eps = 0.10870750772586815
# relative_error_metric = 0.06736023002529931
#
# ------------ 5 - 0.99 CL - lower bound -----------
# eps = 0.009499823567809339 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.81891661393456 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.009500.json
# ThresholdS: [[0.95, [9500, 500], 1.893853857464086], [0.99, [9900, 100], 3.584168509055511]]
# Null distribution computed in 19.982335280859843 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.435436804080382 seconds.
# statistic = 3.5857637276928083 - next threshold = 3.584168509055511 at 0.99 CL
# relative_error_eps = 0.05587218536858841
# relative_error_metric = 0.00044497453661308974
#
# ------------ 6 - 0.99 CL - lower bound -----------
# eps = 0.009241648031836334 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.79701619106345 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.009242.json
# ThresholdS: [[0.95, [9500, 500], 1.901503129830088], [0.99, [9900, 100], 3.5458803085758217]]
# Null distribution computed in 19.959961376851425 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.465321589028463 seconds.
# statistic = 3.42919556243294 - next threshold = 3.5458803085758217 at 0.99 CL
# relative_error_eps = 0.02755125547108969
# relative_error_metric = 0.03345762778807052
#
# ------------ 7 - 0.99 CL - lower bound -----------
# eps = 0.009370735799822836 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.84219562401995 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.009371.json
# ThresholdS: [[0.95, [9500, 500], 1.8980913770167176], [0.99, [9900, 100], 3.565437292514569]]
# Null distribution computed in 20.00438104895875 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.453944378998131 seconds.
# statistic = 3.5070667614233435 - next threshold = 3.565437292514569 at 0.99 CL
# relative_error_eps = 0.01368139284815488
# relative_error_metric = 0.01650632665490675
#
# ------------ 8 - 0.99 CL - lower bound -----------
# eps = 0.009435279683816088 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 19.78310568886809 seconds.
# Saving lr to results/20D_unimodal/20D_20K/null_hypothesis/LR_mean_0.009435.json
# ThresholdS: [[0.95, [9500, 500], 1.8960758380004914], [0.99, [9900, 100], 3.5749061220390383]]
# Null distribution computed in 19.94372925697826 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 20000
# LR metric calculation completed in 5.49020234006457 seconds.
# statistic = 3.5463120236565784 - next threshold = 3.5749061220390383 at 0.99 CL
# relative_error_eps = 0.006817378615319649
# relative_error_metric = 0.008030676156085324
# =======> statistic within required accuracy at 0.99 CL in 204.11080227605999 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 408.9601212029811 seconds.
# Saving results in the file results/20D_unimodal/20D_20K/exclusion_limits.json
# Upper bounds for lr with cov_diag deformation already loaded.
# Central bounds for lr with cov_diag deformation already loaded.
# Lower bounds for lr with cov_diag deformation already loaded.
# Upper bounds for lr with cov_off_diag deformation already loaded.
# Central bounds for lr with cov_off_diag deformation already loaded.
# Lower bounds for lr with cov_off_diag deformation already loaded.
# Upper bounds for lr with power_abs_up deformation already loaded.
# Central bounds for lr with power_abs_up deformation already loaded.
# Lower bounds for lr with power_abs_up deformation already loaded.
# Upper bounds for lr with power_abs_down deformation already loaded.
# Central bounds for lr with power_abs_down deformation already loaded.
# Lower bounds for lr with power_abs_down deformation already loaded.
# dict_keys(['fgd_mean_upper_2024-05-20T13:34:32.502083', 'fgd_mean_central_2024-05-20T13:41:46.781959', 'fgd_mean_lower_2024-05-20T13:47:18.292436', 'fgd_cov_diag_upper_2024-05-20T13:52:47.433375', 'fgd_cov_diag_central_2024-05-20T14:02:24.880464', 'fgd_cov_diag_lower_2024-05-20T14:07:51.816256', 'fgd_cov_off_diag_upper_2024-05-20T14:12:26.909324', 'fgd_cov_off_diag_central_2024-05-20T14:21:39.720667', 'fgd_cov_off_diag_lower_2024-05-20T14:26:11.293675', 'fgd_power_abs_up_upper_2024-05-20T14:30:43.296154', 'fgd_power_abs_up_central_2024-05-20T14:39:27.406698', 'fgd_power_abs_up_lower_2024-05-20T14:43:57.862441', 'fgd_power_abs_down_upper_2024-05-20T14:48:48.402230', 'fgd_power_abs_down_central_2024-05-20T14:57:34.805325', 'fgd_power_abs_down_lower_2024-05-20T15:02:08.273299', 'fgd_random_normal_upper_2024-05-20T15:06:58.722412', 'fgd_random_normal_central_2024-05-20T15:12:46.679277', 'fgd_random_normal_lower_2024-05-20T15:16:48.880940', 'fgd_random_uniform_upper_2024-05-20T15:21:08.959211', 'fgd_random_uniform_central_2024-05-20T15:26:21.706789', 'fgd_random_uniform_lower_2024-05-20T15:30:21.356186', 'mmd_mean_upper_2024-05-20T15:34:41.862979', 'mmd_mean_central_2024-05-20T15:44:36.605868', 'mmd_mean_lower_2024-05-20T15:52:30.227726', 'mmd_cov_diag_upper_2024-05-20T16:00:56.115119', 'mmd_cov_diag_central_2024-05-20T16:12:24.551627', 'mmd_cov_diag_lower_2024-05-20T16:20:23.385496', 'mmd_cov_off_diag_upper_2024-05-20T16:28:55.892361', 'mmd_cov_off_diag_central_2024-05-20T16:41:21.993788', 'mmd_cov_off_diag_lower_2024-05-20T16:49:18.700063', 'mmd_power_abs_up_upper_2024-05-20T16:57:16.616565', 'mmd_power_abs_up_central_2024-05-20T17:11:44.044336', 'mmd_power_abs_up_lower_2024-05-20T17:19:41.183822', 'mmd_power_abs_down_upper_2024-05-20T17:28:10.546396', 'mmd_power_abs_down_central_2024-05-20T17:43:13.639875', 'mmd_power_abs_down_lower_2024-05-20T17:51:46.771137', 'mmd_random_normal_upper_2024-05-24T11:48:27.747327', 'mmd_random_normal_central_2024-05-24T11:57:49.191419', 'mmd_random_normal_lower_2024-05-24T12:04:41.137279', 'mmd_random_uniform_upper_2024-05-21T08:33:25.517679', 'mmd_random_uniform_central_2024-05-21T08:42:16.040217', 'mmd_random_uniform_lower_2024-05-21T08:49:08.870937', 'ks_mean_upper_2024-05-21T08:56:32.358530', 'ks_mean_central_2024-05-21T08:59:19.676226', 'ks_mean_lower_2024-05-21T09:00:55.785615', 'ks_cov_diag_upper_2024-05-21T09:02:39.336549', 'ks_cov_diag_central_2024-05-21T09:05:44.754041', 'ks_cov_diag_lower_2024-05-21T09:07:25.467579', 'ks_cov_off_diag_upper_2024-05-21T09:09:06.718050', 'ks_cov_off_diag_central_2024-05-21T09:11:18.127874', 'ks_cov_off_diag_lower_2024-05-21T09:12:17.200913', 'ks_power_abs_up_upper_2024-05-21T09:13:22.715683', 'ks_power_abs_up_central_2024-05-21T09:17:01.074511', 'ks_power_abs_up_lower_2024-05-21T09:18:39.358445', 'ks_power_abs_down_upper_2024-05-21T09:20:25.768364', 'ks_power_abs_down_central_2024-05-21T09:24:04.473804', 'ks_power_abs_down_lower_2024-05-21T09:25:43.199472', 'ks_random_normal_upper_2024-05-21T09:27:23.879937', 'ks_random_normal_central_2024-05-21T09:29:55.281095', 'ks_random_normal_lower_2024-05-21T09:31:33.696766', 'ks_random_uniform_upper_2024-05-21T09:33:17.513099', 'ks_random_uniform_central_2024-05-21T09:35:36.060577', 'ks_random_uniform_lower_2024-05-21T09:37:12.280225', 'sks_mean_upper_2024-05-21T09:38:55.278994', 'sks_mean_central_2024-05-21T09:43:19.824192', 'sks_mean_lower_2024-05-21T09:45:52.330035', 'sks_cov_diag_upper_2024-05-21T09:48:35.191183', 'sks_cov_diag_central_2024-05-21T09:53:28.692451', 'sks_cov_diag_lower_2024-05-21T09:56:06.768199', 'sks_cov_off_diag_upper_2024-05-21T09:58:56.177409', 'sks_cov_off_diag_central_2024-05-21T11:07:22.625405', 'sks_cov_off_diag_lower_2024-05-21T11:12:30.587913', 'sks_power_abs_up_upper_2024-05-21T11:15:08.810850', 'sks_power_abs_up_central_2024-05-21T11:20:34.153696', 'sks_power_abs_up_lower_2024-05-21T11:23:02.138964', 'sks_power_abs_down_upper_2024-05-21T11:25:40.915690', 'sks_power_abs_down_central_2 ...

# %% [markdown]
# ### Show and save results

# %%
# Function to format bounds
def format_bounds(bounds):
    lower, central, upper = bounds
    return f"${central}_{{-{central-lower:.2g}}}^{{+{upper-central:.2g}}}$"

def format_times(times):
    return sum(times)

global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    pippo = global_result
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    bound = global_result["bound"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][1][3], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][2][3], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, bound, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
    "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "t (s)": lambda x: x.tolist()
}).reset_index()
results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
results_df["time"] = results_df["t (s)"]
results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["t (s)"] = results_df["t (s)"].apply(format_times)
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results
# Out:
# [['fgd', 'mean', 20, 10000, 20000, 'upper', 0.11279, 0.13575, 434],
#  ['fgd', 'mean', 20, 10000, 20000, 'central', 0.07185, 0.09756, 331],
#  ['fgd', 'mean', 20, 10000, 20000, 'lower', 0.03983, 0.06712, 329],
#  ['fgd', 'cov_diag', 20, 10000, 20000, 'upper', 0.03699, 0.04486, 577],
#  ['fgd', 'cov_diag', 20, 10000, 20000, 'central', 0.0269, 0.03574, 326],
#  ['fgd', 'cov_diag', 20, 10000, 20000, 'lower', 0.01808, 0.0276, 275],
#  ['fgd', 'cov_off_diag', 20, 10000, 20000, 'upper', 0.00459, 0.0057, 552],
#  ['fgd', 'cov_off_diag', 20, 10000, 20000, 'central', 0.00371, 0.005, 271],
#  ['fgd', 'cov_off_diag', 20, 10000, 20000, 'lower', 0.00271, 0.00419, 271],
#  ['fgd', 'power_abs_up', 20, 10000, 20000, 'upper', 0.00919, 0.01103, 524],
#  ['fgd', 'power_abs_up', 20, 10000, 20000, 'central', 0.00623, 0.00837, 270],
#  ['fgd', 'power_abs_up', 20, 10000, 20000, 'lower', 0.00377, 0.00609, 290],
#  ['fgd', 'power_abs_down', 20, 10000, 20000, 'upper', 0.00943, 0.01139, 526],
#  ['fgd', 'power_abs_down', 20, 10000, 20000, 'central', 0.0067, 0.00886, 273],
#  ['fgd', 'power_abs_down', 20, 10000, 20000, 'lower', 0.00441, 0.00673, 290],
#  ['fgd', 'random_normal', 20, 10000, 20000, 'upper', 0.23535, 0.26149, 347],
#  ['fgd', 'random_normal', 20, 10000, 20000, 'central', 0.21348, 0.24723, 242],
#  ['fgd', 'random_normal', 20, 10000, 20000, 'lower', 0.18301, 0.22817, 260],
#  ['fgd', 'random_uniform', 20, 10000, 20000, 'upper', 0.4082, 0.45328, 312],
#  ['fgd', 'random_uniform', 20, 10000, 20000, 'central', 0.37006, 0.42858, 239],
#  ['fgd', 'random_uniform', 20, 10000, 20000, 'lower', 0.31725, 0.39552, 260],
#  ['mmd', 'mean', 20, 10000, 20000, 'upper', 0.14893, 0.17802, 594],
#  ['mmd', 'mean', 20, 10000, 20000, 'central', 0.08449, 0.11846, 473],
#  ['mmd', 'mean', 20, 10000, 20000, 'lower', 0.03598, 0.07368, 505],
#  ['mmd', 'cov_diag', 20, 10000, 20000, 'upper', 0.05688, 0.06771, 688],
#  ['mmd', 'cov_diag', 20, 10000, 20000, 'central', 0.03081, 0.04364, 478],
#  ['mmd', 'cov_diag', 20, 10000, 20000, 'lower', 0.01257, 0.02653, 512],
#  ['mmd', 'cov_off_diag', 20, 10000, 20000, 'upper', 0.03528, 0.0427, 746],
#  ['mmd', 'cov_off_diag', 20, 10000, 20000, 'central', 0.0216, 0.02992, 476],
#  ['mmd', 'cov_off_diag', 20, 10000, 20000, 'lower', 0.01233, 0.02051, 477],
#  ['mmd', 'power_abs_up', 20, 10000, 20000, 'upper', 0.00906, 0.01073, 867],
#  ['mmd', 'power_abs_up', 20, 10000, 20000, 'central', 0.00488, 0.00687, 477],
#  ['mmd', 'power_abs_up', 20, 10000, 20000, 'lower', 0.00198, 0.00414, 509],
#  ['mmd', 'power_abs_down', 20, 10000, 20000, 'upper', 0.00943, 0.01139, 903],
#  ['mmd', 'power_abs_down', 20, 10000, 20000, 'central', 0.00568, 0.00784, 513],
#  ['mmd', 'power_abs_down', 20, 10000, 20000, 'lower', 0.00317, 0.00534, 508],
#  ['mmd', 'random_normal', 20, 10000, 20000, 'upper', 1.06934, 1.18833, 561],
#  ['mmd', 'random_normal', 20, 10000, 20000, 'central', 0.87964, 1.04846, 411],
#  ['mmd', 'random_normal', 20, 10000, 20000, 'lower', 0.64505, 0.90033, 441],
#  ['mmd', 'random_uniform', 20, 10000, 20000, 'upper', 1.86035, 2.07498, 530],
#  ['mmd', 'random_uniform', 20, 10000, 20000, 'central', 1.53597, 1.81389, 412],
#  ['mmd', 'random_uniform', 20, 10000, 20000, 'lower', 1.11597, 1.54672, 443],
#  ['ks', 'mean', 20, 10000, 20000, 'upper', 0.10345, 0.12677, 167],
#  ['ks', 'mean', 20, 10000, 20000, 'central', 0.06957, 0.09504, 96],
#  ['ks', 'mean', 20, 10000, 20000, 'lower', 0.03731, 0.06324, 103],
#  ['ks', 'cov_diag', 20, 10000, 20000, 'upper', 0.06088, 0.07626, 185],
#  ['ks', 'cov_diag', 20, 10000, 20000, 'central', 0.04632, 0.06199, 100],
#  ['ks', 'cov_diag', 20, 10000, 20000, 'lower', 0.03112, 0.04824, 101],
#  ['ks', 'cov_off_diag', 20, 10000, 20000, 'upper', 1.03027, 1.03221, 131],
#  ['ks', 'cov_off_diag', 20, 10000, 20000, 'central', 1.02012, 1.02919, 59],
#  ['ks', 'cov_off_diag', 20, 10000, 20000, 'lower', 1.01512, 1.02567, 65],
#  ['ks', 'power_abs_up', 20, 10000, 20000, 'upper', 0.01232, 0.01502, 218],
#  ['ks', 'power_abs_up', 20, 10000, 20000, 'central', 0.00901, 0.01206, 98],
#  ['ks', 'power_abs_up', 20, 10000, 20000, 'lower', 0.00558, 0.0089, 106],
#  ['ks', 'power_abs_down', 20, 10000, 20000, 'upper', 0.01247, 0.01518, 218],
#  ['ks', 'power_abs_down', 20, 10000, 20000, 'central', 0.00946, 0.01227, 98],
#  ['ks', 'power_abs_down', 20, 10000, 20000, 'lower', 0.00635, 0.00945, 100],
#  ['ks', 'random_normal', 20, 10000, 20000, 'upper', 0.46509, 0.5293, 151],
#  ['ks', 'random_normal', 20, 10000, 20000, 'central', 0.40421, 0.47653, 98],
#  ['ks', 'random_normal', 20, 10000, 20000, 'lower', 0.32482, 0.41846, 103],
#  ['ks', 'random_uniform', 20, 10000, 20000, 'upper', 0.80322, 0.91388, 138],
#  ['ks', 'random_uniform', 20, 10000, 20000, 'central', 0.69433, 0.8144, 96],
#  ['ks', 'random_uniform', 20, 10000, 20000, 'lower', 0.56149, 0.71363, 102],
#  ['sks', 'mean', 20, 10000, 20000, 'upper', 0.10284, 0.12735, 264],
#  ['sks', 'mean', 20, 10000, 20000, 'central', 0.0699, 0.09548, 152],
#  ['sks', 'mean', 20, 10000, 20000, 'lower', 0.03898, 0.06568, 162],
#  ['sks', 'cov_diag', 20, 10000, 20000, 'upper', 0.05417, 0.06715, 293],
#  ['sks', 'cov_diag', 20, 10000, 20000, 'central', 0.04131, 0.05484, 158],
#  ['sks', 'cov_diag', 20, 10000, 20000, 'lower', 0.0271, 0.04238, 169],
#  ['sks', 'cov_off_diag', 20, 10000, 20000, 'upper', 0.0219, 0.02896, 323],
#  ['sks', 'cov_off_diag', 20, 10000, 20000, 'central', 0.01625, 0.02363, 307],
#  ['sks', 'cov_off_diag', 20, 10000, 20000, 'lower', 0.00992, 0.0179, 158],
#  ['sks', 'power_abs_up', 20, 10000, 20000, 'upper', 0.01019, 0.01243, 325],
#  ['sks', 'power_abs_up', 20, 10000, 20000, 'central', 0.00745, 0.0099, 147],
#  ['sks', 'power_abs_up', 20, 10000, 20000, 'lower', 0.00458, 0.00735, 158],
#  ['sks', 'power_abs_down', 20, 10000, 20000, 'upper', 0.01072, 0.01297, 326],
#  ['sks', 'power_abs_down', 20, 10000, 20000, 'central', 0.00803, 0.01046, 149],
#  ['sks', 'power_abs_down', 20, 10000, 20000, 'lower', 0.00517, 0.00787, 159],
#  ['sks', 'random_normal', 20, 10000, 20000, 'upper', 0.40894, 0.4605, 224],
#  ['sks', 'random_normal', 20, 10000, 20000, 'central', 0.35347, 0.41869, 140],
#  ['sks', 'random_normal', 20, 10000, 20000, 'lower', 0.28376, 0.36282, 153],
#  ['sks', 'random_uniform', 20, 10000, 20000, 'upper', 0.70557, 0.79993, 211],
#  ['sks', 'random_uniform', 20, 10000, 20000, 'central', 0.61401, 0.72149, 142],
#  ['sks', 'random_uniform', 20, 10000, 20000, 'lower', 0.4918, 0.62997, 151],
#  ['swd', 'mean', 20, 10000, 20000, 'upper', 0.10529, 0.13098, 225],
#  ['swd', 'mean', 20, 10000, 20000, 'central', 0.07086, 0.09763, 131],
#  ['swd', 'mean', 20, 10000, 20000, 'lower', 0.03985, 0.06716, 139],
#  ['swd', 'cov_diag', 20, 10000, 20000, 'upper', 0.04227, 0.05271, 257],
#  ['swd', 'cov_diag', 20, 10000, 20000, 'central', 0.03243, 0.04336, 132],
#  ['swd', 'cov_diag', 20, 10000, 20000, 'lower', 0.02227, 0.0343, 136],
#  ['swd', 'cov_off_diag', 20, 10000, 20000, 'upper', 0.02327, 0.03102, 264],
#  ['swd', 'cov_off_diag', 20, 10000, 20000, 'central', 0.01835, 0.02656, 130],
#  ['swd', 'cov_off_diag', 20, 10000, 20000, 'lower', 0.01261, 0.02188, 136],
#  ['swd', 'power_abs_up', 20, 10000, 20000, 'upper', 0.0095, 0.01182, 291],
#  ['swd', 'power_abs_up', 20, 10000, 20000, 'central', 0.00681, 0.00928, 130],
#  ['swd', 'power_abs_up', 20, 10000, 20000, 'lower', 0.00415, 0.00681, 144],
#  ['swd', 'power_abs_down', 20, 10000, 20000, 'upper', 4.98047, 4.99023, 70],
#  ['swd', 'power_abs_down', 20, 10000, 20000, 'central', 0.00748, 0.01003, 303],
#  ['swd', 'power_abs_down', 20, 10000, 20000, 'lower', 0.00492, 0.00761, 140],
#  ['swd', 'random_normal', 20, 10000, 20000, 'upper', 0.40894, 0.46498, 204],
#  ['swd', 'random_normal', 20, 10000, 20000, 'central', 0.36054, 0.42418, 126],
#  ['swd', 'random_normal', 20, 10000, 20000, 'lower', 0.29742, 0.37962, 141],
#  ['swd', 'random_uniform', 20, 10000, 20000, 'upper', 0.71045, 0.80889, 190],
#  ['swd', 'random_uniform', 20, 10000, 20000, 'central', 0.62405, 0.73669, 128],
#  ['swd', 'random_uniform', 20, 10000, 20000, 'lower', 0.51942, 0.6603, 139],
#  ['lr', 'mean', 20, 10000, 20000, 'upper', 0.01509, 0.01865, 514],
#  ['lr', 'mean', 20, 10000, 20000, 'central', 0.01053, 0.01415, 382],
#  ['lr', 'mean', 20, 10000, 20000, 'lower', 0.00589, 0.00947, 408],
#  ['lr', 'cov_diag', 20, 10000, 20000, 'upper', 0.00387, 0.00488, 628],
#  ['lr', 'cov_diag', 20, 10000, 20000, 'central', 0.00253, 0.00353, 420],
#  ['lr', 'cov_diag', 20, 10000, 20000, 'lower', 0.00117, 0.00218, 455],
#  ['lr', 'cov_off_diag', 20, 10000, 20000, 'upper', 0.00017, 0.00022, 991],
#  ['lr', 'cov_off_diag', 20, 10000, 20000, 'central', 0.00011, 0.00015, 477],
#  ['lr', 'cov_off_diag', 20, 10000, 20000, 'lower', 4e-05, 9e-05, 516],
#  ['lr', 'power_abs_up', 20, 10000, 20000, 'upper', 0.00109, 0.00137, 747],
#  ['lr', 'power_abs_up', 20, 10000, 20000, 'central', 0.00069, 0.00098, 427],
#  ['lr', 'power_abs_up', 20, 10000, 20000, 'lower', 0.00029, 0.00058, 453],
#  ['lr', 'power_abs_down', 20, 10000, 20000, 'upper', 0.00101, 0.00129, 746],
#  ['lr', 'power_abs_down', 20, 10000, 20000, 'central', 0.00061, 0.0009, 425],
#  ['lr', 'power_abs_down', 20, 10000, 20000, 'lower', 0.00021, 0.0005, 480]]

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
sorted_df_mean = results_df_mean.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_mean)
# Out:
# /tmp/ipykernel_2066063/2349835371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 16        lr        mean   20  10000                20000
# 9         ks        mean   20  10000                20000
# 28       sks        mean   20  10000                20000
# 35       swd        mean   20  10000                20000
# 2        fgd        mean   20  10000                20000
# 21       mmd        mean   20  10000                20000
#
#    $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 16      $0.01053_{-0.0046}^{+0.0046}$      $0.01415_{-0.0047}^{+0.0045}$
# 9         $0.06957_{-0.032}^{+0.034}$        $0.09504_{-0.032}^{+0.032}$
# 28         $0.0699_{-0.031}^{+0.033}$         $0.09548_{-0.03}^{+0.032}$
# 35        $0.07086_{-0.031}^{+0.034}$         $0.09763_{-0.03}^{+0.033}$
# 2         $0.07185_{-0.032}^{+0.041}$         $0.09756_{-0.03}^{+0.038}$
# 21        $0.08449_{-0.049}^{+0.064}$         $0.11846_{-0.045}^{+0.06}$
#
#     $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 16           1304  [0.00589, 0.01053, 0.01509]  [0.00947, 0.01415, 0.01865]
# 9             366  [0.03731, 0.06957, 0.10345]  [0.06324, 0.09504, 0.12677]
# 28            578   [0.03898, 0.0699, 0.10284]  [0.06568, 0.09548, 0.12735]
# 35            495  [0.03985, 0.07086, 0.10529]  [0.06716, 0.09763, 0.13098]
# 2            1094  [0.03983, 0.07185, 0.11279]  [0.06712, 0.09756, 0.13575]
# 21           1572  [0.03598, 0.08449, 0.14893]  [0.07368, 0.11846, 0.17802]
#
#                time
# 16  [514, 382, 408]
# 9    [167, 96, 103]
# 28  [264, 152, 162]
# 35  [225, 131, 139]
# 2   [434, 331, 329]
# 21  [594, 473, 505]
#    Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 16        lr      $0.01053_{-0.0046}^{+0.0046}$
# 9         ks        $0.06957_{-0.032}^{+0.034}$
# 28       sks         $0.0699_{-0.031}^{+0.033}$
# 35       swd        $0.07086_{-0.031}^{+0.034}$
# 2        fgd        $0.07185_{-0.032}^{+0.041}$
# 21       mmd        $0.08449_{-0.049}^{+0.064}$
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 16      $0.01415_{-0.0047}^{+0.0045}$           1304
# 9         $0.09504_{-0.032}^{+0.032}$            366
# 28         $0.09548_{-0.03}^{+0.032}$            578
# 35         $0.09763_{-0.03}^{+0.033}$            495
# 2          $0.09756_{-0.03}^{+0.038}$           1094
# 21         $0.11846_{-0.045}^{+0.06}$           1572

# %%
results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_diag)
# Out:
# /tmp/ipykernel_2066063/2882134307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 14        lr    cov_diag   20  10000                20000
# 0        fgd    cov_diag   20  10000                20000
# 19       mmd    cov_diag   20  10000                20000
# 33       swd    cov_diag   20  10000                20000
# 26       sks    cov_diag   20  10000                20000
# 7         ks    cov_diag   20  10000                20000
#
#    $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 14              $0.00253_{-0.0014}^{+0.0013}$
# 0                  $0.0269_{-0.0088}^{+0.01}$
# 19                $0.03081_{-0.018}^{+0.026}$
# 33                $0.03243_{-0.01}^{+0.0098}$
# 26                $0.04131_{-0.014}^{+0.013}$
# 7                 $0.04632_{-0.015}^{+0.015}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)  \
# 14              $0.00353_{-0.0014}^{+0.0013}$                   1503
# 0               $0.03574_{-0.0081}^{+0.0091}$                   1178
# 19                $0.04364_{-0.017}^{+0.024}$                   1678
# 33              $0.04336_{-0.0091}^{+0.0093}$                    525
# 26                $0.05484_{-0.012}^{+0.012}$                    620
# 7                 $0.06199_{-0.014}^{+0.014}$                    386
#
#                           95%CL                        99%CL             time
# 14  [0.00117, 0.00253, 0.00387]  [0.00218, 0.00353, 0.00488]  [628, 420, 455]
# 0    [0.01808, 0.0269, 0.03699]   [0.0276, 0.03574, 0.04486]  [577, 326, 275]
# 19  [0.01257, 0.03081, 0.05688]  [0.02653, 0.04364, 0.06771]  [688, 478, 512]
# 33  [0.02227, 0.03243, 0.04227]   [0.0343, 0.04336, 0.05271]  [257, 132, 136]
# 26   [0.0271, 0.04131, 0.05417]  [0.04238, 0.05484, 0.06715]  [293, 158, 169]
# 7   [0.03112, 0.04632, 0.06088]  [0.04824, 0.06199, 0.07626]  [185, 100, 101]
#    Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 14        lr              $0.00253_{-0.0014}^{+0.0013}$
# 0        fgd                 $0.0269_{-0.0088}^{+0.01}$
# 19       mmd                $0.03081_{-0.018}^{+0.026}$
# 33       swd                $0.03243_{-0.01}^{+0.0098}$
# 26       sks                $0.04131_{-0.014}^{+0.013}$
# 7         ks                $0.04632_{-0.015}^{+0.015}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)
# 14              $0.00353_{-0.0014}^{+0.0013}$                   1503
# 0               $0.03574_{-0.0081}^{+0.0091}$                   1178
# 19                $0.04364_{-0.017}^{+0.024}$                   1678
# 33              $0.04336_{-0.0091}^{+0.0093}$                    525
# 26                $0.05484_{-0.012}^{+0.012}$                    620
# 7                 $0.06199_{-0.014}^{+0.014}$                    386

# %%
results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
# /tmp/ipykernel_2066063/3376285218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 15        lr  cov_off_diag   20  10000                20000
# 1        fgd  cov_off_diag   20  10000                20000
# 27       sks  cov_off_diag   20  10000                20000
# 34       swd  cov_off_diag   20  10000                20000
# 20       mmd  cov_off_diag   20  10000                20000
# 8         ks  cov_off_diag   20  10000                20000
#
#    $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 15                     $0.00011_{-7e-05}^{+6e-05}$
# 1                    $0.00371_{-0.001}^{+0.00088}$
# 27                   $0.01625_{-0.0063}^{+0.0056}$
# 34                   $0.01835_{-0.0057}^{+0.0049}$
# 20                     $0.0216_{-0.0093}^{+0.014}$
# 8                       $1.02012_{-0.005}^{+0.01}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 15                     $0.00015_{-6e-05}^{+7e-05}$
# 1                     $0.005_{-0.00081}^{+0.0007}$
# 27                   $0.02363_{-0.0057}^{+0.0053}$
# 34                   $0.02656_{-0.0047}^{+0.0045}$
# 20                    $0.02992_{-0.0094}^{+0.013}$
# 8                     $1.02919_{-0.0035}^{+0.003}$
#
#     $t^{\Sigma_{i\neq j}}$ (s)                        95%CL  \
# 15                        1984    [4e-05, 0.00011, 0.00017]
# 1                         1094  [0.00271, 0.00371, 0.00459]
# 27                         788   [0.00992, 0.01625, 0.0219]
# 34                         530  [0.01261, 0.01835, 0.02327]
# 20                        1699   [0.01233, 0.0216, 0.03528]
# 8                          255  [1.01512, 1.02012, 1.03027]
#
#                           99%CL             time
# 15    [9e-05, 0.00015, 0.00022]  [991, 477, 516]
# 1      [0.00419, 0.005, 0.0057]  [552, 271, 271]
# 27   [0.0179, 0.02363, 0.02896]  [323, 307, 158]
# 34  [0.02188, 0.02656, 0.03102]  [264, 130, 136]
# 20   [0.02051, 0.02992, 0.0427]  [746, 476, 477]
# 8   [1.02567, 1.02919, 1.03221]    [131, 59, 65]
#    Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 15        lr                     $0.00011_{-7e-05}^{+6e-05}$
# 1        fgd                   $0.00371_{-0.001}^{+0.00088}$
# 27       sks                   $0.01625_{-0.0063}^{+0.0056}$
# 34       swd                   $0.01835_{-0.0057}^{+0.0049}$
# 20       mmd                     $0.0216_{-0.0093}^{+0.014}$
# 8         ks                      $1.02012_{-0.005}^{+0.01}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)
# 15                     $0.00015_{-6e-05}^{+7e-05}$                        1984
# 1                     $0.005_{-0.00081}^{+0.0007}$                        1094
# 27                   $0.02363_{-0.0057}^{+0.0053}$                         788
# 34                   $0.02656_{-0.0047}^{+0.0045}$                         530
# 20                    $0.02992_{-0.0094}^{+0.013}$                        1699
# 8                     $1.02919_{-0.0035}^{+0.003}$                         255

# %%
results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
# /tmp/ipykernel_2066063/2976661110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 18        lr  power_abs_up   20  10000                20000
# 23       mmd  power_abs_up   20  10000                20000
# 4        fgd  power_abs_up   20  10000                20000
# 37       swd  power_abs_up   20  10000                20000
# 30       sks  power_abs_up   20  10000                20000
# 11        ks  power_abs_up   20  10000                20000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 18               $0.00069_{-0.0004}^{+0.0004}$
# 23               $0.00488_{-0.0029}^{+0.0042}$
# 4                 $0.00623_{-0.0025}^{+0.003}$
# 37               $0.00681_{-0.0027}^{+0.0027}$
# 30               $0.00745_{-0.0029}^{+0.0027}$
# 11               $0.00901_{-0.0034}^{+0.0033}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)  \
# 18              $0.00098_{-0.0004}^{+0.00039}$                    1627
# 23               $0.00687_{-0.0027}^{+0.0039}$                    1853
# 4                $0.00837_{-0.0023}^{+0.0027}$                    1084
# 37               $0.00928_{-0.0025}^{+0.0025}$                     565
# 30                $0.0099_{-0.0026}^{+0.0025}$                     630
# 11                $0.01206_{-0.0032}^{+0.003}$                     422
#
#                           95%CL                        99%CL             time
# 18  [0.00029, 0.00069, 0.00109]  [0.00058, 0.00098, 0.00137]  [747, 427, 453]
# 23  [0.00198, 0.00488, 0.00906]  [0.00414, 0.00687, 0.01073]  [867, 477, 509]
# 4   [0.00377, 0.00623, 0.00919]  [0.00609, 0.00837, 0.01103]  [524, 270, 290]
# 37   [0.00415, 0.00681, 0.0095]  [0.00681, 0.00928, 0.01182]  [291, 130, 144]
# 30  [0.00458, 0.00745, 0.01019]   [0.00735, 0.0099, 0.01243]  [325, 147, 158]
# 11  [0.00558, 0.00901, 0.01232]   [0.0089, 0.01206, 0.01502]   [218, 98, 106]
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 18        lr               $0.00069_{-0.0004}^{+0.0004}$
# 23       mmd               $0.00488_{-0.0029}^{+0.0042}$
# 4        fgd                $0.00623_{-0.0025}^{+0.003}$
# 37       swd               $0.00681_{-0.0027}^{+0.0027}$
# 30       sks               $0.00745_{-0.0029}^{+0.0027}$
# 11        ks               $0.00901_{-0.0034}^{+0.0033}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 18              $0.00098_{-0.0004}^{+0.00039}$                    1627
# 23               $0.00687_{-0.0027}^{+0.0039}$                    1853
# 4                $0.00837_{-0.0023}^{+0.0027}$                    1084
# 37               $0.00928_{-0.0025}^{+0.0025}$                     565
# 30                $0.0099_{-0.0026}^{+0.0025}$                     630
# 11                $0.01206_{-0.0032}^{+0.003}$                     422

# %%
results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
# /tmp/ipykernel_2066063/1061777215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 17        lr  power_abs_down   20  10000                20000
# 22       mmd  power_abs_down   20  10000                20000
# 3        fgd  power_abs_down   20  10000                20000
# 36       swd  power_abs_down   20  10000                20000
# 29       sks  power_abs_down   20  10000                20000
# 10        ks  power_abs_down   20  10000                20000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 17               $0.00061_{-0.0004}^{+0.0004}$
# 22               $0.00568_{-0.0025}^{+0.0037}$
# 3                 $0.0067_{-0.0023}^{+0.0027}$
# 36                    $0.00748_{-0.0026}^{+5}$
# 29               $0.00803_{-0.0029}^{+0.0027}$
# 10                $0.00946_{-0.0031}^{+0.003}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)  \
# 17               $0.0009_{-0.0004}^{+0.00039}$                    1651
# 22               $0.00784_{-0.0025}^{+0.0036}$                    1924
# 3                $0.00886_{-0.0021}^{+0.0025}$                    1089
# 36                    $0.01003_{-0.0024}^{+5}$                     513
# 29               $0.01046_{-0.0026}^{+0.0025}$                     634
# 10               $0.01227_{-0.0028}^{+0.0029}$                     416
#
#                           95%CL                        99%CL             time
# 17  [0.00021, 0.00061, 0.00101]    [0.0005, 0.0009, 0.00129]  [746, 425, 480]
# 22  [0.00317, 0.00568, 0.00943]  [0.00534, 0.00784, 0.01139]  [903, 513, 508]
# 3    [0.00441, 0.0067, 0.00943]  [0.00673, 0.00886, 0.01139]  [526, 273, 290]
# 36  [0.00492, 0.00748, 4.98047]  [0.00761, 0.01003, 4.99023]   [70, 303, 140]
# 29  [0.00517, 0.00803, 0.01072]  [0.00787, 0.01046, 0.01297]  [326, 149, 159]
# 10  [0.00635, 0.00946, 0.01247]  [0.00945, 0.01227, 0.01518]   [218, 98, 100]
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 17        lr               $0.00061_{-0.0004}^{+0.0004}$
# 22       mmd               $0.00568_{-0.0025}^{+0.0037}$
# 3        fgd                $0.0067_{-0.0023}^{+0.0027}$
# 36       swd                    $0.00748_{-0.0026}^{+5}$
# 29       sks               $0.00803_{-0.0029}^{+0.0027}$
# 10        ks                $0.00946_{-0.0031}^{+0.003}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 17               $0.0009_{-0.0004}^{+0.00039}$                    1651
# 22               $0.00784_{-0.0025}^{+0.0036}$                    1924
# 3                $0.00886_{-0.0021}^{+0.0025}$                    1089
# 36                    $0.01003_{-0.0024}^{+5}$                     513
# 29               $0.01046_{-0.0026}^{+0.0025}$                     634
# 10               $0.01227_{-0.0028}^{+0.0029}$                     416

# %%
results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_normal = results_df_random_normal.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_normal)
# Out:
# /tmp/ipykernel_2066063/3420336598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        fgd  random_normal   20  10000                20000
# 31       sks  random_normal   20  10000                20000
# 38       swd  random_normal   20  10000                20000
# 12        ks  random_normal   20  10000                20000
# 24       mmd  random_normal   20  10000                20000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                  $0.21348_{-0.03}^{+0.022}$
# 31                 $0.35347_{-0.07}^{+0.055}$
# 38                $0.36054_{-0.063}^{+0.048}$
# 12                $0.40421_{-0.079}^{+0.061}$
# 24                  $0.87964_{-0.23}^{+0.19}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)  \
# 5                 $0.24723_{-0.019}^{+0.014}$                    849
# 31                $0.41869_{-0.056}^{+0.042}$                    517
# 38                $0.42418_{-0.045}^{+0.041}$                    471
# 12                $0.47653_{-0.058}^{+0.053}$                    352
# 24                  $1.04846_{-0.15}^{+0.14}$                   1413
#
#                           95%CL                        99%CL             time
# 5   [0.18301, 0.21348, 0.23535]  [0.22817, 0.24723, 0.26149]  [347, 242, 260]
# 31  [0.28376, 0.35347, 0.40894]   [0.36282, 0.41869, 0.4605]  [224, 140, 153]
# 38  [0.29742, 0.36054, 0.40894]  [0.37962, 0.42418, 0.46498]  [204, 126, 141]
# 12  [0.32482, 0.40421, 0.46509]   [0.41846, 0.47653, 0.5293]   [151, 98, 103]
# 24  [0.64505, 0.87964, 1.06934]  [0.90033, 1.04846, 1.18833]  [561, 411, 441]
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        fgd                 $0.21348_{-0.03}^{+0.022}$
# 31       sks                 $0.35347_{-0.07}^{+0.055}$
# 38       swd                $0.36054_{-0.063}^{+0.048}$
# 12        ks                $0.40421_{-0.079}^{+0.061}$
# 24       mmd                  $0.87964_{-0.23}^{+0.19}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                 $0.24723_{-0.019}^{+0.014}$                    849
# 31                $0.41869_{-0.056}^{+0.042}$                    517
# 38                $0.42418_{-0.045}^{+0.041}$                    471
# 12                $0.47653_{-0.058}^{+0.053}$                    352
# 24                  $1.04846_{-0.15}^{+0.14}$                   1413

# %%
results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_uniform)
# Out:
# /tmp/ipykernel_2066063/3647480920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform   20  10000                20000
# 13        ks  random_uniform   20  10000                20000
# 25       mmd  random_uniform   20  10000                20000
# 32       sks  random_uniform   20  10000                20000
# 39       swd  random_uniform   20  10000                20000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                 $0.37006_{-0.053}^{+0.038}$
# 13                  $0.69433_{-0.13}^{+0.11}$
# 25                  $1.53597_{-0.42}^{+0.32}$
# 32                 $0.61401_{-0.12}^{+0.092}$
# 39                  $0.62405_{-0.1}^{+0.086}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)  \
# 6                 $0.42858_{-0.033}^{+0.025}$                    811
# 13                   $0.8144_{-0.1}^{+0.099}$                    336
# 25                  $1.81389_{-0.27}^{+0.26}$                   1385
# 32                $0.72149_{-0.092}^{+0.078}$                    504
# 39                $0.73669_{-0.076}^{+0.072}$                    457
#
#                           95%CL                        99%CL             time
# 6    [0.31725, 0.37006, 0.4082]  [0.39552, 0.42858, 0.45328]  [312, 239, 260]
# 13  [0.56149, 0.69433, 0.80322]   [0.71363, 0.8144, 0.91388]   [138, 96, 102]
# 25  [1.11597, 1.53597, 1.86035]  [1.54672, 1.81389, 2.07498]  [530, 412, 443]
# 32   [0.4918, 0.61401, 0.70557]  [0.62997, 0.72149, 0.79993]  [211, 142, 151]
# 39  [0.51942, 0.62405, 0.71045]   [0.6603, 0.73669, 0.80889]  [190, 128, 139]
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                $0.37006_{-0.053}^{+0.038}$
# 13        ks                  $0.69433_{-0.13}^{+0.11}$
# 25       mmd                  $1.53597_{-0.42}^{+0.32}$
# 32       sks                 $0.61401_{-0.12}^{+0.092}$
# 39       swd                  $0.62405_{-0.1}^{+0.086}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                 $0.42858_{-0.033}^{+0.025}$                    811
# 13                   $0.8144_{-0.1}^{+0.099}$                    336
# 25                  $1.81389_{-0.27}^{+0.26}$                   1385
# 32                $0.72149_{-0.092}^{+0.078}$                    504
# 39                $0.73669_{-0.076}^{+0.072}$                    457

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(sorted_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule\nStatistic",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\\nStatistic")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule\nStatistic",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\\nStatistic")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
string = string.replace("\n","\n\t\t")
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# 		\toprule
# 		\multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# 		\multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# 		Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# 		\midrule
# 		$d_{\mathrm{FGD}_{\infty}}$ & $0.07185_{-0.032}^{+0.041}$ & $0.09756_{-0.03}^{+0.038}$ & 1094 & $0.0269_{-0.0088}^{+0.01}$ & $0.03574_{-0.0081}^{+0.0091}$ & 1178 & $0.00371_{-0.001}^{+0.00088}$ & $0.005_{-0.00081}^{+0.0007}$ & 1094 & $0.00623_{-0.0025}^{+0.003}$ & $0.00837_{-0.0023}^{+0.0027}$ & 1084 \\
# 		$\overline{D}$ & $0.06957_{-0.032}^{+0.034}$ & $0.09504_{-0.032}^{+0.032}$ & 366 & $0.04632_{-0.015}^{+0.015}$ & $0.06199_{-0.014}^{+0.014}$ & 386 & $1.02012_{-0.005}^{+0.01}$ & $1.02919_{-0.0035}^{+0.003}$ & 255 & $0.00901_{-0.0034}^{+0.0033}$ & $0.01206_{-0.0032}^{+0.003}$ & 422 \\
# 		$t_{\mathrm{LLR}}$ & $0.01053_{-0.0046}^{+0.0046}$ & $0.01415_{-0.0047}^{+0.0045}$ & 1304 & $0.00253_{-0.0014}^{+0.0013}$ & $0.00353_{-0.0014}^{+0.0013}$ & 1503 & $0.00011_{-7e-05}^{+6e-05}$ & $0.00015_{-6e-05}^{+7e-05}$ & 1984 & $0.00069_{-0.0004}^{+0.0004}$ & $0.00098_{-0.0004}^{+0.00039}$ & 1627 \\
# 		$d_{\mathrm{MMD}^{2}_{u}}$ & $0.08449_{-0.049}^{+0.064}$ & $0.11846_{-0.045}^{+0.06}$ & 1572 & $0.03081_{-0.018}^{+0.026}$ & $0.04364_{-0.017}^{+0.024}$ & 1678 & $0.0216_{-0.0093}^{+0.014}$ & $0.02992_{-0.0094}^{+0.013}$ & 1699 & $0.00488_{-0.0029}^{+0.0042}$ & $0.00687_{-0.0027}^{+0.0039}$ & 1853 \\
# 		$\widetilde{D}$ & $0.0699_{-0.031}^{+0.033}$ & $0.09548_{-0.03}^{+0.032}$ & 578 & $0.04131_{-0.014}^{+0.013}$ & $0.05484_{-0.012}^{+0.012}$ & 620 & $0.01625_{-0.0063}^{+0.0056}$ & $0.02363_{-0.0057}^{+0.0053}$ & 788 & $0.00745_{-0.0029}^{+0.0027}$ & $0.0099_{-0.0026}^{+0.0025}$ & 630 \\
# 		$\widetilde{W}$ & $0.07086_{-0.031}^{+0.034}$ & $0.09763_{-0.03}^{+0.033}$ & 495 & $0.03243_{-0.01}^{+0.0098}$ & $0.04336_{-0.0091}^{+0.0093}$ & 525 & $0.01835_{-0.0057}^{+0.0049}$ & $0.02656_{-0.0047}^{+0.0045}$ & 530 & $0.00681_{-0.0027}^{+0.0027}$ & $0.00928_{-0.0025}^{+0.0025}$ & 565 \\
# 		\toprule
# 		\multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# 		Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# 		\midrule
# 		$d_{\mathrm{FGD}_{\infty}}$ & $0.0067_{-0.0023}^{+0.0027}$ & $0.00886_{-0.0021}^{+0.0025}$ & 1089 & $0.21348_{-0.03}^{+0.022}$ & $0.24723_{-0.019}^{+0.014}$ & 8.5e+02 & $0.37006_{-0.053}^{+0.038}$ & $0.42858_{-0.033}^{+0.025}$ & 8.1e+02 & 1150 \\
# 		$\overline{D}$ & $0.00946_{-0.0031}^{+0.003}$ & $0.01227_{-0.0028}^{+0.0029}$ & 416 & $0.40421_{-0.079}^{+0.061}$ & $0.47653_{-0.058}^{+0.053}$ & 3.5e+02 & $0.69433_{-0.13}^{+0.11}$ & $0.8144_{-0.1}^{+0.099}$ & 3.4e+02 & 108 \\
# 		$t_{\mathrm{LLR}}$ & $0.00061_{-0.0004}^{+0.0004}$ & $0.0009_{-0.0004}^{+0.00039}$ & 1651 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# 		$d_{\mathrm{MMD}^{2}_{u}}$ & $0.00568_{-0.0025}^{+0.0037}$ & $0.00784_{-0.0025}^{+0.0036}$ & 1924 & $0.87964_{-0.23}^{+0.19}$ & $1.04846_{-0.15}^{+0.14}$ & 1.4e+03 & $1.53597_{-0.42}^{+0.32}$ & $1.81389_{-0.27}^{+0.26}$ & 1.4e+03 & 2284 \\
# 		$\widetilde{D}$ & $0.00803_{-0.0029}^{+0.0027}$ & $0.01046_{-0.0026}^{+0.0025}$ & 634 & $0.35347_{-0.07}^{+0.055}$ & $0.41869_{-0.056}^{+0.042}$ & 5.2e+02 & $0.61401_{-0.12}^{+0.092}$ & $0.72149_{-0.092}^{+0.078}$ & 5e+02 & 398 \\
# 		$\widetilde{W}$ & $0.00748_{-0.0026}^{+5}$ & $0.01003_{-0.0024}^{+5}$ & 513 & $0.36054_{-0.063}^{+0.048}$ & $0.42418_{-0.045}^{+0.041}$ & 4.7e+02 & $0.62405_{-0.1}^{+0.086}$ & $0.73669_{-0.076}^{+0.072}$ & 4.6e+02 & 276 \\
# 		\bottomrule
# 		\end{tabular}
