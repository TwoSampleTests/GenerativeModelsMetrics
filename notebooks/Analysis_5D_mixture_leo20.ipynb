# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/5D_mixture/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-27 20:19:19.108753: Importing os...
# 2024-04-27 20:19:19.108929: Importing sys...
# Visible devices: [1]
# 2024-04-27 20:19:19.109166: Importing timer from timeit...
# 2024-04-27 20:19:19.109234: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-04-27 20:19:19.109362: Importing numpy...
# 2024-04-27 20:19:19.228131: Importing matplotlib...
# 2024-04-27 20:19:19.582750: Importing h5py...
# 2024-04-27 20:19:19.609643: Importing importlib.util...
# 2024-04-27 20:19:19.609754: Importing json...
# 2024-04-27 20:19:19.609821: Importing pandas...
# 2024-04-27 20:19:20.095498: Importing random...
# 2024-04-27 20:19:20.095632: Importing scipy utils...
# 2024-04-27 20:19:20.520640: Importing subprocess...
# 2024-04-27 20:19:20.520773: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-27 20:19:23.831514: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-27 20:19:24.999621: Importing timeit...
# 2024-04-27 20:19:24.999716: Importing tqdm...
# 2024-04-27 20:19:25.007297: Importing typing...
# 2024-04-27 20:19:25.007401: Setting tf configs...
# 2024-04-27 20:19:25.118057: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-27 20:19:30.127002: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-04-27 20:19:30.156848: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
dist_1 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
dist_2 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture.Mixture'> <class 'tensorflow_probability.python.distributions.mixture.Mixture'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 10_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True        5           0  float64     5  200000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 100,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 10_000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 10_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1/1_000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 1/1_000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2000,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10_000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 10000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1/1_000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 10,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 10000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 2000,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fgd from results/5D_mixture/5D_20K/null_hypothesis/FGD.json
# Loading mmd from results/5D_mixture/5D_20K/null_hypothesis/MMD.json
# Loading ks from results/5D_mixture/5D_20K/null_hypothesis/KS.json
# Loading sks from results/5D_mixture/5D_20K/null_hypothesis/SKS.json
# Loading swd from results/5D_mixture/5D_20K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 2461.8054417608414], [0.95, [9500, 500], 6653.746806468777], [0.99, [9900, 100], 10337.70942747079]]
# Computing time for metric fgd: 382.93505613692105
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 2.1956523303941824e-05], [0.95, [9500, 500], 0.00029238202043111984], [0.99, [9900, 100], 0.0005357047121198093]]
# Computing time for metric mmd: 954.4420203969348
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9230020642280578], [0.95, [9500, 500], 1.167001724243164], [0.99, [9900, 100], 1.3409990072250366]]
# Computing time for metric ks: 41.05420617805794
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9172504767775536], [0.95, [9500, 500], 1.172300335019827], [0.99, [9900, 100], 1.358750369399786]]
# Computing time for metric sks: 384.00181815598626
# ThresholdS for metric swd: [[0.68, [6800, 3199], 1.0304382303304764], [0.95, [9500, 500], 1.5704415986452431], [0.99, [9900, 100], 1.9548155201110047]]
# Computing time for metric swd: 288.6735754099209
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f962159ff60>             lambda ns, ndims: 10_000
# 1  <function <lambda> at 0x7f9541e28180>            lambda ns, ndims: 1/1_000
# 2  <function <lambda> at 0x7f9541e28220>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f9541e282c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f9541e28360>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f9541e28400>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...             10
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...           2000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_mixture/5D_20K/null_hypothesis/FGD....
# 1  $d_{\mathrm{MMD}}$  results/5D_mixture/5D_20K/null_hypothesis/MMD....
# 2      $\overline{D}$  results/5D_mixture/5D_20K/null_hypothesis/KS.json
# 3     $\widetilde{D}$  results/5D_mixture/5D_20K/null_hypothesis/SKS....
# 4     $\widetilde{W}$  results/5D_mixture/5D_20K/null_hypothesis/SWD....
# 5           $t_{\mu}$  results/5D_mixture/5D_20K/null_hypothesis/LR.json
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 2461.8054417608414], [0....
# 1  [[0.68, [6800, 3199], 2.1956523303941824e-05],...
# 2  [[0.68, [6800, 3199], 0.9230020642280578], [0....
# 3  [[0.68, [6800, 3199], 0.9172504767775536], [0....
# 4  [[0.68, [6800, 3199], 1.0304382303304764], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{4})$"
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{3})$"
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 2015.4861539624933 +/- 55513.53111371603
# sigma = 2356.1309622709014 +/- 25.733688850277314
# 68%CL = 2461.8054417608414, 95%CL = 6653.746806468777, 99%CL = 10337.70942747079
# mu = 2015.4861539624933 +/- 55513.53111371603
# sigma = 2356.1309622709014 +/- 25.733688850277314
# /tmp/ipykernel_304205/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_304205/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_304205/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.5118578819092363 seconds.
# mu = -4.601119826220957e-08 +/- 2.28544169458115e-10
# sigma = 0.00015117677383054415 +/- 2.346549712361359e-06
# 68%CL = 2.1956523303941824e-05, 95%CL = 0.00029238202043111984, 99%CL = 0.0005357047121198093
# mu = -4.601119826220957e-08 +/- 2.28544169458115e-10
# sigma = 0.00015117677383054415 +/- 2.346549712361359e-06
# /tmp/ipykernel_304205/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_304205/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_304205/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9069064189679921 seconds.
# mu = 0.8698913754150271 +/- 0.000255935765751625
# sigma = 0.15997992553805773 +/- 0.0014339753418919092
# 68%CL = 0.9230020642280578, 95%CL = 1.167001724243164, 99%CL = 1.3409990072250366
# mu = 0.8698913754150271 +/- 0.000255935765751625
# sigma = 0.15997992553805773 +/- 0.0014339753418919092
# /tmp/ipykernel_304205/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_304205/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_304205/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_304205/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2978394218953326 seconds.
# mu = 0.8694752944866195 +/- 0.000260115224206859
# sigma = 0.161280880518076 +/- 0.001555320380770133
# 68%CL = 0.9172504767775536, 95%CL = 1.172300335019827, 99%CL = 1.358750369399786
# mu = 0.8694752944866195 +/- 0.000260115224206859
# sigma = 0.161280880518076 +/- 0.001555320380770133
# /tmp/ipykernel_304205/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_304205/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_304205/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_304205/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.300396368955262 seconds.
# mu = 0.9308255663811473 +/- 0.0010998466121362833
# sigma = 0.3316393541388421 +/- 0.0030558968111021457
# 68%CL = 1.0304382303304764, 95%CL = 1.5704415986452431, 99%CL = 1.9548155201110047
# mu = 0.9308255663811473 +/- 0.0010998466121362833
# sigma = 0.3316393541388421 +/- 0.0030558968111021457
# /tmp/ipykernel_304205/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_304205/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_304205/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_304205/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.8813138949917629 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f962159ff60>             lambda ns, ndims: 10_000
# 1  <function <lambda> at 0x7f9541e28180>            lambda ns, ndims: 1/1_000
# 2  <function <lambda> at 0x7f9541e28220>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f9541e282c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f9541e28360>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f9541e28400>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...             10
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...           2000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_mixture/5D_20K/null_hypothesis/FGD....
# 1  $d_{\mathrm{MMD}}$  results/5D_mixture/5D_20K/null_hypothesis/MMD....
# 2      $\overline{D}$  results/5D_mixture/5D_20K/null_hypothesis/KS.json
# 3     $\widetilde{D}$  results/5D_mixture/5D_20K/null_hypothesis/SKS....
# 4     $\widetilde{W}$  results/5D_mixture/5D_20K/null_hypothesis/SWD....
# 5           $t_{\mu}$  results/5D_mixture/5D_20K/null_hypothesis/LR.json
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 2461.8054417608414], [0....
# 1  [[0.68, [6800, 3199], 2.1956523303941824e-05],...
# 2  [[0.68, [6800, 3199], 0.9230020642280578], [0....
# 3  [[0.68, [6800, 3199], 0.9172504767775536], [0....
# 4  [[0.68, [6800, 3199], 1.0304382303304764], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/5D_mixture/5D_20K/null_hypothesis/FGD.pdf
# 1  results/5D_mixture/5D_20K/null_hypothesis/MMD.pdf
# 2   results/5D_mixture/5D_20K/null_hypothesis/KS.pdf
# 3  results/5D_mixture/5D_20K/null_hypothesis/SKS.pdf
# 4  results/5D_mixture/5D_20K/null_hypothesis/SWD.pdf
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 10000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normnal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = mean
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714242188.224039  304205 service.cc:145] XLA service 0xbfeefed0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714242188.224084  304205 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1714242188.283390  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1714242188.287568  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1714242188.288601  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1714242188.288958  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1714242188.289970  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1714242188.290046  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1714242188.290117  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1714242188.290189  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1714242188.290261  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1714242188.290331  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1714242188.290402  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1714242188.290473  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1714242191.529016  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1714242191.529461  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1714242191.529561  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1714242191.529599  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1714242191.529693  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1714242191.529702  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1714242191.529709  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1714242191.529716  304205 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# I0000 00:00:1714242198.729386  304205 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:From /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/util/deprecation.py:660: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# statistic = 761.5675642077339 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.5891920282062135
#
# ------------ 2 - 0.95 CL ------------
# eps = 3.75 - deformation = mean
# statistic = 1715.5337021313717 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 1.1800806770099221
#
# ------------ 3 - 0.95 CL ------------
# eps = 4.375 - deformation = mean
# WARNING:tensorflow:5 out of the last 5 calls to <function generate_and_clean_data_simple_1 at 0x7f96211a4e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function generate_and_clean_data_simple_1 at 0x7f96211a4e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 2336.0356378401802 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.9605819040397253
#
# ------------ 4 - 0.95 CL ------------
# eps = 4.6875 - deformation = mean
# statistic = 2682.7461294858745 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.8506407500595127
#
# ------------ 5 - 0.95 CL ------------
# eps = 4.84375 - deformation = mean
# WARNING:tensorflow:5 out of the last 5 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f94003f14e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 2864.1974843717994 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.031746031746031744
# relative_error_metric = 0.7962957559530545
#
# ------------ 6 - 0.95 CL ------------
# eps = 4.921875 - deformation = mean
# WARNING:tensorflow:6 out of the last 6 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f933417ca40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 2957.2990239452783 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.015748031496062992
# relative_error_metric = 0.7692082313927019
#
# ------------ 7 - 0.95 CL ------------
# eps = 4.9609375 - deformation = mean
# statistic = 3004.796614512484 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.00784313725490196
# relative_error_metric = 0.7555901615619754
#
# ------------ 8 - 0.95 CL ------------
# eps = 4.98046875 - deformation = mean
# statistic = 3028.6131932515045 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.003913894324853229
# relative_error_metric = 0.7488119866069844
#
# ------------ 9 - 0.95 CL ------------
# eps = 4.990234375 - deformation = mean
# statistic = 3040.2838486363385 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0019550342130987292
# relative_error_metric = 0.7455026884878891
#
# ------------ 10 - 0.95 CL ------------
# eps = 4.9951171875 - deformation = mean
# statistic = 3046.55310460694 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0009770395701025891
# relative_error_metric = 0.7437282836468129
#
# ------------ 11 - 0.95 CL ------------
# eps = 4.99755859375 - deformation = mean
# statistic = 3048.976977338085 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0004884004884004884
# relative_error_metric = 0.7430428629014031
#
# ------------ 12 - 0.95 CL ------------
# eps = 4.998779296875 - deformation = mean
# statistic = 3050.8089733947704 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.00024417043096081065
# relative_error_metric = 0.7425250397447181
#
# ------------ 13 - 0.95 CL ------------
# eps = 4.9993896484375 - deformation = mean
# statistic = 3051.818062853955 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.00012207776353537203
# relative_error_metric = 0.7422398988851785
#
# ------------ 14 - 0.95 CL ------------
# eps = 4.99969482421875 - deformation = mean
# statistic = 3052.110861788095 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 6.103701895199438e-05
# relative_error_metric = 0.7421571730770125
#
# ------------ 15 - 0.95 CL ------------
# eps = 4.999847412109375 - deformation = mean
# statistic = 3051.970944477327 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.0518043793392844e-05
# relative_error_metric = 0.742196703925447
#
# ------------ 16 - 0.95 CL ------------
# eps = 4.9999237060546875 - deformation = mean
# statistic = 3052.400724541613 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.5258905478710012e-05
# relative_error_metric = 0.7420752817574928
#
# ------------ 17 - 0.95 CL ------------
# eps = 4.999961853027344 - deformation = mean
# statistic = 3052.2881428757137 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 7.629423635191479e-06
# relative_error_metric = 0.7421070874747452
#
# ------------ 18 - 0.95 CL ------------
# eps = 4.999980926513672 - deformation = mean
# statistic = 3052.702990386577 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.814704541596492e-06
# relative_error_metric = 0.7419898915561997
#
# ------------ 19 - 0.95 CL ------------
# eps = 4.999990463256836 - deformation = mean
# statistic = 3052.4052602594998 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.9073504518036383e-06
# relative_error_metric = 0.7420740003763836
#
# ------------ 20 - 0.95 CL ------------
# eps = 4.999995231628418 - deformation = mean
# statistic = 3052.4420529125214 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 9.536747711538177e-07
# relative_error_metric = 0.7420636061651522
#
# ------------ 21 - 0.95 CL ------------
# eps = 4.999997615814209 - deformation = mean
# statistic = 3052.3347515997993 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 4.768372718899898e-07
# relative_error_metric = 0.7420939198424841
#
# ------------ 22 - 0.95 CL ------------
# eps = 4.9999988079071045 - deformation = mean
# statistic = 3052.326174940442 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.384186075232753e-07
# relative_error_metric = 0.7420963428621258
#
# ------------ 23 - 0.95 CL ------------
# eps = 4.999999403953552 - deformation = mean
# statistic = 3052.409620911225 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.1920929665620903e-07
# relative_error_metric = 0.7420727684541689
#
# ------------ 24 - 0.95 CL ------------
# eps = 4.999999701976776 - deformation = mean
# statistic = 3052.287356771919 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 5.960464655174752e-08
# relative_error_metric = 0.7421073095614134
#
# ------------ 25 - 0.95 CL ------------
# eps = 4.999999850988388 - deformation = mean
# statistic = 3051.7516839835894 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.980232283178453e-08
# relative_error_metric = 0.7422586539019289
#
# ------------ 26 - 0.95 CL ------------
# eps = 4.999999925494194 - deformation = mean
# statistic = 3052.0893719299315 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.490116130486996e-08
# relative_error_metric = 0.7421632445341881
#
# ------------ 27 - 0.95 CL ------------
# eps = 4.999999962747097 - deformation = mean
# statistic = 3052.0207201756375 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 7.450580624679404e-09
# relative_error_metric = 0.7421826406630138
#
# ------------ 28 - 0.95 CL ------------
# eps = 4.9999999813735485 - deformation = mean
# statistic = 3052.6100193754737 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.725290305400808e-09
# relative_error_metric = 0.7420161553312934
#
# ------------ 29 - 0.95 CL ------------
# eps = 4.999999990686774 - deformation = mean
# statistic = 3052.888593782729 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.8626451509656805e-09
# relative_error_metric = 0.7419374611706847
#
# ------------ 30 - 0.95 CL ------------
# eps = 4.999999995343387 - deformation = mean
# statistic = 3051.8235068487693 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 9.313225750491594e-10
# relative_error_metric = 0.7422383607231429
#
# ------------ 31 - 0.95 CL ------------
# eps = 4.999999997671694 - deformation = mean
# statistic = 3052.2604258253778 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 4.656612874161595e-10
# relative_error_metric = 0.7421149179984973
#
# ------------ 32 - 0.95 CL ------------
# eps = 4.999999998835847 - deformation = mean
# statistic = 3052.297993641924 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.328306436809747e-10
# relative_error_metric = 0.7421043044816313
#
# ------------ 33 - 0.95 CL ------------
# eps = 4.999999999417923 - deformation = mean
# statistic = 3052.5672552614474 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.1641532183371108e-10
# relative_error_metric = 0.7420282361161086
#
# ------------ 34 - 0.95 CL ------------
# eps = 4.999999999708962 - deformation = mean
# statistic = 3052.2113715262576 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 5.820766091516147e-11
# relative_error_metric = 0.7421287767564831
#
# ------------ 35 - 0.95 CL ------------
# eps = 4.999999999854481 - deformation = mean
# statistic = 3052.5335243800705 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.910383045715722e-11
# relative_error_metric = 0.7420377651041464
#
# ------------ 36 - 0.95 CL ------------
# eps = 4.99999999992724 - deformation = mean
# statistic = 3052.3443045824756 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.455191522847273e-11
# relative_error_metric = 0.7420912210036402
#
# ------------ 37 - 0.95 CL ------------
# eps = 4.99999999996362 - deformation = mean
# statistic = 3052.955466328739 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 7.275957614209896e-12
# relative_error_metric = 0.7419185710951601
#
# ------------ 38 - 0.95 CL ------------
# eps = 4.99999999998181 - deformation = mean
# statistic = 3052.5582497435657 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.63797880709833e-12
# relative_error_metric = 0.7420307801721803
#
# ------------ 39 - 0.95 CL ------------
# eps = 4.999999999990905 - deformation = mean
# statistic = 3052.558298238887 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.818989403547511e-12
# relative_error_metric = 0.7420307664722541
#
# ------------ 40 - 0.95 CL ------------
# eps = 4.9999999999954525 - deformation = mean
# statistic = 3052.454301802959 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 9.094947017733418e-13
# relative_error_metric = 0.7420601457756228
#
# ------------ 41 - 0.95 CL ------------
# eps = 4.999999999997726 - deformation = mean
# statistic = 3051.8936330137444 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 4.547473508865675e-13
# relative_error_metric = 0.7422185472280022
#
# ------------ 42 - 0.95 CL ------------
# eps = 4.999999999998863 - deformation = mean
# statistic = 3052.1463175501844 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.273736754432579e-13
# relative_error_metric = 0.7421471559388576
#
# ------------ 43 - 0.95 CL ------------
# eps = 4.999999999999432 - deformation = mean
# statistic = 3052.3182097753015 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.136868377216225e-13
# relative_error_metric = 0.7420985931304028
#
# ------------ 44 - 0.95 CL ------------
# eps = 4.999999999999716 - deformation = mean
# statistic = 3052.0460408771146 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 5.684341886080963e-14
# relative_error_metric = 0.7421754867922139
#
# ------------ 45 - 0.95 CL ------------
# eps = 4.999999999999858 - deformation = mean
# statistic = 3052.136256614915 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.842170943040441e-14
# relative_error_metric = 0.7421499983968652
#
# ------------ 46 - 0.95 CL ------------
# eps = 4.999999999999929 - deformation = mean
# statistic = 3052.174191241405 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.4210854715202105e-14
# relative_error_metric = 0.7421392809764379
#
# ------------ 47 - 0.95 CL ------------
# eps = 4.9999999999999645 - deformation = mean
# statistic = 3052.134857067872 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 7.105427357601027e-15
# relative_error_metric = 0.7421503938032854
#
# ------------ 48 - 0.95 CL ------------
# eps = 4.999999999999982 - deformation = mean
# statistic = 3051.994713351136 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.552713678800507e-15
# relative_error_metric = 0.7421899884233618
#
# ------------ 49 - 0.95 CL ------------
# eps = 4.999999999999991 - deformation = mean
# statistic = 3052.147360108745 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.776356839400252e-15
# relative_error_metric = 0.7421468613911382
#
# ------------ 50 - 0.95 CL ------------
# eps = 4.999999999999996 - deformation = mean
# statistic = 3051.8722437320007 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 8.881784197001256e-16
# relative_error_metric = 0.7422245905401089
#
# ------------ 51 - 0.95 CL ------------
# eps = 4.999999999999998 - deformation = mean
# statistic = 3052.575672035013 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.5527136788005016e-16
# relative_error_metric = 0.7420258583843955
#
# ------------ 52 - 0.95 CL ------------
# eps = 4.999999999999999 - deformation = mean
# statistic = 3052.320379481507 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.7763568394002506e-16
# relative_error_metric = 0.7420979801583082
#
# ------------ 53 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3051.804629247615 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.742243694462538
#
# ------------ 54 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.552489999595 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420324073005813
#
# ------------ 55 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.4973962658805 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420479713849096
#
# ------------ 56 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.2808905562365 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421091363702625
#
# ------------ 57 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3051.905530675176 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7422151856829237
#
# ------------ 58 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.448957893491 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420616554629949
#
# ------------ 59 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.5297664425457 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420388267271626
#
# ------------ 60 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.5523695492366 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420324413278434
#
# ------------ 61 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.025873785957 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421811846078163
#
# ------------ 62 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.2012729409025 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.742131629813318
#
# ------------ 63 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.561450780722 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420298758796131
#
# ------------ 64 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.281411212999 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.74210898927635
#
# ------------ 65 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.254981466419 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421164561249315
#
# ------------ 66 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.19462899276 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.742133506867746
#
# ------------ 67 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3051.815431134266 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7422406424594873
#
# ------------ 68 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.1154962772775 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421558637139329
#
# ------------ 69 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.730768839461 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7419820444008934
#
# ------------ 70 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.198425265815 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421324343408259
#
# ------------ 71 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.1868003833797 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.74213571861707
#
# ------------ 72 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.0391625722773 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421774301195215
#
# ------------ 73 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.035530190173 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421784563774653
#
# ------------ 74 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.5794778843574 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420247832363932
#
# ------------ 75 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.471768081228 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420552114559216
#
# ------------ 76 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.5364288442092 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420369445892115
#
# ------------ 77 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.266749042944 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421131315813325
#
# ------------ 78 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.3534411089145 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420886398239389
#
# ------------ 79 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.470696872554 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.742055514077754
#
# ------------ 80 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3051.8099528060498 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7422421903247629
#
# ------------ 81 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.1098982071435 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421574453137144
#
# ------------ 82 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.0938918299353 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421619675398459
#
# ------------ 83 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.2372724079178 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421214592549947
#
# ------------ 84 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.420695699109 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.742069639734799
#
# ------------ 85 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.3005825207215 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421035730844509
#
# ------------ 86 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3051.745045603904 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7422605295569102
#
# ------------ 87 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.1941919731953 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421336303350111
#
# ------------ 88 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.1637475518805 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421422315549666
#
# ------------ 89 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3051.716885772598 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7422684860643332
#
# ------------ 90 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3051.9269053265693 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7422091465458809
#
# ------------ 91 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.4419185501324 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420636441234308
#
# ------------ 92 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.728674330921 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7419826360785646
#
# ------------ 93 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.1496315766267 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421462196473732
#
# ------------ 94 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3051.6993059059605 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7422734532460279
#
# ------------ 95 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.2340988738365 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421223558378327
#
# ------------ 96 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.136151970427 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421500279614999
#
# ------------ 97 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.228108826173 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7421240481401264
#
# ------------ 98 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.4258586856936 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420681811507358
#
# ------------ 99 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.5795507323314 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420247626569336
#
# ------------ 100 - 0.95 CL ------------
# eps = 5.0 - deformation = mean
# statistic = 3052.422400405228 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 0.7420691581418251
# Time elapsed: 2341.6278777349507 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_diag
# statistic = 7452.973630698531 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.11331149969117023
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_diag
# statistic = 1863.2655920233312 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.1249205684597983
#
# ------------ 3 - 0.95 CL ------------
# eps = 1.875 - deformation = cov_diag
# statistic = 4192.260456286848 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.4538972343554459
#
# ------------ 4 - 0.95 CL ------------
# eps = 2.1875 - deformation = cov_diag
# statistic = 5706.111014140373 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.15334088888114736
#
# ------------ 5 - 0.95 CL ------------
# eps = 2.34375 - deformation = cov_diag
# statistic = 6550.760611560147 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.01559864244053775
#
# ------------ 6 - 0.95 CL ------------
# eps = 2.421875 - deformation = cov_diag
# statistic = 6994.52036889757 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.04993653158312318
#
# ------------ 7 - 0.95 CL ------------
# eps = 2.3828125 - deformation = cov_diag
# statistic = 6770.611877903869 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.01652892561983471
# relative_error_metric = 0.017410898231009674
# =======> statistic within required accuracy at 0.95 CL in 166.54153647401836 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 2.36328125 - deformation = cov_diag
# statistic = 6659.574860972273 - next threshold = 10337.70942747079 at 0.99 CL
# relative_error_eps = 0.7161803713527851
# relative_error_metric = 0.4327908510654711
#
# ------------ 2 - 0.99 CL ------------
# eps = 3.681640625 - deformation = cov_diag
# statistic = 16164.290208647259 - next threshold = 10337.70942747079 at 0.99 CL
# relative_error_eps = 0.43618739903069464
# relative_error_metric = 0.43970876621972
#
# ------------ 3 - 0.99 CL ------------
# eps = 3.0224609375 - deformation = cov_diag
# statistic = 10893.933764775355 - next threshold = 10337.70942747079 at 0.99 CL
# relative_error_eps = 0.24478694469628287
# relative_error_metric = 0.05239578795368025
#
# ------------ 4 - 0.99 CL ------------
# eps = 2.69287109375 - deformation = cov_diag
# statistic = 8647.459570571194 - next threshold = 10337.70942747079 at 0.99 CL
# relative_error_eps = 0.11533532678342588
# relative_error_metric = 0.17806002749555913
#
# ------------ 5 - 0.99 CL ------------
# eps = 2.857666015625 - deformation = cov_diag
# statistic = 9738.166106397177 - next threshold = 10337.70942747079 at 0.99 CL
# relative_error_eps = 0.0560514843263442
# relative_error_metric = 0.05972773840544938
#
# ------------ 6 - 0.99 CL ------------
# eps = 2.9400634765625 - deformation = cov_diag
# statistic = 10308.042691132592 - next threshold = 10337.70942747079 at 0.99 CL
# relative_error_eps = 0.02763844815231856
# relative_error_metric = 0.002873882837280264
#
# ------------ 7 - 0.99 CL ------------
# eps = 2.98126220703125 - deformation = cov_diag
# statistic = 10599.167553699834 - next threshold = 10337.70942747079 at 0.99 CL
# relative_error_eps = 0.013915373911250837
# relative_error_metric = 0.02497584777941647
#
# ------------ 8 - 0.99 CL ------------
# eps = 2.960662841796875 - deformation = cov_diag
# statistic = 10453.852151753692 - next threshold = 10337.70942747079 at 0.99 CL
# relative_error_eps = 0.00698197615784438
# relative_error_metric = 0.011172102089624132
# =======> statistic within required accuracy at 0.99 CL in 186.80679360602517 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 353.3483635049779 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_off_diag
# statistic = 604.9662513904617 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.6666261655099066
#
# ------------ 2 - 0.95 CL ------------
# eps = 3.75 - deformation = cov_off_diag
# statistic = 991.5285868832427 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 1.4812332920038798
#
# ------------ 3 - 0.95 CL ------------
# eps = 4.375 - deformation = cov_off_diag
# statistic = 1131.7413482114628 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 1.4185380154840428
#
# ------------ 4 - 0.95 CL ------------
# eps = 4.6875 - deformation = cov_off_diag
# statistic = 1191.5633834327411 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 1.3924709898830916
#
# ------------ 5 - 0.95 CL ------------
# eps = 4.84375 - deformation = cov_off_diag
# statistic = 1219.1429673152375 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.031746031746031744
# relative_error_metric = 1.3805867973028816
#
# ------------ 6 - 0.95 CL ------------
# eps = 4.921875 - deformation = cov_off_diag
# statistic = 1232.546052385406 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.015748031496062992
# relative_error_metric = 1.3748413484281965
#
# ------------ 7 - 0.95 CL ------------
# eps = 4.9609375 - deformation = cov_off_diag
# statistic = 1239.3088299397386 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.00784313725490196
# relative_error_metric = 1.37194978116047
#
# ------------ 8 - 0.95 CL ------------
# eps = 4.98046875 - deformation = cov_off_diag
# statistic = 1242.3369798970764 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.003913894324853229
# relative_error_metric = 1.3706566376399318
#
# ------------ 9 - 0.95 CL ------------
# eps = 4.990234375 - deformation = cov_off_diag
# statistic = 1244.029537569577 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0019550342130987292
# relative_error_metric = 1.3699342785220125
#
# ------------ 10 - 0.95 CL ------------
# eps = 4.9951171875 - deformation = cov_off_diag
# statistic = 1244.8419760488591 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0009770395701025891
# relative_error_metric = 1.3695876515034517
#
# ------------ 11 - 0.95 CL ------------
# eps = 4.99755859375 - deformation = cov_off_diag
# statistic = 1245.1504424575855 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0004884004884004884
# relative_error_metric = 1.369456062932415
#
# ------------ 12 - 0.95 CL ------------
# eps = 4.998779296875 - deformation = cov_off_diag
# statistic = 1245.3820945113896 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.00024417043096081065
# relative_error_metric = 1.3693572493256285
#
# ------------ 13 - 0.95 CL ------------
# eps = 4.9993896484375 - deformation = cov_off_diag
# statistic = 1245.5163712059243 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.00012207776353537203
# relative_error_metric = 1.369299974850279
#
# ------------ 14 - 0.95 CL ------------
# eps = 4.99969482421875 - deformation = cov_off_diag
# statistic = 1245.5445865302115 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 6.103701895199438e-05
# relative_error_metric = 1.3692879401136577
#
# ------------ 15 - 0.95 CL ------------
# eps = 4.999847412109375 - deformation = cov_off_diag
# statistic = 1245.5496825972534 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.0518043793392844e-05
# relative_error_metric = 1.3692857664875318
#
# ------------ 16 - 0.95 CL ------------
# eps = 4.9999237060546875 - deformation = cov_off_diag
# statistic = 1245.5791316550703 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.5258905478710012e-05
# relative_error_metric = 1.3692732056320718
#
# ------------ 17 - 0.95 CL ------------
# eps = 4.999961853027344 - deformation = cov_off_diag
# statistic = 1245.5294825651831 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 7.629423635191479e-06
# relative_error_metric = 1.3692943824262642
#
# ------------ 18 - 0.95 CL ------------
# eps = 4.999980926513672 - deformation = cov_off_diag
# statistic = 1245.4941115680624 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.814704541596492e-06
# relative_error_metric = 1.369309469357165
#
# ------------ 19 - 0.95 CL ------------
# eps = 4.999990463256836 - deformation = cov_off_diag
# statistic = 1245.5798696949323 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.9073504518036383e-06
# relative_error_metric = 1.3692728908384149
#
# ------------ 20 - 0.95 CL ------------
# eps = 4.999995231628418 - deformation = cov_off_diag
# statistic = 1245.6146285025045 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 9.536747711538177e-07
# relative_error_metric = 1.3692580653478947
#
# ------------ 21 - 0.95 CL ------------
# eps = 4.999997615814209 - deformation = cov_off_diag
# statistic = 1245.6513623949477 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 4.768372718899898e-07
# relative_error_metric = 1.3692423975766619
#
# ------------ 22 - 0.95 CL ------------
# eps = 4.9999988079071045 - deformation = cov_off_diag
# statistic = 1245.6173116590867 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.384186075232753e-07
# relative_error_metric = 1.3692569209207206
#
# ------------ 23 - 0.95 CL ------------
# eps = 4.999999403953552 - deformation = cov_off_diag
# statistic = 1245.5952383292165 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.1920929665620903e-07
# relative_error_metric = 1.3692663357199546
#
# ------------ 24 - 0.95 CL ------------
# eps = 4.999999701976776 - deformation = cov_off_diag
# statistic = 1245.5060035284557 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 5.960464655174752e-08
# relative_error_metric = 1.3693043970173213
#
# ------------ 25 - 0.95 CL ------------
# eps = 4.999999850988388 - deformation = cov_off_diag
# statistic = 1245.524313235065 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.980232283178453e-08
# relative_error_metric = 1.3692965873125964
#
# ------------ 26 - 0.95 CL ------------
# eps = 4.999999925494194 - deformation = cov_off_diag
# statistic = 1245.4985700992406 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.490116130486996e-08
# relative_error_metric = 1.3693075676348354
#
# ------------ 27 - 0.95 CL ------------
# eps = 4.999999962747097 - deformation = cov_off_diag
# statistic = 1245.5154843789812 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 7.450580624679404e-09
# relative_error_metric = 1.3693003531116772
#
# ------------ 28 - 0.95 CL ------------
# eps = 4.9999999813735485 - deformation = cov_off_diag
# statistic = 1245.605706480367 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.725290305400808e-09
# relative_error_metric = 1.3692618707984041
#
# ------------ 29 - 0.95 CL ------------
# eps = 4.999999990686774 - deformation = cov_off_diag
# statistic = 1245.4175228770225 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.8626451509656805e-09
# relative_error_metric = 1.3693421374966297
#
# ------------ 30 - 0.95 CL ------------
# eps = 4.999999995343387 - deformation = cov_off_diag
# statistic = 1245.5270178554517 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 9.313225750491594e-10
# relative_error_metric = 1.369295433704247
#
# ------------ 31 - 0.95 CL ------------
# eps = 4.999999997671694 - deformation = cov_off_diag
# statistic = 1245.5641024310194 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 4.656612874161595e-10
# relative_error_metric = 1.3692796160091893
#
# ------------ 32 - 0.95 CL ------------
# eps = 4.999999998835847 - deformation = cov_off_diag
# statistic = 1245.5488630834927 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.328306436809747e-10
# relative_error_metric = 1.3692861160346514
#
# ------------ 33 - 0.95 CL ------------
# eps = 4.999999999417923 - deformation = cov_off_diag
# statistic = 1245.4655306285933 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.1641532183371108e-10
# relative_error_metric = 1.3693216601966927
#
# ------------ 34 - 0.95 CL ------------
# eps = 4.999999999708962 - deformation = cov_off_diag
# statistic = 1245.5124780969722 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 5.820766091516147e-11
# relative_error_metric = 1.36930163539229
#
# ------------ 35 - 0.95 CL ------------
# eps = 4.999999999854481 - deformation = cov_off_diag
# statistic = 1245.7325747669427 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.910383045715722e-11
# relative_error_metric = 1.3692077593234646
#
# ------------ 36 - 0.95 CL ------------
# eps = 4.99999999992724 - deformation = cov_off_diag
# statistic = 1245.5952437003166 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.455191522847273e-11
# relative_error_metric = 1.3692663334290462
#
# ------------ 37 - 0.95 CL ------------
# eps = 4.99999999996362 - deformation = cov_off_diag
# statistic = 1245.594742377598 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 7.275957614209896e-12
# relative_error_metric = 1.3692665472556986
#
# ------------ 38 - 0.95 CL ------------
# eps = 4.99999999998181 - deformation = cov_off_diag
# statistic = 1245.4551446223927 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.63797880709833e-12
# relative_error_metric = 1.3693260902385969
#
# ------------ 39 - 0.95 CL ------------
# eps = 4.999999999990905 - deformation = cov_off_diag
# statistic = 1245.5392058297648 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.818989403547511e-12
# relative_error_metric = 1.3692902351475502
#
# ------------ 40 - 0.95 CL ------------
# eps = 4.9999999999954525 - deformation = cov_off_diag
# statistic = 1245.5759514647855 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 9.094947017733418e-13
# relative_error_metric = 1.3692745620685973
#
# ------------ 41 - 0.95 CL ------------
# eps = 4.999999999997726 - deformation = cov_off_diag
# statistic = 1245.6311642226333 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 4.547473508865675e-13
# relative_error_metric = 1.3692510125003645
#
# ------------ 42 - 0.95 CL ------------
# eps = 4.999999999998863 - deformation = cov_off_diag
# statistic = 1245.5907055199375 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.273736754432579e-13
# relative_error_metric = 1.3692682690772375
#
# ------------ 43 - 0.95 CL ------------
# eps = 4.999999999999432 - deformation = cov_off_diag
# statistic = 1245.462674363198 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.136868377216225e-13
# relative_error_metric = 1.3693228785055485
#
# ------------ 44 - 0.95 CL ------------
# eps = 4.999999999999716 - deformation = cov_off_diag
# statistic = 1245.6724213742687 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 5.684341886080963e-14
# relative_error_metric = 1.3692334155484989
#
# ------------ 45 - 0.95 CL ------------
# eps = 4.999999999999858 - deformation = cov_off_diag
# statistic = 1245.5288759528703 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 2.842170943040441e-14
# relative_error_metric = 1.3692946411658675
#
# ------------ 46 - 0.95 CL ------------
# eps = 4.999999999999929 - deformation = cov_off_diag
# statistic = 1245.5443090443575 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.4210854715202105e-14
# relative_error_metric = 1.3692880584698148
#
# ------------ 47 - 0.95 CL ------------
# eps = 4.9999999999999645 - deformation = cov_off_diag
# statistic = 1245.5209216244648 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 7.105427357601027e-15
# relative_error_metric = 1.3692980339456788
#
# ------------ 48 - 0.95 CL ------------
# eps = 4.999999999999982 - deformation = cov_off_diag
# statistic = 1245.5728968609744 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.552713678800507e-15
# relative_error_metric = 1.3692758649401489
#
# ------------ 49 - 0.95 CL ------------
# eps = 4.999999999999991 - deformation = cov_off_diag
# statistic = 1245.6708339941645 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.776356839400252e-15
# relative_error_metric = 1.3692340925925965
#
# ------------ 50 - 0.95 CL ------------
# eps = 4.999999999999996 - deformation = cov_off_diag
# statistic = 1245.570105959128 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 8.881784197001256e-16
# relative_error_metric = 1.3692770553365257
#
# ------------ 51 - 0.95 CL ------------
# eps = 4.999999999999998 - deformation = cov_off_diag
# statistic = 1245.4520869090009 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 3.5527136788005016e-16
# relative_error_metric = 1.3693273944763615
#
# ------------ 52 - 0.95 CL ------------
# eps = 4.999999999999999 - deformation = cov_off_diag
# statistic = 1245.726697948236 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 1.7763568394002506e-16
# relative_error_metric = 1.3692102658478773
#
# ------------ 53 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.4584794127618 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3693246678175068
#
# ------------ 54 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5971159403614 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692655348721772
#
# ------------ 55 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.4684773711097 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.369320403296731
#
# ------------ 56 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5838030106504 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692712131754994
#
# ------------ 57 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5644030031199 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692794878066887
#
# ------------ 58 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.6067303780012 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692614340817486
#
# ------------ 59 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5336724632925 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692925953014494
#
# ------------ 60 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.6273482007923 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.369252640114806
#
# ------------ 61 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.502366556393 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3693059483123489
#
# ------------ 62 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.6168963727546 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692570980497145
#
# ------------ 63 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.681491377098 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692295470461895
#
# ------------ 64 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.577486716727 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.369273907242296
#
# ------------ 65 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5215242092154 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.369297776923442
#
# ------------ 66 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5947522678182 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692665430372726
#
# ------------ 67 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.630096700877 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.36925146782093
#
# ------------ 68 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5022423686944 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3693060012827452
#
# ------------ 69 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5633537445526 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.369279935345182
#
# ------------ 70 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.50450680428 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3693050354220444
#
# ------------ 71 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.6031789546967 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692629488486088
#
# ------------ 72 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5032201092247 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3693055842422635
#
# ------------ 73 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.6519861249567 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692421315440628
#
# ------------ 74 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.6343902962278 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692496365126188
#
# ------------ 75 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.6612419969463 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692381837452305
#
# ------------ 76 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.6033475748418 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692628769280588
#
# ------------ 77 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5915048569773 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692679281397033
#
# ------------ 78 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.564450526638 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692794675365652
#
# ------------ 79 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag
# statistic = 1245.5220336280993 - next threshold = 6653.746806468777 at 0.95 CL
# relative_error_eps = 0.0
# relative_error_metric = 1.3692975596395456
#
# ------------ 80 - 0.95 CL ------------
# eps = 5.0 - deformation = cov_off_diag

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normnal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for LR with mean deformation already loaded.
# Exclusion limits for LR with std deformation already loaded.
# Exclusion limits for LR with both deformation already loaded.
# dict_keys(['2024-04-09T08:17:32.047183', '2024-04-09T12:48:49.241300', '2024-04-09T12:58:18.440799', '2024-04-09T13:07:20.008483', '2024-04-09T13:17:25.561745', '2024-04-09T13:25:56.283172', '2024-04-09T13:35:25.934319', '2024-04-09T13:44:04.744309', '2024-04-09T13:50:02.052651', '2024-04-09T13:58:47.407373', '2024-04-09T14:11:47.394617', '2024-04-09T14:23:42.318644', '2024-04-09T14:35:11.864245', '2024-04-09T14:47:31.477052', '2024-04-09T14:59:13.151367', '2024-04-09T15:11:20.411686', '2024-04-09T15:20:01.727259', '2024-04-09T15:28:01.572144', '2024-04-09T23:46:24.382607', '2024-04-10T00:10:07.236509', '2024-04-10T00:29:45.394176'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normnal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)

# %%
result_table = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer').merge(results_df_cov_off_diag, on='Statistic', how='outer').merge(sorted_df_power_abs_up, on='Statistic', how='outer')
result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fgd","$d_{\\mathrm{FGD}_{\\infty}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("mmd","$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
print(result_table.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g").replace("\\toprule","\\toprule\n\\multicolumn{1}{c}{} & \\multicolumn{3}{c}{$\\mu$-deformation} & \\multicolumn{3}{c}{$\\sigma$-deformation} & \\multicolumn{3}{c}{$\\Sigma_{ij}-\\Sigma_{ii}$-deformation} & \\multicolumn{3}{c}{$\\Sigma_{ij}$-deformation} \\\\").replace("$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$").replace("$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$").replace("$t^{\\mu}$ (s)", "t (s)").replace("$\\epsilon^{\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$").replace("$\\epsilon^{\\sigma}_{99\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$").replace("$t^{\\sigma}$ (s)", "t (s)").replace("$\\epsilon^{\\Sigma_{ij}-\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$").replace("$\\epsilon^{\\Sigma_{ij}-\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$").replace("$t^{\\Sigma_{ij}-\\Sigma_{ii}}$ (s)", "t (s)").replace("$\\epsilon^{\\Sigma_{ij}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$").replace("$\\epsilon^{\\Sigma_{ij}}_{99\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$").replace("$t^{\\Sigma_{ij}}$ (s)", "t (s)").replace("\\bottomrule\n\\end{tabular}\n","").replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\").rstrip())
result_table = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer').merge(sorted_df_random_uniform, on='Statistic', how='outer').merge(times_df, on='Statistic', how='outer')
result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fgd","$d_{\\mathrm{FGD}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("mmd","$d_{\\mathrm{MMD}}$")
#display(result_table)
print(result_table.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g").replace("$\\epsilon^{\\mu-\\sigma}_{95\\%\\mathrm{CL}}$","$\\epsilon_{95\\%\\mathrm{CL}}$").replace("$\\epsilon^{\\mu-\\sigma}_{99\\%\\mathrm{CL}}$","$\\epsilon_{99\\%\\mathrm{CL}}$").replace("$t^{\\mu-\\sigma}$ (s)","t (s)").replace("$\\epsilon^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$","$\\epsilon_{95\\%\\mathrm{CL}}$").replace("$\\epsilon^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$","$\\epsilon_{99\\%\\mathrm{CL}}$").replace("$t^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}$ (s)","t (s)").replace("$\\epsilon^{\\mu-\Sigma_{ij}}_{95\\%\\mathrm{CL}}$","$\\epsilon_{95\\%\\mathrm{CL}}$").replace("$\\epsilon^{\\mu-\Sigma_{ij}}_{99\\%\\mathrm{CL}}$","$\\epsilon_{99\\%\\mathrm{CL}}$").replace("$t^{\\mu-\Sigma_{ij}}$ (s)","t (s)").replace("\\begin{tabular}{l|llr|llr|llr|r}","").replace("\\toprule","\\toprule\n\\multicolumn{1}{c}{} & \\multicolumn{3}{c}{$\\mu-\\sigma$-deformation} & \\multicolumn{3}{c}{$\\mu-\\Sigma_{ij}-\\Sigma_{ii}$-deformation} & \\multicolumn{3}{c}{$\\mu-\\Sigma_{ij}$-deformation} & \\multicolumn{3}{c}{} \\\\").lstrip())
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{} & \multicolumn{3}{c}{$\mu$-deformation} & \multicolumn{3}{c}{$\sigma$-deformation} & \multicolumn{3}{c}{$\Sigma_{ij}-\Sigma_{ii}$-deformation} & \multicolumn{3}{c}{$\Sigma_{ij}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) \\
# \midrule
# $t_{\mathrm{LLR}}$ & 0.01 & 0.014 & 329 & 0.0018 & 0.0027 & 413 & 0.0022 & 0.0034 & 662 & 0.014 & 0.02 & 339 \\
# $d_{\mathrm{MMD}}$ & 0.021 & 0.03 & 298 & 0.15 & 0.2 & 267 & 0.18 & 0.24 & 270 & 0.12 & 0.16 & 271 \\
# $\widetilde{W}$ & 0.03 & 0.04 & 128 & 0.032 & 0.044 & 129 & 0.065 & 0.091 & 163 & 0.044 & 0.06 & 130 \\
# $\widetilde{D}$ & 0.031 & 0.04 & 200 & 0.034 & 0.045 & 203 & 0.063 & 0.086 & 263 & 0.059 & 0.079 & 202 \\
# $d_{\mathrm{FGD}}$ & 0.035 & 0.045 & 218 & 0.026 & 0.034 & 232 & 0.035 & 0.044 & 236 & 0.039 & 0.051 & 226 \\
# $\overline{D}$ & 0.043 & 0.055 & 124 & 0.067 & 0.087 & 117 & 1.1 & 1.1 & 104 & 0.065 & 0.087 & 117 \\
# $\overline{\|\cdot\|}_{F}$ & 0.056 & 0.073 & 73 & 0.034 & 0.044 & 75 & 0.033 & 0.041 & 121 & 0.14 & 0.19 & 64 \\
# \toprule
# \multicolumn{1}{c}{} & \multicolumn{3}{c}{$\mu-\sigma$-deformation} & \multicolumn{3}{c}{$\mu-\Sigma_{ij}-\Sigma_{ii}$-deformation} & \multicolumn{3}{c}{$\mu-\Sigma_{ij}$-deformation} & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $t_{\mathrm{LLR}}$ & 0.0019 & 0.0029 & 419 & 0.0023 & 0.0035 & 637 & 0.0086 & 0.011 & 411 & - \\
# $d_{\mathrm{MMD}}$ & 0.02 & 0.028 & 310 & 0.021 & 0.029 & 323 & 0.02 & 0.028 & 326 & 2008 \\
# $d_{\mathrm{FGD}}$ & 0.02 & 0.026 & 246 & 0.024 & 0.031 & 232 & 0.025 & 0.033 & 239 & 428 \\
# $\widetilde{W}$ & 0.021 & 0.029 & 132 & 0.026 & 0.036 & 164 & 0.024 & 0.033 & 128 & 251 \\
# $\widetilde{D}$ & 0.021 & 0.028 & 222 & 0.026 & 0.034 & 295 & 0.026 & 0.034 & 220 & 324 \\
# $\overline{\|\cdot\|}_{F}$ & 0.033 & 0.042 & 77 & 0.032 & 0.04 & 111 & 0.05 & 0.065 & 76 & 7 \\
# $\overline{D}$ & 0.034 & 0.044 & 132 & 0.043 & 0.055 & 156 & 0.033 & 0.043 & 130 & 26 \\
# \bottomrule
# \end{tabular}
