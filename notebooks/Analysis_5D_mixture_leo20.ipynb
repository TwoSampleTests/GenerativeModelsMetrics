# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/5D_mixture/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-02 19:07:30.893669: Importing os...
# 2024-05-02 19:07:30.893988: Importing sys...
# Visible devices: [1]
# 2024-05-02 19:07:30.894255: Importing timer from timeit...
# 2024-05-02 19:07:30.894328: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-05-02 19:07:30.894468: Importing numpy...
# 2024-05-02 19:07:31.097021: Importing matplotlib...
# 2024-05-02 19:07:31.588180: Importing h5py...
# 2024-05-02 19:07:31.622348: Importing importlib.util...
# 2024-05-02 19:07:31.622490: Importing json...
# 2024-05-02 19:07:31.622559: Importing pandas...
# 2024-05-02 19:07:32.278129: Importing random...
# 2024-05-02 19:07:32.278334: Importing scipy utils...
# 2024-05-02 19:07:32.797160: Importing subprocess...
# 2024-05-02 19:07:32.797344: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-02 19:07:37.976032: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-02 19:07:39.599405: Importing timeit...
# 2024-05-02 19:07:39.599523: Importing tqdm...
# 2024-05-02 19:07:39.609826: Importing typing...
# 2024-05-02 19:07:39.609983: Setting tf configs...
# 2024-05-02 19:07:39.729086: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-02 19:07:46.271057: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-02 19:07:46.305391: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
dist_1 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
dist_2 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture.Mixture'> <class 'tensorflow_probability.python.distributions.mixture.Mixture'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory was created
# Null hypothesis directory was created

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True        5           0  float64     5  200000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 100,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 5,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 10000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/5D_mixture/5D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 100
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714669671.439714  958226 service.cc:145] XLA service 0xb9aad740 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714669671.439785  958226 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1714669671.518503  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1714669671.523193  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1714669671.524347  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1714669671.525000  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1714669671.526202  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1714669671.526434  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1714669671.526581  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1714669671.526803  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1714669671.526938  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1714669671.527019  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1714669671.527105  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1714669671.527188  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1714669675.381876  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1714669675.382401  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1714669675.382518  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1714669675.382563  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1714669675.382677  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1714669675.382689  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1714669675.382697  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1714669675.382705  958226 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# I0000 00:00:1714669684.803703  958226 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# FGD metric calculation completed in 579.3097427510656 seconds.
# Saving fgd to results/5D_mixture/5D_20K/null_hypothesis/FGD.json
# Computing and savng mmd with max_vectorize = 5
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 2000
# Iterating from 0 to 5 out of 10000 .
# Iterating from 5 to 10 out of 10000 .
# Iterating from 10 to 15 out of 10000 .
# Iterating from 15 to 20 out of 10000 .
# Iterating from 20 to 25 out of 10000 .
# Iterating from 25 to 30 out of 10000 .
# Iterating from 30 to 35 out of 10000 .
# Iterating from 35 to 40 out of 10000 .
# Iterating from 40 to 45 out of 10000 .
# Iterating from 45 to 50 out of 10000 .
# Iterating from 50 to 55 out of 10000 .
# Iterating from 55 to 60 out of 10000 .
# Iterating from 60 to 65 out of 10000 .
# Iterating from 65 to 70 out of 10000 .
# Iterating from 70 to 75 out of 10000 .
# Iterating from 75 to 80 out of 10000 .
# Iterating from 80 to 85 out of 10000 .
# Iterating from 85 to 90 out of 10000 .
# Iterating from 90 to 95 out of 10000 .
# Iterating from 95 to 100 out of 10000 .
# Iterating from 100 to 105 out of 10000 .
# Iterating from 105 to 110 out of 10000 .
# Iterating from 110 to 115 out of 10000 .
# Iterating from 115 to 120 out of 10000 .
# Iterating from 120 to 125 out of 10000 .
# Iterating from 125 to 130 out of 10000 .
# Iterating from 130 to 135 out of 10000 .
# Iterating from 135 to 140 out of 10000 .
# Iterating from 140 to 145 out of 10000 .
# Iterating from 145 to 150 out of 10000 .
# Iterating from 150 to 155 out of 10000 .
# Iterating from 155 to 160 out of 10000 .
# Iterating from 160 to 165 out of 10000 .
# Iterating from 165 to 170 out of 10000 .
# Iterating from 170 to 175 out of 10000 .
# Iterating from 175 to 180 out of 10000 .
# Iterating from 180 to 185 out of 10000 .
# Iterating from 185 to 190 out of 10000 .
# Iterating from 190 to 195 out of 10000 .
# Iterating from 195 to 200 out of 10000 .
# Iterating from 200 to 205 out of 10000 .
# Iterating from 205 to 210 out of 10000 .
# Iterating from 210 to 215 out of 10000 .
# Iterating from 215 to 220 out of 10000 .
# Iterating from 220 to 225 out of 10000 .
# Iterating from 225 to 230 out of 10000 .
# Iterating from 230 to 235 out of 10000 .
# Iterating from 235 to 240 out of 10000 .
# Iterating from 240 to 245 out of 10000 .
# Iterating from 245 to 250 out of 10000 .
# Iterating from 250 to 255 out of 10000 .
# Iterating from 255 to 260 out of 10000 .
# Iterating from 260 to 265 out of 10000 .
# Iterating from 265 to 270 out of 10000 .
# Iterating from 270 to 275 out of 10000 .
# Iterating from 275 to 280 out of 10000 .
# Iterating from 280 to 285 out of 10000 .
# Iterating from 285 to 290 out of 10000 .
# Iterating from 290 to 295 out of 10000 .
# Iterating from 295 to 300 out of 10000 .
# Iterating from 300 to 305 out of 10000 .
# Iterating from 305 to 310 out of 10000 .
# Iterating from 310 to 315 out of 10000 .
# Iterating from 315 to 320 out of 10000 .
# Iterating from 320 to 325 out of 10000 .
# Iterating from 325 to 330 out of 10000 .
# Iterating from 330 to 335 out of 10000 .
# Iterating from 335 to 340 out of 10000 .
# Iterating from 340 to 345 out of 10000 .
# Iterating from 345 to 350 out of 10000 .
# Iterating from 350 to 355 out of 10000 .
# Iterating from 355 to 360 out of 10000 .
# Iterating from 360 to 365 out of 10000 .
# Iterating from 365 to 370 out of 10000 .
# Iterating from 370 to 375 out of 10000 .
# Iterating from 375 to 380 out of 10000 .
# Iterating from 380 to 385 out of 10000 .
# Iterating from 385 to 390 out of 10000 .
# Iterating from 390 to 395 out of 10000 .
# Iterating from 395 to 400 out of 10000 .
# Iterating from 400 to 405 out of 10000 .
# Iterating from 405 to 410 out of 10000 .
# Iterating from 410 to 415 out of 10000 .
# Iterating from 415 to 420 out of 10000 .
# Iterating from 420 to 425 out of 10000 .
# Iterating from 425 to 430 out of 10000 .
# Iterating from 430 to 435 out of 10000 .
# Iterating from 435 to 440 out of 10000 .
# Iterating from 440 to 445 out of 10000 .
# Iterating from 445 to 450 out of 10000 .
# Iterating from 450 to 455 out of 10000 .
# Iterating from 455 to 460 out of 10000 .
# Iterating from 460 to 465 out of 10000 .
# Iterating from 465 to 470 out of 10000 .
# Iterating from 470 to 475 out of 10000 .
# Iterating from 475 to 480 out of 10000 .
# Iterating from 480 to 485 out of 10000 .
# Iterating from 485 to 490 out of 10000 .
# Iterating from 490 to 495 out of 10000 .
# Iterating from 495 to 500 out of 10000 .
# Iterating from 500 to 505 out of 10000 .
# Iterating from 505 to 510 out of 10000 .
# Iterating from 510 to 515 out of 10000 .
# Iterating from 515 to 520 out of 10000 .
# Iterating from 520 to 525 out of 10000 .
# Iterating from 525 to 530 out of 10000 .
# Iterating from 530 to 535 out of 10000 .
# Iterating from 535 to 540 out of 10000 .
# Iterating from 540 to 545 out of 10000 .
# Iterating from 545 to 550 out of 10000 .
# Iterating from 550 to 555 out of 10000 .
# Iterating from 555 to 560 out of 10000 .
# Iterating from 560 to 565 out of 10000 .
# Iterating from 565 to 570 out of 10000 .
# Iterating from 570 to 575 out of 10000 .
# Iterating from 575 to 580 out of 10000 .
# Iterating from 580 to 585 out of 10000 .
# Iterating from 585 to 590 out of 10000 .
# Iterating from 590 to 595 out of 10000 .
# Iterating from 595 to 600 out of 10000 .
# Iterating from 600 to 605 out of 10000 .
# Iterating from 605 to 610 out of 10000 .
# Iterating from 610 to 615 out of 10000 .
# Iterating from 615 to 620 out of 10000 .
# Iterating from 620 to 625 out of 10000 .
# Iterating from 625 to 630 out of 10000 .
# Iterating from 630 to 635 out of 10000 .
# Iterating from 635 to 640 out of 10000 .
# Iterating from 640 to 645 out of 10000 .
# Iterating from 645 to 650 out of 10000 .
# Iterating from 650 to 655 out of 10000 .
# Iterating from 655 to 660 out of 10000 .
# Iterating from 660 to 665 out of 10000 .
# Iterating from 665 to 670 out of 10000 .
# Iterating from 670 to 675 out of 10000 .
# Iterating from 675 to 680 out of 10000 .
# Iterating from 680 to 685 out of 10000 .
# Iterating from 685 to 690 out of 10000 .
# Iterating from 690 to 695 out of 10000 .
# Iterating from 695 to 700 out of 10000 .
# Iterating from 700 to 705 out of 10000 .
# Iterating from 705 to 710 out of 10000 .
# Iterating from 710 to 715 out of 10000 .
# Iterating from 715 to 720 out of 10000 .
# Iterating from 720 to 725 out of 10000 .
# Iterating from 725 to 730 out of 10000 .
# Iterating from 730 to 735 out of 10000 .
# Iterating from 735 to 740 out of 10000 .
# Iterating from 740 to 745 out of 10000 .
# Iterating from 745 to 750 out of 10000 .
# Iterating from 750 to 755 out of 10000 .
# Iterating from 755 to 760 out of 10000 .
# Iterating from 760 to 765 out of 10000 .
# Iterating from 765 to 770 out of 10000 .
# Iterating from 770 to 775 out of 10000 .
# Iterating from 775 to 780 out of 10000 .
# Iterating from 780 to 785 out of 10000 .
# Iterating from 785 to 790 out of 10000 .
# Iterating from 790 to 795 out of 10000 .
# Iterating from 795 to 800 out of 10000 .
# Iterating from 800 to 805 out of 10000 .
# Iterating from 805 to 810 out of 10000 .
# Iterating from 810 to 815 out of 10000 .
# Iterating from 815 to 820 out of 10000 .
# Iterating from 820 to 825 out of 10000 .
# Iterating from 825 to 830 out of 10000 .
# Iterating from 830 to 835 out of 10000 .
# Iterating from 835 to 840 out of 10000 .
# Iterating from 840 to 845 out of 10000 .
# Iterating from 845 to 850 out of 10000 .
# Iterating from 850 to 855 out of 10000 .
# Iterating from 855 to 860 out of 10000 .
# Iterating from 860 to 865 out of 10000 .
# Iterating from 865 to 870 out of 10000 .
# Iterating from 870 to 875 out of 10000 .
# Iterating from 875 to 880 out of 10000 .
# Iterating from 880 to 885 out of 10000 .
# Iterating from 885 to 890 out of 10000 .
# Iterating from 890 to 895 out of 10000 .
# Iterating from 895 to 900 out of 10000 .
# Iterating from 900 to 905 out of 10000 .
# Iterating from 905 to 910 out of 10000 .
# Iterating from 910 to 915 out of 10000 .
# Iterating from 915 to 920 out of 10000 .
# Iterating from 920 to 925 out of 10000 .
# Iterating from 925 to 930 out of 10000 .
# Iterating from 930 to 935 out of 10000 .
# Iterating from 935 to 940 out of 10000 .
# Iterating from 940 to 945 out of 10000 .
# Iterating from 945 to 950 out of 10000 .
# Iterating from 950 to 955 out of 10000 .
# Iterating from 955 to 960 out of 10000 .
# Iterating from 960 to 965 out of 10000 .
# Iterating from 965 to 970 out of 10000 .
# Iterating from 970 to 975 out of 10000 .
# Iterating from 975 to 980 out of 10000 .
# Iterating from 980 to 985 out of 10000 .
# Iterating from 985 to 990 out of 10000 .
# Iterating from 990 to 995 out of 10000 .
# Iterating from 995 to 1000 out of 10000 .
# Iterating from 1000 to 1005 out of 10000 .
# Iterating from 1005 to 1010 out of 10000 .
# Iterating from 1010 to 1015 out of 10000 .
# Iterating from 1015 to 1020 out of 10000 .
# Iterating from 1020 to 1025 out of 10000 .
# Iterating from 1025 to 1030 out of 10000 .
# Iterating from 1030 to 1035 out of 10000 .
# Iterating from 1035 to 1040 out of 10000 .
# Iterating from 1040 to 1045 out of 10000 .
# Iterating from 1045 to 1050 out of 10000 .
# Iterating from 1050 to 1055 out of 10000 .
# Iterating from 1055 to 1060 out of 10000 .
# Iterating from 1060 to 1065 out of 10000 .
# Iterating from 1065 to 1070 out of 10000 .
# Iterating from 1070 to 1075 out of 10000 .
# Iterating from 1075 to 1080 out of 10000 .
# Iterating from 1080 to 1085 out of 10000 .
# Iterating from 1085 to 1090 out of 10000 .
# Iterating from 1090 to 1095 out of 10000 .
# Iterating from 1095 to 1100 out of 10000 .
# Iterating from 1100 to 1105 out of 10000 .
# Iterating from 1105 to 1110 out of 10000 .
# Iterating from 1110 to 1115 out of 10000 .
# Iterating from 1115 to 1120 out of 10000 .
# Iterating from 1120 to 1125 out of 10000 .
# Iterating from 1125 to 1130 out of 10000 .
# Iterating from 1130 to 1135 out of 10000 .
# Iterating from 1135 to 1140 out of 10000 .
# Iterating from 1140 to 1145 out of 10000 .
# Iterating from 1145 to 1150 out of 10000 .
# Iterating from 1150 to 1155 out of 10000 .
# Iterating from 1155 to 1160 out of 10000 .
# Iterating from 1160 to 1165 out of 10000 .
# Iterating from 1165 to 1170 out of 10000 .
# Iterating from 1170 to 1175 out of 10000 .
# Iterating from 1175 to 1180 out of 10000 .
# Iterating from 1180 to 1185 out of 10000 .
# Iterating from 1185 to 1190 out of 10000 .
# Iterating from 1190 to 1195 out of 10000 .
# Iterating from 1195 to 1200 out of 10000 .
# Iterating from 1200 to 1205 out of 10000 .
# Iterating from 1205 to 1210 out of 10000 .
# Iterating from 1210 to 1215 out of 10000 .
# Iterating from 1215 to 1220 out of 10000 .
# Iterating from 1220 to 1225 out of 10000 .
# Iterating from 1225 to 1230 out of 10000 .
# Iterating from 1230 to 1235 out of 10000 .
# Iterating from 1235 to 1240 out of 10000 .
# Iterating from 1240 to 1245 out of 10000 .
# Iterating from 1245 to 1250 out of 10000 .
# Iterating from 1250 to 1255 out of 10000 .
# Iterating from 1255 to 1260 out of 10000 .
# Iterating from 1260 to 1265 out of 10000 .
# Iterating from 1265 to 1270 out of 10000 .
# Iterating from 1270 to 1275 out of 10000 .
# Iterating from 1275 to 1280 out of 10000 .
# Iterating from 1280 to 1285 out of 10000 .
# Iterating from 1285 to 1290 out of 10000 .
# Iterating from 1290 to 1295 out of 10000 .
# Iterating from 1295 to 1300 out of 10000 .
# Iterating from 1300 to 1305 out of 10000 .
# Iterating from 1305 to 1310 out of 10000 .
# Iterating from 1310 to 1315 out of 10000 .
# Iterating from 1315 to 1320 out of 10000 .
# Iterating from 1320 to 1325 out of 10000 .
# Iterating from 1325 to 1330 out of 10000 .
# Iterating from 1330 to 1335 out of 10000 .
# Iterating from 1335 to 1340 out of 10000 .
# Iterating from 1340 to 1345 out of 10000 .
# Iterating from 1345 to 1350 out of 10000 .
# Iterating from 1350 to 1355 out of 10000 .
# Iterating from 1355 to 1360 out of 10000 .
# Iterating from 1360 to 1365 out of 10000 .
# Iterating from 1365 to 1370 out of 10000 .
# Iterating from 1370 to 1375 out of 10000 .
# Iterating from 1375 to 1380 out of 10000 .
# Iterating from 1380 to 1385 out of 10000 .
# Iterating from 1385 to 1390 out of 10000 .
# Iterating from 1390 to 1395 out of 10000 .
# Iterating from 1395 to 1400 out of 10000 .
# Iterating from 1400 to 1405 out of 10000 .
# Iterating from 1405 to 1410 out of 10000 .
# Iterating from 1410 to 1415 out of 10000 .
# Iterating from 1415 to 1420 out of 10000 .
# Iterating from 1420 to 1425 out of 10000 .
# Iterating from 1425 to 1430 out of 10000 .
# Iterating from 1430 to 1435 out of 10000 .
# Iterating from 1435 to 1440 out of 10000 .
# Iterating from 1440 to 1445 out of 10000 .
# Iterating from 1445 to 1450 out of 10000 .
# Iterating from 1450 to 1455 out of 10000 .
# Iterating from 1455 to 1460 out of 10000 .
# Iterating from 1460 to 1465 out of 10000 .
# Iterating from 1465 to 1470 out of 10000 .
# Iterating from 1470 to 1475 out of 10000 .
# Iterating from 1475 to 1480 out of 10000 .
# Iterating from 1480 to 1485 out of 10000 .
# Iterating from 1485 to 1490 out of 10000 .
# Iterating from 1490 to 1495 out of 10000 .
# Iterating from 1495 to 1500 out of 10000 .
# Iterating from 1500 to 1505 out of 10000 .
# Iterating from 1505 to 1510 out of 10000 .
# Iterating from 1510 to 1515 out of 10000 .
# Iterating from 1515 to 1520 out of 10000 .
# Iterating from 1520 to 1525 out of 10000 .
# Iterating from 1525 to 1530 out of 10000 .
# Iterating from 1530 to 1535 out of 10000 .
# Iterating from 1535 to 1540 out of 10000 .
# Iterating from 1540 to 1545 out of 10000 .
# Iterating from 1545 to 1550 out of 10000 .
# Iterating from 1550 to 1555 out of 10000 .
# Iterating from 1555 to 1560 out of 10000 .
# Iterating from 1560 to 1565 out of 10000 .
# Iterating from 1565 to 1570 out of 10000 .
# Iterating from 1570 to 1575 out of 10000 .
# Iterating from 1575 to 1580 out of 10000 .
# Iterating from 1580 to 1585 out of 10000 .
# Iterating from 1585 to 1590 out of 10000 .
# Iterating from 1590 to 1595 out of 10000 .
# Iterating from 1595 to 1600 out of 10000 .
# Iterating from 1600 to 1605 out of 10000 .
# Iterating from 1605 to 1610 out of 10000 .
# Iterating from 1610 to 1615 out of 10000 .
# Iterating from 1615 to 1620 out of 10000 .
# Iterating from 1620 to 1625 out of 10000 .
# Iterating from 1625 to 1630 out of 10000 .
# Iterating from 1630 to 1635 out of 10000 .
# Iterating from 1635 to 1640 out of 10000 .
# Iterating from 1640 to 1645 out of 10000 .
# Iterating from 1645 to 1650 out of 10000 .
# Iterating from 1650 to 1655 out of 10000 .
# Iterating from 1655 to 1660 out of 10000 .
# Iterating from 1660 to 1665 out of 10000 .
# Iterating from 1665 to 1670 out of 10000 .
# Iterating from 1670 to 1675 out of 10000 .
# Iterating from 1675 to 1680 out of 10000 .
# Iterating from 1680 to 1685 out of 10000 .
# Iterating from 1685 to 1690 out of 10000 .
# Iterating from 1690 to 1695 out of 10000 .
# Iterating from 1695 to 1700 out of 10000 .
# Iterating from 1700 to 1705 out of 10000 .
# Iterating from 1705 to 1710 out of 10000 .
# Iterating from 1710 to 1715 out of 10000 .
# Iterating from 1715 to 1720 out of 10000 .
# Iterating from 1720 to 1725 out of 10000 .
# Iterating from 1725 to 1730 out of 10000 .
# Iterating from 1730 to 1735 out of 10000 .
# Iterating from 1735 to 1740 out of 10000 .
# Iterating from 1740 to 1745 out of 10000 .
# Iterating from 1745 to 1750 out of 10000 .
# Iterating from 1750 to 1755 out of 10000 .
# Iterating from 1755 to 1760 out of 10000 .
# Iterating from 1760 to 1765 out of 10000 .
# Iterating from 1765 to 1770 out of 10000 .
# Iterating from 1770 to 1775 out of 10000 .
# Iterating from 1775 to 1780 out of 10000 .
# Iterating from 1780 to 1785 out of 10000 .
# Iterating from 1785 to 1790 out of 10000 .
# Iterating from 1790 to 1795 out of 10000 .
# Iterating from 1795 to 1800 out of 10000 .
# Iterating from 1800 to 1805 out of 10000 .
# Iterating from 1805 to 1810 out of 10000 .
# Iterating from 1810 to 1815 out of 10000 .
# Iterating from 1815 to 1820 out of 10000 .
# Iterating from 1820 to 1825 out of 10000 .
# Iterating from 1825 to 1830 out of 10000 .
# Iterating from 1830 to 1835 out of 10000 .
# Iterating from 1835 to 1840 out of 10000 .
# Iterating from 1840 to 1845 out of 10000 .
# Iterating from 1845 to 1850 out of 10000 .
# Iterating from 1850 to 1855 out of 10000 .
# Iterating from 1855 to 1860 out of 10000 .
# Iterating from 1860 to 1865 out of 10000 .
# Iterating from 1865 to 1870 out of 10000 .
# Iterating from 1870 to 1875 out of 10000 .
# Iterating from 1875 to 1880 out of 10000 .
# Iterating from 1880 to 1885 out of 10000 .
# Iterating from 1885 to 1890 out of 10000 .
# Iterating from 1890 to 1895 out of 10000 .
# Iterating from 1895 to 1900 out of 10000 .
# Iterating from 1900 to 1905 out of 10000 .
# Iterating from 1905 to 1910 out of 10000 .
# Iterating from 1910 to 1915 out of 10000 .
# Iterating from 1915 to 1920 out of 10000 .
# Iterating from 1920 to 1925 out of 10000 .
# Iterating from 1925 to 1930 out of 10000 .
# Iterating from 1930 to 1935 out of 10000 .
# Iterating from 1935 to 1940 out of 10000 .
# Iterating from 1940 to 1945 out of 10000 .
# Iterating from 1945 to 1950 out of 10000 .
# Iterating from 1950 to 1955 out of 10000 .
# Iterating from 1955 to 1960 out of 10000 .
# Iterating from 1960 to 1965 out of 10000 .
# Iterating from 1965 to 1970 out of 10000 .
# Iterating from 1970 to 1975 out of 10000 .
# Iterating from 1975 to 1980 out of 10000 .
# Iterating from 1980 to 1985 out of 10000 .
# Iterating from 1985 to 1990 out of 10000 .
# Iterating from 1990 to 1995 out of 10000 .
# Iterating from 1995 to 2000 out of 10000 .
# Iterating from 2000 to 2005 out of 10000 .
# Iterating from 2005 to 2010 out of 10000 .
# Iterating from 2010 to 2015 out of 10000 .
# Iterating from 2015 to 2020 out of 10000 .
# Iterating from 2020 to 2025 out of 10000 .
# Iterating from 2025 to 2030 out of 10000 .
# Iterating from 2030 to 2035 out of 10000 .
# Iterating from 2035 to 2040 out of 10000 .
# Iterating from 2040 to 2045 out of 10000 .
# Iterating from 2045 to 2050 out of 10000 .
# Iterating from 2050 to 2055 out of 10000 .
# Iterating from 2055 to 2060 out of 10000 .
# Iterating from 2060 to 2065 out of 10000 .
# Iterating from 2065 to 2070 out of 10000 .
# Iterating from 2070 to 2075 out of 10000 .
# Iterating from 2075 to 2080 out of 10000 .
# Iterating from 2080 to 2085 out of 10000 .
# Iterating from 2085 to 2090 out of 10000 .
# Iterating from 2090 to 2095 out of 10000 .
# Iterating from 2095 to 2100 out of 10000 .
# Iterating from 2100 to 2105 out of 10000 .
# Iterating from 2105 to 2110 out of 10000 .
# Iterating from 2110 to 2115 out of 10000 .
# Iterating from 2115 to 2120 out of 10000 .
# Iterating from 2120 to 2125 out of 10000 .
# Iterating from 2125 to 2130 out of 10000 .
# Iterating from 2130 to 2135 out of 10000 .
# Iterating from 2135 to 2140 out of 10000 .
# Iterating from 2140 to 2145 out of 10000 .
# Iterating from 2145 to 2150 out of 10000 .
# Iterating from 2150 to 2155 out of 10000 .
# Iterating from 2155 to 2160 out of 10000 .
# Iterating from 2160 to 2165 out of 10000 .
# Iterating from 2165 to 2170 out of 10000 .
# Iterating from 2170 to 2175 out of 10000 .
# Iterating from 2175 to 2180 out of 10000 .
# Iterating from 2180 to 2185 out of 10000 .
# Iterating from 2185 to 2190 out of 10000 .
# Iterating from 2190 to 2195 out of 10000 .
# Iterating from 2195 to 2200 out of 10000 .
# Iterating from 2200 to 2205 out of 10000 .
# Iterating from 2205 to 2210 out of 10000 .
# Iterating from 2210 to 2215 out of 10000 .
# Iterating from 2215 to 2220 out of 10000 .
# Iterating from 2220 to 2225 out of 10000 .
# Iterating from 2225 to 2230 out of 10000 .
# Iterating from 2230 to 2235 out of 10000 .
# Iterating from 2235 to 2240 out of 10000 .
# Iterating from 2240 to 2245 out of 10000 .
# Iterating from 2245 to 2250 out of 10000 .
# Iterating from 2250 to 2255 out of 10000 .
# Iterating from 2255 to 2260 out of 10000 .
# Iterating from 2260 to 2265 out of 10000 .
# Iterating from 2265 to 2270 out of 10000 .
# Iterating from 2270 to 2275 out of 10000 .
# Iterating from 2275 to 2280 out of 10000 .
# Iterating from 2280 to 2285 out of 10000 .
# Iterating from 2285 to 2290 out of 10000 .
# Iterating from 2290 to 2295 out of 10000 .
# Iterating from 2295 to 2300 out of 10000 .
# Iterating from 2300 to 2305 out of 10000 .
# Iterating from 2305 to 2310 out of 10000 .
# Iterating from 2310 to 2315 out of 10000 .
# Iterating from 2315 to 2320 out of 10000 .
# Iterating from 2320 to 2325 out of 10000 .
# Iterating from 2325 to 2330 out of 10000 .
# Iterating from 2330 to 2335 out of 10000 .
# Iterating from 2335 to 2340 out of 10000 .
# Iterating from 2340 to 2345 out of 10000 .
# Iterating from 2345 to 2350 out of 10000 .
# Iterating from 2350 to 2355 out of 10000 .
# Iterating from 2355 to 2360 out of 10000 .
# Iterating from 2360 to 2365 out of 10000 .
# Iterating from 2365 to 2370 out of 10000 .
# Iterating from 2370 to 2375 out of 10000 .
# Iterating from 2375 to 2380 out of 10000 .
# Iterating from 2380 to 2385 out of 10000 .
# Iterating from 2385 to 2390 out of 10000 .
# Iterating from 2390 to 2395 out of 10000 .
# Iterating from 2395 to 2400 out of 10000 .
# Iterating from 2400 to 2405 out of 10000 .
# Iterating from 2405 to 2410 out of 10000 .
# Iterating from 2410 to 2415 out of 10000 .
# Iterating from 2415 to 2420 out of 10000 .
# Iterating from 2420 to 2425 out of 10000 .
# Iterating from 2425 to 2430 out of 10000 .
# Iterating from 2430 to 2435 out of 10000 .
# Iterating from 2435 to 2440 out of 10000 .
# Iterating from 2440 to 2445 out of 10000 .
# Iterating from 2445 to 2450 out of 10000 .
# Iterating from 2450 to 2455 out of 10000 .
# Iterating from 2455 to 2460 out of 10000 .
# Iterating from 2460 to 2465 out of 10000 .
# Iterating from 2465 to 2470 out of 10000 .
# Iterating from 2470 to 2475 out of 10000 .
# Iterating from 2475 to 2480 out of 10000 .
# Iterating from 2480 to 2485 out of 10000 .
# Iterating from 2485 to 2490 out of 10000 .
# Iterating from 2490 to 2495 out of 10000 .
# Iterating from 2495 to 2500 out of 10000 .
# Iterating from 2500 to 2505 out of 10000 .
# Iterating from 2505 to 2510 out of 10000 .
# Iterating from 2510 to 2515 out of 10000 .
# Iterating from 2515 to 2520 out of 10000 .
# Iterating from 2520 to 2525 out of 10000 .
# Iterating from 2525 to 2530 out of 10000 .
# Iterating from 2530 to 2535 out of 10000 .
# Iterating from 2535 to 2540 out of 10000 .
# Iterating from 2540 to 2545 out of 10000 .
# Iterating from 2545 to 2550 out of 10000 .
# Iterating from 2550 to 2555 out of 10000 .
# Iterating from 2555 to 2560 out of 10000 .
# Iterating from 2560 to 2565 out of 10000 .
# Iterating from 2565 to 2570 out of 10000 .
# Iterating from 2570 to 2575 out of 10000 .
# Iterating from 2575 to 2580 out of 10000 .
# Iterating from 2580 to 2585 out of 10000 .
# Iterating from 2585 to 2590 out of 10000 .
# Iterating from 2590 to 2595 out of 10000 .
# Iterating from 2595 to 2600 out of 10000 .
# Iterating from 2600 to 2605 out of 10000 .
# Iterating from 2605 to 2610 out of 10000 .
# Iterating from 2610 to 2615 out of 10000 .
# Iterating from 2615 to 2620 out of 10000 .
# Iterating from 2620 to 2625 out of 10000 .
# Iterating from 2625 to 2630 out of 10000 .
# Iterating from 2630 to 2635 out of 10000 .
# Iterating from 2635 to 2640 out of 10000 .
# Iterating from 2640 to 2645 out of 10000 .
# Iterating from 2645 to 2650 out of 10000 .
# Iterating from 2650 to 2655 out of 10000 .
# Iterating from 2655 to 2660 out of 10000 .
# Iterating from 2660 to 2665 out of 10000 .
# Iterating from 2665 to 2670 out of 10000 .
# Iterating from 2670 to 2675 out of 10000 .
# Iterating from 2675 to 2680 out of 10000 .
# Iterating from 2680 to 2685 out of 10000 .
# Iterating from 2685 to 2690 out of 10000 .
# Iterating from 2690 to 2695 out of 10000 .
# Iterating from 2695 to 2700 out of 10000 .
# Iterating from 2700 to 2705 out of 10000 .
# Iterating from 2705 to 2710 out of 10000 .
# Iterating from 2710 to 2715 out of 10000 .
# Iterating from 2715 to 2720 out of 10000 .
# Iterating from 2720 to 2725 out of 10000 .
# Iterating from 2725 to 2730 out of 10000 .
# Iterating from 2730 to 2735 out of 10000 .
# Iterating from 2735 to 2740 out of 10000 .
# Iterating from 2740 to 2745 out of 10000 .
# Iterating from 2745 to 2750 out of 10000 .
# Iterating from 2750 to 2755 out of 10000 .
# Iterating from 2755 to 2760 out of 10000 .
# Iterating from 2760 to 2765 out of 10000 .
# Iterating from 2765 to 2770 out of 10000 .
# Iterating from 2770 to 2775 out of 10000 .
# Iterating from 2775 to 2780 out of 10000 .
# Iterating from 2780 to 2785 out of 10000 .
# Iterating from 2785 to 2790 out of 10000 .
# Iterating from 2790 to 2795 out of 10000 .
# Iterating from 2795 to 2800 out of 10000 .
# Iterating from 2800 to 2805 out of 10000 .
# Iterating from 2805 to 2810 out of 10000 .
# Iterating from 2810 to 2815 out of 10000 .
# Iterating from 2815 to 2820 out of 10000 .
# Iterating from 2820 to 2825 out of 10000 .
# Iterating from 2825 to 2830 out of 10000 .
# Iterating from 2830 to 2835 out of 10000 .
# Iterating from 2835 to 2840 out of 10000 .
# Iterating from 2840 to 2845 out of 10000 .
# Iterating from 2845 to 2850 out of 10000 .
# Iterating from 2850 to 2855 out of 10000 .
# Iterating from 2855 to 2860 out of 10000 .
# Iterating from 2860 to 2865 out of 10000 .
# Iterating from 2865 to 2870 out of 10000 .
# Iterating from 2870 to 2875 out of 10000 .
# Iterating from 2875 to 2880 out of 10000 .
# Iterating from 2880 to 2885 out of 10000 .
# Iterating from 2885 to 2890 out of 10000 .
# Iterating from 2890 to 2895 out of 10000 .
# Iterating from 2895 to 2900 out of 10000 .
# Iterating from 2900 to 2905 out of 10000 .
# Iterating from 2905 to 2910 out of 10000 .
# Iterating from 2910 to 2915 out of 10000 .
# Iterating from 2915 to 2920 out of 10000 .
# Iterating from 2920 to 2925 out of 10000 .
# Iterating from 2925 to 2930 out of 10000 .
# Iterating from 2930 to 2935 out of 10000 .
# Iterating from 2935 to 2940 out of 10000 .
# Iterating from 2940 to 2945 out of 10000 .
# Iterating from 2945 to 2950 out of 10000 .
# Iterating from 2950 to 2955 out of 10000 .
# Iterating from 2955 to 2960 out of 10000 .
# Iterating from 2960 to 2965 out of 10000 .
# Iterating from 2965 to 2970 out of 10000 .
# Iterating from 2970 to 2975 out of 10000 .
# Iterating from 2975 to 2980 out of 10000 .
# Iterating from 2980 to 2985 out of 10000 .
# Iterating from 2985 to 2990 out of 10000 .
# Iterating from 2990 to 2995 out of 10000 .
# Iterating from 2995 to 3000 out of 10000 .
# Iterating from 3000 to 3005 out of 10000 .
# Iterating from 3005 to 3010 out of 10000 .
# Iterating from 3010 to 3015 out of 10000 .
# Iterating from 3015 to 3020 out of 10000 .
# Iterating from 3020 to 3025 out of 10000 .
# Iterating from 3025 to 3030 out of 10000 .
# Iterating from 3030 to 3035 out of 10000 .
# Iterating from 3035 to 3040 out of 10000 .
# Iterating from 3040 to 3045 out of 10000 .
# Iterating from 3045 to 3050 out of 10000 .
# Iterating from 3050 to 3055 out of 10000 .
# Iterating from 3055 to 3060 out of 10000 .
# Iterating from 3060 to 3065 out of 10000 .
# Iterating from 3065 to 3070 out of 10000 .
# Iterating from 3070 to 3075 out of 10000 .
# Iterating from 3075 to 3080 out of 10000 .
# Iterating from 3080 to 3085 out of 10000 .
# Iterating from 3085 to 3090 out of 10000 .
# Iterating from 3090 to 3095 out of 10000 .
# Iterating from 3095 to 3100 out of 10000 .
# Iterating from 3100 to 3105 out of 10000 .
# Iterating from 3105 to 3110 out of 10000 .
# Iterating from 3110 to 3115 out of 10000 .
# Iterating from 3115 to 3120 out of 10000 .
# Iterating from 3120 to 3125 out of 10000 .
# Iterating from 3125 to 3130 out of 10000 .
# Iterating from 3130 to 3135 out of 10000 .
# Iterating from 3135 to 3140 out of 10000 .
# Iterating from 3140 to 3145 out of 10000 .
# Iterating from 3145 to 3150 out of 10000 .
# Iterating from 3150 to 3155 out of 10000 .
# Iterating from 3155 to 3160 out of 10000 .
# Iterating from 3160 to 3165 out of 10000 .
# Iterating from 3165 to 3170 out of 10000 .
# Iterating from 3170 to 3175 out of 10000 .
# Iterating from 3175 to 3180 out of 10000 .
# Iterating from 3180 to 3185 out of 10000 .
# Iterating from 3185 to 3190 out of 10000 .
# Iterating from 3190 to 3195 out of 10000 .
# Iterating from 3195 to 3200 out of 10000 .
# Iterating from 3200 to 3205 out of 10000 .
# Iterating from 3205 to 3210 out of 10000 .
# Iterating from 3210 to 3215 out of 10000 .
# Iterating from 3215 to 3220 out of 10000 .
# Iterating from 3220 to 3225 out of 10000 .
# Iterating from 3225 to 3230 out of 10000 .
# Iterating from 3230 to 3235 out of 10000 .
# Iterating from 3235 to 3240 out of 10000 .
# Iterating from 3240 to 3245 out of 10000 .
# Iterating from 3245 to 3250 out of 10000 .
# Iterating from 3250 to 3255 out of 10000 .
# Iterating from 3255 to 3260 out of 10000 .
# Iterating from 3260 to 3265 out of 10000 .
# Iterating from 3265 to 3270 out of 10000 .
# Iterating from 3270 to 3275 out of 10000 .
# Iterating from 3275 to 3280 out of 10000 .
# Iterating from 3280 to 3285 out of 10000 .
# Iterating from 3285 to 3290 out of 10000 .
# Iterating from 3290 to 3295 out of 10000 .
# Iterating from 3295 to 3300 out of 10000 .
# Iterating from 3300 to 3305 out of 10000 .
# Iterating from 3305 to 3310 out of 10000 .
# Iterating from 3310 to 3315 out of 10000 .
# Iterating from 3315 to 3320 out of 10000 .
# Iterating from 3320 to 3325 out of 10000 .
# Iterating from 3325 to 3330 out of 10000 .
# Iterating from 3330 to 3335 out of 10000 .
# Iterating from 3335 to 3340 out of 10000 .
# Iterating from 3340 to 3345 out of 10000 .
# Iterating from 3345 to 3350 out of 10000 .
# Iterating from 3350 to 3355 out of 10000 .
# Iterating from 3355 to 3360 out of 10000 .
# Iterating from 3360 to 3365 out of 10000 .
# Iterating from 3365 to 3370 out of 10000 .
# Iterating from 3370 to 3375 out of 10000 .
# Iterating from 3375 to 3380 out of 10000 .
# Iterating from 3380 to 3385 out of 10000 .
# Iterating from 3385 to 3390 out of 10000 .
# Iterating from 3390 to 3395 out of 10000 .
# Iterating from 3395 to 3400 out of 10000 .
# Iterating from 3400 to 3405 out of 10000 .
# Iterating from 3405 to 3410 out of 10000 .
# Iterating from 3410 to 3415 out of 10000 .
# Iterating from 3415 to 3420 out of 10000 .
# Iterating from 3420 to 3425 out of 10000 .
# Iterating from 3425 to 3430 out of 10000 .
# Iterating from 3430 to 3435 out of 10000 .
# Iterating from 3435 to 3440 out of 10000 .
# Iterating from 3440 to 3445 out of 10000 .
# Iterating from 3445 to 3450 out of 10000 .
# Iterating from 3450 to 3455 out of 10000 .
# Iterating from 3455 to 3460 out of 10000 .
# Iterating from 3460 to 3465 out of 10000 .
# Iterating from 3465 to 3470 out of 10000 .
# Iterating from 3470 to 3475 out of 10000 .
# Iterating from 3475 to 3480 out of 10000 .
# Iterating from 3480 to 3485 out of 10000 .
# Iterating from 3485 to 3490 out of 10000 .
# Iterating from 3490 to 3495 out of 10000 .
# Iterating from 3495 to 3500 out of 10000 .
# Iterating from 3500 to 3505 out of 10000 .
# Iterating from 3505 to 3510 out of 10000 .
# Iterating from 3510 to 3515 out of 10000 .
# Iterating from 3515 to 3520 out of 10000 .
# Iterating from 3520 to 3525 out of 10000 .
# Iterating from 3525 to 3530 out of 10000 .
# Iterating from 3530 to 3535 out of 10000 .
# Iterating from 3535 to 3540 out of 10000 .
# Iterating from 3540 to 3545 out of 10000 .
# Iterating from 3545 to 3550 out of 10000 .
# Iterating from 3550 to 3555 out of 10000 .
# Iterating from 3555 to 3560 out of 10000 .
# Iterating from 3560 to 3565 out of 10000 .
# Iterating from 3565 to 3570 out of 10000 .
# Iterating from 3570 to 3575 out of 10000 .
# Iterating from 3575 to 3580 out of 10000 .
# Iterating from 3580 to 3585 out of 10000 .
# Iterating from 3585 to 3590 out of 10000 .
# Iterating from 3590 to 3595 out of 10000 .
# Iterating from 3595 to 3600 out of 10000 .
# Iterating from 3600 to 3605 out of 10000 .
# Iterating from 3605 to 3610 out of 10000 .
# Iterating from 3610 to 3615 out of 10000 .
# Iterating from 3615 to 3620 out of 10000 .
# Iterating from 3620 to 3625 out of 10000 .
# Iterating from 3625 to 3630 out of 10000 .
# Iterating from 3630 to 3635 out of 10000 .
# Iterating from 3635 to 3640 out of 10000 .
# Iterating from 3640 to 3645 out of 10000 .
# Iterating from 3645 to 3650 out of 10000 .
# Iterating from 3650 to 3655 out of 10000 .
# Iterating from 3655 to 3660 out of 10000 .
# Iterating from 3660 to 3665 out of 10000 .
# Iterating from 3665 to 3670 out of 10000 .
# Iterating from 3670 to 3675 out of 10000 .
# Iterating from 3675 to 3680 out of 10000 .
# Iterating from 3680 to 3685 out of 10000 .
# Iterating from 3685 to 3690 out of 10000 .
# Iterating from 3690 to 3695 out of 10000 .
# Iterating from 3695 to 3700 out of 10000 .
# Iterating from 3700 to 3705 out of 10000 .
# Iterating from 3705 to 3710 out of 10000 .
# Iterating from 3710 to 3715 out of 10000 .
# Iterating from 3715 to 3720 out of 10000 .
# Iterating from 3720 to 3725 out of 10000 .
# Iterating from 3725 to 3730 out of 10000 .
# Iterating from 3730 to 3735 out of 10000 .
# Iterating from 3735 to 3740 out of 10000 .
# Iterating from 3740 to 3745 out of 10000 .
# Iterating from 3745 to 3750 out of 10000 .
# Iterating from 3750 to 3755 out of 10000 .
# Iterating from 3755 to 3760 out of 10000 .
# Iterating from 3760 to 3765 out of 10000 .
# Iterating from 3765 to 3770 out of 10000 .
# Iterating from 3770 to 3775 out of 10000 .
# Iterating from 3775 to 3780 out of 10000 .
# Iterating from 3780 to 3785 out of 10000 .
# Iterating from 3785 to 3790 out of 10000 .
# Iterating from 3790 to 3795 out of 10000 .
# Iterating from 3795 to 3800 out of 10000 .
# Iterating from 3800 to 3805 out of 10000 .
# Iterating from 3805 to 3810 out of 10000 .
# Iterating from 3810 to 3815 out of 10000 .
# Iterating from 3815 to 3820 out of 10000 .
# Iterating from 3820 to 3825 out of 10000 .
# Iterating from 3825 to 3830 out of 10000 .
# Iterating from 3830 to 3835 out of 10000 .
# Iterating from 3835 to 3840 out of 10000 .
# Iterating from 3840 to 3845 out of 10000 .
# Iterating from 3845 to 3850 out of 10000 .
# Iterating from 3850 to 3855 out of 10000 .
# Iterating from 3855 to 3860 out of 10000 .
# Iterating from 3860 to 3865 out of 10000 .
# Iterating from 3865 to 3870 out of 10000 .
# Iterating from 3870 to 3875 out of 10000 .
# Iterating from 3875 to 3880 out of 10000 .
# Iterating from 3880 to 3885 out of 10000 .
# Iterating from 3885 to 3890 out of 10000 .
# Iterating from 3890 to 3895 out of 10000 .
# Iterating from 3895 to 3900 out of 10000 .
# Iterating from 3900 to 3905 out of 10000 .
# Iterating from 3905 to 3910 out of 10000 .
# Iterating from 3910 to 3915 out of 10000 .
# Iterating from 3915 to 3920 out of 10000 .
# Iterating from 3920 to 3925 out of 10000 .
# Iterating from 3925 to 3930 out of 10000 .
# Iterating from 3930 to 3935 out of 10000 .
# Iterating from 3935 to 3940 out of 10000 .
# Iterating from 3940 to 3945 out of 10000 .
# Iterating from 3945 to 3950 out of 10000 .
# Iterating from 3950 to 3955 out of 10000 .
# Iterating from 3955 to 3960 out of 10000 .
# Iterating from 3960 to 3965 out of 10000 .
# Iterating from 3965 to 3970 out of 10000 .
# Iterating from 3970 to 3975 out of 10000 .
# Iterating from 3975 to 3980 out of 10000 .
# Iterating from 3980 to 3985 out of 10000 .
# Iterating from 3985 to 3990 out of 10000 .
# Iterating from 3990 to 3995 out of 10000 .
# Iterating from 3995 to 4000 out of 10000 .
# Iterating from 4000 to 4005 out of 10000 .
# Iterating from 4005 to 4010 out of 10000 .
# Iterating from 4010 to 4015 out of 10000 .
# Iterating from 4015 to 4020 out of 10000 .
# Iterating from 4020 to 4025 out of 10000 .
# Iterating from 4025 to 4030 out of 10000 .
# Iterating from 4030 to 4035 out of 10000 .
# Iterating from 4035 to 4040 out of 10000 .
# Iterating from 4040 to 4045 out of 10000 .
# Iterating from 4045 to 4050 out of 10000 .
# Iterating from 4050 to 4055 out of 10000 .
# Iterating from 4055 to 4060 out of 10000 .
# Iterating from 4060 to 4065 out of 10000 .
# Iterating from 4065 to 4070 out of 10000 .
# Iterating from 4070 to 4075 out of 10000 .
# Iterating from 4075 to 4080 out of 10000 .
# Iterating from 4080 to 4085 out of 10000 .
# Iterating from 4085 to 4090 out of 10000 .
# Iterating from 4090 to 4095 out of 10000 .
# Iterating from 4095 to 4100 out of 10000 .
# Iterating from 4100 to 4105 out of 10000 .
# Iterating from 4105 to 4110 out of 10000 .
# Iterating from 4110 to 4115 out of 10000 .
# Iterating from 4115 to 4120 out of 10000 .
# Iterating from 4120 to 4125 out of 10000 .
# Iterating from 4125 to 4130 out of 10000 .
# Iterating from 4130 to 4135 out of 10000 .
# Iterating from 4135 to 4140 out of 10000 .
# Iterating from 4140 to 4145 out of 10000 .
# Iterating from 4145 to 4150 out of 10000 .
# Iterating from 4150 to 4155 out of 10000 .
# Iterating from 4155 to 4160 out of 10000 .
# Iterating from 4160 to 4165 out of 10000 .
# Iterating from 4165 to 4170 out of 10000 .
# Iterating from 4170 to 4175 out of 10000 .
# Iterating from 4175 to 4180 out of 10000 .
# Iterating from 4180 to 4185 out of 10000 .
# Iterating from 4185 to 4190 out of 10000 .
# Iterating from 4190 to 4195 out of 10000 .
# Iterating from 4195 to 4200 out of 10000 .
# Iterating from 4200 to 4205 out of 10000 .
# Iterating from 4205 to 4210 out of 10000 .
# Iterating from 4210 to 4215 out of 10000 .
# Iterating from 4215 to 4220 out of 10000 .
# Iterating from 4220 to 4225 out of 10000 .
# Iterating from 4225 to 4230 out of 10000 .
# Iterating from 4230 to 4235 out of 10000 .
# Iterating from 4235 to 4240 out of 10000 .
# Iterating from 4240 to 4245 out of 10000 .
# Iterating from 4245 to 4250 out of 10000 .
# Iterating from 4250 to 4255 out of 10000 .
# Iterating from 4255 to 4260 out of 10000 .
# Iterating from 4260 to 4265 out of 10000 .
# Iterating from 4265 to 4270 out of 10000 .
# Iterating from 4270 to 4275 out of 10000 .
# Iterating from 4275 to 4280 out of 10000 .
# Iterating from 4280 to 4285 out of 10000 .
# Iterating from 4285 to 4290 out of 10000 .
# Iterating from 4290 to 4295 out of 10000 .
# Iterating from 4295 to 4300 out of 10000 .
# Iterating from 4300 to 4305 out of 10000 .
# Iterating from 4305 to 4310 out of 10000 .
# Iterating from 4310 to 4315 out of 10000 .
# Iterating from 4315 to 4320 out of 10000 .
# Iterating from 4320 to 4325 out of 10000 .
# Iterating from 4325 to 4330 out of 10000 .
# Iterating from 4330 to 4335 out of 10000 .
# Iterating from 4335 to 4340 out of 10000 .
# Iterating from 4340 to 4345 out of 10000 .
# Iterating from 4345 to 4350 out of 10000 .
# Iterating from 4350 to 4355 out of 10000 .
# Iterating from 4355 to 4360 out of 10000 .
# Iterating from 4360 to 4365 out of 10000 .
# Iterating from 4365 to 4370 out of 10000 .
# Iterating from 4370 to 4375 out of 10000 .
# Iterating from 4375 to 4380 out of 10000 .
# Iterating from 4380 to 4385 out of 10000 .
# Iterating from 4385 to 4390 out of 10000 .
# Iterating from 4390 to 4395 out of 10000 .
# Iterating from 4395 to 4400 out of 10000 .
# Iterating from 4400 to 4405 out of 10000 .
# Iterating from 4405 to 4410 out of 10000 .
# Iterating from 4410 to 4415 out of 10000 .
# Iterating from 4415 to 4420 out of 10000 .
# Iterating from 4420 to 4425 out of 10000 .
# Iterating from 4425 to 4430 out of 10000 .
# Iterating from 4430 to 4435 out of 10000 .
# Iterating from 4435 to 4440 out of 10000 .
# Iterating from 4440 to 4445 out of 10000 .
# Iterating from 4445 to 4450 out of 10000 .
# Iterating from 4450 to 4455 out of 10000 .
# Iterating from 4455 to 4460 out of 10000 .
# Iterating from 4460 to 4465 out of 10000 .
# Iterating from 4465 to 4470 out of 10000 .
# Iterating from 4470 to 4475 out of 10000 .
# Iterating from 4475 to 4480 out of 10000 .
# Iterating from 4480 to 4485 out of 10000 .
# Iterating from 4485 to 4490 out of 10000 .
# Iterating from 4490 to 4495 out of 10000 .
# Iterating from 4495 to 4500 out of 10000 .
# Iterating from 4500 to 4505 out of 10000 .
# Iterating from 4505 to 4510 out of 10000 .
# Iterating from 4510 to 4515 out of 10000 .
# Iterating from 4515 to 4520 out of 10000 .
# Iterating from 4520 to 4525 out of 10000 .
# Iterating from 4525 to 4530 out of 10000 .
# Iterating from 4530 to 4535 out of 10000 .
# Iterating from 4535 to 4540 out of 10000 .
# Iterating from 4540 to 4545 out of 10000 .
# Iterating from 4545 to 4550 out of 10000 .
# Iterating from 4550 to 4555 out of 10000 .
# Iterating from 4555 to 4560 out of 10000 .
# Iterating from 4560 to 4565 out of 10000 .
# Iterating from 4565 to 4570 out of 10000 .
# Iterating from 4570 to 4575 out of 10000 .
# Iterating from 4575 to 4580 out of 10000 .
# Iterating from 4580 to 4585 out of 10000 .
# Iterating from 4585 to 4590 out of 10000 .
# Iterating from 4590 to 4595 out of 10000 .
# Iterating from 4595 to 4600 out of 10000 .
# Iterating from 4600 to 4605 out of 10000 .
# ...
# Iterating from 8795 to 8800 out of 10000 .
# Iterating from 8800 to 8805 out of 10000 .
# Iterating from 8805 to 8810 out of 10000 .
# Iterating from 8810 to 8815 out of 10000 .
# Iterating from 8815 to 8820 out of 10000 .
# Iterating from 8820 to 8825 out of 10000 .
# Iterating from 8825 to 8830 out of 10000 .
# Iterating from 8830 to 8835 out of 10000 .
# Iterating from 8835 to 8840 out of 10000 .
# Iterating from 8840 to 8845 out of 10000 .
# Iterating from 8845 to 8850 out of 10000 .
# Iterating from 8850 to 8855 out of 10000 .
# Iterating from 8855 to 8860 out of 10000 .
# Iterating from 8860 to 8865 out of 10000 .
# Iterating from 8865 to 8870 out of 10000 .
# Iterating from 8870 to 8875 out of 10000 .
# Iterating from 8875 to 8880 out of 10000 .
# Iterating from 8880 to 8885 out of 10000 .
# Iterating from 8885 to 8890 out of 10000 .
# Iterating from 8890 to 8895 out of 10000 .
# Iterating from 8895 to 8900 out of 10000 .
# Iterating from 8900 to 8905 out of 10000 .
# Iterating from 8905 to 8910 out of 10000 .
# Iterating from 8910 to 8915 out of 10000 .
# Iterating from 8915 to 8920 out of 10000 .
# Iterating from 8920 to 8925 out of 10000 .
# Iterating from 8925 to 8930 out of 10000 .
# Iterating from 8930 to 8935 out of 10000 .
# Iterating from 8935 to 8940 out of 10000 .
# Iterating from 8940 to 8945 out of 10000 .
# Iterating from 8945 to 8950 out of 10000 .
# Iterating from 8950 to 8955 out of 10000 .
# Iterating from 8955 to 8960 out of 10000 .
# Iterating from 8960 to 8965 out of 10000 .
# Iterating from 8965 to 8970 out of 10000 .
# Iterating from 8970 to 8975 out of 10000 .
# Iterating from 8975 to 8980 out of 10000 .
# Iterating from 8980 to 8985 out of 10000 .
# Iterating from 8985 to 8990 out of 10000 .
# Iterating from 8990 to 8995 out of 10000 .
# Iterating from 8995 to 9000 out of 10000 .
# Iterating from 9000 to 9005 out of 10000 .
# Iterating from 9005 to 9010 out of 10000 .
# Iterating from 9010 to 9015 out of 10000 .
# Iterating from 9015 to 9020 out of 10000 .
# Iterating from 9020 to 9025 out of 10000 .
# Iterating from 9025 to 9030 out of 10000 .
# Iterating from 9030 to 9035 out of 10000 .
# Iterating from 9035 to 9040 out of 10000 .
# Iterating from 9040 to 9045 out of 10000 .
# Iterating from 9045 to 9050 out of 10000 .
# Iterating from 9050 to 9055 out of 10000 .
# Iterating from 9055 to 9060 out of 10000 .
# Iterating from 9060 to 9065 out of 10000 .
# Iterating from 9065 to 9070 out of 10000 .
# Iterating from 9070 to 9075 out of 10000 .
# Iterating from 9075 to 9080 out of 10000 .
# Iterating from 9080 to 9085 out of 10000 .
# Iterating from 9085 to 9090 out of 10000 .
# Iterating from 9090 to 9095 out of 10000 .
# Iterating from 9095 to 9100 out of 10000 .
# Iterating from 9100 to 9105 out of 10000 .
# Iterating from 9105 to 9110 out of 10000 .
# Iterating from 9110 to 9115 out of 10000 .
# Iterating from 9115 to 9120 out of 10000 .
# Iterating from 9120 to 9125 out of 10000 .
# Iterating from 9125 to 9130 out of 10000 .
# Iterating from 9130 to 9135 out of 10000 .
# Iterating from 9135 to 9140 out of 10000 .
# Iterating from 9140 to 9145 out of 10000 .
# Iterating from 9145 to 9150 out of 10000 .
# Iterating from 9150 to 9155 out of 10000 .
# Iterating from 9155 to 9160 out of 10000 .
# Iterating from 9160 to 9165 out of 10000 .
# Iterating from 9165 to 9170 out of 10000 .
# Iterating from 9170 to 9175 out of 10000 .
# Iterating from 9175 to 9180 out of 10000 .
# Iterating from 9180 to 9185 out of 10000 .
# Iterating from 9185 to 9190 out of 10000 .
# Iterating from 9190 to 9195 out of 10000 .
# Iterating from 9195 to 9200 out of 10000 .
# Iterating from 9200 to 9205 out of 10000 .
# Iterating from 9205 to 9210 out of 10000 .
# Iterating from 9210 to 9215 out of 10000 .
# Iterating from 9215 to 9220 out of 10000 .
# Iterating from 9220 to 9225 out of 10000 .
# Iterating from 9225 to 9230 out of 10000 .
# Iterating from 9230 to 9235 out of 10000 .
# Iterating from 9235 to 9240 out of 10000 .
# Iterating from 9240 to 9245 out of 10000 .
# Iterating from 9245 to 9250 out of 10000 .
# Iterating from 9250 to 9255 out of 10000 .
# Iterating from 9255 to 9260 out of 10000 .
# Iterating from 9260 to 9265 out of 10000 .
# Iterating from 9265 to 9270 out of 10000 .
# Iterating from 9270 to 9275 out of 10000 .
# Iterating from 9275 to 9280 out of 10000 .
# Iterating from 9280 to 9285 out of 10000 .
# Iterating from 9285 to 9290 out of 10000 .
# Iterating from 9290 to 9295 out of 10000 .
# Iterating from 9295 to 9300 out of 10000 .
# Iterating from 9300 to 9305 out of 10000 .
# Iterating from 9305 to 9310 out of 10000 .
# Iterating from 9310 to 9315 out of 10000 .
# Iterating from 9315 to 9320 out of 10000 .
# Iterating from 9320 to 9325 out of 10000 .
# Iterating from 9325 to 9330 out of 10000 .
# Iterating from 9330 to 9335 out of 10000 .
# Iterating from 9335 to 9340 out of 10000 .
# Iterating from 9340 to 9345 out of 10000 .
# Iterating from 9345 to 9350 out of 10000 .
# Iterating from 9350 to 9355 out of 10000 .
# Iterating from 9355 to 9360 out of 10000 .
# Iterating from 9360 to 9365 out of 10000 .
# Iterating from 9365 to 9370 out of 10000 .
# Iterating from 9370 to 9375 out of 10000 .
# Iterating from 9375 to 9380 out of 10000 .
# Iterating from 9380 to 9385 out of 10000 .
# Iterating from 9385 to 9390 out of 10000 .
# Iterating from 9390 to 9395 out of 10000 .
# Iterating from 9395 to 9400 out of 10000 .
# Iterating from 9400 to 9405 out of 10000 .
# Iterating from 9405 to 9410 out of 10000 .
# Iterating from 9410 to 9415 out of 10000 .
# Iterating from 9415 to 9420 out of 10000 .
# Iterating from 9420 to 9425 out of 10000 .
# Iterating from 9425 to 9430 out of 10000 .
# Iterating from 9430 to 9435 out of 10000 .
# Iterating from 9435 to 9440 out of 10000 .
# Iterating from 9440 to 9445 out of 10000 .
# Iterating from 9445 to 9450 out of 10000 .
# Iterating from 9450 to 9455 out of 10000 .
# Iterating from 9455 to 9460 out of 10000 .
# Iterating from 9460 to 9465 out of 10000 .
# Iterating from 9465 to 9470 out of 10000 .
# Iterating from 9470 to 9475 out of 10000 .
# Iterating from 9475 to 9480 out of 10000 .
# Iterating from 9480 to 9485 out of 10000 .
# Iterating from 9485 to 9490 out of 10000 .
# Iterating from 9490 to 9495 out of 10000 .
# Iterating from 9495 to 9500 out of 10000 .
# Iterating from 9500 to 9505 out of 10000 .
# Iterating from 9505 to 9510 out of 10000 .
# Iterating from 9510 to 9515 out of 10000 .
# Iterating from 9515 to 9520 out of 10000 .
# Iterating from 9520 to 9525 out of 10000 .
# Iterating from 9525 to 9530 out of 10000 .
# Iterating from 9530 to 9535 out of 10000 .
# Iterating from 9535 to 9540 out of 10000 .
# Iterating from 9540 to 9545 out of 10000 .
# Iterating from 9545 to 9550 out of 10000 .
# Iterating from 9550 to 9555 out of 10000 .
# Iterating from 9555 to 9560 out of 10000 .
# Iterating from 9560 to 9565 out of 10000 .
# Iterating from 9565 to 9570 out of 10000 .
# Iterating from 9570 to 9575 out of 10000 .
# Iterating from 9575 to 9580 out of 10000 .
# Iterating from 9580 to 9585 out of 10000 .
# Iterating from 9585 to 9590 out of 10000 .
# Iterating from 9590 to 9595 out of 10000 .
# Iterating from 9595 to 9600 out of 10000 .
# Iterating from 9600 to 9605 out of 10000 .
# Iterating from 9605 to 9610 out of 10000 .
# Iterating from 9610 to 9615 out of 10000 .
# Iterating from 9615 to 9620 out of 10000 .
# Iterating from 9620 to 9625 out of 10000 .
# Iterating from 9625 to 9630 out of 10000 .
# Iterating from 9630 to 9635 out of 10000 .
# Iterating from 9635 to 9640 out of 10000 .
# Iterating from 9640 to 9645 out of 10000 .
# Iterating from 9645 to 9650 out of 10000 .
# Iterating from 9650 to 9655 out of 10000 .
# Iterating from 9655 to 9660 out of 10000 .
# Iterating from 9660 to 9665 out of 10000 .
# Iterating from 9665 to 9670 out of 10000 .
# Iterating from 9670 to 9675 out of 10000 .
# Iterating from 9675 to 9680 out of 10000 .
# Iterating from 9680 to 9685 out of 10000 .
# Iterating from 9685 to 9690 out of 10000 .
# Iterating from 9690 to 9695 out of 10000 .
# Iterating from 9695 to 9700 out of 10000 .
# Iterating from 9700 to 9705 out of 10000 .
# Iterating from 9705 to 9710 out of 10000 .
# Iterating from 9710 to 9715 out of 10000 .
# Iterating from 9715 to 9720 out of 10000 .
# Iterating from 9720 to 9725 out of 10000 .
# Iterating from 9725 to 9730 out of 10000 .
# Iterating from 9730 to 9735 out of 10000 .
# Iterating from 9735 to 9740 out of 10000 .
# Iterating from 9740 to 9745 out of 10000 .
# Iterating from 9745 to 9750 out of 10000 .
# Iterating from 9750 to 9755 out of 10000 .
# Iterating from 9755 to 9760 out of 10000 .
# Iterating from 9760 to 9765 out of 10000 .
# Iterating from 9765 to 9770 out of 10000 .
# Iterating from 9770 to 9775 out of 10000 .
# Iterating from 9775 to 9780 out of 10000 .
# Iterating from 9780 to 9785 out of 10000 .
# Iterating from 9785 to 9790 out of 10000 .
# Iterating from 9790 to 9795 out of 10000 .
# Iterating from 9795 to 9800 out of 10000 .
# Iterating from 9800 to 9805 out of 10000 .
# Iterating from 9805 to 9810 out of 10000 .
# Iterating from 9810 to 9815 out of 10000 .
# Iterating from 9815 to 9820 out of 10000 .
# Iterating from 9820 to 9825 out of 10000 .
# Iterating from 9825 to 9830 out of 10000 .
# Iterating from 9830 to 9835 out of 10000 .
# Iterating from 9835 to 9840 out of 10000 .
# Iterating from 9840 to 9845 out of 10000 .
# Iterating from 9845 to 9850 out of 10000 .
# Iterating from 9850 to 9855 out of 10000 .
# Iterating from 9855 to 9860 out of 10000 .
# Iterating from 9860 to 9865 out of 10000 .
# Iterating from 9865 to 9870 out of 10000 .
# Iterating from 9870 to 9875 out of 10000 .
# Iterating from 9875 to 9880 out of 10000 .
# Iterating from 9880 to 9885 out of 10000 .
# Iterating from 9885 to 9890 out of 10000 .
# Iterating from 9890 to 9895 out of 10000 .
# Iterating from 9895 to 9900 out of 10000 .
# Iterating from 9900 to 9905 out of 10000 .
# Iterating from 9905 to 9910 out of 10000 .
# Iterating from 9910 to 9915 out of 10000 .
# Iterating from 9915 to 9920 out of 10000 .
# Iterating from 9920 to 9925 out of 10000 .
# Iterating from 9925 to 9930 out of 10000 .
# Iterating from 9930 to 9935 out of 10000 .
# Iterating from 9935 to 9940 out of 10000 .
# Iterating from 9940 to 9945 out of 10000 .
# Iterating from 9945 to 9950 out of 10000 .
# Iterating from 9950 to 9955 out of 10000 .
# Iterating from 9955 to 9960 out of 10000 .
# Iterating from 9960 to 9965 out of 10000 .
# Iterating from 9965 to 9970 out of 10000 .
# Iterating from 9970 to 9975 out of 10000 .
# Iterating from 9975 to 9980 out of 10000 .
# Iterating from 9980 to 9985 out of 10000 .
# Iterating from 9985 to 9990 out of 10000 .
# Iterating from 9990 to 9995 out of 10000 .
# Iterating from 9995 to 10000 out of 10000 .
# MMD metric calculation completed in 1277.3940396041144 seconds.
# Saving mmd to results/5D_mixture/5D_20K/null_hypothesis/MMD.json
# Computing and savng ks with max_vectorize = 10000
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7fa9fd505bc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# KS tests calculation completed in 40.32316223694943 seconds.
# Saving ks to results/5D_mixture/5D_20K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 500
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fa8b4129b20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2500 to 3000 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fa8b4129b20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# SKS metric calculation completed in 379.087874280056 seconds.
# Saving sks to results/5D_mixture/5D_20K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 500
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# SWD metric calculation completed in 282.77236768906005 seconds.
# Saving swd to results/5D_mixture/5D_20K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0004589131872192923], [0.95, [9500, 500], 0.006191613537014557], [0.99, [9900, 100], 0.011884887241794997]]
# Computing time for metric fgd: 579.3097427510656
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.019219401732470942], [0.95, [9500, 500], 0.30224333383080193], [0.99, [9900, 100], 0.564192733427376]]
# Computing time for metric mmd: 1277.3940396041144
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9230020642280578], [0.95, [9500, 500], 1.167001724243164], [0.99, [9900, 100], 1.3409990072250366]]
# Computing time for metric ks: 40.32316223694943
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9172504767775536], [0.95, [9500, 500], 1.172300335019827], [0.99, [9900, 100], 1.358750369399786]]
# Computing time for metric sks: 379.087874280056
# ThresholdS for metric swd: [[0.68, [6800, 3199], 1.0304382303304764], [0.95, [9500, 500], 1.5704415986452431], [0.99, [9900, 100], 1.9548155201110047]]
# Computing time for metric swd: 282.77236768906005
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fa91daec0e0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fa91daec180>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fa91daec220>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fa91daec2c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fa91daec360>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fa91daec400>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              5
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...           1000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_mixture/5D_20K/null_hypothesis/FGD....
# 1  $d_{\mathrm{MMD}}$  results/5D_mixture/5D_20K/null_hypothesis/MMD....
# 2      $\overline{D}$  results/5D_mixture/5D_20K/null_hypothesis/KS.json
# 3     $\widetilde{D}$  results/5D_mixture/5D_20K/null_hypothesis/SKS....
# 4     $\widetilde{W}$  results/5D_mixture/5D_20K/null_hypothesis/SWD....
# 5           $t_{\mu}$  results/5D_mixture/5D_20K/null_hypothesis/LR.json
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0004589131872192923], ...
# 1  [[0.68, [6800, 3199], 0.019219401732470942], [...
# 2  [[0.68, [6800, 3199], 0.9230020642280578], [0....
# 3  [[0.68, [6800, 3199], 0.9172504767775536], [0....
# 4  [[0.68, [6800, 3199], 1.0304382303304764], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{2})$"
        dist_null = dist_null * 100
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.11502432200966459 +/- 0.0006036815719526573
# sigma = 0.2456993227407551 +/- 0.005127462126728607
# 68%CL = 0.04589131872192923, 95%CL = 0.6191613537014558, 99%CL = 1.1884887241794997
# mu = 0.11502432200966459 +/- 0.0006036815719526573
# sigma = 0.2456993227407551 +/- 0.005127462126728607
# /tmp/ipykernel_958226/3311202556.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_958226/3311202556.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_958226/3311202556.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2720147180370986 seconds.
# mu = -0.0003175401369258907 +/- 0.00023486772648704358
# sigma = 0.1532539482320255 +/- 0.00215959285796481
# 68%CL = 0.019219401732470942, 95%CL = 0.30224333383080193, 99%CL = 0.564192733427376
# mu = -0.0003175401369258907 +/- 0.00023486772648704358
# sigma = 0.1532539482320255 +/- 0.00215959285796481
# /tmp/ipykernel_958226/3311202556.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_958226/3311202556.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_958226/3311202556.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.8944580650422722 seconds.
# mu = 0.8698913754150271 +/- 0.000255935765751625
# sigma = 0.15997992553805773 +/- 0.0014339753418919092
# 68%CL = 0.9230020642280578, 95%CL = 1.167001724243164, 99%CL = 1.3409990072250366
# mu = 0.8698913754150271 +/- 0.000255935765751625
# sigma = 0.15997992553805773 +/- 0.0014339753418919092
# /tmp/ipykernel_958226/3311202556.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_958226/3311202556.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_958226/3311202556.py:116: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_958226/3311202556.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3125818250700831 seconds.
# mu = 0.8694752944866195 +/- 0.000260115224206859
# sigma = 0.161280880518076 +/- 0.001555320380770133
# 68%CL = 0.9172504767775536, 95%CL = 1.172300335019827, 99%CL = 1.358750369399786
# mu = 0.8694752944866195 +/- 0.000260115224206859
# sigma = 0.161280880518076 +/- 0.001555320380770133
# /tmp/ipykernel_958226/3311202556.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_958226/3311202556.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_958226/3311202556.py:116: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_958226/3311202556.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.90549454302527 seconds.
# mu = 0.9308255663811473 +/- 0.0010998466121362833
# sigma = 0.3316393541388421 +/- 0.0030558968111021457
# 68%CL = 1.0304382303304764, 95%CL = 1.5704415986452431, 99%CL = 1.9548155201110047
# mu = 0.9308255663811473 +/- 0.0010998466121362833
# sigma = 0.3316393541388421 +/- 0.0030558968111021457
# /tmp/ipykernel_958226/3311202556.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_958226/3311202556.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_958226/3311202556.py:116: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_958226/3311202556.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9073009071871638 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fa91daec0e0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fa91daec180>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fa91daec220>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fa91daec2c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fa91daec360>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fa91daec400>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              5
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...           1000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_mixture/5D_20K/null_hypothesis/FGD....
# 1  $d_{\mathrm{MMD}}$  results/5D_mixture/5D_20K/null_hypothesis/MMD....
# 2      $\overline{D}$  results/5D_mixture/5D_20K/null_hypothesis/KS.json
# 3     $\widetilde{D}$  results/5D_mixture/5D_20K/null_hypothesis/SKS....
# 4     $\widetilde{W}$  results/5D_mixture/5D_20K/null_hypothesis/SWD....
# 5           $t_{\mu}$  results/5D_mixture/5D_20K/null_hypothesis/LR.json
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0004589131872192923], ...
# 1  [[0.68, [6800, 3199], 0.019219401732470942], [...
# 2  [[0.68, [6800, 3199], 0.9230020642280578], [0....
# 3  [[0.68, [6800, 3199], 0.9172504767775536], [0....
# 4  [[0.68, [6800, 3199], 1.0304382303304764], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/5D_mixture/5D_20K/null_hypothesis/FGD.pdf
# 1  results/5D_mixture/5D_20K/null_hypothesis/MMD.pdf
# 2   results/5D_mixture/5D_20K/null_hypothesis/KS.pdf
# 3  results/5D_mixture/5D_20K/null_hypothesis/SKS.pdf
# 4  results/5D_mixture/5D_20K/null_hypothesis/SWD.pdf
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 1.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = mean
# statistic = 0.30005845051217456 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9191299625521698
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 44 calls to <function generate_and_clean_data_simple_1 at 0x7fa9fce5cea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.07485475132666308 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6944162247163568
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = mean
# WARNING:tensorflow:6 out of the last 45 calls to <function generate_and_clean_data_simple_1 at 0x7fa9fce5cea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.019838206250126465 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0485353202370964
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = mean
# WARNING:tensorflow:5 out of the last 104 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7fa774157f60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.006650976999197843 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.071537508088888
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = mean
# WARNING:tensorflow:6 out of the last 105 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7fa774157ba0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.003584649959820318 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.5333251457549727
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.046875 - deformation = mean
# statistic = 0.004792139253759924 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.25482625290512473
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0546875 - deformation = mean
# statistic = 0.0052955038954070124 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.15601993222047847
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.05859375 - deformation = mean
# statistic = 0.006280015142246039 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.014176433167624168
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.056640625 - deformation = mean
# statistic = 0.005643463186647742 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.09263148235801097
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0576171875 - deformation = mean
# statistic = 0.005755998300025261 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.01680672268907563
# relative_error_metric = 0.0729208887819419
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.05810546875 - deformation = mean
# statistic = 0.006129487410556937 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.008368200836820083
# relative_error_metric = 0.010084508961005725
# =======> statistic within required accuracy at 0.95 CL in 249.75141856400296 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.058349609375 - deformation = mean
# statistic = 0.005743510242175473 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.7794694348327567
# relative_error_metric = 0.696759533043646
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5291748046875 - deformation = mean
# statistic = 0.3372861241853009 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.6027425722002908
# relative_error_metric = 1.8638502412531865
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.29376220703125 - deformation = mean
# statistic = 0.10418486316446744 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.3371468192061016
# relative_error_metric = 1.5904225795197795
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.176055908203125 - deformation = mean
# statistic = 0.038617803124828196 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.0042963155839084
# relative_error_metric = 1.058672941539002
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.1172027587890625 - deformation = mean
# statistic = 0.017481715331071308 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.6704910908300739
# relative_error_metric = 0.38116960076597894
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.08777618408203125 - deformation = mean
# statistic = 0.010757221642679306 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.28711802583094503
# relative_error_metric = 0.09960782406526907
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.10248947143554688 - deformation = mean
# statistic = 0.013998791773138458 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.15466046474326844
# relative_error_metric = 0.16333879972192933
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.09513282775878906 - deformation = mean
# statistic = 0.012206356239424048 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.08044047259038344
# relative_error_metric = 0.02668762182239868
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.09145450592041016 - deformation = mean
# statistic = 0.011185119506148235 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.039427347675197164
# relative_error_metric = 0.0606647187659925
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.09329366683959961 - deformation = mean
# statistic = 0.011528531966799293 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.019521256000749065
# relative_error_metric = 0.03044025922236065
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.09421324729919434 - deformation = mean
# statistic = 0.011991159204997368 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.009808496543375959
# relative_error_metric = 0.008901973234069264
# =======> statistic within required accuracy at 0.99 CL in 248.75225206301548 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 498.50370489805937 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = cov_diag
# statistic = 2.9084383271077736 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9915027105833618
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = cov_diag
# statistic = 0.7293744740037896 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9663300761582698
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = cov_diag
# statistic = 0.1841405112088949 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.869877698359533
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = cov_diag
# statistic = 0.04766360081387043 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5401289467219204
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = cov_diag
# statistic = 0.01357302720252459 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7469312255945559
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = cov_diag
# statistic = 0.005389300471946737 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.13855781408047607
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0234375 - deformation = cov_diag
# statistic = 0.008737400657460809 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.34105227408630184
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_diag
# statistic = 0.006753556844539449 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.08681898977948142
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.017578125 - deformation = cov_diag
# statistic = 0.005989133251331049 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.03324595596671287
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0185546875 - deformation = cov_diag
# statistic = 0.006273081086045041 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.013071728027699773
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01806640625 - deformation = cov_diag
# statistic = 0.006124798619040006 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.02666666666666667
# relative_error_metric = 0.010849737265686794
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.018310546875 - deformation = cov_diag
# statistic = 0.0062975032793448306 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.013422818791946308
# relative_error_metric = 0.016957122571160388
# =======> statistic within required accuracy at 0.95 CL in 272.5191742219031 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0181884765625 - deformation = cov_diag
# statistic = 0.0061990984225730175 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.9285457379211126
# relative_error_metric = 0.6288203192314001
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.50909423828125 - deformation = cov_diag
# statistic = 3.016117532728999 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.8620210672531543
# relative_error_metric = 1.9843000294010207
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.263641357421875 - deformation = cov_diag
# statistic = 0.810801199384678 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.7418516513264755
# relative_error_metric = 1.942214230020442
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.1409149169921875 - deformation = cov_diag
# statistic = 0.2337602844032666 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.5427256161887408
# relative_error_metric = 1.8064706558292503
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.07955169677734375 - deformation = cov_diag
# statistic = 0.0758691904262284 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.2556396846460074
# relative_error_metric = 1.4582639322240536
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.048870086669921875 - deformation = cov_diag
# statistic = 0.030131302424883648 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.9150691165595313
# relative_error_metric = 0.8685421180664152
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.03352928161621094 - deformation = cov_diag
# statistic = 0.015033557933675671 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.5932509680988383
# relative_error_metric = 0.23394149783583248
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.02585887908935547 - deformation = cov_diag
# statistic = 0.009841067519808127 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.25831419716410003
# relative_error_metric = 0.18814544579637701
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.029694080352783203 - deformation = cov_diag
# statistic = 0.012494155505843813 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.1380736976730213
# relative_error_metric = 0.04998295219018188
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.027776479721069336 - deformation = cov_diag
# statistic = 0.011227611756725145 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.06673331978145522
# relative_error_metric = 0.05687619370903486
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.02873528003692627 - deformation = cov_diag
# statistic = 0.011599881693443125 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.032819127557172326
# relative_error_metric = 0.024271522461030544
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.029214680194854736 - deformation = cov_diag
# statistic = 0.012361142376776185 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.016545314475144485
# relative_error_metric = 0.03928520607072107
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.028974980115890503 - deformation = cov_diag
# statistic = 0.011784908082294631 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.008238579764314954
# relative_error_metric = 0.008447826280830876
# =======> statistic within required accuracy at 0.99 CL in 296.66350986994803 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 569.1827168250456 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = cov_off_diag
# statistic = 3.273004113552035 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.992447399847632
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = cov_off_diag
# statistic = 1.4884401026614333 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.983429727952615
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = cov_off_diag
# statistic = 0.5884115012640414 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9583479239654762
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = cov_off_diag
# statistic = 0.21078685072276598 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8858575470494332
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = cov_off_diag
# statistic = 0.06958931048702043 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6731835291398243
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = cov_off_diag
# statistic = 0.02218723896058017 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1272919104055625
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = cov_off_diag
# statistic = 0.007863754840662273 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.2379363185248794
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.00390625 - deformation = cov_off_diag
# statistic = 0.0040726278523677455 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.4128869546732925
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.005859375 - deformation = cov_off_diag
# statistic = 0.005476513562504004 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.12257322334791143
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0068359375 - deformation = cov_off_diag
# statistic = 0.006611356825755038 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.06556967279422488
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00634765625 - deformation = cov_off_diag
# statistic = 0.006107523130779684 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.01367419657268581
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.006591796875 - deformation = cov_off_diag
# statistic = 0.0062346801898711494 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.03773584905660377
# relative_error_metric = 0.006931536273508896
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0064697265625 - deformation = cov_off_diag
# statistic = 0.0059542747841191115 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.018691588785046728
# relative_error_metric = 0.03908133297792304
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00653076171875 - deformation = cov_off_diag
# statistic = 0.006503314795440554 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.009389671361502348
# relative_error_metric = 0.049106422700964714
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.006500244140625 - deformation = cov_off_diag
# statistic = 0.006133684921323766 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.00468384074941452
# relative_error_metric = 0.009399953418832053
# =======> statistic within required accuracy at 0.95 CL in 247.58579367608763 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0065155029296875 - deformation = cov_off_diag
# statistic = 0.006407336946565258 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.9741066961781606
# relative_error_metric = 0.5988938511605632
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.5032577514648438 - deformation = cov_off_diag
# statistic = 3.2928455961495517 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.9488752862295524
# relative_error_metric = 1.9856146971118824
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.2548866271972656 - deformation = cov_off_diag
# statistic = 1.5254459016338198 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.900299160890186
# relative_error_metric = 1.9690765648413575
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.13070106506347656 - deformation = cov_off_diag
# statistic = 0.6262449898093583 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.810066582338305
# relative_error_metric = 1.9255017658993432
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.06860828399658203 - deformation = cov_off_diag
# statistic = 0.24277757471232858 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.653079100707095
# relative_error_metric = 1.8133232962471555
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.037561893463134766 - deformation = cov_off_diag
# statistic = 0.09380938023806792 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.4087216158031957
# relative_error_metric = 1.5502163920456962
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.022038698196411133 - deformation = cov_off_diag
# statistic = 0.039136487103417716 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.0872792552081159
# relative_error_metric = 1.0682424850901615
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.014277100563049316 - deformation = cov_off_diag
# statistic = 0.019249470103579254 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.7465729470648603
# relative_error_metric = 0.4730839811523163
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.010396301746368408 - deformation = cov_off_diag
# statistic = 0.011796831151181129 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.31457346400902525
# relative_error_metric = 0.007436630159404763
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.012336701154708862 - deformation = cov_off_diag
# statistic = 0.015505857509251495 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.170712106692117
# relative_error_metric = 0.2643937067332318
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.011366501450538635 - deformation = cov_off_diag
# statistic = 0.013404038051329495 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.08916128086919548
# relative_error_metric = 0.12014356418281809
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.010881401598453522 - deformation = cov_off_diag
# statistic = 0.012659135217332574 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.045597012442902186
# relative_error_metric = 0.06309055305232943
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.010638851672410965 - deformation = cov_off_diag
# statistic = 0.012183730999208123 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.023061388829806923
# relative_error_metric = 0.02483264759287405
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.010517576709389687 - deformation = cov_off_diag
# statistic = 0.011941492441050704 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.011597558365640062
# relative_error_metric = 0.00475147294798303
# =======> statistic within required accuracy at 0.99 CL in 233.38350180000998 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 480.9693284020759 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = power_abs_up
# statistic = 16.256138026422313 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9984770660356552
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = power_abs_up
# statistic = 2.7839251187603606 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9911235061023183
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = power_abs_up
# statistic = 0.5831584671842448 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9579766679292745
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = power_abs_up
# statistic = 0.13521700078293575 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8248589432322575
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = power_abs_up
# statistic = 0.03431161541870845 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3885313643726473
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = power_abs_up
# statistic = 0.010093940159263006 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4792378196070073
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = power_abs_up
# statistic = 0.004598708562949737 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2952469739656967
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01171875 - deformation = power_abs_up
# statistic = 0.006904213913524993 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.10882861418292072
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.005617116591395681 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.09730037681811579
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0107421875 - deformation = power_abs_up
# statistic = 0.0063122655607746325 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.019298334991324047
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01025390625 - deformation = power_abs_up
# statistic = 0.005911896669895738 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.04622078427448592
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.010498046875 - deformation = power_abs_up
# statistic = 0.006191886750219772 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.023529411764705882
# relative_error_metric = 4.4125360177315865e-05
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0103759765625 - deformation = power_abs_up
# statistic = 0.006182043446515096 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.011695906432748537
# relative_error_metric = 0.001546849167097521
# =======> statistic within required accuracy at 0.95 CL in 296.9547217139043 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.01043701171875 - deformation = power_abs_up
# statistic = 0.005932187159155155 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.9586831772878284
# relative_error_metric = 0.6682017427420514
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.505218505859375 - deformation = power_abs_up
# statistic = 16.736821803351585 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.9190388826418892
# relative_error_metric = 1.9971615988120517
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.2578277587890625 - deformation = power_abs_up
# statistic = 2.9946625911060907 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.8443774529321426
# relative_error_metric = 1.9841879932681779
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.13413238525390625 - deformation = power_abs_up
# statistic = 0.6801512316714615 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.7112248667475856
# relative_error_metric = 1.9313048153587211
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.07228469848632812 - deformation = power_abs_up
# statistic = 0.18294161751822116 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.495319345169472
# relative_error_metric = 1.7559903411204836
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.04136085510253906 - deformation = power_abs_up
# statistic = 0.05889767060586822 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.1940199580218729
# relative_error_metric = 1.3283719829750482
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.02589893341064453 - deformation = power_abs_up
# statistic = 0.02425300835990584 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.85105377811606
# relative_error_metric = 0.6844959238594256
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.018167972564697266 - deformation = power_abs_up
# statistic = 0.01314513449101638 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.5405324309456734
# relative_error_metric = 0.10069885377441348
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.014302492141723633 - deformation = power_abs_up
# statistic = 0.009310722417073824 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.23809209125419448
# relative_error_metric = 0.2428960399017419
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.01623523235321045 - deformation = power_abs_up
# statistic = 0.010687828927201016 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.11235814896307975
# relative_error_metric = 0.10606240787612088
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.017201602458953857 - deformation = power_abs_up
# statistic = 0.012012147786146978 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.05780272631498261
# relative_error_metric = 0.010650739240510748
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.016718417406082153 - deformation = power_abs_up
# statistic = 0.011116531981198384 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.028489668036412934
# relative_error_metric = 0.06680937842553011
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.016960009932518005 - deformation = power_abs_up
# statistic = 0.01160630327041746 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.014144093883353318
# relative_error_metric = 0.023718165431650607
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.01708080619573593 - deformation = power_abs_up
# statistic = 0.011871073247826444 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.007047128131202721
# relative_error_metric = 0.0011629918289002088
# =======> statistic within required accuracy at 0.99 CL in 318.13910053204745 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 615.0938549020793 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = power_abs_down
# statistic = 4.065732916417177 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9939177521670972
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = power_abs_down
# statistic = 1.3941738643386246 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9823142925619466
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = power_abs_down
# statistic = 0.4119147887755955 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9407651879735126
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.0625 - deformation = power_abs_down
# statistic = 0.11388168496683462 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7937388707010136
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.03125 - deformation = power_abs_down
# statistic = 0.03133138172658386 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.339965960231205
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.015625 - deformation = power_abs_down
# statistic = 0.0095216066077184 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4238460404718571
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0078125 - deformation = power_abs_down
# statistic = 0.004040950509116409 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.42035662189895306
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01171875 - deformation = power_abs_down
# statistic = 0.006371759176396348 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.028677910540613454
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.005297312450921009 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.1556805374205817
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0107421875 - deformation = power_abs_down
# statistic = 0.00573841316205394 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.0759764225835309
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01123046875 - deformation = power_abs_down
# statistic = 0.006085840578009669 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.0425531914893617
# relative_error_metric = 0.017230438495461554
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.011474609375 - deformation = power_abs_down
# statistic = 0.0062107374423130204 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.021505376344086023
# relative_error_metric = 0.003083916159176461
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0113525390625 - deformation = power_abs_down
# statistic = 0.006156896952406422 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.0106951871657754
# relative_error_metric = 0.0056227971200051895
# =======> statistic within required accuracy at 0.95 CL in 297.2097930049058 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.01141357421875 - deformation = power_abs_down
# statistic = 0.006249956919175981 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.9548609015750407
# relative_error_metric = 0.6214478903266528
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.505706787109375 - deformation = power_abs_down
# statistic = 4.128824072823901 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.9117143700206551
# relative_error_metric = 1.9885189832403904
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.2585601806640625 - deformation = power_abs_down
# statistic = 1.4737634060194367 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.8308935737297236
# relative_error_metric = 1.9680008053165645
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.13498687744140625 - deformation = power_abs_down
# statistic = 0.47390849220480574 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.6881546719474698
# relative_error_metric = 1.9021403934707068
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.07320022583007812 - deformation = power_abs_down
# statistic = 0.15224869823450818 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.4604391145575042
# relative_error_metric = 1.7103606258936956
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.04230690002441406 - deformation = power_abs_down
# statistic = 0.0545624649207894 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.1501508965027516
# relative_error_metric = 1.284553147417229
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.02686023712158203 - deformation = power_abs_down
# statistic = 0.023777933798490903 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.8071661724765156
# relative_error_metric = 0.6669717206757776
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.019136905670166016 - deformation = power_abs_down
# statistic = 0.013344951212272176 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.5056111379918525
# relative_error_metric = 0.11574104789734073
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.015275239944458008 - deformation = power_abs_down
# statistic = 0.009364653682161404 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.2244362074340943
# relative_error_metric = 0.23720357711750104
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.01720607280731201 - deformation = power_abs_down
# statistic = 0.01119169515212085 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.10625617072362703
# relative_error_metric = 0.06007753469221746
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.018171489238739014 - deformation = power_abs_down
# statistic = 0.01235893134130755 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.05457789489113568
# relative_error_metric = 0.03910638894509397
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.017688781023025513 - deformation = power_abs_down
# statistic = 0.011800641585826438 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.026921616161280377
# relative_error_metric = 0.007113681656143906
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.017930135130882263 - deformation = power_abs_down
# statistic = 0.01180752544839735 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.01337081707934697
# relative_error_metric = 0.006530512059641116
# =======> statistic within required accuracy at 0.99 CL in 297.1514689968899 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 594.3612954660784 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with random_normal deformation.
#
# ======================================================
# =============== fgd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = random_normal
# statistic = 0.09437219601073185 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7537239861990368
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = random_normal
# statistic = 0.009763556791942223 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.44774742999076655
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = random_normal
# statistic = 0.0031228718199541117 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.6589181472628661
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.1875 - deformation = random_normal
# statistic = 0.00496474065191857 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.21994154440041352
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.21875 - deformation = random_normal
# statistic = 0.006646605358708854 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.07088083251888795
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.203125 - deformation = random_normal
# statistic = 0.00578823096548034 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.06734354046919554
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.2109375 - deformation = random_normal
# statistic = 0.006187581344048164 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.0006514467225265749
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.21484375 - deformation = random_normal
# statistic = 0.006271185688096923 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.01834862385321101
# relative_error_metric = 0.012769547137056374
# =======> statistic within required accuracy at 0.95 CL in 187.04732414707541 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.212890625 - deformation = random_normal
# statistic = 0.006497177469165738 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 1.2979066022544283
# relative_error_metric = 0.5861920145909084
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.6064453125 - deformation = random_normal
# statistic = 0.18830270020319778 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.9606674612634089
# relative_error_metric = 1.7625249918142762
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.40966796875 - deformation = random_normal
# statistic = 0.048528528459697164 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.6321568627450981
# relative_error_metric = 1.2130961572827308
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.311279296875 - deformation = random_normal
# statistic = 0.019078793116018206 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.37540754541220306
# relative_error_metric = 0.46466736454395274
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.2620849609375 - deformation = random_normal
# statistic = 0.011253328286471851 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.1715988929103683
# relative_error_metric = 0.054590117768727735
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.28668212890625 - deformation = random_normal
# statistic = 0.014431708553727562 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.08964520075631187
# relative_error_metric = 0.1935524892141159
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.274383544921875 - deformation = random_normal
# statistic = 0.012623765632320788 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.0458501621252631
# relative_error_metric = 0.0602953082995548
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.2682342529296875 - deformation = random_normal
# statistic = 0.011883601705237504 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.022665279379095075
# relative_error_metric = 0.00010817150054072367
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.27130889892578125 - deformation = random_normal
# statistic = 0.012349932623391555 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.011397219983314244
# relative_error_metric = 0.038378282502903795
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.2697715759277344 - deformation = random_normal
# statistic = 0.011811632429782884 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.005682419046679028
# relative_error_metric = 0.006182748608436135
# =======> statistic within required accuracy at 0.99 CL in 229.7488696288783 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 416.79622682603076 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with random_uniform deformation.
#
# ======================================================
# =============== fgd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = random_uniform
# W0000 00:00:1714675424.647280  958226 random_ops.cc:59] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. while/random_shiftMixture_CONSTRUCTED_AT_top_level/sample/random_shift/forward/random_uniform/RandomUniform
# statistic = 0.014815195277007798 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8210272979908185
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = random_uniform
# statistic = 0.0034763194088283816 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.561711410990642
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.375 - deformation = random_uniform
# statistic = 0.006776821684706971 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.09025115793649761
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_uniform
# statistic = 0.004485190419681219 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.3196505479082407
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.34375 - deformation = random_uniform
# statistic = 0.005380540677616943 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.14017664202437205
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.359375 - deformation = random_uniform
# statistic = 0.00594914018092232 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.0425531914893617
# relative_error_metric = 0.03994370724018635
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.3671875 - deformation = random_uniform
# statistic = 0.006412082527292924 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.021505376344086023
# relative_error_metric = 0.03498481543088221
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.36328125 - deformation = random_uniform
# statistic = 0.006273537058668263 - next threshold = 0.006191613537014557 at 0.95 CL
# relative_error_eps = 0.010810810810810811
# relative_error_metric = 0.013144409451752489
# =======> statistic within required accuracy at 0.95 CL in 182.5582588869147 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.361328125 - deformation = random_uniform
# statistic = 0.00604547346589066 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.9383070301291249
# relative_error_metric = 0.6513437036881622
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.6806640625 - deformation = random_uniform
# statistic = 0.04148325559389338 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.612933458294283
# relative_error_metric = 1.109214852884307
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.52099609375 - deformation = random_uniform
# statistic = 0.01666992531695001 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.3619258439402324
# relative_error_metric = 0.3351475738326693
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.441162109375 - deformation = random_uniform
# statistic = 0.010240105181774204 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.16594772900279117
# relative_error_metric = 0.14868091509659886
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.4810791015625 - deformation = random_uniform
# statistic = 0.013401116828619896 - next threshold = 0.011884887241794997 at 0.99 CL
# relative_error_eps = 0.08656518861681006
# ...
# relative_error_metric = 0.01169836789295043
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.009521484375 - deformation = power_abs_down
# statistic = 1.5663866329891427 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.02531645569620253
# relative_error_metric = 0.002585392222122187
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0096435546875 - deformation = power_abs_down
# statistic = 1.5735403063847846 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.012738853503184714
# relative_error_metric = 0.0019711994745159746
# =======> statistic within required accuracy at 0.95 CL in 336.4077851700131 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00958251953125 - deformation = power_abs_down
# statistic = 1.569959489622991 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 1.9620337343570522
# relative_error_metric = 0.21837196951589696
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.504791259765625 - deformation = power_abs_down
# statistic = 30.751802215527746 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 1.9254820528033225
# relative_error_metric = 1.7609272183493383
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.2571868896484375 - deformation = power_abs_down
# statistic = 18.327873885318297 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 1.8563175656351885
# relative_error_metric = 1.6144859330956896
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.13338470458984375 - deformation = power_abs_down
# statistic = 10.448346416724567 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 1.7318960456801324
# relative_error_metric = 1.3695751034885744
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.07148361206054688 - deformation = power_abs_down
# statistic = 6.043330530470619 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 1.5271751917556822
# relative_error_metric = 1.0223656793719833
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.04053306579589844 - deformation = power_abs_down
# statistic = 3.750055477077938 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 1.2351665080875356
# relative_error_metric = 0.6293709210432742
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.02505779266357422 - deformation = power_abs_down
# statistic = 2.6126504677411635 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.8934834677752388
# relative_error_metric = 0.2880524778420968
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.01732015609741211 - deformation = power_abs_down
# statistic = 2.067303784929669 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.5752317481699427
# relative_error_metric = 0.05593482255868934
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.013451337814331055 - deformation = power_abs_down
# statistic = 1.809461589853943 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.25145469337155696
# relative_error_metric = 0.07722807115994454
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.015385746955871582 - deformation = power_abs_down
# statistic = 1.936624382527437 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.11829113162776966
# relative_error_metric = 0.009349309273019437
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.016352951526641846 - deformation = power_abs_down
# statistic = 2.0015629651913764 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.0609479668048234
# relative_error_metric = 0.02363143225757326
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.015869349241256714 - deformation = power_abs_down
# statistic = 1.9689915490676697 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.03094549972490982
# relative_error_metric = 0.0072256503476009785
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.015627548098564148 - deformation = power_abs_down
# statistic = 1.9527816487958043 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.015353965826142619
# relative_error_metric = 0.0010409831040845917
# =======> statistic within required accuracy at 0.99 CL in 327.7829774750862 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 664.1907966639847 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = random_normal
# statistic = 5.762978300423885 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.143405603246808
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = random_normal
# statistic = 2.1431513508380298 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.3084397024571453
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.125 - deformation = random_normal
# statistic = 1.3173813759966062 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.17526020456986058
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.1875 - deformation = random_normal
# statistic = 1.6206210119502844 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.03144997101493826
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 1.4489389960158245 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.08048180666210947
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.171875 - deformation = random_normal
# statistic = 1.5153051739999073 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.03573619529257228
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.1796875 - deformation = random_normal
# statistic = 1.576766357800862 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.004019282642358888
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.17578125 - deformation = random_normal
# statistic = 1.54978574618611 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.02197802197802198
# relative_error_metric = 0.01323996630780735
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.177734375 - deformation = random_normal
# statistic = 1.5652005907063966 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.01092896174863388
# relative_error_metric = 0.0033428609658618024
# =======> statistic within required accuracy at 0.95 CL in 226.15599476895295 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.1787109375 - deformation = random_normal
# statistic = 1.5760018667739752 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 1.3935376967688484
# relative_error_metric = 0.21457561342260925
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.58935546875 - deformation = random_normal
# statistic = 7.437015144866403 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 1.0692943420216148
# relative_error_metric = 1.1674400487646752
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.384033203125 - deformation = random_normal
# statistic = 3.8601025139049296 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.7297180043383948
# relative_error_metric = 0.6553100087218543
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.2813720703125 - deformation = random_normal
# statistic = 2.469046859038708 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.44627222074820905
# relative_error_metric = 0.23248071248841193
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.23004150390625 - deformation = random_normal
# statistic = 1.9639895197505368 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.25115723458264894
# relative_error_metric = 0.004682039318728789
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.204376220703125 - deformation = random_normal
# statistic = 1.750967499455526 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.11815946610467158
# relative_error_metric = 0.11001616639677031
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.2172088623046875 - deformation = random_normal
# statistic = 1.850336858400549 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.057384599638361025
# relative_error_metric = 0.054914311605741326
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.22362518310546875 - deformation = random_normal
# statistic = 1.8906809843777943 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.028286497485831525
# relative_error_metric = 0.033355659358081304
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.22683334350585938 - deformation = random_normal
# statistic = 1.9253725013158052 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.014043935307722494
# relative_error_metric = 0.015176078392393374
# =======> statistic within required accuracy at 0.99 CL in 223.14107463182881 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 449.2971029621549 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.5 - deformation = random_uniform
# statistic = 2.586170707780373 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4887292988883935
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.25 - deformation = random_uniform
# statistic = 1.3885411276691144 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.12294797759951769
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.375 - deformation = random_uniform
# statistic = 1.8468234472919842 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.16175616753832445
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_uniform
# statistic = 1.5869316890034768 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.010445448704301774
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.28125 - deformation = random_uniform
# statistic = 1.4730516589004685 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.0639987879081489
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.296875 - deformation = random_uniform
# statistic = 1.5206142827643703 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.03223967329775359
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.3046875 - deformation = random_uniform
# statistic = 1.5667025738737252 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.02531645569620253
# relative_error_metric = 0.002383712424995525
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.30859375 - deformation = random_uniform
# statistic = 1.566455845380298 - next threshold = 1.5704415986452431 at 0.95 CL
# relative_error_eps = 0.012578616352201259
# relative_error_metric = 0.002541207250837213
# =======> statistic within required accuracy at 0.95 CL in 197.16767826979049 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.310546875 - deformation = random_uniform
# statistic = 1.573932249611105 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 1.052160953800298
# relative_error_metric = 0.2158744661593619
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.6552734375 - deformation = random_uniform
# statistic = 3.812042240185578 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.7138523761375126
# relative_error_metric = 0.6441035299539132
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.48291015625 - deformation = random_uniform
# statistic = 2.469555252673071 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.43446153846153845
# relative_error_metric = 0.23268381381073167
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.396728515625 - deformation = random_uniform
# statistic = 1.9632768020927351 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.24370037970314118
# relative_error_metric = 0.004319082495213586
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3536376953125 - deformation = random_uniform
# statistic = 1.7484031496449473 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.11485277371075321
# relative_error_metric = 0.11147727902314791
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.37518310546875 - deformation = random_uniform
# statistic = 1.8541812017553505 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.05582351545821143
# relative_error_metric = 0.05284032815147437
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.385955810546875 - deformation = random_uniform
# statistic = 1.903592971973666 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.02752758607244512
# relative_error_metric = 0.02655112761773109
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.3913421630859375 - deformation = random_uniform
# statistic = 1.936026065982523 - next threshold = 1.9548155201110047 at 0.99 CL
# relative_error_eps = 0.013669719441593897
# relative_error_metric = 0.009658298192163918
# =======> statistic within required accuracy at 0.99 CL in 199.3679397671949 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 396.53565145097673 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T19:50:38.862252', 'fgd_cov_diag_2024-05-02T19:58:57.367862', 'fgd_cov_off_diag_2024-05-02T20:08:26.553384', 'fgd_power_abs_up_2024-05-02T20:16:27.525871', 'fgd_power_abs_down_2024-05-02T20:26:42.623066', 'fgd_random_normal_2024-05-02T20:36:36.989125', 'fgd_random_uniform_2024-05-02T20:43:33.790063', 'mmd_mean_2024-05-02T20:49:38.195984', 'mmd_cov_diag_2024-05-02T20:59:46.015188', 'mmd_cov_off_diag_2024-05-02T21:11:54.196259', 'mmd_power_abs_up_2024-05-02T21:21:45.474892', 'mmd_power_abs_down_2024-05-02T21:34:46.239679', 'mmd_random_normal_2024-05-02T21:47:25.095826', 'mmd_random_uniform_2024-05-02T21:56:36.685173', 'ks_mean_2024-05-02T22:05:20.610839', 'ks_cov_diag_2024-05-02T22:17:54.267780', 'ks_cov_off_diag_2024-05-02T22:31:14.586729', 'ks_power_abs_up_2024-05-02T22:42:28.614386', 'ks_power_abs_down_2024-05-02T22:55:13.347723', 'ks_random_normal_2024-05-02T23:08:32.074202', 'ks_random_uniform_2024-05-02T23:20:24.219962', 'sks_mean_2024-05-02T23:31:53.506608', 'sks_cov_diag_2024-05-02T23:42:55.277706', 'sks_cov_off_diag_2024-05-02T23:56:20.055481', 'sks_power_abs_up_2024-05-03T00:08:18.635914', 'sks_power_abs_down_2024-05-03T00:21:44.360250', 'sks_random_normal_2024-05-03T00:36:02.286783', 'sks_random_uniform_2024-05-03T00:45:32.134003', 'swd_mean_2024-05-03T00:54:17.621386', 'swd_cov_diag_2024-05-03T01:03:06.836416', 'swd_cov_off_diag_2024-05-03T01:13:08.385947', 'swd_power_abs_up_2024-05-03T01:21:53.196342', 'swd_power_abs_down_2024-05-03T01:32:27.873461', 'swd_random_normal_2024-05-03T01:43:32.072999', 'swd_random_uniform_2024-05-03T01:51:01.379163'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.005 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.980752988019958 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -149.08192613471806], [0.99, [9900, 100], -132.99064086452162]]
# Null distribution computed in 21.282215374987572 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.32657188992016 seconds.
# statistic = 187.00370048197453 - next threshold = -149.08192613471806 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 17.72520576379662
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.0025 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.654050583019853 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -27.83136415672851], [0.99, [9900, 100], -19.889846331491835]]
# Null distribution computed in 20.946337521076202 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 24.942722789011896 seconds.
# statistic = 46.777784492600624 - next threshold = -27.83136415672851 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 7.875804223351709
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.00125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.41960273985751 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.001250.json
# ThresholdS: [[0.95, [9500, 500], -2.247242524786404], [0.99, [9900, 100], 1.7561559502886352]]
# Null distribution computed in 20.729285228066146 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.668282016878948 seconds.
# statistic = 11.707875809200692 - next threshold = -2.247242524786404 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.950144649825324
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.000625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.384937611874193 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000625.json
# ThresholdS: [[0.95, [9500, 500], 1.7985227960776844], [0.99, [9900, 100], 3.8128703470632686]]
# Null distribution computed in 20.690753183094785 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.447952253045514 seconds.
# statistic = 2.933683795324412 - next threshold = 1.7985227960776844 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.47975969659025086
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.0003125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.60342730092816 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000313.json
# ThresholdS: [[0.95, [9500, 500], 1.629562915194294], [0.99, [9900, 100], 2.6366258594934044]]
# Null distribution computed in 20.905816331040114 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.569166776025668 seconds.
# statistic = 0.7367783703491391 - next threshold = 1.629562915194294 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.7545695545265576
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.00046875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.471851825946942 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000469.json
# ThresholdS: [[0.95, [9500, 500], 1.8972481361693685], [0.99, [9900, 100], 3.4055420712456463]]
# Null distribution computed in 20.779189847176895 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.31361717102118 seconds.
# statistic = 1.6527152010096666 - next threshold = 1.8972481361693685 at 0.95 CL
# relative_error_eps = 0.28571428571428575
# relative_error_metric = 0.1377664566834761
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.000546875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.48262467700988 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000547.json
# ThresholdS: [[0.95, [9500, 500], 1.893581802726194], [0.99, [9900, 100], 3.653322404517631]]
# Null distribution computed in 20.78508488018997 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.387280991999432 seconds.
# statistic = 2.247570527711291 - next threshold = 1.893581802726194 at 0.95 CL
# relative_error_eps = 0.15384615384615397
# relative_error_metric = 0.17096146035647072
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.0005078125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.266000152099878 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000508.json
# ThresholdS: [[0.95, [9500, 500], 1.9068390535997342], [0.99, [9900, 100], 3.5405422994118037]]
# Null distribution computed in 20.57077105413191 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 24.943725242977962 seconds.
# statistic = 1.9387356217496285 - next threshold = 1.9068390535997342 at 0.95 CL
# relative_error_eps = 0.08000000000000007
# relative_error_metric = 0.016588713439557198
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.00048828125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.84564043697901 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000488.json
# ThresholdS: [[0.95, [9500, 500], 1.9048996159148222], [0.99, [9900, 100], 3.4759036265661623]]
# Null distribution computed in 21.143333278829232 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.30368765303865 seconds.
# statistic = 1.7928736007243626 - next threshold = 1.9048996159148222 at 0.95 CL
# relative_error_eps = 0.03921568627450984
# relative_error_metric = 0.06059106853084799
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.000498046875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.846606611972675 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000498.json
# ThresholdS: [[0.95, [9500, 500], 1.9065833400264218], [0.99, [9900, 100], 3.508938323300915]]
# Null distribution computed in 21.16110375500284 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.968541586073115 seconds.
# statistic = 1.8650916585730462 - next threshold = 1.9065833400264218 at 0.95 CL
# relative_error_eps = 0.019417475728155355
# relative_error_metric = 0.02200172680243273
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.0005029296875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.473879190860316 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000503.json
# ThresholdS: [[0.95, [9500, 500], 1.9068896981213606], [0.99, [9900, 100], 3.5249191514240525]]
# Null distribution computed in 20.778385407989845 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.189722042065114 seconds.
# statistic = 1.9017354019909765 - next threshold = 1.9068896981213606 at 0.95 CL
# relative_error_eps = 0.009661835748792277
# relative_error_metric = 0.0027066439961402696
# =======> statistic within required accuracy at 0.95 CL in 773.0541677679867 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0005053710937500001 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.456326643936336 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000505.json
# ThresholdS: [[0.95, [9500, 500], 1.906909001192763], [0.99, [9900, 100], 3.5327754354245613]]
# Null distribution computed in 20.754597544902936 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.931593538960442 seconds.
# statistic = 1.9201909523246254 - next threshold = 3.5327754354245613 at 0.99 CL
# relative_error_eps = 1.8075761096909133
# relative_error_metric = 0.5914521999339006
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.005252685546875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.86529558408074 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.005253.json
# ThresholdS: [[0.95, [9500, 500], -166.53684034558353], [0.99, [9900, 100], -149.59185218477336]]
# Null distribution computed in 21.187991727842018 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.432310895994306 seconds.
# statistic = 206.37685677948286 - next threshold = -149.59185218477336 at 0.99 CL
# relative_error_eps = 1.6489294042823828
# relative_error_metric = 12.537419394606188
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.0028790283203125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.82478845701553 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.002879.json
# ThresholdS: [[0.95, [9500, 500], -40.214043487951976], [0.99, [9900, 100], -31.022886384812253]]
# Null distribution computed in 21.13228663895279 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.912964256014675 seconds.
# statistic = 62.027723322854236 - next threshold = -31.022886384812253 at 0.99 CL
# relative_error_eps = 1.4027051397655546
# relative_error_metric = 6.002328597541905
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.00169219970703125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.5917295019608 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.001692.json
# ThresholdS: [[0.95, [9500, 500], -8.621324814901737], [0.99, [9900, 100], -3.2355838597519964]]
# Null distribution computed in 20.882426709868014 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.463857162045315 seconds.
# statistic = 21.44375700182358 - next threshold = -3.2355838597519964 at 0.99 CL
# relative_error_eps = 1.0801277600333286
# relative_error_metric = 2.7107981310383953
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.001098785400390625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.341671275906265 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.001099.json
# ThresholdS: [[0.95, [9500, 500], -0.7268836444725344], [0.99, [9900, 100], 2.790035962911209]]
# Null distribution computed in 20.648382904939353 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.269333886913955 seconds.
# statistic = 9.049423943132126 - next threshold = 2.790035962911209 at 0.99 CL
# relative_error_eps = 0.7398459050699134
# relative_error_metric = 1.0573772840813245
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.0008020782470703126 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.626749600982293 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000802.json
# ThresholdS: [[0.95, [9500, 500], 1.2494950340286166], [0.99, [9900, 100], 3.821765742927613]]
# Null distribution computed in 20.927525393897668 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.972844714997336 seconds.
# statistic = 4.8266699392428825 - next threshold = 3.821765742927613 at 0.99 CL
# relative_error_eps = 0.4538717395109996
# relative_error_metric = 0.2323898178226537
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.0006537246704101563 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.607529181987047 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000654.json
# ThresholdS: [[0.95, [9500, 500], 1.7405929840904495], [0.99, [9900, 100], 3.847411392928531]]
# Null distribution computed in 20.898938472149894 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.464293824043125 seconds.
# statistic = 3.208896068663795 - next threshold = 3.847411392928531 at 0.99 CL
# relative_error_eps = 0.20380997301050763
# relative_error_metric = 0.18097718324780848
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.0007279014587402344 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.829680680064484 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000728.json
# ThresholdS: [[0.95, [9500, 500], 1.5354982397020598], [0.99, [9900, 100], 3.8750896754973563]]
# Null distribution computed in 21.137134332908317 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.48052944196388 seconds.
# statistic = 3.976649409679136 - next threshold = 3.8750896754973563 at 0.99 CL
# relative_error_eps = 0.10737606471830691
# relative_error_metric = 0.025869360425772963
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.0006908130645751953 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.88536542491056 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000691.json
# ThresholdS: [[0.95, [9500, 500], 1.6478093142730683], [0.99, [9900, 100], 3.87166725029111]]
# Null distribution computed in 21.19000306399539 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.845148807158694 seconds.
# statistic = 3.5824893405973843 - next threshold = 3.87166725029111 at 0.99 CL
# relative_error_eps = 0.052284506228027106
# relative_error_metric = 0.07758836460376996
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.0007093572616577149 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 21.08578853891231 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000709.json
# ThresholdS: [[0.95, [9500, 500], 1.5942113210182816], [0.99, [9900, 100], 3.8759826419086303]]
# Null distribution computed in 21.38085303409025 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.718002883018926 seconds.
# statistic = 3.776998525493068 - next threshold = 3.8759826419086303 at 0.99 CL
# relative_error_eps = 0.025804953303584673
# relative_error_metric = 0.025868119690974974
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0007186293601989746 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.440913666971028 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000719.json
# ThresholdS: [[0.95, [9500, 500], 1.5654941663575603], [0.99, [9900, 100], 3.876187203469455]]
# Null distribution computed in 20.745651268865913 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.59873766102828 seconds.
# statistic = 3.8761812551764767 - next threshold = 3.876187203469455 at 0.99 CL
# relative_error_eps = 0.012819773239341399
# relative_error_metric = 1.5345743716660438e-06
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0007232654094696046 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 20.643877250142395 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_mean_0.000723.json
# ThresholdS: [[0.95, [9500, 500], 1.5506560495420196], [0.99, [9900, 100], 3.8758012006621585]]
# ...
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_power_abs_down_0.000333.json
# ThresholdS: [[0.95, [9500, 500], 1.8987203230977325], [0.99, [9900, 100], 3.8811246750697617]]
# Null distribution computed in 21.586824862053618 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.715538440970704 seconds.
# statistic = 4.453174528490498 - next threshold = 3.8811246750697617 at 0.99 CL
# relative_error_eps = 0.5975598432654275
# relative_error_metric = 0.13727605391857478
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.0002567720413208008 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 21.38990624807775 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_power_abs_down_0.000257.json
# ThresholdS: [[0.95, [9500, 500], 1.9518838962725715], [0.99, [9900, 100], 3.4794304702500325]]
# Null distribution computed in 21.652426650980487 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 26.17481907317415 seconds.
# statistic = 2.937970401801997 - next threshold = 3.4794304702500325 at 0.99 CL
# relative_error_eps = 0.25994652104017396
# relative_error_metric = 0.16874746622300318
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.0002951312065124512 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 21.61823560600169 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_power_abs_down_0.000295.json
# ThresholdS: [[0.95, [9500, 500], 1.9620948786218486], [0.99, [9900, 100], 3.716834050322109]]
# Null distribution computed in 21.877406114013866 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.707693194039166 seconds.
# statistic = 3.6583381802497628 - next threshold = 3.716834050322109 at 0.99 CL
# relative_error_eps = 0.1220421522928891
# relative_error_metric = 0.015862916347869637
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.0003143107891082764 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 21.578552721999586 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_power_abs_down_0.000314.json
# ThresholdS: [[0.95, [9500, 500], 1.9395850117419158], [0.99, [9900, 100], 3.808173543846126]]
# Null distribution computed in 21.830362112028524 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.392771576996893 seconds.
# statistic = 4.046581413194546 - next threshold = 3.808173543846126 at 0.99 CL
# relative_error_eps = 0.06294145376801752
# relative_error_metric = 0.06070408832670742
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0003047209978103638 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 21.31804119795561 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_power_abs_down_0.000305.json
# ThresholdS: [[0.95, [9500, 500], 1.9531340764668226], [0.99, [9900, 100], 3.764802120452456]]
# Null distribution computed in 21.582364931004122 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.7617314690724 seconds.
# statistic = 3.8501659721219057 - next threshold = 3.764802120452456 at 0.99 CL
# relative_error_eps = 0.03197384698698814
# relative_error_metric = 0.02242001558816541
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.00029992610216140754 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 21.747782347956672 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_power_abs_down_0.000300.json
# ThresholdS: [[0.95, [9500, 500], 1.9581601320684334], [0.99, [9900, 100], 3.741541585571721]]
# Null distribution computed in 22.009582191938534 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.582614310085773 seconds.
# statistic = 3.7542743695288054 - next threshold = 3.741541585571721 at 0.99 CL
# relative_error_eps = 0.016115744077296393
# relative_error_metric = 0.003397304318396533
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0002975286543369294 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 21.59138808492571 seconds.
# Saving lr to results/5D_mixture/5D_20K/null_hypothesis/LR_power_abs_down_0.000298.json
# ThresholdS: [[0.95, [9500, 500], 1.9602483541069384], [0.99, [9900, 100], 3.729485736120005]]
# Null distribution computed in 21.84879033989273 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.503549647983164 seconds.
# statistic = 3.7067533410117663 - next threshold = 3.729485736120005 at 0.99 CL
# relative_error_eps = 0.008025537660891697
# relative_error_metric = 0.006113949503895361
# =======> statistic within required accuracy at 0.99 CL in 936.80655931402 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1872.6738122520037 seconds.
# Saving results in the file results/5D_mixture/5D_20K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T19:50:38.862252', 'fgd_cov_diag_2024-05-02T19:58:57.367862', 'fgd_cov_off_diag_2024-05-02T20:08:26.553384', 'fgd_power_abs_up_2024-05-02T20:16:27.525871', 'fgd_power_abs_down_2024-05-02T20:26:42.623066', 'fgd_random_normal_2024-05-02T20:36:36.989125', 'fgd_random_uniform_2024-05-02T20:43:33.790063', 'mmd_mean_2024-05-02T20:49:38.195984', 'mmd_cov_diag_2024-05-02T20:59:46.015188', 'mmd_cov_off_diag_2024-05-02T21:11:54.196259', 'mmd_power_abs_up_2024-05-02T21:21:45.474892', 'mmd_power_abs_down_2024-05-02T21:34:46.239679', 'mmd_random_normal_2024-05-02T21:47:25.095826', 'mmd_random_uniform_2024-05-02T21:56:36.685173', 'ks_mean_2024-05-02T22:05:20.610839', 'ks_cov_diag_2024-05-02T22:17:54.267780', 'ks_cov_off_diag_2024-05-02T22:31:14.586729', 'ks_power_abs_up_2024-05-02T22:42:28.614386', 'ks_power_abs_down_2024-05-02T22:55:13.347723', 'ks_random_normal_2024-05-02T23:08:32.074202', 'ks_random_uniform_2024-05-02T23:20:24.219962', 'sks_mean_2024-05-02T23:31:53.506608', 'sks_cov_diag_2024-05-02T23:42:55.277706', 'sks_cov_off_diag_2024-05-02T23:56:20.055481', 'sks_power_abs_up_2024-05-03T00:08:18.635914', 'sks_power_abs_down_2024-05-03T00:21:44.360250', 'sks_random_normal_2024-05-03T00:36:02.286783', 'sks_random_uniform_2024-05-03T00:45:32.134003', 'swd_mean_2024-05-03T00:54:17.621386', 'swd_cov_diag_2024-05-03T01:03:06.836416', 'swd_cov_off_diag_2024-05-03T01:13:08.385947', 'swd_power_abs_up_2024-05-03T01:21:53.196342', 'swd_power_abs_down_2024-05-03T01:32:27.873461', 'swd_random_normal_2024-05-03T01:43:32.072999', 'swd_random_uniform_2024-05-03T01:51:01.379163', 'lr_mean_2024-05-03T01:57:37.948117', 'lr_cov_diag_2024-05-03T02:25:51.462524', 'lr_cov_off_diag_2024-05-03T02:58:48.492279', 'lr_power_abs_up_2024-05-03T03:31:17.813861', 'lr_power_abs_down_2024-05-03T04:00:09.217330'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean    5  10000                20000
# 14        ks        mean    5  10000                20000
# 21       sks        mean    5  10000                20000
# 7        mmd        mean    5  10000                20000
# 28       swd        mean    5  10000                20000
# 0        fgd        mean    5  10000                20000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.00051                             0.00072
# 14                             0.00304                             0.00441
# 21                             0.03442                             0.04998
# 7                              0.03638                             0.05496
# 28                             0.05029                             0.07765
# 0                              0.05835                             0.09375
#
#     $t^{\mu}$ (s)
# 35           1693
# 14            753
# 21            661
# 7             607
# 28            529
# 0             498
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.00051
# 14        ks                             0.00304
# 21       sks                             0.03442
# 7        mmd                             0.03638
# 28       swd                             0.05029
# 0        fgd                             0.05835
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.00072           1693
# 14                             0.00441            753
# 21                             0.04998            661
# 7                              0.05496            607
# 28                             0.07765            529
# 0                              0.09375            498

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag    5  10000                20000
# 15        ks    cov_diag    5  10000                20000
# 8        mmd    cov_diag    5  10000                20000
# 22       sks    cov_diag    5  10000                20000
# 29       swd    cov_diag    5  10000                20000
# 1        fgd    cov_diag    5  10000                20000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00023
# 15                                     0.00188
# 8                                      0.00751
# 22                                     0.01019
# 29                                     0.01648
# 1                                      0.01819
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00031                   1977
# 15                                     0.00250                    800
# 8                                      0.01169                    728
# 22                                     0.01491                    804
# 29                                     0.02584                    601
# 1                                      0.02909                    569
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00023
# 15        ks                                     0.00188
# 8        mmd                                     0.00751
# 22       sks                                     0.01019
# 29       swd                                     0.01648
# 1        fgd                                     0.01819
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00031                   1977
# 15                                     0.00250                    800
# 8                                      0.01169                    728
# 22                                     0.01491                    804
# 29                                     0.02584                    601
# 1                                      0.02909                    569

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag    5  10000                20000
# 16        ks  cov_off_diag    5  10000                20000
# 23       sks  cov_off_diag    5  10000                20000
# 9        mmd  cov_off_diag    5  10000                20000
# 30       swd  cov_off_diag    5  10000                20000
# 2        fgd  cov_off_diag    5  10000                20000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00005
# 16                                          0.00056
# 23                                          0.00351
# 9                                           0.00449
# 30                                          0.00595
# 2                                           0.00652
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00006
# 16                                          0.00080
# 23                                          0.00543
# 9                                           0.00758
# 30                                          0.00977
# 2                                           0.01046
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        1949
# 16                         674
# 23                         718
# 9                          591
# 30                         524
# 2                          480
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00005
# 16        ks                                          0.00056
# 23       sks                                          0.00351
# 9        mmd                                          0.00449
# 30       swd                                          0.00595
# 2        fgd                                          0.00652
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00006
# 16                                          0.00080
# 23                                          0.00543
# 9                                           0.00758
# 30                                          0.00977
# 2                                           0.01046
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        1949
# 16                         674
# 23                         718
# 9                          591
# 30                         524
# 2                          480

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up    5  10000                20000
# 17        ks  power_abs_up    5  10000                20000
# 10       mmd  power_abs_up    5  10000                20000
# 24       sks  power_abs_up    5  10000                20000
# 31       swd  power_abs_up    5  10000                20000
# 3        fgd  power_abs_up    5  10000                20000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00038
# 17                                      0.00230
# 10                                      0.00418
# 24                                      0.00665
# 31                                      0.01019
# 3                                       0.01044
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00049                    1731
# 17                                      0.00319                     764
# 10                                      0.00658                     780
# 24                                      0.00962                     805
# 31                                      0.01587                     634
# 3                                       0.01714                     615
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00038
# 17        ks                                      0.00230
# 10       mmd                                      0.00418
# 24       sks                                      0.00665
# 31       swd                                      0.01019
# 3        fgd                                      0.01044
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00049                    1731
# 17                                      0.00319                     764
# 10                                      0.00658                     780
# 24                                      0.00962                     805
# 31                                      0.01587                     634
# 3                                       0.01714                     615

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down    5  10000                20000
# 18        ks  power_abs_down    5  10000                20000
# 11       mmd  power_abs_down    5  10000                20000
# 25       sks  power_abs_down    5  10000                20000
# 32       swd  power_abs_down    5  10000                20000
# 4        fgd  power_abs_down    5  10000                20000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00018
# 18                                      0.00200
# 11                                      0.00436
# 25                                      0.00607
# 32                                      0.00958
# 4                                       0.01141
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00030                    1872
# 18                                      0.00278                     798
# 11                                      0.00698                     758
# 25                                      0.00892                     857
# 32                                      0.01575                     664
# 4                                       0.01805                     594
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00018
# 18        ks                                      0.00200
# 11       mmd                                      0.00436
# 25       sks                                      0.00607
# 32       swd                                      0.00958
# 4        fgd                                      0.01141
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00030                    1872
# 18                                      0.00278                     798
# 11                                      0.00698                     758
# 25                                      0.00892                     857
# 32                                      0.01575                     664
# 4                                       0.01805                     594

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 19        ks  random_normal    5  10000                20000
# 26       sks  random_normal    5  10000                20000
# 33       swd  random_normal    5  10000                20000
# 5        fgd  random_normal    5  10000                20000
# 12       mmd  random_normal    5  10000                20000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 19                                     0.00677
# 26                                     0.12988
# 33                                     0.17871
# 5                                      0.21289
# 12                                     0.27271
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 19                                     0.00853                    712
# 26                                     0.16472                    569
# 33                                     0.22844                    449
# 5                                      0.27054                    416
# 12                                     0.34231                    551
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 19        ks                                     0.00677
# 26       sks                                     0.12988
# 33       swd                                     0.17871
# 5        fgd                                     0.21289
# 12       mmd                                     0.27271
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 19                                     0.00853                    712
# 26                                     0.16472                    569
# 33                                     0.22844                    449
# 5                                      0.27054                    416
# 12                                     0.34231                    551

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 20        ks  random_uniform    5  10000                20000
# 27       sks  random_uniform    5  10000                20000
# 34       swd  random_uniform    5  10000                20000
# 6        fgd  random_uniform    5  10000                20000
# 13       mmd  random_uniform    5  10000                20000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 20                                     0.01129
# 27                                     0.22852
# 34                                     0.31055
# 6                                      0.36133
# 13                                     0.47168
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 20                                     0.01407                    689
# 27                                     0.27824                    525
# 34                                     0.39404                    396
# 6                                      0.46362                    364
# 13                                     0.59499                    523
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 20        ks                                     0.01129
# 27       sks                                     0.22852
# 34       swd                                     0.31055
# 6        fgd                                     0.36133
# 13       mmd                                     0.47168
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 20                                     0.01407                    689
# 27                                     0.27824                    525
# 34                                     0.39404                    396
# 6                                      0.46362                    364
# 13                                     0.59499                    523

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.058 & 0.094 & 498 & cov_diag & 5 & 10000 & 20000 & 0.018 & 0.029 & 569 & cov_off_diag & 5 & 10000 & 20000 & 0.0065 & 0.01 & 480 & 0.01 & 0.017 & 615 \\
# $\overline{D}$ & 0.003 & 0.0044 & 753 & cov_diag & 5 & 10000 & 20000 & 0.0019 & 0.0025 & 800 & cov_off_diag & 5 & 10000 & 20000 & 0.00056 & 0.0008 & 674 & 0.0023 & 0.0032 & 764 \\
# $t_{\mathrm{LLR}}$ & 0.00051 & 0.00072 & 1693 & cov_diag & 5 & 10000 & 20000 & 0.00023 & 0.00031 & 1977 & cov_off_diag & 5 & 10000 & 20000 & 5e-05 & 6e-05 & 1949 & 0.00038 & 0.00049 & 1731 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.036 & 0.055 & 607 & cov_diag & 5 & 10000 & 20000 & 0.0075 & 0.012 & 728 & cov_off_diag & 5 & 10000 & 20000 & 0.0045 & 0.0076 & 591 & 0.0042 & 0.0066 & 780 \\
# $\widetilde{D}$ & 0.034 & 0.05 & 661 & cov_diag & 5 & 10000 & 20000 & 0.01 & 0.015 & 804 & cov_off_diag & 5 & 10000 & 20000 & 0.0035 & 0.0054 & 718 & 0.0066 & 0.0096 & 805 \\
# $\widetilde{W}$ & 0.05 & 0.078 & 529 & cov_diag & 5 & 10000 & 20000 & 0.016 & 0.026 & 601 & cov_off_diag & 5 & 10000 & 20000 & 0.006 & 0.0098 & 524 & 0.01 & 0.016 & 634 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.011 & 0.018 & 594 & 0.21 & 0.27 & 4.2e+02 & 0.36 & 0.46 & 3.6e+02 & 579 \\
# $\overline{D}$ & 0.002 & 0.0028 & 798 & 0.0068 & 0.0085 & 7.1e+02 & 0.011 & 0.014 & 6.9e+02 & 40 \\
# $t_{\mathrm{LLR}}$ & 0.00018 & 0.0003 & 1872 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.0044 & 0.007 & 758 & 0.27 & 0.34 & 5.5e+02 & 0.47 & 0.59 & 5.2e+02 & 1277 \\
# $\widetilde{D}$ & 0.0061 & 0.0089 & 857 & 0.13 & 0.16 & 5.7e+02 & 0.23 & 0.28 & 5.2e+02 & 379 \\
# $\widetilde{W}$ & 0.0096 & 0.016 & 664 & 0.18 & 0.23 & 4.5e+02 & 0.31 & 0.39 & 4e+02 & 282 \\
# \bottomrule
# \end{tabular}
