# %% [markdown]
# # Initialize

# %%
# %cd ".."
# Out:
# /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics

# %%
visible_devices = [0]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more import MixtureDistributions # type: ignore
from GMetrics.more import deformations # type: ignore
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/5D_mixture/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-09-07 20:35:06.694510: Importing os...
# 2024-09-07 20:35:06.694584: Importing sys...
# Visible devices: [0]
# 2024-09-07 20:35:06.694707: Importing timer from timeit...
# 2024-09-07 20:35:06.694739: Setting env variables for tf import (only device(s) [0] will be available)...
# 2024-09-07 20:35:06.694802: Importing numpy...
# 2024-09-07 20:35:06.758201: Importing matplotlib...
# 2024-09-07 20:35:06.981272: Importing h5py...
# 2024-09-07 20:35:06.992911: Importing importlib.util...
# 2024-09-07 20:35:06.992967: Importing json...
# 2024-09-07 20:35:06.993002: Importing pandas...
# 2024-09-07 20:35:07.160346: Importing random...
# 2024-09-07 20:35:07.160415: Importing scipy utils...
# 2024-09-07 20:35:07.326429: Importing subprocess...
# 2024-09-07 20:35:07.326676: Importing tensorflow...
# Tensorflow version: 2.12.0
# 2024-09-07 20:35:08.472173: Importing tensorflow_probability...
# Tensorflow probability version: 0.20.1
# 2024-09-07 20:35:08.606873: Importing timeit...
# 2024-09-07 20:35:08.606934: Importing tqdm...
# 2024-09-07 20:35:08.608563: Importing typing...
# 2024-09-07 20:35:08.608618: Setting tf configs...
# 2024-09-07 20:35:08.717259: Importing GMetrics module...
# 2024-09-07 20:35:10.745076: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #0, model: NVIDIA L40S
# Loaded 1 GPUs: ['NVIDIA L40S']
# Model directory exists
# 2024-09-07 20:35:10.788576: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
dist_1 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
dist_2 = MixtureDistributions.MixMultiNormal(ncomp = ncomp,
                                             ndims = ndims,
                                             loc_factor = 5.,
                                             scale_factor = 1.,
                                             dtype = tf.float64,
                                             seed = seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture_same_family.MixtureSameFamily'> <class 'tensorflow_probability.python.distributions.mixture_same_family.MixtureSameFamily'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)
# sample from dist_1:  tf.Tensor(
# [[-1.21344303  3.79128235 -0.36013196 -4.40885725 -0.9766748 ]
#  [ 1.79642973  0.74689922 -1.4338443  -1.6379499   2.47373712]], shape=(2, 5), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[-1.21344303  3.79128235 -0.36013196 -4.40885725 -0.9766748 ]
#  [ 1.79642973  0.74689922 -1.4338443  -1.6379499   2.47373712]], shape=(2, 5), dtype=float64)

# %% [markdown]
# ## Some checks for off-diagonal deformation

# %%
import GMetrics.more
import GMetrics.more.deformations


DynamicShufflingBijector = GMetrics.more.deformations.DynamicShufflingBijector(fraction_shuffles = 0.5,
                                                                               event_shape = 5, 
                                                                               seed = 0, 
                                                                               shuffle_type = "random", 
                                                                               validate_args = False, 
                                                                               name = "DynamicShufflingBijector")

# %%
#GMetrics.utils.reset_random_seeds(10)
s1 = dist_1.sample(10)
s1
# Out:
# <tf.Tensor: shape=(10, 5), dtype=float64, numpy=
# array([[-2.36775593, -0.98603737, -1.39675227,  4.42708147, -0.61674579],
#        [ 1.81937088,  0.78323495, -0.23989408, -1.47914083,  1.38837258],
#        [ 1.90394217,  0.80720133, -1.87751853, -0.93320899,  2.141156  ],
#        [-1.96993359, -2.39138679, -1.63706364,  4.33233084, -0.11661171],
#        [-1.77021883, -2.80551288, -1.70200365,  4.54499901,  0.93270807],
#        [-1.17264074, -1.21176257, -1.46536834,  4.40669094,  1.40783929],
#        [ 1.72772838,  0.77085145, -0.93439622, -1.93021007,  1.48046889],
#        [ 1.74343338,  0.77846341, -1.66120008, -1.97110015,  1.60258556],
#        [ 1.84918007,  0.77009875, -2.00577187, -2.12746624,  0.74230823],
#        [ 1.71159145,  0.79651744, -2.10213546, -2.20698484,  2.78114395]])>

# %%
s2 = DynamicShufflingBijector._forward(s1)
s2
# Out:
# Shuffling indices: tf.Tensor([9 3 6 8 4], shape=(5,), dtype=int32)
# Permutation for feature 0 : tf.Tensor([0 1 2 4 6 5 8 7 3 9], shape=(10,), dtype=int32)
# Permutation for feature 1 : tf.Tensor([0 1 2 6 9 5 3 7 8 4], shape=(10,), dtype=int32)
# Permutation for feature 2 : tf.Tensor([0 1 2 8 6 5 9 7 4 3], shape=(10,), dtype=int32)
# Permutation for feature 3 : tf.Tensor([0 1 2 8 4 5 3 7 9 6], shape=(10,), dtype=int32)
# Permutation for feature 4 : tf.Tensor([0 1 2 6 3 5 8 7 4 9], shape=(10,), dtype=int32)
# <tf.Tensor: shape=(10, 5), dtype=float64, numpy=
# array([[-2.36775593, -0.98603737, -1.39675227,  4.42708147, -0.61674579],
#        [ 1.81937088,  0.78323495, -0.23989408, -1.47914083,  1.38837258],
#        [ 1.90394217,  0.80720133, -1.87751853, -0.93320899,  2.141156  ],
#        [-1.77021883,  0.77085145, -2.00577187, -2.12746624,  1.48046889],
#        [ 1.72772838,  0.79651744, -0.93439622,  4.54499901, -0.11661171],
#        [-1.17264074, -1.21176257, -1.46536834,  4.40669094,  1.40783929],
#        [ 1.84918007, -2.39138679, -2.10213546,  4.33233084,  0.74230823],
#        [ 1.74343338,  0.77846341, -1.66120008, -1.97110015,  1.60258556],
#        [-1.96993359,  0.77009875, -1.70200365, -2.20698484,  0.93270807],
#        [ 1.71159145, -2.80551288, -1.63706364, -1.93021007,  2.78114395]])>

# %%
DynamicShufflingBijector._inverse(s2) == s1
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 DynamicShufflingBijector._inverse(s2) == s1
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/more/deformations.py:211, in DynamicShufflingBijector._inverse(self, y)
#     209 def _inverse(self, y):
#     210     # This is not truly correct as we don't know the original shift
# --> 211     raise NotImplementedError("Inverse is not well defined for partial random permutation.")
#
# NotImplementedError: Inverse is not well defined for partial random permutation.

# %%
GMetrics.utils.reset_random_seeds(10)
s1 = dist_1.sample(10)
s1
# Out:
# <tf.Tensor: shape=(10, 5), dtype=float64, numpy=
# array([[-1.93115231, -2.10263181, -1.70442756,  4.49313787,  0.68201914],
#        [-2.09254197, -2.44968144, -1.74640356,  4.52758981,  0.81158418],
#        [ 1.8492219 ,  0.78429883, -1.78699404, -1.41881936,  2.60126738],
#        [ 1.82208561,  0.77363246, -0.27601746, -1.8289846 ,  0.31620325],
#        [ 1.72721641,  0.79242362, -2.76962027, -3.11706001,  2.81630621],
#        [-1.56113254, -1.84071181, -1.43297726,  4.50808303,  0.90991105],
#        [ 1.91218404,  0.78016418, -1.70617609, -1.8574056 ,  1.73866728],
#        [-3.38509609,  3.53906804, -0.74695453, -4.51274499, -0.97122498],
#        [-1.92401469,  3.54403139, -1.47150623, -4.45895022, -0.97239645],
#        [-2.20549217, -2.42676911, -1.37422126,  4.69117484,  1.29837796]])>

# %%
deform_cov_off_diag = GMetrics.more.deformations.deform_cov_off_diag(d = dist_1,
                                                                     eps = 0.5, 
                                                                     shuffle_type = "random", # allowed values: "random", "firsts", "lasts"
                                                                     seed = 0)
#GMetrics.utils.reset_random_seeds(10)

# %%
#GMetrics.utils.reset_random_seeds(10)
ss1 = deform_cov_off_diag.sample(10)
ss1
# Out:
# Shuffling indices: tf.Tensor([6 7 4 0 2], shape=(5,), dtype=int32)
# Permutation for feature 0 : tf.Tensor([0 1 2 3 6 5 4 7 8 9], shape=(10,), dtype=int32)
# Permutation for feature 1 : tf.Tensor([0 1 6 3 7 5 4 2 8 9], shape=(10,), dtype=int32)
# Permutation for feature 2 : tf.Tensor([7 1 4 3 2 5 6 0 8 9], shape=(10,), dtype=int32)
# Permutation for feature 3 : tf.Tensor([2 1 6 3 7 5 4 0 8 9], shape=(10,), dtype=int32)
# Permutation for feature 4 : tf.Tensor([6 1 7 3 0 5 4 2 8 9], shape=(10,), dtype=int32)
# <tf.Tensor: shape=(10, 5), dtype=float64, numpy=
# array([[ 1.67346439,  0.76683845, -1.19930603,  4.4065068 ,  1.02783505],
#        [ 1.71700987,  0.76641302, -1.78088307, -1.43473265,  2.54704459],
#        [-1.56490023,  0.78378186, -1.65708598, -1.28815223,  1.99141227],
#        [-3.2635928 ,  2.40932161, -1.20489902, -4.51853999, -0.96434895],
#        [ 1.75110626,  0.79453818, -1.31668954, -0.24097547,  2.57668604],
#        [-1.58290453, -3.4809521 , -1.69416238,  4.24380911, -0.0678736 ],
#        [-1.24659664, -1.37686397, -1.6846692 ,  4.54246776,  1.23684811],
#        [ 1.8414455 , -2.89027152, -1.33344864, -2.60777052, -0.63333466],
#        [-2.91736884,  3.2290921 , -0.87001172, -4.45703272, -0.95845123],
#        [-1.62174984, -2.41449271, -1.75065765,  4.56045572,  1.16829103]])>

# %%
DynamicShufflingBijector._inverse(ss1) == s1
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 DynamicShufflingBijector._inverse(ss1) == s1
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/more/deformations.py:209, in DynamicShufflingBijector._inverse(self, y)
#     207 def _inverse(self, y):
#     208     # This is not truly correct as we don't know the original shift
# --> 209     raise NotImplementedError("Inverse is not well defined for random shifts.")
#
# NotImplementedError: Inverse is not well defined for random shifts.

# %% [markdown]
# # Fixed $n=10000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 10_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 100000000
# batch_size 10000
# niter 10000
# niter * batch_size 100000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 10_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            10000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True        5           0  float64     5  100000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000, # optimized for 5D
                                       "latex": "$t_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 10_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20, # optimized for 5D
                                       "latex": "$t_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$t_{\overline{\mathrm{KS}}}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$t_{\mathrm{SKS}}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$t_{\mathrm{SW}}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2000,
                                       "latex": "$t_{\mathrm{LLR}}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$t_{\\mathrm{FGD}}$',
#   'null_file': 'results/5D_mixture/5D_10K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 10000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 20,
#   'latex': '$t_{\\mathrm{MMD}}$',
#   'null_file': 'results/5D_mixture/5D_10K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 10000,
#   'latex': '$t_{\\overline{\\mathrm{KS}}}$',
#   'null_file': 'results/5D_mixture/5D_10K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$t_{\\mathrm{SKS}}$',
#   'null_file': 'results/5D_mixture/5D_10K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$t_{\\mathrm{SW}}$',
#   'null_file': 'results/5D_mixture/5D_10K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 10000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 100000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 2000,
#   'latex': '$t_{\\mathrm{LLR}}$',
#   'null_file': 'results/5D_mixture/5D_10K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fgd from results/5D_mixture/5D_10K/null_hypothesis/FGD.json
# Loading mmd from results/5D_mixture/5D_10K/null_hypothesis/MMD.json
# Loading ks from results/5D_mixture/5D_10K/null_hypothesis/KS.json
# Loading sks from results/5D_mixture/5D_10K/null_hypothesis/SKS.json
# Loading swd from results/5D_mixture/5D_10K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0007639936940610248], [0.95, [9500, 500], 0.012146227899100895], [0.99, [9900, 100], 0.022982025960021482]]
# Computing time for metric fgd: 368.08616294304375
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.04561235565654442], [0.95, [9500, 500], 0.59989835678914], [0.99, [9900, 100], 1.1295276084438228]]
# Computing time for metric mmd: 215.4278768019867
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9178255979944627], [0.95, [9500, 500], 1.1596557853802705], [0.99, [9900, 100], 1.3152195924997379]]
# Computing time for metric ks: 37.682656027027406
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9143600075212037], [0.95, [9500, 500], 1.16799941258751], [0.99, [9900, 100], 1.3416648433321408]]
# Computing time for metric sks: 352.4246458549751
# ThresholdS for metric swd: [[0.68, [6800, 3199], 1.020703829007035], [0.95, [9500, 500], 1.5629798345828714], [0.99, [9900, 100], 1.9324611216642107]]
# Computing time for metric swd: 261.30284303601366
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f45d97caef0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f45d97caf80>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f45d97cb010>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f45d97cb0a0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f45d97cb130>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f45d97cb1c0>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 10000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 10000, 'ba...             20
# 2  {'niter': 10000, 'batch_size_test': 10000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 10000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 10000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 10000, 'ba...           2000
#
#                           latex  \
# 0            $t_{\mathrm{FGD}}$
# 1            $t_{\mathrm{MMD}}$
# 2  $t_{\overline{\mathrm{KS}}}$
# 3            $t_{\mathrm{SKS}}$
# 4             $t_{\mathrm{SW}}$
# 5            $t_{\mathrm{LLR}}$
#
#                                            null_file  \
# 0  results/5D_mixture/5D_10K/null_hypothesis/FGD....
# 1  results/5D_mixture/5D_10K/null_hypothesis/MMD....
# 2  results/5D_mixture/5D_10K/null_hypothesis/KS.json
# 3  results/5D_mixture/5D_10K/null_hypothesis/SKS....
# 4  results/5D_mixture/5D_10K/null_hypothesis/SWD....
# 5  results/5D_mixture/5D_10K/null_hypothesis/LR.json
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0007639936940610248], ...
# 1  [[0.68, [6800, 3199], 0.04561235565654442], [0...
# 2  [[0.68, [6800, 3199], 0.9178255979944627], [0....
# 3  [[0.68, [6800, 3199], 0.9143600075212037], [0....
# 4  [[0.68, [6800, 3199], 1.020703829007035], [0.9...
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$t_{\mathrm{FGD}}\,(\times 10^{2})$"
        dist_null = dist_null * 100
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $d = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $d = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.22146936259742275 +/- 0.0023254476488259583
# sigma = 0.4822289548363887 +/- 0.010372005807887583
# 68%CL = 0.07639936940610248, 95%CL = 1.2146227899100894, 99%CL = 2.2982025960021484
# mu = 0.22146936259742275 +/- 0.0023254476488259583
# sigma = 0.4822289548363887 +/- 0.010372005807887583
# /tmp/ipykernel_2323528/889747594.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2323528/889747594.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2323528/889747594.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.8788705030456185 seconds.
# mu = 0.002307712368423142 +/- 0.0009197417555745023
# sigma = 0.3032724444413805 +/- 0.004501567385452458
# 68%CL = 0.04561235565654442, 95%CL = 0.59989835678914, 99%CL = 1.1295276084438228
# mu = 0.002307712368423142 +/- 0.0009197417555745023
# sigma = 0.3032724444413805 +/- 0.004501567385452458
# /tmp/ipykernel_2323528/889747594.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2323528/889747594.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2323528/889747594.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.5437827130081132 seconds.
# mu = 0.8671104165773986 +/- 0.0002443262092921647
# sigma = 0.15630937569197975 +/- 0.0013593539023954925
# 68%CL = 0.9178255979944627, 95%CL = 1.1596557853802705, 99%CL = 1.3152195924997379
# mu = 0.8671104165773986 +/- 0.0002443262092921647
# sigma = 0.15630937569197975 +/- 0.0013593539023954925
# /tmp/ipykernel_2323528/889747594.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2323528/889747594.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2323528/889747594.py:116: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2323528/889747594.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.783649708959274 seconds.
# mu = 0.8650661467822341 +/- 0.0002504173332028649
# sigma = 0.1582458003243261 +/- 0.0015235263641073138
# 68%CL = 0.9143600075212037, 95%CL = 1.16799941258751, 99%CL = 1.3416648433321408
# mu = 0.8650661467822341 +/- 0.0002504173332028649
# sigma = 0.1582458003243261 +/- 0.0015235263641073138
# /tmp/ipykernel_2323528/889747594.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2323528/889747594.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2323528/889747594.py:116: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2323528/889747594.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.7726783080724999 seconds.
# mu = 0.9259113708414085 +/- 0.001064657281972061
# sigma = 0.32629086440966454 +/- 0.003040288053877718
# 68%CL = 1.020703829007035, 95%CL = 1.5629798345828714, 99%CL = 1.9324611216642107
# mu = 0.9259113708414085 +/- 0.001064657281972061
# sigma = 0.32629086440966454 +/- 0.003040288053877718
# /tmp/ipykernel_2323528/889747594.py:81: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2323528/889747594.py:83: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2323528/889747594.py:116: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2323528/889747594.py:122: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.559685128973797 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f705f622e60>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f705f622ef0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f705f622f80>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f705f623010>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f705f6230a0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f705f623130>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 10000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 10000, 'ba...             20
# 2  {'niter': 10000, 'batch_size_test': 10000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 10000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 10000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 10000, 'ba...           2000
#
#                           latex  \
# 0            $t_{\mathrm{FGD}}$
# 1            $t_{\mathrm{MMD}}$
# 2  $t_{\overline{\mathrm{KS}}}$
# 3            $t_{\mathrm{SKS}}$
# 4             $t_{\mathrm{SW}}$
# 5            $t_{\mathrm{LLR}}$
#
#                                            null_file  \
# 0  results/5D_mixture/5D_10K/null_hypothesis/FGD....
# 1  results/5D_mixture/5D_10K/null_hypothesis/MMD....
# 2  results/5D_mixture/5D_10K/null_hypothesis/KS.json
# 3  results/5D_mixture/5D_10K/null_hypothesis/SKS....
# 4  results/5D_mixture/5D_10K/null_hypothesis/SWD....
# 5  results/5D_mixture/5D_10K/null_hypothesis/LR.json
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0007639936940610248], ...
# 1  [[0.68, [6800, 3199], 0.04561235565654442], [0...
# 2  [[0.68, [6800, 3199], 0.9178255979944627], [0....
# 3  [[0.68, [6800, 3199], 0.9143600075212037], [0....
# 4  [[0.68, [6800, 3199], 1.020703829007035], [0.9...
# 5                                                 []
#
#                                          null_figure
# 0  results/5D_mixture/5D_10K/null_hypothesis/FGD.pdf
# 1  results/5D_mixture/5D_10K/null_hypothesis/MMD.pdf
# 2   results/5D_mixture/5D_10K/null_hypothesis/KS.pdf
# 3  results/5D_mixture/5D_10K/null_hypothesis/SKS.pdf
# 4  results/5D_mixture/5D_10K/null_hypothesis/SWD.pdf
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = os.path.join(model_dir, "exclusion_limits.json")
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}
    
# Sort the dictionary by keys
existing_data = dict(sorted(existing_data.items()))

# Save the sorted dictionary back to a JSON file
with open(file_path, 'w') as f:
    json.dump(existing_data, f, cls=GMetrics.utils.CustomEncoder, indent=4) # type: ignore

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        eps_max = 2.
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection(dist_1,
                                                     metric_config = metric_config,
                                                     test_kwargs = test_kwargs,
                                                     model_dir = model_dir,
                                                     deformation = deformation,
                                                     seed_dist = 0,
                                                     x_tol = 0.01,
                                                     fn_tol = 0.05,
                                                     bound = bound,
                                                     eps_min = 0.,
                                                     eps_max = eps_max,
                                                     max_iterations = 50,
                                                     save = True,
                                                     filename = "exclusion_limits.json",
                                                     verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Upper bounds for fgd with mean deformation already loaded.
# Central bounds for fgd with mean deformation already loaded.
# Lower bounds for fgd with mean deformation already loaded.
# Upper bounds for fgd with cov_diag deformation already loaded.
# Central bounds for fgd with cov_diag deformation already loaded.
# Lower bounds for fgd with cov_diag deformation already loaded.
# Computing upper bounds for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - upper bound -----------
# eps = 1.0 - deformation = cov_off_diag
# statistic = 4.926857083470956 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9901630129535333
#
# ------------ 2 - 0.95 CL - upper bound -----------
# eps = 0.5 - deformation = cov_off_diag
# statistic = 1.7664408070955184 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9726834219296159
#
# ------------ 3 - 0.95 CL - upper bound -----------
# eps = 0.25 - deformation = cov_off_diag
# WARNING:tensorflow:5 out of the last 5 calls to <function generate_and_clean_data_simple_1 at 0x7f4193cf4160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function generate_and_clean_data_simple_1 at 0x7f4193cf4160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.6299470692812731 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9243335636584984
#
# ------------ 4 - 0.95 CL - upper bound -----------
# eps = 0.125 - deformation = cov_off_diag
# statistic = 0.20548415008793502 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7767549179219009
#
# ------------ 5 - 0.95 CL - upper bound -----------
# eps = 0.0625 - deformation = cov_off_diag
# WARNING:tensorflow:5 out of the last 5 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f3fdc3856c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.06028418597711342 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3292194673989215
#
# ------------ 6 - 0.95 CL - upper bound -----------
# eps = 0.03125 - deformation = cov_off_diag
# WARNING:tensorflow:6 out of the last 6 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f3fdc385ab0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.013311542426000064 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.09154882866942887
#
# ------------ 7 - 0.95 CL - upper bound -----------
# eps = 0.015625 - deformation = cov_off_diag
# statistic = -0.000167011142129872 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 2.0557669655765043
#
# ------------ 8 - 0.95 CL - upper bound -----------
# eps = 0.0234375 - deformation = cov_off_diag
# statistic = 0.004538796335557075 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.9118873855444258
#
# ------------ 9 - 0.95 CL - upper bound -----------
# eps = 0.02734375 - deformation = cov_off_diag
# statistic = 0.009031628352323056 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.2941373772492596
#
# ------------ 10 - 0.95 CL - upper bound -----------
# eps = 0.029296875 - deformation = cov_off_diag
# statistic = 0.010743170516542892 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.12259451795806763
#
# ------------ 11 - 0.95 CL - upper bound -----------
# eps = 0.0302734375 - deformation = cov_off_diag
# statistic = 0.011921114310280718 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.031746031746031744
# relative_error_metric = 0.018706975357871178
#
# ------------ 12 - 0.95 CL - upper bound -----------
# eps = 0.03076171875 - deformation = cov_off_diag
# statistic = 0.011979202765159638 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.015748031496062992
# relative_error_metric = 0.013846396051175018
#
# ------------ 13 - 0.95 CL - upper bound -----------
# eps = 0.031005859375 - deformation = cov_off_diag
# statistic = 0.011843604034267034 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.00784313725490196
# relative_error_metric = 0.025229344305070803
# =======> statistic within required accuracy at 0.95 CL in 407.86957437102683 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - upper bound -----------
# eps = 0.0311279296875 - deformation = cov_off_diag
# statistic = 0.01318508121238147 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 1.9386982390768677
# relative_error_metric = 0.5417599312513167
#
# ------------ 2 - 0.99 CL - upper bound -----------
# eps = 1.01556396484375 - deformation = cov_off_diag
# statistic = 4.967388183176098 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 1.8810426263922095
# relative_error_metric = 1.9815789009657463
#
# ------------ 3 - 0.99 CL - upper bound -----------
# eps = 0.523345947265625 - deformation = cov_off_diag
# statistic = 1.8889221759803931 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 1.7754416863889042
# relative_error_metric = 1.9519180387036197
#
# ------------ 4 - 0.99 CL - upper bound -----------
# eps = 0.2772369384765625 - deformation = cov_off_diag
# statistic = 0.7342120295270296 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 1.5962195061606215
# relative_error_metric = 1.8785937327770554
#
# ------------ 5 - 0.99 CL - upper bound -----------
# eps = 0.15418243408203125 - deformation = cov_off_diag
# statistic = 0.2873330970178566 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 1.3280909053481
# relative_error_metric = 1.7037588662843244
#
# ------------ 6 - 0.99 CL - upper bound -----------
# eps = 0.09265518188476562 - deformation = cov_off_diag
# statistic = 0.12311146087667042 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.9941138401799747
# relative_error_metric = 1.370758369653767
#
# ------------ 7 - 0.99 CL - upper bound -----------
# eps = 0.06189155578613281 - deformation = cov_off_diag
# statistic = 0.05781362867184453 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.6614447702433923
# relative_error_metric = 0.8622147532693021
#
# ------------ 8 - 0.99 CL - upper bound -----------
# eps = 0.046509742736816406 - deformation = cov_off_diag
# statistic = 0.03233577101969219 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.39624611529437775
# relative_error_metric = 0.33818212475456844
#
# ------------ 9 - 0.99 CL - upper bound -----------
# eps = 0.0388188362121582 - deformation = cov_off_diag
# statistic = 0.021821964015762665 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.1802656652528402
# relative_error_metric = 0.05178386768168695
#
# ------------ 10 - 0.99 CL - upper bound -----------
# eps = 0.042664289474487305 - deformation = cov_off_diag
# statistic = 0.02673259791233845 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.0943864936432929
# relative_error_metric = 0.15088405222360304
#
# ------------ 11 - 0.99 CL - upper bound -----------
# eps = 0.040741562843322754 - deformation = cov_off_diag
# statistic = 0.02447610824030807 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.0483337603629602
# relative_error_metric = 0.0629642233291258
#
# ------------ 12 - 0.99 CL - upper bound -----------
# eps = 0.03978019952774048 - deformation = cov_off_diag
# statistic = 0.024344782321143132 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.02446247098408779
# relative_error_metric = 0.057589193550751525
#
# ------------ 13 - 0.99 CL - upper bound -----------
# eps = 0.03929951786994934 - deformation = cov_off_diag
# statistic = 0.022950394841512796 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.012156888608334354
# relative_error_metric = 0.0013772894159164216
#
# ------------ 14 - 0.99 CL - upper bound -----------
# eps = 0.03953985869884491 - deformation = cov_off_diag
# statistic = 0.02353327391081249 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.006096974363714062
# relative_error_metric = 0.02370179069345954
# =======> statistic within required accuracy at 0.99 CL in 436.910836288007 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 844.7804360290756 seconds.
# Saving results in the file results/5D_mixture/5D_10K/exclusion_limits.json
# Computing central bounds for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - central bound -----------
# eps = 0.019709844142198563 - deformation = cov_off_diag
# statistic = 0.007961284230175161 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.4162567344999938
#
# ------------ 2 - 0.95 CL - central bound -----------
# eps = 0.029564766213297844 - deformation = cov_off_diag
# statistic = 0.017899698994206778 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.3829784393429641
#
# ------------ 3 - 0.95 CL - central bound -----------
# eps = 0.024637305177748203 - deformation = cov_off_diag
# statistic = 0.012347922690710184 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.01646881290043091
#
# ------------ 4 - 0.95 CL - central bound -----------
# eps = 0.022173574659973383 - deformation = cov_off_diag
# statistic = 0.01001581281189574 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.192258024880178
#
# ------------ 5 - 0.95 CL - central bound -----------
# eps = 0.023405439918860793 - deformation = cov_off_diag
# statistic = 0.011350665196047644 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.06771641679022768
#
# ------------ 6 - 0.95 CL - central bound -----------
# eps = 0.024021372548304498 - deformation = cov_off_diag
# statistic = 0.011723894098965565 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.02531645569620253
# relative_error_metric = 0.035385977513608016
#
# ------------ 7 - 0.95 CL - central bound -----------
# eps = 0.02432933886302635 - deformation = cov_off_diag
# statistic = 0.012059149781722069 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.012578616352201259
# relative_error_metric = 0.007194939779668471
#
# ------------ 8 - 0.95 CL - central bound -----------
# eps = 0.024483322020387277 - deformation = cov_off_diag
# statistic = 0.012230606596901958 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.006309148264984227
# relative_error_metric = 0.006922859308488052
# =======> statistic within required accuracy at 0.95 CL in 235.01077915902715 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - central bound -----------
# eps = 0.024406330441706814 - deformation = cov_off_diag
# statistic = 0.012314084133642995 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.4704463208685163
# relative_error_metric = 0.6044825788490128
#
# ------------ 2 - 0.99 CL - central bound -----------
# eps = 0.03191300936305197 - deformation = cov_off_diag
# statistic = 0.020398895097554822 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.2104695089044792
# relative_error_metric = 0.11909064166886915
#
# ------------ 3 - 0.99 CL - central bound -----------
# eps = 0.03566634882372455 - deformation = cov_off_diag
# statistic = 0.025380452562997882 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.11107946454001709
# relative_error_metric = 0.09918542954058103
#
# ------------ 4 - 0.99 CL - central bound -----------
# eps = 0.03378967909338826 - deformation = cov_off_diag
# statistic = 0.02267190280462106 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.05403907440764861
# relative_error_metric = 0.013585825526612763
#
# ------------ 5 - 0.99 CL - central bound -----------
# eps = 0.0347280139585564 - deformation = cov_off_diag
# statistic = 0.023831370153375168 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.027389563873867546
# relative_error_metric = 0.036286373725004234
#
# ------------ 6 - 0.99 CL - central bound -----------
# eps = 0.03425884652597233 - deformation = cov_off_diag
# statistic = 0.023274978691485648 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.01378920199413075
# relative_error_metric = 0.012666307888771662
#
# ------------ 7 - 0.99 CL - central bound -----------
# eps = 0.034024262809680295 - deformation = cov_off_diag
# statistic = 0.022956360581246175 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.006870914888744032
# relative_error_metric = 0.0011173826817905972
# =======> statistic within required accuracy at 0.99 CL in 206.63784337893594 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 441.6486474579433 seconds.
# Saving results in the file results/5D_mixture/5D_10K/exclusion_limits.json
# Computing lower bounds for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - lower bound -----------
# eps = 0.017070777333913156 - deformation = cov_off_diag
# statistic = 0.01177941468844468 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.030662767724128657
#
# ------------ 2 - 0.95 CL - lower bound -----------
# eps = 0.025606166000869734 - deformation = cov_off_diag
# statistic = 0.019521111233688083 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.4657722143096697
#
# ------------ 3 - 0.95 CL - lower bound -----------
# eps = 0.021338471667391445 - deformation = cov_off_diag
# statistic = 0.015021359403676682 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.21165895024339076
#
# ------------ 4 - 0.95 CL - lower bound -----------
# eps = 0.0192046245006523 - deformation = cov_off_diag
# statistic = 0.013228249889848727 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.0852842765669876
#
# ------------ 5 - 0.95 CL - lower bound -----------
# eps = 0.01813770091728273 - deformation = cov_off_diag
# statistic = 0.012543457518331132 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.03217777889950556
#
# ------------ 6 - 0.95 CL - lower bound -----------
# eps = 0.017604239125597942 - deformation = cov_off_diag
# statistic = 0.012340754829582381 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.03076923076923077
# relative_error_metric = 0.015888191096212353
#
# ------------ 7 - 0.95 CL - lower bound -----------
# eps = 0.01733750822975555 - deformation = cov_off_diag
# statistic = 0.012061263772497 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.015267175572519083
# relative_error_metric = 0.007019655547673463
#
# ------------ 8 - 0.95 CL - lower bound -----------
# eps = 0.017470873677676746 - deformation = cov_off_diag
# statistic = 0.01184418213755006 - next threshold = 0.012146227899100895 at 0.95 CL
# relative_error_eps = 0.0076045627376425855
# relative_error_metric = 0.02518054181561631
# =======> statistic within required accuracy at 0.95 CL in 236.18314911809284 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL - lower bound -----------
# eps = 0.017537556401637344 - deformation = cov_off_diag
# statistic = 0.012132986734728528 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.6425806451612903
# relative_error_metric = 0.6179145836911503
#
# ------------ 2 - 0.99 CL - lower bound -----------
# eps = 0.02583955553473183 - deformation = cov_off_diag
# statistic = 0.0194366236999152 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.2768204558087827
# relative_error_metric = 0.16716242919230992
#
# ------------ 3 - 0.99 CL - lower bound -----------
# eps = 0.02999055510127907 - deformation = cov_off_diag
# statistic = 0.024921024465691964 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.1487011048074052
# relative_error_metric = 0.08095511615392512
#
# ------------ 4 - 0.99 CL - lower bound -----------
# eps = 0.02791505531800545 - deformation = cov_off_diag
# statistic = 0.022045697687592625 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.07168561969195336
# relative_error_metric = 0.041588967710494994
#
# ------------ 5 - 0.99 CL - lower bound -----------
# eps = 0.02895280520964226 - deformation = cov_off_diag
# statistic = 0.023149142468506436 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.036496885305972886
# relative_error_metric = 0.007245275338901133
#
# ------------ 6 - 0.99 CL - lower bound -----------
# eps = 0.028433930263823855 - deformation = cov_off_diag
# statistic = 0.02241305755388907 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.018083445295762373
# relative_error_metric = 0.02506740211010125
#
# ------------ 7 - 0.99 CL - lower bound -----------
# eps = 0.028693367736733057 - deformation = cov_off_diag
# statistic = 0.02244548095627708 - next threshold = 0.022982025960021482 at 0.99 CL
# relative_error_eps = 0.00900103023840078
# relative_error_metric = 0.02362203167930842
# =======> statistic within required accuracy at 0.99 CL in 208.80233716894872 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 444.9855163269676 seconds.
# Saving results in the file results/5D_mixture/5D_10K/exclusion_limits.json
# Upper bounds for fgd with power_abs_up deformation already loaded.
# Central bounds for fgd with power_abs_up deformation already loaded.
# Lower bounds for fgd with power_abs_up deformation already loaded.
# Upper bounds for fgd with power_abs_down deformation already loaded.
# Central bounds for fgd with power_abs_down deformation already loaded.
# Lower bounds for fgd with power_abs_down deformation already loaded.
# Upper bounds for fgd with random_normal deformation already loaded.
# Central bounds for fgd with random_normal deformation already loaded.
# Lower bounds for fgd with random_normal deformation already loaded.
# Upper bounds for fgd with random_uniform deformation already loaded.
# Central bounds for fgd with random_uniform deformation already loaded.
# Lower bounds for fgd with random_uniform deformation already loaded.
# Upper bounds for mmd with mean deformation already loaded.
# Central bounds for mmd with mean deformation already loaded.
# Lower bounds for mmd with mean deformation already loaded.
# Upper bounds for mmd with cov_diag deformation already loaded.
# Central bounds for mmd with cov_diag deformation already loaded.
# Lower bounds for mmd with cov_diag deformation already loaded.
# Computing upper bounds for mmd with cov_off_diag deformation.
#
# ======================================================
# =============== mmd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - upper bound -----------
# eps = 1.0 - deformation = cov_off_diag
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[15], line 15
#      13 if result == {}:
#      14     print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
# ---> 15     result = compute_exclusion_bisection(dist_1,
#      16                                          metric_config = metric_config,
#      17                                          test_kwargs = test_kwargs,
#      18                                          model_dir = model_dir,
#      19                                          deformation = deformation,
#      20                                          seed_dist = 0,
#      21                                          x_tol = 0.01,
#      22                                          fn_tol = 0.05,
#      23                                          bound = bound,
#      24                                          eps_min = 0.,
#      25                                          eps_max = eps_max,
#      26                                          max_iterations = 50,
#      27                                          save = True,
#      28                                          filename = "exclusion_limits.json",
#      29                                          verbose = True)
#      30     eps_max = list(result.values())[0]["exclusion_list"][-1][3]
#      31 else:
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/more/optimizers_deformations.py:123, in compute_exclusion_bisection(reference_distribution, metric_config, test_kwargs, model_dir, deformation, seed_dist, x_tol, fn_tol, bound, eps_min, eps_max, max_iterations, save, filename, verbose)
#     118 TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
#     119                                                    dist_2_input = dist_2,
#     120                                                    **test_kwargs)
#     122 Metric = metric_class(TwoSampleTestInputs, **metric_kwargs) # type: ignore
# --> 123 Metric.Test_tf(max_vectorize=max_vectorize)
#     124 metric_mean = np.mean(Metric.Results[-1].result_value[metric_result_key] * metric_scale_func(ns, ndims)) # type: ignore
#     125 metric_std = np.std(Metric.Results[-1].result_value[metric_result_key] * metric_scale_func(ns, ndims)) # type: ignore
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/mmd.py:536, in MMDMetric.Test_tf(self, max_vectorize)
#     534 else:
#     535     seed_generator = self.Inputs.seed_generator
# --> 536     vals_list: DataType = compute_test(seed_generator = seed_generator,
#     537                                        max_vectorize = max_vectorize)
#     539 #print(f"vals_list: {vals_list=}")
#     541 metric_list: DataTypeNP
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/mmd.py:519, in MMDMetric.Test_tf.<locals>.compute_test(seed_generator, max_vectorize)
#     515 def cond(i: int,
#     516          res: tf.TensorArray):
#     517     return i < nchunks
# --> 519 _, res = tf.while_loop(cond, body, [0, res])
#     521 res_stacked: DataTypeTF = tf.reshape(res.stack(), (niter,-1))
#     523 return res_stacked
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     640           _PRINTED_WARNING[(func, arg_name)] = True
#     641         logging.warning(
#     642             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     643             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     646             'in a future version' if date is None else
#     647             ('after %s' % date), instructions)
# --> 648 return func(*args, **kwargs)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/control_flow_ops.py:2574, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2368 @tf_export("while_loop", v1=[])
#    2369 @deprecation.deprecated_arg_values(
#    2370     None,
#    (...)
#    2385                   maximum_iterations=None,
#    2386                   name=None):
#    2387   """Repeat `body` while the condition `cond` is true.
#    2388
#    2389   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)
#    2572
#    2573   """
# -> 2574   return while_loop(
#    2575       cond=cond,
#    2576       body=body,
#    2577       loop_vars=loop_vars,
#    2578       shape_invariants=shape_invariants,
#    2579       parallel_iterations=parallel_iterations,
#    2580       back_prop=back_prop,
#    2581       swap_memory=swap_memory,
#    2582       name=name,
#    2583       maximum_iterations=maximum_iterations,
#    2584       return_same_structure=True)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/control_flow_ops.py:2823, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2820 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#    2821                                         list(loop_vars))
#    2822 while cond(*loop_vars):
# -> 2823   loop_vars = body(*loop_vars)
#    2824   if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2825     packed = True
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/mmd.py:511, in MMDMetric.Test_tf.<locals>.compute_test.<locals>.body(i, res)
#     509     chunk_result: DataTypeTF = self.Inputs.strategy.reduce(tf.distribute.ReduceOp.SUM, per_replica_chunk_result, axis=None)
#     510 else:
# --> 511     chunk_result: DataTypeTF = batched_test(start, end, seed_generator = seed_generator) # type: ignore
#     512 res = res.write(i, chunk_result)
#     513 return i+1, res
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'MatMul/pfor/MatMul' defined at (most recent call last):
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 711, in start
#       self.io_loop.start()
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#       handle._run()
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#       res = shell.run_cell(
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3006, in run_cell
#       result = self._run_cell(
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3061, in _run_cell
#       result = runner(coro)
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3266, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3445, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_2325491/1527294510.py", line 15, in <module>
#       result = compute_exclusion_bisection(dist_1,
#     File "/local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/more/optimizers_deformations.py", line 123, in compute_exclusion_bisection
#       Metric.Test_tf(max_vectorize=max_vectorize)
#     File "/local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/mmd.py", line 536, in Test_tf
#       vals_list: DataType = compute_test(seed_generator = seed_generator,
#     File "/local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/mmd.py", line 519, in compute_test
#       _, res = tf.while_loop(cond, body, [0, res])
#     File "/local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/mmd.py", line 511, in body
#       chunk_result: DataTypeTF = batched_test(start, end, seed_generator = seed_generator) # type: ignore
#     File "/local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/mmd.py", line 476, in batched_test
#       vals_list: DataTypeTF = batched_test_sub(dist_1_k, dist_2_k) # type: ignore
#     File "/local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/mmd.py", line 451, in batched_test_sub
#       vals_list: DataTypeTF = tf.vectorized_map(loop_body, tf.range(tf.shape(dist_1_k_replica)[0])) # type: ignore
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 4485, in f
#       [converter._convert_helper(x).t for x in func._func_graph_outputs])
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 4485, in f
#       [converter._convert_helper(x).t for x in func._func_graph_outputs])
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 4485, in f
#       [converter._convert_helper(x).t for x in func._func_graph_outputs])
#     [Previous line repeated 1 more time]
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 5025, in while_fn
#       while_outputs = control_flow_ops.while_loop(
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 4485, in f
#       [converter._convert_helper(x).t for x in func._func_graph_outputs])
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 4485, in f
#       [converter._convert_helper(x).t for x in func._func_graph_outputs])
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 5025, in while_fn
#       while_outputs = control_flow_ops.while_loop(
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 4485, in f
#       [converter._convert_helper(x).t for x in func._func_graph_outputs])
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 4485, in f
#       [converter._convert_helper(x).t for x in func._func_graph_outputs])
#     File "/local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/parallel_for/pfor.py", line 4485, in f
#       [converter._convert_helper(x).t for x in func._func_graph_outputs])
#     [Previous line repeated 1 more time]
# Node: 'MatMul/pfor/MatMul'
# OOM when allocating tensor with shape[20,10000,10000] and type double on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node MatMul/pfor/MatMul}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_batched_test_232889]

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "power_abs_up", "power_abs_down"]
eps_max_def = []
bounds = ["upper", "central", "lower"]

for deformation in deformations:
    eps_max = 0.01
    for bound in bounds:
        try:
            result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation and v["bound"] == bound}
        except:
            result = {}
        if result == {}:
            print(f"Computing {bound} bounds for lr with {deformation} deformation.")
            result = compute_exclusion_LR_bisection(dist_1,
                                                    metric_config = metrics_config[unique_key]["lr"],
                                                    test_kwargs = test_kwargs,
                                                    model_dir = model_dir,
                                                    cl_list = [0.95, 0.99],
                                                    deformation = deformation,
                                                    seed_dist = 0,
                                                    x_tol = 0.01,
                                                    fn_tol = 0.05,
                                                    bound = bound,
                                                    eps_min = 0.,
                                                    eps_max = eps_max,
                                                    max_iterations = 50,
                                                    save = True,
                                                    filename = "exclusion_limits.json",
                                                    verbose = True)
            eps_max = list(result.values())[0]["exclusion_list"][-1][3]
        else:
            print(f"{bound.capitalize()} bounds for lr with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Upper bounds for lr with mean deformation already loaded.
# Central bounds for lr with mean deformation already loaded.
# Lower bounds for lr with mean deformation already loaded.
# Upper bounds for lr with cov_diag deformation already loaded.
# Central bounds for lr with cov_diag deformation already loaded.
# Lower bounds for lr with cov_diag deformation already loaded.
# Computing upper bounds for lr with cov_off_diag deformation.
#
# ======================================================
# =============== lr - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL - upper bound -----------
# eps = 0.005 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Shuffling indices for feature 0 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 0
# Permutation for feature 0 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 1 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 1
# Permutation for feature 1 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 2 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 2
# Permutation for feature 2 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 3 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 3
# Permutation for feature 3 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 4 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 4
# Permutation for feature 4 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Shuffling indices for feature 0 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_1:0", shape=(100000,), dtype=int32)
# Seed for partial permutation: 0
# Inverse permutation for feature 0 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort/TopKV2:1", shape=(20000000,), dtype=int32)
# Shuffling indices for feature 1 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_3:0", shape=(100000,), dtype=int32)
# Seed for partial permutation: 1
# Inverse permutation for feature 1 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_1/TopKV2:1", shape=(20000000,), dtype=int32)
# Shuffling indices for feature 2 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_5:0", shape=(100000,), dtype=int32)
# Seed for partial permutation: 2
# Inverse permutation for feature 2 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_2/TopKV2:1", shape=(20000000,), dtype=int32)
# Shuffling indices for feature 3 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_7:0", shape=(100000,), dtype=int32)
# Seed for partial permutation: 3
# Inverse permutation for feature 3 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_3/TopKV2:1", shape=(20000000,), dtype=int32)
# Shuffling indices for feature 4 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_9:0", shape=(100000,), dtype=int32)
# Seed for partial permutation: 4
# Inverse permutation for feature 4 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_4/TopKV2:1", shape=(20000000,), dtype=int32)
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 19.667175438953564 seconds.
# Saving lr to results/5D_mixture/5D_10K/null_hypothesis/LR_cov_off_diag_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -29622.317668251802], [0.99, [9900, 100], -23159.45151774324]]
# Null distribution computed in 19.81757509696763 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Shuffling indices for feature 0 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 0
# Permutation for feature 0 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 1 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 1
# Permutation for feature 1 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 2 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 2
# Permutation for feature 2 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 3 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 3
# Permutation for feature 3 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 4 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 4
# Permutation for feature 4 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# Shuffling indices for feature 0 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_1:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 0
# Permutation for feature 0 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 1 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_3:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 1
# Permutation for feature 1 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_1:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 2 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_5:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 2
# Permutation for feature 2 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_2:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 3 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_7:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 3
# Permutation for feature 3 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_3:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 4 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_9:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 4
# Permutation for feature 4 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_4:0", shape=(None,), dtype=int32)
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 10000
# Shuffling indices for feature 0 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_1:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 0
# Permutation for feature 0 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 1 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_3:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 1
# Permutation for feature 1 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_1:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 2 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_5:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 2
# Permutation for feature 2 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_2:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 3 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_7:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 3
# Permutation for feature 3 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_3:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 4 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_9:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 4
# Permutation for feature 4 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_4:0", shape=(None,), dtype=int32)
# WARNING:tensorflow:5 out of the last 14 calls to <function generate_and_clean_data_simple_1 at 0x7f0a60de4160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Shuffling indices for feature 0 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_1:0", shape=(5000,), dtype=int32)
# Seed for partial permutation: 0
# Inverse permutation for feature 0 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort/TopKV2:1", shape=(1000000,), dtype=int32)
# Shuffling indices for feature 1 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_3:0", shape=(5000,), dtype=int32)
# Seed for partial permutation: 1
# Inverse permutation for feature 1 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_1/TopKV2:1", shape=(1000000,), dtype=int32)
# Shuffling indices for feature 2 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_5:0", shape=(5000,), dtype=int32)
# Seed for partial permutation: 2
# Inverse permutation for feature 2 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_2/TopKV2:1", shape=(1000000,), dtype=int32)
# Shuffling indices for feature 3 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_7:0", shape=(5000,), dtype=int32)
# Seed for partial permutation: 3
# Inverse permutation for feature 3 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_3/TopKV2:1", shape=(1000000,), dtype=int32)
# Shuffling indices for feature 4 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_9:0", shape=(5000,), dtype=int32)
# Seed for partial permutation: 4
# Inverse permutation for feature 4 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_4/TopKV2:1", shape=(1000000,), dtype=int32)
# LR metric calculation completed in 22.936214384972118 seconds.
# statistic = -56645.04632885229 - next threshold = -29622.317668251802 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 59245.94858043976
#
# ------------ 2 - 0.95 CL - upper bound -----------
# eps = 0.0075 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Shuffling indices for feature 0 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 0
# Permutation for feature 0 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 1 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 1
# Permutation for feature 1 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 2 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 2
# Permutation for feature 2 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 3 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 3
# Permutation for feature 3 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 4 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 4
# Permutation for feature 4 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# WARNING:tensorflow:6 out of the last 15 calls to <function generate_and_clean_data_simple_1 at 0x7f0a60de4160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Shuffling indices for feature 0 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_1:0", shape=(150000,), dtype=int32)
# Seed for partial permutation: 0
# Inverse permutation for feature 0 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort/TopKV2:1", shape=(20000000,), dtype=int32)
# Shuffling indices for feature 1 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_3:0", shape=(150000,), dtype=int32)
# Seed for partial permutation: 1
# Inverse permutation for feature 1 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_1/TopKV2:1", shape=(20000000,), dtype=int32)
# Shuffling indices for feature 2 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_5:0", shape=(150000,), dtype=int32)
# Seed for partial permutation: 2
# Inverse permutation for feature 2 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_2/TopKV2:1", shape=(20000000,), dtype=int32)
# Shuffling indices for feature 3 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_7:0", shape=(150000,), dtype=int32)
# Seed for partial permutation: 3
# Inverse permutation for feature 3 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_3/TopKV2:1", shape=(20000000,), dtype=int32)
# Shuffling indices for feature 4 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_9:0", shape=(150000,), dtype=int32)
# Seed for partial permutation: 4
# Inverse permutation for feature 4 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_4/TopKV2:1", shape=(20000000,), dtype=int32)
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 19.595882897032425 seconds.
# Saving lr to results/5D_mixture/5D_10K/null_hypothesis/LR_cov_off_diag_0.007500.json
# ThresholdS: [[0.95, [9500, 500], -48655.687398685004], [0.99, [9900, 100], -40983.3841069191]]
# Null distribution computed in 19.741460252087563 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Shuffling indices for feature 0 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 0
# Permutation for feature 0 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 1 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 1
# Permutation for feature 1 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 2 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 2
# Permutation for feature 2 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 3 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 3
# Permutation for feature 3 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 4 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 4
# Permutation for feature 4 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# Shuffling indices for feature 0 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_1:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 0
# Permutation for feature 0 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 1 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_3:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 1
# Permutation for feature 1 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_1:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 2 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_5:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 2
# Permutation for feature 2 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_2:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 3 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_7:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 3
# Permutation for feature 3 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_3:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 4 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_9:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 4
# Permutation for feature 4 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_4:0", shape=(None,), dtype=int32)
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 100
# batch_size = 10000
# Shuffling indices for feature 0 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_1:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 0
# Permutation for feature 0 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 1 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_3:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 1
# Permutation for feature 1 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_1:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 2 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_5:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 2
# Permutation for feature 2 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_2:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 3 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_7:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 3
# Permutation for feature 3 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_3:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 4 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/strided_slice_9:0", shape=(None,), dtype=int32)
# Seed for partial permutation: 4
# Permutation for feature 4 : Tensor("while/DynamicShufflingBijectorMixtureSameFamily_CONSTRUCTED_AT_top_level/sample/DynamicShufflingBijector/forward/TensorScatterUpdate_4:0", shape=(None,), dtype=int32)
# Shuffling indices for feature 0 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_1:0", shape=(7500,), dtype=int32)
# Seed for partial permutation: 0
# Inverse permutation for feature 0 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort/TopKV2:1", shape=(1000000,), dtype=int32)
# Shuffling indices for feature 1 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_3:0", shape=(7500,), dtype=int32)
# Seed for partial permutation: 1
# Inverse permutation for feature 1 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_1/TopKV2:1", shape=(1000000,), dtype=int32)
# Shuffling indices for feature 2 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_5:0", shape=(7500,), dtype=int32)
# Seed for partial permutation: 2
# Inverse permutation for feature 2 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_2/TopKV2:1", shape=(1000000,), dtype=int32)
# Shuffling indices for feature 3 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_7:0", shape=(7500,), dtype=int32)
# Seed for partial permutation: 3
# Inverse permutation for feature 3 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_3/TopKV2:1", shape=(1000000,), dtype=int32)
# Shuffling indices for feature 4 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/strided_slice_9:0", shape=(7500,), dtype=int32)
# Seed for partial permutation: 4
# Inverse permutation for feature 4 : Tensor("DynamicShufflingBijectorMixtureSameFamily/log_prob/DynamicShufflingBijector/inverse/argsort_4/TopKV2:1", shape=(1000000,), dtype=int32)
# LR metric calculation completed in 23.870380613021553 seconds.
# statistic = -82239.13492819408 - next threshold = -48655.687398685004 at 0.95 CL
# relative_error_eps = 0.28571428571428575
# relative_error_metric = 97312.63136555912
#
# ------------ 3 - 0.95 CL - upper bound -----------
# eps = 0.00875 - deformation = cov_off_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Shuffling indices for feature 0 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 0
# Permutation for feature 0 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 1 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 1
# Permutation for feature 1 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 2 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 2
# Permutation for feature 2 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 3 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 3
# Permutation for feature 3 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Shuffling indices for feature 4 : tf.Tensor([], shape=(0,), dtype=int32)
# Seed for partial permutation: 4
# Permutation for feature 4 : tf.Tensor([0 1], shape=(2,), dtype=int32)
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 10000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 14
#      12 if result == {}:
#      13     print(f"Computing {bound} bounds for lr with {deformation} deformation.")
# ---> 14     result = compute_exclusion_LR_bisection(dist_1,
#      15                                             metric_config = metrics_config[unique_key]["lr"],
#      16                                             test_kwargs = test_kwargs,
#      17                                             model_dir = model_dir,
#      18                                             cl_list = [0.95, 0.99],
#      19                                             deformation = deformation,
#      20                                             seed_dist = 0,
#      21                                             x_tol = 0.01,
#      22                                             fn_tol = 0.05,
#      23                                             bound = bound,
#      24                                             eps_min = 0.,
#      25                                             eps_max = eps_max,
#      26                                             max_iterations = 50,
#      27                                             save = True,
#      28                                             filename = "exclusion_limits.json",
#      29                                             verbose = True)
#      30     eps_max = list(result.values())[0]["exclusion_list"][-1][3]
#      31 else:
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/more/optimizers_deformations.py:857, in compute_exclusion_LR_bisection(reference_distribution, metric_config, test_kwargs, model_dir, cl_list, deformation, seed_dist, x_tol, fn_tol, bound, eps_min, eps_max, max_iterations, save, filename, verbose)
#     852 TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
#     853                                                    dist_2_input = dist_2,
#     854                                                    **test_kwargs_null)
#     856 LRMetric_null = GMetrics.LRMetric(TwoSampleTestInputs, **metric_kwargs_null)
# --> 857 LRMetric_null.Test_tf(max_vectorize = max_vectorize)
#     859 null_file = null_file_base.replace(".json", "_" + deformation + "_" + str(format(eps, '.6f')) + ".json")
#     860 print("Saving", metric_name, "to", null_file)
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/llr.py:704, in LRMetric.Test_tf(self, max_vectorize)
#     702 lik_ratio_list: DataTypeTF
#     703 lik_ratio_norm_list: DataTypeTF
# --> 704 logprob_ref_ref_sum_list, logprob_ref_alt_sum_list, logprob_alt_alt_sum_list, lik_ratio_list, lik_ratio_norm_list = compute_test(max_vectorize = max_vectorize) # type: ignore
#     706 end_calculation()
#     708 timestamp: str = datetime.now().isoformat()
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/llr.py:677, in LRMetric.Test_tf.<locals>.compute_test(max_vectorize)
#     674     res = res.write(i, chunk_result)
#     675     return i+1, res
# --> 677 _, res = tf.while_loop(lambda i, _: i < nchunks, body, [0, res])
#     679 for i in range(nchunks):
#     680     res_i = res.read(i)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     640           _PRINTED_WARNING[(func, arg_name)] = True
#     641         logging.warning(
#     642             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     643             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     646             'in a future version' if date is None else
#     647             ('after %s' % date), instructions)
# --> 648 return func(*args, **kwargs)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/control_flow_ops.py:2574, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2368 @tf_export("while_loop", v1=[])
#    2369 @deprecation.deprecated_arg_values(
#    2370     None,
#    (...)
#    2385                   maximum_iterations=None,
#    2386                   name=None):
#    2387   """Repeat `body` while the condition `cond` is true.
#    2388
#    2389   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)
#    2572
#    2573   """
# -> 2574   return while_loop(
#    2575       cond=cond,
#    2576       body=body,
#    2577       loop_vars=loop_vars,
#    2578       shape_invariants=shape_invariants,
#    2579       parallel_iterations=parallel_iterations,
#    2580       back_prop=back_prop,
#    2581       swap_memory=swap_memory,
#    2582       name=name,
#    2583       maximum_iterations=maximum_iterations,
#    2584       return_same_structure=True)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/ops/control_flow_ops.py:2823, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2820 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#    2821                                         list(loop_vars))
#    2822 while cond(*loop_vars):
# -> 2823   loop_vars = body(*loop_vars)
#    2824   if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2825     packed = True
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/llr.py:673, in LRMetric.Test_tf.<locals>.compute_test.<locals>.body(i, res)
#     671 end = tf.minimum(start + max_iter_per_chunk, niter)
#     672 conditional_tf_print(tf.logical_and(tf.logical_or(tf.math.logical_not(tf.equal(start,0)),tf.math.logical_not(tf.equal(end,niter))), self.verbose), "Iterating from", start, "to", end, "out of", niter, ".") # type: ignore
# --> 673 chunk_result = batched_test(start, end) # type: ignore
#     674 res = res.write(i, chunk_result)
#     675 return i+1, res
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/llr.py:587, in LRMetric.Test_tf.<locals>.batched_test(start, end)
#     583 def batched_test(start: tf.Tensor,
#     584                  end: tf.Tensor
#     585                 ) -> DataTypeTF:
#     586     # Define the loop body to vectorize over ndims*chunk_size
# --> 587     dist_1_k: DataTypeTF = set_dist_num_from_symb(dist_1_symb, nsamples = batch_size * (end - start)) # type: ignore
#     588     if null:
#     589         dist_2_k: DataTypeTF = set_dist_num_from_symb(dist_1_symb, nsamples = batch_size * (end - start)) # type: ignore
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/metrics/llr.py:527, in LRMetric.Test_tf.<locals>.set_dist_num_from_symb(dist, nsamples)
#     524 def set_dist_num_from_symb(dist: DistTypeTF,
#     525                            nsamples: int,
#     526                           ) -> tf.Tensor:
# --> 527     dist_num: tf.Tensor = generate_and_clean_data(dist, nsamples, self.Inputs.batch_size_gen, dtype = self.Inputs.dtype, seed_generator = self.Inputs.seed_generator, strategy = self.Inputs.strategy) # type: ignore
#     528     return dist_num
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/utils.py:546, in generate_and_clean_data(dist, n_samples, batch_size, dtype, seed_generator, strategy)
#     539     return generate_and_clean_data_mirror(dist = dist,
#     540                                           n_samples = n_samples,
#     541                                           batch_size = batch_size,
#     542                                           dtype = dtype,
#     543                                           seed_generator = seed_generator,
#     544                                           strategy = strategy)
#     545 else:
# --> 546     return generate_and_clean_data_simple(dist = dist,
#     547                                           n_samples = n_samples,
#     548                                           batch_size = batch_size,
#     549                                           dtype = dtype,
#     550                                           seed_generator = seed_generator)
#
# File /local_data/teo_fs_fast/rtorre/cernbox/ML/TwoSampleTests/GitHub/GenerativeModelsMetrics/GMetrics/utils.py:418, in generate_and_clean_data_simple(*args, **kwargs)
#     417 def generate_and_clean_data_simple(*args, **kwargs):
# --> 418     return generate_and_clean_data_simple_1(*args, **kwargs)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:933, in Function._call(self, *args, **kwds)
#     930 self._lock.release()
#     931 # In this case we have not created variables on the first call. So we can
#     932 # run the first trace but we should fail if variables are created.
# --> 933 results = self._variable_creation_fn(*args, **kwds)
#     934 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     935   raise ValueError("Creating variables on a non-first call to a function"
#     936                    " decorated with tf.function.")
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File /local_data/scratch/rtorre/anaconda3/envs/tf2_12/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Show and save results

# %%
import notebooks.shared as shared

# %%
results_df, times_df = shared.generate_result_dataframe(global_results, null_times)
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean, results_df_cov_diag, results_df_cov_off_diag, results_df_power_abs_up, results_df_power_abs_down, results_df_random_normal, results_df_random_uniform = shared.get_individual_dfs(results_df, show = True)
# Out:
#    Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35       swd        $0.09192_{-0.035}^{+0.035}$
# 9         ks      $0.00496_{-0.0017}^{+0.0017}$
# 28       sks        $0.05494_{-0.019}^{+0.019}$
# 2        fgd         $0.10354_{-0.044}^{+0.06}$
# 21       mmd        $0.06434_{-0.025}^{+0.035}$
# 16        lr    $0.00078_{-0.00047}^{+0.00047}$
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$ $t^{\mu}$ (s)
# 35        $0.12363_{-0.032}^{+0.035}$        $1353$
# 9       $0.00664_{-0.0017}^{+0.0015}$        $1539$
# 28        $0.07242_{-0.018}^{+0.018}$        $1748$
# 2         $0.14117_{-0.042}^{+0.056}$        $1278$
# 21        $0.08544_{-0.025}^{+0.033}$        $1344$
# 16     $0.0011_{-0.00047}^{+0.00047}$        $2810$
#    Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 33       swd              $0.03015_{-0.0099}^{+0.0085}$
# 7         ks            $0.00274_{-0.00069}^{+0.00063}$
# 26       sks              $0.01644_{-0.0045}^{+0.0038}$
# 0        fgd                 $0.0327_{-0.01}^{+0.0089}$
# 19       mmd              $0.01392_{-0.0046}^{+0.0054}$
# 14        lr            $0.00027_{-0.00016}^{+0.00016}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$ $t^{\Sigma_{ii}}$ (s)
# 33              $0.04164_{-0.0086}^{+0.0081}$                $1531$
# 7             $0.00353_{-0.00064}^{+0.00059}$                $1626$
# 26              $0.02223_{-0.0038}^{+0.0033}$                $1888$
# 0                $0.0444_{-0.0077}^{+0.0077}$                $1270$
# 19                $0.0188_{-0.0044}^{+0.005}$                $1497$
# 14            $0.00037_{-0.00016}^{+0.00017}$                $3000$
#    Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 34       swd                    $0.02827_{-0.0083}^{+0.006}$
# 8         ks                        $1.00317_{-0.0013}^{+0}$
# 27       sks                   $0.02595_{-0.0081}^{+0.0071}$
# 1        fgd                   $0.01229_{-0.0034}^{+0.0032}$
# 20       mmd                    $0.02322_{-0.008}^{+0.0085}$
# 15        lr                      $0.04301_{-0.02}^{+0.016}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$ $t^{\Sigma_{i\neq j}}$ (s)
# 34                   $0.03864_{-0.0063}^{+0.0056}$                     $1766$
# 8                  $1.00354_{-0.00043}^{+0.00012}$                     $1651$
# 27                    $0.0347_{-0.0073}^{+0.0062}$                     $1941$
# 1                    $0.01728_{-0.0028}^{+0.0027}$                     $2040$
# 20                   $0.03162_{-0.0076}^{+0.0081}$                     $2024$
# 15                      $0.0542_{-0.015}^{+0.015}$                     $4164$
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 37       swd               $0.01845_{-0.0061}^{+0.0052}$
# 11        ks              $0.00345_{-0.0011}^{+0.00099}$
# 30       sks                $0.0106_{-0.0027}^{+0.0024}$
# 4        fgd                $0.01964_{-0.006}^{+0.0054}$
# 23       mmd               $0.00788_{-0.0027}^{+0.0032}$
# 18        lr             $0.00041_{-0.00025}^{+0.00025}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$ $t^{\rm{pow}_{+}}$ (s)
# 37                $0.0255_{-0.0053}^{+0.0047}$                 $1259$
# 11             $0.00444_{-0.00097}^{+0.00096}$                 $1612$
# 30               $0.01405_{-0.0023}^{+0.0021}$                 $1807$
# 4                $0.02668_{-0.0048}^{+0.0046}$                 $1294$
# 23                $0.01064_{-0.0024}^{+0.003}$                 $1518$
# 18             $0.00057_{-0.00025}^{+0.00025}$                 $3017$
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 36       swd               $0.01989_{-0.0064}^{+0.0056}$
# 10        ks              $0.00317_{-0.00089}^{+0.0009}$
# 29       sks               $0.01066_{-0.0027}^{+0.0023}$
# 3        fgd               $0.02088_{-0.0061}^{+0.0059}$
# 22       mmd               $0.00858_{-0.0032}^{+0.0037}$
# 17        lr             $0.00036_{-0.00025}^{+0.00025}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$ $t^{\rm{pow}_{-}}$ (s)
# 36                $0.0273_{-0.0055}^{+0.0052}$                 $1221$
# 10              $0.00416_{-0.00083}^{+0.0009}$                 $1634$
# 29               $0.01407_{-0.0022}^{+0.0021}$                 $1804$
# 3                  $0.02847_{-0.005}^{+0.005}$                 $1300$
# 22                $0.01169_{-0.003}^{+0.0034}$                 $1550$
# 17             $0.00053_{-0.00025}^{+0.00025}$                 $3139$
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 38       swd                $0.25306_{-0.043}^{+0.031}$
# 12        ks              $0.00921_{-0.0017}^{+0.0016}$
# 31       sks                $0.18137_{-0.036}^{+0.025}$
# 5        fgd                $0.29378_{-0.045}^{+0.029}$
# 24       mmd                $0.37502_{-0.064}^{+0.046}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$ $t^{\mathcal{N}}$ (s)
# 38                $0.29897_{-0.029}^{+0.026}$                $1050$
# 12              $0.01112_{-0.0016}^{+0.0016}$                $1496$
# 31                $0.21312_{-0.025}^{+0.023}$                $1551$
# 5                 $0.34516_{-0.026}^{+0.022}$                $1080$
# 24                $0.43162_{-0.039}^{+0.041}$                $1240$
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 39       swd                 $0.4365_{-0.078}^{+0.054}$
# 13        ks              $0.01504_{-0.0027}^{+0.0026}$
# 32       sks                $0.30846_{-0.057}^{+0.044}$
# 6        fgd                $0.50798_{-0.076}^{+0.053}$
# 25       mmd                $0.64544_{-0.099}^{+0.087}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$ $t^{\mathcal{U}}$ (s)
# 39                $0.51675_{-0.053}^{+0.039}$                 $988$
# 13              $0.01804_{-0.0026}^{+0.0022}$                $1510$
# 32                $0.36537_{-0.045}^{+0.036}$                $1513$
# 6                 $0.59684_{-0.049}^{+0.038}$                $1030$
# 25                 $0.7501_{-0.067}^{+0.064}$                $1231$

# %%
sorted_df_mean, sorted_df_cov_diag, sorted_df_cov_off_diag, sorted_df_power_abs_up, sorted_df_power_abs_down, sorted_df_random_normal, sorted_df_random_uniform = shared.get_sorted_dfs(results_df, show = True)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 16        lr        mean    5  10000                10000
# 9         ks        mean    5  10000                10000
# 28       sks        mean    5  10000                10000
# 21       mmd        mean    5  10000                10000
# 35       swd        mean    5  10000                10000
# 2        fgd        mean    5  10000                10000
#
#    $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 16    $0.00078_{-0.00047}^{+0.00047}$     $0.0011_{-0.00047}^{+0.00047}$
# 9       $0.00496_{-0.0017}^{+0.0017}$      $0.00664_{-0.0017}^{+0.0015}$
# 28        $0.05494_{-0.019}^{+0.019}$        $0.07242_{-0.018}^{+0.018}$
# 21        $0.06434_{-0.025}^{+0.035}$        $0.08544_{-0.025}^{+0.033}$
# 35        $0.09192_{-0.035}^{+0.035}$        $0.12363_{-0.032}^{+0.035}$
# 2          $0.10354_{-0.044}^{+0.06}$        $0.14117_{-0.042}^{+0.056}$
#
#    $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 16        $2810$  [0.00031, 0.00078, 0.00125]   [0.00063, 0.0011, 0.00157]
# 9         $1539$  [0.00326, 0.00496, 0.00662]  [0.00499, 0.00664, 0.00817]
# 28        $1748$   [0.0355, 0.05494, 0.07349]  [0.05439, 0.07242, 0.09045]
# 21        $1344$  [0.03888, 0.06434, 0.09912]  [0.06089, 0.08544, 0.11892]
# 35        $1353$  [0.05723, 0.09192, 0.12646]   [0.0912, 0.12363, 0.15845]
# 2         $1278$  [0.05983, 0.10354, 0.16357]  [0.09891, 0.14117, 0.19706]
#
#                                                  time
# 16  [1116.6006071249722, 819.3868620599969, 874.75...
# 9   [721.4121929989778, 394.58612885902403, 423.97...
# 28  [726.5785985229886, 503.2114245800185, 518.374...
# 21  [532.554473030963, 406.1812563749845, 406.2149...
# 35  [549.9583313300973, 390.1698602520628, 413.404...
# 2   [503.86282532603946, 400.80799613601994, 373.9...
#    Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 16        lr    $0.00078_{-0.00047}^{+0.00047}$
# 9         ks      $0.00496_{-0.0017}^{+0.0017}$
# 28       sks        $0.05494_{-0.019}^{+0.019}$
# 21       mmd        $0.06434_{-0.025}^{+0.035}$
# 35       swd        $0.09192_{-0.035}^{+0.035}$
# 2        fgd         $0.10354_{-0.044}^{+0.06}$
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$ $t^{\mu}$ (s)
# 16     $0.0011_{-0.00047}^{+0.00047}$        $2810$
# 9       $0.00664_{-0.0017}^{+0.0015}$        $1539$
# 28        $0.07242_{-0.018}^{+0.018}$        $1748$
# 21        $0.08544_{-0.025}^{+0.033}$        $1344$
# 35        $0.12363_{-0.032}^{+0.035}$        $1353$
# 2         $0.14117_{-0.042}^{+0.056}$        $1278$
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 14        lr    cov_diag    5  10000                10000
# 7         ks    cov_diag    5  10000                10000
# 19       mmd    cov_diag    5  10000                10000
# 26       sks    cov_diag    5  10000                10000
# 33       swd    cov_diag    5  10000                10000
# 0        fgd    cov_diag    5  10000                10000
#
#    $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 14            $0.00027_{-0.00016}^{+0.00016}$
# 7             $0.00274_{-0.00069}^{+0.00063}$
# 19              $0.01392_{-0.0046}^{+0.0054}$
# 26              $0.01644_{-0.0045}^{+0.0038}$
# 33              $0.03015_{-0.0099}^{+0.0085}$
# 0                  $0.0327_{-0.01}^{+0.0089}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$ $t^{\Sigma_{ii}}$ (s)  \
# 14            $0.00037_{-0.00016}^{+0.00017}$                $3000$
# 7             $0.00353_{-0.00064}^{+0.00059}$                $1626$
# 19                $0.0188_{-0.0044}^{+0.005}$                $1497$
# 26              $0.02223_{-0.0038}^{+0.0033}$                $1888$
# 33              $0.04164_{-0.0086}^{+0.0081}$                $1531$
# 0                $0.0444_{-0.0077}^{+0.0077}$                $1270$
#
#                           95%CL                        99%CL  \
# 14  [0.00011, 0.00027, 0.00043]  [0.00021, 0.00037, 0.00054]
# 7   [0.00205, 0.00274, 0.00337]  [0.00289, 0.00353, 0.00412]
# 19  [0.00929, 0.01392, 0.01935]   [0.01445, 0.0188, 0.02384]
# 26   [0.01194, 0.01644, 0.0202]  [0.01845, 0.02223, 0.02558]
# 33   [0.02025, 0.03015, 0.0387]  [0.03303, 0.04164, 0.04973]
# 0    [0.02264, 0.0327, 0.04163]   [0.03675, 0.0444, 0.05215]
#
#                                                  time
# 14  [1251.7937426619465, 843.2239083139575, 905.10...
# 7   [817.7723682789947, 394.41880318004405, 414.67...
# 19  [695.8513301910134, 386.8150321429712, 415.029...
# 26  [855.5153927190113, 527.793515025056, 504.8580...
# 33  [627.1693274779245, 551.4065567920916, 353.248...
# 0   [563.2413620240404, 351.98060620896285, 355.16...
#    Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 14        lr            $0.00027_{-0.00016}^{+0.00016}$
# 7         ks            $0.00274_{-0.00069}^{+0.00063}$
# 19       mmd              $0.01392_{-0.0046}^{+0.0054}$
# 26       sks              $0.01644_{-0.0045}^{+0.0038}$
# 33       swd              $0.03015_{-0.0099}^{+0.0085}$
# 0        fgd                 $0.0327_{-0.01}^{+0.0089}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$ $t^{\Sigma_{ii}}$ (s)
# 14            $0.00037_{-0.00016}^{+0.00017}$                $3000$
# 7             $0.00353_{-0.00064}^{+0.00059}$                $1626$
# 19                $0.0188_{-0.0044}^{+0.005}$                $1497$
# 26              $0.02223_{-0.0038}^{+0.0033}$                $1888$
# 33              $0.04164_{-0.0086}^{+0.0081}$                $1531$
# 0                $0.0444_{-0.0077}^{+0.0077}$                $1270$
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 1        fgd  cov_off_diag    5  10000                10000
# 20       mmd  cov_off_diag    5  10000                10000
# 27       sks  cov_off_diag    5  10000                10000
# 34       swd  cov_off_diag    5  10000                10000
# 15        lr  cov_off_diag    5  10000                10000
# 8         ks  cov_off_diag    5  10000                10000
#
#    $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 1                    $0.01229_{-0.0034}^{+0.0032}$
# 20                    $0.02322_{-0.008}^{+0.0085}$
# 27                   $0.02595_{-0.0081}^{+0.0071}$
# 34                    $0.02827_{-0.0083}^{+0.006}$
# 15                      $0.04301_{-0.02}^{+0.016}$
# 8                         $1.00317_{-0.0013}^{+0}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$ $t^{\Sigma_{i\neq j}}$ (s)  \
# 1                    $0.01728_{-0.0028}^{+0.0027}$                     $2040$
# 20                   $0.03162_{-0.0076}^{+0.0081}$                     $2024$
# 27                    $0.0347_{-0.0073}^{+0.0062}$                     $1941$
# 34                   $0.03864_{-0.0063}^{+0.0056}$                     $1766$
# 15                      $0.0542_{-0.015}^{+0.015}$                     $4164$
# 8                  $1.00354_{-0.00043}^{+0.00012}$                     $1651$
#
#                           95%CL                        99%CL  \
# 1   [0.00888, 0.01229, 0.01544]  [0.01446, 0.01728, 0.01998]
# 20  [0.01525, 0.02322, 0.03171]  [0.02401, 0.03162, 0.03976]
# 27  [0.01783, 0.02595, 0.03308]   [0.02745, 0.0347, 0.04088]
# 34      [0.02, 0.02827, 0.0343]  [0.03238, 0.03864, 0.04426]
# 15  [0.02297, 0.04301, 0.05933]   [0.03895, 0.0542, 0.06904]
# 8   [1.00182, 1.00317, 1.00317]  [1.00311, 1.00354, 1.00366]
#
#                                                  time
# 1   [1012.8642071262002, 515.768616579473, 511.550...
# 20  [1023.7511811899021, 491.38002337981015, 509.4...
# 27  [934.1699034655467, 502.4757956666872, 505.329...
# 34  [852.6976961968467, 457.02830883394927, 456.46...
# 15  [1900.7924868213013, 1090.7797615518793, 1172....
# 8   [793.6250622477382, 413.12721985857934, 444.49...
#    Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 1        fgd                   $0.01229_{-0.0034}^{+0.0032}$
# 20       mmd                    $0.02322_{-0.008}^{+0.0085}$
# 27       sks                   $0.02595_{-0.0081}^{+0.0071}$
# 34       swd                    $0.02827_{-0.0083}^{+0.006}$
# 15        lr                      $0.04301_{-0.02}^{+0.016}$
# 8         ks                        $1.00317_{-0.0013}^{+0}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$ $t^{\Sigma_{i\neq j}}$ (s)
# 1                    $0.01728_{-0.0028}^{+0.0027}$                     $2040$
# 20                   $0.03162_{-0.0076}^{+0.0081}$                     $2024$
# 27                    $0.0347_{-0.0073}^{+0.0062}$                     $1941$
# 34                   $0.03864_{-0.0063}^{+0.0056}$                     $1766$
# 15                      $0.0542_{-0.015}^{+0.015}$                     $4164$
# 8                  $1.00354_{-0.00043}^{+0.00012}$                     $1651$
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 18        lr  power_abs_up    5  10000                10000
# 11        ks  power_abs_up    5  10000                10000
# 23       mmd  power_abs_up    5  10000                10000
# 30       sks  power_abs_up    5  10000                10000
# 37       swd  power_abs_up    5  10000                10000
# 4        fgd  power_abs_up    5  10000                10000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 18             $0.00041_{-0.00025}^{+0.00025}$
# 11              $0.00345_{-0.0011}^{+0.00099}$
# 23               $0.00788_{-0.0027}^{+0.0032}$
# 30                $0.0106_{-0.0027}^{+0.0024}$
# 37               $0.01845_{-0.0061}^{+0.0052}$
# 4                 $0.01964_{-0.006}^{+0.0054}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$ $t^{\rm{pow}_{+}}$ (s)  \
# 18             $0.00057_{-0.00025}^{+0.00025}$                 $3017$
# 11             $0.00444_{-0.00097}^{+0.00096}$                 $1612$
# 23                $0.01064_{-0.0024}^{+0.003}$                 $1518$
# 30               $0.01405_{-0.0023}^{+0.0021}$                 $1807$
# 37                $0.0255_{-0.0053}^{+0.0047}$                 $1259$
# 4                $0.02668_{-0.0048}^{+0.0046}$                 $1294$
#
#                           95%CL                        99%CL  \
# 18  [0.00016, 0.00041, 0.00066]  [0.00032, 0.00057, 0.00082]
# 11   [0.0024, 0.00345, 0.00444]   [0.00347, 0.00444, 0.0054]
# 23  [0.00522, 0.00788, 0.01108]   [0.0082, 0.01064, 0.01367]
# 30     [0.00788, 0.0106, 0.013]  [0.01178, 0.01405, 0.01619]
# 37   [0.0124, 0.01845, 0.02362]   [0.02023, 0.0255, 0.03018]
# 4    [0.0136, 0.01964, 0.02502]  [0.02187, 0.02668, 0.03133]
#
#                                                  time
# 18  [1236.8033300900133, 861.3543256989797, 919.22...
# 11  [830.1397032879759, 392.12970347795635, 389.85...
# 23  [713.0644931560382, 387.9335741070099, 417.280...
# 30  [873.0460290480405, 471.58915127592627, 463.33...
# 37  [573.8578686630353, 332.55843842204195, 353.12...
# 4   [587.1641694679856, 354.59670760895824, 352.25...
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 18        lr             $0.00041_{-0.00025}^{+0.00025}$
# 11        ks              $0.00345_{-0.0011}^{+0.00099}$
# 23       mmd               $0.00788_{-0.0027}^{+0.0032}$
# 30       sks                $0.0106_{-0.0027}^{+0.0024}$
# 37       swd               $0.01845_{-0.0061}^{+0.0052}$
# 4        fgd                $0.01964_{-0.006}^{+0.0054}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$ $t^{\rm{pow}_{+}}$ (s)
# 18             $0.00057_{-0.00025}^{+0.00025}$                 $3017$
# 11             $0.00444_{-0.00097}^{+0.00096}$                 $1612$
# 23                $0.01064_{-0.0024}^{+0.003}$                 $1518$
# 30               $0.01405_{-0.0023}^{+0.0021}$                 $1807$
# 37                $0.0255_{-0.0053}^{+0.0047}$                 $1259$
# 4                $0.02668_{-0.0048}^{+0.0046}$                 $1294$
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 17        lr  power_abs_down    5  10000                10000
# 10        ks  power_abs_down    5  10000                10000
# 22       mmd  power_abs_down    5  10000                10000
# 29       sks  power_abs_down    5  10000                10000
# 36       swd  power_abs_down    5  10000                10000
# 3        fgd  power_abs_down    5  10000                10000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 17             $0.00036_{-0.00025}^{+0.00025}$
# 10              $0.00317_{-0.00089}^{+0.0009}$
# 22               $0.00858_{-0.0032}^{+0.0037}$
# 29               $0.01066_{-0.0027}^{+0.0023}$
# 36               $0.01989_{-0.0064}^{+0.0056}$
# 3                $0.02088_{-0.0061}^{+0.0059}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$ $t^{\rm{pow}_{-}}$ (s)  \
# 17             $0.00053_{-0.00025}^{+0.00025}$                 $3139$
# 10              $0.00416_{-0.00083}^{+0.0009}$                 $1634$
# 22                $0.01169_{-0.003}^{+0.0034}$                 $1550$
# 29               $0.01407_{-0.0022}^{+0.0021}$                 $1804$
# 36                $0.0273_{-0.0055}^{+0.0052}$                 $1221$
# 3                  $0.02847_{-0.005}^{+0.005}$                 $1300$
#
#                           95%CL                        99%CL  \
# 17  [0.00011, 0.00036, 0.00061]  [0.00028, 0.00053, 0.00078]
# 10  [0.00228, 0.00317, 0.00407]  [0.00333, 0.00416, 0.00506]
# 22  [0.00541, 0.00858, 0.01227]   [0.00867, 0.01169, 0.0151]
# 29    [0.00794, 0.01066, 0.013]  [0.01182, 0.01407, 0.01619]
# 36  [0.01349, 0.01989, 0.02551]   [0.02179, 0.0273, 0.03253]
# 3   [0.01474, 0.02088, 0.02673]  [0.02343, 0.02847, 0.03351]
#
#                                                  time
# 17  [1249.9514621690032, 886.3874903999968, 1003.4...
# 10  [816.6894576060004, 416.58517683303216, 401.25...
# 22  [707.537885158963, 406.76474929298274, 436.005...
# 29  [858.6036595510086, 478.25074878602754, 467.42...
# 36  [553.6826110670809, 333.47791843803134, 334.34...
# 3   [588.7946560000419, 356.40796241303906, 355.30...
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 17        lr             $0.00036_{-0.00025}^{+0.00025}$
# 10        ks              $0.00317_{-0.00089}^{+0.0009}$
# 22       mmd               $0.00858_{-0.0032}^{+0.0037}$
# 29       sks               $0.01066_{-0.0027}^{+0.0023}$
# 36       swd               $0.01989_{-0.0064}^{+0.0056}$
# 3        fgd               $0.02088_{-0.0061}^{+0.0059}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$ $t^{\rm{pow}_{-}}$ (s)
# 17             $0.00053_{-0.00025}^{+0.00025}$                 $3139$
# 10              $0.00416_{-0.00083}^{+0.0009}$                 $1634$
# 22                $0.01169_{-0.003}^{+0.0034}$                 $1550$
# 29               $0.01407_{-0.0022}^{+0.0021}$                 $1804$
# 36                $0.0273_{-0.0055}^{+0.0052}$                 $1221$
# 3                  $0.02847_{-0.005}^{+0.005}$                 $1300$
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 12        ks  random_normal    5  10000                10000
# 31       sks  random_normal    5  10000                10000
# 38       swd  random_normal    5  10000                10000
# 5        fgd  random_normal    5  10000                10000
# 24       mmd  random_normal    5  10000                10000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 12              $0.00921_{-0.0017}^{+0.0016}$
# 31                $0.18137_{-0.036}^{+0.025}$
# 38                $0.25306_{-0.043}^{+0.031}$
# 5                 $0.29378_{-0.045}^{+0.029}$
# 24                $0.37502_{-0.064}^{+0.046}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$ $t^{\mathcal{N}}$ (s)  \
# 12              $0.01112_{-0.0016}^{+0.0016}$                $1496$
# 31                $0.21312_{-0.025}^{+0.023}$                $1551$
# 38                $0.29897_{-0.029}^{+0.026}$                $1050$
# 5                 $0.34516_{-0.026}^{+0.022}$                $1080$
# 24                $0.43162_{-0.039}^{+0.041}$                $1240$
#
#                           95%CL                        99%CL  \
# 12  [0.00749, 0.00921, 0.01083]  [0.00956, 0.01112, 0.01271]
# 31  [0.14527, 0.18137, 0.20605]  [0.18821, 0.21312, 0.23629]
# 38  [0.20963, 0.25306, 0.28418]  [0.27035, 0.29897, 0.32472]
# 5   [0.24876, 0.29378, 0.32324]  [0.31956, 0.34516, 0.36686]
# 24   [0.31107, 0.37502, 0.4209]  [0.39301, 0.43162, 0.47293]
#
#                                                  time
# 12  [733.2968799090013, 367.1510402719723, 395.704...
# 31  [598.604157524067, 466.22437625797465, 486.983...
# 38  [400.9483711060602, 313.18829382793047, 336.66...
# 5   [428.91028671199456, 315.42435057403054, 335.9...
# 24  [467.9148893489619, 353.14258448802866, 419.09...
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 12        ks              $0.00921_{-0.0017}^{+0.0016}$
# 31       sks                $0.18137_{-0.036}^{+0.025}$
# 38       swd                $0.25306_{-0.043}^{+0.031}$
# 5        fgd                $0.29378_{-0.045}^{+0.029}$
# 24       mmd                $0.37502_{-0.064}^{+0.046}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$ $t^{\mathcal{N}}$ (s)
# 12              $0.01112_{-0.0016}^{+0.0016}$                $1496$
# 31                $0.21312_{-0.025}^{+0.023}$                $1551$
# 38                $0.29897_{-0.029}^{+0.026}$                $1050$
# 5                 $0.34516_{-0.026}^{+0.022}$                $1080$
# 24                $0.43162_{-0.039}^{+0.041}$                $1240$
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 13        ks  random_uniform    5  10000                10000
# 32       sks  random_uniform    5  10000                10000
# 39       swd  random_uniform    5  10000                10000
# 6        fgd  random_uniform    5  10000                10000
# 25       mmd  random_uniform    5  10000                10000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 13              $0.01504_{-0.0027}^{+0.0026}$
# 32                $0.30846_{-0.057}^{+0.044}$
# 39                 $0.4365_{-0.078}^{+0.054}$
# 6                 $0.50798_{-0.076}^{+0.053}$
# 25                $0.64544_{-0.099}^{+0.087}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$ $t^{\mathcal{U}}$ (s)  \
# 13              $0.01804_{-0.0026}^{+0.0022}$                $1510$
# 32                $0.36537_{-0.045}^{+0.036}$                $1513$
# 39                $0.51675_{-0.053}^{+0.039}$                 $988$
# 6                 $0.59684_{-0.049}^{+0.038}$                $1030$
# 25                 $0.7501_{-0.067}^{+0.064}$                $1231$
#
#                           95%CL                        99%CL  \
# 13  [0.01229, 0.01504, 0.01764]  [0.01548, 0.01804, 0.02022]
# 32  [0.25191, 0.30846, 0.35254]  [0.32016, 0.36537, 0.40186]
# 39    [0.3583, 0.4365, 0.49023]  [0.46352, 0.51675, 0.55595]
# 6   [0.43248, 0.50798, 0.56055]  [0.54805, 0.59684, 0.63436]
# 25  [0.54646, 0.64544, 0.73242]   [0.68328, 0.7501, 0.81395]
#
#                                                  time
# 13  [732.9645943000214, 380.5699969410198, 396.706...
# 32  [571.6364182489924, 444.9441656289855, 497.232...
# 39  [356.3348404649878, 294.2506056819111, 337.463...
# 6   [382.48942911898484, 315.8973020550329, 332.40...
# 25  [415.7412443989888, 414.977384281985, 400.3538...
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 13        ks              $0.01504_{-0.0027}^{+0.0026}$
# 32       sks                $0.30846_{-0.057}^{+0.044}$
# 39       swd                 $0.4365_{-0.078}^{+0.054}$
# 6        fgd                $0.50798_{-0.076}^{+0.053}$
# 25       mmd                $0.64544_{-0.099}^{+0.087}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$ $t^{\mathcal{U}}$ (s)
# 13              $0.01804_{-0.0026}^{+0.0022}$                $1510$
# 32                $0.36537_{-0.045}^{+0.036}$                $1513$
# 39                $0.51675_{-0.053}^{+0.039}$                 $988$
# 6                 $0.59684_{-0.049}^{+0.038}$                $1030$
# 25                 $0.7501_{-0.067}^{+0.064}$                $1231$

# %% [markdown]
# ### Latex

# %%
#tex_string = shared.generate_result_latex_wide(results_df, times_df, nstring = "10^{4}")
tex_string = shared.generate_result_latex(results_df, times_df, title = "{\\bf MoG model with $\\mathbf{d=5}$, $\\mathbf{q=3}$, and $\\mathbf{n=m=10^{4}}$}")
print(tex_string)
# Out:
# \begin{tabular}{l|llr|llr}
# 	\toprule
# 	\multicolumn{7}{c}{{\bf MoG model with $\mathbf{d=5}$, $\mathbf{q=3}$, and $\mathbf{n=m=10^{4}}$}} \\
# 	\toprule
# 	\multicolumn{1}{c}{} & \multicolumn{3}{c}{$\mu$-deformation} & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation} \\
# 	Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# 	\midrule
# 	$t_{\mathrm{SW}}$ & $0.09192_{-0.035}^{+0.035}$ & $0.12363_{-0.032}^{+0.035}$ & $1353$ & $0.03015_{-0.0099}^{+0.0085}$ & $0.04164_{-0.0086}^{+0.0081}$ & $1531$ \\
# 	$t_{\overline{\mathrm{KS}}}$ & ${\mathbf{0.00496_{-0.0017}^{+0.0017}}}$ & ${\mathbf{0.00664_{-0.0017}^{+0.0015}}}$ & $1539$ & ${\mathbf{0.00274_{-0.00069}^{+0.00063}}}$ & ${\mathbf{0.00353_{-0.00064}^{+0.00059}}}$ & $1626$ \\
# 	$t_{\mathrm{SKS}}$ & $0.05494_{-0.019}^{+0.019}$ & $0.07242_{-0.018}^{+0.018}$ & $1748$ & $0.01644_{-0.0045}^{+0.0038}$ & $0.02223_{-0.0038}^{+0.0033}$ & $1888$ \\
# 	$t_{\mathrm{FGD}}$ & $0.10354_{-0.044}^{+0.06}$ & $0.14117_{-0.042}^{+0.056}$ & ${\mathbf{1278}}$ & $0.0327_{-0.01}^{+0.0089}$ & $0.0444_{-0.0077}^{+0.0077}$ & ${\mathbf{1270}}$ \\
# 	$t_{\mathrm{MMD}}$ & $0.06434_{-0.025}^{+0.035}$ & $0.08544_{-0.025}^{+0.033}$ & $1344$ & $0.01392_{-0.0046}^{+0.0054}$ & $0.0188_{-0.0044}^{+0.005}$ & $1497$ \\
# 	$t_{\mathrm{LLR}}$ & $0.00078_{-0.00047}^{+0.00047}$ & $0.0011_{-0.00047}^{+0.00047}$ & $2810$ & $0.00027_{-0.00016}^{+0.00016}$ & $0.00037_{-0.00016}^{+0.00017}$ & $3000$ \\
# 	\toprule
# 	\multicolumn{1}{c}{} & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation} & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# 	Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# 	\midrule
# 	$t_{\mathrm{SW}}$ & $0.02827_{-0.0083}^{+0.006}$ & $0.03864_{-0.0063}^{+0.0056}$ & $1766$ & $0.01845_{-0.0061}^{+0.0052}$ & $0.0255_{-0.0053}^{+0.0047}$ & ${\mathbf{1259}}$ \\
# 	$t_{\overline{\mathrm{KS}}}$ & $1.00317_{-0.0013}^{+0}$ & $1.00354_{-0.00043}^{+0.00012}$ & ${\mathbf{1651}}$ & ${\mathbf{0.00345_{-0.0011}^{+0.00099}}}$ & ${\mathbf{0.00444_{-0.00097}^{+0.00096}}}$ & $1612$ \\
# 	$t_{\mathrm{SKS}}$ & $0.02595_{-0.0081}^{+0.0071}$ & $0.0347_{-0.0073}^{+0.0062}$ & $1941$ & $0.0106_{-0.0027}^{+0.0024}$ & $0.01405_{-0.0023}^{+0.0021}$ & $1807$ \\
# 	$t_{\mathrm{FGD}}$ & ${\mathbf{0.01229_{-0.0034}^{+0.0032}}}$ & ${\mathbf{0.01728_{-0.0028}^{+0.0027}}}$ & $2040$ & $0.01964_{-0.006}^{+0.0054}$ & $0.02668_{-0.0048}^{+0.0046}$ & $1294$ \\
# 	$t_{\mathrm{MMD}}$ & $0.02322_{-0.008}^{+0.0085}$ & $0.03162_{-0.0076}^{+0.0081}$ & $2024$ & $0.00788_{-0.0027}^{+0.0032}$ & $0.01064_{-0.0024}^{+0.003}$ & $1518$ \\
# 	$t_{\mathrm{LLR}}$ & $0.04301_{-0.02}^{+0.016}$ & $0.0542_{-0.015}^{+0.015}$ & $4164$ & $0.00041_{-0.00025}^{+0.00025}$ & $0.00057_{-0.00025}^{+0.00025}$ & $3017$ \\
# 	\toprule
# 	\multicolumn{1}{c}{} & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation} & \multicolumn{3}{c}{$\mathcal{N}$-deformation} \\
# 	Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# 	\midrule
# 	$t_{\mathrm{SW}}$ & $0.01989_{-0.0064}^{+0.0056}$ & $0.0273_{-0.0055}^{+0.0052}$ & ${\mathbf{1221}}$ & $0.25306_{-0.043}^{+0.031}$ & $0.29897_{-0.029}^{+0.026}$ & ${\mathbf{1050}}$ \\
# 	$t_{\overline{\mathrm{KS}}}$ & ${\mathbf{0.00317_{-0.00089}^{+0.0009}}}$ & ${\mathbf{0.00416_{-0.00083}^{+0.0009}}}$ & $1634$ & ${\mathbf{0.00921_{-0.0017}^{+0.0016}}}$ & ${\mathbf{0.01112_{-0.0016}^{+0.0016}}}$ & $1496$ \\
# 	$t_{\mathrm{SKS}}$ & $0.01066_{-0.0027}^{+0.0023}$ & $0.01407_{-0.0022}^{+0.0021}$ & $1804$ & $0.18137_{-0.036}^{+0.025}$ & $0.21312_{-0.025}^{+0.023}$ & $1551$ \\
# 	$t_{\mathrm{FGD}}$ & $0.02088_{-0.0061}^{+0.0059}$ & $0.02847_{-0.005}^{+0.005}$ & $1300$ & $0.29378_{-0.045}^{+0.029}$ & $0.34516_{-0.026}^{+0.022}$ & $1080$ \\
# 	$t_{\mathrm{MMD}}$ & $0.00858_{-0.0032}^{+0.0037}$ & $0.01169_{-0.003}^{+0.0034}$ & $1550$ & $0.37502_{-0.064}^{+0.046}$ & $0.43162_{-0.039}^{+0.041}$ & $1240$ \\
# 	$t_{\mathrm{LLR}}$ & $0.00036_{-0.00025}^{+0.00025}$ & $0.00053_{-0.00025}^{+0.00025}$ & $3139$ & - & - & - \\
# 	\toprule
# 	\multicolumn{1}{c}{} & \multicolumn{3}{c}{$\mathcal{U}$-deformation} & \multicolumn{3}{c}{Timing} \\
# 	Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# 	\midrule
# 	$t_{\mathrm{SW}}$ & $0.4365_{-0.078}^{+0.054}$ & $0.51675_{-0.053}^{+0.039}$ & ${\mathbf{988}}$ & $261$ \\
# 	$t_{\overline{\mathrm{KS}}}$ & ${\mathbf{0.01504_{-0.0027}^{+0.0026}}}$ & ${\mathbf{0.01804_{-0.0026}^{+0.0022}}}$ & $1510$ & ${\mathbf{37}}$ \\
# 	$t_{\mathrm{SKS}}$ & $0.30846_{-0.057}^{+0.044}$ & $0.36537_{-0.045}^{+0.036}$ & $1513$ & $352$ \\
# 	$t_{\mathrm{FGD}}$ & $0.50798_{-0.076}^{+0.053}$ & $0.59684_{-0.049}^{+0.038}$ & $1030$ & $368$ \\
# 	$t_{\mathrm{MMD}}$ & $0.64544_{-0.099}^{+0.087}$ & $0.7501_{-0.067}^{+0.064}$ & $1231$ & $215$ \\
# 	$t_{\mathrm{LLR}}$ & - & - & - & - \\
# 	\bottomrule
# \end{tabular}

# %%
shared.save_latex(tex_string, model_dir)
# Out:
# LaTeX table code has been written to results/5D_mixture/5D_10K/results_table.tex
