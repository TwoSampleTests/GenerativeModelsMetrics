# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/100D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-30 15:20:56.406193: Importing os...
# 2024-04-30 15:20:56.406380: Importing sys...
# Visible devices: [1]
# 2024-04-30 15:20:56.406616: Importing timer from timeit...
# 2024-04-30 15:20:56.406683: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-04-30 15:20:56.406811: Importing numpy...
# 2024-04-30 15:20:56.519596: Importing matplotlib...
# 2024-04-30 15:20:56.862444: Importing h5py...
# 2024-04-30 15:20:56.889055: Importing importlib.util...
# 2024-04-30 15:20:56.889153: Importing json...
# 2024-04-30 15:20:56.889215: Importing pandas...
# 2024-04-30 15:20:57.322449: Importing random...
# 2024-04-30 15:20:57.322575: Importing scipy utils...
# 2024-04-30 15:20:57.765300: Importing subprocess...
# 2024-04-30 15:20:57.765434: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-30 15:21:01.240948: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-30 15:21:02.373691: Importing timeit...
# 2024-04-30 15:21:02.373781: Importing tqdm...
# 2024-04-30 15:21:02.381241: Importing typing...
# 2024-04-30 15:21:02.381345: Setting tf configs...
# 2024-04-30 15:21:02.512087: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-30 15:21:07.204459: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-04-30 15:21:07.234449: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 10
ndims = 100
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (100,) (100,)
# sample from dist_1:  tf.Tensor(
# [[  1.91544564  -2.76561943  -3.43238751   7.63969004   0.40053677
#    -1.53371952   5.40518506  -2.46227562  -6.61238919   0.11070361
#    -2.43762175   7.60029826   5.00623137  -0.80830675  -0.86605178
#    -3.75058169  -0.69380601  -5.33493967   5.27270148  -5.77781631
#     1.12998499  -4.47808311  -0.44031361  -2.594015    -2.44992317
#     1.56227034  -1.8473778   -5.48289763  -5.48753345   1.93092494
#     1.79804844   1.37683738  -5.50962657  -4.87417033  -0.72193383
#    -5.10550792   4.48638515 -10.64465497  -2.19470468   6.38369957
#    -1.69169541   1.54297027   5.89350422   2.06708108  -0.90056118
#    -4.52907036  -5.69635496   1.55048682   6.4208089   -7.28610231
#    -5.08435585  -3.3389148    5.70948589   8.2946287   -5.84409661
#    -3.41249172   0.17450962   2.34921217   2.76600152  -1.35626994
#     4.67985208   3.74505089  -1.53903479  -0.9632767    7.66386021
#    -6.44508355   7.20013913   6.46012388   7.95496576  -1.07239111
#     2.63046089  -1.89127358   0.33629951   0.08755734  -4.28856395
#     1.78142513  -1.78334129   3.21504492  -1.34998805  -3.46388964
#    -4.46767048  -3.0690922    4.10920542  -1.12462778   0.43631843
#    -3.45204044   8.14946355  -3.75325945  -3.65654744  -9.30852399
#    -0.23871862   0.24312011  -6.63856444  -1.3104451   -2.44773711
#    -6.17225405  -2.40174311  -4.69520006   3.0814107    0.60472495]
#  [ -1.92269202  -4.08394393   0.28484768  -0.46825721   1.55903162
#     8.68423884   0.1292585   -3.09593241  -3.92592339  -0.78352017
#    -4.50758392   1.57655743  -2.79706173  -6.67679694  -3.89510347
#    -0.67142402  -2.3331029   -4.65618365   6.25135925   2.17635361
#     0.02229862  -5.25625134  -2.13850902  -4.05479007  -3.57251666
#     2.04591286  -0.14158755  -1.07676659   1.27568216   0.48903681
#    -1.65055387   3.28812542  -5.22640853  -0.92624111  -2.08771499
#    -3.93104846   2.93525398  -4.66540103  -1.34764653  -0.10523317
#    -1.50393875   4.51796248   4.56419684   0.78592104   1.87166036
#    -4.43561494  -5.41652595  -2.73506816   1.76755216  -5.15925416
#    -4.3965557   -5.11767262  -0.32448409   3.31767934  -3.42011481
#     0.12151845   1.33857006  -1.59406799  -1.52287611   5.92251815
#     0.35865444   2.59290903  -6.12798207  -6.88506817   6.79410239
#    -4.32117031   6.36315359   0.14532651   3.96861049  -2.69664263
#     4.07705442  -6.06308564   3.31986369   1.93834979  -1.93673443
#    -3.60680136   3.69535118   3.06222825  -0.16709543  -2.17638917
#     2.96497292  -0.41208625   7.46657337  -1.19022553  -4.69285676
#    -3.57289518   3.99034323  -0.81382891  -0.80077353  -2.56404593
#    -0.40735411   4.1613677   -2.13420216   3.955205     0.10965705
#    -0.3132572   -1.46848024  -6.0741503    2.39560734  -1.95077145]], shape=(2, 100), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[  1.91544564  -2.76561943  -3.43238751   7.63969004   0.40053677
#    -1.53371952   5.40518506  -2.46227562  -6.61238919   0.11070361
#    -2.43762175   7.60029826   5.00623137  -0.80830675  -0.86605178
#    -3.75058169  -0.69380601  -5.33493967   5.27270148  -5.77781631
#     1.12998499  -4.47808311  -0.44031361  -2.594015    -2.44992317
#     1.56227034  -1.8473778   -5.48289763  -5.48753345   1.93092494
#     1.79804844   1.37683738  -5.50962657  -4.87417033  -0.72193383
#    -5.10550792   4.48638515 -10.64465497  -2.19470468   6.38369957
#    -1.69169541   1.54297027   5.89350422   2.06708108  -0.90056118
#    -4.52907036  -5.69635496   1.55048682   6.4208089   -7.28610231
#    -5.08435585  -3.3389148    5.70948589   8.2946287   -5.84409661
#    -3.41249172   0.17450962   2.34921217   2.76600152  -1.35626994
#     4.67985208   3.74505089  -1.53903479  -0.9632767    7.66386021
#    -6.44508355   7.20013913   6.46012388   7.95496576  -1.07239111
#     2.63046089  -1.89127358   0.33629951   0.08755734  -4.28856395
#     1.78142513  -1.78334129   3.21504492  -1.34998805  -3.46388964
#    -4.46767048  -3.0690922    4.10920542  -1.12462778   0.43631843
#    -3.45204044   8.14946355  -3.75325945  -3.65654744  -9.30852399
#    -0.23871862   0.24312011  -6.63856444  -1.3104451   -2.44773711
#    -6.17225405  -2.40174311  -4.69520006   3.0814107    0.60472495]
#  [ -1.92269202  -4.08394393   0.28484768  -0.46825721   1.55903162
#     8.68423884   0.1292585   -3.09593241  -3.92592339  -0.78352017
#    -4.50758392   1.57655743  -2.79706173  -6.67679694  -3.89510347
#    -0.67142402  -2.3331029   -4.65618365   6.25135925   2.17635361
#     0.02229862  -5.25625134  -2.13850902  -4.05479007  -3.57251666
#     2.04591286  -0.14158755  -1.07676659   1.27568216   0.48903681
#    -1.65055387   3.28812542  -5.22640853  -0.92624111  -2.08771499
#    -3.93104846   2.93525398  -4.66540103  -1.34764653  -0.10523317
#    -1.50393875   4.51796248   4.56419684   0.78592104   1.87166036
#    -4.43561494  -5.41652595  -2.73506816   1.76755216  -5.15925416
#    -4.3965557   -5.11767262  -0.32448409   3.31767934  -3.42011481
#     0.12151845   1.33857006  -1.59406799  -1.52287611   5.92251815
#     0.35865444   2.59290903  -6.12798207  -6.88506817   6.79410239
#    -4.32117031   6.36315359   0.14532651   3.96861049  -2.69664263
#     4.07705442  -6.06308564   3.31986369   1.93834979  -1.93673443
#    -3.60680136   3.69535118   3.06222825  -0.16709543  -2.17638917
#     2.96497292  -0.41208625   7.46657337  -1.19022553  -4.69285676
#    -3.57289518   3.99034323  -0.81382891  -0.80077353  -2.56404593
#    -0.40735411   4.1613677   -2.13420216   3.955205     0.10965705
#    -0.3132572   -1.46848024  -6.0741503    2.39560734  -1.95077145]], shape=(2, 100), dtype=float64)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...      100           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True      100           0  float64   100  200000000         False
#
#    ncomp
# 0     10
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 2,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 10000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 100,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 100,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 100,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 10},
#   'max_vectorize': 100,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/100D_unimodal/100D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fgd from results/100D_unimodal/100D_20K/null_hypothesis/FGD.json
# Loading mmd from results/100D_unimodal/100D_20K/null_hypothesis/MMD.json
# Loading ks from results/100D_unimodal/100D_20K/null_hypothesis/KS.json
# Loading sks from results/100D_unimodal/100D_20K/null_hypothesis/SKS.json
# Loading swd from results/100D_unimodal/100D_20K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.023913020960868364], [0.95, [9500, 500], 0.10900758878220636], [0.99, [9900, 100], 0.16550496970572942]]
# Computing time for metric fgd: 8718.71113805892
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.8239903680732823], [0.95, [9500, 500], 5.0631036241175025], [0.99, [9900, 100], 8.34905088339292]]
# Computing time for metric mmd: 2387.563377124956
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.8958505541086197], [0.95, [9500, 500], 0.9957506358623504], [0.99, [9900, 100], 1.05635055154562]]
# Computing time for metric ks: 527.3212742729811
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.8951503783464432], [0.95, [9500, 500], 0.9985505603253841], [0.99, [9900, 100], 1.0643506422638893]]
# Computing time for metric sks: 455.26243996201083
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.3830072195264897], [0.95, [9500, 500], 0.44684544568681733], [0.99, [9900, 100], 0.48971344995573707]]
# Computing time for metric swd: 290.9170654009795
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f417e76f6a0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f417e76d4e0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f417e76f7e0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f417e76f880>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f417e76f920>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f417e76f9c0>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 1  $d_{\mathrm{MMD}}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 2      $\overline{D}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 3     $\widetilde{D}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 4     $\widetilde{W}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 5           $t_{\mu}$  results/100D_unimodal/100D_20K/null_hypothesis...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.023913020960868364], [...
# 1  [[0.68, [6800, 3199], 0.8239903680732823], [0....
# 2  [[0.68, [6800, 3199], 0.8958505541086197], [0....
# 3  [[0.68, [6800, 3199], 0.8951503783464432], [0....
# 4  [[0.68, [6800, 3199], 0.3830072195264897], [0....
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{4})$"
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{3})$"
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.024115940461300542 +/- 1.5516580315691533e-05
# sigma = 0.03939109076389169 +/- 0.0005206789015528851
# 68%CL = 0.023913020960868364, 95%CL = 0.10900758878220636, 99%CL = 0.16550496970572942
# mu = 0.024115940461300542 +/- 1.5516580315691533e-05
# sigma = 0.03939109076389169 +/- 0.0005206789015528851
# /tmp/ipykernel_896902/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_896902/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_896902/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 2.648682255996391 seconds.
# mu = -0.037526905458895636 +/- 0.0759141289141168
# sigma = 2.7552518744048937 +/- 0.02763561529633575
# 68%CL = 0.8239903680732823, 95%CL = 5.0631036241175025, 99%CL = 8.34905088339292
# mu = -0.037526905458895636 +/- 0.0759141289141168
# sigma = 2.7552518744048937 +/- 0.02763561529633575
# /tmp/ipykernel_896902/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_896902/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_896902/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_896902/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.0112599290441722 seconds.
# mu = 0.8659962367941625 +/- 5.265407282107566e-05
# sigma = 0.07256312618753114 +/- 0.0005390671604663675
# 68%CL = 0.8958505541086197, 95%CL = 0.9957506358623504, 99%CL = 1.05635055154562
# mu = 0.8659962367941625 +/- 5.265407282107566e-05
# sigma = 0.07256312618753114 +/- 0.0005390671604663675
# /tmp/ipykernel_896902/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_896902/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_896902/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_896902/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3373753789346665 seconds.
# mu = 0.8655796067370102 +/- 5.4403857149576096e-05
# sigma = 0.07375897040331847 +/- 0.0005543541078516184
# 68%CL = 0.8951503783464432, 95%CL = 0.9985505603253841, 99%CL = 1.0643506422638893
# mu = 0.8655796067370102 +/- 5.4403857149576096e-05
# sigma = 0.07375897040331847 +/- 0.0005543541078516184
# /tmp/ipykernel_896902/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_896902/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_896902/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_896902/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.541306903003715 seconds.
# mu = 0.367320682381955 +/- 1.8368422000667308e-05
# sigma = 0.04285839707766415 +/- 0.0003470241731386383
# 68%CL = 0.3830072195264897, 95%CL = 0.44684544568681733, 99%CL = 0.48971344995573707
# mu = 0.367320682381955 +/- 1.8368422000667308e-05
# sigma = 0.04285839707766415 +/- 0.0003470241731386383
# /tmp/ipykernel_896902/3479431200.py:87: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_896902/3479431200.py:89: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_896902/3479431200.py:126: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_896902/3479431200.py:132: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2669690690236166 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f48282e36a0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f48282e23e0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f48282e37e0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f48282e3880>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f48282e3920>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7f48282e39c0>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              2
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            100
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 1  $d_{\mathrm{MMD}}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 2      $\overline{D}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 3     $\widetilde{D}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 4     $\widetilde{W}$  results/100D_unimodal/100D_20K/null_hypothesis...
# 5           $t_{\mu}$  results/100D_unimodal/100D_20K/null_hypothesis...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.023913020960868364], [...
# 1  [[0.68, [6800, 3199], 0.8239903680732823], [0....
# 2  [[0.68, [6800, 3199], 0.8958505541086197], [0....
# 3  [[0.68, [6800, 3199], 0.8951503783464432], [0....
# 4  [[0.68, [6800, 3199], 0.3830072195264897], [0....
# 5                                                 []
#
#                                          null_figure
# 0  results/100D_unimodal/100D_20K/null_hypothesis...
# 1  results/100D_unimodal/100D_20K/null_hypothesis...
# 2  results/100D_unimodal/100D_20K/null_hypothesis...
# 3  results/100D_unimodal/100D_20K/null_hypothesis...
# 4  results/100D_unimodal/100D_20K/null_hypothesis...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = mean
# statistic = 163.73705888532857 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9973387804509926
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 204 calls to <function generate_and_clean_data_simple_1 at 0x7f49396d0e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 40.8346451733295 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.98935047740703
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = mean
# WARNING:tensorflow:6 out of the last 205 calls to <function generate_and_clean_data_simple_1 at 0x7f49396d0e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 10.167797627407657 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.957571409990148
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = mean
# statistic = 2.5304289251893963 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8348017264970231
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = mean
# WARNING:tensorflow:5 out of the last 5 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f36801d7f60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.6340146749184788 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4131665006144776
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = mean
# WARNING:tensorflow:6 out of the last 6 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f3670701ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.15862774746689948 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.37080423968013226
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = mean
# statistic = 0.05330847129505534 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.6863044539232717
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.05859375 - deformation = mean
# statistic = 0.0988891947723766 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.097340553680795
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.068359375 - deformation = mean
# statistic = 0.1295275260553171 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.17204961447364045
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0634765625 - deformation = mean
# statistic = 0.11297466388675681 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.03574227269840762
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.06103515625 - deformation = mean
# statistic = 0.10938686118142786 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.0034732787329042223
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.059814453125 - deformation = mean
# statistic = 0.09980630722477404 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.08812901567743102
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0604248046875 - deformation = mean
# statistic = 0.10360551644411116 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.010050251256281407
# relative_error_metric = 0.05081598645901836
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.06072998046875 - deformation = mean
# statistic = 0.10338846358244673 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.005012531328320802
# relative_error_metric = 0.05291176683559456
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.060882568359375 - deformation = mean
# statistic = 0.10452815881572844 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.0025031289111389237
# relative_error_metric = 0.041954848467922204
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0609588623046875 - deformation = mean
# statistic = 0.10235589646872098 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.0012507817385866166
# relative_error_metric = 0.062940789470694
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.06099700927734375 - deformation = mean
# statistic = 0.10413768732268032 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.0006251953735542357
# relative_error_metric = 0.04569560769556636
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.061016082763671875 - deformation = mean
# statistic = 0.10648797363243198 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.0003125488357555868
# relative_error_metric = 0.023384380834036347
#
# ------------ 19 - 0.95 CL ------------
# eps = 0.06102561950683594 - deformation = mean
# statistic = 0.10532554528847464 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.00015626220798499883
# relative_error_metric = 0.03435813608284648
#
# ------------ 20 - 0.95 CL ------------
# eps = 0.06103038787841797 - deformation = mean
# statistic = 0.10664695149904088 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 7.812805187702645e-05
# relative_error_metric = 0.021892766830569257
#
# ------------ 21 - 0.95 CL ------------
# eps = 0.061032772064208984 - deformation = mean
# statistic = 0.1074171824407681 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 3.9063262954354575e-05
# relative_error_metric = 0.01469708233906107
# =======> statistic within required accuracy at 0.95 CL in 370.2906330169644 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.06103396415710449 - deformation = mean
# statistic = 0.1056717760677107 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9517616640478173
# relative_error_metric = 0.44128557902238075
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5305169820785522 - deformation = mean
# statistic = 167.69560624823993 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.90579546314417
# relative_error_metric = 1.9960561450235883
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2957754731178284 - deformation = mean
# statistic = 43.90927514231548 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.8200662156958831
# relative_error_metric = 1.9849796215173323
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6784047186374664 - deformation = mean
# statistic = 12.006318273208626 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.6698362388808874
# relative_error_metric = 1.945610459040448
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.36971934139728546 - deformation = mean
# statistic = 3.5501495609993663 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.4332350942398244
# relative_error_metric = 1.8218295394923891
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.21537665277719498 - deformation = mean
# statistic = 1.2060496380849532 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.116763822836635
# relative_error_metric = 1.517321530573757
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.13820530846714973 - deformation = mean
# statistic = 0.502353046516237 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.7746599683244462
# relative_error_metric = 1.008741584674052
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.09961963631212711 - deformation = mean
# statistic = 0.2635629182482835 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.4803586355030064
# relative_error_metric = 0.45707428262757255
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.0803268002346158 - deformation = mean
# statistic = 0.17781038233054677 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.27295885333570424
# relative_error_metric = 0.07168576966821519
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.07068038219586015 - deformation = mean
# statistic = 0.14068456201493218 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.1277610492891209
# relative_error_metric = 0.16212446945077819
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.07550359121523798 - deformation = mean
# statistic = 0.16016282713057198 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.06190331647764533
# relative_error_metric = 0.03280731240272245
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.07791519572492689 - deformation = mean
# statistic = 0.1666230862618137 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.03143819029972474
# relative_error_metric = 0.00673304489635503
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.07670939347008243 - deformation = mean
# statistic = 0.15915913425717831 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.015596513609148209
# relative_error_metric = 0.039091697364092376
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.07731229459750466 - deformation = mean
# statistic = 0.16222178318126979 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.007767968497975577
# relative_error_metric = 0.02003612152830065
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.07761374516121577 - deformation = mean
# statistic = 0.16571049419972878 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.0038915415921118098
# relative_error_metric = 0.0012410319951608214
# =======> statistic within required accuracy at 0.99 CL in 274.9602746020537 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 645.2509435440879 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_diag
# statistic = 1632.4258397408007 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997329120687122
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_diag
# statistic = 408.32726772217995 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9989324396938128
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_diag
# statistic = 102.23510371980743 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9957395657693084
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_diag
# statistic = 25.59973355332667 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9830396069290752
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_diag
# statistic = 6.426614490881571 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9332840317548998
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_diag
# statistic = 1.6258926784011938 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.748671227172777
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_diag
# statistic = 0.42448534963172263 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1826876726332296
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_diag
# statistic = 0.12192333513610472 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.11185809275562544
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_diag
# statistic = 0.04755263867603075 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7850646502486577
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0146484375 - deformation = cov_diag
# statistic = 0.0802877350837686 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.3034396530446997
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.01708984375 - deformation = cov_diag
# statistic = 0.0971003793505502 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.11554341677840019
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.018310546875 - deformation = cov_diag
# statistic = 0.11302818327181152 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.03621573634204326
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0177001953125 - deformation = cov_diag
# statistic = 0.10531336493244178 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.03447375336602084
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.01800537109375 - deformation = cov_diag
# statistic = 0.1057070442166655 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.01680672268907563
# relative_error_metric = 0.030743545695445865
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.018157958984375 - deformation = cov_diag
# statistic = 0.10797878647731281 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.008368200836820083
# relative_error_metric = 0.00948264427813116
# =======> statistic within required accuracy at 0.95 CL in 271.65702326595783 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0182342529296875 - deformation = cov_diag
# statistic = 0.10881865512931632 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9854656024325352
# relative_error_metric = 0.41328058865144623
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5091171264648438 - deformation = cov_diag
# statistic = 1644.4550496382792 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.971140929467345
# relative_error_metric = 1.9995974634532152
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2636756896972656 - deformation = cov_diag
# statistic = 417.26966224900406 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9431028582481513
# relative_error_metric = 1.9984140773686272
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6409549713134766 - deformation = cov_diag
# statistic = 107.48807291316648 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.8893534526410207
# relative_error_metric = 1.9938504609708074
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.32959461212158203 - deformation = cov_diag
# statistic = 28.473213620826414 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.7903077661251627
# relative_error_metric = 1.976883746501082
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.17391443252563477 - deformation = cov_diag
# statistic = 7.970026326871401 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.6204136835705334
# relative_error_metric = 1.9186261038536658
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.09607434272766113 - deformation = cov_diag
# statistic = 2.449681741559897 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.3619288969537695
# relative_error_metric = 1.7468555969747448
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.057154297828674316 - deformation = cov_diag
# statistic = 0.8819196180808053 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.032518718226453
# relative_error_metric = 1.3679546131125984
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.03769427537918091 - deformation = cov_diag
# statistic = 0.3950105455595779 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.6958889510564037
# relative_error_metric = 0.8189089136817816
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.027964264154434204 - deformation = cov_diag
# statistic = 0.23192542260762092 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.42122612754126176
# relative_error_metric = 0.33424948965414253
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.023099258542060852 - deformation = cov_diag
# statistic = 0.1615639410734387 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.1905471990755264
# relative_error_metric = 0.02409907210625503
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.025531761348247528 - deformation = cov_diag
# statistic = 0.19482129197670414 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.10003914422002269
# relative_error_metric = 0.1627209858870186
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.02431550994515419 - deformation = cov_diag
# statistic = 0.17678334660982442 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.051302640164584544
# relative_error_metric = 0.06589986491795718
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.02370738424360752 - deformation = cov_diag
# statistic = 0.1714597793991201 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.025984589594743153
# relative_error_metric = 0.03534381391056304
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.023403321392834187 - deformation = cov_diag
# statistic = 0.17102289908936344 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.013077246518323557
# relative_error_metric = 0.03279329823940262
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.02325128996744752 - deformation = cov_diag
# statistic = 0.16854082615765253 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.006560070172868805
# relative_error_metric = 0.018176288937129553
# =======> statistic within required accuracy at 0.99 CL in 289.1612991230795 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 560.8183655659668 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_off_diag
# statistic = 681.0809736182525 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9993598990484913
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_off_diag
# statistic = 924.4267157692902 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995283791160117
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_off_diag
# statistic = 1064.7495430864926 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9995905274415537
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_off_diag
# statistic = 1915.8187367664054 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997724181632563
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_off_diag
# statistic = 1347.23152329003 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9996763770218922
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_off_diag
# statistic = 682.756434363329 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9993614695834037
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_off_diag
# statistic = 288.8901319244317 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9984912399536436
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_off_diag
# statistic = 106.9548437306368 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9959273802524817
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_off_diag
# statistic = 35.467045148542105 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9877437118066963
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = cov_off_diag
# statistic = 10.744426444964269 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9598255857295412
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = cov_off_diag
# statistic = 3.061221360607051 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.862460925665061
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.001220703125 - deformation = cov_off_diag
# statistic = 0.8415976655136905 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.541312912843314
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0006103515625 - deformation = cov_off_diag
# statistic = 0.23164059316461386 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.719997997238994
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00030517578125 - deformation = cov_off_diag
# statistic = 0.07824588411696536 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.32855683997706053
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.000457763671875 - deformation = cov_off_diag
# statistic = 0.14361724677263346 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.274000439540427
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0003814697265625 - deformation = cov_off_diag
# statistic = 0.10804036334056052 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.008912550726106368
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00041961669921875 - deformation = cov_off_diag
# statistic = 0.12389918482574466 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.1278760236368663
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.000400543212890625 - deformation = cov_off_diag
# statistic = 0.11153669405638282 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.04878048780487805
# relative_error_metric = 0.022935124335346762
#
# ------------ 19 - 0.95 CL ------------
# eps = 0.0003910064697265625 - deformation = cov_off_diag
# statistic = 0.11540126443287373 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.024691358024691357
# relative_error_metric = 0.05698238335133312
#
# ------------ 20 - 0.95 CL ------------
# eps = 0.00038623809814453125 - deformation = cov_off_diag
# statistic = 0.11140655982910745 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.012422360248447204
# relative_error_metric = 0.021767849859144255
#
# ------------ 21 - 0.95 CL ------------
# eps = 0.0003838539123535156 - deformation = cov_off_diag
# statistic = 0.10677471092850181 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.006191950464396285
# relative_error_metric = 0.02069565350539027
#
# ------------ 22 - 0.95 CL ------------
# eps = 0.00038504600524902344 - deformation = cov_off_diag
# statistic = 0.10844933888246674 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.0030911901081916537
# relative_error_metric = 0.005134349185696724
# =======> statistic within required accuracy at 0.95 CL in 389.3195360531099 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00038564205169677734 - deformation = cov_off_diag
# statistic = 0.10475397117720493 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.999691510151974
# relative_error_metric = 0.44957623477729425
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5001928210258484 - deformation = cov_off_diag
# statistic = 681.000923900581 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9993831154552582
# relative_error_metric = 1.9990281084757497
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2502892315387726 - deformation = cov_off_diag
# statistic = 924.2263963023757 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9987666113397171
# relative_error_metric = 1.9992838320219901
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6253374367952347 - deformation = cov_off_diag
# statistic = 1063.6217398990282 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9975347429894552
# relative_error_metric = 1.9993776764272964
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31286153942346573 - deformation = cov_off_diag
# statistic = 1916.2937087896084 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9950755559889708
# relative_error_metric = 1.9996545609350462
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.15662359073758125 - deformation = cov_off_diag
# statistic = 1349.8679165075675 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9901753025641657
# relative_error_metric = 1.999509627044567
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.07850461639463902 - deformation = cov_off_diag
# statistic = 686.6864696252566 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.980446657963018
# relative_error_metric = 1.9990361534896757
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.039445129223167896 - deformation = cov_off_diag
# statistic = 292.5454765227939 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.961271947355924
# relative_error_metric = 1.997738315537574
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.019915385637432337 - deformation = cov_off_diag
# statistic = 110.10011792494527 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9240152651181728
# relative_error_metric = 1.9939961353190245
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.010150513844564557 - deformation = cov_off_diag
# statistic = 37.78942043347964 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.8535928832132718
# relative_error_metric = 1.9825577346868568
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.005268077948130667 - deformation = cov_off_diag
# statistic = 12.286709065793769 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.7271587190674123
# relative_error_metric = 1.946835167068636
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0028268599999137223 - deformation = cov_off_diag
# statistic = 3.998717480531434 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.519823432948849
# relative_error_metric = 1.8410219706718083
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0016062510258052498 - deformation = cov_off_diag
# statistic = 1.3991299317510508 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.2255768021837812
# relative_error_metric = 1.576885394665214
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.0009959465387510136 - deformation = cov_off_diag
# statistic = 0.5687403703952298 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.8834822338195897
# relative_error_metric = 1.098366931778022
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0006907942952238955 - deformation = cov_off_diag
# statistic = 0.2895917357377062 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.5669675580912098
# relative_error_metric = 0.5453204321093449
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.0005382181734603364 - deformation = cov_off_diag
# statistic = 0.18925093253206765 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.3303013109750701
# relative_error_metric = 0.13387212264291534
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.0004619301125785569 - deformation = cov_off_diag
# statistic = 0.14503885954854392 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.15255350020929373
# relative_error_metric = 0.1318081908523633
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.0005000741430194466 - deformation = cov_off_diag
# statistic = 0.16280673022128198 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.07347455015407019
# relative_error_metric = 0.016437059568984624
#
# ------------ 19 - 0.99 CL ------------
# eps = 0.0005191461582398915 - deformation = cov_off_diag
# statistic = 0.17644964186812329 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.03742471612247067
# relative_error_metric = 0.06401242616393328
#
# ------------ 20 - 0.99 CL ------------
# eps = 0.0005096101506296691 - deformation = cov_off_diag
# statistic = 0.1731835259944594 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.018889087747930015
# relative_error_metric = 0.04534288224260879
#
# ------------ 21 - 0.99 CL ------------
# eps = 0.0005048421468245579 - deformation = cov_off_diag
# statistic = 0.1671572742116223 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.009489355189677279
# relative_error_metric = 0.009933826492815838
# =======> statistic within required accuracy at 0.99 CL in 369.3679586889921 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 758.6875305550639 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_up
# statistic = 43121455.33938203 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.99999998988832
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_up
# statistic = 148595.26489723875 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999997065653232
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_up
# statistic = 6805.166120889958 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999359275933892
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_up
# statistic = 819.829247071388 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9994682156215413
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_up
# statistic = 146.2807986293585 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9970214431838298
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_up
# statistic = 31.0886996485985 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.986023641038391
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_up
# statistic = 7.177696419737896 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.940160825166085
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_up
# statistic = 1.7289723469099971 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7627665315265741
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.43399747278378253 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1970049894722083
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.12022237712097936 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.09784748948145389
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_up
# statistic = 0.05013707637401671 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7398364544661286
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_up
# statistic = 0.08115096523893615 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.29298312333793836
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0042724609375 - deformation = power_abs_up
# statistic = 0.09795617363485364 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.10679565367663374
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00457763671875 - deformation = power_abs_up
# statistic = 0.1072215035116871 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.016520304937428565
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.004730224609375 - deformation = power_abs_up
# statistic = 0.11295283402190721 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.03278688524590164
# relative_error_metric = 0.03554908744413997
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0046539306640625 - deformation = power_abs_up
# statistic = 0.11058726026145349 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.01652892561983471
# relative_error_metric = 0.014387145109519965
# =======> statistic within required accuracy at 0.95 CL in 290.6272029419197 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00461578369140625 - deformation = power_abs_up
# statistic = 0.10929682105852363 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9963107787763066
# relative_error_metric = 0.40908138546612044
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.502307891845703 - deformation = power_abs_up
# statistic = 43584310.313387 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9926351428462739
# relative_error_metric = 1.9999999848105918
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2534618377685547 - deformation = power_abs_up
# statistic = 150945.366628329 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.985324327807215
# relative_error_metric = 1.9999956141803636
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6290388107299805 - deformation = power_abs_up
# statistic = 6962.817751449921 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9708624620918525
# relative_error_metric = 1.9999049229540784
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31682729721069336 - deformation = power_abs_up
# statistic = 851.1069746338128 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.942561729081833
# relative_error_metric = 1.999222317301822
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.1607215404510498 - deformation = power_abs_up
# statistic = 156.1890224905526 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.88833050939111
# relative_error_metric = 1.9957659052822045
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08266866207122803 - deformation = power_abs_up
# statistic = 35.10814951487764 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.788471650311734
# relative_error_metric = 1.9812318885441185
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04364222288131714 - deformation = power_abs_up
# statistic = 9.043119120068855 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.6174078442755069
# relative_error_metric = 1.9281087084922888
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.024129003286361694 - deformation = power_abs_up
# statistic = 2.668831245871207 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.3576875424436115
# relative_error_metric = 1.7664285996895532
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.014372393488883972 - deformation = power_abs_up
# statistic = 0.9375210899752517 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.0276510172451
# relative_error_metric = 1.3998148339175343
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.009494088590145111 - deformation = power_abs_up
# statistic = 0.4143621755194341 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.6914739979776058
# relative_error_metric = 0.8583249037745463
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0070549361407756805 - deformation = power_abs_up
# statistic = 0.23268962616939087 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.4179952024284713
# relative_error_metric = 0.3374463498983876
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.005835359916090965 - deformation = power_abs_up
# statistic = 0.16723998080874808 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.23338617676439583
# relative_error_metric = 0.010428474423645197
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.005225571803748608 - deformation = power_abs_up
# statistic = 0.1327613970857961 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.11025980953279078
# relative_error_metric = 0.21955926826184582
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0055304658599197865 - deformation = power_abs_up
# statistic = 0.1487695040098292 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.05365101703647483
# relative_error_metric = 0.10650222716495296
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.005682912888005376 - deformation = power_abs_up
# statistic = 0.15294073025789606 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.026470466653884667
# relative_error_metric = 0.07890977613620477
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.005759136402048171 - deformation = power_abs_up
# statistic = 0.1621892532715772 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.013148223424513232
# relative_error_metric = 0.020236648690519204
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.005797248159069568 - deformation = power_abs_up
# statistic = 0.16169242238455447 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.006552573038677124
# relative_error_metric = 0.023304264724230733
#
# ------------ 19 - 0.99 CL ------------
# eps = 0.005816304037580267 - deformation = power_abs_up
# statistic = 0.16135758996383442 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.003270928270239807
# relative_error_metric = 0.02537690303892694
#
# ------------ 20 - 0.99 CL ------------
# eps = 0.005825831976835616 - deformation = power_abs_up
# statistic = 0.16446914134543664 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 0.0016341278563692574
# relative_error_metric = 0.0062782401746188385
# =======> statistic within required accuracy at 0.99 CL in 338.5405666909646 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 629.1678108529886 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_down
# statistic = 1.0 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6068283395539
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_down
# statistic = 1021.2253445602666 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999573077754399
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_down
# statistic = 587.9317953532617 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999258503231498
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_down
# statistic = 241.57181289866986 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9981958421266137
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_down
# statistic = 79.46394853998837 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9945203700309537
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_down
# statistic = 22.96718600406426 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9811047539805704
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_down
# statistic = 6.206076359304773 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9309541474486795
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_down
# statistic = 1.635819110980804 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.750101052907977
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.43495172284176287 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1984136573982456
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.1253321323748961 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.13932374342756593
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00244140625 - deformation = power_abs_down
# statistic = 0.047849588927049436 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7797921746178165
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.003662109375 - deformation = power_abs_down
# statistic = 0.0710691361868973 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.4213587580717973
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0042724609375 - deformation = power_abs_down
# statistic = 0.09676859256500871 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.11895444980142053
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00457763671875 - deformation = power_abs_down
# statistic = 0.11403752551507643 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.045102415703811224
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.004425048828125 - deformation = power_abs_down
# statistic = 0.10264085845177065 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.06016326047880046
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0045013427734375 - deformation = power_abs_down
# statistic = 0.10709014679352571 - next threshold = 0.10900758878220636 at 0.95 CL
# relative_error_eps = 0.01680672268907563
# relative_error_metric = 0.017746062757873462
# =======> statistic within required accuracy at 0.95 CL in 267.84855780703947 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00453948974609375 - deformation = power_abs_down
# statistic = 0.1041564760909306 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9963717023271415
# relative_error_metric = 0.45500381734998974
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.502269744873047 - deformation = power_abs_down
# statistic = 1.0 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9927565453590912
# relative_error_metric = 1.4319887979627692
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2534046173095703 - deformation = power_abs_down
# statistic = 1022.5340914249766 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.9855653690155795
# relative_error_metric = 1.9993526741565593
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.628972053527832 - deformation = power_abs_down
# statistic = 591.879933511022 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.971337603588821
# relative_error_metric = 1.998881809003509
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3167557716369629 - deformation = power_abs_down
# statistic = 246.38672806843815 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.943485132939055
# relative_error_metric = 1.9973148899498288
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16064763069152832 - deformation = power_abs_down
# statistic = 83.27945010246161 - next threshold = 0.16550496970572942 at 0.99 CL
# relative_error_eps = 1.8900764240198025
# relative_error_metric = 1.9920663882166345
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08259356021881104 - deformation = power_abs_down
# statistic = 25.458622323401872 - next threshold = 0.16550496970572942 at 0.99 CL
# ...
# statistic = 3.9977891923962323 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.7760401478417145
# relative_error_metric = 1.563486875453675
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04394501447677612 - deformation = power_abs_down
# statistic = 2.2175319004079115 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.5971872388956314
# relative_error_metric = 1.2764402385768887
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.024432986974716187 - deformation = power_abs_down
# statistic = 1.2901212225167962 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.3294312938154536
# relative_error_metric = 0.8994181144354699
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.014676973223686218 - deformation = power_abs_down
# statistic = 0.8325467333526495 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.9956166195887302
# relative_error_metric = 0.5185564652474368
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.009798966348171234 - deformation = power_abs_down
# statistic = 0.62074584311615 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.6627760132612904
# relative_error_metric = 0.23599675193484174
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.007359962910413742 - deformation = power_abs_down
# statistic = 0.526713530167163 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.39720199536800405
# relative_error_metric = 0.07280420715898775
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.006140461191534996 - deformation = power_abs_down
# statistic = 0.48471279542729795 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.18066124584970858
# relative_error_metric = 0.010263792774738786
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.006750212050974369 - deformation = power_abs_down
# statistic = 0.5052118510403382 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.09460341565847895
# relative_error_metric = 0.03115490392913877
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.0064453366212546825 - deformation = power_abs_down
# statistic = 0.49483107270176474 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.04844753336333948
# relative_error_metric = 0.010395919388620608
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.006292898906394839 - deformation = power_abs_down
# statistic = 0.4897369020619933 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.02452075925722191
# relative_error_metric = 4.7888300224493425e-05
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.006216680048964918 - deformation = power_abs_down
# statistic = 0.48721719490277837 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.012185679102695217
# relative_error_metric = 0.005110403826712217
# =======> statistic within required accuracy at 0.99 CL in 120.55690229299944 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 237.99312816094607 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 7.706329068073154 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7807747424355096
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 2.211324482789127 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3275893449851566
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 0.6735621076182237 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4047039155754079
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 0.39564315292961927 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.12155011436661389
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_normal
# statistic = 0.48968758514166366 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.09149093100741376
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.390625 - deformation = random_normal
# statistic = 0.42988425935127017 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.03869193946111435
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.4296875 - deformation = random_normal
# statistic = 0.45638574595240566 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.021124824638250547
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.41015625 - deformation = random_normal
# statistic = 0.44304647096636274 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.008538058722327243
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.419921875 - deformation = random_normal
# statistic = 0.4506063212269451 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.023529411764705882
# relative_error_metric = 0.008381231568713733
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.4150390625 - deformation = random_normal
# statistic = 0.4458113823841705 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.011695906432748537
# relative_error_metric = 0.0023168215827831943
# =======> statistic within required accuracy at 0.95 CL in 74.39642972499132 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.41748046875 - deformation = random_normal
# statistic = 0.44760752278243376 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.6917530419107707
# relative_error_metric = 0.08984313463146008
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.708740234375 - deformation = random_normal
# statistic = 8.844304100116242 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.4658336587270597
# relative_error_metric = 1.7901381919077448
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.5631103515625 - deformation = random_normal
# statistic = 3.347372133141384 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.1568567026194145
# relative_error_metric = 1.4894943682121755
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.99029541015625 - deformation = random_normal
# statistic = 1.4383292481940078 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.8137871233470626
# relative_error_metric = 0.9840194920461195
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.703887939453125 - deformation = random_normal
# statistic = 0.8032852159799497 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.5108177983399101
# relative_error_metric = 0.4850303009358396
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.5606842041015625 - deformation = random_normal
# statistic = 0.5864435835510954 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.29280087356680445
# relative_error_metric = 0.17976955143832024
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.48908233642578125 - deformation = random_normal
# statistic = 0.5077399451823268 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.1579633915421839
# relative_error_metric = 0.03614503758161966
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.4532814025878906 - deformation = random_normal
# statistic = 0.47605792631373184 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.07598113627623616
# relative_error_metric = 0.02827899848254578
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.47118186950683594 - deformation = random_normal
# statistic = 0.4899799967539171 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.0387261829848252
# relative_error_metric = 0.0005441432706838369
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.4622316360473633 - deformation = random_normal
# statistic = 0.482925806879564 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.01917742438097379
# relative_error_metric = 0.013957164546819115
# =======> statistic within required accuracy at 0.99 CL in 74.34502618806437 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 148.74148963892367 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_uniform
# statistic = 2.882686228814344 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4631732154898152
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_uniform
# statistic = 0.8337883350548754 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6042990512774947
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_uniform
# statistic = 0.4149671758284837 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.07397958456974782
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.9375 - deformation = random_uniform
# statistic = 0.5631284490550423 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.23026932472932066
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.78125 - deformation = random_uniform
# statistic = 0.47421582980365984 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.05943227632117617
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.703125 - deformation = random_uniform
# statistic = 0.43872161615005967 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.0183471808897384
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.7421875 - deformation = random_uniform
# statistic = 0.4569789082616442 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.022423521850363254
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.72265625 - deformation = random_uniform
# statistic = 0.4465000899239601 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.02666666666666667
# relative_error_metric = 0.0007731739827212432
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.732421875 - deformation = random_uniform
# statistic = 0.4515497495053749 - next threshold = 0.44684544568681733 at 0.95 CL
# relative_error_eps = 0.013422818791946308
# relative_error_metric = 0.01047268249815426
# =======> statistic within required accuracy at 0.95 CL in 74.70293457899243 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.7275390625 - deformation = random_uniform
# statistic = 0.4498175888325387 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.4919011082693947
# relative_error_metric = 0.08492718063823103
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.86376953125 - deformation = random_uniform
# statistic = 3.6953947083484735 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 1.1896668932698844
# relative_error_metric = 1.5319466724088995
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.795654296875 - deformation = random_uniform
# statistic = 1.562357162442489 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.8466376390904693
# relative_error_metric = 1.045425733409016
#
# ------------ 4 - 0.99 CL ------------
# eps = 1.2615966796875 - deformation = random_uniform
# statistic = 0.8481470480506337 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.5369745320650506
# relative_error_metric = 0.5358310505901337
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.99456787109375 - deformation = random_uniform
# statistic = 0.605272804857071 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.31011873117136274
# relative_error_metric = 0.21106996438250128
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.861053466796875 - deformation = random_uniform
# statistic = 0.5146116460256976 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.1680914417443089
# relative_error_metric = 0.04958194546683085
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.7942962646484375 - deformation = random_uniform
# statistic = 0.47737180674795854 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.08065631193252523
# relative_error_metric = 0.02552338198153273
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.8276748657226562 - deformation = random_uniform
# statistic = 0.49607327249383004 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.041158070509654504
# relative_error_metric = 0.012903039558677649
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.8109855651855469 - deformation = random_uniform
# statistic = 0.48933838522619094 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.020369443506803395
# relative_error_metric = 0.000766179513828155
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.8193302154541016 - deformation = random_uniform
# statistic = 0.49163358364005894 - next threshold = 0.48971344995573707 at 0.99 CL
# relative_error_eps = 0.010236851495457763
# relative_error_metric = 0.003913261300207375
# =======> statistic within required accuracy at 0.99 CL in 76.03924749896396 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 150.7422159659909 seconds.
# Saving results in the file results/100D_unimodal/100D_20K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-04-30T09:29:36.483319', 'fgd_cov_diag_2024-04-30T09:40:21.740219', 'fgd_cov_off_diag_2024-04-30T09:49:42.562932', 'fgd_power_abs_up_2024-04-30T10:02:21.253640', 'fgd_power_abs_down_2024-04-30T10:12:50.426370', 'fgd_random_normal_2024-04-30T10:22:18.396861', 'fgd_random_uniform_2024-04-30T10:29:01.550689', 'mmd_mean_2024-04-30T10:35:18.258834', 'mmd_cov_diag_2024-04-30T10:40:42.554812', 'mmd_cov_off_diag_2024-04-30T10:46:10.478307', 'mmd_power_abs_up_2024-04-30T10:53:51.812046', 'mmd_power_abs_down_2024-04-30T11:00:44.634993', 'mmd_random_normal_2024-04-30T11:07:18.342623', 'mmd_random_uniform_2024-04-30T11:11:08.180405', 'ks_mean_2024-04-30T11:15:00.296970', 'ks_cov_diag_2024-04-30T11:18:23.886462', 'ks_cov_off_diag_2024-04-30T11:21:59.541343', 'ks_power_abs_up_2024-04-30T11:26:41.901424', 'ks_power_abs_down_2024-04-30T11:30:37.567780', 'ks_random_normal_2024-04-30T11:34:30.667430', 'ks_random_uniform_2024-04-30T11:37:04.255855', 'sks_mean_2024-04-30T11:39:16.901278', 'sks_cov_diag_2024-04-30T11:43:03.882325', 'sks_cov_off_diag_2024-04-30T11:47:27.722674', 'sks_power_abs_up_2024-04-30T11:53:33.356629', 'sks_power_abs_down_2024-04-30T11:58:39.202998', 'sks_random_normal_2024-04-30T12:03:44.591786', 'sks_random_uniform_2024-04-30T12:06:59.917404', 'swd_mean_2024-04-30T12:09:54.486611', 'swd_cov_diag_2024-04-30T12:13:05.484721', 'swd_cov_off_diag_2024-04-30T12:16:45.232656', 'swd_power_abs_up_2024-04-30T12:21:40.104177', 'swd_power_abs_down_2024-04-30T12:25:41.005125', 'swd_random_normal_2024-04-30T12:29:39.007363', 'swd_random_uniform_2024-04-30T12:32:07.763545'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normnal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.005 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 50
# Iterating from 0 to 200 out of 10000 .
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[18], line 7
#       5 if result == {}:
#       6     print(f"Computing exclusion limits for lr with {deformation} deformation.")
# ----> 7     result = compute_exclusion_LR_bisection(dist_1,
#       8                                             metric_config = metrics_config[unique_key]["lr"],
#       9                                             test_kwargs = test_kwargs,
#      10                                             model_dir = model_dir,
#      11                                             cl_list = [0.95, 0.99],
#      12                                             deformation = deformation,
#      13                                             seed_dist = 0,
#      14                                             x_tol = 0.01,
#      15                                             fn_tol = 0.01,
#      16                                             eps_min = 0.,
#      17                                             eps_max = 0.01,
#      18                                             max_iterations = 100,
#      19                                             save = True,
#      20                                             verbose = True)
#      21 else:
#      22     print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/utils_func/optimizers_deformations.py:304, in compute_exclusion_LR_bisection(reference_distribution, metric_config, test_kwargs, model_dir, cl_list, deformation, seed_dist, x_tol, fn_tol, eps_min, eps_max, max_iterations, save, verbose)
#     299 TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
#     300                                                    dist_2_input = dist_2,
#     301                                                    **test_kwargs_null)
#     303 LRMetric_null = GMetrics.LRMetric(TwoSampleTestInputs, **metric_kwargs_null)
# --> 304 LRMetric_null.Test_tf(max_vectorize = max_vectorize)
#     306 null_file = null_file_base.replace(".json", "_" + deformation + "_" + str(format(eps, '.6f')) + ".json")
#     307 print("Saving", metric_name, "to", null_file)
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:704, in LRMetric.Test_tf(self, max_vectorize)
#     702 lik_ratio_list: DataTypeTF
#     703 lik_ratio_norm_list: DataTypeTF
# --> 704 logprob_ref_ref_sum_list, logprob_ref_alt_sum_list, logprob_alt_alt_sum_list, lik_ratio_list, lik_ratio_norm_list = compute_test(max_vectorize = max_vectorize) # type: ignore
#     706 end_calculation()
#     708 timestamp: str = datetime.now().isoformat()
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:677, in LRMetric.Test_tf.<locals>.compute_test(max_vectorize)
#     674     res = res.write(i, chunk_result)
#     675     return i+1, res
# --> 677 _, res = tf.while_loop(lambda i, _: i < nchunks, body, [0, res])
#     679 for i in range(nchunks):
#     680     res_i = res.read(i)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/util/deprecation.py:660, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     652           _PRINTED_WARNING[(func, arg_name)] = True
#     653         _log_deprecation(
#     654             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     655             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     658             'in a future version' if date is None else
#     659             ('after %s' % date), instructions)
# --> 660 return func(*args, **kwargs)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py:241, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      35 @tf_export("while_loop", v1=[])
#      36 @deprecation.deprecated_arg_values(
#      37     None,
#    (...)
#      52                   maximum_iterations=None,
#      53                   name=None):
#      54   """Repeat `body` while the condition `cond` is true.
#      55
#      56   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#     245       shape_invariants=shape_invariants,
#     246       parallel_iterations=parallel_iterations,
#     247       back_prop=back_prop,
#     248       swap_memory=swap_memory,
#     249       name=name,
#     250       maximum_iterations=maximum_iterations,
#     251       return_same_structure=True)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py:488, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     485 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                         list(loop_vars))
#     487 while cond(*loop_vars):
# --> 488   loop_vars = body(*loop_vars)
#     489   if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490     packed = True
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:673, in LRMetric.Test_tf.<locals>.compute_test.<locals>.body(i, res)
#     671 end = tf.minimum(start + max_iter_per_chunk, niter)
#     672 conditional_tf_print(tf.logical_and(tf.logical_or(tf.math.logical_not(tf.equal(start,0)),tf.math.logical_not(tf.equal(end,niter))), self.verbose), "Iterating from", start, "to", end, "out of", niter, ".") # type: ignore
# --> 673 chunk_result = batched_test(start, end) # type: ignore
#     674 res = res.write(i, chunk_result)
#     675 return i+1, res
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:587, in LRMetric.Test_tf.<locals>.batched_test(start, end)
#     583 def batched_test(start: tf.Tensor,
#     584                  end: tf.Tensor
#     585                 ) -> DataTypeTF:
#     586     # Define the loop body to vectorize over ndims*chunk_size
# --> 587     dist_1_k: DataTypeTF = set_dist_num_from_symb(dist_1_symb, nsamples = batch_size * (end - start)) # type: ignore
#     588     if null:
#     589         dist_2_k: DataTypeTF = set_dist_num_from_symb(dist_1_symb, nsamples = batch_size * (end - start)) # type: ignore
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/lr_metrics.py:527, in LRMetric.Test_tf.<locals>.set_dist_num_from_symb(dist, nsamples)
#     524 def set_dist_num_from_symb(dist: DistTypeTF,
#     525                            nsamples: int,
#     526                           ) -> tf.Tensor:
# --> 527     dist_num: tf.Tensor = generate_and_clean_data(dist, nsamples, self.Inputs.batch_size_gen, dtype = self.Inputs.dtype, seed_generator = self.Inputs.seed_generator, strategy = self.Inputs.strategy) # type: ignore
#     528     return dist_num
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/utils.py:542, in generate_and_clean_data(dist, n_samples, batch_size, dtype, seed_generator, strategy)
#     535     return generate_and_clean_data_mirror(dist = dist,
#     536                                           n_samples = n_samples,
#     537                                           batch_size = batch_size,
#     538                                           dtype = dtype,
#     539                                           seed_generator = seed_generator,
#     540                                           strategy = strategy)
#     541 else:
# --> 542     return generate_and_clean_data_simple(dist = dist,
#     543                                           n_samples = n_samples,
#     544                                           batch_size = batch_size,
#     545                                           dtype = dtype,
#     546                                           seed_generator = seed_generator)
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics/GMetrics/utils.py:414, in generate_and_clean_data_simple(*args, **kwargs)
#     413 def generate_and_clean_data_simple(*args, **kwargs):
# --> 414     return generate_and_clean_data_simple_1(*args, **kwargs)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Expected a non-negative size, got -1123281152 [Op:__inference_generate_and_clean_data_simple_1_3706694]

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normnal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{} & \multicolumn{3}{c}{$\mu$-deformation} & \multicolumn{3}{c}{$\sigma$-deformation} & \multicolumn{3}{c}{$\Sigma_{ij}-\Sigma_{ii}$-deformation} & \multicolumn{3}{c}{$\Sigma_{ij}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) \\
# \midrule
# $t_{\mathrm{LLR}}$ & 0.01 & 0.014 & 329 & 0.0018 & 0.0027 & 413 & 0.0022 & 0.0034 & 662 & 0.014 & 0.02 & 339 \\
# $d_{\mathrm{MMD}}$ & 0.021 & 0.03 & 298 & 0.15 & 0.2 & 267 & 0.18 & 0.24 & 270 & 0.12 & 0.16 & 271 \\
# $\widetilde{W}$ & 0.03 & 0.04 & 128 & 0.032 & 0.044 & 129 & 0.065 & 0.091 & 163 & 0.044 & 0.06 & 130 \\
# $\widetilde{D}$ & 0.031 & 0.04 & 200 & 0.034 & 0.045 & 203 & 0.063 & 0.086 & 263 & 0.059 & 0.079 & 202 \\
# $d_{\mathrm{FGD}}$ & 0.035 & 0.045 & 218 & 0.026 & 0.034 & 232 & 0.035 & 0.044 & 236 & 0.039 & 0.051 & 226 \\
# $\overline{D}$ & 0.043 & 0.055 & 124 & 0.067 & 0.087 & 117 & 1.1 & 1.1 & 104 & 0.065 & 0.087 & 117 \\
# $\overline{\|\cdot\|}_{F}$ & 0.056 & 0.073 & 73 & 0.034 & 0.044 & 75 & 0.033 & 0.041 & 121 & 0.14 & 0.19 & 64 \\
# \toprule
# \multicolumn{1}{c}{} & \multicolumn{3}{c}{$\mu-\sigma$-deformation} & \multicolumn{3}{c}{$\mu-\Sigma_{ij}-\Sigma_{ii}$-deformation} & \multicolumn{3}{c}{$\mu-\Sigma_{ij}$-deformation} & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & t (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $t_{\mathrm{LLR}}$ & 0.0019 & 0.0029 & 419 & 0.0023 & 0.0035 & 637 & 0.0086 & 0.011 & 411 & - \\
# $d_{\mathrm{MMD}}$ & 0.02 & 0.028 & 310 & 0.021 & 0.029 & 323 & 0.02 & 0.028 & 326 & 2008 \\
# $d_{\mathrm{FGD}}$ & 0.02 & 0.026 & 246 & 0.024 & 0.031 & 232 & 0.025 & 0.033 & 239 & 428 \\
# $\widetilde{W}$ & 0.021 & 0.029 & 132 & 0.026 & 0.036 & 164 & 0.024 & 0.033 & 128 & 251 \\
# $\widetilde{D}$ & 0.021 & 0.028 & 222 & 0.026 & 0.034 & 295 & 0.026 & 0.034 & 220 & 324 \\
# $\overline{\|\cdot\|}_{F}$ & 0.033 & 0.042 & 77 & 0.032 & 0.04 & 111 & 0.05 & 0.065 & 76 & 7 \\
# $\overline{D}$ & 0.034 & 0.044 & 132 & 0.043 & 0.055 & 156 & 0.033 & 0.043 & 130 & 26 \\
# \bottomrule
# \end{tabular}
