# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/5D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-05-02 19:09:27.390452: Importing os...
# 2024-05-02 19:09:27.390622: Importing sys...
# Visible devices: [1]
# 2024-05-02 19:09:27.390856: Importing timer from timeit...
# 2024-05-02 19:09:27.390924: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-05-02 19:09:27.391053: Importing numpy...
# 2024-05-02 19:09:27.498239: Importing matplotlib...
# 2024-05-02 19:09:27.847498: Importing h5py...
# 2024-05-02 19:09:27.871225: Importing importlib.util...
# 2024-05-02 19:09:27.871325: Importing json...
# 2024-05-02 19:09:27.871389: Importing pandas...
# 2024-05-02 19:09:28.294408: Importing random...
# 2024-05-02 19:09:28.294553: Importing scipy utils...
# 2024-05-02 19:09:28.690351: Importing subprocess...
# 2024-05-02 19:09:28.690493: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-05-02 19:09:32.008821: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-05-02 19:09:33.163244: Importing timeit...
# 2024-05-02 19:09:33.163346: Importing tqdm...
# 2024-05-02 19:09:33.171459: Importing typing...
# 2024-05-02 19:09:33.171576: Setting tf configs...
# 2024-05-02 19:09:33.260221: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-05-02 19:09:37.888686: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-05-02 19:09:37.918545: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed,
                                                 nsamples = 1_000_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)
# sample from dist_1:  tf.Tensor(
# [[ 1.1610332  -2.23691168 -2.20072828  5.13732308  1.32224517]
#  [-2.52914258 -0.85839971 -1.86610514  1.33679732 -0.66477288]], shape=(2, 5), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[ 1.1610332  -2.23691168 -2.20072828  5.13732308  1.32224517]
#  [-2.52914258 -0.85839971 -1.86610514  1.33679732 -0.66477288]], shape=(2, 5), dtype=float64)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory was created
# Null hypothesis directory was created

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100, # to be included in metric kwargs
                           seed_slicing = 0, # to be included in metric kwargs
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
FGDMetric = GMetrics.FGDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               num_batches = 20, # to be included in metric kwargs
                               num_points = 10, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
MMDMetric = GMetrics.MMDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4, # to be included in metric kwargs
                               block_size = 20_000, # to be included in metric kwargs
                               normalise = False) # to be included in metric kwargs
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True        5           0  float64     5  200000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetric",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": null_hypotheses_dir+"FGD.json"},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetric" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": null_hypotheses_dir+"MMD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 10000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2000,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fgd': {'name': 'fgd',
#   'object_name': 'FGDMetric',
#   'class_name': 'GMetrics.FGDMetric',
#   'kwargs': {'num_batches': 20, 'num_points': 10, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$d_{\\mathrm{FGD}}$',
#   'null_file': 'results/5D_unimodal/5D_20K/null_hypothesis/FGD.json'},
#  'mmd': {'name': 'mmd',
#   'object_name': 'MMDMetric',
#   'class_name': 'GMetrics.MMDMetric',
#   'kwargs': {'degree': 4, 'block_size': 20000, 'normalise': False},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 5,
#   'latex': '$d_{\\mathrm{MMD}}$',
#   'null_file': 'results/5D_unimodal/5D_20K/null_hypothesis/MMD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 10000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results/5D_unimodal/5D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results/5D_unimodal/5D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results/5D_unimodal/5D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 2000,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results/5D_unimodal/5D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 1000
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714669782.771519  164219 service.cc:145] XLA service 0x7de3500 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714669782.771561  164219 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1714669785.653082  164219 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# FGD metric calculation completed in 434.96176538895816 seconds.
# Saving fgd to results/5D_unimodal/5D_20K/null_hypothesis/FGD.json
# Computing and savng mmd with max_vectorize = 5
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 2000
# Iterating from 0 to 5 out of 10000 .
# Iterating from 5 to 10 out of 10000 .
# Iterating from 10 to 15 out of 10000 .
# Iterating from 15 to 20 out of 10000 .
# Iterating from 20 to 25 out of 10000 .
# Iterating from 25 to 30 out of 10000 .
# Iterating from 30 to 35 out of 10000 .
# Iterating from 35 to 40 out of 10000 .
# Iterating from 40 to 45 out of 10000 .
# Iterating from 45 to 50 out of 10000 .
# Iterating from 50 to 55 out of 10000 .
# Iterating from 55 to 60 out of 10000 .
# Iterating from 60 to 65 out of 10000 .
# Iterating from 65 to 70 out of 10000 .
# Iterating from 70 to 75 out of 10000 .
# Iterating from 75 to 80 out of 10000 .
# Iterating from 80 to 85 out of 10000 .
# Iterating from 85 to 90 out of 10000 .
# Iterating from 90 to 95 out of 10000 .
# Iterating from 95 to 100 out of 10000 .
# Iterating from 100 to 105 out of 10000 .
# Iterating from 105 to 110 out of 10000 .
# Iterating from 110 to 115 out of 10000 .
# Iterating from 115 to 120 out of 10000 .
# Iterating from 120 to 125 out of 10000 .
# Iterating from 125 to 130 out of 10000 .
# Iterating from 130 to 135 out of 10000 .
# Iterating from 135 to 140 out of 10000 .
# Iterating from 140 to 145 out of 10000 .
# Iterating from 145 to 150 out of 10000 .
# Iterating from 150 to 155 out of 10000 .
# Iterating from 155 to 160 out of 10000 .
# Iterating from 160 to 165 out of 10000 .
# Iterating from 165 to 170 out of 10000 .
# Iterating from 170 to 175 out of 10000 .
# Iterating from 175 to 180 out of 10000 .
# Iterating from 180 to 185 out of 10000 .
# Iterating from 185 to 190 out of 10000 .
# Iterating from 190 to 195 out of 10000 .
# Iterating from 195 to 200 out of 10000 .
# Iterating from 200 to 205 out of 10000 .
# Iterating from 205 to 210 out of 10000 .
# Iterating from 210 to 215 out of 10000 .
# Iterating from 215 to 220 out of 10000 .
# Iterating from 220 to 225 out of 10000 .
# Iterating from 225 to 230 out of 10000 .
# Iterating from 230 to 235 out of 10000 .
# Iterating from 235 to 240 out of 10000 .
# Iterating from 240 to 245 out of 10000 .
# Iterating from 245 to 250 out of 10000 .
# Iterating from 250 to 255 out of 10000 .
# Iterating from 255 to 260 out of 10000 .
# Iterating from 260 to 265 out of 10000 .
# Iterating from 265 to 270 out of 10000 .
# Iterating from 270 to 275 out of 10000 .
# Iterating from 275 to 280 out of 10000 .
# Iterating from 280 to 285 out of 10000 .
# Iterating from 285 to 290 out of 10000 .
# Iterating from 290 to 295 out of 10000 .
# Iterating from 295 to 300 out of 10000 .
# Iterating from 300 to 305 out of 10000 .
# Iterating from 305 to 310 out of 10000 .
# Iterating from 310 to 315 out of 10000 .
# Iterating from 315 to 320 out of 10000 .
# Iterating from 320 to 325 out of 10000 .
# Iterating from 325 to 330 out of 10000 .
# Iterating from 330 to 335 out of 10000 .
# Iterating from 335 to 340 out of 10000 .
# Iterating from 340 to 345 out of 10000 .
# Iterating from 345 to 350 out of 10000 .
# Iterating from 350 to 355 out of 10000 .
# Iterating from 355 to 360 out of 10000 .
# Iterating from 360 to 365 out of 10000 .
# Iterating from 365 to 370 out of 10000 .
# Iterating from 370 to 375 out of 10000 .
# Iterating from 375 to 380 out of 10000 .
# Iterating from 380 to 385 out of 10000 .
# Iterating from 385 to 390 out of 10000 .
# Iterating from 390 to 395 out of 10000 .
# Iterating from 395 to 400 out of 10000 .
# Iterating from 400 to 405 out of 10000 .
# Iterating from 405 to 410 out of 10000 .
# Iterating from 410 to 415 out of 10000 .
# Iterating from 415 to 420 out of 10000 .
# Iterating from 420 to 425 out of 10000 .
# Iterating from 425 to 430 out of 10000 .
# Iterating from 430 to 435 out of 10000 .
# Iterating from 435 to 440 out of 10000 .
# Iterating from 440 to 445 out of 10000 .
# Iterating from 445 to 450 out of 10000 .
# Iterating from 450 to 455 out of 10000 .
# Iterating from 455 to 460 out of 10000 .
# Iterating from 460 to 465 out of 10000 .
# Iterating from 465 to 470 out of 10000 .
# Iterating from 470 to 475 out of 10000 .
# Iterating from 475 to 480 out of 10000 .
# Iterating from 480 to 485 out of 10000 .
# Iterating from 485 to 490 out of 10000 .
# Iterating from 490 to 495 out of 10000 .
# Iterating from 495 to 500 out of 10000 .
# Iterating from 500 to 505 out of 10000 .
# Iterating from 505 to 510 out of 10000 .
# Iterating from 510 to 515 out of 10000 .
# Iterating from 515 to 520 out of 10000 .
# Iterating from 520 to 525 out of 10000 .
# Iterating from 525 to 530 out of 10000 .
# Iterating from 530 to 535 out of 10000 .
# Iterating from 535 to 540 out of 10000 .
# Iterating from 540 to 545 out of 10000 .
# Iterating from 545 to 550 out of 10000 .
# Iterating from 550 to 555 out of 10000 .
# Iterating from 555 to 560 out of 10000 .
# Iterating from 560 to 565 out of 10000 .
# Iterating from 565 to 570 out of 10000 .
# Iterating from 570 to 575 out of 10000 .
# Iterating from 575 to 580 out of 10000 .
# Iterating from 580 to 585 out of 10000 .
# Iterating from 585 to 590 out of 10000 .
# Iterating from 590 to 595 out of 10000 .
# Iterating from 595 to 600 out of 10000 .
# Iterating from 600 to 605 out of 10000 .
# Iterating from 605 to 610 out of 10000 .
# Iterating from 610 to 615 out of 10000 .
# Iterating from 615 to 620 out of 10000 .
# Iterating from 620 to 625 out of 10000 .
# Iterating from 625 to 630 out of 10000 .
# Iterating from 630 to 635 out of 10000 .
# Iterating from 635 to 640 out of 10000 .
# Iterating from 640 to 645 out of 10000 .
# Iterating from 645 to 650 out of 10000 .
# Iterating from 650 to 655 out of 10000 .
# Iterating from 655 to 660 out of 10000 .
# Iterating from 660 to 665 out of 10000 .
# Iterating from 665 to 670 out of 10000 .
# Iterating from 670 to 675 out of 10000 .
# Iterating from 675 to 680 out of 10000 .
# Iterating from 680 to 685 out of 10000 .
# Iterating from 685 to 690 out of 10000 .
# Iterating from 690 to 695 out of 10000 .
# Iterating from 695 to 700 out of 10000 .
# Iterating from 700 to 705 out of 10000 .
# Iterating from 705 to 710 out of 10000 .
# Iterating from 710 to 715 out of 10000 .
# Iterating from 715 to 720 out of 10000 .
# Iterating from 720 to 725 out of 10000 .
# Iterating from 725 to 730 out of 10000 .
# Iterating from 730 to 735 out of 10000 .
# Iterating from 735 to 740 out of 10000 .
# Iterating from 740 to 745 out of 10000 .
# Iterating from 745 to 750 out of 10000 .
# Iterating from 750 to 755 out of 10000 .
# Iterating from 755 to 760 out of 10000 .
# Iterating from 760 to 765 out of 10000 .
# Iterating from 765 to 770 out of 10000 .
# Iterating from 770 to 775 out of 10000 .
# Iterating from 775 to 780 out of 10000 .
# Iterating from 780 to 785 out of 10000 .
# Iterating from 785 to 790 out of 10000 .
# Iterating from 790 to 795 out of 10000 .
# Iterating from 795 to 800 out of 10000 .
# Iterating from 800 to 805 out of 10000 .
# Iterating from 805 to 810 out of 10000 .
# Iterating from 810 to 815 out of 10000 .
# Iterating from 815 to 820 out of 10000 .
# Iterating from 820 to 825 out of 10000 .
# Iterating from 825 to 830 out of 10000 .
# Iterating from 830 to 835 out of 10000 .
# Iterating from 835 to 840 out of 10000 .
# Iterating from 840 to 845 out of 10000 .
# Iterating from 845 to 850 out of 10000 .
# Iterating from 850 to 855 out of 10000 .
# Iterating from 855 to 860 out of 10000 .
# Iterating from 860 to 865 out of 10000 .
# Iterating from 865 to 870 out of 10000 .
# Iterating from 870 to 875 out of 10000 .
# Iterating from 875 to 880 out of 10000 .
# Iterating from 880 to 885 out of 10000 .
# Iterating from 885 to 890 out of 10000 .
# Iterating from 890 to 895 out of 10000 .
# Iterating from 895 to 900 out of 10000 .
# Iterating from 900 to 905 out of 10000 .
# Iterating from 905 to 910 out of 10000 .
# Iterating from 910 to 915 out of 10000 .
# Iterating from 915 to 920 out of 10000 .
# Iterating from 920 to 925 out of 10000 .
# Iterating from 925 to 930 out of 10000 .
# Iterating from 930 to 935 out of 10000 .
# Iterating from 935 to 940 out of 10000 .
# Iterating from 940 to 945 out of 10000 .
# Iterating from 945 to 950 out of 10000 .
# Iterating from 950 to 955 out of 10000 .
# Iterating from 955 to 960 out of 10000 .
# Iterating from 960 to 965 out of 10000 .
# Iterating from 965 to 970 out of 10000 .
# Iterating from 970 to 975 out of 10000 .
# Iterating from 975 to 980 out of 10000 .
# Iterating from 980 to 985 out of 10000 .
# Iterating from 985 to 990 out of 10000 .
# Iterating from 990 to 995 out of 10000 .
# Iterating from 995 to 1000 out of 10000 .
# Iterating from 1000 to 1005 out of 10000 .
# Iterating from 1005 to 1010 out of 10000 .
# Iterating from 1010 to 1015 out of 10000 .
# Iterating from 1015 to 1020 out of 10000 .
# Iterating from 1020 to 1025 out of 10000 .
# Iterating from 1025 to 1030 out of 10000 .
# Iterating from 1030 to 1035 out of 10000 .
# Iterating from 1035 to 1040 out of 10000 .
# Iterating from 1040 to 1045 out of 10000 .
# Iterating from 1045 to 1050 out of 10000 .
# Iterating from 1050 to 1055 out of 10000 .
# Iterating from 1055 to 1060 out of 10000 .
# Iterating from 1060 to 1065 out of 10000 .
# Iterating from 1065 to 1070 out of 10000 .
# Iterating from 1070 to 1075 out of 10000 .
# Iterating from 1075 to 1080 out of 10000 .
# Iterating from 1080 to 1085 out of 10000 .
# Iterating from 1085 to 1090 out of 10000 .
# Iterating from 1090 to 1095 out of 10000 .
# Iterating from 1095 to 1100 out of 10000 .
# Iterating from 1100 to 1105 out of 10000 .
# Iterating from 1105 to 1110 out of 10000 .
# Iterating from 1110 to 1115 out of 10000 .
# Iterating from 1115 to 1120 out of 10000 .
# Iterating from 1120 to 1125 out of 10000 .
# Iterating from 1125 to 1130 out of 10000 .
# Iterating from 1130 to 1135 out of 10000 .
# Iterating from 1135 to 1140 out of 10000 .
# Iterating from 1140 to 1145 out of 10000 .
# Iterating from 1145 to 1150 out of 10000 .
# Iterating from 1150 to 1155 out of 10000 .
# Iterating from 1155 to 1160 out of 10000 .
# Iterating from 1160 to 1165 out of 10000 .
# Iterating from 1165 to 1170 out of 10000 .
# Iterating from 1170 to 1175 out of 10000 .
# Iterating from 1175 to 1180 out of 10000 .
# Iterating from 1180 to 1185 out of 10000 .
# Iterating from 1185 to 1190 out of 10000 .
# Iterating from 1190 to 1195 out of 10000 .
# Iterating from 1195 to 1200 out of 10000 .
# Iterating from 1200 to 1205 out of 10000 .
# Iterating from 1205 to 1210 out of 10000 .
# Iterating from 1210 to 1215 out of 10000 .
# Iterating from 1215 to 1220 out of 10000 .
# Iterating from 1220 to 1225 out of 10000 .
# Iterating from 1225 to 1230 out of 10000 .
# Iterating from 1230 to 1235 out of 10000 .
# Iterating from 1235 to 1240 out of 10000 .
# Iterating from 1240 to 1245 out of 10000 .
# Iterating from 1245 to 1250 out of 10000 .
# Iterating from 1250 to 1255 out of 10000 .
# Iterating from 1255 to 1260 out of 10000 .
# Iterating from 1260 to 1265 out of 10000 .
# Iterating from 1265 to 1270 out of 10000 .
# Iterating from 1270 to 1275 out of 10000 .
# Iterating from 1275 to 1280 out of 10000 .
# Iterating from 1280 to 1285 out of 10000 .
# Iterating from 1285 to 1290 out of 10000 .
# Iterating from 1290 to 1295 out of 10000 .
# Iterating from 1295 to 1300 out of 10000 .
# Iterating from 1300 to 1305 out of 10000 .
# Iterating from 1305 to 1310 out of 10000 .
# Iterating from 1310 to 1315 out of 10000 .
# Iterating from 1315 to 1320 out of 10000 .
# Iterating from 1320 to 1325 out of 10000 .
# Iterating from 1325 to 1330 out of 10000 .
# Iterating from 1330 to 1335 out of 10000 .
# Iterating from 1335 to 1340 out of 10000 .
# Iterating from 1340 to 1345 out of 10000 .
# Iterating from 1345 to 1350 out of 10000 .
# Iterating from 1350 to 1355 out of 10000 .
# Iterating from 1355 to 1360 out of 10000 .
# Iterating from 1360 to 1365 out of 10000 .
# Iterating from 1365 to 1370 out of 10000 .
# Iterating from 1370 to 1375 out of 10000 .
# Iterating from 1375 to 1380 out of 10000 .
# Iterating from 1380 to 1385 out of 10000 .
# Iterating from 1385 to 1390 out of 10000 .
# Iterating from 1390 to 1395 out of 10000 .
# Iterating from 1395 to 1400 out of 10000 .
# Iterating from 1400 to 1405 out of 10000 .
# Iterating from 1405 to 1410 out of 10000 .
# Iterating from 1410 to 1415 out of 10000 .
# Iterating from 1415 to 1420 out of 10000 .
# Iterating from 1420 to 1425 out of 10000 .
# Iterating from 1425 to 1430 out of 10000 .
# Iterating from 1430 to 1435 out of 10000 .
# Iterating from 1435 to 1440 out of 10000 .
# Iterating from 1440 to 1445 out of 10000 .
# Iterating from 1445 to 1450 out of 10000 .
# Iterating from 1450 to 1455 out of 10000 .
# Iterating from 1455 to 1460 out of 10000 .
# Iterating from 1460 to 1465 out of 10000 .
# Iterating from 1465 to 1470 out of 10000 .
# Iterating from 1470 to 1475 out of 10000 .
# Iterating from 1475 to 1480 out of 10000 .
# Iterating from 1480 to 1485 out of 10000 .
# Iterating from 1485 to 1490 out of 10000 .
# Iterating from 1490 to 1495 out of 10000 .
# Iterating from 1495 to 1500 out of 10000 .
# Iterating from 1500 to 1505 out of 10000 .
# Iterating from 1505 to 1510 out of 10000 .
# Iterating from 1510 to 1515 out of 10000 .
# Iterating from 1515 to 1520 out of 10000 .
# Iterating from 1520 to 1525 out of 10000 .
# Iterating from 1525 to 1530 out of 10000 .
# Iterating from 1530 to 1535 out of 10000 .
# Iterating from 1535 to 1540 out of 10000 .
# Iterating from 1540 to 1545 out of 10000 .
# Iterating from 1545 to 1550 out of 10000 .
# Iterating from 1550 to 1555 out of 10000 .
# Iterating from 1555 to 1560 out of 10000 .
# Iterating from 1560 to 1565 out of 10000 .
# Iterating from 1565 to 1570 out of 10000 .
# Iterating from 1570 to 1575 out of 10000 .
# Iterating from 1575 to 1580 out of 10000 .
# Iterating from 1580 to 1585 out of 10000 .
# Iterating from 1585 to 1590 out of 10000 .
# Iterating from 1590 to 1595 out of 10000 .
# Iterating from 1595 to 1600 out of 10000 .
# Iterating from 1600 to 1605 out of 10000 .
# Iterating from 1605 to 1610 out of 10000 .
# Iterating from 1610 to 1615 out of 10000 .
# Iterating from 1615 to 1620 out of 10000 .
# Iterating from 1620 to 1625 out of 10000 .
# Iterating from 1625 to 1630 out of 10000 .
# Iterating from 1630 to 1635 out of 10000 .
# Iterating from 1635 to 1640 out of 10000 .
# Iterating from 1640 to 1645 out of 10000 .
# Iterating from 1645 to 1650 out of 10000 .
# Iterating from 1650 to 1655 out of 10000 .
# Iterating from 1655 to 1660 out of 10000 .
# Iterating from 1660 to 1665 out of 10000 .
# Iterating from 1665 to 1670 out of 10000 .
# Iterating from 1670 to 1675 out of 10000 .
# Iterating from 1675 to 1680 out of 10000 .
# Iterating from 1680 to 1685 out of 10000 .
# Iterating from 1685 to 1690 out of 10000 .
# Iterating from 1690 to 1695 out of 10000 .
# Iterating from 1695 to 1700 out of 10000 .
# Iterating from 1700 to 1705 out of 10000 .
# Iterating from 1705 to 1710 out of 10000 .
# Iterating from 1710 to 1715 out of 10000 .
# Iterating from 1715 to 1720 out of 10000 .
# Iterating from 1720 to 1725 out of 10000 .
# Iterating from 1725 to 1730 out of 10000 .
# Iterating from 1730 to 1735 out of 10000 .
# Iterating from 1735 to 1740 out of 10000 .
# Iterating from 1740 to 1745 out of 10000 .
# Iterating from 1745 to 1750 out of 10000 .
# Iterating from 1750 to 1755 out of 10000 .
# Iterating from 1755 to 1760 out of 10000 .
# Iterating from 1760 to 1765 out of 10000 .
# Iterating from 1765 to 1770 out of 10000 .
# Iterating from 1770 to 1775 out of 10000 .
# Iterating from 1775 to 1780 out of 10000 .
# Iterating from 1780 to 1785 out of 10000 .
# Iterating from 1785 to 1790 out of 10000 .
# Iterating from 1790 to 1795 out of 10000 .
# Iterating from 1795 to 1800 out of 10000 .
# Iterating from 1800 to 1805 out of 10000 .
# Iterating from 1805 to 1810 out of 10000 .
# Iterating from 1810 to 1815 out of 10000 .
# Iterating from 1815 to 1820 out of 10000 .
# Iterating from 1820 to 1825 out of 10000 .
# Iterating from 1825 to 1830 out of 10000 .
# Iterating from 1830 to 1835 out of 10000 .
# Iterating from 1835 to 1840 out of 10000 .
# Iterating from 1840 to 1845 out of 10000 .
# Iterating from 1845 to 1850 out of 10000 .
# Iterating from 1850 to 1855 out of 10000 .
# Iterating from 1855 to 1860 out of 10000 .
# Iterating from 1860 to 1865 out of 10000 .
# Iterating from 1865 to 1870 out of 10000 .
# Iterating from 1870 to 1875 out of 10000 .
# Iterating from 1875 to 1880 out of 10000 .
# Iterating from 1880 to 1885 out of 10000 .
# Iterating from 1885 to 1890 out of 10000 .
# Iterating from 1890 to 1895 out of 10000 .
# Iterating from 1895 to 1900 out of 10000 .
# Iterating from 1900 to 1905 out of 10000 .
# Iterating from 1905 to 1910 out of 10000 .
# Iterating from 1910 to 1915 out of 10000 .
# Iterating from 1915 to 1920 out of 10000 .
# Iterating from 1920 to 1925 out of 10000 .
# Iterating from 1925 to 1930 out of 10000 .
# Iterating from 1930 to 1935 out of 10000 .
# Iterating from 1935 to 1940 out of 10000 .
# Iterating from 1940 to 1945 out of 10000 .
# Iterating from 1945 to 1950 out of 10000 .
# Iterating from 1950 to 1955 out of 10000 .
# Iterating from 1955 to 1960 out of 10000 .
# Iterating from 1960 to 1965 out of 10000 .
# Iterating from 1965 to 1970 out of 10000 .
# Iterating from 1970 to 1975 out of 10000 .
# Iterating from 1975 to 1980 out of 10000 .
# Iterating from 1980 to 1985 out of 10000 .
# Iterating from 1985 to 1990 out of 10000 .
# Iterating from 1990 to 1995 out of 10000 .
# Iterating from 1995 to 2000 out of 10000 .
# Iterating from 2000 to 2005 out of 10000 .
# Iterating from 2005 to 2010 out of 10000 .
# Iterating from 2010 to 2015 out of 10000 .
# Iterating from 2015 to 2020 out of 10000 .
# Iterating from 2020 to 2025 out of 10000 .
# Iterating from 2025 to 2030 out of 10000 .
# Iterating from 2030 to 2035 out of 10000 .
# Iterating from 2035 to 2040 out of 10000 .
# Iterating from 2040 to 2045 out of 10000 .
# Iterating from 2045 to 2050 out of 10000 .
# Iterating from 2050 to 2055 out of 10000 .
# Iterating from 2055 to 2060 out of 10000 .
# Iterating from 2060 to 2065 out of 10000 .
# Iterating from 2065 to 2070 out of 10000 .
# Iterating from 2070 to 2075 out of 10000 .
# Iterating from 2075 to 2080 out of 10000 .
# Iterating from 2080 to 2085 out of 10000 .
# Iterating from 2085 to 2090 out of 10000 .
# Iterating from 2090 to 2095 out of 10000 .
# Iterating from 2095 to 2100 out of 10000 .
# Iterating from 2100 to 2105 out of 10000 .
# Iterating from 2105 to 2110 out of 10000 .
# Iterating from 2110 to 2115 out of 10000 .
# Iterating from 2115 to 2120 out of 10000 .
# Iterating from 2120 to 2125 out of 10000 .
# Iterating from 2125 to 2130 out of 10000 .
# Iterating from 2130 to 2135 out of 10000 .
# Iterating from 2135 to 2140 out of 10000 .
# Iterating from 2140 to 2145 out of 10000 .
# Iterating from 2145 to 2150 out of 10000 .
# Iterating from 2150 to 2155 out of 10000 .
# Iterating from 2155 to 2160 out of 10000 .
# Iterating from 2160 to 2165 out of 10000 .
# Iterating from 2165 to 2170 out of 10000 .
# Iterating from 2170 to 2175 out of 10000 .
# Iterating from 2175 to 2180 out of 10000 .
# Iterating from 2180 to 2185 out of 10000 .
# Iterating from 2185 to 2190 out of 10000 .
# Iterating from 2190 to 2195 out of 10000 .
# Iterating from 2195 to 2200 out of 10000 .
# Iterating from 2200 to 2205 out of 10000 .
# Iterating from 2205 to 2210 out of 10000 .
# Iterating from 2210 to 2215 out of 10000 .
# Iterating from 2215 to 2220 out of 10000 .
# Iterating from 2220 to 2225 out of 10000 .
# Iterating from 2225 to 2230 out of 10000 .
# Iterating from 2230 to 2235 out of 10000 .
# Iterating from 2235 to 2240 out of 10000 .
# Iterating from 2240 to 2245 out of 10000 .
# Iterating from 2245 to 2250 out of 10000 .
# Iterating from 2250 to 2255 out of 10000 .
# Iterating from 2255 to 2260 out of 10000 .
# Iterating from 2260 to 2265 out of 10000 .
# Iterating from 2265 to 2270 out of 10000 .
# Iterating from 2270 to 2275 out of 10000 .
# Iterating from 2275 to 2280 out of 10000 .
# Iterating from 2280 to 2285 out of 10000 .
# Iterating from 2285 to 2290 out of 10000 .
# Iterating from 2290 to 2295 out of 10000 .
# Iterating from 2295 to 2300 out of 10000 .
# Iterating from 2300 to 2305 out of 10000 .
# Iterating from 2305 to 2310 out of 10000 .
# Iterating from 2310 to 2315 out of 10000 .
# Iterating from 2315 to 2320 out of 10000 .
# Iterating from 2320 to 2325 out of 10000 .
# Iterating from 2325 to 2330 out of 10000 .
# Iterating from 2330 to 2335 out of 10000 .
# Iterating from 2335 to 2340 out of 10000 .
# Iterating from 2340 to 2345 out of 10000 .
# Iterating from 2345 to 2350 out of 10000 .
# Iterating from 2350 to 2355 out of 10000 .
# Iterating from 2355 to 2360 out of 10000 .
# Iterating from 2360 to 2365 out of 10000 .
# Iterating from 2365 to 2370 out of 10000 .
# Iterating from 2370 to 2375 out of 10000 .
# Iterating from 2375 to 2380 out of 10000 .
# Iterating from 2380 to 2385 out of 10000 .
# Iterating from 2385 to 2390 out of 10000 .
# Iterating from 2390 to 2395 out of 10000 .
# Iterating from 2395 to 2400 out of 10000 .
# Iterating from 2400 to 2405 out of 10000 .
# Iterating from 2405 to 2410 out of 10000 .
# Iterating from 2410 to 2415 out of 10000 .
# Iterating from 2415 to 2420 out of 10000 .
# Iterating from 2420 to 2425 out of 10000 .
# Iterating from 2425 to 2430 out of 10000 .
# Iterating from 2430 to 2435 out of 10000 .
# Iterating from 2435 to 2440 out of 10000 .
# Iterating from 2440 to 2445 out of 10000 .
# Iterating from 2445 to 2450 out of 10000 .
# Iterating from 2450 to 2455 out of 10000 .
# Iterating from 2455 to 2460 out of 10000 .
# Iterating from 2460 to 2465 out of 10000 .
# Iterating from 2465 to 2470 out of 10000 .
# Iterating from 2470 to 2475 out of 10000 .
# Iterating from 2475 to 2480 out of 10000 .
# Iterating from 2480 to 2485 out of 10000 .
# Iterating from 2485 to 2490 out of 10000 .
# Iterating from 2490 to 2495 out of 10000 .
# Iterating from 2495 to 2500 out of 10000 .
# Iterating from 2500 to 2505 out of 10000 .
# Iterating from 2505 to 2510 out of 10000 .
# Iterating from 2510 to 2515 out of 10000 .
# Iterating from 2515 to 2520 out of 10000 .
# Iterating from 2520 to 2525 out of 10000 .
# Iterating from 2525 to 2530 out of 10000 .
# Iterating from 2530 to 2535 out of 10000 .
# Iterating from 2535 to 2540 out of 10000 .
# Iterating from 2540 to 2545 out of 10000 .
# Iterating from 2545 to 2550 out of 10000 .
# Iterating from 2550 to 2555 out of 10000 .
# Iterating from 2555 to 2560 out of 10000 .
# Iterating from 2560 to 2565 out of 10000 .
# Iterating from 2565 to 2570 out of 10000 .
# Iterating from 2570 to 2575 out of 10000 .
# Iterating from 2575 to 2580 out of 10000 .
# Iterating from 2580 to 2585 out of 10000 .
# Iterating from 2585 to 2590 out of 10000 .
# Iterating from 2590 to 2595 out of 10000 .
# Iterating from 2595 to 2600 out of 10000 .
# Iterating from 2600 to 2605 out of 10000 .
# Iterating from 2605 to 2610 out of 10000 .
# Iterating from 2610 to 2615 out of 10000 .
# Iterating from 2615 to 2620 out of 10000 .
# Iterating from 2620 to 2625 out of 10000 .
# Iterating from 2625 to 2630 out of 10000 .
# Iterating from 2630 to 2635 out of 10000 .
# Iterating from 2635 to 2640 out of 10000 .
# Iterating from 2640 to 2645 out of 10000 .
# Iterating from 2645 to 2650 out of 10000 .
# Iterating from 2650 to 2655 out of 10000 .
# Iterating from 2655 to 2660 out of 10000 .
# Iterating from 2660 to 2665 out of 10000 .
# Iterating from 2665 to 2670 out of 10000 .
# Iterating from 2670 to 2675 out of 10000 .
# Iterating from 2675 to 2680 out of 10000 .
# Iterating from 2680 to 2685 out of 10000 .
# Iterating from 2685 to 2690 out of 10000 .
# Iterating from 2690 to 2695 out of 10000 .
# Iterating from 2695 to 2700 out of 10000 .
# Iterating from 2700 to 2705 out of 10000 .
# Iterating from 2705 to 2710 out of 10000 .
# Iterating from 2710 to 2715 out of 10000 .
# Iterating from 2715 to 2720 out of 10000 .
# Iterating from 2720 to 2725 out of 10000 .
# Iterating from 2725 to 2730 out of 10000 .
# Iterating from 2730 to 2735 out of 10000 .
# Iterating from 2735 to 2740 out of 10000 .
# Iterating from 2740 to 2745 out of 10000 .
# Iterating from 2745 to 2750 out of 10000 .
# Iterating from 2750 to 2755 out of 10000 .
# Iterating from 2755 to 2760 out of 10000 .
# Iterating from 2760 to 2765 out of 10000 .
# Iterating from 2765 to 2770 out of 10000 .
# Iterating from 2770 to 2775 out of 10000 .
# Iterating from 2775 to 2780 out of 10000 .
# Iterating from 2780 to 2785 out of 10000 .
# Iterating from 2785 to 2790 out of 10000 .
# Iterating from 2790 to 2795 out of 10000 .
# Iterating from 2795 to 2800 out of 10000 .
# Iterating from 2800 to 2805 out of 10000 .
# Iterating from 2805 to 2810 out of 10000 .
# Iterating from 2810 to 2815 out of 10000 .
# Iterating from 2815 to 2820 out of 10000 .
# Iterating from 2820 to 2825 out of 10000 .
# Iterating from 2825 to 2830 out of 10000 .
# Iterating from 2830 to 2835 out of 10000 .
# Iterating from 2835 to 2840 out of 10000 .
# Iterating from 2840 to 2845 out of 10000 .
# Iterating from 2845 to 2850 out of 10000 .
# Iterating from 2850 to 2855 out of 10000 .
# Iterating from 2855 to 2860 out of 10000 .
# Iterating from 2860 to 2865 out of 10000 .
# Iterating from 2865 to 2870 out of 10000 .
# Iterating from 2870 to 2875 out of 10000 .
# Iterating from 2875 to 2880 out of 10000 .
# Iterating from 2880 to 2885 out of 10000 .
# Iterating from 2885 to 2890 out of 10000 .
# Iterating from 2890 to 2895 out of 10000 .
# Iterating from 2895 to 2900 out of 10000 .
# Iterating from 2900 to 2905 out of 10000 .
# Iterating from 2905 to 2910 out of 10000 .
# Iterating from 2910 to 2915 out of 10000 .
# Iterating from 2915 to 2920 out of 10000 .
# Iterating from 2920 to 2925 out of 10000 .
# Iterating from 2925 to 2930 out of 10000 .
# Iterating from 2930 to 2935 out of 10000 .
# Iterating from 2935 to 2940 out of 10000 .
# Iterating from 2940 to 2945 out of 10000 .
# Iterating from 2945 to 2950 out of 10000 .
# Iterating from 2950 to 2955 out of 10000 .
# Iterating from 2955 to 2960 out of 10000 .
# Iterating from 2960 to 2965 out of 10000 .
# Iterating from 2965 to 2970 out of 10000 .
# Iterating from 2970 to 2975 out of 10000 .
# Iterating from 2975 to 2980 out of 10000 .
# Iterating from 2980 to 2985 out of 10000 .
# Iterating from 2985 to 2990 out of 10000 .
# Iterating from 2990 to 2995 out of 10000 .
# Iterating from 2995 to 3000 out of 10000 .
# Iterating from 3000 to 3005 out of 10000 .
# Iterating from 3005 to 3010 out of 10000 .
# Iterating from 3010 to 3015 out of 10000 .
# Iterating from 3015 to 3020 out of 10000 .
# Iterating from 3020 to 3025 out of 10000 .
# Iterating from 3025 to 3030 out of 10000 .
# Iterating from 3030 to 3035 out of 10000 .
# Iterating from 3035 to 3040 out of 10000 .
# Iterating from 3040 to 3045 out of 10000 .
# Iterating from 3045 to 3050 out of 10000 .
# Iterating from 3050 to 3055 out of 10000 .
# Iterating from 3055 to 3060 out of 10000 .
# Iterating from 3060 to 3065 out of 10000 .
# Iterating from 3065 to 3070 out of 10000 .
# Iterating from 3070 to 3075 out of 10000 .
# Iterating from 3075 to 3080 out of 10000 .
# Iterating from 3080 to 3085 out of 10000 .
# Iterating from 3085 to 3090 out of 10000 .
# Iterating from 3090 to 3095 out of 10000 .
# Iterating from 3095 to 3100 out of 10000 .
# Iterating from 3100 to 3105 out of 10000 .
# Iterating from 3105 to 3110 out of 10000 .
# Iterating from 3110 to 3115 out of 10000 .
# Iterating from 3115 to 3120 out of 10000 .
# Iterating from 3120 to 3125 out of 10000 .
# Iterating from 3125 to 3130 out of 10000 .
# Iterating from 3130 to 3135 out of 10000 .
# Iterating from 3135 to 3140 out of 10000 .
# Iterating from 3140 to 3145 out of 10000 .
# Iterating from 3145 to 3150 out of 10000 .
# Iterating from 3150 to 3155 out of 10000 .
# Iterating from 3155 to 3160 out of 10000 .
# Iterating from 3160 to 3165 out of 10000 .
# Iterating from 3165 to 3170 out of 10000 .
# Iterating from 3170 to 3175 out of 10000 .
# Iterating from 3175 to 3180 out of 10000 .
# Iterating from 3180 to 3185 out of 10000 .
# Iterating from 3185 to 3190 out of 10000 .
# Iterating from 3190 to 3195 out of 10000 .
# Iterating from 3195 to 3200 out of 10000 .
# Iterating from 3200 to 3205 out of 10000 .
# Iterating from 3205 to 3210 out of 10000 .
# Iterating from 3210 to 3215 out of 10000 .
# Iterating from 3215 to 3220 out of 10000 .
# Iterating from 3220 to 3225 out of 10000 .
# Iterating from 3225 to 3230 out of 10000 .
# Iterating from 3230 to 3235 out of 10000 .
# Iterating from 3235 to 3240 out of 10000 .
# Iterating from 3240 to 3245 out of 10000 .
# Iterating from 3245 to 3250 out of 10000 .
# Iterating from 3250 to 3255 out of 10000 .
# Iterating from 3255 to 3260 out of 10000 .
# Iterating from 3260 to 3265 out of 10000 .
# Iterating from 3265 to 3270 out of 10000 .
# Iterating from 3270 to 3275 out of 10000 .
# Iterating from 3275 to 3280 out of 10000 .
# Iterating from 3280 to 3285 out of 10000 .
# Iterating from 3285 to 3290 out of 10000 .
# Iterating from 3290 to 3295 out of 10000 .
# Iterating from 3295 to 3300 out of 10000 .
# Iterating from 3300 to 3305 out of 10000 .
# Iterating from 3305 to 3310 out of 10000 .
# Iterating from 3310 to 3315 out of 10000 .
# Iterating from 3315 to 3320 out of 10000 .
# Iterating from 3320 to 3325 out of 10000 .
# Iterating from 3325 to 3330 out of 10000 .
# Iterating from 3330 to 3335 out of 10000 .
# Iterating from 3335 to 3340 out of 10000 .
# Iterating from 3340 to 3345 out of 10000 .
# Iterating from 3345 to 3350 out of 10000 .
# Iterating from 3350 to 3355 out of 10000 .
# Iterating from 3355 to 3360 out of 10000 .
# Iterating from 3360 to 3365 out of 10000 .
# Iterating from 3365 to 3370 out of 10000 .
# Iterating from 3370 to 3375 out of 10000 .
# Iterating from 3375 to 3380 out of 10000 .
# Iterating from 3380 to 3385 out of 10000 .
# Iterating from 3385 to 3390 out of 10000 .
# Iterating from 3390 to 3395 out of 10000 .
# Iterating from 3395 to 3400 out of 10000 .
# Iterating from 3400 to 3405 out of 10000 .
# Iterating from 3405 to 3410 out of 10000 .
# Iterating from 3410 to 3415 out of 10000 .
# Iterating from 3415 to 3420 out of 10000 .
# Iterating from 3420 to 3425 out of 10000 .
# Iterating from 3425 to 3430 out of 10000 .
# Iterating from 3430 to 3435 out of 10000 .
# Iterating from 3435 to 3440 out of 10000 .
# Iterating from 3440 to 3445 out of 10000 .
# Iterating from 3445 to 3450 out of 10000 .
# Iterating from 3450 to 3455 out of 10000 .
# Iterating from 3455 to 3460 out of 10000 .
# Iterating from 3460 to 3465 out of 10000 .
# Iterating from 3465 to 3470 out of 10000 .
# Iterating from 3470 to 3475 out of 10000 .
# Iterating from 3475 to 3480 out of 10000 .
# Iterating from 3480 to 3485 out of 10000 .
# Iterating from 3485 to 3490 out of 10000 .
# Iterating from 3490 to 3495 out of 10000 .
# Iterating from 3495 to 3500 out of 10000 .
# Iterating from 3500 to 3505 out of 10000 .
# Iterating from 3505 to 3510 out of 10000 .
# Iterating from 3510 to 3515 out of 10000 .
# Iterating from 3515 to 3520 out of 10000 .
# Iterating from 3520 to 3525 out of 10000 .
# Iterating from 3525 to 3530 out of 10000 .
# Iterating from 3530 to 3535 out of 10000 .
# Iterating from 3535 to 3540 out of 10000 .
# Iterating from 3540 to 3545 out of 10000 .
# Iterating from 3545 to 3550 out of 10000 .
# Iterating from 3550 to 3555 out of 10000 .
# Iterating from 3555 to 3560 out of 10000 .
# Iterating from 3560 to 3565 out of 10000 .
# Iterating from 3565 to 3570 out of 10000 .
# Iterating from 3570 to 3575 out of 10000 .
# Iterating from 3575 to 3580 out of 10000 .
# Iterating from 3580 to 3585 out of 10000 .
# Iterating from 3585 to 3590 out of 10000 .
# Iterating from 3590 to 3595 out of 10000 .
# Iterating from 3595 to 3600 out of 10000 .
# Iterating from 3600 to 3605 out of 10000 .
# Iterating from 3605 to 3610 out of 10000 .
# Iterating from 3610 to 3615 out of 10000 .
# Iterating from 3615 to 3620 out of 10000 .
# Iterating from 3620 to 3625 out of 10000 .
# Iterating from 3625 to 3630 out of 10000 .
# Iterating from 3630 to 3635 out of 10000 .
# Iterating from 3635 to 3640 out of 10000 .
# Iterating from 3640 to 3645 out of 10000 .
# Iterating from 3645 to 3650 out of 10000 .
# Iterating from 3650 to 3655 out of 10000 .
# Iterating from 3655 to 3660 out of 10000 .
# Iterating from 3660 to 3665 out of 10000 .
# Iterating from 3665 to 3670 out of 10000 .
# Iterating from 3670 to 3675 out of 10000 .
# Iterating from 3675 to 3680 out of 10000 .
# Iterating from 3680 to 3685 out of 10000 .
# Iterating from 3685 to 3690 out of 10000 .
# Iterating from 3690 to 3695 out of 10000 .
# Iterating from 3695 to 3700 out of 10000 .
# Iterating from 3700 to 3705 out of 10000 .
# Iterating from 3705 to 3710 out of 10000 .
# Iterating from 3710 to 3715 out of 10000 .
# Iterating from 3715 to 3720 out of 10000 .
# Iterating from 3720 to 3725 out of 10000 .
# Iterating from 3725 to 3730 out of 10000 .
# Iterating from 3730 to 3735 out of 10000 .
# Iterating from 3735 to 3740 out of 10000 .
# Iterating from 3740 to 3745 out of 10000 .
# Iterating from 3745 to 3750 out of 10000 .
# Iterating from 3750 to 3755 out of 10000 .
# Iterating from 3755 to 3760 out of 10000 .
# Iterating from 3760 to 3765 out of 10000 .
# Iterating from 3765 to 3770 out of 10000 .
# Iterating from 3770 to 3775 out of 10000 .
# Iterating from 3775 to 3780 out of 10000 .
# Iterating from 3780 to 3785 out of 10000 .
# Iterating from 3785 to 3790 out of 10000 .
# Iterating from 3790 to 3795 out of 10000 .
# Iterating from 3795 to 3800 out of 10000 .
# Iterating from 3800 to 3805 out of 10000 .
# Iterating from 3805 to 3810 out of 10000 .
# Iterating from 3810 to 3815 out of 10000 .
# Iterating from 3815 to 3820 out of 10000 .
# Iterating from 3820 to 3825 out of 10000 .
# Iterating from 3825 to 3830 out of 10000 .
# Iterating from 3830 to 3835 out of 10000 .
# Iterating from 3835 to 3840 out of 10000 .
# Iterating from 3840 to 3845 out of 10000 .
# Iterating from 3845 to 3850 out of 10000 .
# Iterating from 3850 to 3855 out of 10000 .
# Iterating from 3855 to 3860 out of 10000 .
# Iterating from 3860 to 3865 out of 10000 .
# Iterating from 3865 to 3870 out of 10000 .
# Iterating from 3870 to 3875 out of 10000 .
# Iterating from 3875 to 3880 out of 10000 .
# Iterating from 3880 to 3885 out of 10000 .
# Iterating from 3885 to 3890 out of 10000 .
# Iterating from 3890 to 3895 out of 10000 .
# Iterating from 3895 to 3900 out of 10000 .
# Iterating from 3900 to 3905 out of 10000 .
# Iterating from 3905 to 3910 out of 10000 .
# Iterating from 3910 to 3915 out of 10000 .
# Iterating from 3915 to 3920 out of 10000 .
# Iterating from 3920 to 3925 out of 10000 .
# Iterating from 3925 to 3930 out of 10000 .
# Iterating from 3930 to 3935 out of 10000 .
# Iterating from 3935 to 3940 out of 10000 .
# Iterating from 3940 to 3945 out of 10000 .
# Iterating from 3945 to 3950 out of 10000 .
# Iterating from 3950 to 3955 out of 10000 .
# Iterating from 3955 to 3960 out of 10000 .
# Iterating from 3960 to 3965 out of 10000 .
# Iterating from 3965 to 3970 out of 10000 .
# Iterating from 3970 to 3975 out of 10000 .
# Iterating from 3975 to 3980 out of 10000 .
# Iterating from 3980 to 3985 out of 10000 .
# Iterating from 3985 to 3990 out of 10000 .
# Iterating from 3990 to 3995 out of 10000 .
# Iterating from 3995 to 4000 out of 10000 .
# Iterating from 4000 to 4005 out of 10000 .
# Iterating from 4005 to 4010 out of 10000 .
# Iterating from 4010 to 4015 out of 10000 .
# Iterating from 4015 to 4020 out of 10000 .
# Iterating from 4020 to 4025 out of 10000 .
# Iterating from 4025 to 4030 out of 10000 .
# Iterating from 4030 to 4035 out of 10000 .
# Iterating from 4035 to 4040 out of 10000 .
# Iterating from 4040 to 4045 out of 10000 .
# Iterating from 4045 to 4050 out of 10000 .
# Iterating from 4050 to 4055 out of 10000 .
# Iterating from 4055 to 4060 out of 10000 .
# Iterating from 4060 to 4065 out of 10000 .
# Iterating from 4065 to 4070 out of 10000 .
# Iterating from 4070 to 4075 out of 10000 .
# Iterating from 4075 to 4080 out of 10000 .
# Iterating from 4080 to 4085 out of 10000 .
# Iterating from 4085 to 4090 out of 10000 .
# Iterating from 4090 to 4095 out of 10000 .
# Iterating from 4095 to 4100 out of 10000 .
# Iterating from 4100 to 4105 out of 10000 .
# Iterating from 4105 to 4110 out of 10000 .
# Iterating from 4110 to 4115 out of 10000 .
# Iterating from 4115 to 4120 out of 10000 .
# Iterating from 4120 to 4125 out of 10000 .
# Iterating from 4125 to 4130 out of 10000 .
# Iterating from 4130 to 4135 out of 10000 .
# Iterating from 4135 to 4140 out of 10000 .
# Iterating from 4140 to 4145 out of 10000 .
# Iterating from 4145 to 4150 out of 10000 .
# Iterating from 4150 to 4155 out of 10000 .
# Iterating from 4155 to 4160 out of 10000 .
# Iterating from 4160 to 4165 out of 10000 .
# Iterating from 4165 to 4170 out of 10000 .
# Iterating from 4170 to 4175 out of 10000 .
# Iterating from 4175 to 4180 out of 10000 .
# Iterating from 4180 to 4185 out of 10000 .
# Iterating from 4185 to 4190 out of 10000 .
# Iterating from 4190 to 4195 out of 10000 .
# Iterating from 4195 to 4200 out of 10000 .
# Iterating from 4200 to 4205 out of 10000 .
# Iterating from 4205 to 4210 out of 10000 .
# Iterating from 4210 to 4215 out of 10000 .
# Iterating from 4215 to 4220 out of 10000 .
# Iterating from 4220 to 4225 out of 10000 .
# Iterating from 4225 to 4230 out of 10000 .
# Iterating from 4230 to 4235 out of 10000 .
# Iterating from 4235 to 4240 out of 10000 .
# Iterating from 4240 to 4245 out of 10000 .
# Iterating from 4245 to 4250 out of 10000 .
# Iterating from 4250 to 4255 out of 10000 .
# Iterating from 4255 to 4260 out of 10000 .
# Iterating from 4260 to 4265 out of 10000 .
# Iterating from 4265 to 4270 out of 10000 .
# Iterating from 4270 to 4275 out of 10000 .
# Iterating from 4275 to 4280 out of 10000 .
# Iterating from 4280 to 4285 out of 10000 .
# Iterating from 4285 to 4290 out of 10000 .
# Iterating from 4290 to 4295 out of 10000 .
# Iterating from 4295 to 4300 out of 10000 .
# Iterating from 4300 to 4305 out of 10000 .
# Iterating from 4305 to 4310 out of 10000 .
# Iterating from 4310 to 4315 out of 10000 .
# Iterating from 4315 to 4320 out of 10000 .
# Iterating from 4320 to 4325 out of 10000 .
# Iterating from 4325 to 4330 out of 10000 .
# Iterating from 4330 to 4335 out of 10000 .
# Iterating from 4335 to 4340 out of 10000 .
# Iterating from 4340 to 4345 out of 10000 .
# Iterating from 4345 to 4350 out of 10000 .
# Iterating from 4350 to 4355 out of 10000 .
# Iterating from 4355 to 4360 out of 10000 .
# Iterating from 4360 to 4365 out of 10000 .
# Iterating from 4365 to 4370 out of 10000 .
# Iterating from 4370 to 4375 out of 10000 .
# Iterating from 4375 to 4380 out of 10000 .
# Iterating from 4380 to 4385 out of 10000 .
# Iterating from 4385 to 4390 out of 10000 .
# Iterating from 4390 to 4395 out of 10000 .
# Iterating from 4395 to 4400 out of 10000 .
# Iterating from 4400 to 4405 out of 10000 .
# Iterating from 4405 to 4410 out of 10000 .
# Iterating from 4410 to 4415 out of 10000 .
# Iterating from 4415 to 4420 out of 10000 .
# Iterating from 4420 to 4425 out of 10000 .
# Iterating from 4425 to 4430 out of 10000 .
# Iterating from 4430 to 4435 out of 10000 .
# Iterating from 4435 to 4440 out of 10000 .
# Iterating from 4440 to 4445 out of 10000 .
# Iterating from 4445 to 4450 out of 10000 .
# Iterating from 4450 to 4455 out of 10000 .
# Iterating from 4455 to 4460 out of 10000 .
# Iterating from 4460 to 4465 out of 10000 .
# Iterating from 4465 to 4470 out of 10000 .
# Iterating from 4470 to 4475 out of 10000 .
# Iterating from 4475 to 4480 out of 10000 .
# Iterating from 4480 to 4485 out of 10000 .
# Iterating from 4485 to 4490 out of 10000 .
# Iterating from 4490 to 4495 out of 10000 .
# Iterating from 4495 to 4500 out of 10000 .
# Iterating from 4500 to 4505 out of 10000 .
# Iterating from 4505 to 4510 out of 10000 .
# Iterating from 4510 to 4515 out of 10000 .
# Iterating from 4515 to 4520 out of 10000 .
# Iterating from 4520 to 4525 out of 10000 .
# Iterating from 4525 to 4530 out of 10000 .
# Iterating from 4530 to 4535 out of 10000 .
# Iterating from 4535 to 4540 out of 10000 .
# Iterating from 4540 to 4545 out of 10000 .
# Iterating from 4545 to 4550 out of 10000 .
# Iterating from 4550 to 4555 out of 10000 .
# Iterating from 4555 to 4560 out of 10000 .
# Iterating from 4560 to 4565 out of 10000 .
# Iterating from 4565 to 4570 out of 10000 .
# Iterating from 4570 to 4575 out of 10000 .
# Iterating from 4575 to 4580 out of 10000 .
# Iterating from 4580 to 4585 out of 10000 .
# Iterating from 4585 to 4590 out of 10000 .
# Iterating from 4590 to 4595 out of 10000 .
# Iterating from 4595 to 4600 out of 10000 .
# Iterating from 4600 to 4605 out of 10000 .
# Iterating from 4605 to 4610 out of 10000 .
# Iterating from 4610 to 4615 out of 10000 .
# Iterating from 4615 to 4620 out of 10000 .
# Iterating from 4620 to 4625 out of 10000 .
# Iterating from 4625 to 4630 out of 10000 .
# Iterating from 4630 to 4635 out of 10000 .
# Iterating from 4635 to 4640 out of 10000 .
# Iterating from 4640 to 4645 out of 10000 .
# Iterating from 4645 to 4650 out of 10000 .
# Iterating from 4650 to 4655 out of 10000 .
# Iterating from 4655 to 4660 out of 10000 .
# Iterating from 4660 to 4665 out of 10000 .
# Iterating from 4665 to 4670 out of 10000 .
# Iterating from 4670 to 4675 out of 10000 .
# Iterating from 4675 to 4680 out of 10000 .
# Iterating from 4680 to 4685 out of 10000 .
# Iterating from 4685 to 4690 out of 10000 .
# Iterating from 4690 to 4695 out of 10000 .
# Iterating from 4695 to 4700 out of 10000 .
# Iterating from 4700 to 4705 out of 10000 .
# Iterating from 4705 to 4710 out of 10000 .
# Iterating from 4710 to 4715 out of 10000 .
# Iterating from 4715 to 4720 out of 10000 .
# Iterating from 4720 to 4725 out of 10000 .
# Iterating from 4725 to 4730 out of 10000 .
# Iterating from 4730 to 4735 out of 10000 .
# Iterating from 4735 to 4740 out of 10000 .
# Iterating from 4740 to 4745 out of 10000 .
# Iterating from 4745 to 4750 out of 10000 .
# Iterating from 4750 to 4755 out of 10000 .
# Iterating from 4755 to 4760 out of 10000 .
# Iterating from 4760 to 4765 out of 10000 .
# Iterating from 4765 to 4770 out of 10000 .
# Iterating from 4770 to 4775 out of 10000 .
# Iterating from 4775 to 4780 out of 10000 .
# Iterating from 4780 to 4785 out of 10000 .
# Iterating from 4785 to 4790 out of 10000 .
# Iterating from 4790 to 4795 out of 10000 .
# Iterating from 4795 to 4800 out of 10000 .
# Iterating from 4800 to 4805 out of 10000 .
# Iterating from 4805 to 4810 out of 10000 .
# Iterating from 4810 to 4815 out of 10000 .
# Iterating from 4815 to 4820 out of 10000 .
# Iterating from 4820 to 4825 out of 10000 .
# Iterating from 4825 to 4830 out of 10000 .
# Iterating from 4830 to 4835 out of 10000 .
# Iterating from 4835 to 4840 out of 10000 .
# Iterating from 4840 to 4845 out of 10000 .
# Iterating from 4845 to 4850 out of 10000 .
# Iterating from 4850 to 4855 out of 10000 .
# Iterating from 4855 to 4860 out of 10000 .
# Iterating from 4860 to 4865 out of 10000 .
# Iterating from 4865 to 4870 out of 10000 .
# Iterating from 4870 to 4875 out of 10000 .
# Iterating from 4875 to 4880 out of 10000 .
# Iterating from 4880 to 4885 out of 10000 .
# Iterating from 4885 to 4890 out of 10000 .
# Iterating from 4890 to 4895 out of 10000 .
# Iterating from 4895 to 4900 out of 10000 .
# Iterating from 4900 to 4905 out of 10000 .
# Iterating from 4905 to 4910 out of 10000 .
# Iterating from 4910 to 4915 out of 10000 .
# Iterating from 4915 to 4920 out of 10000 .
# Iterating from 4920 to 4925 out of 10000 .
# Iterating from 4925 to 4930 out of 10000 .
# Iterating from 4930 to 4935 out of 10000 .
# Iterating from 4935 to 4940 out of 10000 .
# Iterating from 4940 to 4945 out of 10000 .
# Iterating from 4945 to 4950 out of 10000 .
# Iterating from 4950 to 4955 out of 10000 .
# Iterating from 4955 to 4960 out of 10000 .
# Iterating from 4960 to 4965 out of 10000 .
# Iterating from 4965 to 4970 out of 10000 .
# Iterating from 4970 to 4975 out of 10000 .
# Iterating from 4975 to 4980 out of 10000 .
# Iterating from 4980 to 4985 out of 10000 .
# Iterating from 4985 to 4990 out of 10000 .
# Iterating from 4990 to 4995 out of 10000 .
# Iterating from 4995 to 5000 out of 10000 .
# Iterating from 5000 to 5005 out of 10000 .
# Iterating from 5005 to 5010 out of 10000 .
# Iterating from 5010 to 5015 out of 10000 .
# Iterating from 5015 to 5020 out of 10000 .
# Iterating from 5020 to 5025 out of 10000 .
# Iterating from 5025 to 5030 out of 10000 .
# Iterating from 5030 to 5035 out of 10000 .
# Iterating from 5035 to 5040 out of 10000 .
# Iterating from 5040 to 5045 out of 10000 .
# Iterating from 5045 to 5050 out of 10000 .
# Iterating from 5050 to 5055 out of 10000 .
# Iterating from 5055 to 5060 out of 10000 .
# Iterating from 5060 to 5065 out of 10000 .
# Iterating from 5065 to 5070 out of 10000 .
# Iterating from 5070 to 5075 out of 10000 .
# Iterating from 5075 to 5080 out of 10000 .
# Iterating from 5080 to 5085 out of 10000 .
# Iterating from 5085 to 5090 out of 10000 .
# Iterating from 5090 to 5095 out of 10000 .
# Iterating from 5095 to 5100 out of 10000 .
# Iterating from 5100 to 5105 out of 10000 .
# Iterating from 5105 to 5110 out of 10000 .
# Iterating from 5110 to 5115 out of 10000 .
# Iterating from 5115 to 5120 out of 10000 .
# Iterating from 5120 to 5125 out of 10000 .
# Iterating from 5125 to 5130 out of 10000 .
# Iterating from 5130 to 5135 out of 10000 .
# Iterating from 5135 to 5140 out of 10000 .
# Iterating from 5140 to 5145 out of 10000 .
# Iterating from 5145 to 5150 out of 10000 .
# Iterating from 5150 to 5155 out of 10000 .
# Iterating from 5155 to 5160 out of 10000 .
# Iterating from 5160 to 5165 out of 10000 .
# Iterating from 5165 to 5170 out of 10000 .
# Iterating from 5170 to 5175 out of 10000 .
# Iterating from 5175 to 5180 out of 10000 .
# Iterating from 5180 to 5185 out of 10000 .
# Iterating from 5185 to 5190 out of 10000 .
# Iterating from 5190 to 5195 out of 10000 .
# Iterating from 5195 to 5200 out of 10000 .
# Iterating from 5200 to 5205 out of 10000 .
# Iterating from 5205 to 5210 out of 10000 .
# Iterating from 5210 to 5215 out of 10000 .
# Iterating from 5215 to 5220 out of 10000 .
# Iterating from 5220 to 5225 out of 10000 .
# Iterating from 5225 to 5230 out of 10000 .
# Iterating from 5230 to 5235 out of 10000 .
# Iterating from 5235 to 5240 out of 10000 .
# Iterating from 5240 to 5245 out of 10000 .
# Iterating from 5245 to 5250 out of 10000 .
# Iterating from 5250 to 5255 out of 10000 .
# Iterating from 5255 to 5260 out of 10000 .
# Iterating from 5260 to 5265 out of 10000 .
# Iterating from 5265 to 5270 out of 10000 .
# Iterating from 5270 to 5275 out of 10000 .
# Iterating from 5275 to 5280 out of 10000 .
# Iterating from 5280 to 5285 out of 10000 .
# Iterating from 5285 to 5290 out of 10000 .
# Iterating from 5290 to 5295 out of 10000 .
# Iterating from 5295 to 5300 out of 10000 .
# Iterating from 5300 to 5305 out of 10000 .
# Iterating from 5305 to 5310 out of 10000 .
# Iterating from 5310 to 5315 out of 10000 .
# Iterating from 5315 to 5320 out of 10000 .
# Iterating from 5320 to 5325 out of 10000 .
# Iterating from 5325 to 5330 out of 10000 .
# Iterating from 5330 to 5335 out of 10000 .
# Iterating from 5335 to 5340 out of 10000 .
# Iterating from 5340 to 5345 out of 10000 .
# Iterating from 5345 to 5350 out of 10000 .
# Iterating from 5350 to 5355 out of 10000 .
# Iterating from 5355 to 5360 out of 10000 .
# Iterating from 5360 to 5365 out of 10000 .
# Iterating from 5365 to 5370 out of 10000 .
# Iterating from 5370 to 5375 out of 10000 .
# Iterating from 5375 to 5380 out of 10000 .
# Iterating from 5380 to 5385 out of 10000 .
# Iterating from 5385 to 5390 out of 10000 .
# Iterating from 5390 to 5395 out of 10000 .
# Iterating from 5395 to 5400 out of 10000 .
# Iterating from 5400 to 5405 out of 10000 .
# Iterating from 5405 to 5410 out of 10000 .
# Iterating from 5410 to 5415 out of 10000 .
# ...
# Iterating from 8795 to 8800 out of 10000 .
# Iterating from 8800 to 8805 out of 10000 .
# Iterating from 8805 to 8810 out of 10000 .
# Iterating from 8810 to 8815 out of 10000 .
# Iterating from 8815 to 8820 out of 10000 .
# Iterating from 8820 to 8825 out of 10000 .
# Iterating from 8825 to 8830 out of 10000 .
# Iterating from 8830 to 8835 out of 10000 .
# Iterating from 8835 to 8840 out of 10000 .
# Iterating from 8840 to 8845 out of 10000 .
# Iterating from 8845 to 8850 out of 10000 .
# Iterating from 8850 to 8855 out of 10000 .
# Iterating from 8855 to 8860 out of 10000 .
# Iterating from 8860 to 8865 out of 10000 .
# Iterating from 8865 to 8870 out of 10000 .
# Iterating from 8870 to 8875 out of 10000 .
# Iterating from 8875 to 8880 out of 10000 .
# Iterating from 8880 to 8885 out of 10000 .
# Iterating from 8885 to 8890 out of 10000 .
# Iterating from 8890 to 8895 out of 10000 .
# Iterating from 8895 to 8900 out of 10000 .
# Iterating from 8900 to 8905 out of 10000 .
# Iterating from 8905 to 8910 out of 10000 .
# Iterating from 8910 to 8915 out of 10000 .
# Iterating from 8915 to 8920 out of 10000 .
# Iterating from 8920 to 8925 out of 10000 .
# Iterating from 8925 to 8930 out of 10000 .
# Iterating from 8930 to 8935 out of 10000 .
# Iterating from 8935 to 8940 out of 10000 .
# Iterating from 8940 to 8945 out of 10000 .
# Iterating from 8945 to 8950 out of 10000 .
# Iterating from 8950 to 8955 out of 10000 .
# Iterating from 8955 to 8960 out of 10000 .
# Iterating from 8960 to 8965 out of 10000 .
# Iterating from 8965 to 8970 out of 10000 .
# Iterating from 8970 to 8975 out of 10000 .
# Iterating from 8975 to 8980 out of 10000 .
# Iterating from 8980 to 8985 out of 10000 .
# Iterating from 8985 to 8990 out of 10000 .
# Iterating from 8990 to 8995 out of 10000 .
# Iterating from 8995 to 9000 out of 10000 .
# Iterating from 9000 to 9005 out of 10000 .
# Iterating from 9005 to 9010 out of 10000 .
# Iterating from 9010 to 9015 out of 10000 .
# Iterating from 9015 to 9020 out of 10000 .
# Iterating from 9020 to 9025 out of 10000 .
# Iterating from 9025 to 9030 out of 10000 .
# Iterating from 9030 to 9035 out of 10000 .
# Iterating from 9035 to 9040 out of 10000 .
# Iterating from 9040 to 9045 out of 10000 .
# Iterating from 9045 to 9050 out of 10000 .
# Iterating from 9050 to 9055 out of 10000 .
# Iterating from 9055 to 9060 out of 10000 .
# Iterating from 9060 to 9065 out of 10000 .
# Iterating from 9065 to 9070 out of 10000 .
# Iterating from 9070 to 9075 out of 10000 .
# Iterating from 9075 to 9080 out of 10000 .
# Iterating from 9080 to 9085 out of 10000 .
# Iterating from 9085 to 9090 out of 10000 .
# Iterating from 9090 to 9095 out of 10000 .
# Iterating from 9095 to 9100 out of 10000 .
# Iterating from 9100 to 9105 out of 10000 .
# Iterating from 9105 to 9110 out of 10000 .
# Iterating from 9110 to 9115 out of 10000 .
# Iterating from 9115 to 9120 out of 10000 .
# Iterating from 9120 to 9125 out of 10000 .
# Iterating from 9125 to 9130 out of 10000 .
# Iterating from 9130 to 9135 out of 10000 .
# Iterating from 9135 to 9140 out of 10000 .
# Iterating from 9140 to 9145 out of 10000 .
# Iterating from 9145 to 9150 out of 10000 .
# Iterating from 9150 to 9155 out of 10000 .
# Iterating from 9155 to 9160 out of 10000 .
# Iterating from 9160 to 9165 out of 10000 .
# Iterating from 9165 to 9170 out of 10000 .
# Iterating from 9170 to 9175 out of 10000 .
# Iterating from 9175 to 9180 out of 10000 .
# Iterating from 9180 to 9185 out of 10000 .
# Iterating from 9185 to 9190 out of 10000 .
# Iterating from 9190 to 9195 out of 10000 .
# Iterating from 9195 to 9200 out of 10000 .
# Iterating from 9200 to 9205 out of 10000 .
# Iterating from 9205 to 9210 out of 10000 .
# Iterating from 9210 to 9215 out of 10000 .
# Iterating from 9215 to 9220 out of 10000 .
# Iterating from 9220 to 9225 out of 10000 .
# Iterating from 9225 to 9230 out of 10000 .
# Iterating from 9230 to 9235 out of 10000 .
# Iterating from 9235 to 9240 out of 10000 .
# Iterating from 9240 to 9245 out of 10000 .
# Iterating from 9245 to 9250 out of 10000 .
# Iterating from 9250 to 9255 out of 10000 .
# Iterating from 9255 to 9260 out of 10000 .
# Iterating from 9260 to 9265 out of 10000 .
# Iterating from 9265 to 9270 out of 10000 .
# Iterating from 9270 to 9275 out of 10000 .
# Iterating from 9275 to 9280 out of 10000 .
# Iterating from 9280 to 9285 out of 10000 .
# Iterating from 9285 to 9290 out of 10000 .
# Iterating from 9290 to 9295 out of 10000 .
# Iterating from 9295 to 9300 out of 10000 .
# Iterating from 9300 to 9305 out of 10000 .
# Iterating from 9305 to 9310 out of 10000 .
# Iterating from 9310 to 9315 out of 10000 .
# Iterating from 9315 to 9320 out of 10000 .
# Iterating from 9320 to 9325 out of 10000 .
# Iterating from 9325 to 9330 out of 10000 .
# Iterating from 9330 to 9335 out of 10000 .
# Iterating from 9335 to 9340 out of 10000 .
# Iterating from 9340 to 9345 out of 10000 .
# Iterating from 9345 to 9350 out of 10000 .
# Iterating from 9350 to 9355 out of 10000 .
# Iterating from 9355 to 9360 out of 10000 .
# Iterating from 9360 to 9365 out of 10000 .
# Iterating from 9365 to 9370 out of 10000 .
# Iterating from 9370 to 9375 out of 10000 .
# Iterating from 9375 to 9380 out of 10000 .
# Iterating from 9380 to 9385 out of 10000 .
# Iterating from 9385 to 9390 out of 10000 .
# Iterating from 9390 to 9395 out of 10000 .
# Iterating from 9395 to 9400 out of 10000 .
# Iterating from 9400 to 9405 out of 10000 .
# Iterating from 9405 to 9410 out of 10000 .
# Iterating from 9410 to 9415 out of 10000 .
# Iterating from 9415 to 9420 out of 10000 .
# Iterating from 9420 to 9425 out of 10000 .
# Iterating from 9425 to 9430 out of 10000 .
# Iterating from 9430 to 9435 out of 10000 .
# Iterating from 9435 to 9440 out of 10000 .
# Iterating from 9440 to 9445 out of 10000 .
# Iterating from 9445 to 9450 out of 10000 .
# Iterating from 9450 to 9455 out of 10000 .
# Iterating from 9455 to 9460 out of 10000 .
# Iterating from 9460 to 9465 out of 10000 .
# Iterating from 9465 to 9470 out of 10000 .
# Iterating from 9470 to 9475 out of 10000 .
# Iterating from 9475 to 9480 out of 10000 .
# Iterating from 9480 to 9485 out of 10000 .
# Iterating from 9485 to 9490 out of 10000 .
# Iterating from 9490 to 9495 out of 10000 .
# Iterating from 9495 to 9500 out of 10000 .
# Iterating from 9500 to 9505 out of 10000 .
# Iterating from 9505 to 9510 out of 10000 .
# Iterating from 9510 to 9515 out of 10000 .
# Iterating from 9515 to 9520 out of 10000 .
# Iterating from 9520 to 9525 out of 10000 .
# Iterating from 9525 to 9530 out of 10000 .
# Iterating from 9530 to 9535 out of 10000 .
# Iterating from 9535 to 9540 out of 10000 .
# Iterating from 9540 to 9545 out of 10000 .
# Iterating from 9545 to 9550 out of 10000 .
# Iterating from 9550 to 9555 out of 10000 .
# Iterating from 9555 to 9560 out of 10000 .
# Iterating from 9560 to 9565 out of 10000 .
# Iterating from 9565 to 9570 out of 10000 .
# Iterating from 9570 to 9575 out of 10000 .
# Iterating from 9575 to 9580 out of 10000 .
# Iterating from 9580 to 9585 out of 10000 .
# Iterating from 9585 to 9590 out of 10000 .
# Iterating from 9590 to 9595 out of 10000 .
# Iterating from 9595 to 9600 out of 10000 .
# Iterating from 9600 to 9605 out of 10000 .
# Iterating from 9605 to 9610 out of 10000 .
# Iterating from 9610 to 9615 out of 10000 .
# Iterating from 9615 to 9620 out of 10000 .
# Iterating from 9620 to 9625 out of 10000 .
# Iterating from 9625 to 9630 out of 10000 .
# Iterating from 9630 to 9635 out of 10000 .
# Iterating from 9635 to 9640 out of 10000 .
# Iterating from 9640 to 9645 out of 10000 .
# Iterating from 9645 to 9650 out of 10000 .
# Iterating from 9650 to 9655 out of 10000 .
# Iterating from 9655 to 9660 out of 10000 .
# Iterating from 9660 to 9665 out of 10000 .
# Iterating from 9665 to 9670 out of 10000 .
# Iterating from 9670 to 9675 out of 10000 .
# Iterating from 9675 to 9680 out of 10000 .
# Iterating from 9680 to 9685 out of 10000 .
# Iterating from 9685 to 9690 out of 10000 .
# Iterating from 9690 to 9695 out of 10000 .
# Iterating from 9695 to 9700 out of 10000 .
# Iterating from 9700 to 9705 out of 10000 .
# Iterating from 9705 to 9710 out of 10000 .
# Iterating from 9710 to 9715 out of 10000 .
# Iterating from 9715 to 9720 out of 10000 .
# Iterating from 9720 to 9725 out of 10000 .
# Iterating from 9725 to 9730 out of 10000 .
# Iterating from 9730 to 9735 out of 10000 .
# Iterating from 9735 to 9740 out of 10000 .
# Iterating from 9740 to 9745 out of 10000 .
# Iterating from 9745 to 9750 out of 10000 .
# Iterating from 9750 to 9755 out of 10000 .
# Iterating from 9755 to 9760 out of 10000 .
# Iterating from 9760 to 9765 out of 10000 .
# Iterating from 9765 to 9770 out of 10000 .
# Iterating from 9770 to 9775 out of 10000 .
# Iterating from 9775 to 9780 out of 10000 .
# Iterating from 9780 to 9785 out of 10000 .
# Iterating from 9785 to 9790 out of 10000 .
# Iterating from 9790 to 9795 out of 10000 .
# Iterating from 9795 to 9800 out of 10000 .
# Iterating from 9800 to 9805 out of 10000 .
# Iterating from 9805 to 9810 out of 10000 .
# Iterating from 9810 to 9815 out of 10000 .
# Iterating from 9815 to 9820 out of 10000 .
# Iterating from 9820 to 9825 out of 10000 .
# Iterating from 9825 to 9830 out of 10000 .
# Iterating from 9830 to 9835 out of 10000 .
# Iterating from 9835 to 9840 out of 10000 .
# Iterating from 9840 to 9845 out of 10000 .
# Iterating from 9845 to 9850 out of 10000 .
# Iterating from 9850 to 9855 out of 10000 .
# Iterating from 9855 to 9860 out of 10000 .
# Iterating from 9860 to 9865 out of 10000 .
# Iterating from 9865 to 9870 out of 10000 .
# Iterating from 9870 to 9875 out of 10000 .
# Iterating from 9875 to 9880 out of 10000 .
# Iterating from 9880 to 9885 out of 10000 .
# Iterating from 9885 to 9890 out of 10000 .
# Iterating from 9890 to 9895 out of 10000 .
# Iterating from 9895 to 9900 out of 10000 .
# Iterating from 9900 to 9905 out of 10000 .
# Iterating from 9905 to 9910 out of 10000 .
# Iterating from 9910 to 9915 out of 10000 .
# Iterating from 9915 to 9920 out of 10000 .
# Iterating from 9920 to 9925 out of 10000 .
# Iterating from 9925 to 9930 out of 10000 .
# Iterating from 9930 to 9935 out of 10000 .
# Iterating from 9935 to 9940 out of 10000 .
# Iterating from 9940 to 9945 out of 10000 .
# Iterating from 9945 to 9950 out of 10000 .
# Iterating from 9950 to 9955 out of 10000 .
# Iterating from 9955 to 9960 out of 10000 .
# Iterating from 9960 to 9965 out of 10000 .
# Iterating from 9965 to 9970 out of 10000 .
# Iterating from 9970 to 9975 out of 10000 .
# Iterating from 9975 to 9980 out of 10000 .
# Iterating from 9980 to 9985 out of 10000 .
# Iterating from 9985 to 9990 out of 10000 .
# Iterating from 9990 to 9995 out of 10000 .
# Iterating from 9995 to 10000 out of 10000 .
# MMD metric calculation completed in 1266.1213205429958 seconds.
# Saving mmd to results/5D_unimodal/5D_20K/null_hypothesis/MMD.json
# Computing and savng ks with max_vectorize = 10000
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7fafb41209a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# KS tests calculation completed in 32.208049683016725 seconds.
# Saving ks to results/5D_unimodal/5D_20K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 500
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7faf2e249e40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2500 to 3000 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7faf2e249e40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# SKS metric calculation completed in 385.8424547170289 seconds.
# Saving sks to results/5D_unimodal/5D_20K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 500
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# SWD metric calculation completed in 281.88299666298553 seconds.
# Saving swd to results/5D_unimodal/5D_20K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [6800, 3199], 0.0005177265941017422], [0.95, [9500, 500], 0.0050706607699602954], [0.99, [9900, 100], 0.00956706954130897]]
# Computing time for metric fgd: 434.96176538895816
# ThresholdS for metric mmd: [[0.68, [6800, 3199], 0.679910785285756], [0.95, [9500, 500], 44.854666053914116], [0.99, [9900, 100], 85.25561089196708]]
# Computing time for metric mmd: 1266.1213205429958
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9200006723403931], [0.95, [9500, 500], 1.1250007152557373], [0.99, [9900, 100], 1.2680017948150635]]
# Computing time for metric ks: 32.208049683016725
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9088504128158092], [0.95, [9500, 500], 1.1235504411160946], [0.99, [9900, 100], 1.282250601798296]]
# Computing time for metric sks: 385.8424547170289
# ThresholdS for metric swd: [[0.68, [6800, 3199], 1.157595022510337], [0.95, [9500, 500], 1.5804932650089702], [0.99, [9900, 100], 1.9427348723353544]]
# Computing time for metric swd: 281.88299666298553
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fb0359e82c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fb0359e8400>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fb0359e84a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fb0359e8540>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fb0359e85e0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fb0359e8680>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              5
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...           2000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_unimodal/5D_20K/null_hypothesis/FGD...
# 1  $d_{\mathrm{MMD}}$  results/5D_unimodal/5D_20K/null_hypothesis/MMD...
# 2      $\overline{D}$  results/5D_unimodal/5D_20K/null_hypothesis/KS....
# 3     $\widetilde{D}$  results/5D_unimodal/5D_20K/null_hypothesis/SKS...
# 4     $\widetilde{W}$  results/5D_unimodal/5D_20K/null_hypothesis/SWD...
# 5           $t_{\mu}$  results/5D_unimodal/5D_20K/null_hypothesis/LR....
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.0005177265941017422], ...
# 1  [[0.68, [6800, 3199], 0.679910785285756], [0.9...
# 2  [[0.68, [6800, 3199], 0.9200006723403931], [0....
# 3  [[0.68, [6800, 3199], 0.9088504128158092], [0....
# 4  [[0.68, [6800, 3199], 1.157595022510337], [0.9...
# 5                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    if "FGD" in latex:
        latex = r"$d_{\mathrm{FGD}}\,(\times 10^{2})$"
        dist_null = dist_null * 100
    elif "MMD" in latex:
        latex = r"$d_{\mathrm{MMD}}\,(\times 10^{-2})$"
        dist_null = dist_null / 100
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for CG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        if "FGD" in latex:
            threshold_value = threshold_value * 100
        elif "MMD" in latex:
            threshold_value = threshold_value / 100
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.09777232141515221 +/- 0.0004230971075611359
# sigma = 0.20569324431325786 +/- 0.004838182357820089
# 68%CL = 0.05177265941017423, 95%CL = 0.5070660769960296, 99%CL = 0.9567069541308971
# mu = 0.09777232141515221 +/- 0.0004230971075611359
# sigma = 0.20569324431325786 +/- 0.004838182357820089
# /tmp/ipykernel_164219/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164219/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164219/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.24155224498827 seconds.
# mu = 0.0036349006204429457 +/- 0.00046911213528267096
# sigma = 0.21658996636101843 +/- 0.003610623622604685
# 68%CL = 0.00679910785285756, 95%CL = 0.44854666053914116, 99%CL = 0.8525561089196708
# mu = 0.0036349006204429457 +/- 0.00046911213528267096
# sigma = 0.21658996636101843 +/- 0.003610623622604685
# /tmp/ipykernel_164219/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164219/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164219/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9471166210132651 seconds.
# mu = 0.8676869675274939 +/- 0.00020276075681501302
# sigma = 0.14239408583751398 +/- 0.0011612259565947241
# 68%CL = 0.9200006723403931, 95%CL = 1.1250007152557373, 99%CL = 1.2680017948150635
# mu = 0.8676869675274939 +/- 0.00020276075681501302
# sigma = 0.14239408583751398 +/- 0.0011612259565947241
# /tmp/ipykernel_164219/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164219/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164219/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_164219/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2728051560116 seconds.
# mu = 0.8643720483127981 +/- 0.00019066400042719114
# sigma = 0.13808113572359954 +/- 0.0013083929030473925
# 68%CL = 0.9088504128158092, 95%CL = 1.1235504411160946, 99%CL = 1.282250601798296
# mu = 0.8643720483127981 +/- 0.00019066400042719114
# sigma = 0.13808113572359954 +/- 0.0013083929030473925
# /tmp/ipykernel_164219/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164219/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164219/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_164219/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.222052049008198 seconds.
# mu = 1.0929053675181024 +/- 0.0006497471046426166
# sigma = 0.2549013739944563 +/- 0.0028462719112150583
# 68%CL = 1.157595022510337, 95%CL = 1.5804932650089702, 99%CL = 1.9427348723353544
# mu = 1.0929053675181024 +/- 0.0006497471046426166
# sigma = 0.2549013739944563 +/- 0.0028462719112150583
# /tmp/ipykernel_164219/249574702.py:86: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_164219/249574702.py:88: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_164219/249574702.py:123: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_164219/249574702.py:129: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.4521632140385918 seconds.
#   name object_name          class_name  \
# 0  fgd   FGDMetric  GMetrics.FGDMetric
# 1  mmd   MMDMetric  GMetrics.MMDMetric
# 2   ks      KSTest     GMetrics.KSTest
# 3  sks     SKSTest    GMetrics.SKSTest
# 4  swd   SWDMetric  GMetrics.SWDMetric
# 5   lr    LRMetric   GMetrics.LRMetric
#
#                                               kwargs           result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...          metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...          metric_list
# 2                                                 {}      statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}         metric_means
# 5                                {'null_test': True}  lik_ratio_norm_list
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fb0359e82c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fb0359e8400>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fb0359e84a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fb0359e8540>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fb0359e85e0>  lambda ns, ndims: np.sqrt(ns/ndims)
# 5  <function <lambda> at 0x7fb0359e8680>        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...              5
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...          10000
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...           2000
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results/5D_unimodal/5D_20K/null_hypothesis/FGD...
# 1  $d_{\mathrm{MMD}}$  results/5D_unimodal/5D_20K/null_hypothesis/MMD...
# 2      $\overline{D}$  results/5D_unimodal/5D_20K/null_hypothesis/KS....
# 3     $\widetilde{D}$  results/5D_unimodal/5D_20K/null_hypothesis/SKS...
# 4     $\widetilde{W}$  results/5D_unimodal/5D_20K/null_hypothesis/SWD...
# 5           $t_{\mu}$  results/5D_unimodal/5D_20K/null_hypothesis/LR....
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.0005177265941017422], ...
# 1  [[0.68, [6800, 3199], 0.679910785285756], [0.9...
# 2  [[0.68, [6800, 3199], 0.9200006723403931], [0....
# 3  [[0.68, [6800, 3199], 0.9088504128158092], [0....
# 4  [[0.68, [6800, 3199], 1.157595022510337], [0.9...
# 5                                                 []
#
#                                          null_figure
# 0  results/5D_unimodal/5D_20K/null_hypothesis/FGD...
# 1  results/5D_unimodal/5D_20K/null_hypothesis/MMD...
# 2  results/5D_unimodal/5D_20K/null_hypothesis/KS.pdf
# 3  results/5D_unimodal/5D_20K/null_hypothesis/SKS...
# 4  results/5D_unimodal/5D_20K/null_hypothesis/SWD...
# 5                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
for metric_config in list(metrics_config[unique_key].values())[:-1]:
    print(metric_config["kwargs"])
# Out:
# {'num_batches': 20, 'num_points': 10, 'normalise': False}
# {'degree': 4, 'block_size': 20000, 'normalise': False}
# {}
# {'nslices': 100, 'seed_slicing': 0}
# {'nslices': 100, 'seed_slicing': 0}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(dist_1,
                                                 metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.02,
                                                 fn_tol = 0.02,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fgd with mean deformation.
#
# ======================================================
# =============== fgd - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = mean
# statistic = 7.664107795627459 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9973553043269032
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = mean
# WARNING:tensorflow:5 out of the last 44 calls to <function generate_and_clean_data_simple_1 at 0x7fb114d88f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.9215945532187972 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.989472668664708
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = mean
# WARNING:tensorflow:6 out of the last 45 calls to <function generate_and_clean_data_simple_1 at 0x7fb114d88f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.4850060468512153 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.958613329781999
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = mean
# WARNING:tensorflow:5 out of the last 14 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7fad8c138680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.12381542099995287 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8426312383671521
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = mean
# WARNING:tensorflow:6 out of the last 15 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7fad5c4a9ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.0313527937799124 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4431433445702073
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = mean
# statistic = 0.008123818916690336 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4627932619152902
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = mean
# statistic = 0.0027068342784010374 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.6078631942188895
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.05859375 - deformation = mean
# statistic = 0.004855736850809417 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.04330350795160122
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.068359375 - deformation = mean
# statistic = 0.006499563016822266 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.24699647529623425
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0634765625 - deformation = mean
# statistic = 0.005732605423927791 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.1225452825261288
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.06103515625 - deformation = mean
# statistic = 0.005283415623371403 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.041095863180636204
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.059814453125 - deformation = mean
# statistic = 0.005335520753448852 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.020618556701030927
# relative_error_metric = 0.0509043558182687
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0592041015625 - deformation = mean
# statistic = 0.005338184669600253 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.010362694300518135
# relative_error_metric = 0.051403184184710536
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.05889892578125 - deformation = mean
# statistic = 0.00513770151997361 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.005194805194805195
# relative_error_metric = 0.013134477031525595
# =======> statistic within required accuracy at 0.95 CL in 92.77520006301347 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.058746337890625 - deformation = mean
# statistic = 0.005095851307784354 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9535486984586614
# relative_error_metric = 0.6098673353748743
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5293731689453125 - deformation = mean
# statistic = 7.847738521733239 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.909206143324588
# relative_error_metric = 1.9951295927438875
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2940597534179688 - deformation = mean
# statistic = 2.0597372605003557 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.8262978315427347
# relative_error_metric = 1.9815066940083845
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6764030456542969 - deformation = mean
# statistic = 0.5669646098561091 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.6803570038658122
# relative_error_metric = 1.9336232863990526
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.36757469177246094 - deformation = mean
# statistic = 0.16971200471022568 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.448806567791871
# relative_error_metric = 1.7865435309446978
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.21316051483154297 - deformation = mean
# statistic = 0.05799155802960475 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.135787313890886
# relative_error_metric = 1.4335545356502821
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.13595342636108398 - deformation = mean
# statistic = 0.023731741939888123 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.7930886692871925
# relative_error_metric = 0.8507614397335199
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.09734988212585449 - deformation = mean
# statistic = 0.01264217262590967 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.4946121594892434
# relative_error_metric = 0.27692102787186706
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.07804811000823975 - deformation = mean
# statistic = 0.008353747307012533 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.22009114109879055
# relative_error_metric = 0.1354092555675083
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.08769899606704712 - deformation = mean
# statistic = 0.010284698880703115 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.11645314705432838
# relative_error_metric = 0.07229878206703444
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.08287355303764343 - deformation = mean
# statistic = 0.00916423668321596 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.05657936232684222
# relative_error_metric = 0.04301172094080451
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.08528627455234528 - deformation = mean
# statistic = 0.00992067923140454 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.0286955755043303
# relative_error_metric = 0.03629046066015469
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.08407991379499435 - deformation = mean
# statistic = 0.00932825302983548 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.014245591391321772
# relative_error_metric = 0.025277844352675344
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.08468309417366982 - deformation = mean
# statistic = 0.009593815806190615 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.007148253470185351
# relative_error_metric = 0.0027917566852028617
# =======> statistic within required accuracy at 0.99 CL in 93.54865391895873 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 186.32389069598867 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_diag deformation.
#
# ======================================================
# =============== fgd - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_diag
# statistic = 72.27481146862445 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9997193874355865
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_diag
# statistic = 18.045411631623733 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.99887633788664
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_diag
# statistic = 4.503070980120053 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9955008860201124
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_diag
# statistic = 1.1201553672478426 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9819746054794247
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_diag
# statistic = 0.27735618446444177 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.928184436351978
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_diag
# statistic = 0.06801870660134224 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.722495298436461
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_diag
# statistic = 0.01611900123968998 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0428047851540065
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_diag
# statistic = 0.003403855979751334 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.393368693327718
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.029296875 - deformation = cov_diag
# statistic = 0.008687001807770146 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.5257202693230214
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0244140625 - deformation = cov_diag
# statistic = 0.005833016482755672 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.13983460719281354
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.02197265625 - deformation = cov_diag
# statistic = 0.004659382091186824 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.08453789662443154
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.023193359375 - deformation = cov_diag
# statistic = 0.005116723279323999 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.009043049548512812
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0225830078125 - deformation = cov_diag
# statistic = 0.0048262220219844835 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.02666666666666667
# relative_error_metric = 0.049397118893792356
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.02288818359375 - deformation = cov_diag
# statistic = 0.004971793908313056 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.013245033112582781
# relative_error_metric = 0.019689780001922372
# =======> statistic within required accuracy at 0.95 CL in 95.0194728130009 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.023040771484375 - deformation = cov_diag
# statistic = 0.005198560253084026 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9816519335338254
# relative_error_metric = 0.5917132352707115
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5115203857421875 - deformation = cov_diag
# statistic = 72.93578441215158 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9636374582342495
# relative_error_metric = 1.9994753842789443
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2672805786132812 - deformation = cov_diag
# statistic = 18.55638426984568 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9285735402808573
# relative_error_metric = 1.9979387924989307
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6451606750488281 - deformation = cov_diag
# statistic = 4.796097298077187 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.8620729026917477
# relative_error_metric = 1.9920368391885426
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.33410072326660156 - deformation = cov_diag
# statistic = 1.2816174498941462 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.7419423749632834
# relative_error_metric = 1.9703618827602052
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.17857074737548828 - deformation = cov_diag
# statistic = 0.36401960572123826 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.5428679548733473
# relative_error_metric = 1.8975651951763484
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.10080575942993164 - deformation = cov_diag
# statistic = 0.11453136555201779 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.2558282799114449
# relative_error_metric = 1.6916296475740675
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.06192326545715332 - deformation = cov_diag
# statistic = 0.04222507913243552 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.9152694568770783
# relative_error_metric = 1.2611181589259766
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.04248201847076416 - deformation = cov_diag
# statistic = 0.019158113580765374 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.5934193888782759
# relative_error_metric = 0.667779488032994
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.03276139497756958 - deformation = cov_diag
# statistic = 0.011181478898261842 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.34839591756079064
# relative_error_metric = 0.15561660726819163
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.02790108323097229 - deformation = cov_diag
# statistic = 0.007743828148350484 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.1602411207101958
# relative_error_metric = 0.21064666034593774
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.030331239104270935 - deformation = cov_diag
# statistic = 0.009307703015176803 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.07703453528810897
# relative_error_metric = 0.027482876983653398
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.03154631704092026 - deformation = cov_diag
# statistic = 0.010426676409858551 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.03927362398728968
# relative_error_metric = 0.08598757537972858
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.030938778072595596 - deformation = cov_diag
# statistic = 0.009773684476232534 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.019831525967126618
# relative_error_metric = 0.021365757998490567
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.030635008588433266 - deformation = cov_diag
# statistic = 0.009572599613671916 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.009965169111061515
# relative_error_metric = 0.000577864990054593
# =======> statistic within required accuracy at 0.99 CL in 103.58166828699177 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 198.60117809998337 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with cov_off_diag deformation.
#
# ======================================================
# =============== fgd - cov_off_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = cov_off_diag
# statistic = 9.553591907632633 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9978780877623106
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = cov_off_diag
# statistic = 4.834042790007712 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9958086035208407
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = cov_off_diag
# statistic = 3.9804404100259916 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9949109053470047
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = cov_off_diag
# statistic = 1.9519369263664075 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9896358893991208
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = cov_off_diag
# statistic = 0.8016675774973843 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9748584582734012
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = cov_off_diag
# statistic = 0.2949311869932003 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.932391606148194
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = cov_off_diag
# statistic = 0.09832745008897972 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.803839326353732
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = cov_off_diag
# statistic = 0.029979162571815786 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4213196773615067
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = cov_off_diag
# statistic = 0.00842409320688874 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.49699793603965436
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = cov_off_diag
# statistic = 0.002345348621097234 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.7349807706957149
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00732421875 - deformation = cov_off_diag
# statistic = 0.004719022755155962 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.07183848464604124
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.008544921875 - deformation = cov_off_diag
# statistic = 0.006228172703993869 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.20489052019429188
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0079345703125 - deformation = cov_off_diag
# statistic = 0.00561045321704695 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.1010741852850313
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00762939453125 - deformation = cov_off_diag
# statistic = 0.005088894300381184 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.0035894348314755653
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.007476806640625 - deformation = cov_off_diag
# statistic = 0.004884274511813972 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.03744600097753794
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0075531005859375 - deformation = cov_off_diag
# statistic = 0.004956158069826735 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.010050251256281407
# relative_error_metric = 0.022839287706925872
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00759124755859375 - deformation = cov_off_diag
# statistic = 0.005206114460390302 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.005037783375314861
# relative_error_metric = 0.026361127375826684
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.007572174072265625 - deformation = cov_off_diag
# statistic = 0.005134615050984633 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.0025220680958385876
# relative_error_metric = 0.012533572271134474
# =======> statistic within required accuracy at 0.95 CL in 120.30996815901017 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0075626373291015625 - deformation = cov_off_diag
# statistic = 0.004991202900685457 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9939590272738872
# relative_error_metric = 0.6286276972567272
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.503781318664551 - deformation = cov_off_diag
# statistic = 9.56564925678008 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9879544380035203
# relative_error_metric = 1.9960034032797738
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2556719779968262 - deformation = cov_off_diag
# statistic = 4.84682526905692 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9760531029237183
# relative_error_metric = 1.992120019245339
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6316173076629639 - deformation = cov_off_diag
# statistic = 4.0147240922630045 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9526728747461222
# relative_error_metric = 1.9904906785750365
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3195899724960327 - deformation = cov_off_diag
# statistic = 2.0037712800378142 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9075338285316585
# relative_error_metric = 1.9809926244273668
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16357630491256714 - deformation = cov_off_diag
# statistic = 0.8535581602284698 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.8232398253713122
# relative_error_metric = 1.955663121821334
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08556947112083435 - deformation = cov_off_diag
# statistic = 0.33804481548192666 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.6751866802986886
# relative_error_metric = 1.8899109040455335
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04656605422496796 - deformation = cov_off_diag
# statistic = 0.1308246341916069 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.4411365128567948
# relative_error_metric = 1.7274178092600239
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.02706434577703476 - deformation = cov_off_diag
# statistic = 0.052937422630704334 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.1263879609816345
# relative_error_metric = 1.3877515545615347
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.01731349155306816 - deformation = cov_off_diag
# statistic = 0.024093111863764737 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.783952701817335
# relative_error_metric = 0.8630994674476834
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.012438064441084862 - deformation = cov_off_diag
# statistic = 0.01314211009744094 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.48752560465160677
# relative_error_metric = 0.3148542230941431
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.010000350885093212 - deformation = cov_off_diag
# statistic = 0.008680263148942982 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.2172803667777429
# relative_error_metric = 0.09719846811799916
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.011219207663089037 - deformation = cov_off_diag
# statistic = 0.010783711562877173 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.11488050283687329
# relative_error_metric = 0.11956710804755695
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.010609779274091125 - deformation = cov_off_diag
# statistic = 0.009890887410385556 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.059138722976607445
# relative_error_metric = 0.03328385090793259
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.010305065079592168 - deformation = cov_off_diag
# statistic = 0.009164110082515576 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.02913855722242497
# relative_error_metric = 0.04302552929243851
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.010457422176841646 - deformation = cov_off_diag
# statistic = 0.00941380163400753 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.014463914213221931
# relative_error_metric = 0.016149723148720038
# =======> statistic within required accuracy at 0.99 CL in 109.43902739800978 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 229.74903292197268 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_up deformation.
#
# ======================================================
# =============== fgd - power_abs_up ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_up
# statistic = 2501885.534083378 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999999918930573
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_up
# statistic = 6318.32344187976 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999967898720303
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_up
# statistic = 256.7705222331799 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999210102375728
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_up
# statistic = 29.71992033258105 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9993176568805564
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_up
# statistic = 5.230171411192186 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9961257487617492
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_up
# statistic = 1.1064801093081462 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9817528415023133
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_up
# statistic = 0.25581786206667567 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.922255517953383
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_up
# statistic = 0.06200337959978961 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6976081511113414
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_up
# statistic = 0.015552011869790106 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0164881422427183
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_up
# statistic = 0.0036540370502452747 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.32473874715391404
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00732421875 - deformation = power_abs_up
# statistic = 0.008618347473201535 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.5183263301800467
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.006103515625 - deformation = power_abs_up
# statistic = 0.005490399356914537 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.079487964638347
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0054931640625 - deformation = power_abs_up
# statistic = 0.004749353970032949 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.06543916856230036
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00579833984375 - deformation = power_abs_up
# statistic = 0.005207467785915476 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.026620997239224328
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.005645751953125 - deformation = power_abs_up
# statistic = 0.005239002532626676 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.0273972602739726
# relative_error_metric = 0.032657082530355555
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0055694580078125 - deformation = power_abs_up
# statistic = 0.004793456129464441 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.013605442176870748
# relative_error_metric = 0.05620465436941873
#
# ------------ 17 - 0.95 CL ------------
# eps = 0.00560760498046875 - deformation = power_abs_up
# statistic = 0.00462578772190699 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.006779661016949152
# relative_error_metric = 0.09175999819448002
#
# ------------ 18 - 0.95 CL ------------
# eps = 0.005626678466796875 - deformation = power_abs_up
# statistic = 0.005043598172621332 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.00338409475465313
# relative_error_metric = 0.005351375220388776
# =======> statistic within required accuracy at 0.95 CL in 120.76688485400518 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.0056362152099609375 - deformation = power_abs_up
# statistic = 0.004989806689559383 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9954961048165387
# relative_error_metric = 0.6288798199772209
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.5028181076049805 - deformation = power_abs_up
# statistic = 2538094.5385379507 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9910124491266221
# relative_error_metric = 1.9999999849224381
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2542271614074707 - deformation = power_abs_up
# statistic = 6447.351134249356 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9821053129583195
# relative_error_metric = 1.9999940645048515
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6299316883087158 - deformation = power_abs_up
# statistic = 264.23849658279426 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9645280060320396
# relative_error_metric = 1.9998551804783868
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.3177839517593384 - deformation = power_abs_up
# statistic = 31.10803058961552 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9302923467911517
# relative_error_metric = 1.9987702046094817
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.16171008348464966 - deformation = power_abs_up
# statistic = 5.671243223552283 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.8652801943293305
# relative_error_metric = 1.9932635880814817
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.0836731493473053 - deformation = power_abs_up
# statistic = 1.283907698878931 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.7475644244967423
# relative_error_metric = 1.970414360527516
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04465468227863312 - deformation = power_abs_up
# statistic = 0.33827942858532734 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.5517109066316244
# relative_error_metric = 1.8899851561785623
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.025145448744297028 - deformation = power_abs_up
# statistic = 0.10419426244082945 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.267587974667459
# relative_error_metric = 1.663609088444531
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.015390831977128983 - deformation = power_abs_up
# statistic = 0.03830030860928741 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.927816129423739
# relative_error_metric = 1.2005353197988116
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.01051352359354496 - deformation = power_abs_up
# statistic = 0.01756546302342253 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.6040108069766704
# relative_error_metric = 0.5895795730112089
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.008074869401752949 - deformation = power_abs_up
# statistic = 0.010441292788906768 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.3557200995913305
# relative_error_metric = 0.08738578731929336
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.006855542305856943 - deformation = power_abs_up
# statistic = 0.007572949312456505 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.1633346916045893
# relative_error_metric = 0.23268588510500726
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.007465205853804946 - deformation = power_abs_up
# statistic = 0.008825074205318327 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.0784633971099924
# relative_error_metric = 0.08068611753066675
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.007770037627778947 - deformation = power_abs_up
# statistic = 0.009675418281929943 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.04001665931266237
# relative_error_metric = 0.011261406697123699
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.007617621740791947 - deformation = power_abs_up
# statistic = 0.009035743216388833 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.01981014569354301
# relative_error_metric = 0.05712322451885953
#
# ------------ 17 - 0.99 CL ------------
# eps = 0.007693829684285447 - deformation = power_abs_up
# statistic = 0.009343902101912249 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.00985625936327654
# relative_error_metric = 0.02360190090779582
#
# ------------ 18 - 0.99 CL ------------
# eps = 0.007731933656032197 - deformation = power_abs_up
# statistic = 0.009239203034388691 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.0049160162987197005
# relative_error_metric = 0.034867782076493346
#
# ------------ 19 - 0.99 CL ------------
# eps = 0.007750985641905572 - deformation = power_abs_up
# statistic = 0.009559140088140681 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.0024549909554722727
# relative_error_metric = 0.0008291714168059956
# =======> statistic within required accuracy at 0.99 CL in 130.2134917699732 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 250.98041454795748 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with power_abs_down deformation.
#
# ======================================================
# =============== fgd - power_abs_down ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = power_abs_down
# statistic = 3557576.4967064783 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9999999942987472
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = power_abs_down
# statistic = 31.162630427970036 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.999349241606813
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = power_abs_down
# statistic = 19.47059183746153 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9989585646659425
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = power_abs_down
# statistic = 8.248153897540433 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9975424583523036
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = power_abs_down
# statistic = 2.749725099316019 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9926373332739524
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.078125 - deformation = power_abs_down
# statistic = 0.7980325310400659 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.97474466135027
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.0390625 - deformation = power_abs_down
# statistic = 0.21401577017656948 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9074217285287223
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.01953125 - deformation = power_abs_down
# statistic = 0.055465740030310004 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6649512886178952
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.009765625 - deformation = power_abs_down
# statistic = 0.013547529587073295 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9106007248347425
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.0048828125 - deformation = power_abs_down
# statistic = 0.0032326655386308877 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.4427129954962009
#
# ------------ 11 - 0.95 CL ------------
# eps = 0.00732421875 - deformation = power_abs_down
# statistic = 0.007583737700470401 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.3971863121557879
#
# ------------ 12 - 0.95 CL ------------
# eps = 0.006103515625 - deformation = power_abs_down
# statistic = 0.0048161460208507294 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.051485733360566235
#
# ------------ 13 - 0.95 CL ------------
# eps = 0.0067138671875 - deformation = power_abs_down
# statistic = 0.006143826581552432 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.19138918756680867
#
# ------------ 14 - 0.95 CL ------------
# eps = 0.00640869140625 - deformation = power_abs_down
# statistic = 0.0055093973627182566 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.04878048780487805
# relative_error_metric = 0.08293651835481668
#
# ------------ 15 - 0.95 CL ------------
# eps = 0.006256103515625 - deformation = power_abs_down
# statistic = 0.0053592380267404715 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.024691358024691357
# relative_error_metric = 0.05533654015347878
#
# ------------ 16 - 0.95 CL ------------
# eps = 0.0061798095703125 - deformation = power_abs_down
# statistic = 0.005143768272482816 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.012422360248447204
# relative_error_metric = 0.014314554875019094
# =======> statistic within required accuracy at 0.95 CL in 108.23610169399763 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.00614166259765625 - deformation = power_abs_down
# statistic = 0.005093441357720903 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9950926977208476
# relative_error_metric = 0.6102963552087534
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.503070831298828 - deformation = power_abs_down
# statistic = 3740186.1146454536 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9902094181140968
# relative_error_metric = 1.9999999897683494
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.2546062469482422 - deformation = power_abs_down
# statistic = 31.178583545887598 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.980514224767207
# relative_error_metric = 1.9987729866179913
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.6303739547729492 - deformation = power_abs_down
# statistic = 19.63843769267498 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9614044813352611
# relative_error_metric = 1.9980523071615484
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.31825780868530273 - deformation = power_abs_down
# statistic = 8.46510770570407 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.9242703747528718
# relative_error_metric = 1.9954843956635344
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.1621997356414795 - deformation = power_abs_down
# statistic = 2.9308355493775813 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.8540664943525829
# relative_error_metric = 1.9869853611478194
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.08417069911956787 - deformation = power_abs_down
# statistic = 0.9164880012267249 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.7279813092747445
# relative_error_metric = 1.958676023302267
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04515618085861206 - deformation = power_abs_down
# statistic = 0.2835235063096616 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.5210977940706571
# relative_error_metric = 1.8694319049525003
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.025648921728134155 - deformation = power_abs_down
# statistic = 0.09413253505030392 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 1.2272350159133414
# relative_error_metric = 1.6309698738395095
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.015895292162895203 - deformation = power_abs_down
# statistic = 0.03644349938173052 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.8852066604682614
# relative_error_metric = 1.1682720066068712
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.011018477380275726 - deformation = power_abs_down
# statistic = 0.01751098588565931 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.5683886948347838
# relative_error_metric = 0.5867420107603907
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.008580069988965988 - deformation = power_abs_down
# statistic = 0.010190682892243758 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.331266361070237
# relative_error_metric = 0.06312594036513616
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.007360866293311119 - deformation = power_abs_down
# statistic = 0.007405699153180854 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.15296513003572587
# relative_error_metric = 0.2546868371369252
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.007970468141138554 - deformation = power_abs_down
# statistic = 0.008582559979406646 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.07366550175412138
# relative_error_metric = 0.108488116606306
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.008275269065052271 - deformation = power_abs_down
# statistic = 0.009526487924300255 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.036166691507882036
# relative_error_metric = 0.004250817804048381
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.00842766952700913 - deformation = power_abs_down
# statistic = 0.009755574563978771 - next threshold = 0.00956706954130897 at 0.99 CL
# relative_error_eps = 0.01824834128639996
# relative_error_metric = 0.019511307214752763
# =======> statistic within required accuracy at 0.99 CL in 108.83298957999796 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 217.06912781798746 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# Computing exclusion limits for fgd with random_normal deformation.
#
# ======================================================
# =============== fgd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 12.99285565094463 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.998439547771435
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 1.8681608333580324 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.989172377710165
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 0.20250809980038356 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9022894104189054
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 0.015973235878043456 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0361745536435518
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.15625 - deformation = random_normal
# statistic = 0.0011892487089399627 - next threshold = 0.0050706607699602954 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.240085683060778
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.234375 - deformation = random_normal
# ...
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.04614025354385376 - deformation = power_abs_down
# statistic = 7.507624633122866 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 1.4643902056982383
# relative_error_metric = 1.1777096432306968
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.026636868715286255 - deformation = power_abs_down
# statistic = 4.5035034368705436 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 1.1550595907849392
# relative_error_metric = 0.7945001229253799
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.016885176301002502 - deformation = power_abs_down
# statistic = 2.9958498655263828 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.8120096906378635
# relative_error_metric = 0.4264845291070156
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.012009330093860626 - deformation = power_abs_down
# statistic = 2.2588555670279806 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.5094179165182803
# relative_error_metric = 0.15047668222537555
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.009571406990289688 - deformation = power_abs_down
# statistic = 1.9055747842204247 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.22593511000710337
# relative_error_metric = 0.019312421001062466
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.010790368542075157 - deformation = power_abs_down
# statistic = 2.080138456552546 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.11973037909665014
# relative_error_metric = 0.06831116616598806
#
# ------------ 14 - 0.99 CL ------------
# eps = 0.010180887766182423 - deformation = power_abs_down
# statistic = 1.992239011645812 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.06171240186591786
# relative_error_metric = 0.02516110183703295
#
# ------------ 15 - 0.99 CL ------------
# eps = 0.009876147378236055 - deformation = power_abs_down
# statistic = 1.9487322675438545 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.03133971317643563
# relative_error_metric = 0.003082331158364265
#
# ------------ 16 - 0.99 CL ------------
# eps = 0.009723777184262872 - deformation = power_abs_down
# statistic = 1.9271091419142936 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.015548038818957263
# relative_error_metric = 0.008075638378975092
# =======> statistic within required accuracy at 0.99 CL in 105.31822660902981 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 213.93709392903838 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_normal deformation.
#
# ======================================================
# =============== swd - random_normal ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_normal
# statistic = 46.01835661554518 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8671822307492638
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_normal
# statistic = 14.61974099577638 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6097603924568553
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_normal
# statistic = 4.253972244726994 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9164434943549821
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_normal
# statistic = 1.5659358746632654 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.009253277095711901
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_normal
# statistic = 2.6084800363839347 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.490806074621264
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.390625 - deformation = random_normal
# statistic = 2.017794961830704 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.24306096079791223
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.3515625 - deformation = random_normal
# statistic = 1.7790422581468859 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.11820026415520923
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.33203125 - deformation = random_normal
# statistic = 1.6552380812591567 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.04619964283276612
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.322265625 - deformation = random_normal
# statistic = 1.6138419384725522 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.03076923076923077
# relative_error_metric = 0.020879883505798048
#
# ------------ 10 - 0.95 CL ------------
# eps = 0.3173828125 - deformation = random_normal
# statistic = 1.6049552007712817 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.015503875968992248
# relative_error_metric = 0.015358550624877062
# =======> statistic within required accuracy at 0.95 CL in 68.59214520896785 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.31494140625 - deformation = random_normal
# statistic = 1.5743904850841126 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 1.7629765732659624
# relative_error_metric = 0.20945763930433114
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.657470703125 - deformation = random_normal
# statistic = 50.5983173467526 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 1.5761806981519506
# relative_error_metric = 1.8520977566848522
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.4862060546875 - deformation = random_normal
# statistic = 19.726643514546947 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 1.3005760759064724
# relative_error_metric = 1.6413861371286218
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.90057373046875 - deformation = random_normal
# statistic = 8.133705485118249 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.9635952799397439
# relative_error_metric = 1.2288011228495779
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.607757568359375 - deformation = random_normal
# statistic = 4.017172883255547 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.6346948900281131
# relative_error_metric = 0.696130912084736
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.4613494873046875 - deformation = random_normal
# statistic = 2.559197257170488 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.3771990171990172
# relative_error_metric = 0.27386569459580024
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.38814544677734375 - deformation = random_normal
# statistic = 2.0090160052871524 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.20823612392165375
# relative_error_metric = 0.033545198067584055
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.3515434265136719 - deformation = random_normal
# statistic = 1.7596758989610293 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.09896598849952296
# relative_error_metric = 0.0988863660367041
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.3698444366455078 - deformation = random_normal
# statistic = 1.8940916393823373 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.04828827015261509
# relative_error_metric = 0.025355972079769758
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.3789949417114258 - deformation = random_normal
# statistic = 1.902797481704078 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.023856142117465704
# relative_error_metric = 0.02077079943915968
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.38357019424438477 - deformation = random_normal
# statistic = 1.956103981615364 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.011999637322061137
# relative_error_metric = 0.006857995306198751
# =======> statistic within required accuracy at 0.99 CL in 75.54622590902727 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 144.13840651098872 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# Computing exclusion limits for swd with random_uniform deformation.
#
# ======================================================
# =============== swd - random_uniform ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 2.5 - deformation = random_uniform
# statistic = 19.140076083501224 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6948938538462295
#
# ------------ 2 - 0.95 CL ------------
# eps = 1.25 - deformation = random_uniform
# statistic = 5.524610573949245 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1102208773682274
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.625 - deformation = random_uniform
# statistic = 1.830549216344566 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.14661555973138807
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.3125 - deformation = random_uniform
# statistic = 1.1377380310972443 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.325767152005026
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.46875 - deformation = random_uniform
# statistic = 1.384900285265087 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.131917046710921
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.546875 - deformation = random_uniform
# statistic = 1.560867071395252 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.012495346927429252
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.5859375 - deformation = random_uniform
# statistic = 1.7005940646492375 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.07320792625948067
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.56640625 - deformation = random_uniform
# statistic = 1.6492101157190933 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.03508771929824561
# relative_error_metric = 0.04255304132271884
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.556640625 - deformation = random_uniform
# statistic = 1.591402651052966 - next threshold = 1.5804932650089702 at 0.95 CL
# relative_error_eps = 0.017699115044247787
# relative_error_metric = 0.006878779337463414
# =======> statistic within required accuracy at 0.95 CL in 60.7902537000482 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.5517578125 - deformation = random_uniform
# statistic = 1.5901917163347734 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 1.6024626209322779
# relative_error_metric = 0.1995757042510674
#
# ------------ 2 - 0.99 CL ------------
# eps = 2.77587890625 - deformation = random_uniform
# statistic = 22.924842253316477 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 1.3367571533382245
# relative_error_metric = 1.687507172489056
#
# ------------ 3 - 0.99 CL ------------
# eps = 1.663818359375 - deformation = random_uniform
# statistic = 9.334116780015721 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 1.0038567493112949
# relative_error_metric = 1.3108945892960047
#
# ------------ 4 - 0.99 CL ------------
# eps = 1.1077880859375 - deformation = random_uniform
# statistic = 4.385607328452114 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.6700993012136816
# relative_error_metric = 0.7720418329504306
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.82977294921875 - deformation = random_uniform
# statistic = 2.743527265743412 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.40247404462116193
# relative_error_metric = 0.3417616726563912
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.690765380859375 - deformation = random_uniform
# statistic = 2.0757999200175097 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.22375046051823652
# relative_error_metric = 0.06622565415403327
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.6212615966796875 - deformation = random_uniform
# statistic = 1.8109507274912802 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.10594871198464849
# relative_error_metric = 0.07021586722668552
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.6560134887695312 - deformation = random_uniform
# statistic = 1.9523739257392232 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.05441567362542186
# relative_error_metric = 0.004949311510186105
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.6386375427246094 - deformation = random_uniform
# statistic = 1.8815938577628475 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.026842671302503056
# relative_error_metric = 0.031974769371322785
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.6473255157470703 - deformation = random_uniform
# statistic = 1.901490859297536 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.01333186990085245
# relative_error_metric = 0.021457643706213607
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.6516695022583008 - deformation = random_uniform
# statistic = 1.9097967288177677 - next threshold = 1.9427348723353544 at 0.99 CL
# relative_error_eps = 0.006643791409745443
# relative_error_metric = 0.017099479992702837
# =======> statistic within required accuracy at 0.99 CL in 84.1986585650011 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 144.9889472160139 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T19:49:52.710073', 'fgd_cov_diag_2024-05-02T19:52:59.036853', 'fgd_cov_off_diag_2024-05-02T19:56:17.641156', 'fgd_power_abs_up_2024-05-02T20:00:07.392836', 'fgd_power_abs_down_2024-05-02T20:04:18.376374', 'fgd_random_normal_2024-05-02T20:07:55.449606', 'fgd_random_uniform_2024-05-02T20:11:01.023840', 'mmd_mean_2024-05-02T20:13:48.662192', 'mmd_cov_diag_2024-05-02T20:17:46.859468', 'mmd_cov_off_diag_2024-05-02T20:22:22.268616', 'mmd_power_abs_up_2024-05-02T20:26:29.136769', 'mmd_power_abs_down_2024-05-02T20:31:45.319527', 'mmd_random_normal_2024-05-02T20:36:55.729769', 'mmd_random_uniform_2024-05-02T20:41:50.839387', 'ks_mean_2024-05-02T20:45:35.666367', 'ks_cov_diag_2024-05-02T20:48:22.569800', 'ks_cov_off_diag_2024-05-02T20:51:34.022991', 'ks_power_abs_up_2024-05-02T20:53:59.390373', 'ks_power_abs_down_2024-05-02T20:57:25.333144', 'ks_random_normal_2024-05-02T21:00:59.557989', 'ks_random_uniform_2024-05-02T21:03:26.918823', 'sks_mean_2024-05-02T21:06:08.545837', 'sks_cov_diag_2024-05-02T21:10:03.264135', 'sks_cov_off_diag_2024-05-02T21:14:33.854194', 'sks_power_abs_up_2024-05-02T21:19:14.055005', 'sks_power_abs_down_2024-05-02T21:24:24.774866', 'sks_random_normal_2024-05-02T21:29:24.292777', 'sks_random_uniform_2024-05-02T21:32:48.853817', 'swd_mean_2024-05-02T21:36:01.704663', 'swd_cov_diag_2024-05-02T21:38:45.396524', 'swd_cov_off_diag_2024-05-02T21:42:12.506023', 'swd_power_abs_up_2024-05-02T21:45:22.506047', 'swd_power_abs_down_2024-05-02T21:49:03.998713', 'swd_random_normal_2024-05-02T21:52:37.944691', 'swd_random_uniform_2024-05-02T21:55:02.091876'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down"]#, "random_normal", "random_uniform"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(dist_1,
                                                metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.1,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - mean ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.05 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.804058699985035 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.050000.json
# ThresholdS: [[0.95, [9500, 500], -1.0727907629668463], [0.99, [9900, 100], 2.7046193987504368]]
# Null distribution computed in 18.98355518595781 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.43474812299246 seconds.
# statistic = 9.868785148293972 - next threshold = -1.0727907629668463 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 2.487854228172952
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.025 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.451400413003284 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.025000.json
# ThresholdS: [[0.95, [9500, 500], 1.9754987261435466], [0.99, [9900, 100], 3.8642038070433475]]
# Null distribution computed in 18.620874928019475 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.430109441978857 seconds.
# statistic = 2.4224984665241314 - next threshold = 1.9754987261435466 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.20327422724408323
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.0125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# WARNING:tensorflow:5 out of the last 13 calls to <function LRMetric.Test_tf.<locals>.get_logprobs at 0x7f8df9ccbd80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function LRMetric.Test_tf.<locals>.batched_test_sub at 0x7f8df9ccaac0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.40863016998628 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.012500.json
# ThresholdS: [[0.95, [9500, 500], 1.615722889916777], [0.99, [9900, 100], 2.5600754304489954]]
# Null distribution computed in 18.5833649780252 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.362011844990775 seconds.
# statistic = 0.5832757063306276 - next threshold = 1.615722889916777 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.9390157732233412
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.018750000000000003 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# WARNING:tensorflow:5 out of the last 13 calls to <function LRMetric.Test_tf.<locals>.get_logprobs at 0x7f8e089c23e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function LRMetric.Test_tf.<locals>.batched_test_sub at 0x7f8e089c3f60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.461247080005705 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.018750.json
# ThresholdS: [[0.95, [9500, 500], 1.9526041897414126], [0.99, [9900, 100], 3.3691330004985818]]
# Null distribution computed in 18.6324015930295 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.3690665530157275 seconds.
# statistic = 1.3458937046873172 - next threshold = 1.9526041897414126 at 0.95 CL
# relative_error_eps = 0.28571428571428564
# relative_error_metric = 0.36787077298357485
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.021875000000000002 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.46223987301346 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.021875.json
# ThresholdS: [[0.95, [9500, 500], 2.0032998033908718], [0.99, [9900, 100], 3.6559167491370386]]
# Null distribution computed in 18.633041510009207 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.432892364042345 seconds.
# statistic = 1.844947740177912 - next threshold = 2.0032998033908718 at 0.95 CL
# relative_error_eps = 0.1333333333333333
# relative_error_metric = 0.08229827287363507
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.0234375 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.413702878984623 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.023438.json
# ThresholdS: [[0.95, [9500, 500], 1.9992113511498866], [0.99, [9900, 100], 3.7698723644728704]]
# Null distribution computed in 18.584917171043344 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.334403768996708 seconds.
# statistic = 2.1239110169889233 - next threshold = 1.9992113511498866 at 0.95 CL
# relative_error_eps = 0.06896551724137921
# relative_error_metric = 0.060487977171207026
#
# ------------ 7 - 0.95 CL ------------
# eps = 0.022656250000000003 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.342566348030232 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.022656.json
# ThresholdS: [[0.95, [9500, 500], 2.0037085988454693], [0.99, [9900, 100], 3.7153475785035215]]
# Null distribution computed in 18.51657510799123 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.36117321101483 seconds.
# statistic = 1.9819763570083277 - next threshold = 2.0037085988454693 at 0.95 CL
# relative_error_eps = 0.03389830508474564
# relative_error_metric = 0.01090514783674673
#
# ------------ 8 - 0.95 CL ------------
# eps = 0.023046875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.4229882779764 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.023047.json
# ThresholdS: [[0.95, [9500, 500], 2.002073230329712], [0.99, [9900, 100], 3.743223226861389]]
# Null distribution computed in 18.599275666987523 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.298559315036982 seconds.
# statistic = 2.052330431580158 - next threshold = 2.002073230329712 at 0.95 CL
# relative_error_eps = 0.017094017094017033
# relative_error_metric = 0.024791414689464678
#
# ------------ 9 - 0.95 CL ------------
# eps = 0.022851562500000002 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.453426907013636 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.022852.json
# ThresholdS: [[0.95, [9500, 500], 2.0030442284411785], [0.99, [9900, 100], 3.729438716453725]]
# Null distribution computed in 18.628038475988433 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.302856226975564 seconds.
# statistic = 2.017000080440654 - next threshold = 2.0030442284411785 at 0.95 CL
# relative_error_eps = 0.008583690987124432
# relative_error_metric = 0.006943133422008162
# =======> statistic within required accuracy at 0.95 CL in 278.32287038699724 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL ------------
# eps = 0.022753906250000004 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.371490626013838 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.022754.json
# ThresholdS: [[0.95, [9500, 500], 2.0034147421273003], [0.99, [9900, 100], 3.7224314759214407]]
# Null distribution computed in 18.544288260978647 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.31295555800898 seconds.
# statistic = 1.9994498902528623 - next threshold = 3.7224314759214407 at 0.99 CL
# relative_error_eps = 1.2585521081941127
# relative_error_metric = 0.6022430300125492
#
# ------------ 2 - 0.99 CL ------------
# eps = 0.061376953125 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.34310205798829 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.061377.json
# ThresholdS: [[0.95, [9500, 500], -4.123312161818463], [0.99, [9900, 100], 0.5136063668782079]]
# Null distribution computed in 18.516706772963516 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.258751477987971 seconds.
# statistic = 14.920738863282162 - next threshold = 0.5136063668782079 at 0.99 CL
# relative_error_eps = 0.9181659895531049
# relative_error_metric = 1.8668926062701863
#
# ------------ 3 - 0.99 CL ------------
# eps = 0.0420654296875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.414304155972786 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.042065.json
# ThresholdS: [[0.95, [9500, 500], 0.4388882053231508], [0.99, [9900, 100], 3.616855836568557]]
# Null distribution computed in 18.5876323049888 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.275286803022027 seconds.
# statistic = 6.961257461602896 - next threshold = 3.616855836568557 at 0.99 CL
# relative_error_eps = 0.5958568738229755
# relative_error_metric = 0.6323247881287974
#
# ------------ 4 - 0.99 CL ------------
# eps = 0.03240966796875 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.54808035795577 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.032410.json
# ThresholdS: [[0.95, [9500, 500], 1.5958607025379883], [0.99, [9900, 100], 4.044352884975443]]
# Null distribution computed in 18.722341546963435 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.281000554969069 seconds.
# statistic = 4.1056444471110005 - next threshold = 4.044352884975443 at 0.99 CL
# relative_error_eps = 0.35007745076344304
# relative_error_metric = 0.01504087906734724
#
# ------------ 5 - 0.99 CL ------------
# eps = 0.027581787109375002 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.405156550987158 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.027582.json
# ThresholdS: [[0.95, [9500, 500], 1.8933150295152554], [0.99, [9900, 100], 3.977069487672212]]
# Null distribution computed in 18.573811971000396 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.234129294985905 seconds.
# statistic = 2.9588698614952036 - next threshold = 3.977069487672212 at 0.99 CL
# relative_error_eps = 0.16095228405738113
# relative_error_metric = 0.29360107547631087
#
# ------------ 6 - 0.99 CL ------------
# eps = 0.029995727539062503 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.2921498020296 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.029996.json
# ThresholdS: [[0.95, [9500, 500], 1.768007192801695], [0.99, [9900, 100], 4.034130513098901]]
# Null distribution computed in 18.46047756401822 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.19241044903174 seconds.
# statistic = 3.508837827523913 - next threshold = 4.034130513098901 at 0.99 CL
# relative_error_eps = 0.07736319624431504
# relative_error_metric = 0.13928009819317771
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.03120269775390625 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.301144497992937 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.031203.json
# ThresholdS: [[0.95, [9500, 500], 1.6877887793533202], [0.99, [9900, 100], 4.045096530802969]]
# Null distribution computed in 18.468289552023634 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.230328811972868 seconds.
# statistic = 3.8013863056298627 - next threshold = 4.045096530802969 at 0.99 CL
# relative_error_eps = 0.0379476600542109
# relative_error_metric = 0.06211960957628287
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.03180618286132812 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.27132487099152 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.031806.json
# ThresholdS: [[0.95, [9500, 500], 1.6432884488459445], [0.99, [9900, 100], 4.046188415789496]]
# Null distribution computed in 18.44514888804406 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.268450520001352 seconds.
# statistic = 3.9520516684454456 - next threshold = 4.046188415789496 at 0.99 CL
# relative_error_eps = 0.018795518540080165
# relative_error_metric = 0.023539365248512644
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.03210792541503906 - deformation = mean
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.38919081701897 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_mean_0.032108.json
# ThresholdS: [[0.95, [9500, 500], 1.619940502656749], [0.99, [9900, 100], 4.045636577388412]]
# Null distribution computed in 18.565176243020687 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.259845439984929 seconds.
# statistic = 4.02848213081344 - next threshold = 4.045636577388412 at 0.99 CL
# relative_error_eps = 0.009353806857487523
# relative_error_metric = 0.0042492430926351155
# =======> statistic within required accuracy at 0.99 CL in 275.36375348397996 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 553.686662766966 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# Computing exclusion limits for lr with cov_diag deformation.
#
# ======================================================
# =============== lr - cov_diag ===============
# ======================================================
#
# ------------ 1 - 0.95 CL ------------
# eps = 0.05 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.463892224011943 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_cov_diag_0.050000.json
# ThresholdS: [[0.95, [9500, 500], -186.91193358948297], [0.99, [9900, 100], -168.14579684931797]]
# Null distribution computed in 18.649301291035954 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.578600078006275 seconds.
# statistic = 252.14301718772813 - next threshold = -186.91193358948297 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 13.461525596641247
#
# ------------ 2 - 0.95 CL ------------
# eps = 0.025 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.379481537034735 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_cov_diag_0.025000.json
# ThresholdS: [[0.95, [9500, 500], -38.33653518575916], [0.99, [9900, 100], -28.50414668344068]]
# Null distribution computed in 18.559767797996756 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.5087705359910615 seconds.
# statistic = 64.25363179487917 - next threshold = -38.33653518575916 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 7.916794734217081
#
# ------------ 3 - 0.95 CL ------------
# eps = 0.0125 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.291301184974145 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_cov_diag_0.012500.json
# ThresholdS: [[0.95, [9500, 500], -4.374724359398287], [0.99, [9900, 100], 0.6145310227195281]]
# Null distribution computed in 18.474168700980954 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.484085834992584 seconds.
# statistic = 16.61303856859684 - next threshold = -4.374724359398287 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 3.429845413222079
#
# ------------ 4 - 0.95 CL ------------
# eps = 0.00625 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.225777880987152 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_cov_diag_0.006250.json
# ThresholdS: [[0.95, [9500, 500], 1.6372316711963704], [0.99, [9900, 100], 4.134605072537533]]
# Null distribution computed in 18.404960345011204 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.549797345011029 seconds.
# statistic = 4.420461844188327 - next threshold = 1.6372316711963704 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9189075564563969
#
# ------------ 5 - 0.95 CL ------------
# eps = 0.003125 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.308169409050606 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_cov_diag_0.003125.json
# ThresholdS: [[0.95, [9500, 500], 1.7927519169137236], [0.99, [9900, 100], 3.045053313811746]]
# Null distribution computed in 18.491378356004134 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.514664237969555 seconds.
# statistic = 1.2377520394644796 - next threshold = 1.7927519169137236 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.3662756329891296
#
# ------------ 6 - 0.95 CL ------------
# eps = 0.004687500000000001 - deformation = cov_diag
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.257894435024355 seconds.
# ...
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.202121886017267 seconds.
# statistic = 15.599306008263286 - next threshold = -1.8010997138601517 at 0.99 CL
# relative_error_eps = 0.8799452242382746
# relative_error_metric = 2.522125753284532
#
# ------------ 7 - 0.99 CL ------------
# eps = 0.0034821033477783207 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.49674957001116 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_power_abs_down_0.003482.json
# ThresholdS: [[0.95, [9500, 500], -0.3882117479102482], [0.99, [9900, 100], 2.563001635680134]]
# Null distribution computed in 18.659709585015662 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.198079690977465 seconds.
# statistic = 7.114995488178352 - next threshold = 2.563001635680134 at 0.99 CL
# relative_error_eps = 0.5640575486521363
# relative_error_metric = 0.9406892344029547
#
# ------------ 8 - 0.99 CL ------------
# eps = 0.0027160882949829102 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.500416882976424 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_power_abs_down_0.002716.json
# ThresholdS: [[0.95, [9500, 500], 1.1718223893206687], [0.99, [9900, 100], 3.4742788259610786]]
# Null distribution computed in 18.6779130930081 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.194690619013272 seconds.
# statistic = 4.094316295839616 - next threshold = 3.4742788259610786 at 0.99 CL
# relative_error_eps = 0.32832770434258335
# relative_error_metric = 0.16384479811651498
#
# ------------ 9 - 0.99 CL ------------
# eps = 0.002333080768585205 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.511682781972922 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_power_abs_down_0.002333.json
# ThresholdS: [[0.95, [9500, 500], 1.6366931462603314], [0.99, [9900, 100], 3.61654205212894]]
# Null distribution computed in 18.674729249964003 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.194013433007058 seconds.
# statistic = 2.8908711333169808 - next threshold = 3.61654205212894 at 0.99 CL
# relative_error_eps = 0.15171111189810066
# relative_error_metric = 0.2230289972780429
#
# ------------ 10 - 0.99 CL ------------
# eps = 0.0025245845317840576 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.432165319973137 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_power_abs_down_0.002525.json
# ThresholdS: [[0.95, [9500, 500], 1.4303130016061099], [0.99, [9900, 100], 3.5715533364533654]]
# Null distribution computed in 18.59384643501835 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.206418634974398 seconds.
# statistic = 3.46709610684392 - next threshold = 3.5715533364533654 at 0.99 CL
# relative_error_eps = 0.07308365529736514
# relative_error_metric = 0.029681043345301715
#
# ------------ 11 - 0.99 CL ------------
# eps = 0.0026203364133834837 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.470961472019553 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_power_abs_down_0.002620.json
# ThresholdS: [[0.95, [9500, 500], 1.3075952543574878], [0.99, [9900, 100], 3.5294409743543116]]
# Null distribution computed in 18.633827917976305 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.23431502195308 seconds.
# statistic = 3.774313302217236 - next threshold = 3.5294409743543116 at 0.99 CL
# relative_error_eps = 0.03722190588345687
# relative_error_metric = 0.06705382426361413
#
# ------------ 12 - 0.99 CL ------------
# eps = 0.0025724604725837707 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.489268647041172 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_power_abs_down_0.002572.json
# ThresholdS: [[0.95, [9500, 500], 1.3705851752519718], [0.99, [9900, 100], 3.552133646943777]]
# Null distribution computed in 18.658547692000866 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.2415099729551 seconds.
# statistic = 3.6191061143261836 - next threshold = 3.552133646943777 at 0.99 CL
# relative_error_eps = 0.01878576342123193
# relative_error_metric = 0.01867807230323203
#
# ------------ 13 - 0.99 CL ------------
# eps = 0.0025485225021839144 - deformation = power_abs_down
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# LR metric calculation completed in 18.49318739096634 seconds.
# Saving lr to results/5D_unimodal/5D_20K/null_hypothesis/LR_power_abs_down_0.002549.json
# ThresholdS: [[0.95, [9500, 500], 1.400893934750275], [0.99, [9900, 100], 3.562264599754039]]
# Null distribution computed in 18.65969059302006 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 6.23957168799825 seconds.
# statistic = 3.542606766655075 - next threshold = 3.562264599754039 at 0.99 CL
# relative_error_eps = 0.009348974803393976
# relative_error_metric = 0.005533621112946165
# =======> statistic within required accuracy at 0.99 CL in 398.440880309965 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 825.1019793140003 seconds.
# Saving results in the file results/5D_unimodal/5D_20K/exclusion_limits.json
# dict_keys(['fgd_mean_2024-05-02T19:49:52.710073', 'fgd_cov_diag_2024-05-02T19:52:59.036853', 'fgd_cov_off_diag_2024-05-02T19:56:17.641156', 'fgd_power_abs_up_2024-05-02T20:00:07.392836', 'fgd_power_abs_down_2024-05-02T20:04:18.376374', 'fgd_random_normal_2024-05-02T20:07:55.449606', 'fgd_random_uniform_2024-05-02T20:11:01.023840', 'mmd_mean_2024-05-02T20:13:48.662192', 'mmd_cov_diag_2024-05-02T20:17:46.859468', 'mmd_cov_off_diag_2024-05-02T20:22:22.268616', 'mmd_power_abs_up_2024-05-02T20:26:29.136769', 'mmd_power_abs_down_2024-05-02T20:31:45.319527', 'mmd_random_normal_2024-05-02T20:36:55.729769', 'mmd_random_uniform_2024-05-02T20:41:50.839387', 'ks_mean_2024-05-02T20:45:35.666367', 'ks_cov_diag_2024-05-02T20:48:22.569800', 'ks_cov_off_diag_2024-05-02T20:51:34.022991', 'ks_power_abs_up_2024-05-02T20:53:59.390373', 'ks_power_abs_down_2024-05-02T20:57:25.333144', 'ks_random_normal_2024-05-02T21:00:59.557989', 'ks_random_uniform_2024-05-02T21:03:26.918823', 'sks_mean_2024-05-02T21:06:08.545837', 'sks_cov_diag_2024-05-02T21:10:03.264135', 'sks_cov_off_diag_2024-05-02T21:14:33.854194', 'sks_power_abs_up_2024-05-02T21:19:14.055005', 'sks_power_abs_down_2024-05-02T21:24:24.774866', 'sks_random_normal_2024-05-02T21:29:24.292777', 'sks_random_uniform_2024-05-02T21:32:48.853817', 'swd_mean_2024-05-02T21:36:01.704663', 'swd_cov_diag_2024-05-02T21:38:45.396524', 'swd_cov_off_diag_2024-05-02T21:42:12.506023', 'swd_power_abs_up_2024-05-02T21:45:22.506047', 'swd_power_abs_down_2024-05-02T21:49:03.998713', 'swd_random_normal_2024-05-02T21:52:37.944691', 'swd_random_uniform_2024-05-02T21:55:02.091876', 'lr_mean_2024-05-02T21:57:27.110052', 'lr_cov_diag_2024-05-02T22:06:40.807204', 'lr_cov_off_diag_2024-05-02T22:19:08.420603', 'lr_power_abs_up_2024-05-02T22:36:54.597811', 'lr_power_abs_down_2024-05-02T22:50:36.758682'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 35        lr        mean    5  10000                20000
# 0        fgd        mean    5  10000                20000
# 28       swd        mean    5  10000                20000
# 14        ks        mean    5  10000                20000
# 21       sks        mean    5  10000                20000
# 7        mmd        mean    5  10000                20000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 35                             0.02275                             0.03226
# 0                              0.05875                             0.08438
# 28                             0.06531                             0.08880
# 14                             0.06653                             0.08520
# 21                             0.07019                             0.09366
# 7                              0.09247                             0.12182
#
#     $t^{\mu}$ (s)
# 35            553
# 0             186
# 28            163
# 14            166
# 21            234
# 7             238
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 35        lr                             0.02275
# 0        fgd                             0.05875
# 28       swd                             0.06531
# 14        ks                             0.06653
# 21       sks                             0.07019
# 7        mmd                             0.09247
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 35                             0.03226            553
# 0                              0.08438            186
# 28                             0.08880            163
# 14                             0.08520            166
# 21                             0.09366            234
# 7                              0.12182            238

# %%
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_diag)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 36        lr    cov_diag    5  10000                20000
# 1        fgd    cov_diag    5  10000                20000
# 29       swd    cov_diag    5  10000                20000
# 8        mmd    cov_diag    5  10000                20000
# 22       sks    cov_diag    5  10000                20000
# 15        ks    cov_diag    5  10000                20000
#
#     $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36                                     0.00402
# 1                                      0.02304
# 29                                     0.02640
# 8                                      0.02670
# 22                                     0.03510
# 15                                     0.04364
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00601                    747
# 1                                      0.03048                    198
# 29                                     0.03642                    207
# 8                                      0.03505                    275
# 22                                     0.04752                    270
# 15                                     0.05907                    191
#    Statistic  $\epsilon^{\sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 36        lr                                     0.00402
# 1        fgd                                     0.02304
# 29       swd                                     0.02640
# 8        mmd                                     0.02670
# 22       sks                                     0.03510
# 15        ks                                     0.04364
#
#     $\epsilon^{\sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\sigma_{ii}}$ (s)
# 36                                     0.00601                    747
# 1                                      0.03048                    198
# 29                                     0.03642                    207
# 8                                      0.03505                    275
# 22                                     0.04752                    270
# 15                                     0.05907                    191

# %%
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 37        lr  cov_off_diag    5  10000                20000
# 2        fgd  cov_off_diag    5  10000                20000
# 23       sks  cov_off_diag    5  10000                20000
# 30       swd  cov_off_diag    5  10000                20000
# 9        mmd  cov_off_diag    5  10000                20000
# 16        ks  cov_off_diag    5  10000                20000
#
#     $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37                                          0.00036
# 2                                           0.00756
# 23                                          0.02121
# 30                                          0.02365
# 9                                           0.04669
# 16                                          1.02295
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00056
# 2                                           0.01053
# 23                                          0.03185
# 30                                          0.03550
# 9                                           0.06181
# 16                                          1.02683
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        1066
# 2                          229
# 23                         280
# 30                         189
# 9                          246
# 16                         145
#    Statistic  $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 37        lr                                          0.00036
# 2        fgd                                          0.00756
# 23       sks                                          0.02121
# 30       swd                                          0.02365
# 9        mmd                                          0.04669
# 16        ks                                          1.02295
#
#     $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 37                                          0.00056
# 2                                           0.01053
# 23                                          0.03185
# 30                                          0.03550
# 9                                           0.06181
# 16                                          1.02683
#
#     $t^{\Sigma_{i\neq j}}$ (s)
# 37                        1066
# 2                          229
# 23                         280
# 30                         189
# 9                          246
# 16                         145

# %%
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 38        lr  power_abs_up    5  10000                20000
# 10       mmd  power_abs_up    5  10000                20000
# 3        fgd  power_abs_up    5  10000                20000
# 31       swd  power_abs_up    5  10000                20000
# 24       sks  power_abs_up    5  10000                20000
# 17        ks  power_abs_up    5  10000                20000
#
#     $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38                                      0.00140
# 10                                      0.00502
# 3                                       0.00564
# 31                                      0.00637
# 24                                      0.00721
# 17                                      0.00938
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00207                     822
# 10                                      0.00658                     316
# 3                                       0.00776                     250
# 31                                      0.00889                     221
# 24                                      0.00957                     310
# 17                                      0.01205                     205
#    Statistic  $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 38        lr                                      0.00140
# 10       mmd                                      0.00502
# 3        fgd                                      0.00564
# 31       swd                                      0.00637
# 24       sks                                      0.00721
# 17        ks                                      0.00938
#
#     $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 38                                      0.00207                     822
# 10                                      0.00658                     316
# 3                                       0.00776                     250
# 31                                      0.00889                     221
# 24                                      0.00957                     310
# 17                                      0.01205                     205

# %%
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 39        lr  power_abs_down    5  10000                20000
# 11       mmd  power_abs_down    5  10000                20000
# 4        fgd  power_abs_down    5  10000                20000
# 32       swd  power_abs_down    5  10000                20000
# 25       sks  power_abs_down    5  10000                20000
# 18        ks  power_abs_down    5  10000                20000
#
#     $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39                                      0.00195
# 11                                      0.00530
# 4                                       0.00614
# 32                                      0.00713
# 25                                      0.00801
# 18                                      0.00969
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00256                     825
# 11                                      0.00702                     310
# 4                                       0.00835                     217
# 32                                      0.00980                     213
# 25                                      0.01037                     299
# 18                                      0.01235                     214
#    Statistic  $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 39        lr                                      0.00195
# 11       mmd                                      0.00530
# 4        fgd                                      0.00614
# 32       swd                                      0.00713
# 25       sks                                      0.00801
# 18        ks                                      0.00969
#
#     $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 39                                      0.00256                     825
# 11                                      0.00702                     310
# 4                                       0.00835                     217
# 32                                      0.00980                     213
# 25                                      0.01037                     299
# 18                                      0.01235                     214

# %%
sorted_df_random_normal = results_df_random_normal.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_normal)
# Out:
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        fgd  random_normal    5  10000                20000
# 19        ks  random_normal    5  10000                20000
# 26       sks  random_normal    5  10000                20000
# 33       swd  random_normal    5  10000                20000
# 12       mmd  random_normal    5  10000                20000
#
#     $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                                      0.23468
# 19                                     0.25146
# 26                                     0.30518
# 33                                     0.31494
# 12                                     0.68327
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.27249                    185
# 19                                     0.30943                    147
# 26                                     0.36249                    204
# 33                                     0.38128                    144
# 12                                     0.80552                    295
#    Statistic  $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        fgd                                     0.23468
# 19        ks                                     0.25146
# 26       sks                                     0.30518
# 33       swd                                     0.31494
# 12       mmd                                     0.68327
#
#     $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                                      0.27249                    185
# 19                                     0.30943                    147
# 26                                     0.36249                    204
# 33                                     0.38128                    144
# 12                                     0.80552                    295

# %%
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_random_uniform)
# Out:
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform    5  10000                20000
# 20        ks  random_uniform    5  10000                20000
# 27       sks  random_uniform    5  10000                20000
# 34       swd  random_uniform    5  10000                20000
# 13       mmd  random_uniform    5  10000                20000
#
#     $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                                      0.40161
# 20                                     0.45654
# 27                                     0.51270
# 34                                     0.55176
# 13                                     1.20850
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.47290                    167
# 20                                     0.52421                    161
# 27                                     0.62225                    192
# 34                                     0.65384                    144
# 13                                     1.35614                    224
#    Statistic  $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                                     0.40161
# 20        ks                                     0.45654
# 27       sks                                     0.51270
# 34       swd                                     0.55176
# 13       mmd                                     1.20850
#
#     $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                                      0.47290                    167
# 20                                     0.52421                    161
# 27                                     0.62225                    192
# 34                                     0.65384                    144
# 13                                     1.35614                    224

# %%
# Table with first 4 columns
result_table_1 = sorted_df_mean.merge(results_df_cov_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(results_df_cov_off_diag, on='Statistic', how='outer')
result_table_1 = result_table_1.merge(sorted_df_power_abs_up, on='Statistic', how='outer')
# Fix columns names
result_table_1 = result_table_1.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_1 = result_table_1.replace("ks",  "$\\overline{D}$")
result_table_1 = result_table_1.replace("sks", "$\\widetilde{D}$")
result_table_1 = result_table_1.replace("swd", "$\\widetilde{W}$")
result_table_1 = result_table_1.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_1 = result_table_1.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_1 = result_table_1.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
# Table with last 4 columns
result_table_2 = sorted_df_power_abs_down.merge(sorted_df_random_normal, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(sorted_df_random_uniform, on='Statistic', how='outer')
result_table_2 = result_table_2.merge(times_df, on='Statistic', how='outer')
# Fix columns names
result_table_2 = result_table_2.replace("lr",  "$t_{\\mathrm{LLR}}$")
result_table_2 = result_table_2.replace("ks",  "$\\overline{D}$")
result_table_2 = result_table_2.replace("sks", "$\\widetilde{D}$")
result_table_2 = result_table_2.replace("swd", "$\\widetilde{W}$")
result_table_2 = result_table_2.replace("fgd", "$d_{\\mathrm{FGD}_{\\infty}}$")
result_table_2 = result_table_2.replace("fn",  "$\\overline{\\|\cdot\\|}_{F}$")
result_table_2 = result_table_2.replace("mmd", "$d_{\\mathrm{MMD}^{2}_{u}}$")
#display(result_table)
# Make Latex Table (first part)
string = result_table_1.to_latex(index=False, column_format='l|llr|llr|llr|llr', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\mu$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{ii}$-deformation} \
     & \\multicolumn{3}{c}{$\\Sigma_{i\\neq j}$-deformation} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{+}$-deformation} \\\\")
# Fix sub-columns names
string = string.replace("^{\\mu}", "")
string = string.replace("^{\\Sigma_{ii}}", "")
string = string.replace("^{\\Sigma_{i\\neq j}}", "")
string = string.replace("^{\\rm{pow}_{+}}", "")
# Close first table
string = string.replace("\\bottomrule\n\\end{tabular}\n","")
string = string.replace("\\toprule","\\toprule\n\\multicolumn{13}{c}{$\\mathbf{n=m=10^{4}}$} \\\\")
string = string.rstrip()
#display(result_table)
# Make Latex Table (second part)
string = string + result_table_2.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g")
# Legend row
string = string.replace("\\toprule",
    "\\toprule\n\\multicolumn{1}{c}{} \
     & \\multicolumn{3}{c}{$\\rm{pow}_{-}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{N}$-deformation} \
     & \\multicolumn{3}{c}{$\\mathcal{U}$-deformation} \
     & \\multicolumn{3}{c}{} \\\\")
# Fix sub-columns names
string = string.replace("^{\\rm{pow}_{-}}", "")
string = string.replace("^{\\mathcal{N}}", "")
string = string.replace("^{\\mathcal{U}}", "")
string = string.replace("\\begin{tabular}{l|llr|llr|llr|r}","")
string = string.lstrip()
print(string)
# Out:
# \begin{tabular}{l|llr|llr|llr|llr}
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# \multicolumn{13}{c}{$\mathbf{n=m=10^{4}}$} \\
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\mu$-deformation}      & \multicolumn{3}{c}{$\Sigma_{ii}$-deformation}      & \multicolumn{3}{c}{$\Sigma_{i\neq j}$-deformation}      & \multicolumn{3}{c}{$\rm{pow}_{+}$-deformation} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & Deformation_x & $N$_x & $n=m$_x & $n_{\mathrm{iter}}$_x & $\epsilon_{95\%\mathrm{CL}}$_x & $\epsilon_{99\%\mathrm{CL}}$_x & t (s)_x & Deformation_y & $N$_y & $n=m$_y & $n_{\mathrm{iter}}$_y & $\epsilon_{95\%\mathrm{CL}}$_y & $\epsilon_{99\%\mathrm{CL}}$_y & t (s)_y & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.059 & 0.084 & 186 & cov_diag & 5 & 10000 & 20000 & 0.023 & 0.03 & 198 & cov_off_diag & 5 & 10000 & 20000 & 0.0076 & 0.011 & 229 & 0.0056 & 0.0078 & 250 \\
# $\overline{D}$ & 0.067 & 0.085 & 166 & cov_diag & 5 & 10000 & 20000 & 0.044 & 0.059 & 191 & cov_off_diag & 5 & 10000 & 20000 & 1 & 1 & 145 & 0.0094 & 0.012 & 205 \\
# $t_{\mathrm{LLR}}$ & 0.023 & 0.032 & 553 & cov_diag & 5 & 10000 & 20000 & 0.004 & 0.006 & 747 & cov_off_diag & 5 & 10000 & 20000 & 0.00036 & 0.00056 & 1066 & 0.0014 & 0.0021 & 822 \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.092 & 0.12 & 238 & cov_diag & 5 & 10000 & 20000 & 0.027 & 0.035 & 275 & cov_off_diag & 5 & 10000 & 20000 & 0.047 & 0.062 & 246 & 0.005 & 0.0066 & 316 \\
# $\widetilde{D}$ & 0.07 & 0.094 & 234 & cov_diag & 5 & 10000 & 20000 & 0.035 & 0.048 & 270 & cov_off_diag & 5 & 10000 & 20000 & 0.021 & 0.032 & 280 & 0.0072 & 0.0096 & 310 \\
# $\widetilde{W}$ & 0.065 & 0.089 & 163 & cov_diag & 5 & 10000 & 20000 & 0.026 & 0.036 & 207 & cov_off_diag & 5 & 10000 & 20000 & 0.024 & 0.035 & 189 & 0.0064 & 0.0089 & 221 \\
# \toprule
# \multicolumn{1}{c}{}      & \multicolumn{3}{c}{$\rm{pow}_{-}$-deformation}      & \multicolumn{3}{c}{$\mathcal{N}$-deformation}      & \multicolumn{3}{c}{$\mathcal{U}$-deformation}      & \multicolumn{3}{c}{} \\
# Statistic & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $\epsilon_{95\%\mathrm{CL}}$ & $\epsilon_{99\%\mathrm{CL}}$ & $t$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $d_{\mathrm{FGD}_{\infty}}$ & 0.0061 & 0.0083 & 217 & 0.23 & 0.27 & 1.8e+02 & 0.4 & 0.47 & 1.7e+02 & 434 \\
# $\overline{D}$ & 0.0097 & 0.012 & 214 & 0.25 & 0.31 & 1.5e+02 & 0.46 & 0.52 & 1.6e+02 & 32 \\
# $t_{\mathrm{LLR}}$ & 0.0019 & 0.0026 & 825 & NaN & NaN & NaN & NaN & NaN & NaN & - \\
# $d_{\mathrm{MMD}^{2}_{u}}$ & 0.0053 & 0.007 & 310 & 0.68 & 0.81 & 3e+02 & 1.2 & 1.4 & 2.2e+02 & 1266 \\
# $\widetilde{D}$ & 0.008 & 0.01 & 299 & 0.31 & 0.36 & 2e+02 & 0.51 & 0.62 & 1.9e+02 & 385 \\
# $\widetilde{W}$ & 0.0071 & 0.0098 & 213 & 0.31 & 0.38 & 1.4e+02 & 0.55 & 0.65 & 1.4e+02 & 281 \\
# \bottomrule
# \end{tabular}
