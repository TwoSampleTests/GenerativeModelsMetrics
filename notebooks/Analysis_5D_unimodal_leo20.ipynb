# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_unimodal import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results_leonardo/5D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-16 09:27:11.283994: Importing os...
# 2024-04-16 09:27:11.284177: Importing sys...
# Visible devices: [1]
# 2024-04-16 09:27:11.284417: Importing timer from timeit...
# 2024-04-16 09:27:11.284485: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-04-16 09:27:11.284614: Importing numpy...
# 2024-04-16 09:27:11.398035: Importing matplotlib...
# 2024-04-16 09:27:11.748656: Importing h5py...
# 2024-04-16 09:27:11.772605: Importing importlib.util...
# 2024-04-16 09:27:11.772704: Importing json...
# 2024-04-16 09:27:11.772767: Importing pandas...
# 2024-04-16 09:27:12.217785: Importing random...
# 2024-04-16 09:27:12.217921: Importing scipy utils...
# 2024-04-16 09:27:12.624325: Importing subprocess...
# 2024-04-16 09:27:12.624451: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-16 09:27:16.102610: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-16 09:27:17.250325: Importing timeit...
# 2024-04-16 09:27:17.250432: Importing tqdm...
# 2024-04-16 09:27:17.259503: Importing typing...
# 2024-04-16 09:27:17.259615: Setting tf configs...
# 2024-04-16 09:27:17.346926: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-16 09:27:22.170440: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-04-16 09:27:22.199500: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = 0.,
                                                             eps_scale = 0.,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
dist_2 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = eps_loc,
                                                             eps_scale = eps_scale,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)

# %% [markdown]
# # Fixed $n=20000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory was created
# Null hypothesis directory was created

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 200000000
# batch_size 20000
# niter 10000
# niter * batch_size 200000000
# small_sample False

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               #min_samples_input = 20_000,
                               #max_samples_input = 50_000,
                               num_batches = 20)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4,
                               block_size = 10_000,
                               num_batches = 1,
                               batch_size = 20_000)
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            20000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True        5           0  float64     5  200000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fn": {"name": "fn", # type: ignore
                                      "object_name": "FNMetric",
                                      "class_name": "GMetrics.FNMetric",
                                      "kwargs": {},
                                      "result_key": "metric_list", 
                                      "scale_func": lambda ns, ndims: np.sqrt(ns)/ndims,
                                      "scale_func_string": "lambda ns, ndims: np.sqrt(ns)/ndims",
                                      "test_config": test_config_null,
                                      "max_vectorize": 2000, # optimized for 5D
                                      "latex": "$\overline{\|\cdot\|}_{F}$",
                                      "null_file": null_hypotheses_dir+"FN.json"},
                               "fpd": {"name": "fpd",
                                       "object_name": "FPDMetric",
                                       "class_name": "GMetrics.FPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500, # optimized for 5D
                                       "latex": "$d_{\mathrm{FPD}}$",
                                       "null_file": null_hypotheses_dir+"FPD.json"},
                               "kpd": {"name": "kpd",
                                       "object_name": "KPDMetric" ,
                                       "class_name": "GMetrics.KPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1, # optimized for 5D
                                       "latex": "$d_{\mathrm{KPD}}$",
                                       "null_file": null_hypotheses_dir+"KPD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1000,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fn': {'name': 'fn',
#   'object_name': 'FNMetric',
#   'class_name': 'GMetrics.FNMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)/ndims',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 2000,
#   'latex': '$\\overline{\\|\\cdot\\|}_{F}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_20K/null_hypothesis/FN.json'},
#  'fpd': {'name': 'fpd',
#   'object_name': 'FPDMetric',
#   'class_name': 'GMetrics.FPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$d_{\\mathrm{FPD}}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_20K/null_hypothesis/FPD.json'},
#  'kpd': {'name': 'kpd',
#   'object_name': 'KPDMetric',
#   'class_name': 'GMetrics.KPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{KPD}}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_20K/null_hypothesis/KPD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 5000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_20K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_20K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 200,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_20K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 20000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 200000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results_leonardo/5D_unimodal/5D_20K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fn with max_vectorize = 2000
#
# ------------------------------------------
# Starting FN metric calculation...
# Running TF FN calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 5
# Iterating from 0 to 2000 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713252478.147457  397751 service.cc:145] XLA service 0x10c3d4530 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1713252478.147496  397751 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1713252480.948620  397751 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iterating from 2000 to 4000 out of 10000 .
# Iterating from 4000 to 6000 out of 10000 .
# Iterating from 6000 to 8000 out of 10000 .
# Iterating from 8000 to 10000 out of 10000 .
# FN metric calculation completed in 8.453927748138085 seconds.
# Saving fn to results_leonardo/5D_unimodal/5D_20K/null_hypothesis/FN.json
# Computing and savng fpd with max_vectorize = 500
#
# ------------------------------------------
# Starting FPD metric calculation...
# Running TF FPD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# FPD metric calculation completed in 139.20650215400383 seconds.
# Saving fpd to results_leonardo/5D_unimodal/5D_20K/null_hypothesis/FPD.json
# Computing and savng kpd with max_vectorize = 1
#
# ------------------------------------------
# Starting KPD metric calculation...
# Running TF KPD calculation...
# niter = 10000
# batch_size = 20000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10000
# Iterating from 0 to 1 out of 10000 .
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# Iterating from 1 to 2 out of 10000 .
# Iterating from 2 to 3 out of 10000 .
# Iterating from 3 to 4 out of 10000 .
# Iterating from 4 to 5 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f7e6d82c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 5 to 6 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f7e6d82c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 6 to 7 out of 10000 .
# Iterating from 7 to 8 out of 10000 .
# Iterating from 8 to 9 out of 10000 .
# Iterating from 9 to 10 out of 10000 .
# Iterating from 10 to 11 out of 10000 .
# Iterating from 11 to 12 out of 10000 .
# Iterating from 12 to 13 out of 10000 .
# Iterating from 13 to 14 out of 10000 .
# Iterating from 14 to 15 out of 10000 .
# Iterating from 15 to 16 out of 10000 .
# Iterating from 16 to 17 out of 10000 .
# Iterating from 17 to 18 out of 10000 .
# Iterating from 18 to 19 out of 10000 .
# Iterating from 19 to 20 out of 10000 .
# Iterating from 20 to 21 out of 10000 .
# Iterating from 21 to 22 out of 10000 .
# Iterating from 22 to 23 out of 10000 .
# Iterating from 23 to 24 out of 10000 .
# Iterating from 24 to 25 out of 10000 .
# Iterating from 25 to 26 out of 10000 .
# Iterating from 26 to 27 out of 10000 .
# Iterating from 27 to 28 out of 10000 .
# Iterating from 28 to 29 out of 10000 .
# Iterating from 29 to 30 out of 10000 .
# Iterating from 30 to 31 out of 10000 .
# Iterating from 31 to 32 out of 10000 .
# Iterating from 32 to 33 out of 10000 .
# Iterating from 33 to 34 out of 10000 .
# Iterating from 34 to 35 out of 10000 .
# Iterating from 35 to 36 out of 10000 .
# Iterating from 36 to 37 out of 10000 .
# Iterating from 37 to 38 out of 10000 .
# Iterating from 38 to 39 out of 10000 .
# Iterating from 39 to 40 out of 10000 .
# Iterating from 40 to 41 out of 10000 .
# Iterating from 41 to 42 out of 10000 .
# Iterating from 42 to 43 out of 10000 .
# Iterating from 43 to 44 out of 10000 .
# Iterating from 44 to 45 out of 10000 .
# Iterating from 45 to 46 out of 10000 .
# Iterating from 46 to 47 out of 10000 .
# Iterating from 47 to 48 out of 10000 .
# Iterating from 48 to 49 out of 10000 .
# Iterating from 49 to 50 out of 10000 .
# Iterating from 50 to 51 out of 10000 .
# Iterating from 51 to 52 out of 10000 .
# Iterating from 52 to 53 out of 10000 .
# Iterating from 53 to 54 out of 10000 .
# Iterating from 54 to 55 out of 10000 .
# Iterating from 55 to 56 out of 10000 .
# Iterating from 56 to 57 out of 10000 .
# Iterating from 57 to 58 out of 10000 .
# Iterating from 58 to 59 out of 10000 .
# Iterating from 59 to 60 out of 10000 .
# Iterating from 60 to 61 out of 10000 .
# Iterating from 61 to 62 out of 10000 .
# Iterating from 62 to 63 out of 10000 .
# Iterating from 63 to 64 out of 10000 .
# Iterating from 64 to 65 out of 10000 .
# Iterating from 65 to 66 out of 10000 .
# Iterating from 66 to 67 out of 10000 .
# Iterating from 67 to 68 out of 10000 .
# Iterating from 68 to 69 out of 10000 .
# Iterating from 69 to 70 out of 10000 .
# Iterating from 70 to 71 out of 10000 .
# Iterating from 71 to 72 out of 10000 .
# Iterating from 72 to 73 out of 10000 .
# Iterating from 73 to 74 out of 10000 .
# Iterating from 74 to 75 out of 10000 .
# Iterating from 75 to 76 out of 10000 .
# Iterating from 76 to 77 out of 10000 .
# Iterating from 77 to 78 out of 10000 .
# Iterating from 78 to 79 out of 10000 .
# Iterating from 79 to 80 out of 10000 .
# Iterating from 80 to 81 out of 10000 .
# Iterating from 81 to 82 out of 10000 .
# Iterating from 82 to 83 out of 10000 .
# Iterating from 83 to 84 out of 10000 .
# Iterating from 84 to 85 out of 10000 .
# Iterating from 85 to 86 out of 10000 .
# Iterating from 86 to 87 out of 10000 .
# Iterating from 87 to 88 out of 10000 .
# Iterating from 88 to 89 out of 10000 .
# Iterating from 89 to 90 out of 10000 .
# Iterating from 90 to 91 out of 10000 .
# Iterating from 91 to 92 out of 10000 .
# Iterating from 92 to 93 out of 10000 .
# Iterating from 93 to 94 out of 10000 .
# Iterating from 94 to 95 out of 10000 .
# Iterating from 95 to 96 out of 10000 .
# Iterating from 96 to 97 out of 10000 .
# Iterating from 97 to 98 out of 10000 .
# Iterating from 98 to 99 out of 10000 .
# Iterating from 99 to 100 out of 10000 .
# Iterating from 100 to 101 out of 10000 .
# Iterating from 101 to 102 out of 10000 .
# Iterating from 102 to 103 out of 10000 .
# Iterating from 103 to 104 out of 10000 .
# Iterating from 104 to 105 out of 10000 .
# Iterating from 105 to 106 out of 10000 .
# Iterating from 106 to 107 out of 10000 .
# Iterating from 107 to 108 out of 10000 .
# Iterating from 108 to 109 out of 10000 .
# Iterating from 109 to 110 out of 10000 .
# Iterating from 110 to 111 out of 10000 .
# Iterating from 111 to 112 out of 10000 .
# Iterating from 112 to 113 out of 10000 .
# Iterating from 113 to 114 out of 10000 .
# Iterating from 114 to 115 out of 10000 .
# Iterating from 115 to 116 out of 10000 .
# Iterating from 116 to 117 out of 10000 .
# Iterating from 117 to 118 out of 10000 .
# Iterating from 118 to 119 out of 10000 .
# Iterating from 119 to 120 out of 10000 .
# Iterating from 120 to 121 out of 10000 .
# Iterating from 121 to 122 out of 10000 .
# Iterating from 122 to 123 out of 10000 .
# Iterating from 123 to 124 out of 10000 .
# Iterating from 124 to 125 out of 10000 .
# Iterating from 125 to 126 out of 10000 .
# Iterating from 126 to 127 out of 10000 .
# Iterating from 127 to 128 out of 10000 .
# Iterating from 128 to 129 out of 10000 .
# Iterating from 129 to 130 out of 10000 .
# Iterating from 130 to 131 out of 10000 .
# Iterating from 131 to 132 out of 10000 .
# Iterating from 132 to 133 out of 10000 .
# Iterating from 133 to 134 out of 10000 .
# Iterating from 134 to 135 out of 10000 .
# Iterating from 135 to 136 out of 10000 .
# Iterating from 136 to 137 out of 10000 .
# Iterating from 137 to 138 out of 10000 .
# Iterating from 138 to 139 out of 10000 .
# Iterating from 139 to 140 out of 10000 .
# Iterating from 140 to 141 out of 10000 .
# Iterating from 141 to 142 out of 10000 .
# Iterating from 142 to 143 out of 10000 .
# Iterating from 143 to 144 out of 10000 .
# Iterating from 144 to 145 out of 10000 .
# Iterating from 145 to 146 out of 10000 .
# Iterating from 146 to 147 out of 10000 .
# Iterating from 147 to 148 out of 10000 .
# Iterating from 148 to 149 out of 10000 .
# Iterating from 149 to 150 out of 10000 .
# Iterating from 150 to 151 out of 10000 .
# Iterating from 151 to 152 out of 10000 .
# Iterating from 152 to 153 out of 10000 .
# Iterating from 153 to 154 out of 10000 .
# Iterating from 154 to 155 out of 10000 .
# Iterating from 155 to 156 out of 10000 .
# Iterating from 156 to 157 out of 10000 .
# Iterating from 157 to 158 out of 10000 .
# Iterating from 158 to 159 out of 10000 .
# Iterating from 159 to 160 out of 10000 .
# Iterating from 160 to 161 out of 10000 .
# Iterating from 161 to 162 out of 10000 .
# Iterating from 162 to 163 out of 10000 .
# Iterating from 163 to 164 out of 10000 .
# Iterating from 164 to 165 out of 10000 .
# Iterating from 165 to 166 out of 10000 .
# Iterating from 166 to 167 out of 10000 .
# Iterating from 167 to 168 out of 10000 .
# Iterating from 168 to 169 out of 10000 .
# Iterating from 169 to 170 out of 10000 .
# Iterating from 170 to 171 out of 10000 .
# Iterating from 171 to 172 out of 10000 .
# Iterating from 172 to 173 out of 10000 .
# Iterating from 173 to 174 out of 10000 .
# Iterating from 174 to 175 out of 10000 .
# Iterating from 175 to 176 out of 10000 .
# Iterating from 176 to 177 out of 10000 .
# Iterating from 177 to 178 out of 10000 .
# Iterating from 178 to 179 out of 10000 .
# Iterating from 179 to 180 out of 10000 .
# Iterating from 180 to 181 out of 10000 .
# Iterating from 181 to 182 out of 10000 .
# Iterating from 182 to 183 out of 10000 .
# Iterating from 183 to 184 out of 10000 .
# Iterating from 184 to 185 out of 10000 .
# Iterating from 185 to 186 out of 10000 .
# Iterating from 186 to 187 out of 10000 .
# Iterating from 187 to 188 out of 10000 .
# Iterating from 188 to 189 out of 10000 .
# Iterating from 189 to 190 out of 10000 .
# Iterating from 190 to 191 out of 10000 .
# Iterating from 191 to 192 out of 10000 .
# Iterating from 192 to 193 out of 10000 .
# Iterating from 193 to 194 out of 10000 .
# Iterating from 194 to 195 out of 10000 .
# Iterating from 195 to 196 out of 10000 .
# Iterating from 196 to 197 out of 10000 .
# Iterating from 197 to 198 out of 10000 .
# Iterating from 198 to 199 out of 10000 .
# Iterating from 199 to 200 out of 10000 .
# Iterating from 200 to 201 out of 10000 .
# Iterating from 201 to 202 out of 10000 .
# Iterating from 202 to 203 out of 10000 .
# Iterating from 203 to 204 out of 10000 .
# Iterating from 204 to 205 out of 10000 .
# Iterating from 205 to 206 out of 10000 .
# Iterating from 206 to 207 out of 10000 .
# Iterating from 207 to 208 out of 10000 .
# Iterating from 208 to 209 out of 10000 .
# Iterating from 209 to 210 out of 10000 .
# Iterating from 210 to 211 out of 10000 .
# Iterating from 211 to 212 out of 10000 .
# Iterating from 212 to 213 out of 10000 .
# Iterating from 213 to 214 out of 10000 .
# Iterating from 214 to 215 out of 10000 .
# Iterating from 215 to 216 out of 10000 .
# Iterating from 216 to 217 out of 10000 .
# Iterating from 217 to 218 out of 10000 .
# Iterating from 218 to 219 out of 10000 .
# Iterating from 219 to 220 out of 10000 .
# Iterating from 220 to 221 out of 10000 .
# Iterating from 221 to 222 out of 10000 .
# Iterating from 222 to 223 out of 10000 .
# Iterating from 223 to 224 out of 10000 .
# Iterating from 224 to 225 out of 10000 .
# Iterating from 225 to 226 out of 10000 .
# Iterating from 226 to 227 out of 10000 .
# Iterating from 227 to 228 out of 10000 .
# Iterating from 228 to 229 out of 10000 .
# Iterating from 229 to 230 out of 10000 .
# Iterating from 230 to 231 out of 10000 .
# Iterating from 231 to 232 out of 10000 .
# Iterating from 232 to 233 out of 10000 .
# Iterating from 233 to 234 out of 10000 .
# Iterating from 234 to 235 out of 10000 .
# Iterating from 235 to 236 out of 10000 .
# Iterating from 236 to 237 out of 10000 .
# Iterating from 237 to 238 out of 10000 .
# Iterating from 238 to 239 out of 10000 .
# Iterating from 239 to 240 out of 10000 .
# Iterating from 240 to 241 out of 10000 .
# Iterating from 241 to 242 out of 10000 .
# Iterating from 242 to 243 out of 10000 .
# Iterating from 243 to 244 out of 10000 .
# Iterating from 244 to 245 out of 10000 .
# Iterating from 245 to 246 out of 10000 .
# Iterating from 246 to 247 out of 10000 .
# Iterating from 247 to 248 out of 10000 .
# Iterating from 248 to 249 out of 10000 .
# Iterating from 249 to 250 out of 10000 .
# Iterating from 250 to 251 out of 10000 .
# Iterating from 251 to 252 out of 10000 .
# Iterating from 252 to 253 out of 10000 .
# Iterating from 253 to 254 out of 10000 .
# Iterating from 254 to 255 out of 10000 .
# Iterating from 255 to 256 out of 10000 .
# Iterating from 256 to 257 out of 10000 .
# Iterating from 257 to 258 out of 10000 .
# Iterating from 258 to 259 out of 10000 .
# Iterating from 259 to 260 out of 10000 .
# Iterating from 260 to 261 out of 10000 .
# Iterating from 261 to 262 out of 10000 .
# Iterating from 262 to 263 out of 10000 .
# Iterating from 263 to 264 out of 10000 .
# Iterating from 264 to 265 out of 10000 .
# Iterating from 265 to 266 out of 10000 .
# Iterating from 266 to 267 out of 10000 .
# Iterating from 267 to 268 out of 10000 .
# Iterating from 268 to 269 out of 10000 .
# Iterating from 269 to 270 out of 10000 .
# Iterating from 270 to 271 out of 10000 .
# Iterating from 271 to 272 out of 10000 .
# Iterating from 272 to 273 out of 10000 .
# Iterating from 273 to 274 out of 10000 .
# Iterating from 274 to 275 out of 10000 .
# Iterating from 275 to 276 out of 10000 .
# Iterating from 276 to 277 out of 10000 .
# Iterating from 277 to 278 out of 10000 .
# Iterating from 278 to 279 out of 10000 .
# Iterating from 279 to 280 out of 10000 .
# Iterating from 280 to 281 out of 10000 .
# Iterating from 281 to 282 out of 10000 .
# Iterating from 282 to 283 out of 10000 .
# Iterating from 283 to 284 out of 10000 .
# Iterating from 284 to 285 out of 10000 .
# Iterating from 285 to 286 out of 10000 .
# Iterating from 286 to 287 out of 10000 .
# Iterating from 287 to 288 out of 10000 .
# Iterating from 288 to 289 out of 10000 .
# Iterating from 289 to 290 out of 10000 .
# Iterating from 290 to 291 out of 10000 .
# Iterating from 291 to 292 out of 10000 .
# Iterating from 292 to 293 out of 10000 .
# Iterating from 293 to 294 out of 10000 .
# Iterating from 294 to 295 out of 10000 .
# Iterating from 295 to 296 out of 10000 .
# Iterating from 296 to 297 out of 10000 .
# Iterating from 297 to 298 out of 10000 .
# Iterating from 298 to 299 out of 10000 .
# Iterating from 299 to 300 out of 10000 .
# Iterating from 300 to 301 out of 10000 .
# Iterating from 301 to 302 out of 10000 .
# Iterating from 302 to 303 out of 10000 .
# Iterating from 303 to 304 out of 10000 .
# Iterating from 304 to 305 out of 10000 .
# Iterating from 305 to 306 out of 10000 .
# Iterating from 306 to 307 out of 10000 .
# Iterating from 307 to 308 out of 10000 .
# Iterating from 308 to 309 out of 10000 .
# Iterating from 309 to 310 out of 10000 .
# Iterating from 310 to 311 out of 10000 .
# Iterating from 311 to 312 out of 10000 .
# Iterating from 312 to 313 out of 10000 .
# Iterating from 313 to 314 out of 10000 .
# Iterating from 314 to 315 out of 10000 .
# Iterating from 315 to 316 out of 10000 .
# Iterating from 316 to 317 out of 10000 .
# Iterating from 317 to 318 out of 10000 .
# Iterating from 318 to 319 out of 10000 .
# Iterating from 319 to 320 out of 10000 .
# Iterating from 320 to 321 out of 10000 .
# Iterating from 321 to 322 out of 10000 .
# Iterating from 322 to 323 out of 10000 .
# Iterating from 323 to 324 out of 10000 .
# Iterating from 324 to 325 out of 10000 .
# Iterating from 325 to 326 out of 10000 .
# Iterating from 326 to 327 out of 10000 .
# Iterating from 327 to 328 out of 10000 .
# Iterating from 328 to 329 out of 10000 .
# Iterating from 329 to 330 out of 10000 .
# Iterating from 330 to 331 out of 10000 .
# Iterating from 331 to 332 out of 10000 .
# Iterating from 332 to 333 out of 10000 .
# Iterating from 333 to 334 out of 10000 .
# Iterating from 334 to 335 out of 10000 .
# Iterating from 335 to 336 out of 10000 .
# Iterating from 336 to 337 out of 10000 .
# Iterating from 337 to 338 out of 10000 .
# Iterating from 338 to 339 out of 10000 .
# Iterating from 339 to 340 out of 10000 .
# Iterating from 340 to 341 out of 10000 .
# Iterating from 341 to 342 out of 10000 .
# Iterating from 342 to 343 out of 10000 .
# Iterating from 343 to 344 out of 10000 .
# Iterating from 344 to 345 out of 10000 .
# Iterating from 345 to 346 out of 10000 .
# Iterating from 346 to 347 out of 10000 .
# Iterating from 347 to 348 out of 10000 .
# Iterating from 348 to 349 out of 10000 .
# Iterating from 349 to 350 out of 10000 .
# Iterating from 350 to 351 out of 10000 .
# Iterating from 351 to 352 out of 10000 .
# Iterating from 352 to 353 out of 10000 .
# Iterating from 353 to 354 out of 10000 .
# Iterating from 354 to 355 out of 10000 .
# Iterating from 355 to 356 out of 10000 .
# Iterating from 356 to 357 out of 10000 .
# Iterating from 357 to 358 out of 10000 .
# Iterating from 358 to 359 out of 10000 .
# Iterating from 359 to 360 out of 10000 .
# Iterating from 360 to 361 out of 10000 .
# Iterating from 361 to 362 out of 10000 .
# Iterating from 362 to 363 out of 10000 .
# Iterating from 363 to 364 out of 10000 .
# Iterating from 364 to 365 out of 10000 .
# Iterating from 365 to 366 out of 10000 .
# Iterating from 366 to 367 out of 10000 .
# Iterating from 367 to 368 out of 10000 .
# Iterating from 368 to 369 out of 10000 .
# Iterating from 369 to 370 out of 10000 .
# Iterating from 370 to 371 out of 10000 .
# Iterating from 371 to 372 out of 10000 .
# Iterating from 372 to 373 out of 10000 .
# Iterating from 373 to 374 out of 10000 .
# Iterating from 374 to 375 out of 10000 .
# Iterating from 375 to 376 out of 10000 .
# Iterating from 376 to 377 out of 10000 .
# Iterating from 377 to 378 out of 10000 .
# Iterating from 378 to 379 out of 10000 .
# Iterating from 379 to 380 out of 10000 .
# Iterating from 380 to 381 out of 10000 .
# Iterating from 381 to 382 out of 10000 .
# Iterating from 382 to 383 out of 10000 .
# Iterating from 383 to 384 out of 10000 .
# Iterating from 384 to 385 out of 10000 .
# Iterating from 385 to 386 out of 10000 .
# Iterating from 386 to 387 out of 10000 .
# Iterating from 387 to 388 out of 10000 .
# Iterating from 388 to 389 out of 10000 .
# Iterating from 389 to 390 out of 10000 .
# Iterating from 390 to 391 out of 10000 .
# Iterating from 391 to 392 out of 10000 .
# Iterating from 392 to 393 out of 10000 .
# Iterating from 393 to 394 out of 10000 .
# Iterating from 394 to 395 out of 10000 .
# Iterating from 395 to 396 out of 10000 .
# Iterating from 396 to 397 out of 10000 .
# Iterating from 397 to 398 out of 10000 .
# Iterating from 398 to 399 out of 10000 .
# Iterating from 399 to 400 out of 10000 .
# Iterating from 400 to 401 out of 10000 .
# Iterating from 401 to 402 out of 10000 .
# Iterating from 402 to 403 out of 10000 .
# Iterating from 403 to 404 out of 10000 .
# Iterating from 404 to 405 out of 10000 .
# Iterating from 405 to 406 out of 10000 .
# Iterating from 406 to 407 out of 10000 .
# Iterating from 407 to 408 out of 10000 .
# Iterating from 408 to 409 out of 10000 .
# Iterating from 409 to 410 out of 10000 .
# Iterating from 410 to 411 out of 10000 .
# Iterating from 411 to 412 out of 10000 .
# Iterating from 412 to 413 out of 10000 .
# Iterating from 413 to 414 out of 10000 .
# Iterating from 414 to 415 out of 10000 .
# Iterating from 415 to 416 out of 10000 .
# Iterating from 416 to 417 out of 10000 .
# Iterating from 417 to 418 out of 10000 .
# Iterating from 418 to 419 out of 10000 .
# Iterating from 419 to 420 out of 10000 .
# Iterating from 420 to 421 out of 10000 .
# Iterating from 421 to 422 out of 10000 .
# Iterating from 422 to 423 out of 10000 .
# Iterating from 423 to 424 out of 10000 .
# Iterating from 424 to 425 out of 10000 .
# Iterating from 425 to 426 out of 10000 .
# Iterating from 426 to 427 out of 10000 .
# Iterating from 427 to 428 out of 10000 .
# Iterating from 428 to 429 out of 10000 .
# Iterating from 429 to 430 out of 10000 .
# Iterating from 430 to 431 out of 10000 .
# Iterating from 431 to 432 out of 10000 .
# Iterating from 432 to 433 out of 10000 .
# Iterating from 433 to 434 out of 10000 .
# Iterating from 434 to 435 out of 10000 .
# Iterating from 435 to 436 out of 10000 .
# Iterating from 436 to 437 out of 10000 .
# Iterating from 437 to 438 out of 10000 .
# Iterating from 438 to 439 out of 10000 .
# Iterating from 439 to 440 out of 10000 .
# Iterating from 440 to 441 out of 10000 .
# Iterating from 441 to 442 out of 10000 .
# Iterating from 442 to 443 out of 10000 .
# Iterating from 443 to 444 out of 10000 .
# Iterating from 444 to 445 out of 10000 .
# Iterating from 445 to 446 out of 10000 .
# Iterating from 446 to 447 out of 10000 .
# Iterating from 447 to 448 out of 10000 .
# Iterating from 448 to 449 out of 10000 .
# Iterating from 449 to 450 out of 10000 .
# Iterating from 450 to 451 out of 10000 .
# Iterating from 451 to 452 out of 10000 .
# Iterating from 452 to 453 out of 10000 .
# Iterating from 453 to 454 out of 10000 .
# Iterating from 454 to 455 out of 10000 .
# Iterating from 455 to 456 out of 10000 .
# Iterating from 456 to 457 out of 10000 .
# Iterating from 457 to 458 out of 10000 .
# Iterating from 458 to 459 out of 10000 .
# Iterating from 459 to 460 out of 10000 .
# Iterating from 460 to 461 out of 10000 .
# Iterating from 461 to 462 out of 10000 .
# Iterating from 462 to 463 out of 10000 .
# Iterating from 463 to 464 out of 10000 .
# Iterating from 464 to 465 out of 10000 .
# Iterating from 465 to 466 out of 10000 .
# Iterating from 466 to 467 out of 10000 .
# Iterating from 467 to 468 out of 10000 .
# Iterating from 468 to 469 out of 10000 .
# Iterating from 469 to 470 out of 10000 .
# Iterating from 470 to 471 out of 10000 .
# Iterating from 471 to 472 out of 10000 .
# Iterating from 472 to 473 out of 10000 .
# Iterating from 473 to 474 out of 10000 .
# Iterating from 474 to 475 out of 10000 .
# Iterating from 475 to 476 out of 10000 .
# Iterating from 476 to 477 out of 10000 .
# Iterating from 477 to 478 out of 10000 .
# Iterating from 478 to 479 out of 10000 .
# Iterating from 479 to 480 out of 10000 .
# Iterating from 480 to 481 out of 10000 .
# Iterating from 481 to 482 out of 10000 .
# Iterating from 482 to 483 out of 10000 .
# Iterating from 483 to 484 out of 10000 .
# Iterating from 484 to 485 out of 10000 .
# Iterating from 485 to 486 out of 10000 .
# Iterating from 486 to 487 out of 10000 .
# Iterating from 487 to 488 out of 10000 .
# Iterating from 488 to 489 out of 10000 .
# Iterating from 489 to 490 out of 10000 .
# Iterating from 490 to 491 out of 10000 .
# Iterating from 491 to 492 out of 10000 .
# Iterating from 492 to 493 out of 10000 .
# Iterating from 493 to 494 out of 10000 .
# Iterating from 494 to 495 out of 10000 .
# Iterating from 495 to 496 out of 10000 .
# Iterating from 496 to 497 out of 10000 .
# Iterating from 497 to 498 out of 10000 .
# Iterating from 498 to 499 out of 10000 .
# Iterating from 499 to 500 out of 10000 .
# Iterating from 500 to 501 out of 10000 .
# Iterating from 501 to 502 out of 10000 .
# Iterating from 502 to 503 out of 10000 .
# Iterating from 503 to 504 out of 10000 .
# Iterating from 504 to 505 out of 10000 .
# Iterating from 505 to 506 out of 10000 .
# Iterating from 506 to 507 out of 10000 .
# Iterating from 507 to 508 out of 10000 .
# Iterating from 508 to 509 out of 10000 .
# Iterating from 509 to 510 out of 10000 .
# Iterating from 510 to 511 out of 10000 .
# Iterating from 511 to 512 out of 10000 .
# Iterating from 512 to 513 out of 10000 .
# Iterating from 513 to 514 out of 10000 .
# Iterating from 514 to 515 out of 10000 .
# Iterating from 515 to 516 out of 10000 .
# Iterating from 516 to 517 out of 10000 .
# Iterating from 517 to 518 out of 10000 .
# Iterating from 518 to 519 out of 10000 .
# Iterating from 519 to 520 out of 10000 .
# Iterating from 520 to 521 out of 10000 .
# Iterating from 521 to 522 out of 10000 .
# Iterating from 522 to 523 out of 10000 .
# Iterating from 523 to 524 out of 10000 .
# Iterating from 524 to 525 out of 10000 .
# Iterating from 525 to 526 out of 10000 .
# Iterating from 526 to 527 out of 10000 .
# Iterating from 527 to 528 out of 10000 .
# Iterating from 528 to 529 out of 10000 .
# Iterating from 529 to 530 out of 10000 .
# Iterating from 530 to 531 out of 10000 .
# Iterating from 531 to 532 out of 10000 .
# Iterating from 532 to 533 out of 10000 .
# Iterating from 533 to 534 out of 10000 .
# Iterating from 534 to 535 out of 10000 .
# Iterating from 535 to 536 out of 10000 .
# Iterating from 536 to 537 out of 10000 .
# Iterating from 537 to 538 out of 10000 .
# Iterating from 538 to 539 out of 10000 .
# Iterating from 539 to 540 out of 10000 .
# Iterating from 540 to 541 out of 10000 .
# Iterating from 541 to 542 out of 10000 .
# Iterating from 542 to 543 out of 10000 .
# Iterating from 543 to 544 out of 10000 .
# Iterating from 544 to 545 out of 10000 .
# Iterating from 545 to 546 out of 10000 .
# Iterating from 546 to 547 out of 10000 .
# Iterating from 547 to 548 out of 10000 .
# Iterating from 548 to 549 out of 10000 .
# Iterating from 549 to 550 out of 10000 .
# Iterating from 550 to 551 out of 10000 .
# Iterating from 551 to 552 out of 10000 .
# Iterating from 552 to 553 out of 10000 .
# Iterating from 553 to 554 out of 10000 .
# Iterating from 554 to 555 out of 10000 .
# Iterating from 555 to 556 out of 10000 .
# Iterating from 556 to 557 out of 10000 .
# Iterating from 557 to 558 out of 10000 .
# Iterating from 558 to 559 out of 10000 .
# Iterating from 559 to 560 out of 10000 .
# Iterating from 560 to 561 out of 10000 .
# Iterating from 561 to 562 out of 10000 .
# Iterating from 562 to 563 out of 10000 .
# Iterating from 563 to 564 out of 10000 .
# Iterating from 564 to 565 out of 10000 .
# Iterating from 565 to 566 out of 10000 .
# Iterating from 566 to 567 out of 10000 .
# Iterating from 567 to 568 out of 10000 .
# Iterating from 568 to 569 out of 10000 .
# Iterating from 569 to 570 out of 10000 .
# Iterating from 570 to 571 out of 10000 .
# Iterating from 571 to 572 out of 10000 .
# Iterating from 572 to 573 out of 10000 .
# Iterating from 573 to 574 out of 10000 .
# Iterating from 574 to 575 out of 10000 .
# Iterating from 575 to 576 out of 10000 .
# Iterating from 576 to 577 out of 10000 .
# Iterating from 577 to 578 out of 10000 .
# Iterating from 578 to 579 out of 10000 .
# Iterating from 579 to 580 out of 10000 .
# Iterating from 580 to 581 out of 10000 .
# Iterating from 581 to 582 out of 10000 .
# Iterating from 582 to 583 out of 10000 .
# Iterating from 583 to 584 out of 10000 .
# Iterating from 584 to 585 out of 10000 .
# Iterating from 585 to 586 out of 10000 .
# Iterating from 586 to 587 out of 10000 .
# Iterating from 587 to 588 out of 10000 .
# Iterating from 588 to 589 out of 10000 .
# Iterating from 589 to 590 out of 10000 .
# Iterating from 590 to 591 out of 10000 .
# Iterating from 591 to 592 out of 10000 .
# Iterating from 592 to 593 out of 10000 .
# Iterating from 593 to 594 out of 10000 .
# Iterating from 594 to 595 out of 10000 .
# Iterating from 595 to 596 out of 10000 .
# Iterating from 596 to 597 out of 10000 .
# Iterating from 597 to 598 out of 10000 .
# Iterating from 598 to 599 out of 10000 .
# Iterating from 599 to 600 out of 10000 .
# Iterating from 600 to 601 out of 10000 .
# Iterating from 601 to 602 out of 10000 .
# Iterating from 602 to 603 out of 10000 .
# Iterating from 603 to 604 out of 10000 .
# Iterating from 604 to 605 out of 10000 .
# Iterating from 605 to 606 out of 10000 .
# Iterating from 606 to 607 out of 10000 .
# Iterating from 607 to 608 out of 10000 .
# Iterating from 608 to 609 out of 10000 .
# Iterating from 609 to 610 out of 10000 .
# Iterating from 610 to 611 out of 10000 .
# Iterating from 611 to 612 out of 10000 .
# Iterating from 612 to 613 out of 10000 .
# Iterating from 613 to 614 out of 10000 .
# Iterating from 614 to 615 out of 10000 .
# Iterating from 615 to 616 out of 10000 .
# Iterating from 616 to 617 out of 10000 .
# Iterating from 617 to 618 out of 10000 .
# Iterating from 618 to 619 out of 10000 .
# Iterating from 619 to 620 out of 10000 .
# Iterating from 620 to 621 out of 10000 .
# Iterating from 621 to 622 out of 10000 .
# Iterating from 622 to 623 out of 10000 .
# Iterating from 623 to 624 out of 10000 .
# Iterating from 624 to 625 out of 10000 .
# Iterating from 625 to 626 out of 10000 .
# Iterating from 626 to 627 out of 10000 .
# Iterating from 627 to 628 out of 10000 .
# Iterating from 628 to 629 out of 10000 .
# Iterating from 629 to 630 out of 10000 .
# Iterating from 630 to 631 out of 10000 .
# Iterating from 631 to 632 out of 10000 .
# Iterating from 632 to 633 out of 10000 .
# Iterating from 633 to 634 out of 10000 .
# Iterating from 634 to 635 out of 10000 .
# Iterating from 635 to 636 out of 10000 .
# Iterating from 636 to 637 out of 10000 .
# Iterating from 637 to 638 out of 10000 .
# Iterating from 638 to 639 out of 10000 .
# Iterating from 639 to 640 out of 10000 .
# Iterating from 640 to 641 out of 10000 .
# Iterating from 641 to 642 out of 10000 .
# Iterating from 642 to 643 out of 10000 .
# Iterating from 643 to 644 out of 10000 .
# Iterating from 644 to 645 out of 10000 .
# Iterating from 645 to 646 out of 10000 .
# Iterating from 646 to 647 out of 10000 .
# Iterating from 647 to 648 out of 10000 .
# Iterating from 648 to 649 out of 10000 .
# Iterating from 649 to 650 out of 10000 .
# Iterating from 650 to 651 out of 10000 .
# Iterating from 651 to 652 out of 10000 .
# Iterating from 652 to 653 out of 10000 .
# Iterating from 653 to 654 out of 10000 .
# Iterating from 654 to 655 out of 10000 .
# Iterating from 655 to 656 out of 10000 .
# Iterating from 656 to 657 out of 10000 .
# Iterating from 657 to 658 out of 10000 .
# Iterating from 658 to 659 out of 10000 .
# Iterating from 659 to 660 out of 10000 .
# Iterating from 660 to 661 out of 10000 .
# Iterating from 661 to 662 out of 10000 .
# Iterating from 662 to 663 out of 10000 .
# Iterating from 663 to 664 out of 10000 .
# Iterating from 664 to 665 out of 10000 .
# Iterating from 665 to 666 out of 10000 .
# Iterating from 666 to 667 out of 10000 .
# Iterating from 667 to 668 out of 10000 .
# Iterating from 668 to 669 out of 10000 .
# Iterating from 669 to 670 out of 10000 .
# Iterating from 670 to 671 out of 10000 .
# Iterating from 671 to 672 out of 10000 .
# Iterating from 672 to 673 out of 10000 .
# Iterating from 673 to 674 out of 10000 .
# Iterating from 674 to 675 out of 10000 .
# Iterating from 675 to 676 out of 10000 .
# Iterating from 676 to 677 out of 10000 .
# Iterating from 677 to 678 out of 10000 .
# Iterating from 678 to 679 out of 10000 .
# Iterating from 679 to 680 out of 10000 .
# Iterating from 680 to 681 out of 10000 .
# Iterating from 681 to 682 out of 10000 .
# Iterating from 682 to 683 out of 10000 .
# Iterating from 683 to 684 out of 10000 .
# Iterating from 684 to 685 out of 10000 .
# Iterating from 685 to 686 out of 10000 .
# Iterating from 686 to 687 out of 10000 .
# Iterating from 687 to 688 out of 10000 .
# Iterating from 688 to 689 out of 10000 .
# Iterating from 689 to 690 out of 10000 .
# Iterating from 690 to 691 out of 10000 .
# Iterating from 691 to 692 out of 10000 .
# Iterating from 692 to 693 out of 10000 .
# Iterating from 693 to 694 out of 10000 .
# Iterating from 694 to 695 out of 10000 .
# Iterating from 695 to 696 out of 10000 .
# Iterating from 696 to 697 out of 10000 .
# Iterating from 697 to 698 out of 10000 .
# Iterating from 698 to 699 out of 10000 .
# Iterating from 699 to 700 out of 10000 .
# Iterating from 700 to 701 out of 10000 .
# Iterating from 701 to 702 out of 10000 .
# Iterating from 702 to 703 out of 10000 .
# Iterating from 703 to 704 out of 10000 .
# Iterating from 704 to 705 out of 10000 .
# Iterating from 705 to 706 out of 10000 .
# Iterating from 706 to 707 out of 10000 .
# Iterating from 707 to 708 out of 10000 .
# Iterating from 708 to 709 out of 10000 .
# Iterating from 709 to 710 out of 10000 .
# Iterating from 710 to 711 out of 10000 .
# Iterating from 711 to 712 out of 10000 .
# Iterating from 712 to 713 out of 10000 .
# Iterating from 713 to 714 out of 10000 .
# Iterating from 714 to 715 out of 10000 .
# Iterating from 715 to 716 out of 10000 .
# Iterating from 716 to 717 out of 10000 .
# Iterating from 717 to 718 out of 10000 .
# Iterating from 718 to 719 out of 10000 .
# Iterating from 719 to 720 out of 10000 .
# Iterating from 720 to 721 out of 10000 .
# Iterating from 721 to 722 out of 10000 .
# Iterating from 722 to 723 out of 10000 .
# Iterating from 723 to 724 out of 10000 .
# Iterating from 724 to 725 out of 10000 .
# Iterating from 725 to 726 out of 10000 .
# Iterating from 726 to 727 out of 10000 .
# Iterating from 727 to 728 out of 10000 .
# Iterating from 728 to 729 out of 10000 .
# Iterating from 729 to 730 out of 10000 .
# Iterating from 730 to 731 out of 10000 .
# Iterating from 731 to 732 out of 10000 .
# Iterating from 732 to 733 out of 10000 .
# Iterating from 733 to 734 out of 10000 .
# Iterating from 734 to 735 out of 10000 .
# Iterating from 735 to 736 out of 10000 .
# Iterating from 736 to 737 out of 10000 .
# Iterating from 737 to 738 out of 10000 .
# Iterating from 738 to 739 out of 10000 .
# Iterating from 739 to 740 out of 10000 .
# Iterating from 740 to 741 out of 10000 .
# Iterating from 741 to 742 out of 10000 .
# Iterating from 742 to 743 out of 10000 .
# Iterating from 743 to 744 out of 10000 .
# Iterating from 744 to 745 out of 10000 .
# Iterating from 745 to 746 out of 10000 .
# Iterating from 746 to 747 out of 10000 .
# Iterating from 747 to 748 out of 10000 .
# Iterating from 748 to 749 out of 10000 .
# Iterating from 749 to 750 out of 10000 .
# Iterating from 750 to 751 out of 10000 .
# Iterating from 751 to 752 out of 10000 .
# Iterating from 752 to 753 out of 10000 .
# Iterating from 753 to 754 out of 10000 .
# Iterating from 754 to 755 out of 10000 .
# Iterating from 755 to 756 out of 10000 .
# Iterating from 756 to 757 out of 10000 .
# Iterating from 757 to 758 out of 10000 .
# Iterating from 758 to 759 out of 10000 .
# Iterating from 759 to 760 out of 10000 .
# Iterating from 760 to 761 out of 10000 .
# Iterating from 761 to 762 out of 10000 .
# Iterating from 762 to 763 out of 10000 .
# Iterating from 763 to 764 out of 10000 .
# Iterating from 764 to 765 out of 10000 .
# Iterating from 765 to 766 out of 10000 .
# Iterating from 766 to 767 out of 10000 .
# Iterating from 767 to 768 out of 10000 .
# Iterating from 768 to 769 out of 10000 .
# Iterating from 769 to 770 out of 10000 .
# Iterating from 770 to 771 out of 10000 .
# Iterating from 771 to 772 out of 10000 .
# Iterating from 772 to 773 out of 10000 .
# Iterating from 773 to 774 out of 10000 .
# Iterating from 774 to 775 out of 10000 .
# Iterating from 775 to 776 out of 10000 .
# Iterating from 776 to 777 out of 10000 .
# Iterating from 777 to 778 out of 10000 .
# Iterating from 778 to 779 out of 10000 .
# Iterating from 779 to 780 out of 10000 .
# Iterating from 780 to 781 out of 10000 .
# Iterating from 781 to 782 out of 10000 .
# Iterating from 782 to 783 out of 10000 .
# Iterating from 783 to 784 out of 10000 .
# Iterating from 784 to 785 out of 10000 .
# Iterating from 785 to 786 out of 10000 .
# Iterating from 786 to 787 out of 10000 .
# Iterating from 787 to 788 out of 10000 .
# Iterating from 788 to 789 out of 10000 .
# Iterating from 789 to 790 out of 10000 .
# Iterating from 790 to 791 out of 10000 .
# Iterating from 791 to 792 out of 10000 .
# Iterating from 792 to 793 out of 10000 .
# Iterating from 793 to 794 out of 10000 .
# Iterating from 794 to 795 out of 10000 .
# Iterating from 795 to 796 out of 10000 .
# Iterating from 796 to 797 out of 10000 .
# Iterating from 797 to 798 out of 10000 .
# Iterating from 798 to 799 out of 10000 .
# Iterating from 799 to 800 out of 10000 .
# Iterating from 800 to 801 out of 10000 .
# Iterating from 801 to 802 out of 10000 .
# Iterating from 802 to 803 out of 10000 .
# Iterating from 803 to 804 out of 10000 .
# Iterating from 804 to 805 out of 10000 .
# Iterating from 805 to 806 out of 10000 .
# Iterating from 806 to 807 out of 10000 .
# Iterating from 807 to 808 out of 10000 .
# Iterating from 808 to 809 out of 10000 .
# Iterating from 809 to 810 out of 10000 .
# Iterating from 810 to 811 out of 10000 .
# Iterating from 811 to 812 out of 10000 .
# Iterating from 812 to 813 out of 10000 .
# Iterating from 813 to 814 out of 10000 .
# Iterating from 814 to 815 out of 10000 .
# Iterating from 815 to 816 out of 10000 .
# Iterating from 816 to 817 out of 10000 .
# Iterating from 817 to 818 out of 10000 .
# Iterating from 818 to 819 out of 10000 .
# Iterating from 819 to 820 out of 10000 .
# Iterating from 820 to 821 out of 10000 .
# Iterating from 821 to 822 out of 10000 .
# Iterating from 822 to 823 out of 10000 .
# Iterating from 823 to 824 out of 10000 .
# Iterating from 824 to 825 out of 10000 .
# Iterating from 825 to 826 out of 10000 .
# Iterating from 826 to 827 out of 10000 .
# Iterating from 827 to 828 out of 10000 .
# Iterating from 828 to 829 out of 10000 .
# Iterating from 829 to 830 out of 10000 .
# Iterating from 830 to 831 out of 10000 .
# Iterating from 831 to 832 out of 10000 .
# Iterating from 832 to 833 out of 10000 .
# Iterating from 833 to 834 out of 10000 .
# Iterating from 834 to 835 out of 10000 .
# Iterating from 835 to 836 out of 10000 .
# Iterating from 836 to 837 out of 10000 .
# Iterating from 837 to 838 out of 10000 .
# Iterating from 838 to 839 out of 10000 .
# Iterating from 839 to 840 out of 10000 .
# Iterating from 840 to 841 out of 10000 .
# Iterating from 841 to 842 out of 10000 .
# Iterating from 842 to 843 out of 10000 .
# Iterating from 843 to 844 out of 10000 .
# Iterating from 844 to 845 out of 10000 .
# Iterating from 845 to 846 out of 10000 .
# Iterating from 846 to 847 out of 10000 .
# Iterating from 847 to 848 out of 10000 .
# Iterating from 848 to 849 out of 10000 .
# Iterating from 849 to 850 out of 10000 .
# Iterating from 850 to 851 out of 10000 .
# Iterating from 851 to 852 out of 10000 .
# Iterating from 852 to 853 out of 10000 .
# Iterating from 853 to 854 out of 10000 .
# Iterating from 854 to 855 out of 10000 .
# Iterating from 855 to 856 out of 10000 .
# Iterating from 856 to 857 out of 10000 .
# Iterating from 857 to 858 out of 10000 .
# Iterating from 858 to 859 out of 10000 .
# Iterating from 859 to 860 out of 10000 .
# Iterating from 860 to 861 out of 10000 .
# Iterating from 861 to 862 out of 10000 .
# Iterating from 862 to 863 out of 10000 .
# Iterating from 863 to 864 out of 10000 .
# Iterating from 864 to 865 out of 10000 .
# Iterating from 865 to 866 out of 10000 .
# Iterating from 866 to 867 out of 10000 .
# Iterating from 867 to 868 out of 10000 .
# Iterating from 868 to 869 out of 10000 .
# Iterating from 869 to 870 out of 10000 .
# Iterating from 870 to 871 out of 10000 .
# Iterating from 871 to 872 out of 10000 .
# Iterating from 872 to 873 out of 10000 .
# Iterating from 873 to 874 out of 10000 .
# Iterating from 874 to 875 out of 10000 .
# Iterating from 875 to 876 out of 10000 .
# Iterating from 876 to 877 out of 10000 .
# Iterating from 877 to 878 out of 10000 .
# Iterating from 878 to 879 out of 10000 .
# Iterating from 879 to 880 out of 10000 .
# Iterating from 880 to 881 out of 10000 .
# Iterating from 881 to 882 out of 10000 .
# Iterating from 882 to 883 out of 10000 .
# Iterating from 883 to 884 out of 10000 .
# Iterating from 884 to 885 out of 10000 .
# Iterating from 885 to 886 out of 10000 .
# Iterating from 886 to 887 out of 10000 .
# Iterating from 887 to 888 out of 10000 .
# Iterating from 888 to 889 out of 10000 .
# Iterating from 889 to 890 out of 10000 .
# Iterating from 890 to 891 out of 10000 .
# Iterating from 891 to 892 out of 10000 .
# Iterating from 892 to 893 out of 10000 .
# Iterating from 893 to 894 out of 10000 .
# Iterating from 894 to 895 out of 10000 .
# Iterating from 895 to 896 out of 10000 .
# Iterating from 896 to 897 out of 10000 .
# Iterating from 897 to 898 out of 10000 .
# Iterating from 898 to 899 out of 10000 .
# Iterating from 899 to 900 out of 10000 .
# Iterating from 900 to 901 out of 10000 .
# Iterating from 901 to 902 out of 10000 .
# Iterating from 902 to 903 out of 10000 .
# Iterating from 903 to 904 out of 10000 .
# Iterating from 904 to 905 out of 10000 .
# Iterating from 905 to 906 out of 10000 .
# Iterating from 906 to 907 out of 10000 .
# Iterating from 907 to 908 out of 10000 .
# Iterating from 908 to 909 out of 10000 .
# Iterating from 909 to 910 out of 10000 .
# Iterating from 910 to 911 out of 10000 .
# Iterating from 911 to 912 out of 10000 .
# Iterating from 912 to 913 out of 10000 .
# Iterating from 913 to 914 out of 10000 .
# Iterating from 914 to 915 out of 10000 .
# Iterating from 915 to 916 out of 10000 .
# Iterating from 916 to 917 out of 10000 .
# Iterating from 917 to 918 out of 10000 .
# Iterating from 918 to 919 out of 10000 .
# Iterating from 919 to 920 out of 10000 .
# Iterating from 920 to 921 out of 10000 .
# Iterating from 921 to 922 out of 10000 .
# Iterating from 922 to 923 out of 10000 .
# Iterating from 923 to 924 out of 10000 .
# Iterating from 924 to 925 out of 10000 .
# Iterating from 925 to 926 out of 10000 .
# Iterating from 926 to 927 out of 10000 .
# Iterating from 927 to 928 out of 10000 .
# Iterating from 928 to 929 out of 10000 .
# Iterating from 929 to 930 out of 10000 .
# Iterating from 930 to 931 out of 10000 .
# Iterating from 931 to 932 out of 10000 .
# Iterating from 932 to 933 out of 10000 .
# Iterating from 933 to 934 out of 10000 .
# Iterating from 934 to 935 out of 10000 .
# Iterating from 935 to 936 out of 10000 .
# Iterating from 936 to 937 out of 10000 .
# Iterating from 937 to 938 out of 10000 .
# Iterating from 938 to 939 out of 10000 .
# Iterating from 939 to 940 out of 10000 .
# Iterating from 940 to 941 out of 10000 .
# Iterating from 941 to 942 out of 10000 .
# Iterating from 942 to 943 out of 10000 .
# Iterating from 943 to 944 out of 10000 .
# Iterating from 944 to 945 out of 10000 .
# Iterating from 945 to 946 out of 10000 .
# Iterating from 946 to 947 out of 10000 .
# Iterating from 947 to 948 out of 10000 .
# Iterating from 948 to 949 out of 10000 .
# Iterating from 949 to 950 out of 10000 .
# Iterating from 950 to 951 out of 10000 .
# Iterating from 951 to 952 out of 10000 .
# Iterating from 952 to 953 out of 10000 .
# Iterating from 953 to 954 out of 10000 .
# Iterating from 954 to 955 out of 10000 .
# Iterating from 955 to 956 out of 10000 .
# Iterating from 956 to 957 out of 10000 .
# Iterating from 957 to 958 out of 10000 .
# Iterating from 958 to 959 out of 10000 .
# Iterating from 959 to 960 out of 10000 .
# Iterating from 960 to 961 out of 10000 .
# Iterating from 961 to 962 out of 10000 .
# Iterating from 962 to 963 out of 10000 .
# Iterating from 963 to 964 out of 10000 .
# Iterating from 964 to 965 out of 10000 .
# Iterating from 965 to 966 out of 10000 .
# Iterating from 966 to 967 out of 10000 .
# Iterating from 967 to 968 out of 10000 .
# Iterating from 968 to 969 out of 10000 .
# Iterating from 969 to 970 out of 10000 .
# Iterating from 970 to 971 out of 10000 .
# Iterating from 971 to 972 out of 10000 .
# Iterating from 972 to 973 out of 10000 .
# Iterating from 973 to 974 out of 10000 .
# Iterating from 974 to 975 out of 10000 .
# Iterating from 975 to 976 out of 10000 .
# Iterating from 976 to 977 out of 10000 .
# Iterating from 977 to 978 out of 10000 .
# Iterating from 978 to 979 out of 10000 .
# Iterating from 979 to 980 out of 10000 .
# Iterating from 980 to 981 out of 10000 .
# Iterating from 981 to 982 out of 10000 .
# Iterating from 982 to 983 out of 10000 .
# Iterating from 983 to 984 out of 10000 .
# Iterating from 984 to 985 out of 10000 .
# Iterating from 985 to 986 out of 10000 .
# Iterating from 986 to 987 out of 10000 .
# Iterating from 987 to 988 out of 10000 .
# Iterating from 988 to 989 out of 10000 .
# Iterating from 989 to 990 out of 10000 .
# Iterating from 990 to 991 out of 10000 .
# Iterating from 991 to 992 out of 10000 .
# Iterating from 992 to 993 out of 10000 .
# Iterating from 993 to 994 out of 10000 .
# Iterating from 994 to 995 out of 10000 .
# Iterating from 995 to 996 out of 10000 .
# Iterating from 996 to 997 out of 10000 .
# Iterating from 997 to 998 out of 10000 .
# Iterating from 998 to 999 out of 10000 .
# Iterating from 999 to 1000 out of 10000 .
# Iterating from 1000 to 1001 out of 10000 .
# Iterating from 1001 to 1002 out of 10000 .
# Iterating from 1002 to 1003 out of 10000 .
# Iterating from 1003 to 1004 out of 10000 .
# Iterating from 1004 to 1005 out of 10000 .
# Iterating from 1005 to 1006 out of 10000 .
# Iterating from 1006 to 1007 out of 10000 .
# Iterating from 1007 to 1008 out of 10000 .
# Iterating from 1008 to 1009 out of 10000 .
# Iterating from 1009 to 1010 out of 10000 .
# Iterating from 1010 to 1011 out of 10000 .
# Iterating from 1011 to 1012 out of 10000 .
# Iterating from 1012 to 1013 out of 10000 .
# Iterating from 1013 to 1014 out of 10000 .
# Iterating from 1014 to 1015 out of 10000 .
# Iterating from 1015 to 1016 out of 10000 .
# Iterating from 1016 to 1017 out of 10000 .
# Iterating from 1017 to 1018 out of 10000 .
# Iterating from 1018 to 1019 out of 10000 .
# Iterating from 1019 to 1020 out of 10000 .
# Iterating from 1020 to 1021 out of 10000 .
# Iterating from 1021 to 1022 out of 10000 .
# Iterating from 1022 to 1023 out of 10000 .
# Iterating from 1023 to 1024 out of 10000 .
# Iterating from 1024 to 1025 out of 10000 .
# Iterating from 1025 to 1026 out of 10000 .
# Iterating from 1026 to 1027 out of 10000 .
# Iterating from 1027 to 1028 out of 10000 .
# Iterating from 1028 to 1029 out of 10000 .
# Iterating from 1029 to 1030 out of 10000 .
# Iterating from 1030 to 1031 out of 10000 .
# Iterating from 1031 to 1032 out of 10000 .
# Iterating from 1032 to 1033 out of 10000 .
# Iterating from 1033 to 1034 out of 10000 .
# Iterating from 1034 to 1035 out of 10000 .
# Iterating from 1035 to 1036 out of 10000 .
# Iterating from 1036 to 1037 out of 10000 .
# Iterating from 1037 to 1038 out of 10000 .
# Iterating from 1038 to 1039 out of 10000 .
# Iterating from 1039 to 1040 out of 10000 .
# Iterating from 1040 to 1041 out of 10000 .
# Iterating from 1041 to 1042 out of 10000 .
# Iterating from 1042 to 1043 out of 10000 .
# Iterating from 1043 to 1044 out of 10000 .
# Iterating from 1044 to 1045 out of 10000 .
# Iterating from 1045 to 1046 out of 10000 .
# Iterating from 1046 to 1047 out of 10000 .
# Iterating from 1047 to 1048 out of 10000 .
# Iterating from 1048 to 1049 out of 10000 .
# Iterating from 1049 to 1050 out of 10000 .
# Iterating from 1050 to 1051 out of 10000 .
# Iterating from 1051 to 1052 out of 10000 .
# Iterating from 1052 to 1053 out of 10000 .
# Iterating from 1053 to 1054 out of 10000 .
# Iterating from 1054 to 1055 out of 10000 .
# Iterating from 1055 to 1056 out of 10000 .
# Iterating from 1056 to 1057 out of 10000 .
# Iterating from 1057 to 1058 out of 10000 .
# Iterating from 1058 to 1059 out of 10000 .
# Iterating from 1059 to 1060 out of 10000 .
# Iterating from 1060 to 1061 out of 10000 .
# Iterating from 1061 to 1062 out of 10000 .
# Iterating from 1062 to 1063 out of 10000 .
# Iterating from 1063 to 1064 out of 10000 .
# Iterating from 1064 to 1065 out of 10000 .
# Iterating from 1065 to 1066 out of 10000 .
# Iterating from 1066 to 1067 out of 10000 .
# Iterating from 1067 to 1068 out of 10000 .
# Iterating from 1068 to 1069 out of 10000 .
# Iterating from 1069 to 1070 out of 10000 .
# Iterating from 1070 to 1071 out of 10000 .
# Iterating from 1071 to 1072 out of 10000 .
# Iterating from 1072 to 1073 out of 10000 .
# Iterating from 1073 to 1074 out of 10000 .
# Iterating from 1074 to 1075 out of 10000 .
# Iterating from 1075 to 1076 out of 10000 .
# Iterating from 1076 to 1077 out of 10000 .
# Iterating from 1077 to 1078 out of 10000 .
# Iterating from 1078 to 1079 out of 10000 .
# Iterating from 1079 to 1080 out of 10000 .
# Iterating from 1080 to 1081 out of 10000 .
# Iterating from 1081 to 1082 out of 10000 .
# Iterating from 1082 to 1083 out of 10000 .
# Iterating from 1083 to 1084 out of 10000 .
# Iterating from 1084 to 1085 out of 10000 .
# Iterating from 1085 to 1086 out of 10000 .
# Iterating from 1086 to 1087 out of 10000 .
# Iterating from 1087 to 1088 out of 10000 .
# Iterating from 1088 to 1089 out of 10000 .
# Iterating from 1089 to 1090 out of 10000 .
# Iterating from 1090 to 1091 out of 10000 .
# Iterating from 1091 to 1092 out of 10000 .
# Iterating from 1092 to 1093 out of 10000 .
# Iterating from 1093 to 1094 out of 10000 .
# Iterating from 1094 to 1095 out of 10000 .
# Iterating from 1095 to 1096 out of 10000 .
# Iterating from 1096 to 1097 out of 10000 .
# Iterating from 1097 to 1098 out of 10000 .
# Iterating from 1098 to 1099 out of 10000 .
# Iterating from 1099 to 1100 out of 10000 .
# Iterating from 1100 to 1101 out of 10000 .
# Iterating from 1101 to 1102 out of 10000 .
# Iterating from 1102 to 1103 out of 10000 .
# Iterating from 1103 to 1104 out of 10000 .
# Iterating from 1104 to 1105 out of 10000 .
# Iterating from 1105 to 1106 out of 10000 .
# Iterating from 1106 to 1107 out of 10000 .
# Iterating from 1107 to 1108 out of 10000 .
# Iterating from 1108 to 1109 out of 10000 .
# Iterating from 1109 to 1110 out of 10000 .
# Iterating from 1110 to 1111 out of 10000 .
# Iterating from 1111 to 1112 out of 10000 .
# Iterating from 1112 to 1113 out of 10000 .
# Iterating from 1113 to 1114 out of 10000 .
# Iterating from 1114 to 1115 out of 10000 .
# Iterating from 1115 to 1116 out of 10000 .
# Iterating from 1116 to 1117 out of 10000 .
# Iterating from 1117 to 1118 out of 10000 .
# Iterating from 1118 to 1119 out of 10000 .
# Iterating from 1119 to 1120 out of 10000 .
# Iterating from 1120 to 1121 out of 10000 .
# Iterating from 1121 to 1122 out of 10000 .
# Iterating from 1122 to 1123 out of 10000 .
# Iterating from 1123 to 1124 out of 10000 .
# Iterating from 1124 to 1125 out of 10000 .
# Iterating from 1125 to 1126 out of 10000 .
# Iterating from 1126 to 1127 out of 10000 .
# Iterating from 1127 to 1128 out of 10000 .
# Iterating from 1128 to 1129 out of 10000 .
# Iterating from 1129 to 1130 out of 10000 .
# Iterating from 1130 to 1131 out of 10000 .
# Iterating from 1131 to 1132 out of 10000 .
# Iterating from 1132 to 1133 out of 10000 .
# Iterating from 1133 to 1134 out of 10000 .
# Iterating from 1134 to 1135 out of 10000 .
# Iterating from 1135 to 1136 out of 10000 .
# Iterating from 1136 to 1137 out of 10000 .
# Iterating from 1137 to 1138 out of 10000 .
# Iterating from 1138 to 1139 out of 10000 .
# Iterating from 1139 to 1140 out of 10000 .
# Iterating from 1140 to 1141 out of 10000 .
# Iterating from 1141 to 1142 out of 10000 .
# Iterating from 1142 to 1143 out of 10000 .
# Iterating from 1143 to 1144 out of 10000 .
# Iterating from 1144 to 1145 out of 10000 .
# Iterating from 1145 to 1146 out of 10000 .
# Iterating from 1146 to 1147 out of 10000 .
# Iterating from 1147 to 1148 out of 10000 .
# Iterating from 1148 to 1149 out of 10000 .
# Iterating from 1149 to 1150 out of 10000 .
# Iterating from 1150 to 1151 out of 10000 .
# Iterating from 1151 to 1152 out of 10000 .
# Iterating from 1152 to 1153 out of 10000 .
# Iterating from 1153 to 1154 out of 10000 .
# Iterating from 1154 to 1155 out of 10000 .
# Iterating from 1155 to 1156 out of 10000 .
# Iterating from 1156 to 1157 out of 10000 .
# Iterating from 1157 to 1158 out of 10000 .
# Iterating from 1158 to 1159 out of 10000 .
# Iterating from 1159 to 1160 out of 10000 .
# Iterating from 1160 to 1161 out of 10000 .
# Iterating from 1161 to 1162 out of 10000 .
# Iterating from 1162 to 1163 out of 10000 .
# Iterating from 1163 to 1164 out of 10000 .
# Iterating from 1164 to 1165 out of 10000 .
# Iterating from 1165 to 1166 out of 10000 .
# Iterating from 1166 to 1167 out of 10000 .
# Iterating from 1167 to 1168 out of 10000 .
# Iterating from 1168 to 1169 out of 10000 .
# Iterating from 1169 to 1170 out of 10000 .
# Iterating from 1170 to 1171 out of 10000 .
# Iterating from 1171 to 1172 out of 10000 .
# Iterating from 1172 to 1173 out of 10000 .
# Iterating from 1173 to 1174 out of 10000 .
# Iterating from 1174 to 1175 out of 10000 .
# Iterating from 1175 to 1176 out of 10000 .
# Iterating from 1176 to 1177 out of 10000 .
# Iterating from 1177 to 1178 out of 10000 .
# Iterating from 1178 to 1179 out of 10000 .
# Iterating from 1179 to 1180 out of 10000 .
# Iterating from 1180 to 1181 out of 10000 .
# Iterating from 1181 to 1182 out of 10000 .
# Iterating from 1182 to 1183 out of 10000 .
# Iterating from 1183 to 1184 out of 10000 .
# Iterating from 1184 to 1185 out of 10000 .
# Iterating from 1185 to 1186 out of 10000 .
# Iterating from 1186 to 1187 out of 10000 .
# Iterating from 1187 to 1188 out of 10000 .
# Iterating from 1188 to 1189 out of 10000 .
# Iterating from 1189 to 1190 out of 10000 .
# Iterating from 1190 to 1191 out of 10000 .
# Iterating from 1191 to 1192 out of 10000 .
# Iterating from 1192 to 1193 out of 10000 .
# Iterating from 1193 to 1194 out of 10000 .
# Iterating from 1194 to 1195 out of 10000 .
# Iterating from 1195 to 1196 out of 10000 .
# Iterating from 1196 to 1197 out of 10000 .
# Iterating from 1197 to 1198 out of 10000 .
# Iterating from 1198 to 1199 out of 10000 .
# Iterating from 1199 to 1200 out of 10000 .
# Iterating from 1200 to 1201 out of 10000 .
# Iterating from 1201 to 1202 out of 10000 .
# Iterating from 1202 to 1203 out of 10000 .
# Iterating from 1203 to 1204 out of 10000 .
# Iterating from 1204 to 1205 out of 10000 .
# Iterating from 1205 to 1206 out of 10000 .
# Iterating from 1206 to 1207 out of 10000 .
# Iterating from 1207 to 1208 out of 10000 .
# Iterating from 1208 to 1209 out of 10000 .
# Iterating from 1209 to 1210 out of 10000 .
# Iterating from 1210 to 1211 out of 10000 .
# Iterating from 1211 to 1212 out of 10000 .
# Iterating from 1212 to 1213 out of 10000 .
# Iterating from 1213 to 1214 out of 10000 .
# Iterating from 1214 to 1215 out of 10000 .
# Iterating from 1215 to 1216 out of 10000 .
# Iterating from 1216 to 1217 out of 10000 .
# Iterating from 1217 to 1218 out of 10000 .
# Iterating from 1218 to 1219 out of 10000 .
# Iterating from 1219 to 1220 out of 10000 .
# Iterating from 1220 to 1221 out of 10000 .
# Iterating from 1221 to 1222 out of 10000 .
# Iterating from 1222 to 1223 out of 10000 .
# Iterating from 1223 to 1224 out of 10000 .
# Iterating from 1224 to 1225 out of 10000 .
# Iterating from 1225 to 1226 out of 10000 .
# Iterating from 1226 to 1227 out of 10000 .
# Iterating from 1227 to 1228 out of 10000 .
# Iterating from 1228 to 1229 out of 10000 .
# Iterating from 1229 to 1230 out of 10000 .
# Iterating from 1230 to 1231 out of 10000 .
# Iterating from 1231 to 1232 out of 10000 .
# Iterating from 1232 to 1233 out of 10000 .
# Iterating from 1233 to 1234 out of 10000 .
# Iterating from 1234 to 1235 out of 10000 .
# Iterating from 1235 to 1236 out of 10000 .
# Iterating from 1236 to 1237 out of 10000 .
# Iterating from 1237 to 1238 out of 10000 .
# Iterating from 1238 to 1239 out of 10000 .
# Iterating from 1239 to 1240 out of 10000 .
# Iterating from 1240 to 1241 out of 10000 .
# Iterating from 1241 to 1242 out of 10000 .
# Iterating from 1242 to 1243 out of 10000 .
# Iterating from 1243 to 1244 out of 10000 .
# Iterating from 1244 to 1245 out of 10000 .
# Iterating from 1245 to 1246 out of 10000 .
# Iterating from 1246 to 1247 out of 10000 .
# Iterating from 1247 to 1248 out of 10000 .
# Iterating from 1248 to 1249 out of 10000 .
# Iterating from 1249 to 1250 out of 10000 .
# Iterating from 1250 to 1251 out of 10000 .
# Iterating from 1251 to 1252 out of 10000 .
# Iterating from 1252 to 1253 out of 10000 .
# Iterating from 1253 to 1254 out of 10000 .
# Iterating from 1254 to 1255 out of 10000 .
# Iterating from 1255 to 1256 out of 10000 .
# Iterating from 1256 to 1257 out of 10000 .
# Iterating from 1257 to 1258 out of 10000 .
# Iterating from 1258 to 1259 out of 10000 .
# Iterating from 1259 to 1260 out of 10000 .
# Iterating from 1260 to 1261 out of 10000 .
# Iterating from 1261 to 1262 out of 10000 .
# Iterating from 1262 to 1263 out of 10000 .
# Iterating from 1263 to 1264 out of 10000 .
# Iterating from 1264 to 1265 out of 10000 .
# Iterating from 1265 to 1266 out of 10000 .
# Iterating from 1266 to 1267 out of 10000 .
# Iterating from 1267 to 1268 out of 10000 .
# Iterating from 1268 to 1269 out of 10000 .
# Iterating from 1269 to 1270 out of 10000 .
# Iterating from 1270 to 1271 out of 10000 .
# Iterating from 1271 to 1272 out of 10000 .
# Iterating from 1272 to 1273 out of 10000 .
# Iterating from 1273 to 1274 out of 10000 .
# Iterating from 1274 to 1275 out of 10000 .
# Iterating from 1275 to 1276 out of 10000 .
# Iterating from 1276 to 1277 out of 10000 .
# Iterating from 1277 to 1278 out of 10000 .
# Iterating from 1278 to 1279 out of 10000 .
# Iterating from 1279 to 1280 out of 10000 .
# Iterating from 1280 to 1281 out of 10000 .
# Iterating from 1281 to 1282 out of 10000 .
# Iterating from 1282 to 1283 out of 10000 .
# Iterating from 1283 to 1284 out of 10000 .
# Iterating from 1284 to 1285 out of 10000 .
# Iterating from 1285 to 1286 out of 10000 .
# Iterating from 1286 to 1287 out of 10000 .
# Iterating from 1287 to 1288 out of 10000 .
# Iterating from 1288 to 1289 out of 10000 .
# Iterating from 1289 to 1290 out of 10000 .
# Iterating from 1290 to 1291 out of 10000 .
# Iterating from 1291 to 1292 out of 10000 .
# Iterating from 1292 to 1293 out of 10000 .
# Iterating from 1293 to 1294 out of 10000 .
# Iterating from 1294 to 1295 out of 10000 .
# Iterating from 1295 to 1296 out of 10000 .
# Iterating from 1296 to 1297 out of 10000 .
# Iterating from 1297 to 1298 out of 10000 .
# Iterating from 1298 to 1299 out of 10000 .
# Iterating from 1299 to 1300 out of 10000 .
# Iterating from 1300 to 1301 out of 10000 .
# Iterating from 1301 to 1302 out of 10000 .
# Iterating from 1302 to 1303 out of 10000 .
# Iterating from 1303 to 1304 out of 10000 .
# Iterating from 1304 to 1305 out of 10000 .
# Iterating from 1305 to 1306 out of 10000 .
# Iterating from 1306 to 1307 out of 10000 .
# Iterating from 1307 to 1308 out of 10000 .
# Iterating from 1308 to 1309 out of 10000 .
# Iterating from 1309 to 1310 out of 10000 .
# Iterating from 1310 to 1311 out of 10000 .
# Iterating from 1311 to 1312 out of 10000 .
# Iterating from 1312 to 1313 out of 10000 .
# Iterating from 1313 to 1314 out of 10000 .
# Iterating from 1314 to 1315 out of 10000 .
# Iterating from 1315 to 1316 out of 10000 .
# Iterating from 1316 to 1317 out of 10000 .
# Iterating from 1317 to 1318 out of 10000 .
# Iterating from 1318 to 1319 out of 10000 .
# Iterating from 1319 to 1320 out of 10000 .
# Iterating from 1320 to 1321 out of 10000 .
# Iterating from 1321 to 1322 out of 10000 .
# Iterating from 1322 to 1323 out of 10000 .
# Iterating from 1323 to 1324 out of 10000 .
# Iterating from 1324 to 1325 out of 10000 .
# Iterating from 1325 to 1326 out of 10000 .
# Iterating from 1326 to 1327 out of 10000 .
# Iterating from 1327 to 1328 out of 10000 .
# Iterating from 1328 to 1329 out of 10000 .
# Iterating from 1329 to 1330 out of 10000 .
# Iterating from 1330 to 1331 out of 10000 .
# Iterating from 1331 to 1332 out of 10000 .
# Iterating from 1332 to 1333 out of 10000 .
# Iterating from 1333 to 1334 out of 10000 .
# Iterating from 1334 to 1335 out of 10000 .
# Iterating from 1335 to 1336 out of 10000 .
# Iterating from 1336 to 1337 out of 10000 .
# Iterating from 1337 to 1338 out of 10000 .
# Iterating from 1338 to 1339 out of 10000 .
# Iterating from 1339 to 1340 out of 10000 .
# Iterating from 1340 to 1341 out of 10000 .
# Iterating from 1341 to 1342 out of 10000 .
# Iterating from 1342 to 1343 out of 10000 .
# Iterating from 1343 to 1344 out of 10000 .
# Iterating from 1344 to 1345 out of 10000 .

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fn: [[0.68, [6800, 3199], 0.7273971147598925], [0.95, [9500, 500], 1.1976979866809125], [0.99, [9900, 100], 1.5272186802671115]]
# Computing time for metric fn: 36.711499811994145
# ThresholdS for metric fpd: [[0.68, [6800, 3199], 0.7603198140599615], [0.95, [9500, 500], 1.0564703611749042], [0.99, [9900, 100], 1.3860494412310478]]
# Computing time for metric fpd: 606.7347321969864
# ThresholdS for metric kpd: [[0.68, [6800, 3199], 0.3039724341280525], [0.95, [9500, 500], 1.302956129920485], [0.99, [9900, 100], 2.3135020940445727]]
# Computing time for metric kpd: 21885.26378197901
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9160017967224121], [0.95, [9500, 500], 1.1319997906684875], [0.99, [9900, 100], 1.309000849723816]]
# Computing time for metric ks: 73.37600612200913
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9108503349125385], [0.95, [9500, 500], 1.1089506559073925], [0.99, [9900, 100], 1.2629506178200245]]
# Computing time for metric sks: 1429.8128464320034
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.6885463628737355], [0.95, [9500, 500], 0.9806132715456718], [0.99, [9900, 100], 1.1990690186585224]]
# Computing time for metric swd: 926.4212351279857
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f0ec556b490>
# 1          metric_list  <function <lambda> at 0x7f0ec556bb50>
# 2          metric_list  <function <lambda> at 0x7f0eb8728b80>
# 3      statistic_means  <function <lambda> at 0x7f0eb8728c10>
# 4         metric_means  <function <lambda> at 0x7f0eb8728ca0>
# 5         metric_means  <function <lambda> at 0x7f0eb8728d30>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f0eb8728dc0>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1              lambda ns, ndims: 10000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...           2000
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...           5000
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
# 6  {'niter': 10000, 'batch_size_test': 20000, 'ba...           1000
#
#                         latex                                   null_file  \
# 0  $\overline{\|\cdot\|}_{F}$   ../results/5D_20K/null_hypothesis/FN.json
# 1          $d_{\mathrm{FPD}}$  ../results/5D_20K/null_hypothesis/FPD.json
# 2          $d_{\mathrm{KPD}}$  ../results/5D_20K/null_hypothesis/KPD.json
# 3              $\overline{D}$   ../results/5D_20K/null_hypothesis/KS.json
# 4             $\widetilde{D}$  ../results/5D_20K/null_hypothesis/SKS.json
# 5             $\widetilde{W}$  ../results/5D_20K/null_hypothesis/SWD.json
# 6                   $t_{\mu}$   ../results/5D_20K/null_hypothesis/LR.json
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.7273971147598925], [0....
# 1  [[0.68, [6800, 3199], 0.7603198140599615], [0....
# 2  [[0.68, [6800, 3199], 0.3039724341280525], [0....
# 3  [[0.68, [6800, 3199], 0.9160017967224121], [0....
# 4  [[0.68, [6800, 3199], 0.9108503349125385], [0....
# 5  [[0.68, [6800, 3199], 0.6885463628737355], [0....
# 6                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.646109218928857 +/- 0.0008092928278313957
# sigma = 0.284480724800714 +/- 0.0026860877510946277
# /tmp/ipykernel_18751/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_18751/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_18751/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_18751/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.65878333200817 seconds.
# mu = 0.7463154285759117 +/- 0.0002636776032112809
# sigma = 0.16238152703164266 +/- 0.0028365875012072365
# /tmp/ipykernel_18751/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_18751/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_18751/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_18751/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.4706849189824425 seconds.
# mu = 0.24312745888825993 +/- 0.0030465148556061477
# sigma = 0.551952430523333 +/- 0.009044892096418728
# /tmp/ipykernel_18751/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_18751/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_18751/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_18751/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3365799879829865 seconds.
# mu = 0.8673682661131025 +/- 0.00021150451882098395
# sigma = 0.14543194931684852 +/- 0.001325720177430651
# /tmp/ipykernel_18751/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_18751/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_18751/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_18751/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.8884250959963538 seconds.
# mu = 0.8683062179060653 +/- 0.00017048418516868815
# sigma = 0.13056959261967854 +/- 0.0012143195048050744
# /tmp/ipykernel_18751/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_18751/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_18751/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_18751/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.9714800989895593 seconds.
# mu = 0.6356181715959718 +/- 0.00033254467156421927
# sigma = 0.1823580740094113 +/- 0.0017555101172213273
# /tmp/ipykernel_18751/3831742232.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_18751/3831742232.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_18751/3831742232.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_18751/3831742232.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.37400386101217 seconds.
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f0ec556b490>
# 1          metric_list  <function <lambda> at 0x7f0ec556bb50>
# 2          metric_list  <function <lambda> at 0x7f0eb8728b80>
# 3      statistic_means  <function <lambda> at 0x7f0eb8728c10>
# 4         metric_means  <function <lambda> at 0x7f0eb8728ca0>
# 5         metric_means  <function <lambda> at 0x7f0eb8728d30>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f0eb8728dc0>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1              lambda ns, ndims: 10000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 20000, 'ba...           2000
# 1  {'niter': 10000, 'batch_size_test': 20000, 'ba...            500
# 2  {'niter': 10000, 'batch_size_test': 20000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 20000, 'ba...           5000
# 4  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
# 5  {'niter': 10000, 'batch_size_test': 20000, 'ba...            200
# 6  {'niter': 10000, 'batch_size_test': 20000, 'ba...           1000
#
#                         latex                                   null_file  \
# 0  $\overline{\|\cdot\|}_{F}$   ../results/5D_20K/null_hypothesis/FN.json
# 1          $d_{\mathrm{FPD}}$  ../results/5D_20K/null_hypothesis/FPD.json
# 2          $d_{\mathrm{KPD}}$  ../results/5D_20K/null_hypothesis/KPD.json
# 3              $\overline{D}$   ../results/5D_20K/null_hypothesis/KS.json
# 4             $\widetilde{D}$  ../results/5D_20K/null_hypothesis/SKS.json
# 5             $\widetilde{W}$  ../results/5D_20K/null_hypothesis/SWD.json
# 6                   $t_{\mu}$   ../results/5D_20K/null_hypothesis/LR.json
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.7273971147598925], [0....
# 1  [[0.68, [6800, 3199], 0.7603198140599615], [0....
# 2  [[0.68, [6800, 3199], 0.3039724341280525], [0....
# 3  [[0.68, [6800, 3199], 0.9160017967224121], [0....
# 4  [[0.68, [6800, 3199], 0.9108503349125385], [0....
# 5  [[0.68, [6800, 3199], 0.6885463628737355], [0....
# 6                                                 []
#
#                                  null_figure
# 0   ../results/5D_20K/null_hypothesis/FN.pdf
# 1  ../results/5D_20K/null_hypothesis/FPD.pdf
# 2  ../results/5D_20K/null_hypothesis/KPD.pdf
# 3   ../results/5D_20K/null_hypothesis/KS.pdf
# 4  ../results/5D_20K/null_hypothesis/SKS.pdf
# 5  ../results/5D_20K/null_hypothesis/SWD.pdf
# 6                                        NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.01,
                                                 fn_tol = 0.01,
                                                 eps_min = 0.,
                                                 eps_max = 5,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fn with mean deformation.
#
# ======================================================
# =============== fn - only mean ===============
# ======================================================
# ------------ 1 ------------
# eps = 2.5
# statistic = 35.96611059119897 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8710898551561488
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 22.156472876202237 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7948635395856565
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 12.902214177616125 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6602254048890737
#
# ------------ 4 ------------
# eps = 0.3125
# WARNING:tensorflow:5 out of the last 107 calls to <function generate_and_clean_data_simple_1 at 0x7f0fecdc2b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 6.952889265830589 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.412215120420013
#
# ------------ 5 ------------
# eps = 0.15625
# WARNING:tensorflow:6 out of the last 109 calls to <function generate_and_clean_data_simple_1 at 0x7f0fecdc2b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f138c8df130> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 3.6374773115586514 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0091792642000121
#
# ------------ 6 ------------
# eps = 0.078125
# WARNING:tensorflow:6 out of the last 6 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f139c847e20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.923848548859401 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.46525051214897095
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.1148226151692326 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.07167535843388811
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.506047633111175 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.2280907228646561
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 1.3054560851442463 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.0860978552428957
#
# ------------ 10 ------------
# eps = 0.0439453125
# statistic = 1.2086423515727465 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.009096273472086264
#
# ------------ 11 ------------
# eps = 0.04150390625
# statistic = 1.1613246777409085 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.05714285714285714
# relative_error_metric = 0.030837608717014034
#
# ------------ 12 ------------
# eps = 0.042724609375
# statistic = 1.1848858679774905 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.028169014084507043
# relative_error_metric = 0.010754810310975546
#
# ------------ 13 ------------
# eps = 0.0433349609375
# statistic = 1.1967402245291887 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.013986013986013986
# relative_error_metric = 0.000799989030612567
#
# ------------ 14 ------------
# eps = 0.04364013671875
# statistic = 1.202685381954007 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.007017543859649123
# relative_error_metric = 0.004155498940930296
# =======> statistic within required accuracy at 0.95 CL in 315.5405412389955 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.043487548828125
# statistic = 1.19971131858975 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.965509938583487
# relative_error_metric = 0.2402022507469232
#
# ------------ 2 ------------
# eps = 2.5217437744140625
# statistic = 36.185897399632616 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.9321892751985248
# relative_error_metric = 1.8380172376070418
#
# ------------ 3 ------------
# eps = 1.2826156616210938
# statistic = 22.562887551943472 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.8688260506860743
# relative_error_metric = 1.7464156171756378
#
# ------------ 4 ------------
# eps = 0.6630516052246094
# statistic = 13.56228379133725 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.7537996382582404
# relative_error_metric = 1.5951573133332784
#
# ------------ 5 ------------
# eps = 0.3532695770263672
# statistic = 7.782140708546703 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.5615700790808356
# relative_error_metric = 1.343792148747753
#
# ------------ 6 ------------
# eps = 0.1983785629272461
# statistic = 4.551323607306879 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.280799637245431
# relative_error_metric = 0.9950099165129668
#
# ------------ 7 ------------
# eps = 0.12093305587768555
# statistic = 2.8630163333735696 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.9420413845105347
# relative_error_metric = 0.6085312740461809
#
# ------------ 8 ------------
# eps = 0.08221030235290527
# statistic = 2.0127542071936206 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.6161243515453847
# relative_error_metric = 0.27431595798169517
#
# ------------ 9 ------------
# eps = 0.06284892559051514
# statistic = 1.5956285859766786 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.3641530691748457
# relative_error_metric = 0.0438125209958485
#
# ------------ 10 ------------
# eps = 0.05316823720932007
# statistic = 1.3936063980415576 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.16688372905476395
# relative_error_metric = 0.09148941045310616
#
# ------------ 11 ------------
# eps = 0.0580085813999176
# statistic = 1.4938166406968216 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.0801000171380451
# relative_error_metric = 0.02211297520323738
#
# ------------ 12 ------------
# eps = 0.06042875349521637
# statistic = 1.5445460977551437 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.04086839842253493
# relative_error_metric = 0.011281734598954828
#
# ------------ 13 ------------
# eps = 0.059218667447566986
# statistic = 1.5191344393177661 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.020227532496969732
# relative_error_metric = 0.00530748776126582
#
# ------------ 14 ------------
# eps = 0.05982371047139168
# statistic = 1.5318288964822337 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.010165170326765335
# relative_error_metric = 0.0030141513653875475
#
# ------------ 15 ------------
# eps = 0.05952118895947933
# statistic = 1.5254787804737835 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.005069701568395515
# relative_error_metric = 0.0011399097458584886
# =======> statistic within required accuracy at 0.99 CL in 314.6546500659897 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 630.1952148650016 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# Computing exclusion limits for fn with std deformation.
#
# ======================================================
# =============== fn - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 16.67563154385413 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.731958618088533
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 3.973810444597074 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0736180728724545
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 3.162304404519098 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9011951102611498
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 2.310778332626142 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6345092539573246
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 1.3968277027678084 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.15349989934322564
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 0.8904432105448056 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2942854406055705
#
# ------------ 7 ------------
# eps = 0.1171875
# statistic = 1.138602052620953 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.05058933618613351
#
# ------------ 8 ------------
# eps = 0.13671875
# statistic = 1.2677516169358238 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.05682828004445504
#
# ------------ 9 ------------
# eps = 0.126953125
# statistic = 1.203064531464756 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.004470700240678893
#
# ------------ 10 ------------
# eps = 0.1220703125
# statistic = 1.1707872172422338 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.0392156862745098
# relative_error_metric = 0.02272403424273363
#
# ------------ 11 ------------
# eps = 0.12451171875
# statistic = 1.1869167505206655 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.019417475728155338
# relative_error_metric = 0.009042329557100022
#
# ------------ 12 ------------
# eps = 0.125732421875
# statistic = 1.1949886460462869 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.00966183574879227
# relative_error_metric = 0.0022646848923442734
# =======> statistic within required accuracy at 0.95 CL in 267.2813813110115 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.1263427734375
# statistic = 1.1990261249719392 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.9014168353375402
# relative_error_metric = 0.24076528612873027
#
# ------------ 2 ------------
# eps = 2.56317138671875
# statistic = 17.328746496714974 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.8120957676160219
# relative_error_metric = 1.6760242891981105
#
# ------------ 3 ------------
# eps = 1.344757080078125
# statistic = 4.603060589952024 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.6564671714552432
# relative_error_metric = 1.003491610774516
#
# ------------ 4 ------------
# eps = 0.7355499267578125
# statistic = 3.1860247420609893 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.4136496414977429
# relative_error_metric = 0.7038915299539155
#
# ------------ 5 ------------
# eps = 0.43094635009765625
# statistic = 2.7920076572236106 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.093161749606407
# relative_error_metric = 0.5856553364560585
#
# ------------ 6 ------------
# eps = 0.2786445617675781
# statistic = 2.137172081922877 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.7521311166580323
# relative_error_metric = 0.3329084921561327
#
# ------------ 7 ------------
# eps = 0.20249366760253906
# statistic = 1.6941291448060007 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.46315362083466255
# relative_error_metric = 0.10362771957734866
#
# ------------ 8 ------------
# eps = 0.16441822052001953
# statistic = 1.450400209115907 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.2075454533640038
# relative_error_metric = 0.05159724867753094
#
# ------------ 9 ------------
# eps = 0.1834559440612793
# statistic = 1.5736910804862698 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.10945178158989508
# relative_error_metric = 0.029973397360565326
#
# ------------ 10 ------------
# eps = 0.17393708229064941
# statistic = 1.5123556696127767 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.05326831285877726
# relative_error_metric = 0.009779665797562837
#
# ------------ 11 ------------
# eps = 0.17869651317596436
# statistic = 1.543107300929372 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.02699363274799238
# relative_error_metric = 0.010349793969478719
#
# ------------ 12 ------------
# eps = 0.17631679773330688
# statistic = 1.5277517058390402 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.013588517234953716
# relative_error_metric = 0.0003489562938828241
#
# ------------ 13 ------------
# eps = 0.17512694001197815
# statistic = 1.520058644286733 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.0067712557859893096
# relative_error_metric = 0.004699300534733457
# =======> statistic within required accuracy at 0.99 CL in 271.52971701699425 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 538.8111299120064 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# Computing exclusion limits for fn with both deformation.
#
# ======================================================
# =============== fn - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 32.76275864015772 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8589302847318745
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 21.246130901610783 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7865430194389487
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 12.938401006380458 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6610951897637964
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 7.2674069248175694 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4340540375091948
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 3.864185335099318 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0535554373389306
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 2.0376638987601026 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5192407785101255
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.1566646716597222 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.03485725945900859
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.5840288583828817 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.2777633414204688
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 1.3649253346197514 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.13051262473796763
#
# ------------ 10 ------------
# eps = 0.0439453125
# statistic = 1.2590986141230651 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.049984298596033094
#
# ------------ 11 ------------
# eps = 0.04150390625
# statistic = 1.207414118252937 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.008079566480159292
#
# ------------ 12 ------------
# eps = 0.040283203125
# statistic = 1.1819171848148171 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.029850746268656716
# relative_error_metric = 0.013263322620502754
#
# ------------ 13 ------------
# eps = 0.0408935546875
# statistic = 1.1946357598898159 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.014814814814814815
# relative_error_metric = 0.002560033101975185
#
# ------------ 14 ------------
# eps = 0.04119873046875
# statistic = 1.2010175491991963 - next threshold = 1.1976979866809125 at 0.95 CL
# relative_error_eps = 0.007434944237918215
# relative_error_metric = 0.0027677833979307827
# =======> statistic within required accuracy at 0.95 CL in 293.17311395000434 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.041046142578125
# statistic = 1.1978247966757396 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.9674304567606018
# relative_error_metric = 0.2417531216499412
#
# ------------ 2 ------------
# eps = 2.5205230712890625
# statistic = 32.92534088802275 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.9359046909903201
# relative_error_metric = 1.822687347540615
#
# ------------ 3 ------------
# eps = 1.2807846069335938
# statistic = 21.590788241468182 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.875790020490029
# relative_error_metric = 1.7357525351666476
#
# ------------ 4 ------------
# eps = 0.6609153747558594
# statistic = 13.505847195394928 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.7661060239654376
# relative_error_metric = 1.5936374674604146
#
# ------------ 5 ------------
# eps = 0.3509807586669922
# statistic = 8.045137289177664 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.5811905514875813
# relative_error_metric = 1.3618211921319952
#
# ------------ 6 ------------
# eps = 0.1960134506225586
# statistic = 4.7666789875707645 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 1.3074122498239968
# relative_error_metric = 1.029397196544028
#
# ------------ 7 ------------
# eps = 0.1185297966003418
# statistic = 2.988265003110222 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.9711195111383365
# relative_error_metric = 0.6471272737499201
#
# ------------ 8 ------------
# eps = 0.0797879695892334
# statistic = 2.076724921529244 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.6412399001608082
# relative_error_metric = 0.3049471922858259
#
# ------------ 9 ------------
# eps = 0.0604170560836792
# statistic = 1.6257329237201226 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.38183131935591885
# relative_error_metric = 0.0624901716400782
#
# ------------ 10 ------------
# eps = 0.0507315993309021
# statistic = 1.4069482626007495 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.17427933278455998
# relative_error_metric = 0.08197926021810435
#
# ------------ 11 ------------
# eps = 0.05557432770729065
# statistic = 1.5154393847326333 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.08350151913207135
# relative_error_metric = 0.007742766543488807
#
# ------------ 12 ------------
# eps = 0.057995691895484924
# statistic = 1.5703939767860189 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.04264090464478706
# relative_error_metric = 0.02787649799957984
#
# ------------ 13 ------------
# eps = 0.05678500980138779
# statistic = 1.5428647757926135 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.02155018213779743
# relative_error_metric = 0.010192619027746472
#
# ------------ 14 ------------
# eps = 0.05617966875433922
# statistic = 1.5291385965175768 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.010833456810762187
# relative_error_metric = 0.0012563428137465972
#
# ------------ 15 ------------
# eps = 0.055876998230814934
# statistic = 1.5222855546991183 - next threshold = 1.5272186802671115 at 0.99 CL
# relative_error_eps = 0.005402097557736279
# relative_error_metric = 0.003235362332951684
# =======> statistic within required accuracy at 0.99 CL in 327.55465109998477 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 620.7277899839974 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# Computing exclusion limits for fpd with mean deformation.
#
# ======================================================
# =============== fpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 905.6150692815648 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9953391263981168
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 231.70406093342126 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.98184451023034
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 59.3364123204042 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9300268300325962
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 15.052866634074125 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.737675023748903
#
# ------------ 5 ------------
# eps = 0.15625
# WARNING:tensorflow:5 out of the last 5 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f13690696c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 4.407598550643531 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2266053900675917
#
# ------------ 6 ------------
# eps = 0.078125
# WARNING:tensorflow:6 out of the last 6 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f1368f8fd90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.6242680883413672 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4236129244678233
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.9598580707471164 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.09582991431182104
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.2300299216013273 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.1518124110754011
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 1.0798189533471165 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.021859016953830884
#
# ------------ 10 ------------
# eps = 0.0439453125
# statistic = 1.0161429105825228 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.03891459264678609
#
# ------------ 11 ------------
# eps = 0.04638671875
# statistic = 1.047044883203812 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.00896164455787069
#
# ------------ 12 ------------
# eps = 0.047607421875
# statistic = 1.0631965006782167 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.025974025974025976
# relative_error_metric = 0.006346411904965229
#
# ------------ 13 ------------
# eps = 0.0469970703125
# statistic = 1.0550620076654715 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.012903225806451613
# relative_error_metric = 0.001333963457265057
#
# ------------ 14 ------------
# eps = 0.04730224609375
# statistic = 1.0591145615096262 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.006472491909385114
# relative_error_metric = 0.0024997345238844926
# =======> statistic within required accuracy at 0.95 CL in 346.93294818297727 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.047149658203125
# statistic = 1.0570846141025572 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.9626326450403604
# relative_error_metric = 0.2692974021710578
#
# ------------ 2 ------------
# eps = 2.5235748291015625
# statistic = 922.5325859406383 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.9266359994064401
# relative_error_metric = 1.9939992575616436
#
# ------------ 3 ------------
# eps = 1.2853622436523438
# statistic = 244.80965484467055 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.8584638286908477
# relative_error_metric = 1.9774805259864086
#
# ------------ 4 ------------
# eps = 0.6662559509277344
# statistic = 66.91970016114108 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.7356361789161296
# relative_error_metric = 1.9188326341896749
#
# ------------ 5 ------------
# eps = 0.3567028045654297
# statistic = 19.541667874691825 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.5330011571067608
# relative_error_metric = 1.7350787149296076
#
# ------------ 6 ------------
# eps = 0.20192623138427734
# statistic = 6.500111559113034 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.242806547334163
# relative_error_metric = 1.2969712684432524
#
# ------------ 7 ------------
# eps = 0.12453794479370117
# statistic = 3.0731170752053925 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.9015011595450695
# relative_error_metric = 0.756673978312239
#
# ------------ 8 ------------
# eps = 0.08584380149841309
# statistic = 1.814372073376261 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.5818954312809802
# relative_error_metric = 0.2676663871869817
#
# ------------ 9 ------------
# eps = 0.06649672985076904
# statistic = 1.3744098960518676 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.2539976915703191
# relative_error_metric = 0.008433049545034672
#
# ------------ 10 ------------
# eps = 0.07617026567459106
# statistic = 1.5791655976464158 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.1356100026947365
# relative_error_metric = 0.13025440238457425
#
# ------------ 11 ------------
# eps = 0.07133349776268005
# statistic = 1.472937780466257 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.07018442899878158
# relative_error_metric = 0.06078260061870847
#
# ------------ 12 ------------
# eps = 0.06891511380672455
# statistic = 1.4227090041885233 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.03571894290240208
# relative_error_metric = 0.026103749161668712
#
# ------------ 13 ------------
# eps = 0.0677059218287468
# statistic = 1.3983180901734589 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.01802038876050493
# relative_error_metric = 0.008812521194874344
#
# ------------ 14 ------------
# eps = 0.06710132583975792
# statistic = 1.3863036430757882 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.009050969879223271
# relative_error_metric = 0.00018338345586598406
# =======> statistic within required accuracy at 0.99 CL in 350.0971201059874 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 697.0301093769958 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# Computing exclusion limits for fpd with std deformation.
#
# ======================================================
# =============== fpd - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 111.40331166952544 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9624231759266082
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 11.629112727282179 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6668752697268723
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 8.108803181185616 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5389246785523392
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 3.824380212264787 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1341915960927478
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 1.6478043208611668 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.43733276328353027
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 0.992617948512863 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.062322753353437295
#
# ------------ 7 ------------
# eps = 0.1171875
# statistic = 1.2707253426231233 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.18413146870162306
#
# ------------ 8 ------------
# eps = 0.09765625
# statistic = 1.1186677443186812 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.05718936465384856
#
# ------------ 9 ------------
# eps = 0.087890625
# statistic = 1.052352580381303 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.003905288312694983
#
# ------------ 10 ------------
# eps = 0.0927734375
# statistic = 1.0846907090133775 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.026359855156521905
#
# ------------ 11 ------------
# eps = 0.09033203125
# statistic = 1.0683162832995652 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.0273972602739726
# relative_error_metric = 0.011150222687502676
#
# ------------ 12 ------------
# eps = 0.089111328125
# statistic = 1.0602830389732576 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.013793103448275862
# relative_error_metric = 0.0036023825903258285
#
# ------------ 13 ------------
# eps = 0.0885009765625
# statistic = 1.056304955532647 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.006872852233676976
# relative_error_metric = 0.00015657665152494357
# =======> statistic within required accuracy at 0.95 CL in 364.63349049398676 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.08880615234375
# statistic = 1.058290784393978 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.9301949025487257
# relative_error_metric = 0.26817760752045955
#
# ------------ 2 ------------
# eps = 2.544403076171875
# statistic = 119.71679374497946 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.8650982210117633
# relative_error_metric = 1.9542190949522191
#
# ------------ 3 ------------
# eps = 1.3166046142578125
# statistic = 12.418284453505203 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.747244992128549
# relative_error_metric = 1.598372669974445
#
# ------------ 4 ------------
# eps = 0.7027053833007812
# statistic = 8.907749287147421 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.5512072870981735
# relative_error_metric = 1.4614041024874846
#
# ------------ 5 ------------
# eps = 0.3957557678222656
# statistic = 5.029190742031937 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.2669159614249164
# relative_error_metric = 1.1357770548655832
#
# ------------ 6 ------------
# eps = 0.2422809600830078
# statistic = 2.668555401539903 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.9270962352737852
# relative_error_metric = 0.6326169923046705
#
# ------------ 7 ------------
# eps = 0.1655435562133789
# statistic = 1.7501921208061337 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.603400761140586
# relative_error_metric = 0.23221596447344633
#
# ------------ 8 ------------
# eps = 0.12717485427856445
# statistic = 1.3582061661883291 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.26215434738342497
# relative_error_metric = 0.020292042014921283
#
# ------------ 9 ------------
# eps = 0.14635920524597168
# statistic = 1.543719389856864 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.14027029029404203
# relative_error_metric = 0.10763303026011685
#
# ------------ 10 ------------
# eps = 0.13676702976226807
# statistic = 1.4481683295461525 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.07268399646809885
# relative_error_metric = 0.04383494377573566
#
# ------------ 11 ------------
# eps = 0.13197094202041626
# statistic = 1.4024733243708145 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.037014590322109506
# relative_error_metric = 0.011779629947702342
#
# ------------ 12 ------------
# eps = 0.12957289814949036
# statistic = 1.3801594777488946 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.01833760542299955
# relative_error_metric = 0.004258509501390203
#
# ------------ 13 ------------
# eps = 0.1307719200849533
# statistic = 1.3912715520228918 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.009211029768859989
# relative_error_metric = 0.003760538162155826
# =======> statistic within required accuracy at 0.99 CL in 337.57056281500263 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 702.2040873850056 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# Computing exclusion limits for fpd with both deformation.
#
# ======================================================
# =============== fpd - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 996.7143008938085 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9957646770516395
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 231.2783302247724 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9818112420780614
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 63.28498097659498 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9343210114656066
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 17.22753127166592 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7688754612059703
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 5.021891982722902 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3047664476695657
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.8439526269815762 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5430120151593466
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.0217844765031332 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.03337981853132542
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.3597571382201954 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.25104157379321174
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 1.1724881226637243 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.10410042387960373
#
# ------------ 10 ------------
# eps = 0.0439453125
# statistic = 1.0926313193043753 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.03365216123362452
#
# ------------ 11 ------------
# eps = 0.04150390625
# statistic = 1.0560933470987273 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.05714285714285714
# relative_error_metric = 0.00035692563940242544
#
# ------------ 12 ------------
# eps = 0.042724609375
# statistic = 1.074082090977901 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.028985507246376812
# relative_error_metric = 0.016532547495088486
#
# ------------ 13 ------------
# eps = 0.0421142578125
# statistic = 1.0650178506186792 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.014598540145985401
# relative_error_metric = 0.008058012668897713
#
# ------------ 14 ------------
# eps = 0.04180908203125
# statistic = 1.0605381565315013 - next threshold = 1.0564703611749042 at 0.95 CL
# relative_error_eps = 0.007326007326007326
# relative_error_metric = 0.0038429655077667543
# =======> statistic within required accuracy at 0.95 CL in 335.9498800029978 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.041656494140625
# statistic = 1.0583113943648152 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.9669501528404103
# relative_error_metric = 0.2681584830631928
#
# ------------ 2 ------------
# eps = 2.5208282470703125
# statistic = 1015.6606412696951 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.934974841456516
# relative_error_metric = 1.994548728376424
#
# ------------ 3 ------------
# eps = 1.2812423706054688
# statistic = 242.7610056932113 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.8740448109807089
# relative_error_metric = 1.9772915640458115
#
# ------------ 4 ------------
# eps = 0.6614494323730469
# statistic = 70.03034030197115 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.7630144046876273
# relative_error_metric = 1.9223679916492569
#
# ------------ 5 ------------
# eps = 0.35155296325683594
# statistic = 21.983154423545468 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.5762411777546022
# relative_error_metric = 1.7627562412050868
#
# ------------ 6 ------------
# eps = 0.19660472869873047
# statistic = 7.368206164946542 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 1.3006584345668142
# relative_error_metric = 1.366685414004609
#
# ------------ 7 ------------
# eps = 0.11913061141967773
# statistic = 3.33181823266259 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.9636857011521524
# relative_error_metric = 0.8248509394184457
#
# ------------ 8 ------------
# eps = 0.08039355278015137
# statistic = 1.8594990535662312 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.634773351044607
# relative_error_metric = 0.2917532201993831
#
# ------------ 9 ------------
# eps = 0.061025023460388184
# statistic = 1.4121328858512876 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.3772544421289712
# relative_error_metric = 0.018643134414644828
#
# ------------ 10 ------------
# eps = 0.05134075880050659
# statistic = 1.2171434937721306 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.17237035092046668
# relative_error_metric = 0.1297682896936035
#
# ------------ 11 ------------
# eps = 0.05618289113044739
# statistic = 1.3100875195439579 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.08262466484186384
# relative_error_metric = 0.056348711354229315
#
# ------------ 12 ------------
# eps = 0.058603957295417786
# statistic = 1.359972232994644 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.040476248308299594
# relative_error_metric = 0.0189927184342104
#
# ------------ 13 ------------
# eps = 0.059814490377902985
# statistic = 1.3857682465586885 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.020035384851103396
# relative_error_metric = 0.00020289550326345294
#
# ------------ 14 ------------
# eps = 0.060419756919145584
# statistic = 1.3988795237022267 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.010068122100806084
# relative_error_metric = 0.009213938763056598
#
# ------------ 15 ------------
# eps = 0.060117123648524284
# statistic = 1.3923061194686037 - next threshold = 1.3860494412310478 at 0.99 CL
# relative_error_eps = 0.005046763909216025
# relative_error_metric = 0.004503871517424044
# =======> statistic within required accuracy at 0.99 CL in 363.32542258501053 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 699.275335407001 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# Computing exclusion limits for kpd with mean deformation.
#
# ======================================================
# =============== kpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# statistic = 1271.461285466467 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9959051139642763
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 305.4716824446384 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.983010901605495
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 75.4796436244547 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9321223228133144
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 19.036856796660118 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.743762416178814
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 5.045669543081388 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1790625580831275
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.5672971817339842 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.18419353493307386
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.7030291852530013 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.5981369256589991
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.062375542263183 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.20342228575090154
#
# ------------ 9 ------------
# eps = 0.068359375
# statistic = 1.2966305024244562 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.004866641040020148
#
# ------------ 10 ------------
# eps = 0.0732421875
# statistic = 1.4274112480263668 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.09116364274720273
#
# ------------ 11 ------------
# eps = 0.07080078125
# statistic = 1.3608828683207008 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 0.03508771929824561
# relative_error_metric = 0.04349117077906152
#
# ------------ 12 ------------
# eps = 0.069580078125
# statistic = 1.3284722013109374 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 0.017699115044247787
# relative_error_metric = 0.019393324216823056
#
# ------------ 13 ------------
# eps = 0.0689697265625
# statistic = 1.312480233059965 - next threshold = 1.302956129920485 at 0.95 CL
# relative_error_eps = 0.008888888888888889
# relative_error_metric = 0.007282993594710623
# =======> statistic within required accuracy at 0.95 CL in 357.7385828339902 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.06866455078125
# statistic = 1.3045375883145027 - next threshold = 2.3135020940445727 at 0.99 CL
# relative_error_eps = 1.94581251128906
# relative_error_metric = 0.5577409836877154
#
# ------------ 2 ------------
# eps = 2.534332275390625
# statistic = 1308.31745876755 - next threshold = 2.3135020940445727 at 0.99 CL
# relative_error_eps = 1.8944838501670673
# relative_error_metric = 1.9929392722646386
#
# ------------ 3 ------------
# eps = 1.3014984130859375
# statistic = 331.5975934282518 - next threshold = 2.3135020940445727 at 0.99 CL
# relative_error_eps = 1.7995434044211815
# relative_error_metric = 1.9722860111560434
#
# ------------ 4 ------------
# eps = 0.6850814819335938
# statistic = 90.7347544867374 - next threshold = 2.3135020940445727 at 0.99 CL
# relative_error_eps = 1.6356090895288222
# relative_error_metric = 1.9005461390010652
#
# ------------ 5 ------------
# eps = 0.3768730163574219
# statistic = 27.545247229076253 - next threshold = 2.3135020940445727 at 0.99 CL
# relative_error_eps = 1.3835352540776575
# relative_error_metric = 1.690073811329648
#
# ------------ 6 ------------
# eps = 0.22276878356933594
# statistic = 9.8523020957888 - next threshold = 2.3135020940445727 at 0.99 CL
# relative_error_eps = 1.05756078405707
# relative_error_metric = 1.2393426499571965
#
# ------------ 7 ------------
# eps = 0.14571666717529297
# statistic = 4.440360168475266 - next threshold = 2.3135020940445727 at 0.99 CL
# relative_error_eps = 0.7188327142507618
# relative_error_metric = 0.6298197954771944
#
# ------------ 8 ------------
# eps = 0.10719060897827148
# ...
# eps = 0.05038559436798096
# statistic = 1.313394750615406 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.4771393616163984
# relative_error_metric = 0.09100687011293485
#
# ------------ 10 ------------
# eps = 0.04068046808242798
# statistic = 1.1418733600481985 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.21314474403322348
# relative_error_metric = 0.04886549889529729
#
# ------------ 11 ------------
# eps = 0.04553303122520447
# statistic = 1.2267704120581298 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.1125708428899578
# relative_error_metric = 0.022838604277632374
#
# ------------ 12 ------------
# eps = 0.04310674965381622
# statistic = 1.1840773321626443 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.0547447556238826
# relative_error_metric = 0.012581423285827491
#
# ------------ 13 ------------
# eps = 0.044319890439510345
# statistic = 1.2053659906951695 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.027752199659031012
# relative_error_metric = 0.005237797663193771
#
# ------------ 14 ------------
# eps = 0.043713320046663284
# statistic = 1.1947066000543058 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.013780490101342566
# relative_error_metric = 0.0036448016013817894
#
# ------------ 15 ------------
# eps = 0.044016605243086815
# statistic = 1.20003259612961 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.006914064851231893
# relative_error_metric = 0.0008032819161540658
# =======> statistic within required accuracy at 0.99 CL in 293.31601482699625 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 572.0630669149978 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# Computing exclusion limits for swd with std deformation.
#
# ======================================================
# =============== swd - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 12.668960577713701 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7126318279602906
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 6.104440145257544 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.446376356615741
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 5.1575050863193015 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3609681570970817
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 3.0877028010212535 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0358534056308475
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 1.776773287143595 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5774743574411132
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.1183090026893747 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.13120612690995068
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.8245948189099735 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1728537041913193
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 0.9649366905212197 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.016115320942771183
#
# ------------ 9 ------------
# eps = 0.068359375
# statistic = 1.0404599774817667 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.05922269859827567
#
# ------------ 10 ------------
# eps = 0.0634765625
# statistic = 1.0023642225922014 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.021937668088347215
#
# ------------ 11 ------------
# eps = 0.06103515625
# statistic = 0.9835617494221524 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.003002255751147606
#
# ------------ 12 ------------
# eps = 0.059814453125
# statistic = 0.9742262718539543 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.006534551353110042
#
# ------------ 13 ------------
# eps = 0.0604248046875
# statistic = 0.9788884091572223 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.010050251256281407
# relative_error_metric = 0.001760511262057976
#
# ------------ 14 ------------
# eps = 0.06072998046875
# statistic = 0.9812236803980225 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.005037783375314861
# relative_error_metric = 0.0006222829595966049
# =======> statistic within required accuracy at 0.95 CL in 263.96397525799694 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.060577392578125
# statistic = 0.9800556610591569 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.9521181968943162
# relative_error_metric = 0.20101039618140645
#
# ------------ 2 ------------
# eps = 2.5302886962890625
# statistic = 13.003335684744059 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.9064754556965753
# relative_error_metric = 1.6622912686409357
#
# ------------ 3 ------------
# eps = 1.2954330444335938
# statistic = 6.096051870322139 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.8213070019973556
# relative_error_metric = 1.3425364503720694
#
# ------------ 4 ------------
# eps = 0.6780052185058594
# statistic = 5.397613800817557 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.6719262453838803
# relative_error_metric = 1.2729260742272555
#
# ------------ 5 ------------
# eps = 0.3692913055419922
# statistic = 3.532532840109314 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.4363172490293954
# relative_error_metric = 0.9863314332446611
#
# ------------ 6 ------------
# eps = 0.2149343490600586
# statistic = 2.278669412457502 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.1205109122691634
# relative_error_metric = 0.6208634807837059
#
# ------------ 7 ------------
# eps = 0.1377558708190918
# statistic = 1.618235886232694 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.7782706432495462
# relative_error_metric = 0.29756585227707666
#
# ------------ 8 ------------
# eps = 0.0991666316986084
# statistic = 1.2912398356856576 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.48313843719916716
# relative_error_metric = 0.07402360302927825
#
# ------------ 9 ------------
# eps = 0.0798720121383667
# statistic = 1.1324285703226604 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.2155358099987682
# relative_error_metric = 0.05716535899570246
#
# ------------ 10 ------------
# eps = 0.08951932191848755
# statistic = 1.2112319119451496 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.11390558830929144
# relative_error_metric = 0.010092427158944723
#
# ------------ 11 ------------
# eps = 0.08469566702842712
# statistic = 1.1716626296306034 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.05537588836894222
# relative_error_metric = 0.02312061683379244
#
# ------------ 12 ------------
# eps = 0.08710749447345734
# statistic = 1.191406847237723 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.027309867145861148
# relative_error_metric = 0.006410582537236084
#
# ------------ 13 ------------
# eps = 0.08831340819597244
# statistic = 1.2013096090015292 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.013748803069239458
# relative_error_metric = 0.0018668640998448678
#
# ------------ 14 ------------
# eps = 0.08771045133471489
# statistic = 1.1963556586044817 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.006850853774768367
# relative_error_metric = 0.002265452201269828
# =======> statistic within required accuracy at 0.99 CL in 271.8709712359996 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 535.8350114490022 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# Computing exclusion limits for swd with both deformation.
#
# ======================================================
# =============== swd - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 50.601950050956034 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9239577711239564
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 25.45669765877649 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8516319191266974
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 13.878226713859652 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7360188890899018
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 7.246401128067415 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5232227761304078
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 3.7744002934910714 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1750910838563764
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 2.04858532253137 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7051185439435317
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.226600392758263 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.22289380062366138
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.8623530597607411 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.12833681199276203
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 1.0370089129558537 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.0559030742657254
#
# ------------ 10 ------------
# eps = 0.0244140625
# statistic = 0.9471855670474894 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.03467966037636664
#
# ------------ 11 ------------
# eps = 0.02685546875
# statistic = 0.9915809565286852 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.01112231729196589
#
# ------------ 12 ------------
# eps = 0.025634765625
# statistic = 0.9692430983005786 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.011662575173154634
#
# ------------ 13 ------------
# eps = 0.0262451171875
# statistic = 0.9803783188135605 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.022988505747126436
# relative_error_metric = 0.0002396264555813115
#
# ------------ 14 ------------
# eps = 0.02655029296875
# statistic = 0.9859713918807848 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.011560693641618497
# relative_error_metric = 0.0054491631453865794
#
# ------------ 15 ------------
# eps = 0.026397705078125
# statistic = 0.9831727292026373 - next threshold = 0.9806132715456718 at 0.95 CL
# relative_error_eps = 0.005797101449275362
# relative_error_metric = 0.002606656383119375
# =======> statistic within required accuracy at 0.95 CL in 283.26465721201384 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0263214111328125
# statistic = 0.9817749939800138 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.9790531412698653
# relative_error_metric = 0.19927516449524632
#
# ------------ 2 ------------
# eps = 2.5131607055664062
# statistic = 50.89578373232874 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.9585405056255727
# relative_error_metric = 1.9079318623365686
#
# ------------ 3 ------------
# eps = 1.2697410583496094
# statistic = 25.812616235276096 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.9187649924210093
# relative_error_metric = 1.8224369923777544
#
# ------------ 4 ------------
# eps = 0.6480312347412109
# statistic = 14.34144553659437 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.8438715334247855
# relative_error_metric = 1.6913695452244286
#
# ------------ 5 ------------
# eps = 0.3371763229370117
# statistic = 7.789257424691526 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.7103540554367647
# relative_error_metric = 1.466388308784381
#
# ------------ 6 ------------
# eps = 0.1817488670349121
# statistic = 4.342562422323685 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.4939899852184575
# relative_error_metric = 1.1345010714418804
#
# ------------ 7 ------------
# eps = 0.1040351390838623
# statistic = 2.61610975131276 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 1.1923256303097365
# relative_error_metric = 0.7428436873299669
#
# ------------ 8 ------------
# eps = 0.0651782751083374
# statistic = 1.7695865980060328 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.8493332725342158
# relative_error_metric = 0.38436090474416
#
# ------------ 9 ------------
# eps = 0.04574984312057495
# statistic = 1.3618761904870778 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.539145105466214
# relative_error_metric = 0.12714615779138214
#
# ------------ 10 ------------
# eps = 0.036035627126693726
# statistic = 1.1666770878427548 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.23755358903021392
# relative_error_metric = 0.027384114235041345
#
# ------------ 11 ------------
# eps = 0.04089273512363434
# statistic = 1.2632569291952855 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.1262761315816235
# relative_error_metric = 0.05213599815467975
#
# ------------ 12 ------------
# eps = 0.03846418112516403
# statistic = 1.2146833613550267 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.065196248297988
# relative_error_metric = 0.012937816509924397
#
# ------------ 13 ------------
# eps = 0.03724990412592888
# statistic = 1.1906048359892452 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.032075326412733106
# relative_error_metric = 0.007083964745075965
#
# ------------ 14 ------------
# eps = 0.037857042625546455
# statistic = 1.202625653672102 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.016167306111552204
# relative_error_metric = 0.0029617711647985825
#
# ------------ 15 ------------
# eps = 0.03755347337573767
# statistic = 1.1966105305274777 - next threshold = 1.1990690186585224 at 0.99 CL
# relative_error_eps = 0.008051111858288279
# relative_error_metric = 0.0020524348775111494
# =======> statistic within required accuracy at 0.99 CL in 286.9568231140147 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 570.2215490569943 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# dict_keys(['2024-04-11T16:16:17.904964', '2024-04-11T16:26:48.108020', '2024-04-11T16:35:46.932490', '2024-04-11T16:46:07.669678', '2024-04-11T16:57:44.710508', '2024-04-11T17:09:26.925799', '2024-04-11T17:21:06.209488', '2024-04-11T17:33:28.096756', '2024-04-11T17:42:32.548628', '2024-04-11T17:55:04.454233', '2024-04-11T18:08:34.245264', '2024-04-11T18:19:47.716309', '2024-04-11T18:31:24.061390', '2024-04-11T18:44:17.832363', '2024-04-11T18:56:07.164861', '2024-04-11T19:08:41.355575', '2024-04-11T19:18:13.445337', '2024-04-11T19:27:09.304062'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 0.005
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.07597344199894 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -68.70869050228032], [0.99, [9900, 100], -56.85002727894647]]
# Null distribution computed in 38.57172086299397 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.343978221004363 seconds.
# statistic = 94.78447309696321 - next threshold = -68.70869050228032 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 12.539847117193053
#
# ------------ 2 ------------
# eps = 0.0025
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 36.89413672001683 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -10.234033269687512], [0.99, [9900, 100], -4.562957932500928]]
# Null distribution computed in 37.32482193398755 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 16.05440542299766 seconds.
# statistic = 23.32639983369979 - next threshold = -10.234033269687512 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 5.126717608967159
#
# ------------ 3 ------------
# eps = 0.00125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 34.64721554599237 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.001250.json
# ThresholdS: [[0.95, [9500, 500], 0.9234570026896989], [0.99, [9900, 100], 3.7905578311859958]]
# Null distribution computed in 34.93462150997948 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.73729376902338 seconds.
# statistic = 5.646740555143634 - next threshold = 0.9234570026896989 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.437790419809398
#
# ------------ 4 ------------
# eps = 0.000625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 35.6789412710059 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000625.json
# ThresholdS: [[0.95, [9500, 500], 1.9833001495999099], [0.99, [9900, 100], 3.415245954238169]]
# Null distribution computed in 35.99930738899275 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.403293513983954 seconds.
# statistic = 1.319255414201149 - next threshold = 1.9833001495999099 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.40213993228594286
#
# ------------ 5 ------------
# eps = 0.0009375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 36.35246238001855 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000937.json
# ThresholdS: [[0.95, [9500, 500], 1.8293621380022207], [0.99, [9900, 100], 3.9746290434946236]]
# Null distribution computed in 36.70399517501937 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 19.17296318701119 seconds.
# statistic = 3.106969271699795 - next threshold = 1.8293621380022207 at 0.95 CL
# relative_error_eps = 0.3999999999999999
# relative_error_metric = 0.517634262232283
#
# ------------ 6 ------------
# eps = 0.00078125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 36.04869573400356 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000781.json
# ThresholdS: [[0.95, [9500, 500], 2.0034499651829107], [0.99, [9900, 100], 3.7912211278746257]]
# Null distribution computed in 36.44425290002255 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.302281642972957 seconds.
# statistic = 2.1191051643474386 - next threshold = 2.0034499651829107 at 0.95 CL
# relative_error_eps = 0.22222222222222227
# relative_error_metric = 0.056108503358063534
#
# ------------ 7 ------------
# eps = 0.000703125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 37.08002409301116 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000703.json
# ThresholdS: [[0.95, [9500, 500], 2.0171588184784004], [0.99, [9900, 100], 3.6279145144071894]]
# Null distribution computed in 37.39394758301205 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 19.474938608997036 seconds.
# statistic = 1.695678494579804 - next threshold = 2.0171588184784004 at 0.95 CL
# relative_error_eps = 0.10526315789473693
# relative_error_metric = 0.17317231906064753
#
# ------------ 8 ------------
# eps = 0.0007421875
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 36.1292245920049 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000742.json
# ThresholdS: [[0.95, [9500, 500], 2.015882564819558], [0.99, [9900, 100], 3.715847623716722]]
# Null distribution computed in 36.47728513900074 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 25.87895449300413 seconds.
# statistic = 1.901516380803376 - next threshold = 2.015882564819558 at 0.95 CL
# relative_error_eps = 0.05128205128205133
# relative_error_metric = 0.05838883688063895
#
# ------------ 9 ------------
# eps = 0.00076171875
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 37.74872167099966 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000762.json
# ThresholdS: [[0.95, [9500, 500], 2.0112412418266543], [0.99, [9900, 100], 3.755036843598621]]
# Null distribution computed in 38.33264661999419 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.648733162001008 seconds.
# statistic = 2.0088419104036572 - next threshold = 2.0112412418266543 at 0.95 CL
# relative_error_eps = 0.025316455696202552
# relative_error_metric = 0.0011936725346917043
#
# ------------ 10 ------------
# eps = 0.000771484375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 36.83387693398981 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000771.json
# ThresholdS: [[0.95, [9500, 500], 2.00776492069991], [0.99, [9900, 100], 3.773504602700222]]
# Null distribution computed in 37.106802444002824 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 20.096757290011737 seconds.
# statistic = 2.0636063218377556 - next threshold = 2.00776492069991 at 0.95 CL
# relative_error_eps = 0.012738853503184724
# relative_error_metric = 0.027431249970238512
#
# ------------ 11 ------------
# eps = 0.0007666015625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 37.630726196977776 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000767.json
# ThresholdS: [[0.95, [9500, 500], 2.009643682532529], [0.99, [9900, 100], 3.76436462737746]]
# Null distribution computed in 38.11741531701409 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.531016344000818 seconds.
# statistic = 2.0361323122390877 - next threshold = 2.009643682532529 at 0.95 CL
# relative_error_eps = 0.006389776357827482
# relative_error_metric = 0.013094461848995296
#
# ------------ 12 ------------
# eps = 0.00076416015625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 37.412630967010045 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000764.json
# ThresholdS: [[0.95, [9500, 500], 2.0105133844390712], [0.99, [9900, 100], 3.759724211529615]]
# Null distribution computed in 37.78050895099295 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.851057702006074 seconds.
# statistic = 2.0224641603465954 - next threshold = 2.0105133844390712 at 0.95 CL
# relative_error_eps = 0.0031999999999999316
# relative_error_metric = 0.005926527373293007
# =======> statistic within required accuracy at 0.95 CL in 879.039632785978 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.000762939453125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.35553345698281 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.000763.json
# ThresholdS: [[0.95, [9500, 500], 2.0109308156759154], [0.99, [9900, 100], 3.7573863965745122]]
# Null distribution computed in 38.89984785899287 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 19.051830585987773 seconds.
# statistic = 2.0156472976394064 - next threshold = 3.7573863965745122 at 0.99 CL
# relative_error_eps = 1.716456844731768
# relative_error_metric = 0.6034051388547348
#
# ------------ 2 ------------
# eps = 0.0053814697265625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 34.634684977005236 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.005381.json
# ThresholdS: [[0.95, [9500, 500], -81.87327738280284], [0.99, [9900, 100], -68.98477584901276]]
# Null distribution computed in 35.04192600498209 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 19.72336481101229 seconds.
# statistic = 109.92059126551474 - next threshold = -68.98477584901276 at 0.99 CL
# relative_error_eps = 1.5033277043806497
# relative_error_metric = 8.740774565951725
#
# ------------ 3 ------------
# eps = 0.00307220458984375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 35.875566489004996 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.003072.json
# ThresholdS: [[0.95, [9500, 500], -19.42485452614849], [0.99, [9900, 100], -12.274866597501049]]
# Null distribution computed in 36.15202774500358 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.79120434698416 seconds.
# statistic = 35.43435650663127 - next threshold = -12.274866597501049 at 0.99 CL
# relative_error_eps = 1.2042651388557333
# relative_error_metric = 4.120058195696599
#
# ------------ 4 ------------
# eps = 0.001917572021484375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 36.16434757900424 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.001918.json
# ThresholdS: [[0.95, [9500, 500], -3.53556358155347], [0.99, [9900, 100], 0.8709214198008393]]
# Null distribution computed in 36.541839951009024 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.551102989993524 seconds.
# statistic = 13.591561064327868 - next threshold = 0.8709214198008393 at 0.99 CL
# relative_error_eps = 0.861501679285023
# relative_error_metric = 1.75912256536688
#
# ------------ 5 ------------
# eps = 0.0013402557373046876
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 36.55274486300186 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.001340.json
# ThresholdS: [[0.95, [9500, 500], 0.519776472546662], [0.99, [9900, 100], 3.5890094359421267]]
# Null distribution computed in 36.96450484500383 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.45238236800651 seconds.
# statistic = 6.52024395348508 - next threshold = 3.5890094359421267 at 0.99 CL
# relative_error_eps = 0.5489897341023688
# relative_error_metric = 0.5799111773394846
#
# ------------ 6 ------------
# eps = 0.0010515975952148438
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 36.57004443599726 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.001052.json
# ThresholdS: [[0.95, [9500, 500], 1.588905064503794], [0.99, [9900, 100], 3.996737055289659]]
# Null distribution computed in 36.89752800899441 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.214214470004663 seconds.
# statistic = 3.9471055664197405 - next threshold = 3.996737055289659 at 0.99 CL
# relative_error_eps = 0.24136776127972445
# relative_error_metric = 0.012495587144257535
#
# ------------ 7 ------------
# eps = 0.0011959266662597656
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 37.38205030898098 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.001196.json
# ThresholdS: [[0.95, [9500, 500], 1.1351241267789343], [0.99, [9900, 100], 3.8806466362017207]]
# Null distribution computed in 37.776168996002525 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.358922049985267 seconds.
# statistic = 5.153464745467502 - next threshold = 3.8806466362017207 at 0.99 CL
# relative_error_eps = 0.12843382696142905
# relative_error_metric = 0.2817804774575636
#
# ------------ 8 ------------
# eps = 0.0011237621307373046
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.56854224199196 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.001124.json
# ThresholdS: [[0.95, [9500, 500], 1.3819331926050382], [0.99, [9900, 100], 3.9570562390119046]]
# Null distribution computed in 38.96372357601649 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.37478080499568 seconds.
# statistic = 4.530232652279692 - next threshold = 3.9570562390119046 at 0.99 CL
# relative_error_eps = 0.06634722033467325
# relative_error_metric = 0.13506702095551307
#
# ------------ 9 ------------
# eps = 0.001087679862976074
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 37.22217301800265 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.001088.json
# ThresholdS: [[0.95, [9500, 500], 1.4904924002434963], [0.99, [9900, 100], 3.980810597856451]]
# Null distribution computed in 37.61309858702589 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.533966609975323 seconds.
# statistic = 4.233655983439136 - next threshold = 3.980810597856451 at 0.99 CL
# relative_error_eps = 0.03373313510417045
# relative_error_metric = 0.06156099926400973
#
# ------------ 10 ------------
# eps = 0.0010696387290954588
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 35.0471915040107 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.001070.json
# ThresholdS: [[0.95, [9500, 500], 1.5409670503139221], [0.99, [9900, 100], 3.990043230782498]]
# Null distribution computed in 35.35561220801901 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.828254695021315 seconds.
# statistic = 4.089127493448449 - next threshold = 3.990043230782498 at 0.99 CL
# relative_error_eps = 0.01701001785973179
# relative_error_metric = 0.02452832500959002
#
# ------------ 11 ------------
# eps = 0.0010606181621551514
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 36.357449166011065 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_mean_0.001061.json
# ThresholdS: [[0.95, [9500, 500], 1.5652531369067895], [0.99, [9900, 100], 3.9937074940910122]]
# Null distribution computed in 36.68481132600573 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.05666021502111 seconds.
# statistic = 4.017803209567706 - next threshold = 3.9937074940910122 at 0.99 CL
# relative_error_eps = 0.008541330977986355
# relative_error_metric = 0.006015273864812981
# =======> statistic within required accuracy at 0.99 CL in 800.488367752987 seconds
#
# ======================================================
# ...
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 18.57317766197957 seconds.
# statistic = 16.296747843547543 - next threshold = -1.2977171949860005 at 0.99 CL
# relative_error_eps = 0.8994208722373241
# relative_error_metric = 2.346080283557646
#
# ------------ 5 ------------
# eps = 0.001291046142578125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 39.33455657001468 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_both_0.001291.json
# ThresholdS: [[0.95, [9500, 500], -0.2205995439226248], [0.99, [9900, 100], 3.0451112152880553]]
# Null distribution computed in 39.769612058007624 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 19.240827586996602 seconds.
# statistic = 7.4504370824653945 - next threshold = 3.0451112152880553 at 0.99 CL
# relative_error_eps = 0.5801631470610656
# relative_error_metric = 0.8394655985948424
#
# ------------ 6 ------------
# eps = 0.0010007476806640626
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 38.04193372000009 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_both_0.001001.json
# ThresholdS: [[0.95, [9500, 500], 1.3375431294074644], [0.99, [9900, 100], 3.819410238273414]]
# Null distribution computed in 38.3462010769872 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.304032952990383 seconds.
# statistic = 4.30722107809273 - next threshold = 3.819410238273414 at 0.99 CL
# relative_error_eps = 0.3392928797538901
# relative_error_metric = 0.12005241060632797
#
# ------------ 7 ------------
# eps = 0.0008555984497070313
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 35.695860178006114 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_both_0.000856.json
# ThresholdS: [[0.95, [9500, 500], 1.78893196403173], [0.99, [9900, 100], 3.905264628979657]]
# Null distribution computed in 35.98875907500042 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 19.145994532009354 seconds.
# statistic = 3.0552600080525747 - next threshold = 3.905264628979657 at 0.99 CL
# relative_error_eps = 0.15638164519244604
# relative_error_metric = 0.2442357911944695
#
# ------------ 8 ------------
# eps = 0.000928173065185547
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 40.32678889299859 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_both_0.000928.json
# ThresholdS: [[0.95, [9500, 500], 1.594187580097758], [0.99, [9900, 100], 3.8892895745014364]]
# Null distribution computed in 40.75290446600411 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 19.51856146598584 seconds.
# statistic = 3.6546132518870276 - next threshold = 3.8892895745014364 at 0.99 CL
# relative_error_eps = 0.07524893455023683
# relative_error_metric = 0.06221615734325591
#
# ------------ 9 ------------
# eps = 0.0009644603729248049
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 37.74477430997649 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_both_0.000964.json
# ThresholdS: [[0.95, [9500, 500], 1.4728354606083454], [0.99, [9900, 100], 3.8604061217120176]]
# Null distribution computed in 38.11893079499714 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 20.05911518901121 seconds.
# statistic = 3.9742595983648785 - next threshold = 3.8604061217120176 at 0.99 CL
# relative_error_eps = 0.038345838141259886
# relative_error_metric = 0.02906402920576514
#
# ------------ 10 ------------
# eps = 0.0009463167190551759
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 37.12155165101285 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_both_0.000946.json
# ThresholdS: [[0.95, [9500, 500], 1.5357684076687779], [0.99, [9900, 100], 3.8765934400053097]]
# Null distribution computed in 37.52205530399806 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 17.732480842998484 seconds.
# statistic = 3.812772126557541 - next threshold = 3.8765934400053097 at 0.99 CL
# relative_error_eps = 0.018990863922100115
# relative_error_metric = 0.01659989056191971
#
# ------------ 11 ------------
# eps = 0.0009553885459899904
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 20000
# nchunks = 10
# Iterating from 0 to 1000 out of 10000 .
# Iterating from 1000 to 2000 out of 10000 .
# Iterating from 2000 to 3000 out of 10000 .
# Iterating from 3000 to 4000 out of 10000 .
# Iterating from 4000 to 5000 out of 10000 .
# Iterating from 5000 to 6000 out of 10000 .
# Iterating from 6000 to 7000 out of 10000 .
# Iterating from 7000 to 8000 out of 10000 .
# Iterating from 8000 to 9000 out of 10000 .
# Iterating from 9000 to 10000 out of 10000 .
# LR metric calculation completed in 37.150578036002116 seconds.
# Saving lr to ../results/5D_20K/null_hypothesis/LR_both_0.000955.json
# ThresholdS: [[0.95, [9500, 500], 1.5045517031849467], [0.99, [9900, 100], 3.868936499382421]]
# Null distribution computed in 37.46917487299652 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 20000
# LR metric calculation completed in 19.75289461997454 seconds.
# statistic = 3.893099776197597 - next threshold = 3.868936499382421 at 0.99 CL
# relative_error_eps = 0.009540728630836532
# relative_error_metric = 0.006226014916007506
# =======> statistic within required accuracy at 0.99 CL in 816.9211758870224 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1633.7925323910022 seconds.
# Saving results in the file ../results/5D_20K/exclusion_limits.json
# dict_keys(['2024-04-11T16:16:17.904964', '2024-04-11T16:26:48.108020', '2024-04-11T16:35:46.932490', '2024-04-11T16:46:07.669678', '2024-04-11T16:57:44.710508', '2024-04-11T17:09:26.925799', '2024-04-11T17:21:06.209488', '2024-04-11T17:33:28.096756', '2024-04-11T17:42:32.548628', '2024-04-11T17:55:04.454233', '2024-04-11T18:08:34.245264', '2024-04-11T18:19:47.716309', '2024-04-11T18:31:24.061390', '2024-04-11T18:44:17.832363', '2024-04-11T18:56:07.164861', '2024-04-11T19:08:41.355575', '2024-04-11T19:18:13.445337', '2024-04-11T19:27:09.304062', '2024-04-11T19:36:39.627388', '2024-04-11T20:04:39.164865', '2024-04-11T20:29:30.050529'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_std = results_df[results_df["Deformation"] == "std"]
results_df_both = results_df[results_df["Deformation"] == "both"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 18        lr        mean    5  10000                20000
# 9         ks        mean    5  10000                20000
# 12       sks        mean    5  10000                20000
# 15       swd        mean    5  10000                20000
# 0         fn        mean    5  10000                20000
# 3        fpd        mean    5  10000                20000
# 6        kpd        mean    5  10000                20000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 18                             0.00076                             0.00106
# 9                              0.00782                             0.01060
# 12                             0.01930                             0.02622
# 15                             0.03098                             0.04386
# 0                              0.04349                             0.05967
# 3                              0.04715                             0.06680
# 6                              0.06866                             0.10027
#
#     $t^{\mu}$ (s)
# 18           1679
# 9             809
# 12            773
# 15            572
# 0             630
# 3             697
# 6             741
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 18        lr                             0.00076
# 9         ks                             0.00782
# 12       sks                             0.01930
# 15       swd                             0.03098
# 0         fn                             0.04349
# 3        fpd                             0.04715
# 6        kpd                             0.06866
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 18                             0.00106           1679
# 9                              0.01060            809
# 12                             0.02622            773
# 15                             0.04386            572
# 0                              0.05967            630
# 3                              0.06680            697
# 6                              0.10027            741

# %%
sorted_df_std = results_df_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma}$ (s)"}, inplace=True)
display(sorted_df_std)
sorted_df_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 19        lr         std    5  10000                20000
# 10        ks         std    5  10000                20000
# 13       sks         std    5  10000                20000
# 16       swd         std    5  10000                20000
# 4        fpd         std    5  10000                20000
# 1         fn         std    5  10000                20000
# 7        kpd         std    5  10000                20000
#
#     $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 19                                0.00144
# 10                                0.01732
# 13                                0.03952
# 16                                0.06058
# 4                                 0.08881
# 1                                 0.12634
# 7                                 1.84082
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 19                                0.00195              1490
# 10                                0.02348               673
# 13                                0.05572               709
# 16                                0.08801               535
# 4                                 0.13017               702
# 1                                 0.17572               538
# 7                                 2.28199               544
#    Statistic  $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 19        lr                                0.00144
# 10        ks                                0.01732
# 13       sks                                0.03952
# 16       swd                                0.06058
# 4        fpd                                0.08881
# 1         fn                                0.12634
# 7        kpd                                1.84082
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 19                                0.00195              1490
# 10                                0.02348               673
# 13                                0.05572               709
# 16                                0.08801               535
# 4                                 0.13017               702
# 1                                 0.17572               538
# 7                                 2.28199               544

# %%
sorted_df_both = results_df_both.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_both.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\sigma}$ (s)"}, inplace=True)
display(sorted_df_both)
sorted_df_both.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_both)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 20        lr        both    5  10000                20000
# 11        ks        both    5  10000                20000
# 14       sks        both    5  10000                20000
# 17       swd        both    5  10000                20000
# 2         fn        both    5  10000                20000
# 5        fpd        both    5  10000                20000
# 8        kpd        both    5  10000                20000
#
#     $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 20                                    0.00071
# 11                                    0.00669
# 14                                    0.01610
# 17                                    0.02632
# 2                                     0.04105
# 5                                     0.04166
# 8                                     0.06866
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 20                                    0.00095                  1633
# 11                                    0.00894                   696
# 14                                    0.02195                   754
# 17                                    0.03771                   570
# 2                                     0.05603                   620
# 5                                     0.05997                   699
# 8                                     0.10087                   751
#    Statistic  $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 20        lr                                    0.00071
# 11        ks                                    0.00669
# 14       sks                                    0.01610
# 17       swd                                    0.02632
# 2         fn                                    0.04105
# 5        fpd                                    0.04166
# 8        kpd                                    0.06866
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 20                                    0.00095                  1633
# 11                                    0.00894                   696
# 14                                    0.02195                   754
# 17                                    0.03771                   570
# 2                                     0.05603                   620
# 5                                     0.05997                   699
# 8                                     0.10087                   751

# %%
result_table = sorted_df_mean.merge(sorted_df_std, on='Statistic', how='outer').merge(sorted_df_both, on='Statistic', how='outer').merge(times_df, on='Statistic', how='outer')
result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fpd","$d_{\\mathrm{FPD}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("kpd","$d_{\\mathrm{KPD}}$")
display(result_table)
print(result_table.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g"))
# Out:
#                     Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 0          $t_{\mathrm{LLR}}$                             0.00076
# 1              $\overline{D}$                             0.00782
# 2             $\widetilde{D}$                             0.01930
# 3             $\widetilde{W}$                             0.03098
# 4  $\overline{\|\cdot\|}_{F}$                             0.04349
# 5          $d_{\mathrm{FPD}}$                             0.04715
# 6          $d_{\mathrm{KPD}}$                             0.06866
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)  \
# 0                             0.00106           1679
# 1                             0.01060            809
# 2                             0.02622            773
# 3                             0.04386            572
# 4                             0.05967            630
# 5                             0.06680            697
# 6                             0.10027            741
#
#    $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 0                                0.00144
# 1                                0.01732
# 2                                0.03952
# 3                                0.06058
# 4                                0.12634
# 5                                0.08881
# 6                                1.84082
#
#    $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)  \
# 0                                0.00195              1490
# 1                                0.02348               673
# 2                                0.05572               709
# 3                                0.08801               535
# 4                                0.17572               538
# 5                                0.13017               702
# 6                                2.28199               544
#
#    $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 0                                    0.00071
# 1                                    0.00669
# 2                                    0.01610
# 3                                    0.02632
# 4                                    0.04105
# 5                                    0.04166
# 6                                    0.06866
#
#    $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)  \
# 0                                    0.00095                  1633
# 1                                    0.00894                   696
# 2                                    0.02195                   754
# 3                                    0.03771                   570
# 4                                    0.05603                   620
# 5                                    0.05997                   699
# 6                                    0.10087                   751
#
#   $t^{\mathrm{null}}$ (s)
# 0                       -
# 1                      73
# 2                    1429
# 3                     926
# 4                      36
# 5                     606
# 6                   21885
# \begin{tabular}{l|llr|llr|llr|r}
# \toprule
# Statistic & $\epsilon^{\mu}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu}_{99\%\mathrm{CL}}$ & $t^{\mu}$ (s) & $\epsilon^{\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\sigma}_{99\%\mathrm{CL}}$ & $t^{\sigma}$ (s) & $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$ & $t^{\mu-\sigma}$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $t_{\mathrm{LLR}}$ & 0.00076 & 0.0011 & 1679 & 0.0014 & 0.0019 & 1490 & 0.00071 & 0.00095 & 1633 & - \\
# $\overline{D}$ & 0.0078 & 0.011 & 809 & 0.017 & 0.023 & 673 & 0.0067 & 0.0089 & 696 & 73 \\
# $\widetilde{D}$ & 0.019 & 0.026 & 773 & 0.04 & 0.056 & 709 & 0.016 & 0.022 & 754 & 1429 \\
# $\widetilde{W}$ & 0.031 & 0.044 & 572 & 0.061 & 0.088 & 535 & 0.026 & 0.038 & 570 & 926 \\
# $\overline{\|\cdot\|}_{F}$ & 0.043 & 0.06 & 630 & 0.13 & 0.18 & 538 & 0.041 & 0.056 & 620 & 36 \\
# $d_{\mathrm{FPD}}$ & 0.047 & 0.067 & 697 & 0.089 & 0.13 & 702 & 0.042 & 0.06 & 699 & 606 \\
# $d_{\mathrm{KPD}}$ & 0.069 & 0.1 & 741 & 1.8 & 2.3 & 544 & 0.069 & 0.1 & 751 & 21885 \\
# \bottomrule
# \end{tabular}
