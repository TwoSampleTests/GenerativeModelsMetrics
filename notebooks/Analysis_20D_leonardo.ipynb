# %% [markdown]
# # Initialize

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

sys.path.insert(0,'../utils_func/')
import MixtureDistributions # type: ignore

sys.path.insert(0,'../')
import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std, compute_exclusion_bisection, compute_exclusion_LR_bisection, save_update_metrics_config # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "../results_leonardo/"
if not os.path.exists(results_dir):
    print("WARNING: Results directory does not exist")
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-11 17:16:27.565993: Importing os...
# 2024-04-11 17:16:27.566117: Importing sys...
# Visible devices: [1]
# 2024-04-11 17:16:27.566359: Importing timer from timeit...
# 2024-04-11 17:16:27.566428: Setting env variables for tf import (only device(s) [1] will be available)...
# 2024-04-11 17:16:27.566555: Importing numpy...
# 2024-04-11 17:16:27.668316: Importing matplotlib...
# 2024-04-11 17:16:28.025012: Importing h5py...
# 2024-04-11 17:16:28.048839: Importing importlib.util...
# 2024-04-11 17:16:28.048936: Importing json...
# 2024-04-11 17:16:28.048996: Importing pandas...
# 2024-04-11 17:16:28.481621: Importing random...
# 2024-04-11 17:16:28.481754: Importing scipy utils...
# 2024-04-11 17:16:28.935803: Importing subprocess...
# 2024-04-11 17:16:28.935914: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-11 17:16:32.389427: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-11 17:16:33.425681: Importing timeit...
# 2024-04-11 17:16:33.425765: Importing tqdm...
# 2024-04-11 17:16:33.433574: Importing typing...
# 2024-04-11 17:16:33.433679: Setting tf configs...
# 2024-04-11 17:16:33.531968: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-11 17:16:38.262661: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-04-11 17:16:38.292348: All done.

# %% [markdown]
# # Fixed $n=50000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 10_000
batch_size_test = 50_000
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MixtureGaussian(ncomp, ndims, 0., 0., seed)
dist_2 = MixtureDistributions.MixtureGaussian(ncomp, ndims, eps_loc, eps_scale, seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture.Mixture'> <class 'tensorflow_probability.python.distributions.mixture.Mixture'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 500000000
# batch_size 50000
# niter 10000
# niter * batch_size 500000000
# small_sample False

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               #min_samples_input = 20_000,
                               #max_samples_input = 50_000,
                               num_batches = 20)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4,
                               block_size = 10_000,
                               num_batches = 1,
                               batch_size = 50_000)
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            50000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...       20           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True       20           0  float64    20  500000000         False
#
#    ncomp
# 0      5
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fn": {"name": "fn", # type: ignore
                                       "object_name": "FNMetric",
                                       "class_name": "GMetrics.FNMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns)/ndims,
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)/ndims",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200,
                                       "latex": "$\overline{\|\cdot\|}_{F}$",
                                       "null_file": null_hypotheses_dir+"FN.json"},
                               "fpd": {"name": "fpd",
                                       "object_name": "FPDMetric",
                                       "class_name": "GMetrics.FPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1000,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50,
                                       "latex": "$d_{\mathrm{FPD}}$",
                                       "null_file": null_hypotheses_dir+"FPD.json"},
                               "kpd": {"name": "kpd",
                                       "object_name": "KPDMetric" ,
                                       "class_name": "GMetrics.KPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1,
                                       "latex": "$d_{\mathrm{KPD}}$",
                                       "null_file": null_hypotheses_dir+"KPD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 5000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fn': {'name': 'fn',
#   'object_name': 'FNMetric',
#   'class_name': 'GMetrics.FNMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)/ndims',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 200,
#   'latex': '$\\overline{\\|\\cdot\\|}_{F}$',
#   'null_file': '../results_leonardo/20D_50K/null_hypothesis/FN.json'},
#  'fpd': {'name': 'fpd',
#   'object_name': 'FPDMetric',
#   'class_name': 'GMetrics.FPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 50,
#   'latex': '$d_{\\mathrm{FPD}}$',
#   'null_file': '../results_leonardo/20D_50K/null_hypothesis/FPD.json'},
#  'kpd': {'name': 'kpd',
#   'object_name': 'KPDMetric',
#   'class_name': 'GMetrics.KPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{KPD}}$',
#   'null_file': '../results_leonardo/20D_50K/null_hypothesis/KPD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 5000,
#   'latex': '$\\overline{D}$',
#   'null_file': '../results_leonardo/20D_50K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{D}$',
#   'null_file': '../results_leonardo/20D_50K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{W}$',
#   'null_file': '../results_leonardo/20D_50K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$t_{\\mu}$',
#   'null_file': '../results_leonardo/20D_50K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fn from ../results_leonardo/20D_50K/null_hypothesis/FN.json
# Loading fpd from ../results_leonardo/20D_50K/null_hypothesis/FPD.json
# Computing and savng kpd with max_vectorize = 1
#
# ------------------------------------------
# Starting KPD metric calculation...
# Running TF KPD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10000
# Iterating from 0 to 1 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712848602.531618 2598324 service.cc:145] XLA service 0xb9dc9170 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1712848602.531670 2598324 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1712848602.627489 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1712848602.632692 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1712848602.636313 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1712848602.636640 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1712848602.637554 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1712848602.637624 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1712848602.637695 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1712848602.637761 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1712848602.637826 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1712848602.637892 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1712848602.637957 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1712848602.638025 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1712848602.638089 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_25/Assert/Assert
# W0000 00:00:1712848602.638155 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_27/Assert/Assert
# W0000 00:00:1712848602.638218 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_29/Assert/Assert
# W0000 00:00:1712848602.638283 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_31/Assert/Assert
# W0000 00:00:1712848602.638347 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_33/Assert/Assert
# W0000 00:00:1712848602.638412 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_35/Assert/Assert
# W0000 00:00:1712848602.638476 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_37/Assert/Assert
# W0000 00:00:1712848602.638542 2598324 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_39/Assert/Assert
# I0000 00:00:1712848642.109573 2598324 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# Iterating from 1 to 2 out of 10000 .
# Iterating from 2 to 3 out of 10000 .
# Iterating from 3 to 4 out of 10000 .
# Iterating from 4 to 5 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f2fc01f8180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 5 to 6 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f2fc01f82c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 6 to 7 out of 10000 .
# Iterating from 7 to 8 out of 10000 .
# Iterating from 8 to 9 out of 10000 .
# Iterating from 9 to 10 out of 10000 .
# Iterating from 10 to 11 out of 10000 .
# Iterating from 11 to 12 out of 10000 .
# Iterating from 12 to 13 out of 10000 .
# Iterating from 13 to 14 out of 10000 .
# Iterating from 14 to 15 out of 10000 .
# Iterating from 15 to 16 out of 10000 .
# Iterating from 16 to 17 out of 10000 .
# Iterating from 17 to 18 out of 10000 .
# Iterating from 18 to 19 out of 10000 .
# Iterating from 19 to 20 out of 10000 .
# Iterating from 20 to 21 out of 10000 .
# Iterating from 21 to 22 out of 10000 .
# Iterating from 22 to 23 out of 10000 .
# Iterating from 23 to 24 out of 10000 .
# Iterating from 24 to 25 out of 10000 .
# Iterating from 25 to 26 out of 10000 .
# Iterating from 26 to 27 out of 10000 .
# Iterating from 27 to 28 out of 10000 .
# Iterating from 28 to 29 out of 10000 .
# Iterating from 29 to 30 out of 10000 .
# Iterating from 30 to 31 out of 10000 .
# Iterating from 31 to 32 out of 10000 .
# Iterating from 32 to 33 out of 10000 .
# Iterating from 33 to 34 out of 10000 .
# Iterating from 34 to 35 out of 10000 .
# Iterating from 35 to 36 out of 10000 .
# Iterating from 36 to 37 out of 10000 .
# Iterating from 37 to 38 out of 10000 .
# Iterating from 38 to 39 out of 10000 .
# Iterating from 39 to 40 out of 10000 .
# Iterating from 40 to 41 out of 10000 .
# Iterating from 41 to 42 out of 10000 .
# Iterating from 42 to 43 out of 10000 .
# Iterating from 43 to 44 out of 10000 .
# Iterating from 44 to 45 out of 10000 .
# Iterating from 45 to 46 out of 10000 .
# Iterating from 46 to 47 out of 10000 .
# Iterating from 47 to 48 out of 10000 .
# Iterating from 48 to 49 out of 10000 .
# Iterating from 49 to 50 out of 10000 .
# Iterating from 50 to 51 out of 10000 .
# Iterating from 51 to 52 out of 10000 .
# Iterating from 52 to 53 out of 10000 .
# Iterating from 53 to 54 out of 10000 .
# Iterating from 54 to 55 out of 10000 .
# Iterating from 55 to 56 out of 10000 .
# Iterating from 56 to 57 out of 10000 .
# Iterating from 57 to 58 out of 10000 .
# Iterating from 58 to 59 out of 10000 .
# Iterating from 59 to 60 out of 10000 .
# Iterating from 60 to 61 out of 10000 .
# Iterating from 61 to 62 out of 10000 .
# Iterating from 62 to 63 out of 10000 .
# Iterating from 63 to 64 out of 10000 .
# Iterating from 64 to 65 out of 10000 .
# Iterating from 65 to 66 out of 10000 .
# Iterating from 66 to 67 out of 10000 .
# Iterating from 67 to 68 out of 10000 .
# Iterating from 68 to 69 out of 10000 .
# Iterating from 69 to 70 out of 10000 .
# Iterating from 70 to 71 out of 10000 .
# Iterating from 71 to 72 out of 10000 .
# Iterating from 72 to 73 out of 10000 .
# Iterating from 73 to 74 out of 10000 .
# Iterating from 74 to 75 out of 10000 .
# Iterating from 75 to 76 out of 10000 .
# Iterating from 76 to 77 out of 10000 .
# Iterating from 77 to 78 out of 10000 .
# Iterating from 78 to 79 out of 10000 .
# Iterating from 79 to 80 out of 10000 .
# Iterating from 80 to 81 out of 10000 .
# Iterating from 81 to 82 out of 10000 .
# Iterating from 82 to 83 out of 10000 .
# Iterating from 83 to 84 out of 10000 .
# Iterating from 84 to 85 out of 10000 .
# Iterating from 85 to 86 out of 10000 .
# Iterating from 86 to 87 out of 10000 .
# Iterating from 87 to 88 out of 10000 .
# Iterating from 88 to 89 out of 10000 .
# Iterating from 89 to 90 out of 10000 .
# Iterating from 90 to 91 out of 10000 .
# Iterating from 91 to 92 out of 10000 .
# Iterating from 92 to 93 out of 10000 .
# Iterating from 93 to 94 out of 10000 .
# Iterating from 94 to 95 out of 10000 .
# Iterating from 95 to 96 out of 10000 .
# Iterating from 96 to 97 out of 10000 .
# Iterating from 97 to 98 out of 10000 .
# Iterating from 98 to 99 out of 10000 .
# Iterating from 99 to 100 out of 10000 .
# Iterating from 100 to 101 out of 10000 .
# Iterating from 101 to 102 out of 10000 .
# Iterating from 102 to 103 out of 10000 .
# Iterating from 103 to 104 out of 10000 .
# Iterating from 104 to 105 out of 10000 .
# Iterating from 105 to 106 out of 10000 .
# Iterating from 106 to 107 out of 10000 .
# Iterating from 107 to 108 out of 10000 .
# Iterating from 108 to 109 out of 10000 .
# Iterating from 109 to 110 out of 10000 .
# Iterating from 110 to 111 out of 10000 .
# Iterating from 111 to 112 out of 10000 .
# Iterating from 112 to 113 out of 10000 .
# Iterating from 113 to 114 out of 10000 .
# Iterating from 114 to 115 out of 10000 .
# Iterating from 115 to 116 out of 10000 .
# Iterating from 116 to 117 out of 10000 .
# Iterating from 117 to 118 out of 10000 .
# Iterating from 118 to 119 out of 10000 .
# Iterating from 119 to 120 out of 10000 .
# Iterating from 120 to 121 out of 10000 .
# Iterating from 121 to 122 out of 10000 .
# Iterating from 122 to 123 out of 10000 .
# Iterating from 123 to 124 out of 10000 .
# Iterating from 124 to 125 out of 10000 .
# Iterating from 125 to 126 out of 10000 .
# Iterating from 126 to 127 out of 10000 .
# Iterating from 127 to 128 out of 10000 .
# Iterating from 128 to 129 out of 10000 .
# Iterating from 129 to 130 out of 10000 .
# Iterating from 130 to 131 out of 10000 .
# Iterating from 131 to 132 out of 10000 .
# Iterating from 132 to 133 out of 10000 .
# Iterating from 133 to 134 out of 10000 .
# Iterating from 134 to 135 out of 10000 .
# Iterating from 135 to 136 out of 10000 .
# Iterating from 136 to 137 out of 10000 .
# Iterating from 137 to 138 out of 10000 .
# Iterating from 138 to 139 out of 10000 .
# Iterating from 139 to 140 out of 10000 .
# Iterating from 140 to 141 out of 10000 .
# Iterating from 141 to 142 out of 10000 .
# Iterating from 142 to 143 out of 10000 .
# Iterating from 143 to 144 out of 10000 .
# Iterating from 144 to 145 out of 10000 .
# Iterating from 145 to 146 out of 10000 .
# Iterating from 146 to 147 out of 10000 .
# Iterating from 147 to 148 out of 10000 .
# Iterating from 148 to 149 out of 10000 .
# Iterating from 149 to 150 out of 10000 .
# Iterating from 150 to 151 out of 10000 .
# Iterating from 151 to 152 out of 10000 .
# Iterating from 152 to 153 out of 10000 .
# Iterating from 153 to 154 out of 10000 .
# Iterating from 154 to 155 out of 10000 .
# Iterating from 155 to 156 out of 10000 .
# Iterating from 156 to 157 out of 10000 .
# Iterating from 157 to 158 out of 10000 .
# Iterating from 158 to 159 out of 10000 .
# Iterating from 159 to 160 out of 10000 .
# Iterating from 160 to 161 out of 10000 .
# Iterating from 161 to 162 out of 10000 .
# Iterating from 162 to 163 out of 10000 .
# Iterating from 163 to 164 out of 10000 .
# Iterating from 164 to 165 out of 10000 .
# Iterating from 165 to 166 out of 10000 .
# Iterating from 166 to 167 out of 10000 .
# Iterating from 167 to 168 out of 10000 .
# Iterating from 168 to 169 out of 10000 .
# Iterating from 169 to 170 out of 10000 .
# Iterating from 170 to 171 out of 10000 .
# Iterating from 171 to 172 out of 10000 .
# Iterating from 172 to 173 out of 10000 .
# Iterating from 173 to 174 out of 10000 .
# Iterating from 174 to 175 out of 10000 .
# Iterating from 175 to 176 out of 10000 .
# Iterating from 176 to 177 out of 10000 .
# Iterating from 177 to 178 out of 10000 .
# Iterating from 178 to 179 out of 10000 .
# Iterating from 179 to 180 out of 10000 .
# Iterating from 180 to 181 out of 10000 .
# Iterating from 181 to 182 out of 10000 .
# Iterating from 182 to 183 out of 10000 .
# Iterating from 183 to 184 out of 10000 .
# Iterating from 184 to 185 out of 10000 .
# Iterating from 185 to 186 out of 10000 .
# Iterating from 186 to 187 out of 10000 .
# Iterating from 187 to 188 out of 10000 .
# Iterating from 188 to 189 out of 10000 .
# Iterating from 189 to 190 out of 10000 .
# Iterating from 190 to 191 out of 10000 .
# Iterating from 191 to 192 out of 10000 .
# Iterating from 192 to 193 out of 10000 .
# Iterating from 193 to 194 out of 10000 .
# Iterating from 194 to 195 out of 10000 .
# Iterating from 195 to 196 out of 10000 .
# Iterating from 196 to 197 out of 10000 .
# Iterating from 197 to 198 out of 10000 .
# Iterating from 198 to 199 out of 10000 .
# Iterating from 199 to 200 out of 10000 .
# Iterating from 200 to 201 out of 10000 .
# Iterating from 201 to 202 out of 10000 .
# Iterating from 202 to 203 out of 10000 .
# Iterating from 203 to 204 out of 10000 .
# Iterating from 204 to 205 out of 10000 .
# Iterating from 205 to 206 out of 10000 .
# Iterating from 206 to 207 out of 10000 .
# Iterating from 207 to 208 out of 10000 .
# Iterating from 208 to 209 out of 10000 .
# Iterating from 209 to 210 out of 10000 .
# Iterating from 210 to 211 out of 10000 .
# Iterating from 211 to 212 out of 10000 .
# Iterating from 212 to 213 out of 10000 .
# Iterating from 213 to 214 out of 10000 .
# Iterating from 214 to 215 out of 10000 .
# Iterating from 215 to 216 out of 10000 .
# Iterating from 216 to 217 out of 10000 .
# Iterating from 217 to 218 out of 10000 .
# Iterating from 218 to 219 out of 10000 .
# Iterating from 219 to 220 out of 10000 .
# Iterating from 220 to 221 out of 10000 .
# Iterating from 221 to 222 out of 10000 .
# Iterating from 222 to 223 out of 10000 .
# Iterating from 223 to 224 out of 10000 .
# Iterating from 224 to 225 out of 10000 .
# Iterating from 225 to 226 out of 10000 .
# Iterating from 226 to 227 out of 10000 .
# Iterating from 227 to 228 out of 10000 .
# Iterating from 228 to 229 out of 10000 .
# Iterating from 229 to 230 out of 10000 .
# Iterating from 230 to 231 out of 10000 .
# Iterating from 231 to 232 out of 10000 .
# Iterating from 232 to 233 out of 10000 .
# Iterating from 233 to 234 out of 10000 .
# Iterating from 234 to 235 out of 10000 .
# Iterating from 235 to 236 out of 10000 .
# Iterating from 236 to 237 out of 10000 .
# Iterating from 237 to 238 out of 10000 .
# Iterating from 238 to 239 out of 10000 .
# Iterating from 239 to 240 out of 10000 .
# Iterating from 240 to 241 out of 10000 .
# Iterating from 241 to 242 out of 10000 .
# Iterating from 242 to 243 out of 10000 .
# Iterating from 243 to 244 out of 10000 .
# Iterating from 244 to 245 out of 10000 .
# Iterating from 245 to 246 out of 10000 .
# Iterating from 246 to 247 out of 10000 .
# Iterating from 247 to 248 out of 10000 .
# Iterating from 248 to 249 out of 10000 .
# Iterating from 249 to 250 out of 10000 .
# Iterating from 250 to 251 out of 10000 .
# Iterating from 251 to 252 out of 10000 .
# Iterating from 252 to 253 out of 10000 .
# Iterating from 253 to 254 out of 10000 .
# Iterating from 254 to 255 out of 10000 .
# Iterating from 255 to 256 out of 10000 .
# Iterating from 256 to 257 out of 10000 .
# Iterating from 257 to 258 out of 10000 .
# Iterating from 258 to 259 out of 10000 .
# Iterating from 259 to 260 out of 10000 .
# Iterating from 260 to 261 out of 10000 .
# Iterating from 261 to 262 out of 10000 .
# Iterating from 262 to 263 out of 10000 .
# Iterating from 263 to 264 out of 10000 .
# Iterating from 264 to 265 out of 10000 .
# Iterating from 265 to 266 out of 10000 .
# Iterating from 266 to 267 out of 10000 .
# Iterating from 267 to 268 out of 10000 .
# Iterating from 268 to 269 out of 10000 .
# Iterating from 269 to 270 out of 10000 .
# Iterating from 270 to 271 out of 10000 .
# Iterating from 271 to 272 out of 10000 .
# Iterating from 272 to 273 out of 10000 .
# Iterating from 273 to 274 out of 10000 .
# Iterating from 274 to 275 out of 10000 .
# Iterating from 275 to 276 out of 10000 .
# Iterating from 276 to 277 out of 10000 .
# Iterating from 277 to 278 out of 10000 .
# Iterating from 278 to 279 out of 10000 .
# Iterating from 279 to 280 out of 10000 .
# Iterating from 280 to 281 out of 10000 .
# Iterating from 281 to 282 out of 10000 .
# Iterating from 282 to 283 out of 10000 .
# Iterating from 283 to 284 out of 10000 .
# Iterating from 284 to 285 out of 10000 .
# Iterating from 285 to 286 out of 10000 .
# Iterating from 286 to 287 out of 10000 .
# Iterating from 287 to 288 out of 10000 .
# Iterating from 288 to 289 out of 10000 .
# Iterating from 289 to 290 out of 10000 .
# Iterating from 290 to 291 out of 10000 .
# Iterating from 291 to 292 out of 10000 .
# Iterating from 292 to 293 out of 10000 .
# Iterating from 293 to 294 out of 10000 .
# Iterating from 294 to 295 out of 10000 .
# Iterating from 295 to 296 out of 10000 .
# Iterating from 296 to 297 out of 10000 .
# Iterating from 297 to 298 out of 10000 .
# Iterating from 298 to 299 out of 10000 .
# Iterating from 299 to 300 out of 10000 .
# Iterating from 300 to 301 out of 10000 .
# Iterating from 301 to 302 out of 10000 .
# Iterating from 302 to 303 out of 10000 .
# Iterating from 303 to 304 out of 10000 .
# Iterating from 304 to 305 out of 10000 .
# Iterating from 305 to 306 out of 10000 .
# Iterating from 306 to 307 out of 10000 .
# Iterating from 307 to 308 out of 10000 .
# Iterating from 308 to 309 out of 10000 .
# Iterating from 309 to 310 out of 10000 .
# Iterating from 310 to 311 out of 10000 .
# Iterating from 311 to 312 out of 10000 .
# Iterating from 312 to 313 out of 10000 .
# Iterating from 313 to 314 out of 10000 .
# Iterating from 314 to 315 out of 10000 .
# Iterating from 315 to 316 out of 10000 .
# Iterating from 316 to 317 out of 10000 .
# Iterating from 317 to 318 out of 10000 .
# Iterating from 318 to 319 out of 10000 .
# Iterating from 319 to 320 out of 10000 .
# Iterating from 320 to 321 out of 10000 .
# Iterating from 321 to 322 out of 10000 .
# Iterating from 322 to 323 out of 10000 .
# Iterating from 323 to 324 out of 10000 .
# Iterating from 324 to 325 out of 10000 .
# Iterating from 325 to 326 out of 10000 .
# Iterating from 326 to 327 out of 10000 .
# Iterating from 327 to 328 out of 10000 .
# Iterating from 328 to 329 out of 10000 .
# Iterating from 329 to 330 out of 10000 .
# Iterating from 330 to 331 out of 10000 .
# Iterating from 331 to 332 out of 10000 .
# Iterating from 332 to 333 out of 10000 .
# Iterating from 333 to 334 out of 10000 .
# Iterating from 334 to 335 out of 10000 .
# Iterating from 335 to 336 out of 10000 .
# Iterating from 336 to 337 out of 10000 .
# Iterating from 337 to 338 out of 10000 .
# Iterating from 338 to 339 out of 10000 .
# Iterating from 339 to 340 out of 10000 .
# Iterating from 340 to 341 out of 10000 .
# Iterating from 341 to 342 out of 10000 .
# Iterating from 342 to 343 out of 10000 .
# Iterating from 343 to 344 out of 10000 .
# Iterating from 344 to 345 out of 10000 .
# Iterating from 345 to 346 out of 10000 .
# Iterating from 346 to 347 out of 10000 .
# Iterating from 347 to 348 out of 10000 .
# Iterating from 348 to 349 out of 10000 .
# Iterating from 349 to 350 out of 10000 .
# Iterating from 350 to 351 out of 10000 .
# Iterating from 351 to 352 out of 10000 .
# Iterating from 352 to 353 out of 10000 .
# Iterating from 353 to 354 out of 10000 .
# Iterating from 354 to 355 out of 10000 .
# Iterating from 355 to 356 out of 10000 .
# Iterating from 356 to 357 out of 10000 .
# Iterating from 357 to 358 out of 10000 .
# Iterating from 358 to 359 out of 10000 .
# Iterating from 359 to 360 out of 10000 .
# Iterating from 360 to 361 out of 10000 .
# Iterating from 361 to 362 out of 10000 .
# Iterating from 362 to 363 out of 10000 .
# Iterating from 363 to 364 out of 10000 .
# Iterating from 364 to 365 out of 10000 .
# Iterating from 365 to 366 out of 10000 .
# Iterating from 366 to 367 out of 10000 .
# Iterating from 367 to 368 out of 10000 .
# Iterating from 368 to 369 out of 10000 .
# Iterating from 369 to 370 out of 10000 .
# Iterating from 370 to 371 out of 10000 .
# Iterating from 371 to 372 out of 10000 .
# Iterating from 372 to 373 out of 10000 .
# Iterating from 373 to 374 out of 10000 .
# Iterating from 374 to 375 out of 10000 .
# Iterating from 375 to 376 out of 10000 .
# Iterating from 376 to 377 out of 10000 .
# Iterating from 377 to 378 out of 10000 .
# Iterating from 378 to 379 out of 10000 .
# Iterating from 379 to 380 out of 10000 .
# Iterating from 380 to 381 out of 10000 .
# Iterating from 381 to 382 out of 10000 .
# Iterating from 382 to 383 out of 10000 .
# Iterating from 383 to 384 out of 10000 .
# Iterating from 384 to 385 out of 10000 .
# Iterating from 385 to 386 out of 10000 .
# Iterating from 386 to 387 out of 10000 .
# Iterating from 387 to 388 out of 10000 .
# Iterating from 388 to 389 out of 10000 .
# Iterating from 389 to 390 out of 10000 .
# Iterating from 390 to 391 out of 10000 .
# Iterating from 391 to 392 out of 10000 .
# Iterating from 392 to 393 out of 10000 .
# Iterating from 393 to 394 out of 10000 .
# Iterating from 394 to 395 out of 10000 .
# Iterating from 395 to 396 out of 10000 .
# Iterating from 396 to 397 out of 10000 .
# Iterating from 397 to 398 out of 10000 .
# Iterating from 398 to 399 out of 10000 .
# Iterating from 399 to 400 out of 10000 .
# Iterating from 400 to 401 out of 10000 .
# Iterating from 401 to 402 out of 10000 .
# Iterating from 402 to 403 out of 10000 .
# Iterating from 403 to 404 out of 10000 .
# Iterating from 404 to 405 out of 10000 .
# Iterating from 405 to 406 out of 10000 .
# Iterating from 406 to 407 out of 10000 .
# Iterating from 407 to 408 out of 10000 .
# Iterating from 408 to 409 out of 10000 .
# Iterating from 409 to 410 out of 10000 .
# Iterating from 410 to 411 out of 10000 .
# Iterating from 411 to 412 out of 10000 .
# Iterating from 412 to 413 out of 10000 .
# Iterating from 413 to 414 out of 10000 .
# Iterating from 414 to 415 out of 10000 .
# Iterating from 415 to 416 out of 10000 .
# Iterating from 416 to 417 out of 10000 .
# Iterating from 417 to 418 out of 10000 .
# Iterating from 418 to 419 out of 10000 .
# Iterating from 419 to 420 out of 10000 .
# Iterating from 420 to 421 out of 10000 .
# Iterating from 421 to 422 out of 10000 .
# Iterating from 422 to 423 out of 10000 .
# Iterating from 423 to 424 out of 10000 .
# Iterating from 424 to 425 out of 10000 .
# Iterating from 425 to 426 out of 10000 .
# Iterating from 426 to 427 out of 10000 .
# Iterating from 427 to 428 out of 10000 .
# Iterating from 428 to 429 out of 10000 .
# Iterating from 429 to 430 out of 10000 .
# Iterating from 430 to 431 out of 10000 .
# Iterating from 431 to 432 out of 10000 .
# Iterating from 432 to 433 out of 10000 .
# Iterating from 433 to 434 out of 10000 .
# Iterating from 434 to 435 out of 10000 .
# Iterating from 435 to 436 out of 10000 .
# Iterating from 436 to 437 out of 10000 .
# Iterating from 437 to 438 out of 10000 .
# Iterating from 438 to 439 out of 10000 .
# Iterating from 439 to 440 out of 10000 .
# Iterating from 440 to 441 out of 10000 .
# Iterating from 441 to 442 out of 10000 .
# Iterating from 442 to 443 out of 10000 .
# Iterating from 443 to 444 out of 10000 .
# Iterating from 444 to 445 out of 10000 .
# Iterating from 445 to 446 out of 10000 .
# Iterating from 446 to 447 out of 10000 .
# Iterating from 447 to 448 out of 10000 .
# Iterating from 448 to 449 out of 10000 .
# Iterating from 449 to 450 out of 10000 .
# Iterating from 450 to 451 out of 10000 .
# Iterating from 451 to 452 out of 10000 .
# Iterating from 452 to 453 out of 10000 .
# Iterating from 453 to 454 out of 10000 .
# Iterating from 454 to 455 out of 10000 .
# Iterating from 455 to 456 out of 10000 .
# Iterating from 456 to 457 out of 10000 .
# Iterating from 457 to 458 out of 10000 .
# Iterating from 458 to 459 out of 10000 .
# Iterating from 459 to 460 out of 10000 .
# Iterating from 460 to 461 out of 10000 .
# Iterating from 461 to 462 out of 10000 .
# Iterating from 462 to 463 out of 10000 .
# Iterating from 463 to 464 out of 10000 .
# Iterating from 464 to 465 out of 10000 .
# Iterating from 465 to 466 out of 10000 .
# Iterating from 466 to 467 out of 10000 .
# Iterating from 467 to 468 out of 10000 .
# Iterating from 468 to 469 out of 10000 .
# Iterating from 469 to 470 out of 10000 .
# Iterating from 470 to 471 out of 10000 .
# Iterating from 471 to 472 out of 10000 .
# Iterating from 472 to 473 out of 10000 .
# Iterating from 473 to 474 out of 10000 .
# Iterating from 474 to 475 out of 10000 .
# Iterating from 475 to 476 out of 10000 .
# Iterating from 476 to 477 out of 10000 .
# Iterating from 477 to 478 out of 10000 .
# Iterating from 478 to 479 out of 10000 .
# Iterating from 479 to 480 out of 10000 .
# Iterating from 480 to 481 out of 10000 .
# Iterating from 481 to 482 out of 10000 .
# Iterating from 482 to 483 out of 10000 .
# Iterating from 483 to 484 out of 10000 .
# Iterating from 484 to 485 out of 10000 .
# Iterating from 485 to 486 out of 10000 .
# Iterating from 486 to 487 out of 10000 .
# Iterating from 487 to 488 out of 10000 .
# Iterating from 488 to 489 out of 10000 .
# Iterating from 489 to 490 out of 10000 .
# Iterating from 490 to 491 out of 10000 .
# Iterating from 491 to 492 out of 10000 .
# Iterating from 492 to 493 out of 10000 .
# Iterating from 493 to 494 out of 10000 .
# Iterating from 494 to 495 out of 10000 .
# Iterating from 495 to 496 out of 10000 .
# Iterating from 496 to 497 out of 10000 .
# Iterating from 497 to 498 out of 10000 .
# Iterating from 498 to 499 out of 10000 .
# Iterating from 499 to 500 out of 10000 .
# Iterating from 500 to 501 out of 10000 .
# Iterating from 501 to 502 out of 10000 .
# Iterating from 502 to 503 out of 10000 .
# Iterating from 503 to 504 out of 10000 .
# Iterating from 504 to 505 out of 10000 .
# Iterating from 505 to 506 out of 10000 .
# Iterating from 506 to 507 out of 10000 .
# Iterating from 507 to 508 out of 10000 .
# Iterating from 508 to 509 out of 10000 .
# Iterating from 509 to 510 out of 10000 .
# Iterating from 510 to 511 out of 10000 .
# Iterating from 511 to 512 out of 10000 .
# Iterating from 512 to 513 out of 10000 .
# Iterating from 513 to 514 out of 10000 .
# Iterating from 514 to 515 out of 10000 .
# Iterating from 515 to 516 out of 10000 .
# Iterating from 516 to 517 out of 10000 .
# Iterating from 517 to 518 out of 10000 .
# Iterating from 518 to 519 out of 10000 .
# Iterating from 519 to 520 out of 10000 .
# Iterating from 520 to 521 out of 10000 .
# Iterating from 521 to 522 out of 10000 .
# Iterating from 522 to 523 out of 10000 .
# Iterating from 523 to 524 out of 10000 .
# Iterating from 524 to 525 out of 10000 .
# Iterating from 525 to 526 out of 10000 .
# Iterating from 526 to 527 out of 10000 .
# Iterating from 527 to 528 out of 10000 .
# Iterating from 528 to 529 out of 10000 .
# Iterating from 529 to 530 out of 10000 .
# Iterating from 530 to 531 out of 10000 .
# Iterating from 531 to 532 out of 10000 .
# Iterating from 532 to 533 out of 10000 .
# Iterating from 533 to 534 out of 10000 .
# Iterating from 534 to 535 out of 10000 .
# Iterating from 535 to 536 out of 10000 .
# Iterating from 536 to 537 out of 10000 .
# Iterating from 537 to 538 out of 10000 .
# Iterating from 538 to 539 out of 10000 .
# Iterating from 539 to 540 out of 10000 .
# Iterating from 540 to 541 out of 10000 .
# Iterating from 541 to 542 out of 10000 .
# Iterating from 542 to 543 out of 10000 .
# Iterating from 543 to 544 out of 10000 .
# Iterating from 544 to 545 out of 10000 .
# Iterating from 545 to 546 out of 10000 .
# Iterating from 546 to 547 out of 10000 .
# Iterating from 547 to 548 out of 10000 .
# Iterating from 548 to 549 out of 10000 .
# Iterating from 549 to 550 out of 10000 .
# Iterating from 550 to 551 out of 10000 .
# Iterating from 551 to 552 out of 10000 .
# Iterating from 552 to 553 out of 10000 .
# Iterating from 553 to 554 out of 10000 .
# Iterating from 554 to 555 out of 10000 .
# Iterating from 555 to 556 out of 10000 .
# Iterating from 556 to 557 out of 10000 .
# Iterating from 557 to 558 out of 10000 .
# Iterating from 558 to 559 out of 10000 .
# Iterating from 559 to 560 out of 10000 .
# Iterating from 560 to 561 out of 10000 .
# Iterating from 561 to 562 out of 10000 .
# Iterating from 562 to 563 out of 10000 .
# Iterating from 563 to 564 out of 10000 .
# Iterating from 564 to 565 out of 10000 .
# Iterating from 565 to 566 out of 10000 .
# Iterating from 566 to 567 out of 10000 .
# Iterating from 567 to 568 out of 10000 .
# Iterating from 568 to 569 out of 10000 .
# Iterating from 569 to 570 out of 10000 .
# Iterating from 570 to 571 out of 10000 .
# Iterating from 571 to 572 out of 10000 .
# Iterating from 572 to 573 out of 10000 .
# Iterating from 573 to 574 out of 10000 .
# Iterating from 574 to 575 out of 10000 .
# Iterating from 575 to 576 out of 10000 .
# Iterating from 576 to 577 out of 10000 .
# Iterating from 577 to 578 out of 10000 .
# Iterating from 578 to 579 out of 10000 .
# Iterating from 579 to 580 out of 10000 .
# Iterating from 580 to 581 out of 10000 .
# Iterating from 581 to 582 out of 10000 .
# Iterating from 582 to 583 out of 10000 .
# Iterating from 583 to 584 out of 10000 .
# Iterating from 584 to 585 out of 10000 .
# Iterating from 585 to 586 out of 10000 .
# Iterating from 586 to 587 out of 10000 .
# Iterating from 587 to 588 out of 10000 .
# Iterating from 588 to 589 out of 10000 .
# Iterating from 589 to 590 out of 10000 .
# Iterating from 590 to 591 out of 10000 .
# Iterating from 591 to 592 out of 10000 .
# Iterating from 592 to 593 out of 10000 .
# Iterating from 593 to 594 out of 10000 .
# Iterating from 594 to 595 out of 10000 .
# Iterating from 595 to 596 out of 10000 .
# Iterating from 596 to 597 out of 10000 .
# Iterating from 597 to 598 out of 10000 .
# Iterating from 598 to 599 out of 10000 .
# Iterating from 599 to 600 out of 10000 .
# Iterating from 600 to 601 out of 10000 .
# Iterating from 601 to 602 out of 10000 .
# Iterating from 602 to 603 out of 10000 .
# Iterating from 603 to 604 out of 10000 .
# Iterating from 604 to 605 out of 10000 .
# Iterating from 605 to 606 out of 10000 .
# Iterating from 606 to 607 out of 10000 .
# Iterating from 607 to 608 out of 10000 .
# Iterating from 608 to 609 out of 10000 .
# Iterating from 609 to 610 out of 10000 .
# Iterating from 610 to 611 out of 10000 .
# Iterating from 611 to 612 out of 10000 .
# Iterating from 612 to 613 out of 10000 .
# Iterating from 613 to 614 out of 10000 .
# Iterating from 614 to 615 out of 10000 .
# Iterating from 615 to 616 out of 10000 .
# Iterating from 616 to 617 out of 10000 .
# Iterating from 617 to 618 out of 10000 .
# Iterating from 618 to 619 out of 10000 .
# Iterating from 619 to 620 out of 10000 .
# Iterating from 620 to 621 out of 10000 .
# Iterating from 621 to 622 out of 10000 .
# Iterating from 622 to 623 out of 10000 .
# Iterating from 623 to 624 out of 10000 .
# Iterating from 624 to 625 out of 10000 .
# Iterating from 625 to 626 out of 10000 .
# Iterating from 626 to 627 out of 10000 .
# Iterating from 627 to 628 out of 10000 .
# Iterating from 628 to 629 out of 10000 .
# Iterating from 629 to 630 out of 10000 .
# Iterating from 630 to 631 out of 10000 .
# Iterating from 631 to 632 out of 10000 .
# Iterating from 632 to 633 out of 10000 .
# Iterating from 633 to 634 out of 10000 .
# Iterating from 634 to 635 out of 10000 .
# Iterating from 635 to 636 out of 10000 .
# Iterating from 636 to 637 out of 10000 .
# Iterating from 637 to 638 out of 10000 .
# Iterating from 638 to 639 out of 10000 .
# Iterating from 639 to 640 out of 10000 .
# Iterating from 640 to 641 out of 10000 .
# Iterating from 641 to 642 out of 10000 .
# Iterating from 642 to 643 out of 10000 .
# Iterating from 643 to 644 out of 10000 .
# Iterating from 644 to 645 out of 10000 .
# Iterating from 645 to 646 out of 10000 .
# Iterating from 646 to 647 out of 10000 .
# Iterating from 647 to 648 out of 10000 .
# Iterating from 648 to 649 out of 10000 .
# Iterating from 649 to 650 out of 10000 .
# Iterating from 650 to 651 out of 10000 .
# Iterating from 651 to 652 out of 10000 .
# Iterating from 652 to 653 out of 10000 .
# Iterating from 653 to 654 out of 10000 .
# Iterating from 654 to 655 out of 10000 .
# Iterating from 655 to 656 out of 10000 .
# Iterating from 656 to 657 out of 10000 .
# Iterating from 657 to 658 out of 10000 .
# Iterating from 658 to 659 out of 10000 .
# Iterating from 659 to 660 out of 10000 .
# Iterating from 660 to 661 out of 10000 .
# Iterating from 661 to 662 out of 10000 .
# Iterating from 662 to 663 out of 10000 .
# Iterating from 663 to 664 out of 10000 .
# Iterating from 664 to 665 out of 10000 .
# Iterating from 665 to 666 out of 10000 .
# Iterating from 666 to 667 out of 10000 .
# Iterating from 667 to 668 out of 10000 .
# Iterating from 668 to 669 out of 10000 .
# Iterating from 669 to 670 out of 10000 .
# Iterating from 670 to 671 out of 10000 .
# Iterating from 671 to 672 out of 10000 .
# Iterating from 672 to 673 out of 10000 .
# Iterating from 673 to 674 out of 10000 .
# Iterating from 674 to 675 out of 10000 .
# Iterating from 675 to 676 out of 10000 .
# Iterating from 676 to 677 out of 10000 .
# Iterating from 677 to 678 out of 10000 .
# Iterating from 678 to 679 out of 10000 .
# Iterating from 679 to 680 out of 10000 .
# Iterating from 680 to 681 out of 10000 .
# Iterating from 681 to 682 out of 10000 .
# Iterating from 682 to 683 out of 10000 .
# Iterating from 683 to 684 out of 10000 .
# Iterating from 684 to 685 out of 10000 .
# Iterating from 685 to 686 out of 10000 .
# Iterating from 686 to 687 out of 10000 .
# Iterating from 687 to 688 out of 10000 .
# Iterating from 688 to 689 out of 10000 .
# Iterating from 689 to 690 out of 10000 .
# Iterating from 690 to 691 out of 10000 .
# Iterating from 691 to 692 out of 10000 .
# Iterating from 692 to 693 out of 10000 .
# Iterating from 693 to 694 out of 10000 .
# Iterating from 694 to 695 out of 10000 .
# Iterating from 695 to 696 out of 10000 .
# Iterating from 696 to 697 out of 10000 .
# Iterating from 697 to 698 out of 10000 .
# Iterating from 698 to 699 out of 10000 .
# Iterating from 699 to 700 out of 10000 .
# Iterating from 700 to 701 out of 10000 .
# Iterating from 701 to 702 out of 10000 .
# Iterating from 702 to 703 out of 10000 .
# Iterating from 703 to 704 out of 10000 .
# Iterating from 704 to 705 out of 10000 .
# Iterating from 705 to 706 out of 10000 .
# Iterating from 706 to 707 out of 10000 .
# Iterating from 707 to 708 out of 10000 .
# Iterating from 708 to 709 out of 10000 .
# Iterating from 709 to 710 out of 10000 .
# Iterating from 710 to 711 out of 10000 .
# Iterating from 711 to 712 out of 10000 .
# Iterating from 712 to 713 out of 10000 .
# Iterating from 713 to 714 out of 10000 .
# Iterating from 714 to 715 out of 10000 .
# Iterating from 715 to 716 out of 10000 .
# Iterating from 716 to 717 out of 10000 .
# Iterating from 717 to 718 out of 10000 .
# Iterating from 718 to 719 out of 10000 .
# Iterating from 719 to 720 out of 10000 .
# Iterating from 720 to 721 out of 10000 .
# Iterating from 721 to 722 out of 10000 .
# Iterating from 722 to 723 out of 10000 .
# Iterating from 723 to 724 out of 10000 .
# Iterating from 724 to 725 out of 10000 .
# Iterating from 725 to 726 out of 10000 .
# Iterating from 726 to 727 out of 10000 .
# Iterating from 727 to 728 out of 10000 .
# Iterating from 728 to 729 out of 10000 .
# Iterating from 729 to 730 out of 10000 .
# Iterating from 730 to 731 out of 10000 .
# Iterating from 731 to 732 out of 10000 .
# Iterating from 732 to 733 out of 10000 .
# Iterating from 733 to 734 out of 10000 .
# Iterating from 734 to 735 out of 10000 .
# Iterating from 735 to 736 out of 10000 .
# Iterating from 736 to 737 out of 10000 .
# Iterating from 737 to 738 out of 10000 .
# Iterating from 738 to 739 out of 10000 .
# Iterating from 739 to 740 out of 10000 .
# Iterating from 740 to 741 out of 10000 .
# Iterating from 741 to 742 out of 10000 .
# Iterating from 742 to 743 out of 10000 .
# Iterating from 743 to 744 out of 10000 .
# Iterating from 744 to 745 out of 10000 .
# Iterating from 745 to 746 out of 10000 .
# Iterating from 746 to 747 out of 10000 .
# Iterating from 747 to 748 out of 10000 .
# Iterating from 748 to 749 out of 10000 .
# Iterating from 749 to 750 out of 10000 .
# Iterating from 750 to 751 out of 10000 .
# Iterating from 751 to 752 out of 10000 .
# Iterating from 752 to 753 out of 10000 .
# Iterating from 753 to 754 out of 10000 .
# Iterating from 754 to 755 out of 10000 .
# Iterating from 755 to 756 out of 10000 .
# Iterating from 756 to 757 out of 10000 .
# Iterating from 757 to 758 out of 10000 .
# Iterating from 758 to 759 out of 10000 .
# Iterating from 759 to 760 out of 10000 .
# Iterating from 760 to 761 out of 10000 .
# Iterating from 761 to 762 out of 10000 .
# Iterating from 762 to 763 out of 10000 .
# Iterating from 763 to 764 out of 10000 .
# Iterating from 764 to 765 out of 10000 .
# Iterating from 765 to 766 out of 10000 .
# Iterating from 766 to 767 out of 10000 .
# Iterating from 767 to 768 out of 10000 .
# Iterating from 768 to 769 out of 10000 .
# Iterating from 769 to 770 out of 10000 .
# Iterating from 770 to 771 out of 10000 .
# Iterating from 771 to 772 out of 10000 .
# Iterating from 772 to 773 out of 10000 .
# Iterating from 773 to 774 out of 10000 .
# Iterating from 774 to 775 out of 10000 .
# Iterating from 775 to 776 out of 10000 .
# Iterating from 776 to 777 out of 10000 .
# Iterating from 777 to 778 out of 10000 .
# Iterating from 778 to 779 out of 10000 .
# Iterating from 779 to 780 out of 10000 .
# Iterating from 780 to 781 out of 10000 .
# Iterating from 781 to 782 out of 10000 .
# Iterating from 782 to 783 out of 10000 .
# Iterating from 783 to 784 out of 10000 .
# Iterating from 784 to 785 out of 10000 .
# Iterating from 785 to 786 out of 10000 .
# Iterating from 786 to 787 out of 10000 .
# Iterating from 787 to 788 out of 10000 .
# Iterating from 788 to 789 out of 10000 .
# Iterating from 789 to 790 out of 10000 .
# Iterating from 790 to 791 out of 10000 .
# Iterating from 791 to 792 out of 10000 .
# Iterating from 792 to 793 out of 10000 .
# Iterating from 793 to 794 out of 10000 .
# Iterating from 794 to 795 out of 10000 .
# Iterating from 795 to 796 out of 10000 .
# Iterating from 796 to 797 out of 10000 .
# Iterating from 797 to 798 out of 10000 .
# Iterating from 798 to 799 out of 10000 .
# Iterating from 799 to 800 out of 10000 .
# Iterating from 800 to 801 out of 10000 .
# Iterating from 801 to 802 out of 10000 .
# Iterating from 802 to 803 out of 10000 .
# Iterating from 803 to 804 out of 10000 .
# Iterating from 804 to 805 out of 10000 .
# Iterating from 805 to 806 out of 10000 .
# Iterating from 806 to 807 out of 10000 .
# Iterating from 807 to 808 out of 10000 .
# Iterating from 808 to 809 out of 10000 .
# Iterating from 809 to 810 out of 10000 .
# Iterating from 810 to 811 out of 10000 .
# Iterating from 811 to 812 out of 10000 .
# Iterating from 812 to 813 out of 10000 .
# Iterating from 813 to 814 out of 10000 .
# Iterating from 814 to 815 out of 10000 .
# Iterating from 815 to 816 out of 10000 .
# Iterating from 816 to 817 out of 10000 .
# Iterating from 817 to 818 out of 10000 .
# Iterating from 818 to 819 out of 10000 .
# Iterating from 819 to 820 out of 10000 .
# Iterating from 820 to 821 out of 10000 .
# Iterating from 821 to 822 out of 10000 .
# Iterating from 822 to 823 out of 10000 .
# Iterating from 823 to 824 out of 10000 .
# Iterating from 824 to 825 out of 10000 .
# Iterating from 825 to 826 out of 10000 .
# Iterating from 826 to 827 out of 10000 .
# Iterating from 827 to 828 out of 10000 .
# Iterating from 828 to 829 out of 10000 .
# Iterating from 829 to 830 out of 10000 .
# Iterating from 830 to 831 out of 10000 .
# Iterating from 831 to 832 out of 10000 .
# Iterating from 832 to 833 out of 10000 .
# Iterating from 833 to 834 out of 10000 .
# Iterating from 834 to 835 out of 10000 .
# Iterating from 835 to 836 out of 10000 .
# Iterating from 836 to 837 out of 10000 .
# Iterating from 837 to 838 out of 10000 .
# Iterating from 838 to 839 out of 10000 .
# Iterating from 839 to 840 out of 10000 .
# Iterating from 840 to 841 out of 10000 .
# Iterating from 841 to 842 out of 10000 .
# Iterating from 842 to 843 out of 10000 .
# Iterating from 843 to 844 out of 10000 .
# Iterating from 844 to 845 out of 10000 .
# Iterating from 845 to 846 out of 10000 .
# Iterating from 846 to 847 out of 10000 .
# Iterating from 847 to 848 out of 10000 .
# Iterating from 848 to 849 out of 10000 .
# Iterating from 849 to 850 out of 10000 .
# Iterating from 850 to 851 out of 10000 .
# Iterating from 851 to 852 out of 10000 .
# Iterating from 852 to 853 out of 10000 .
# Iterating from 853 to 854 out of 10000 .
# Iterating from 854 to 855 out of 10000 .
# Iterating from 855 to 856 out of 10000 .
# Iterating from 856 to 857 out of 10000 .
# Iterating from 857 to 858 out of 10000 .
# Iterating from 858 to 859 out of 10000 .
# Iterating from 859 to 860 out of 10000 .
# Iterating from 860 to 861 out of 10000 .
# Iterating from 861 to 862 out of 10000 .
# Iterating from 862 to 863 out of 10000 .
# Iterating from 863 to 864 out of 10000 .
# Iterating from 864 to 865 out of 10000 .
# Iterating from 865 to 866 out of 10000 .
# Iterating from 866 to 867 out of 10000 .
# Iterating from 867 to 868 out of 10000 .
# Iterating from 868 to 869 out of 10000 .
# Iterating from 869 to 870 out of 10000 .
# Iterating from 870 to 871 out of 10000 .
# Iterating from 871 to 872 out of 10000 .
# Iterating from 872 to 873 out of 10000 .
# Iterating from 873 to 874 out of 10000 .
# Iterating from 874 to 875 out of 10000 .
# Iterating from 875 to 876 out of 10000 .
# Iterating from 876 to 877 out of 10000 .
# Iterating from 877 to 878 out of 10000 .
# Iterating from 878 to 879 out of 10000 .
# Iterating from 879 to 880 out of 10000 .
# Iterating from 880 to 881 out of 10000 .
# Iterating from 881 to 882 out of 10000 .
# Iterating from 882 to 883 out of 10000 .
# Iterating from 883 to 884 out of 10000 .
# Iterating from 884 to 885 out of 10000 .
# Iterating from 885 to 886 out of 10000 .
# Iterating from 886 to 887 out of 10000 .
# Iterating from 887 to 888 out of 10000 .
# Iterating from 888 to 889 out of 10000 .
# Iterating from 889 to 890 out of 10000 .
# Iterating from 890 to 891 out of 10000 .
# Iterating from 891 to 892 out of 10000 .
# Iterating from 892 to 893 out of 10000 .
# Iterating from 893 to 894 out of 10000 .
# Iterating from 894 to 895 out of 10000 .
# Iterating from 895 to 896 out of 10000 .
# Iterating from 896 to 897 out of 10000 .
# Iterating from 897 to 898 out of 10000 .
# Iterating from 898 to 899 out of 10000 .
# Iterating from 899 to 900 out of 10000 .
# Iterating from 900 to 901 out of 10000 .
# Iterating from 901 to 902 out of 10000 .
# Iterating from 902 to 903 out of 10000 .
# Iterating from 903 to 904 out of 10000 .
# Iterating from 904 to 905 out of 10000 .
# Iterating from 905 to 906 out of 10000 .
# Iterating from 906 to 907 out of 10000 .
# Iterating from 907 to 908 out of 10000 .
# Iterating from 908 to 909 out of 10000 .
# Iterating from 909 to 910 out of 10000 .
# Iterating from 910 to 911 out of 10000 .
# Iterating from 911 to 912 out of 10000 .
# Iterating from 912 to 913 out of 10000 .
# Iterating from 913 to 914 out of 10000 .
# Iterating from 914 to 915 out of 10000 .
# Iterating from 915 to 916 out of 10000 .
# Iterating from 916 to 917 out of 10000 .
# Iterating from 917 to 918 out of 10000 .
# Iterating from 918 to 919 out of 10000 .
# Iterating from 919 to 920 out of 10000 .
# Iterating from 920 to 921 out of 10000 .
# Iterating from 921 to 922 out of 10000 .
# Iterating from 922 to 923 out of 10000 .
# Iterating from 923 to 924 out of 10000 .
# Iterating from 924 to 925 out of 10000 .
# Iterating from 925 to 926 out of 10000 .
# Iterating from 926 to 927 out of 10000 .
# Iterating from 927 to 928 out of 10000 .
# Iterating from 928 to 929 out of 10000 .
# Iterating from 929 to 930 out of 10000 .
# Iterating from 930 to 931 out of 10000 .
# Iterating from 931 to 932 out of 10000 .
# Iterating from 932 to 933 out of 10000 .
# Iterating from 933 to 934 out of 10000 .
# Iterating from 934 to 935 out of 10000 .
# Iterating from 935 to 936 out of 10000 .
# Iterating from 936 to 937 out of 10000 .
# Iterating from 937 to 938 out of 10000 .
# Iterating from 938 to 939 out of 10000 .
# Iterating from 939 to 940 out of 10000 .
# Iterating from 940 to 941 out of 10000 .
# Iterating from 941 to 942 out of 10000 .
# Iterating from 942 to 943 out of 10000 .
# Iterating from 943 to 944 out of 10000 .
# Iterating from 944 to 945 out of 10000 .
# Iterating from 945 to 946 out of 10000 .
# Iterating from 946 to 947 out of 10000 .
# Iterating from 947 to 948 out of 10000 .
# Iterating from 948 to 949 out of 10000 .
# Iterating from 949 to 950 out of 10000 .
# Iterating from 950 to 951 out of 10000 .
# Iterating from 951 to 952 out of 10000 .
# Iterating from 952 to 953 out of 10000 .
# Iterating from 953 to 954 out of 10000 .
# Iterating from 954 to 955 out of 10000 .
# Iterating from 955 to 956 out of 10000 .
# Iterating from 956 to 957 out of 10000 .
# Iterating from 957 to 958 out of 10000 .
# Iterating from 958 to 959 out of 10000 .
# Iterating from 959 to 960 out of 10000 .
# Iterating from 960 to 961 out of 10000 .
# Iterating from 961 to 962 out of 10000 .
# Iterating from 962 to 963 out of 10000 .
# Iterating from 963 to 964 out of 10000 .
# Iterating from 964 to 965 out of 10000 .
# Iterating from 965 to 966 out of 10000 .
# Iterating from 966 to 967 out of 10000 .
# Iterating from 967 to 968 out of 10000 .
# Iterating from 968 to 969 out of 10000 .
# Iterating from 969 to 970 out of 10000 .
# Iterating from 970 to 971 out of 10000 .
# Iterating from 971 to 972 out of 10000 .
# Iterating from 972 to 973 out of 10000 .
# Iterating from 973 to 974 out of 10000 .
# Iterating from 974 to 975 out of 10000 .
# Iterating from 975 to 976 out of 10000 .
# Iterating from 976 to 977 out of 10000 .
# Iterating from 977 to 978 out of 10000 .
# Iterating from 978 to 979 out of 10000 .
# Iterating from 979 to 980 out of 10000 .
# Iterating from 980 to 981 out of 10000 .
# Iterating from 981 to 982 out of 10000 .
# Iterating from 982 to 983 out of 10000 .
# Iterating from 983 to 984 out of 10000 .
# Iterating from 984 to 985 out of 10000 .
# Iterating from 985 to 986 out of 10000 .
# Iterating from 986 to 987 out of 10000 .
# Iterating from 987 to 988 out of 10000 .
# Iterating from 988 to 989 out of 10000 .
# Iterating from 989 to 990 out of 10000 .
# Iterating from 990 to 991 out of 10000 .
# Iterating from 991 to 992 out of 10000 .
# Iterating from 992 to 993 out of 10000 .
# Iterating from 993 to 994 out of 10000 .
# Iterating from 994 to 995 out of 10000 .
# Iterating from 995 to 996 out of 10000 .
# Iterating from 996 to 997 out of 10000 .
# Iterating from 997 to 998 out of 10000 .
# Iterating from 998 to 999 out of 10000 .
# Iterating from 999 to 1000 out of 10000 .
# Iterating from 1000 to 1001 out of 10000 .
# Iterating from 1001 to 1002 out of 10000 .
# Iterating from 1002 to 1003 out of 10000 .
# Iterating from 1003 to 1004 out of 10000 .
# Iterating from 1004 to 1005 out of 10000 .
# Iterating from 1005 to 1006 out of 10000 .
# Iterating from 1006 to 1007 out of 10000 .
# Iterating from 1007 to 1008 out of 10000 .
# Iterating from 1008 to 1009 out of 10000 .
# Iterating from 1009 to 1010 out of 10000 .
# Iterating from 1010 to 1011 out of 10000 .
# Iterating from 1011 to 1012 out of 10000 .
# Iterating from 1012 to 1013 out of 10000 .
# Iterating from 1013 to 1014 out of 10000 .
# Iterating from 1014 to 1015 out of 10000 .
# Iterating from 1015 to 1016 out of 10000 .
# Iterating from 1016 to 1017 out of 10000 .
# Iterating from 1017 to 1018 out of 10000 .
# Iterating from 1018 to 1019 out of 10000 .
# Iterating from 1019 to 1020 out of 10000 .
# Iterating from 1020 to 1021 out of 10000 .
# Iterating from 1021 to 1022 out of 10000 .
# Iterating from 1022 to 1023 out of 10000 .
# Iterating from 1023 to 1024 out of 10000 .
# Iterating from 1024 to 1025 out of 10000 .
# Iterating from 1025 to 1026 out of 10000 .
# Iterating from 1026 to 1027 out of 10000 .
# Iterating from 1027 to 1028 out of 10000 .
# Iterating from 1028 to 1029 out of 10000 .
# Iterating from 1029 to 1030 out of 10000 .
# Iterating from 1030 to 1031 out of 10000 .
# Iterating from 1031 to 1032 out of 10000 .
# Iterating from 1032 to 1033 out of 10000 .
# Iterating from 1033 to 1034 out of 10000 .
# Iterating from 1034 to 1035 out of 10000 .
# Iterating from 1035 to 1036 out of 10000 .
# Iterating from 1036 to 1037 out of 10000 .
# ...
# Iterating from 9969 to 9970 out of 10000 .
# Iterating from 9970 to 9971 out of 10000 .
# Iterating from 9971 to 9972 out of 10000 .
# Iterating from 9972 to 9973 out of 10000 .
# Iterating from 9973 to 9974 out of 10000 .
# Iterating from 9974 to 9975 out of 10000 .
# Iterating from 9975 to 9976 out of 10000 .
# Iterating from 9976 to 9977 out of 10000 .
# Iterating from 9977 to 9978 out of 10000 .
# Iterating from 9978 to 9979 out of 10000 .
# Iterating from 9979 to 9980 out of 10000 .
# Iterating from 9980 to 9981 out of 10000 .
# Iterating from 9981 to 9982 out of 10000 .
# Iterating from 9982 to 9983 out of 10000 .
# Iterating from 9983 to 9984 out of 10000 .
# Iterating from 9984 to 9985 out of 10000 .
# Iterating from 9985 to 9986 out of 10000 .
# Iterating from 9986 to 9987 out of 10000 .
# Iterating from 9987 to 9988 out of 10000 .
# Iterating from 9988 to 9989 out of 10000 .
# Iterating from 9989 to 9990 out of 10000 .
# Iterating from 9990 to 9991 out of 10000 .
# Iterating from 9991 to 9992 out of 10000 .
# Iterating from 9992 to 9993 out of 10000 .
# Iterating from 9993 to 9994 out of 10000 .
# Iterating from 9994 to 9995 out of 10000 .
# Iterating from 9995 to 9996 out of 10000 .
# Iterating from 9996 to 9997 out of 10000 .
# Iterating from 9997 to 9998 out of 10000 .
# Iterating from 9998 to 9999 out of 10000 .
# Iterating from 9999 to 10000 out of 10000 .
# KPD metric calculation completed in 21299.58738276083 seconds.
# Saving kpd to ../results_leonardo/20D_50K/null_hypothesis/KPD.json
# Computing and savng ks with max_vectorize = 5000
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 40
# Iterating from 0 to 250 out of 10000 .
# Iterating from 250 to 500 out of 10000 .
# Iterating from 500 to 750 out of 10000 .
# Iterating from 750 to 1000 out of 10000 .
# Iterating from 1000 to 1250 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f2fa82c2980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 1250 to 1500 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f2fa82c2980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 1500 to 1750 out of 10000 .
# Iterating from 1750 to 2000 out of 10000 .
# Iterating from 2000 to 2250 out of 10000 .
# Iterating from 2250 to 2500 out of 10000 .
# Iterating from 2500 to 2750 out of 10000 .
# Iterating from 2750 to 3000 out of 10000 .
# Iterating from 3000 to 3250 out of 10000 .
# Iterating from 3250 to 3500 out of 10000 .
# Iterating from 3500 to 3750 out of 10000 .
# Iterating from 3750 to 4000 out of 10000 .
# Iterating from 4000 to 4250 out of 10000 .
# Iterating from 4250 to 4500 out of 10000 .
# Iterating from 4500 to 4750 out of 10000 .
# Iterating from 4750 to 5000 out of 10000 .
# Iterating from 5000 to 5250 out of 10000 .
# Iterating from 5250 to 5500 out of 10000 .
# Iterating from 5500 to 5750 out of 10000 .
# Iterating from 5750 to 6000 out of 10000 .
# Iterating from 6000 to 6250 out of 10000 .
# Iterating from 6250 to 6500 out of 10000 .
# Iterating from 6500 to 6750 out of 10000 .
# Iterating from 6750 to 7000 out of 10000 .
# Iterating from 7000 to 7250 out of 10000 .
# Iterating from 7250 to 7500 out of 10000 .
# Iterating from 7500 to 7750 out of 10000 .
# Iterating from 7750 to 8000 out of 10000 .
# Iterating from 8000 to 8250 out of 10000 .
# Iterating from 8250 to 8500 out of 10000 .
# Iterating from 8500 to 8750 out of 10000 .
# Iterating from 8750 to 9000 out of 10000 .
# Iterating from 9000 to 9250 out of 10000 .
# Iterating from 9250 to 9500 out of 10000 .
# Iterating from 9500 to 9750 out of 10000 .
# Iterating from 9750 to 10000 out of 10000 .
# KS tests calculation completed in 180.53224830329418 seconds.
# Saving ks to ../results_leonardo/20D_50K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 100
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f2fd1ce19e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 500 to 600 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f2fd1ce19e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SKS metric calculation completed in 588.819163207896 seconds.
# Saving sks to ../results_leonardo/20D_50K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 100
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SWD metric calculation completed in 349.7333195116371 seconds.
# Saving swd to ../results_leonardo/20D_50K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fn: [[0.68, [6800, 3199], 0.6785144811910258], [0.95, [9500, 500], 0.966201426908678], [0.99, [9900, 100], 1.157897800697627]]
# Computing time for metric fn: 57.71853160299361
# ThresholdS for metric fpd: [[0.68, [6800, 3199], 0.30998923839973586], [0.95, [9500, 500], 0.40164100626660354], [0.99, [9900, 100], 0.5082638039985077]]
# Computing time for metric fpd: 308.572451219894
# ThresholdS for metric kpd: [[0.68, [6800, 3199], -0.012572873258065442], [0.95, [9500, 500], 0.01909257533796449], [0.99, [9900, 100], 0.043113464419874965]]
# Computing time for metric kpd: 21299.58738276083
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9195917501004521], [0.95, [9500, 500], 1.1755778891604751], [0.99, [9900, 100], 1.3447591915257378]]
# Computing time for metric ks: 180.53224830329418
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9118751448364196], [0.95, [9500, 500], 1.1608093289295256], [0.99, [9900, 100], 1.3268295075957064]]
# Computing time for metric sks: 588.819163207896
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.6926097825260524], [0.95, [9500, 500], 1.0096694268034219], [0.99, [9900, 100], 1.2407426364571785]]
# Computing time for metric swd: 349.7333195116371
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f2fd1ce27a0>
# 1          metric_list  <function <lambda> at 0x7f2fd1ce2840>
# 2          metric_list  <function <lambda> at 0x7f2fd1ce3ec0>
# 3      statistic_means  <function <lambda> at 0x7f2fd1ce3f60>
# 4         metric_means  <function <lambda> at 0x7f2fd00d0040>
# 5         metric_means  <function <lambda> at 0x7f2fd00d00e0>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f2fd00d0180>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
# 6  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  ../results_leonardo/20D_50K/null_hypothesis/FN...
# 1  ../results_leonardo/20D_50K/null_hypothesis/FP...
# 2  ../results_leonardo/20D_50K/null_hypothesis/KP...
# 3  ../results_leonardo/20D_50K/null_hypothesis/KS...
# 4  ../results_leonardo/20D_50K/null_hypothesis/SK...
# 5  ../results_leonardo/20D_50K/null_hypothesis/SW...
# 6  ../results_leonardo/20D_50K/null_hypothesis/LR...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.6785144811910258], [0....
# 1  [[0.68, [6800, 3199], 0.30998923839973586], [0...
# 2  [[0.68, [6800, 3199], -0.012572873258065442], ...
# 3  [[0.68, [6800, 3199], 0.9195917501004521], [0....
# 4  [[0.68, [6800, 3199], 0.9118751448364196], [0....
# 5  [[0.68, [6800, 3199], 0.6926097825260524], [0....
# 6                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    if "FPD" in latex:
        latex = r"$d_{\mathrm{FPD}}\,(\times 10^{3})$"
    elif "KPD" in latex:
        latex = r"$d_{\mathrm{KPD}}\,(\times 10^{4})$"
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.6101349610302593 +/- 0.00036348882715102446
# sigma = 0.1906538295316998 +/- 0.0016208903203650952
# /tmp/ipykernel_2598324/1904285626.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598324/1904285626.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598324/1904285626.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598324/1904285626.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 3.2810480454936624 seconds.
# mu = 0.2797751569484641 +/- 6.15960437450416e-05
# sigma = 0.07848314707314023 +/- 0.0008398878083077868
# /tmp/ipykernel_2598324/1904285626.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598324/1904285626.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598324/1904285626.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598324/1904285626.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.017607112415135 seconds.
# mu = -0.02051214160040187 +/- 4.889542827298688e-06
# sigma = 0.022112310660124798 +/- 0.0001900716105991554
# /tmp/ipykernel_2598324/1904285626.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598324/1904285626.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598324/1904285626.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598324/1904285626.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.0461311414837837 seconds.
# mu = 0.8668370228706197 +/- 0.00025895465438036184
# sigma = 0.16092068057908587 +/- 0.001405116942830179
# /tmp/ipykernel_2598324/1904285626.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598324/1904285626.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598324/1904285626.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598324/1904285626.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2824251940473914 seconds.
# mu = 0.865353462100772 +/- 0.0002327056819423629
# sigma = 0.15254693767570782 +/- 0.0014016555861021656
# /tmp/ipykernel_2598324/1904285626.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598324/1904285626.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598324/1904285626.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598324/1904285626.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3029219219461083 seconds.
# mu = 0.6287967949926487 +/- 0.00040991203234614157
# sigma = 0.2024628440840792 +/- 0.0017930541509977623
# /tmp/ipykernel_2598324/1904285626.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598324/1904285626.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598324/1904285626.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598324/1904285626.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9510320220142603 seconds.
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f2fd1ce27a0>
# 1          metric_list  <function <lambda> at 0x7f2fd1ce2840>
# 2          metric_list  <function <lambda> at 0x7f2fd1ce3ec0>
# 3      statistic_means  <function <lambda> at 0x7f2fd1ce3f60>
# 4         metric_means  <function <lambda> at 0x7f2fd00d0040>
# 5         metric_means  <function <lambda> at 0x7f2fd00d00e0>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f2fd00d0180>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...             50
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...           5000
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
# 6  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  ../results_leonardo/20D_50K/null_hypothesis/FN...
# 1  ../results_leonardo/20D_50K/null_hypothesis/FP...
# 2  ../results_leonardo/20D_50K/null_hypothesis/KP...
# 3  ../results_leonardo/20D_50K/null_hypothesis/KS...
# 4  ../results_leonardo/20D_50K/null_hypothesis/SK...
# 5  ../results_leonardo/20D_50K/null_hypothesis/SW...
# 6  ../results_leonardo/20D_50K/null_hypothesis/LR...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.6785144811910258], [0....
# 1  [[0.68, [6800, 3199], 0.30998923839973586], [0...
# 2  [[0.68, [6800, 3199], -0.012572873258065442], ...
# 3  [[0.68, [6800, 3199], 0.9195917501004521], [0....
# 4  [[0.68, [6800, 3199], 0.9118751448364196], [0....
# 5  [[0.68, [6800, 3199], 0.6926097825260524], [0....
# 6                                                 []
#
#                                          null_figure
# 0  ../results_leonardo/20D_50K/null_hypothesis/FN...
# 1  ../results_leonardo/20D_50K/null_hypothesis/FP...
# 2  ../results_leonardo/20D_50K/null_hypothesis/KP...
# 3  ../results_leonardo/20D_50K/null_hypothesis/KS...
# 4  ../results_leonardo/20D_50K/null_hypothesis/SK...
# 5  ../results_leonardo/20D_50K/null_hypothesis/SW...
# 6                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "std", "both"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.01,
                                                 fn_tol = 0.01,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fn with mean deformation.
#
# ======================================================
# =============== fn - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 40.72461212627922 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.907298385945285
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 23.26639731780531 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8405121238398845
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 12.508337120179192 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.713177138190756
#
# ------------ 4 ------------
# eps = 0.3125
# WARNING:tensorflow:5 out of the last 207 calls to <function generate_and_clean_data_simple_1 at 0x7f30a09df6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 6.497005703440122 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4821521578948744
#
# ------------ 5 ------------
# eps = 0.15625
# WARNING:tensorflow:6 out of the last 209 calls to <function generate_and_clean_data_simple_1 at 0x7f30a09df6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f2d21250d60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 3.355729292512863 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.105768704188764
#
# ------------ 6 ------------
# eps = 0.078125
# WARNING:tensorflow:6 out of the last 6 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7f2d295aa7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.788742501827513 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5971381604823944
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.0585081090580204 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.09118017227618824
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.7602274583845654 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.23861274597375245
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 0.8985981391639759 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.07250461548216412
#
# ------------ 10 ------------
# eps = 0.0341796875
# statistic = 0.976509560926342 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.010612112745757882
#
# ------------ 11 ------------
# eps = 0.03173828125
# statistic = 0.9369762657614636 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.030711962692471204
#
# ------------ 12 ------------
# eps = 0.032958984375
# statistic = 0.9566076200634536 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.009978949142487089
#
# ------------ 13 ------------
# eps = 0.0335693359375
# statistic = 0.9665258334474519 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.01834862385321101
# relative_error_metric = 0.00033569820784137133
#
# ------------ 14 ------------
# eps = 0.03326416015625
# statistic = 0.9615584072522242 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.0091324200913242
# relative_error_metric = 0.004817010474206538
# =======> statistic within required accuracy at 0.95 CL in 577.6925245150924 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.033416748046875
# statistic = 0.964040056940424 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.973444084033104
# relative_error_metric = 0.18271764468445637
#
# ------------ 2 ------------
# eps = 2.5167083740234375
# statistic = 40.93003960003432 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.947584143605086
# relative_error_metric = 1.889954426640305
#
# ------------ 3 ------------
# eps = 1.2750625610351562
# statistic = 23.6646400819478 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.897845543861695
# relative_error_metric = 1.8134118588241268
#
# ------------ 4 ------------
# eps = 0.6542396545410156
# statistic = 13.049173244874874 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.805619504618201
# relative_error_metric = 1.6739939437246707
#
# ------------ 5 ------------
# eps = 0.3438282012939453
# statistic = 7.117789902823161 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.6456758601511743
# relative_error_metric = 1.4403376047141008
#
# ------------ 6 ------------
# eps = 0.18862247467041016
# statistic = 4.010784753856563 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.3980027917964135
# relative_error_metric = 1.103912621077966
#
# ------------ 7 ------------
# eps = 0.11101961135864258
# statistic = 2.4427488086153275 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.074561331110414
# relative_error_metric = 0.7136779291777624
#
# ------------ 8 ------------
# eps = 0.07221817970275879
# statistic = 1.673508349947086 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.7346326159818537
# relative_error_metric = 0.3642081155556253
#
# ------------ 9 ------------
# eps = 0.052817463874816895
# statistic = 1.3045760443143384 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.44995403554124014
# relative_error_metric = 0.11913080328859177
#
# ------------ 10 ------------
# eps = 0.04311710596084595
# statistic = 1.1290551676329121 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.2022286216655328
# relative_error_metric = 0.02522363464760698
#
# ------------ 11 ------------
# eps = 0.04796728491783142
# statistic = 1.2157855948582281 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.10649857588542953
# relative_error_metric = 0.04877465484148551
#
# ------------ 12 ------------
# eps = 0.045542195439338684
# statistic = 1.1721333905681495 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.05470581067510389
# relative_error_metric = 0.012219226870339894
#
# ------------ 13 ------------
# eps = 0.044329650700092316
# statistic = 1.15051840037751 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.02698386182843457
# relative_error_metric = 0.006393474726680699
#
# ------------ 14 ------------
# eps = 0.0449359230697155
# statistic = 1.1613074640730277 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.013583565175676784
# relative_error_metric = 0.002940372227671523
#
# ------------ 15 ------------
# eps = 0.04463278688490391
# statistic = 1.1559082585176876 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.006768796490765092
# relative_error_metric = 0.0017197138645354956
# =======> statistic within required accuracy at 0.99 CL in 617.4128159666434 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1195.1053750813007 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# Computing exclusion limits for fn with std deformation.
#
# ======================================================
# =============== fn - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 18.90514960591778 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.805508659111791
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 5.604918204652967 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4118497418504266
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 1.8171801445241578 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6114711158178797
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 0.9748681418989803 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.008929834488751431
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 0.7241780692343092 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2863538728748239
#
# ------------ 6 ------------
# eps = 0.234375
# statistic = 0.8385631025822139 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.1414459584513995
#
# ------------ 7 ------------
# eps = 0.2734375
# statistic = 0.9040298827645469 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.06648540618753096
#
# ------------ 8 ------------
# eps = 0.29296875
# statistic = 0.9387565247230072 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.06451612903225806
# relative_error_metric = 0.028814181606647036
#
# ------------ 9 ------------
# eps = 0.302734375
# statistic = 0.9566353450455801 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.031746031746031744
# relative_error_metric = 0.009949967675493878
#
# ------------ 10 ------------
# eps = 0.3076171875
# statistic = 0.9657069491595199 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.015748031496062992
# relative_error_metric = 0.0005119060047397012
#
# ------------ 11 ------------
# eps = 0.31005859375
# statistic = 0.9702762749267202 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.007905138339920948
# relative_error_metric = 0.004208515299897326
# =======> statistic within required accuracy at 0.95 CL in 449.6925119860098 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.308837890625
# statistic = 0.9679888035500684 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.767302828236376
# relative_error_metric = 0.17866333676321672
#
# ------------ 2 ------------
# eps = 2.6544189453125
# statistic = 20.74037767618119 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.5831101956745623
# relative_error_metric = 1.7884951622021221
#
# ------------ 3 ------------
# eps = 1.48162841796875
# statistic = 7.6594578349791735 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.31003920231805
# relative_error_metric = 1.4747187939147928
#
# ------------ 4 ------------
# eps = 0.895233154296875
# statistic = 3.1009115750779612 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.9740210366240021
# relative_error_metric = 0.9124680646343719
#
# ------------ 5 ------------
# eps = 0.6020355224609375
# statistic = 1.733983334047636 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.6437725102604909
# relative_error_metric = 0.3984157761039889
#
# ------------ 6 ------------
# eps = 0.45543670654296875
# statistic = 1.2894773954141043 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.3836286498627402
# relative_error_metric = 0.10752711306833904
#
# ------------ 7 ------------
# eps = 0.3821372985839844
# statistic = 1.1160637257792139 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.17502789606722383
# relative_error_metric = 0.03679400414766801
#
# ------------ 8 ------------
# eps = 0.41878700256347656
# statistic = 1.1992490957483002 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.09151852160556304
# relative_error_metric = 0.03508588719101218
#
# ------------ 9 ------------
# eps = 0.40046215057373047
# statistic = 1.1568211677586169 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.04473572397255091
# relative_error_metric = 0.0009302493768634109
#
# ------------ 10 ------------
# eps = 0.4096245765686035
# statistic = 1.1778206594760579 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.022620852034434553
# relative_error_metric = 0.017059298128721676
#
# ------------ 11 ------------
# eps = 0.405043363571167
# statistic = 1.1672680039549286 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.011374752666466382
# relative_error_metric = 0.00805981512247614
#
# ------------ 12 ------------
# eps = 0.40275275707244873
# statistic = 1.162031447007868 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.005703595580492605
# relative_error_metric = 0.0035635968763524928
# =======> statistic within required accuracy at 0.99 CL in 485.3680412406102 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 935.0605868240818 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# Computing exclusion limits for fn with both deformation.
#
# ======================================================
# =============== fn - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 37.892143075225015 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9005411641398544
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 21.9909211357976 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.831651127135895
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 12.250536953666865 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7075824915082862
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 6.509004586376967 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4829833852383716
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 3.3957748229158047 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1139782781278955
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.8136095836721722 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6096876036090133
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.0687561871332847 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.10079301850509391
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.7628074207525796 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.23527237171888302
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 0.9048394343413555 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.0655912907496065
#
# ------------ 10 ------------
# eps = 0.0341796875
# statistic = 0.9847405744484576 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.01900532924800756
#
# ------------ 11 ------------
# eps = 0.03173828125
# statistic = 0.9442062161601699 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.023026719798058846
#
# ------------ 12 ------------
# eps = 0.032958984375
# statistic = 0.9643369438968505 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.0019315679398276293
#
# ------------ 13 ------------
# eps = 0.0335693359375
# statistic = 0.9745057574374084 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.01834862385321101
# relative_error_metric = 0.008558045846085199
#
# ------------ 14 ------------
# eps = 0.03326416015625
# statistic = 0.9694129645643951 - next threshold = 0.966201426908678 at 0.95 CL
# relative_error_eps = 0.009216589861751152
# relative_error_metric = 0.003318365134982206
# =======> statistic within required accuracy at 0.95 CL in 568.5838543632999 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.033111572265625
# statistic = 0.9668728404693657 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.973685008337123
# relative_error_metric = 0.17980760513835436
#
# ------------ 2 ------------
# eps = 2.5165557861328125
# statistic = 38.083676451083015 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.9480535024985786
# relative_error_metric = 1.881972339512339
#
# ------------ 3 ------------
# eps = 1.2748336791992188
# statistic = 22.342245430728305 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.8987371306909324
# relative_error_metric = 1.8029122138882612
#
# ------------ 4 ------------
# eps = 0.6539726257324219
# statistic = 12.749340832592576 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.807234266996086
# relative_error_metric = 1.6669654325407401
#
# ------------ 5 ------------
# eps = 0.34354209899902344
# statistic = 7.109500834237057 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.6483605519686035
# relative_error_metric = 1.4397764753692561
#
# ------------ 6 ------------
# eps = 0.18832683563232422
# statistic = 4.045406667341515 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.4018820388035917
# relative_error_metric = 1.1098750359046514
#
# ------------ 7 ------------
# eps = 0.11071920394897461
# statistic = 2.4703056022507157 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 1.0791519551776154
# relative_error_metric = 0.7234477540518278
#
# ------------ 8 ------------
# eps = 0.0719153881072998
# statistic = 1.6904513307664988 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.7389305699011385
# relative_error_metric = 0.37393838008553776
#
# ------------ 9 ------------
# eps = 0.0525134801864624
# statistic = 1.3146579727497023 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.45318297309526295
# relative_error_metric = 0.12680011002017916
#
# ------------ 10 ------------
# eps = 0.0428125262260437
# statistic = 1.13548209262696 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.203532159281688
# relative_error_metric = 0.019548185746210794
#
# ------------ 11 ------------
# eps = 0.04766300320625305
# statistic = 1.224046793716681 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.10722185348114452
# relative_error_metric = 0.0555420081341726
#
# ------------ 12 ------------
# eps = 0.045237764716148376
# statistic = 1.179477752374736 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.05508757470652594
# relative_error_metric = 0.01846511284739258
#
# ------------ 13 ------------
# eps = 0.04402514547109604
# statistic = 1.1574039152976567 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.027169610368038836
# relative_error_metric = 0.0004266272482400841
#
# ------------ 14 ------------
# eps = 0.04463145509362221
# statistic = 1.1684223972222487 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.013677709694803156
# relative_error_metric = 0.009048278507861857
#
# ------------ 15 ------------
# eps = 0.04432830028235912
# statistic = 1.1629084779826595 - next threshold = 1.157897800697627 at 0.99 CL
# relative_error_eps = 0.006862320052780266
# relative_error_metric = 0.00431804871527817
# =======> statistic within required accuracy at 0.99 CL in 605.3048079507425 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1173.888696721755 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# Computing exclusion limits for fpd with mean deformation.
#
# ======================================================
# =============== fpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 336.52329616895673 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.995231685613609
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 84.44399169846147 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9810648589225868
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 21.335592746136555 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.926091606532556
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 5.490852791731849 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.727354142381596
#
# ------------ 5 ------------
# eps = 0.15625
# WARNING:tensorflow:5 out of the last 5 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f170f3a4860> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.5818716873967105 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1900409661108444
#
# ------------ 6 ------------
# eps = 0.078125
# WARNING:tensorflow:6 out of the last 6 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f17091cc2c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 0.59164191546228 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.38257158164959804
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.35016436616920293 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.13694139995466972
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 0.4476724143662745 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.10839675196788948
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 0.3905946137424558 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.027886634342498825
#
# ------------ 10 ------------
# eps = 0.0537109375
# statistic = 0.41824958666054457 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.040514138196525926
#
# ------------ 11 ------------
# eps = 0.05126953125
# statistic = 0.39300473528361307 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.046511627906976744
# relative_error_metric = 0.021736153688164478
#
# ------------ 12 ------------
# eps = 0.052490234375
# statistic = 0.39979391853457924 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.022988505747126436
# relative_error_metric = 0.004609451559607335
#
# ------------ 13 ------------
# eps = 0.0531005859375
# statistic = 0.41475715483145564 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.011560693641618497
# relative_error_metric = 0.03213174450861287
#
# ------------ 14 ------------
# eps = 0.05279541015625
# statistic = 0.41302639363727883 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.005797101449275362
# relative_error_metric = 0.027951007667714665
#
# ------------ 15 ------------
# eps = 0.052642822265625
# statistic = 0.4121648764061084 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.002902757619738752
# relative_error_metric = 0.025863342508516185
#
# ------------ 16 ------------
# eps = 0.0525665283203125
# statistic = 0.4002237096794265 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.0014503263234227702
# relative_error_metric = 0.0035350017502763734
# =======> statistic within required accuracy at 0.95 CL in 696.5794964944944 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.05260467529296875
# statistic = 0.4119499000877803 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.958354410310228
# relative_error_metric = 0.20932942746459263
#
# ------------ 2 ------------
# eps = 2.5263023376464844
# statistic = 343.64131937224806 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.9184077982974506
# relative_error_metric = 1.9940925245434546
#
# ------------ 3 ------------
# eps = 1.2894535064697266
# statistic = 89.83863659770226 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.8432119381772962
# relative_error_metric = 1.9774972333643475
#
# ------------ 4 ------------
# eps = 0.6710290908813477
# statistic = 24.550298925132935 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.7092193440829748
# relative_error_metric = 1.9188678441788471
#
# ------------ 5 ------------
# eps = 0.3618168830871582
# statistic = 7.330820434291642 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.4922592782229995
# relative_error_metric = 1.7406514390974985
#
# ------------ 6 ------------
# eps = 0.20721077919006348
# statistic = 2.5827916818079957 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.1901224598415225
# relative_error_metric = 1.3422779936078775
#
# ------------ 7 ------------
# eps = 0.1299077272415161
# statistic = 1.1747499761337825 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.8470991655916787
# relative_error_metric = 0.7920151100401411
#
# ------------ 8 ------------
# eps = 0.09125620126724243
# statistic = 0.7348672862056987 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.5373458983213767
# relative_error_metric = 0.3645689243762175
#
# ------------ 9 ------------
# eps = 0.07193043828010559
# statistic = 0.5414437972894327 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.31036648913957793
# relative_error_metric = 0.06321759173738435
#
# ------------ 10 ------------
# eps = 0.06226755678653717
# statistic = 0.4715471996636744 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.14400932724471527
# relative_error_metric = 0.07494629923036128
#
# ------------ 11 ------------
# eps = 0.06709899753332138
# statistic = 0.5052114799170758 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.06950241462919908
# relative_error_metric = 0.006023480058910044
#
# ------------ 12 ------------
# eps = 0.06951471790671349
# statistic = 0.5230071489895841 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.03536570783703573
# relative_error_metric = 0.028592572976787176
#
# ------------ 13 ------------
# eps = 0.06830685772001743
# statistic = 0.5140291253509639 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.01784059019362487
# relative_error_metric = 0.011279196376962012
#
# ------------ 14 ------------
# eps = 0.0677029276266694
# statistic = 0.5096002470180647 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.008960259174804022
# relative_error_metric = 0.0026259754791856456
# =======> statistic within required accuracy at 0.99 CL in 621.656935159117 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1318.236466318369 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# Computing exclusion limits for fpd with std deformation.
#
# ======================================================
# =============== fpd - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 138.12978465389355 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.988402891131666
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 18.239122324168473 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9138144722623374
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 2.8222191378642862 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.501664478841863
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 0.8228790687316051 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6880051557596846
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 0.40126075147526113 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.0009472012925014865
#
# ------------ 6 ------------
# eps = 0.234375
# statistic = 0.5617734478324525 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.33242690284442117
#
# ------------ 7 ------------
# eps = 0.1953125
# statistic = 0.47029443600341697 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.15747365322845283
#
# ------------ 8 ------------
# eps = 0.17578125
# statistic = 0.43102401815465563 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.07057582827734273
#
# ------------ 9 ------------
# eps = 0.166015625
# statistic = 0.4129753767989421 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.027827504498952754
#
# ------------ 10 ------------
# eps = 0.1611328125
# statistic = 0.3931095173651755 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.029850746268656716
# relative_error_metric = 0.021469602467052408
#
# ------------ 11 ------------
# eps = 0.16357421875
# statistic = 0.4086274191106848 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.015037593984962405
# relative_error_metric = 0.017244687378329317
#
# ------------ 12 ------------
# eps = 0.162353515625
# statistic = 0.4064780135946656 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.007547169811320755
# relative_error_metric = 0.011971027062059391
#
# ------------ 13 ------------
# eps = 0.1617431640625
# statistic = 0.4054094486857842 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.003780718336483932
# relative_error_metric = 0.009338802539682587
# =======> statistic within required accuracy at 0.95 CL in 573.1089752912521 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.16143798828125
# statistic = 0.40487670170988355 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.8748891385324897
# relative_error_metric = 0.22644292229358295
#
# ------------ 2 ------------
# eps = 2.580718994140625
# statistic = 150.92319946809084 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.7645094875076512
# relative_error_metric = 1.9865744200573356
#
# ------------ 3 ------------
# eps = 1.3710784912109375
# statistic = 23.989051284366028 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.5786329466819335
# relative_error_metric = 1.9170090596189595
#
# ------------ 4 ------------
# eps = 0.7662582397460938
# statistic = 4.627009659583588 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.303918746658991
# relative_error_metric = 1.6040999120276884
#
# ------------ 5 ------------
# eps = 0.4638481140136719
# statistic = 1.5193547919076742 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.9672696214501418
# relative_error_metric = 0.9973187165974778
#
# ------------ 6 ------------
# eps = 0.31264305114746094
# statistic = 0.8233847353760944 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.6378869867836092
# relative_error_metric = 0.4732794308107463
#
# ------------ 7 ------------
# eps = 0.23704051971435547
# statistic = 0.5686586218778608 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.37945600536096785
# relative_error_metric = 0.11216187243980087
#
# ------------ 8 ------------
# eps = 0.19923925399780273
# statistic = 0.47870463787749395 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.1732891048095787
# relative_error_metric = 0.05989890834772488
#
# ------------ 9 ------------
# eps = 0.2181398868560791
# statistic = 0.5216277521466752 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.09056817175678261
# relative_error_metric = 0.025952146259336152
#
# ------------ 10 ------------
# eps = 0.20868957042694092
# statistic = 0.49965836738878283 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.04428146308970383
# relative_error_metric = 0.017075597410225515
#
# ------------ 11 ------------
# eps = 0.21341472864151
# statistic = 0.5105154567632971 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.022388581329292893
# relative_error_metric = 0.004420295645016852
#
# ------------ 12 ------------
# eps = 0.21105214953422546
# statistic = 0.5050550949821749 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.011131983336077421
# relative_error_metric = 0.006333068532641497
#
# ------------ 13 ------------
# eps = 0.21223343908786774
# statistic = 0.5077773110140104 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.005550544525747017
# relative_error_metric = 0.0009576246026054333
# =======> statistic within required accuracy at 0.99 CL in 571.023916660808 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1144.1329259099439 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# Computing exclusion limits for fpd with both deformation.
#
# ======================================================
# =============== fpd - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 466.9063218758252 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9965620872044247
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 101.21481685911904 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.984189922982804
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 23.740903679569364 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9334550667308503
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 6.047761394264441 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7508972265501481
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 1.7102235787752063 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2392675001770492
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 0.623727505260813 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4331837705126783
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.3408333061691582 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.16379745151844935
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 0.4653751083198804 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.14701941747339792
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 0.39198277686281 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.024339566452278517
#
# ------------ 10 ------------
# eps = 0.0537109375
# statistic = 0.4329910627714728 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.07512305761507725
#
# ------------ 11 ------------
# eps = 0.05126953125
# statistic = 0.417886183137214 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.04878048780487805
# relative_error_metric = 0.0396452419899048
#
# ------------ 12 ------------
# eps = 0.050048828125
# statistic = 0.3990926725976735 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.024096385542168676
# relative_error_metric = 0.0063649968427566895
#
# ------------ 13 ------------
# eps = 0.0506591796875
# statistic = 0.41422331198284496 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.012121212121212121
# relative_error_metric = 0.03084411325461204
#
# ------------ 14 ------------
# eps = 0.05035400390625
# statistic = 0.41240888235049833 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.0060790273556231
# relative_error_metric = 0.026455076610076383
#
# ------------ 15 ------------
# eps = 0.050201416015625
# statistic = 0.3999941500496659 - next threshold = 0.40164100626660354 at 0.95 CL
# relative_error_eps = 0.0030349013657056147
# relative_error_metric = 0.0041087424970367185
# =======> statistic within required accuracy at 0.95 CL in 657.4755851151422 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0502777099609375
# statistic = 0.4119570474234824 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.9601782611979757
# relative_error_metric = 0.20931226765010882
#
# ------------ 2 ------------
# eps = 2.5251388549804688
# statistic = 477.4281242338109 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.9219113355946262
# relative_error_metric = 1.995746180314203
#
# ------------ 3 ------------
# eps = 1.2877082824707031
# statistic = 107.93605474496579 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.8496913712241088
# relative_error_metric = 1.9812525428422878
#
# ------------ 4 ------------
# eps = 0.6689929962158203
# statistic = 27.248674069868464 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.7203961761313162
# relative_error_metric = 1.9267550611946955
#
# ------------ 5 ------------
# eps = 0.3596353530883789
# statistic = 7.929798136122468 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.5093817251206887
# relative_error_metric = 1.7590613543226865
#
# ------------ 6 ------------
# eps = 0.2049565315246582
# statistic = 2.7520063524166396 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 1.2120538424892342
# relative_error_metric = 1.3764151071978983
#
# ------------ 7 ------------
# eps = 0.12761712074279785
# statistic = 1.228753639996427 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.8694958754665648
# relative_error_metric = 0.8295712152905936
#
# ------------ 8 ------------
# eps = 0.08894741535186768
# statistic = 0.7655947236207206 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.5554989489727332
# relative_error_metric = 0.40401805073778524
#
# ------------ 9 ------------
# eps = 0.06961256265640259
# statistic = 0.5490676175350828 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.3225424761052488
# relative_error_metric = 0.07718263678836265
#
# ------------ 10 ------------
# eps = 0.059945136308670044
# statistic = 0.47484930647974494 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.1492373888230105
# relative_error_metric = 0.06797691366867781
#
# ------------ 11 ------------
# eps = 0.06477884948253632
# statistic = 0.5105476583375483 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.07751056291543038
# relative_error_metric = 0.004483369933439808
#
# ------------ 12 ------------
# eps = 0.06236199289560318
# statistic = 0.49234508317188536 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.03801857124314112
# relative_error_metric = 0.0318180680398285
#
# ------------ 13 ------------
# eps = 0.06357042118906975
# statistic = 0.5013581051571037 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.018830310248640958
# relative_error_metric = 0.013679772157835878
#
# ------------ 14 ------------
# eps = 0.06417463533580303
# statistic = 0.5059308264045964 - next threshold = 0.5082638039985077 at 0.99 CL
# relative_error_eps = 0.009371040225620249
# relative_error_metric = 0.004600650652200745
# =======> statistic within required accuracy at 0.99 CL in 617.2650446752086 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1274.7406652458012 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# Computing exclusion limits for kpd with mean deformation.
#
# ======================================================
# =============== kpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# statistic = 0.9778635406547664 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.923396526560438
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 0.153637382617422 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5578630235550497
#
# ------------ 3 ------------
# eps = 0.625
# statistic = -0.04622469413373409 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = -4.814756264585039
#
# ------------ 4 ------------
# eps = 0.9375
# statistic = 0.036408996467063304 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.6239975037078193
#
# ------------ 5 ------------
# eps = 0.78125
# statistic = -0.009216904575115592 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 5.733176124011138
#
# ------------ 6 ------------
# eps = 0.859375
# statistic = 0.012517264385447646 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.41602937629872105
#
# ------------ 7 ------------
# eps = 0.8984375
# statistic = 0.024193211045631102 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.23567254444519672
#
# ------------ 8 ------------
# eps = 0.87890625
# statistic = 0.018287787402204714 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 0.02197802197802198
# relative_error_metric = 0.04305939679365099
#
# ------------ 9 ------------
# eps = 0.888671875
# statistic = 0.021223633050126978 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 0.011049723756906077
# relative_error_metric = 0.1057171692163371
#
# ------------ 10 ------------
# eps = 0.8837890625
# statistic = 0.019751494136688308 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 0.00554016620498615
# relative_error_metric = 0.03392635260081525
#
# ------------ 11 ------------
# eps = 0.88134765625
# statistic = 0.019018586804975257 - next threshold = 0.01909257533796449 at 0.95 CL
# relative_error_eps = 0.0027662517289073307
# relative_error_metric = 0.003882774957726647
# =======> statistic within required accuracy at 0.95 CL in 645.3309105122462 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.882568359375
# statistic = 0.01938477697249752 - next threshold = 0.043113464419874965 at 0.99 CL
# relative_error_eps = 1.3998754928408383
# relative_error_metric = 0.7593393643960479
#
# ------------ 2 ------------
# eps = 2.9412841796875
# statistic = 1.410956569007027 - next threshold = 0.043113464419874965 at 0.99 CL
# relative_error_eps = 1.0767757382282521
# relative_error_metric = 1.8813992079370025
#
# ------------ 3 ------------
# eps = 1.91192626953125
# statistic = 0.5179637510721591 - next threshold = 0.043113464419874965 at 0.99 CL
# relative_error_eps = 0.7367041607513378
# relative_error_metric = 1.6926379241255283
#
# ------------ 4 ------------
# eps = 1.397247314453125
# statistic = 0.22095763041285466 - next threshold = 0.043113464419874965 at 0.99 CL
# relative_error_eps = 0.45150926979452516
# relative_error_metric = 1.3469415583377757
#
# ------------ 5 ------------
# eps = 1.1399078369140625
# statistic = 0.1083732370221746 - next threshold = 0.043113464419874965 at 0.99 CL
# relative_error_eps = 0.2544796106982534
# relative_error_metric = 0.8615907796667476
#
# ------------ 6 ------------
# eps = 1.0112380981445312
# statistic = 0.06094181822913214 - next threshold = 0.043113464419874965 at 0.99 CL
# relative_error_eps = 0.13588478195185819
# relative_error_metric = 0.34267080642882275
#
# ------------ 7 ------------
# eps = 0.9469032287597656
# statistic = 0.03943028422304096 - next threshold = 0.043113464419874965 at 0.99 CL
# relative_error_eps = 0.06571013899847072
# relative_error_metric = 0.0892418931145819
#
# ------------ 8 ------------
# eps = 0.9790706634521484
# statistic = 0.05000264871535265 - next threshold = 0.043113464419874965 at 0.99 CL
# relative_error_eps = 0.03340381177798795
# relative_error_metric = 0.14796975654413078
#
# ------------ 9 ------------
# eps = 0.962986946105957
# ...
# relative_error_eps = 1.9087506263078782
# relative_error_metric = 1.8374352419684472
#
# ------------ 3 ------------
# eps = 1.2942886352539062
# statistic = 15.293478356225336 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.8254643853764412
# relative_error_metric = 1.6998364453925496
#
# ------------ 4 ------------
# eps = 0.6766700744628906
# statistic = 8.122554804654522 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.6789464132942733
# relative_error_metric = 1.4699548340697095
#
# ------------ 5 ------------
# eps = 0.3678607940673828
# statistic = 4.5163909421891155 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.44671059979895
# relative_error_metric = 1.1379441734274152
#
# ------------ 6 ------------
# eps = 0.2134561538696289
# statistic = 2.721628772565366 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.1332131795831948
# relative_error_metric = 0.7474746727356884
#
# ------------ 7 ------------
# eps = 0.13625383377075195
# statistic = 1.8407574236013116 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.7905807097427884
# relative_error_metric = 0.389430326431825
#
# ------------ 8 ------------
# eps = 0.09765267372131348
# statistic = 1.4136801784378996 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.4926627768099625
# relative_error_metric = 0.13030142825046268
#
# ------------ 9 ------------
# eps = 0.07835209369659424
# statistic = 1.207465831243022 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.21931883218699097
# relative_error_metric = 0.027184617366687022
#
# ------------ 10 ------------
# eps = 0.08800238370895386
# statistic = 1.3097260570340976 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.11602080284059456
# relative_error_metric = 0.0540947009096507
#
# ------------ 11 ------------
# eps = 0.08317723870277405
# statistic = 1.2583555225088443 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.05974326686685025
# relative_error_metric = 0.014095393563054712
#
# ------------ 12 ------------
# eps = 0.08076466619968414
# statistic = 1.2328457398458266 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.0294320418507438
# relative_error_metric = 0.006384972283185257
#
# ------------ 13 ------------
# eps = 0.0819709524512291
# statistic = 1.2455850036223302 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.01482510419716505
# relative_error_metric = 0.003895196342664459
#
# ------------ 14 ------------
# eps = 0.08136780932545662
# statistic = 1.2392114184925378 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.0073851805806766715
# relative_error_metric = 0.001234876074889038
# =======> statistic within required accuracy at 0.99 CL in 594.7101302435622 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1202.3360039712861 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# Computing exclusion limits for swd with std deformation.
#
# ======================================================
# =============== swd - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 16.032407463817307 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7630172816884535
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 5.761295114402474 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.40352992802789
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 2.4371700773826834 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8282953986372709
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 1.4109818857982972 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.33157395028823394
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 0.9425825688248625 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.06872766233948108
#
# ------------ 6 ------------
# eps = 0.234375
# statistic = 1.1730616051814098 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.14971352492240864
#
# ------------ 7 ------------
# eps = 0.1953125
# statistic = 1.056258921174976 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.04510272044734176
#
# ------------ 8 ------------
# eps = 0.17578125
# statistic = 0.9989422527230379 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.010681182619542382
#
# ------------ 9 ------------
# eps = 0.185546875
# statistic = 1.0274932633774803 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.05405405405405406
# relative_error_metric = 0.01749868742439576
#
# ------------ 10 ------------
# eps = 0.1806640625
# statistic = 1.0131908396692875 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.0273972602739726
# relative_error_metric = 0.0034816175138047884
#
# ------------ 11 ------------
# eps = 0.17822265625
# statistic = 1.0060594116849655 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.013605442176870748
# relative_error_metric = 0.0035818459800015163
#
# ------------ 12 ------------
# eps = 0.179443359375
# statistic = 1.0096235700102956 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.006779661016949152
# relative_error_metric = 4.5418662074949984e-05
# =======> statistic within required accuracy at 0.95 CL in 527.0340290637687 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.1800537109375
# statistic = 1.0114068999657906 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.8609638270295747
# relative_error_metric = 0.20365942206096666
#
# ------------ 2 ------------
# eps = 2.59002685546875
# statistic = 16.81515059968982 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.740002203371158
# relative_error_metric = 1.7251329258032446
#
# ------------ 3 ------------
# eps = 1.385040283203125
# statistic = 6.7379456464644125 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.5398264599785512
# relative_error_metric = 1.3779716201656895
#
# ------------ 4 ------------
# eps = 0.7825469970703125
# statistic = 3.0755651787088927 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.2518031227708648
# relative_error_metric = 0.8501815073543909
#
# ------------ 5 ------------
# eps = 0.48130035400390625
# statistic = 1.9418379155545782 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.9109995962392571
# relative_error_metric = 0.44058289657694716
#
# ------------ 6 ------------
# eps = 0.3306770324707031
# statistic = 1.466905166949924 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.5898345595100273
# relative_error_metric = 0.16705461486398593
#
# ------------ 7 ------------
# eps = 0.25536537170410156
# statistic = 1.2365917990678237 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.2570177865291045
# relative_error_metric = 0.0033510512991962588
#
# ------------ 8 ------------
# eps = 0.29302120208740234
# statistic = 1.3512874694634192 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.13733315942785096
# relative_error_metric = 0.08529594834083071
#
# ------------ 9 ------------
# eps = 0.27419328689575195
# statistic = 1.2938244574915425 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.07110794955720737
# relative_error_metric = 0.041886301736574136
#
# ------------ 10 ------------
# eps = 0.26477932929992676
# statistic = 1.2651851103685887 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.03619745650644353
# relative_error_metric = 0.019507724388599167
#
# ------------ 11 ------------
# eps = 0.26007235050201416
# statistic = 1.250883212492298 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.018264005892957708
# relative_error_metric = 0.008139726146600145
#
# ------------ 12 ------------
# eps = 0.25771886110305786
# statistic = 1.243735658122889 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.009173890946053873
# relative_error_metric = 0.0024093763847644885
# =======> statistic within required accuracy at 0.99 CL in 527.117531250231 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1054.1515933638439 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# Computing exclusion limits for swd with both deformation.
#
# ======================================================
# =============== swd - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 31.850592963756302 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8770953908032717
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 15.60187171890001 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7568751946740178
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 7.900902431343972 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.546754375419697
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 4.1129020244703955 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2115917277816792
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 2.2036840634519894 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7431579751617443
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.2728449597651192 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.2306014231589112
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.8537299945411987 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1673709141217807
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.0548896232102316 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.04380615454569893
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 0.9513762242136301 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.059451142873251636
#
# ------------ 10 ------------
# eps = 0.0537109375
# statistic = 1.0025440496999631 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.007082128399060787
#
# ------------ 11 ------------
# eps = 0.05615234375
# statistic = 1.0285826404809117 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.018558267626524638
#
# ------------ 12 ------------
# eps = 0.054931640625
# statistic = 1.0155287180352455 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.02247191011235955
# relative_error_metric = 0.005786388108992043
#
# ------------ 13 ------------
# eps = 0.0543212890625
# statistic = 1.0090274858275516 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.0111731843575419
# relative_error_metric = 0.0006359954006503947
#
# ------------ 14 ------------
# eps = 0.05462646484375
# statistic = 1.0122759389494982 - next threshold = 1.0096694268034219 at 0.95 CL
# relative_error_eps = 0.0056022408963585435
# relative_error_metric = 0.002578222132234246
# =======> statistic within required accuracy at 0.95 CL in 611.3703328054398 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.054473876953125
# statistic = 1.0106511459751322 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.9568905660377358
# relative_error_metric = 0.20439915245165619
#
# ------------ 2 ------------
# eps = 2.5272369384765625
# statistic = 32.20879605211277 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.9156003427997281
# relative_error_metric = 1.851628131794696
#
# ------------ 3 ------------
# eps = 1.2908554077148438
# statistic = 16.121515847768983 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.8380355573198741
# relative_error_metric = 1.714151787894551
#
# ------------ 4 ------------
# eps = 0.6726646423339844
# statistic = 8.476140810410277 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.700338378406736
# relative_error_metric = 1.4892425567347227
#
# ------------ 5 ------------
# eps = 0.3635692596435547
# statistic = 4.735128171183384 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.4787726702406752
# relative_error_metric = 1.1694983533641299
#
# ------------ 6 ------------
# eps = 0.20902156829833984
# statistic = 2.847870113287851 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 1.173057782442679
# relative_error_metric = 0.7861480532392776
#
# ------------ 7 ------------
# eps = 0.13174772262573242
# statistic = 1.9067134428658565 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.8299128119118645
# relative_error_metric = 0.42318036511055435
#
# ------------ 8 ------------
# eps = 0.09311079978942871
# statistic = 1.4463324687312755 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.5235898968522572
# relative_error_metric = 0.15302127720741787
#
# ------------ 9 ------------
# eps = 0.07379233837127686
# statistic = 1.2235388434150791 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.23149308791966203
# relative_error_metric = 0.013962522692814464
#
# ------------ 10 ------------
# eps = 0.08345156908035278
# statistic = 1.3340326686334836 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.12285666091129462
# relative_error_metric = 0.07246460069106508
#
# ------------ 11 ------------
# eps = 0.07862195372581482
# statistic = 1.278528499001862 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.06337483562842491
# relative_error_metric = 0.029997456020388526
#
# ------------ 12 ------------
# eps = 0.07620714604854584
# statistic = 1.2509647365210055 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.03219754636636419
# relative_error_metric = 0.008204896108333226
#
# ------------ 13 ------------
# eps = 0.07499974220991135
# statistic = 1.2372339493575928 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.015970222686822067
# relative_error_metric = 0.0028318968949676854
#
# ------------ 14 ------------
# eps = 0.07560344412922859
# statistic = 1.2440950476325814 - next threshold = 1.2407426364571785 at 0.99 CL
# relative_error_eps = 0.008017120141904338
# relative_error_metric = 0.0026982938940986853
# =======> statistic within required accuracy at 0.99 CL in 605.6889686146751 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1217.0593332638964 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# dict_keys(['2024-04-11T23:30:33.485929', '2024-04-11T23:50:28.595065', '2024-04-12T00:06:03.659394', '2024-04-12T00:25:37.550541', '2024-04-12T00:47:35.790240', '2024-04-12T01:06:39.926479', '2024-04-12T01:27:54.673350', '2024-04-12T01:49:32.317842', '2024-04-12T03:36:12.933135', '2024-04-12T04:00:02.514841', '2024-04-12T04:25:49.586817', '2024-04-12T04:49:34.189731', '2024-04-12T05:15:58.000190', '2024-04-12T05:39:07.001042', '2024-04-12T06:00:01.648681', '2024-04-12T06:23:33.531887', '2024-04-12T06:43:35.873390', '2024-04-12T07:01:10.031087'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "std", "both"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 0.005
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 71.9175664819777 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -749.5951980881971], [0.99, [9900, 100], -714.2237404044241]]
# Null distribution computed in 72.24564602505416 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 42.763597750104964 seconds.
# statistic = 843.4903827298851 - next threshold = -749.5951980881971 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 33.93327542615591
#
# ------------ 2 ------------
# eps = 0.0025
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 69.81457647960633 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_mean_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -167.53386108530856], [0.99, [9900, 100], -149.98528101068547]]
# Null distribution computed in 70.14171120151877 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 43.9371982794255 seconds.
# statistic = 214.4490748866147 - next threshold = -167.53386108530856 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 16.283968675478512
#
# ------------ 3 ------------
# eps = 0.00125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 71.10361204110086 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_mean_0.001250.json
# ThresholdS: [[0.95, [9500, 500], -31.93768257060377], [0.99, [9900, 100], -23.250229736892326]]
# Null distribution computed in 71.432148152031 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 43.81874965224415 seconds.
# statistic = 55.40050832368217 - next threshold = -31.93768257060377 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 7.444814347038048
#
# ------------ 4 ------------
# eps = 0.000625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 69.25282897148281 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_mean_0.000625.json
# ThresholdS: [[0.95, [9500, 500], -3.019498823122459], [0.99, [9900, 100], 1.312932807067844]]
# Null distribution computed in 69.58803068753332 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 43.86619514692575 seconds.
# statistic = 14.744246881916265 - next threshold = -3.019498823122459 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 3.03012834322108
#
# ------------ 5 ------------
# eps = 0.0003125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 71.08500030916184 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_mean_0.000313.json
# ThresholdS: [[0.95, [9500, 500], 1.726621931257948], [0.99, [9900, 100], 3.8940491508293347]]
# Null distribution computed in 71.41180103644729 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 44.896732113324106 seconds.
# statistic = 4.1331216210201465 - next threshold = 1.726621931257948 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8213668971320846
#
# ------------ 6 ------------
# eps = 0.00015625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 70.50971929356456 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_mean_0.000156.json
# ThresholdS: [[0.95, [9500, 500], 1.674214000801152], [0.99, [9900, 100], 2.7559084575606776]]
# Null distribution computed in 70.8407307555899 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 43.18049547448754 seconds.
# statistic = 1.2568103555399814 - next threshold = 1.674214000801152 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.2848175890167117
#
# ------------ 7 ------------
# eps = 0.000234375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 69.59121550619602 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_mean_0.000234.json
# ThresholdS: [[0.95, [9500, 500], 1.9038257777848893], [0.99, [9900, 100], 3.527199774937304]]
# Null distribution computed in 69.92279235832393 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 43.64137062802911 seconds.
# statistic = 2.492528374512845 - next threshold = 1.9038257777848893 at 0.95 CL
# relative_error_eps = 0.3999999999999999
# relative_error_metric = 0.2678140005714839
#
# ------------ 8 ------------
# eps = 0.0001953125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 71.36481610499322 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_mean_0.000195.json
# ThresholdS: [[0.95, [9500, 500], 1.840212868764452], [0.99, [9900, 100], 3.192109358913986]]
# Null distribution computed in 71.69798699207604 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 45.035495297051966 seconds.
# statistic = 1.8240599615619713 - next threshold = 1.840212868764452 at 0.95 CL
# relative_error_eps = 0.18181818181818174
# relative_error_metric = 0.008816432591369947
#
# ------------ 9 ------------
# eps = 0.00021484375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# ...
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 71.62255982216448 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_both_0.000312.json
# ThresholdS: [[0.95, [9500, 500], 1.1196191367195414], [0.99, [9900, 100], 3.8159997606491656]]
# Null distribution computed in 71.9579759221524 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 43.70914164558053 seconds.
# statistic = 3.8145442494959623 - next threshold = 3.8159997606491656 at 0.99 CL
# relative_error_eps = 0.015152239535085274
# relative_error_metric = 0.00038149603783639563
#
# ------------ 13 ------------
# eps = 0.00031479582190513616
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 71.83671334199607 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_both_0.000315.json
# ThresholdS: [[0.95, [9500, 500], 1.0884290348408137], [0.99, [9900, 100], 3.8053311953985984]]
# Null distribution computed in 72.16401795390993 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 44.62650011386722 seconds.
# statistic = 3.883551382982326 - next threshold = 3.8053311953985984 at 0.99 CL
# relative_error_eps = 0.00760492768904056
# relative_error_metric = 0.020346308266863587
#
# ------------ 14 ------------
# eps = 0.0003136033564805985
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# LR metric calculation completed in 72.07654928322881 seconds.
# Saving lr to ../results_leonardo/20D_50K/null_hypothesis/LR_both_0.000314.json
# ThresholdS: [[0.95, [9500, 500], 1.1040989357843187], [0.99, [9900, 100], 3.8107404473892155]]
# Null distribution computed in 72.41028965357691 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 44.990077678114176 seconds.
# statistic = 3.8489722971537823 - next threshold = 3.8107404473892155 at 0.99 CL
# relative_error_eps = 0.003809706981047104
# relative_error_metric = 0.009982580558730305
# =======> statistic within required accuracy at 0.99 CL in 2214.650723268278 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 4271.769938343205 seconds.
# Saving results in the file ../results_leonardo/20D_50K/exclusion_limits.json
# dict_keys(['2024-04-11T23:30:33.485929', '2024-04-11T23:50:28.595065', '2024-04-12T00:06:03.659394', '2024-04-12T00:25:37.550541', '2024-04-12T00:47:35.790240', '2024-04-12T01:06:39.926479', '2024-04-12T01:27:54.673350', '2024-04-12T01:49:32.317842', '2024-04-12T03:36:12.933135', '2024-04-12T04:00:02.514841', '2024-04-12T04:25:49.586817', '2024-04-12T04:49:34.189731', '2024-04-12T05:15:58.000190', '2024-04-12T05:39:07.001042', '2024-04-12T06:00:01.648681', '2024-04-12T06:23:33.531887', '2024-04-12T06:43:35.873390', '2024-04-12T07:01:10.031087', '2024-04-12T07:21:27.115347', '2024-04-12T08:29:41.247225', '2024-04-12T09:38:15.257665'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_std = results_df[results_df["Deformation"] == "std"]
results_df_both = results_df[results_df["Deformation"] == "both"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 18        lr        mean   20  10000                50000
# 9         ks        mean   20  10000                50000
# 0         fn        mean   20  10000                50000
# 12       sks        mean   20  10000                50000
# 3        fpd        mean   20  10000                50000
# 15       swd        mean   20  10000                50000
# 6        kpd        mean   20  10000                50000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 18                             0.00020                             0.0003
# 9                              0.00525                            0.00702
# 0                              0.03342                            0.04478
# 12                             0.03647                            0.04753
# 3                              0.05260                             0.0674
# 15                             0.05905                            0.08167
# 6                              0.88257                            0.95696
#
#     $t^{\mu}$ (s)
# 18           4094
# 9            1547
# 0            1195
# 12           1388
# 3            1318
# 15           1202
# 6            1297
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 18        lr                             0.00020
# 9         ks                             0.00525
# 0         fn                             0.03342
# 12       sks                             0.03647
# 3        fpd                             0.05260
# 15       swd                             0.05905
# 6        kpd                             0.88257
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 18                             0.0003           4094
# 9                             0.00702           1547
# 0                             0.04478           1195
# 12                            0.04753           1388
# 3                              0.0674           1318
# 15                            0.08167           1202
# 6                             0.95696           1297

# %%
sorted_df_std = results_df_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma}$ (s)"}, inplace=True)
display(sorted_df_std)
sorted_df_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 19        lr         std   20  10000                50000
# 10        ks         std   20  10000                50000
# 13       sks         std   20  10000                50000
# 4        fpd         std   20  10000                50000
# 16       swd         std   20  10000                50000
# 1         fn         std   20  10000                50000
# 7        kpd         std   20  10000                50000
#
#     $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 19                                0.00049
# 10                                0.01247
# 13                                0.10834
# 4                                 0.16144
# 16                                0.18005
# 1                                 0.30884
# 7                                 4.98047
#
#    $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 19                               0.00062              4114
# 10                               0.01696              1424
# 13                               0.14715              1254
# 4                                0.21282              1144
# 16                               0.25654              1054
# 1                                0.40161               935
# 7                                    N/A              6400
#    Statistic  $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 19        lr                                0.00049
# 10        ks                                0.01247
# 13       sks                                0.10834
# 4        fpd                                0.16144
# 16       swd                                0.18005
# 1         fn                                0.30884
# 7        kpd                                4.98047
#
#    $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 19                               0.00062              4114
# 10                               0.01696              1424
# 13                               0.14715              1254
# 4                                0.21282              1144
# 16                               0.25654              1054
# 1                                0.40161               935
# 7                                    N/A              6400

# %%
sorted_df_both = results_df_both.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_both.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\sigma}$ (s)"}, inplace=True)
display(sorted_df_both)
sorted_df_both.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_both)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 20        lr        both   20  10000                50000
# 11        ks        both   20  10000                50000
# 2         fn        both   20  10000                50000
# 14       sks        both   20  10000                50000
# 5        fpd        both   20  10000                50000
# 17       swd        both   20  10000                50000
# 8        kpd        both   20  10000                50000
#
#     $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 20                                    0.00023
# 11                                    0.00475
# 2                                     0.03311
# 14                                    0.03403
# 5                                     0.05028
# 17                                    0.05447
# 8                                     0.87921
#
#    $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 20                                   0.00031                  4271
# 11                                   0.00629                  1583
# 2                                    0.04418                  1173
# 14                                   0.04448                  1411
# 5                                    0.06448                  1274
# 17                                    0.0753                  1217
# 8                                    0.95366                  1429
#    Statistic  $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 20        lr                                    0.00023
# 11        ks                                    0.00475
# 2         fn                                    0.03311
# 14       sks                                    0.03403
# 5        fpd                                    0.05028
# 17       swd                                    0.05447
# 8        kpd                                    0.87921
#
#    $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 20                                   0.00031                  4271
# 11                                   0.00629                  1583
# 2                                    0.04418                  1173
# 14                                   0.04448                  1411
# 5                                    0.06448                  1274
# 17                                    0.0753                  1217
# 8                                    0.95366                  1429

# %%
result_table = sorted_df_mean.merge(sorted_df_std, on='Statistic', how='outer').merge(sorted_df_both, on='Statistic', how='outer').merge(times_df, on='Statistic', how='outer')
result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fpd","$d_{\\mathrm{FPD}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("kpd","$d_{\\mathrm{KPD}}$")
display(result_table)
print(result_table.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g"))
# Out:
# /tmp/ipykernel_2598324/2797441218.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fpd","$d_{\\mathrm{FPD}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("kpd","$d_{\\mathrm{KPD}}$")
#                     Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 0  $\overline{\|\cdot\|}_{F}$                             0.03342
# 1          $d_{\mathrm{FPD}}$                             0.05260
# 2          $d_{\mathrm{KPD}}$                             0.88257
# 3              $\overline{D}$                             0.00525
# 4          $t_{\mathrm{LLR}}$                             0.00020
# 5             $\widetilde{D}$                             0.03647
# 6             $\widetilde{W}$                             0.05905
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)  \
# 0                             0.04478           1195
# 1                             0.06740           1318
# 2                             0.95696           1297
# 3                             0.00702           1547
# 4                             0.00030           4094
# 5                             0.04753           1388
# 6                             0.08167           1202
#
#    $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 0                                0.30884
# 1                                0.16144
# 2                                4.98047
# 3                                0.01247
# 4                                0.00049
# 5                                0.10834
# 6                                0.18005
#
#   $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)  \
# 0                               0.40161               935
# 1                               0.21282              1144
# 2                                   N/A              6400
# 3                               0.01696              1424
# 4                               0.00062              4114
# 5                               0.14715              1254
# 6                               0.25654              1054
#
#    $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 0                                    0.03311
# 1                                    0.05028
# 2                                    0.87921
# 3                                    0.00475
# 4                                    0.00023
# 5                                    0.03403
# 6                                    0.05447
#
#    $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)  \
# 0                                    0.04418                  1173
# 1                                    0.06448                  1274
# 2                                    0.95366                  1429
# 3                                    0.00629                  1583
# 4                                    0.00031                  4271
# 5                                    0.04448                  1411
# 6                                    0.07530                  1217
#
#   $t^{\mathrm{null}}$ (s)
# 0                      57
# 1                     308
# 2                   21299
# 3                     180
# 4                       -
# 5                     588
# 6                     349
# \begin{tabular}{l|llr|llr|llr|r}
# \toprule
# Statistic & $\epsilon^{\mu}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu}_{99\%\mathrm{CL}}$ & $t^{\mu}$ (s) & $\epsilon^{\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\sigma}_{99\%\mathrm{CL}}$ & $t^{\sigma}$ (s) & $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$ & $t^{\mu-\sigma}$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $\overline{\|\cdot\|}_{F}$ & 0.033 & 0.045 & 1195 & 0.31 & 0.4 & 935 & 0.033 & 0.044 & 1173 & 57 \\
# $d_{\mathrm{FPD}}$ & 0.053 & 0.067 & 1318 & 0.16 & 0.21 & 1144 & 0.05 & 0.064 & 1274 & 308 \\
# $d_{\mathrm{KPD}}$ & 0.88 & 0.96 & 1297 & 5 & N/A & 6400 & 0.88 & 0.95 & 1429 & 21299 \\
# $\overline{D}$ & 0.0053 & 0.007 & 1547 & 0.012 & 0.017 & 1424 & 0.0047 & 0.0063 & 1583 & 180 \\
# $t_{\mathrm{LLR}}$ & 0.0002 & 0.0003 & 4094 & 0.00049 & 0.00062 & 4114 & 0.00023 & 0.00031 & 4271 & - \\
# $\widetilde{D}$ & 0.036 & 0.048 & 1388 & 0.11 & 0.15 & 1254 & 0.034 & 0.044 & 1411 & 588 \\
# $\widetilde{W}$ & 0.059 & 0.082 & 1202 & 0.18 & 0.26 & 1054 & 0.054 & 0.075 & 1217 & 349 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Fixed $\epsilon$

# %%
fpd_results = {5: {10_000: [[0.68, 0.00010175550386551708], 
                            [0.95, 0.00015583746551772079], 
                            [0.99, 0.00022347410983350775]],
                   50_000: [[0.68, 4.5226688115357585e-05], 
                            [0.95, 5.398123973119404e-05], 
                            [0.99, 6.354077850007809e-05]],
                   100_000 : [[0.68, 3.725127064668703e-05], 
                              [0.95, 4.0825583153507725e-05], 
                              [0.99, 4.465564257168013e-05]]},
               20: {10_000: [[0.68, 0.0006669445748113884], 
                             [0.95, 0.0013217846893085318], 
                             [0.99, 0.0019605548728214763]],
                    100_000 : [[0.68, 0.00015735387007512796], 
                               [0.95, 0.0001991294338873111], 
                               [0.99, 0.00028358152805583374]]},
               100: {10_000: [[0.68, 0.0060367495598200515], 
                              [0.95, 0.009021833572706342], 
                              [0.99, 0.011125954730711617]],
                    100_000 : [[0.68, 0.000817842570244682], 
                               [0.95, 0.0011978135448655475], 
                               [0.99, 0.001414743609381014]]}}
fpd_results
# Out:
# {5: {10000: [[0.68, 0.00010175550386551708],
#    [0.95, 0.00015583746551772079],
#    [0.99, 0.00022347410983350775]],
#   50000: [[0.68, 4.5226688115357585e-05],
#    [0.95, 5.398123973119404e-05],
#    [0.99, 6.354077850007809e-05]],
#   100000: [[0.68, 3.725127064668703e-05],
#    [0.95, 4.0825583153507725e-05],
#    [0.99, 4.465564257168013e-05]]},
#  20: {10000: [[0.68, 0.0006669445748113884],
#    [0.95, 0.0013217846893085318],
#    [0.99, 0.0019605548728214763]],
#   100000: [[0.68, 0.00015735387007512796],
#    [0.95, 0.0001991294338873111],
#    [0.99, 0.00028358152805583374]]},
#  100: {10000: [[0.68, 0.0060367495598200515],
#    [0.95, 0.009021833572706342],
#    [0.99, 0.011125954730711617]],
#   100000: [[0.68, 0.000817842570244682],
#    [0.95, 0.0011978135448655475],
#    [0.99, 0.001414743609381014]]}}

# %%
def define_norm_df(dic,x,y):
    # Flatten the dictionary to a list of rows
    rows = []
    for N, n_dict in dic.items():
        for n, values in n_dict.items():
            row = {'N': N, 'n': n}
            for confidence, value in values:
                row[confidence] = value*(N**x)*(n**y)
            rows.append(row)

    # Convert the list of rows to a DataFrame
    df = pd.DataFrame(rows)

    # Optionally, rename the columns for clarity
    df.rename(columns={0.68: '0.68', 0.95: '0.95', 0.99: '0.99'}, inplace=True)
    return df

df = define_norm_df(fpd_results,-1/2,1/2)
# Show the DataFrame
display(df)

df = define_norm_df(fpd_results,-2/3,2/3)
# Show the DataFrame
display(df)
# Out:
#      N       n      0.68      0.95      0.99
# 0    5   10000  0.004551  0.006969  0.009994
# 1    5   50000  0.004523  0.005398  0.006354
# 2    5  100000  0.005268  0.005774  0.006315
# 3   20   10000  0.014913  0.029556  0.043839
# 4   20  100000  0.011127  0.014081  0.020052
# 5  100   10000  0.060367  0.090218  0.111260
# 6  100  100000  0.025862  0.037878  0.044738
#      N       n      0.68      0.95      0.99
# 0    5   10000  0.016153  0.024738  0.035474
# 1    5   50000  0.020992  0.025056  0.029493
# 2    5  100000  0.027447  0.030081  0.032903
# 3   20   10000  0.042015  0.083267  0.123507
# 4   20  100000  0.046011  0.058226  0.082920
# 5  100   10000  0.130058  0.194370  0.239701
# 6  100  100000  0.081784  0.119781  0.141474
