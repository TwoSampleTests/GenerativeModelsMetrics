# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/git/github/GenerativeModelsMetrics

# %%
visible_devices = [0]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std # type: ignore
from GMetrics.plotters import cornerplotter, plot_corr_matrix # type: ignore

sys.path.insert(0,'utils_func/')
import MixtureDistributions # type: ignore
from optimizers_unimodal import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results_leonardo/20D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-17 09:23:52.777986: Importing os...
# 2024-04-17 09:23:52.778100: Importing sys...
# Visible devices: [0]
# 2024-04-17 09:23:52.778330: Importing timer from timeit...
# 2024-04-17 09:23:52.778397: Setting env variables for tf import (only device(s) [0] will be available)...
# 2024-04-17 09:23:52.778528: Importing numpy...
# 2024-04-17 09:23:52.890319: Importing matplotlib...
# 2024-04-17 09:23:53.228759: Importing h5py...
# 2024-04-17 09:23:53.255381: Importing importlib.util...
# 2024-04-17 09:23:53.255476: Importing json...
# 2024-04-17 09:23:53.255542: Importing pandas...
# 2024-04-17 09:23:53.675478: Importing random...
# 2024-04-17 09:23:53.675620: Importing scipy utils...
# 2024-04-17 09:23:54.044482: Importing subprocess...
# 2024-04-17 09:23:54.044615: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-17 09:23:57.148047: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-17 09:23:58.220676: Importing timeit...
# 2024-04-17 09:23:58.220768: Importing tqdm...
# 2024-04-17 09:23:58.228217: Importing typing...
# 2024-04-17 09:23:58.228321: Setting tf configs...
# 2024-04-17 09:23:58.310916: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-17 09:24:02.679533: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #0, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2024-04-17 09:24:02.711617: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 10_000
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = 0.,
                                                             eps_scale = 0.,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
dist_2 = MixtureDistributions.MultiNormalFromMixtureGaussian(ncomp = ncomp,
                                                             ndims = ndims,
                                                             eps_loc = eps_loc,
                                                             eps_scale = eps_scale,
                                                             seed = 0,
                                                             scale_def = None,
                                                             nsamples = 50_000)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)

# %% [markdown]
# # Fixed $n=100000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 100_000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 1000000000
# batch_size 100000
# niter 10000
# niter * batch_size 1000000000
# small_sample False

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               #min_samples_input = 20_000,
                               #max_samples_input = 50_000,
                               num_batches = 20)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4,
                               block_size = 10_000,
                               num_batches = 1,
                               batch_size = 100_000)
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000           100000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...       20           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims    nsamples  small_sample  \
# 0       True       20           0  float64    20  1000000000         False
#
#    ncomp
# 0      5
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fn": {"name": "fn", # type: ignore
                                       "object_name": "FNMetric",
                                       "class_name": "GMetrics.FNMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns)/ndims,
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)/ndims",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\overline{\|\cdot\|}_{F}$",
                                       "null_file": null_hypotheses_dir+"FN.json"},
                               "fpd": {"name": "fpd",
                                       "object_name": "FPDMetric",
                                       "class_name": "GMetrics.FPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1000,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 1000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 20,
                                       "latex": "$d_{\mathrm{FPD}}$",
                                       "null_file": null_hypotheses_dir+"FPD.json"},
                               "kpd": {"name": "kpd",
                                       "object_name": "KPDMetric" ,
                                       "class_name": "GMetrics.KPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1,
                                       "latex": "$d_{\mathrm{KPD}}$",
                                       "null_file": null_hypotheses_dir+"KPD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 50,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fn': {'name': 'fn',
#   'object_name': 'FNMetric',
#   'class_name': 'GMetrics.FNMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)/ndims',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$\\overline{\\|\\cdot\\|}_{F}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_100K/null_hypothesis/FN.json'},
#  'fpd': {'name': 'fpd',
#   'object_name': 'FPDMetric',
#   'class_name': 'GMetrics.FPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 1000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 20,
#   'latex': '$d_{\\mathrm{FPD}}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_100K/null_hypothesis/FPD.json'},
#  'kpd': {'name': 'kpd',
#   'object_name': 'KPDMetric',
#   'class_name': 'GMetrics.KPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{KPD}}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_100K/null_hypothesis/KPD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 2000,
#   'latex': '$\\overline{D}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_100K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{D}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_100K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{W}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_100K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 100000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 20,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 20,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 20,
#    'nsamples': 1000000000,
#    'small_sample': False,
#    'ncomp': 5},
#   'max_vectorize': 50,
#   'latex': '$t_{\\mu}$',
#   'null_file': 'results_leonardo/20D_unimodal/20D_100K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fn from results_leonardo/20D_unimodal/20D_100K/null_hypothesis/FN.json
# Loading fpd from results_leonardo/20D_unimodal/20D_100K/null_hypothesis/FPD.json
# Loading kpd from results_leonardo/20D_unimodal/20D_100K/null_hypothesis/KPD.json
# Loading ks from results_leonardo/20D_unimodal/20D_100K/null_hypothesis/KS.json
# Loading sks from results_leonardo/20D_unimodal/20D_100K/null_hypothesis/SKS.json
# Loading swd from results_leonardo/20D_unimodal/20D_100K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fn: [[0.68, [6800, 3199], 0.7497740563332209], [0.95, [9500, 500], 1.0335148147738626], [0.99, [9900, 100], 1.2423774808290733]]
# Computing time for metric fn: 25.915534429019317
# ThresholdS for metric fpd: [[0.68, [6800, 3199], 0.05293719844674096], [0.95, [9500, 500], 0.0600483317796896], [0.99, [9900, 100], 0.06628593187637868]]
# Computing time for metric fpd: 564.2194251650944
# ThresholdS for metric kpd: [[0.68, [6800, 3199], -0.02159208404930446], [0.95, [9500, 500], -0.013456617087248548], [0.99, [9900, 100], -0.008393198214751152]]
# Computing time for metric kpd: 29900.47628878709
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9098575007485578], [0.95, [9500, 500], 1.1147930513981992], [0.99, [9900, 100], 1.246831668641481]]
# Computing time for metric ks: 206.73133146693
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9054295005779338], [0.95, [9500, 500], 1.0848732656815778], [0.99, [9900, 100], 1.2053976747108415]]
# Computing time for metric sks: 650.5813115499914
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.29478870243519845], [0.95, [9500, 500], 0.38412994044916837], [0.99, [9900, 100], 0.4514289544828107]]
# Computing time for metric swd: 347.0270691139158
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f4d714abba0>
# 1          metric_list  <function <lambda> at 0x7f4d714abc40>
# 2          metric_list  <function <lambda> at 0x7f4d714abf60>
# 3      statistic_means  <function <lambda> at 0x7f4d68030040>
# 4         metric_means  <function <lambda> at 0x7f4d680300e0>
# 5         metric_means  <function <lambda> at 0x7f4d68030180>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f4d68030220>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...             20
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...           2000
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 6  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 1  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 2  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 3  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 4  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 5  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 6  results_leonardo/20D_unimodal/20D_100K/null_hy...
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.7497740563332209], [0....
# 1  [[0.68, [6800, 3199], 0.05293719844674096], [0...
# 2  [[0.68, [6800, 3199], -0.02159208404930446], [...
# 3  [[0.68, [6800, 3199], 0.9098575007485578], [0....
# 4  [[0.68, [6800, 3199], 0.9054295005779338], [0....
# 5  [[0.68, [6800, 3199], 0.29478870243519845], [0...
# 6                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    if "FPD" in latex:
        latex = r"$d_{\mathrm{FPD}}\,(\times 10^{3})$"
    elif "KPD" in latex:
        latex = r"$d_{\mathrm{KPD}}\,(\times 10^{4})$"
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.6806095719296456 +/- 0.00037194252371767025
# sigma = 0.19285811461218588 +/- 0.0016098426169475506
# /tmp/ipykernel_334085/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_334085/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_334085/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_334085/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.4474067529663444 seconds.
# mu = 0.05205573580888985 +/- 1.699660993511015e-07
# sigma = 0.004122694499366907 +/- 5.3259995984945545e-05
# /tmp/ipykernel_334085/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_334085/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_334085/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_334085/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9490460599772632 seconds.
# mu = -0.024495745081719093 +/- 4.305448175527881e-07
# sigma = 0.00656159140417009 +/- 4.769171953377556e-05
# /tmp/ipykernel_334085/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_334085/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_334085/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_334085/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9601487079635262 seconds.
# mu = 0.8671350622227308 +/- 0.00016891488507959362
# sigma = 0.129967259369271 +/- 0.0011078670572348777
# /tmp/ipykernel_334085/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_334085/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_334085/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_334085/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3067492530681193 seconds.
# mu = 0.8668801748175944 +/- 0.0001346382919099102
# sigma = 0.1160337416055822 +/- 0.0009820466638004156
# /tmp/ipykernel_334085/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_334085/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_334085/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_334085/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.2885297308675945 seconds.
# mu = 0.2806762541431985 +/- 2.8849517929946965e-05
# sigma = 0.05371174725322848 +/- 0.0005333610390741083
# /tmp/ipykernel_334085/2428069334.py:82: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_334085/2428069334.py:84: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_334085/2428069334.py:121: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_334085/2428069334.py:127: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.0079857320524752 seconds.
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7f4d714abba0>
# 1          metric_list  <function <lambda> at 0x7f4d714abc40>
# 2          metric_list  <function <lambda> at 0x7f4d714abf60>
# 3      statistic_means  <function <lambda> at 0x7f4d68030040>
# 4         metric_means  <function <lambda> at 0x7f4d680300e0>
# 5         metric_means  <function <lambda> at 0x7f4d68030180>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7f4d68030220>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1               lambda ns, ndims: 1000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 1  {'niter': 10000, 'batch_size_test': 100000, 'b...             20
# 2  {'niter': 10000, 'batch_size_test': 100000, 'b...              1
# 3  {'niter': 10000, 'batch_size_test': 100000, 'b...           2000
# 4  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 5  {'niter': 10000, 'batch_size_test': 100000, 'b...            100
# 6  {'niter': 10000, 'batch_size_test': 100000, 'b...             50
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 1  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 2  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 3  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 4  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 5  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 6  results_leonardo/20D_unimodal/20D_100K/null_hy...
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.7497740563332209], [0....
# 1  [[0.68, [6800, 3199], 0.05293719844674096], [0...
# 2  [[0.68, [6800, 3199], -0.02159208404930446], [...
# 3  [[0.68, [6800, 3199], 0.9098575007485578], [0....
# 4  [[0.68, [6800, 3199], 0.9054295005779338], [0....
# 5  [[0.68, [6800, 3199], 0.29478870243519845], [0...
# 6                                                 []
#
#                                          null_figure
# 0  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 1  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 2  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 3  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 4  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 5  results_leonardo/20D_unimodal/20D_100K/null_hy...
# 6                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.01,
                                                 fn_tol = 0.03,
                                                 eps_min = 0.,
                                                 eps_max = 50.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Exclusion limits for fn with mean deformation already loaded.
# Exclusion limits for fn with std deformation already loaded.
# Exclusion limits for fn with off deformation already loaded.
# Exclusion limits for fn with cov deformation already loaded.
# Exclusion limits for fn with mean_std deformation already loaded.
# Exclusion limits for fn with mean_off deformation already loaded.
# Exclusion limits for fn with mean_cov deformation already loaded.
# Exclusion limits for fpd with mean deformation already loaded.
# Exclusion limits for fpd with std deformation already loaded.
# Exclusion limits for fpd with off deformation already loaded.
# Exclusion limits for fpd with cov deformation already loaded.
# Exclusion limits for fpd with mean_std deformation already loaded.
# Exclusion limits for fpd with mean_off deformation already loaded.
# Exclusion limits for fpd with mean_cov deformation already loaded.
# Exclusion limits for kpd with mean deformation already loaded.
# Exclusion limits for kpd with std deformation already loaded.
# Exclusion limits for kpd with off deformation already loaded.
# Exclusion limits for kpd with cov deformation already loaded.
# Exclusion limits for kpd with mean_std deformation already loaded.
# Exclusion limits for kpd with mean_off deformation already loaded.
# Exclusion limits for kpd with mean_cov deformation already loaded.
# Exclusion limits for ks with mean deformation already loaded.
# Exclusion limits for ks with std deformation already loaded.
# Exclusion limits for ks with off deformation already loaded.
# Exclusion limits for ks with cov deformation already loaded.
# Exclusion limits for ks with mean_std deformation already loaded.
# Exclusion limits for ks with mean_off deformation already loaded.
# Exclusion limits for ks with mean_cov deformation already loaded.
# Computing exclusion limits for sks with mean deformation.
#
# ======================================================
# =============== sks - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713338673.130334  334348 service.cc:145] XLA service 0x114a527f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1713338673.130636  334348 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# I0000 00:00:1713338675.792893  334348 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# statistic = 207.58329987126965 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.979203857505005
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 195.41262799638415 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9779157850107274
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 168.08762401529108 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9743487083747484
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 116.24523201410469 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.963014666590656
#
# ------------ 5 ------------
# eps = 1.5625
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f4c4c375940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 65.2771204068588 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.934608759885375
#
# ------------ 6 ------------
# eps = 0.78125
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f4badc7d620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 33.843069212665256 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8757586976267917
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 17.217424952768418 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7628990080408704
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 8.812089816795517 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5615328635094607
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 4.624035322019814 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2398734370918443
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 2.565356939375817 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8111727702231102
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.5754745013907479 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.36882488957379406
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 1.1220846252368641 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.03372185732080328
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.9309209581300888 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1527460548630609
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 1.021128422549758 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.0605363647028735
#
# ------------ 15 ------------
# eps = 0.01068115234375
# statistic = 1.0708541216379057 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.013006416419938943
#
# ------------ 16 ------------
# eps = 0.011444091796875
# statistic = 1.096452676988938 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.010616855629731277
#
# ------------ 17 ------------
# eps = 0.0110626220703125
# statistic = 1.0836558254266042 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 0.0011228258453765674
#
# ------------ 18 ------------
# eps = 0.01125335693359375
# statistic = 1.0899390420691122 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.017094017094017096
# relative_error_metric = 0.004658587198059094
#
# ------------ 19 ------------
# eps = 0.011157989501953125
# statistic = 1.0867795554803288 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.008583690987124463
# relative_error_metric = 0.0017556119285503761
# =======> statistic within required accuracy at 0.95 CL in 117.90923591307364 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.011110305786132812
# statistic = 1.0852410873475482 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9991113729954644
# relative_error_metric = 0.10491098758437094
#
# ------------ 2 ------------
# eps = 25.005555152893066
# statistic = 207.5858161983775 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.998223535298182
# relative_error_metric = 1.9769071187939253
#
# ------------ 3 ------------
# eps = 12.5083327293396
# statistic = 195.4296278651663 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9964502236225812
# relative_error_metric = 1.9754794920914762
#
# ------------ 4 ------------
# eps = 6.259721517562866
# statistic = 168.17660843232295 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9929130258319068
# relative_error_metric = 1.9715342213163034
#
# ------------ 5 ------------
# eps = 3.1354159116744995
# statistic = 116.52293563302445 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9858760995227311
# relative_error_metric = 1.9590447722873985
#
# ------------ 6 ------------
# eps = 1.5732631087303162
# statistic = 65.68742366867966 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9719502847388444
# relative_error_metric = 1.9279206557293795
#
# ------------ 7 ------------
# eps = 0.7921867072582245
# statistic = 34.30284435840286 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.944676474052721
# relative_error_metric = 1.8642120695711453
#
# ------------ 8 ------------
# eps = 0.40164850652217865
# statistic = 17.690114101138807 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.8923312553982838
# relative_error_metric = 1.7448287849495645
#
# ------------ 9 ------------
# eps = 0.20637940615415573
# statistic = 9.28904550906611 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.7956628718293925
# relative_error_metric = 1.5405577395190513
#
# ------------ 10 ------------
# eps = 0.10874485597014427
# statistic = 5.09644728956223 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.6292089344061667
# relative_error_metric = 1.2348922059843874
#
# ------------ 11 ------------
# eps = 0.05992758087813854
# statistic = 3.028516086090357 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.3744011086005032
# relative_error_metric = 0.8611977070758854
#
# ------------ 12 ------------
# eps = 0.03551894333213568
# statistic = 2.01947253939015 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.0469238946607873
# relative_error_metric = 0.5048729472086684
#
# ------------ 13 ------------
# eps = 0.023314624559134245
# statistic = 1.5327227948019277 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.709039562351902
# relative_error_metric = 0.2390874497566074
#
# ------------ 14 ------------
# eps = 0.01721246517263353
# statistic = 1.3000108929886265 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.4309012981381331
# relative_error_metric = 0.07552717708206878
#
# ------------ 15 ------------
# eps = 0.01416138547938317
# statistic = 1.189860012890001 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.19449826080269403
# relative_error_metric = 0.01297368704943262
#
# ------------ 16 ------------
# eps = 0.01568692532600835
# statistic = 1.2442815321366119 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.10221950961121859
# relative_error_metric = 0.03174608113346472
#
# ------------ 17 ------------
# eps = 0.01492415540269576
# statistic = 1.2169902057718924 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.05245011096098066
# relative_error_metric = 0.009571160056118508
#
# ------------ 18 ------------
# eps = 0.014542770441039465
# statistic = 1.2033837508693122 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.025885629446301985
# relative_error_metric = 0.0016721515868084768
#
# ------------ 19 ------------
# eps = 0.014733462921867613
# statistic = 1.2102505258259786 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.013027118513801323
# relative_error_metric = 0.004017845904928278
#
# ------------ 20 ------------
# eps = 0.014638116681453539
# statistic = 1.2067088899671945 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.006534841796538775
# relative_error_metric = 0.0010871951310559493
# =======> statistic within required accuracy at 0.99 CL in 119.94542249618098 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 237.8546931229066 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_100K/exclusion_limits.json
# Computing exclusion limits for sks with std deformation.
#
# ======================================================
# =============== sks - only diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 74.57887350109964 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9426476582490428
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 64.11479452948933 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9334430188147718
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 52.38812777310524 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9188470260051675
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 40.326925457014234 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8952111910959315
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 28.949675976123387 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8555166242786096
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 19.246222013481614 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.786558815295419
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 11.919774703306548 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6663121467743995
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 6.988757553430843 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4625103426263208
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 3.9899979017111544 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1449057681289332
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 2.3169364649185966 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7243575019227477
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.4565045332737583 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.29246440080254416
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 1.0566257695853818 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.02638104956482009
#
# ------------ 13 ------------
# eps = 0.018310546875
# statistic = 1.2510809277868238 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.14230387100053746
#
# ------------ 14 ------------
# eps = 0.0152587890625
# statistic = 1.151023834315143 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.059171389089115324
#
# ------------ 15 ------------
# eps = 0.01373291015625
# statistic = 1.1034179125733021 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.016948975598862766
#
# ------------ 16 ------------
# eps = 0.012969970703125
# statistic = 1.0798969326942045 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.05714285714285714
# relative_error_metric = 0.00459756235660214
#
# ------------ 17 ------------
# eps = 0.0133514404296875
# statistic = 1.0912984984515357 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.028985507246376812
# relative_error_metric = 0.005905078703672451
#
# ------------ 18 ------------
# eps = 0.01316070556640625
# statistic = 1.0854177458722434 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.014598540145985401
# relative_error_metric = 0.0005017577714388927
#
# ------------ 19 ------------
# eps = 0.013065338134765625
# statistic = 1.0826291630502978 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.007272727272727273
# relative_error_metric = 0.002070680615193584
# =======> statistic within required accuracy at 0.95 CL in 115.87351732281968 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.013113021850585938
# statistic = 1.0839529461976862 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9989512333019657
# relative_error_metric = 0.106095350711251
#
# ------------ 2 ------------
# eps = 25.006556510925293
# statistic = 74.58248539011569 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9979035659390452
# relative_error_metric = 1.9363804541852803
#
# ------------ 3 ------------
# eps = 12.50983476638794
# statistic = 64.1276160690961 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.995811522311735
# relative_error_metric = 1.9261997813578529
#
# ------------ 4 ------------
# eps = 6.261473894119263
# statistic = 52.420159630916004 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9916405513056414
# relative_error_metric = 1.9100878211602768
#
# ------------ 5 ------------
# eps = 3.1372934579849243
# statistic = 40.39472634488704 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9833506921287558
# relative_error_metric = 1.884096722967174
#
# ------------ 6 ------------
# eps = 1.5752032399177551
# statistic = 29.075629943155022 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.966976295171878
# relative_error_metric = 1.8407718932233788
#
# ------------ 7 ------------
# eps = 0.7941581308841705
# statistic = 19.44966416131115 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9350254406779503
# relative_error_metric = 1.7665661455230013
#
# ------------ 8 ------------
# eps = 0.40363557636737823
# statistic = 12.208941155150864 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.874139738857836
# relative_error_metric = 1.640564416927504
#
# ------------ 9 ------------
# eps = 0.2083742991089821
# statistic = 7.358509239294285 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.7631824378248777
# relative_error_metric = 1.4369870262183373
#
# ------------ 10 ------------
# eps = 0.11074366047978401
# statistic = 4.416740548106508 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.576509830430987
# relative_error_metric = 1.1423920032284114
#
# ------------ 11 ------------
# eps = 0.061928341165184975
# statistic = 2.775784273145331 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.3010243245272575
# relative_error_metric = 0.7889047117176483
#
# ------------ 12 ------------
# eps = 0.037520681507885456
# statistic = 1.9180374969308431 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.9640874768531398
# relative_error_metric = 0.45631798520437133
#
# ------------ 13 ------------
# eps = 0.025316851679235697
# statistic = 1.4873329764709904 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.6351220395861865
# relative_error_metric = 0.20940475545625648
#
# ------------ 14 ------------
# eps = 0.019214936764910817
# statistic = 1.2807066748332303 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.37750078728446906
# relative_error_metric = 0.060583941407125405
#
# ------------ 15 ------------
# eps = 0.016163979307748377
# statistic = 1.1801709706644132 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.17247320132118
# relative_error_metric = 0.021149426234565578
#
# ------------ 16 ------------
# eps = 0.017689458036329597
# statistic = 1.2304042896828573 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.09012253101962031
# relative_error_metric = 0.02053255177355134
#
# ------------ 17 ------------
# eps = 0.016926718672038987
# statistic = 1.2051478371155606 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.04406837708950191
# relative_error_metric = 0.00020728718379729762
#
# ------------ 18 ------------
# eps = 0.017308088354184292
# statistic = 1.2178464571252612 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.02227964549957488
# relative_error_metric = 0.01027447647628241
#
# ------------ 19 ------------
# eps = 0.01711740351311164
# statistic = 1.2113082278735168 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.0112022181118728
# relative_error_metric = 0.00489141285777034
#
# ------------ 20 ------------
# eps = 0.017022061092575314
# statistic = 1.2082403608980066 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.0056168393207289375
# relative_error_metric = 0.0023555198793078543
# =======> statistic within required accuracy at 0.99 CL in 123.77195929689333 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 239.6455111990217 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_100K/exclusion_limits.json
# Computing exclusion limits for sks with off deformation.
#
# ======================================================
# =============== sks - only off-diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 74.57549818415015 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9426450996793783
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 64.08525567477987 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9334128513587747
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 52.245603099012165 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.918630146240374
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 39.99398659215647 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8943618913050644
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 28.928798991050567 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.855416124171445
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 20.796449943770345 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8016805007088508
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 13.613947406487835 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7047727052726984
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 8.422352081259874 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5435584090659678
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 5.005738395445255 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2875111229922913
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 2.9473421708056313 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9237943430654597
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.8168442015520414 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5045087567179966
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 1.24126943452679 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.13446824980359356
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.9810670568177475 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.10049294041393027
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 1.105808425408268 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.01911291796689566
#
# ------------ 15 ------------
# eps = 0.00762939453125
# statistic = 1.0409444152241198 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.04132889744217598
#
# ------------ 16 ------------
# eps = 0.008392333984375
# statistic = 1.0731617405370533 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.08695652173913043
# relative_error_metric = 0.010853878746893749
#
# ------------ 17 ------------
# eps = 0.0087738037109375
# statistic = 1.0894023400181345 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.044444444444444446
# relative_error_metric = 0.004166053580957299
#
# ------------ 18 ------------
# eps = 0.00858306884765625
# statistic = 1.0811267117651489 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.02197802197802198
# relative_error_metric = 0.003459421934847293
#
# ------------ 19 ------------
# eps = 0.008678436279296875
# statistic = 1.0852276239812608 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.011049723756906077
# relative_error_metric = 0.00032658232745856825
#
# ------------ 20 ------------
# eps = 0.008630752563476562
# statistic = 1.0831501526343554 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.005509641873278237
# relative_error_metric = 0.0015895705117067991
# =======> statistic within required accuracy at 0.95 CL in 124.27624897006899 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.008654594421386719
# statistic = 1.0841764297480534 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9993077522687561
# relative_error_metric = 0.1058897763795567
#
# ------------ 2 ------------
# eps = 25.004327297210693
# statistic = 74.57790588802743 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9986159835786261
# relative_error_metric = 1.9363766097257593
#
# ------------ 3 ------------
# eps = 12.50649094581604
# statistic = 64.09376427237338 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9972338813340806
# relative_error_metric = 1.926161522520755
#
# ------------ 4 ------------
# eps = 6.257572770118713
# statistic = 52.266646017731674 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9944754035128938
# relative_error_metric = 1.9098296910704236
#
# ------------ 5 ------------
# eps = 3.13311368227005
# statistic = 40.038697046733795 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9889812441158126
# relative_error_metric = 1.8830962170122159
#
# ------------ 6 ------------
# eps = 1.5708841383457184
# statistic = 29.000104810709338 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9780832359679457
# relative_error_metric = 1.8403737629867045
#
# ------------ 7 ------------
# eps = 0.7897693663835526
# statistic = 20.925303584617673 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9566416097399606
# relative_error_metric = 1.7821311379904434
#
# ------------ 8 ------------
# eps = 0.39921198040246964
# statistic = 13.808393818186817 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9151232784875853
# relative_error_metric = 1.6788558905241064
#
# ------------ 9 ------------
# eps = 0.20393328741192818
# statistic = 8.690139165590042 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.837157332830992
# relative_error_metric = 1.512750972821727
#
# ------------ 10 ------------
# eps = 0.10629394091665745
# statistic = 5.339925636104199 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.6988358522034221
# relative_error_metric = 1.2633533181047754
#
# ------------ 11 ------------
# eps = 0.05747426766902208
# statistic = 3.334148370266614 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.476501234238418
# relative_error_metric = 0.9378694144587509
#
# ------------ 12 ------------
# eps = 0.0330644310452044
# statistic = 2.2228784725345 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.1702016694213169
# relative_error_metric = 0.5935815868515819
#
# ------------ 13 ------------
# eps = 0.02085951273329556
# statistic = 1.6480771878768339 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.8270565833445913
# relative_error_metric = 0.3102739883711807
#
# ------------ 14 ------------
# eps = 0.01475705357734114
# statistic = 1.3589176499344626 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.5213182050478476
# relative_error_metric = 0.11973564541627191
#
# ------------ 15 ------------
# eps = 0.011705823999363929
# statistic = 1.219232746527733 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.29972169676704685
# relative_error_metric = 0.01141210775522994
#
# ------------ 16 ------------
# eps = 0.010180209210375324
# statistic = 1.1510795307933108 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.13941446349534997
# relative_error_metric = 0.04610114096640256
#
# ------------ 17 ------------
# eps = 0.010943016604869626
# statistic = 1.184575792603517 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.06735950928558501
# relative_error_metric = 0.017424362564762944
#
# ------------ 18 ------------
# eps = 0.011324420302116778
# statistic = 1.2016887411674955 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.03312198448738377
# relative_error_metric = 0.0030816787622413872
#
# ------------ 19 ------------
# eps = 0.011515122150740353
# statistic = 1.2103442279398375 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.016699270488207144
# relative_error_metric = 0.004095266322588887
#
# ------------ 20 ------------
# eps = 0.011419771226428566
# statistic = 1.2060534645578191 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.008384639585198412
# relative_error_metric = 0.0005438964416890975
# =======> statistic within required accuracy at 0.99 CL in 126.86591530195437 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 251.1421991980169 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_100K/exclusion_limits.json
# Computing exclusion limits for sks with cov deformation.
#
# ======================================================
# =============== sks - only cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 74.65403744464372 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9427045752041068
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 64.36348841544846 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.933695925287348
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 52.575326582965424 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9191301360232311
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 39.335784793000215 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.892641701764817
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 26.286752655626547 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8414601647997784
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 16.038650152971755 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7465770941744894
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 9.225046517562797 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.579095361170624
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 5.139012685236139 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3027679014448441
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 2.8724984325516236 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9034406182609254
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 1.6959691723116461 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4395041576473218
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 1.1323685649922999 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.042841785369245884
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.9024669040070369 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.1835683336518289
#
# ------------ 13 ------------
# eps = 0.018310546875
# statistic = 1.0088969594839716 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.07257368099367154
#
# ------------ 14 ------------
# eps = 0.0213623046875
# statistic = 1.0691365896922533 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.13333333333333333
# relative_error_metric = 0.014611517166520456
#
# ------------ 15 ------------
# eps = 0.02288818359375
# statistic = 1.1005378455006212 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.06896551724137931
# relative_error_metric = 0.014335590899937894
#
# ------------ 16 ------------
# eps = 0.022125244140625
# statistic = 1.0848248058929457 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.03389830508474576
# relative_error_metric = 4.466961488050554e-05
#
# ------------ 17 ------------
# eps = 0.0225067138671875
# statistic = 1.0926443144551221 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.017094017094017096
# relative_error_metric = 0.007137530226558664
#
# ------------ 18 ------------
# eps = 0.02231597900390625
# statistic = 1.0887492678344213 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.008583690987124463
# relative_error_metric = 0.0035663985748010463
# =======> statistic within required accuracy at 0.95 CL in 113.91541275801137 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.022220611572265625
# statistic = 1.086814635202697 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9982231407322109
# relative_error_metric = 0.10346601751965753
#
# ------------ 2 ------------
# eps = 25.011110305786133
# statistic = 74.66006570073951 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9964494358907934
# relative_error_metric = 1.9364455117741548
#
# ------------ 3 ------------
# eps = 12.5166654586792
# statistic = 64.38484254305551 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.992911455946638
# relative_error_metric = 1.9264892050580211
#
# ------------ 4 ------------
# eps = 6.269443035125732
# statistic = 52.631713701627476 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9858729818883898
# relative_error_metric = 1.9104411329735187
#
# ------------ 5 ------------
# eps = 3.145831823348999
# statistic = 39.46587310679487 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9719441366218198
# relative_error_metric = 1.8814497160724104
#
# ------------ 6 ------------
# eps = 1.5840262174606323
# statistic = 26.522787103824502 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9446645156382487
# relative_error_metric = 1.826112284761756
#
# ------------ 7 ------------
# eps = 0.803123414516449
# statistic = 16.378339485128475 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.8923086089199987
# relative_error_metric = 1.7257926085328594
#
# ------------ 8 ------------
# eps = 0.4126720130443573
# statistic = 9.653814978878025 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.7956220886306906
# relative_error_metric = 1.5559907653848295
#
# ------------ 9 ------------
# eps = 0.21744631230831146
# statistic = 5.63125184930607 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.629141790406792
# relative_error_metric = 1.2947436193847168
#
# ------------ 10 ------------
# eps = 0.11983346194028854
# statistic = 3.4000919591669545 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.374305543718129
# relative_error_metric = 0.9530775048594314
#
# ------------ 11 ------------
# eps = 0.07102703675627708
# statistic = 2.2315477766982292 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.0468129986946173
# relative_error_metric = 0.5971291174066724
#
# ------------ 12 ------------
# eps = 0.046623824164271355
# statistic = 1.6432874052919384 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.7089378344357468
# relative_error_metric = 0.30743288098428173
#
# ------------ 13 ------------
# eps = 0.03442221786826849
# statistic = 1.3557224068106208 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.4308261581040048
# relative_error_metric = 0.1173898351618697
#
# ------------ 14 ------------
# eps = 0.028321414720267057
# statistic = 1.2170837100481957 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.24141505972437807
# relative_error_metric = 0.00964798772933947
#
# ------------ 15 ------------
# eps = 0.02527101314626634
# statistic = 1.150779900609023 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.11383703614239822
# relative_error_metric = 0.04636133937774524
#
# ------------ 16 ------------
# eps = 0.0267962139332667
# statistic = 1.1836570662325734 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.05534348353727924
# relative_error_metric = 0.01820017608276563
#
# ------------ 17 ------------
# eps = 0.02755881432676688
# statistic = 1.200181229405923 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.027294104068839965
# relative_error_metric = 0.004336956311007939
#
# ------------ 18 ------------
# eps = 0.027940114523516968
# statistic = 1.208499528095912 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.013740812828251167
# relative_error_metric = 0.002569996254574517
#
# ------------ 19 ------------
# eps = 0.027749464425141923
# statistic = 1.2043695233466163 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.006846885969484816
# relative_error_metric = 0.0008533200759425954
# =======> statistic within required accuracy at 0.99 CL in 120.25071917893365 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 234.16616526897997 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_100K/exclusion_limits.json
# Computing exclusion limits for sks with mean_std deformation.
#
# ======================================================
# =============== sks - mean + diag of cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 188.92506356819206 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9771617572478835
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 168.55638190235558 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9744195888056366
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 137.5073977280838 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9686887801779254
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 99.59675538438498 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9568988590976328
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 65.05703441454725 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9343911717257063
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 39.517639406557045 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8931225488984729
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 22.73265519663689 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8178025453148179
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 12.550301485777641 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6817427615101226
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 6.772426976075709 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.44771194568024
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 3.6652698785131483 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0864500435045377
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 2.075293592742958 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6268152103557865
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 1.318990490952705 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.1947841050683516
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.9908185636484068 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.09062491907917858
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 1.1466544981860216 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.05537124252253702
#
# ------------ 15 ------------
# eps = 0.00762939453125
# statistic = 1.06470023869428 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.01876932977284263
#
# ------------ 16 ------------
# eps = 0.008392333984375
# statistic = 1.10552880805461 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.018860046400339454
#
# ------------ 17 ------------
# eps = 0.0080108642578125
# statistic = 1.0849500683031827 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.04878048780487805
# relative_error_metric = 7.079158971332229e-05
#
# ------------ 18 ------------
# eps = 0.00782012939453125
# statistic = 1.07492809670894 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.024096385542168676
# relative_error_metric = 0.009209336697176827
#
# ------------ 19 ------------
# eps = 0.007915496826171875
# statistic = 1.0801157097932477 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.011976047904191617
# relative_error_metric = 0.004394993177539603
#
# ------------ 20 ------------
# eps = 0.007963180541992188
# statistic = 1.0826047873809408 - next threshold = 1.0848732656815778 at 0.95 CL
# relative_error_eps = 0.005970149253731343
# relative_error_metric = 0.0020931960971247734
# =======> statistic within required accuracy at 0.95 CL in 127.78544190106913 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.007987022399902344
# statistic = 1.0838570262207032 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9993611402597489
# relative_error_metric = 0.10618359629505696
#
# ------------ 2 ------------
# eps = 25.00399351119995
# statistic = 188.92870877721748 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9987226885309346
# relative_error_metric = 1.974641105749944
#
# ------------ 3 ------------
# eps = 12.505990266799927
# statistic = 168.57407882573384 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9974470075451405
# relative_error_metric = 1.971600862493938
#
# ------------ 4 ------------
# eps = 6.2569886445999146
# statistic = 137.56554381004062 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.994900524551453
# relative_error_metric = 1.9652550408085747
#
# ------------ 5 ------------
# eps = 3.1324878334999084
# statistic = 99.72736315712575 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9898269876163504
# relative_error_metric = 1.9522296758841604
#
# ------------ 6 ------------
# eps = 1.5702374279499054
# statistic = 65.27345720502832 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.979756941674216
# relative_error_metric = 1.927471814796364
#
# ------------ 7 ------------
# eps = 0.7891122251749039
# statistic = 39.81944038945553 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9599195587038725
# relative_error_metric = 1.8824714264245967
#
# ------------ 8 ------------
# eps = 0.3985496237874031
# statistic = 23.113375121535764 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.9214139982232012
# relative_error_metric = 1.8017337988540467
#
# ------------ 9 ------------
# eps = 0.20326832309365273
# statistic = 12.997709660136335 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.8487702664992018
# relative_error_metric = 1.6605256451865542
#
# ------------ 10 ------------
# eps = 0.10562767274677753
# statistic = 7.2640621733257404 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.7188031921542943
# relative_error_metric = 1.4307085947209346
#
# ------------ 11 ------------
# eps = 0.05680734757333994
# statistic = 4.183478491288445 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.5069310865619532
# relative_error_metric = 1.1052697166684151
#
# ------------ 12 ------------
# eps = 0.03239718498662114
# statistic = 2.593902628730896 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 1.208896455640957
# relative_error_metric = 0.7309266670824761
#
# ------------ 13 ------------
# eps = 0.020192103693261743
# statistic = 1.807455216423362 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.8662498086709796
# relative_error_metric = 0.39965943473985743
#
# ------------ 14 ------------
# eps = 0.014089563046582043
# statistic = 1.4319432714645228 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.5528518584971215
# relative_error_metric = 0.17179849050780838
#
# ------------ 15 ------------
# eps = 0.011038292723242193
# statistic = 1.2519104606576767 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.3207589786124426
# relative_error_metric = 0.03785669796747719
#
# ------------ 16 ------------
# eps = 0.009512657561572269
# statistic = 1.1659897560126495 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.1484734419115645
# relative_error_metric = 0.03323617068019029
#
# ------------ 17 ------------
# eps = 0.010275475142407231
# statistic = 1.2085734985167205 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.07709849051917422
# relative_error_metric = 0.0026312027592548352
#
# ------------ 18 ------------
# eps = 0.00989406635198975
# statistic = 1.1870737416437056 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.03782027375520015
# relative_error_metric = 0.01531799539327946
#
# ------------ 19 ------------
# eps = 0.01008477074719849
# statistic = 1.1977800645804604 - next threshold = 1.2053976747108415 at 0.99 CL
# relative_error_eps = 0.018733014939284077
# relative_error_metric = 0.006339614424547332
#
# ------------ 20 ------------
# eps = 0.01018012294480286
# statistic = 1.2030391907348854 - next threshold = 1.2053976747108415 at 0.99 CL
# ...
# eps = 0.006389617919921875
# statistic = 0.38403317152383315 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.014814814814814815
# relative_error_metric = 0.00025194889946400685
#
# ------------ 20 ------------
# eps = 0.0064373016357421875
# statistic = 0.38542891790327 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.007434944237918215
# relative_error_metric = 0.0033759015051366623
# =======> statistic within required accuracy at 0.95 CL in 83.6021390769165 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.006413459777832031
# statistic = 0.3847304742243072 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.999486989021279
# relative_error_metric = 0.15953531819077535
#
# ------------ 2 ------------
# eps = 25.003206729888916
# statistic = 623.2034291902206 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9989742411553324
# relative_error_metric = 1.997104623183241
#
# ------------ 3 ------------
# eps = 12.504810094833374
# statistic = 320.3520865738404 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9979495339525069
# relative_error_metric = 1.9943712717270023
#
# ------------ 4 ------------
# eps = 6.255611777305603
# statistic = 167.13798263074906 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9959032680099391
# relative_error_metric = 1.9892253585662067
#
# ------------ 5 ------------
# eps = 3.1310126185417175
# statistic = 88.8306324560661 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.991823284924989
# relative_error_metric = 1.9797751553962453
#
# ------------ 6 ------------
# eps = 1.5687130391597748
# statistic = 48.371921144980696 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.983713156290221
# relative_error_metric = 1.9630153233186047
#
# ------------ 7 ------------
# eps = 0.7875632494688034
# statistic = 26.73866535781556 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9676894311727735
# relative_error_metric = 1.9335892035830675
#
# ------------ 8 ------------
# eps = 0.3969883546233177
# statistic = 14.309050125297768 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9364062376630327
# relative_error_metric = 1.877665500681155
#
# ------------ 9 ------------
# eps = 0.20170090720057487
# statistic = 7.6229024319694085 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.876732012864879
# relative_error_metric = 1.7763634248451803
#
# ------------ 10 ------------
# eps = 0.10405718348920345
# statistic = 4.073998885383669 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.7677768649421521
# relative_error_metric = 1.6009845075809408
#
# ------------ 11 ------------
# eps = 0.05523532163351774
# statistic = 2.2248062610423753 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.58387110784634
# relative_error_metric = 1.3252776110799036
#
# ------------ 12 ------------
# eps = 0.030824390705674887
# statistic = 1.2818169382632718 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.311081633922707
# relative_error_metric = 0.9581883185251101
#
# ------------ 13 ------------
# eps = 0.01861892524175346
# statistic = 0.8134078798976591 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.9751739959553832
# relative_error_metric = 0.5723725235945543
#
# ------------ 14 ------------
# eps = 0.012516192509792745
# statistic = 0.5876727729676283 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.6447802251444802
# relative_error_metric = 0.2622338407984524
#
# ------------ 15 ------------
# eps = 0.009464826143812388
# statistic = 0.4813450977631079 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.3843445547004415
# relative_error_metric = 0.06414445858193765
#
# ------------ 16 ------------
# eps = 0.00793914296082221
# statistic = 0.43140063291639014 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.17532588960800854
# relative_error_metric = 0.04537301842232903
#
# ------------ 17 ------------
# eps = 0.008701984552317299
# statistic = 0.4560259414338237 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.09168147902151035
# relative_error_metric = 0.010131604274104504
#
# ------------ 18 ------------
# eps = 0.008320563756569754
# statistic = 0.4436183248457819 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.04481359533559546
# relative_error_metric = 0.017452999003332678
#
# ------------ 19 ------------
# eps = 0.008511274154443527
# statistic = 0.4497989520888425 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.022158546632296564
# relative_error_metric = 0.0036172923232455625
#
# ------------ 20 ------------
# eps = 0.008606629353380413
# statistic = 0.45290683621280503 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.011140990354724566
# relative_error_metric = 0.0032684357850253152
#
# ------------ 21 ------------
# eps = 0.00855895175391197
# statistic = 0.45135144319932247 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.00555502306277163
# relative_error_metric = 0.00017171680662809207
# =======> statistic within required accuracy at 0.99 CL in 88.02601566491649 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 171.62818712112494 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_100K/exclusion_limits.json
# Computing exclusion limits for swd with mean_cov deformation.
#
# ======================================================
# =============== swd - mean + cov matrix ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 25.0
# statistic = 619.9666222260674 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9975231435499505
#
# ------------ 2 ------------
# eps = 12.5
# statistic = 316.5478636432528 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9951518944350728
#
# ------------ 3 ------------
# eps = 6.25
# statistic = 161.9018769632203 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9905320255817947
#
# ------------ 4 ------------
# eps = 3.125
# statistic = 82.5457173192653 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9814720536384842
#
# ------------ 5 ------------
# eps = 1.5625
# statistic = 42.23077832905957 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9639440790983451
#
# ------------ 6 ------------
# eps = 0.78125
# statistic = 21.695218533577897 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9304091892202278
#
# ------------ 7 ------------
# eps = 0.390625
# statistic = 11.105515315190313 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.866269173015372
#
# ------------ 8 ------------
# eps = 0.1953125
# statistic = 5.647253246725466 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7452458724453146
#
# ------------ 9 ------------
# eps = 0.09765625
# statistic = 2.863335942474837 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5268557647130083
#
# ------------ 10 ------------
# eps = 0.048828125
# statistic = 1.4620070485345753 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1677108627553727
#
# ------------ 11 ------------
# eps = 0.0244140625
# statistic = 0.7720481678227787 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6710354133125781
#
# ------------ 12 ------------
# eps = 0.01220703125
# statistic = 0.4518813372632835 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.16208249486657855
#
# ------------ 13 ------------
# eps = 0.006103515625
# statistic = 0.32429058071834993 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.16893739789524925
#
# ------------ 14 ------------
# eps = 0.0091552734375
# statistic = 0.3829655748645052 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.003035777322168362
#
# ------------ 15 ------------
# eps = 0.01068115234375
# statistic = 0.41642456419920554 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.08068063713968325
#
# ------------ 16 ------------
# eps = 0.009918212890625
# statistic = 0.399414157757338 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.03901303664504515
#
# ------------ 17 ------------
# eps = 0.0095367431640625
# statistic = 0.39111551002225015 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.018021568701458157
#
# ------------ 18 ------------
# eps = 0.00934600830078125
# statistic = 0.38702153617556945 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.020618556701030927
# relative_error_metric = 0.0074994234311975515
#
# ------------ 19 ------------
# eps = 0.009250640869140625
# statistic = 0.3849887602186437 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.010362694300518135
# relative_error_metric = 0.0022332567618746743
#
# ------------ 20 ------------
# eps = 0.009202957153320312
# statistic = 0.3839759676853915 - next threshold = 0.38412994044916837 at 0.95 CL
# relative_error_eps = 0.00516795865633075
# relative_error_metric = 0.0004009154522735522
# =======> statistic within required accuracy at 0.95 CL in 83.7940015620552 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.009226799011230469
# statistic = 0.38448206486644704 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9992619922680819
# relative_error_metric = 0.16017707164210046
#
# ------------ 2 ------------
# eps = 25.004613399505615
# statistic = 620.078066070231 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9985245289906701
# relative_error_metric = 1.9970900403084637
#
# ------------ 3 ------------
# eps = 12.506920099258423
# statistic = 316.71724277407634 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9970512333911625
# relative_error_metric = 1.9943067648891986
#
# ------------ 4 ------------
# eps = 6.258073449134827
# statistic = 162.10473528062352 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9941111492056185
# relative_error_metric = 1.9888917419623677
#
# ------------ 5 ------------
# eps = 3.1336501240730286
# statistic = 82.76759504007882 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.98825687516624
# relative_error_metric = 1.9783016462912466
#
# ------------ 6 ------------
# eps = 1.5714384615421295
# statistic = 42.46329807223156 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9766508463455434
# relative_error_metric = 1.9579231666367778
#
# ------------ 7 ------------
# eps = 0.79033263027668
# statistic = 21.937710518991597 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.9538405843355615
# relative_error_metric = 1.9193485832686616
#
# ------------ 8 ------------
# eps = 0.39977971464395523
# statistic = 11.358153713898341 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.909763793942811
# relative_error_metric = 1.8470974065183652
#
# ------------ 9 ------------
# eps = 0.20450325682759285
# statistic = 5.907302453084186 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.8273186431357409
# relative_error_metric = 1.7160257758674298
#
# ------------ 10 ------------
# eps = 0.10686502791941166
# statistic = 3.1273703789559923 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.682086181079985
# relative_error_metric = 1.4954408868193896
#
# ------------ 11 ------------
# eps = 0.058045913465321064
# statistic = 1.7260633655596163 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.4513793975858162
# relative_error_metric = 1.1707360796128734
#
# ------------ 12 ------------
# eps = 0.033636356238275766
# statistic = 1.0298628236373693 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 1.1389528878570592
# relative_error_metric = 0.7809857284006732
#
# ------------ 13 ------------
# eps = 0.021431577624753118
# statistic = 0.6903690932031729 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.7961790513851252
# relative_error_metric = 0.4185331008484529
#
# ------------ 14 ------------
# eps = 0.015329188317991793
# statistic = 0.5289523202720104 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.49701844401094986
# relative_error_metric = 0.15814942162902332
#
# ------------ 15 ------------
# eps = 0.012277993664611131
# statistic = 0.453571840221107 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.2837688044124566
# relative_error_metric = 0.0047356549316565485
#
# ------------ 16 ------------
# eps = 0.0107523963379208
# statistic = 0.4180391500489401 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.13248558331166854
# relative_error_metric = 0.07680512777832729
#
# ------------ 17 ------------
# eps = 0.011515195001265965
# statistic = 0.43558544804815624 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.06411907828387291
# relative_error_metric = 0.03572322250788101
#
# ------------ 18 ------------
# eps = 0.011896594332938548
# statistic = 0.4445264761855179 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.03155373996125528
# relative_error_metric = 0.015408084065395886
#
# ------------ 19 ------------
# eps = 0.01208729399877484
# statistic = 0.4490365981419461 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.015653389237251503
# relative_error_metric = 0.005313598802066657
#
# ------------ 20 ------------
# eps = 0.012182643831692985
# statistic = 0.4513011442856369 - next threshold = 0.4514289544828107 at 0.99 CL
# relative_error_eps = 0.007796185437321705
# relative_error_metric = 0.00028316369942278153
# =======> statistic within required accuracy at 0.99 CL in 83.87708946387284 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 167.67112308507785 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_100K/exclusion_limits.json
# dict_keys(['2024-04-17T07:24:43.051423', '2024-04-17T07:26:26.930200', '2024-04-17T07:28:23.507793', '2024-04-17T07:30:27.206645', '2024-04-17T07:31:52.972621', '2024-04-17T07:33:52.427533', '2024-04-17T07:35:58.700775', '2024-04-17T07:37:47.344442', '2024-04-17T07:40:58.009294', '2024-04-17T07:44:28.924656', '2024-04-17T07:48:10.145713', '2024-04-17T07:51:25.267259', '2024-04-17T07:55:00.831464', '2024-04-17T07:58:47.601342', '2024-04-17T08:02:10.617212', '2024-04-17T08:12:14.433601', '2024-04-17T08:19:28.505098', '2024-04-17T08:26:39.904285', '2024-04-17T08:34:16.641518', '2024-04-17T08:44:21.115412', '2024-04-17T08:54:21.955845', '2024-04-17T09:04:31.865536', '2024-04-17T09:07:13.365923', '2024-04-17T09:09:45.243311', '2024-04-17T09:12:17.898937', '2024-04-17T09:14:49.981533', '2024-04-17T09:17:33.409472', '2024-04-17T09:20:18.820640', '2024-04-17T09:24:27.868529', '2024-04-17T09:28:25.733393', '2024-04-17T09:32:25.389860', '2024-04-17T09:36:36.543259', '2024-04-17T09:40:30.722019', '2024-04-17T09:44:45.986668', '2024-04-17T09:49:09.584793', '2024-04-17T09:53:20.744196', '2024-04-17T09:56:01.535383', '2024-04-17T09:58:39.962660', '2024-04-17T10:01:23.832821', '2024-04-17T10:03:59.440302', '2024-04-17T10:06:43.937468', '2024-04-17T10:09:35.577796'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "std", "off", "cov", "mean_std", "mean_off", "mean_cov"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 0.005
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# LR metric calculation completed in 86.61310449708253 seconds.
# Saving lr to results_leonardo/20D_unimodal/20D_100K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -36.38336773203409], [0.99, [9900, 100], -28.06044080917077]]
# Null distribution computed in 86.98202361282893 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.5131606010254472 seconds.
# statistic = 62.88973018572312 - next threshold = -36.38336773203409 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 7.490510860643639
#
# ------------ 2 ------------
# eps = 0.0025
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# LR metric calculation completed in 86.52805095585063 seconds.
# Saving lr to results_leonardo/20D_unimodal/20D_100K/null_hypothesis/LR_mean_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -3.7678940863164954], [0.99, [9900, 100], 0.3802627039439431]]
# Null distribution computed in 86.90963871288113 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.2869282751344144 seconds.
# statistic = 17.023885105223957 - next threshold = -3.7678940863164954 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 3.13696337933308
#
# ------------ 3 ------------
# eps = 0.00125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# LR metric calculation completed in 86.65541051095352 seconds.
# Saving lr to results_leonardo/20D_unimodal/20D_100K/null_hypothesis/LR_mean_0.001250.json
# ThresholdS: [[0.95, [9500, 500], 1.7196292417604755], [0.99, [9900, 100], 3.789839533477445]]
# Null distribution computed in 87.01354552898556 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.3153189739678055 seconds.
# statistic = 4.906578619041225 - next threshold = 1.7196292417604755 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9619225488332817
#
# ------------ 4 ------------
# eps = 0.000625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# LR metric calculation completed in 86.70775798102841 seconds.
# Saving lr to results_leonardo/20D_unimodal/20D_100K/null_hypothesis/LR_mean_0.000625.json
# ThresholdS: [[0.95, [9500, 500], 1.7606351958263318], [0.99, [9900, 100], 2.794772782245816]]
# Null distribution computed in 87.06686497409828 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.3855743971653283 seconds.
# statistic = 1.5519335261015494 - next threshold = 1.7606351958263318 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.12600594115573252
#
# ------------ 5 ------------
# eps = 0.0009375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# ...
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# LR metric calculation completed in 85.48704072996043 seconds.
# Saving lr to results_leonardo/20D_unimodal/20D_100K/null_hypothesis/LR_mean_cov_0.001121.json
# ThresholdS: [[0.95, [9500, 500], 1.6214528608206793], [0.99, [9900, 100], 3.857564321471922]]
# Null distribution computed in 85.83926577307284 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.321467564906925 seconds.
# statistic = 3.8860889000818646 - next threshold = 3.857564321471922 at 0.99 CL
# relative_error_eps = 0.01619622431148893
# relative_error_metric = 0.007367214877481065
#
# ------------ 11 ------------
# eps = 0.0011119961738586428
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 100000
# nchunks = 200
# Iterating from 0 to 50 out of 10000 .
# Iterating from 50 to 100 out of 10000 .
# Iterating from 100 to 150 out of 10000 .
# Iterating from 150 to 200 out of 10000 .
# Iterating from 200 to 250 out of 10000 .
# Iterating from 250 to 300 out of 10000 .
# Iterating from 300 to 350 out of 10000 .
# Iterating from 350 to 400 out of 10000 .
# Iterating from 400 to 450 out of 10000 .
# Iterating from 450 to 500 out of 10000 .
# Iterating from 500 to 550 out of 10000 .
# Iterating from 550 to 600 out of 10000 .
# Iterating from 600 to 650 out of 10000 .
# Iterating from 650 to 700 out of 10000 .
# Iterating from 700 to 750 out of 10000 .
# Iterating from 750 to 800 out of 10000 .
# Iterating from 800 to 850 out of 10000 .
# Iterating from 850 to 900 out of 10000 .
# Iterating from 900 to 950 out of 10000 .
# Iterating from 950 to 1000 out of 10000 .
# Iterating from 1000 to 1050 out of 10000 .
# Iterating from 1050 to 1100 out of 10000 .
# Iterating from 1100 to 1150 out of 10000 .
# Iterating from 1150 to 1200 out of 10000 .
# Iterating from 1200 to 1250 out of 10000 .
# Iterating from 1250 to 1300 out of 10000 .
# Iterating from 1300 to 1350 out of 10000 .
# Iterating from 1350 to 1400 out of 10000 .
# Iterating from 1400 to 1450 out of 10000 .
# Iterating from 1450 to 1500 out of 10000 .
# Iterating from 1500 to 1550 out of 10000 .
# Iterating from 1550 to 1600 out of 10000 .
# Iterating from 1600 to 1650 out of 10000 .
# Iterating from 1650 to 1700 out of 10000 .
# Iterating from 1700 to 1750 out of 10000 .
# Iterating from 1750 to 1800 out of 10000 .
# Iterating from 1800 to 1850 out of 10000 .
# Iterating from 1850 to 1900 out of 10000 .
# Iterating from 1900 to 1950 out of 10000 .
# Iterating from 1950 to 2000 out of 10000 .
# Iterating from 2000 to 2050 out of 10000 .
# Iterating from 2050 to 2100 out of 10000 .
# Iterating from 2100 to 2150 out of 10000 .
# Iterating from 2150 to 2200 out of 10000 .
# Iterating from 2200 to 2250 out of 10000 .
# Iterating from 2250 to 2300 out of 10000 .
# Iterating from 2300 to 2350 out of 10000 .
# Iterating from 2350 to 2400 out of 10000 .
# Iterating from 2400 to 2450 out of 10000 .
# Iterating from 2450 to 2500 out of 10000 .
# Iterating from 2500 to 2550 out of 10000 .
# Iterating from 2550 to 2600 out of 10000 .
# Iterating from 2600 to 2650 out of 10000 .
# Iterating from 2650 to 2700 out of 10000 .
# Iterating from 2700 to 2750 out of 10000 .
# Iterating from 2750 to 2800 out of 10000 .
# Iterating from 2800 to 2850 out of 10000 .
# Iterating from 2850 to 2900 out of 10000 .
# Iterating from 2900 to 2950 out of 10000 .
# Iterating from 2950 to 3000 out of 10000 .
# Iterating from 3000 to 3050 out of 10000 .
# Iterating from 3050 to 3100 out of 10000 .
# Iterating from 3100 to 3150 out of 10000 .
# Iterating from 3150 to 3200 out of 10000 .
# Iterating from 3200 to 3250 out of 10000 .
# Iterating from 3250 to 3300 out of 10000 .
# Iterating from 3300 to 3350 out of 10000 .
# Iterating from 3350 to 3400 out of 10000 .
# Iterating from 3400 to 3450 out of 10000 .
# Iterating from 3450 to 3500 out of 10000 .
# Iterating from 3500 to 3550 out of 10000 .
# Iterating from 3550 to 3600 out of 10000 .
# Iterating from 3600 to 3650 out of 10000 .
# Iterating from 3650 to 3700 out of 10000 .
# Iterating from 3700 to 3750 out of 10000 .
# Iterating from 3750 to 3800 out of 10000 .
# Iterating from 3800 to 3850 out of 10000 .
# Iterating from 3850 to 3900 out of 10000 .
# Iterating from 3900 to 3950 out of 10000 .
# Iterating from 3950 to 4000 out of 10000 .
# Iterating from 4000 to 4050 out of 10000 .
# Iterating from 4050 to 4100 out of 10000 .
# Iterating from 4100 to 4150 out of 10000 .
# Iterating from 4150 to 4200 out of 10000 .
# Iterating from 4200 to 4250 out of 10000 .
# Iterating from 4250 to 4300 out of 10000 .
# Iterating from 4300 to 4350 out of 10000 .
# Iterating from 4350 to 4400 out of 10000 .
# Iterating from 4400 to 4450 out of 10000 .
# Iterating from 4450 to 4500 out of 10000 .
# Iterating from 4500 to 4550 out of 10000 .
# Iterating from 4550 to 4600 out of 10000 .
# Iterating from 4600 to 4650 out of 10000 .
# Iterating from 4650 to 4700 out of 10000 .
# Iterating from 4700 to 4750 out of 10000 .
# Iterating from 4750 to 4800 out of 10000 .
# Iterating from 4800 to 4850 out of 10000 .
# Iterating from 4850 to 4900 out of 10000 .
# Iterating from 4900 to 4950 out of 10000 .
# Iterating from 4950 to 5000 out of 10000 .
# Iterating from 5000 to 5050 out of 10000 .
# Iterating from 5050 to 5100 out of 10000 .
# Iterating from 5100 to 5150 out of 10000 .
# Iterating from 5150 to 5200 out of 10000 .
# Iterating from 5200 to 5250 out of 10000 .
# Iterating from 5250 to 5300 out of 10000 .
# Iterating from 5300 to 5350 out of 10000 .
# Iterating from 5350 to 5400 out of 10000 .
# Iterating from 5400 to 5450 out of 10000 .
# Iterating from 5450 to 5500 out of 10000 .
# Iterating from 5500 to 5550 out of 10000 .
# Iterating from 5550 to 5600 out of 10000 .
# Iterating from 5600 to 5650 out of 10000 .
# Iterating from 5650 to 5700 out of 10000 .
# Iterating from 5700 to 5750 out of 10000 .
# Iterating from 5750 to 5800 out of 10000 .
# Iterating from 5800 to 5850 out of 10000 .
# Iterating from 5850 to 5900 out of 10000 .
# Iterating from 5900 to 5950 out of 10000 .
# Iterating from 5950 to 6000 out of 10000 .
# Iterating from 6000 to 6050 out of 10000 .
# Iterating from 6050 to 6100 out of 10000 .
# Iterating from 6100 to 6150 out of 10000 .
# Iterating from 6150 to 6200 out of 10000 .
# Iterating from 6200 to 6250 out of 10000 .
# Iterating from 6250 to 6300 out of 10000 .
# Iterating from 6300 to 6350 out of 10000 .
# Iterating from 6350 to 6400 out of 10000 .
# Iterating from 6400 to 6450 out of 10000 .
# Iterating from 6450 to 6500 out of 10000 .
# Iterating from 6500 to 6550 out of 10000 .
# Iterating from 6550 to 6600 out of 10000 .
# Iterating from 6600 to 6650 out of 10000 .
# Iterating from 6650 to 6700 out of 10000 .
# Iterating from 6700 to 6750 out of 10000 .
# Iterating from 6750 to 6800 out of 10000 .
# Iterating from 6800 to 6850 out of 10000 .
# Iterating from 6850 to 6900 out of 10000 .
# Iterating from 6900 to 6950 out of 10000 .
# Iterating from 6950 to 7000 out of 10000 .
# Iterating from 7000 to 7050 out of 10000 .
# Iterating from 7050 to 7100 out of 10000 .
# Iterating from 7100 to 7150 out of 10000 .
# Iterating from 7150 to 7200 out of 10000 .
# Iterating from 7200 to 7250 out of 10000 .
# Iterating from 7250 to 7300 out of 10000 .
# Iterating from 7300 to 7350 out of 10000 .
# Iterating from 7350 to 7400 out of 10000 .
# Iterating from 7400 to 7450 out of 10000 .
# Iterating from 7450 to 7500 out of 10000 .
# Iterating from 7500 to 7550 out of 10000 .
# Iterating from 7550 to 7600 out of 10000 .
# Iterating from 7600 to 7650 out of 10000 .
# Iterating from 7650 to 7700 out of 10000 .
# Iterating from 7700 to 7750 out of 10000 .
# Iterating from 7750 to 7800 out of 10000 .
# Iterating from 7800 to 7850 out of 10000 .
# Iterating from 7850 to 7900 out of 10000 .
# Iterating from 7900 to 7950 out of 10000 .
# Iterating from 7950 to 8000 out of 10000 .
# Iterating from 8000 to 8050 out of 10000 .
# Iterating from 8050 to 8100 out of 10000 .
# Iterating from 8100 to 8150 out of 10000 .
# Iterating from 8150 to 8200 out of 10000 .
# Iterating from 8200 to 8250 out of 10000 .
# Iterating from 8250 to 8300 out of 10000 .
# Iterating from 8300 to 8350 out of 10000 .
# Iterating from 8350 to 8400 out of 10000 .
# Iterating from 8400 to 8450 out of 10000 .
# Iterating from 8450 to 8500 out of 10000 .
# Iterating from 8500 to 8550 out of 10000 .
# Iterating from 8550 to 8600 out of 10000 .
# Iterating from 8600 to 8650 out of 10000 .
# Iterating from 8650 to 8700 out of 10000 .
# Iterating from 8700 to 8750 out of 10000 .
# Iterating from 8750 to 8800 out of 10000 .
# Iterating from 8800 to 8850 out of 10000 .
# Iterating from 8850 to 8900 out of 10000 .
# Iterating from 8900 to 8950 out of 10000 .
# Iterating from 8950 to 9000 out of 10000 .
# Iterating from 9000 to 9050 out of 10000 .
# Iterating from 9050 to 9100 out of 10000 .
# Iterating from 9100 to 9150 out of 10000 .
# Iterating from 9150 to 9200 out of 10000 .
# Iterating from 9200 to 9250 out of 10000 .
# Iterating from 9250 to 9300 out of 10000 .
# Iterating from 9300 to 9350 out of 10000 .
# Iterating from 9350 to 9400 out of 10000 .
# Iterating from 9400 to 9450 out of 10000 .
# Iterating from 9450 to 9500 out of 10000 .
# Iterating from 9500 to 9550 out of 10000 .
# Iterating from 9550 to 9600 out of 10000 .
# Iterating from 9600 to 9650 out of 10000 .
# Iterating from 9650 to 9700 out of 10000 .
# Iterating from 9700 to 9750 out of 10000 .
# Iterating from 9750 to 9800 out of 10000 .
# Iterating from 9800 to 9850 out of 10000 .
# Iterating from 9850 to 9900 out of 10000 .
# Iterating from 9900 to 9950 out of 10000 .
# Iterating from 9950 to 10000 out of 10000 .
# LR metric calculation completed in 85.4155526929535 seconds.
# Saving lr to results_leonardo/20D_unimodal/20D_100K/null_hypothesis/LR_mean_cov_0.001112.json
# ThresholdS: [[0.95, [9500, 500], 1.6380376424169936], [0.99, [9900, 100], 3.8562391722004508]]
# Null distribution computed in 85.78091789898463 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 100000
# LR metric calculation completed in 3.334416339872405 seconds.
# statistic = 3.8252190331188993 - next threshold = 3.8562391722004508 at 0.99 CL
# relative_error_eps = 0.008065454677461788
# relative_error_metric = 0.00807662770594006
# =======> statistic within required accuracy at 0.99 CL in 982.316896620905 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1964.916869748151 seconds.
# Saving results in the file results_leonardo/20D_unimodal/20D_100K/exclusion_limits.json
# dict_keys(['2024-04-17T07:24:43.051423', '2024-04-17T07:26:26.930200', '2024-04-17T07:28:23.507793', '2024-04-17T07:30:27.206645', '2024-04-17T07:31:52.972621', '2024-04-17T07:33:52.427533', '2024-04-17T07:35:58.700775', '2024-04-17T07:37:47.344442', '2024-04-17T07:40:58.009294', '2024-04-17T07:44:28.924656', '2024-04-17T07:48:10.145713', '2024-04-17T07:51:25.267259', '2024-04-17T07:55:00.831464', '2024-04-17T07:58:47.601342', '2024-04-17T08:02:10.617212', '2024-04-17T08:12:14.433601', '2024-04-17T08:19:28.505098', '2024-04-17T08:26:39.904285', '2024-04-17T08:34:16.641518', '2024-04-17T08:44:21.115412', '2024-04-17T08:54:21.955845', '2024-04-17T09:04:31.865536', '2024-04-17T09:07:13.365923', '2024-04-17T09:09:45.243311', '2024-04-17T09:12:17.898937', '2024-04-17T09:14:49.981533', '2024-04-17T09:17:33.409472', '2024-04-17T09:20:18.820640', '2024-04-17T09:24:27.868529', '2024-04-17T09:28:25.733393', '2024-04-17T09:32:25.389860', '2024-04-17T09:36:36.543259', '2024-04-17T09:40:30.722019', '2024-04-17T09:44:45.986668', '2024-04-17T09:49:09.584793', '2024-04-17T09:53:20.744196', '2024-04-17T09:56:01.535383', '2024-04-17T09:58:39.962660', '2024-04-17T10:01:23.832821', '2024-04-17T10:03:59.440302', '2024-04-17T10:06:43.937468', '2024-04-17T10:09:35.577796', '2024-04-17T10:12:23.277854', '2024-04-17T10:45:29.788936', '2024-04-17T11:30:47.376725', '2024-04-17T12:19:00.892799', '2024-04-17T12:50:30.942091', '2024-04-17T13:35:18.760837', '2024-04-17T14:25:56.647773'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_std = results_df[results_df["Deformation"] == "std"]
results_df_off = results_df[results_df["Deformation"] == "off"]
results_df_cov = results_df[results_df["Deformation"] == "cov"]
results_df_mean_std = results_df[results_df["Deformation"] == "mean_std"]
results_df_mean_off = results_df[results_df["Deformation"] == "mean_off"]
results_df_mean_cov = results_df[results_df["Deformation"] == "mean_cov"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 42        lr        mean   20  10000               100000
# 35       swd        mean   20  10000               100000
# 7        fpd        mean   20  10000               100000
# 28       sks        mean   20  10000               100000
# 21        ks        mean   20  10000               100000
# 0         fn        mean   20  10000               100000
# 14       kpd        mean   20  10000               100000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 42                             0.00070                             0.00105
# 35                             0.01044                             0.01411
# 7                              0.01111                             0.01421
# 28                             0.01111                             0.01459
# 21                             0.01178                             0.01564
# 0                              0.02794                             0.03623
# 14                             0.34943                             0.35700
#
#     $t^{\mu}$ (s)
# 42           1986
# 35            160
# 7             190
# 28            237
# 21            161
# 0             103
# 14            603
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 42        lr                             0.00070
# 35       swd                             0.01044
# 7        fpd                             0.01111
# 28       sks                             0.01111
# 21        ks                             0.01178
# 0         fn                             0.02794
# 14       kpd                             0.34943
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 42                             0.00105           1986
# 35                             0.01411            160
# 7                              0.01421            190
# 28                             0.01459            237
# 21                             0.01564            161
# 0                              0.03623            103
# 14                             0.35700            603

# %%
sorted_df_std = results_df_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma}$ (s)"}, inplace=True)
display(sorted_df_std)
sorted_df_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 43        lr         std   20  10000               100000
# 8        fpd         std   20  10000               100000
# 1         fn         std   20  10000               100000
# 36       swd         std   20  10000               100000
# 29       sks         std   20  10000               100000
# 22        ks         std   20  10000               100000
# 15       kpd         std   20  10000               100000
#
#     $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 43                                0.00008
# 8                                 0.00368
# 1                                 0.00656
# 36                                0.01264
# 29                                0.01311
# 22                                0.02375
# 15                                5.68848
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 43                                0.00011              2717
# 8                                 0.00465               210
# 1                                 0.00863               116
# 36                                0.01669               158
# 29                                0.01697               239
# 22                                0.02994               151
# 15                                5.79666               434
#    Statistic  $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 43        lr                                0.00008
# 8        fpd                                0.00368
# 1         fn                                0.00656
# 36       swd                                0.01264
# 29       sks                                0.01311
# 22        ks                                0.02375
# 15       kpd                                5.68848
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 43                                0.00011              2717
# 8                                 0.00465               210
# 1                                 0.00863               116
# 36                                0.01669               158
# 29                                0.01697               239
# 22                                0.02994               151
# 15                                5.79666               434

# %%
sorted_df_off = results_df_off.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_off.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}-\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}-\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ij}-\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_off)
sorted_df_off.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_off)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 44        lr         off   20  10000               100000
# 9        fpd         off   20  10000               100000
# 2         fn         off   20  10000               100000
# 30       sks         off   20  10000               100000
# 37       swd         off   20  10000               100000
# 23        ks         off   20  10000               100000
# 16       kpd         off   20  10000               100000
#
#     $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 44                                            0.00004
# 9                                             0.00187
# 2                                             0.00325
# 30                                            0.00865
# 37                                            0.00880
# 23                                            0.02375
# 16                                            5.49316
#
#     $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 44                                            0.00005
# 9                                             0.00236
# 2                                             0.00427
# 30                                            0.01137
# 37                                            0.01199
# 23                                            0.02994
# 16                                            5.60182
#
#     $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 44                               2893
# 9                                 221
# 2                                 123
# 30                                251
# 37                                163
# 23                                152
# 16                                431
#    Statistic  $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 44        lr                                            0.00004
# 9        fpd                                            0.00187
# 2         fn                                            0.00325
# 30       sks                                            0.00865
# 37       swd                                            0.00880
# 23        ks                                            0.02375
# 16       kpd                                            5.49316
#
#     $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 44                                            0.00005
# 9                                             0.00236
# 2                                             0.00427
# 30                                            0.01137
# 37                                            0.01199
# 23                                            0.02994
# 16                                            5.60182
#
#     $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 44                               2893
# 9                                 221
# 2                                 123
# 30                                251
# 37                                163
# 23                                152
# 16                                431

# %%
sorted_df_cov = results_df_cov.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_cov.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ij}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ij}}$ (s)"}, inplace=True)
display(sorted_df_cov)
sorted_df_cov.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_cov)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 45        lr         cov   20  10000               100000
# 10       fpd         cov   20  10000               100000
# 38       swd         cov   20  10000               100000
# 31       sks         cov   20  10000               100000
# 24        ks         cov   20  10000               100000
# 3         fn         cov   20  10000               100000
# 17       kpd         cov   20  10000               100000
#
#     $\epsilon^{\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 45                                     0.00227
# 10                                     0.01512
# 38                                     0.01721
# 31                                     0.02222
# 24                                     0.02337
# 3                                      0.25253
# 17                                     4.33350
#
#     $\epsilon^{\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ij}}$ (s)
# 45                                     0.00297                   1890
# 10                                     0.01888                    195
# 38                                     0.02189                    155
# 31                                     0.02784                    234
# 24                                     0.02956                    152
# 3                                      0.32692                     85
# 17                                     4.48958                    456
#    Statistic  $\epsilon^{\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 45        lr                                     0.00227
# 10       fpd                                     0.01512
# 38       swd                                     0.01721
# 31       sks                                     0.02222
# 24        ks                                     0.02337
# 3         fn                                     0.25253
# 17       kpd                                     4.33350
#
#     $\epsilon^{\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ij}}$ (s)
# 45                                     0.00297                   1890
# 10                                     0.01888                    195
# 38                                     0.02189                    155
# 31                                     0.02784                    234
# 24                                     0.02956                    152
# 3                                      0.32692                     85
# 17                                     4.48958                    456

# %%
sorted_df_mean_std = results_df_mean_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\sigma}$ (s)"}, inplace=True)
display(sorted_df_mean_std)
sorted_df_mean_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 46        lr    mean_std   20  10000               100000
# 11       fpd    mean_std   20  10000               100000
# 4         fn    mean_std   20  10000               100000
# 39       swd    mean_std   20  10000               100000
# 32       sks    mean_std   20  10000               100000
# 25        ks    mean_std   20  10000               100000
# 18       kpd    mean_std   20  10000               100000
#
#     $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 46                                    0.00008
# 11                                    0.00340
# 4                                     0.00660
# 39                                    0.00789
# 32                                    0.00799
# 25                                    0.01044
# 18                                    0.34637
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 46                                    0.00011                  2687
# 11                                    0.00432                   215
# 4                                     0.00868                   119
# 39                                    0.01042                   164
# 32                                    0.01023                   255
# 25                                    0.01345                   163
# 18                                    0.35395                   604
#    Statistic  $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 46        lr                                    0.00008
# 11       fpd                                    0.00340
# 4         fn                                    0.00660
# 39       swd                                    0.00789
# 32       sks                                    0.00799
# 25        ks                                    0.01044
# 18       kpd                                    0.34637
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 46                                    0.00011                  2687
# 11                                    0.00432                   215
# 4                                     0.00868                   119
# 39                                    0.01042                   164
# 32                                    0.01023                   255
# 25                                    0.01345                   163
# 18                                    0.35395                   604

# %%
sorted_df_mean_off = results_df_mean_off.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean_off.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\Sigma_{ij}-\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_mean_off)
sorted_df_mean_off.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean_off)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 47        lr    mean_off   20  10000               100000
# 12       fpd    mean_off   20  10000               100000
# 5         fn    mean_off   20  10000               100000
# 33       sks    mean_off   20  10000               100000
# 40       swd    mean_off   20  10000               100000
# 26        ks    mean_off   20  10000               100000
# 19       kpd    mean_off   20  10000               100000
#
#     $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 47                                            0.00004
# 12                                            0.00181
# 5                                             0.00328
# 33                                            0.00622
# 40                                            0.00641
# 26                                            0.01044
# 19                                            0.35858
#
#     $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 47                                            0.00005
# 12                                            0.00230
# 5                                             0.00432
# 33                                            0.00806
# 40                                            0.00858
# 26                                            0.01354
# 19                                            0.36616
#
#     $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 47                                   3037
# 12                                    226
# 5                                     126
# 33                                    263
# 40                                    171
# 26                                    165
# 19                                    600
#    Statistic  $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 47        lr                                            0.00004
# 12       fpd                                            0.00181
# 5         fn                                            0.00328
# 33       sks                                            0.00622
# 40       swd                                            0.00641
# 26        ks                                            0.01044
# 19       kpd                                            0.35858
#
#     $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 47                                            0.00005
# 12                                            0.00230
# 5                                             0.00432
# 33                                            0.00806
# 40                                            0.00858
# 26                                            0.01354
# 19                                            0.36616
#
#     $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s)
# 47                                   3037
# 12                                    226
# 5                                     126
# 33                                    263
# 40                                    171
# 26                                    165
# 19                                    600

# %%
sorted_df_mean_cov = results_df_mean_cov.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean_cov.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\Sigma_{ij}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\Sigma_{ij}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\Sigma_{ij}}$ (s)"}, inplace=True)
display(sorted_df_mean_cov)
sorted_df_mean_cov.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean_cov)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 48        lr    mean_cov   20  10000               100000
# 13       fpd    mean_cov   20  10000               100000
# 41       swd    mean_cov   20  10000               100000
# 34       sks    mean_cov   20  10000               100000
# 27        ks    mean_cov   20  10000               100000
# 6         fn    mean_cov   20  10000               100000
# 20       kpd    mean_cov   20  10000               100000
#
#     $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 48                                         0.00078
# 13                                         0.00885
# 41                                         0.00923
# 34                                         0.00997
# 27                                         0.01044
# 6                                          0.02756
# 20                                         0.33417
#
#     $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\mu-\Sigma_{ij}}$ (s)
# 48                                         0.00112                       1964
# 13                                         0.01128                        203
# 41                                         0.01223                        167
# 34                                         0.01278                        251
# 27                                         0.01335                        165
# 6                                          0.03566                        108
# 20                                         0.33871                        609
#    Statistic  $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 48        lr                                         0.00078
# 13       fpd                                         0.00885
# 41       swd                                         0.00923
# 34       sks                                         0.00997
# 27        ks                                         0.01044
# 6         fn                                         0.02756
# 20       kpd                                         0.33417
#
#     $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\mu-\Sigma_{ij}}$ (s)
# 48                                         0.00112                       1964
# 13                                         0.01128                        203
# 41                                         0.01223                        167
# 34                                         0.01278                        251
# 27                                         0.01335                        165
# 6                                          0.03566                        108
# 20                                         0.33871                        609

# %%
result_table = sorted_df_mean.merge(sorted_df_std, on='Statistic', how='outer').merge(sorted_df_off, on='Statistic', how='outer').merge(sorted_df_cov, on='Statistic', how='outer').merge(sorted_df_mean_std, on='Statistic', how='outer').merge(sorted_df_mean_off, on='Statistic', how='outer').merge(sorted_df_mean_cov, on='Statistic', how='outer').merge(times_df, on='Statistic', how='outer')
result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fpd","$d_{\\mathrm{FPD}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("kpd","$d_{\\mathrm{KPD}}$")
display(result_table)
print(result_table.to_latex(index=False, column_format='l|llr|llr|llr|llr|llr|llr|llr|r', longtable=False, float_format="%.2g"))
# Out:
#                     Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 0  $\overline{\|\cdot\|}_{F}$                             0.02794
# 1          $d_{\mathrm{FPD}}$                             0.01111
# 2          $d_{\mathrm{KPD}}$                             0.34943
# 3              $\overline{D}$                             0.01178
# 4          $t_{\mathrm{LLR}}$                             0.00070
# 5             $\widetilde{D}$                             0.01111
# 6             $\widetilde{W}$                             0.01044
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)  \
# 0                             0.03623            103
# 1                             0.01421            190
# 2                             0.35700            603
# 3                             0.01564            161
# 4                             0.00105           1986
# 5                             0.01459            237
# 6                             0.01411            160
#
#    $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 0                                0.00656
# 1                                0.00368
# 2                                5.68848
# 3                                0.02375
# 4                                0.00008
# 5                                0.01311
# 6                                0.01264
#
#    $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)  \
# 0                                0.00863               116
# 1                                0.00465               210
# 2                                5.79666               434
# 3                                0.02994               151
# 4                                0.00011              2717
# 5                                0.01697               239
# 6                                0.01669               158
#
#    $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 0                                            0.00325
# 1                                            0.00187
# 2                                            5.49316
# 3                                            0.02375
# 4                                            0.00004
# 5                                            0.00865
# 6                                            0.00880
#
#    $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 0                                            0.00427
# 1                                            0.00236
# 2                                            5.60182
# 3                                            0.02994
# 4                                            0.00005
# 5                                            0.01137
# 6                                            0.01199
#
#    $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s)  ...  \
# 0                                123  ...
# 1                                221  ...
# 2                                431  ...
# 3                                152  ...
# 4                               2893  ...
# 5                                251  ...
# 6                                163  ...
#
#    $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 0                                    0.00660
# 1                                    0.00340
# 2                                    0.34637
# 3                                    0.01044
# 4                                    0.00008
# 5                                    0.00799
# 6                                    0.00789
#
#    $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)  \
# 0                                    0.00868                   119
# 1                                    0.00432                   215
# 2                                    0.35395                   604
# 3                                    0.01345                   163
# 4                                    0.00011                  2687
# 5                                    0.01023                   255
# 6                                    0.01042                   164
#
#    $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 0                                            0.00328
# 1                                            0.00181
# 2                                            0.35858
# 3                                            0.01044
# 4                                            0.00004
# 5                                            0.00622
# 6                                            0.00641
#
#    $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$  \
# 0                                            0.00432
# 1                                            0.00230
# 2                                            0.36616
# 3                                            0.01354
# 4                                            0.00005
# 5                                            0.00806
# 6                                            0.00858
#
#    $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s)  \
# 0                                    126
# 1                                    226
# 2                                    600
# 3                                    165
# 4                                   3037
# 5                                    263
# 6                                    171
#
#    $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$  \
# 0                                         0.02756
# 1                                         0.00885
# 2                                         0.33417
# 3                                         0.01044
# 4                                         0.00078
# 5                                         0.00997
# 6                                         0.00923
#
#    $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$  $t^{\mu-\Sigma_{ij}}$ (s)  \
# 0                                         0.03566                        108
# 1                                         0.01128                        203
# 2                                         0.33871                        609
# 3                                         0.01335                        165
# 4                                         0.00112                       1964
# 5                                         0.01278                        251
# 6                                         0.01223                        167
#
#    $t^{\mathrm{null}}$ (s)
# 0                       25
# 1                      564
# 2                    29900
# 3                      206
# 4                        -
# 5                      650
# 6                      347
#
# [7 rows x 23 columns]
# \begin{tabular}{l|llr|llr|llr|llr|llr|llr|llr|r}
# \toprule
# Statistic & $\epsilon^{\mu}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu}_{99\%\mathrm{CL}}$ & $t^{\mu}$ (s) & $\epsilon^{\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\sigma}_{99\%\mathrm{CL}}$ & $t^{\sigma}$ (s) & $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$ & $\epsilon^{\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$ & $t^{\Sigma_{ij}-\Sigma_{ii}}$ (s) & $\epsilon^{\Sigma_{ij}}_{95\%\mathrm{CL}}$ & $\epsilon^{\Sigma_{ij}}_{99\%\mathrm{CL}}$ & $t^{\Sigma_{ij}}$ (s) & $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$ & $t^{\mu-\sigma}$ (s) & $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\Sigma_{ij}-\Sigma_{ii}}_{99\%\mathrm{CL}}$ & $t^{\mu-\Sigma_{ij}-\Sigma_{ii}}$ (s) & $\epsilon^{\mu-\Sigma_{ij}}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\Sigma_{ij}}_{99\%\mathrm{CL}}$ & $t^{\mu-\Sigma_{ij}}$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $\overline{\|\cdot\|}_{F}$ & 0.028 & 0.036 & 103 & 0.0066 & 0.0086 & 116 & 0.0032 & 0.0043 & 123 & 0.25 & 0.33 & 85 & 0.0066 & 0.0087 & 119 & 0.0033 & 0.0043 & 126 & 0.028 & 0.036 & 108 & 25 \\
# $d_{\mathrm{FPD}}$ & 0.011 & 0.014 & 190 & 0.0037 & 0.0046 & 210 & 0.0019 & 0.0024 & 221 & 0.015 & 0.019 & 195 & 0.0034 & 0.0043 & 215 & 0.0018 & 0.0023 & 226 & 0.0089 & 0.011 & 203 & 564 \\
# $d_{\mathrm{KPD}}$ & 0.35 & 0.36 & 603 & 5.7 & 5.8 & 434 & 5.5 & 5.6 & 431 & 4.3 & 4.5 & 456 & 0.35 & 0.35 & 604 & 0.36 & 0.37 & 600 & 0.33 & 0.34 & 609 & 29900 \\
# $\overline{D}$ & 0.012 & 0.016 & 161 & 0.024 & 0.03 & 151 & 0.024 & 0.03 & 152 & 0.023 & 0.03 & 152 & 0.01 & 0.013 & 163 & 0.01 & 0.014 & 165 & 0.01 & 0.013 & 165 & 206 \\
# $t_{\mathrm{LLR}}$ & 0.0007 & 0.001 & 1986 & 8e-05 & 0.00011 & 2717 & 4e-05 & 5e-05 & 2893 & 0.0023 & 0.003 & 1890 & 8e-05 & 0.00011 & 2687 & 4e-05 & 5e-05 & 3037 & 0.00078 & 0.0011 & 1964 & - \\
# $\widetilde{D}$ & 0.011 & 0.015 & 237 & 0.013 & 0.017 & 239 & 0.0086 & 0.011 & 251 & 0.022 & 0.028 & 234 & 0.008 & 0.01 & 255 & 0.0062 & 0.0081 & 263 & 0.01 & 0.013 & 251 & 650 \\
# $\widetilde{W}$ & 0.01 & 0.014 & 160 & 0.013 & 0.017 & 158 & 0.0088 & 0.012 & 163 & 0.017 & 0.022 & 155 & 0.0079 & 0.01 & 164 & 0.0064 & 0.0086 & 171 & 0.0092 & 0.012 & 167 & 347 \\
# \bottomrule
# \end{tabular}
