# %% [markdown]
# # Initialize

# %%
visible_devices = [0]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

sys.path.insert(0,'../utils_func/')
import MixtureDistributions # type: ignore

sys.path.insert(0,'../')
import GMetrics # type: ignore
from GMetrics.utils import se_mean, se_std, compute_exclusion_bisection, compute_exclusion_LR_bisection, save_update_metrics_config # type: ignore

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "../results_leonardo/"
if not os.path.exists(results_dir):
    print("WARNING: Results directory does not exist")
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-04-11 17:14:50.301121: Importing os...
# 2024-04-11 17:14:50.301422: Importing sys...
# Visible devices: [0]
# 2024-04-11 17:14:50.301664: Importing timer from timeit...
# 2024-04-11 17:14:50.301731: Setting env variables for tf import (only device(s) [0] will be available)...
# 2024-04-11 17:14:50.301860: Importing numpy...
# 2024-04-11 17:14:50.631696: Importing matplotlib...
# 2024-04-11 17:14:51.094794: Importing h5py...
# 2024-04-11 17:14:51.363386: Importing importlib.util...
# 2024-04-11 17:14:51.363508: Importing json...
# 2024-04-11 17:14:51.363569: Importing pandas...
# 2024-04-11 17:14:52.478761: Importing random...
# 2024-04-11 17:14:52.478900: Importing scipy utils...
# 2024-04-11 17:14:53.510421: Importing subprocess...
# 2024-04-11 17:14:53.510560: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-04-11 17:15:03.375730: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-04-11 17:15:04.938695: Importing timeit...
# 2024-04-11 17:15:04.938783: Importing tqdm...
# 2024-04-11 17:15:04.949644: Importing typing...
# 2024-04-11 17:15:04.949753: Setting tf configs...
# 2024-04-11 17:15:06.148323: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-04-11 17:15:15.341825: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #0, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-04-11 17:15:15.372469: All done.

# %% [markdown]
# # Fixed $n=50000$

# %% [markdown]
# ## Null hypotheses

# %% [markdown]
# ### Model definition

# %%
seed = 0
ncomp = 3
ndims = 5
niter = 10_000
batch_size_test = 50_000
eps_loc = 0.
eps_scale = 0.
dist_1 = MixtureDistributions.MixtureGaussian(ncomp, ndims, 0., 0., seed)
dist_2 = MixtureDistributions.MixtureGaussian(ncomp, ndims, eps_loc, eps_scale, seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mixture.Mixture'> <class 'tensorflow_probability.python.distributions.mixture.Mixture'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (5,) (5,)

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
metrics_config_file = model_dir + "metrics_config.json"
# Out:
# Model directory exists
# Null hypothesis directory exists

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10_000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = True,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# nsamples 500000000
# batch_size 50000
# niter 10000
# niter * batch_size 500000000
# small_sample False

# %%
FNMetric = GMetrics.FNMetric(TwoSampleTestInputs,
                             progress_bar = True,
                             verbose = True)
KSTest = GMetrics.KSTest(TwoSampleTestInputs,
                         progress_bar = True,
                         verbose = True)
SKSTest = GMetrics.SKSTest(TwoSampleTestInputs,
                           nslices = 100,
                           seed_slicing = 0,
                           progress_bar = True,
                           verbose = True)
SWDMetric = GMetrics.SWDMetric(TwoSampleTestInputs,
                               nslices = 100,
                               seed_slicing = 0,
                               progress_bar = True,
                               verbose = True)
FPDMetric = GMetrics.FPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               #min_samples_input = 20_000,
                               #max_samples_input = 50_000,
                               num_batches = 20)
KPDMetric = GMetrics.KPDMetric(TwoSampleTestInputs,
                               progress_bar = True,
                               verbose = True,
                               degree = 4,
                               block_size = 10_000,
                               num_batches = 1,
                               batch_size = 50_000)
LRMetric = GMetrics.LRMetric(TwoSampleTestInputs,
                             null_test=True,
                             verbose = True)
# Out:
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.
# To run under the alternative hypothesis, set the `null_test` attribute to False.

# %% [markdown]
# ### Set up tests and metrics configurations

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputs.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

test_config_null["ncomp"] = ncomp

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0  10000            50000           10000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  ...  ndims_1  nsamples_1  \
# 0     0    True            False     None     True  ...        5           0
#
#    is_symb_2  ndims_2  nsamples_2    dtype ndims   nsamples  small_sample  \
# 0       True        5           0  float64     5  500000000         False
#
#    ncomp
# 0      3
#
# [1 rows x 21 columns]

# %%
unique_key = "config_ndims_"+str(TwoSampleTestInputs.ndims)+"_ncop_"+str(ncomp)+"_nsamples_"+str(TwoSampleTestInputs.batch_size_test)+"_niter_"+str(TwoSampleTestInputs.niter)
metrics_config = {unique_key: {"fn": {"name": "fn", # type: ignore
                                      "object_name": "FNMetric",
                                      "class_name": "GMetrics.FNMetric",
                                      "kwargs": {},
                                      "result_key": "metric_list", 
                                      "scale_func": lambda ns, ndims: np.sqrt(ns)/ndims,
                                      "scale_func_string": "lambda ns, ndims: np.sqrt(ns)/ndims",
                                      "test_config": test_config_null,
                                      "max_vectorize": 1000, # optimized for 5D
                                      "latex": "$\overline{\|\cdot\|}_{F}$",
                                      "null_file": null_hypotheses_dir+"FN.json"},
                               "fpd": {"name": "fpd",
                                       "object_name": "FPDMetric",
                                       "class_name": "GMetrics.FPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#(ns/ndims)**(3/2),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 200, # optimized for 5D
                                       "latex": "$d_{\mathrm{FPD}}$",
                                       "null_file": null_hypotheses_dir+"FPD.json"},
                               "kpd": {"name": "kpd",
                                       "object_name": "KPDMetric" ,
                                       "class_name": "GMetrics.KPDMetric",
                                       "kwargs": {},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 10000,#ns/np.sqrt(ndims),
                                       "scale_func_string": "lambda ns, ndims: 10000",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1, # optimized for 5D
                                       "latex": "$d_{\mathrm{KPD}}$",
                                       "null_file": null_hypotheses_dir+"KPD.json"},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTest",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2000,
                                       "latex": "$\overline{D}$",
                                       "null_file": null_hypotheses_dir+"KS.json"},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTest",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": null_hypotheses_dir+"SKS.json"},
                               "swd": {"name": "swd",
                                       "object_name": "SWDMetric",
                                       "class_name": "GMetrics.SWDMetric", 
                                       "kwargs": {"nslices": 100, "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 100,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": null_hypotheses_dir+"SWD.json"},
                               "lr": {"name": "lr",
                                       "object_name": "LRMetric",
                                       "class_name": "GMetrics.LRMetric", 
                                       "kwargs": {"null_test": True},
                                       "result_key": "lik_ratio_norm_list", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 500,
                                       "latex": "$t_{\mu}$",
                                       "null_file": null_hypotheses_dir+"LR.json"}}}
metrics_config[unique_key]
# Out:
# {'fn': {'name': 'fn',
#   'object_name': 'FNMetric',
#   'class_name': 'GMetrics.FNMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)/ndims',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1000,
#   'latex': '$\\overline{\\|\\cdot\\|}_{F}$',
#   'null_file': '../results_leonardo/5D_50K/null_hypothesis/FN.json'},
#  'fpd': {'name': 'fpd',
#   'object_name': 'FPDMetric',
#   'class_name': 'GMetrics.FPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 200,
#   'latex': '$d_{\\mathrm{FPD}}$',
#   'null_file': '../results_leonardo/5D_50K/null_hypothesis/FPD.json'},
#  'kpd': {'name': 'kpd',
#   'object_name': 'KPDMetric',
#   'class_name': 'GMetrics.KPDMetric',
#   'kwargs': {},
#   'result_key': 'metric_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: 10000',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 1,
#   'latex': '$d_{\\mathrm{KPD}}$',
#   'null_file': '../results_leonardo/5D_50K/null_hypothesis/KPD.json'},
#  'ks': {'name': 'ks',
#   'object_name': 'KSTest',
#   'class_name': 'GMetrics.KSTest',
#   'kwargs': {},
#   'result_key': 'statistic_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 2000,
#   'latex': '$\\overline{D}$',
#   'null_file': '../results_leonardo/5D_50K/null_hypothesis/KS.json'},
#  'sks': {'name': 'sks',
#   'object_name': 'SKSTest',
#   'class_name': 'GMetrics.SKSTest',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, _)>,
#   'scale_func_string': 'lambda ns, _: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{D}$',
#   'null_file': '../results_leonardo/5D_50K/null_hypothesis/SKS.json'},
#  'swd': {'name': 'swd',
#   'object_name': 'SWDMetric',
#   'class_name': 'GMetrics.SWDMetric',
#   'kwargs': {'nslices': 100, 'seed_slicing': 0},
#   'result_key': 'metric_means',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns/ndims)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 100,
#   'latex': '$\\widetilde{W}$',
#   'null_file': '../results_leonardo/5D_50K/null_hypothesis/SWD.json'},
#  'lr': {'name': 'lr',
#   'object_name': 'LRMetric',
#   'class_name': 'GMetrics.LRMetric',
#   'kwargs': {'null_test': True},
#   'result_key': 'lik_ratio_norm_list',
#   'scale_func': <function __main__.<lambda>(ns, ndims)>,
#   'scale_func_string': 'lambda ns, ndims: np.sqrt(ns)',
#   'test_config': {'niter': 10000,
#    'batch_size_test': 50000,
#    'batch_size_gen': 10000,
#    'small_sample_threshold': 10000000,
#    'dtype_input': 'float64',
#    'seed': 0,
#    'use_tf': True,
#    'mirror_strategy': False,
#    'strategy': None,
#    'verbose': True,
#    'is_symb_1': True,
#    'ndims_1': 5,
#    'nsamples_1': 0,
#    'is_symb_2': True,
#    'ndims_2': 5,
#    'nsamples_2': 0,
#    'dtype': 'float64',
#    'ndims': 5,
#    'nsamples': 500000000,
#    'small_sample': False,
#    'ncomp': 3},
#   'max_vectorize': 500,
#   'latex': '$t_{\\mu}$',
#   'null_file': '../results_leonardo/5D_50K/null_hypothesis/LR.json'}}

# %% [markdown]
# ### Evaluate null hypotheses

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        obj.Test_tf(max_vectorize=max_vectorize)
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading fn from ../results_leonardo/5D_50K/null_hypothesis/FN.json
# Loading fpd from ../results_leonardo/5D_50K/null_hypothesis/FPD.json
# Computing and savng kpd with max_vectorize = 1
#
# ------------------------------------------
# Starting KPD metric calculation...
# Running TF KPD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 10000
# Iterating from 0 to 1 out of 10000 .
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712848522.167949 2598269 service.cc:145] XLA service 0xba40d210 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1712848522.168217 2598269 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# W0000 00:00:1712848522.247539 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1712848522.251328 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1712848522.252252 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1712848522.252565 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1712848522.253474 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1712848522.253545 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1712848522.253612 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1712848522.253681 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# W0000 00:00:1712848522.253746 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_17/Assert/Assert
# W0000 00:00:1712848522.253811 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_19/Assert/Assert
# W0000 00:00:1712848522.253876 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_21/Assert/Assert
# W0000 00:00:1712848522.253942 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_23/Assert/Assert
# W0000 00:00:1712848525.505582 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_1/Assert/Assert
# W0000 00:00:1712848525.506023 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_3/Assert/Assert
# W0000 00:00:1712848525.506121 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_5/Assert/Assert
# W0000 00:00:1712848525.506159 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_7/Assert/Assert
# W0000 00:00:1712848525.506252 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_9/Assert/Assert
# W0000 00:00:1712848525.506261 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_11/Assert/Assert
# W0000 00:00:1712848525.506268 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_13/Assert/Assert
# W0000 00:00:1712848525.506275 2598269 assert_op.cc:38] Ignoring Assert operator while/Mixture_CONSTRUCTED_AT_top_level/sample/assert_equal_15/Assert/Assert
# I0000 00:00:1712848533.508524 2598269 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# Iterating from 1 to 2 out of 10000 .
# Iterating from 2 to 3 out of 10000 .
# Iterating from 3 to 4 out of 10000 .
# Iterating from 4 to 5 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fa86010a200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 5 to 6 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7fa8925e1800> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 6 to 7 out of 10000 .
# Iterating from 7 to 8 out of 10000 .
# Iterating from 8 to 9 out of 10000 .
# Iterating from 9 to 10 out of 10000 .
# Iterating from 10 to 11 out of 10000 .
# Iterating from 11 to 12 out of 10000 .
# Iterating from 12 to 13 out of 10000 .
# Iterating from 13 to 14 out of 10000 .
# Iterating from 14 to 15 out of 10000 .
# Iterating from 15 to 16 out of 10000 .
# Iterating from 16 to 17 out of 10000 .
# Iterating from 17 to 18 out of 10000 .
# Iterating from 18 to 19 out of 10000 .
# Iterating from 19 to 20 out of 10000 .
# Iterating from 20 to 21 out of 10000 .
# Iterating from 21 to 22 out of 10000 .
# Iterating from 22 to 23 out of 10000 .
# Iterating from 23 to 24 out of 10000 .
# Iterating from 24 to 25 out of 10000 .
# Iterating from 25 to 26 out of 10000 .
# Iterating from 26 to 27 out of 10000 .
# Iterating from 27 to 28 out of 10000 .
# Iterating from 28 to 29 out of 10000 .
# Iterating from 29 to 30 out of 10000 .
# Iterating from 30 to 31 out of 10000 .
# Iterating from 31 to 32 out of 10000 .
# Iterating from 32 to 33 out of 10000 .
# Iterating from 33 to 34 out of 10000 .
# Iterating from 34 to 35 out of 10000 .
# Iterating from 35 to 36 out of 10000 .
# Iterating from 36 to 37 out of 10000 .
# Iterating from 37 to 38 out of 10000 .
# Iterating from 38 to 39 out of 10000 .
# Iterating from 39 to 40 out of 10000 .
# Iterating from 40 to 41 out of 10000 .
# Iterating from 41 to 42 out of 10000 .
# Iterating from 42 to 43 out of 10000 .
# Iterating from 43 to 44 out of 10000 .
# Iterating from 44 to 45 out of 10000 .
# Iterating from 45 to 46 out of 10000 .
# Iterating from 46 to 47 out of 10000 .
# Iterating from 47 to 48 out of 10000 .
# Iterating from 48 to 49 out of 10000 .
# Iterating from 49 to 50 out of 10000 .
# Iterating from 50 to 51 out of 10000 .
# Iterating from 51 to 52 out of 10000 .
# Iterating from 52 to 53 out of 10000 .
# Iterating from 53 to 54 out of 10000 .
# Iterating from 54 to 55 out of 10000 .
# Iterating from 55 to 56 out of 10000 .
# Iterating from 56 to 57 out of 10000 .
# Iterating from 57 to 58 out of 10000 .
# Iterating from 58 to 59 out of 10000 .
# Iterating from 59 to 60 out of 10000 .
# Iterating from 60 to 61 out of 10000 .
# Iterating from 61 to 62 out of 10000 .
# Iterating from 62 to 63 out of 10000 .
# Iterating from 63 to 64 out of 10000 .
# Iterating from 64 to 65 out of 10000 .
# Iterating from 65 to 66 out of 10000 .
# Iterating from 66 to 67 out of 10000 .
# Iterating from 67 to 68 out of 10000 .
# Iterating from 68 to 69 out of 10000 .
# Iterating from 69 to 70 out of 10000 .
# Iterating from 70 to 71 out of 10000 .
# Iterating from 71 to 72 out of 10000 .
# Iterating from 72 to 73 out of 10000 .
# Iterating from 73 to 74 out of 10000 .
# Iterating from 74 to 75 out of 10000 .
# Iterating from 75 to 76 out of 10000 .
# Iterating from 76 to 77 out of 10000 .
# Iterating from 77 to 78 out of 10000 .
# Iterating from 78 to 79 out of 10000 .
# Iterating from 79 to 80 out of 10000 .
# Iterating from 80 to 81 out of 10000 .
# Iterating from 81 to 82 out of 10000 .
# Iterating from 82 to 83 out of 10000 .
# Iterating from 83 to 84 out of 10000 .
# Iterating from 84 to 85 out of 10000 .
# Iterating from 85 to 86 out of 10000 .
# Iterating from 86 to 87 out of 10000 .
# Iterating from 87 to 88 out of 10000 .
# Iterating from 88 to 89 out of 10000 .
# Iterating from 89 to 90 out of 10000 .
# Iterating from 90 to 91 out of 10000 .
# Iterating from 91 to 92 out of 10000 .
# Iterating from 92 to 93 out of 10000 .
# Iterating from 93 to 94 out of 10000 .
# Iterating from 94 to 95 out of 10000 .
# Iterating from 95 to 96 out of 10000 .
# Iterating from 96 to 97 out of 10000 .
# Iterating from 97 to 98 out of 10000 .
# Iterating from 98 to 99 out of 10000 .
# Iterating from 99 to 100 out of 10000 .
# Iterating from 100 to 101 out of 10000 .
# Iterating from 101 to 102 out of 10000 .
# Iterating from 102 to 103 out of 10000 .
# Iterating from 103 to 104 out of 10000 .
# Iterating from 104 to 105 out of 10000 .
# Iterating from 105 to 106 out of 10000 .
# Iterating from 106 to 107 out of 10000 .
# Iterating from 107 to 108 out of 10000 .
# Iterating from 108 to 109 out of 10000 .
# Iterating from 109 to 110 out of 10000 .
# Iterating from 110 to 111 out of 10000 .
# Iterating from 111 to 112 out of 10000 .
# Iterating from 112 to 113 out of 10000 .
# Iterating from 113 to 114 out of 10000 .
# Iterating from 114 to 115 out of 10000 .
# Iterating from 115 to 116 out of 10000 .
# Iterating from 116 to 117 out of 10000 .
# Iterating from 117 to 118 out of 10000 .
# Iterating from 118 to 119 out of 10000 .
# Iterating from 119 to 120 out of 10000 .
# Iterating from 120 to 121 out of 10000 .
# Iterating from 121 to 122 out of 10000 .
# Iterating from 122 to 123 out of 10000 .
# Iterating from 123 to 124 out of 10000 .
# Iterating from 124 to 125 out of 10000 .
# Iterating from 125 to 126 out of 10000 .
# Iterating from 126 to 127 out of 10000 .
# Iterating from 127 to 128 out of 10000 .
# Iterating from 128 to 129 out of 10000 .
# Iterating from 129 to 130 out of 10000 .
# Iterating from 130 to 131 out of 10000 .
# Iterating from 131 to 132 out of 10000 .
# Iterating from 132 to 133 out of 10000 .
# Iterating from 133 to 134 out of 10000 .
# Iterating from 134 to 135 out of 10000 .
# Iterating from 135 to 136 out of 10000 .
# Iterating from 136 to 137 out of 10000 .
# Iterating from 137 to 138 out of 10000 .
# Iterating from 138 to 139 out of 10000 .
# Iterating from 139 to 140 out of 10000 .
# Iterating from 140 to 141 out of 10000 .
# Iterating from 141 to 142 out of 10000 .
# Iterating from 142 to 143 out of 10000 .
# Iterating from 143 to 144 out of 10000 .
# Iterating from 144 to 145 out of 10000 .
# Iterating from 145 to 146 out of 10000 .
# Iterating from 146 to 147 out of 10000 .
# Iterating from 147 to 148 out of 10000 .
# Iterating from 148 to 149 out of 10000 .
# Iterating from 149 to 150 out of 10000 .
# Iterating from 150 to 151 out of 10000 .
# Iterating from 151 to 152 out of 10000 .
# Iterating from 152 to 153 out of 10000 .
# Iterating from 153 to 154 out of 10000 .
# Iterating from 154 to 155 out of 10000 .
# Iterating from 155 to 156 out of 10000 .
# Iterating from 156 to 157 out of 10000 .
# Iterating from 157 to 158 out of 10000 .
# Iterating from 158 to 159 out of 10000 .
# Iterating from 159 to 160 out of 10000 .
# Iterating from 160 to 161 out of 10000 .
# Iterating from 161 to 162 out of 10000 .
# Iterating from 162 to 163 out of 10000 .
# Iterating from 163 to 164 out of 10000 .
# Iterating from 164 to 165 out of 10000 .
# Iterating from 165 to 166 out of 10000 .
# Iterating from 166 to 167 out of 10000 .
# Iterating from 167 to 168 out of 10000 .
# Iterating from 168 to 169 out of 10000 .
# Iterating from 169 to 170 out of 10000 .
# Iterating from 170 to 171 out of 10000 .
# Iterating from 171 to 172 out of 10000 .
# Iterating from 172 to 173 out of 10000 .
# Iterating from 173 to 174 out of 10000 .
# Iterating from 174 to 175 out of 10000 .
# Iterating from 175 to 176 out of 10000 .
# Iterating from 176 to 177 out of 10000 .
# Iterating from 177 to 178 out of 10000 .
# Iterating from 178 to 179 out of 10000 .
# Iterating from 179 to 180 out of 10000 .
# Iterating from 180 to 181 out of 10000 .
# Iterating from 181 to 182 out of 10000 .
# Iterating from 182 to 183 out of 10000 .
# Iterating from 183 to 184 out of 10000 .
# Iterating from 184 to 185 out of 10000 .
# Iterating from 185 to 186 out of 10000 .
# Iterating from 186 to 187 out of 10000 .
# Iterating from 187 to 188 out of 10000 .
# Iterating from 188 to 189 out of 10000 .
# Iterating from 189 to 190 out of 10000 .
# Iterating from 190 to 191 out of 10000 .
# Iterating from 191 to 192 out of 10000 .
# Iterating from 192 to 193 out of 10000 .
# Iterating from 193 to 194 out of 10000 .
# Iterating from 194 to 195 out of 10000 .
# Iterating from 195 to 196 out of 10000 .
# Iterating from 196 to 197 out of 10000 .
# Iterating from 197 to 198 out of 10000 .
# Iterating from 198 to 199 out of 10000 .
# Iterating from 199 to 200 out of 10000 .
# Iterating from 200 to 201 out of 10000 .
# Iterating from 201 to 202 out of 10000 .
# Iterating from 202 to 203 out of 10000 .
# Iterating from 203 to 204 out of 10000 .
# Iterating from 204 to 205 out of 10000 .
# Iterating from 205 to 206 out of 10000 .
# Iterating from 206 to 207 out of 10000 .
# Iterating from 207 to 208 out of 10000 .
# Iterating from 208 to 209 out of 10000 .
# Iterating from 209 to 210 out of 10000 .
# Iterating from 210 to 211 out of 10000 .
# Iterating from 211 to 212 out of 10000 .
# Iterating from 212 to 213 out of 10000 .
# Iterating from 213 to 214 out of 10000 .
# Iterating from 214 to 215 out of 10000 .
# Iterating from 215 to 216 out of 10000 .
# Iterating from 216 to 217 out of 10000 .
# Iterating from 217 to 218 out of 10000 .
# Iterating from 218 to 219 out of 10000 .
# Iterating from 219 to 220 out of 10000 .
# Iterating from 220 to 221 out of 10000 .
# Iterating from 221 to 222 out of 10000 .
# Iterating from 222 to 223 out of 10000 .
# Iterating from 223 to 224 out of 10000 .
# Iterating from 224 to 225 out of 10000 .
# Iterating from 225 to 226 out of 10000 .
# Iterating from 226 to 227 out of 10000 .
# Iterating from 227 to 228 out of 10000 .
# Iterating from 228 to 229 out of 10000 .
# Iterating from 229 to 230 out of 10000 .
# Iterating from 230 to 231 out of 10000 .
# Iterating from 231 to 232 out of 10000 .
# Iterating from 232 to 233 out of 10000 .
# Iterating from 233 to 234 out of 10000 .
# Iterating from 234 to 235 out of 10000 .
# Iterating from 235 to 236 out of 10000 .
# Iterating from 236 to 237 out of 10000 .
# Iterating from 237 to 238 out of 10000 .
# Iterating from 238 to 239 out of 10000 .
# Iterating from 239 to 240 out of 10000 .
# Iterating from 240 to 241 out of 10000 .
# Iterating from 241 to 242 out of 10000 .
# Iterating from 242 to 243 out of 10000 .
# Iterating from 243 to 244 out of 10000 .
# Iterating from 244 to 245 out of 10000 .
# Iterating from 245 to 246 out of 10000 .
# Iterating from 246 to 247 out of 10000 .
# Iterating from 247 to 248 out of 10000 .
# Iterating from 248 to 249 out of 10000 .
# Iterating from 249 to 250 out of 10000 .
# Iterating from 250 to 251 out of 10000 .
# Iterating from 251 to 252 out of 10000 .
# Iterating from 252 to 253 out of 10000 .
# Iterating from 253 to 254 out of 10000 .
# Iterating from 254 to 255 out of 10000 .
# Iterating from 255 to 256 out of 10000 .
# Iterating from 256 to 257 out of 10000 .
# Iterating from 257 to 258 out of 10000 .
# Iterating from 258 to 259 out of 10000 .
# Iterating from 259 to 260 out of 10000 .
# Iterating from 260 to 261 out of 10000 .
# Iterating from 261 to 262 out of 10000 .
# Iterating from 262 to 263 out of 10000 .
# Iterating from 263 to 264 out of 10000 .
# Iterating from 264 to 265 out of 10000 .
# Iterating from 265 to 266 out of 10000 .
# Iterating from 266 to 267 out of 10000 .
# Iterating from 267 to 268 out of 10000 .
# Iterating from 268 to 269 out of 10000 .
# Iterating from 269 to 270 out of 10000 .
# Iterating from 270 to 271 out of 10000 .
# Iterating from 271 to 272 out of 10000 .
# Iterating from 272 to 273 out of 10000 .
# Iterating from 273 to 274 out of 10000 .
# Iterating from 274 to 275 out of 10000 .
# Iterating from 275 to 276 out of 10000 .
# Iterating from 276 to 277 out of 10000 .
# Iterating from 277 to 278 out of 10000 .
# Iterating from 278 to 279 out of 10000 .
# Iterating from 279 to 280 out of 10000 .
# Iterating from 280 to 281 out of 10000 .
# Iterating from 281 to 282 out of 10000 .
# Iterating from 282 to 283 out of 10000 .
# Iterating from 283 to 284 out of 10000 .
# Iterating from 284 to 285 out of 10000 .
# Iterating from 285 to 286 out of 10000 .
# Iterating from 286 to 287 out of 10000 .
# Iterating from 287 to 288 out of 10000 .
# Iterating from 288 to 289 out of 10000 .
# Iterating from 289 to 290 out of 10000 .
# Iterating from 290 to 291 out of 10000 .
# Iterating from 291 to 292 out of 10000 .
# Iterating from 292 to 293 out of 10000 .
# Iterating from 293 to 294 out of 10000 .
# Iterating from 294 to 295 out of 10000 .
# Iterating from 295 to 296 out of 10000 .
# Iterating from 296 to 297 out of 10000 .
# Iterating from 297 to 298 out of 10000 .
# Iterating from 298 to 299 out of 10000 .
# Iterating from 299 to 300 out of 10000 .
# Iterating from 300 to 301 out of 10000 .
# Iterating from 301 to 302 out of 10000 .
# Iterating from 302 to 303 out of 10000 .
# Iterating from 303 to 304 out of 10000 .
# Iterating from 304 to 305 out of 10000 .
# Iterating from 305 to 306 out of 10000 .
# Iterating from 306 to 307 out of 10000 .
# Iterating from 307 to 308 out of 10000 .
# Iterating from 308 to 309 out of 10000 .
# Iterating from 309 to 310 out of 10000 .
# Iterating from 310 to 311 out of 10000 .
# Iterating from 311 to 312 out of 10000 .
# Iterating from 312 to 313 out of 10000 .
# Iterating from 313 to 314 out of 10000 .
# Iterating from 314 to 315 out of 10000 .
# Iterating from 315 to 316 out of 10000 .
# Iterating from 316 to 317 out of 10000 .
# Iterating from 317 to 318 out of 10000 .
# Iterating from 318 to 319 out of 10000 .
# Iterating from 319 to 320 out of 10000 .
# Iterating from 320 to 321 out of 10000 .
# Iterating from 321 to 322 out of 10000 .
# Iterating from 322 to 323 out of 10000 .
# Iterating from 323 to 324 out of 10000 .
# Iterating from 324 to 325 out of 10000 .
# Iterating from 325 to 326 out of 10000 .
# Iterating from 326 to 327 out of 10000 .
# Iterating from 327 to 328 out of 10000 .
# Iterating from 328 to 329 out of 10000 .
# Iterating from 329 to 330 out of 10000 .
# Iterating from 330 to 331 out of 10000 .
# Iterating from 331 to 332 out of 10000 .
# Iterating from 332 to 333 out of 10000 .
# Iterating from 333 to 334 out of 10000 .
# Iterating from 334 to 335 out of 10000 .
# Iterating from 335 to 336 out of 10000 .
# Iterating from 336 to 337 out of 10000 .
# Iterating from 337 to 338 out of 10000 .
# Iterating from 338 to 339 out of 10000 .
# Iterating from 339 to 340 out of 10000 .
# Iterating from 340 to 341 out of 10000 .
# Iterating from 341 to 342 out of 10000 .
# Iterating from 342 to 343 out of 10000 .
# Iterating from 343 to 344 out of 10000 .
# Iterating from 344 to 345 out of 10000 .
# Iterating from 345 to 346 out of 10000 .
# Iterating from 346 to 347 out of 10000 .
# Iterating from 347 to 348 out of 10000 .
# Iterating from 348 to 349 out of 10000 .
# Iterating from 349 to 350 out of 10000 .
# Iterating from 350 to 351 out of 10000 .
# Iterating from 351 to 352 out of 10000 .
# Iterating from 352 to 353 out of 10000 .
# Iterating from 353 to 354 out of 10000 .
# Iterating from 354 to 355 out of 10000 .
# Iterating from 355 to 356 out of 10000 .
# Iterating from 356 to 357 out of 10000 .
# Iterating from 357 to 358 out of 10000 .
# Iterating from 358 to 359 out of 10000 .
# Iterating from 359 to 360 out of 10000 .
# Iterating from 360 to 361 out of 10000 .
# Iterating from 361 to 362 out of 10000 .
# Iterating from 362 to 363 out of 10000 .
# Iterating from 363 to 364 out of 10000 .
# Iterating from 364 to 365 out of 10000 .
# Iterating from 365 to 366 out of 10000 .
# Iterating from 366 to 367 out of 10000 .
# Iterating from 367 to 368 out of 10000 .
# Iterating from 368 to 369 out of 10000 .
# Iterating from 369 to 370 out of 10000 .
# Iterating from 370 to 371 out of 10000 .
# Iterating from 371 to 372 out of 10000 .
# Iterating from 372 to 373 out of 10000 .
# Iterating from 373 to 374 out of 10000 .
# Iterating from 374 to 375 out of 10000 .
# Iterating from 375 to 376 out of 10000 .
# Iterating from 376 to 377 out of 10000 .
# Iterating from 377 to 378 out of 10000 .
# Iterating from 378 to 379 out of 10000 .
# Iterating from 379 to 380 out of 10000 .
# Iterating from 380 to 381 out of 10000 .
# Iterating from 381 to 382 out of 10000 .
# Iterating from 382 to 383 out of 10000 .
# Iterating from 383 to 384 out of 10000 .
# Iterating from 384 to 385 out of 10000 .
# Iterating from 385 to 386 out of 10000 .
# Iterating from 386 to 387 out of 10000 .
# Iterating from 387 to 388 out of 10000 .
# Iterating from 388 to 389 out of 10000 .
# Iterating from 389 to 390 out of 10000 .
# Iterating from 390 to 391 out of 10000 .
# Iterating from 391 to 392 out of 10000 .
# Iterating from 392 to 393 out of 10000 .
# Iterating from 393 to 394 out of 10000 .
# Iterating from 394 to 395 out of 10000 .
# Iterating from 395 to 396 out of 10000 .
# Iterating from 396 to 397 out of 10000 .
# Iterating from 397 to 398 out of 10000 .
# Iterating from 398 to 399 out of 10000 .
# Iterating from 399 to 400 out of 10000 .
# Iterating from 400 to 401 out of 10000 .
# Iterating from 401 to 402 out of 10000 .
# Iterating from 402 to 403 out of 10000 .
# Iterating from 403 to 404 out of 10000 .
# Iterating from 404 to 405 out of 10000 .
# Iterating from 405 to 406 out of 10000 .
# Iterating from 406 to 407 out of 10000 .
# Iterating from 407 to 408 out of 10000 .
# Iterating from 408 to 409 out of 10000 .
# Iterating from 409 to 410 out of 10000 .
# Iterating from 410 to 411 out of 10000 .
# Iterating from 411 to 412 out of 10000 .
# Iterating from 412 to 413 out of 10000 .
# Iterating from 413 to 414 out of 10000 .
# Iterating from 414 to 415 out of 10000 .
# Iterating from 415 to 416 out of 10000 .
# Iterating from 416 to 417 out of 10000 .
# Iterating from 417 to 418 out of 10000 .
# Iterating from 418 to 419 out of 10000 .
# Iterating from 419 to 420 out of 10000 .
# Iterating from 420 to 421 out of 10000 .
# Iterating from 421 to 422 out of 10000 .
# Iterating from 422 to 423 out of 10000 .
# Iterating from 423 to 424 out of 10000 .
# Iterating from 424 to 425 out of 10000 .
# Iterating from 425 to 426 out of 10000 .
# Iterating from 426 to 427 out of 10000 .
# Iterating from 427 to 428 out of 10000 .
# Iterating from 428 to 429 out of 10000 .
# Iterating from 429 to 430 out of 10000 .
# Iterating from 430 to 431 out of 10000 .
# Iterating from 431 to 432 out of 10000 .
# Iterating from 432 to 433 out of 10000 .
# Iterating from 433 to 434 out of 10000 .
# Iterating from 434 to 435 out of 10000 .
# Iterating from 435 to 436 out of 10000 .
# Iterating from 436 to 437 out of 10000 .
# Iterating from 437 to 438 out of 10000 .
# Iterating from 438 to 439 out of 10000 .
# Iterating from 439 to 440 out of 10000 .
# Iterating from 440 to 441 out of 10000 .
# Iterating from 441 to 442 out of 10000 .
# Iterating from 442 to 443 out of 10000 .
# Iterating from 443 to 444 out of 10000 .
# Iterating from 444 to 445 out of 10000 .
# Iterating from 445 to 446 out of 10000 .
# Iterating from 446 to 447 out of 10000 .
# Iterating from 447 to 448 out of 10000 .
# Iterating from 448 to 449 out of 10000 .
# Iterating from 449 to 450 out of 10000 .
# Iterating from 450 to 451 out of 10000 .
# Iterating from 451 to 452 out of 10000 .
# Iterating from 452 to 453 out of 10000 .
# Iterating from 453 to 454 out of 10000 .
# Iterating from 454 to 455 out of 10000 .
# Iterating from 455 to 456 out of 10000 .
# Iterating from 456 to 457 out of 10000 .
# Iterating from 457 to 458 out of 10000 .
# Iterating from 458 to 459 out of 10000 .
# Iterating from 459 to 460 out of 10000 .
# Iterating from 460 to 461 out of 10000 .
# Iterating from 461 to 462 out of 10000 .
# Iterating from 462 to 463 out of 10000 .
# Iterating from 463 to 464 out of 10000 .
# Iterating from 464 to 465 out of 10000 .
# Iterating from 465 to 466 out of 10000 .
# Iterating from 466 to 467 out of 10000 .
# Iterating from 467 to 468 out of 10000 .
# Iterating from 468 to 469 out of 10000 .
# Iterating from 469 to 470 out of 10000 .
# Iterating from 470 to 471 out of 10000 .
# Iterating from 471 to 472 out of 10000 .
# Iterating from 472 to 473 out of 10000 .
# Iterating from 473 to 474 out of 10000 .
# Iterating from 474 to 475 out of 10000 .
# Iterating from 475 to 476 out of 10000 .
# Iterating from 476 to 477 out of 10000 .
# Iterating from 477 to 478 out of 10000 .
# Iterating from 478 to 479 out of 10000 .
# Iterating from 479 to 480 out of 10000 .
# Iterating from 480 to 481 out of 10000 .
# Iterating from 481 to 482 out of 10000 .
# Iterating from 482 to 483 out of 10000 .
# Iterating from 483 to 484 out of 10000 .
# Iterating from 484 to 485 out of 10000 .
# Iterating from 485 to 486 out of 10000 .
# Iterating from 486 to 487 out of 10000 .
# Iterating from 487 to 488 out of 10000 .
# Iterating from 488 to 489 out of 10000 .
# Iterating from 489 to 490 out of 10000 .
# Iterating from 490 to 491 out of 10000 .
# Iterating from 491 to 492 out of 10000 .
# Iterating from 492 to 493 out of 10000 .
# Iterating from 493 to 494 out of 10000 .
# Iterating from 494 to 495 out of 10000 .
# Iterating from 495 to 496 out of 10000 .
# Iterating from 496 to 497 out of 10000 .
# Iterating from 497 to 498 out of 10000 .
# Iterating from 498 to 499 out of 10000 .
# Iterating from 499 to 500 out of 10000 .
# Iterating from 500 to 501 out of 10000 .
# Iterating from 501 to 502 out of 10000 .
# Iterating from 502 to 503 out of 10000 .
# Iterating from 503 to 504 out of 10000 .
# Iterating from 504 to 505 out of 10000 .
# Iterating from 505 to 506 out of 10000 .
# Iterating from 506 to 507 out of 10000 .
# Iterating from 507 to 508 out of 10000 .
# Iterating from 508 to 509 out of 10000 .
# Iterating from 509 to 510 out of 10000 .
# Iterating from 510 to 511 out of 10000 .
# Iterating from 511 to 512 out of 10000 .
# Iterating from 512 to 513 out of 10000 .
# Iterating from 513 to 514 out of 10000 .
# Iterating from 514 to 515 out of 10000 .
# Iterating from 515 to 516 out of 10000 .
# Iterating from 516 to 517 out of 10000 .
# Iterating from 517 to 518 out of 10000 .
# Iterating from 518 to 519 out of 10000 .
# Iterating from 519 to 520 out of 10000 .
# Iterating from 520 to 521 out of 10000 .
# Iterating from 521 to 522 out of 10000 .
# Iterating from 522 to 523 out of 10000 .
# Iterating from 523 to 524 out of 10000 .
# Iterating from 524 to 525 out of 10000 .
# Iterating from 525 to 526 out of 10000 .
# Iterating from 526 to 527 out of 10000 .
# Iterating from 527 to 528 out of 10000 .
# Iterating from 528 to 529 out of 10000 .
# Iterating from 529 to 530 out of 10000 .
# Iterating from 530 to 531 out of 10000 .
# Iterating from 531 to 532 out of 10000 .
# Iterating from 532 to 533 out of 10000 .
# Iterating from 533 to 534 out of 10000 .
# Iterating from 534 to 535 out of 10000 .
# Iterating from 535 to 536 out of 10000 .
# Iterating from 536 to 537 out of 10000 .
# Iterating from 537 to 538 out of 10000 .
# Iterating from 538 to 539 out of 10000 .
# Iterating from 539 to 540 out of 10000 .
# Iterating from 540 to 541 out of 10000 .
# Iterating from 541 to 542 out of 10000 .
# Iterating from 542 to 543 out of 10000 .
# Iterating from 543 to 544 out of 10000 .
# Iterating from 544 to 545 out of 10000 .
# Iterating from 545 to 546 out of 10000 .
# Iterating from 546 to 547 out of 10000 .
# Iterating from 547 to 548 out of 10000 .
# Iterating from 548 to 549 out of 10000 .
# Iterating from 549 to 550 out of 10000 .
# Iterating from 550 to 551 out of 10000 .
# Iterating from 551 to 552 out of 10000 .
# Iterating from 552 to 553 out of 10000 .
# Iterating from 553 to 554 out of 10000 .
# Iterating from 554 to 555 out of 10000 .
# Iterating from 555 to 556 out of 10000 .
# Iterating from 556 to 557 out of 10000 .
# Iterating from 557 to 558 out of 10000 .
# Iterating from 558 to 559 out of 10000 .
# Iterating from 559 to 560 out of 10000 .
# Iterating from 560 to 561 out of 10000 .
# Iterating from 561 to 562 out of 10000 .
# Iterating from 562 to 563 out of 10000 .
# Iterating from 563 to 564 out of 10000 .
# Iterating from 564 to 565 out of 10000 .
# Iterating from 565 to 566 out of 10000 .
# Iterating from 566 to 567 out of 10000 .
# Iterating from 567 to 568 out of 10000 .
# Iterating from 568 to 569 out of 10000 .
# Iterating from 569 to 570 out of 10000 .
# Iterating from 570 to 571 out of 10000 .
# Iterating from 571 to 572 out of 10000 .
# Iterating from 572 to 573 out of 10000 .
# Iterating from 573 to 574 out of 10000 .
# Iterating from 574 to 575 out of 10000 .
# Iterating from 575 to 576 out of 10000 .
# Iterating from 576 to 577 out of 10000 .
# Iterating from 577 to 578 out of 10000 .
# Iterating from 578 to 579 out of 10000 .
# Iterating from 579 to 580 out of 10000 .
# Iterating from 580 to 581 out of 10000 .
# Iterating from 581 to 582 out of 10000 .
# Iterating from 582 to 583 out of 10000 .
# Iterating from 583 to 584 out of 10000 .
# Iterating from 584 to 585 out of 10000 .
# Iterating from 585 to 586 out of 10000 .
# Iterating from 586 to 587 out of 10000 .
# Iterating from 587 to 588 out of 10000 .
# Iterating from 588 to 589 out of 10000 .
# Iterating from 589 to 590 out of 10000 .
# Iterating from 590 to 591 out of 10000 .
# Iterating from 591 to 592 out of 10000 .
# Iterating from 592 to 593 out of 10000 .
# Iterating from 593 to 594 out of 10000 .
# Iterating from 594 to 595 out of 10000 .
# Iterating from 595 to 596 out of 10000 .
# Iterating from 596 to 597 out of 10000 .
# Iterating from 597 to 598 out of 10000 .
# Iterating from 598 to 599 out of 10000 .
# Iterating from 599 to 600 out of 10000 .
# Iterating from 600 to 601 out of 10000 .
# Iterating from 601 to 602 out of 10000 .
# Iterating from 602 to 603 out of 10000 .
# Iterating from 603 to 604 out of 10000 .
# Iterating from 604 to 605 out of 10000 .
# Iterating from 605 to 606 out of 10000 .
# Iterating from 606 to 607 out of 10000 .
# Iterating from 607 to 608 out of 10000 .
# Iterating from 608 to 609 out of 10000 .
# Iterating from 609 to 610 out of 10000 .
# Iterating from 610 to 611 out of 10000 .
# Iterating from 611 to 612 out of 10000 .
# Iterating from 612 to 613 out of 10000 .
# Iterating from 613 to 614 out of 10000 .
# Iterating from 614 to 615 out of 10000 .
# Iterating from 615 to 616 out of 10000 .
# Iterating from 616 to 617 out of 10000 .
# Iterating from 617 to 618 out of 10000 .
# Iterating from 618 to 619 out of 10000 .
# Iterating from 619 to 620 out of 10000 .
# Iterating from 620 to 621 out of 10000 .
# Iterating from 621 to 622 out of 10000 .
# Iterating from 622 to 623 out of 10000 .
# Iterating from 623 to 624 out of 10000 .
# Iterating from 624 to 625 out of 10000 .
# Iterating from 625 to 626 out of 10000 .
# Iterating from 626 to 627 out of 10000 .
# Iterating from 627 to 628 out of 10000 .
# Iterating from 628 to 629 out of 10000 .
# Iterating from 629 to 630 out of 10000 .
# Iterating from 630 to 631 out of 10000 .
# Iterating from 631 to 632 out of 10000 .
# Iterating from 632 to 633 out of 10000 .
# Iterating from 633 to 634 out of 10000 .
# Iterating from 634 to 635 out of 10000 .
# Iterating from 635 to 636 out of 10000 .
# Iterating from 636 to 637 out of 10000 .
# Iterating from 637 to 638 out of 10000 .
# Iterating from 638 to 639 out of 10000 .
# Iterating from 639 to 640 out of 10000 .
# Iterating from 640 to 641 out of 10000 .
# Iterating from 641 to 642 out of 10000 .
# Iterating from 642 to 643 out of 10000 .
# Iterating from 643 to 644 out of 10000 .
# Iterating from 644 to 645 out of 10000 .
# Iterating from 645 to 646 out of 10000 .
# Iterating from 646 to 647 out of 10000 .
# Iterating from 647 to 648 out of 10000 .
# Iterating from 648 to 649 out of 10000 .
# Iterating from 649 to 650 out of 10000 .
# Iterating from 650 to 651 out of 10000 .
# Iterating from 651 to 652 out of 10000 .
# Iterating from 652 to 653 out of 10000 .
# Iterating from 653 to 654 out of 10000 .
# Iterating from 654 to 655 out of 10000 .
# Iterating from 655 to 656 out of 10000 .
# Iterating from 656 to 657 out of 10000 .
# Iterating from 657 to 658 out of 10000 .
# Iterating from 658 to 659 out of 10000 .
# Iterating from 659 to 660 out of 10000 .
# Iterating from 660 to 661 out of 10000 .
# Iterating from 661 to 662 out of 10000 .
# Iterating from 662 to 663 out of 10000 .
# Iterating from 663 to 664 out of 10000 .
# Iterating from 664 to 665 out of 10000 .
# Iterating from 665 to 666 out of 10000 .
# Iterating from 666 to 667 out of 10000 .
# Iterating from 667 to 668 out of 10000 .
# Iterating from 668 to 669 out of 10000 .
# Iterating from 669 to 670 out of 10000 .
# Iterating from 670 to 671 out of 10000 .
# Iterating from 671 to 672 out of 10000 .
# Iterating from 672 to 673 out of 10000 .
# Iterating from 673 to 674 out of 10000 .
# Iterating from 674 to 675 out of 10000 .
# Iterating from 675 to 676 out of 10000 .
# Iterating from 676 to 677 out of 10000 .
# Iterating from 677 to 678 out of 10000 .
# Iterating from 678 to 679 out of 10000 .
# Iterating from 679 to 680 out of 10000 .
# Iterating from 680 to 681 out of 10000 .
# Iterating from 681 to 682 out of 10000 .
# Iterating from 682 to 683 out of 10000 .
# Iterating from 683 to 684 out of 10000 .
# Iterating from 684 to 685 out of 10000 .
# Iterating from 685 to 686 out of 10000 .
# Iterating from 686 to 687 out of 10000 .
# Iterating from 687 to 688 out of 10000 .
# Iterating from 688 to 689 out of 10000 .
# Iterating from 689 to 690 out of 10000 .
# Iterating from 690 to 691 out of 10000 .
# Iterating from 691 to 692 out of 10000 .
# Iterating from 692 to 693 out of 10000 .
# Iterating from 693 to 694 out of 10000 .
# Iterating from 694 to 695 out of 10000 .
# Iterating from 695 to 696 out of 10000 .
# Iterating from 696 to 697 out of 10000 .
# Iterating from 697 to 698 out of 10000 .
# Iterating from 698 to 699 out of 10000 .
# Iterating from 699 to 700 out of 10000 .
# Iterating from 700 to 701 out of 10000 .
# Iterating from 701 to 702 out of 10000 .
# Iterating from 702 to 703 out of 10000 .
# Iterating from 703 to 704 out of 10000 .
# Iterating from 704 to 705 out of 10000 .
# Iterating from 705 to 706 out of 10000 .
# Iterating from 706 to 707 out of 10000 .
# Iterating from 707 to 708 out of 10000 .
# Iterating from 708 to 709 out of 10000 .
# Iterating from 709 to 710 out of 10000 .
# Iterating from 710 to 711 out of 10000 .
# Iterating from 711 to 712 out of 10000 .
# Iterating from 712 to 713 out of 10000 .
# Iterating from 713 to 714 out of 10000 .
# Iterating from 714 to 715 out of 10000 .
# Iterating from 715 to 716 out of 10000 .
# Iterating from 716 to 717 out of 10000 .
# Iterating from 717 to 718 out of 10000 .
# Iterating from 718 to 719 out of 10000 .
# Iterating from 719 to 720 out of 10000 .
# Iterating from 720 to 721 out of 10000 .
# Iterating from 721 to 722 out of 10000 .
# Iterating from 722 to 723 out of 10000 .
# Iterating from 723 to 724 out of 10000 .
# Iterating from 724 to 725 out of 10000 .
# Iterating from 725 to 726 out of 10000 .
# Iterating from 726 to 727 out of 10000 .
# Iterating from 727 to 728 out of 10000 .
# Iterating from 728 to 729 out of 10000 .
# Iterating from 729 to 730 out of 10000 .
# Iterating from 730 to 731 out of 10000 .
# Iterating from 731 to 732 out of 10000 .
# Iterating from 732 to 733 out of 10000 .
# Iterating from 733 to 734 out of 10000 .
# Iterating from 734 to 735 out of 10000 .
# Iterating from 735 to 736 out of 10000 .
# Iterating from 736 to 737 out of 10000 .
# Iterating from 737 to 738 out of 10000 .
# Iterating from 738 to 739 out of 10000 .
# Iterating from 739 to 740 out of 10000 .
# Iterating from 740 to 741 out of 10000 .
# Iterating from 741 to 742 out of 10000 .
# Iterating from 742 to 743 out of 10000 .
# Iterating from 743 to 744 out of 10000 .
# Iterating from 744 to 745 out of 10000 .
# Iterating from 745 to 746 out of 10000 .
# Iterating from 746 to 747 out of 10000 .
# Iterating from 747 to 748 out of 10000 .
# Iterating from 748 to 749 out of 10000 .
# Iterating from 749 to 750 out of 10000 .
# Iterating from 750 to 751 out of 10000 .
# Iterating from 751 to 752 out of 10000 .
# Iterating from 752 to 753 out of 10000 .
# Iterating from 753 to 754 out of 10000 .
# Iterating from 754 to 755 out of 10000 .
# Iterating from 755 to 756 out of 10000 .
# Iterating from 756 to 757 out of 10000 .
# Iterating from 757 to 758 out of 10000 .
# Iterating from 758 to 759 out of 10000 .
# Iterating from 759 to 760 out of 10000 .
# Iterating from 760 to 761 out of 10000 .
# Iterating from 761 to 762 out of 10000 .
# Iterating from 762 to 763 out of 10000 .
# Iterating from 763 to 764 out of 10000 .
# Iterating from 764 to 765 out of 10000 .
# Iterating from 765 to 766 out of 10000 .
# Iterating from 766 to 767 out of 10000 .
# Iterating from 767 to 768 out of 10000 .
# Iterating from 768 to 769 out of 10000 .
# Iterating from 769 to 770 out of 10000 .
# Iterating from 770 to 771 out of 10000 .
# Iterating from 771 to 772 out of 10000 .
# Iterating from 772 to 773 out of 10000 .
# Iterating from 773 to 774 out of 10000 .
# Iterating from 774 to 775 out of 10000 .
# Iterating from 775 to 776 out of 10000 .
# Iterating from 776 to 777 out of 10000 .
# Iterating from 777 to 778 out of 10000 .
# Iterating from 778 to 779 out of 10000 .
# Iterating from 779 to 780 out of 10000 .
# Iterating from 780 to 781 out of 10000 .
# Iterating from 781 to 782 out of 10000 .
# Iterating from 782 to 783 out of 10000 .
# Iterating from 783 to 784 out of 10000 .
# Iterating from 784 to 785 out of 10000 .
# Iterating from 785 to 786 out of 10000 .
# Iterating from 786 to 787 out of 10000 .
# Iterating from 787 to 788 out of 10000 .
# Iterating from 788 to 789 out of 10000 .
# Iterating from 789 to 790 out of 10000 .
# Iterating from 790 to 791 out of 10000 .
# Iterating from 791 to 792 out of 10000 .
# Iterating from 792 to 793 out of 10000 .
# Iterating from 793 to 794 out of 10000 .
# Iterating from 794 to 795 out of 10000 .
# Iterating from 795 to 796 out of 10000 .
# Iterating from 796 to 797 out of 10000 .
# Iterating from 797 to 798 out of 10000 .
# Iterating from 798 to 799 out of 10000 .
# Iterating from 799 to 800 out of 10000 .
# Iterating from 800 to 801 out of 10000 .
# Iterating from 801 to 802 out of 10000 .
# Iterating from 802 to 803 out of 10000 .
# Iterating from 803 to 804 out of 10000 .
# Iterating from 804 to 805 out of 10000 .
# Iterating from 805 to 806 out of 10000 .
# Iterating from 806 to 807 out of 10000 .
# Iterating from 807 to 808 out of 10000 .
# Iterating from 808 to 809 out of 10000 .
# Iterating from 809 to 810 out of 10000 .
# Iterating from 810 to 811 out of 10000 .
# Iterating from 811 to 812 out of 10000 .
# Iterating from 812 to 813 out of 10000 .
# Iterating from 813 to 814 out of 10000 .
# Iterating from 814 to 815 out of 10000 .
# Iterating from 815 to 816 out of 10000 .
# Iterating from 816 to 817 out of 10000 .
# Iterating from 817 to 818 out of 10000 .
# Iterating from 818 to 819 out of 10000 .
# Iterating from 819 to 820 out of 10000 .
# Iterating from 820 to 821 out of 10000 .
# Iterating from 821 to 822 out of 10000 .
# Iterating from 822 to 823 out of 10000 .
# Iterating from 823 to 824 out of 10000 .
# Iterating from 824 to 825 out of 10000 .
# Iterating from 825 to 826 out of 10000 .
# Iterating from 826 to 827 out of 10000 .
# Iterating from 827 to 828 out of 10000 .
# Iterating from 828 to 829 out of 10000 .
# Iterating from 829 to 830 out of 10000 .
# Iterating from 830 to 831 out of 10000 .
# Iterating from 831 to 832 out of 10000 .
# Iterating from 832 to 833 out of 10000 .
# Iterating from 833 to 834 out of 10000 .
# Iterating from 834 to 835 out of 10000 .
# Iterating from 835 to 836 out of 10000 .
# Iterating from 836 to 837 out of 10000 .
# Iterating from 837 to 838 out of 10000 .
# Iterating from 838 to 839 out of 10000 .
# Iterating from 839 to 840 out of 10000 .
# Iterating from 840 to 841 out of 10000 .
# Iterating from 841 to 842 out of 10000 .
# Iterating from 842 to 843 out of 10000 .
# Iterating from 843 to 844 out of 10000 .
# Iterating from 844 to 845 out of 10000 .
# Iterating from 845 to 846 out of 10000 .
# Iterating from 846 to 847 out of 10000 .
# Iterating from 847 to 848 out of 10000 .
# Iterating from 848 to 849 out of 10000 .
# Iterating from 849 to 850 out of 10000 .
# Iterating from 850 to 851 out of 10000 .
# Iterating from 851 to 852 out of 10000 .
# Iterating from 852 to 853 out of 10000 .
# Iterating from 853 to 854 out of 10000 .
# Iterating from 854 to 855 out of 10000 .
# Iterating from 855 to 856 out of 10000 .
# Iterating from 856 to 857 out of 10000 .
# Iterating from 857 to 858 out of 10000 .
# Iterating from 858 to 859 out of 10000 .
# Iterating from 859 to 860 out of 10000 .
# Iterating from 860 to 861 out of 10000 .
# Iterating from 861 to 862 out of 10000 .
# Iterating from 862 to 863 out of 10000 .
# Iterating from 863 to 864 out of 10000 .
# Iterating from 864 to 865 out of 10000 .
# Iterating from 865 to 866 out of 10000 .
# Iterating from 866 to 867 out of 10000 .
# Iterating from 867 to 868 out of 10000 .
# Iterating from 868 to 869 out of 10000 .
# Iterating from 869 to 870 out of 10000 .
# Iterating from 870 to 871 out of 10000 .
# Iterating from 871 to 872 out of 10000 .
# Iterating from 872 to 873 out of 10000 .
# Iterating from 873 to 874 out of 10000 .
# Iterating from 874 to 875 out of 10000 .
# Iterating from 875 to 876 out of 10000 .
# Iterating from 876 to 877 out of 10000 .
# Iterating from 877 to 878 out of 10000 .
# Iterating from 878 to 879 out of 10000 .
# Iterating from 879 to 880 out of 10000 .
# Iterating from 880 to 881 out of 10000 .
# Iterating from 881 to 882 out of 10000 .
# Iterating from 882 to 883 out of 10000 .
# Iterating from 883 to 884 out of 10000 .
# Iterating from 884 to 885 out of 10000 .
# Iterating from 885 to 886 out of 10000 .
# Iterating from 886 to 887 out of 10000 .
# Iterating from 887 to 888 out of 10000 .
# Iterating from 888 to 889 out of 10000 .
# Iterating from 889 to 890 out of 10000 .
# Iterating from 890 to 891 out of 10000 .
# Iterating from 891 to 892 out of 10000 .
# Iterating from 892 to 893 out of 10000 .
# Iterating from 893 to 894 out of 10000 .
# Iterating from 894 to 895 out of 10000 .
# Iterating from 895 to 896 out of 10000 .
# Iterating from 896 to 897 out of 10000 .
# Iterating from 897 to 898 out of 10000 .
# Iterating from 898 to 899 out of 10000 .
# Iterating from 899 to 900 out of 10000 .
# Iterating from 900 to 901 out of 10000 .
# Iterating from 901 to 902 out of 10000 .
# Iterating from 902 to 903 out of 10000 .
# Iterating from 903 to 904 out of 10000 .
# Iterating from 904 to 905 out of 10000 .
# Iterating from 905 to 906 out of 10000 .
# Iterating from 906 to 907 out of 10000 .
# Iterating from 907 to 908 out of 10000 .
# Iterating from 908 to 909 out of 10000 .
# Iterating from 909 to 910 out of 10000 .
# Iterating from 910 to 911 out of 10000 .
# Iterating from 911 to 912 out of 10000 .
# Iterating from 912 to 913 out of 10000 .
# Iterating from 913 to 914 out of 10000 .
# Iterating from 914 to 915 out of 10000 .
# Iterating from 915 to 916 out of 10000 .
# Iterating from 916 to 917 out of 10000 .
# Iterating from 917 to 918 out of 10000 .
# Iterating from 918 to 919 out of 10000 .
# Iterating from 919 to 920 out of 10000 .
# Iterating from 920 to 921 out of 10000 .
# Iterating from 921 to 922 out of 10000 .
# Iterating from 922 to 923 out of 10000 .
# Iterating from 923 to 924 out of 10000 .
# Iterating from 924 to 925 out of 10000 .
# Iterating from 925 to 926 out of 10000 .
# Iterating from 926 to 927 out of 10000 .
# Iterating from 927 to 928 out of 10000 .
# Iterating from 928 to 929 out of 10000 .
# Iterating from 929 to 930 out of 10000 .
# Iterating from 930 to 931 out of 10000 .
# Iterating from 931 to 932 out of 10000 .
# Iterating from 932 to 933 out of 10000 .
# Iterating from 933 to 934 out of 10000 .
# Iterating from 934 to 935 out of 10000 .
# Iterating from 935 to 936 out of 10000 .
# Iterating from 936 to 937 out of 10000 .
# Iterating from 937 to 938 out of 10000 .
# Iterating from 938 to 939 out of 10000 .
# Iterating from 939 to 940 out of 10000 .
# Iterating from 940 to 941 out of 10000 .
# Iterating from 941 to 942 out of 10000 .
# Iterating from 942 to 943 out of 10000 .
# Iterating from 943 to 944 out of 10000 .
# Iterating from 944 to 945 out of 10000 .
# Iterating from 945 to 946 out of 10000 .
# Iterating from 946 to 947 out of 10000 .
# Iterating from 947 to 948 out of 10000 .
# Iterating from 948 to 949 out of 10000 .
# Iterating from 949 to 950 out of 10000 .
# Iterating from 950 to 951 out of 10000 .
# Iterating from 951 to 952 out of 10000 .
# Iterating from 952 to 953 out of 10000 .
# Iterating from 953 to 954 out of 10000 .
# Iterating from 954 to 955 out of 10000 .
# Iterating from 955 to 956 out of 10000 .
# Iterating from 956 to 957 out of 10000 .
# Iterating from 957 to 958 out of 10000 .
# Iterating from 958 to 959 out of 10000 .
# Iterating from 959 to 960 out of 10000 .
# Iterating from 960 to 961 out of 10000 .
# Iterating from 961 to 962 out of 10000 .
# Iterating from 962 to 963 out of 10000 .
# Iterating from 963 to 964 out of 10000 .
# Iterating from 964 to 965 out of 10000 .
# Iterating from 965 to 966 out of 10000 .
# Iterating from 966 to 967 out of 10000 .
# Iterating from 967 to 968 out of 10000 .
# Iterating from 968 to 969 out of 10000 .
# Iterating from 969 to 970 out of 10000 .
# Iterating from 970 to 971 out of 10000 .
# Iterating from 971 to 972 out of 10000 .
# Iterating from 972 to 973 out of 10000 .
# Iterating from 973 to 974 out of 10000 .
# Iterating from 974 to 975 out of 10000 .
# Iterating from 975 to 976 out of 10000 .
# Iterating from 976 to 977 out of 10000 .
# Iterating from 977 to 978 out of 10000 .
# Iterating from 978 to 979 out of 10000 .
# Iterating from 979 to 980 out of 10000 .
# Iterating from 980 to 981 out of 10000 .
# Iterating from 981 to 982 out of 10000 .
# Iterating from 982 to 983 out of 10000 .
# Iterating from 983 to 984 out of 10000 .
# Iterating from 984 to 985 out of 10000 .
# Iterating from 985 to 986 out of 10000 .
# Iterating from 986 to 987 out of 10000 .
# Iterating from 987 to 988 out of 10000 .
# Iterating from 988 to 989 out of 10000 .
# Iterating from 989 to 990 out of 10000 .
# Iterating from 990 to 991 out of 10000 .
# Iterating from 991 to 992 out of 10000 .
# Iterating from 992 to 993 out of 10000 .
# Iterating from 993 to 994 out of 10000 .
# Iterating from 994 to 995 out of 10000 .
# Iterating from 995 to 996 out of 10000 .
# Iterating from 996 to 997 out of 10000 .
# Iterating from 997 to 998 out of 10000 .
# Iterating from 998 to 999 out of 10000 .
# Iterating from 999 to 1000 out of 10000 .
# Iterating from 1000 to 1001 out of 10000 .
# Iterating from 1001 to 1002 out of 10000 .
# Iterating from 1002 to 1003 out of 10000 .
# Iterating from 1003 to 1004 out of 10000 .
# Iterating from 1004 to 1005 out of 10000 .
# Iterating from 1005 to 1006 out of 10000 .
# Iterating from 1006 to 1007 out of 10000 .
# Iterating from 1007 to 1008 out of 10000 .
# Iterating from 1008 to 1009 out of 10000 .
# Iterating from 1009 to 1010 out of 10000 .
# Iterating from 1010 to 1011 out of 10000 .
# Iterating from 1011 to 1012 out of 10000 .
# Iterating from 1012 to 1013 out of 10000 .
# Iterating from 1013 to 1014 out of 10000 .
# Iterating from 1014 to 1015 out of 10000 .
# Iterating from 1015 to 1016 out of 10000 .
# Iterating from 1016 to 1017 out of 10000 .
# Iterating from 1017 to 1018 out of 10000 .
# Iterating from 1018 to 1019 out of 10000 .
# Iterating from 1019 to 1020 out of 10000 .
# Iterating from 1020 to 1021 out of 10000 .
# Iterating from 1021 to 1022 out of 10000 .
# Iterating from 1022 to 1023 out of 10000 .
# Iterating from 1023 to 1024 out of 10000 .
# Iterating from 1024 to 1025 out of 10000 .
# Iterating from 1025 to 1026 out of 10000 .
# Iterating from 1026 to 1027 out of 10000 .
# Iterating from 1027 to 1028 out of 10000 .
# Iterating from 1028 to 1029 out of 10000 .
# Iterating from 1029 to 1030 out of 10000 .
# Iterating from 1030 to 1031 out of 10000 .
# Iterating from 1031 to 1032 out of 10000 .
# Iterating from 1032 to 1033 out of 10000 .
# Iterating from 1033 to 1034 out of 10000 .
# Iterating from 1034 to 1035 out of 10000 .
# Iterating from 1035 to 1036 out of 10000 .
# Iterating from 1036 to 1037 out of 10000 .
# ...
# Iterating from 9954 to 9955 out of 10000 .
# Iterating from 9955 to 9956 out of 10000 .
# Iterating from 9956 to 9957 out of 10000 .
# Iterating from 9957 to 9958 out of 10000 .
# Iterating from 9958 to 9959 out of 10000 .
# Iterating from 9959 to 9960 out of 10000 .
# Iterating from 9960 to 9961 out of 10000 .
# Iterating from 9961 to 9962 out of 10000 .
# Iterating from 9962 to 9963 out of 10000 .
# Iterating from 9963 to 9964 out of 10000 .
# Iterating from 9964 to 9965 out of 10000 .
# Iterating from 9965 to 9966 out of 10000 .
# Iterating from 9966 to 9967 out of 10000 .
# Iterating from 9967 to 9968 out of 10000 .
# Iterating from 9968 to 9969 out of 10000 .
# Iterating from 9969 to 9970 out of 10000 .
# Iterating from 9970 to 9971 out of 10000 .
# Iterating from 9971 to 9972 out of 10000 .
# Iterating from 9972 to 9973 out of 10000 .
# Iterating from 9973 to 9974 out of 10000 .
# Iterating from 9974 to 9975 out of 10000 .
# Iterating from 9975 to 9976 out of 10000 .
# Iterating from 9976 to 9977 out of 10000 .
# Iterating from 9977 to 9978 out of 10000 .
# Iterating from 9978 to 9979 out of 10000 .
# Iterating from 9979 to 9980 out of 10000 .
# Iterating from 9980 to 9981 out of 10000 .
# Iterating from 9981 to 9982 out of 10000 .
# Iterating from 9982 to 9983 out of 10000 .
# Iterating from 9983 to 9984 out of 10000 .
# Iterating from 9984 to 9985 out of 10000 .
# Iterating from 9985 to 9986 out of 10000 .
# Iterating from 9986 to 9987 out of 10000 .
# Iterating from 9987 to 9988 out of 10000 .
# Iterating from 9988 to 9989 out of 10000 .
# Iterating from 9989 to 9990 out of 10000 .
# Iterating from 9990 to 9991 out of 10000 .
# Iterating from 9991 to 9992 out of 10000 .
# Iterating from 9992 to 9993 out of 10000 .
# Iterating from 9993 to 9994 out of 10000 .
# Iterating from 9994 to 9995 out of 10000 .
# Iterating from 9995 to 9996 out of 10000 .
# Iterating from 9996 to 9997 out of 10000 .
# Iterating from 9997 to 9998 out of 10000 .
# Iterating from 9998 to 9999 out of 10000 .
# Iterating from 9999 to 10000 out of 10000 .
# KPD metric calculation completed in 21290.91097209882 seconds.
# Saving kpd to ../results_leonardo/5D_50K/null_hypothesis/KPD.json
# Computing and savng ks with max_vectorize = 2000
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 25
# Iterating from 0 to 400 out of 10000 .
# Iterating from 400 to 800 out of 10000 .
# Iterating from 800 to 1200 out of 10000 .
# Iterating from 1200 to 1600 out of 10000 .
# Iterating from 1600 to 2000 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7fa8403a40e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2000 to 2400 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7fa8403a40e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2400 to 2800 out of 10000 .
# Iterating from 2800 to 3200 out of 10000 .
# Iterating from 3200 to 3600 out of 10000 .
# Iterating from 3600 to 4000 out of 10000 .
# Iterating from 4000 to 4400 out of 10000 .
# Iterating from 4400 to 4800 out of 10000 .
# Iterating from 4800 to 5200 out of 10000 .
# Iterating from 5200 to 5600 out of 10000 .
# Iterating from 5600 to 6000 out of 10000 .
# Iterating from 6000 to 6400 out of 10000 .
# Iterating from 6400 to 6800 out of 10000 .
# Iterating from 6800 to 7200 out of 10000 .
# Iterating from 7200 to 7600 out of 10000 .
# Iterating from 7600 to 8000 out of 10000 .
# Iterating from 8000 to 8400 out of 10000 .
# Iterating from 8400 to 8800 out of 10000 .
# Iterating from 8800 to 9200 out of 10000 .
# Iterating from 9200 to 9600 out of 10000 .
# Iterating from 9600 to 10000 out of 10000 .
# KS tests calculation completed in 65.52993017807603 seconds.
# Saving ks to ../results_leonardo/5D_50K/null_hypothesis/KS.json
# Computing and savng sks with max_vectorize = 100
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fa860287100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 500 to 600 out of 10000 .
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fa860287100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SKS metric calculation completed in 538.6133488258347 seconds.
# Saving sks to ../results_leonardo/5D_50K/null_hypothesis/SKS.json
# Computing and savng swd with max_vectorize = 100
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 10000
# batch_size = 50000
# The dist_1_num tensor is empty. Batches will be generated 'on-the-fly' from dist_1_symb.
# The dist_2_num tensor is empty. Batches will be generated 'on-the-fly' from dist_2_symb.
# nchunks = 100
# Iterating from 0 to 100 out of 10000 .
# Iterating from 100 to 200 out of 10000 .
# Iterating from 200 to 300 out of 10000 .
# Iterating from 300 to 400 out of 10000 .
# Iterating from 400 to 500 out of 10000 .
# Iterating from 500 to 600 out of 10000 .
# Iterating from 600 to 700 out of 10000 .
# Iterating from 700 to 800 out of 10000 .
# Iterating from 800 to 900 out of 10000 .
# Iterating from 900 to 1000 out of 10000 .
# Iterating from 1000 to 1100 out of 10000 .
# Iterating from 1100 to 1200 out of 10000 .
# Iterating from 1200 to 1300 out of 10000 .
# Iterating from 1300 to 1400 out of 10000 .
# Iterating from 1400 to 1500 out of 10000 .
# Iterating from 1500 to 1600 out of 10000 .
# Iterating from 1600 to 1700 out of 10000 .
# Iterating from 1700 to 1800 out of 10000 .
# Iterating from 1800 to 1900 out of 10000 .
# Iterating from 1900 to 2000 out of 10000 .
# Iterating from 2000 to 2100 out of 10000 .
# Iterating from 2100 to 2200 out of 10000 .
# Iterating from 2200 to 2300 out of 10000 .
# Iterating from 2300 to 2400 out of 10000 .
# Iterating from 2400 to 2500 out of 10000 .
# Iterating from 2500 to 2600 out of 10000 .
# Iterating from 2600 to 2700 out of 10000 .
# Iterating from 2700 to 2800 out of 10000 .
# Iterating from 2800 to 2900 out of 10000 .
# Iterating from 2900 to 3000 out of 10000 .
# Iterating from 3000 to 3100 out of 10000 .
# Iterating from 3100 to 3200 out of 10000 .
# Iterating from 3200 to 3300 out of 10000 .
# Iterating from 3300 to 3400 out of 10000 .
# Iterating from 3400 to 3500 out of 10000 .
# Iterating from 3500 to 3600 out of 10000 .
# Iterating from 3600 to 3700 out of 10000 .
# Iterating from 3700 to 3800 out of 10000 .
# Iterating from 3800 to 3900 out of 10000 .
# Iterating from 3900 to 4000 out of 10000 .
# Iterating from 4000 to 4100 out of 10000 .
# Iterating from 4100 to 4200 out of 10000 .
# Iterating from 4200 to 4300 out of 10000 .
# Iterating from 4300 to 4400 out of 10000 .
# Iterating from 4400 to 4500 out of 10000 .
# Iterating from 4500 to 4600 out of 10000 .
# Iterating from 4600 to 4700 out of 10000 .
# Iterating from 4700 to 4800 out of 10000 .
# Iterating from 4800 to 4900 out of 10000 .
# Iterating from 4900 to 5000 out of 10000 .
# Iterating from 5000 to 5100 out of 10000 .
# Iterating from 5100 to 5200 out of 10000 .
# Iterating from 5200 to 5300 out of 10000 .
# Iterating from 5300 to 5400 out of 10000 .
# Iterating from 5400 to 5500 out of 10000 .
# Iterating from 5500 to 5600 out of 10000 .
# Iterating from 5600 to 5700 out of 10000 .
# Iterating from 5700 to 5800 out of 10000 .
# Iterating from 5800 to 5900 out of 10000 .
# Iterating from 5900 to 6000 out of 10000 .
# Iterating from 6000 to 6100 out of 10000 .
# Iterating from 6100 to 6200 out of 10000 .
# Iterating from 6200 to 6300 out of 10000 .
# Iterating from 6300 to 6400 out of 10000 .
# Iterating from 6400 to 6500 out of 10000 .
# Iterating from 6500 to 6600 out of 10000 .
# Iterating from 6600 to 6700 out of 10000 .
# Iterating from 6700 to 6800 out of 10000 .
# Iterating from 6800 to 6900 out of 10000 .
# Iterating from 6900 to 7000 out of 10000 .
# Iterating from 7000 to 7100 out of 10000 .
# Iterating from 7100 to 7200 out of 10000 .
# Iterating from 7200 to 7300 out of 10000 .
# Iterating from 7300 to 7400 out of 10000 .
# Iterating from 7400 to 7500 out of 10000 .
# Iterating from 7500 to 7600 out of 10000 .
# Iterating from 7600 to 7700 out of 10000 .
# Iterating from 7700 to 7800 out of 10000 .
# Iterating from 7800 to 7900 out of 10000 .
# Iterating from 7900 to 8000 out of 10000 .
# Iterating from 8000 to 8100 out of 10000 .
# Iterating from 8100 to 8200 out of 10000 .
# Iterating from 8200 to 8300 out of 10000 .
# Iterating from 8300 to 8400 out of 10000 .
# Iterating from 8400 to 8500 out of 10000 .
# Iterating from 8500 to 8600 out of 10000 .
# Iterating from 8600 to 8700 out of 10000 .
# Iterating from 8700 to 8800 out of 10000 .
# Iterating from 8800 to 8900 out of 10000 .
# Iterating from 8900 to 9000 out of 10000 .
# Iterating from 9000 to 9100 out of 10000 .
# Iterating from 9100 to 9200 out of 10000 .
# Iterating from 9200 to 9300 out of 10000 .
# Iterating from 9300 to 9400 out of 10000 .
# Iterating from 9400 to 9500 out of 10000 .
# Iterating from 9500 to 9600 out of 10000 .
# Iterating from 9600 to 9700 out of 10000 .
# Iterating from 9700 to 9800 out of 10000 .
# Iterating from 9800 to 9900 out of 10000 .
# Iterating from 9900 to 10000 out of 10000 .
# SWD metric calculation completed in 316.2601915728301 seconds.
# Saving swd to ../results_leonardo/5D_50K/null_hypothesis/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[-1].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
metrics_config[unique_key]["lr"]["thresholds"] = []

save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fn: [[0.68, [6800, 3199], 0.7298814389654293], [0.95, [9500, 500], 1.194343275342383], [0.99, [9900, 100], 1.5257207752319304]]
# Computing time for metric fn: 23.026496447157115
# ThresholdS for metric fpd: [[0.68, [6800, 3199], 0.45283092579245954], [0.95, [9500, 500], 0.5406599898901173], [0.99, [9900, 100], 0.6272189852022225]]
# Computing time for metric fpd: 175.1618712239433
# ThresholdS for metric kpd: [[0.68, [6800, 3199], 0.26125275099655454], [0.95, [9500, 500], 0.3405622095279171], [0.99, [9900, 100], 0.3937468760378593]]
# Computing time for metric kpd: 21290.91097209882
# ThresholdS for metric ks: [[0.68, [6800, 3199], 0.9151610229957364], [0.95, [9500, 500], 1.132729974348813], [0.99, [9900, 100], 1.3022259312592006]]
# Computing time for metric ks: 65.52993017807603
# ThresholdS for metric sks: [[0.68, [6800, 3199], 0.9121602305718006], [0.95, [9500, 500], 1.1096755356387438], [0.99, [9900, 100], 1.2692760577053381]]
# Computing time for metric sks: 538.6133488258347
# ThresholdS for metric swd: [[0.68, [6800, 3199], 0.689925739441241], [0.95, [9500, 500], 0.987831895785366], [0.99, [9900, 100], 1.1960121960186678]]
# Computing time for metric swd: 316.2601915728301
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7fa892426ca0>
# 1          metric_list  <function <lambda> at 0x7fa892426d40>
# 2          metric_list  <function <lambda> at 0x7fa892426de0>
# 3      statistic_means  <function <lambda> at 0x7fa892427100>
# 4         metric_means  <function <lambda> at 0x7fa8924271a0>
# 5         metric_means  <function <lambda> at 0x7fa892427240>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7fa8924272e0>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1              lambda ns, ndims: 10000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...           2000
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
# 6  {'niter': 10000, 'batch_size_test': 50000, 'ba...            500
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  ../results_leonardo/5D_50K/null_hypothesis/FN....
# 1  ../results_leonardo/5D_50K/null_hypothesis/FPD...
# 2  ../results_leonardo/5D_50K/null_hypothesis/KPD...
# 3  ../results_leonardo/5D_50K/null_hypothesis/KS....
# 4  ../results_leonardo/5D_50K/null_hypothesis/SKS...
# 5  ../results_leonardo/5D_50K/null_hypothesis/SWD...
# 6  ../results_leonardo/5D_50K/null_hypothesis/LR....
#
#                                           thresholds
# 0  [[0.68, [6800, 3199], 0.7298814389654293], [0....
# 1  [[0.68, [6800, 3199], 0.45283092579245954], [0...
# 2  [[0.68, [6800, 3199], 0.26125275099655454], [0...
# 3  [[0.68, [6800, 3199], 0.9151610229957364], [0....
# 4  [[0.68, [6800, 3199], 0.9121602305718006], [0....
# 5  [[0.68, [6800, 3199], 0.689925739441241], [0.9...
# 6                                                 []

# %% [markdown]
# ### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[:-1]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null = np.array(obj.Results[-1].result_value[result_key])*scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size

    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[0].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[0].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for MoG null with $q = '+str(ncomp)+'$, $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    closest_edge = bin_edges[np.argmin(np.abs(bin_edges - threshold_value))]
    #    ax[1].fill_betweenx([0, 2*counts.max()], closest_edge, bin_edges[-1], color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    #    ax[1].axvline(x=closest_edge, linestyle=dash_styles[i], color=colors[i], linewidth=1)#, label=f'{int(confidence_level * 100)}% threshold')
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.6508200052736014 +/- 0.0007990373971406097
# sigma = 0.28267249550329615 +/- 0.002600462813563546
# /tmp/ipykernel_2598269/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598269/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598269/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598269/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.5053469175472856 seconds.
# mu = 0.4486719672142794 +/- 2.3320974314924517e-05
# sigma = 0.0482917946600916 +/- 0.000906739632955105
# /tmp/ipykernel_2598269/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598269/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598269/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598269/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9294569715857506 seconds.
# mu = 0.23526316883062617 +/- 3.794665829105511e-05
# sigma = 0.06160085899649055 +/- 0.0004882661923778792
# /tmp/ipykernel_2598269/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598269/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598269/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598269/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.0353951742872596 seconds.
# mu = 0.8671596004843392 +/- 0.00021271926894740018
# sigma = 0.14584898660854664 +/- 0.0013058973980972959
# /tmp/ipykernel_2598269/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598269/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598269/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598269/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3334097173064947 seconds.
# mu = 0.8681516134119874 +/- 0.00016924598357191862
# sigma = 0.13009457466471022 +/- 0.0011652934262257292
# /tmp/ipykernel_2598269/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598269/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598269/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598269/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 3.225208536721766 seconds.
# mu = 0.6355531217607878 +/- 0.00033337332233071164
# sigma = 0.18258513694458037 +/- 0.0016565666300937987
# /tmp/ipykernel_2598269/1823599339.py:78: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_2598269/1823599339.py:80: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_2598269/1823599339.py:117: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_2598269/1823599339.py:123: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9458500975742936 seconds.
#   name object_name          class_name                               kwargs  \
# 0   fn    FNMetric   GMetrics.FNMetric                                   {}
# 1  fpd   FPDMetric  GMetrics.FPDMetric                                   {}
# 2  kpd   KPDMetric  GMetrics.KPDMetric                                   {}
# 3   ks      KSTest     GMetrics.KSTest                                   {}
# 4  sks     SKSTest    GMetrics.SKSTest  {'nslices': 100, 'seed_slicing': 0}
# 5  swd   SWDMetric  GMetrics.SWDMetric  {'nslices': 100, 'seed_slicing': 0}
# 6   lr    LRMetric   GMetrics.LRMetric                  {'null_test': True}
#
#             result_key                             scale_func  \
# 0          metric_list  <function <lambda> at 0x7fa892426ca0>
# 1          metric_list  <function <lambda> at 0x7fa892426d40>
# 2          metric_list  <function <lambda> at 0x7fa892426de0>
# 3      statistic_means  <function <lambda> at 0x7fa892427100>
# 4         metric_means  <function <lambda> at 0x7fa8924271a0>
# 5         metric_means  <function <lambda> at 0x7fa892427240>
# 6  lik_ratio_norm_list  <function <lambda> at 0x7fa8924272e0>
#
#                      scale_func_string  \
# 0  lambda ns, ndims: np.sqrt(ns)/ndims
# 1              lambda ns, ndims: 10000
# 2              lambda ns, ndims: 10000
# 3            lambda ns, _: np.sqrt(ns)
# 4            lambda ns, _: np.sqrt(ns)
# 5  lambda ns, ndims: np.sqrt(ns/ndims)
# 6        lambda ns, ndims: np.sqrt(ns)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 10000, 'batch_size_test': 50000, 'ba...           1000
# 1  {'niter': 10000, 'batch_size_test': 50000, 'ba...            200
# 2  {'niter': 10000, 'batch_size_test': 50000, 'ba...              1
# 3  {'niter': 10000, 'batch_size_test': 50000, 'ba...           2000
# 4  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
# 5  {'niter': 10000, 'batch_size_test': 50000, 'ba...            100
# 6  {'niter': 10000, 'batch_size_test': 50000, 'ba...            500
#
#                         latex  \
# 0  $\overline{\|\cdot\|}_{F}$
# 1          $d_{\mathrm{FPD}}$
# 2          $d_{\mathrm{KPD}}$
# 3              $\overline{D}$
# 4             $\widetilde{D}$
# 5             $\widetilde{W}$
# 6                   $t_{\mu}$
#
#                                            null_file  \
# 0  ../results_leonardo/5D_50K/null_hypothesis/FN....
# 1  ../results_leonardo/5D_50K/null_hypothesis/FPD...
# 2  ../results_leonardo/5D_50K/null_hypothesis/KPD...
# 3  ../results_leonardo/5D_50K/null_hypothesis/KS....
# 4  ../results_leonardo/5D_50K/null_hypothesis/SKS...
# 5  ../results_leonardo/5D_50K/null_hypothesis/SWD...
# 6  ../results_leonardo/5D_50K/null_hypothesis/LR....
#
#                                           thresholds  \
# 0  [[0.68, [6800, 3199], 0.7298814389654293], [0....
# 1  [[0.68, [6800, 3199], 0.45283092579245954], [0...
# 2  [[0.68, [6800, 3199], 0.26125275099655454], [0...
# 3  [[0.68, [6800, 3199], 0.9151610229957364], [0....
# 4  [[0.68, [6800, 3199], 0.9121602305718006], [0....
# 5  [[0.68, [6800, 3199], 0.689925739441241], [0.9...
# 6                                                 []
#
#                                          null_figure
# 0  ../results_leonardo/5D_50K/null_hypothesis/FN.pdf
# 1  ../results_leonardo/5D_50K/null_hypothesis/FPD...
# 2  ../results_leonardo/5D_50K/null_hypothesis/KPD...
# 3  ../results_leonardo/5D_50K/null_hypothesis/KS.pdf
# 4  ../results_leonardo/5D_50K/null_hypothesis/SKS...
# 5  ../results_leonardo/5D_50K/null_hypothesis/SWD...
# 6                                                NaN

# %% [markdown]
# ## Alternative hypotheses and results

# %% [markdown]
# ### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": False}

# %%
file_path = model_dir + "exclusion_limits.json"
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}

# %%
deformations = ["mean", "std", "both"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[:-1]:
    for deformation in deformations:
        result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation}.items() if v["exclusion_list"] != []}
        if result == {}:
            print(f"Computing exclusion limits for {metric_config['name']} with {deformation} deformation.")
            result = compute_exclusion_bisection(metric_config = metric_config,
                                                 test_kwargs = test_kwargs,
                                                 model_dir = model_dir,
                                                 deformation = deformation,
                                                 seed_dist = 0,
                                                 x_tol = 0.01,
                                                 fn_tol = 0.01,
                                                 eps_min = 0.,
                                                 eps_max = 5.,
                                                 max_iterations = 100,
                                                 save = True,
                                                 verbose = True)
        else:
            print(f"Exclusion limits for {metric_config['name']} with {deformation} deformation already loaded.")
        global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for fn with mean deformation.
#
# ======================================================
# =============== fn - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 56.86236920971069 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.917711959618804
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 34.98552488133282 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8679549333711956
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 20.287542934935047 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7776092353061657
#
# ------------ 4 ------------
# eps = 0.3125
# WARNING:tensorflow:5 out of the last 207 calls to <function generate_and_clean_data_simple_1 at 0x7fa96881b6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 10.81991722833954 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6023581226738468
#
# ------------ 5 ------------
# eps = 0.15625
# WARNING:tensorflow:6 out of the last 209 calls to <function generate_and_clean_data_simple_1 at 0x7fa96881b6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7fa892275b20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 5.529386786084043 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2894757734583973
#
# ------------ 6 ------------
# eps = 0.078125
# WARNING:tensorflow:6 out of the last 6 calls to <function FNMetric.Test_tf.<locals>.batched_test_sub at 0x7fa8403a65c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 2.7623306099017904 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7925785040849501
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.3806468571074604 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.14470236558757468
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.7811738790132962 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.41828985935973134
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 1.0565757935072118 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.12240998243049388
#
# ------------ 10 ------------
# eps = 0.0341796875
# statistic = 1.2155593809685747 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.01760743785283758
#
# ------------ 11 ------------
# eps = 0.03173828125
# statistic = 1.1350758392963598 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.05088602190440489
#
# ------------ 12 ------------
# eps = 0.032958984375
# statistic = 1.1751043626408453 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.016239154132912687
#
# ------------ 13 ------------
# eps = 0.0335693359375
# statistic = 1.1952822711992863 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.01834862385321101
# relative_error_metric = 0.0007858937215181757
#
# ------------ 14 ------------
# eps = 0.03326416015625
# statistic = 1.185180477346121 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.0091324200913242
# relative_error_metric = 0.007701371323492349
# =======> statistic within required accuracy at 0.95 CL in 158.87386244628578 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.033416748046875
# statistic = 1.1902282207565644 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.973444084033104
# relative_error_metric = 0.24705364862955415
#
# ------------ 2 ------------
# eps = 2.5167083740234375
# statistic = 57.129601732065694 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.947584143605086
# relative_error_metric = 1.8959534644077964
#
# ------------ 3 ------------
# eps = 1.2750625610351562
# statistic = 35.48157974571358 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.897845543861695
# relative_error_metric = 1.8350897521565077
#
# ------------ 4 ------------
# eps = 0.6542396545410156
# statistic = 21.09605215012061 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.805619504618201
# relative_error_metric = 1.7302208310079825
#
# ------------ 5 ------------
# eps = 0.3438282012939453
# statistic = 11.83699974847831 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.6456758601511743
# relative_error_metric = 1.5432903733862409
#
# ------------ 6 ------------
# eps = 0.18862247467041016
# statistic = 6.65438946632299 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.3980027917964135
# relative_error_metric = 1.2539363259525396
#
# ------------ 7 ------------
# eps = 0.11101961135864258
# statistic = 3.9348138632615415 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.074561331110414
# relative_error_metric = 0.882365280149295
#
# ------------ 8 ------------
# eps = 0.07221817970275879
# statistic = 2.551355489773596 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.7346326159818537
# relative_error_metric = 0.5031226535274416
#
# ------------ 9 ------------
# eps = 0.052817463874816895
# statistic = 1.8608995769371093 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.44995403554124014
# relative_error_metric = 0.1979429442042453
#
# ------------ 10 ------------
# eps = 0.04311710596084595
# statistic = 1.5205285976082552 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.2022286216655328
# relative_error_metric = 0.0034088986082148843
#
# ------------ 11 ------------
# eps = 0.04796728491783142
# statistic = 1.6899644114414234 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.10649857588542953
# relative_error_metric = 0.10215156439452586
#
# ------------ 12 ------------
# eps = 0.045542195439338684
# statistic = 1.6050152454527282 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.05470581067510389
# relative_error_metric = 0.05065548145669399
#
# ------------ 13 ------------
# eps = 0.044329650700092316
# statistic = 1.5627073845008042 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.027732183228883593
# relative_error_metric = 0.023951736842131692
#
# ------------ 14 ------------
# eps = 0.04372337833046913
# statistic = 1.5416009200689933 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.013962897019076563
# relative_error_metric = 0.010354404535651394
#
# ------------ 15 ------------
# eps = 0.04342024214565754
# statistic = 1.531060367241263 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.007005904189218174
# relative_error_metric = 0.003493604390016925
# =======> statistic within required accuracy at 0.99 CL in 166.0693768048659 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 324.9432739261538 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# Computing exclusion limits for fn with std deformation.
#
# ======================================================
# =============== fn - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 26.40891739774194 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.826927218564874
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 6.142934924528371 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3488902872111777
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 4.95452314065118 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2230481558449042
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 3.6525344778091826 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.0143400876444306
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 2.1840162810414356 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.5858896835471202
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.3033804026734896 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.08730919940489405
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.892289094452842 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.2895135580774908
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.0883574461387255 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.09286003040721835
#
# ------------ 9 ------------
# eps = 0.068359375
# statistic = 1.1944464322154096 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 8.636747948147912e-05
#
# ------------ 10 ------------
# eps = 0.0634765625
# statistic = 1.140953766440435 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.04572395540842145
#
# ------------ 11 ------------
# eps = 0.06591796875
# statistic = 1.1676009147662887 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.03636363636363636
# relative_error_metric = 0.022644362799159923
#
# ------------ 12 ------------
# eps = 0.067138671875
# statistic = 1.1810003620131693 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.018018018018018018
# relative_error_metric = 0.011234512025441774
#
# ------------ 13 ------------
# eps = 0.0677490234375
# statistic = 1.1877177477032632 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.008968609865470852
# relative_error_metric = 0.0055628529874088535
# =======> statistic within required accuracy at 0.95 CL in 143.3837316473946 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.06805419921875
# statistic = 1.1910806994847165 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.9462877100018066
# relative_error_metric = 0.24634856750592402
#
# ------------ 2 ------------
# eps = 2.534027099609375
# statistic = 26.970575467981977 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.895384976250513
# relative_error_metric = 1.7858359188562596
#
# ------------ 3 ------------
# eps = 1.3010406494140625
# statistic = 6.655406456362763 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.801170242407356
# relative_error_metric = 1.2540290685910616
#
# ------------ 4 ------------
# eps = 0.6845474243164062
# statistic = 4.981712086208861 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.6382989507831112
# relative_error_metric = 1.0621673352805825
#
# ------------ 5 ------------
# eps = 0.3763008117675781
# statistic = 4.097129346589051 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.387388934197536
# relative_error_metric = 0.9146281745544232
#
# ------------ 6 ------------
# eps = 0.22217750549316406
# statistic = 2.864972432768172 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.0620707784313081
# relative_error_metric = 0.6100411001597861
#
# ------------ 7 ------------
# eps = 0.14511585235595703
# statistic = 2.061683199372953 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.7230063751258249
# relative_error_metric = 0.29880238073831855
#
# ------------ 8 ------------
# eps = 0.10658502578735352
# statistic = 1.6272986967762875 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.4412619967508089
# relative_error_metric = 0.06443215618941939
#
# ------------ 9 ------------
# eps = 0.08731961250305176
# statistic = 1.4074637837025699 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.19871018511118352
# relative_error_metric = 0.08063385658372496
#
# ------------ 10 ------------
# eps = 0.09695231914520264
# statistic = 1.517283240397326 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.09465296548250404
# relative_error_metric = 0.005545529871973981
#
# ------------ 11 ------------
# eps = 0.10176867246627808
# statistic = 1.5722979024852644 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.04847352342617019
# relative_error_metric = 0.03006897769102849
#
# ------------ 12 ------------
# eps = 0.09936049580574036
# statistic = 1.5447887288794724 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.024534074977626944
# relative_error_metric = 0.012420058379242963
#
# ------------ 13 ------------
# eps = 0.0981564074754715
# statistic = 1.5310350485992767 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.012342741927784917
# relative_error_metric = 0.003477067632236109
#
# ------------ 14 ------------
# eps = 0.09755436331033707
# statistic = 1.524158849167717 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.006152386633777292
# relative_error_metric = 0.0010242542372608664
# =======> statistic within required accuracy at 0.99 CL in 151.97371855843812 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 295.3574850540608 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# Computing exclusion limits for fn with both deformation.
#
# ======================================================
# =============== fn - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 51.9328856106354 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9100767496903936
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 33.58661312094961 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8626439984301624
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 20.39081174451966 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7786732086485582
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 11.360733463091723 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6194867462064293
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 5.939438472375751 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3303168963786063
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 3.0042974164590457 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8621619585838391
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.5124190864179476 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.23502307817573276
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.8413424780517068 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.34681266173044595
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 1.1558182438181774 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.032785007507029666
#
# ------------ 10 ------------
# eps = 0.0341796875
# statistic = 1.3315747468711683 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.1086586898877458
#
# ------------ 11 ------------
# eps = 0.03173828125
# statistic = 1.242862419989862 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.039815387548456094
#
# ------------ 12 ------------
# eps = 0.030517578125
# statistic = 1.199098906015094 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.00397388389805496
#
# ------------ 13 ------------
# eps = 0.0299072265625
# statistic = 1.1773934261197903 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.01429319638401955
#
# ------------ 14 ------------
# eps = 0.03021240234375
# statistic = 1.1882305124030579 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.010050251256281407
# relative_error_metric = 0.005131226550687014
#
# ------------ 15 ------------
# eps = 0.030364990234375
# statistic = 1.1936608718260757 - next threshold = 1.194343275342383 at 0.95 CL
# relative_error_eps = 0.005012531328320802
# relative_error_metric = 0.0005715262405356191
# =======> statistic within required accuracy at 0.95 CL in 165.10170268453658 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0304412841796875
# statistic = 1.1963789388892352 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.9757943429134754
# relative_error_metric = 0.2419763204369049
#
# ------------ 2 ------------
# eps = 2.5152206420898438
# statistic = 52.126285665182166 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.9521675932447216
# relative_error_metric = 1.8862506082096746
#
# ------------ 3 ------------
# eps = 1.2728309631347656
# statistic = 33.99217060453057 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.9065696849068479
# relative_error_metric = 1.8281743970756934
#
# ------------ 4 ------------
# eps = 0.6516361236572266
# statistic = 21.063163632325242 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.821479006166021
# relative_error_metric = 1.7298280432615791
#
# ------------ 5 ------------
# eps = 0.34103870391845703
# statistic = 12.282584198021368 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.6722161607085553
# relative_error_metric = 1.5580280771065667
#
# ------------ 6 ------------
# eps = 0.18573999404907227
# statistic = 7.010692423040053 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.4367452273554422
# relative_error_metric = 1.2850764180249477
#
# ------------ 7 ------------
# eps = 0.10809063911437988
# statistic = 4.145063736530958 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 1.1210319338433339
# relative_error_metric = 0.9238026787530839
#
# ------------ 8 ------------
# eps = 0.06926596164703369
# statistic = 2.6646592229381216 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.7787734410961197
# relative_error_metric = 0.5435967373859021
#
# ------------ 9 ------------
# eps = 0.049853622913360596
# statistic = 1.9207496710842984 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.48352602765148
# relative_error_metric = 0.22923678122619384
#
# ------------ 10 ------------
# eps = 0.04014745354652405
# statistic = 1.5530506613525337 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.27500617462472005
# relative_error_metric = 0.0177537609943027
#
# ------------ 11 ------------
# eps = 0.035294368863105774
# statistic = 1.3725119251047415 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.1286576736459855
# relative_error_metric = 0.10572570664142424
#
# ------------ 12 ------------
# eps = 0.03772091120481491
# statistic = 1.4623723686521177 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.06232421470408269
# relative_error_metric = 0.04240055682967752
#
# ------------ 13 ------------
# eps = 0.03893418237566948
# statistic = 1.507622535808203 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.03068401802027151
# relative_error_metric = 0.01193286586312683
#
# ------------ 14 ------------
# eps = 0.039540817961096764
# statistic = 1.5303158033479336 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.015460607399145688
# relative_error_metric = 0.00300718135915671
#
# ------------ 15 ------------
# eps = 0.03923750016838312
# statistic = 1.5189637977504276 - next threshold = 1.5257207752319304 at 0.99 CL
# relative_error_eps = 0.007700539943366387
# relative_error_metric = 0.004438540229396688
# =======> statistic within required accuracy at 0.99 CL in 164.05445806868374 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 329.1561955315992 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# Computing exclusion limits for fpd with mean deformation.
#
# ======================================================
# =============== fpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 882.3849478030023 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9975505977621753
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 225.31688523633738 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9904247610705488
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 57.0449647256328 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9624447946819357
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 14.44901299209605 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.855724673769773
#
# ------------ 5 ------------
# eps = 0.15625
# WARNING:tensorflow:5 out of the last 5 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7fa548d7dbc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 3.7833038465460906 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4998478152530277
#
# ------------ 6 ------------
# eps = 0.078125
# WARNING:tensorflow:6 out of the last 6 calls to <function FPDMetric.Test_tf.<locals>.batched_test at 0x7f9c4773e840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# statistic = 1.144784030074259 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7168722698923108
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.588240092236225 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.08429462110851837
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.4761642873590559 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.12685712560982984
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 0.5209682418566265 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.0370972576738867
#
# ------------ 10 ------------
# eps = 0.0341796875
# statistic = 0.55160269499565 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.020036764520023977
#
# ------------ 11 ------------
# eps = 0.03173828125
# statistic = 0.5355607245735321 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.009476244506456127
#
# ------------ 12 ------------
# eps = 0.032958984375
# statistic = 0.5433973944598294 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.03773584905660377
# relative_error_metric = 0.005050294586302799
#
# ------------ 13 ------------
# eps = 0.0323486328125
# statistic = 0.5394333771632484 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.018691588785046728
# relative_error_metric = 0.0022713086929055546
#
# ------------ 14 ------------
# eps = 0.03265380859375
# statistic = 0.5414039159579427 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.009389671361502348
# relative_error_metric = 0.0013750131832413642
# =======> statistic within required accuracy at 0.95 CL in 187.35686513222754 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.032501220703125
# statistic = 0.5404157853106621 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.9741669446044692
# relative_error_metric = 0.14868210862448364
#
# ------------ 2 ------------
# eps = 2.5162506103515625
# statistic = 893.7424675557712 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.9489927260753734
# relative_error_metric = 1.9971948110735815
#
# ------------ 3 ------------
# eps = 1.2743759155273438
# statistic = 234.0856569670271 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.9005224904404683
# relative_error_metric = 1.989310872142696
#
# ------------ 4 ------------
# eps = 0.6534385681152344
# statistic = 62.31552592278468 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.8104718738703667
# relative_error_metric = 1.9601403474780694
#
# ------------ 5 ------------
# eps = 0.3429698944091797
# statistic = 17.265815438408534 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.6537553021259304
# relative_error_metric = 1.8597847697929701
#
# ------------ 6 ------------
# eps = 0.18773555755615234
# statistic = 5.353651119524366 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.409704029272306
# relative_error_metric = 1.5805165641657786
#
# ------------ 7 ------------
# eps = 0.11011838912963867
# statistic = 1.9911090652046868 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.0884501579765626
# relative_error_metric = 1.041802290427668
#
# ------------ 8 ------------
# eps = 0.07130980491638184
# statistic = 1.0103335618933877 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.747677503071782
# relative_error_metric = 0.4679111853487248
#
# ------------ 9 ------------
# eps = 0.05190551280975342
# statistic = 0.7164057300474933 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.45978066675611357
# relative_error_metric = 0.1327554395703345
#
# ------------ 10 ------------
# eps = 0.04220336675643921
# statistic = 0.6151764760550221 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.20618981116420765
# relative_error_metric = 0.019385951611597094
#
# ------------ 11 ------------
# eps = 0.047054439783096313
# statistic = 0.6622726583048386 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.10869801118198862
# relative_error_metric = 0.05436820514366387
#
# ------------ 12 ------------
# eps = 0.04462890326976776
# statistic = 0.6378707559954595 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.055867168106891546
# relative_error_metric = 0.016839549711552902
#
# ------------ 13 ------------
# eps = 0.043416135013103485
# statistic = 0.6263134591983612 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.027548815477094625
# relative_error_metric = 0.0014447587821219833
#
# ------------ 14 ------------
# eps = 0.04402251914143562
# statistic = 0.6320391542101995 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.013869932793348227
# relative_error_metric = 0.007655569350103411
#
# ------------ 15 ------------
# eps = 0.043719327077269554
# statistic = 0.6291631200642099 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.006959096948418352
# relative_error_metric = 0.0030948146329657137
# =======> statistic within required accuracy at 0.99 CL in 202.8255793582648 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 390.1824801126495 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# Computing exclusion limits for fpd with std deformation.
#
# ======================================================
# =============== fpd - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 109.40695269202826 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9803302690544355
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 10.25856595922181 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7997412064761626
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 7.0682208879721165 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.715774238777664
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 3.0948932202322874 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4051414366487418
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 1.109586166106574 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6895046222638769
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 0.5923845095762642 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.09130183273561993
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.477952000685511 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.12312438845171919
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 0.5243695860264369 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.03059145817553667
#
# ------------ 9 ------------
# eps = 0.068359375
# statistic = 0.5555635907479074 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.027190805089443295
#
# ------------ 10 ------------
# eps = 0.0634765625
# statistic = 0.5392779858052988 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.07407407407407407
# relative_error_metric = 0.0025594138106469475
#
# ------------ 11 ------------
# eps = 0.06591796875
# statistic = 0.5472468017328957 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.03773584905660377
# relative_error_metric = 0.012109147389275465
#
# ------------ 12 ------------
# eps = 0.064697265625
# statistic = 0.5432191280322703 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.01904761904761905
# relative_error_metric = 0.004722183682362035
#
# ------------ 13 ------------
# eps = 0.0640869140625
# statistic = 0.5412377692124702 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.009569377990430622
# relative_error_metric = 0.001068084886010262
# =======> statistic within required accuracy at 0.95 CL in 177.43428653199226 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.06378173828125
# statistic = 0.540255184208742 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.949617308503586
# relative_error_metric = 0.148977687510392
#
# ------------ 2 ------------
# eps = 2.531890869140625
# statistic = 115.13599129185785 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.9017106578096525
# relative_error_metric = 1.9783275192973286
#
# ------------ 3 ------------
# eps = 1.2978363037109375
# statistic = 10.842742031902173 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.8126295735978035
# relative_error_metric = 1.7812655215595266
#
# ------------ 4 ------------
# eps = 0.6808090209960938
# statistic = 7.548454087344123 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.6573594958758133
# relative_error_metric = 1.6931291260613615
#
# ------------ 5 ------------
# eps = 0.3722953796386719
# statistic = 3.963254104158905 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.4149499190832349
# relative_error_metric = 1.4534602660838039
#
# ------------ 6 ------------
# eps = 0.21803855895996094
# statistic = 1.7820686746076873 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.094717606849176
# relative_error_metric = 0.9586648441112932
#
# ------------ 7 ------------
# eps = 0.14091014862060547
# statistic = 0.9761061025071671 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.7536049572530109
# relative_error_metric = 0.43520446349827474
#
# ------------ 8 ------------
# eps = 0.10234594345092773
# statistic = 0.7094494539392088 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.46427187531393965
# relative_error_metric = 0.12303794468253403
#
# ------------ 9 ------------
# eps = 0.08306384086608887
# statistic = 0.6132233492668568 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.20799444490879748
# relative_error_metric = 0.022565556731592752
#
# ------------ 10 ------------
# eps = 0.0927048921585083
# statistic = 0.6583300835854758 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.10970155074247773
# relative_error_metric = 0.04840126159103641
#
# ------------ 11 ------------
# eps = 0.08788436651229858
# statistic = 0.635036291065984 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.05639749863582558
# relative_error_metric = 0.012386251831520118
#
# ------------ 12 ------------
# eps = 0.08547410368919373
# statistic = 0.6239462422519727 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.02780669234452105
# relative_error_metric = 0.005231511999272905
#
# ------------ 13 ------------
# eps = 0.08667923510074615
# statistic = 0.6294451759006415 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.014000674282860361
# relative_error_metric = 0.0035430161332289023
#
# ------------ 14 ------------
# eps = 0.08607666939496994
# statistic = 0.6266842107202266 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.006975920244638083
# relative_error_metric = 0.0008529757061548757
# =======> statistic within required accuracy at 0.99 CL in 190.9773918101564 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 368.4117140788585 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# Computing exclusion limits for fpd with both deformation.
#
# ======================================================
# =============== fpd - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 969.054326830727 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9977695429648907
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 223.56391070458594 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9903498623305242
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 60.480892812413195 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9645594079428468
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 16.306946255217238 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.871635179022034
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 4.3728648945084005 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5598597726802383
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.2911588658377522 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8194029377969533
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.6154785251578777 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.1294283241911622
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.4809987315571215 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.11679293110419929
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 0.5344257370895165 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.011597684992275894
#
# ------------ 10 ------------
# eps = 0.0341796875
# statistic = 0.5712455184092022 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.05501461822212942
#
# ------------ 11 ------------
# eps = 0.03173828125
# statistic = 0.551942252801303 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.020652095465947408
#
# ------------ 12 ------------
# eps = 0.030517578125
# statistic = 0.5429647105114088 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.004253724782090165
#
# ------------ 13 ------------
# eps = 0.0299072265625
# statistic = 0.5386409015639245 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.020202020202020204
# relative_error_metric = 0.00374147439732523
#
# ------------ 14 ------------
# eps = 0.03021240234375
# statistic = 0.5407891634911471 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.01015228426395939
# relative_error_metric = 0.0002388898278313772
#
# ------------ 15 ------------
# eps = 0.030059814453125
# statistic = 0.5397116297372075 - next threshold = 0.5406599898901173 at 0.95 CL
# relative_error_eps = 0.005063291139240506
# relative_error_metric = 0.0017556184107037447
# =======> statistic within required accuracy at 0.95 CL in 206.6761644538492 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0301361083984375
# statistic = 0.5402495449838289 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.9760355523198496
# relative_error_metric = 0.14898806772039305
#
# ------------ 2 ------------
# eps = 2.5150680541992188
# statistic = 982.3918344381308 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.9526385995413738
# relative_error_metric = 1.9974477850331873
#
# ------------ 3 ------------
# eps = 1.2726020812988281
# statistic = 231.607087856287 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.9074684118826957
# relative_error_metric = 1.9891967901946488
#
# ------------ 4 ------------
# eps = 0.6513690948486328
# statistic = 65.31309723653416 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.8231203033822645
# relative_error_metric = 1.9619523216665762
#
# ------------ 5 ------------
# eps = 0.34075260162353516
# statistic = 19.179473629683127 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.6749848934829843
# relative_error_metric = 1.8733319090879719
#
# ------------ 6 ------------
# eps = 0.18544435501098633
# statistic = 6.038039643690688 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.440837858462083
# relative_error_metric = 1.6235891087656695
#
# ------------ 7 ------------
# eps = 0.10779023170471191
# statistic = 2.210457431483837 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 1.1260231112954944
# relative_error_metric = 1.1158696156981684
#
# ------------ 8 ------------
# eps = 0.06896317005157471
# statistic = 1.077159051846505 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.7835992806490999
# relative_error_metric = 0.5279815356262055
#
# ------------ 9 ------------
# eps = 0.049549639225006104
# statistic = 0.7380506656629761 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.4872522729737715
# relative_error_metric = 0.16235866722814396
#
# ------------ 10 ------------
# eps = 0.0398428738117218
# statistic = 0.623270966433998 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.21717177610380345
# relative_error_metric = 0.006314355046289885
#
# ------------ 11 ------------
# eps = 0.04469625651836395
# statistic = 0.6764310043180182 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.11481979262601737
# relative_error_metric = 0.07549882178713671
#
# ------------ 12 ------------
# eps = 0.04226956516504288
# statistic = 0.6488250620126009 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.059106546670907076
# relative_error_metric = 0.033864155171660776
#
# ------------ 13 ------------
# eps = 0.04105621948838234
# statistic = 0.6357956110721396 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.02999652102797982
# relative_error_metric = 0.013581198341201037
#
# ------------ 14 ------------
# eps = 0.04044954665005207
# statistic = 0.6294707034590573 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.01511158425269039
# relative_error_metric = 0.0035835708324041217
#
# ------------ 15 ------------
# eps = 0.040146210230886936
# statistic = 0.6263552534576481 - next threshold = 0.6272189852022225 at 0.99 CL
# relative_error_eps = 0.007527354563174872
# relative_error_metric = 0.0013780304635133632
# =======> statistic within required accuracy at 0.99 CL in 211.39535479992628 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 418.0715553322807 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# Computing exclusion limits for kpd with mean deformation.
#
# ======================================================
# =============== kpd - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# Computing (Tensor("while/Placeholder:0", shape=(), dtype=int32),Tensor("while/while/Placeholder:0", shape=(), dtype=int32)) component
# statistic = 49.506770198952225 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9726715799564047
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 12.180739025858145 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8912054895491326
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 3.0510860755335045 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.598351974138439
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 0.6919618717917686 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6806614366121552
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 0.04818121048710822 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.504236388255822
#
# ------------ 6 ------------
# eps = 0.234375
# statistic = 0.3258076991872194 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.04428324312887013
#
# ------------ 7 ------------
# eps = 0.2734375
# statistic = 0.4977920466178176 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 0.15384615384615385
# relative_error_metric = 0.37509164159970243
#
# ------------ 8 ------------
# eps = 0.25390625
# statistic = 0.4090301068382374 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 0.08
# relative_error_metric = 0.1826803605518167
#
# ------------ 9 ------------
# eps = 0.244140625
# statistic = 0.36672688257644026 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 0.04081632653061224
# relative_error_metric = 0.07398579545649964
#
# ------------ 10 ------------
# eps = 0.2392578125
# statistic = 0.34609433801779943 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 0.020618556701030927
# relative_error_metric = 0.016113233055609962
#
# ------------ 11 ------------
# eps = 0.23681640625
# statistic = 0.33590778689251977 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 0.010256410256410256
# relative_error_metric = 0.01376091374348121
#
# ------------ 12 ------------
# eps = 0.238037109375
# statistic = 0.3409902537168108 - next threshold = 0.3405622095279171 at 0.95 CL
# relative_error_eps = 0.005141388174807198
# relative_error_metric = 0.0012560858099048354
# =======> statistic within required accuracy at 0.95 CL in 353.91002088505775 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.2374267578125
# statistic = 0.3384463182207753 - next threshold = 0.3937468760378593 at 0.99 CL
# relative_error_eps = 1.8186691527793963
# relative_error_metric = 0.15105455295327427
#
# ------------ 2 ------------
# eps = 2.61871337890625
# statistic = 54.49077960982329 - next threshold = 0.3937468760378593 at 0.99 CL
# relative_error_eps = 1.6674858425045411
# relative_error_metric = 1.9713036149713858
#
# ------------ 3 ------------
# ...
# eps = 0.026605352759361267
# statistic = 1.1132754114073304 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.16743196657057116
# relative_error_metric = 0.07165567800674105
#
# ------------ 12 ------------
# eps = 0.02903614193201065
# statistic = 1.1791502228087598 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.0803525854356552
# relative_error_metric = 0.014198585390410856
#
# ------------ 13 ------------
# eps = 0.030251536518335342
# statistic = 1.2125327624487083 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.04099990480627763
# relative_error_metric = 0.013718296079100812
#
# ------------ 14 ------------
# eps = 0.029643839225172997
# statistic = 1.1958062465356616 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.020291960293051844
# relative_error_metric = 0.00017221163558408435
#
# ------------ 15 ------------
# eps = 0.02994768787175417
# statistic = 1.2041607632318034 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.010197713043565915
# relative_error_metric = 0.006789983348266917
#
# ------------ 16 ------------
# eps = 0.029795763548463583
# statistic = 1.1999813595234765 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.0051118889158515675
# relative_error_metric = 0.0033131670956523794
# =======> statistic within required accuracy at 0.99 CL in 215.90583896357566 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 415.56003917194903 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# Computing exclusion limits for swd with std deformation.
#
# ======================================================
# =============== swd - only std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 20.07101589379792 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8123673420966564
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 9.472944540948879 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6222720553260357
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 7.959466611155595 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5583775840186644
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 4.64250140708923 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2982071627759422
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 2.503504865894664 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8682479368618435
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 1.401612528978541 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.3463404537931945
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 0.8968362359444025 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.09656412002621033
#
# ------------ 8 ------------
# eps = 0.05859375
# statistic = 1.1396340431773315 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.14270700612577672
#
# ------------ 9 ------------
# eps = 0.048828125
# statistic = 1.0146994480618547 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.026833589755325744
#
# ------------ 10 ------------
# eps = 0.0439453125
# statistic = 0.9546467314376313 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.10526315789473684
# relative_error_metric = 0.03416785531913602
#
# ------------ 11 ------------
# eps = 0.04638671875
# statistic = 0.9844224233947637 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.05128205128205128
# relative_error_metric = 0.00345743686039397
#
# ------------ 12 ------------
# eps = 0.047607421875
# statistic = 0.9995021610351273 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.025974025974025976
# relative_error_metric = 0.01174464374492975
#
# ------------ 13 ------------
# eps = 0.0469970703125
# statistic = 0.9919466481765215 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.013071895424836602
# relative_error_metric = 0.004156780467901316
#
# ------------ 14 ------------
# eps = 0.04669189453125
# statistic = 0.9881805770210083 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.006557377049180328
# relative_error_metric = 0.0003529140027613701
# =======> statistic within required accuracy at 0.95 CL in 190.35190635360777 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.046539306640625
# statistic = 0.98630055294734 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.9631119039700058
# relative_error_metric = 0.19219210736013012
#
# ------------ 2 ------------
# eps = 2.5232696533203125
# statistic = 20.4787555925047 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.927559896683787
# relative_error_metric = 1.77928027507599
#
# ------------ 3 ------------
# eps = 1.2849044799804688
# statistic = 9.464609390386435 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.860183938343409
# relative_error_metric = 1.5512411030351643
#
# ------------ 4 ------------
# eps = 0.6657218933105469
# statistic = 8.260320196532751 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.7386391023752779
# relative_error_metric = 1.4940904585965085
#
# ------------ 5 ------------
# eps = 0.35613059997558594
# statistic = 5.196784374774914 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.537692726712929
# relative_error_metric = 1.2516500828555548
#
# ------------ 6 ------------
# eps = 0.20133495330810547
# statistic = 3.1395946765514737 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.2489852451763077
# relative_error_metric = 0.8965676721425865
#
# ------------ 7 ------------
# eps = 0.12393712997436523
# statistic = 2.04414628830303 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.9080178454050879
# relative_error_metric = 0.5235139554983296
#
# ------------ 8 ------------
# eps = 0.08523821830749512
# statistic = 1.499618652838033 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.5873370543589372
# relative_error_metric = 0.2252581854434067
#
# ------------ 9 ------------
# eps = 0.06588876247406006
# statistic = 1.2359659422002818 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.3442104091229596
# relative_error_metric = 0.03285699452123689
#
# ------------ 10 ------------
# eps = 0.05621403455734253
# statistic = 1.1087082433912137 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.1584685715959376
# relative_error_metric = 0.07576099134158601
#
# ------------ 11 ------------
# eps = 0.061051398515701294
# statistic = 1.171842673200145 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.07621487038682632
# relative_error_metric = 0.020414699509431214
#
# ------------ 12 ------------
# eps = 0.06347008049488068
# statistic = 1.203788568783263 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.03884762690577808
# relative_error_metric = 0.006480848642647236
#
# ------------ 13 ------------
# eps = 0.062260739505290985
# statistic = 1.187785789974273 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.019236985642629868
# relative_error_metric = 0.0069019322046018385
#
# ------------ 14 ------------
# eps = 0.06286541000008583
# statistic = 1.1957799471962651 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.009572456519158994
# relative_error_metric = 0.00019420485434868448
# =======> statistic within required accuracy at 0.99 CL in 187.36701256595552 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 377.7189527852461 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# Computing exclusion limits for swd with both deformation.
#
# ======================================================
# =============== swd - mean+std ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 2.5
# statistic = 79.78133245204845 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9510787611207046
#
# ------------ 2 ------------
# eps = 1.25
# statistic = 40.01089642101507 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.9036231672209623
#
# ------------ 3 ------------
# eps = 0.625
# statistic = 21.697625943444777 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.825821122450154
#
# ------------ 4 ------------
# eps = 0.3125
# statistic = 11.205641920326423 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.675947343412474
#
# ------------ 5 ------------
# eps = 0.15625
# statistic = 5.692201238984853 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4084868288190937
#
# ------------ 6 ------------
# eps = 0.078125
# statistic = 2.929852262110767 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9914124202234318
#
# ------------ 7 ------------
# eps = 0.0390625
# statistic = 1.595017135809047 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4701670384883942
#
# ------------ 8 ------------
# eps = 0.01953125
# statistic = 0.9836137756285983 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.004279215215443774
#
# ------------ 9 ------------
# eps = 0.029296875
# statistic = 1.2798541879916434 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.2575508967448363
#
# ------------ 10 ------------
# eps = 0.0244140625
# statistic = 1.1284169518683762 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.2222222222222222
# relative_error_metric = 0.13286249983207316
#
# ------------ 11 ------------
# eps = 0.02197265625
# statistic = 1.055008945056869 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.11764705882352941
# relative_error_metric = 0.06576826537676499
#
# ------------ 12 ------------
# eps = 0.020751953125
# statistic = 1.0190298739092143 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.06060606060606061
# relative_error_metric = 0.031091307428310053
#
# ------------ 13 ------------
# eps = 0.0201416015625
# statistic = 1.0012476768300422 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.03076923076923077
# relative_error_metric = 0.013489436249185378
#
# ------------ 14 ------------
# eps = 0.01983642578125
# statistic = 0.992411294814766 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.015503875968992248
# relative_error_metric = 0.004625087515652191
#
# ------------ 15 ------------
# eps = 0.019683837890625
# statistic = 0.9880075285526467 - next threshold = 0.987831895785366 at 0.95 CL
# relative_error_eps = 0.007782101167315175
# relative_error_metric = 0.00017778040575292626
# =======> statistic within required accuracy at 0.95 CL in 198.40688771754503 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.0196075439453125
# statistic = 0.9858094274535788 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.9843752374872707
# relative_error_metric = 0.1926855672376765
#
# ------------ 2 ------------
# eps = 2.5098037719726562
# statistic = 80.12730120430662 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.968992715701208
# relative_error_metric = 1.9411724807556163
#
# ------------ 3 ------------
# eps = 1.2647056579589844
# statistic = 40.43099206164372 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.9389322046483999
# relative_error_metric = 1.8850734308320043
#
# ------------ 4 ------------
# eps = 0.6421566009521484
# statistic = 22.243930303489595 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.8814831894626105
# relative_error_metric = 1.795901854956554
#
# ------------ 5 ------------
# eps = 0.33088207244873047
# statistic = 11.846372381991722 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.7762268206739862
# relative_error_metric = 1.6331921700775
#
# ------------ 6 ------------
# eps = 0.17524480819702148
# statistic = 6.366621333422613 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.5974892018549562
# relative_error_metric = 1.3674096774026665
#
# ------------ 7 ------------
# eps = 0.09742617607116699
# statistic = 3.60762330084381 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 1.3298497580850521
# relative_error_metric = 1.0040774769027747
#
# ------------ 8 ------------
# eps = 0.058516860008239746
# statistic = 2.2503573850407945 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.9960860907447109
# relative_error_metric = 0.6118584581390172
#
# ------------ 9 ------------
# eps = 0.03906220197677612
# statistic = 1.595007334330346 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.6631921691734861
# relative_error_metric = 0.28591354089291104
#
# ------------ 10 ------------
# eps = 0.02933487296104431
# statistic = 1.2810523709957633 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.39750096667042173
# relative_error_metric = 0.06866205758987795
#
# ------------ 11 ------------
# eps = 0.024471208453178406
# statistic = 1.1301560769530277 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.18078493657336953
# relative_error_metric = 0.056621973423709816
#
# ------------ 12 ------------
# eps = 0.02690304070711136
# statistic = 1.204941672983497 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.09467125237570038
# relative_error_metric = 0.007438274495911276
#
# ------------ 13 ------------
# eps = 0.025687124580144882
# statistic = 1.1673666754508978 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.04624119815273217
# relative_error_metric = 0.024241158210878008
#
# ------------ 14 ------------
# eps = 0.02629508264362812
# statistic = 1.1861111210355648 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.022856372563179423
# relative_error_metric = 0.00831281480032428
#
# ------------ 15 ------------
# eps = 0.02659906167536974
# statistic = 1.1955159357265719 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.011363255580818259
# relative_error_metric = 0.00041501522437352944
#
# ------------ 16 ------------
# eps = 0.02675105119124055
# statistic = 1.200226222826637 - next threshold = 1.1960121960186678 at 0.99 CL
# relative_error_eps = 0.005697814220218219
# relative_error_metric = 0.0035172016063407968
# =======> statistic within required accuracy at 0.99 CL in 220.63045958895236 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 419.03738018032163 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# dict_keys(['2024-04-11T23:25:45.606527', '2024-04-11T23:31:10.554306', '2024-04-11T23:36:05.914697', '2024-04-11T23:41:35.074587', '2024-04-11T23:48:05.262103', '2024-04-11T23:54:13.676716', '2024-04-12T00:01:11.751848', '2024-04-12T00:13:34.051687', '2024-04-12T00:22:59.539402', '2024-04-12T00:36:03.621034', '2024-04-12T00:44:02.192974', '2024-04-12T00:51:29.890947', '2024-04-12T01:00:09.140104', '2024-04-12T01:09:15.387598', '2024-04-12T01:17:40.307844', '2024-04-12T01:27:09.592354', '2024-04-12T01:34:05.159968', '2024-04-12T01:40:22.888033'])

# %% [markdown]
# ### Likelihood-ratio test

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter": 10_000,
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}
metrics_config[unique_key]["lr"]['kwargs']["verbose"] = True

# %%
deformations = ["mean", "std", "both"]

for deformation in deformations:
    result = {k: v for k, v in existing_data.items() if v["null_config"]["name"] == "lr" and v["deformation"] == deformation}
    if result == {}:
        print(f"Computing exclusion limits for lr with {deformation} deformation.")
        result = compute_exclusion_LR_bisection(metric_config = metrics_config[unique_key]["lr"],
                                                test_kwargs = test_kwargs,
                                                model_dir = model_dir,
                                                cl_list = [0.95, 0.99],
                                                deformation = deformation,
                                                seed_dist = 0,
                                                x_tol = 0.01,
                                                fn_tol = 0.01,
                                                eps_min = 0.,
                                                eps_max = 0.01,
                                                max_iterations = 100,
                                                save = True,
                                                verbose = True)
    else:
        print(f"Exclusion limits for LR with {deformation} deformation already loaded.")
    global_results.update(result)
print(global_results.keys())
# Out:
# Computing exclusion limits for lr with mean deformation.
#
# ======================================================
# =============== lr - only mean ===============
# ======================================================
#
# ------------ 1 ------------
# eps = 0.005
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.40085822623223 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.005000.json
# ThresholdS: [[0.95, [9500, 500], -198.5821505698653], [0.99, [9900, 100], -180.0948326165285]]
# Null distribution computed in 26.67816246766597 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.55494770500809 seconds.
# statistic = 249.55575245156842 - next threshold = -198.5821505698653 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 17.58313662281307
#
# ------------ 2 ------------
# eps = 0.0025
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.109928945079446 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.002500.json
# ThresholdS: [[0.95, [9500, 500], -38.91877904356029], [0.99, [9900, 100], -29.493749918038013]]
# Null distribution computed in 26.387822290882468 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.719617481343448 seconds.
# statistic = 64.14632796390266 - next threshold = -38.91877904356029 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 8.170837946476508
#
# ------------ 3 ------------
# eps = 0.00125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.192687303759158 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.001250.json
# ThresholdS: [[0.95, [9500, 500], -4.344900174235751], [0.99, [9900, 100], 0.3896504188950026]]
# Null distribution computed in 26.466743471100926 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.709341010078788 seconds.
# statistic = 16.91524325677346 - next threshold = -4.344900174235751 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 3.382587617762489
#
# ------------ 4 ------------
# eps = 0.000625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.123064412735403 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000625.json
# ThresholdS: [[0.95, [9500, 500], 1.5803999191102707], [0.99, [9900, 100], 3.979867444735462]]
# Null distribution computed in 26.397633620537817 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.486086573451757 seconds.
# statistic = 4.6681383765245705 - next threshold = 1.5803999191102707 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9883074445014955
#
# ------------ 5 ------------
# eps = 0.0003125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.15742721501738 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000313.json
# ThresholdS: [[0.95, [9500, 500], 1.7336637883469308], [0.99, [9900, 100], 2.933345536515472]]
# Null distribution computed in 26.431433975696564 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.562689991667867 seconds.
# statistic = 1.386698068244708 - next threshold = 1.7336637883469308 at 0.95 CL
# relative_error_eps = 0.6666666666666667
# relative_error_metric = 0.22238813063893317
#
# ------------ 6 ------------
# eps = 0.00046875
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.028069656342268 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000469.json
# ThresholdS: [[0.95, [9500, 500], 1.887916724427677], [0.99, [9900, 100], 3.686057756358053]]
# Null distribution computed in 26.302694075740874 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.302703042514622 seconds.
# statistic = 2.790575477269212 - next threshold = 1.887916724427677 at 0.95 CL
# relative_error_eps = 0.3999999999999999
# relative_error_metric = 0.38587592494613576
#
# ------------ 7 ------------
# eps = 0.000390625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 25.78173985797912 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000391.json
# ThresholdS: [[0.95, [9500, 500], 1.8686776770516687], [0.99, [9900, 100], 3.3687672722907633]]
# Null distribution computed in 26.054039479233325 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.002062382176518 seconds.
# statistic = 2.029426081889386 - next threshold = 1.8686776770516687 at 0.95 CL
# relative_error_eps = 0.22222222222222227
# relative_error_metric = 0.08247518012777863
#
# ------------ 8 ------------
# eps = 0.0003515625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.16413760650903 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000352.json
# ThresholdS: [[0.95, [9500, 500], 1.8159906923931999], [0.99, [9900, 100], 3.166787976763865]]
# Null distribution computed in 26.435188348405063 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.412464793771505 seconds.
# statistic = 1.693259401798108 - next threshold = 1.8159906923931999 at 0.95 CL
# relative_error_eps = 0.10526315789473693
# relative_error_metric = 0.06994730344140652
#
# ------------ 9 ------------
# eps = 0.00037109375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.276329753920436 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000371.json
# ThresholdS: [[0.95, [9500, 500], 1.8452351222181869], [0.99, [9900, 100], 3.271524775375689]]
# Null distribution computed in 26.608219494111836 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.432874084450305 seconds.
# statistic = 1.8576420735959684 - next threshold = 1.8452351222181869 at 0.95 CL
# relative_error_eps = 0.054054054054054106
# relative_error_metric = 0.006701249175536677
#
# ------------ 10 ------------
# eps = 0.000361328125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 25.859770042821765 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000361.json
# ThresholdS: [[0.95, [9500, 500], 1.8315012063856644], [0.99, [9900, 100], 3.22009316382303]]
# Null distribution computed in 26.1298158923164 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.601147779263556 seconds.
# statistic = 1.7745255706510425 - next threshold = 1.8315012063856644 at 0.95 CL
# relative_error_eps = 0.02666666666666669
# relative_error_metric = 0.03160022887098038
#
# ------------ 11 ------------
# eps = 0.0003662109375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.215446151793003 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000366.json
# ThresholdS: [[0.95, [9500, 500], 1.8385483484589595], [0.99, [9900, 100], 3.2460431665479628]]
# Null distribution computed in 26.48917093127966 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.572384621016681 seconds.
# statistic = 1.8158525303522308 - next threshold = 1.8385483484589595 at 0.95 CL
# relative_error_eps = 0.013245033112582794
# relative_error_metric = 0.012421088358599492
#
# ------------ 12 ------------
# eps = 0.00036865234375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.19469726923853 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000369.json
# ThresholdS: [[0.95, [9500, 500], 1.8419323375297816], [0.99, [9900, 100], 3.2588425202195563]]
# Null distribution computed in 26.532488897442818 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.7144556902349 seconds.
# statistic = 1.836689479037455 - next threshold = 1.8419323375297816 at 0.95 CL
# relative_error_eps = 0.006600660066006606
# relative_error_metric = 0.0028504471259940415
# =======> statistic within required accuracy at 0.95 CL in 627.818217298016 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 ------------
# eps = 0.00036987304687500003
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.35707727726549 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000370.json
# ThresholdS: [[0.95, [9500, 500], 1.843598360551523], [0.99, [9900, 100], 3.2651982851429247]]
# Null distribution computed in 26.630665487609804 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.76736532151699 seconds.
# statistic = 1.8471513205732892 - next threshold = 3.2651982851429247 at 0.99 CL
# relative_error_eps = 1.8573278399058268
# relative_error_metric = 0.5547535180239201
#
# ------------ 2 ------------
# eps = 0.0051849365234375
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.305983015336096 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.005185.json
# ThresholdS: [[0.95, [9500, 500], -215.17535712593843], [0.99, [9900, 100], -196.0165268514756]]
# Null distribution computed in 26.5841676723212 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.386897793971002 seconds.
# statistic = 268.08830987454843 - next threshold = -196.0165268514756 at 0.99 CL
# relative_error_eps = 1.7336556422371168
# relative_error_metric = 12.878960870926335
#
# ------------ 3 ------------
# eps = 0.00277740478515625
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.56499905604869 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.002777.json
# ThresholdS: [[0.95, [9500, 500], -50.73467752909989], [0.99, [9900, 100], -40.25765526963667]]
# Null distribution computed in 26.839678244665265 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.297131409868598 seconds.
# statistic = 78.73845941505388 - next threshold = -40.25765526963667 at 0.99 CL
# relative_error_eps = 1.5299137011538833
# relative_error_metric = 6.184699999252076
#
# ------------ 4 ------------
# eps = 0.0015736389160156251
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.158137931488454 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.001574.json
# ThresholdS: [[0.95, [9500, 500], -10.390812344860947], [0.99, [9900, 100], -4.446449859197092]]
# Null distribution computed in 26.431869159452617 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.745203383266926 seconds.
# statistic = 26.235455455601954 - next threshold = -4.446449859197092 at 0.99 CL
# relative_error_eps = 1.2387532385962159
# relative_error_metric = 2.816274031327202
#
# ------------ 5 ------------
# eps = 0.0009717559814453125
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.059137186966836 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000972.json
# ThresholdS: [[0.95, [9500, 500], -0.7873894855364227], [0.99, [9900, 100], 2.9239887091951524]]
# Null distribution computed in 26.372484475374222 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.52244866359979 seconds.
# statistic = 10.526962843178532 - next threshold = 2.9239887091951524 at 0.99 CL
# relative_error_eps = 0.8972419675860107
# relative_error_metric = 1.1304737965012872
#
# ------------ 6 ------------
# eps = 0.0006708145141601563
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.145194251090288 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000671.json
# ThresholdS: [[0.95, [9500, 500], 1.4010640445345848], [0.99, [9900, 100], 3.975416957568896]]
# Null distribution computed in 26.41716301906854 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.583301686681807 seconds.
# statistic = 5.3084716271456465 - next threshold = 3.975416957568896 at 0.99 CL
# relative_error_eps = 0.578351233459184
# relative_error_metric = 0.28717593008851017
#
# ------------ 7 ------------
# eps = 0.0005203437805175782
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.023677893914282 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_mean_0.000520.json
# ThresholdS: [[0.95, [9500, 500], 1.838102036053015], [0.99, [9900, 100], 3.834764997928662]]
# Null distribution computed in 26.296580503694713 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.649767953902483 seconds.
# statistic = 3.358165074480703 - next threshold = 3.834764997928662 at 0.99 CL
# relative_error_eps = 0.2526460745224255
# relative_error_metric = 0.1325189925802562
#
# ------------ 8 ------------
# eps = 0.0005955791473388673
# Computing null distribution
# Parsing input distribution...
# ...
# eps = 0.0005035209655761719
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.502437599003315 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_both_0.000504.json
# ThresholdS: [[0.95, [9500, 500], 1.7734984335835562], [0.99, [9900, 100], 3.850215497443025]]
# Null distribution computed in 26.772810101509094 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.758150384761393 seconds.
# statistic = 3.6908482441601174 - next threshold = 3.850215497443025 at 0.99 CL
# relative_error_eps = 0.2603910973460074
# relative_error_metric = 0.04226651802548693
#
# ------------ 8 ------------
# eps = 0.0005788898468017578
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.42982865218073 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_both_0.000579.json
# ThresholdS: [[0.95, [9500, 500], 1.4836947147475068], [0.99, [9900, 100], 3.875720899401507]]
# Null distribution computed in 26.703920604661107 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 14.023283389396966 seconds.
# statistic = 4.796174517353511 - next threshold = 3.875720899401507 at 0.99 CL
# relative_error_eps = 0.13926113886465954
# relative_error_metric = 0.21228429857989073
#
# ------------ 9 ------------
# eps = 0.0005412054061889648
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.51496958360076 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_both_0.000541.json
# ThresholdS: [[0.95, [9500, 500], 1.6444519079069582], [0.99, [9900, 100], 3.88115702552336]]
# Null distribution computed in 26.784821202978492 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.99929445143789 seconds.
# statistic = 4.225506370582983 - next threshold = 3.88115702552336 at 0.99 CL
# relative_error_eps = 0.07214222141080351
# relative_error_metric = 0.08495464243032848
#
# ------------ 10 ------------
# eps = 0.0005223631858825683
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.58525351062417 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_both_0.000522.json
# ThresholdS: [[0.95, [9500, 500], 1.7135960265864436], [0.99, [9900, 100], 3.8702265870857433]]
# Null distribution computed in 26.86486495565623 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 14.007015043869615 seconds.
# statistic = 3.953676312749107 - next threshold = 3.8702265870857433 at 0.99 CL
# relative_error_eps = 0.036733621977889055
# relative_error_metric = 0.021331994205890513
#
# ------------ 11 ------------
# eps = 0.0005129420757293701
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.70621877722442 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_both_0.000513.json
# ThresholdS: [[0.95, [9500, 500], 1.744701569868621], [0.99, [9900, 100], 3.8613552647068983]]
# Null distribution computed in 26.981241525150836 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 14.102077743969858 seconds.
# statistic = 3.8211370619725016 - next threshold = 3.8613552647068983 at 0.99 CL
# relative_error_eps = 0.018199675984510756
# relative_error_metric = 0.010470092523159131
#
# ------------ 12 ------------
# eps = 0.0005176526308059693
# Computing null distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Resetting dist_num.
# Resetting dist_num.
# To run under the alternative hypothesis, set the `null_test` attribute to False.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10000
# batch_size = 50000
# nchunks = 20
# Iterating from 0 to 500 out of 10000 .
# Iterating from 500 to 1000 out of 10000 .
# Iterating from 1000 to 1500 out of 10000 .
# Iterating from 1500 to 2000 out of 10000 .
# Iterating from 2000 to 2500 out of 10000 .
# Iterating from 2500 to 3000 out of 10000 .
# Iterating from 3000 to 3500 out of 10000 .
# Iterating from 3500 to 4000 out of 10000 .
# Iterating from 4000 to 4500 out of 10000 .
# Iterating from 4500 to 5000 out of 10000 .
# Iterating from 5000 to 5500 out of 10000 .
# Iterating from 5500 to 6000 out of 10000 .
# Iterating from 6000 to 6500 out of 10000 .
# Iterating from 6500 to 7000 out of 10000 .
# Iterating from 7000 to 7500 out of 10000 .
# Iterating from 7500 to 8000 out of 10000 .
# Iterating from 8000 to 8500 out of 10000 .
# Iterating from 8500 to 9000 out of 10000 .
# Iterating from 9000 to 9500 out of 10000 .
# Iterating from 9500 to 10000 out of 10000 .
# LR metric calculation completed in 26.52120261080563 seconds.
# Saving lr to ../results_leonardo/5D_50K/null_hypothesis/LR_both_0.000518.json
# ThresholdS: [[0.95, [9500, 500], 1.7294374923683489], [0.99, [9900, 100], 3.8660745888394143]]
# Null distribution computed in 26.785458073951304 seconds
# Evaluating alternative distribution
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# Setting dist_num from dist_symb.
# To run under the null hypothesis, set the `null_test` attribute to True.
#
# ------------------------------------------
# Starting LR metric calculation...
# Running TF LR calculation...
# niter = 10
# batch_size = 50000
# LR metric calculation completed in 13.939920716919005 seconds.
# statistic = 3.88712537925351 - next threshold = 3.8660745888394143 at 0.99 CL
# relative_error_eps = 0.009141430761730063
# relative_error_metric = 0.0054302199093863085
# =======> statistic within required accuracy at 0.99 CL in 641.2567592896521 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 1281.175311437808 seconds.
# Saving results in the file ../results_leonardo/5D_50K/exclusion_limits.json
# dict_keys(['2024-04-11T23:25:45.606527', '2024-04-11T23:31:10.554306', '2024-04-11T23:36:05.914697', '2024-04-11T23:41:35.074587', '2024-04-11T23:48:05.262103', '2024-04-11T23:54:13.676716', '2024-04-12T00:01:11.751848', '2024-04-12T00:13:34.051687', '2024-04-12T00:22:59.539402', '2024-04-12T00:36:03.621034', '2024-04-12T00:44:02.192974', '2024-04-12T00:51:29.890947', '2024-04-12T01:00:09.140104', '2024-04-12T01:09:15.387598', '2024-04-12T01:17:40.307844', '2024-04-12T01:27:09.592354', '2024-04-12T01:34:05.159968', '2024-04-12T01:40:22.888033', '2024-04-12T01:47:21.950515', '2024-04-12T02:09:18.026643', '2024-04-12T02:29:30.199040'])

# %% [markdown]
# ### Show and save results

# %%
global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][0][2], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][1][2], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fn
# Metric: fn
# Metric: fn
# Metric: fpd
# Metric: fpd
# Metric: fpd
# Metric: kpd
# Metric: kpd
# Metric: kpd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: lr
# Metric: lr
# Metric: lr

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_std = results_df[results_df["Deformation"] == "std"]
results_df_both = results_df[results_df["Deformation"] == "both"]

# %%
sorted_df_mean = results_df_mean.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_mean)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 18        lr        mean    5  10000                50000
# 9         ks        mean    5  10000                50000
# 12       sks        mean    5  10000                50000
# 15       swd        mean    5  10000                50000
# 3        fpd        mean    5  10000                50000
# 0         fn        mean    5  10000                50000
# 6        kpd        mean    5  10000                50000
#
#     $\epsilon^{\mu}_{95\%\mathrm{CL}}$  $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 18                             0.00037                             0.00057
# 9                              0.00399                             0.00568
# 12                             0.01286                             0.01719
# 15                             0.02174                             0.02972
# 3                              0.03250                             0.04357
# 0                              0.03342                             0.04327
# 6                              0.23743                             0.25080
#
#     $t^{\mu}$ (s)
# 18           1316
# 9             478
# 12            546
# 15            415
# 3             390
# 0             324
# 6             742
#    Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 18        lr                             0.00037
# 9         ks                             0.00399
# 12       sks                             0.01286
# 15       swd                             0.02174
# 3        fpd                             0.03250
# 0         fn                             0.03342
# 6        kpd                             0.23743
#
#     $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 18                             0.00057           1316
# 9                              0.00568            478
# 12                             0.01719            546
# 15                             0.02972            415
# 3                              0.04357            390
# 0                              0.04327            324
# 6                              0.25080            742

# %%
sorted_df_std = results_df_std.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_std.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\sigma}$ (s)"}, inplace=True)
display(sorted_df_std)
sorted_df_std.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_std)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 19        lr         std    5  10000                50000
# 10        ks         std    5  10000                50000
# 13       sks         std    5  10000                50000
# 16       swd         std    5  10000                50000
# 4        fpd         std    5  10000                50000
# 1         fn         std    5  10000                50000
# 7        kpd         std    5  10000                50000
#
#     $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 19                                0.00088
# 10                                0.01324
# 13                                0.03189
# 16                                0.04654
# 4                                 0.06378
# 1                                 0.06805
# 7                                 3.07373
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 19                                0.00121              1212
# 10                                0.01727               447
# 13                                0.04235               504
# 16                                0.06317               377
# 4                                 0.08638               368
# 1                                 0.09786               295
# 7                                 3.13769               565
#    Statistic  $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 19        lr                                0.00088
# 10        ks                                0.01324
# 13       sks                                0.03189
# 16       swd                                0.04654
# 4        fpd                                0.06378
# 1         fn                                0.06805
# 7        kpd                                3.07373
#
#     $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)
# 19                                0.00121              1212
# 10                                0.01727               447
# 13                                0.04235               504
# 16                                0.06317               377
# 4                                 0.08638               368
# 1                                 0.09786               295
# 7                                 3.13769               565

# %%
sorted_df_both = results_df_both.sort_values(by="$\\epsilon_{95\\%\\mathrm{CL}}$", ascending=True)
sorted_df_both.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu-\\sigma}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu-\\sigma}$ (s)"}, inplace=True)
display(sorted_df_both)
sorted_df_both.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$"], inplace=True)
display(sorted_df_both)
# Out:
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 20        lr        both    5  10000                50000
# 11        ks        both    5  10000                50000
# 14       sks        both    5  10000                50000
# 17       swd        both    5  10000                50000
# 5        fpd        both    5  10000                50000
# 2         fn        both    5  10000                50000
# 8        kpd        both    5  10000                50000
#
#     $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 20                                    0.00035
# 11                                    0.00371
# 14                                    0.01171
# 17                                    0.01961
# 5                                     0.03014
# 2                                     0.03044
# 8                                     0.23956
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 20                                    0.00052                  1281
# 11                                    0.00522                   519
# 14                                    0.01559                   569
# 17                                    0.02668                   419
# 5                                     0.04030                   418
# 2                                     0.03939                   329
# 8                                     0.25177                   784
#    Statistic  $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 20        lr                                    0.00035
# 11        ks                                    0.00371
# 14       sks                                    0.01171
# 17       swd                                    0.01961
# 5        fpd                                    0.03014
# 2         fn                                    0.03044
# 8        kpd                                    0.23956
#
#     $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)
# 20                                    0.00052                  1281
# 11                                    0.00522                   519
# 14                                    0.01559                   569
# 17                                    0.02668                   419
# 5                                     0.04030                   418
# 2                                     0.03939                   329
# 8                                     0.25177                   784

# %%
result_table = sorted_df_mean.merge(sorted_df_std, on='Statistic', how='outer').merge(sorted_df_both, on='Statistic', how='outer').merge(times_df, on='Statistic', how='outer')
result_table = result_table.replace("lr","$t_{\\mathrm{LLR}}$").replace("ks","$\\overline{D}$").replace("sks","$\\widetilde{D}$").replace("swd","$\\widetilde{W}$").replace("fpd","$d_{\\mathrm{FPD}}$").replace("fn","$\\overline{\\|\cdot\\|}_{F}$").replace("kpd","$d_{\\mathrm{KPD}}$")
display(result_table)
print(result_table.to_latex(index=False, column_format='l|llr|llr|llr|r', longtable=False, float_format="%.2g"))
# Out:
#                     Statistic  $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 0  $\overline{\|\cdot\|}_{F}$                             0.03342
# 1          $d_{\mathrm{FPD}}$                             0.03250
# 2          $d_{\mathrm{KPD}}$                             0.23743
# 3              $\overline{D}$                             0.00399
# 4          $t_{\mathrm{LLR}}$                             0.00037
# 5             $\widetilde{D}$                             0.01286
# 6             $\widetilde{W}$                             0.02174
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)  \
# 0                             0.04327            324
# 1                             0.04357            390
# 2                             0.25080            742
# 3                             0.00568            478
# 4                             0.00057           1316
# 5                             0.01719            546
# 6                             0.02972            415
#
#    $\epsilon^{\sigma}_{95\%\mathrm{CL}}$  \
# 0                                0.06805
# 1                                0.06378
# 2                                3.07373
# 3                                0.01324
# 4                                0.00088
# 5                                0.03189
# 6                                0.04654
#
#    $\epsilon^{\sigma}_{99\%\mathrm{CL}}$  $t^{\sigma}$ (s)  \
# 0                                0.09786               295
# 1                                0.08638               368
# 2                                3.13769               565
# 3                                0.01727               447
# 4                                0.00121              1212
# 5                                0.04235               504
# 6                                0.06317               377
#
#    $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$  \
# 0                                    0.03044
# 1                                    0.03014
# 2                                    0.23956
# 3                                    0.00371
# 4                                    0.00035
# 5                                    0.01171
# 6                                    0.01961
#
#    $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$  $t^{\mu-\sigma}$ (s)  \
# 0                                    0.03939                   329
# 1                                    0.04030                   418
# 2                                    0.25177                   784
# 3                                    0.00522                   519
# 4                                    0.00052                  1281
# 5                                    0.01559                   569
# 6                                    0.02668                   419
#
#   $t^{\mathrm{null}}$ (s)
# 0                      23
# 1                     175
# 2                   21290
# 3                      65
# 4                       -
# 5                     538
# 6                     316
# \begin{tabular}{l|llr|llr|llr|r}
# \toprule
# Statistic & $\epsilon^{\mu}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu}_{99\%\mathrm{CL}}$ & $t^{\mu}$ (s) & $\epsilon^{\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\sigma}_{99\%\mathrm{CL}}$ & $t^{\sigma}$ (s) & $\epsilon^{\mu-\sigma}_{95\%\mathrm{CL}}$ & $\epsilon^{\mu-\sigma}_{99\%\mathrm{CL}}$ & $t^{\mu-\sigma}$ (s) & $t^{\mathrm{null}}$ (s) \\
# \midrule
# $\overline{\|\cdot\|}_{F}$ & 0.033 & 0.043 & 324 & 0.068 & 0.098 & 295 & 0.03 & 0.039 & 329 & 23 \\
# $d_{\mathrm{FPD}}$ & 0.033 & 0.044 & 390 & 0.064 & 0.086 & 368 & 0.03 & 0.04 & 418 & 175 \\
# $d_{\mathrm{KPD}}$ & 0.24 & 0.25 & 742 & 3.1 & 3.1 & 565 & 0.24 & 0.25 & 784 & 21290 \\
# $\overline{D}$ & 0.004 & 0.0057 & 478 & 0.013 & 0.017 & 447 & 0.0037 & 0.0052 & 519 & 65 \\
# $t_{\mathrm{LLR}}$ & 0.00037 & 0.00057 & 1316 & 0.00088 & 0.0012 & 1212 & 0.00035 & 0.00052 & 1281 & - \\
# $\widetilde{D}$ & 0.013 & 0.017 & 546 & 0.032 & 0.042 & 504 & 0.012 & 0.016 & 569 & 538 \\
# $\widetilde{W}$ & 0.022 & 0.03 & 415 & 0.047 & 0.063 & 377 & 0.02 & 0.027 & 419 & 316 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Fixed $\epsilon$

# %%
fpd_results = {5: {10_000: [[0.68, 0.00010175550386551708], 
                            [0.95, 0.00015583746551772079], 
                            [0.99, 0.00022347410983350775]],
                   50_000: [[0.68, 4.5226688115357585e-05], 
                            [0.95, 5.398123973119404e-05], 
                            [0.99, 6.354077850007809e-05]],
                   100_000 : [[0.68, 3.725127064668703e-05], 
                              [0.95, 4.0825583153507725e-05], 
                              [0.99, 4.465564257168013e-05]],
                   200_000 : [[0.68, 3.3691504288769034e-05], 
                              [0.95, 3.5351867696872585e-05], 
                              [0.99, 3.68684570537516e-05]]},
               20: {10_000: [[0.68, 0.0006669445748113884], 
                             [0.95, 0.0013217846893085318], 
                             [0.99, 0.0019605548728214763]],
                    50_000: [[0.68, 0.00031117601754665936], 
                             [0.95, 0.00040269921440860503], 
                             [0.99, 0.000502723348035641]],
                    100_000 : [[0.68, 0.00015735387007512796], 
                               [0.95, 0.0001991294338873111], 
                               [0.99, 0.00028358152805583374]]},
               100: {10_000: [[0.68, 0.0060367495598200515], 
                              [0.95, 0.009021833572706342], 
                              [0.99, 0.011125954730711617]],
                     50_000: [[0.68, 0.0012229712948642107], 
                              [0.95, 0.001787009273603958], 
                              [0.99, 0.0022351123346437667]],
                    100_000 : [[0.68, 0.000817842570244682], 
                               [0.95, 0.0011978135448655475], 
                               [0.99, 0.001414743609381014]]}}
fpd_results
# Out:
# {5: {10000: [[0.68, 0.00010175550386551708],
#    [0.95, 0.00015583746551772079],
#    [0.99, 0.00022347410983350775]],
#   50000: [[0.68, 4.5226688115357585e-05],
#    [0.95, 5.398123973119404e-05],
#    [0.99, 6.354077850007809e-05]],
#   100000: [[0.68, 3.725127064668703e-05],
#    [0.95, 4.0825583153507725e-05],
#    [0.99, 4.465564257168013e-05]],
#   200000: [[0.68, 3.3691504288769034e-05],
#    [0.95, 3.5351867696872585e-05],
#    [0.99, 3.68684570537516e-05]]},
#  20: {10000: [[0.68, 0.0006669445748113884],
#    [0.95, 0.0013217846893085318],
#    [0.99, 0.0019605548728214763]],
#   50000: [[0.68, 0.00031117601754665936],
#    [0.95, 0.00040269921440860503],
#    [0.99, 0.000502723348035641]],
#   100000: [[0.68, 0.00015735387007512796],
#    [0.95, 0.0001991294338873111],
#    [0.99, 0.00028358152805583374]]},
#  100: {10000: [[0.68, 0.0060367495598200515],
#    [0.95, 0.009021833572706342],
#    [0.99, 0.011125954730711617]],
#   50000: [[0.68, 0.0012229712948642107],
#    [0.95, 0.001787009273603958],
#    [0.99, 0.0022351123346437667]],
#   100000: [[0.68, 0.000817842570244682],
#    [0.95, 0.0011978135448655475],
#    [0.99, 0.001414743609381014]]}}

# %%
def define_norm_df(dic,x,y):
    # Flatten the dictionary to a list of rows
    rows = []
    for N, n_dict in dic.items():
        for n, values in n_dict.items():
            row = {'N': N, 'n': n}
            for confidence, value in values:
                row[confidence] = value*(N**x)*(n**y)
            rows.append(row)

    # Convert the list of rows to a DataFrame
    df = pd.DataFrame(rows)

    # Optionally, rename the columns for clarity
    df.rename(columns={0.68: '0.68', 0.95: '0.95', 0.99: '0.99'}, inplace=True)
    return df

df = define_norm_df(fpd_results,0.,0.)
# Show the DataFrame
display(df)
# Out:
#      N       n      0.68      0.95      0.99
# 0    5   10000  0.000102  0.000156  0.000223
# 1    5   50000  0.000045  0.000054  0.000064
# 2    5  100000  0.000037  0.000041  0.000045
# 3    5  200000  0.000034  0.000035  0.000037
# 4   20   10000  0.000667  0.001322  0.001961
# 5   20   50000  0.000311  0.000403  0.000503
# 6   20  100000  0.000157  0.000199  0.000284
# 7  100   10000  0.006037  0.009022  0.011126
# 8  100   50000  0.001223  0.001787  0.002235
# 9  100  100000  0.000818  0.001198  0.001415
